# %%
import numpy as np

import sensors
import em_stoch

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 20
Num_emitters1 = 1
sample_size1 = 80
failing_sensors1 = np.array([2, 4], dtype=np.int16)
gap_ratio1 = np.array([0.5, 0.5], dtype=np.float32)
theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P_1 = 1 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q_1 = 2.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
N1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + N1.T).T

Num_sensors2 = 20
Num_emitters2 = 2
sample_size2 = 80
failing_sensors2 = np.array([2, 4], dtype=np.int16)
gap_ratio2 = np.array([0.5, 0.5], dtype=np.float32)
theta2_rad = np.array([-0.5, 0.7], dtype=np.float64) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P_2 = 1 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q_2 = 1.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sensors.gss(Num_emitters2, sample_size2, P_2)
N2 = sensors.gss(Num_sensors2, sample_size2, Q_2)
X2 = (A2 @ S2.T + N2.T).T

# %%
X1_with_mv = sensors.MCAR(X1, failing_sensors1, gap_ratio1)
X2_with_mv = sensors.MCAR(X2, failing_sensors2, gap_ratio2)

# %%
X1_with_mv
# Out:
# array([[ 1.47375889-1.19127215j,  0.03175204-1.88842948j,
#                 nan+0.j        , ..., -0.76397286-2.94873339j,
#          0.72662444+0.27358696j,  1.62576741-0.61924096j],
#        [-0.75093165-1.09293498j, -0.99980865-0.34039036j,
#          2.94445197-1.56076135j, ...,  0.33293359+0.82505105j,
#          0.07846728+0.13232699j, -1.07843768+0.39630101j],
#        [ 0.76613778+1.51307616j,  0.98300291+0.8604167j ,
#         -2.77695094-1.28910182j, ..., -0.60766186+0.05449384j,
#         -1.0589133 -1.09211055j, -0.1291021 +1.6502334j ],
#        ...,
#        [ 1.16245983+2.06921586j,  2.97479457-1.66960229j,
#         -2.74510029-0.87284081j, ...,  1.19492776-0.80840476j,
#         -2.23063739-0.51135893j,  0.20866592+3.56230975j],
#        [ 1.57700122+0.90672591j, -2.1236758 -2.06001117j,
#         -1.06651492+2.87218098j, ..., -1.12889979-0.66445606j,
#         -0.37962652-0.26983634j,  1.95978744-1.35519038j],
#        [-0.56114001+1.07715026j, -0.59027711+0.12132465j,
#                 nan+0.j        , ...,  1.47473186+0.5409653j ,
#         -1.79549689-0.86866438j, -0.2348961 -0.34663937j]], shape=(80, 20))

# %%
print(np.trace(sensors.initial_Cov(X1_with_mv)))
print(np.trace(sensors.complex_cov(X1)))
# Out:
# (73.88343486532314+0j)
# (63.702954966635296+0j)

# %%
EM_theta1_rad, EM_P1, lhd_1 = em_stoch.multi_start_EM(X1_with_mv, 
                                                      Num_emitters1, 
                                                      Q=Q_1, 
                                                      num_of_starts=10, 
                                                      max_iter=100, 
                                                      rtol=1e-6)
# Out:
# 0-th start
# theta=[0.15335215],P=[[0.00022361+0.j]]
# new_angles=[0.14840203]
# new_P:
# [[0.00130209+0.j]]
# likelihood is -3420.7933927768236 on iteration 0
# new_angles=[0.14840203]
# new_P:
# [[0.00230294+0.j]]
# 1-th start
# theta=[0.13636065],P=[[0.0023446-2.48253415e-17j]]
# new_angles=[0.13241885]
# new_P:
# [[0.01456911+0.j]]
# likelihood is -3420.345039060425 on iteration 0
# new_angles=[0.13143373]
# new_P:
# [[0.01555237+0.j]]
# likelihood is -3420.3336916219964 on iteration 1
# new_angles=[0.13054863]
# new_P:
# [[0.01661065+0.j]]
# likelihood is -3420.3293908137553 on iteration 2
# new_angles=[0.12980871]
# new_P:
# [[0.01776041+0.j]]
# likelihood is -3420.334375935114 on iteration 3
# new_angles=[0.12921475]
# new_P:
# [[0.01902063+0.j]]
# likelihood is -3420.350359027041 on iteration 4
# new_angles=[0.12854348]
# new_P:
# [[0.02041346+0.j]]
# likelihood is -3420.3748851076975 on iteration 5
# new_angles=[0.12792564]
# new_P:
# [[0.0219661+0.j]]
# likelihood is -3420.41365791147 on iteration 6
# new_angles=[0.12741645]
# new_P:
# [[0.02371006+0.j]]
# likelihood is -3420.4716944652123 on iteration 7
# new_angles=[0.12678098]
# new_P:
# [[0.02568242+0.j]]
# likelihood is -3420.5490865508627 on iteration 8
# new_angles=[0.12631217]
# new_P:
# [[0.02792831+0.j]]
# likelihood is -3420.6585725411524 on iteration 9
# new_angles=[0.12581999]
# new_P:
# [[0.03049893+0.j]]
# likelihood is -3420.804565730496 on iteration 10
# new_angles=[0.12540793]
# new_P:
# [[0.03345468+0.j]]
# likelihood is -3420.9999567880914 on iteration 11
# new_angles=[0.1249158]
# new_P:
# [[0.0368632+0.j]]
# likelihood is -3421.2545891524264 on iteration 12
# new_angles=[0.12452295]
# new_P:
# [[0.04079944+0.j]]
# likelihood is -3421.588254374198 on iteration 13
# new_angles=[0.1242769]
# new_P:
# [[0.04533953+0.j]]
# likelihood is -3422.020220229664 on iteration 14
# new_angles=[0.12394138]
# new_P:
# [[0.0505544+0.j]]
# likelihood is -3422.564654741978 on iteration 15
# new_angles=[0.12372923]
# new_P:
# [[0.05650193+0.j]]
# likelihood is -3423.244759883527 on iteration 16
# new_angles=[0.12348321]
# new_P:
# [[0.06320891+0.j]]
# likelihood is -3424.070998528 on iteration 17
# new_angles=[0.12320122]
# new_P:
# [[0.07065946+0.j]]
# likelihood is -3425.0491208273475 on iteration 18
# new_angles=[0.1229844]
# new_P:
# [[0.07878142+0.j]]
# likelihood is -3426.1754572064947 on iteration 19
# new_angles=[0.12273841]
# new_P:
# [[0.0874411+0.j]]
# likelihood is -3427.4277158390732 on iteration 20
# new_angles=[0.12249242]
# new_P:
# [[0.0964559+0.j]]
# likelihood is -3428.774316440608 on iteration 21
# new_angles=[0.12224644]
# new_P:
# [[0.10561605+0.j]]
# likelihood is -3430.1752920822714 on iteration 22
# new_angles=[0.12200047]
# new_P:
# [[0.11471666+0.j]]
# likelihood is -3431.589857506053 on iteration 23
# new_angles=[0.12181754]
# new_P:
# [[0.12358759+0.j]]
# likelihood is -3432.9842954581068 on iteration 24
# new_angles=[0.12163659]
# new_P:
# [[0.13211133+0.j]]
# likelihood is -3434.33185778917 on iteration 25
# new_angles=[0.12149559]
# new_P:
# [[0.14023011+0.j]]
# likelihood is -3435.6192663893053 on iteration 26
# new_angles=[0.12136285]
# new_P:
# [[0.14793601+0.j]]
# likelihood is -3436.841358239521 on iteration 27
# new_angles=[0.12121932]
# new_P:
# [[0.15525793+0.j]]
# likelihood is -3438.0003884542803 on iteration 28
# new_angles=[0.12107523]
# new_P:
# [[0.1622455+0.j]]
# likelihood is -3439.103320847028 on iteration 29
# new_angles=[0.12097061]
# new_P:
# [[0.16895557+0.j]]
# likelihood is -3440.1592106563535 on iteration 30
# new_angles=[0.12084764]
# new_P:
# [[0.17544284+0.j]]
# likelihood is -3441.175284068254 on iteration 31
# new_angles=[0.12073963]
# new_P:
# [[0.181757+0.j]]
# likelihood is -3442.1597029401964 on iteration 32
# new_angles=[0.12063322]
# new_P:
# [[0.18793858+0.j]]
# likelihood is -3443.1184297509153 on iteration 33
# new_angles=[0.12051175]
# new_P:
# [[0.19401997+0.j]]
# likelihood is -3444.056156849617 on iteration 34
# new_angles=[0.12040792]
# new_P:
# [[0.20002621+0.j]]
# likelihood is -3444.977137187274 on iteration 35
# new_angles=[0.12032141]
# new_P:
# [[0.2059754+0.j]]
# likelihood is -3445.8840215499713 on iteration 36
# new_angles=[0.12025212]
# new_P:
# [[0.21188084+0.j]]
# likelihood is -3446.778735040278 on iteration 37
# new_angles=[0.12016201]
# new_P:
# [[0.21775226+0.j]]
# likelihood is -3447.662228523314 on iteration 38
# new_angles=[0.1200787]
# new_P:
# [[0.22359725+0.j]]
# likelihood is -3448.5359266888345 on iteration 39
# new_angles=[0.11999891]
# new_P:
# [[0.22942082+0.j]]
# likelihood is -3449.4004876595836 on iteration 40
# new_angles=[0.11993893]
# new_P:
# [[0.23522671+0.j]]
# likelihood is -3450.2565718789524 on iteration 41
# new_angles=[0.1199023]
# new_P:
# [[0.24101746+0.j]]
# likelihood is -3451.104533788177 on iteration 42
# new_angles=[0.11986047]
# new_P:
# [[0.24679505+0.j]]
# likelihood is -3451.944380359318 on iteration 43
# new_angles=[0.1197968]
# new_P:
# [[0.25256143+0.j]]
# likelihood is -3452.776264816031 on iteration 44
# new_angles=[0.11975606]
# new_P:
# [[0.25831828+0.j]]
# likelihood is -3453.600800004195 on iteration 45
# new_angles=[0.11969636]
# new_P:
# [[0.26406628+0.j]]
# likelihood is -3454.4177705903053 on iteration 46
# new_angles=[0.11964847]
# new_P:
# [[0.26980666+0.j]]
# likelihood is -3455.2275962598733 on iteration 47
# new_angles=[0.11962122]
# new_P:
# [[0.27553995+0.j]]
# likelihood is -3456.030416946322 on iteration 48
# new_angles=[0.11957927]
# new_P:
# [[0.28126661+0.j]]
# likelihood is -3456.826098576219 on iteration 49
# new_angles=[0.11953996]
# new_P:
# [[0.28698751+0.j]]
# likelihood is -3457.6149105230293 on iteration 50
# new_angles=[0.11950328]
# new_P:
# [[0.2927031+0.j]]
# likelihood is -3458.3969518030913 on iteration 51
# new_angles=[0.11946844]
# new_P:
# [[0.29841381+0.j]]
# likelihood is -3459.172316735767 on iteration 52
# new_angles=[0.11943573]
# new_P:
# [[0.30412003+0.j]]
# likelihood is -3459.9411050868757 on iteration 53
# new_angles=[0.11940896]
# new_P:
# [[0.3098221+0.j]]
# likelihood is -3460.703427302821 on iteration 54
# new_angles=[0.11939111]
# new_P:
# [[0.31552031+0.j]]
# likelihood is -3461.459379970277 on iteration 55
# new_angles=[0.1193757]
# new_P:
# [[0.3212149+0.j]]
# likelihood is -3462.209019909214 on iteration 56
# new_angles=[0.11936255]
# new_P:
# [[0.32690618+0.j]]
# likelihood is -3462.952441787236 on iteration 57
# new_angles=[0.11935069]
# new_P:
# [[0.33259441+0.j]]
# likelihood is -3463.6897325641935 on iteration 58
# new_angles=[0.11932498]
# new_P:
# [[0.33827982+0.j]]
# likelihood is -3464.420928465621 on iteration 59
# new_angles=[0.11930135]
# new_P:
# [[0.34396278+0.j]]
# likelihood is -3465.1461932995167 on iteration 60
# new_angles=[0.11928424]
# new_P:
# [[0.34964336+0.j]]
# likelihood is -3465.8656094509092 on iteration 61
# new_angles=[0.11927374]
# new_P:
# [[0.35532166+0.j]]
# likelihood is -3466.579245136603 on iteration 62
# new_angles=[0.11925732]
# new_P:
# [[0.36099778+0.j]]
# likelihood is -3467.2871399814962 on iteration 63
# new_angles=[0.11923988]
# new_P:
# [[0.36667199+0.j]]
# likelihood is -3467.989400583556 on iteration 64
# new_angles=[0.11921999]
# new_P:
# [[0.37234439+0.j]]
# likelihood is -3468.6861011164146 on iteration 65
# new_angles=[0.11921248]
# new_P:
# [[0.37801513+0.j]]
# likelihood is -3469.377351837837 on iteration 66
# new_angles=[0.11919639]
# new_P:
# [[0.38368417+0.j]]
# likelihood is -3470.063164084431 on iteration 67
# new_angles=[0.11917841]
# new_P:
# [[0.38935177+0.j]]
# likelihood is -3470.7436444545924 on iteration 68
# new_angles=[0.11916632]
# new_P:
# [[0.39501801+0.j]]
# likelihood is -3471.4188784494927 on iteration 69
# new_angles=[0.11914985]
# new_P:
# [[0.4006829+0.j]]
# likelihood is -3472.0889102800675 on iteration 70
# new_angles=[0.11913203]
# new_P:
# [[0.40634659+0.j]]
# likelihood is -3472.753823570379 on iteration 71
# new_angles=[0.11912474]
# new_P:
# [[0.41200915+0.j]]
# likelihood is -3473.413701642472 on iteration 72
# new_angles=[0.11911235]
# new_P:
# [[0.41767056+0.j]]
# likelihood is -3474.068579460835 on iteration 73
# new_angles=[0.11909252]
# new_P:
# [[0.42333097+0.j]]
# likelihood is -3474.7185343277065 on iteration 74
# new_angles=[0.11909252]
# new_P:
# [[0.42899049+0.j]]
# 2-th start
# theta=[1.40627821],P=[[0.00072472+1.11520089e-18j]]
# new_angles=[1.57079633]
# new_P:
# [[0.00186845+0.j]]
# likelihood is -3420.802212809264 on iteration 0
# new_angles=[1.57079633]
# new_P:
# [[0.00286947+0.j]]
# 3-th start
# theta=[-0.15355298],P=[[0.00022361+0.j]]
# new_angles=[-0.15355298]
# new_P:
# [[0.00129572+0.j]]
# 4-th start
# theta=[0.5300775],P=[[0.00056861+3.10619813e-20j]]
# new_angles=[0.71752153]
# new_P:
# [[0.00243134+0.j]]
# likelihood is -3404.8145540435316 on iteration 0
# new_angles=[0.71278079]
# new_P:
# [[0.0039079+0.j]]
# likelihood is -3394.7412530046654 on iteration 1
# new_angles=[0.70971682]
# new_P:
# [[0.00614477+0.j]]
# likelihood is -3380.1054698152293 on iteration 2
# new_angles=[0.7074399]
# new_P:
# [[0.01013399+0.j]]
# likelihood is -3355.519493121425 on iteration 3
# new_angles=[0.70569146]
# new_P:
# [[0.01880116+0.j]]
# likelihood is -3307.729564779304 on iteration 4
# new_angles=[0.70440917]
# new_P:
# [[0.04279205+0.j]]
# likelihood is -3205.351582793084 on iteration 5
# new_angles=[0.70333992]
# new_P:
# [[0.12716667+0.j]]
# likelihood is -3018.748419389304 on iteration 6
# new_angles=[0.70249994]
# new_P:
# [[0.41149613+0.j]]
# likelihood is -2862.43574979977 on iteration 7
# new_angles=[0.70185004]
# new_P:
# [[0.85334909+0.j]]
# likelihood is -2827.2903189603107 on iteration 8
# new_angles=[0.70134392]
# new_P:
# [[1.06836632+0.j]]
# likelihood is -2825.074797205685 on iteration 9
# new_angles=[0.70095371]
# new_P:
# [[1.12186518+0.j]]
# likelihood is -2824.9484674307446 on iteration 10
# new_angles=[0.70064955]
# new_P:
# [[1.13638486+0.j]]
# likelihood is -2824.8845533538342 on iteration 11
# new_angles=[0.70041043]
# new_P:
# [[1.14371432+0.j]]
# likelihood is -2824.8450785464147 on iteration 12
# new_angles=[0.70022569]
# new_P:
# [[1.14975749+0.j]]
# likelihood is -2824.8276940192545 on iteration 13
# new_angles=[0.70007821]
# new_P:
# [[1.15555222+0.j]]
# likelihood is -2824.824843336033 on iteration 14
# new_angles=[0.69996473]
# new_P:
# [[1.16128777+0.j]]
# likelihood is -2824.8324043002185 on iteration 15
# new_angles=[0.6998749]
# new_P:
# [[1.16700196+0.j]]
# likelihood is -2824.846568355793 on iteration 16
# new_angles=[0.69980296]
# new_P:
# [[1.17270596+0.j]]
# likelihood is -2824.865305052445 on iteration 17
# new_angles=[0.6997489]
# new_P:
# [[1.17840415+0.j]]
# likelihood is -2824.887596822018 on iteration 18
# new_angles=[0.69970748]
# new_P:
# [[1.18409855+0.j]]
# likelihood is -2824.9124529561404 on iteration 19
# new_angles=[0.69967544]
# new_P:
# [[1.18979065+0.j]]
# likelihood is -2824.9393404547222 on iteration 20
# new_angles=[0.69964937]
# new_P:
# [[1.19548134+0.j]]
# likelihood is -2824.9679159167235 on iteration 21
# new_angles=[0.69962943]
# new_P:
# [[1.20117112+0.j]]
# likelihood is -2824.998038988543 on iteration 22
# new_angles=[0.69961425]
# new_P:
# [[1.20686025+0.j]]
# likelihood is -2825.0295701628097 on iteration 23
# new_angles=[0.69960561]
# new_P:
# [[1.21254888+0.j]]
# likelihood is -2825.0624548148417 on iteration 24
# new_angles=[0.69959809]
# new_P:
# [[1.21823713+0.j]]
# likelihood is -2825.0965596464002 on iteration 25
# new_angles=[0.69958972]
# new_P:
# [[1.22392509+0.j]]
# likelihood is -2825.1318381144115 on iteration 26
# new_angles=[0.69958125]
# new_P:
# [[1.22961278+0.j]]
# likelihood is -2825.1682798876227 on iteration 27
# new_angles=[0.69957775]
# new_P:
# [[1.23530023+0.j]]
# likelihood is -2825.2058936936305 on iteration 28
# new_angles=[0.69957442]
# new_P:
# [[1.24098743+0.j]]
# likelihood is -2825.24461636136 on iteration 29
# new_angles=[0.69957214]
# new_P:
# [[1.24667441+0.j]]
# likelihood is -2825.2844315967864 on iteration 30
# new_angles=[0.69957017]
# new_P:
# [[1.25236118+0.j]]
# likelihood is -2825.325314757619 on iteration 31
# new_angles=[0.69956573]
# new_P:
# [[1.25804772+0.j]]
# likelihood is -2825.367236292968 on iteration 32
# new_angles=[0.69956395]
# new_P:
# [[1.26373404+0.j]]
# likelihood is -2825.410196266896 on iteration 33
# new_angles=[0.69956395]
# new_P:
# [[1.26942017+0.j]]
# 5-th start
# theta=[0.60846218],P=[[0.00408934+9.69739904e-20j]]
# new_angles=[0.60370938]
# new_P:
# [[0.02292225+0.j]]
# likelihood is -3405.8720139754296 on iteration 0
# new_angles=[0.6187492]
# new_P:
# [[0.02712515+0.j]]
# likelihood is -3384.783041589278 on iteration 1
# new_angles=[0.63364994]
# new_P:
# [[0.0376075+0.j]]
# likelihood is -3341.8213548437566 on iteration 2
# new_angles=[0.64679566]
# new_P:
# [[0.06572043+0.j]]
# likelihood is -3258.7053545720146 on iteration 3
# new_angles=[0.6577277]
# new_P:
# [[0.14721921+0.j]]
# likelihood is -3121.6377248422973 on iteration 4
# new_angles=[0.66656819]
# new_P:
# [[0.36038242+0.j]]
# likelihood is -2985.3255027427244 on iteration 5
# new_angles=[0.67362218]
# new_P:
# [[0.68328159+0.j]]
# likelihood is -2912.4735314709947 on iteration 6
# new_angles=[0.67920305]
# new_P:
# [[0.91052708+0.j]]
# likelihood is -2877.6387302635267 on iteration 7
# new_angles=[0.68360762]
# new_P:
# [[1.01616136+0.j]]
# likelihood is -2857.344857040442 on iteration 8
# new_angles=[0.68707265]
# new_P:
# [[1.06768538+0.j]]
# likelihood is -2844.799185782262 on iteration 9
# new_angles=[0.68978605]
# new_P:
# [[1.09773905+0.j]]
# likelihood is -2837.0573159399873 on iteration 10
# new_angles=[0.69191724]
# new_P:
# [[1.11758879+0.j]]
# likelihood is -2832.285044583967 on iteration 11
# new_angles=[0.69358293]
# new_P:
# [[1.13182077+0.j]]
# likelihood is -2829.3695858728124 on iteration 12
# new_angles=[0.69488721]
# new_P:
# [[1.14270761+0.j]]
# likelihood is -2827.5913844982783 on iteration 13
# new_angles=[0.69590728]
# new_P:
# [[1.1515721+0.j]]
# likelihood is -2826.513054947636 on iteration 14
# new_angles=[0.69670379]
# new_P:
# [[1.15920197+0.j]]
# likelihood is -2825.8644791694587 on iteration 15
# new_angles=[0.69732528]
# new_P:
# [[1.16607651+0.j]]
# likelihood is -2825.478852798319 on iteration 16
# new_angles=[0.69781418]
# new_P:
# [[1.17248968+0.j]]
# likelihood is -2825.252127386984 on iteration 17
# new_angles=[0.69819552]
# new_P:
# [[1.1786238+0.j]]
# likelihood is -2825.125008014857 on iteration 18
# new_angles=[0.69849436]
# new_P:
# [[1.18458513+0.j]]
# likelihood is -2825.0585863234523 on iteration 19
# new_angles=[0.69872107]
# new_P:
# [[1.19044117+0.j]]
# likelihood is -2825.031448498534 on iteration 20
# new_angles=[0.69890044]
# new_P:
# [[1.1962305+0.j]]
# likelihood is -2825.0265523970056 on iteration 21
# new_angles=[0.6990436]
# new_P:
# [[1.20198141+0.j]]
# likelihood is -2825.0358231175533 on iteration 22
# new_angles=[0.69915466]
# new_P:
# [[1.20770897+0.j]]
# likelihood is -2825.054800104064 on iteration 23
# new_angles=[0.69923913]
# new_P:
# [[1.21342138+0.j]]
# likelihood is -2825.080237691397 on iteration 24
# new_angles=[0.69930915]
# new_P:
# [[1.21912414+0.j]]
# likelihood is -2825.109578935601 on iteration 25
# new_angles=[0.69936383]
# new_P:
# [[1.22482152+0.j]]
# likelihood is -2825.142073333706 on iteration 26
# new_angles=[0.69940371]
# new_P:
# [[1.23051514+0.j]]
# likelihood is -2825.1770273758893 on iteration 27
# new_angles=[0.69943506]
# new_P:
# [[1.23620612+0.j]]
# likelihood is -2825.2137619302557 on iteration 28
# new_angles=[0.69946634]
# new_P:
# [[1.24189557+0.j]]
# likelihood is -2825.251848794736 on iteration 29
# new_angles=[0.69948629]
# new_P:
# [[1.24758427+0.j]]
# likelihood is -2825.291454852273 on iteration 30
# new_angles=[0.6995006]
# new_P:
# [[1.25327199+0.j]]
# likelihood is -2825.332296615331 on iteration 31
# new_angles=[0.69951368]
# new_P:
# [[1.25895909+0.j]]
# likelihood is -2825.374245196228 on iteration 32
# new_angles=[0.69952214]
# new_P:
# [[1.26464583+0.j]]
# likelihood is -2825.4172972413726 on iteration 33
# new_angles=[0.69952826]
# new_P:
# [[1.27033219+0.j]]
# likelihood is -2825.4613875909513 on iteration 34
# new_angles=[0.69953733]
# new_P:
# [[1.27601825+0.j]]
# likelihood is -2825.50646083892 on iteration 35
# new_angles=[0.69954096]
# new_P:
# [[1.28170413+0.j]]
# likelihood is -2825.552540222991 on iteration 36
# new_angles=[0.69954435]
# new_P:
# [[1.28738972+0.j]]
# likelihood is -2825.5995754888077 on iteration 37
# new_angles=[0.69954804]
# new_P:
# [[1.29307509+0.j]]
# likelihood is -2825.647548642289 on iteration 38
# new_angles=[0.69954804]
# new_P:
# [[1.29876027+0.j]]
# 6-th start
# theta=[-1.46911153],P=[[0.00075317-3.39408966e-19j]]
# new_angles=[-1.46911153]
# new_P:
# [[0.0019368+0.j]]
# 7-th start
# theta=[-1.07899142],P=[[0.00022361+0.j]]
# new_angles=[-1.05824328]
# new_P:
# [[0.00133793+0.j]]
# likelihood is -3420.832050042011 on iteration 0
# new_angles=[-1.05824328]
# new_P:
# [[0.00233817+0.j]]
# 8-th start
# theta=[-1.31513736],P=[[0.00092031-6.30330937e-19j]]
# new_angles=[-1.32014066]
# new_P:
# [[0.00219867+0.j]]
# likelihood is -3420.845472483543 on iteration 0
# new_angles=[-1.32014066]
# new_P:
# [[0.0031986+0.j]]
# 9-th start
# theta=[-0.20985359],P=[[0.00022361+0.j]]
# new_angles=[-0.20985359]
# new_P:
# [[0.00130934+0.j]]
# best_start=4

# %%
print(f"EM_theta1_rad={EM_theta1_rad},\nEM_P1={EM_P1}")
# Out:
# EM_theta1_rad=[0.69956395],
# EM_P1=[[1.26373404+0.j]]

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)
print(f"Погрешность в смысле разности углов в градусах: \
      {np.abs(EM_theta1_deg-theta1_deg)},")
print(f"Погрешность в смысле разности синусов углов: \
      {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах:       [0.02498373],
# Погрешность в смысле разности синусов углов:       [0.00033357].

# %%
print(np.trace(sensors.initial_Cov(X2_with_mv)))
print(np.trace(sensors.complex_cov(X2)))
# Out:
# (49.65503774285381+0j)
# (61.03171543408073+0j)

# %%
EM_theta2_rad, EM_P2, lhd_2 = em_stoch.multi_start_EM(X2_with_mv, 
                                                      Num_emitters2, 
                                                      Q=Q_2, 
                                                      num_of_starts=20, 
                                                      max_iter=30,
                                                      rtol=1e-3)
# Out:
# 0-th start
# theta=[-1.41744418  0.15335215],P=[[0.00276336-1.33017438e-17j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00299515+1.51605636e-17j]]
# new_angles=[-0.51965652  0.70854627]
# new_P:
# [[0.01073064+0.j         0.00025857-0.00566143j]
#  [0.00025857+0.00566143j 0.01479629+0.j        ]]
# likelihood is -3888.134533796155 on iteration 0
# new_angles=[-0.51523208  0.70718057]
# new_P:
# [[0.0363239 +0.j         0.00169974-0.02436544j]
#  [0.00169974+0.02436544j 0.05152884+0.j        ]]
# likelihood is -3342.9547156433446 on iteration 1
# new_angles=[-0.51131132  0.70573342]
# new_P:
# [[0.1711726 +0.j         0.00792447-0.11974104j]
#  [0.00792447+0.11974104j 0.2256284 +0.j        ]]
# likelihood is -2568.6782988831064 on iteration 2
# new_angles=[-0.50832482  0.70441475]
# new_P:
# [[ 5.81732059e-01+0.j        -1.11863995e-04-0.2301428j]
#  [-1.11863995e-04+0.2301428j  5.84788533e-01+0.j       ]]
# likelihood is -2171.500265179814 on iteration 3
# new_angles=[-0.50635209  0.70355399]
# new_P:
# [[ 0.97690213+0.j         -0.02784682-0.13851793j]
#  [-0.02784682+0.13851793j  0.81400105+0.j        ]]
# likelihood is -2120.2748871504277 on iteration 4
# new_angles=[-0.50490447  0.70295383]
# new_P:
# [[ 1.07951243+0.j         -0.03052274-0.10284283j]
#  [-0.03052274+0.10284283j  0.87348015+0.j        ]]
# likelihood is -2113.29179629151 on iteration 5
# new_angles=[-0.50379774  0.70250392]
# new_P:
# [[ 1.09820475+0.j         -0.02627373-0.10221473j]
#  [-0.02627373+0.10221473j  0.88541072+0.j        ]]
# likelihood is -2109.7637354259687 on iteration 6
# new_angles=[-0.50294419  0.70216409]
# new_P:
# [[ 1.10536819+0.j         -0.02197389-0.10583328j]
#  [-0.02197389+0.10583328j  0.89030087+0.j        ]]
# 1-th start
# theta=[-1.43443568  0.13636065],P=[[0.00209247+2.33229794e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00447612-8.48930966e-18j]]
# new_angles=[-0.51544252  0.67532239]
# new_P:
# [[0.00708937+0.j         0.00637969-0.00405922j]
#  [0.00637969+0.00405922j 0.04482536+0.j        ]]
# likelihood is -3737.5926173990483 on iteration 0
# new_angles=[-0.51216224  0.6809747 ]
# new_P:
# [[0.02102455+0.j         0.02803768-0.01700432j]
#  [0.02803768+0.01700432j 0.18080897+0.j        ]]
# likelihood is -3242.2326720162487 on iteration 1
# new_angles=[-0.50836771  0.68532262]
# new_P:
# [[0.07757691+0.j         0.08414775-0.05223173j]
#  [0.08414775+0.05223173j 0.53075772+0.j        ]]
# likelihood is -2693.863032090387 on iteration 2
# new_angles=[-0.50601111  0.68861842]
# new_P:
# [[0.33532296+0.j        0.09646634-0.0803843j]
#  [0.09646634+0.0803843j 0.76562633+0.j       ]]
# likelihood is -2222.9983767356616 on iteration 3
# new_angles=[-0.50463903  0.69125813]
# new_P:
# [[0.87163784+0.j         0.03104   -0.09079372j]
#  [0.03104   +0.09079372j 0.84003595+0.j        ]]
# likelihood is -2131.9979607301298 on iteration 4
# new_angles=[-0.50363914  0.69339583]
# new_P:
# [[1.07024699+0.j         0.00133115-0.09515035j]
#  [0.00133115+0.09515035j 0.86561328+0.j        ]]
# likelihood is -2119.944899108237 on iteration 5
# new_angles=[-0.50286628  0.69507267]
# new_P:
# [[ 1.1000833 +0.j         -0.00332743-0.09940042j]
#  [-0.00332743+0.09940042j  0.8773052 +0.j        ]]
# likelihood is -2113.8597199408387 on iteration 6
# new_angles=[-0.50226558  0.69639462]
# new_P:
# [[ 1.10719548+0.j         -0.00408744-0.10351606j]
#  [-0.00408744+0.10351606j  0.88496846+0.j        ]]
# likelihood is -2110.1788482191205 on iteration 7
# new_angles=[-0.5017869  0.6974194]
# new_P:
# [[ 1.11155522+0.j         -0.00421497-0.10740356j]
#  [-0.00421497+0.10740356j  0.89088086+0.j        ]]
# likelihood is -2107.973625197899 on iteration 8
# new_angles=[-0.50141274  0.6982259 ]
# new_P:
# [[ 1.11539401+0.j         -0.00404976-0.11107909j]
#  [-0.00404976+0.11107909j  0.89578981+0.j        ]]
# 2-th start
# theta=[-0.16451812  1.40627821],P=[[0.0001118+0.00000000e+00j 0.       +0.00000000e+00j]
#  [0.       +0.00000000e+00j 0.0047305+9.15648187e-18j]]
# new_angles=[-0.18141455  0.6588341 ]
# new_P:
# [[ 0.00117652+0.j         -0.00049521+0.00076441j]
#  [-0.00049521-0.00076441j  0.02484056+0.j        ]]
# likelihood is -4065.1337252599874 on iteration 0
# new_angles=[-1.57079633  0.66785835]
# new_P:
# [[ 0.00223712+0.j         -0.00150583+0.00232346j]
#  [-0.00150583-0.00232346j  0.07781725+0.j        ]]
# likelihood is -3781.9924787337627 on iteration 1
# new_angles=[-1.11507289  0.67499295]
# new_P:
# [[ 0.00356276+0.j         -0.00598932+0.00903916j]
#  [-0.00598932-0.00903916j  0.28153835+0.j        ]]
# likelihood is -3519.5449300640753 on iteration 2
# new_angles=[-1.09898625  0.68057886]
# new_P:
# [[ 0.00521803+0.j         -0.01335322+0.02144642j]
#  [-0.01335322-0.02144642j  0.60940971+0.j        ]]
# likelihood is -3431.2541578192518 on iteration 3
# new_angles=[-1.09152051  0.68498448]
# new_P:
# [[ 0.00669584+0.j         -0.01747442+0.02891802j]
#  [-0.01747442-0.02891802j  0.76727672+0.j        ]]
# likelihood is -3397.6312337627483 on iteration 4
# new_angles=[-1.08579445  0.68841767]
# new_P:
# [[ 0.00802138+0.j         -0.0192287 +0.03259871j]
#  [-0.0192287 -0.03259871j  0.81752727+0.j        ]]
# likelihood is -3378.2462976878337 on iteration 5
# new_angles=[-1.08344317  0.69110571]
# new_P:
# [[ 0.0093172 +0.j         -0.02027598+0.03501695j]
#  [-0.02027598-0.03501695j  0.83971316+0.j        ]]
# likelihood is -3366.4517730157227 on iteration 6
# new_angles=[-1.0810374   0.69320662]
# new_P:
# [[ 0.01061971+0.j         -0.02086897+0.03681577j]
#  [-0.02086897-0.03681577j  0.85282781+0.j        ]]
# likelihood is -3359.3224856121938 on iteration 7
# new_angles=[-1.07867473  0.69485424]
# new_P:
# [[ 0.01195114+0.j         -0.02118524+0.03811283j]
#  [-0.02118524-0.03811283j  0.86174645+0.j        ]]
# likelihood is -3355.0640659682317 on iteration 8
# new_angles=[-1.07661189  0.69612624]
# new_P:
# [[ 0.01333494+0.j         -0.02133108+0.03894752j]
#  [-0.02133108-0.03894752j  0.86831903+0.j        ]]
# likelihood is -3352.6268931578215 on iteration 9
# new_angles=[-1.07526243  0.69712093]
# new_P:
# [[ 0.01479983+0.j         -0.02136992+0.03936127j]
#  [-0.02136992-0.03936127j  0.87347348+0.j        ]]
# likelihood is -3351.2842709885217 on iteration 10
# new_angles=[-1.07452486  0.69789736]
# new_P:
# [[ 0.01637968+0.j         -0.02130696+0.03941738j]
#  [-0.02130696-0.03941738j  0.87778305+0.j        ]]
# likelihood is -3350.636815361105 on iteration 11
# new_angles=[-1.07359632  0.69851488]
# new_P:
# [[ 0.01811362+0.j        -0.02114221+0.0391819j]
#  [-0.02114221-0.0391819j  0.88158891+0.j       ]]
# likelihood is -3350.4362132433744 on iteration 12
# new_angles=[-1.0730847   0.69883373]
# new_P:
# [[ 0.02004485+0.j         -0.02094511+0.03868353j]
#  [-0.02094511-0.03868353j  0.88514669+0.j        ]]
# 3-th start
# theta=[-0.15355298  1.41724335],P=[[0.0001118 +0.00000000e+00j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00572669-4.89593623e-18j]]
# new_angles=[-0.16793423  0.65939643]
# new_P:
# [[ 0.0011684 +0.j         -0.00076956+0.00065685j]
#  [-0.00076956-0.00065685j  0.03483802+0.j        ]]
# likelihood is -4002.7160553440735 on iteration 0
# new_angles=[-0.40337089  0.66837575]
# new_P:
# [[ 0.00222483+0.j         -0.00252321+0.00202062j]
#  [-0.00252321-0.00202062j  0.11659573+0.j        ]]
# likelihood is -3699.6321197215207 on iteration 1
# new_angles=[-1.10194926  0.67546326]
# new_P:
# [[ 0.00349606+0.j         -0.00857487+0.00696149j]
#  [-0.00857487-0.00696149j  0.37714641+0.j        ]]
# likelihood is -3494.3288972444248 on iteration 2
# new_angles=[-1.08416051  0.68094993]
# new_P:
# [[ 0.00489251+0.j         -0.01598321+0.01453603j]
#  [-0.01598321-0.01453603j  0.66656471+0.j        ]]
# likelihood is -3427.761304725621 on iteration 3
# new_angles=[-1.07728789  0.68527805]
# new_P:
# [[ 0.00621364+0.j         -0.0200062 +0.01933399j]
#  [-0.0200062 -0.01933399j  0.78153936+0.j        ]]
# likelihood is -3396.3511991485966 on iteration 4
# new_angles=[-1.07305274  0.68867254]
# new_P:
# [[ 0.00750167+0.j         -0.02225117+0.02258244j]
#  [-0.02225117-0.02258244j  0.82227349+0.j        ]]
# likelihood is -3377.440338153993 on iteration 5
# new_angles=[-1.06961202  0.69132367]
# new_P:
# [[ 0.0088021 +0.j        -0.02380893+0.0252195j]
#  [-0.02380893-0.0252195j  0.84273904+0.j       ]]
# likelihood is -3365.918186408239 on iteration 6
# new_angles=[-1.06935801  0.69338528]
# new_P:
# [[ 0.01013217+0.j         -0.02496076+0.02740195j]
#  [-0.02496076-0.02740195j  0.85549852+0.j        ]]
# likelihood is -3359.016240592852 on iteration 7
# new_angles=[-1.06885035  0.69497354]
# new_P:
# [[ 0.0115032 +0.j         -0.02562953+0.02926401j]
#  [-0.02562953-0.02926401j  0.86405477+0.j        ]]
# likelihood is -3354.954601659207 on iteration 8
# new_angles=[-1.06695078  0.69624567]
# new_P:
# [[ 0.01293615+0.j         -0.02593722+0.03078826j]
#  [-0.02593722-0.03078826j  0.87027454+0.j        ]]
# likelihood is -3352.513543887979 on iteration 9
# new_angles=[-1.06650848  0.69724046]
# new_P:
# [[ 0.01445868+0.j         -0.02607279+0.03189848j]
#  [-0.02607279-0.03189848j  0.87528572+0.j        ]]
# likelihood is -3351.1841511568873 on iteration 10
# new_angles=[-1.06682437  0.69799705]
# new_P:
# [[ 0.01609942+0.j         -0.02598417+0.03267961j]
#  [-0.02598417-0.03267961j  0.87941945+0.j        ]]
# 4-th start
# theta=[-1.04071883  0.5300775 ],P=[[3.49385621e-06+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 3.58409028e-03-8.27175728e-19j]]
# new_angles=[-0.68291667  0.68185084]
# new_P:
# [[1.00354475e-03+0.00000000e+00j 2.34549655e-05-2.79397042e-05j]
#  [2.34549655e-05+2.79397042e-05j 4.09971042e-02+0.00000000e+00j]]
# likelihood is -3862.2229604817207 on iteration 0
# new_angles=[0.68612641 0.69626618]
# new_P:
# [[0.17184182+0.00000000e+00j 0.00019134-6.28227399e-05j]
#  [0.00019134+6.28227399e-05j 0.00201134+0.00000000e+00j]]
# likelihood is -3510.583144774276 on iteration 1
# new_angles=[0.68940461 0.69917334]
# new_P:
# [[0.5280134 +0.j         0.00512517-0.00146374j]
#  [0.00512517+0.00146374j 0.00308547+0.j        ]]
# likelihood is -3384.1861444326346 on iteration 2
# new_angles=[0.69193845 0.70172795]
# new_P:
# [[0.76327078+0.j         0.00941981-0.00282884j]
#  [0.00941981+0.00282884j 0.00417098+0.j        ]]
# likelihood is -3366.469600774164 on iteration 3
# new_angles=[0.69392171 0.70372757]
# new_P:
# [[0.81623515+0.j        0.01110452-0.0035597j]
#  [0.01110452+0.0035597j 0.00522272+0.j       ]]
# likelihood is -3359.7628219412777 on iteration 4
# new_angles=[0.69547093 0.70520948]
# new_P:
# [[0.82782176+0.j         0.01206392-0.00412248j]
#  [0.01206392+0.00412248j 0.00626669+0.j        ]]
# likelihood is -3355.77371287487 on iteration 5
# new_angles=[0.58195081 0.69643758]
# new_P:
# [[0.00731112+0.j        0.01282411+0.0046427j]
#  [0.01282411-0.0046427j 0.83224089+0.j       ]]
# likelihood is -3351.575193961046 on iteration 6
# new_angles=[0.57966934 0.69729319]
# new_P:
# [[0.00874194+0.j         0.01606876+0.00698938j]
#  [0.01606876-0.00698938j 0.8692607 +0.j        ]]
# likelihood is -3349.9415491773034 on iteration 7
# new_angles=[0.58025307 0.69793032]
# new_P:
# [[0.01030753+0.j         0.01880808+0.00837728j]
#  [0.01880808-0.00837728j 0.87687776+0.j        ]]
# 5-th start
# theta=[-0.96233415  0.60846218],P=[[0.00189661+1.15722072e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00636671+3.83942552e-19j]]
# new_angles=[-0.96920187  0.61084449]
# new_P:
# [[0.00858805+0.j         0.00104531+0.00200067j]
#  [0.00104531-0.00200067j 0.01732267+0.j        ]]
# likelihood is -4266.800488340703 on iteration 0
# new_angles=[-0.51800627  0.62673662]
# new_P:
# [[0.01001434+0.j         0.00110183+0.00335262j]
#  [0.00110183-0.00335262j 0.02437097+0.j        ]]
# likelihood is -4010.8896545109865 on iteration 1
# new_angles=[-0.51379621  0.641587  ]
# new_P:
# [[0.03213626+0.j        0.00314108+0.0110831j]
#  [0.00314108-0.0110831j 0.04731743+0.j       ]]
# likelihood is -3585.929087113995 on iteration 2
# new_angles=[-0.51054029  0.65410202]
# new_P:
# [[0.15459691+0.j         0.01131134+0.04484943j]
#  [0.01131134-0.04484943j 0.1252856 +0.j        ]]
# likelihood is -2861.921725269655 on iteration 3
# new_angles=[-0.50805858  0.66379033]
# new_P:
# [[0.60582275+0.j        0.02575489+0.0792315j]
#  [0.02575489-0.0792315j 0.31882008+0.j       ]]
# likelihood is -2425.836803032833 on iteration 4
# new_angles=[-0.50630422  0.67165064]
# new_P:
# [[0.99332185+0.j         0.02510388-0.00574222j]
#  [0.02510388+0.00574222j 0.5676907 +0.j        ]]
# likelihood is -2286.403410748447 on iteration 5
# new_angles=[-0.50499612  0.67800184]
# new_P:
# [[1.08254103+0.j         0.02187164-0.05977299j]
#  [0.02187164+0.05977299j 0.72113437+0.j        ]]
# likelihood is -2216.8418515984554 on iteration 6
# new_angles=[-0.50398516  0.68302759]
# new_P:
# [[1.09997602+0.j         0.01892971-0.07958928j]
#  [0.01892971+0.07958928j 0.79503435+0.j        ]]
# likelihood is -2173.7565478086117 on iteration 7
# new_angles=[-0.50318377  0.68700776]
# new_P:
# [[1.10726456+0.j         0.01566264-0.09089724j]
#  [0.01566264+0.09089724j 0.83637158+0.j        ]]
# likelihood is -2146.718567560012 on iteration 8
# new_angles=[-0.50253991  0.69009908]
# new_P:
# [[1.11255626+0.j         0.01245483-0.09933851j]
#  [0.01245483+0.09933851j 0.86239789+0.j        ]]
# likelihood is -2130.1921780058597 on iteration 9
# new_angles=[-0.50203504  0.69251541]
# new_P:
# [[1.11706096+0.j         0.00972838-0.10607321j]
#  [0.00972838+0.10607321j 0.87948495+0.j        ]]
# likelihood is -2120.1114136152173 on iteration 10
# new_angles=[-0.50163473  0.69440034]
# new_P:
# [[1.12111159+0.j         0.00754299-0.11169297j]
#  [0.00754299+0.11169297j 0.89122436+0.j        ]]
# likelihood is -2114.0037856585827 on iteration 11
# new_angles=[-0.50131281  0.69588059]
# new_P:
# [[1.12489059+0.j         0.00590996-0.11654283j]
#  [0.00590996+0.11654283j 0.89969606+0.j        ]]
# likelihood is -2110.2996908473597 on iteration 12
# new_angles=[-0.50105085  0.6970303 ]
# new_P:
# [[1.12850618+0.j         0.00476629-0.12086925j]
#  [0.00476629+0.12086925j 0.90618914+0.j        ]]
# likelihood is -2108.091414952938 on iteration 13
# new_angles=[-0.50084209  0.69792616]
# new_P:
# [[1.1320218 +0.j         0.00407329-0.12482161j]
#  [0.00407329+0.12482161j 0.91145505+0.j        ]]
# 6-th start
# theta=[-1.46911153  0.10168479],P=[[0.00443737+1.62172784e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.0001118 +0.00000000e+00j]]
# new_angles=[-0.52569501  0.85245226]
# new_P:
# [[0.02331274+0.j         0.00036645+0.00043142j]
#  [0.00036645-0.00043142j 0.0011566 +0.j        ]]
# likelihood is -3951.5985223788402 on iteration 0
# new_angles=[-0.51990477  0.70970241]
# new_P:
# [[0.09753815+0.j         0.00177769+0.00187633j]
#  [0.00177769-0.00187633j 0.0022124 +0.j        ]]
# likelihood is -3454.3977083549466 on iteration 1
# new_angles=[-0.51553232  0.71504533]
# new_P:
# [[0.4438136 +0.j         0.0082697 +0.00913811j]
#  [0.0082697 -0.00913811j 0.00455298+0.j        ]]
# likelihood is -3103.4816036361917 on iteration 2
# new_angles=[-0.51215068  0.71891167]
# new_P:
# [[0.89048687+0.j         0.01579567+0.01801436j]
#  [0.01579567-0.01801436j 0.00962637+0.j        ]]
# likelihood is -2974.5263881210003 on iteration 3
# new_angles=[-0.50952689  0.71644057]
# new_P:
# [[1.02254752+0.j        0.01521654+0.0179313j]
#  [0.01521654-0.0179313j 0.02499016+0.j       ]]
# likelihood is -2773.6854608124895 on iteration 4
# new_angles=[-0.50745314  0.71303574]
# new_P:
# [[1.05590417+0.j         0.00649559+0.00662399j]
#  [0.00649559-0.00662399j 0.09650388+0.j        ]]
# likelihood is -2400.273237353861 on iteration 5
# new_angles=[-0.50579531  0.71027527]
# new_P:
# [[ 1.07799564+0.j         -0.01732439-0.03500334j]
#  [-0.01732439+0.03500334j  0.39319999+0.j        ]]
# likelihood is -2159.6413350481776 on iteration 6
# new_angles=[-0.50446142  0.70817405]
# new_P:
# [[ 1.09571914+0.j         -0.03535002-0.08462502j]
#  [-0.03535002+0.08462502j  0.75887534+0.j        ]]
# likelihood is -2122.8762888356982 on iteration 7
# new_angles=[-0.50342464  0.70655799]
# new_P:
# [[ 1.10529391+0.j         -0.03365893-0.10287168j]
#  [-0.03365893+0.10287168j  0.86756048+0.j        ]]
# likelihood is -2115.1982660670906 on iteration 8
# new_angles=[-0.5026235   0.70531483]
# new_P:
# [[ 1.11152314+0.j         -0.02801937-0.10997223j]
#  [-0.02801937+0.10997223j  0.88900983+0.j        ]]
# likelihood is -2110.9990138068774 on iteration 9
# new_angles=[-0.50201417  0.7043533 ]
# new_P:
# [[ 1.11645368+0.j         -0.02273765-0.11463554j]
#  [-0.02273765+0.11463554j  0.89657799+0.j        ]]
# likelihood is -2108.5152833121133 on iteration 10
# new_angles=[-0.50154425  0.70361265]
# new_P:
# [[ 1.12070594+0.j        -0.01823632-0.1184427j]
#  [-0.01823632+0.1184427j  0.90165426+0.j       ]]
# 7-th start
# theta=[-1.07899142  0.49180491],P=[[3.49385621e-06+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 1.27299140e-03+2.29972578e-19j]]
# new_angles=[-1.26786365  0.65540765]
# new_P:
# [[1.00353948e-03+0.00000000e+00j 1.23509533e-05-8.71047739e-06j]
#  [1.23509533e-05+8.71047739e-06j 9.23969866e-03+0.00000000e+00j]]
# likelihood is -4202.486517351807 on iteration 0
# new_angles=[-1.24268671  0.66529975]
# new_P:
# [[2.00792331e-03+0.00000000e+00j 6.17384821e-05+9.73455664e-06j]
#  [6.17384821e-05-9.73455664e-06j 2.07650082e-02+0.00000000e+00j]]
# likelihood is -4068.9304770918375 on iteration 1
# new_angles=[-1.21292178  0.67308165]
# new_P:
# [[0.00303223+0.j         0.00042501+0.00020159j]
#  [0.00042501-0.00020159j 0.06695318+0.j        ]]
# likelihood is -3781.730907888034 on iteration 2
# new_angles=[0.67918729 0.70009077]
# new_P:
# [[0.26169661+0.j        0.00231069-0.0014503j]
#  [0.00231069+0.0014503j 0.00411063+0.j       ]]
# likelihood is -3490.3353984436544 on iteration 3
# new_angles=[0.68390286 0.70256738]
# new_P:
# [[0.59324627+0.j         0.01250292-0.00786832j]
#  [0.01250292+0.00786832j 0.00554395+0.j        ]]
# likelihood is -3407.5914942778495 on iteration 4
# new_angles=[0.68753044 0.70593109]
# new_P:
# [[0.74199947+0.j         0.01970838-0.01244376j]
#  [0.01970838+0.01244376j 0.00698052+0.j        ]]
# likelihood is -3383.2854554572837 on iteration 5
# new_angles=[0.69033738 0.70846021]
# new_P:
# [[0.7768619 +0.j         0.02364244-0.01511518j]
#  [0.02364244+0.01511518j 0.00833913+0.j        ]]
# likelihood is -3369.881951582082 on iteration 6
# new_angles=[0.69251626 0.71059214]
# new_P:
# [[0.78662156+0.j         0.02646245-0.01712038j]
#  [0.02646245+0.01712038j 0.00967545+0.j        ]]
# likelihood is -3361.7407151865514 on iteration 7
# new_angles=[0.69418278 0.71228438]
# new_P:
# [[0.79032188+0.j         0.02874378-0.01879967j]
#  [0.02874378+0.01879967j 0.01100541+0.j        ]]
# likelihood is -3356.8568387263554 on iteration 8
# new_angles=[0.69549381 0.71353499]
# new_P:
# [[0.79178817+0.j         0.03063118-0.02021551j]
#  [0.03063118+0.02021551j 0.01233022+0.j        ]]
# likelihood is -3353.8651470289487 on iteration 9
# new_angles=[0.69648798 0.71446375]
# new_P:
# [[0.79237417+0.j         0.03218643-0.02136822j]
#  [0.03218643+0.02136822j 0.01364726+0.j        ]]
# likelihood is -3352.0939937051808 on iteration 10
# new_angles=[0.69724409 0.71523154]
# new_P:
# [[0.79260492+0.j        0.03347283-0.0222635j]
#  [0.03347283+0.0222635j 0.01495928+0.j       ]]
# likelihood is -3351.033105916336 on iteration 11
# new_angles=[0.69780154 0.71579762]
# new_P:
# [[0.79279913+0.j         0.03454767-0.02290719j]
#  [0.03454767+0.02290719j 0.01627262+0.j        ]]
# 8-th start
# theta=[-1.31513736  0.25565896],P=[[3.79460496e-03-1.42636553e-18j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 5.59016994e-05+0.00000000e+00j]]
# new_angles=[-0.50676522 -0.21899213]
# new_P:
# [[0.01613147+0.00000000e+00j 0.00012821+3.13356669e-05j]
#  [0.00012821-3.13356669e-05j 0.00106385+0.00000000e+00j]]
# likelihood is -3995.1001145819996 on iteration 0
# new_angles=[-0.50538686 -0.49534331]
# new_P:
# [[0.06629546+0.j         0.00060537-0.00028692j]
#  [0.00060537+0.00028692j 0.00206898+0.j        ]]
# likelihood is -3531.4867226542033 on iteration 1
# new_angles=[-0.50434083 -0.49471905]
# new_P:
# [[0.34066566+0.j         0.01129677-0.00385342j]
#  [0.01129677+0.00385342j 0.00353395+0.j        ]]
# likelihood is -3133.504895681203 on iteration 2
# new_angles=[-0.5035567 -0.494251 ]
# new_P:
# [[0.82388828+0.j         0.03167207-0.01062533j]
#  [0.03167207+0.01062533j 0.00549073+0.j        ]]
# 9-th start
# theta=[-0.20985359  1.36094274],P=[[0.0001118+0.00000000e+00j 0.       +0.00000000e+00j]
#  [0.       +0.00000000e+00j 0.0041411+1.10075139e-17j]]
# new_angles=[-0.21896777  0.65504113]
# new_P:
# [[0.00117551+0.j         0.00050579+0.00061923j]
#  [0.00050579-0.00061923j 0.01984094+0.j        ]]
# likelihood is -4113.966198219348 on iteration 0
# new_angles=[0.42323345 0.66464671]
# new_P:
# [[0.00224391+0.j         0.00156494+0.00171213j]
#  [0.00156494-0.00171213j 0.05617539+0.j        ]]
# likelihood is -3871.5288415064806 on iteration 1
# new_angles=[0.67248743 0.69666883]
# new_P:
# [[0.20475186+0.j         0.00645252-0.00664428j]
#  [0.00645252+0.00664428j 0.0035821 +0.j        ]]
# likelihood is -3557.318905684643 on iteration 2
# new_angles=[0.67839206 0.70189264]
# new_P:
# [[0.49587987+0.j        0.02176337-0.0207841j]
#  [0.02176337+0.0207841j 0.00607061+0.j       ]]
# likelihood is -3443.3285625255985 on iteration 3
# new_angles=[0.68298655 0.70625681]
# new_P:
# [[0.6604998 +0.j         0.03327408-0.03117929j]
#  [0.03327408+0.03117929j 0.00846999+0.j        ]]
# likelihood is -3404.1905016633605 on iteration 4
# new_angles=[0.68659168 0.70928924]
# new_P:
# [[0.706947  +0.j         0.03907168-0.03635123j]
#  [0.03907168+0.03635123j 0.01043917+0.j        ]]
# likelihood is -3382.3691744581297 on iteration 5
# new_angles=[0.6893569  0.71210784]
# new_P:
# [[0.72169296+0.j         0.04288504-0.03971943j]
#  [0.04288504+0.03971943j 0.01224716+0.j        ]]
# likelihood is -3369.102725269363 on iteration 6
# new_angles=[0.69149439 0.71428687]
# new_P:
# [[0.72750948+0.j         0.04585566-0.04238452j]
#  [0.04585566+0.04238452j 0.01399278+0.j        ]]
# likelihood is -3361.061086449579 on iteration 7
# new_angles=[0.69308016 0.71590363]
# new_P:
# [[0.72977033+0.j         0.04825775-0.04456286j]
#  [0.04825775+0.04456286j 0.01568663+0.j        ]]
# likelihood is -3356.360021818347 on iteration 8
# new_angles=[0.69435027 0.71719868]
# new_P:
# [[0.73025739+0.j         0.05023021-0.04633317j]
#  [0.05023021+0.04633317j 0.01733561+0.j        ]]
# likelihood is -3353.4031177471347 on iteration 9
# new_angles=[0.69532362 0.71811014]
# new_P:
# [[0.7301485 +0.j        0.05186155-0.0477351j]
#  [0.05186155+0.0477351j 0.01894198+0.j       ]]
# likelihood is -3351.638153685255 on iteration 10
# new_angles=[0.696079   0.71879927]
# new_P:
# [[0.7298564 +0.j       0.05322419-0.048781j]
#  [0.05322419+0.048781j 0.0205118 +0.j      ]]
# likelihood is -3350.567587038499 on iteration 11
# new_angles=[0.6966359  0.71936711]
# new_P:
# [[0.72966654+0.j         0.05438065-0.04948277j]
#  [0.05438065+0.04948277j 0.02205481+0.j        ]]
# 10-th start
# theta=[-1.08828041  0.48251591],P=[[6.98771243e-06+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 1.21468000e-03-1.28893587e-18j]]
# new_angles=[-1.02446066  0.64925174]
# new_P:
# [[1.00715846e-03+0.00000000e+00j 2.32613677e-05-1.45172838e-05j]
#  [2.32613677e-05+1.45172838e-05j 8.45794738e-03+0.00000000e+00j]]
# likelihood is -4222.320218457134 on iteration 0
# new_angles=[-1.02082755  0.6602241 ]
# new_P:
# [[2.01018765e-03+0.00000000e+00j 1.57799220e-05-7.41310119e-05j]
#  [1.57799220e-05+7.41310119e-05j 1.74016886e-02+0.00000000e+00j]]
# likelihood is -4114.824839360543 on iteration 1
# new_angles=[-1.03404962  0.66890817]
# new_P:
# [[ 0.00302621+0.j         -0.00013323-0.00034615j]
#  [-0.00013323+0.00034615j  0.05053505+0.j        ]]
# likelihood is -3871.035250275604 on iteration 2
# new_angles=[-1.03920456  0.6758516 ]
# new_P:
# [[ 0.00407401+0.j         -0.00169984-0.00135298j]
#  [-0.00169984+0.00135298j  0.19394463+0.j        ]]
# likelihood is -3558.9136986677245 on iteration 3
# new_angles=[-1.03327427  0.68130071]
# new_P:
# [[ 0.00521761+0.j         -0.00751754-0.00284117j]
#  [-0.00751754+0.00284117j  0.53462495+0.j        ]]
# likelihood is -3432.0590903628067 on iteration 4
# new_angles=[-1.03764135  0.68559064]
# new_P:
# [[ 0.00646016+0.j         -0.01406862-0.00265706j]
#  [-0.01406862+0.00265706j  0.75739731+0.j        ]]
# likelihood is -3396.2336459735743 on iteration 5
# new_angles=[-1.03746124  0.68894647]
# new_P:
# [[ 0.00775161+0.j         -0.01866042-0.00066483j]
#  [-0.01866042+0.00066483j  0.82372913+0.j        ]]
# likelihood is -3377.2556810814954 on iteration 6
# new_angles=[-1.03686129  0.69155858]
# new_P:
# [[ 0.00912487+0.j         -0.02221216+0.00180459j]
#  [-0.02221216-0.00180459j  0.84802014+0.j        ]]
# likelihood is -3365.729982995377 on iteration 7
# new_angles=[-1.03455713  0.69360075]
# new_P:
# [[ 0.01060134+0.j         -0.02512377+0.00436892j]
#  [-0.02512377-0.00436892j  0.86134606+0.j        ]]
# likelihood is -3358.6223374322044 on iteration 8
# new_angles=[-1.03983704  0.69518929]
# new_P:
# [[ 0.01220836+0.j         -0.02751613+0.00670943j]
#  [-0.02751613-0.00670943j  0.87030669+0.j        ]]
# likelihood is -3354.70372304468 on iteration 9
# new_angles=[-1.03809185  0.69642187]
# new_P:
# [[ 0.01392484+0.j         -0.02923969+0.00942144j]
#  [-0.02923969-0.00942144j  0.8763831 +0.j        ]]
# likelihood is -3352.1743710253218 on iteration 10
# new_angles=[-1.04050037  0.69737699]
# new_P:
# [[ 0.01582028+0.j        -0.03056494+0.0117209j]
#  [-0.03056494-0.0117209j  0.8813958 +0.j       ]]
# likelihood is -3350.981031609891 on iteration 11
# new_angles=[-1.0433734   0.69811375]
# new_P:
# [[ 0.01789569+0.j         -0.03137935+0.01398065j]
#  [-0.03137935-0.01398065j  0.88532645+0.j        ]]
# likelihood is -3350.532830156073 on iteration 12
# new_angles=[-1.04449621  0.69869153]
# new_P:
# [[ 0.02017848+0.j         -0.03171255+0.01619132j]
#  [-0.03171255-0.01619132j  0.88868869+0.j        ]]
# likelihood is -3350.4471973744703 on iteration 13
# new_angles=[-1.04626068  0.69913003]
# new_P:
# [[ 0.02272157+0.j         -0.03172593+0.01811334j]
#  [-0.03172593-0.01811334j  0.89187748+0.j        ]]
# likelihood is -3350.761380963353 on iteration 14
# new_angles=[-1.04766391  0.69948893]
# new_P:
# [[ 0.02555278+0.j         -0.0314384 +0.01980505j]
#  [-0.0314384 -0.01980505j  0.89486858+0.j        ]]
# likelihood is -3351.3143974564255 on iteration 15
# new_angles=[-1.04836681  0.6997482 ]
# new_P:
# [[ 0.02870449+0.j        -0.03093453+0.0212084j]
#  [-0.03093453-0.0212084j  0.89780348+0.j       ]]
# 11-th start
# theta=[-1.02904989  0.54174644],P=[[0.00014748+4.31407799e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00345971-8.53692467e-19j]]
# new_angles=[-0.99227961  0.69037496]
# new_P:
# [[0.00123576+0.j         0.00072873-0.00100782j]
#  [0.00072873+0.00100782j 0.02983369+0.j        ]]
# likelihood is -3922.1646820968667 on iteration 0
# new_angles=[0.66268323 0.69277102]
# new_P:
# [[0.00240054+0.j        0.00293159-0.0041483j]
#  [0.00293159+0.0041483j 0.12392016+0.j       ]]
# likelihood is -3538.038356562278 on iteration 1
# new_angles=[0.66722047 0.69479539]
# new_P:
# [[0.00429935+0.j         0.01302471-0.01760166j]
#  [0.01302471+0.01760166j 0.44039371+0.j        ]]
# likelihood is -3373.693510309549 on iteration 2
# new_angles=[0.6697287  0.69644519]
# new_P:
# [[0.00600927+0.j         0.02084741-0.02896135j]
#  [0.02084741+0.02896135j 0.70989522+0.j        ]]
# likelihood is -3356.5966265366264 on iteration 3
# new_angles=[0.53743078 0.69770044]
# new_P:
# [[0.00708321+0.j        0.02143821-0.0314254j]
#  [0.02143821+0.0314254j 0.77604501+0.j       ]]
# likelihood is -3351.3544319656776 on iteration 4
# new_angles=[0.53538928 0.69839756]
# new_P:
# [[0.00825527+0.j         0.02283664-0.03328281j]
#  [0.02283664+0.03328281j 0.84160222+0.j        ]]
# likelihood is -3350.2383422915063 on iteration 5
# new_angles=[0.53581513 0.69887582]
# new_P:
# [[0.00933588+0.j         0.02239831-0.03303666j]
#  [0.02239831+0.03303666j 0.85327425+0.j        ]]
# 12-th start
# theta=[-1.3761631   0.19463323],P=[[0.00287821-7.09935656e-18j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.0001118 +0.00000000e+00j]]
# new_angles=[-0.51572314  0.5049963 ]
# new_P:
# [[ 0.01127975+0.j         -0.00024895+0.00014076j]
#  [-0.00024895-0.00014076j  0.00113188+0.j        ]]
# likelihood is -4083.581954094363 on iteration 0
# new_angles=[-0.51258257  0.66609826]
# new_P:
# [[ 0.03868372+0.j         -0.00094148+0.00036603j]
#  [-0.00094148-0.00036603j  0.00216263+0.j        ]]
# likelihood is -3717.0803788814123 on iteration 1
# new_angles=[-0.50985325  0.67287008]
# new_P:
# [[ 0.19874247+0.j         -0.00516131+0.00221237j]
#  [-0.00516131-0.00221237j  0.00414919+0.j        ]]
# likelihood is -3186.56581044707 on iteration 2
# new_angles=[-0.50775661  0.67740499]
# new_P:
# [[ 0.70982906+0.j         -0.01857964+0.00745144j]
#  [-0.01857964-0.00745144j  0.00862337+0.j        ]]
# likelihood is -2970.2627781276765 on iteration 3
# new_angles=[-0.50615084  0.68368733]
# new_P:
# [[ 1.01269338+0.j         -0.02570565+0.00740022j]
#  [-0.02570565-0.00740022j  0.0213067 +0.j        ]]
# likelihood is -2795.9900850565587 on iteration 4
# new_angles=[-0.50488755  0.68861299]
# new_P:
# [[ 1.06913332+0.j         -0.02440866-0.00299874j]
#  [-0.02440866+0.00299874j  0.07751308+0.j        ]]
# likelihood is -2444.9726802391738 on iteration 5
# new_angles=[-0.50387666  0.69150167]
# new_P:
# [[ 1.08805793+0.j        -0.01580694-0.0383783j]
#  [-0.01580694+0.0383783j  0.3318552 +0.j       ]]
# likelihood is -2166.3641703591106 on iteration 6
# new_angles=[-0.5030725   0.69362446]
# new_P:
# [[ 1.10202276+0.j         -0.00435195-0.08528527j]
#  [-0.00435195+0.08528527j  0.7254299 +0.j        ]]
# likelihood is -2119.1715105687617 on iteration 7
# new_angles=[-0.5024282   0.69527265]
# new_P:
# [[ 1.10914754+0.j         -0.00153919-0.10246783j]
#  [-0.00153919+0.10246783j  0.86229967+0.j        ]]
# likelihood is -2112.7050756731496 on iteration 8
# new_angles=[-0.5019256   0.69655626]
# new_P:
# [[ 1.11373346+0.j         -0.0016186 -0.10835232j]
#  [-0.0016186 +0.10835232j  0.88843709+0.j        ]]
# likelihood is -2109.4936725599546 on iteration 9
# new_angles=[-0.50152532  0.6975513 ]
# new_P:
# [[ 1.11766425+0.j         -0.00183551-0.11244699j]
#  [-0.00183551+0.11244699j  0.8965179 +0.j        ]]
# likelihood is -2107.5778946381015 on iteration 10
# new_angles=[-0.50119471  0.69832802]
# new_P:
# [[ 1.12134704+0.j         -0.00181662-0.11614776j]
#  [-0.00181662+0.11614776j  0.90160735+0.j        ]]
# 13-th start
# theta=[-0.56420445  1.00659187],P=[[0.0070949 +1.15579095e-18j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00035925+1.83608190e-19j]]
# new_angles=[-0.53048886  0.52786748]
# new_P:
# [[0.07105508+0.j         0.00204384+0.00037896j]
#  [0.00204384-0.00037896j 0.00149235+0.j        ]]
# likelihood is -3679.8308135855314 on iteration 0
# new_angles=[-0.52371566  0.70499607]
# new_P:
# [[0.30995069+0.j         0.00820889+0.00166278j]
#  [0.00820889-0.00166278j 0.00268229+0.j        ]]
# likelihood is -3255.298406770548 on iteration 1
# new_angles=[-0.51864834  0.72243643]
# new_P:
# [[0.75668529+0.j         0.01983732+0.00444584j]
#  [0.01983732-0.00444584j 0.00540403+0.j        ]]
# likelihood is -3102.0649925041744 on iteration 2
# new_angles=[-0.51457698  0.72716511]
# new_P:
# [[0.95897617+0.j         0.02431194+0.00559148j]
#  [0.02431194-0.00559148j 0.01118542+0.j        ]]
# likelihood is -2983.3826320055155 on iteration 3
# new_angles=[-0.51138961  0.7214199 ]
# new_P:
# [[1.01867661+0.j         0.02254122+0.00425922j]
#  [0.02254122-0.00425922j 0.02979232+0.j        ]]
# likelihood is -2755.6099424447452 on iteration 4
# new_angles=[-0.50888019  0.71656559]
# new_P:
# [[1.0481733 +0.j         0.01093888-0.00552242j]
#  [0.01093888+0.00552242j 0.11768506+0.j        ]]
# likelihood is -2375.8907413652655 on iteration 5
# new_angles=[-0.50686325  0.71298356]
# new_P:
# [[ 1.07285652+0.j       -0.02020461-0.042133j]
#  [-0.02020461+0.042133j  0.44279246+0.j      ]]
# likelihood is -2167.7696715254797 on iteration 6
# new_angles=[-0.505267   0.7102534]
# new_P:
# [[ 1.09184655+0.j         -0.04080015-0.08301447j]
#  [-0.04080015+0.08301447j  0.77304241+0.j        ]]
# likelihood is -2132.4828183548057 on iteration 7
# new_angles=[-0.50403805  0.70815222]
# new_P:
# [[ 1.10281053+0.j         -0.03887031-0.10006777j]
#  [-0.03887031+0.10006777j  0.86480317+0.j        ]]
# likelihood is -2121.031712489431 on iteration 8
# new_angles=[-0.50308859  0.70653619]
# new_P:
# [[ 1.11011738+0.j         -0.03252729-0.10825618j]
#  [-0.03252729+0.10825618j  0.88570334+0.j        ]]
# likelihood is -2114.452045778907 on iteration 9
# new_angles=[-0.50235723  0.70529306]
# new_P:
# [[ 1.11571931+0.j         -0.02642742-0.11379778j]
#  [-0.02642742+0.11379778j  0.89445953+0.j        ]]
# likelihood is -2110.553272136909 on iteration 10
# new_angles=[-0.50180021  0.70433154]
# new_P:
# [[ 1.12037412+0.j         -0.02115675-0.11813661j]
#  [-0.02115675+0.11813661j  0.90042602+0.j        ]]
# likelihood is -2108.251085371041 on iteration 11
# new_angles=[-0.50137721  0.7035973 ]
# new_P:
# [[ 1.12447588+0.j         -0.01670751-0.12181164j]
#  [-0.01670751+0.12181164j  0.90528846+0.j        ]]
# 14-th start
# theta=[-1.18205423  0.38874209],P=[[0.00209668-2.48175665e-21j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00301632+5.44595085e-19j]]
# new_angles=[-1.34716095  0.62461215]
# new_P:
# [[0.00756935+0.j         0.00222947-0.00472278j]
#  [0.00222947+0.00472278j 0.0197586 +0.j        ]]
# likelihood is -4228.851321840611 on iteration 0
# new_angles=[-1.34730342  0.63863868]
# new_P:
# [[0.00940052+0.j         0.00317843-0.00797114j]
#  [0.00317843+0.00797114j 0.03452419+0.j        ]]
# likelihood is -4124.948830133326 on iteration 1
# new_angles=[-1.33069329  0.65091922]
# new_P:
# [[0.01254427+0.j         0.0055529 -0.01762858j]
#  [0.0055529 +0.01762858j 0.08168731+0.j        ]]
# likelihood is -3928.723818703516 on iteration 2
# new_angles=[-1.31071718  0.66118998]
# new_P:
# [[0.01844251+0.j         0.01078251-0.04330979j]
#  [0.01078251+0.04330979j 0.2227213 +0.j        ]]
# likelihood is -3707.268432665921 on iteration 3
# new_angles=[-1.29627449  0.66960816]
# new_P:
# [[0.0246206 +0.j         0.01540516-0.07841956j]
#  [0.01540516+0.07841956j 0.45909143+0.j        ]]
# likelihood is -3568.5952555576946 on iteration 4
# new_angles=[0.6756107  0.84057481]
# new_P:
# [[0.63653   +0.j        0.01417007+0.0936785j]
#  [0.01417007-0.0936785j 0.02612238+0.j       ]]
# likelihood is -3468.3227200271517 on iteration 5
# new_angles=[0.68037151 0.84311761]
# new_P:
# [[ 7.44124104e-01+0.j        -2.47384490e-04+0.1042928j]
#  [-2.47384490e-04-0.1042928j  2.79389815e-02+0.j       ]]
# likelihood is -3426.432219672087 on iteration 6
# new_angles=[0.68424517 0.84340585]
# new_P:
# [[ 0.79324566+0.j         -0.01430029+0.10237771j]
#  [-0.01430029-0.10237771j  0.0282032 +0.j        ]]
# likelihood is -3399.077717040394 on iteration 7
# new_angles=[0.68732089 0.84368127]
# new_P:
# [[ 0.82141115+0.j         -0.02614535+0.09451113j]
#  [-0.02614535-0.09451113j  0.02800051+0.j        ]]
# likelihood is -3381.2675830359767 on iteration 8
# new_angles=[0.68977124 0.84432426]
# new_P:
# [[ 0.8407011 +0.j         -0.03486503+0.08365207j]
#  [-0.03486503-0.08365207j  0.02780561+0.j        ]]
# likelihood is -3369.812080538354 on iteration 9
# new_angles=[0.69173113 0.84255717]
# new_P:
# [[ 0.85511461+0.j         -0.0401933 +0.07146466j]
#  [-0.0401933 -0.07146466j  0.02784734+0.j        ]]
# likelihood is -3362.5088969571566 on iteration 10
# new_angles=[0.69334444 0.83937987]
# new_P:
# [[ 0.86464082+0.j         -0.04297245+0.05831799j]
#  [-0.04297245-0.05831799j  0.02827724+0.j        ]]
# likelihood is -3357.8011326986166 on iteration 11
# new_angles=[0.69457511 0.83901442]
# new_P:
# [[ 0.87134532+0.j         -0.04352963+0.04481982j]
#  [-0.04352963-0.04481982j  0.02925366+0.j        ]]
# likelihood is -3355.2482543711803 on iteration 12
# new_angles=[0.69560827 0.83655153]
# new_P:
# [[ 0.87832441+0.j         -0.04177262+0.03249329j]
#  [-0.04177262-0.03249329j  0.0308602 +0.j        ]]
# likelihood is -3353.899497003797 on iteration 13
# new_angles=[0.69646328 0.83366392]
# new_P:
# [[ 0.88348996+0.j         -0.03823694+0.02103367j]
#  [-0.03823694-0.02103367j  0.03313712+0.j        ]]
# likelihood is -3353.4853842372936 on iteration 14
# new_angles=[0.69715967 0.83132874]
# new_P:
# [[ 0.88791331+0.j         -0.03322149+0.01074551j]
#  [-0.03322149-0.01074551j  0.03612141+0.j        ]]
# likelihood is -3353.8332245394868 on iteration 15
# new_angles=[0.69773699 0.82949652]
# new_P:
# [[ 0.89228726+0.j         -0.0270574 +0.00198196j]
#  [-0.0270574 -0.00198196j  0.03979146+0.j        ]]
# likelihood is -3354.7421467564122 on iteration 16
# new_angles=[0.69821498 0.82642842]
# new_P:
# [[ 0.89670804+0.j         -0.02012564-0.00514447j]
#  [-0.02012564+0.00514447j  0.04407583+0.j        ]]
# likelihood is -3355.975009591312 on iteration 17
# new_angles=[0.69861346 0.82507809]
# new_P:
# [[ 0.90069633+0.j         -0.01251405-0.01078982j]
#  [-0.01251405+0.01078982j  0.04895682+0.j        ]]
# likelihood is -3357.5897767415786 on iteration 18
# new_angles=[0.6989722  0.82377464]
# new_P:
# [[ 0.90518639+0.j         -0.00486557-0.01497531j]
#  [-0.00486557+0.01497531j  0.05423488+0.j        ]]
# likelihood is -3359.3567410210007 on iteration 19
# new_angles=[0.69929117 0.8234154 ]
# new_P:
# [[0.90973436+0.j         0.00271822-0.01794538j]
#  [0.00271822+0.01794538j 0.05976547+0.j        ]]
# 15-th start
# theta=[-0.04864751  1.52214882],P=[[0.00352447+8.08248645e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00031347+1.24302742e-18j]]
# new_angles=[-0.55179291  0.11352494]
# new_P:
# [[ 0.01814676+0.j         -0.00048499-0.00012573j]
#  [-0.00048499+0.00012573j  0.00140093+0.j        ]]
# likelihood is -4130.645188744637 on iteration 0
# new_angles=[-0.54056237 -0.22170629]
# new_P:
# [[ 0.04950748+0.j        -0.00127462-0.0003259j]
#  [-0.00127462+0.0003259j  0.00242465+0.j       ]]
# likelihood is -3862.1173710356898 on iteration 1
# new_angles=[-0.53169    -0.45570998]
# new_P:
# [[ 0.19418882+0.j         -0.00624972-0.00283367j]
#  [-0.00624972+0.00283367j  0.00363498+0.j        ]]
# likelihood is -3429.7497189956616 on iteration 2
# new_angles=[-0.5252231  -0.45737597]
# new_P:
# [[ 0.57447627+0.j         -0.02691366-0.02330706j]
#  [-0.02691366+0.02330706j  0.00677913+0.j        ]]
# likelihood is -3227.9633738063167 on iteration 3
# new_angles=[-0.52050312 -0.45577795]
# new_P:
# [[ 0.83294443+0.j         -0.0433849 -0.05072642j]
#  [-0.0433849 +0.05072642j  0.011141  +0.j        ]]
# likelihood is -3159.2607901669926 on iteration 4
# new_angles=[-0.51700661 -0.45426609]
# new_P:
# [[ 0.90273041+0.j         -0.04873961-0.07054568j]
#  [-0.04873961+0.07054568j  0.01521152+0.j        ]]
# likelihood is -3123.4314684411197 on iteration 5
# new_angles=[-0.51441069 -0.45304383]
# new_P:
# [[ 0.92044849+0.j         -0.04938153-0.08546296j]
#  [-0.04938153+0.08546296j  0.01899847+0.j        ]]
# likelihood is -3103.1513691883983 on iteration 6
# new_angles=[-0.51246625 -0.45244993]
# new_P:
# [[ 0.92434211+0.j         -0.04762025-0.09704525j]
#  [-0.04762025+0.09704525j  0.02249431+0.j        ]]
# likelihood is -3091.7967553462013 on iteration 7
# new_angles=[-0.51103118 -0.45211064]
# new_P:
# [[ 0.92317071+0.j         -0.04410479-0.10580315j]
#  [-0.04410479+0.10580315j  0.02564125+0.j        ]]
# likelihood is -3085.510765059358 on iteration 8
# new_angles=[-0.50999935 -0.45172053]
# new_P:
# [[ 0.92062274+0.j         -0.03928497-0.11218198j]
#  [-0.03928497+0.11218198j  0.02846304+0.j        ]]
# likelihood is -3082.0699263913034 on iteration 9
# new_angles=[-0.50926518 -0.45127962]
# new_P:
# [[ 0.91868372+0.j         -0.03351446-0.11659975j]
#  [-0.03351446+0.11659975j  0.03104843+0.j        ]]
# 16-th start
# theta=[-1.14004319  0.43075313],P=[[0.00099367+2.23919387e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00189668+1.31236594e-18j]]
# new_angles=[-0.57080617  0.62621101]
# new_P:
# [[0.00389175+0.j        0.00223662-0.0014649j]
#  [0.00223662+0.0014649j 0.00951848+0.j       ]]
# likelihood is -4237.118215654725 on iteration 0
# new_angles=[-0.55665327  0.6398377 ]
# new_P:
# [[0.00631059+0.j         0.00376001-0.00261711j]
#  [0.00376001+0.00261711j 0.01565597+0.j        ]]
# likelihood is -4137.739139000856 on iteration 1
# new_angles=[-0.54537416  0.65202028]
# new_P:
# [[0.01266285+0.j         0.00925718-0.00661442j]
#  [0.00925718+0.00661442j 0.03466895+0.j        ]]
# likelihood is -3914.493528519331 on iteration 2
# new_angles=[-0.53590611  0.66211851]
# new_P:
# [[0.03543154+0.j        0.0319749 -0.0231934j]
#  [0.0319749 +0.0231934j 0.10701659+0.j       ]]
# likelihood is -3484.224641642134 on iteration 3
# new_angles=[-0.52776514  0.67013151]
# new_P:
# [[0.12126696+0.j         0.09972925-0.07612674j]
#  [0.09972925+0.07612674j 0.32462545+0.j        ]]
# likelihood is -2912.8619226341407 on iteration 4
# new_angles=[-0.52118978  0.67635759]
# new_P:
# [[0.38331699+0.j         0.13343284-0.12742947j]
#  [0.13343284+0.12742947j 0.58462728+0.j        ]]
# likelihood is -2431.647331194705 on iteration 5
# new_angles=[-0.51639295  0.68143558]
# new_P:
# [[0.82004533+0.j         0.04487805-0.11207816j]
#  [0.04487805+0.11207816j 0.74331054+0.j        ]]
# likelihood is -2268.1781946335755 on iteration 6
# new_angles=[-0.51275574  0.68559784]
# new_P:
# [[ 1.01459402e+00+0.j         -8.98614369e-04-0.09925977j]
#  [-8.98614369e-04+0.09925977j  8.17052500e-01+0.j        ]]
# likelihood is -2203.471032963742 on iteration 7
# new_angles=[-0.50994208  0.6889115 ]
# new_P:
# [[ 1.06700335+0.j         -0.00726379-0.10095534j]
#  [-0.00726379+0.10095534j  0.85094588+0.j        ]]
# likelihood is -2164.962208447565 on iteration 8
# new_angles=[-0.50774503  0.69151978]
# new_P:
# [[ 1.08961826+0.j         -0.00704036-0.10530112j]
#  [-0.00704036+0.10530112j  0.87097082+0.j        ]]
# likelihood is -2141.292123091134 on iteration 9
# new_angles=[-0.50603931  0.69357711]
# new_P:
# [[ 1.10348834+0.j         -0.00603029-0.10974017j]
#  [-0.00603029+0.10974017j  0.88437854+0.j        ]]
# likelihood is -2126.835508936459 on iteration 10
# new_angles=[-0.50470524  0.69519542]
# new_P:
# [[ 1.11304941+0.j         -0.00498773-0.11395316j]
#  [-0.00498773+0.11395316j  0.89396088+0.j        ]]
# likelihood is -2118.0294845803896 on iteration 11
# new_angles=[-0.50366855  0.69646118]
# new_P:
# [[ 1.12012885+0.j         -0.0039532 -0.11793411j]
#  [-0.0039532 +0.11793411j  0.90118956+0.j        ]]
# likelihood is -2112.7255683551607 on iteration 12
# new_angles=[-0.5028673   0.69745615]
# new_P:
# [[ 1.12570358+0.j         -0.00293055-0.12171359j]
#  [-0.00293055+0.12171359j  0.90694989+0.j        ]]
# likelihood is -2109.548268991159 on iteration 13
# new_angles=[-0.50223178  0.69824276]
# new_P:
# [[ 1.13036988+0.j         -0.00193671-0.12533093j]
#  [-0.00193671+0.12533093j  0.91180811+0.j        ]]
# likelihood is -2107.6307308538476 on iteration 14
# new_angles=[-0.5017357  0.6988505]
# new_P:
# [[ 1.13451097e+00+0.j         -9.31990156e-04-0.12882074j]
#  [-9.31990156e-04+0.12882074j  9.16112172e-01+0.j        ]]
# 17-th start
# theta=[-1.25895905  0.31183728],P=[[2.78193468e-03+7.02365578e-19j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 1.39754249e-05+0.00000000e+00j]]
# new_angles=[-0.49452019  0.54858968]
# new_P:
# [[ 8.78360977e-03+0.00000000e+00j -6.84331782e-06-1.80928432e-05j]
#  [-6.84331782e-06+1.80928432e-05j  1.01443785e-03+0.00000000e+00j]]
# likelihood is -4118.082472814595 on iteration 0
# new_angles=[-0.49563     0.54515975]
# new_P:
# [[ 0.02787577+0.j         -0.00015288-0.00010719j]
#  [-0.00015288+0.00010719j  0.00202506+0.j        ]]
# likelihood is -3839.338086005409 on iteration 1
# new_angles=[-0.49674048  0.54173694]
# new_P:
# [[ 0.13782881+0.j         -0.00120533-0.00076556j]
#  [-0.00120533+0.00076556j  0.00307943+0.j        ]]
# likelihood is -3317.189275913703 on iteration 2
# new_angles=[-0.49762587  0.54100694]
# new_P:
# [[ 0.60015298+0.j         -0.00560096-0.00380254j]
#  [-0.00560096+0.00380254j  0.00424156+0.j        ]]
# likelihood is -3089.4453471721736 on iteration 3
# new_angles=[-0.49830353  0.58565802]
# new_P:
# [[ 0.99586325+0.j         -0.00877813-0.00671981j]
#  [-0.00877813+0.00671981j  0.00547825+0.j        ]]
# likelihood is -3074.7955234904425 on iteration 4
# new_angles=[-0.49881019  0.78238649]
# new_P:
# [[ 1.07277407+0.j         -0.00930206-0.00835856j]
#  [-0.00930206+0.00835856j  0.00673571+0.j        ]]
# likelihood is -3043.8031744028476 on iteration 5
# new_angles=[-0.49915775  0.77920737]
# new_P:
# [[ 1.08478293+0.j         -0.01189961-0.00887727j]
#  [-0.01189961+0.00887727j  0.01034701+0.j        ]]
# likelihood is -3023.02501924511 on iteration 6
# new_angles=[-0.4994433   0.75958709]
# new_P:
# [[ 1.08907733+0.j         -0.0154194 -0.01005285j]
#  [-0.0154194 +0.01005285j  0.01747242+0.j        ]]
# likelihood is -2935.464157842615 on iteration 7
# new_angles=[-0.49958236  0.75003462]
# new_P:
# [[ 1.09381658+0.j         -0.02144815-0.01477171j]
#  [-0.02144815+0.01477171j  0.04255741+0.j        ]]
# likelihood is -2766.127834638484 on iteration 8
# new_angles=[-0.49970404  0.73926476]
# new_P:
# [[ 1.09898987+0.j         -0.03307934-0.02742924j]
#  [-0.03307934+0.02742924j  0.13829034+0.j        ]]
# likelihood is -2478.6459741333983 on iteration 9
# new_angles=[-0.49971274  0.73073883]
# new_P:
# [[ 1.1063601 +0.j         -0.05029695-0.05664594j]
#  [-0.05029695+0.05664594j  0.41158486+0.j        ]]
# likelihood is -2286.700061558656 on iteration 10
# new_angles=[-0.49967273  0.72409309]
# new_P:
# [[ 1.11384757+0.j         -0.0565344 -0.08776684j]
#  [-0.0565344 +0.08776684j  0.68713657+0.j        ]]
# likelihood is -2210.798748813092 on iteration 11
# new_angles=[-0.49963796  0.718931  ]
# new_P:
# [[ 1.11981121+0.j         -0.05067201-0.10624236j]
#  [-0.05067201+0.10624236j  0.80373879+0.j        ]]
# likelihood is -2169.940314231937 on iteration 12
# new_angles=[-0.49962836  0.71493031]
# new_P:
# [[ 1.12477159+0.j         -0.04192888-0.11737345j]
#  [-0.04192888+0.11737345j  0.85227405+0.j        ]]
# likelihood is -2144.8835643005937 on iteration 13
# new_angles=[-0.49963705  0.71183276]
# new_P:
# [[ 1.12913668+0.j         -0.03345117-0.12479453j]
#  [-0.03345117+0.12479453j  0.87892629+0.j        ]]
# likelihood is -2129.4833056390657 on iteration 14
# new_angles=[-0.49966118  0.70943253]
# new_P:
# [[ 1.13313008+0.j         -0.0260129 -0.13007919j]
#  [-0.0260129 +0.13007919j  0.89586059+0.j        ]]
# likelihood is -2120.057738739174 on iteration 15
# new_angles=[-0.4996837   0.70755473]
# new_P:
# [[ 1.13689264+0.j         -0.01974042-0.13412146j]
#  [-0.01974042+0.13412146j  0.90738731+0.j        ]]
# likelihood is -2114.260901324864 on iteration 16
# new_angles=[-0.49970977  0.70609994]
# new_P:
# [[ 1.14051174+0.j         -0.01446893-0.13748305j]
#  [-0.01446893+0.13748305j  0.91572526+0.j        ]]
# likelihood is -2110.742340438587 on iteration 17
# new_angles=[-0.49974454  0.70497747]
# new_P:
# [[ 1.14404101+0.j         -0.01009046-0.14047899j]
#  [-0.01009046+0.14047899j  0.92209791+0.j        ]]
# likelihood is -2108.616260448674 on iteration 18
# new_angles=[-0.49977062  0.7041063 ]
# new_P:
# [[ 1.14751607+0.j         -0.00646998-0.14329838j]
#  [-0.00646998+0.14329838j  0.92727237+0.j        ]]
# 18-th start
# theta=[-0.61987909  0.95091723],P=[[0.00054693-1.12589220e-18j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00157373-2.18587428e-19j]]
# new_angles=[-0.49762655  0.52009577]
# new_P:
# [[0.00928164+0.j         0.00179819-0.00082643j]
#  [0.00179819+0.00082643j 0.00232985+0.j        ]]
# likelihood is -4108.388627889917 on iteration 0
# new_angles=[-0.4979052   0.17565536]
# new_P:
# [[0.02999627+0.j         0.00536103-0.00275329j]
#  [0.00536103+0.00275329j 0.00420068+0.j        ]]
# likelihood is -3807.110466750631 on iteration 1
# new_angles=[-0.49856528  0.17500451]
# new_P:
# [[0.15037526+0.j         0.02684592-0.01374198j]
#  [0.02684592+0.01374198j 0.01007452+0.j        ]]
# 19-th start
# theta=[-0.52701452  1.0437818 ],P=[[0.01962923+1.43197902e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00047232+9.80408692e-20j]]
# new_angles=[-0.513688    0.90432597]
# new_P:
# [[0.17889453+0.j        0.00092387+0.0001565j]
#  [0.00092387-0.0001565j 0.00157632+0.j       ]]
# likelihood is -3296.3005073977183 on iteration 0
# new_angles=[-0.5107121   0.91701651]
# new_P:
# [[0.66192117+0.j         0.00388055+0.00065977j]
#  [0.00388055-0.00065977j 0.00260629+0.j        ]]
# likelihood is -3117.69426466479 on iteration 1
# new_angles=[-0.50841012  0.94219014]
# new_P:
# [[0.98738299+0.j         0.00611676+0.00107113j]
#  [0.00611676-0.00107113j 0.00365415+0.j        ]]
# likelihood is -3096.0450204765266 on iteration 2
# new_angles=[-0.50659434  0.94949275]
# new_P:
# [[1.05286773+0.j         0.00700061+0.00076379j]
#  [0.00700061-0.00076379j 0.00470471+0.j        ]]
# likelihood is -3087.645779033147 on iteration 3
# new_angles=[-0.50523371  0.95501895]
# new_P:
# [[1.06845984+0.j         0.00746689+0.00029947j]
#  [0.00746689-0.00029947j 0.00577555+0.j        ]]
# likelihood is -3082.9643944104614 on iteration 4
# new_angles=[-0.50418777  0.95681766]
# new_P:
# [[1.07609042+0.j         0.00770901-0.00025418j]
#  [0.00770901+0.00025418j 0.00687662+0.j        ]]
# likelihood is -3080.1795903785464 on iteration 5
# new_angles=[-0.50336887  0.95987008]
# new_P:
# [[1.08153068+0.j         0.00768593-0.00073869j]
#  [0.00768593+0.00073869j 0.00802767+0.j        ]]
# likelihood is -3078.6415015515836 on iteration 6
# new_angles=[-0.50267223  0.96606888]
# new_P:
# [[1.0859869 +0.j         0.00740243-0.00125714j]
#  [0.00740243+0.00125714j 0.00923998+0.j        ]]
# likelihood is -3077.903742380068 on iteration 7
# new_angles=[-0.50220215  0.96733145]
# new_P:
# [[1.08996463+0.j        0.00689543-0.0020632j]
#  [0.00689543+0.0020632j 0.0105182 +0.j       ]]
# likelihood is -3077.5723955834574 on iteration 8
# new_angles=[-0.50183661  0.96897356]
# new_P:
# [[1.09349306+0.j         0.0061056 -0.00285173j]
#  [0.0061056 +0.00285173j 0.01190223+0.j        ]]
# likelihood is -3077.5429439766144 on iteration 9
# new_angles=[-0.50156264  0.97750171]
# new_P:
# [[1.09683787+0.j         0.00504962-0.00368321j]
#  [0.00504962+0.00368321j 0.01341712+0.j        ]]
# likelihood is -3077.9222134764536 on iteration 10
# new_angles=[-0.50128423  0.98452507]
# new_P:
# [[1.10017716+0.j         0.00376837-0.00528582j]
#  [0.00376837+0.00528582j 0.01506669+0.j        ]]
# likelihood is -3078.2261174092887 on iteration 11
# new_angles=[-0.50113339  0.9927925 ]
# new_P:
# [[1.10355361+0.j         0.00213194-0.00747646j]
#  [0.00213194+0.00747646j 0.01690693+0.j        ]]
# likelihood is -3078.486821421109 on iteration 12
# new_angles=[-0.50102036  1.01944211]
# new_P:
# [[ 1.10702749e+00+0.j         -5.61961085e-05-0.01040064j]
#  [-5.61961085e-05+0.01040064j  1.90116987e-02+0.j        ]]
# likelihood is -3077.1582110448544 on iteration 13
# new_angles=[-0.50098911  1.04820984]
# new_P:
# [[ 1.11130442+0.j         -0.00522553-0.01535339j]
#  [-0.00522553+0.01535339j  0.0217598 +0.j        ]]
# likelihood is -3074.7610821197413 on iteration 14
# new_angles=[-0.50091952  1.05004704]
# new_P:
# [[ 1.11606219+0.j         -0.01489434-0.01928264j]
#  [-0.01489434+0.01928264j  0.02552724+0.j        ]]
# likelihood is -3074.858632189113 on iteration 15
# new_angles=[-0.50084994  1.05238265]
# new_P:
# [[ 1.12076894+0.j        -0.02383339-0.0224334j]
#  [-0.02383339+0.0224334j  0.03000387+0.j       ]]
# likelihood is -3075.2523764866346 on iteration 16
# new_angles=[-0.50081515  1.05726914]
# new_P:
# [[ 1.12512406+0.j         -0.03201519-0.02471239j]
#  [-0.03201519+0.02471239j  0.03517714+0.j        ]]
# likelihood is -3075.7115770504347 on iteration 17
# new_angles=[-0.50074557  1.06163458]
# new_P:
# [[ 1.12921004+0.j         -0.03987504-0.02572765j]
#  [-0.03987504+0.02572765j  0.04104491+0.j        ]]
# likelihood is -3076.538191046611 on iteration 18
# new_angles=[-0.50074557  1.06793085]
# new_P:
# [[ 1.13307058+0.j         -0.04711326-0.02561045j]
#  [-0.04711326+0.02561045j  0.04746499+0.j        ]]
# likelihood is -3077.5346116789487 on iteration 19
# new_angles=[-0.500676    1.07085144]
# new_P:
# [[ 1.13671746+0.j         -0.0539803 -0.02394259j]
#  [-0.0539803 +0.02394259j  0.05425968+0.j        ]]
# likelihood is -3079.0339306561796 on iteration 20
# new_angles=[-0.50064121  1.07590404]
# new_P:
# [[ 1.14024407+0.j         -0.05964168-0.02197787j]
#  [-0.05964168+0.02197787j  0.06109577+0.j        ]]
# likelihood is -3080.581805809386 on iteration 21
# new_angles=[-0.50060642  1.07622542]
# new_P:
# [[ 1.14358265+0.j         -0.06461911-0.01903219j]
#  [-0.06461911+0.01903219j  0.06772602+0.j        ]]
# best_start=12

# %%
print(f"EM_theta2_rad={EM_theta2_rad},\nEM_P2={EM_P2}")
# Out:
# EM_theta2_rad=[-0.50152532  0.6975513 ],
# EM_P2=[[ 1.11766425+0.j         -0.00183551-0.11244699j]
#  [-0.00183551+0.11244699j  0.8965179 +0.j        ]]

# %%
EM_theta2_deg = np.rad2deg(EM_theta2_rad)
print(f"Погрешность в смысле разности углов в градусах: \
      {np.abs(np.sort(EM_theta2_deg)-np.sort(theta2_deg))},")
print(f"Погрешность в смысле разности синусов углов: \
      {np.abs(np.sin(EM_theta2_rad)-np.sin(theta2_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах:       [0.08739432 0.14029997],
# Погрешность в смысле разности синусов углов:       [0.00133803 0.0018748 ].

# %%
em_stoch.incomplete_lkhd(X1_with_mv, theta1_rad, P_1, Q_1)
# Out:
# np.float64(-2824.893641702692)

# %%
em_stoch.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q_1)
# Out:
# np.float64(-2825.410196266896)

# %%
em_stoch.incomplete_lkhd(X2_with_mv, theta2_rad, P_2, Q_2)
# Out:
# np.float64(-2106.416306045104)

# %%
em_stoch.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q_2)
# Out:
# np.float64(-2107.5778946381015)
