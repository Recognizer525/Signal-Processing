# %%
import numpy as np

import diff_sensor_structures
import sensors
import em_stoch
import subspace_methods

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12
failing_sensors1 = np.array([0, 1, 2, 3, 4], dtype=np.int16)
gap_ratio1 = np.array([0.5, 0.5, 0.5, 0.5, 0.5], dtype=np.float32)
theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P_1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q_1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
N1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sensors.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sensors.initial_Cov(X1_with_mv)
MUSIC_theta1 = subspace_methods.MUSIC_DoA(R1, Num_emitters1)

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sensors.SNR(A1, P_1, Q_1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1 = em_stoch.multistart_EM2(X1_with_mv, 
                                                      Num_emitters1, 
                                                      Q=Q_1,
                                                      MUSIC_theta=MUSIC_theta1, 
                                                      num_of_starts=10, 
                                                      max_iter=20, 
                                                      rtol=1e-5)
# Out:
# 0-th start
# theta=[0.80378761],P=[[4.8828125e-08+0.j]]
# new_angles=[0.80378761]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -870.4013699741913 on iteration 0
# new_angles=[0.80378761]
# new_P:
# [[0.002+0.j]]
# 1-th start
# theta=[0.62809672],P=[[6.82086539e-08+0.j]]
# new_angles=[0.62809672]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3703510235397 on iteration 0
# new_angles=[0.62809672]
# new_P:
# [[0.00200259+0.j]]
# likelihood is -870.3397588975417 on iteration 1
# new_angles=[0.6339026]
# new_P:
# [[0.00301397+0.j]]
# likelihood is -870.2925733083172 on iteration 2
# new_angles=[0.63924299]
# new_P:
# [[0.00404641+0.j]]
# likelihood is -870.2313800713952 on iteration 3
# new_angles=[0.64411916]
# new_P:
# [[0.00511756+0.j]]
# likelihood is -870.1552450130418 on iteration 4
# new_angles=[0.65035471]
# new_P:
# [[0.00625178+0.j]]
# likelihood is -870.0473620399755 on iteration 5
# new_angles=[0.65630934]
# new_P:
# [[0.00749007+0.j]]
# likelihood is -869.9136831363899 on iteration 6
# new_angles=[0.66184064]
# new_P:
# [[0.00888574+0.j]]
# likelihood is -869.7537853666089 on iteration 7
# new_angles=[0.66708195]
# new_P:
# [[0.0105124+0.j]]
# likelihood is -869.5627804975182 on iteration 8
# new_angles=[0.67206387]
# new_P:
# [[0.01247738+0.j]]
# likelihood is -869.3336650064432 on iteration 9
# new_angles=[0.67627165]
# new_P:
# [[0.0149434+0.j]]
# likelihood is -869.0629173348765 on iteration 10
# new_angles=[0.67953706]
# new_P:
# [[0.01815997+0.j]]
# likelihood is -868.7348220045533 on iteration 11
# new_angles=[0.68238543]
# new_P:
# [[0.0225409+0.j]]
# likelihood is -868.3092978842212 on iteration 12
# new_angles=[0.68479913]
# new_P:
# [[0.02883912+0.j]]
# likelihood is -867.7301179770766 on iteration 13
# new_angles=[0.68684602]
# new_P:
# [[0.03850473+0.j]]
# likelihood is -866.8958785337151 on iteration 14
# new_angles=[0.68855231]
# new_P:
# [[0.05457345+0.j]]
# likelihood is -865.6245374095187 on iteration 15
# new_angles=[0.68997594]
# new_P:
# [[0.08397575+0.j]]
# likelihood is -863.5974958593176 on iteration 16
# new_angles=[0.69114587]
# new_P:
# [[0.14372758+0.j]]
# likelihood is -860.3774107665204 on iteration 17
# new_angles=[0.6920968]
# new_P:
# [[0.27526407+0.j]]
# likelihood is -855.934084450438 on iteration 18
# new_angles=[0.69287866]
# new_P:
# [[0.55393054+0.j]]
# likelihood is -851.9366873282099 on iteration 19
# 2-th start
# theta=[0.64303758],P=[[1.11433171e-07-5.95570041e-24j]]
# new_angles=[0.64303758]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3537914015952 on iteration 0
# new_angles=[0.65020667]
# new_P:
# [[0.00200397+0.j]]
# likelihood is -870.2864099637939 on iteration 1
# new_angles=[0.65640096]
# new_P:
# [[0.00302422+0.j]]
# likelihood is -870.2007861620481 on iteration 2
# new_angles=[0.66134131]
# new_P:
# [[0.00407971+0.j]]
# likelihood is -870.1019420544385 on iteration 3
# new_angles=[0.66630073]
# new_P:
# [[0.00519503+0.j]]
# likelihood is -869.9848899364225 on iteration 4
# new_angles=[0.67121724]
# new_P:
# [[0.00640435+0.j]]
# likelihood is -869.8487097881498 on iteration 5
# new_angles=[0.67513153]
# new_P:
# [[0.00775376+0.j]]
# likelihood is -869.6996956374934 on iteration 6
# new_angles=[0.67872021]
# new_P:
# [[0.00930165+0.j]]
# likelihood is -869.5297350525396 on iteration 7
# new_angles=[0.68150882]
# new_P:
# [[0.01113332+0.j]]
# likelihood is -869.3370319736267 on iteration 8
# new_angles=[0.68410441]
# new_P:
# [[0.01337123+0.j]]
# likelihood is -869.1064680604367 on iteration 9
# new_angles=[0.68621494]
# new_P:
# [[0.01621032+0.j]]
# likelihood is -868.8245642916338 on iteration 10
# new_angles=[0.6881226]
# new_P:
# [[0.01996647+0.j]]
# likelihood is -868.4629109140708 on iteration 11
# new_angles=[0.68960238]
# new_P:
# [[0.02519093+0.j]]
# likelihood is -867.9802772521065 on iteration 12
# new_angles=[0.69086884]
# new_P:
# [[0.03290132+0.j]]
# likelihood is -867.3001998782034 on iteration 13
# new_angles=[0.69194318]
# new_P:
# [[0.04513574+0.j]]
# likelihood is -866.2892122902759 on iteration 14
# new_angles=[0.69274827]
# new_P:
# [[0.06632878+0.j]]
# likelihood is -864.7095407765637 on iteration 15
# new_angles=[0.69341696]
# new_P:
# [[0.10696202+0.j]]
# likelihood is -862.1730098908702 on iteration 16
# new_angles=[0.69395562]
# new_P:
# [[0.19298931+0.j]]
# likelihood is -858.3176621458011 on iteration 17
# new_angles=[0.69438443]
# new_P:
# [[0.38236646+0.j]]
# likelihood is -853.777275832209 on iteration 18
# new_angles=[0.69474554]
# new_P:
# [[0.74373027+0.j]]
# likelihood is -850.8913006481839 on iteration 19
# 3-th start
# theta=[0.64132648],P=[[1.05540317e-07-2.64697796e-24j]]
# new_angles=[0.64132648]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3560430120068 on iteration 0
# new_angles=[0.65249049]
# new_P:
# [[0.00200379+0.j]]
# likelihood is -870.2796525418406 on iteration 1
# new_angles=[0.65684083]
# new_P:
# [[0.00302515+0.j]]
# likelihood is -870.1987303970029 on iteration 2
# new_angles=[0.66178286]
# new_P:
# [[0.00408118+0.j]]
# likelihood is -870.0991982784408 on iteration 3
# new_angles=[0.6670986]
# new_P:
# [[0.00519746+0.j]]
# likelihood is -869.9790095494767 on iteration 4
# new_angles=[0.67208058]
# new_P:
# [[0.0064094+0.j]]
# likelihood is -869.8414691355249 on iteration 5
# new_angles=[0.67600543]
# new_P:
# [[0.00776293+0.j]]
# likelihood is -869.6915186519096 on iteration 6
# new_angles=[0.67910662]
# new_P:
# [[0.00931673+0.j]]
# likelihood is -869.5249762791457 on iteration 7
# new_angles=[0.68224128]
# new_P:
# [[0.01115359+0.j]]
# likelihood is -869.3286391515142 on iteration 8
# new_angles=[0.68476025]
# new_P:
# [[0.01340171+0.j]]
# likelihood is -869.0977845712048 on iteration 9
# new_angles=[0.68682802]
# new_P:
# [[0.01625513+0.j]]
# likelihood is -868.8149215454323 on iteration 10
# new_angles=[0.68866446]
# new_P:
# [[0.02003289+0.j]]
# likelihood is -868.4520127223474 on iteration 11
# new_angles=[0.69012418]
# new_P:
# [[0.0252914+0.j]]
# likelihood is -867.9666022726784 on iteration 12
# new_angles=[0.69135635]
# new_P:
# [[0.03306064+0.j]]
# likelihood is -867.2820623065494 on iteration 13
# new_angles=[0.69223282]
# new_P:
# [[0.04540492+0.j]]
# likelihood is -866.2650115318593 on iteration 14
# new_angles=[0.69296716]
# new_P:
# [[0.06681746+0.j]]
# likelihood is -864.6729663235326 on iteration 15
# new_angles=[0.69360199]
# new_P:
# [[0.10793972+0.j]]
# likelihood is -862.1162893118025 on iteration 16
# new_angles=[0.69412022]
# new_P:
# [[0.19511389+0.j]]
# likelihood is -858.2391919219865 on iteration 17
# new_angles=[0.69453059]
# new_P:
# [[0.38688931+0.j]]
# likelihood is -853.7052378370544 on iteration 18
# new_angles=[0.694864]
# new_P:
# [[0.75103657+0.j]]
# likelihood is -850.8652219546494 on iteration 19
# 4-th start
# theta=[0.65905647],P=[[1.72770544e-07-1.09187841e-23j]]
# new_angles=[0.65905647]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -870.3304044487845 on iteration 0
# new_angles=[0.65905647]
# new_P:
# [[0.00200592+0.j]]
# likelihood is -870.2597706055938 on iteration 1
# new_angles=[0.65905647]
# new_P:
# [[0.00303061+0.j]]
# likelihood is -870.1883266949918 on iteration 2
# new_angles=[0.66486663]
# new_P:
# [[0.00408935+0.j]]
# likelihood is -870.0804506719063 on iteration 3
# new_angles=[0.66983982]
# new_P:
# [[0.00521221+0.j]]
# likelihood is -869.958854570391 on iteration 4
# new_angles=[0.67351466]
# new_P:
# [[0.00643345+0.j]]
# likelihood is -869.8284083984403 on iteration 5
# new_angles=[0.67738926]
# new_P:
# [[0.00779537+0.j]]
# likelihood is -869.6774037995568 on iteration 6
# new_angles=[0.68076971]
# new_P:
# [[0.00936083+0.j]]
# likelihood is -869.5070297805426 on iteration 7
# new_angles=[0.68333668]
# new_P:
# [[0.01121595+0.j]]
# likelihood is -869.3135997959087 on iteration 8
# new_angles=[0.6858579]
# new_P:
# [[0.01348594+0.j]]
# likelihood is -869.0807543187734 on iteration 9
# new_angles=[0.68775223]
# new_P:
# [[0.01637167+0.j]]
# likelihood is -868.7964004093985 on iteration 10
# new_angles=[0.68960442]
# new_P:
# [[0.02019741+0.j]]
# likelihood is -868.4292947489748 on iteration 11
# new_angles=[0.69086884]
# new_P:
# [[0.02553403+0.j]]
# likelihood is -867.9388785309372 on iteration 12
# new_angles=[0.69193768]
# new_P:
# [[0.03343585+0.j]]
# likelihood is -867.2452562207964 on iteration 13
# new_angles=[0.69271619]
# new_P:
# [[0.04602577+0.j]]
# likelihood is -866.2115925947115 on iteration 14
# new_angles=[0.69339362]
# new_P:
# [[0.06794019+0.j]]
# likelihood is -864.5905683340163 on iteration 15
# new_angles=[0.69392208]
# new_P:
# [[0.11018632+0.j]]
# likelihood is -861.9888185422732 on iteration 16
# new_angles=[0.69438032]
# new_P:
# [[0.19999+0.j]]
# likelihood is -858.0643485506301 on iteration 17
# new_angles=[0.69475045]
# new_P:
# [[0.3972078+0.j]]
# likelihood is -853.5483900022623 on iteration 18
# new_angles=[0.69504838]
# new_P:
# [[0.76746117+0.j]]
# likelihood is -850.811737933706 on iteration 19
# 5-th start
# theta=[0.69671681],P=[[2.64175428e-07+1.32348898e-24j]]
# new_angles=[0.69621938]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -870.2958106904471 on iteration 0
# new_angles=[0.69621938]
# new_P:
# [[0.0020088+0.j]]
# likelihood is -870.1902881473998 on iteration 1
# new_angles=[0.69621938]
# new_P:
# [[0.00304508+0.j]]
# likelihood is -870.0826200466558 on iteration 2
# new_angles=[0.69621938]
# new_P:
# [[0.00413071+0.j]]
# likelihood is -869.9706177699321 on iteration 3
# new_angles=[0.69621938]
# new_P:
# [[0.0052923+0.j]]
# likelihood is -869.8516679914106 on iteration 4
# new_angles=[0.69621938]
# new_P:
# [[0.0065639+0.j]]
# likelihood is -869.7224940196874 on iteration 5
# new_angles=[0.69621938]
# new_P:
# [[0.00799106+0.j]]
# likelihood is -869.5788019056323 on iteration 6
# new_angles=[0.69621938]
# new_P:
# [[0.00963713+0.j]]
# likelihood is -869.4147314983778 on iteration 7
# new_angles=[0.69621938]
# new_P:
# [[0.01159396+0.j]]
# likelihood is -869.2219702598461 on iteration 8
# new_angles=[0.69627517]
# new_P:
# [[0.01400036+0.j]]
# likelihood is -868.9882594813869 on iteration 9
# new_angles=[0.69627517]
# new_P:
# [[0.0170758+0.j]]
# likelihood is -868.6948304757625 on iteration 10
# new_angles=[0.69627517]
# new_P:
# [[0.02118545+0.j]]
# likelihood is -868.311674787341 on iteration 11
# new_angles=[0.69627517]
# new_P:
# [[0.02697343+0.j]]
# likelihood is -867.788769848898 on iteration 12
# new_angles=[0.69627517]
# new_P:
# [[0.03565567+0.j]]
# likelihood is -867.0392047821528 on iteration 13
# new_angles=[0.6962883]
# new_P:
# [[0.04971351+0.j]]
# likelihood is -865.907446550146 on iteration 14
# new_angles=[0.69632336]
# new_P:
# [[0.07466116+0.j]]
# likelihood is -864.1187013393604 on iteration 15
# new_angles=[0.69632418]
# new_P:
# [[0.12374568+0.j]]
# likelihood is -861.258709822486 on iteration 16
# new_angles=[0.69632418]
# new_P:
# [[0.22948665+0.j]]
# likelihood is -857.0955707673756 on iteration 17
# new_angles=[0.69633739]
# new_P:
# [[0.45828985+0.j]]
# likelihood is -852.7515933663542 on iteration 18
# new_angles=[0.69633739]
# new_P:
# [[0.85892521+0.j]]
# likelihood is -850.5894937632039 on iteration 19
# 6-th start
# theta=[0.71784892],P=[[1.15423857e-07+2.31610572e-24j]]
# new_angles=[0.71784892]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -870.308956101243 on iteration 0
# new_angles=[0.71287027]
# new_P:
# [[0.0020077+0.j]]
# likelihood is -870.2062572501275 on iteration 1
# new_angles=[0.70927498]
# new_P:
# [[0.00304132+0.j]]
# likelihood is -870.0978149218649 on iteration 2
# new_angles=[0.70668778]
# new_P:
# [[0.00412302+0.j]]
# likelihood is -869.984263320323 on iteration 3
# new_angles=[0.70400545]
# new_P:
# [[0.00527964+0.j]]
# likelihood is -869.8619630519034 on iteration 4
# new_angles=[0.70251635]
# new_P:
# [[0.00654607+0.j]]
# likelihood is -869.7315003878923 on iteration 5
# new_angles=[0.70087946]
# new_P:
# [[0.0079671+0.j]]
# likelihood is -869.585884301096 on iteration 6
# new_angles=[0.70043609]
# new_P:
# [[0.00960636+0.j]]
# likelihood is -869.4223411958695 on iteration 7
# new_angles=[0.69944959]
# new_P:
# [[0.01155373+0.j]]
# likelihood is -869.2290146097715 on iteration 8
# new_angles=[0.69885415]
# new_P:
# [[0.01394784+0.j]]
# likelihood is -868.9957331748462 on iteration 9
# new_angles=[0.69825211]
# new_P:
# [[0.01700572+0.j]]
# likelihood is -868.7031067892817 on iteration 10
# new_angles=[0.69800139]
# new_P:
# [[0.02108901+0.j]]
# likelihood is -868.3220656489514 on iteration 11
# new_angles=[0.69772296]
# new_P:
# [[0.0268338+0.j]]
# likelihood is -867.8024513102193 on iteration 12
# new_angles=[0.69753432]
# new_P:
# [[0.03544047+0.j]]
# likelihood is -867.0585216774183 on iteration 13
# new_angles=[0.69732082]
# new_P:
# [[0.04935441+0.j]]
# likelihood is -865.9362577682589 on iteration 14
# new_angles=[0.69714994]
# new_P:
# [[0.0740023+0.j]]
# likelihood is -864.1637108084685 on iteration 15
# new_angles=[0.69699073]
# new_P:
# [[0.12240694+0.j]]
# likelihood is -861.3279955303217 on iteration 16
# new_angles=[0.69687535]
# new_P:
# [[0.22657064+0.j]]
# likelihood is -857.1851072517603 on iteration 17
# new_angles=[0.69678631]
# new_P:
# [[0.45235382+0.j]]
# likelihood is -852.8204049230274 on iteration 18
# new_angles=[0.69670548]
# new_P:
# [[0.85043841+0.j]]
# likelihood is -850.6057009404662 on iteration 19
# 7-th start
# theta=[0.70172546],P=[[2.62158203e-07+1.12496563e-23j]]
# new_angles=[0.70172546]
# new_P:
# [[0.00100003+0.j]]
# likelihood is -870.2966599178419 on iteration 0
# new_angles=[0.70172546]
# new_P:
# [[0.00200871+0.j]]
# likelihood is -870.1919945109717 on iteration 1
# new_angles=[0.70047915]
# new_P:
# [[0.00304471+0.j]]
# likelihood is -870.0841619278978 on iteration 2
# new_angles=[0.70040307]
# new_P:
# [[0.00412994+0.j]]
# likelihood is -869.9726546150603 on iteration 3
# new_angles=[0.6999557]
# new_P:
# [[0.0052908+0.j]]
# likelihood is -869.8537909244358 on iteration 4
# new_angles=[0.69884419]
# new_P:
# [[0.0065614+0.j]]
# likelihood is -869.723891616708 on iteration 5
# new_angles=[0.69838567]
# new_P:
# [[0.00798761+0.j]]
# likelihood is -869.5800577852293 on iteration 6
# new_angles=[0.69808238]
# new_P:
# [[0.00963255+0.j]]
# likelihood is -869.4159662706941 on iteration 7
# new_angles=[0.69793885]
# new_P:
# [[0.01158789+0.j]]
# likelihood is -869.2233437648415 on iteration 8
# new_angles=[0.69773735]
# new_P:
# [[0.01399214+0.j]]
# likelihood is -868.9897605793254 on iteration 9
# new_angles=[0.69740106]
# new_P:
# [[0.01706445+0.j]]
# likelihood is -868.6963775639955 on iteration 10
# new_angles=[0.69722302]
# new_P:
# [[0.02116954+0.j]]
# likelihood is -868.3135287707511 on iteration 11
# new_angles=[0.69707517]
# new_P:
# [[0.02695015+0.j]]
# likelihood is -867.7911603905013 on iteration 12
# new_angles=[0.69687832]
# new_P:
# [[0.03561952+0.j]]
# likelihood is -867.0424455670293 on iteration 13
# new_angles=[0.69681639]
# new_P:
# [[0.04965314+0.j]]
# likelihood is -865.9123135153513 on iteration 14
# new_angles=[0.6967076]
# new_P:
# [[0.07455017+0.j]]
# likelihood is -864.126268618708 on iteration 15
# new_angles=[0.69664938]
# new_P:
# [[0.12351993+0.j]]
# likelihood is -861.2703736950555 on iteration 16
# new_angles=[0.69660339]
# new_P:
# [[0.2289945+0.j]]
# likelihood is -857.1106383417614 on iteration 17
# new_angles=[0.69656298]
# new_P:
# [[0.45728835+0.j]]
# likelihood is -852.7631656733226 on iteration 18
# new_angles=[0.6965232]
# new_P:
# [[0.85749594+0.j]]
# likelihood is -850.5922637996811 on iteration 19
# 8-th start
# theta=[0.7055677],P=[[2.57996973e-07-6.6174449e-24j]]
# new_angles=[0.70122724]
# new_P:
# [[0.00100001+0.j]]
# likelihood is -870.2965102983368 on iteration 0
# new_angles=[0.70122724]
# new_P:
# [[0.0020087+0.j]]
# likelihood is -870.1916918715007 on iteration 1
# new_angles=[0.70122724]
# new_P:
# [[0.00304476+0.j]]
# likelihood is -870.084760951539 on iteration 2
# new_angles=[0.70096557]
# new_P:
# [[0.00412984+0.j]]
# likelihood is -869.9732558867336 on iteration 3
# new_angles=[0.70048861]
# new_P:
# [[0.00529049+0.j]]
# likelihood is -869.8544603842752 on iteration 4
# new_angles=[0.69922477]
# new_P:
# [[0.00656078+0.j]]
# likelihood is -869.7243422186093 on iteration 5
# new_angles=[0.69922477]
# new_P:
# [[0.00798671+0.j]]
# likelihood is -869.5810953422904 on iteration 6
# new_angles=[0.69871129]
# new_P:
# [[0.00963088+0.j]]
# likelihood is -869.4168380842556 on iteration 7
# new_angles=[0.69871129]
# new_P:
# [[0.01158536+0.j]]
# likelihood is -869.2245932917057 on iteration 8
# new_angles=[0.69834185]
# new_P:
# [[0.01398807+0.j]]
# likelihood is -868.990952334717 on iteration 9
# new_angles=[0.69805934]
# new_P:
# [[0.01705834+0.j]]
# likelihood is -868.6978092382373 on iteration 10
# new_angles=[0.69771715]
# new_P:
# [[0.02116016+0.j]]
# likelihood is -868.3150241708145 on iteration 11
# new_angles=[0.69749132]
# new_P:
# [[0.02693575+0.j]]
# likelihood is -867.7929881331296 on iteration 12
# new_angles=[0.69731506]
# new_P:
# [[0.03559645+0.j]]
# likelihood is -867.0449736937164 on iteration 13
# new_angles=[0.6971491]
# new_P:
# [[0.04961339+0.j]]
# likelihood is -865.9158878923946 on iteration 14
# new_angles=[0.69700603]
# new_P:
# [[0.07447577+0.j]]
# likelihood is -864.1317374768685 on iteration 15
# new_angles=[0.69690581]
# new_P:
# [[0.12336663+0.j]]
# likelihood is -861.2787288718068 on iteration 16
# new_angles=[0.69679492]
# new_P:
# [[0.22865707+0.j]]
# likelihood is -857.1213602418437 on iteration 17
# new_angles=[0.69671534]
# new_P:
# [[0.45659713+0.j]]
# likelihood is -852.7715138383949 on iteration 18
# new_angles=[0.69664398]
# new_P:
# [[0.85650283+0.j]]
# likelihood is -850.5944613203367 on iteration 19
# 9-th start
# theta=[0.62610695],P=[[6.40458684e-08+0.j]]
# new_angles=[0.62742715]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3709078832201 on iteration 0
# new_angles=[0.62928325]
# new_P:
# [[0.00200254+0.j]]
# likelihood is -870.3377059880088 on iteration 1
# new_angles=[0.63330114]
# new_P:
# [[0.00301426+0.j]]
# likelihood is -870.2944531754011 on iteration 2
# new_angles=[0.63769062]
# new_P:
# [[0.00404624+0.j]]
# likelihood is -870.2389226076699 on iteration 3
# new_angles=[0.64347839]
# new_P:
# [[0.00511487+0.j]]
# likelihood is -870.1597617995953 on iteration 4
# new_angles=[0.64931715]
# new_P:
# [[0.00624711+0.j]]
# likelihood is -870.0569796495429 on iteration 5
# new_angles=[0.65515136]
# new_P:
# [[0.00748027+0.j]]
# likelihood is -869.927119641925 on iteration 6
# new_angles=[0.66075472]
# new_P:
# [[0.00886712+0.j]]
# likelihood is -869.7690284917865 on iteration 7
# new_angles=[0.66574667]
# new_P:
# [[0.0104812+0.j]]
# likelihood is -869.5841740741537 on iteration 8
# new_angles=[0.67057908]
# new_P:
# [[0.01242457+0.j]]
# likelihood is -869.3605117949572 on iteration 9
# new_angles=[0.67472463]
# new_P:
# [[0.01485622+0.j]]
# likelihood is -869.0948683695988 on iteration 10
# new_angles=[0.67840003]
# new_P:
# [[0.01801914+0.j]]
# likelihood is -868.7657568856074 on iteration 11
# new_angles=[0.68153623]
# new_P:
# [[0.02232403+0.j]]
# likelihood is -868.3425927907506 on iteration 12
# new_angles=[0.68412859]
# new_P:
# [[0.02850231+0.j]]
# likelihood is -867.770721379073 on iteration 13
# new_angles=[0.68620622]
# new_P:
# [[0.03795738+0.j]]
# likelihood is -866.9525901924376 on iteration 14
# new_angles=[0.68796161]
# new_P:
# [[0.05361245+0.j]]
# likelihood is -865.7085935991319 on iteration 15
# new_angles=[0.68947421]
# new_P:
# [[0.08212356+0.j]]
# likelihood is -863.726824760621 on iteration 16
# new_angles=[0.69074054]
# new_P:
# [[0.13980171+0.j]]
# likelihood is -860.5705271954853 on iteration 17
# new_angles=[0.69176076]
# new_P:
# [[0.26655104+0.j]]
# likelihood is -856.1634438164488 on iteration 18
# new_angles=[0.69258791]
# new_P:
# [[0.53693727+0.j]]
# likelihood is -852.0827425312721 on iteration 19
# best_start=5

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.69633739]), array([[0.85892521+0.j]]))

# %%
em_stoch.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q_1), em_stoch.incomplete_lkhd(X1_with_mv, theta1_rad, P_1, Q_1)
# Out:
# (np.float64(-850.5894937632039), np.float64(-852.4011191641745))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11
failing_sensors2 = np.array([0, 1, 2, 3, 4, 5, 6, 7], dtype=np.int16)
gap_ratio2 = np.array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5], dtype=np.float32)
theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P_2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q_2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sensors.gss(Num_emitters2, sample_size2, P_2)
N2 = sensors.gss(Num_sensors2, sample_size2, Q_2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sensors.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sensors.initial_Cov(X2_with_mv)
MUSIC_theta2 = subspace_methods.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sensors.SNR(A2, P_2, Q_2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2 = em_stoch.multistart_EM2(X2_with_mv, 
                                                      Num_emitters2, 
                                                      Q=Q_2,
                                                      MUSIC_theta=MUSIC_theta2, 
                                                      num_of_starts=20, 
                                                      max_iter=20, 
                                                      rtol=1e-5)
# Out:
# 0-th start
# theta=[0.81251426],P=[[4.8828125e-08+0.j]]
# new_angles=[0.81251426]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -689.5858366251647 on iteration 0
# new_angles=[0.81251426]
# new_P:
# [[0.00199942+0.j]]
# 1-th start
# theta=[0.63682337],P=[[1.17743922e-07+4.63221143e-24j]]
# new_angles=[0.63682337]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.542752465457 on iteration 0
# new_angles=[0.63682337]
# new_P:
# [[0.00200334+0.j]]
# likelihood is -689.5065020930143 on iteration 1
# new_angles=[0.64264951]
# new_P:
# [[0.00301881+0.j]]
# likelihood is -689.450198309814 on iteration 2
# new_angles=[0.64753817]
# new_P:
# [[0.00406431+0.j]]
# likelihood is -689.3798550308624 on iteration 3
# new_angles=[0.6524355]
# new_P:
# [[0.00516515+0.j]]
# likelihood is -689.2897917056298 on iteration 4
# new_angles=[0.65738678]
# new_P:
# [[0.0063589+0.j]]
# likelihood is -689.1753199052384 on iteration 5
# new_angles=[0.66233092]
# new_P:
# [[0.00770036+0.j]]
# likelihood is -689.0315995121632 on iteration 6
# new_angles=[0.66712927]
# new_P:
# [[0.00927039+0.j]]
# likelihood is -688.853493126056 on iteration 7
# new_angles=[0.67137628]
# new_P:
# [[0.01119113+0.j]]
# likelihood is -688.637887941064 on iteration 8
# new_angles=[0.67545394]
# new_P:
# [[0.01365079+0.j]]
# likelihood is -688.3642574153159 on iteration 9
# new_angles=[0.67902271]
# new_P:
# [[0.01697194+0.j]]
# likelihood is -688.0123368893461 on iteration 10
# new_angles=[0.68204669]
# new_P:
# [[0.02172728+0.j]]
# likelihood is -687.5381924922036 on iteration 11
# new_angles=[0.68482735]
# new_P:
# [[0.02902638+0.j]]
# likelihood is -686.8528506346141 on iteration 12
# new_angles=[0.68723738]
# new_P:
# [[0.04123665+0.j]]
# likelihood is -685.8043590862544 on iteration 13
# new_angles=[0.68936379]
# new_P:
# [[0.06387851+0.j]]
# likelihood is -684.1101480410395 on iteration 14
# new_angles=[0.69113673]
# new_P:
# [[0.11098422+0.j]]
# likelihood is -681.3662835839351 on iteration 15
# new_angles=[0.69263097]
# new_P:
# [[0.2184304+0.j]]
# likelihood is -677.5195249494586 on iteration 16
# new_angles=[0.69390061]
# new_P:
# [[0.45560875+0.j]]
# likelihood is -674.1714780555991 on iteration 17
# new_angles=[0.69495957]
# new_P:
# [[0.84052371+0.j]]
# likelihood is -673.2845761658193 on iteration 18
# new_angles=[0.69584861]
# new_P:
# [[1.19806555+0.j]]
# 2-th start
# theta=[0.65176423],P=[[8.96189647e-08-1.32348898e-24j]]
# new_angles=[0.65176423]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.5231536456283 on iteration 0
# new_angles=[0.65683477]
# new_P:
# [[0.00200513+0.j]]
# likelihood is -689.4511301564963 on iteration 1
# new_angles=[0.66180195]
# new_P:
# [[0.00303063+0.j]]
# likelihood is -689.3618121968345 on iteration 2
# new_angles=[0.66676316]
# new_P:
# [[0.00410042+0.j]]
# likelihood is -689.2532960648542 on iteration 3
# new_angles=[0.6710425]
# new_P:
# [[0.00524884+0.j]]
# likelihood is -689.1289394889939 on iteration 4
# new_angles=[0.67521842]
# new_P:
# [[0.00652187+0.j]]
# likelihood is -688.9830667420429 on iteration 5
# new_angles=[0.67892336]
# new_P:
# [[0.00798595+0.j]]
# likelihood is -688.8146827581363 on iteration 6
# new_angles=[0.68234346]
# new_P:
# [[0.00973659+0.j]]
# likelihood is -688.6150548672352 on iteration 7
# new_angles=[0.68518013]
# new_P:
# [[0.01192197+0.j]]
# likelihood is -688.3751410467426 on iteration 8
# new_angles=[0.68760206]
# new_P:
# [[0.01478045+0.j]]
# likelihood is -688.0729192379532 on iteration 9
# new_angles=[0.68971033]
# new_P:
# [[0.01872742+0.j]]
# likelihood is -687.6722151177296 on iteration 10
# new_angles=[0.69150257]
# new_P:
# [[0.02453884+0.j]]
# likelihood is -687.1111794375024 on iteration 11
# new_angles=[0.69299751]
# new_P:
# [[0.03378395+0.j]]
# likelihood is -686.2768724965904 on iteration 12
# new_angles=[0.69426754]
# new_P:
# [[0.04994024+0.j]]
# likelihood is -684.960515536733 on iteration 13
# new_angles=[0.69531195]
# new_P:
# [[0.08146742+0.j]]
# likelihood is -682.81074588995 on iteration 14
# new_angles=[0.6961765]
# new_P:
# [[0.15020376+0.j]]
# likelihood is -679.4734586727255 on iteration 15
# new_angles=[0.69690898]
# new_P:
# [[0.30780223+0.j]]
# likelihood is -675.5369229939286 on iteration 16
# new_angles=[0.69750775]
# new_P:
# [[0.61991545+0.j]]
# likelihood is -673.2763637440764 on iteration 17
# new_angles=[0.69801328]
# new_P:
# [[1.0154854+0.j]]
# 3-th start
# theta=[0.65005312],P=[[8.55417288e-08-3.97046694e-24j]]
# new_angles=[0.65005312]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.5257666281028 on iteration 0
# new_angles=[0.65569711]
# new_P:
# [[0.00200489+0.j]]
# likelihood is -689.4548437234525 on iteration 1
# new_angles=[0.66123066]
# new_P:
# [[0.00302972+0.j]]
# likelihood is -689.364731464668 on iteration 2
# new_angles=[0.66618964]
# new_P:
# [[0.00409868+0.j]]
# likelihood is -689.2572206256548 on iteration 3
# new_angles=[0.67086046]
# new_P:
# [[0.0052456+0.j]]
# likelihood is -689.1306676437831 on iteration 4
# new_angles=[0.67454373]
# new_P:
# [[0.00651761+0.j]]
# likelihood is -688.9896333788269 on iteration 5
# new_angles=[0.67830062]
# new_P:
# [[0.00797753+0.j]]
# likelihood is -688.8217370296354 on iteration 6
# new_angles=[0.68140232]
# new_P:
# [[0.00972222+0.j]]
# likelihood is -688.6266027005727 on iteration 7
# new_angles=[0.6842938]
# new_P:
# [[0.01189556+0.j]]
# likelihood is -688.3878423326994 on iteration 8
# new_angles=[0.68682494]
# new_P:
# [[0.0147357+0.j]]
# likelihood is -688.0866412627988 on iteration 9
# new_angles=[0.68899812]
# new_P:
# [[0.01865394+0.j]]
# likelihood is -687.688365482294 on iteration 10
# new_angles=[0.69089514]
# new_P:
# [[0.02441583+0.j]]
# likelihood is -687.1309142931162 on iteration 11
# new_angles=[0.69248012]
# new_P:
# [[0.0335689+0.j]]
# likelihood is -686.3033887157592 on iteration 12
# new_angles=[0.69382219]
# new_P:
# [[0.04953491+0.j]]
# likelihood is -684.9995061861168 on iteration 13
# new_angles=[0.69493416]
# new_P:
# [[0.08062471+0.j]]
# likelihood is -682.870488410293 on iteration 14
# new_angles=[0.6958602]
# new_P:
# [[0.14828855+0.j]]
# likelihood is -679.5567693963765 on iteration 15
# new_angles=[0.69664731]
# new_P:
# [[0.30350624+0.j]]
# likelihood is -675.6134101712167 on iteration 16
# new_angles=[0.69729473]
# new_P:
# [[0.61269081+0.j]]
# likelihood is -673.3018348685125 on iteration 17
# new_angles=[0.69783343]
# new_P:
# [[1.00885112+0.j]]
# likelihood is -673.2936999044282 on iteration 18
# new_angles=[0.69828424]
# new_P:
# [[1.29534294+0.j]]
# 4-th start
# theta=[0.66778311],P=[[1.30082571e-07+5.29395592e-24j]]
# new_angles=[0.66778311]
# new_P:
# [[0.00100007+0.j]]
# likelihood is -689.4970085428247 on iteration 0
# new_angles=[0.67301831]
# new_P:
# [[0.00200752+0.j]]
# likelihood is -689.3985551363522 on iteration 1
# new_angles=[0.67802388]
# new_P:
# [[0.00304257+0.j]]
# likelihood is -689.2852713653717 on iteration 2
# new_angles=[0.68107421]
# new_P:
# [[0.0041336+0.j]]
# likelihood is -689.1660767285983 on iteration 3
# new_angles=[0.68361875]
# new_P:
# [[0.0053157+0.j]]
# likelihood is -689.035608336856 on iteration 4
# new_angles=[0.68601481]
# new_P:
# [[0.00663712+0.j]]
# likelihood is -688.8886988323165 on iteration 5
# new_angles=[0.68839793]
# new_P:
# [[0.0081668+0.j]]
# likelihood is -688.7185728520582 on iteration 6
# new_angles=[0.69033649]
# new_P:
# [[0.01000782+0.j]]
# likelihood is -688.5187475201134 on iteration 7
# new_angles=[0.69203939]
# new_P:
# [[0.01231923+0.j]]
# likelihood is -688.2736080963122 on iteration 8
# new_angles=[0.69352901]
# new_P:
# [[0.01536514+0.j]]
# likelihood is -687.9595534530847 on iteration 9
# new_angles=[0.69472075]
# new_P:
# [[0.0196109+0.j]]
# likelihood is -687.5376195048341 on iteration 10
# new_angles=[0.69565026]
# new_P:
# [[0.02593615+0.j]]
# likelihood is -686.9381256688182 on iteration 11
# new_angles=[0.69645859]
# new_P:
# [[0.03614858+0.j]]
# likelihood is -686.0332221394752 on iteration 12
# new_angles=[0.69714917]
# new_P:
# [[0.05432378+0.j]]
# likelihood is -684.5908547431147 on iteration 13
# new_angles=[0.69771782]
# new_P:
# [[0.09051169+0.j]]
# likelihood is -682.2364804105734 on iteration 14
# new_angles=[0.69820803]
# new_P:
# [[0.17060574+0.j]]
# likelihood is -678.6897544257931 on iteration 15
# new_angles=[0.69860901]
# new_P:
# [[0.35244427+0.j]]
# likelihood is -674.8791418370903 on iteration 16
# new_angles=[0.69894422]
# new_P:
# [[0.69059581+0.j]]
# likelihood is -673.114561762008 on iteration 17
# new_angles=[0.6992276]
# new_P:
# [[1.07556664+0.j]]
# 5-th start
# theta=[0.70544346],P=[[1.7674577e-07+6.6174449e-25j]]
# new_angles=[0.70544346]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.4663031180482 on iteration 0
# new_angles=[0.70544346]
# new_P:
# [[0.00201027+0.j]]
# likelihood is -689.3531652999187 on iteration 1
# new_angles=[0.70544346]
# new_P:
# [[0.00305361+0.j]]
# likelihood is -689.2373382350112 on iteration 2
# new_angles=[0.70418712]
# new_P:
# [[0.00415816+0.j]]
# likelihood is -689.1144276945445 on iteration 3
# new_angles=[0.70393374]
# new_P:
# [[0.00536072+0.j]]
# likelihood is -688.9827319413014 on iteration 4
# new_angles=[0.70304857]
# new_P:
# [[0.00671059+0.j]]
# likelihood is -688.8356789399111 on iteration 5
# new_angles=[0.70273324]
# new_P:
# [[0.00827885+0.j]]
# likelihood is -688.6675365542955 on iteration 6
# new_angles=[0.70269792]
# new_P:
# [[0.01017122+0.j]]
# likelihood is -688.4678675055092 on iteration 7
# new_angles=[0.70229728]
# new_P:
# [[0.01255453+0.j]]
# likelihood is -688.2203188052869 on iteration 8
# new_angles=[0.70217981]
# new_P:
# [[0.01570758+0.j]]
# likelihood is -687.900644427476 on iteration 9
# new_angles=[0.70183039]
# new_P:
# [[0.02012421+0.j]]
# likelihood is -687.4661681260162 on iteration 10
# new_angles=[0.70167145]
# new_P:
# [[0.02674721+0.j]]
# likelihood is -686.8434250809642 on iteration 11
# new_angles=[0.70148262]
# new_P:
# [[0.03752962+0.j]]
# likelihood is -685.8970563880714 on iteration 12
# new_angles=[0.70133302]
# new_P:
# [[0.0569121+0.j]]
# likelihood is -684.3816516579011 on iteration 13
# new_angles=[0.70125909]
# new_P:
# [[0.09591783+0.j]]
# likelihood is -681.9129246240741 on iteration 14
# new_angles=[0.70116338]
# new_P:
# [[0.18284717+0.j]]
# likelihood is -678.2668480767477 on iteration 15
# new_angles=[0.70108351]
# new_P:
# [[0.37852035+0.j]]
# likelihood is -674.5634702996335 on iteration 16
# new_angles=[0.70102845]
# new_P:
# [[0.72880822+0.j]]
# likelihood is -673.0617823042815 on iteration 17
# new_angles=[0.70098266]
# new_P:
# [[1.10509782+0.j]]
# 6-th start
# theta=[0.72657557],P=[[7.35180779e-08+1.32348898e-24j]]
# new_angles=[0.72657557]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.4863069221292 on iteration 0
# new_angles=[0.72433024]
# new_P:
# [[0.00200845+0.j]]
# likelihood is -689.3869524419584 on iteration 1
# new_angles=[0.71912651]
# new_P:
# [[0.00304563+0.j]]
# likelihood is -689.269007212925 on iteration 2
# new_angles=[0.7154103]
# new_P:
# [[0.0041412+0.j]]
# likelihood is -689.1435382900071 on iteration 3
# new_angles=[0.71291376]
# new_P:
# [[0.00533204+0.j]]
# likelihood is -689.0097404974248 on iteration 4
# new_angles=[0.71079036]
# new_P:
# [[0.00666691+0.j]]
# likelihood is -688.8610996811302 on iteration 5
# new_angles=[0.70904759]
# new_P:
# [[0.00821575+0.j]]
# likelihood is -688.6915541497866 on iteration 6
# new_angles=[0.70776163]
# new_P:
# [[0.01008248+0.j]]
# likelihood is -688.491926649207 on iteration 7
# new_angles=[0.70647708]
# new_P:
# [[0.01242969+0.j]]
# likelihood is -688.2452500948937 on iteration 8
# new_angles=[0.70553014]
# new_P:
# [[0.0155292+0.j]]
# likelihood is -687.9287432671375 on iteration 9
# new_angles=[0.70469648]
# new_P:
# [[0.01985975+0.j]]
# likelihood is -687.5006485343415 on iteration 10
# new_angles=[0.70410177]
# new_P:
# [[0.0263323+0.j]]
# likelihood is -686.8897997989616 on iteration 11
# new_angles=[0.7036075]
# new_P:
# [[0.03682572+0.j]]
# likelihood is -685.9646758105806 on iteration 12
# new_angles=[0.70312507]
# new_P:
# [[0.05559385+0.j]]
# likelihood is -684.48599699843 on iteration 13
# new_angles=[0.70271852]
# new_P:
# [[0.09316418+0.j]]
# likelihood is -682.0741916879223 on iteration 14
# new_angles=[0.70239285]
# new_P:
# [[0.1766192+0.j]]
# likelihood is -678.4760249017402 on iteration 15
# new_angles=[0.70212438]
# new_P:
# [[0.36533645+0.j]]
# likelihood is -674.7156492447938 on iteration 16
# new_angles=[0.70190146]
# new_P:
# [[0.70976766+0.j]]
# likelihood is -673.0840335567736 on iteration 17
# new_angles=[0.70170354]
# new_P:
# [[1.09061749+0.j]]
# 7-th start
# theta=[0.7104521],P=[[1.73164662e-07-1.81979735e-24j]]
# new_angles=[0.7104521]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.4686980328167 on iteration 0
# new_angles=[0.7104521]
# new_P:
# [[0.00201005+0.j]]
# likelihood is -689.3579837497081 on iteration 1
# new_angles=[0.70781146]
# new_P:
# [[0.0030525+0.j]]
# likelihood is -689.2402726205856 on iteration 2
# new_angles=[0.7068109]
# new_P:
# [[0.0041562+0.j]]
# likelihood is -689.1180621369135 on iteration 3
# new_angles=[0.70553014]
# new_P:
# [[0.0053573+0.j]]
# likelihood is -688.9853440806066 on iteration 4
# new_angles=[0.70553014]
# new_P:
# [[0.00670567+0.j]]
# likelihood is -688.840064327138 on iteration 5
# new_angles=[0.70474594]
# new_P:
# [[0.00827082+0.j]]
# likelihood is -688.6716281071348 on iteration 6
# new_angles=[0.70424803]
# new_P:
# [[0.01015916+0.j]]
# likelihood is -688.4718999125455 on iteration 7
# new_angles=[0.70384683]
# new_P:
# [[0.01253686+0.j]]
# likelihood is -688.225019210113 on iteration 8
# new_angles=[0.7031738]
# new_P:
# [[0.01568103+0.j]]
# likelihood is -687.905199148184 on iteration 9
# new_angles=[0.70272928]
# new_P:
# [[0.02008428+0.j]]
# likelihood is -687.471737676511 on iteration 10
# new_angles=[0.70239657]
# new_P:
# [[0.02668383+0.j]]
# likelihood is -686.850732418883 on iteration 11
# new_angles=[0.7021146]
# new_P:
# [[0.03742135+0.j]]
# likelihood is -685.9076105763262 on iteration 12
# new_angles=[0.70190031]
# new_P:
# [[0.05670834+0.j]]
# likelihood is -684.3979840759772 on iteration 13
# new_angles=[0.70168799]
# new_P:
# [[0.09549013+0.j]]
# likelihood is -681.9379362639844 on iteration 14
# new_angles=[0.70153439]
# new_P:
# [[0.18187829+0.j]]
# likelihood is -678.2991025520796 on iteration 15
# new_angles=[0.70140832]
# new_P:
# [[0.37647618+0.j]]
# likelihood is -674.5866681697634 on iteration 16
# new_angles=[0.7012975]
# new_P:
# [[0.72588574+0.j]]
# likelihood is -673.0651472466247 on iteration 17
# new_angles=[0.7012086]
# new_P:
# [[1.10289844+0.j]]
# 8-th start
# theta=[0.71429435],P=[[8.44135407e-08-3.72231276e-25j]]
# new_angles=[0.71429435]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.4716077369084 on iteration 0
# new_angles=[0.71167748]
# new_P:
# [[0.00200979+0.j]]
# likelihood is -689.3596732238005 on iteration 1
# new_angles=[0.70931051]
# new_P:
# [[0.00305194+0.j]]
# likelihood is -689.2426873871447 on iteration 2
# new_angles=[0.70733119]
# new_P:
# [[0.00415496+0.j]]
# likelihood is -689.1190980547007 on iteration 3
# new_angles=[0.70590263]
# new_P:
# [[0.0053556+0.j]]
# likelihood is -688.9861795994407 on iteration 4
# new_angles=[0.7049281]
# new_P:
# [[0.00670344+0.j]]
# likelihood is -688.8391194017989 on iteration 5
# new_angles=[0.7039036]
# new_P:
# [[0.00826894+0.j]]
# likelihood is -688.6702067591173 on iteration 6
# new_angles=[0.70326454]
# new_P:
# [[0.01015807+0.j]]
# likelihood is -688.4700728122814 on iteration 7
# new_angles=[0.70297]
# new_P:
# [[0.01253721+0.j]]
# likelihood is -688.2231115562408 on iteration 8
# new_angles=[0.70250841]
# new_P:
# [[0.01568353+0.j]]
# likelihood is -687.9035694269276 on iteration 9
# new_angles=[0.70212349]
# new_P:
# [[0.02008965+0.j]]
# likelihood is -687.4699516143957 on iteration 10
# new_angles=[0.70183279]
# new_P:
# [[0.02669411+0.j]]
# likelihood is -686.8485465583817 on iteration 11
# new_angles=[0.7016583]
# new_P:
# [[0.03744112+0.j]]
# likelihood is -685.9048149176392 on iteration 12
# new_angles=[0.70154572]
# new_P:
# [[0.05674811+0.j]]
# likelihood is -684.3940195652266 on iteration 13
# new_angles=[0.70140449]
# new_P:
# [[0.09557688+0.j]]
# likelihood is -681.932095593295 on iteration 14
# new_angles=[0.70130723]
# new_P:
# [[0.18207967+0.j]]
# likelihood is -678.2916131345074 on iteration 15
# new_angles=[0.70122003]
# new_P:
# [[0.37690899+0.j]]
# likelihood is -674.5809670140035 on iteration 16
# new_angles=[0.70114015]
# new_P:
# [[0.72651686+0.j]]
# likelihood is -673.063732330941 on iteration 17
# new_angles=[0.70107599]
# new_P:
# [[1.10338709+0.j]]
# 9-th start
# theta=[0.6348336],P=[[1.11590995e-07-6.6174449e-25j]]
# new_angles=[0.6348336]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.5446987603111 on iteration 0
# new_angles=[0.63834264]
# new_P:
# [[0.00200316+0.j]]
# likelihood is -689.5033081298686 on iteration 1
# new_angles=[0.64213314]
# new_P:
# [[0.00301921+0.j]]
# likelihood is -689.4521216098126 on iteration 2
# new_angles=[0.6470199]
# new_P:
# [[0.00406419+0.j]]
# likelihood is -689.3828287808291 on iteration 3
# new_angles=[0.65177453]
# new_P:
# [[0.00516395+0.j]]
# likelihood is -689.2950817928518 on iteration 4
# new_angles=[0.65674582]
# new_P:
# [[0.0063552+0.j]]
# likelihood is -689.1820838405175 on iteration 5
# new_angles=[0.6616875]
# new_P:
# [[0.00769259+0.j]]
# likelihood is -689.0401534117235 on iteration 6
# new_angles=[0.66640052]
# new_P:
# [[0.00925607+0.j]]
# likelihood is -688.8652121669951 on iteration 7
# new_angles=[0.67058881]
# new_P:
# [[0.01116542+0.j]]
# likelihood is -688.6530574814775 on iteration 8
# new_angles=[0.67497632]
# new_P:
# [[0.01360593+0.j]]
# likelihood is -688.3768630643805 on iteration 9
# new_angles=[0.67862532]
# new_P:
# [[0.0169023+0.j]]
# likelihood is -688.0264756791672 on iteration 10
# new_angles=[0.68192955]
# new_P:
# [[0.02161718+0.j]]
# likelihood is -687.5503172053244 on iteration 11
# new_angles=[0.68476303]
# new_P:
# [[0.02885313+0.j]]
# likelihood is -686.8689509268434 on iteration 12
# new_angles=[0.68716704]
# new_P:
# [[0.04094076+0.j]]
# likelihood is -685.8294071357951 on iteration 13
# new_angles=[0.68928597]
# new_P:
# [[0.06331283+0.j]]
# likelihood is -684.1506338986857 on iteration 14
# new_angles=[0.69107262]
# new_P:
# [[0.10976974+0.j]]
# likelihood is -681.4281684565966 on iteration 15
# new_angles=[0.69257852]
# new_P:
# [[0.21566001+0.j]]
# likelihood is -677.5924046446203 on iteration 16
# new_angles=[0.69384811]
# new_P:
# [[0.45007687+0.j]]
# likelihood is -674.2123919129501 on iteration 17
# new_angles=[0.69491457]
# new_P:
# [[0.83367795+0.j]]
# likelihood is -673.2844742600964 on iteration 18
# new_angles=[0.69581179]
# new_P:
# [[1.19367095+0.j]]
# 10-th start
# theta=[0.68408872],P=[[1.6429738e-07+0.j]]
# new_angles=[0.68408872]
# new_P:
# [[0.00100008+0.j]]
# likelihood is -689.474582365374 on iteration 0
# new_angles=[0.6888915]
# new_P:
# [[0.00200956+0.j]]
# likelihood is -689.3611094818099 on iteration 1
# new_angles=[0.69137136]
# new_P:
# [[0.00305144+0.j]]
# likelihood is -689.2442619858444 on iteration 2
# new_angles=[0.69439823]
# new_P:
# [[0.004154+0.j]]
# likelihood is -689.1188616906865 on iteration 3
# new_angles=[0.69531195]
# new_P:
# [[0.00535469+0.j]]
# likelihood is -688.9868868545334 on iteration 4
# new_angles=[0.69535934]
# new_P:
# [[0.00670212+0.j]]
# likelihood is -688.8418990434412 on iteration 5
# new_angles=[0.69634237]
# new_P:
# [[0.00826583+0.j]]
# likelihood is -688.6731855643341 on iteration 6
# new_angles=[0.69694441]
# new_P:
# [[0.01015239+0.j]]
# likelihood is -688.4734488583682 on iteration 7
# new_angles=[0.69748052]
# new_P:
# [[0.01252759+0.j]]
# likelihood is -688.2265210854306 on iteration 8
# new_angles=[0.69817753]
# new_P:
# [[0.01566815+0.j]]
# likelihood is -687.9069621128468 on iteration 9
# new_angles=[0.69873072]
# new_P:
# [[0.02006554+0.j]]
# likelihood is -687.4737505747562 on iteration 10
# new_angles=[0.6989922]
# new_P:
# [[0.02665514+0.j]]
# likelihood is -686.8537794533835 on iteration 11
# new_angles=[0.69928528]
# new_P:
# [[0.037373+0.j]]
# likelihood is -685.9121104692499 on iteration 12
# new_angles=[0.69952158]
# new_P:
# [[0.05661815+0.j]]
# likelihood is -684.404960581429 on iteration 13
# new_angles=[0.69974357]
# new_P:
# [[0.09530229+0.j]]
# likelihood is -681.9487330813897 on iteration 14
# new_angles=[0.69990315]
# new_P:
# [[0.181455+0.j]]
# likelihood is -678.3129687957818 on iteration 15
# new_angles=[0.70004337]
# new_P:
# [[0.37558787+0.j]]
# likelihood is -674.5963136900083 on iteration 16
# new_angles=[0.70015613]
# new_P:
# [[0.72462844+0.j]]
# likelihood is -673.0660330335911 on iteration 17
# new_angles=[0.70024541]
# new_P:
# [[1.10197701+0.j]]
# 11-th start
# theta=[0.72251562],P=[[7.77089257e-08+6.6174449e-25j]]
# new_angles=[0.72251562]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.4806436166313 on iteration 0
# new_angles=[0.72251562]
# new_P:
# [[0.00200897+0.j]]
# likelihood is -689.3820098928734 on iteration 1
# new_angles=[0.71867756]
# new_P:
# [[0.00304705+0.j]]
# likelihood is -689.2673308608094 on iteration 2
# new_angles=[0.71674057]
# new_P:
# [[0.00414313+0.j]]
# likelihood is -689.148655256923 on iteration 3
# new_angles=[0.71413618]
# new_P:
# [[0.00533218+0.j]]
# likelihood is -689.0150364658996 on iteration 4
# new_angles=[0.71159981]
# new_P:
# [[0.00666453+0.j]]
# likelihood is -688.8649703109231 on iteration 5
# new_angles=[0.70989181]
# new_P:
# [[0.00821085+0.j]]
# likelihood is -688.6959578611588 on iteration 6
# new_angles=[0.70844499]
# new_P:
# [[0.01007377+0.j]]
# likelihood is -688.4960808281357 on iteration 7
# new_angles=[0.70696728]
# new_P:
# [[0.01241588+0.j]]
# likelihood is -688.2489823588455 on iteration 8
# new_angles=[0.70601209]
# new_P:
# [[0.01550845+0.j]]
# likelihood is -687.9331882719506 on iteration 9
# new_angles=[0.70504971]
# new_P:
# [[0.01982748+0.j]]
# likelihood is -687.505560860635 on iteration 10
# new_angles=[0.7043327]
# new_P:
# [[0.02628063+0.j]]
# likelihood is -686.8958171624461 on iteration 11
# new_angles=[0.70369212]
# new_P:
# [[0.0367378+0.j]]
# likelihood is -685.9726272112812 on iteration 12
# new_angles=[0.70319801]
# new_P:
# [[0.05543125+0.j]]
# likelihood is -684.4984490926498 on iteration 13
# new_angles=[0.70280277]
# new_P:
# [[0.09282758+0.j]]
# likelihood is -682.0938435272408 on iteration 14
# new_angles=[0.70245469]
# new_P:
# [[0.17586021+0.j]]
# likelihood is -678.5016516820817 on iteration 15
# new_angles=[0.70217146]
# new_P:
# [[0.36372433+0.j]]
# likelihood is -674.73450885886 on iteration 16
# new_angles=[0.70194421]
# new_P:
# [[0.70741003+0.j]]
# likelihood is -673.0867313147477 on iteration 17
# new_angles=[0.70175261]
# new_P:
# [[1.08880066+0.j]]
# 12-th start
# theta=[0.75041272],P=[[8.5918593e-08-5.29395592e-24j]]
# new_angles=[0.75041272]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -689.527624394897 on iteration 0
# new_angles=[0.75041272]
# new_P:
# [[0.00200469+0.j]]
# likelihood is -689.4762524993391 on iteration 1
# new_angles=[0.73978373]
# new_P:
# [[0.00302564+0.j]]
# likelihood is -689.3666857267009 on iteration 2
# new_angles=[0.73195424]
# new_P:
# [[0.00409396+0.j]]
# likelihood is -689.2379993032406 on iteration 3
# new_angles=[0.72624771]
# new_P:
# [[0.00524771+0.j]]
# likelihood is -689.0979207569742 on iteration 4
# new_angles=[0.72181413]
# new_P:
# [[0.00653515+0.j]]
# likelihood is -688.9441870472357 on iteration 5
# new_angles=[0.71807373]
# new_P:
# [[0.00802291+0.j]]
# likelihood is -688.7699726542179 on iteration 6
# new_angles=[0.71484649]
# new_P:
# [[0.00980948+0.j]]
# likelihood is -688.5666172624989 on iteration 7
# new_angles=[0.71227327]
# new_P:
# [[0.0120476+0.j]]
# likelihood is -688.3224167336518 on iteration 8
# new_angles=[0.71029253]
# new_P:
# [[0.01498608+0.j]]
# likelihood is -688.0151934357038 on iteration 9
# new_angles=[0.70870631]
# new_P:
# [[0.0190596+0.j]]
# likelihood is -687.6063595621492 on iteration 10
# new_angles=[0.70742072]
# new_P:
# [[0.02508598+0.j]]
# likelihood is -687.0300255220669 on iteration 11
# new_angles=[0.70625283]
# new_P:
# [[0.03473196+0.j]]
# likelihood is -686.1655647469388 on iteration 12
# new_angles=[0.70529052]
# new_P:
# [[0.05172294+0.j]]
# likelihood is -684.7952847981966 on iteration 13
# new_angles=[0.70450922]
# new_P:
# [[0.08517532+0.j]]
# likelihood is -682.5563504970848 on iteration 14
# new_angles=[0.70386855]
# new_P:
# [[0.1586285+0.j]]
# likelihood is -679.1217653054679 on iteration 15
# new_angles=[0.70335838]
# new_P:
# [[0.32653333+0.j]]
# likelihood is -675.2255246500731 on iteration 16
# new_angles=[0.70293936]
# new_P:
# [[0.65058531+0.j]]
# likelihood is -673.1812269548868 on iteration 17
# new_angles=[0.70258737]
# new_P:
# [[1.04264287+0.j]]
# 13-th start
# theta=[0.76848612],P=[[8.39647801e-08+2.64697796e-24j]]
# new_angles=[0.76848612]
# new_P:
# [[0.00100001+0.j]]
# likelihood is -689.5567832264339 on iteration 0
# new_angles=[0.75639147]
# new_P:
# [[0.00200204+0.j]]
# likelihood is -689.4972524547165 on iteration 1
# new_angles=[0.74570363]
# new_P:
# [[0.00301916+0.j]]
# likelihood is -689.399349395479 on iteration 2
# new_angles=[0.73818225]
# new_P:
# [[0.00407845+0.j]]
# likelihood is -689.282536957318 on iteration 3
# new_angles=[0.73113692]
# new_P:
# [[0.00521525+0.j]]
# likelihood is -689.1397841791382 on iteration 4
# new_angles=[0.72590178]
# new_P:
# [[0.00648112+0.j]]
# likelihood is -688.9847422578484 on iteration 5
# new_angles=[0.72129218]
# new_P:
# [[0.00794067+0.j]]
# likelihood is -688.8071116243193 on iteration 6
# new_angles=[0.71739755]
# new_P:
# [[0.0096913+0.j]]
# likelihood is -688.601748586697 on iteration 7
# new_angles=[0.71438886]
# new_P:
# [[0.01188103+0.j]]
# likelihood is -688.3586505686101 on iteration 8
# new_angles=[0.71180652]
# new_P:
# [[0.01474843+0.j]]
# likelihood is -688.0528649948377 on iteration 9
# new_angles=[0.70980234]
# new_P:
# [[0.01871266+0.j]]
# likelihood is -687.6503851503555 on iteration 10
# new_angles=[0.70828907]
# new_P:
# [[0.02455378+0.j]]
# likelihood is -687.0881006173462 on iteration 11
# new_angles=[0.70698968]
# new_P:
# [[0.03385206+0.j]]
# likelihood is -686.2494658447089 on iteration 12
# new_angles=[0.7059286]
# new_P:
# [[0.05012014+0.j]]
# likelihood is -684.9250002324002 on iteration 13
# new_angles=[0.70505284]
# new_P:
# [[0.08191064+0.j]]
# likelihood is -682.7603646667679 on iteration 14
# new_angles=[0.7043565]
# new_P:
# [[0.15131699+0.j]]
# likelihood is -679.405071033032 on iteration 15
# new_angles=[0.7037676]
# new_P:
# [[0.31046125+0.j]]
# likelihood is -675.4696244122218 on iteration 16
# new_angles=[0.70326961]
# new_P:
# [[0.62458701+0.j]]
# likelihood is -673.2412499006748 on iteration 17
# new_angles=[0.70286321]
# new_P:
# [[1.01997588+0.j]]
# 14-th start
# theta=[0.73864851],P=[[5.87367942e-08-3.30872245e-24j]]
# new_angles=[0.73864851]
# new_P:
# [[0.00100003+0.j]]
# likelihood is -689.5063149461322 on iteration 0
# new_angles=[0.73864851]
# new_P:
# [[0.00200663+0.j]]
# likelihood is -689.4335546225536 on iteration 1
# new_angles=[0.72981968]
# new_P:
# [[0.00303533+0.j]]
# likelihood is -689.3146238550734 on iteration 2
# new_angles=[0.72523656]
# new_P:
# [[0.00411811+0.j]]
# likelihood is -689.1937293520585 on iteration 3
# new_angles=[0.72069961]
# new_P:
# [[0.00528924+0.j]]
# likelihood is -689.0552772389123 on iteration 4
# new_angles=[0.71704769]
# new_P:
# [[0.0065995+0.j]]
# likelihood is -688.9025128936277 on iteration 5
# new_angles=[0.71429414]
# new_P:
# [[0.00811749+0.j]]
# likelihood is -688.7314311241101 on iteration 6
# new_angles=[0.71191731]
# new_P:
# [[0.00994308+0.j]]
# likelihood is -688.5303178905847 on iteration 7
# new_angles=[0.71030275]
# new_P:
# [[0.01223389+0.j]]
# likelihood is -688.2879723320021 on iteration 8
# new_angles=[0.70855673]
# new_P:
# [[0.01524677+0.j]]
# likelihood is -687.9752636155149 on iteration 9
# new_angles=[0.70727131]
# new_P:
# [[0.01944044+0.j]]
# likelihood is -687.5574678872518 on iteration 10
# new_angles=[0.70612226]
# new_P:
# [[0.02567472+0.j]]
# likelihood is -686.9640084736621 on iteration 11
# new_angles=[0.70520948]
# new_P:
# [[0.03571627+0.j]]
# likelihood is -686.071072966937 on iteration 12
# new_angles=[0.7044822]
# new_P:
# [[0.05353358+0.j]]
# likelihood is -684.6503939585085 on iteration 13
# new_angles=[0.70384154]
# new_P:
# [[0.08889241+0.j]]
# likelihood is -682.3296685232325 on iteration 14
# new_angles=[0.70333572]
# new_P:
# [[0.16698062+0.j]]
# likelihood is -678.8145992144518 on iteration 15
# new_angles=[0.70291197]
# new_P:
# [[0.34467155+0.j]]
# likelihood is -674.975449654592 on iteration 16
# new_angles=[0.70256464]
# new_P:
# [[0.67884496+0.j]]
# likelihood is -673.1295675580861 on iteration 17
# new_angles=[0.70227452]
# new_P:
# [[1.06613106+0.j]]
# 15-th start
# theta=[0.68749862],P=[[1.6917191e-07+2.64697796e-24j]]
# new_angles=[0.68749862]
# new_P:
# [[0.00100008+0.j]]
# likelihood is -689.4713567101921 on iteration 0
# new_angles=[0.68749862]
# new_P:
# [[0.00200985+0.j]]
# likelihood is -689.3633372076036 on iteration 1
# new_angles=[0.69027876]
# new_P:
# [[0.00305133+0.j]]
# likelihood is -689.2464293380027 on iteration 2
# new_angles=[0.69155929]
# new_P:
# [[0.0041533+0.j]]
# likelihood is -689.1249503065372 on iteration 3
# new_angles=[0.69349773]
# new_P:
# [[0.00535168+0.j]]
# likelihood is -688.9912635857726 on iteration 4
# new_angles=[0.69498361]
# new_P:
# [[0.0066968+0.j]]
# likelihood is -688.8433895835335 on iteration 5
# new_angles=[0.69580777]
# new_P:
# [[0.0082591+0.j]]
# likelihood is -688.6752509080972 on iteration 6
# new_angles=[0.6958333]
# new_P:
# [[0.01014328+0.j]]
# likelihood is -688.4776016438072 on iteration 7
# new_angles=[0.69660523]
# new_P:
# [[0.01251326+0.j]]
# likelihood is -688.230617008748 on iteration 8
# new_angles=[0.69732698]
# new_P:
# [[0.01564633+0.j]]
# likelihood is -687.9117041260512 on iteration 9
# new_angles=[0.69787614]
# new_P:
# [[0.02003141+0.j]]
# likelihood is -687.4796973005562 on iteration 10
# new_angles=[0.69840898]
# new_P:
# [[0.02659902+0.j]]
# likelihood is -686.860889840834 on iteration 11
# new_angles=[0.69881594]
# new_P:
# [[0.03727586+0.j]]
# likelihood is -685.9220711996647 on iteration 12
# new_angles=[0.69913347]
# new_P:
# [[0.05643415+0.j]]
# likelihood is -684.4201122053086 on iteration 13
# new_angles=[0.69939732]
# new_P:
# [[0.09491503+0.j]]
# likelihood is -681.9721007639429 on iteration 14
# new_angles=[0.69961248]
# new_P:
# [[0.18057425+0.j]]
# likelihood is -678.3431536537001 on iteration 15
# new_angles=[0.69979969]
# new_P:
# [[0.3737203+0.j]]
# likelihood is -674.6183412167387 on iteration 16
# new_angles=[0.6999458]
# new_P:
# [[0.72193859+0.j]]
# likelihood is -673.0697350348635 on iteration 17
# new_angles=[0.70007264]
# new_P:
# [[1.09993777+0.j]]
# 16-th start
# theta=[0.65346953],P=[[9.37792273e-08+6.6174449e-24j]]
# new_angles=[0.65346953]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.5204833069567 on iteration 0
# new_angles=[0.65971006]
# new_P:
# [[0.00200537+0.j]]
# likelihood is -689.4416486722708 on iteration 1
# new_angles=[0.66466315]
# new_P:
# [[0.00303259+0.j]]
# likelihood is -689.3474014983001 on iteration 2
# new_angles=[0.66963554]
# new_P:
# [[0.00410636+0.j]]
# likelihood is -689.2341249800372 on iteration 3
# new_angles=[0.67349662]
# new_P:
# [[0.00526208+0.j]]
# likelihood is -689.108574205161 on iteration 4
# new_angles=[0.67734028]
# new_P:
# [[0.00654549+0.j]]
# likelihood is -688.9620952596185 on iteration 5
# new_angles=[0.68091559]
# new_P:
# [[0.0080238+0.j]]
# likelihood is -688.7918756196708 on iteration 6
# new_angles=[0.68384067]
# new_P:
# [[0.009795+0.j]]
# likelihood is -688.5940483260414 on iteration 7
# new_angles=[0.68636293]
# new_P:
# [[0.01200734+0.j]]
# likelihood is -688.3540253997111 on iteration 8
# new_angles=[0.68873334]
# new_P:
# [[0.01490472+0.j]]
# likelihood is -688.0480275175327 on iteration 9
# new_angles=[0.69065452]
# new_P:
# [[0.01891514+0.j]]
# likelihood is -687.6430028338759 on iteration 10
# new_angles=[0.69219575]
# new_P:
# [[0.02483476+0.j]]
# likelihood is -687.0750663081365 on iteration 11
# new_angles=[0.69354544]
# new_P:
# [[0.03427971+0.j]]
# likelihood is -686.2265100107679 on iteration 12
# new_angles=[0.69468806]
# new_P:
# [[0.05084882+0.j]]
# likelihood is -684.8846074627153 on iteration 13
# new_angles=[0.69567391]
# new_P:
# [[0.08332034+0.j]]
# likelihood is -682.691743480156 on iteration 14
# new_angles=[0.6964693]
# new_P:
# [[0.15435909+0.j]]
# likelihood is -679.3079896075199 on iteration 15
# new_angles=[0.69715038]
# new_P:
# [[0.31698222+0.j]]
# likelihood is -675.3910970172859 on iteration 16
# new_angles=[0.69772369]
# new_P:
# [[0.63497915+0.j]]
# likelihood is -673.2363348719509 on iteration 17
# new_angles=[0.69819686]
# new_P:
# [[1.02889079+0.j]]
# 17-th start
# theta=[0.69944808],P=[[1.77772732e-07+6.6174449e-24j]]
# new_angles=[0.69944808]
# new_P:
# [[0.00100006+0.j]]
# likelihood is -689.4656264602315 on iteration 0
# new_angles=[0.69944808]
# new_P:
# [[0.00201035+0.j]]
# likelihood is -689.3518048351036 on iteration 1
# new_angles=[0.69944808]
# new_P:
# [[0.00305394+0.j]]
# likelihood is -689.235256331019 on iteration 2
# new_angles=[0.69944808]
# new_P:
# [[0.00415906+0.j]]
# likelihood is -689.1129565562354 on iteration 3
# new_angles=[0.69944808]
# new_P:
# [[0.00536222+0.j]]
# likelihood is -688.9811035456968 on iteration 4
# new_angles=[0.6997038]
# new_P:
# [[0.00671298+0.j]]
# likelihood is -688.8345259493015 on iteration 5
# new_angles=[0.69998484]
# new_P:
# [[0.00828217+0.j]]
# likelihood is -688.6663062604014 on iteration 6
# new_angles=[0.70014116]
# new_P:
# [[0.01017588+0.j]]
# likelihood is -688.4662815888503 on iteration 7
# new_angles=[0.70021351]
# new_P:
# [[0.01256138+0.j]]
# likelihood is -688.2187968720062 on iteration 8
# new_angles=[0.70027905]
# new_P:
# [[0.01571757+0.j]]
# likelihood is -687.8987712093569 on iteration 9
# new_angles=[0.70039926]
# new_P:
# [[0.02013946+0.j]]
# likelihood is -687.4640733684657 on iteration 10
# new_angles=[0.70045178]
# new_P:
# [[0.02677137+0.j]]
# likelihood is -686.8406288972791 on iteration 11
# new_angles=[0.7005014]
# new_P:
# [[0.03757095+0.j]]
# likelihood is -685.8930936508531 on iteration 12
# new_angles=[0.70056357]
# new_P:
# [[0.05698975+0.j]]
# likelihood is -684.3755704229474 on iteration 13
# new_angles=[0.700577]
# new_P:
# [[0.0960804+0.j]]
# likelihood is -681.9034798943636 on iteration 14
# new_angles=[0.70059975]
# new_P:
# [[0.18321542+0.j]]
# likelihood is -678.2547222974213 on iteration 15
# new_angles=[0.70064955]
# new_P:
# [[0.37929632+0.j]]
# likelihood is -674.5548124238331 on iteration 16
# new_angles=[0.70066336]
# new_P:
# [[0.72991514+0.j]]
# likelihood is -673.0605614224675 on iteration 17
# new_angles=[0.70067177]
# new_P:
# [[1.10593147+0.j]]
# 18-th start
# theta=[0.74249062],P=[[1.07227531e-07+3.30872245e-24j]]
# new_angles=[0.74249062]
# new_P:
# [[0.00100001+0.j]]
# likelihood is -689.5132478541717 on iteration 0
# new_angles=[0.73767975]
# new_P:
# [[0.00200599+0.j]]
# likelihood is -689.430157547296 on iteration 1
# new_angles=[0.72891013]
# new_P:
# [[0.00303529+0.j]]
# likelihood is -689.3103096186389 on iteration 2
# new_angles=[0.72368534]
# new_P:
# [[0.00411924+0.j]]
# likelihood is -689.1848304007659 on iteration 3
# new_angles=[0.71848456]
# new_P:
# [[0.00529371+0.j]]
# likelihood is -689.0414025350581 on iteration 4
# new_angles=[0.71529329]
# new_P:
# [[0.00661083+0.j]]
# likelihood is -688.8902374519811 on iteration 5
# new_angles=[0.71270893]
# new_P:
# [[0.00813708+0.j]]
# likelihood is -688.7190723112203 on iteration 6
# new_angles=[0.71031847]
# new_P:
# [[0.00997398+0.j]]
# likelihood is -688.516689854887 on iteration 7
# new_angles=[0.70875303]
# new_P:
# [[0.01228168+0.j]]
# likelihood is -688.2725838730164 on iteration 8
# new_angles=[0.70742211]
# new_P:
# [[0.01532085+0.j]]
# likelihood is -687.9600169299873 on iteration 9
# new_angles=[0.70630614]
# new_P:
# [[0.01955417+0.j]]
# likelihood is -687.5394631388964 on iteration 10
# new_angles=[0.70533334]
# new_P:
# [[0.02585689+0.j]]
# likelihood is -686.9411365652419 on iteration 11
# new_angles=[0.70456843]
# new_P:
# [[0.03602761+0.j]]
# likelihood is -686.0390521914672 on iteration 12
# new_angles=[0.70392772]
# new_P:
# [[0.05411586+0.j]]
# likelihood is -684.6015243456918 on iteration 13
# new_angles=[0.70338582]
# new_P:
# [[0.09010479+0.j]]
# likelihood is -682.2542637682242 on iteration 14
# new_angles=[0.7029554]
# new_P:
# [[0.16972647+0.j]]
# likelihood is -678.7138876272849 on iteration 15
# new_angles=[0.7025812]
# new_P:
# [[0.35061237+0.j]]
# likelihood is -674.8952893925875 on iteration 16
# new_angles=[0.7022875]
# new_P:
# [[0.68790978+0.j]]
# likelihood is -673.1125651979357 on iteration 17
# new_angles=[0.70203776]
# new_P:
# [[1.07348006+0.j]]
# 19-th start
# theta=[0.78572482],P=[[4.92090995e-08+5.29395592e-24j]]
# new_angles=[0.78572482]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -689.5752533619083 on iteration 0
# new_angles=[0.78572482]
# new_P:
# [[0.00200038+0.j]]
# likelihood is -689.5713991214664 on iteration 1
# new_angles=[0.77473289]
# new_P:
# [[0.0030041+0.j]]
# likelihood is -689.5361493145631 on iteration 2
# new_angles=[0.7661008]
# new_P:
# [[0.0040261+0.j]]
# likelihood is -689.4771624511473 on iteration 3
# new_angles=[0.75531519]
# new_P:
# [[0.00509063+0.j]]
# likelihood is -689.3648447283551 on iteration 4
# new_angles=[0.74480602]
# new_P:
# [[0.00624665+0.j]]
# likelihood is -689.2026163381386 on iteration 5
# new_angles=[0.73790986]
# new_P:
# [[0.0075651+0.j]]
# likelihood is -689.0338628129828 on iteration 6
# new_angles=[0.73113902]
# new_P:
# [[0.00912051+0.j]]
# likelihood is -688.8237088548766 on iteration 7
# new_angles=[0.72557943]
# new_P:
# [[0.0110456+0.j]]
# likelihood is -688.5806698782668 on iteration 8
# new_angles=[0.72133554]
# new_P:
# [[0.01353548+0.j]]
# likelihood is -688.294412274454 on iteration 9
# new_angles=[0.7175171]
# new_P:
# [[0.01691257+0.j]]
# likelihood is -687.925741842129 on iteration 10
# new_angles=[0.71454454]
# new_P:
# [[0.0217756+0.j]]
# likelihood is -687.4335794894181 on iteration 11
# new_angles=[0.71213894]
# new_P:
# [[0.02928352+0.j]]
# likelihood is -686.7266709148208 on iteration 12
# new_angles=[0.71019432]
# new_P:
# [[0.04192095+0.j]]
# likelihood is -685.6412150325973 on iteration 13
# new_angles=[0.70858078]
# new_P:
# [[0.06553535+0.j]]
# likelihood is -683.8824269427761 on iteration 14
# new_angles=[0.70724666]
# new_P:
# [[0.1150723+0.j]]
# likelihood is -681.0380187313642 on iteration 15
# new_angles=[0.70615906]
# new_P:
# [[0.2286305+0.j]]
# likelihood is -677.1233382114929 on iteration 16
# new_angles=[0.70526725]
# new_P:
# [[0.47719268+0.j]]
# likelihood is -673.8891486496334 on iteration 17
# new_angles=[0.70452837]
# new_P:
# [[0.86844723+0.j]]
# likelihood is -673.174872221131 on iteration 18
# new_angles=[0.70391726]
# new_P:
# [[1.21740834+0.j]]
# best_start=17

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.70066336]), array([[0.72991514+0.j]]))

# %%
em_stoch.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q_2), em_stoch.incomplete_lkhd(X2_with_mv, theta2_rad, P_2, Q_2)
# Out:
# (np.float64(-673.0605614224675), np.float64(-673.6467390084401))
