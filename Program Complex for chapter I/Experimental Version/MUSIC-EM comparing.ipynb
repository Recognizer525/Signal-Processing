# %%
import numpy as np

import diff_sensor_structures
import sensors
import em_stoch
import subspace_methods

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12
failing_sensors1 = np.array([0, 1, 2, 3, 4], dtype=np.int16)
gap_ratio1 = np.array([0.5, 0.5, 0.5, 0.5, 0.5], dtype=np.float32)
theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P_1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q_1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
N1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sensors.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sensors.initial_Cov(X1_with_mv)
MUSIC_theta1 = subspace_methods.MUSIC_DoA(R1, Num_emitters1)

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sensors.SNR(A1, P_1, Q_1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1 = em_stoch.multistart_EM2(X1_with_mv, 
                                                      Num_emitters1, 
                                                      Q=Q_1,
                                                      MUSIC_theta=MUSIC_theta1, 
                                                      num_of_starts=10, 
                                                      max_iter=20, 
                                                      rtol=1e-5)
# Out:
# 0-th start
# theta=[0.80378761],P=[[4.8828125e-08+0.j]]
# new_angles=[0.80378761]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -870.4013699741913 on iteration 0
# new_angles=[0.80378761]
# new_P:
# [[0.002+0.j]]
# 1-th start
# theta=[0.62809672],P=[[6.82086539e-08+0.j]]
# new_angles=[0.62809672]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3703510235397 on iteration 0
# new_angles=[0.63459813]
# new_P:
# [[0.00200259+0.j]]
# likelihood is -870.3272169549845 on iteration 1
# new_angles=[0.64081501]
# new_P:
# [[0.00301605+0.j]]
# likelihood is -870.2681744869597 on iteration 2
# new_angles=[0.64679832]
# new_P:
# [[0.0040546+0.j]]
# likelihood is -870.1905563457689 on iteration 3
# new_angles=[0.65374657]
# new_P:
# [[0.00513954+0.j]]
# likelihood is -870.0834838476042 on iteration 4
# new_angles=[0.65972039]
# new_P:
# [[0.00630474+0.j]]
# likelihood is -869.9572801875106 on iteration 5
# new_angles=[0.66542608]
# new_P:
# [[0.00759193+0.j]]
# likelihood is -869.8069433809702 on iteration 6
# new_angles=[0.67023125]
# new_P:
# [[0.00906022+0.j]]
# likelihood is -869.6377194839989 on iteration 7
# new_angles=[0.67459381]
# new_P:
# [[0.01078725+0.j]]
# likelihood is -869.4414409801034 on iteration 8
# new_angles=[0.67854717]
# new_P:
# [[0.01288882+0.j]]
# likelihood is -869.2099200159087 on iteration 9
# new_angles=[0.6815142]
# new_P:
# [[0.01554213+0.j]]
# likelihood is -868.9367316223634 on iteration 10
# new_angles=[0.68403168]
# new_P:
# [[0.01902398+0.j]]
# likelihood is -868.5933122707733 on iteration 11
# new_angles=[0.68636109]
# new_P:
# [[0.02381489+0.j]]
# likelihood is -868.1384648738449 on iteration 12
# new_angles=[0.6881231]
# new_P:
# [[0.03079658+0.j]]
# likelihood is -867.5114978529273 on iteration 13
# new_angles=[0.68960238]
# new_P:
# [[0.04169034+0.j]]
# likelihood is -866.592869320488 on iteration 14
# new_angles=[0.69081296]
# new_P:
# [[0.06017904+0.j]]
# likelihood is -865.1728741535145 on iteration 15
# new_angles=[0.69184375]
# new_P:
# [[0.09483045+0.j]]
# likelihood is -862.8951878430463 on iteration 16
# new_angles=[0.69267354]
# new_P:
# [[0.16684009+0.j]]
# likelihood is -859.3417282848891 on iteration 17
# new_angles=[0.6933506]
# new_P:
# [[0.32604516+0.j]]
# likelihood is -854.7826039176651 on iteration 18
# new_angles=[0.69390162]
# new_P:
# [[0.64815763+0.j]]
# likelihood is -851.3091735556997 on iteration 19
# 2-th start
# theta=[0.64303758],P=[[1.11433171e-07-5.95570041e-24j]]
# new_angles=[0.64303758]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3537914015952 on iteration 0
# new_angles=[0.65376466]
# new_P:
# [[0.00200397+0.j]]
# likelihood is -870.2758270524014 on iteration 1
# new_angles=[0.65770127]
# new_P:
# [[0.00302597+0.j]]
# likelihood is -870.1947756614 on iteration 2
# new_angles=[0.66264661]
# new_P:
# [[0.00408301+0.j]]
# likelihood is -870.0939306048172 on iteration 3
# new_angles=[0.66791322]
# new_P:
# [[0.00520112+0.j]]
# likelihood is -869.9729847960832 on iteration 4
# new_angles=[0.67254323]
# new_P:
# [[0.0064158+0.j]]
# likelihood is -869.8373319129897 on iteration 5
# new_angles=[0.67734387]
# new_P:
# [[0.0077719+0.j]]
# likelihood is -869.6798838526 on iteration 6
# new_angles=[0.68068149]
# new_P:
# [[0.00933382+0.j]]
# likelihood is -869.5102369462062 on iteration 7
# new_angles=[0.6833146]
# new_P:
# [[0.01118362+0.j]]
# likelihood is -869.3167990408408 on iteration 8
# new_angles=[0.68575281]
# new_P:
# [[0.01344641+0.j]]
# likelihood is -869.085297796439 on iteration 9
# new_angles=[0.68764698]
# new_P:
# [[0.01632066+0.j]]
# likelihood is -868.80198040771 on iteration 10
# new_angles=[0.68922477]
# new_P:
# [[0.02012862+0.j]]
# likelihood is -868.4385798899144 on iteration 11
# new_angles=[0.69049083]
# new_P:
# [[0.02543284+0.j]]
# likelihood is -867.950917169512 on iteration 12
# new_angles=[0.69160375]
# new_P:
# [[0.03327829+0.j]]
# likelihood is -867.2614177109624 on iteration 13
# new_angles=[0.69254708]
# new_P:
# [[0.04576299+0.j]]
# likelihood is -866.2337923617276 on iteration 14
# new_angles=[0.69325227]
# new_P:
# [[0.06746575+0.j]]
# likelihood is -864.6248507540756 on iteration 15
# new_angles=[0.69381343]
# new_P:
# [[0.10923813+0.j]]
# likelihood is -862.0420491276735 on iteration 16
# new_angles=[0.69428933]
# new_P:
# [[0.19793359+0.j]]
# likelihood is -858.1372561327343 on iteration 17
# new_angles=[0.6946736]
# new_P:
# [[0.39286617+0.j]]
# likelihood is -853.6132422837903 on iteration 18
# new_angles=[0.69497511]
# new_P:
# [[0.76058973+0.j]]
# likelihood is -850.8334868385184 on iteration 19
# 3-th start
# theta=[0.64132648],P=[[1.05540317e-07-2.64697796e-24j]]
# new_angles=[0.64132648]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3560430120068 on iteration 0
# new_angles=[0.64994635]
# new_P:
# [[0.00200379+0.j]]
# likelihood is -870.2871848829768 on iteration 1
# new_angles=[0.65439425]
# new_P:
# [[0.0030239+0.j]]
# likelihood is -870.2098983427705 on iteration 2
# new_angles=[0.65939727]
# new_P:
# [[0.00407711+0.j]]
# likelihood is -870.1138267586718 on iteration 3
# new_angles=[0.66510727]
# new_P:
# [[0.00518836+0.j]]
# likelihood is -869.9940412985114 on iteration 4
# new_angles=[0.66997184]
# new_P:
# [[0.00639347+0.j]]
# likelihood is -869.8596954644366 on iteration 5
# new_angles=[0.6741188]
# new_P:
# [[0.00773647+0.j]]
# likelihood is -869.7100162517427 on iteration 6
# new_angles=[0.67785563]
# new_P:
# [[0.00927643+0.j]]
# likelihood is -869.5397968979307 on iteration 7
# new_angles=[0.68106528]
# new_P:
# [[0.01109789+0.j]]
# likelihood is -869.3443681637156 on iteration 8
# new_angles=[0.6836983]
# new_P:
# [[0.01332456+0.j]]
# likelihood is -869.114546304369 on iteration 9
# new_angles=[0.68609418]
# new_P:
# [[0.01614736+0.j]]
# likelihood is -868.8314856888885 on iteration 10
# new_angles=[0.68808865]
# new_P:
# [[0.0198818+0.j]]
# likelihood is -868.4709233300687 on iteration 11
# new_angles=[0.68941294]
# new_P:
# [[0.02507222+0.j]]
# likelihood is -867.9926024702938 on iteration 12
# new_angles=[0.69067885]
# new_P:
# [[0.03272082+0.j]]
# likelihood is -867.3174060450087 on iteration 13
# new_angles=[0.69176174]
# new_P:
# [[0.04483962+0.j]]
# likelihood is -866.3145332246827 on iteration 14
# new_angles=[0.69258858]
# new_P:
# [[0.06579658+0.j]]
# likelihood is -864.7486235776315 on iteration 15
# new_angles=[0.69327]
# new_P:
# [[0.10590303+0.j]]
# likelihood is -862.2341006324924 on iteration 16
# new_angles=[0.69383996]
# new_P:
# [[0.19069451+0.j]]
# likelihood is -858.4023036026423 on iteration 17
# new_angles=[0.69430402]
# new_P:
# [[0.37747998+0.j]]
# likelihood is -853.8550668701984 on iteration 18
# new_angles=[0.69467621]
# new_P:
# [[0.73579586+0.j]]
# likelihood is -850.9193943158077 on iteration 19
# 4-th start
# theta=[0.65905647],P=[[1.72770544e-07-1.09187841e-23j]]
# new_angles=[0.65905647]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -870.3304044487845 on iteration 0
# new_angles=[0.66104052]
# new_P:
# [[0.00200592+0.j]]
# likelihood is -870.25385055722 on iteration 1
# new_angles=[0.66505566]
# new_P:
# [[0.0030316+0.j]]
# likelihood is -870.161720061363 on iteration 2
# new_angles=[0.67002959]
# new_P:
# [[0.00409702+0.j]]
# likelihood is -870.0511619548191 on iteration 3
# new_angles=[0.6750232]
# new_P:
# [[0.00523001+0.j]]
# likelihood is -869.9246310277701 on iteration 4
# new_angles=[0.67863251]
# new_P:
# [[0.00646679+0.j]]
# likelihood is -869.7901432105015 on iteration 5
# new_angles=[0.68120129]
# new_P:
# [[0.00785109+0.j]]
# likelihood is -869.6446136390659 on iteration 6
# new_angles=[0.68371813]
# new_P:
# [[0.00944219+0.j]]
# likelihood is -869.4776629649386 on iteration 7
# new_angles=[0.68615156]
# new_P:
# [[0.0113285+0.j]]
# likelihood is -869.2822265685343 on iteration 8
# new_angles=[0.68811156]
# new_P:
# [[0.01364223+0.j]]
# likelihood is -869.0497631415531 on iteration 9
# new_angles=[0.68959823]
# new_P:
# [[0.01658788+0.j]]
# likelihood is -868.7629595888991 on iteration 10
# new_angles=[0.69084156]
# new_P:
# [[0.02050243+0.j]]
# likelihood is -868.3926332287671 on iteration 11
# new_angles=[0.69179399]
# new_P:
# [[0.02597677+0.j]]
# likelihood is -867.8928749303858 on iteration 12
# new_angles=[0.69259277]
# new_P:
# [[0.03411431+0.j]]
# likelihood is -867.1828730306273 on iteration 13
# new_angles=[0.69330596]
# new_P:
# [[0.0471434+0.j]]
# likelihood is -866.1191318474993 on iteration 14
# new_angles=[0.69385023]
# new_P:
# [[0.06996087+0.j]]
# likelihood is -864.4474052573653 on iteration 15
# new_angles=[0.69433098]
# new_P:
# [[0.11423202+0.j]]
# likelihood is -861.7657119742901 on iteration 16
# new_angles=[0.69471708]
# new_P:
# [[0.20877055+0.j]]
# likelihood is -857.7620209457277 on iteration 17
# new_angles=[0.695021]
# new_P:
# [[0.41562023+0.j]]
# likelihood is -853.2871470069908 on iteration 18
# new_angles=[0.69526298]
# new_P:
# [[0.79602905+0.j]]
# likelihood is -850.7307303519348 on iteration 19
# 5-th start
# theta=[0.69671681],P=[[2.64175428e-07+1.32348898e-24j]]
# new_angles=[0.69671681]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -870.2958123617279 on iteration 0
# new_angles=[0.69671681]
# new_P:
# [[0.0020088+0.j]]
# likelihood is -870.1902915258543 on iteration 1
# new_angles=[0.69671681]
# new_P:
# [[0.00304508+0.j]]
# likelihood is -870.0826252298389 on iteration 2
# new_angles=[0.69671681]
# new_P:
# [[0.00413071+0.j]]
# likelihood is -869.9706249269598 on iteration 3
# new_angles=[0.69671681]
# new_P:
# [[0.00529229+0.j]]
# likelihood is -869.8516773816025 on iteration 4
# new_angles=[0.69671681]
# new_P:
# [[0.00656389+0.j]]
# likelihood is -869.7225060238651 on iteration 5
# new_angles=[0.69671681]
# new_P:
# [[0.00799104+0.j]]
# likelihood is -869.5788170773889 on iteration 6
# new_angles=[0.69671681]
# new_P:
# [[0.0096371+0.j]]
# likelihood is -869.4147506486981 on iteration 7
# new_angles=[0.69667016]
# new_P:
# [[0.01159392+0.j]]
# likelihood is -869.2219856264095 on iteration 8
# new_angles=[0.69667016]
# new_P:
# [[0.01400029+0.j]]
# likelihood is -868.9882865893727 on iteration 9
# new_angles=[0.69667016]
# new_P:
# [[0.01707569+0.j]]
# likelihood is -868.6948661852587 on iteration 10
# new_angles=[0.69661516]
# new_P:
# [[0.02118526+0.j]]
# likelihood is -868.3117077061797 on iteration 11
# new_angles=[0.69659954]
# new_P:
# [[0.02697313+0.j]]
# likelihood is -867.7888117723076 on iteration 12
# new_angles=[0.69659954]
# new_P:
# [[0.03565517+0.j]]
# likelihood is -867.0392675763136 on iteration 13
# new_angles=[0.69653002]
# new_P:
# [[0.04971263+0.j]]
# likelihood is -865.9075207082811 on iteration 14
# new_angles=[0.69651099]
# new_P:
# [[0.07465949+0.j]]
# likelihood is -864.1188281010815 on iteration 15
# new_angles=[0.69648643]
# new_P:
# [[0.12374216+0.j]]
# likelihood is -861.2589065864424 on iteration 16
# new_angles=[0.69647129]
# new_P:
# [[0.22947866+0.j]]
# likelihood is -857.0958446373397 on iteration 17
# new_angles=[0.69645162]
# new_P:
# [[0.45827264+0.j]]
# likelihood is -852.7518471336382 on iteration 18
# new_angles=[0.6964356]
# new_P:
# [[0.85889826+0.j]]
# likelihood is -850.5896199879836 on iteration 19
# 6-th start
# theta=[0.71784892],P=[[1.15423857e-07+2.31610572e-24j]]
# new_angles=[0.71784892]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -870.308956101243 on iteration 0
# new_angles=[0.71291991]
# new_P:
# [[0.0020077+0.j]]
# likelihood is -870.2063500198244 on iteration 1
# new_angles=[0.70952339]
# new_P:
# [[0.0030413+0.j]]
# likelihood is -870.0983825762246 on iteration 2
# new_angles=[0.70708963]
# new_P:
# [[0.00412286+0.j]]
# likelihood is -869.9852913325475 on iteration 3
# new_angles=[0.70494637]
# new_P:
# [[0.00527913+0.j]]
# likelihood is -869.8643666600613 on iteration 4
# new_angles=[0.70362324]
# new_P:
# [[0.00654449+0.j]]
# likelihood is -869.7344938211413 on iteration 5
# new_angles=[0.70233205]
# new_P:
# [[0.0079638+0.j]]
# likelihood is -869.5897438596447 on iteration 6
# new_angles=[0.70105341]
# new_P:
# [[0.00960025+0.j]]
# likelihood is -869.424448709927 on iteration 7
# new_angles=[0.69997435]
# new_P:
# [[0.01154529+0.j]]
# likelihood is -869.2310065733808 on iteration 8
# new_angles=[0.6991124]
# new_P:
# [[0.01393635+0.j]]
# likelihood is -868.9973766507867 on iteration 9
# new_angles=[0.69868019]
# new_P:
# [[0.01699039+0.j]]
# likelihood is -868.7054158065883 on iteration 10
# new_angles=[0.69819593]
# new_P:
# [[0.02106724+0.j]]
# likelihood is -868.3244623000033 on iteration 11
# new_angles=[0.69788819]
# new_P:
# [[0.02680224+0.j]]
# likelihood is -867.8055996799785 on iteration 12
# new_angles=[0.69761323]
# new_P:
# [[0.03539176+0.j]]
# likelihood is -867.0627979957701 on iteration 13
# new_angles=[0.69733344]
# new_P:
# [[0.04927349+0.j]]
# likelihood is -865.942542678767 on iteration 14
# new_angles=[0.69718523]
# new_P:
# [[0.07385481+0.j]]
# likelihood is -864.1736758830594 on iteration 15
# new_angles=[0.6970281]
# new_P:
# [[0.1221083+0.j]]
# likelihood is -861.3434230759804 on iteration 16
# new_angles=[0.69691296]
# new_P:
# [[0.22592111+0.j]]
# likelihood is -857.2051437970869 on iteration 17
# new_angles=[0.69680069]
# new_P:
# [[0.45102969+0.j]]
# likelihood is -852.8358058898021 on iteration 18
# new_angles=[0.6967211]
# new_P:
# [[0.84853782+0.j]]
# likelihood is -850.6092994598976 on iteration 19
# 7-th start
# theta=[0.70172546],P=[[2.62158203e-07+1.12496563e-23j]]
# new_angles=[0.70172546]
# new_P:
# [[0.00100003+0.j]]
# likelihood is -870.2966599178419 on iteration 0
# new_angles=[0.70044234]
# new_P:
# [[0.00200871+0.j]]
# likelihood is -870.191274006739 on iteration 1
# new_angles=[0.70044234]
# new_P:
# [[0.00304483+0.j]]
# likelihood is -870.0841224707241 on iteration 2
# new_angles=[0.7002125]
# new_P:
# [[0.00413007+0.j]]
# likelihood is -869.9724583466227 on iteration 3
# new_angles=[0.6994216]
# new_P:
# [[0.005291+0.j]]
# likelihood is -869.8532198384194 on iteration 4
# new_angles=[0.6994216]
# new_P:
# [[0.00656186+0.j]]
# likelihood is -869.724455385649 on iteration 5
# new_angles=[0.69923054]
# new_P:
# [[0.00798781+0.j]]
# likelihood is -869.5809926321593 on iteration 6
# new_angles=[0.69922141]
# new_P:
# [[0.00963216+0.j]]
# likelihood is -869.4174495469824 on iteration 7
# new_angles=[0.69857475]
# new_P:
# [[0.0115863+0.j]]
# likelihood is -869.2242950326502 on iteration 8
# new_angles=[0.69811629]
# new_P:
# [[0.01398943+0.j]]
# likelihood is -868.9904888973768 on iteration 9
# new_angles=[0.69776655]
# new_P:
# [[0.01706045+0.j]]
# likelihood is -868.6971777063018 on iteration 10
# new_angles=[0.69760346]
# new_P:
# [[0.02116358+0.j]]
# likelihood is -868.3145378356679 on iteration 11
# new_angles=[0.69740278]
# new_P:
# [[0.02694091+0.j]]
# likelihood is -867.7923920665082 on iteration 12
# new_angles=[0.69725957]
# new_P:
# [[0.03560459+0.j]]
# likelihood is -867.044194648126 on iteration 13
# new_angles=[0.69706007]
# new_P:
# [[0.0496271+0.j]]
# likelihood is -865.9146659449817 on iteration 14
# new_angles=[0.69696709]
# new_P:
# [[0.07450139+0.j]]
# likelihood is -864.1299445271351 on iteration 15
# new_angles=[0.69688271]
# new_P:
# [[0.12341893+0.j]]
# likelihood is -861.2760011375601 on iteration 16
# new_angles=[0.69679568]
# new_P:
# [[0.22877118+0.j]]
# likelihood is -857.1179110222174 on iteration 17
# new_angles=[0.6967161]
# new_P:
# [[0.45682861+0.j]]
# likelihood is -852.7688924822878 on iteration 18
# new_angles=[0.69664788]
# new_P:
# [[0.85683199+0.j]]
# likelihood is -850.5938978478341 on iteration 19
# 8-th start
# theta=[0.7055677],P=[[2.57996973e-07-6.6174449e-24j]]
# new_angles=[0.7055677]
# new_P:
# [[0.00100001+0.j]]
# likelihood is -870.2983175085549 on iteration 0
# new_angles=[0.7055677]
# new_P:
# [[0.00200855+0.j]]
# likelihood is -870.19532667503 on iteration 1
# new_angles=[0.70343636]
# new_P:
# [[0.003044+0.j]]
# likelihood is -870.0872066673471 on iteration 2
# new_angles=[0.70264165]
# new_P:
# [[0.00412844+0.j]]
# likelihood is -869.9756137432203 on iteration 3
# new_angles=[0.7014929]
# new_P:
# [[0.00528823+0.j]]
# likelihood is -869.8561311563201 on iteration 4
# new_angles=[0.70100498]
# new_P:
# [[0.00655767+0.j]]
# likelihood is -869.7272132120795 on iteration 5
# new_angles=[0.70039664]
# new_P:
# [[0.00798183+0.j]]
# likelihood is -869.5834569378294 on iteration 6
# new_angles=[0.69945349]
# new_P:
# [[0.00962403+0.j]]
# likelihood is -869.418637565666 on iteration 7
# new_angles=[0.69879247]
# new_P:
# [[0.01157631+0.j]]
# likelihood is -869.2256064052297 on iteration 8
# new_angles=[0.69847213]
# new_P:
# [[0.01397679+0.j]]
# likelihood is -868.9922493444408 on iteration 9
# new_angles=[0.69809724]
# new_P:
# [[0.01704363+0.j]]
# likelihood is -868.6992597973699 on iteration 10
# new_angles=[0.69781218]
# new_P:
# [[0.02114031+0.j]]
# likelihood is -868.3170055453305 on iteration 11
# new_angles=[0.69759267]
# new_P:
# [[0.02690727+0.j]]
# likelihood is -867.7956880311516 on iteration 12
# new_angles=[0.69731834]
# new_P:
# [[0.03555274+0.j]]
# likelihood is -867.0486532733992 on iteration 13
# new_angles=[0.69707562]
# new_P:
# [[0.0495411+0.j]]
# likelihood is -865.9213301577365 on iteration 14
# new_angles=[0.6970154]
# new_P:
# [[0.07434442+0.j]]
# likelihood is -864.1405201354306 on iteration 15
# new_angles=[0.6968894]
# new_P:
# [[0.12310068+0.j]]
# likelihood is -861.2922387551803 on iteration 16
# new_angles=[0.69679988]
# new_P:
# [[0.22807978+0.j]]
# likelihood is -857.1388692752607 on iteration 17
# new_angles=[0.69672127]
# new_P:
# [[0.45542508+0.j]]
# likelihood is -852.7848672620772 on iteration 18
# new_angles=[0.69665117]
# new_P:
# [[0.85483334+0.j]]
# likelihood is -850.5974624301742 on iteration 19
# 9-th start
# theta=[0.62610695],P=[[6.40458684e-08+0.j]]
# new_angles=[0.62610695]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.371955076054 on iteration 0
# new_angles=[0.62610695]
# new_P:
# [[0.00200246+0.j]]
# likelihood is -870.3429653719961 on iteration 1
# new_angles=[0.62742384]
# new_P:
# [[0.0030133+0.j]]
# likelihood is -870.3108560997849 on iteration 2
# new_angles=[0.63194831]
# new_P:
# [[0.00404119+0.j]]
# likelihood is -870.2641963774216 on iteration 3
# new_angles=[0.63654111]
# new_P:
# [[0.0051013+0.j]]
# likelihood is -870.2042343111239 on iteration 4
# new_angles=[0.64169038]
# new_P:
# [[0.0062145+0.j]]
# likelihood is -870.1235859493361 on iteration 5
# new_angles=[0.64785985]
# new_P:
# [[0.0074123+0.j]]
# likelihood is -870.0098623897595 on iteration 6
# new_angles=[0.6536419]
# new_P:
# [[0.00874486+0.j]]
# likelihood is -869.8688520117742 on iteration 7
# new_angles=[0.65955512]
# new_P:
# [[0.01027771+0.j]]
# likelihood is -869.6898975778653 on iteration 8
# new_angles=[0.66466628]
# new_P:
# [[0.01211087+0.j]]
# likelihood is -869.4802983572216 on iteration 9
# new_angles=[0.66963683]
# new_P:
# [[0.01438176+0.j]]
# likelihood is -869.2212941190542 on iteration 10
# new_angles=[0.67397641]
# new_P:
# [[0.01731525+0.j]]
# likelihood is -868.9050871246274 on iteration 11
# new_angles=[0.67774845]
# new_P:
# [[0.02127207+0.j]]
# likelihood is -868.5037035686632 on iteration 12
# new_angles=[0.6810333]
# new_P:
# [[0.02688673+0.j]]
# likelihood is -867.9680634792426 on iteration 13
# new_angles=[0.68384928]
# new_P:
# [[0.03535873+0.j]]
# likelihood is -867.2129234623744 on iteration 14
# new_angles=[0.68605599]
# new_P:
# [[0.04914131+0.j]]
# likelihood is -866.0880023016653 on iteration 15
# new_angles=[0.68790455]
# new_P:
# [[0.07369584+0.j]]
# likelihood is -864.3134099776817 on iteration 16
# new_angles=[0.68944311]
# new_P:
# [[0.12225559+0.j]]
# likelihood is -861.4644689616089 on iteration 17
# new_angles=[0.6906925]
# new_P:
# [[0.22772667+0.j]]
# likelihood is -857.2806936634149 on iteration 18
# new_angles=[0.69172129]
# new_P:
# [[0.45878134+0.j]]
# likelihood is -852.8716716361519 on iteration 19
# best_start=5

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.6964356]), array([[0.85889826+0.j]]))

# %%
em_stoch.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q_1), em_stoch.incomplete_lkhd(X1_with_mv, theta1_rad, P_1, Q_1)
# Out:
# (np.float64(-850.5896199879836), np.float64(-852.4011191641745))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11
failing_sensors2 = np.array([0, 1, 2, 3, 4, 5, 6, 7], dtype=np.int16)
gap_ratio2 = np.array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5], dtype=np.float32)
theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P_2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q_2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sensors.gss(Num_emitters2, sample_size2, P_2)
N2 = sensors.gss(Num_sensors2, sample_size2, Q_2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sensors.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sensors.initial_Cov(X2_with_mv)
MUSIC_theta2 = subspace_methods.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sensors.SNR(A2, P_2, Q_2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2 = em_stoch.multistart_EM2(X2_with_mv, 
                                                      Num_emitters2, 
                                                      Q=Q_2,
                                                      MUSIC_theta=MUSIC_theta2, 
                                                      num_of_starts=20, 
                                                      max_iter=20, 
                                                      rtol=1e-5)
# Out:
# 0-th start
# theta=[0.81251426],P=[[4.8828125e-08+0.j]]
# new_angles=[0.81251426]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -689.5858366251647 on iteration 0
# new_angles=[0.80873796]
# new_P:
# [[0.00199942+0.j]]
# 1-th start
# theta=[0.63682337],P=[[1.17743922e-07+4.63221143e-24j]]
# new_angles=[0.63682337]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.542752465457 on iteration 0
# new_angles=[0.63682337]
# new_P:
# [[0.00200334+0.j]]
# likelihood is -689.5065020930143 on iteration 1
# new_angles=[0.63715889]
# new_P:
# [[0.00301881+0.j]]
# likelihood is -689.469165088779 on iteration 2
# new_angles=[0.64202748]
# new_P:
# [[0.00405916+0.j]]
# likelihood is -689.4097442862554 on iteration 3
# new_angles=[0.64643133]
# new_P:
# [[0.00514899+0.j]]
# likelihood is -689.3359017699948 on iteration 4
# new_angles=[0.65133401]
# new_P:
# [[0.00632079+0.j]]
# likelihood is -689.2375119127994 on iteration 5
# new_angles=[0.65625508]
# new_P:
# [[0.00762471+0.j]]
# likelihood is -689.1114456447533 on iteration 6
# new_angles=[0.66119487]
# new_P:
# [[0.00913368+0.j]]
# likelihood is -688.9504997228615 on iteration 7
# new_angles=[0.66596276]
# new_P:
# [[0.0109589+0.j]]
# likelihood is -688.7476426549146 on iteration 8
# new_angles=[0.67028564]
# new_P:
# [[0.01327416+0.j]]
# likelihood is -688.494001041007 on iteration 9
# new_angles=[0.67435522]
# new_P:
# [[0.01636307+0.j]]
# likelihood is -688.1636705781902 on iteration 10
# new_angles=[0.67809041]
# new_P:
# [[0.02073238+0.j]]
# likelihood is -687.7178308536322 on iteration 11
# new_angles=[0.68139775]
# new_P:
# [[0.02734869+0.j]]
# likelihood is -687.0860967573692 on iteration 12
# new_angles=[0.68426905]
# new_P:
# [[0.03822099+0.j]]
# likelihood is -686.1343103012134 on iteration 13
# new_angles=[0.6867922]
# new_P:
# [[0.05794788+0.j]]
# likelihood is -684.611570648477 on iteration 14
# new_angles=[0.68896528]
# new_P:
# [[0.09806176+0.j]]
# likelihood is -682.125423981175 on iteration 15
# new_angles=[0.69078759]
# new_P:
# [[0.18845152+0.j]]
# likelihood is -678.4570806562582 on iteration 16
# new_angles=[0.69232558]
# new_P:
# [[0.39332844+0.j]]
# likelihood is -674.7896498549759 on iteration 17
# new_angles=[0.69361062]
# new_P:
# [[0.75764765+0.j]]
# likelihood is -673.3824998352153 on iteration 18
# new_angles=[0.69470486]
# new_P:
# [[1.14042975+0.j]]
# 2-th start
# theta=[0.65176423],P=[[8.96189647e-08-1.32348898e-24j]]
# new_angles=[0.65176423]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.5231536456283 on iteration 0
# new_angles=[0.65691518]
# new_P:
# [[0.00200513+0.j]]
# likelihood is -689.4508675183723 on iteration 1
# new_angles=[0.66235828]
# new_P:
# [[0.00303068+0.j]]
# likelihood is -689.3590287120256 on iteration 2
# new_angles=[0.66732166]
# new_P:
# [[0.00410122+0.j]]
# likelihood is -689.2495577068358 on iteration 3
# new_angles=[0.67230452]
# new_P:
# [[0.00525106+0.j]]
# likelihood is -689.1187668087643 on iteration 4
# new_angles=[0.67684385]
# new_P:
# [[0.00652898+0.j]]
# likelihood is -688.967917322175 on iteration 5
# new_angles=[0.68032586]
# new_P:
# [[0.00800246+0.j]]
# likelihood is -688.7994556157237 on iteration 6
# new_angles=[0.68320554]
# new_P:
# [[0.00976577+0.j]]
# likelihood is -688.6032765776383 on iteration 7
# new_angles=[0.68580733]
# new_P:
# [[0.01196569+0.j]]
# likelihood is -688.3640047148988 on iteration 8
# new_angles=[0.68808756]
# new_P:
# [[0.01484438+0.j]]
# likelihood is -688.0611131136022 on iteration 9
# new_angles=[0.68998537]
# new_P:
# [[0.01882264+0.j]]
# likelihood is -687.6598067720879 on iteration 10
# new_angles=[0.69166421]
# new_P:
# [[0.02468496+0.j]]
# likelihood is -687.0957094925499 on iteration 11
# new_angles=[0.6930933]
# new_P:
# [[0.03402364+0.j]]
# likelihood is -686.2550324092456 on iteration 12
# new_angles=[0.69435847]
# new_P:
# [[0.05037208+0.j]]
# likelihood is -684.9263052477897 on iteration 13
# new_angles=[0.69542835]
# new_P:
# [[0.08233966+0.j]]
# likelihood is -682.7557210546105 on iteration 14
# new_angles=[0.69628051]
# new_P:
# [[0.15215197+0.j]]
# likelihood is -679.3963020097896 on iteration 15
# new_angles=[0.69699669]
# new_P:
# [[0.31210437+0.j]]
# likelihood is -675.4685912353995 on iteration 16
# new_angles=[0.69759734]
# new_P:
# [[0.62700064+0.j]]
# likelihood is -673.2574368044507 on iteration 17
# new_angles=[0.69809097]
# new_P:
# [[1.02182843+0.j]]
# 3-th start
# theta=[0.65005312],P=[[8.55417288e-08-3.97046694e-24j]]
# new_angles=[0.65005312]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.5257666281028 on iteration 0
# new_angles=[0.65706797]
# new_P:
# [[0.00200489+0.j]]
# likelihood is -689.4503832273058 on iteration 1
# new_angles=[0.66297603]
# new_P:
# [[0.00303052+0.j]]
# likelihood is -689.355955185066 on iteration 2
# new_angles=[0.66794182]
# new_P:
# [[0.0041019+0.j]]
# likelihood is -689.2454441771731 on iteration 3
# new_angles=[0.67277276]
# new_P:
# [[0.00525327+0.j]]
# likelihood is -689.114925280012 on iteration 4
# new_angles=[0.67777735]
# new_P:
# [[0.00653314+0.j]]
# likelihood is -688.9594813779112 on iteration 5
# new_angles=[0.68118191]
# new_P:
# [[0.00801187+0.j]]
# likelihood is -688.7905357385904 on iteration 6
# new_angles=[0.68412022]
# new_P:
# [[0.0097826+0.j]]
# likelihood is -688.5924815770037 on iteration 7
# new_angles=[0.68664306]
# new_P:
# [[0.01199436+0.j]]
# likelihood is -688.3523571887225 on iteration 8
# new_angles=[0.68883217]
# new_P:
# [[0.01489089+0.j]]
# likelihood is -688.048277223808 on iteration 9
# new_angles=[0.69069415]
# new_P:
# [[0.01889744+0.j]]
# likelihood is -687.64421220626 on iteration 10
# new_angles=[0.69224881]
# new_P:
# [[0.02480928+0.j]]
# likelihood is -687.076700689129 on iteration 11
# new_angles=[0.69351805]
# new_P:
# [[0.03423998+0.j]]
# likelihood is -686.2302845179089 on iteration 12
# new_angles=[0.69467931]
# new_P:
# [[0.05077652+0.j]]
# likelihood is -684.8901909372555 on iteration 13
# new_angles=[0.69564636]
# new_P:
# [[0.08317424+0.j]]
# likelihood is -682.7010425651113 on iteration 14
# new_angles=[0.69647904]
# new_P:
# [[0.15403117+0.j]]
# likelihood is -679.3199651363391 on iteration 15
# new_angles=[0.69714157]
# new_P:
# [[0.31626757+0.j]]
# likelihood is -675.4018392823341 on iteration 16
# new_angles=[0.6977176]
# new_P:
# [[0.63382112+0.j]]
# likelihood is -673.2388506030949 on iteration 17
# new_angles=[0.69819558]
# new_P:
# [[1.02787873+0.j]]
# 4-th start
# theta=[0.66778311],P=[[1.30082571e-07+5.29395592e-24j]]
# new_angles=[0.66778311]
# new_P:
# [[0.00100007+0.j]]
# likelihood is -689.4970085428247 on iteration 0
# new_angles=[0.67288072]
# new_P:
# [[0.00200752+0.j]]
# likelihood is -689.3989669860221 on iteration 1
# new_angles=[0.67682133]
# new_P:
# [[0.0030425+0.j]]
# likelihood is -689.2901598171561 on iteration 2
# new_angles=[0.68001539]
# new_P:
# [[0.00413218+0.j]]
# likelihood is -689.1714560936528 on iteration 3
# new_angles=[0.68294938]
# new_P:
# [[0.00531223+0.j]]
# likelihood is -689.0397332607903 on iteration 4
# new_angles=[0.6854698]
# new_P:
# [[0.00663145+0.j]]
# likelihood is -688.8926326877818 on iteration 5
# new_angles=[0.68786388]
# new_P:
# [[0.00815827+0.j]]
# likelihood is -688.7228935210617 on iteration 6
# new_angles=[0.69012505]
# new_P:
# [[0.00999511+0.j]]
# likelihood is -688.5214449450813 on iteration 7
# new_angles=[0.69204347]
# new_P:
# [[0.01230209+0.j]]
# likelihood is -688.2753040922795 on iteration 8
# new_angles=[0.69350742]
# new_P:
# [[0.01534263+0.j]]
# likelihood is -687.9619289110258 on iteration 9
# new_angles=[0.69467621]
# new_P:
# [[0.01957927+0.j]]
# likelihood is -687.5409828388607 on iteration 10
# new_angles=[0.69580933]
# new_P:
# [[0.02588813+0.j]]
# likelihood is -686.9412459092082 on iteration 11
# new_angles=[0.69659609]
# new_P:
# [[0.0360726+0.j]]
# likelihood is -686.038400461635 on iteration 12
# new_angles=[0.69728777]
# new_P:
# [[0.05418898+0.j]]
# likelihood is -684.5993062949785 on iteration 13
# new_angles=[0.69785827]
# new_P:
# [[0.09024207+0.j]]
# likelihood is -682.2499446886682 on iteration 14
# new_angles=[0.69832258]
# new_P:
# [[0.17001426+0.j]]
# likelihood is -678.7078408958378 on iteration 15
# new_angles=[0.69870769]
# new_P:
# [[0.35119986+0.j]]
# likelihood is -674.8920660372246 on iteration 16
# new_angles=[0.69903177]
# new_P:
# [[0.68876119+0.j]]
# likelihood is -673.1146316410103 on iteration 17
# new_angles=[0.69929883]
# new_P:
# [[1.07414879+0.j]]
# 5-th start
# theta=[0.70544346],P=[[1.7674577e-07+6.6174449e-25j]]
# new_angles=[0.70544346]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.4663031180482 on iteration 0
# new_angles=[0.70421826]
# new_P:
# [[0.00201027+0.j]]
# likelihood is -689.3524957407438 on iteration 1
# new_angles=[0.70421826]
# new_P:
# [[0.00305373+0.j]]
# likelihood is -689.236311625046 on iteration 2
# new_angles=[0.70336145]
# new_P:
# [[0.00415856+0.j]]
# likelihood is -689.1136968330367 on iteration 3
# new_angles=[0.70336145]
# new_P:
# [[0.00536142+0.j]]
# likelihood is -688.9820708224895 on iteration 4
# new_angles=[0.70283411]
# new_P:
# [[0.00671166+0.j]]
# likelihood is -688.8353575111425 on iteration 5
# new_angles=[0.70222788]
# new_P:
# [[0.00828022+0.j]]
# likelihood is -688.6669216020885 on iteration 6
# new_angles=[0.70215069]
# new_P:
# [[0.01017322+0.j]]
# likelihood is -688.4670586336221 on iteration 7
# new_angles=[0.70193128]
# new_P:
# [[0.01255758+0.j]]
# likelihood is -688.2196063890947 on iteration 8
# new_angles=[0.70193128]
# new_P:
# [[0.01571207+0.j]]
# likelihood is -687.899875319771 on iteration 9
# new_angles=[0.70164284]
# new_P:
# [[0.02013096+0.j]]
# likelihood is -687.4652875320064 on iteration 10
# new_angles=[0.70137796]
# new_P:
# [[0.02675782+0.j]]
# likelihood is -686.8420895316559 on iteration 11
# new_angles=[0.70130362]
# new_P:
# [[0.037548+0.j]]
# likelihood is -685.895261702682 on iteration 12
# new_angles=[0.70121351]
# new_P:
# [[0.05694672+0.j]]
# likelihood is -684.378945520582 on iteration 13
# new_angles=[0.701153]
# new_P:
# [[0.09599026+0.j]]
# likelihood is -681.9087167081082 on iteration 14
# new_angles=[0.70109291]
# new_P:
# [[0.18301114+0.j]]
# likelihood is -678.2614865056771 on iteration 15
# new_angles=[0.70103484]
# new_P:
# [[0.37886521+0.j]]
# likelihood is -674.559708364653 on iteration 16
# new_angles=[0.70098587]
# new_P:
# [[0.72929818+0.j]]
# likelihood is -673.0613297567572 on iteration 17
# new_angles=[0.70094779]
# new_P:
# [[1.10546373+0.j]]
# 6-th start
# theta=[0.72657557],P=[[7.35180779e-08+1.32348898e-24j]]
# new_angles=[0.72657557]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.4863069221292 on iteration 0
# new_angles=[0.72512741]
# new_P:
# [[0.00200845+0.j]]
# likelihood is -689.3891915322417 on iteration 1
# new_angles=[0.71992004]
# new_P:
# [[0.00304522+0.j]]
# likelihood is -689.271833453221 on iteration 2
# new_angles=[0.71473633]
# new_P:
# [[0.00414001+0.j]]
# likelihood is -689.1411276434001 on iteration 3
# new_angles=[0.71215322]
# new_P:
# [[0.00533168+0.j]]
# likelihood is -689.0067134098358 on iteration 4
# new_angles=[0.71051477]
# new_P:
# [[0.00666796+0.j]]
# likelihood is -688.8598169964998 on iteration 5
# new_angles=[0.70818871]
# new_P:
# [[0.00821766+0.j]]
# likelihood is -688.6877668549946 on iteration 6
# new_angles=[0.70707469]
# new_P:
# [[0.01008738+0.j]]
# likelihood is -688.4884442320263 on iteration 7
# new_angles=[0.70597075]
# new_P:
# [[0.01243848+0.j]]
# likelihood is -688.242147742046 on iteration 8
# new_angles=[0.7051692]
# new_P:
# [[0.01554319+0.j]]
# likelihood is -687.9257140042592 on iteration 9
# new_angles=[0.70450476]
# new_P:
# [[0.01988155+0.j]]
# likelihood is -687.497631364432 on iteration 10
# new_angles=[0.70386409]
# new_P:
# [[0.02636674+0.j]]
# likelihood is -686.8854102790489 on iteration 11
# new_angles=[0.70332465]
# new_P:
# [[0.03688516+0.j]]
# likelihood is -685.9579906844016 on iteration 12
# new_angles=[0.70293248]
# new_P:
# [[0.05570772+0.j]]
# likelihood is -684.4763071494672 on iteration 13
# new_angles=[0.70256709]
# new_P:
# [[0.09340413+0.j]]
# likelihood is -682.0594360445137 on iteration 14
# new_angles=[0.70228654]
# new_P:
# [[0.17716521+0.j]]
# likelihood is -678.4569797413005 on iteration 15
# new_angles=[0.70203844]
# new_P:
# [[0.36650155+0.j]]
# likelihood is -674.7014168789452 on iteration 16
# new_angles=[0.70182574]
# new_P:
# [[0.71147652+0.j]]
# likelihood is -673.0814840349896 on iteration 17
# new_angles=[0.70164923]
# new_P:
# [[1.0919415+0.j]]
# 7-th start
# theta=[0.7104521],P=[[1.73164662e-07-1.81979735e-24j]]
# new_angles=[0.7104521]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.4686980328167 on iteration 0
# new_angles=[0.71003748]
# new_P:
# [[0.00201005+0.j]]
# likelihood is -689.3574639882778 on iteration 1
# new_angles=[0.70835185]
# new_P:
# [[0.0030526+0.j]]
# likelihood is -689.2410599961667 on iteration 2
# new_angles=[0.70689238]
# new_P:
# [[0.00415608+0.j]]
# likelihood is -689.1182112178763 on iteration 3
# new_angles=[0.70567681]
# new_P:
# [[0.00535712+0.j]]
# likelihood is -688.9856143913001 on iteration 4
# new_angles=[0.70502763]
# new_P:
# [[0.00670534+0.j]]
# likelihood is -688.8390999581437 on iteration 5
# new_angles=[0.70424803]
# new_P:
# [[0.00827104+0.j]]
# likelihood is -688.6706001821921 on iteration 6
# new_angles=[0.7037172]
# new_P:
# [[0.01016016+0.j]]
# likelihood is -688.4706685005418 on iteration 7
# new_angles=[0.7031392]
# new_P:
# [[0.01253912+0.j]]
# likelihood is -688.2232282651088 on iteration 8
# new_angles=[0.70264358]
# new_P:
# [[0.01568572+0.j]]
# likelihood is -687.9035944910506 on iteration 9
# new_angles=[0.70234016]
# new_P:
# [[0.02009241+0.j]]
# likelihood is -687.4700855791176 on iteration 10
# new_angles=[0.70192372]
# new_P:
# [[0.02669761+0.j]]
# likelihood is -686.848391775901 on iteration 11
# new_angles=[0.70176371]
# new_P:
# [[0.03744654+0.j]]
# likelihood is -685.9045788944682 on iteration 12
# new_angles=[0.70160207]
# new_P:
# [[0.05675745+0.j]]
# likelihood is -684.3934847104451 on iteration 13
# new_angles=[0.70144226]
# new_P:
# [[0.09559557+0.j]]
# likelihood is -681.9311838124348 on iteration 14
# new_angles=[0.70131918]
# new_P:
# [[0.18212086+0.j]]
# likelihood is -678.290357218334 on iteration 15
# new_angles=[0.70122486]
# new_P:
# [[0.37699481+0.j]]
# likelihood is -674.5800873024073 on iteration 16
# new_angles=[0.7011471]
# new_P:
# [[0.72663834+0.j]]
# likelihood is -673.0636926159253 on iteration 17
# new_angles=[0.70108276]
# new_P:
# [[1.10347681+0.j]]
# 8-th start
# theta=[0.71429435],P=[[8.44135407e-08-3.72231276e-25j]]
# new_angles=[0.71429435]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.4716077369084 on iteration 0
# new_angles=[0.71429435]
# new_P:
# [[0.00200979+0.j]]
# likelihood is -689.3638396288362 on iteration 1
# new_angles=[0.71242425]
# new_P:
# [[0.00305119+0.j]]
# likelihood is -689.2490375064995 on iteration 2
# new_angles=[0.70996307]
# new_P:
# [[0.00415243+0.j]]
# likelihood is -689.1250295707141 on iteration 3
# new_angles=[0.70863292]
# new_P:
# [[0.00535074+0.j]]
# likelihood is -688.9929455002591 on iteration 4
# new_angles=[0.70711705]
# new_P:
# [[0.00669498+0.j]]
# likelihood is -688.8450794245641 on iteration 5
# new_angles=[0.70604032]
# new_P:
# [[0.00825609+0.j]]
# likelihood is -688.6764185169571 on iteration 6
# new_angles=[0.70514263]
# new_P:
# [[0.01013902+0.j]]
# likelihood is -688.4763173555768 on iteration 7
# new_angles=[0.70424803]
# new_P:
# [[0.01250943+0.j]]
# likelihood is -688.2288907227776 on iteration 8
# new_angles=[0.7036075]
# new_P:
# [[0.01564355+0.j]]
# likelihood is -687.910080806766 on iteration 9
# new_angles=[0.70304095]
# new_P:
# [[0.02003004+0.j]]
# likelihood is -687.4778025012431 on iteration 10
# new_angles=[0.7027685]
# new_P:
# [[0.02660034+0.j]]
# likelihood is -686.8594789954258 on iteration 11
# new_angles=[0.70243899]
# new_P:
# [[0.03728082+0.j]]
# likelihood is -685.9205237004523 on iteration 12
# new_angles=[0.70211917]
# new_P:
# [[0.05644648+0.j]]
# likelihood is -684.4178968946986 on iteration 13
# new_angles=[0.70191179]
# new_P:
# [[0.09494571+0.j]]
# likelihood is -681.969121043173 on iteration 14
# new_angles=[0.70171929]
# new_P:
# [[0.18065011+0.j]]
# likelihood is -678.3393725254657 on iteration 15
# new_angles=[0.70156119]
# new_P:
# [[0.37388897+0.j]]
# likelihood is -674.6153842588948 on iteration 16
# new_angles=[0.70142662]
# new_P:
# [[0.72218413+0.j]]
# likelihood is -673.0686913471407 on iteration 17
# new_angles=[0.7013148]
# new_P:
# [[1.10011537+0.j]]
# 9-th start
# theta=[0.6348336],P=[[1.11590995e-07-6.6174449e-25j]]
# new_angles=[0.6348336]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.5446987603111 on iteration 0
# new_angles=[0.638023]
# new_P:
# [[0.00200316+0.j]]
# likelihood is -689.5039980392538 on iteration 1
# new_angles=[0.64259728]
# new_P:
# [[0.00301908+0.j]]
# likelihood is -689.4503843453003 on iteration 2
# new_angles=[0.64694526]
# new_P:
# [[0.00406453+0.j]]
# likelihood is -689.3832372006414 on iteration 3
# new_angles=[0.65184985]
# new_P:
# [[0.00516416+0.j]]
# likelihood is -689.2944777917462 on iteration 4
# new_angles=[0.65670216]
# new_P:
# [[0.0063557+0.j]]
# likelihood is -689.1824981274281 on iteration 5
# new_angles=[0.66164366]
# new_P:
# [[0.00769288+0.j]]
# likelihood is -689.0406800042057 on iteration 6
# new_angles=[0.66660425]
# new_P:
# [[0.00925603+0.j]]
# likelihood is -688.862233175299 on iteration 7
# new_angles=[0.67093787]
# new_P:
# [[0.0111678+0.j]]
# likelihood is -688.6470371592706 on iteration 8
# new_angles=[0.67513153]
# new_P:
# [[0.01361458+0.j]]
# likelihood is -688.3732567376077 on iteration 9
# new_angles=[0.67875689]
# new_P:
# [[0.0169171+0.j]]
# likelihood is -688.0224961284232 on iteration 10
# new_angles=[0.68197415]
# new_P:
# [[0.02164197+0.j]]
# likelihood is -687.547168759668 on iteration 11
# new_angles=[0.68478349]
# new_P:
# [[0.02889287+0.j]]
# likelihood is -686.8651076507253 on iteration 12
# new_angles=[0.68721302]
# new_P:
# [[0.04100893+0.j]]
# likelihood is -685.8227125418658 on iteration 13
# new_angles=[0.68930358]
# new_P:
# [[0.06344603+0.j]]
# likelihood is -684.1411167258673 on iteration 14
# new_angles=[0.69110932]
# new_P:
# [[0.11005536+0.j]]
# likelihood is -681.4125046221508 on iteration 15
# new_angles=[0.69261239]
# new_P:
# [[0.2163191+0.j]]
# likelihood is -677.5735889021954 on iteration 16
# new_angles=[0.69388113]
# new_P:
# [[0.45141035+0.j]]
# likelihood is -674.2008632969734 on iteration 17
# new_angles=[0.69493989]
# new_P:
# [[0.83535828+0.j]]
# likelihood is -673.2833495509419 on iteration 18
# new_angles=[0.69583418]
# new_P:
# [[1.19477332+0.j]]
# 10-th start
# theta=[0.68408872],P=[[1.6429738e-07+0.j]]
# new_angles=[0.68408872]
# new_P:
# [[0.00100008+0.j]]
# likelihood is -689.474582365374 on iteration 0
# new_angles=[0.6887251]
# new_P:
# [[0.00200956+0.j]]
# likelihood is -689.3613672997803 on iteration 1
# new_angles=[0.68964245]
# new_P:
# [[0.00305139+0.j]]
# likelihood is -689.2477805302941 on iteration 2
# new_angles=[0.69182032]
# new_P:
# [[0.00415299+0.j]]
# likelihood is -689.1243429380796 on iteration 3
# new_angles=[0.69277102]
# new_P:
# [[0.00535158+0.j]]
# likelihood is -688.9932112188002 on iteration 4
# new_angles=[0.69438045]
# new_P:
# [[0.00669576+0.j]]
# likelihood is -688.8451060057558 on iteration 5
# new_angles=[0.69551405]
# new_P:
# [[0.00825694+0.j]]
# likelihood is -688.6762862365326 on iteration 6
# new_angles=[0.69641187]
# new_P:
# [[0.01014009+0.j]]
# likelihood is -688.4761669854765 on iteration 7
# new_angles=[0.6972352]
# new_P:
# [[0.01251081+0.j]]
# likelihood is -688.2289141607552 on iteration 8
# new_angles=[0.69785827]
# new_P:
# [[0.01564521+0.j]]
# likelihood is -687.9101324597322 on iteration 9
# new_angles=[0.69842862]
# new_P:
# [[0.02003209+0.j]]
# likelihood is -687.4778115525237 on iteration 10
# new_angles=[0.69882516]
# new_P:
# [[0.02660313+0.j]]
# likelihood is -686.8590496607475 on iteration 11
# new_angles=[0.69913995]
# new_P:
# [[0.03728586+0.j]]
# likelihood is -685.9199469555791 on iteration 12
# new_angles=[0.69943867]
# new_P:
# [[0.05645632+0.j]]
# likelihood is -684.4170749331103 on iteration 13
# new_angles=[0.69963921]
# new_P:
# [[0.09496675+0.j]]
# likelihood is -681.9678140365968 on iteration 14
# new_angles=[0.69984428]
# new_P:
# [[0.18069912+0.j]]
# likelihood is -678.3374343523358 on iteration 15
# new_angles=[0.69999683]
# new_P:
# [[0.37399873+0.j]]
# likelihood is -674.613609700642 on iteration 16
# new_angles=[0.70012137]
# new_P:
# [[0.72235911+0.j]]
# likelihood is -673.0678359228027 on iteration 17
# new_angles=[0.70021786]
# new_P:
# [[1.10027763+0.j]]
# 11-th start
# theta=[0.72251562],P=[[7.77089257e-08+6.6174449e-25j]]
# new_angles=[0.72251562]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.4806436166313 on iteration 0
# new_angles=[0.72223415]
# new_P:
# [[0.00200897+0.j]]
# likelihood is -689.3812773763428 on iteration 1
# new_angles=[0.71843057]
# new_P:
# [[0.00304718+0.j]]
# likelihood is -689.2664874372405 on iteration 2
# new_angles=[0.71843057]
# new_P:
# [[0.0041435+0.j]]
# likelihood is -689.1559496848805 on iteration 3
# new_angles=[0.71506634]
# new_P:
# [[0.00532986+0.j]]
# likelihood is -689.0196250872425 on iteration 4
# new_angles=[0.71248248]
# new_P:
# [[0.00665987+0.j]]
# likelihood is -688.8697047216601 on iteration 5
# new_angles=[0.71028573]
# new_P:
# [[0.00820293+0.j]]
# likelihood is -688.6987194178004 on iteration 6
# new_angles=[0.70866955]
# new_P:
# [[0.01006284+0.j]]
# likelihood is -688.4983394652115 on iteration 7
# new_angles=[0.70741834]
# new_P:
# [[0.01240116+0.j]]
# likelihood is -688.252782185598 on iteration 8
# new_angles=[0.70613416]
# new_P:
# [[0.01548653+0.j]]
# likelihood is -687.9360047265124 on iteration 9
# new_angles=[0.70524299]
# new_P:
# [[0.01979593+0.j]]
# likelihood is -687.5096493056978 on iteration 10
# new_angles=[0.7044263]
# new_P:
# [[0.02623133+0.j]]
# likelihood is -686.9008761591107 on iteration 11
# new_angles=[0.70381906]
# new_P:
# [[0.03665544+0.j]]
# likelihood is -685.9804069477677 on iteration 12
# new_angles=[0.70331243]
# new_P:
# [[0.05527806+0.j]]
# likelihood is -684.5105634456767 on iteration 13
# new_angles=[0.70288957]
# new_P:
# [[0.09250909+0.j]]
# likelihood is -682.1125747026036 on iteration 14
# new_angles=[0.70253299]
# new_P:
# [[0.17514154+0.j]]
# likelihood is -678.5262941732965 on iteration 15
# new_angles=[0.70224241]
# new_P:
# [[0.36219324+0.j]]
# likelihood is -674.7529937224227 on iteration 16
# new_angles=[0.70199758]
# new_P:
# [[0.70515717+0.j]]
# likelihood is -673.0896044244247 on iteration 17
# new_angles=[0.70179775]
# new_P:
# [[1.08705351+0.j]]
# 12-th start
# theta=[0.75041272],P=[[8.5918593e-08-5.29395592e-24j]]
# new_angles=[0.74043712]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -689.5095269303214 on iteration 0
# new_angles=[0.74043712]
# new_P:
# [[0.00200633+0.j]]
# likelihood is -689.4399948312425 on iteration 1
# new_angles=[0.72990407]
# new_P:
# [[0.00303386+0.j]]
# likelihood is -689.3151552316573 on iteration 2
# new_angles=[0.72178282]
# new_P:
# [[0.00411645+0.j]]
# likelihood is -689.1749016426674 on iteration 3
# new_angles=[0.71842119]
# new_P:
# [[0.00529443+0.j]]
# likelihood is -689.0409652105303 on iteration 4
# new_angles=[0.71482844]
# new_P:
# [[0.00661181+0.j]]
# likelihood is -688.8873738255428 on iteration 5
# new_angles=[0.71224511]
# new_P:
# [[0.00813983+0.j]]
# likelihood is -688.7159789210306 on iteration 6
# new_angles=[0.71067267]
# new_P:
# [[0.00997931+0.j]]
# likelihood is -688.518341329006 on iteration 7
# new_angles=[0.70869607]
# new_P:
# [[0.01228642+0.j]]
# likelihood is -688.2717495932652 on iteration 8
# new_angles=[0.70730906]
# new_P:
# [[0.01532747+0.j]]
# likelihood is -687.9586363268667 on iteration 9
# new_angles=[0.70623011]
# new_P:
# [[0.01956437+0.j]]
# likelihood is -687.5379706668846 on iteration 10
# new_angles=[0.70531107]
# new_P:
# [[0.02587304+0.j]]
# likelihood is -686.939495710099 on iteration 11
# new_angles=[0.70456843]
# new_P:
# [[0.03605442+0.j]]
# likelihood is -686.0367809583738 on iteration 12
# new_angles=[0.70392772]
# new_P:
# [[0.05416468+0.j]]
# likelihood is -684.597916605628 on iteration 13
# new_angles=[0.70341642]
# new_P:
# [[0.09020461+0.j]]
# likelihood is -682.248930743905 on iteration 14
# new_angles=[0.70298478]
# new_P:
# [[0.16994746+0.j]]
# likelihood is -678.7068148178804 on iteration 15
# new_angles=[0.70262893]
# new_P:
# [[0.35108028+0.j]]
# likelihood is -674.8905158639111 on iteration 16
# new_angles=[0.70232748]
# new_P:
# [[0.68859883+0.j]]
# likelihood is -673.1125989396106 on iteration 17
# new_angles=[0.70207382]
# new_P:
# [[1.07401135+0.j]]
# 13-th start
# theta=[0.76848612],P=[[8.39647801e-08+2.64697796e-24j]]
# new_angles=[0.76848612]
# new_P:
# [[0.00100001+0.j]]
# likelihood is -689.5567832264339 on iteration 0
# new_angles=[0.75136022]
# new_P:
# [[0.00200204+0.j]]
# likelihood is -689.4797632928689 on iteration 1
# new_angles=[0.74072197]
# new_P:
# [[0.00302232+0.j]]
# likelihood is -689.3719886484221 on iteration 2
# new_angles=[0.73110849]
# new_P:
# [[0.00408912+0.j]]
# likelihood is -689.2327841085103 on iteration 3
# new_angles=[0.72559043]
# new_P:
# [[0.00524456+0.j]]
# likelihood is -689.0932748876039 on iteration 4
# new_angles=[0.72065558]
# new_P:
# [[0.00653398+0.j]]
# likelihood is -688.9350534138083 on iteration 5
# new_angles=[0.71728491]
# new_P:
# [[0.00802692+0.j]]
# likelihood is -688.7630132437303 on iteration 6
# new_angles=[0.71426451]
# new_P:
# [[0.0098189+0.j]]
# likelihood is -688.5607674276042 on iteration 7
# new_angles=[0.71184925]
# new_P:
# [[0.01206354+0.j]]
# likelihood is -688.3172055894586 on iteration 8
# new_angles=[0.70991619]
# new_P:
# [[0.01501071+0.j]]
# likelihood is -688.0094680478621 on iteration 9
# new_angles=[0.70809857]
# new_P:
# [[0.01909801+0.j]]
# likelihood is -687.5971664931778 on iteration 10
# new_angles=[0.70683172]
# new_P:
# [[0.02515207+0.j]]
# likelihood is -687.0182033323028 on iteration 11
# new_angles=[0.70594423]
# new_P:
# [[0.03485127+0.j]]
# likelihood is -686.1519969803066 on iteration 12
# new_angles=[0.70504829]
# new_P:
# [[0.0519474+0.j]]
# likelihood is -684.7753393658859 on iteration 13
# new_angles=[0.70433589]
# new_P:
# [[0.08564184+0.j]]
# likelihood is -682.5261037251435 on iteration 14
# new_angles=[0.70374772]
# new_P:
# [[0.15968375+0.j]]
# likelihood is -679.0809464602073 on iteration 15
# new_angles=[0.70326629]
# new_P:
# [[0.32884746+0.j]]
# likelihood is -675.1913045039704 on iteration 16
# new_angles=[0.7028488]
# new_P:
# [[0.65426421+0.j]]
# likelihood is -673.1725581591895 on iteration 17
# new_angles=[0.70250954]
# new_P:
# [[1.04578546+0.j]]
# 14-th start
# theta=[0.73864851],P=[[5.87367942e-08-3.30872245e-24j]]
# new_angles=[0.73864851]
# new_P:
# [[0.00100003+0.j]]
# likelihood is -689.5063149461322 on iteration 0
# new_angles=[0.73864851]
# new_P:
# [[0.00200663+0.j]]
# likelihood is -689.4335546225536 on iteration 1
# new_angles=[0.73139845]
# new_P:
# [[0.00303533+0.j]]
# likelihood is -689.3223024223693 on iteration 2
# new_angles=[0.72329812]
# new_P:
# [[0.00411602+0.j]]
# likelihood is -689.1830059145184 on iteration 3
# new_angles=[0.71871485]
# new_P:
# [[0.00529099+0.j]]
# likelihood is -689.043007424659 on iteration 4
# new_angles=[0.71582458]
# new_P:
# [[0.00660717+0.j]]
# likelihood is -688.8938633469512 on iteration 5
# new_angles=[0.71321926]
# new_P:
# [[0.00813094+0.j]]
# likelihood is -688.7229086007326 on iteration 6
# new_angles=[0.71117988]
# new_P:
# [[0.00996433+0.j]]
# likelihood is -688.5231387920586 on iteration 7
# new_angles=[0.70894483]
# new_P:
# [[0.01226483+0.j]]
# likelihood is -688.2754983599134 on iteration 8
# new_angles=[0.70763937]
# new_P:
# [[0.01529739+0.j]]
# likelihood is -687.9637658931315 on iteration 9
# new_angles=[0.70644546]
# new_P:
# [[0.01951955+0.j]]
# likelihood is -687.5437463202347 on iteration 10
# new_angles=[0.70546779]
# new_P:
# [[0.02580336+0.j]]
# likelihood is -686.9470285772852 on iteration 11
# new_angles=[0.70465936]
# new_P:
# [[0.03593782+0.j]]
# likelihood is -686.0474090107409 on iteration 12
# new_angles=[0.70399368]
# new_P:
# [[0.05395027+0.j]]
# likelihood is -684.6144088142528 on iteration 13
# new_angles=[0.70344742]
# new_P:
# [[0.08976375+0.j]]
# likelihood is -682.2745118842398 on iteration 14
# new_angles=[0.70301731]
# new_P:
# [[0.16895929+0.j]]
# likelihood is -678.7410698967167 on iteration 15
# new_angles=[0.70264019]
# new_P:
# [[0.34896248+0.j]]
# likelihood is -674.9165682433294 on iteration 16
# new_angles=[0.70232932]
# new_P:
# [[0.68541384+0.j]]
# likelihood is -673.1163125055989 on iteration 17
# new_angles=[0.70207161]
# new_P:
# [[1.07148191+0.j]]
# 15-th start
# theta=[0.68749862],P=[[1.6917191e-07+2.64697796e-24j]]
# new_angles=[0.68749862]
# new_P:
# [[0.00100008+0.j]]
# likelihood is -689.4713567101921 on iteration 0
# new_angles=[0.68759545]
# new_P:
# [[0.00200985+0.j]]
# likelihood is -689.36317284399 on iteration 1
# new_angles=[0.68915803]
# new_P:
# [[0.00305136+0.j]]
# likelihood is -689.248867082987 on iteration 2
# new_angles=[0.69023544]
# new_P:
# [[0.00415266+0.j]]
# likelihood is -689.1285345446246 on iteration 3
# new_angles=[0.69236798]
# new_P:
# [[0.00534968+0.j]]
# likelihood is -688.9945655169321 on iteration 4
# new_angles=[0.69390125]
# new_P:
# [[0.00669307+0.j]]
# likelihood is -688.8467788590474 on iteration 5
# new_angles=[0.69513644]
# new_P:
# [[0.00825299+0.j]]
# likelihood is -688.6778081065229 on iteration 6
# new_angles=[0.696085]
# new_P:
# [[0.01013451+0.j]]
# likelihood is -688.4777188315311 on iteration 7
# new_angles=[0.69703625]
# new_P:
# [[0.01250293+0.j]]
# likelihood is -688.2303032215426 on iteration 8
# new_angles=[0.69764897]
# new_P:
# [[0.01563414+0.j]]
# likelihood is -687.9118671302314 on iteration 9
# new_angles=[0.69812932]
# new_P:
# [[0.02001569+0.j]]
# likelihood is -687.4803313367114 on iteration 10
# new_angles=[0.69851692]
# new_P:
# [[0.02657674+0.j]]
# likelihood is -686.8625218360895 on iteration 11
# new_angles=[0.69885558]
# new_P:
# [[0.03723993+0.j]]
# likelihood is -685.9249273760415 on iteration 12
# new_angles=[0.69917452]
# new_P:
# [[0.05636857+0.j]]
# likelihood is -684.4246806381594 on iteration 13
# new_angles=[0.6994426]
# new_P:
# [[0.09478055+0.j]]
# likelihood is -681.9792612327655 on iteration 14
# new_angles=[0.69964536]
# new_P:
# [[0.18027447+0.j]]
# likelihood is -678.3524740239991 on iteration 15
# new_angles=[0.69982273]
# new_P:
# [[0.37309326+0.j]]
# likelihood is -674.624851261124 on iteration 16
# new_angles=[0.69997107]
# new_P:
# [[0.72104521+0.j]]
# likelihood is -673.0701036899152 on iteration 17
# new_angles=[0.70009077]
# new_P:
# [[1.09927206+0.j]]
# 16-th start
# theta=[0.65346953],P=[[9.37792273e-08+6.6174449e-24j]]
# new_angles=[0.65346953]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.5204833069567 on iteration 0
# new_angles=[0.65841811]
# new_P:
# [[0.00200537+0.j]]
# likelihood is -689.445918243876 on iteration 1
# new_angles=[0.66516314]
# new_P:
# [[0.00303182+0.j]]
# likelihood is -689.3449814140226 on iteration 2
# new_angles=[0.66981706]
# new_P:
# [[0.00410622+0.j]]
# likelihood is -689.2329744911308 on iteration 3
# new_angles=[0.67480983]
# new_P:
# [[0.00526237+0.j]]
# likelihood is -689.0986187735714 on iteration 4
# new_angles=[0.67893606]
# new_P:
# [[0.00655046+0.j]]
# likelihood is -688.9481684702428 on iteration 5
# new_angles=[0.68236669]
# new_P:
# [[0.00803731+0.j]]
# likelihood is -688.77741013013 on iteration 6
# new_angles=[0.68508207]
# new_P:
# [[0.00982036+0.j]]
# likelihood is -688.579586182417 on iteration 7
# new_angles=[0.68757384]
# new_P:
# [[0.01204907+0.j]]
# likelihood is -688.337642946959 on iteration 8
# new_angles=[0.68946922]
# new_P:
# [[0.01497194+0.j]]
# likelihood is -688.0336293855638 on iteration 9
# new_angles=[0.6913692]
# new_P:
# [[0.01901813+0.j]]
# likelihood is -687.6251255814858 on iteration 10
# new_angles=[0.69292048]
# new_P:
# [[0.02500055+0.j]]
# likelihood is -687.050985760472 on iteration 11
# new_angles=[0.69419042]
# new_P:
# [[0.03456635+0.j]]
# likelihood is -686.1931222539437 on iteration 12
# new_angles=[0.69519068]
# new_P:
# [[0.05138801+0.j]]
# likelihood is -684.8357470469246 on iteration 13
# new_angles=[0.69610709]
# new_P:
# [[0.08443948+0.j]]
# likelihood is -682.6163006423985 on iteration 14
# new_angles=[0.6968691]
# new_P:
# [[0.15689793+0.j]]
# likelihood is -679.2031551042747 on iteration 15
# new_angles=[0.69748569]
# new_P:
# [[0.32261639+0.j]]
# likelihood is -675.2989911006908 on iteration 16
# new_angles=[0.69800342]
# new_P:
# [[0.64415594+0.j]]
# likelihood is -673.2088839336936 on iteration 17
# new_angles=[0.69843467]
# new_P:
# [[1.03696677+0.j]]
# 17-th start
# theta=[0.69944808],P=[[1.77772732e-07+6.6174449e-24j]]
# new_angles=[0.69944808]
# new_P:
# [[0.00100006+0.j]]
# likelihood is -689.4656264602315 on iteration 0
# new_angles=[0.69944808]
# new_P:
# [[0.00201035+0.j]]
# likelihood is -689.3518048351036 on iteration 1
# new_angles=[0.69944808]
# new_P:
# [[0.00305394+0.j]]
# likelihood is -689.235256331019 on iteration 2
# new_angles=[0.69944808]
# new_P:
# [[0.00415906+0.j]]
# likelihood is -689.1129565562354 on iteration 3
# new_angles=[0.69957642]
# new_P:
# [[0.00536222+0.j]]
# likelihood is -688.981045997795 on iteration 4
# new_angles=[0.69957642]
# new_P:
# [[0.00671301+0.j]]
# likelihood is -688.8345869122909 on iteration 5
# new_angles=[0.69985441]
# new_P:
# [[0.00828217+0.j]]
# likelihood is -688.6663673827474 on iteration 6
# new_angles=[0.69985441]
# new_P:
# [[0.01017583+0.j]]
# likelihood is -688.466434315276 on iteration 7
# new_angles=[0.70013869]
# new_P:
# [[0.01256119+0.j]]
# likelihood is -688.2188531864348 on iteration 8
# new_angles=[0.70027611]
# new_P:
# [[0.01571727+0.j]]
# likelihood is -687.898802583461 on iteration 9
# new_angles=[0.70040568]
# new_P:
# [[0.02013903+0.j]]
# likelihood is -687.4641111919626 on iteration 10
# new_angles=[0.70044262]
# new_P:
# [[0.02677073+0.j]]
# likelihood is -686.8406919452432 on iteration 11
# new_angles=[0.70044262]
# new_P:
# [[0.03756988+0.j]]
# likelihood is -685.8932219690516 on iteration 12
# new_angles=[0.70046589]
# new_P:
# [[0.05698768+0.j]]
# likelihood is -684.3757991442502 on iteration 13
# new_angles=[0.70052787]
# new_P:
# [[0.09607578+0.j]]
# likelihood is -681.9037826429613 on iteration 14
# new_angles=[0.70056061]
# new_P:
# [[0.18320477+0.j]]
# likelihood is -678.2551072831785 on iteration 15
# new_angles=[0.70058231]
# new_P:
# [[0.37927366+0.j]]
# likelihood is -674.5551380843112 on iteration 16
# new_angles=[0.70060963]
# new_P:
# [[0.72988232+0.j]]
# likelihood is -673.0606479698669 on iteration 17
# new_angles=[0.70062959]
# new_P:
# [[1.10590682+0.j]]
# 18-th start
# theta=[0.74249062],P=[[1.07227531e-07+3.30872245e-24j]]
# new_angles=[0.73751578]
# new_P:
# [[0.00100001+0.j]]
# likelihood is -689.5043029104642 on iteration 0
# new_angles=[0.72641895]
# new_P:
# [[0.0020068+0.j]]
# likelihood is -689.3930813746887 on iteration 1
# new_angles=[0.72120566]
# new_P:
# [[0.00304283+0.j]]
# likelihood is -689.2767837151769 on iteration 2
# new_angles=[0.71833834]
# new_P:
# [[0.00413618+0.j]]
# likelihood is -689.1562687786881 on iteration 3
# new_angles=[0.71573256]
# new_P:
# [[0.00532204+0.j]]
# likelihood is -689.0236986132068 on iteration 4
# new_angles=[0.71288809]
# new_P:
# [[0.00664956+0.j]]
# likelihood is -688.8728257535678 on iteration 5
# new_angles=[0.71084167]
# new_P:
# [[0.00818977+0.j]]
# likelihood is -688.7029482550782 on iteration 6
# new_angles=[0.70902221]
# new_P:
# [[0.01004495+0.j]]
# likelihood is -688.5020203424074 on iteration 7
# new_angles=[0.70756235]
# new_P:
# [[0.01237709+0.j]]
# likelihood is -688.2559929223256 on iteration 8
# new_angles=[0.70631188]
# new_P:
# [[0.01545395+0.j]]
# likelihood is -687.9401963860045 on iteration 9
# new_angles=[0.70529027]
# new_P:
# [[0.01974903+0.j]]
# likelihood is -687.5144269267835 on iteration 10
# new_angles=[0.70449239]
# new_P:
# [[0.02616025+0.j]]
# likelihood is -686.9077775858811 on iteration 11
# new_angles=[0.70385172]
# new_P:
# [[0.03653763+0.j]]
# likelihood is -685.9905766488741 on iteration 12
# new_angles=[0.70328736]
# new_P:
# [[0.05506191+0.j]]
# likelihood is -684.5262357774509 on iteration 13
# new_angles=[0.70288475]
# new_P:
# [[0.09206599+0.j]]
# likelihood is -682.137481005421 on iteration 14
# new_angles=[0.70252676]
# new_P:
# [[0.1741494+0.j]]
# likelihood is -678.5590595174538 on iteration 15
# new_angles=[0.70224752]
# new_P:
# [[0.36009008+0.j]]
# likelihood is -674.777222969392 on iteration 16
# new_angles=[0.70200769]
# new_P:
# [[0.70206995+0.j]]
# likelihood is -673.0926345501038 on iteration 17
# new_angles=[0.70180787]
# new_P:
# [[1.08466617+0.j]]
# 19-th start
# theta=[0.78572482],P=[[4.92090995e-08+5.29395592e-24j]]
# new_angles=[0.78572482]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -689.5752533619083 on iteration 0
# new_angles=[0.76743087]
# new_P:
# [[0.00200038+0.j]]
# likelihood is -689.531670773512 on iteration 1
# new_angles=[0.7600768]
# new_P:
# [[0.00301127+0.j]]
# likelihood is -689.4748216881 on iteration 2
# new_angles=[0.75016345]
# new_P:
# [[0.00404995+0.j]]
# likelihood is -689.3714448239907 on iteration 3
# new_angles=[0.74140839]
# new_P:
# [[0.00515337+0.j]]
# likelihood is -689.2355746689578 on iteration 4
# new_angles=[0.73349227]
# new_P:
# [[0.00637141+0.j]]
# likelihood is -689.0695222958725 on iteration 5
# new_angles=[0.72759106]
# new_P:
# [[0.00777352+0.j]]
# likelihood is -688.889146820811 on iteration 6
# new_angles=[0.72252928]
# new_P:
# [[0.00944834+0.j]]
# likelihood is -688.680845391195 on iteration 7
# new_angles=[0.71842947]
# new_P:
# [[0.01153532+0.j]]
# likelihood is -688.4370334421765 on iteration 8
# new_angles=[0.71520678]
# new_P:
# [[0.01425577+0.j]]
# likelihood is -688.1390265654362 on iteration 9
# new_angles=[0.71262262]
# new_P:
# [[0.01798929+0.j]]
# likelihood is -687.7522570229011 on iteration 10
# new_angles=[0.71049106]
# new_P:
# [[0.02343886+0.j]]
# likelihood is -687.2178720795429 on iteration 11
# new_angles=[0.70874157]
# new_P:
# [[0.03201307+0.j]]
# likelihood is -686.4316763748806 on iteration 12
# new_angles=[0.7073613]
# new_P:
# [[0.04679644+0.j]]
# likelihood is -685.202514354592 on iteration 13
# new_angles=[0.70622115]
# new_P:
# [[0.07520855+0.j]]
# likelihood is -683.1964809563602 on iteration 14
# new_angles=[0.705291]
# new_P:
# [[0.13638922+0.j]]
# likelihood is -680.0246999239675 on iteration 15
# new_angles=[0.70456374]
# new_P:
# [[0.27717363+0.j]]
# likelihood is -676.0477438715794 on iteration 16
# new_angles=[0.70394377]
# new_P:
# [[0.5677878+0.j]]
# likelihood is -673.4194436913062 on iteration 17
# new_angles=[0.70342609]
# new_P:
# [[0.96659508+0.j]]
# likelihood is -673.2266694888947 on iteration 18
# new_angles=[0.7029938]
# new_P:
# [[1.27372566+0.j]]
# best_start=17

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.70060963]), array([[0.72988232+0.j]]))

# %%
em_stoch.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q_2), em_stoch.incomplete_lkhd(X2_with_mv, theta2_rad, P_2, Q_2)
# Out:
# (np.float64(-673.0606479698669), np.float64(-673.6467390084401))
