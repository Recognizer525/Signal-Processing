# %%
import numpy as np

import sensors as sn
import em_tools as em
import subspace_methods as sm

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12

failing_sensors1 = np.arange(5)
gap_ratio1 = 0.5 * np.ones_like(failing_sensors1, dtype=np.float32)

theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sn.gss(Num_emitters1, sample_size1, P1)
N1 = sn.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sn.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sn.initial_Cov(X1_with_mv)
MUSIC_theta1 = sm.MUSIC_DoA(R1, Num_emitters1)

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sn.SNR(A1, P1, Q1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1, lhd_list1, angles_list1 = em.multistart_EM2(X1_with_mv, 
                                                                         Num_emitters1, 
                                                                         Q=Q1,
                                                                         theta_guess=MUSIC_theta1, 
                                                                         num_of_starts=10, 
                                                                         max_iter=20, 
                                                                         rtol=1e-6,
                                                                         reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.71558499],P=[[1.18642836e-07-1.98523347e-24j]]
# Iteration=0
# likelihood is -870.3909570216754 on iteration 0.
# Iteration=1
# likelihood is -870.3814469960676 on iteration 1.
# Iteration=2
# likelihood is -870.3718879745038 on iteration 2.
# Iteration=3
# likelihood is -870.3599271548069 on iteration 3.
# Iteration=4
# likelihood is -870.3495571065747 on iteration 4.
# Iteration=5
# likelihood is -870.3389961994174 on iteration 5.
# Iteration=6
# likelihood is -870.3259350663559 on iteration 6.
# Iteration=7
# likelihood is -870.3138719805875 on iteration 7.
# Iteration=8
# likelihood is -870.3013999859351 on iteration 8.
# Iteration=9
# likelihood is -870.2884840541122 on iteration 9.
# Iteration=10
# likelihood is -870.2753401616369 on iteration 10.
# Iteration=11
# likelihood is -870.2614988339282 on iteration 11.
# Iteration=12
# likelihood is -870.2468265149835 on iteration 12.
# Iteration=13
# likelihood is -870.231163762605 on iteration 13.
# Iteration=14
# likelihood is -870.2143180299817 on iteration 14.
# Iteration=15
# likelihood is -870.1960540039953 on iteration 15.
# Iteration=16
# likelihood is -870.1760804821286 on iteration 16.
# Iteration=17
# likelihood is -870.154032262283 on iteration 17.
# Iteration=18
# likelihood is -870.1294447124217 on iteration 18.
# Iteration=19
# likelihood is -870.1017173720213 on iteration 19.
# 1-th start
# theta=[0.75761751],P=[[7.62531873e-08-2.64697796e-24j]]
# Iteration=0
# likelihood is -870.3977092205137 on iteration 0.
# Iteration=1
# likelihood is -870.3945151008795 on iteration 1.
# Iteration=2
# likelihood is -870.3913152175655 on iteration 2.
# Iteration=3
# likelihood is -870.3881033904768 on iteration 3.
# Iteration=4
# likelihood is -870.3848727882236 on iteration 4.
# Iteration=5
# likelihood is -870.3801100841266 on iteration 5.
# Iteration=6
# likelihood is -870.3747512787047 on iteration 6.
# Iteration=7
# likelihood is -870.3687553549003 on iteration 7.
# Iteration=8
# likelihood is -870.3426561956107 on iteration 8.
# Iteration=9
# likelihood is -870.3249501373664 on iteration 9.
# Iteration=10
# likelihood is -870.3053368454938 on iteration 10.
# Iteration=11
# likelihood is -870.2843792248761 on iteration 11.
# Iteration=12
# likelihood is -870.2642955878779 on iteration 12.
# Iteration=13
# likelihood is -870.2451030805022 on iteration 13.
# Iteration=14
# likelihood is -870.2275603260886 on iteration 14.
# Iteration=15
# likelihood is -870.2086156579652 on iteration 15.
# Iteration=16
# likelihood is -870.1880402441063 on iteration 16.
# Iteration=17
# likelihood is -870.1655439397011 on iteration 17.
# Iteration=18
# likelihood is -870.1407552614264 on iteration 18.
# Iteration=19
# likelihood is -870.113617759376 on iteration 19.
# 2-th start
# theta=[0.75275765],P=[[9.44715207e-08-1.12496563e-23j]]
# Iteration=0
# likelihood is -870.3968224833759 on iteration 0.
# Iteration=1
# likelihood is -870.3929144529621 on iteration 1.
# Iteration=2
# likelihood is -870.3889974839025 on iteration 2.
# Iteration=3
# likelihood is -870.3850630652618 on iteration 3.
# Iteration=4
# likelihood is -870.3759401820281 on iteration 4.
# Iteration=5
# likelihood is -870.3644724091179 on iteration 5.
# Iteration=6
# likelihood is -870.350781430949 on iteration 6.
# Iteration=7
# likelihood is -870.3351587608753 on iteration 7.
# Iteration=8
# likelihood is -870.3180574770835 on iteration 8.
# Iteration=9
# likelihood is -870.3013264975198 on iteration 9.
# Iteration=10
# likelihood is -870.2852182111013 on iteration 10.
# Iteration=11
# likelihood is -870.268469972589 on iteration 11.
# Iteration=12
# likelihood is -870.2529903734442 on iteration 12.
# Iteration=13
# likelihood is -870.2365000305798 on iteration 13.
# Iteration=14
# likelihood is -870.2188565690118 on iteration 14.
# Iteration=15
# likelihood is -870.1998819719327 on iteration 15.
# Iteration=16
# likelihood is -870.1793522816637 on iteration 16.
# Iteration=17
# likelihood is -870.1576423432152 on iteration 17.
# Iteration=18
# likelihood is -870.133466031804 on iteration 18.
# Iteration=19
# likelihood is -870.1062444520184 on iteration 19.
# 3-th start
# theta=[0.82383174],P=[[9.765625e-08+0.j]]
# Iteration=0
# Likelihood is converged!
# 4-th start
# theta=[0.72131738],P=[[1.09961713e-07-2.97785021e-24j]]
# Iteration=0
# likelihood is -870.3942347896451 on iteration 0.
# Iteration=1
# likelihood is -870.3877997069226 on iteration 1.
# Iteration=2
# likelihood is -870.3813414456832 on iteration 2.
# Iteration=3
# likelihood is -870.3706983295732 on iteration 3.
# Iteration=4
# likelihood is -870.3582999399575 on iteration 4.
# Iteration=5
# likelihood is -870.3445722796072 on iteration 5.
# Iteration=6
# likelihood is -870.330819999082 on iteration 6.
# Iteration=7
# likelihood is -870.3166325496438 on iteration 7.
# Iteration=8
# likelihood is -870.3040445399181 on iteration 8.
# Iteration=9
# likelihood is -870.2908993585675 on iteration 9.
# Iteration=10
# likelihood is -870.2771446633832 on iteration 10.
# Iteration=11
# likelihood is -870.2627151396262 on iteration 11.
# Iteration=12
# likelihood is -870.2475295960394 on iteration 12.
# Iteration=13
# likelihood is -870.2319216273828 on iteration 13.
# Iteration=14
# likelihood is -870.2151395480935 on iteration 14.
# Iteration=15
# likelihood is -870.1969500421327 on iteration 15.
# Iteration=16
# likelihood is -870.1770645139782 on iteration 16.
# Iteration=17
# likelihood is -870.1551212130036 on iteration 17.
# Iteration=18
# likelihood is -870.1306601491239 on iteration 18.
# Iteration=19
# likelihood is -870.1030872157562 on iteration 19.
# 5-th start
# theta=[0.69420695],P=[[2.63712642e-07-3.97046694e-24j]]
# Iteration=0
# likelihood is -870.3882718527846 on iteration 0.
# Iteration=1
# likelihood is -870.3777014681383 on iteration 1.
# Iteration=2
# likelihood is -870.3670653074641 on iteration 2.
# Iteration=3
# likelihood is -870.3563176081793 on iteration 3.
# Iteration=4
# likelihood is -870.3454091209795 on iteration 4.
# Iteration=5
# likelihood is -870.334286164781 on iteration 5.
# Iteration=6
# likelihood is -870.3228894964695 on iteration 6.
# Iteration=7
# likelihood is -870.3111529399727 on iteration 7.
# Iteration=8
# likelihood is -870.2990017015914 on iteration 8.
# Iteration=9
# likelihood is -870.2863502741037 on iteration 9.
# Iteration=10
# likelihood is -870.273099797964 on iteration 10.
# Iteration=11
# likelihood is -870.259134699485 on iteration 11.
# Iteration=12
# likelihood is -870.2443183563486 on iteration 12.
# Iteration=13
# likelihood is -870.2284874396242 on iteration 13.
# Iteration=14
# likelihood is -870.2114444319537 on iteration 14.
# Iteration=15
# likelihood is -870.1929475969325 on iteration 15.
# Iteration=16
# likelihood is -870.1726973310602 on iteration 16.
# Iteration=17
# likelihood is -870.1503172933448 on iteration 17.
# Iteration=18
# likelihood is -870.1253278524221 on iteration 18.
# Iteration=19
# likelihood is -870.0971079943116 on iteration 19.
# 6-th start
# theta=[0.72207198],P=[[1.08695785e-07+1.65436123e-24j]]
# Iteration=0
# likelihood is -870.3943702840432 on iteration 0.
# Iteration=1
# likelihood is -870.3880611169825 on iteration 1.
# Iteration=2
# likelihood is -870.3817296429928 on iteration 2.
# Iteration=3
# likelihood is -870.3711896433381 on iteration 3.
# Iteration=4
# likelihood is -870.358855409158 on iteration 4.
# Iteration=5
# likelihood is -870.3451385773012 on iteration 5.
# Iteration=6
# likelihood is -870.3313626658412 on iteration 6.
# Iteration=7
# likelihood is -870.317097481001 on iteration 7.
# Iteration=8
# likelihood is -870.3045116062028 on iteration 8.
# Iteration=9
# likelihood is -870.2913542296068 on iteration 9.
# Iteration=10
# likelihood is -870.2775719913571 on iteration 10.
# Iteration=11
# likelihood is -870.2630983341692 on iteration 11.
# Iteration=12
# likelihood is -870.2478505354792 on iteration 12.
# Iteration=13
# likelihood is -870.2317258558844 on iteration 13.
# Iteration=14
# likelihood is -870.2149177138672 on iteration 14.
# Iteration=15
# likelihood is -870.1966995870004 on iteration 15.
# Iteration=16
# likelihood is -870.1767822751664 on iteration 16.
# Iteration=17
# likelihood is -870.1548032489144 on iteration 17.
# Iteration=18
# likelihood is -870.1303014975083 on iteration 18.
# Iteration=19
# likelihood is -870.1026815516982 on iteration 19.
# 7-th start
# theta=[0.83118872],P=[[9.765625e-08+0.j]]
# Iteration=0
# Likelihood is converged!
# 8-th start
# theta=[0.85933204],P=[[9.765625e-08+0.j]]
# Iteration=0
# Likelihood is converged!
# 9-th start
# theta=[0.73719288],P=[[7.93250092e-08-4.63221143e-24j]]
# Iteration=0
# likelihood is -870.3943501451865 on iteration 0.
# Iteration=1
# likelihood is -870.3879261062261 on iteration 1.
# Iteration=2
# likelihood is -870.3814792545307 on iteration 2.
# Iteration=3
# likelihood is -870.3708623326942 on iteration 3.
# Iteration=4
# likelihood is -870.3584863150229 on iteration 4.
# Iteration=5
# likelihood is -870.3447754942285 on iteration 5.
# Iteration=6
# likelihood is -870.3310339354947 on iteration 6.
# Iteration=7
# likelihood is -870.3168517954066 on iteration 7.
# Iteration=8
# likelihood is -870.3042719616935 on iteration 8.
# Iteration=9
# likelihood is -870.2911348393934 on iteration 9.
# Iteration=10
# likelihood is -870.2773881922706 on iteration 10.
# Iteration=11
# likelihood is -870.2629668341165 on iteration 11.
# Iteration=12
# likelihood is -870.247789731311 on iteration 12.
# Iteration=13
# likelihood is -870.2322001117399 on iteration 13.
# Iteration=14
# likelihood is -870.2154396651223 on iteration 14.
# Iteration=15
# likelihood is -870.1972758118962 on iteration 15.
# Iteration=16
# likelihood is -870.1774209207581 on iteration 16.
# Iteration=17
# likelihood is -870.1555145209093 on iteration 17.
# Iteration=18
# likelihood is -870.1310983474552 on iteration 18.
# Iteration=19
# likelihood is -870.1035806600944 on iteration 19.
# best_start=5

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.69420695]), array([[0.00290927+0.j]]))

# %%
em.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q1), em.incomplete_lkhd(X1_with_mv, theta1_rad, P1, Q1)
# Out:
# (np.float64(-870.0971079943116), np.float64(-852.4011191641745))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11

failing_sensors2 = np.arange(8)
gap_ratio2 = 0.5 * np.ones_like(failing_sensors2, dtype=np.float32)

theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sn.gss(Num_emitters2, sample_size2, P2)
N2 = sn.gss(Num_sensors2, sample_size2, Q2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sn.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sn.initial_Cov(X2_with_mv)
MUSIC_theta2 = sm.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sn.SNR(A2, P2, Q2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2, lhd_list2, angles_list2 = em.multistart_EM2(X2_with_mv, 
                                                                         Num_emitters2, 
                                                                         Q=Q2,
                                                                         theta_guess=MUSIC_theta2, 
                                                                         num_of_starts=20, 
                                                                         max_iter=20, 
                                                                         rtol=1e-6,
                                                                         reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.72431164],P=[[7.5917774e-08+4.13590306e-24j]]
# Iteration=0
# likelihood is -689.5691426530494 on iteration 0.
# Iteration=1
# likelihood is -689.559471069902 on iteration 1.
# Iteration=2
# likelihood is -689.547368542294 on iteration 2.
# Iteration=3
# likelihood is -689.5344206660517 on iteration 3.
# Iteration=4
# likelihood is -689.5229973752716 on iteration 4.
# Iteration=5
# likelihood is -689.5113029767524 on iteration 5.
# Iteration=6
# likelihood is -689.4984381855377 on iteration 6.
# Iteration=7
# likelihood is -689.4850034148457 on iteration 7.
# Iteration=8
# likelihood is -689.4709289727629 on iteration 8.
# Iteration=9
# likelihood is -689.456208714154 on iteration 9.
# Iteration=10
# likelihood is -689.4410772514203 on iteration 10.
# Iteration=11
# likelihood is -689.4248467612551 on iteration 11.
# Iteration=12
# likelihood is -689.4072672592796 on iteration 12.
# Iteration=13
# likelihood is -689.3880254837283 on iteration 13.
# Iteration=14
# likelihood is -689.3667225303005 on iteration 14.
# Iteration=15
# likelihood is -689.3428416166741 on iteration 15.
# Iteration=16
# likelihood is -689.3157005782374 on iteration 16.
# Iteration=17
# likelihood is -689.2843801066002 on iteration 17.
# Iteration=18
# likelihood is -689.2476122806393 on iteration 18.
# Iteration=19
# likelihood is -689.203601863871 on iteration 19.
# 1-th start
# theta=[0.76634416],P=[[4.65993421e-08-2.64697796e-24j]]
# Iteration=0
# likelihood is -689.576630918838 on iteration 0.
# Iteration=1
# likelihood is -689.574068543121 on iteration 1.
# Iteration=2
# likelihood is -689.5715023772061 on iteration 2.
# Iteration=3
# likelihood is -689.5689267141796 on iteration 3.
# Iteration=4
# likelihood is -689.565047252586 on iteration 4.
# Iteration=5
# likelihood is -689.5605668434605 on iteration 5.
# Iteration=6
# likelihood is -689.5554389947742 on iteration 6.
# Iteration=7
# likelihood is -689.5447346433664 on iteration 7.
# Iteration=8
# likelihood is -689.5315382465826 on iteration 8.
# Iteration=9
# likelihood is -689.51576064152 on iteration 9.
# Iteration=10
# likelihood is -689.4973790972033 on iteration 10.
# Iteration=11
# likelihood is -689.4764347670591 on iteration 11.
# Iteration=12
# likelihood is -689.4558444985308 on iteration 12.
# Iteration=13
# likelihood is -689.4301237927247 on iteration 13.
# Iteration=14
# likelihood is -689.4021466857623 on iteration 14.
# Iteration=15
# likelihood is -689.3744188720601 on iteration 15.
# Iteration=16
# likelihood is -689.3440251617797 on iteration 16.
# Iteration=17
# likelihood is -689.3128455244791 on iteration 17.
# Iteration=18
# likelihood is -689.2781167300826 on iteration 18.
# Iteration=19
# likelihood is -689.2373222629695 on iteration 19.
# 2-th start
# theta=[0.7614843],P=[[5.77524969e-08+5.29395592e-24j]]
# Iteration=0
# likelihood is -689.5758272549378 on iteration 0.
# Iteration=1
# likelihood is -689.5725283082227 on iteration 1.
# Iteration=2
# likelihood is -689.5692226536926 on iteration 2.
# Iteration=3
# likelihood is -689.5659020377113 on iteration 3.
# Iteration=4
# likelihood is -689.5611503447552 on iteration 4.
# Iteration=5
# likelihood is -689.5557464271533 on iteration 5.
# Iteration=6
# likelihood is -689.5496425075103 on iteration 6.
# Iteration=7
# likelihood is -689.5376486006439 on iteration 7.
# Iteration=8
# likelihood is -689.5231990927333 on iteration 8.
# Iteration=9
# likelihood is -689.506278164263 on iteration 9.
# Iteration=10
# likelihood is -689.486939605536 on iteration 10.
# Iteration=11
# likelihood is -689.4678881523704 on iteration 11.
# Iteration=12
# likelihood is -689.444142747775 on iteration 12.
# Iteration=13
# likelihood is -689.4183818045453 on iteration 13.
# Iteration=14
# likelihood is -689.3930175846474 on iteration 14.
# Iteration=15
# likelihood is -689.365438832598 on iteration 15.
# Iteration=16
# likelihood is -689.3386207641996 on iteration 16.
# Iteration=17
# likelihood is -689.3080396624076 on iteration 17.
# Iteration=18
# likelihood is -689.2726566966521 on iteration 18.
# Iteration=19
# likelihood is -689.2318453262493 on iteration 19.
# 3-th start
# theta=[0.83255839],P=[[4.8828125e-08+0.j]]
# Iteration=0
# Accumulation of floating-point errors, likelihood started to decrease!
# 4-th start
# theta=[0.73004403],P=[[6.95706666e-08-3.30872245e-25j]]
# Iteration=0
# likelihood is -689.5700799668855 on iteration 0.
# Iteration=1
# likelihood is -689.5612725585704 on iteration 1.
# Iteration=2
# likelihood is -689.5495651305179 on iteration 2.
# Iteration=3
# likelihood is -689.5365632089113 on iteration 3.
# Iteration=4
# likelihood is -689.5256869852009 on iteration 4.
# Iteration=5
# likelihood is -689.5116885091362 on iteration 5.
# Iteration=6
# likelihood is -689.4988356967838 on iteration 6.
# Iteration=7
# likelihood is -689.4854014207833 on iteration 7.
# Iteration=8
# likelihood is -689.4713153482546 on iteration 8.
# Iteration=9
# likelihood is -689.45648810056 on iteration 9.
# Iteration=10
# likelihood is -689.4408064962017 on iteration 10.
# Iteration=11
# likelihood is -689.4245254556288 on iteration 11.
# Iteration=12
# likelihood is -689.4068901593611 on iteration 12.
# Iteration=13
# likelihood is -689.3875858965816 on iteration 13.
# Iteration=14
# likelihood is -689.3662118505014 on iteration 14.
# Iteration=15
# likelihood is -689.3422486601321 on iteration 15.
# Iteration=16
# likelihood is -689.3150106035281 on iteration 16.
# Iteration=17
# likelihood is -689.2830464561697 on iteration 17.
# Iteration=18
# likelihood is -689.2460411567014 on iteration 18.
# Iteration=19
# likelihood is -689.2017294968155 on iteration 19.
# 5-th start
# theta=[0.7029336],P=[[1.77615171e-07-2.64697796e-24j]]
# Iteration=0
# likelihood is -689.5669628080799 on iteration 0.
# Iteration=1
# likelihood is -689.5565512921921 on iteration 1.
# Iteration=2
# likelihood is -689.5442088487559 on iteration 2.
# Iteration=3
# likelihood is -689.5329927378436 on iteration 3.
# Iteration=4
# likelihood is -689.5215708914435 on iteration 4.
# Iteration=5
# likelihood is -689.509869491794 on iteration 5.
# Iteration=6
# likelihood is -689.4969398853142 on iteration 6.
# Iteration=7
# likelihood is -689.4834200161067 on iteration 7.
# Iteration=8
# likelihood is -689.4692373849781 on iteration 8.
# Iteration=9
# likelihood is -689.4542999234021 on iteration 9.
# Iteration=10
# likelihood is -689.4384910613529 on iteration 10.
# Iteration=11
# likelihood is -689.4220397734321 on iteration 11.
# Iteration=12
# likelihood is -689.4041973084674 on iteration 12.
# Iteration=13
# likelihood is -689.3846394435594 on iteration 13.
# Iteration=14
# likelihood is -689.362952413171 on iteration 14.
# Iteration=15
# likelihood is -689.3385989132945 on iteration 15.
# Iteration=16
# likelihood is -689.3108678479015 on iteration 16.
# Iteration=17
# likelihood is -689.2782958868424 on iteration 17.
# Iteration=18
# likelihood is -689.2404677077947 on iteration 18.
# Iteration=19
# likelihood is -689.1950560928265 on iteration 19.
# 6-th start
# theta=[0.73079862],P=[[6.86735671e-08-2.97785021e-24j]]
# Iteration=0
# likelihood is -689.5702128037703 on iteration 0.
# Iteration=1
# likelihood is -689.5615276068268 on iteration 1.
# Iteration=2
# likelihood is -689.5498896009021 on iteration 2.
# Iteration=3
# likelihood is -689.5369016971352 on iteration 3.
# Iteration=4
# likelihood is -689.5231769010447 on iteration 4.
# Iteration=5
# likelihood is -689.5115028301321 on iteration 5.
# Iteration=6
# likelihood is -689.4986446177973 on iteration 6.
# Iteration=7
# likelihood is -689.4852126032121 on iteration 7.
# Iteration=8
# likelihood is -689.4711369371578 on iteration 8.
# Iteration=9
# likelihood is -689.4563382511662 on iteration 9.
# Iteration=10
# likelihood is -689.4412148479297 on iteration 10.
# Iteration=11
# likelihood is -689.4249941665762 on iteration 11.
# Iteration=12
# likelihood is -689.4074266354775 on iteration 12.
# Iteration=13
# likelihood is -689.388199545877 on iteration 13.
# Iteration=14
# likelihood is -689.3669147457347 on iteration 14.
# Iteration=15
# likelihood is -689.3430564941038 on iteration 15.
# Iteration=16
# likelihood is -689.3159440971946 on iteration 16.
# Iteration=17
# likelihood is -689.2846603722314 on iteration 17.
# Iteration=18
# likelihood is -689.2479405519215 on iteration 18.
# Iteration=19
# likelihood is -689.2039942230754 on iteration 19.
# 7-th start
# theta=[0.83991537],P=[[4.8828125e-08+0.j]]
# Iteration=0
# Accumulation of floating-point errors, likelihood started to decrease!
# 8-th start
# theta=[0.86805869],P=[[4.8828125e-08+0.j]]
# Iteration=0
# Accumulation of floating-point errors, likelihood started to decrease!
# 9-th start
# theta=[0.74591953],P=[[9.79826128e-08-1.98523347e-24j]]
# Iteration=0
# likelihood is -689.5726185916083 on iteration 0.
# Iteration=1
# likelihood is -689.5666111755163 on iteration 1.
# Iteration=2
# likelihood is -689.5605801550466 on iteration 2.
# Iteration=3
# likelihood is -689.5497286184074 on iteration 3.
# Iteration=4
# likelihood is -689.5366624201018 on iteration 4.
# Iteration=5
# likelihood is -689.5217328591506 on iteration 5.
# Iteration=6
# likelihood is -689.5064795349582 on iteration 6.
# Iteration=7
# likelihood is -689.4902803968367 on iteration 7.
# Iteration=8
# likelihood is -689.4762377576747 on iteration 8.
# Iteration=9
# likelihood is -689.4612953659681 on iteration 9.
# Iteration=10
# likelihood is -689.4453262385259 on iteration 10.
# Iteration=11
# likelihood is -689.4281691011853 on iteration 11.
# Iteration=12
# likelihood is -689.4096182366519 on iteration 12.
# Iteration=13
# likelihood is -689.3898614485719 on iteration 13.
# Iteration=14
# likelihood is -689.3680119850663 on iteration 14.
# Iteration=15
# likelihood is -689.3436398879654 on iteration 15.
# Iteration=16
# likelihood is -689.3166051203708 on iteration 16.
# Iteration=17
# likelihood is -689.2854209709432 on iteration 17.
# Iteration=18
# likelihood is -689.2488312013792 on iteration 18.
# Iteration=19
# likelihood is -689.2050584366434 on iteration 19.
# 10-th start
# theta=[0.45944132],P=[[5.55659323e-08+3.57342025e-23j]]
# Iteration=0
# likelihood is -689.5779965051295 on iteration 0.
# Iteration=1
# likelihood is -689.5767736196564 on iteration 1.
# Iteration=2
# likelihood is -689.5755505276843 on iteration 2.
# Iteration=3
# likelihood is -689.5743251065169 on iteration 3.
# Iteration=4
# likelihood is -689.5730947949075 on iteration 4.
# Iteration=5
# likelihood is -689.5718565738227 on iteration 5.
# Iteration=6
# likelihood is -689.5706069369726 on iteration 6.
# Iteration=7
# likelihood is -689.569341849008 on iteration 7.
# Iteration=8
# likelihood is -689.5680566888278 on iteration 8.
# Iteration=9
# likelihood is -689.5667461747825 on iteration 9.
# Iteration=10
# likelihood is -689.5654042676632 on iteration 10.
# Iteration=11
# likelihood is -689.5640240461274 on iteration 11.
# Iteration=12
# likelihood is -689.562597547508 on iteration 12.
# Iteration=13
# likelihood is -689.5603931823031 on iteration 13.
# Iteration=14
# likelihood is -689.5587803083528 on iteration 14.
# Iteration=15
# likelihood is -689.5570848746612 on iteration 15.
# Iteration=16
# likelihood is -689.5552913345 on iteration 16.
# Iteration=17
# likelihood is -689.553381160845 on iteration 17.
# Iteration=18
# likelihood is -689.551332067106 on iteration 18.
# Iteration=19
# likelihood is -689.549116971201 on iteration 19.
# 11-th start
# theta=[0.49094045],P=[[4.8828125e-08+0.j]]
# Iteration=0
# likelihood is -689.5779402338592 on iteration 0.
# Iteration=1
# likelihood is -689.5766625075435 on iteration 1.
# Iteration=2
# likelihood is -689.5753843545987 on iteration 2.
# Iteration=3
# likelihood is -689.5741035301478 on iteration 3.
# Iteration=4
# likelihood is -689.5728173290295 on iteration 4.
# Iteration=5
# likelihood is -689.5715225648522 on iteration 5.
# Iteration=6
# likelihood is -689.5702155381861 on iteration 6.
# Iteration=7
# likelihood is -689.5688919916563 on iteration 7.
# Iteration=8
# likelihood is -689.567547049208 on iteration 8.
# Iteration=9
# likelihood is -689.5661751361058 on iteration 9.
# Iteration=10
# likelihood is -689.5647698752657 on iteration 10.
# Iteration=11
# likelihood is -689.5633239541752 on iteration 11.
# Iteration=12
# likelihood is -689.5618289548337 on iteration 12.
# Iteration=13
# likelihood is -689.5602751366242 on iteration 13.
# Iteration=14
# likelihood is -689.5586511585221 on iteration 14.
# Iteration=15
# likelihood is -689.5569437221434 on iteration 15.
# Iteration=16
# likelihood is -689.555137110197 on iteration 16.
# Iteration=17
# likelihood is -689.5532125849124 on iteration 17.
# Iteration=18
# likelihood is -689.5511475965219 on iteration 18.
# Iteration=19
# likelihood is -689.5489147304294 on iteration 19.
# 12-th start
# theta=[0.61180126],P=[[8.06311518e-08-5.29395592e-24j]]
# Iteration=0
# likelihood is -689.5765917081906 on iteration 0.
# Iteration=1
# likelihood is -689.5740970038345 on iteration 1.
# Iteration=2
# likelihood is -689.5715983533875 on iteration 2.
# Iteration=3
# likelihood is -689.569090233315 on iteration 3.
# Iteration=4
# likelihood is -689.5665661814601 on iteration 4.
# Iteration=5
# likelihood is -689.5640187291822 on iteration 5.
# Iteration=6
# likelihood is -689.5614393061358 on iteration 6.
# Iteration=7
# likelihood is -689.5588181120042 on iteration 7.
# Iteration=8
# likelihood is -689.5561439479559 on iteration 8.
# Iteration=9
# likelihood is -689.5534039984362 on iteration 9.
# Iteration=10
# likelihood is -689.5505835509726 on iteration 10.
# Iteration=11
# likelihood is -689.5476656376028 on iteration 11.
# Iteration=12
# likelihood is -689.5446305759395 on iteration 12.
# Iteration=13
# likelihood is -689.5414553800423 on iteration 13.
# Iteration=14
# likelihood is -689.5381130002195 on iteration 14.
# Iteration=15
# likelihood is -689.5345713350995 on iteration 15.
# Iteration=16
# likelihood is -689.5307919364491 on iteration 16.
# Iteration=17
# likelihood is -689.5267188445362 on iteration 17.
# Iteration=18
# likelihood is -689.5223132045984 on iteration 18.
# Iteration=19
# likelihood is -689.5174959956425 on iteration 19.
# 13-th start
# theta=[0.74517223],P=[[9.99993584e-08+7.94093388e-24j]]
# Iteration=0
# likelihood is -689.5724453531509 on iteration 0.
# Iteration=1
# likelihood is -689.5663009541302 on iteration 1.
# Iteration=2
# likelihood is -689.5601318234228 on iteration 2.
# Iteration=3
# likelihood is -689.549148251473 on iteration 3.
# Iteration=4
# likelihood is -689.535984199253 on iteration 4.
# Iteration=5
# likelihood is -689.52100809534 on iteration 5.
# Iteration=6
# likelihood is -689.5057452477346 on iteration 6.
# Iteration=7
# likelihood is -689.4895932163652 on iteration 7.
# Iteration=8
# likelihood is -689.475517528726 on iteration 8.
# Iteration=9
# likelihood is -689.4605541143509 on iteration 9.
# Iteration=10
# likelihood is -689.4445767686416 on iteration 10.
# Iteration=11
# likelihood is -689.4274252213788 on iteration 11.
# Iteration=12
# likelihood is -689.4088950652842 on iteration 12.
# Iteration=13
# likelihood is -689.3891256203498 on iteration 13.
# Iteration=14
# likelihood is -689.3671550128198 on iteration 14.
# Iteration=15
# likelihood is -689.3433250585551 on iteration 15.
# Iteration=16
# likelihood is -689.3162484215135 on iteration 16.
# Iteration=17
# likelihood is -689.2850105697952 on iteration 17.
# Iteration=18
# likelihood is -689.2483506683913 on iteration 18.
# Iteration=19
# likelihood is -689.2044843163559 on iteration 19.
# 14-th start
# theta=[0.81529611],P=[[4.8828125e-08+0.j]]
# Iteration=0
# Accumulation of floating-point errors, likelihood started to decrease!
# 15-th start
# theta=[0.64780331],P=[[8.03558405e-08+0.j]]
# Iteration=0
# likelihood is -689.573969965526 on iteration 0.
# Iteration=1
# likelihood is -689.5689278296895 on iteration 1.
# Iteration=2
# likelihood is -689.5638696000176 on iteration 2.
# Iteration=3
# likelihood is -689.5549628408959 on iteration 3.
# Iteration=4
# likelihood is -689.5437014877981 on iteration 4.
# Iteration=5
# likelihood is -689.5300964728143 on iteration 5.
# Iteration=6
# likelihood is -689.51437617389 on iteration 6.
# Iteration=7
# likelihood is -689.4969864884561 on iteration 7.
# Iteration=8
# likelihood is -689.4785750121392 on iteration 8.
# Iteration=9
# likelihood is -689.4616382108162 on iteration 9.
# Iteration=10
# likelihood is -689.4471741713232 on iteration 10.
# Iteration=11
# likelihood is -689.4316938506279 on iteration 11.
# Iteration=12
# likelihood is -689.4149680994132 on iteration 12.
# Iteration=13
# likelihood is -689.3967109772972 on iteration 13.
# Iteration=14
# likelihood is -689.3748742880995 on iteration 14.
# Iteration=15
# likelihood is -689.3504419476143 on iteration 15.
# Iteration=16
# likelihood is -689.322770870069 on iteration 16.
# Iteration=17
# likelihood is -689.289882314841 on iteration 17.
# Iteration=18
# likelihood is -689.2528630323746 on iteration 18.
# Iteration=19
# likelihood is -689.2097882967673 on iteration 19.
# 16-th start
# theta=[0.22711654],P=[[4.8828125e-08+0.j]]
# Iteration=0
# Likelihood is converged!
# 17-th start
# theta=[0.45039062],P=[[4.93435618e-08-4.76456033e-23j]]
# Iteration=0
# likelihood is -689.578317775065 on iteration 0.
# Iteration=1
# likelihood is -689.5773961358435 on iteration 1.
# Iteration=2
# likelihood is -689.5764748753246 on iteration 2.
# Iteration=3
# likelihood is -689.5755524992906 on iteration 3.
# Iteration=4
# likelihood is -689.5746271877433 on iteration 4.
# Iteration=5
# likelihood is -689.5736967830823 on iteration 5.
# Iteration=6
# likelihood is -689.5718226261873 on iteration 6.
# Iteration=7
# likelihood is -689.5698302426631 on iteration 7.
# Iteration=8
# likelihood is -689.5686073056482 on iteration 8.
# Iteration=9
# likelihood is -689.5673606010023 on iteration 9.
# Iteration=10
# likelihood is -689.5660844330806 on iteration 10.
# Iteration=11
# likelihood is -689.5647722766419 on iteration 11.
# Iteration=12
# likelihood is -689.5634166282338 on iteration 12.
# Iteration=13
# likelihood is -689.5620088165359 on iteration 13.
# Iteration=14
# likelihood is -689.5605387599477 on iteration 14.
# Iteration=15
# likelihood is -689.5589946555158 on iteration 15.
# Iteration=16
# likelihood is -689.557362577388 on iteration 16.
# Iteration=17
# likelihood is -689.5556259544995 on iteration 17.
# Iteration=18
# likelihood is -689.553764884937 on iteration 18.
# Iteration=19
# likelihood is -689.5517552263509 on iteration 19.
# 18-th start
# theta=[1.57079633],P=[[8.75235434e-08-2.70617725e-23j]]
# Iteration=0
# likelihood is -689.5779876603073 on iteration 0.
# Iteration=1
# likelihood is -689.5768067697128 on iteration 1.
# Iteration=2
# likelihood is -689.5756256724272 on iteration 2.
# Iteration=3
# likelihood is -689.5744423245816 on iteration 3.
# Iteration=4
# likelihood is -689.573254258908 on iteration 4.
# Iteration=5
# likelihood is -689.5720585663075 on iteration 5.
# Iteration=6
# likelihood is -689.5708518675757 on iteration 6.
# Iteration=7
# likelihood is -689.5696302732679 on iteration 7.
# Iteration=8
# likelihood is -689.5683893292425 on iteration 8.
# Iteration=9
# likelihood is -689.5671239447996 on iteration 9.
# Iteration=10
# likelihood is -689.5658282994629 on iteration 10.
# Iteration=11
# likelihood is -689.5644957232719 on iteration 11.
# Iteration=12
# likelihood is -689.5631185438205 on iteration 12.
# Iteration=13
# likelihood is -689.5616878910417 on iteration 13.
# Iteration=14
# likelihood is -689.560193447637 on iteration 14.
# Iteration=15
# likelihood is -689.558623128703 on iteration 15.
# Iteration=16
# likelihood is -689.5569626679812 on iteration 16.
# Iteration=17
# likelihood is -689.5551950793633 on iteration 17.
# Iteration=18
# likelihood is -689.553299949533 on iteration 18.
# Iteration=19
# likelihood is -689.5512524988426 on iteration 19.
# 19-th start
# theta=[0.75399535],P=[[7.64820505e-08-1.0753348e-24j]]
# Iteration=0
# likelihood is -689.5743936172373 on iteration 0.
# Iteration=1
# likelihood is -689.5698408821099 on iteration 1.
# Iteration=2
# likelihood is -689.5652748649854 on iteration 2.
# Iteration=3
# likelihood is -689.5606820355667 on iteration 3.
# Iteration=4
# likelihood is -689.5545039642577 on iteration 4.
# Iteration=5
# likelihood is -689.5476123203946 on iteration 5.
# Iteration=6
# likelihood is -689.5399575709478 on iteration 6.
# Iteration=7
# likelihood is -689.5314806819819 on iteration 7.
# Iteration=8
# likelihood is -689.5160850115996 on iteration 8.
# Iteration=9
# likelihood is -689.5049522400325 on iteration 9.
# Iteration=10
# likelihood is -689.4927010639466 on iteration 10.
# Iteration=11
# likelihood is -689.4791920549685 on iteration 11.
# Iteration=12
# likelihood is -689.4586562727142 on iteration 12.
# Iteration=13
# likelihood is -689.4327089269849 on iteration 13.
# Iteration=14
# likelihood is -689.4042812020194 on iteration 14.
# Iteration=15
# likelihood is -689.3761031891859 on iteration 15.
# Iteration=16
# likelihood is -689.3470630642188 on iteration 16.
# Iteration=17
# likelihood is -689.316812074902 on iteration 17.
# Iteration=18
# likelihood is -689.2817625824839 on iteration 18.
# Iteration=19
# likelihood is -689.2404729536249 on iteration 19.
# best_start=5

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.70303333]), array([[0.00341951+0.j]]))

# %%
em.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q2), em.incomplete_lkhd(X2_with_mv, theta2_rad, P2, Q2)
# Out:
# (np.float64(-689.1950560928265), np.float64(-673.6467390084401))
