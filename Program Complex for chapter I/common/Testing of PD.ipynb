# %%
import numpy as np

from . import sensors as sn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
# ----> 3 from . import sensors as sn
#
# ImportError: attempted relative import with no known parent package

# %%
A = np.array([[-6.70622243e-10 - 2.60345708e-23j]], dtype=np.complex128)

# %%
A
# Out:
# array([[-6.70622243e-10-2.60345708e-23j]])
