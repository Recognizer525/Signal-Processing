# %%
import numpy as np

# %%
from pathlib import Path
import sys

try:
    ROOT = Path().resolve().parents[1]
    assert (ROOT / "common").exists()
except AssertionError:
    ROOT = next(p for p in Path().resolve().parents if (p / "common").exists())

if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
#print(ROOT)

# %%
from common import sensors as sn 
from common import subspace_methods as sm
from common import map_em_tools as met
from common import log_funcs as lf

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12

failing_sensors1 = np.arange(5)
gap_ratio1 = 0.5 * np.ones_like(failing_sensors1, dtype=np.float32)

theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sn.gss(Num_emitters1, sample_size1, P1)
N1 = sn.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sn.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sn.initial_Cov(X1_with_mv)
MUSIC_theta1 = sm.MUSIC_DoA(R1, Num_emitters1)

Psi = 1.1 * P1
nu = 10 * P1.shape[0]

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sn.SNR(A1, P1, Q1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1, lhd_list1, angles_list1 = met.multistart_EM(X1_with_mv, 
                                                                         Num_emitters1, 
                                                                         Q=Q1,
                                                                         theta_guess=MUSIC_theta1,
                                                                         Psi=Psi,
                                                                         nu=nu, 
                                                                         num_of_starts=10, 
                                                                         max_iter=20, 
                                                                         rtol_params=1e-6,
                                                                         rtol_lkhd=1e-6,
                                                                         reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.71558499],P=[[1.18642836e-07-1.98523347e-24j]]
# Inital log_posterior = -4636457.408280083
# Iteration=1
# new_angles=[0.72207638]
# new_P:
# [[0.02401335+0.j]]
# Log_posterior is -850.3513688421477 on iteration 1.
# Iteration=2
# new_angles=[0.71688292]
# new_P:
# [[0.02542536+0.j]]
# Log_posterior is -849.4525412302517 on iteration 2.
# Iteration=3
# new_angles=[0.71277335]
# new_P:
# [[0.02555941+0.j]]
# Log_posterior is -849.2858397343188 on iteration 3.
# Iteration=4
# new_angles=[0.70952274]
# new_P:
# [[0.02559291+0.j]]
# Log_posterior is -849.2037138247634 on iteration 4.
# Iteration=5
# new_angles=[0.70695118]
# new_P:
# [[0.02561324+0.j]]
# Log_posterior is -849.1512088178622 on iteration 5.
# Iteration=6
# new_angles=[0.7048829]
# new_P:
# [[0.02562889+0.j]]
# Log_posterior is -849.115675777937 on iteration 6.
# Iteration=7
# new_angles=[0.70323773]
# new_P:
# [[0.02564188+0.j]]
# Log_posterior is -849.0913161189603 on iteration 7.
# Iteration=8
# new_angles=[0.7019037]
# new_P:
# [[0.02565314+0.j]]
# Log_posterior is -849.0739715029272 on iteration 8.
# Iteration=9
# new_angles=[0.70086507]
# new_P:
# [[0.02566333+0.j]]
# Log_posterior is -849.0615016463925 on iteration 9.
# Iteration=10
# new_angles=[0.70001243]
# new_P:
# [[0.0256728+0.j]]
# Log_posterior is -849.051866412723 on iteration 10.
# Iteration=11
# new_angles=[0.69931989]
# new_P:
# [[0.02568186+0.j]]
# Log_posterior is -849.0441309255784 on iteration 11.
# Iteration=12
# new_angles=[0.69876174]
# new_P:
# [[0.02569065+0.j]]
# Log_posterior is -849.0376604569699 on iteration 12.
# Iteration=13
# new_angles=[0.69831593]
# new_P:
# [[0.02569928+0.j]]
# Log_posterior is -849.0320234289817 on iteration 13.
# Iteration=14
# new_angles=[0.69795671]
# new_P:
# [[0.02570781+0.j]]
# Log_posterior is -849.0269135415828 on iteration 14.
# Iteration=15
# new_angles=[0.69765495]
# new_P:
# [[0.02571629+0.j]]
# Log_posterior is -849.0221217473078 on iteration 15.
# Iteration=16
# new_angles=[0.69741605]
# new_P:
# [[0.02572473+0.j]]
# Log_posterior is -849.0175674934295 on iteration 16.
# Iteration=17
# new_angles=[0.69722902]
# new_P:
# [[0.02573317+0.j]]
# Log_posterior is -849.0131655555958 on iteration 17.
# Iteration=18
# new_angles=[0.69707299]
# new_P:
# [[0.02574159+0.j]]
# Log_posterior is -849.0088479020102 on iteration 18.
# Iteration=19
# new_angles=[0.6969529]
# new_P:
# [[0.02575003+0.j]]
# Log_posterior is -849.0045944908635 on iteration 19.
# Iteration=20
# new_angles=[0.69684553]
# new_P:
# [[0.02575847+0.j]]
# Log_posterior is -849.0003692468994 on iteration 20.
# 1-th start
# theta=[0.75761751],P=[[7.62531873e-08-2.64697796e-24j]]
# Inital log_posterior = -7213503.376399581
# Iteration=1
# new_angles=[0.76310548]
# new_P:
# [[0.02401335+0.j]]
# Log_posterior is -851.7553367482046 on iteration 1.
# Iteration=2
# new_angles=[0.75042925]
# new_P:
# [[0.02520419+0.j]]
# Log_posterior is -850.7586453128655 on iteration 2.
# Iteration=3
# new_angles=[0.7395647]
# new_P:
# [[0.02534873+0.j]]
# Log_posterior is -850.2759119511032 on iteration 3.
# Iteration=4
# new_angles=[0.7307598]
# new_P:
# [[0.02543431+0.j]]
# Log_posterior is -849.898453000497 on iteration 4.
# Iteration=5
# new_angles=[0.7237492]
# new_P:
# [[0.02550291+0.j]]
# Log_posterior is -849.6193688661559 on iteration 5.
# Iteration=6
# new_angles=[0.71821629]
# new_P:
# [[0.02555529+0.j]]
# Log_posterior is -849.4248472022301 on iteration 6.
# Iteration=7
# new_angles=[0.71384678]
# new_P:
# [[0.02559387+0.j]]
# Log_posterior is -849.2932878330587 on iteration 7.
# Iteration=8
# new_angles=[0.71038087]
# new_P:
# [[0.02562226+0.j]]
# Log_posterior is -849.2052736586872 on iteration 8.
# Iteration=9
# new_angles=[0.70763225]
# new_P:
# [[0.02564365+0.j]]
# Log_posterior is -849.1465769727807 on iteration 9.
# Iteration=10
# new_angles=[0.70544143]
# new_P:
# [[0.02566036+0.j]]
# Log_posterior is -849.1070386084523 on iteration 10.
# Iteration=11
# new_angles=[0.70369112]
# new_P:
# [[0.02567404+0.j]]
# Log_posterior is -849.0799655839743 on iteration 11.
# Iteration=12
# new_angles=[0.70229106]
# new_P:
# [[0.02568578+0.j]]
# Log_posterior is -849.0609804360006 on iteration 12.
# Iteration=13
# new_angles=[0.70117222]
# new_P:
# [[0.02569628+0.j]]
# Log_posterior is -849.0472433217903 on iteration 13.
# Iteration=14
# new_angles=[0.70025327]
# new_P:
# [[0.02570598+0.j]]
# Log_posterior is -849.0367569872244 on iteration 14.
# Iteration=15
# new_angles=[0.69952071]
# new_P:
# [[0.02571521+0.j]]
# Log_posterior is -849.0285294790614 on iteration 15.
# Iteration=16
# new_angles=[0.69892191]
# new_P:
# [[0.02572412+0.j]]
# Log_posterior is -849.0217048193985 on iteration 16.
# Iteration=17
# new_angles=[0.69844682]
# new_P:
# [[0.02573284+0.j]]
# Log_posterior is -849.0158461578139 on iteration 17.
# Iteration=18
# new_angles=[0.69806419]
# new_P:
# [[0.02574144+0.j]]
# Log_posterior is -849.0105902327134 on iteration 18.
# Iteration=19
# new_angles=[0.69774874]
# new_P:
# [[0.02574997+0.j]]
# Log_posterior is -849.0057089851506 on iteration 19.
# Iteration=20
# new_angles=[0.69749542]
# new_P:
# [[0.02575847+0.j]]
# Log_posterior is -849.0010873471166 on iteration 20.
# 2-th start
# theta=[0.75275765],P=[[9.44715207e-08-1.12496563e-23j]]
# Inital log_posterior = -5822552.8186785495
# Iteration=1
# new_angles=[0.75812361]
# new_P:
# [[0.02401349+0.j]]
# Log_posterior is -851.6068488383381 on iteration 1.
# Iteration=2
# new_angles=[0.74604561]
# new_P:
# [[0.02522838+0.j]]
# Log_posterior is -850.5831350261003 on iteration 2.
# Iteration=3
# new_angles=[0.73596537]
# new_P:
# [[0.02537759+0.j]]
# Log_posterior is -850.1226359981744 on iteration 3.
# Iteration=4
# new_angles=[0.72786878]
# new_P:
# [[0.02545922+0.j]]
# Log_posterior is -849.781589933847 on iteration 4.
# Iteration=5
# new_angles=[0.7214695]
# new_P:
# [[0.02552174+0.j]]
# Log_posterior is -849.5373994750604 on iteration 5.
# Iteration=6
# new_angles=[0.71639948]
# new_P:
# [[0.02556839+0.j]]
# Log_posterior is -849.3691496825328 on iteration 6.
# Iteration=7
# new_angles=[0.71240157]
# new_P:
# [[0.02560269+0.j]]
# Log_posterior is -849.2563401545468 on iteration 7.
# Iteration=8
# new_angles=[0.70923622]
# new_P:
# [[0.02562805+0.j]]
# Log_posterior is -849.1811974266964 on iteration 8.
# Iteration=9
# new_angles=[0.70671754]
# new_P:
# [[0.02564737+0.j]]
# Log_posterior is -849.130899144037 on iteration 9.
# Iteration=10
# new_angles=[0.70470921]
# new_P:
# [[0.02566274+0.j]]
# Log_posterior is -849.0968538272921 on iteration 10.
# Iteration=11
# new_angles=[0.70310428]
# new_P:
# [[0.02567555+0.j]]
# Log_posterior is -849.0733581010934 on iteration 11.
# Iteration=12
# new_angles=[0.70181735]
# new_P:
# [[0.02568673+0.j]]
# Log_posterior is -849.0566716912747 on iteration 12.
# Iteration=13
# new_angles=[0.7007788]
# new_P:
# [[0.02569688+0.j]]
# Log_posterior is -849.0443615745269 on iteration 13.
# Iteration=14
# new_angles=[0.69994383]
# new_P:
# [[0.02570636+0.j]]
# Log_posterior is -849.034921681764 on iteration 14.
# Iteration=15
# new_angles=[0.69926894]
# new_P:
# [[0.02571544+0.j]]
# Log_posterior is -849.0273304336878 on iteration 15.
# Iteration=16
# new_angles=[0.69872661]
# new_P:
# [[0.02572426+0.j]]
# Log_posterior is -849.0209545268727 on iteration 16.
# Iteration=17
# new_angles=[0.69828757]
# new_P:
# [[0.02573292+0.j]]
# Log_posterior is -849.0153564074596 on iteration 17.
# Iteration=18
# new_angles=[0.69793222]
# new_P:
# [[0.02574148+0.j]]
# Log_posterior is -849.0102649587513 on iteration 18.
# Iteration=19
# new_angles=[0.69764601]
# new_P:
# [[0.02575+0.j]]
# Log_posterior is -849.0055057540877 on iteration 19.
# Iteration=20
# new_angles=[0.69741913]
# new_P:
# [[0.02575848+0.j]]
# Log_posterior is -849.0009663778291 on iteration 20.
# 3-th start
# theta=[0.82383174],P=[[9.765625e-08+0.j]]
# Inital log_posterior = -5632692.841192848
# Iteration=1
# new_angles=[0.82008405]
# new_P:
# [[0.02401349+0.j]]
# Log_posterior is -852.3072107197914 on iteration 1.
# Iteration=2
# new_angles=[0.82144066]
# new_P:
# [[0.02510724+0.j]]
# Log_posterior is -851.7993681337227 on iteration 2.
# Iteration=3
# new_angles=[0.82276919]
# new_P:
# [[0.0251666+0.j]]
# Log_posterior is -851.7716854344352 on iteration 3.
# Iteration=4
# new_angles=[0.8240441]
# new_P:
# [[0.02517713+0.j]]
# Log_posterior is -851.7651587217921 on iteration 4.
# Iteration=5
# new_angles=[0.82530294]
# new_P:
# [[0.02518533+0.j]]
# Log_posterior is -851.7597002226107 on iteration 5.
# Iteration=6
# new_angles=[0.82651766]
# new_P:
# [[0.02519342+0.j]]
# Log_posterior is -851.7544222565195 on iteration 6.
# Iteration=7
# new_angles=[0.82762746]
# new_P:
# [[0.02520151+0.j]]
# Log_posterior is -851.7493844727674 on iteration 7.
# Iteration=8
# new_angles=[0.82870214]
# new_P:
# [[0.02520958+0.j]]
# Log_posterior is -851.744496889572 on iteration 8.
# Iteration=9
# new_angles=[0.82970975]
# new_P:
# [[0.02521764+0.j]]
# Log_posterior is -851.7397985239375 on iteration 9.
# Iteration=10
# new_angles=[0.83060586]
# new_P:
# [[0.02522568+0.j]]
# Log_posterior is -851.7353345295431 on iteration 10.
# Iteration=11
# new_angles=[0.83142202]
# new_P:
# [[0.0252337+0.j]]
# Log_posterior is -851.7310536153611 on iteration 11.
# Iteration=12
# new_angles=[0.83216492]
# new_P:
# [[0.02524171+0.j]]
# Log_posterior is -851.7269297809862 on iteration 12.
# Iteration=13
# new_angles=[0.83282868]
# new_P:
# [[0.0252497+0.j]]
# Log_posterior is -851.7229505458154 on iteration 13.
# Iteration=14
# new_angles=[0.83341888]
# new_P:
# [[0.02525767+0.j]]
# Log_posterior is -851.7190936685099 on iteration 14.
# Iteration=15
# new_angles=[0.83396372]
# new_P:
# [[0.02526564+0.j]]
# Log_posterior is -851.715323188681 on iteration 15.
# Iteration=16
# new_angles=[0.83443601]
# new_P:
# [[0.0252736+0.j]]
# Log_posterior is -851.711643593291 on iteration 16.
# Iteration=17
# new_angles=[0.83487251]
# new_P:
# [[0.02528155+0.j]]
# Log_posterior is -851.7080221019286 on iteration 17.
# Iteration=18
# new_angles=[0.83523992]
# new_P:
# [[0.02528951+0.j]]
# Log_posterior is -851.7044653876928 on iteration 18.
# Iteration=19
# new_angles=[0.83555756]
# new_P:
# [[0.02529746+0.j]]
# Log_posterior is -851.7009551432473 on iteration 19.
# Iteration=20
# new_angles=[0.83585965]
# new_P:
# [[0.02530541+0.j]]
# Log_posterior is -851.6974697393154 on iteration 20.
# 4-th start
# theta=[0.72131738],P=[[1.09961713e-07-2.97785021e-24j]]
# Inital log_posterior = -5002435.049991155
# Iteration=1
# new_angles=[0.7278417]
# new_P:
# [[0.02401336+0.j]]
# Log_posterior is -850.5348045989954 on iteration 1.
# Iteration=2
# new_angles=[0.72142787]
# new_P:
# [[0.0253974+0.j]]
# Log_posterior is -849.5971267939335 on iteration 2.
# Iteration=3
# new_angles=[0.71637096]
# new_P:
# [[0.02553663+0.j]]
# Log_posterior is -849.3840101774894 on iteration 3.
# Iteration=4
# new_angles=[0.71237199]
# new_P:
# [[0.02557755+0.j]]
# Log_posterior is -849.2680920806171 on iteration 4.
# Iteration=5
# new_angles=[0.70920293]
# new_P:
# [[0.0256033+0.j]]
# Log_posterior is -849.1928319756515 on iteration 5.
# Iteration=6
# new_angles=[0.70668432]
# new_P:
# [[0.02562256+0.j]]
# Log_posterior is -849.1426832589564 on iteration 6.
# Iteration=7
# new_angles=[0.70468288]
# new_P:
# [[0.02563786+0.j]]
# Log_posterior is -849.108853853023 on iteration 7.
# Iteration=8
# new_angles=[0.70308092]
# new_P:
# [[0.02565059+0.j]]
# Log_posterior is -849.0854843261433 on iteration 8.
# Iteration=9
# new_angles=[0.70180147]
# new_P:
# [[0.02566171+0.j]]
# Log_posterior is -849.0689241145108 on iteration 9.
# Iteration=10
# new_angles=[0.70076293]
# new_P:
# [[0.0256718+0.j]]
# Log_posterior is -849.0566589377362 on iteration 10.
# Iteration=11
# new_angles=[0.69992798]
# new_P:
# [[0.02568125+0.j]]
# Log_posterior is -849.0472510499908 on iteration 11.
# Iteration=12
# new_angles=[0.69925309]
# new_P:
# [[0.02569029+0.j]]
# Log_posterior is -849.0396854404228 on iteration 12.
# Iteration=13
# new_angles=[0.69871185]
# new_P:
# [[0.02569907+0.j]]
# Log_posterior is -849.0333341106136 on iteration 13.
# Iteration=14
# new_angles=[0.69827669]
# new_P:
# [[0.02570769+0.j]]
# Log_posterior is -849.02776348004 on iteration 14.
# Iteration=15
# new_angles=[0.69792135]
# new_P:
# [[0.02571622+0.j]]
# Log_posterior is -849.0226847430479 on iteration 15.
# Iteration=16
# new_angles=[0.69764188]
# new_P:
# [[0.0257247+0.j]]
# Log_posterior is -849.0179481467512 on iteration 16.
# Iteration=17
# new_angles=[0.69740412]
# new_P:
# [[0.02573316+0.j]]
# Log_posterior is -849.0134002389542 on iteration 17.
# Iteration=18
# new_angles=[0.69721709]
# new_P:
# [[0.0257416+0.j]]
# Log_posterior is -849.0090003235857 on iteration 18.
# Iteration=19
# new_angles=[0.69706106]
# new_P:
# [[0.02575004+0.j]]
# Log_posterior is -849.0046839613508 on iteration 19.
# Iteration=20
# new_angles=[0.69693806]
# new_P:
# [[0.02575848+0.j]]
# Log_posterior is -849.0004289256423 on iteration 20.
# 5-th start
# theta=[0.69420695],P=[[2.63712642e-07-3.97046694e-24j]]
# Inital log_posterior = -2086307.2332863433
# Iteration=1
# new_angles=[0.68922612]
# new_P:
# [[0.02401399+0.j]]
# Log_posterior is -849.971346278049 on iteration 1.
# Iteration=2
# new_angles=[0.69054373]
# new_P:
# [[0.02547808+0.j]]
# Log_posterior is -849.1643458634072 on iteration 2.
# Iteration=3
# new_angles=[0.69161237]
# new_P:
# [[0.02560046+0.j]]
# Log_posterior is -849.0949076837904 on iteration 3.
# Iteration=4
# new_angles=[0.69249635]
# new_P:
# [[0.02561926+0.j]]
# Log_posterior is -849.0800497480784 on iteration 4.
# Iteration=5
# new_angles=[0.69322227]
# new_P:
# [[0.0256295+0.j]]
# Log_posterior is -849.0712712648019 on iteration 5.
# Iteration=6
# new_angles=[0.69380319]
# new_P:
# [[0.02563874+0.j]]
# Log_posterior is -849.0642681290377 on iteration 6.
# Iteration=7
# new_angles=[0.69429161]
# new_P:
# [[0.02564766+0.j]]
# Log_posterior is -849.0581793754789 on iteration 7.
# Iteration=8
# new_angles=[0.69468878]
# new_P:
# [[0.02565643+0.j]]
# Log_posterior is -849.0527341628388 on iteration 8.
# Iteration=9
# new_angles=[0.69500661]
# new_P:
# [[0.02566508+0.j]]
# Log_posterior is -849.0477314305639 on iteration 9.
# Iteration=10
# new_angles=[0.69527041]
# new_P:
# [[0.02567365+0.j]]
# Log_posterior is -849.0430035192326 on iteration 10.
# Iteration=11
# new_angles=[0.69548115]
# new_P:
# [[0.02568217+0.j]]
# Log_posterior is -849.0384713736944 on iteration 11.
# Iteration=12
# new_angles=[0.69565592]
# new_P:
# [[0.02569066+0.j]]
# Log_posterior is -849.0340616744099 on iteration 12.
# Iteration=13
# new_angles=[0.69580058]
# new_P:
# [[0.02569912+0.j]]
# Log_posterior is -849.0297342344998 on iteration 13.
# Iteration=14
# new_angles=[0.69591245]
# new_P:
# [[0.02570758+0.j]]
# Log_posterior is -849.025468233418 on iteration 14.
# Iteration=15
# new_angles=[0.69600399]
# new_P:
# [[0.02571603+0.j]]
# Log_posterior is -849.0212391297115 on iteration 15.
# Iteration=16
# new_angles=[0.69608353]
# new_P:
# [[0.02572448+0.j]]
# Log_posterior is -849.0170314998951 on iteration 16.
# Iteration=17
# new_angles=[0.69615565]
# new_P:
# [[0.02573293+0.j]]
# Log_posterior is -849.0128372948705 on iteration 17.
# Iteration=18
# new_angles=[0.69619657]
# new_P:
# [[0.02574139+0.j]]
# Log_posterior is -849.0086597832252 on iteration 18.
# Iteration=19
# new_angles=[0.69623566]
# new_P:
# [[0.02574985+0.j]]
# Log_posterior is -849.004488695005 on iteration 19.
# Iteration=20
# new_angles=[0.69626801]
# new_P:
# [[0.02575831+0.j]]
# Log_posterior is -849.0003203643121 on iteration 20.
# 6-th start
# theta=[0.72207198],P=[[1.08695785e-07+1.65436123e-24j]]
# Inital log_posterior = -5060687.827578303
# Iteration=1
# new_angles=[0.72860067]
# new_P:
# [[0.02401336+0.j]]
# Log_posterior is -850.5604783432401 on iteration 1.
# Iteration=2
# new_angles=[0.72203387]
# new_P:
# [[0.02539346+0.j]]
# Log_posterior is -849.617909838688 on iteration 2.
# Iteration=3
# new_angles=[0.71684384]
# new_P:
# [[0.02553333+0.j]]
# Log_posterior is -849.398103868636 on iteration 3.
# Iteration=4
# new_angles=[0.71274798]
# new_P:
# [[0.02557533+0.j]]
# Log_posterior is -849.2774151295754 on iteration 4.
# Iteration=5
# new_angles=[0.70948459]
# new_P:
# [[0.02560185+0.j]]
# Log_posterior is -849.1986017417477 on iteration 5.
# Iteration=6
# new_angles=[0.70691243]
# new_P:
# [[0.02562168+0.j]]
# Log_posterior is -849.1464562592657 on iteration 6.
# Iteration=7
# new_angles=[0.70485284]
# new_P:
# [[0.02563729+0.j]]
# Log_posterior is -849.1111530937831 on iteration 7.
# Iteration=8
# new_angles=[0.70321133]
# new_P:
# [[0.02565025+0.j]]
# Log_posterior is -849.0869074540332 on iteration 8.
# Iteration=9
# new_angles=[0.70189497]
# new_P:
# [[0.02566151+0.j]]
# Log_posterior is -849.0697544589423 on iteration 9.
# Iteration=10
# new_angles=[0.70084891]
# new_P:
# [[0.02567169+0.j]]
# Log_posterior is -849.0572593500368 on iteration 10.
# Iteration=11
# new_angles=[0.69999627]
# new_P:
# [[0.02568117+0.j]]
# Log_posterior is -849.0476394940189 on iteration 11.
# Iteration=12
# new_angles=[0.69931072]
# new_P:
# [[0.02569024+0.j]]
# Log_posterior is -849.0399478896023 on iteration 12.
# Iteration=13
# new_angles=[0.69876461]
# new_P:
# [[0.02569904+0.j]]
# Log_posterior is -849.0335261856126 on iteration 13.
# Iteration=14
# new_angles=[0.69831881]
# new_P:
# [[0.02570767+0.j]]
# Log_posterior is -849.0278878791911 on iteration 14.
# Iteration=15
# new_angles=[0.69795958]
# new_P:
# [[0.02571621+0.j]]
# Log_posterior is -849.0227746120853 on iteration 15.
# Iteration=16
# new_angles=[0.69765783]
# new_P:
# [[0.0257247+0.j]]
# Log_posterior is -849.0179795918431 on iteration 16.
# Iteration=17
# new_angles=[0.69742006]
# new_P:
# [[0.02573316+0.j]]
# Log_posterior is -849.0134241340395 on iteration 17.
# Iteration=18
# new_angles=[0.69723304]
# new_P:
# [[0.0257416+0.j]]
# Log_posterior is -849.009019288926 on iteration 18.
# Iteration=19
# new_angles=[0.697077]
# new_P:
# [[0.02575004+0.j]]
# Log_posterior is -849.004698930447 on iteration 19.
# Iteration=20
# new_angles=[0.69695692]
# new_P:
# [[0.02575848+0.j]]
# Log_posterior is -849.0004430566793 on iteration 20.
# 7-th start
# theta=[0.83118872],P=[[9.765625e-08+0.j]]
# Inital log_posterior = -5632692.841192806
# Iteration=1
# new_angles=[0.82741109]
# new_P:
# [[0.02401347+0.j]]
# Log_posterior is -852.2964529135985 on iteration 1.
# Iteration=2
# new_angles=[0.82851184]
# new_P:
# [[0.02510875+0.j]]
# Log_posterior is -851.7881208673608 on iteration 2.
# Iteration=3
# new_angles=[0.82951924]
# new_P:
# [[0.02516828+0.j]]
# Log_posterior is -851.7611795933447 on iteration 3.
# Iteration=4
# new_angles=[0.83044154]
# new_P:
# [[0.02517874+0.j]]
# Log_posterior is -851.7556109494053 on iteration 4.
# Iteration=5
# new_angles=[0.83130075]
# new_P:
# [[0.02518683+0.j]]
# Log_posterior is -851.7512219335991 on iteration 5.
# Iteration=6
# new_angles=[0.83207013]
# new_P:
# [[0.0251948+0.j]]
# Log_posterior is -851.7470612296808 on iteration 6.
# Iteration=7
# new_angles=[0.83274944]
# new_P:
# [[0.02520274+0.j]]
# Log_posterior is -851.7430632676476 on iteration 7.
# Iteration=8
# new_angles=[0.83338595]
# new_P:
# [[0.02521066+0.j]]
# Log_posterior is -851.7391687520329 on iteration 8.
# Iteration=9
# new_angles=[0.83393077]
# new_P:
# [[0.02521858+0.j]]
# Log_posterior is -851.7353972637242 on iteration 9.
# Iteration=10
# new_angles=[0.83442969]
# new_P:
# [[0.02522649+0.j]]
# Log_posterior is -851.731703996136 on iteration 10.
# Iteration=11
# new_angles=[0.83488551]
# new_P:
# [[0.02523439+0.j]]
# Log_posterior is -851.728074939943 on iteration 11.
# Iteration=12
# new_angles=[0.83526303]
# new_P:
# [[0.02524229+0.j]]
# Log_posterior is -851.7245176998974 on iteration 12.
# Iteration=13
# new_angles=[0.8356002]
# new_P:
# [[0.02525019+0.j]]
# Log_posterior is -851.721004473133 on iteration 13.
# Iteration=14
# new_angles=[0.8359023]
# new_P:
# [[0.02525809+0.j]]
# Log_posterior is -851.7175247542816 on iteration 14.
# Iteration=15
# new_angles=[0.83617673]
# new_P:
# [[0.02526599+0.j]]
# Log_posterior is -851.714070593626 on iteration 15.
# Iteration=16
# new_angles=[0.83640362]
# new_P:
# [[0.02527389+0.j]]
# Log_posterior is -851.7106435678187 on iteration 16.
# Iteration=17
# new_angles=[0.83660385]
# new_P:
# [[0.0252818+0.j]]
# Log_posterior is -851.7072337006425 on iteration 17.
# Iteration=18
# new_angles=[0.83678395]
# new_P:
# [[0.02528971+0.j]]
# Log_posterior is -851.7038358784249 on iteration 18.
# Iteration=19
# new_angles=[0.8369577]
# new_P:
# [[0.02529763+0.j]]
# Log_posterior is -851.7004451687469 on iteration 19.
# Iteration=20
# new_angles=[0.83707794]
# new_P:
# [[0.02530556+0.j]]
# Log_posterior is -851.6970685920672 on iteration 20.
# 8-th start
# theta=[0.85933204],P=[[9.765625e-08+0.j]]
# Inital log_posterior = -5632692.841192965
# Iteration=1
# new_angles=[0.85933204]
# new_P:
# [[0.02401349+0.j]]
# Log_posterior is -852.3288324937129 on iteration 1.
# Iteration=2
# new_angles=[0.85654635]
# new_P:
# [[0.02510565+0.j]]
# Log_posterior is -851.8145267876174 on iteration 2.
# Iteration=3
# new_angles=[0.85407989]
# new_P:
# [[0.02516589+0.j]]
# Log_posterior is -851.7806131328156 on iteration 3.
# Iteration=4
# new_angles=[0.85194552]
# new_P:
# [[0.02517722+0.j]]
# Log_posterior is -851.7697134806532 on iteration 4.
# Iteration=5
# new_angles=[0.85009747]
# new_P:
# [[0.02518594+0.j]]
# Log_posterior is -851.7614266384758 on iteration 5.
# Iteration=6
# new_angles=[0.84852787]
# new_P:
# [[0.02519434+0.j]]
# Log_posterior is -851.7544791506024 on iteration 6.
# Iteration=7
# new_angles=[0.8471398]
# new_P:
# [[0.02520256+0.j]]
# Log_posterior is -851.7483929642146 on iteration 7.
# Iteration=8
# new_angles=[0.84594359]
# new_P:
# [[0.02521068+0.j]]
# Log_posterior is -851.7430117201045 on iteration 8.
# Iteration=9
# new_angles=[0.84492298]
# new_P:
# [[0.02521872+0.j]]
# Log_posterior is -851.7381703326092 on iteration 9.
# Iteration=10
# new_angles=[0.84403329]
# new_P:
# [[0.0252267+0.j]]
# Log_posterior is -851.7337036048732 on iteration 10.
# Iteration=11
# new_angles=[0.84327667]
# new_P:
# [[0.02523463+0.j]]
# Log_posterior is -851.729535558867 on iteration 11.
# Iteration=12
# new_angles=[0.84262589]
# new_P:
# [[0.02524255+0.j]]
# Log_posterior is -851.7255794505307 on iteration 12.
# Iteration=13
# new_angles=[0.84206723]
# new_P:
# [[0.02525045+0.j]]
# Log_posterior is -851.7217802578822 on iteration 13.
# Iteration=14
# new_angles=[0.84156248]
# new_P:
# [[0.02525833+0.j]]
# Log_posterior is -851.718080762071 on iteration 14.
# Iteration=15
# new_angles=[0.84113382]
# new_P:
# [[0.02526622+0.j]]
# Log_posterior is -851.7144747063032 on iteration 15.
# Iteration=16
# new_angles=[0.84075912]
# new_P:
# [[0.02527411+0.j]]
# Log_posterior is -851.7109318454558 on iteration 16.
# Iteration=17
# new_angles=[0.84043603]
# new_P:
# [[0.025282+0.j]]
# Log_posterior is -851.7074383670498 on iteration 17.
# Iteration=18
# new_angles=[0.84015307]
# new_P:
# [[0.02528989+0.j]]
# Log_posterior is -851.7039798476621 on iteration 18.
# Iteration=19
# new_angles=[0.83990793]
# new_P:
# [[0.0252978+0.j]]
# Log_posterior is -851.7005485708196 on iteration 19.
# Iteration=20
# new_angles=[0.83967859]
# new_P:
# [[0.02530571+0.j]]
# Log_posterior is -851.6971327404583 on iteration 20.
# 9-th start
# theta=[0.73719288],P=[[7.93250092e-08-4.63221143e-24j]]
# Inital log_posterior = -6934191.172299341
# Iteration=1
# new_angles=[0.74381132]
# new_P:
# [[0.02401329+0.j]]
# Log_posterior is -851.111687861986 on iteration 1.
# Iteration=2
# new_angles=[0.73416252]
# new_P:
# [[0.02530756+0.j]]
# Log_posterior is -850.0871519291532 on iteration 2.
# Iteration=3
# new_angles=[0.72645346]
# new_P:
# [[0.02545822+0.j]]
# Log_posterior is -849.7323927114975 on iteration 3.
# Iteration=4
# new_angles=[0.72034635]
# new_P:
# [[0.02552215+0.j]]
# Log_posterior is -849.5029218313842 on iteration 4.
# Iteration=5
# new_angles=[0.71552388]
# new_P:
# [[0.02556631+0.j]]
# Log_posterior is -849.3476470126699 on iteration 5.
# Iteration=6
# new_angles=[0.71172181]
# new_P:
# [[0.02559847+0.j]]
# Log_posterior is -849.2439365260494 on iteration 6.
# Iteration=7
# new_angles=[0.70868862]
# new_P:
# [[0.02562233+0.j]]
# Log_posterior is -849.1744577981599 on iteration 7.
# Iteration=8
# new_angles=[0.70627933]
# new_P:
# [[0.02564072+0.j]]
# Log_posterior is -849.1279494074569 on iteration 8.
# Iteration=9
# new_angles=[0.70435546]
# new_P:
# [[0.02565547+0.j]]
# Log_posterior is -849.0963586757981 on iteration 9.
# Iteration=10
# new_angles=[0.70282717]
# new_P:
# [[0.02566788+0.j]]
# Log_posterior is -849.0745497108155 on iteration 10.
# Iteration=11
# new_angles=[0.70158726]
# new_P:
# [[0.02567879+0.j]]
# Log_posterior is -849.0588479906136 on iteration 11.
# Iteration=12
# new_angles=[0.70059203]
# new_P:
# [[0.02568877+0.j]]
# Log_posterior is -849.0472159588558 on iteration 12.
# Iteration=13
# new_angles=[0.69979708]
# new_P:
# [[0.02569815+0.j]]
# Log_posterior is -849.0382467366892 on iteration 13.
# Iteration=14
# new_angles=[0.69915152]
# new_P:
# [[0.02570714+0.j]]
# Log_posterior is -849.0309492698422 on iteration 14.
# Iteration=15
# new_angles=[0.69863444]
# new_P:
# [[0.02571591+0.j]]
# Log_posterior is -849.0247683816569 on iteration 15.
# Iteration=16
# new_angles=[0.69820815]
# new_P:
# [[0.02572453+0.j]]
# Log_posterior is -849.0192764524712 on iteration 16.
# Iteration=17
# new_angles=[0.69786651]
# new_P:
# [[0.02573307+0.j]]
# Log_posterior is -849.0142633965229 on iteration 17.
# Iteration=18
# new_angles=[0.69758888]
# new_P:
# [[0.02574156+0.j]]
# Log_posterior is -849.0095524021224 on iteration 18.
# Iteration=19
# new_angles=[0.69736685]
# new_P:
# [[0.02575003+0.j]]
# Log_posterior is -849.0050429683201 on iteration 19.
# Iteration=20
# new_angles=[0.69718466]
# new_P:
# [[0.02575849+0.j]]
# Log_posterior is -849.00065661825 on iteration 20.
# best_start=5
# Время выполнения функции: 88.960678 секунд

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.69626801]), array([[0.02575831+0.j]]))

# %%
lf.log_posterior(X1_with_mv, EM_theta1_rad, EM_P1, Q1, Psi, nu), lf.log_posterior(X1_with_mv, theta1_rad, P1, Q1, Psi, nu)
# Out:
# (np.float64(-849.0003203643121), np.float64(-845.876500178015))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11

failing_sensors2 = np.arange(8)
gap_ratio2 = 0.5 * np.ones_like(failing_sensors2, dtype=np.float32)

theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sn.gss(Num_emitters2, sample_size2, P2)
N2 = sn.gss(Num_sensors2, sample_size2, Q2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sn.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sn.initial_Cov(X2_with_mv)
MUSIC_theta2 = sm.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sn.SNR(A2, P2, Q2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2, lhd_list2, angles_list2 = met.multistart_EM(X2_with_mv, 
                                                                         Num_emitters2, 
                                                                         Q=Q2,
                                                                         theta_guess=MUSIC_theta2,   
                                                                         Psi=Psi,
                                                                         nu=nu,
                                                                         num_of_starts=20, 
                                                                         max_iter=20, 
                                                                         rtol_params=1e-6,
                                                                         rtol_lkhd=1e-6,
                                                                         reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.72431164],P=[[7.5917774e-08+4.13590306e-24j]]
# Inital log_posterior = -7245189.527913359
# Iteration=1
# new_angles=[0.72431164]
# new_P:
# [[0.02510022+0.j]]
# Log_posterior is -668.7759243218117 on iteration 1.
# Iteration=2
# new_angles=[0.71999701]
# new_P:
# [[0.02673966+0.j]]
# Log_posterior is -667.8656149686985 on iteration 2.
# Iteration=3
# new_angles=[0.71650773]
# new_P:
# [[0.02691798+0.j]]
# Log_posterior is -667.6941735534044 on iteration 3.
# Iteration=4
# new_angles=[0.71367475]
# new_P:
# [[0.0269685+0.j]]
# Log_posterior is -667.6082046008988 on iteration 4.
# Iteration=5
# new_angles=[0.71136847]
# new_P:
# [[0.02700219+0.j]]
# Log_posterior is -667.5500199204613 on iteration 5.
# Iteration=6
# new_angles=[0.70948859]
# new_P:
# [[0.02703035+0.j]]
# Log_posterior is -667.5082541644447 on iteration 6.
# Iteration=7
# new_angles=[0.70796109]
# new_P:
# [[0.02705525+0.j]]
# Log_posterior is -667.4775123956045 on iteration 7.
# Iteration=8
# new_angles=[0.70671576]
# new_P:
# [[0.02707797+0.j]]
# Log_posterior is -667.4541608115653 on iteration 8.
# Iteration=9
# new_angles=[0.7056905]
# new_P:
# [[0.02709924+0.j]]
# Log_posterior is -667.4357158088761 on iteration 9.
# Iteration=10
# new_angles=[0.70484816]
# new_P:
# [[0.02711955+0.j]]
# Log_posterior is -667.4206241915379 on iteration 10.
# Iteration=11
# new_angles=[0.70416657]
# new_P:
# [[0.02713923+0.j]]
# Log_posterior is -667.4078752365779 on iteration 11.
# Iteration=12
# new_angles=[0.7036025]
# new_P:
# [[0.02715847+0.j]]
# Log_posterior is -667.3966370839232 on iteration 12.
# Iteration=13
# new_angles=[0.70312733]
# new_P:
# [[0.02717745+0.j]]
# Log_posterior is -667.3863965637325 on iteration 13.
# Iteration=14
# new_angles=[0.70273054]
# new_P:
# [[0.02719626+0.j]]
# Log_posterior is -667.376864818058 on iteration 14.
# Iteration=15
# new_angles=[0.70240744]
# new_P:
# [[0.02721497+0.j]]
# Log_posterior is -667.3678490608023 on iteration 15.
# Iteration=16
# new_angles=[0.7021276]
# new_P:
# [[0.02723363+0.j]]
# Log_posterior is -667.3591439112587 on iteration 16.
# Iteration=17
# new_angles=[0.70189986]
# new_P:
# [[0.02725226+0.j]]
# Log_posterior is -667.3506876659346 on iteration 17.
# Iteration=18
# new_angles=[0.70169937]
# new_P:
# [[0.02727088+0.j]]
# Log_posterior is -667.3423762941131 on iteration 18.
# Iteration=19
# new_angles=[0.70155162]
# new_P:
# [[0.02728952+0.j]]
# Log_posterior is -667.3342062728799 on iteration 19.
# Iteration=20
# new_angles=[0.70143108]
# new_P:
# [[0.02730818+0.j]]
# Log_posterior is -667.326109322004 on iteration 20.
# 1-th start
# theta=[0.76634416],P=[[4.65993421e-08-2.64697796e-24j]]
# Inital log_posterior = -11803245.62962001
# Iteration=1
# new_angles=[0.76634416]
# new_P:
# [[0.02510013+0.j]]
# Log_posterior is -670.4057365540632 on iteration 1.
# Iteration=2
# new_angles=[0.75524747]
# new_P:
# [[0.02643036+0.j]]
# Log_posterior is -669.4196794151402 on iteration 2.
# Iteration=3
# new_angles=[0.74552516]
# new_P:
# [[0.02660975+0.j]]
# Log_posterior is -668.9259347163103 on iteration 3.
# Iteration=4
# new_angles=[0.73737251]
# new_P:
# [[0.02672199+0.j]]
# Log_posterior is -668.5208026419019 on iteration 4.
# Iteration=5
# new_angles=[0.73068913]
# new_P:
# [[0.02681838+0.j]]
# Log_posterior is -668.2025938099492 on iteration 5.
# Iteration=6
# new_angles=[0.72524455]
# new_P:
# [[0.02689815+0.j]]
# Log_posterior is -667.9650720897258 on iteration 6.
# Iteration=7
# new_angles=[0.72084122]
# new_P:
# [[0.02696223+0.j]]
# Log_posterior is -667.7938882297888 on iteration 7.
# Iteration=8
# new_angles=[0.71725741]
# new_P:
# [[0.02701325+0.j]]
# Log_posterior is -667.6717583232951 on iteration 8.
# Iteration=9
# new_angles=[0.71434256]
# new_P:
# [[0.02705454+0.j]]
# Log_posterior is -667.5850205880205 on iteration 9.
# Iteration=10
# new_angles=[0.71196186]
# new_P:
# [[0.02708876+0.j]]
# Log_posterior is -667.5229655457204 on iteration 10.
# Iteration=11
# new_angles=[0.7100211]
# new_P:
# [[0.02711804+0.j]]
# Log_posterior is -667.4780913104257 on iteration 11.
# Iteration=12
# new_angles=[0.70842467]
# new_P:
# [[0.02714387+0.j]]
# Log_posterior is -667.4448220923937 on iteration 12.
# Iteration=13
# new_angles=[0.70709856]
# new_P:
# [[0.02716737+0.j]]
# Log_posterior is -667.4193944374039 on iteration 13.
# Iteration=14
# new_angles=[0.70601845]
# new_P:
# [[0.02718932+0.j]]
# Log_posterior is -667.3995881556948 on iteration 14.
# Iteration=15
# new_angles=[0.70513648]
# new_P:
# [[0.02721016+0.j]]
# Log_posterior is -667.3835849014474 on iteration 15.
# Iteration=16
# new_angles=[0.70440822]
# new_P:
# [[0.02723026+0.j]]
# Log_posterior is -667.3701046196118 on iteration 16.
# Iteration=17
# new_angles=[0.70380694]
# new_P:
# [[0.02724988+0.j]]
# Log_posterior is -667.358349467626 on iteration 17.
# Iteration=18
# new_angles=[0.70331223]
# new_P:
# [[0.02726919+0.j]]
# Log_posterior is -667.3477847917275 on iteration 18.
# Iteration=19
# new_angles=[0.70288732]
# new_P:
# [[0.0272883+0.j]]
# Log_posterior is -667.3379703741184 on iteration 19.
# Iteration=20
# new_angles=[0.7025267]
# new_P:
# [[0.0273073+0.j]]
# Log_posterior is -667.3287037276366 on iteration 20.
# 2-th start
# theta=[0.7614843],P=[[5.77524969e-08+5.29395592e-24j]]
# Inital log_posterior = -9523904.008305788
# Iteration=1
# new_angles=[0.7614843]
# new_P:
# [[0.0251002+0.j]]
# Log_posterior is -670.2365150139348 on iteration 1.
# Iteration=2
# new_angles=[0.75091248]
# new_P:
# [[0.0264625+0.j]]
# Log_posterior is -669.2225794177124 on iteration 2.
# Iteration=3
# new_angles=[0.74185051]
# new_P:
# [[0.02664856+0.j]]
# Log_posterior is -668.7471866339496 on iteration 3.
# Iteration=4
# new_angles=[0.73434229]
# new_P:
# [[0.02675747+0.j]]
# Log_posterior is -668.3771464001021 on iteration 4.
# Iteration=5
# new_angles=[0.72820461]
# new_P:
# [[0.02684711+0.j]]
# Log_posterior is -668.0944049023879 on iteration 5.
# Iteration=6
# new_angles=[0.72321971]
# new_P:
# [[0.02691995+0.j]]
# Log_posterior is -667.8870447071491 on iteration 6.
# Iteration=7
# new_angles=[0.71916849]
# new_P:
# [[0.02697806+0.j]]
# Log_posterior is -667.7383132946163 on iteration 7.
# Iteration=8
# new_angles=[0.71588691]
# new_P:
# [[0.02702459+0.j]]
# Log_posterior is -667.6329939897721 on iteration 8.
# Iteration=9
# new_angles=[0.71321213]
# new_P:
# [[0.02706249+0.j]]
# Log_posterior is -667.5580963311706 on iteration 9.
# Iteration=10
# new_angles=[0.71103511]
# new_P:
# [[0.0270943+0.j]]
# Log_posterior is -667.5044556045959 on iteration 10.
# Iteration=11
# new_angles=[0.70925675]
# new_P:
# [[0.02712186+0.j]]
# Log_posterior is -667.465342512741 on iteration 11.
# Iteration=12
# new_angles=[0.70780625]
# new_P:
# [[0.02714651+0.j]]
# Log_posterior is -667.436193646476 on iteration 12.
# Iteration=13
# new_angles=[0.70660189]
# new_P:
# [[0.02716918+0.j]]
# Log_posterior is -667.4136174910693 on iteration 13.
# Iteration=14
# new_angles=[0.70561032]
# new_P:
# [[0.02719053+0.j]]
# Log_posterior is -667.3956449798748 on iteration 14.
# Iteration=15
# new_angles=[0.70480515]
# new_P:
# [[0.02721099+0.j]]
# Log_posterior is -667.380907974879 on iteration 15.
# Iteration=16
# new_angles=[0.70412748]
# new_P:
# [[0.02723083+0.j]]
# Log_posterior is -667.3682204371435 on iteration 16.
# Iteration=17
# new_angles=[0.70356748]
# new_P:
# [[0.02725029+0.j]]
# Log_posterior is -667.3570075440801 on iteration 17.
# Iteration=18
# new_angles=[0.70311287]
# new_P:
# [[0.02726949+0.j]]
# Log_posterior is -667.3468440777937 on iteration 18.
# Iteration=19
# new_angles=[0.70272496]
# new_P:
# [[0.02728851+0.j]]
# Log_posterior is -667.3373265477398 on iteration 19.
# Iteration=20
# new_angles=[0.70240744]
# new_P:
# [[0.02730745+0.j]]
# Log_posterior is -667.3283007674363 on iteration 20.
# 3-th start
# theta=[0.83255839],P=[[4.8828125e-08+0.j]]
# Inital log_posterior = -11264504.394715903
# Iteration=1
# new_angles=[0.83255839]
# new_P:
# [[0.02510018+0.j]]
# Log_posterior is -671.1610983030062 on iteration 1.
# Iteration=2
# new_angles=[0.83266279]
# new_P:
# [[0.02628656+0.j]]
# Log_posterior is -670.6907767406526 on iteration 2.
# Iteration=3
# new_angles=[0.83278365]
# new_P:
# [[0.02635963+0.j]]
# Log_posterior is -670.6639500626453 on iteration 3.
# Iteration=4
# new_angles=[0.83289358]
# new_P:
# [[0.02637884+0.j]]
# Log_posterior is -670.656922758552 on iteration 4.
# Iteration=5
# new_angles=[0.83300229]
# new_P:
# [[0.02639542+0.j]]
# Log_posterior is -670.6508686269984 on iteration 5.
# Iteration=6
# new_angles=[0.83310674]
# new_P:
# [[0.0264119+0.j]]
# Log_posterior is -670.6448627834259 on iteration 6.
# Iteration=7
# new_angles=[0.83321121]
# new_P:
# [[0.02642841+0.j]]
# Log_posterior is -670.6388578967461 on iteration 7.
# Iteration=8
# new_angles=[0.83331568]
# new_P:
# [[0.02644496+0.j]]
# Log_posterior is -670.6328515309335 on iteration 8.
# Iteration=9
# new_angles=[0.83342017]
# new_P:
# [[0.02646155+0.j]]
# Log_posterior is -670.6268435696093 on iteration 9.
# Iteration=10
# new_angles=[0.83352467]
# new_P:
# [[0.02647817+0.j]]
# Log_posterior is -670.6208340181048 on iteration 10.
# Iteration=11
# new_angles=[0.83362918]
# new_P:
# [[0.02649484+0.j]]
# Log_posterior is -670.6148228882375 on iteration 11.
# Iteration=12
# new_angles=[0.8337337]
# new_P:
# [[0.02651154+0.j]]
# Log_posterior is -670.6088101921456 on iteration 12.
# Iteration=13
# new_angles=[0.83383823]
# new_P:
# [[0.02652827+0.j]]
# Log_posterior is -670.6027959419532 on iteration 13.
# Iteration=14
# new_angles=[0.83394278]
# new_P:
# [[0.02654505+0.j]]
# Log_posterior is -670.5967801497516 on iteration 14.
# Iteration=15
# new_angles=[0.83404734]
# new_P:
# [[0.02656187+0.j]]
# Log_posterior is -670.5907628275971 on iteration 15.
# Iteration=16
# new_angles=[0.83414182]
# new_P:
# [[0.02657872+0.j]]
# Log_posterior is -670.5847457128099 on iteration 16.
# Iteration=17
# new_angles=[0.83423631]
# new_P:
# [[0.02659561+0.j]]
# Log_posterior is -670.5787271944293 on iteration 17.
# Iteration=18
# new_angles=[0.83432718]
# new_P:
# [[0.02661255+0.j]]
# Log_posterior is -670.5727077921475 on iteration 18.
# Iteration=19
# new_angles=[0.83441805]
# new_P:
# [[0.02662952+0.j]]
# Log_posterior is -670.5666869261798 on iteration 19.
# Iteration=20
# new_angles=[0.83450894]
# new_P:
# [[0.02664653+0.j]]
# Log_posterior is -670.560664566052 on iteration 20.
# 4-th start
# theta=[0.73004403],P=[[6.95706666e-08-3.30872245e-25j]]
# Inital log_posterior = -7906139.023451852
# Iteration=1
# new_angles=[0.73539341]
# new_P:
# [[0.0251002+0.j]]
# Log_posterior is -669.1795125205743 on iteration 1.
# Iteration=2
# new_angles=[0.72898836]
# new_P:
# [[0.02666311+0.j]]
# Log_posterior is -668.2030126267745 on iteration 2.
# Iteration=3
# new_angles=[0.72378921]
# new_P:
# [[0.02685054+0.j]]
# Log_posterior is -667.9357336290201 on iteration 3.
# Iteration=4
# new_angles=[0.71960126]
# new_P:
# [[0.02691974+0.j]]
# Log_posterior is -667.7757394681099 on iteration 4.
# Iteration=5
# new_angles=[0.71619776]
# new_P:
# [[0.0269682+0.j]]
# Log_posterior is -667.6648204611764 on iteration 5.
# Iteration=6
# new_angles=[0.71344239]
# new_P:
# [[0.02700696+0.j]]
# Log_posterior is -667.5867501997685 on iteration 6.
# Iteration=7
# new_angles=[0.71119654]
# new_P:
# [[0.0270392+0.j]]
# Log_posterior is -667.5310105288985 on iteration 7.
# Iteration=8
# new_angles=[0.70937069]
# new_P:
# [[0.02706699+0.j]]
# Log_posterior is -667.4906684572434 on iteration 8.
# Iteration=9
# new_angles=[0.70786899]
# new_P:
# [[0.02709172+0.j]]
# Log_posterior is -667.4606014860663 on iteration 9.
# Iteration=10
# new_angles=[0.70665007]
# new_P:
# [[0.02711441+0.j]]
# Log_posterior is -667.4377220524377 on iteration 10.
# Iteration=11
# new_angles=[0.70564371]
# new_P:
# [[0.02713568+0.j]]
# Log_posterior is -667.4195581004684 on iteration 11.
# Iteration=12
# new_angles=[0.70480878]
# new_P:
# [[0.02715604+0.j]]
# Log_posterior is -667.4045869342068 on iteration 12.
# Iteration=13
# new_angles=[0.70412722]
# new_P:
# [[0.02717578+0.j]]
# Log_posterior is -667.3918769479575 on iteration 13.
# Iteration=14
# new_angles=[0.70356317]
# new_P:
# [[0.02719511+0.j]]
# Log_posterior is -667.3806646795989 on iteration 14.
# Iteration=15
# new_angles=[0.70308622]
# new_P:
# [[0.02721417+0.j]]
# Log_posterior is -667.370437315415 on iteration 15.
# Iteration=16
# new_angles=[0.70269832]
# new_P:
# [[0.02723307+0.j]]
# Log_posterior is -667.3609500340116 on iteration 16.
# Iteration=17
# new_angles=[0.70238163]
# new_P:
# [[0.02725186+0.j]]
# Log_posterior is -667.3519608939371 on iteration 17.
# Iteration=18
# new_angles=[0.70211388]
# new_P:
# [[0.0272706+0.j]]
# Log_posterior is -667.3432857030456 on iteration 18.
# Iteration=19
# new_angles=[0.70189959]
# new_P:
# [[0.02728932+0.j]]
# Log_posterior is -667.3348513754529 on iteration 19.
# Iteration=20
# new_angles=[0.7017253]
# new_P:
# [[0.02730803+0.j]]
# Log_posterior is -667.3265723225632 on iteration 20.
# 5-th start
# theta=[0.7029336],P=[[1.77615171e-07-2.64697796e-24j]]
# Inital log_posterior = -3097100.9298643675
# Iteration=1
# new_angles=[0.71321846]
# new_P:
# [[0.02510084+0.j]]
# Log_posterior is -668.4909372327061 on iteration 1.
# Iteration=2
# new_angles=[0.71097305]
# new_P:
# [[0.0267937+0.j]]
# Log_posterior is -667.6350562339194 on iteration 2.
# Iteration=3
# new_angles=[0.70914755]
# new_P:
# [[0.02696428+0.j]]
# Log_posterior is -667.5323344354175 on iteration 3.
# Iteration=4
# new_angles=[0.70766387]
# new_P:
# [[0.0270013+0.j]]
# Log_posterior is -667.4975881251291 on iteration 4.
# Iteration=5
# new_angles=[0.70645252]
# new_P:
# [[0.02702469+0.j]]
# Log_posterior is -667.4748276101976 on iteration 5.
# Iteration=6
# new_angles=[0.70546208]
# new_P:
# [[0.0270457+0.j]]
# Log_posterior is -667.4571758318111 on iteration 6.
# Iteration=7
# new_angles=[0.70466064]
# new_P:
# [[0.02706571+0.j]]
# Log_posterior is -667.4427605025187 on iteration 7.
# Iteration=8
# new_angles=[0.70399195]
# new_P:
# [[0.02708511+0.j]]
# Log_posterior is -667.4303750449857 on iteration 8.
# Iteration=9
# new_angles=[0.70344367]
# new_P:
# [[0.02710414+0.j]]
# Log_posterior is -667.419423681429 on iteration 9.
# Iteration=10
# new_angles=[0.70297565]
# new_P:
# [[0.02712292+0.j]]
# Log_posterior is -667.4093797004346 on iteration 10.
# Iteration=11
# new_angles=[0.70260125]
# new_P:
# [[0.02714156+0.j]]
# Log_posterior is -667.4000518221503 on iteration 11.
# Iteration=12
# new_angles=[0.7022875]
# new_P:
# [[0.0271601+0.j]]
# Log_posterior is -667.3911648833869 on iteration 12.
# Iteration=13
# new_angles=[0.70203321]
# new_P:
# [[0.02717859+0.j]]
# Log_posterior is -667.3825976518149 on iteration 13.
# Iteration=14
# new_angles=[0.70181894]
# new_P:
# [[0.02719706+0.j]]
# Log_posterior is -667.3742296856634 on iteration 14.
# Iteration=15
# new_angles=[0.7016591]
# new_P:
# [[0.02721553+0.j]]
# Log_posterior is -667.3660289087653 on iteration 15.
# Iteration=16
# new_angles=[0.70150249]
# new_P:
# [[0.02723402+0.j]]
# Log_posterior is -667.3578840680647 on iteration 16.
# Iteration=17
# new_angles=[0.70138195]
# new_P:
# [[0.02725253+0.j]]
# Log_posterior is -667.3498156830766 on iteration 17.
# Iteration=18
# new_angles=[0.70128763]
# new_P:
# [[0.02727108+0.j]]
# Log_posterior is -667.3417950316921 on iteration 18.
# Iteration=19
# new_angles=[0.70120774]
# new_P:
# [[0.02728965+0.j]]
# Log_posterior is -667.3337985384914 on iteration 19.
# Iteration=20
# new_angles=[0.70113993]
# new_P:
# [[0.02730827+0.j]]
# Log_posterior is -667.3258168558082 on iteration 20.
# 6-th start
# theta=[0.73079862],P=[[6.86735671e-08-2.97785021e-24j]]
# Inital log_posterior = -8009412.058595211
# Iteration=1
# new_angles=[0.73501302]
# new_P:
# [[0.0251002+0.j]]
# Log_posterior is -669.1643598772894 on iteration 1.
# Iteration=2
# new_angles=[0.72866711]
# new_P:
# [[0.02666598+0.j]]
# Log_posterior is -668.189583915302 on iteration 2.
# Iteration=3
# new_angles=[0.72353718]
# new_P:
# [[0.02685322+0.j]]
# Log_posterior is -667.9261950373672 on iteration 3.
# Iteration=4
# new_angles=[0.71939143]
# new_P:
# [[0.02692166+0.j]]
# Log_posterior is -667.7689327220176 on iteration 4.
# Iteration=5
# new_angles=[0.716029]
# new_P:
# [[0.02696958+0.j]]
# Log_posterior is -667.6601642885654 on iteration 5.
# Iteration=6
# new_angles=[0.71330733]
# new_P:
# [[0.02700791+0.j]]
# Log_posterior is -667.5836164597982 on iteration 6.
# Iteration=7
# new_angles=[0.71108916]
# new_P:
# [[0.02703984+0.j]]
# Log_posterior is -667.528926909604 on iteration 7.
# Iteration=8
# new_angles=[0.70927801]
# new_P:
# [[0.02706742+0.j]]
# Log_posterior is -667.4891858587382 on iteration 8.
# Iteration=9
# new_angles=[0.70779417]
# new_P:
# [[0.02709203+0.j]]
# Log_posterior is -667.4595992150513 on iteration 9.
# Iteration=10
# new_angles=[0.70657532]
# new_P:
# [[0.02711462+0.j]]
# Log_posterior is -667.436910042169 on iteration 10.
# Iteration=11
# new_angles=[0.70558478]
# new_P:
# [[0.02713585+0.j]]
# Log_posterior is -667.4190117618117 on iteration 11.
# Iteration=12
# new_angles=[0.70476872]
# new_P:
# [[0.02715615+0.j]]
# Log_posterior is -667.4042700638283 on iteration 12.
# Iteration=13
# new_angles=[0.70409107]
# new_P:
# [[0.02717585+0.j]]
# Log_posterior is -667.391647160557 on iteration 13.
# Iteration=14
# new_angles=[0.70353386]
# new_P:
# [[0.02719516+0.j]]
# Log_posterior is -667.3805080551198 on iteration 14.
# Iteration=15
# new_angles=[0.70306581]
# new_P:
# [[0.0272142+0.j]]
# Log_posterior is -667.3703444397142 on iteration 15.
# Iteration=16
# new_angles=[0.70268734]
# new_P:
# [[0.02723309+0.j]]
# Log_posterior is -667.3609061429527 on iteration 16.
# Iteration=17
# new_angles=[0.70237066]
# new_P:
# [[0.02725187+0.j]]
# Log_posterior is -667.3519271673575 on iteration 17.
# Iteration=18
# new_angles=[0.7021029]
# new_P:
# [[0.02727061+0.j]]
# Log_posterior is -667.3432578437397 on iteration 18.
# Iteration=19
# new_angles=[0.70188779]
# new_P:
# [[0.02728932+0.j]]
# Log_posterior is -667.3348264148395 on iteration 19.
# Iteration=20
# new_angles=[0.70170006]
# new_P:
# [[0.02730803+0.j]]
# Log_posterior is -667.3265299435199 on iteration 20.
# 7-th start
# theta=[0.83991537],P=[[4.8828125e-08+0.j]]
# Inital log_posterior = -11264504.394715901
# Iteration=1
# new_angles=[0.83991537]
# new_P:
# [[0.02510018+0.j]]
# Log_posterior is -671.1602262813309 on iteration 1.
# Iteration=2
# new_angles=[0.83991903]
# new_P:
# [[0.02628672+0.j]]
# Log_posterior is -670.6898319099993 on iteration 2.
# Iteration=3
# new_angles=[0.83992269]
# new_P:
# [[0.0263598+0.j]]
# Log_posterior is -670.663017999252 on iteration 3.
# Iteration=4
# new_angles=[0.83992635]
# new_P:
# [[0.02637901+0.j]]
# Log_posterior is -670.6560097680676 on iteration 4.
# Iteration=5
# new_angles=[0.83993001]
# new_P:
# [[0.02639559+0.j]]
# Log_posterior is -670.649975060818 on iteration 5.
# Iteration=6
# new_angles=[0.83993367]
# new_P:
# [[0.02641207+0.j]]
# Log_posterior is -670.6439879945838 on iteration 6.
# Iteration=7
# new_angles=[0.83993733]
# new_P:
# [[0.02642857+0.j]]
# Log_posterior is -670.6380018915854 on iteration 7.
# Iteration=8
# new_angles=[0.83994099]
# new_P:
# [[0.02644512+0.j]]
# Log_posterior is -670.6320143496246 on iteration 8.
# Iteration=9
# new_angles=[0.83994465]
# new_P:
# [[0.0264617+0.j]]
# Log_posterior is -670.6260252436371 on iteration 9.
# Iteration=10
# new_angles=[0.83994831]
# new_P:
# [[0.02647832+0.j]]
# Log_posterior is -670.6200345681176 on iteration 10.
# Iteration=11
# new_angles=[0.83995197]
# new_P:
# [[0.02649498+0.j]]
# Log_posterior is -670.6140423239875 on iteration 11.
# Iteration=12
# new_angles=[0.83995563]
# new_P:
# [[0.02651168+0.j]]
# Log_posterior is -670.6080485125422 on iteration 12.
# Iteration=13
# new_angles=[0.83995929]
# new_P:
# [[0.02652842+0.j]]
# Log_posterior is -670.6020531351227 on iteration 13.
# Iteration=14
# new_angles=[0.83996296]
# new_P:
# [[0.02654519+0.j]]
# Log_posterior is -670.5960561930965 on iteration 14.
# Iteration=15
# new_angles=[0.83996662]
# new_P:
# [[0.026562+0.j]]
# Log_posterior is -670.5900576878577 on iteration 15.
# Iteration=16
# new_angles=[0.83997028]
# new_P:
# [[0.02657885+0.j]]
# Log_posterior is -670.5840576208255 on iteration 16.
# Iteration=17
# new_angles=[0.83997394]
# new_P:
# [[0.02659574+0.j]]
# Log_posterior is -670.5780559934473 on iteration 17.
# Iteration=18
# new_angles=[0.83997394]
# new_P:
# [[0.02661267+0.j]]
# Log_posterior is -670.5720528531224 on iteration 18.
# Iteration=19
# new_angles=[0.83997394]
# new_P:
# [[0.02662964+0.j]]
# Log_posterior is -670.5660481571399 on iteration 19.
# Iteration=20
# new_angles=[0.83997394]
# new_P:
# [[0.02664665+0.j]]
# Log_posterior is -670.5600419048654 on iteration 20.
# 8-th start
# theta=[0.86805869],P=[[4.8828125e-08+0.j]]
# Inital log_posterior = -11264504.394715939
# Iteration=1
# new_angles=[0.86354155]
# new_P:
# [[0.02510019+0.j]]
# Log_posterior is -671.1730925800499 on iteration 1.
# Iteration=2
# new_angles=[0.86295257]
# new_P:
# [[0.02628431+0.j]]
# Log_posterior is -670.7035809122777 on iteration 2.
# Iteration=3
# new_angles=[0.86238953]
# new_P:
# [[0.02635717+0.j]]
# Log_posterior is -670.676341320888 on iteration 3.
# Iteration=4
# new_angles=[0.86182685]
# new_P:
# [[0.02637646+0.j]]
# Log_posterior is -670.6687807436658 on iteration 4.
# Iteration=5
# new_angles=[0.86126454]
# new_P:
# [[0.02639314+0.j]]
# Log_posterior is -670.6621853985774 on iteration 5.
# Iteration=6
# new_angles=[0.86071675]
# new_P:
# [[0.02640972+0.j]]
# Log_posterior is -670.6556526981439 on iteration 6.
# Iteration=7
# new_angles=[0.86015891]
# new_P:
# [[0.02642633+0.j]]
# Log_posterior is -670.6491156136368 on iteration 7.
# Iteration=8
# new_angles=[0.85960144]
# new_P:
# [[0.02644298+0.j]]
# Log_posterior is -670.6425810669261 on iteration 8.
# Iteration=9
# new_angles=[0.8590865]
# new_P:
# [[0.02645966+0.j]]
# Log_posterior is -670.6360889141798 on iteration 9.
# Iteration=10
# new_angles=[0.85857188]
# new_P:
# [[0.02647638+0.j]]
# Log_posterior is -670.6296035958239 on iteration 10.
# Iteration=11
# new_angles=[0.85809632]
# new_P:
# [[0.02649313+0.j]]
# Log_posterior is -670.6231576420278 on iteration 11.
# Iteration=12
# new_angles=[0.85763347]
# new_P:
# [[0.02650991+0.j]]
# Log_posterior is -670.6167295678748 on iteration 12.
# Iteration=13
# new_angles=[0.85716713]
# new_P:
# [[0.02652672+0.j]]
# Log_posterior is -670.6103039601508 on iteration 13.
# Iteration=14
# new_angles=[0.85670477]
# new_P:
# [[0.02654358+0.j]]
# Log_posterior is -670.6038867338405 on iteration 14.
# Iteration=15
# new_angles=[0.856253]
# new_P:
# [[0.02656047+0.j]]
# Log_posterior is -670.597484122243 on iteration 15.
# Iteration=16
# new_angles=[0.85583315]
# new_P:
# [[0.0265774+0.j]]
# Log_posterior is -670.5911139287164 on iteration 16.
# Iteration=17
# new_angles=[0.8554135]
# new_P:
# [[0.02659435+0.j]]
# Log_posterior is -670.5847509007303 on iteration 17.
# Iteration=18
# new_angles=[0.85503269]
# new_P:
# [[0.02661135+0.j]]
# Log_posterior is -670.5784239296338 on iteration 18.
# Iteration=19
# new_angles=[0.85465204]
# new_P:
# [[0.02662838+0.j]]
# Log_posterior is -670.5721037264556 on iteration 19.
# Iteration=20
# new_angles=[0.85428394]
# new_P:
# [[0.02664545+0.j]]
# Log_posterior is -670.5657978307698 on iteration 20.
# 9-th start
# theta=[0.74591953],P=[[9.79826128e-08-1.98523347e-24j]]
# Inital log_posterior = -5613752.859389736
# Iteration=1
# new_angles=[0.7472533]
# new_P:
# [[0.02510049+0.j]]
# Log_posterior is -669.6710404614779 on iteration 1.
# Iteration=2
# new_angles=[0.73874328]
# new_P:
# [[0.02656984+0.j]]
# Log_posterior is -668.6440589000757 on iteration 2.
# Iteration=3
# new_angles=[0.73174822]
# new_P:
# [[0.02676288+0.j]]
# Log_posterior is -668.2683942735339 on iteration 3.
# Iteration=4
# new_angles=[0.7260645]
# new_P:
# [[0.02685295+0.j]]
# Log_posterior is -668.0133734406605 on iteration 4.
# Iteration=5
# new_angles=[0.72145475]
# new_P:
# [[0.02692019+0.j]]
# Log_posterior is -667.8306849309567 on iteration 5.
# Iteration=6
# new_angles=[0.71772484]
# new_P:
# [[0.02697327+0.j]]
# Log_posterior is -667.7011244170396 on iteration 6.
# Iteration=7
# new_angles=[0.71468979]
# new_P:
# [[0.02701586+0.j]]
# Log_posterior is -667.609306041452 on iteration 7.
# Iteration=8
# new_angles=[0.7122202]
# new_P:
# [[0.02705095+0.j]]
# Log_posterior is -667.5440214994198 on iteration 8.
# Iteration=9
# new_angles=[0.71020925]
# new_P:
# [[0.02708075+0.j]]
# Log_posterior is -667.4970657877783 on iteration 9.
# Iteration=10
# new_angles=[0.70857237]
# new_P:
# [[0.02710689+0.j]]
# Log_posterior is -667.462660622364 on iteration 10.
# Iteration=11
# new_angles=[0.70723227]
# new_P:
# [[0.02713052+0.j]]
# Log_posterior is -667.4366997035714 on iteration 11.
# Iteration=12
# new_angles=[0.70612083]
# new_P:
# [[0.02715247+0.j]]
# Log_posterior is -667.4163569880865 on iteration 12.
# Iteration=13
# new_angles=[0.70521082]
# new_P:
# [[0.02717332+0.j]]
# Log_posterior is -667.3999706249383 on iteration 13.
# Iteration=14
# new_angles=[0.70446171]
# new_P:
# [[0.0271934+0.j]]
# Log_posterior is -667.3862554142997 on iteration 14.
# Iteration=15
# new_angles=[0.70384662]
# new_P:
# [[0.02721298+0.j]]
# Log_posterior is -667.3743699409453 on iteration 15.
# Iteration=16
# new_angles=[0.70333843]
# new_P:
# [[0.02723223+0.j]]
# Log_posterior is -667.3637165635965 on iteration 16.
# Iteration=17
# new_angles=[0.70291045]
# new_P:
# [[0.02725126+0.j]]
# Log_posterior is -667.3538774342929 on iteration 17.
# Iteration=18
# new_angles=[0.7025626]
# new_P:
# [[0.02727018+0.j]]
# Log_posterior is -667.3446448481908 on iteration 18.
# Iteration=19
# new_angles=[0.70228203]
# new_P:
# [[0.02728901+0.j]]
# Log_posterior is -667.3358287672659 on iteration 19.
# Iteration=20
# new_angles=[0.70204219]
# new_P:
# [[0.0273078+0.j]]
# Log_posterior is -667.3272609614521 on iteration 20.
# 10-th start
# theta=[0.45944132],P=[[5.55659323e-08+3.57342025e-23j]]
# Inital log_posterior = -9898657.029034527
# Iteration=1
# new_angles=[0.46489919]
# new_P:
# [[0.02510018+0.j]]
# Log_posterior is -670.6881027821231 on iteration 1.
# Iteration=2
# new_angles=[0.46571874]
# new_P:
# [[0.02637677+0.j]]
# Log_posterior is -670.1597680890688 on iteration 2.
# Iteration=3
# new_angles=[0.4664672]
# new_P:
# [[0.02646352+0.j]]
# Log_posterior is -670.124373426299 on iteration 3.
# Iteration=4
# new_angles=[0.46711591]
# new_P:
# [[0.02648462+0.j]]
# Log_posterior is -670.1144765190706 on iteration 4.
# Iteration=5
# new_angles=[0.46772486]
# new_P:
# [[0.02650195+0.j]]
# Log_posterior is -670.1062931275974 on iteration 5.
# Iteration=6
# new_angles=[0.46826559]
# new_P:
# [[0.02651905+0.j]]
# Log_posterior is -670.0985225506428 on iteration 6.
# Iteration=7
# new_angles=[0.46875476]
# new_P:
# [[0.02653611+0.j]]
# Log_posterior is -670.0910086047219 on iteration 7.
# Iteration=8
# new_angles=[0.46917886]
# new_P:
# [[0.02655316+0.j]]
# Log_posterior is -670.0837362877967 on iteration 8.
# Iteration=9
# new_angles=[0.46958948]
# new_P:
# [[0.02657019+0.j]]
# Log_posterior is -670.0765756632644 on iteration 9.
# Iteration=10
# new_angles=[0.4699453]
# new_P:
# [[0.02658724+0.j]]
# Log_posterior is -670.0695793981002 on iteration 10.
# Iteration=11
# new_angles=[0.47028122]
# new_P:
# [[0.0266043+0.j]]
# Log_posterior is -670.0626735925836 on iteration 11.
# Iteration=12
# new_angles=[0.47058876]
# new_P:
# [[0.02662138+0.j]]
# Log_posterior is -670.0558566143043 on iteration 12.
# Iteration=13
# new_angles=[0.47086544]
# new_P:
# [[0.02663848+0.j]]
# Log_posterior is -670.0491215455489 on iteration 13.
# Iteration=14
# new_angles=[0.47113302]
# new_P:
# [[0.0266556+0.j]]
# Log_posterior is -670.0424306703741 on iteration 14.
# Iteration=15
# new_angles=[0.47137219]
# new_P:
# [[0.02667275+0.j]]
# Log_posterior is -670.0358004374082 on iteration 15.
# Iteration=16
# new_angles=[0.4715913]
# new_P:
# [[0.02668993+0.j]]
# Log_posterior is -670.029215487556 on iteration 16.
# Iteration=17
# new_angles=[0.47179046]
# new_P:
# [[0.02670714+0.j]]
# Log_posterior is -670.0226695120177 on iteration 17.
# Iteration=18
# new_angles=[0.4719802]
# new_P:
# [[0.02672438+0.j]]
# Log_posterior is -670.0161476891075 on iteration 18.
# Iteration=19
# new_angles=[0.47213084]
# new_P:
# [[0.02674166+0.j]]
# Log_posterior is -670.0096729146803 on iteration 19.
# Iteration=20
# new_angles=[0.47228149]
# new_P:
# [[0.02675896+0.j]]
# Log_posterior is -670.0032079508079 on iteration 20.
# 11-th start
# theta=[0.49094045],P=[[4.8828125e-08+0.j]]
# Inital log_posterior = -11264504.394714931
# Iteration=1
# new_angles=[0.49648824]
# new_P:
# [[0.02510017+0.j]]
# Log_posterior is -670.7105529966972 on iteration 1.
# Iteration=2
# new_angles=[0.49604635]
# new_P:
# [[0.02637299+0.j]]
# Log_posterior is -670.1866386819082 on iteration 2.
# Iteration=3
# new_angles=[0.4955711]
# new_P:
# [[0.02645878+0.j]]
# Log_posterior is -670.1531210510899 on iteration 3.
# Iteration=4
# new_angles=[0.49511957]
# new_P:
# [[0.02647949+0.j]]
# Log_posterior is -670.1443523601633 on iteration 4.
# Iteration=5
# new_angles=[0.49464456]
# new_P:
# [[0.02649658+0.j]]
# Log_posterior is -670.1368818093615 on iteration 5.
# Iteration=6
# new_angles=[0.49416966]
# new_P:
# [[0.02651351+0.j]]
# Log_posterior is -670.1294535888233 on iteration 6.
# Iteration=7
# new_angles=[0.49368719]
# new_P:
# [[0.02653047+0.j]]
# Log_posterior is -670.121981482672 on iteration 7.
# Iteration=8
# new_angles=[0.49320208]
# new_P:
# [[0.02654749+0.j]]
# Log_posterior is -670.1144734076594 on iteration 8.
# Iteration=9
# new_angles=[0.49271709]
# new_P:
# [[0.02656455+0.j]]
# Log_posterior is -670.1069390581898 on iteration 9.
# Iteration=10
# new_angles=[0.49223222]
# new_P:
# [[0.02658165+0.j]]
# Log_posterior is -670.099381857591 on iteration 10.
# Iteration=11
# new_angles=[0.49174102]
# new_P:
# [[0.0265988+0.j]]
# Log_posterior is -670.0917887134126 on iteration 11.
# Iteration=12
# new_angles=[0.49124995]
# new_P:
# [[0.02661599+0.j]]
# Log_posterior is -670.0841771827221 on iteration 12.
# Iteration=13
# new_angles=[0.49075902]
# new_P:
# [[0.02663322+0.j]]
# Log_posterior is -670.0765514247457 on iteration 13.
# Iteration=14
# new_angles=[0.4902682]
# new_P:
# [[0.0266505+0.j]]
# Log_posterior is -670.0689146119137 on iteration 14.
# Iteration=15
# new_angles=[0.48977752]
# new_P:
# [[0.02666782+0.j]]
# Log_posterior is -670.0612698595573 on iteration 15.
# Iteration=16
# new_angles=[0.48929342]
# new_P:
# [[0.02668518+0.j]]
# Log_posterior is -670.0536367475923 on iteration 16.
# Iteration=17
# new_angles=[0.48880944]
# new_P:
# [[0.02670258+0.j]]
# Log_posterior is -670.0460030445612 on iteration 17.
# Iteration=18
# new_angles=[0.48833603]
# new_P:
# [[0.02672002+0.j]]
# Log_posterior is -670.0383971387856 on iteration 18.
# Iteration=19
# new_angles=[0.48786273]
# new_P:
# [[0.0267375+0.j]]
# Log_posterior is -670.0307970079707 on iteration 19.
# Iteration=20
# new_angles=[0.48739153]
# new_P:
# [[0.02675501+0.j]]
# Log_posterior is -670.0232086212035 on iteration 20.
# 12-th start
# theta=[0.61180126],P=[[8.06311518e-08-5.29395592e-24j]]
# Inital log_posterior = -6821694.871886148
# Iteration=1
# new_angles=[0.60712296]
# new_P:
# [[0.02510033+0.j]]
# Log_posterior is -670.4066902114174 on iteration 1.
# Iteration=2
# new_angles=[0.60652163]
# new_P:
# [[0.02643106+0.j]]
# Log_posterior is -669.8446384164386 on iteration 2.
# Iteration=3
# new_angles=[0.60586793]
# new_P:
# [[0.02652616+0.j]]
# Log_posterior is -669.8051129405468 on iteration 3.
# Iteration=4
# new_angles=[0.60517827]
# new_P:
# [[0.02654822+0.j]]
# Log_posterior is -669.7935800004531 on iteration 4.
# Iteration=5
# new_angles=[0.60443737]
# new_P:
# [[0.02656597+0.j]]
# Log_posterior is -669.7832527374167 on iteration 5.
# Iteration=6
# new_angles=[0.60365807]
# new_P:
# [[0.02658358+0.j]]
# Log_posterior is -669.7725537039105 on iteration 6.
# Iteration=7
# new_angles=[0.60283587]
# new_P:
# [[0.02660131+0.j]]
# Log_posterior is -669.7613447271224 on iteration 7.
# Iteration=8
# new_angles=[0.60196167]
# new_P:
# [[0.02661918+0.j]]
# Log_posterior is -669.7495477753079 on iteration 8.
# Iteration=9
# new_angles=[0.60106642]
# new_P:
# [[0.02663721+0.j]]
# Log_posterior is -669.7373283521003 on iteration 9.
# Iteration=10
# new_angles=[0.60011931]
# new_P:
# [[0.02665537+0.j]]
# Log_posterior is -669.7245179617996 on iteration 10.
# Iteration=11
# new_angles=[0.59915483]
# new_P:
# [[0.02667368+0.j]]
# Log_posterior is -669.71132817514 on iteration 11.
# Iteration=12
# new_angles=[0.59815676]
# new_P:
# [[0.02669211+0.j]]
# Log_posterior is -669.6976938460678 on iteration 12.
# Iteration=13
# new_angles=[0.59713873]
# new_P:
# [[0.02671067+0.j]]
# Log_posterior is -669.6837285232086 on iteration 13.
# Iteration=14
# new_angles=[0.59612139]
# new_P:
# [[0.02672934+0.j]]
# Log_posterior is -669.6696214139616 on iteration 14.
# Iteration=15
# new_angles=[0.59510029]
# new_P:
# [[0.02674809+0.j]]
# Log_posterior is -669.6554000666113 on iteration 15.
# Iteration=16
# new_angles=[0.59408337]
# new_P:
# [[0.0267669+0.j]]
# Log_posterior is -669.6411660085345 on iteration 16.
# Iteration=17
# new_angles=[0.59306814]
# new_P:
# [[0.02678576+0.j]]
# Log_posterior is -669.6269527292853 on iteration 17.
# Iteration=18
# new_angles=[0.59206152]
# new_P:
# [[0.02680466+0.j]]
# Log_posterior is -669.6128522646306 on iteration 18.
# Iteration=19
# new_angles=[0.59109876]
# new_P:
# [[0.02682358+0.j]]
# Log_posterior is -669.5991485071708 on iteration 19.
# Iteration=20
# new_angles=[0.59014641]
# new_P:
# [[0.02684247+0.j]]
# Log_posterior is -669.5856604350677 on iteration 20.
# 13-th start
# theta=[0.74517223],P=[[9.99993584e-08+7.94093388e-24j]]
# Inital log_posterior = -5500547.567162023
# Iteration=1
# new_angles=[0.74650508]
# new_P:
# [[0.02510051+0.j]]
# Log_posterior is -669.6396779549125 on iteration 1.
# Iteration=2
# new_angles=[0.73809758]
# new_P:
# [[0.02657579+0.j]]
# Log_posterior is -668.6136089133738 on iteration 2.
# Iteration=3
# new_angles=[0.73121476]
# new_P:
# [[0.02676892+0.j]]
# Log_posterior is -668.2444601496078 on iteration 3.
# Iteration=4
# new_angles=[0.72561135]
# new_P:
# [[0.02685775+0.j]]
# Log_posterior is -667.9952367274743 on iteration 4.
# Iteration=5
# new_angles=[0.72109159]
# new_P:
# [[0.02692384+0.j]]
# Log_posterior is -667.8179802968457 on iteration 5.
# Iteration=6
# new_angles=[0.71742598]
# new_P:
# [[0.02697585+0.j]]
# Log_posterior is -667.6922286361355 on iteration 6.
# Iteration=7
# new_angles=[0.71444501]
# new_P:
# [[0.02701768+0.j]]
# Log_posterior is -667.6031602444841 on iteration 7.
# Iteration=8
# new_angles=[0.71202701]
# new_P:
# [[0.02705221+0.j]]
# Log_posterior is -667.5399378042551 on iteration 8.
# Iteration=9
# new_angles=[0.71005341]
# new_P:
# [[0.02708159+0.j]]
# Log_posterior is -667.4943224306262 on iteration 9.
# Iteration=10
# new_angles=[0.7084441]
# new_P:
# [[0.02710745+0.j]]
# Log_posterior is -667.4607842484065 on iteration 10.
# Iteration=11
# new_angles=[0.70712187]
# new_P:
# [[0.0271309+0.j]]
# Log_posterior is -667.4353629843886 on iteration 11.
# Iteration=12
# new_angles=[0.7060349]
# new_P:
# [[0.02715275+0.j]]
# Log_posterior is -667.4154805566207 on iteration 12.
# Iteration=13
# new_angles=[0.70513844]
# new_P:
# [[0.0271735+0.j]]
# Log_posterior is -667.399361352301 on iteration 13.
# Iteration=14
# new_angles=[0.70440822]
# new_P:
# [[0.02719353+0.j]]
# Log_posterior is -667.3858736239533 on iteration 14.
# Iteration=15
# new_angles=[0.70379316]
# new_P:
# [[0.02721306+0.j]]
# Log_posterior is -667.3740629233728 on iteration 15.
# Iteration=16
# new_angles=[0.70328736]
# new_P:
# [[0.02723229+0.j]]
# Log_posterior is -667.3634715267127 on iteration 16.
# Iteration=17
# new_angles=[0.70288732]
# new_P:
# [[0.02725132+0.j]]
# Log_posterior is -667.3537725214553 on iteration 17.
# Iteration=18
# new_angles=[0.70253947]
# new_P:
# [[0.0272702+0.j]]
# Log_posterior is -667.3445656549627 on iteration 18.
# Iteration=19
# new_angles=[0.70224752]
# new_P:
# [[0.02728903+0.j]]
# Log_posterior is -667.3357345729769 on iteration 19.
# Iteration=20
# new_angles=[0.702007]
# new_P:
# [[0.02730782+0.j]]
# Log_posterior is -667.3271779190736 on iteration 20.
# 14-th start
# theta=[0.81529611],P=[[4.8828125e-08+0.j]]
# Inital log_posterior = -11264504.394715887
# Iteration=1
# new_angles=[0.81529611]
# new_P:
# [[0.02510017+0.j]]
# Log_posterior is -671.152629343693 on iteration 1.
# Iteration=2
# new_angles=[0.81371397]
# new_P:
# [[0.02628824+0.j]]
# Log_posterior is -670.6778982702081 on iteration 2.
# Iteration=3
# new_angles=[0.81185085]
# new_P:
# [[0.02636223+0.j]]
# Log_posterior is -670.6457219439134 on iteration 3.
# Iteration=4
# new_angles=[0.80954761]
# new_P:
# [[0.02638251+0.j]]
# Log_posterior is -670.6304905635942 on iteration 4.
# Iteration=5
# new_angles=[0.80662402]
# new_P:
# [[0.02640072+0.j]]
# Log_posterior is -670.6109316712713 on iteration 5.
# Iteration=6
# new_angles=[0.80283851]
# new_P:
# [[0.02641988+0.j]]
# Log_posterior is -670.581446546078 on iteration 6.
# Iteration=7
# new_angles=[0.7978393]
# new_P:
# [[0.02644106+0.j]]
# Log_posterior is -670.5322042488843 on iteration 7.
# Iteration=8
# new_angles=[0.79117433]
# new_P:
# [[0.0264662+0.j]]
# Log_posterior is -670.4427286367104 on iteration 8.
# Iteration=9
# new_angles=[0.78261612]
# new_P:
# [[0.02649937+0.j]]
# Log_posterior is -670.2782266993411 on iteration 9.
# Iteration=10
# new_angles=[0.77255146]
# new_P:
# [[0.02654749+0.j]]
# Log_posterior is -670.0024114403956 on iteration 10.
# Iteration=11
# new_angles=[0.76203676]
# new_P:
# [[0.02661785+0.j]]
# Log_posterior is -669.6166465914599 on iteration 11.
# Iteration=12
# new_angles=[0.75212791]
# new_P:
# [[0.02671036+0.j]]
# Log_posterior is -669.1752480300579 on iteration 12.
# Iteration=13
# new_angles=[0.74339988]
# new_P:
# [[0.02681452+0.j]]
# Log_posterior is -668.7479050613559 on iteration 13.
# Iteration=14
# new_angles=[0.7360039]
# new_P:
# [[0.02691665+0.j]]
# Log_posterior is -668.3811689826052 on iteration 14.
# Iteration=15
# new_angles=[0.72984589]
# new_P:
# [[0.02700737+0.j]]
# Log_posterior is -668.089979491937 on iteration 15.
# Iteration=16
# new_angles=[0.7247708]
# new_P:
# [[0.02708339+0.j]]
# Log_posterior is -667.8701210417387 on iteration 16.
# Iteration=17
# new_angles=[0.72061297]
# new_P:
# [[0.02714528+0.j]]
# Log_posterior is -667.7091080432019 on iteration 17.
# Iteration=18
# new_angles=[0.71719891]
# new_P:
# [[0.02719536+0.j]]
# Log_posterior is -667.5925346063107 on iteration 18.
# Iteration=19
# new_angles=[0.71440462]
# new_P:
# [[0.02723644+0.j]]
# Log_posterior is -667.5086302556538 on iteration 19.
# Iteration=20
# new_angles=[0.71210372]
# new_P:
# [[0.02727085+0.j]]
# Log_posterior is -667.4477020895614 on iteration 20.
# 15-th start
# theta=[0.64780331],P=[[8.03558405e-08+0.j]]
# Inital log_posterior = -6845065.252687014
# Iteration=1
# new_angles=[0.64300145]
# new_P:
# [[0.02510023+0.j]]
# Log_posterior is -669.9838340297944 on iteration 1.
# Iteration=2
# new_angles=[0.64752029]
# new_P:
# [[0.02651114+0.j]]
# Log_posterior is -669.2231142874098 on iteration 2.
# Iteration=3
# new_angles=[0.65234675]
# new_P:
# [[0.02664853+0.j]]
# Log_posterior is -668.9919146237595 on iteration 3.
# Iteration=4
# new_angles=[0.65727473]
# new_P:
# [[0.026709+0.j]]
# Log_posterior is -668.7750855851791 on iteration 4.
# Iteration=5
# new_angles=[0.66221844]
# new_P:
# [[0.02676785+0.j]]
# Log_posterior is -668.5515043996152 on iteration 5.
# Iteration=6
# new_angles=[0.666973]
# new_P:
# [[0.02682839+0.j]]
# Log_posterior is -668.3350910158151 on iteration 6.
# Iteration=7
# new_angles=[0.67142046]
# new_P:
# [[0.0268878+0.j]]
# Log_posterior is -668.1376820729031 on iteration 7.
# Iteration=8
# new_angles=[0.67548389]
# new_P:
# [[0.02694372+0.j]]
# Log_posterior is -667.9666008932261 on iteration 8.
# Iteration=9
# new_angles=[0.67912528]
# new_P:
# [[0.0269946+0.j]]
# Log_posterior is -667.8244299753451 on iteration 9.
# Iteration=10
# new_angles=[0.68233126]
# new_P:
# [[0.02703986+0.j]]
# Log_posterior is -667.7102553775075 on iteration 10.
# Iteration=11
# new_angles=[0.68512558]
# new_P:
# [[0.02707963+0.j]]
# Log_posterior is -667.6205226830481 on iteration 11.
# Iteration=12
# new_angles=[0.68753135]
# new_P:
# [[0.02711454+0.j]]
# Log_posterior is -667.5511627475973 on iteration 12.
# Iteration=13
# new_angles=[0.68959846]
# new_P:
# [[0.02714541+0.j]]
# Log_posterior is -667.4976985766184 on iteration 13.
# Iteration=14
# new_angles=[0.69135215]
# new_P:
# [[0.02717309+0.j]]
# Log_posterior is -667.4566497030827 on iteration 14.
# Iteration=15
# new_angles=[0.69285034]
# new_P:
# [[0.0271983+0.j]]
# Log_posterior is -667.4246507905161 on iteration 15.
# Iteration=16
# new_angles=[0.69412022]
# new_P:
# [[0.02722169+0.j]]
# Log_posterior is -667.3994231168767 on iteration 16.
# Iteration=17
# new_angles=[0.69517836]
# new_P:
# [[0.02724374+0.j]]
# Log_posterior is -667.3792847763057 on iteration 17.
# Iteration=18
# new_angles=[0.69606732]
# new_P:
# [[0.02726479+0.j]]
# Log_posterior is -667.3626984959839 on iteration 18.
# Iteration=19
# new_angles=[0.69682249]
# new_P:
# [[0.02728516+0.j]]
# Log_posterior is -667.3485753942488 on iteration 19.
# Iteration=20
# new_angles=[0.69744497]
# new_P:
# [[0.02730505+0.j]]
# Log_posterior is -667.3363236021219 on iteration 20.
# 16-th start
# theta=[0.22711654],P=[[4.8828125e-08+0.j]]
# Inital log_posterior = -11264504.394715782
# Iteration=1
# new_angles=[0.22711654]
# new_P:
# [[0.02510018+0.j]]
# Log_posterior is -671.1015538557243 on iteration 1.
# Iteration=2
# new_angles=[0.22598909]
# new_P:
# [[0.02629824+0.j]]
# Log_posterior is -670.6193031047251 on iteration 2.
# Iteration=3
# new_angles=[0.2248714]
# new_P:
# [[0.02637394+0.j]]
# Log_posterior is -670.586372952498 on iteration 3.
# Iteration=4
# new_angles=[0.22374704]
# new_P:
# [[0.02639436+0.j]]
# Log_posterior is -670.5737728637989 on iteration 4.
# Iteration=5
# new_angles=[0.22262297]
# new_P:
# [[0.02641204+0.j]]
# Log_posterior is -670.5621581112066 on iteration 5.
# Iteration=6
# new_angles=[0.22149919]
# new_P:
# [[0.02642963+0.j]]
# Log_posterior is -670.5505895637372 on iteration 6.
# Iteration=7
# new_angles=[0.22043824]
# new_P:
# [[0.02644726+0.j]]
# Log_posterior is -670.5393315303828 on iteration 7.
# Iteration=8
# new_angles=[0.21938448]
# new_P:
# [[0.02646486+0.j]]
# Log_posterior is -670.5281724564685 on iteration 8.
# Iteration=9
# new_angles=[0.21838122]
# new_P:
# [[0.02648249+0.j]]
# Log_posterior is -670.5173087606827 on iteration 9.
# Iteration=10
# new_angles=[0.21740685]
# new_P:
# [[0.0265001+0.j]]
# Log_posterior is -670.5066698399235 on iteration 10.
# Iteration=11
# new_angles=[0.21646652]
# new_P:
# [[0.0265177+0.j]]
# Log_posterior is -670.4962814420352 on iteration 11.
# Iteration=12
# new_angles=[0.21553865]
# new_P:
# [[0.0265353+0.j]]
# Log_posterior is -670.4860615631719 on iteration 12.
# Iteration=13
# new_angles=[0.21467344]
# new_P:
# [[0.0265529+0.j]]
# Log_posterior is -670.4762128581634 on iteration 13.
# Iteration=14
# new_angles=[0.21384537]
# new_P:
# [[0.02657048+0.j]]
# Log_posterior is -670.4666397995638 on iteration 14.
# Iteration=15
# new_angles=[0.21305343]
# new_P:
# [[0.02658804+0.j]]
# Log_posterior is -670.4573265176624 on iteration 15.
# Iteration=16
# new_angles=[0.2123013]
# new_P:
# [[0.02660558+0.j]]
# Log_posterior is -670.4482784692186 on iteration 16.
# Iteration=17
# new_angles=[0.21157204]
# new_P:
# [[0.02662312+0.j]]
# Log_posterior is -670.4394280181592 on iteration 17.
# Iteration=18
# new_angles=[0.21089483]
# new_P:
# [[0.02664066+0.j]]
# Log_posterior is -670.4308627672485 on iteration 18.
# Iteration=19
# new_angles=[0.21023895]
# new_P:
# [[0.02665818+0.j]]
# Log_posterior is -670.4224747095859 on iteration 19.
# Iteration=20
# new_angles=[0.20963482]
# new_P:
# [[0.02667571+0.j]]
# Log_posterior is -670.4143437101204 on iteration 20.
# 17-th start
# theta=[0.45039062],P=[[4.93435618e-08-4.76456033e-23j]]
# Inital log_posterior = -11146842.136829069
# Iteration=1
# new_angles=[0.45481234]
# new_P:
# [[0.02510014+0.j]]
# Log_posterior is -670.745726365441 on iteration 1.
# Iteration=2
# new_angles=[0.45671253]
# new_P:
# [[0.02636561+0.j]]
# Log_posterior is -670.2125009108116 on iteration 2.
# Iteration=3
# new_angles=[0.45837875]
# new_P:
# [[0.02645303+0.j]]
# Log_posterior is -670.1676989294572 on iteration 3.
# Iteration=4
# new_angles=[0.45981883]
# new_P:
# [[0.02647597+0.j]]
# Log_posterior is -670.1499293831224 on iteration 4.
# Iteration=5
# new_angles=[0.46111605]
# new_P:
# [[0.02649484+0.j]]
# Log_posterior is -670.1353923721628 on iteration 5.
# Iteration=6
# new_angles=[0.4622719]
# new_P:
# [[0.02651318+0.j]]
# Log_posterior is -670.1225022286998 on iteration 6.
# Iteration=7
# new_angles=[0.46330858]
# new_P:
# [[0.02653125+0.j]]
# Log_posterior is -670.110847118031 on iteration 7.
# Iteration=8
# new_angles=[0.46425179]
# new_P:
# [[0.02654911+0.j]]
# Log_posterior is -670.100127609123 on iteration 8.
# Iteration=9
# new_angles=[0.46508461]
# new_P:
# [[0.02656683+0.j]]
# Log_posterior is -670.0902662108357 on iteration 9.
# Iteration=10
# new_angles=[0.46582955]
# new_P:
# [[0.02658442+0.j]]
# Log_posterior is -670.0810595244528 on iteration 10.
# Iteration=11
# new_angles=[0.46650564]
# new_P:
# [[0.02660192+0.j]]
# Log_posterior is -670.0723469464496 on iteration 11.
# Iteration=12
# new_angles=[0.46712077]
# new_P:
# [[0.02661936+0.j]]
# Log_posterior is -670.0640330866457 on iteration 12.
# Iteration=13
# new_angles=[0.46767045]
# new_P:
# [[0.02663676+0.j]]
# Log_posterior is -670.0560740523833 on iteration 13.
# Iteration=14
# new_angles=[0.46818276]
# new_P:
# [[0.02665413+0.j]]
# Log_posterior is -670.0483529300151 on iteration 14.
# Iteration=15
# new_angles=[0.46862679]
# new_P:
# [[0.02667149+0.j]]
# Log_posterior is -670.040905072486 on iteration 15.
# Iteration=16
# new_angles=[0.46904764]
# new_P:
# [[0.02668884+0.j]]
# Log_posterior is -670.0336024144231 on iteration 16.
# Iteration=17
# new_angles=[0.46942342]
# new_P:
# [[0.02670619+0.j]]
# Log_posterior is -670.0264644787076 on iteration 17.
# Iteration=18
# new_angles=[0.46977598]
# new_P:
# [[0.02672355+0.j]]
# Log_posterior is -670.0194334376027 on iteration 18.
# Iteration=19
# new_angles=[0.47011188]
# new_P:
# [[0.02674093+0.j]]
# Log_posterior is -670.0124839643395 on iteration 19.
# Iteration=20
# new_angles=[0.4704047]
# new_P:
# [[0.02675834+0.j]]
# Log_posterior is -670.0056476046989 on iteration 20.
# 18-th start
# theta=[1.57079633],P=[[8.75235434e-08-2.70617725e-23j]]
# Inital log_posterior = -6284534.276544974
# Iteration=1
# new_angles=[-1.4457148]
# new_P:
# [[0.02510038+0.j]]
# Log_posterior is -670.8796714120721 on iteration 1.
# Iteration=2
# new_angles=[-1.48100738]
# new_P:
# [[0.02634032+0.j]]
# Log_posterior is -670.2965572475825 on iteration 2.
# Iteration=3
# new_angles=[-1.53954506]
# new_P:
# [[0.02643698+0.j]]
# Log_posterior is -670.1866567974133 on iteration 3.
# Iteration=4
# new_angles=[-1.57079633]
# new_P:
# [[0.02647257+0.j]]
# Log_posterior is -670.1633560005713 on iteration 4.
# Iteration=5
# new_angles=[-1.57079633]
# new_P:
# [[0.02649227+0.j]]
# Log_posterior is -670.1559535837076 on iteration 5.
# Iteration=6
# new_angles=[-1.57079633]
# new_P:
# [[0.02650914+0.j]]
# Log_posterior is -670.1496284642188 on iteration 6.
# Iteration=7
# new_angles=[-1.57079633]
# new_P:
# [[0.02652588+0.j]]
# Log_posterior is -670.1433636683101 on iteration 7.
# Iteration=8
# new_angles=[-1.57079633]
# new_P:
# [[0.02654265+0.j]]
# Log_posterior is -670.1371004087642 on iteration 8.
# Iteration=9
# new_angles=[-1.57079633]
# new_P:
# [[0.02655946+0.j]]
# Log_posterior is -670.1308352229169 on iteration 9.
# Iteration=10
# new_angles=[-1.57079633]
# new_P:
# [[0.0265763+0.j]]
# Log_posterior is -670.1245679022903 on iteration 10.
# Iteration=11
# new_angles=[-1.57079633]
# new_P:
# [[0.02659319+0.j]]
# Log_posterior is -670.1182984333129 on iteration 11.
# Iteration=12
# new_angles=[-1.57079633]
# new_P:
# [[0.02661011+0.j]]
# Log_posterior is -670.1120268143055 on iteration 12.
# Iteration=13
# new_angles=[-1.57079633]
# new_P:
# [[0.02662708+0.j]]
# Log_posterior is -670.1057530443396 on iteration 13.
# Iteration=14
# new_angles=[1.49423107]
# new_P:
# [[0.02664408+0.j]]
# Log_posterior is -670.0413954521414 on iteration 14.
# Iteration=15
# new_angles=[1.46477277]
# new_P:
# [[0.02667276+0.j]]
# Log_posterior is -669.9804671853219 on iteration 15.
# Iteration=16
# new_angles=[1.44377285]
# new_P:
# [[0.02670077+0.j]]
# Log_posterior is -669.927254343172 on iteration 16.
# Iteration=17
# new_angles=[1.42746819]
# new_P:
# [[0.02672731+0.j]]
# Log_posterior is -669.8815292245624 on iteration 17.
# Iteration=18
# new_angles=[1.41399561]
# new_P:
# [[0.02675243+0.j]]
# Log_posterior is -669.8417352066165 on iteration 18.
# Iteration=19
# new_angles=[1.40267508]
# new_P:
# [[0.02677643+0.j]]
# Log_posterior is -669.8072537492135 on iteration 19.
# Iteration=20
# new_angles=[1.39309673]
# new_P:
# [[0.02679943+0.j]]
# Log_posterior is -669.7775087229114 on iteration 20.
# 19-th start
# theta=[0.75399535],P=[[7.64820505e-08-1.0753348e-24j]]
# Inital log_posterior = -7191739.121224152
# Iteration=1
# new_angles=[0.75399535]
# new_P:
# [[0.02510032+0.j]]
# Log_posterior is -669.9486905536276 on iteration 1.
# Iteration=2
# new_angles=[0.74441282]
# new_P:
# [[0.02651714+0.j]]
# Log_posterior is -668.9150399678383 on iteration 2.
# Iteration=3
# new_angles=[0.736419]
# new_P:
# [[0.02670925+0.j]]
# Log_posterior is -668.4852178409582 on iteration 3.
# Iteration=4
# new_angles=[0.7298882]
# new_P:
# [[0.02680963+0.j]]
# Log_posterior is -668.1748542489528 on iteration 4.
# Iteration=5
# new_angles=[0.72456975]
# new_P:
# [[0.02688769+0.j]]
# Log_posterior is -667.9461887377811 on iteration 5.
# Iteration=6
# new_angles=[0.72025782]
# new_P:
# [[0.02694988+0.j]]
# Log_posterior is -667.78180066771 on iteration 6.
# Iteration=7
# new_angles=[0.71676386]
# new_P:
# [[0.02699944+0.j]]
# Log_posterior is -667.6652204735148 on iteration 7.
# Iteration=8
# new_angles=[0.71391931]
# new_P:
# [[0.02703952+0.j]]
# Log_posterior is -667.582491316632 on iteration 8.
# Iteration=9
# new_angles=[0.7116055]
# new_P:
# [[0.02707285+0.j]]
# Log_posterior is -667.5234846073762 on iteration 9.
# Iteration=10
# new_angles=[0.7097163]
# new_P:
# [[0.02710144+0.j]]
# Log_posterior is -667.4807213929963 on iteration 10.
# Iteration=11
# new_angles=[0.70817893]
# new_P:
# [[0.02712678+0.j]]
# Log_posterior is -667.449145005392 on iteration 11.
# Iteration=12
# new_angles=[0.70690605]
# new_P:
# [[0.02714988+0.j]]
# Log_posterior is -667.424944556161 on iteration 12.
# Iteration=13
# new_angles=[0.70585937]
# new_P:
# [[0.02717153+0.j]]
# Log_posterior is -667.405879268951 on iteration 13.
# Iteration=14
# new_angles=[0.70500311]
# new_P:
# [[0.02719216+0.j]]
# Log_posterior is -667.3903627819536 on iteration 14.
# Iteration=15
# new_angles=[0.70428528]
# new_P:
# [[0.02721211+0.j]]
# Log_posterior is -667.377155662647 on iteration 15.
# Iteration=16
# new_angles=[0.70369685]
# new_P:
# [[0.02723163+0.j]]
# Log_posterior is -667.3656174932726 on iteration 16.
# Iteration=17
# new_angles=[0.70321595]
# new_P:
# [[0.02725085+0.j]]
# Log_posterior is -667.3552256953228 on iteration 17.
# Iteration=18
# new_angles=[0.70281913]
# new_P:
# [[0.02726988+0.j]]
# Log_posterior is -667.3455967829203 on iteration 18.
# Iteration=19
# new_angles=[0.70248476]
# new_P:
# [[0.02728879+0.j]]
# Log_posterior is -667.3364683837307 on iteration 19.
# Iteration=20
# new_angles=[0.70220755]
# new_P:
# [[0.02730765+0.j]]
# Log_posterior is -667.3277004089827 on iteration 20.
# best_start=5
# Время выполнения функции: 163.641164 секунд

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.70113993]), array([[0.02730827+0.j]]))

# %%
lf.log_posterior(X2_with_mv, EM_theta2_rad, EM_P2, Q2, Psi, nu), lf.log_posterior(X2_with_mv, theta2_rad, P2, Q2, Psi, nu)
# Out:
# (np.float64(-667.3258168558082), np.float64(-667.1221200222807))
