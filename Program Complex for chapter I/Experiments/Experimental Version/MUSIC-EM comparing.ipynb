# %%
import numpy as np

# %%
from pathlib import Path
import sys

try:
    ROOT = Path().resolve().parents[1]
    assert (ROOT / "common").exists()
except AssertionError:
    ROOT = next(p for p in Path().resolve().parents if (p / "common").exists())

if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
#print(ROOT)

# %%
from common import sensors as sn 
from common import subspace_methods as sm
from common import em_tools as em
from common import log_funcs as lf

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12

failing_sensors1 = np.arange(5)
gap_ratio1 = 0.5 * np.ones_like(failing_sensors1, dtype=np.float32)

theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sn.gss(Num_emitters1, sample_size1, P1)
N1 = sn.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sn.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sn.initial_Cov(X1_with_mv)
MUSIC_theta1 = sm.MUSIC_DoA(R1, Num_emitters1)

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sn.SNR(A1, P1, Q1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1, lhd_list1, angles_list1 = em.multistart_EM(X1_with_mv, 
                                                                        Num_emitters1, 
                                                                        Q=Q1,
                                                                        theta_guess=MUSIC_theta1, 
                                                                        num_of_starts=10, 
                                                                        max_iter=20, 
                                                                        rtol_params=1e-6,
                                                                        rtol_lkhd=1e-6,
                                                                        reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.71558499],P=[[1.18642836e-07-1.98523347e-24j]]
# Inital likelihood = -870.4011155592349
# Iteration=1
# new_angles=[0.72207638]
# likelihood is -870.3923435488267 on iteration 1.
# Iteration=2
# new_angles=[0.71688292]
# likelihood is -870.3823358969338 on iteration 2.
# Iteration=3
# new_angles=[0.71263946]
# likelihood is -870.3716135091055 on iteration 3.
# Iteration=4
# new_angles=[0.70942051]
# likelihood is -870.3605813225518 on iteration 4.
# Iteration=5
# new_angles=[0.70684918]
# likelihood is -870.3493290350375 on iteration 5.
# Iteration=6
# new_angles=[0.70492438]
# likelihood is -870.3379305872429 on iteration 6.
# Iteration=7
# new_angles=[0.70328208]
# likelihood is -870.3262799680947 on iteration 7.
# Iteration=8
# new_angles=[0.70200241]
# likelihood is -870.3143694316464 on iteration 8.
# Iteration=9
# new_angles=[0.70090075]
# likelihood is -870.302088983878 on iteration 9.
# Iteration=10
# new_angles=[0.69990221]
# likelihood is -870.289347337437 on iteration 10.
# Iteration=11
# new_angles=[0.69922347]
# likelihood is -870.2760986484135 on iteration 11.
# Iteration=12
# new_angles=[0.6986774]
# likelihood is -870.2621840190832 on iteration 12.
# Iteration=13
# new_angles=[0.6982753]
# likelihood is -870.2474699877887 on iteration 13.
# Iteration=14
# new_angles=[0.69790237]
# likelihood is -870.231777245195 on iteration 14.
# Iteration=15
# new_angles=[0.69758696]
# likelihood is -870.2149191058608 on iteration 15.
# Iteration=16
# new_angles=[0.69736009]
# likelihood is -870.1966642103627 on iteration 16.
# Iteration=17
# new_angles=[0.69721663]
# likelihood is -870.1767205224869 on iteration 17.
# Iteration=18
# new_angles=[0.69707319]
# likelihood is -870.1547161504155 on iteration 18.
# Iteration=19
# new_angles=[0.69693084]
# likelihood is -870.1301911019478 on iteration 19.
# Iteration=20
# new_angles=[0.69687666]
# likelihood is -870.102557428791 on iteration 20.
# 1-th start
# theta=[0.75761751],P=[[7.62531873e-08-2.64697796e-24j]]
# Inital likelihood = -870.4011243940959
# Iteration=1
# new_angles=[0.75852232]
# likelihood is -870.3980371988739 on iteration 1.
# Iteration=2
# new_angles=[0.74648545]
# likelihood is -870.3913034556049 on iteration 2.
# Iteration=3
# new_angles=[0.73598934]
# likelihood is -870.3812098336941 on iteration 3.
# Iteration=4
# new_angles=[0.72774315]
# likelihood is -870.3693001481623 on iteration 4.
# Iteration=5
# new_angles=[0.72131621]
# likelihood is -870.3566410800721 on iteration 5.
# Iteration=6
# new_angles=[0.71621934]
# likelihood is -870.3437197452242 on iteration 6.
# Iteration=7
# new_angles=[0.71219656]
# likelihood is -870.3307712640807 on iteration 7.
# Iteration=8
# new_angles=[0.70906818]
# likelihood is -870.3178399505332 on iteration 8.
# Iteration=9
# new_angles=[0.70658998]
# likelihood is -870.3047975506119 on iteration 9.
# Iteration=10
# new_angles=[0.70461107]
# likelihood is -870.2915103038314 on iteration 10.
# Iteration=11
# new_angles=[0.70301311]
# likelihood is -870.2778286776804 on iteration 11.
# Iteration=12
# new_angles=[0.70173693]
# likelihood is -870.2636086075324 on iteration 12.
# Iteration=13
# new_angles=[0.70072394]
# likelihood is -870.2486827440872 on iteration 13.
# Iteration=14
# new_angles=[0.69994153]
# likelihood is -870.2328694954078 on iteration 14.
# Iteration=15
# new_angles=[0.69926276]
# likelihood is -870.2159275551719 on iteration 15.
# Iteration=16
# new_angles=[0.69871668]
# likelihood is -870.197630532673 on iteration 16.
# Iteration=17
# new_angles=[0.69825535]
# likelihood is -870.1776735605954 on iteration 17.
# Iteration=18
# new_angles=[0.69789614]
# likelihood is -870.1556976035262 on iteration 18.
# Iteration=19
# new_angles=[0.69758074]
# likelihood is -870.1312301776287 on iteration 19.
# Iteration=20
# new_angles=[0.69735387]
# likelihood is -870.103687754222 on iteration 20.
# 2-th start
# theta=[0.75275765],P=[[4.72357604e-08-5.62482817e-24j]]
# Inital likelihood = -870.4011249844442
# Iteration=1
# new_angles=[0.75275765]
# likelihood is -870.3972087573839 on iteration 1.
# Iteration=2
# new_angles=[0.7421057]
# likelihood is -870.3898898841412 on iteration 2.
# Iteration=3
# new_angles=[0.73286991]
# likelihood is -870.3797198925328 on iteration 3.
# Iteration=4
# new_angles=[0.72551978]
# likelihood is -870.368013713579 on iteration 4.
# Iteration=5
# new_angles=[0.71965356]
# likelihood is -870.355597334092 on iteration 5.
# Iteration=6
# new_angles=[0.71497195]
# likelihood is -870.3429256870395 on iteration 6.
# Iteration=7
# new_angles=[0.71119138]
# likelihood is -870.3301491301015 on iteration 7.
# Iteration=8
# new_angles=[0.70825376]
# likelihood is -870.317360027403 on iteration 8.
# Iteration=9
# new_angles=[0.70592194]
# likelihood is -870.3044275909109 on iteration 9.
# Iteration=10
# new_angles=[0.70409083]
# likelihood is -870.291240132611 on iteration 10.
# Iteration=11
# new_angles=[0.70258242]
# likelihood is -870.2776198355316 on iteration 11.
# Iteration=12
# new_angles=[0.70139547]
# likelihood is -870.2634517637086 on iteration 12.
# Iteration=13
# new_angles=[0.70042967]
# likelihood is -870.2485541606163 on iteration 13.
# Iteration=14
# new_angles=[0.69964745]
# likelihood is -870.2327487449313 on iteration 14.
# Iteration=15
# new_angles=[0.69901259]
# likelihood is -870.215826772038 on iteration 15.
# Iteration=16
# new_angles=[0.69855116]
# likelihood is -870.1975555833745 on iteration 16.
# Iteration=17
# new_angles=[0.6981491]
# likelihood is -870.1776134636314 on iteration 17.
# Iteration=18
# new_angles=[0.697823]
# likelihood is -870.1556429725011 on iteration 18.
# Iteration=19
# new_angles=[0.69758521]
# likelihood is -870.131186589887 on iteration 19.
# Iteration=20
# new_angles=[0.69735834]
# likelihood is -870.1036385166789 on iteration 20.
# 3-th start
# theta=[0.82383174],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -870.4011268160693
# Iteration=1
# new_angles=[0.82383174]
# likelihood is -870.401097126884 on iteration 1.
# Likelihood is converged!
# 4-th start
# theta=[0.72131738],P=[[1.09961713e-07-2.97785021e-24j]]
# Inital likelihood = -870.4011171320063
# Iteration=1
# new_angles=[0.7278417]
# likelihood is -870.3931668768738 on iteration 1.
# Iteration=2
# new_angles=[0.7214142]
# likelihood is -870.3834431278541 on iteration 2.
# Iteration=3
# new_angles=[0.71631688]
# likelihood is -870.3727394253249 on iteration 3.
# Iteration=4
# new_angles=[0.71243907]
# likelihood is -870.3616078670675 on iteration 4.
# Iteration=5
# new_angles=[0.70921746]
# likelihood is -870.3501616019516 on iteration 5.
# Iteration=6
# new_angles=[0.70664978]
# likelihood is -870.3385391824335 on iteration 6.
# Iteration=7
# new_angles=[0.70472531]
# likelihood is -870.3267785509827 on iteration 7.
# Iteration=8
# new_angles=[0.70308329]
# likelihood is -870.3147333870579 on iteration 8.
# Iteration=9
# new_angles=[0.70180704]
# likelihood is -870.3023827158074 on iteration 9.
# Iteration=10
# new_angles=[0.700794]
# likelihood is -870.2896165011034 on iteration 10.
# Iteration=11
# new_angles=[0.70001154]
# likelihood is -870.2763290239099 on iteration 11.
# Iteration=12
# new_angles=[0.69936585]
# likelihood is -870.2623815443912 on iteration 12.
# Iteration=13
# new_angles=[0.69873115]
# likelihood is -870.247613639849 on iteration 13.
# Iteration=14
# new_angles=[0.69826982]
# likelihood is -870.231901703058 on iteration 14.
# Iteration=15
# new_angles=[0.69789689]
# likelihood is -870.215033299898 on iteration 15.
# Iteration=16
# new_angles=[0.69758149]
# likelihood is -870.1967680052908 on iteration 16.
# Iteration=17
# new_angles=[0.69735462]
# likelihood is -870.1768194021324 on iteration 17.
# Iteration=18
# new_angles=[0.69721116]
# likelihood is -870.1548221506616 on iteration 18.
# Iteration=19
# new_angles=[0.69706772]
# likelihood is -870.1303055111705 on iteration 19.
# Iteration=20
# new_angles=[0.69692537]
# likelihood is -870.1026758450593 on iteration 20.
# 5-th start
# theta=[0.69420695],P=[[2.63712642e-07-3.97046694e-24j]]
# Inital likelihood = -870.4010990043953
# Iteration=1
# new_angles=[0.69420695]
# likelihood is -870.3903426116663 on iteration 1.
# Iteration=2
# new_angles=[0.69447058]
# likelihood is -870.3797732735353 on iteration 2.
# Iteration=3
# new_angles=[0.69473427]
# likelihood is -870.3691412040844 on iteration 3.
# Iteration=4
# new_angles=[0.69501169]
# likelihood is -870.3584017254803 on iteration 4.
# Iteration=5
# new_angles=[0.69510317]
# likelihood is -870.3475146252745 on iteration 5.
# Iteration=6
# new_angles=[0.69536699]
# likelihood is -870.3364144444286 on iteration 6.
# Iteration=7
# new_angles=[0.69560189]
# likelihood is -870.325051104228 on iteration 7.
# Iteration=8
# new_angles=[0.69577775]
# likelihood is -870.3133610554731 on iteration 8.
# Iteration=9
# new_angles=[0.69586929]
# likelihood is -870.301271572834 on iteration 9.
# Iteration=10
# new_angles=[0.69596083]
# likelihood is -870.2886962073 on iteration 10.
# Iteration=11
# new_angles=[0.69605238]
# likelihood is -870.2755383355209 on iteration 11.
# Iteration=12
# new_angles=[0.69614393]
# likelihood is -870.2616851770925 on iteration 12.
# Iteration=13
# new_angles=[0.6962355]
# likelihood is -870.2470036220732 on iteration 13.
# Iteration=14
# new_angles=[0.69623868]
# likelihood is -870.2313359037169 on iteration 14.
# Iteration=15
# new_angles=[0.69624187]
# likelihood is -870.2144886838023 on iteration 15.
# Iteration=16
# new_angles=[0.69624505]
# likelihood is -870.1962274676137 on iteration 16.
# Iteration=17
# new_angles=[0.69624823]
# likelihood is -870.1762621672403 on iteration 17.
# Iteration=18
# new_angles=[0.69625142]
# likelihood is -870.1542291134261 on iteration 18.
# Iteration=19
# new_angles=[0.6962546]
# likelihood is -870.1296658085547 on iteration 19.
# Iteration=20
# new_angles=[0.69625779]
# likelihood is -870.1019748094141 on iteration 20.
# 6-th start
# theta=[0.72207198],P=[[1.08695785e-07+1.65436123e-24j]]
# Inital likelihood = -870.4011173514194
# Iteration=1
# new_angles=[0.72860067]
# likelihood is -870.3932823076648 on iteration 1.
# Iteration=2
# new_angles=[0.72170859]
# likelihood is -870.3835208581686 on iteration 2.
# Iteration=3
# new_angles=[0.71660997]
# likelihood is -870.3728375198448 on iteration 3.
# Iteration=4
# new_angles=[0.71273118]
# likelihood is -870.361717300503 on iteration 4.
# Iteration=5
# new_angles=[0.70951197]
# likelihood is -870.35027570092 on iteration 5.
# Iteration=6
# new_angles=[0.70694365]
# likelihood is -870.3386518898653 on iteration 6.
# Iteration=7
# new_angles=[0.7050187]
# likelihood is -870.3268884191152 on iteration 7.
# Iteration=8
# new_angles=[0.70337627]
# likelihood is -870.3148374776944 on iteration 8.
# Iteration=9
# new_angles=[0.7020965]
# likelihood is -870.3024799035016 on iteration 9.
# Iteration=10
# new_angles=[0.70099366]
# likelihood is -870.2896815042853 on iteration 10.
# Iteration=11
# new_angles=[0.7001275]
# likelihood is -870.2763683060645 on iteration 11.
# Iteration=12
# new_angles=[0.6994349]
# likelihood is -870.2624078052002 on iteration 12.
# Iteration=13
# new_angles=[0.69888873]
# likelihood is -870.247657545701 on iteration 13.
# Iteration=14
# new_angles=[0.69842626]
# likelihood is -870.2319429068568 on iteration 14.
# Iteration=15
# new_angles=[0.69805329]
# likelihood is -870.2150724463763 on iteration 15.
# Iteration=16
# new_angles=[0.69773784]
# likelihood is -870.1968052691954 on iteration 16.
# Iteration=17
# new_angles=[0.69742247]
# likelihood is -870.1768438047006 on iteration 17.
# Iteration=18
# new_angles=[0.69719564]
# likelihood is -870.1548379146327 on iteration 18.
# Iteration=19
# new_angles=[0.6970522]
# likelihood is -870.1303234463409 on iteration 19.
# Iteration=20
# new_angles=[0.69690985]
# likelihood is -870.1026964860154 on iteration 20.
# 7-th start
# theta=[0.83118872],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -870.4011267950915
# Iteration=1
# new_angles=[0.83118872]
# likelihood is -870.4010540618876 on iteration 1.
# Likelihood is converged!
# 8-th start
# theta=[0.85933204],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -870.4011268744408
# Iteration=1
# new_angles=[0.85933204]
# likelihood is -870.4012169873824 on iteration 1.
# Likelihood is converged!
# 9-th start
# theta=[0.73719288],P=[[7.93250092e-08-4.63221143e-24j]]
# Inital likelihood = -870.4011217367256
# Iteration=1
# new_angles=[0.74381132]
# likelihood is -870.3957658959068 on iteration 1.
# Iteration=2
# new_angles=[0.7341905]
# likelihood is -870.3872668789235 on iteration 2.
# Iteration=3
# new_angles=[0.72641955]
# likelihood is -870.3767081355625 on iteration 3.
# Iteration=4
# new_angles=[0.72040993]
# likelihood is -870.3651805524319 on iteration 4.
# Iteration=5
# new_angles=[0.71550632]
# likelihood is -870.3531193918759 on iteration 5.
# Iteration=6
# new_angles=[0.711724]
# likelihood is -870.3409391887512 on iteration 6.
# Iteration=7
# new_angles=[0.7087712]
# likelihood is -870.3286719895419 on iteration 7.
# Iteration=8
# new_angles=[0.70637873]
# likelihood is -870.3162315341161 on iteration 8.
# Iteration=9
# new_angles=[0.70444723]
# likelihood is -870.3035521033992 on iteration 9.
# Iteration=10
# new_angles=[0.7028056]
# likelihood is -870.2904977804972 on iteration 10.
# Iteration=11
# new_angles=[0.70152965]
# likelihood is -870.2770109377553 on iteration 11.
# Iteration=12
# new_angles=[0.70057118]
# likelihood is -870.2629499173237 on iteration 12.
# Iteration=13
# new_angles=[0.69978887]
# likelihood is -870.2481254029324 on iteration 13.
# Iteration=14
# new_angles=[0.69914331]
# likelihood is -870.2323636469722 on iteration 14.
# Iteration=15
# new_angles=[0.69859728]
# likelihood is -870.2154608810366 on iteration 15.
# Iteration=16
# new_angles=[0.6981952]
# likelihood is -870.1971905055177 on iteration 16.
# Iteration=17
# new_angles=[0.69786909]
# likelihood is -870.1772452815821 on iteration 17.
# Iteration=18
# new_angles=[0.69763129]
# likelihood is -870.1552642522864 on iteration 18.
# Iteration=19
# new_angles=[0.69739353]
# likelihood is -870.1307723481584 on iteration 19.
# Iteration=20
# new_angles=[0.69725007]
# likelihood is -870.1031917682157 on iteration 20.
# best_start=5
# Время выполнения функции: 30.076228 секунд

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.69625779]), array([[0.00285826+0.j]]))

# %%
lf.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q1), lf.incomplete_lkhd(X1_with_mv, theta1_rad, P1, Q1)
# Out:
# (np.float64(-870.1019748094141), np.float64(-852.4011191641745))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11

failing_sensors2 = np.arange(8)
gap_ratio2 = 0.5 * np.ones_like(failing_sensors2, dtype=np.float32)

theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sn.gss(Num_emitters2, sample_size2, P2)
N2 = sn.gss(Num_sensors2, sample_size2, Q2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sn.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sn.initial_Cov(X2_with_mv)
MUSIC_theta2 = sm.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sn.SNR(A2, P2, Q2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2, lhd_list2, angles_list2 = em.multistart_EM(X2_with_mv, 
                                                                        Num_emitters2, 
                                                                        Q=Q2,
                                                                        theta_guess=MUSIC_theta2, 
                                                                        num_of_starts=20, 
                                                                        max_iter=20, 
                                                                        rtol_params=1e-6,
                                                                        rtol_lkhd=1e-6,
                                                                        reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.72431164],P=[[7.5917774e-08+4.13590306e-24j]]
# Inital likelihood = -689.5792611594288
# Iteration=1
# new_angles=[0.72431164]
# likelihood is -689.5695600608823 on iteration 1.
# Iteration=2
# new_angles=[0.72004058]
# likelihood is -689.5587808820582 on iteration 2.
# Iteration=3
# new_angles=[0.7164188]
# likelihood is -689.5472974740945 on iteration 3.
# Iteration=4
# new_angles=[0.71346791]
# likelihood is -689.5353988983796 on iteration 4.
# Iteration=5
# new_angles=[0.71116887]
# likelihood is -689.5232343329268 on iteration 5.
# Iteration=6
# new_angles=[0.70932952]
# likelihood is -689.51078733156 on iteration 6.
# Iteration=7
# new_angles=[0.70781437]
# likelihood is -689.4979898916647 on iteration 7.
# Iteration=8
# new_angles=[0.70662213]
# likelihood is -689.4847758105063 on iteration 8.
# Iteration=9
# new_angles=[0.70560494]
# likelihood is -689.4709965194622 on iteration 9.
# Iteration=10
# new_angles=[0.70488891]
# likelihood is -689.456560015956 on iteration 10.
# Iteration=11
# new_angles=[0.70419351]
# likelihood is -689.441218257258 on iteration 11.
# Iteration=12
# new_angles=[0.70364515]
# likelihood is -689.4248075677481 on iteration 12.
# Iteration=13
# new_angles=[0.70309704]
# likelihood is -689.4070392475313 on iteration 13.
# Iteration=14
# new_angles=[0.70272259]
# likelihood is -689.3876406531388 on iteration 14.
# Iteration=15
# new_angles=[0.70236203]
# likelihood is -689.3661723127638 on iteration 15.
# Iteration=16
# new_angles=[0.70213425]
# likelihood is -689.342137652467 on iteration 16.
# Iteration=17
# new_angles=[0.70190651]
# likelihood is -689.3148231760201 on iteration 17.
# Iteration=18
# new_angles=[0.70168799]
# likelihood is -689.2833056314867 on iteration 18.
# Iteration=19
# new_angles=[0.70153137]
# likelihood is -689.2463162500679 on iteration 19.
# Iteration=20
# new_angles=[0.70136837]
# likelihood is -689.2020356618018 on iteration 20.
# 1-th start
# theta=[0.76634416],P=[[4.65993421e-08-2.64697796e-24j]]
# Inital likelihood = -689.5792672995802
# Iteration=1
# new_angles=[0.76634416]
# likelihood is -689.5766970662252 on iteration 1.
# Iteration=2
# new_angles=[0.75565258]
# likelihood is -689.570727622528 on iteration 2.
# Iteration=3
# new_angles=[0.74592661]
# likelihood is -689.5612280810625 on iteration 3.
# Iteration=4
# new_angles=[0.73760602]
# likelihood is -689.5490938858268 on iteration 4.
# Iteration=5
# new_angles=[0.73102031]
# likelihood is -689.5356915668838 on iteration 5.
# Iteration=6
# new_angles=[0.72541788]
# likelihood is -689.5213593398419 on iteration 6.
# Iteration=7
# new_angles=[0.72095248]
# likelihood is -689.5067785426336 on iteration 7.
# Iteration=8
# new_angles=[0.71734176]
# likelihood is -689.4919927672418 on iteration 8.
# Iteration=9
# new_angles=[0.7143885]
# likelihood is -689.4769209339562 on iteration 9.
# Iteration=10
# new_angles=[0.71196186]
# likelihood is -689.4614201752498 on iteration 10.
# Iteration=11
# new_angles=[0.7100211]
# likelihood is -689.4453376310141 on iteration 11.
# Iteration=12
# new_angles=[0.70841575]
# likelihood is -689.4283742959699 on iteration 12.
# Iteration=13
# new_angles=[0.70707583]
# likelihood is -689.410239411414 on iteration 13.
# Iteration=14
# new_angles=[0.70605824]
# likelihood is -689.3906529924212 on iteration 14.
# Iteration=15
# new_angles=[0.70518835]
# likelihood is -689.3691080374823 on iteration 15.
# Iteration=16
# new_angles=[0.70449278]
# likelihood is -689.3451067115237 on iteration 16.
# Iteration=17
# new_angles=[0.70385532]
# likelihood is -689.3179145951271 on iteration 17.
# Iteration=18
# new_angles=[0.70330711]
# likelihood is -689.2866433291596 on iteration 18.
# Iteration=19
# new_angles=[0.7029326]
# likelihood is -689.2500807125925 on iteration 19.
# Iteration=20
# new_angles=[0.70257197]
# likelihood is -689.2063978133392 on iteration 20.
# 2-th start
# theta=[0.7614843],P=[[5.77524969e-08+5.29395592e-24j]]
# Inital likelihood = -689.5792665882861
# Iteration=1
# new_angles=[0.7614843]
# likelihood is -689.5759541508345 on iteration 1.
# Iteration=2
# new_angles=[0.75084161]
# likelihood is -689.5690248600367 on iteration 2.
# Iteration=3
# new_angles=[0.74162717]
# likelihood is -689.5588525383849 on iteration 3.
# Iteration=4
# new_angles=[0.73398231]
# likelihood is -689.5465244878758 on iteration 4.
# Iteration=5
# new_angles=[0.72771094]
# likelihood is -689.533003485387 on iteration 5.
# Iteration=6
# new_angles=[0.72277579]
# likelihood is -689.5190567516323 on iteration 6.
# Iteration=7
# new_angles=[0.7188761]
# likelihood is -689.504902421083 on iteration 7.
# Iteration=8
# new_angles=[0.71562894]
# likelihood is -689.4904256391609 on iteration 8.
# Iteration=9
# new_angles=[0.7129889]
# likelihood is -689.4756314722484 on iteration 9.
# Iteration=10
# new_angles=[0.71069081]
# likelihood is -689.4602642046766 on iteration 10.
# Iteration=11
# new_angles=[0.70902657]
# likelihood is -689.4443981184425 on iteration 11.
# Iteration=12
# new_angles=[0.70765667]
# likelihood is -689.4276000047028 on iteration 12.
# Iteration=13
# new_angles=[0.70646459]
# likelihood is -689.4095553001671 on iteration 13.
# Iteration=14
# new_angles=[0.70550211]
# likelihood is -689.3899844871722 on iteration 14.
# Iteration=15
# new_angles=[0.70463263]
# likelihood is -689.3684165350554 on iteration 15.
# Iteration=16
# new_angles=[0.70399509]
# likelihood is -689.344403538154 on iteration 16.
# Iteration=17
# new_angles=[0.70344682]
# likelihood is -689.3171976011344 on iteration 17.
# Iteration=18
# new_angles=[0.70296731]
# likelihood is -689.2858803547394 on iteration 18.
# Iteration=19
# new_angles=[0.70260668]
# likelihood is -689.2492166064773 on iteration 19.
# Iteration=20
# new_angles=[0.70229001]
# likelihood is -689.205406951283 on iteration 20.
# 3-th start
# theta=[0.83255839],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688437123
# Iteration=1
# new_angles=[0.83255839]
# likelihood is -689.5799863001762 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 4-th start
# theta=[0.73004403],P=[[6.95706666e-08-3.30872245e-25j]]
# Inital likelihood = -689.5792623721018
# Iteration=1
# new_angles=[0.73004403]
# likelihood is -689.5704295427246 on iteration 1.
# Iteration=2
# new_angles=[0.72444645]
# likelihood is -689.5599332705547 on iteration 2.
# Iteration=3
# new_angles=[0.72017488]
# likelihood is -689.5485535944613 on iteration 3.
# Iteration=4
# new_angles=[0.71655268]
# likelihood is -689.5365588692316 on iteration 4.
# Iteration=5
# new_angles=[0.71360145]
# likelihood is -689.5242014243382 on iteration 5.
# Iteration=6
# new_angles=[0.71130214]
# likelihood is -689.5115911931495 on iteration 6.
# Iteration=7
# new_angles=[0.70946259]
# likelihood is -689.4986652022321 on iteration 7.
# Iteration=8
# new_angles=[0.70781392]
# likelihood is -689.4852681088216 on iteration 8.
# Iteration=9
# new_angles=[0.70662168]
# likelihood is -689.4714172958422 on iteration 9.
# Iteration=10
# new_angles=[0.70560449]
# likelihood is -689.4568758581722 on iteration 10.
# Iteration=11
# new_angles=[0.70488891]
# likelihood is -689.4415260276619 on iteration 11.
# Iteration=12
# new_angles=[0.70419351]
# likelihood is -689.425070859492 on iteration 12.
# Iteration=13
# new_angles=[0.70364515]
# likelihood is -689.4073029308676 on iteration 13.
# Iteration=14
# new_angles=[0.70309704]
# likelihood is -689.3878652206442 on iteration 14.
# Iteration=15
# new_angles=[0.70272259]
# likelihood is -689.3664036737366 on iteration 15.
# Iteration=16
# new_angles=[0.70236203]
# likelihood is -689.3423565079196 on iteration 16.
# Iteration=17
# new_angles=[0.70213425]
# likelihood is -689.3150642492449 on iteration 17.
# Iteration=18
# new_angles=[0.70190651]
# likelihood is -689.2835732465543 on iteration 18.
# Iteration=19
# new_angles=[0.70168799]
# likelihood is -689.2466116863321 on iteration 19.
# Iteration=20
# new_angles=[0.70153137]
# likelihood is -689.2023841504313 on iteration 20.
# 5-th start
# theta=[0.7029336],P=[[1.77615171e-07-2.64697796e-24j]]
# Inital likelihood = -689.579248242526
# Iteration=1
# new_angles=[0.7029336]
# likelihood is -689.5676552044063 on iteration 1.
# Iteration=2
# new_angles=[0.7029336]
# likelihood is -689.5562390363045 on iteration 2.
# Iteration=3
# new_angles=[0.7025592]
# likelihood is -689.5447309164492 on iteration 3.
# Iteration=4
# new_angles=[0.70232748]
# likelihood is -689.5330822869553 on iteration 4.
# Iteration=5
# new_angles=[0.70196703]
# likelihood is -689.5212148770661 on iteration 5.
# Iteration=6
# new_angles=[0.70168799]
# likelihood is -689.5090611007802 on iteration 6.
# Iteration=7
# new_angles=[0.70168799]
# likelihood is -689.4965413522098 on iteration 7.
# Iteration=8
# new_angles=[0.70168799]
# likelihood is -689.4835439877653 on iteration 8.
# Iteration=9
# new_angles=[0.70168799]
# likelihood is -689.469950474598 on iteration 9.
# Iteration=10
# new_angles=[0.70168799]
# likelihood is -689.4556206001718 on iteration 10.
# Iteration=11
# new_angles=[0.70160446]
# likelihood is -689.4403801550151 on iteration 11.
# Iteration=12
# new_angles=[0.70152093]
# likelihood is -689.4240295659552 on iteration 12.
# Iteration=13
# new_angles=[0.70136837]
# likelihood is -689.4063116507554 on iteration 13.
# Iteration=14
# new_angles=[0.70131399]
# likelihood is -689.3869202583378 on iteration 14.
# Iteration=15
# new_angles=[0.70125961]
# likelihood is -689.3654454823086 on iteration 15.
# Iteration=16
# new_angles=[0.70120523]
# likelihood is -689.341363964183 on iteration 16.
# Iteration=17
# new_angles=[0.7011646]
# likelihood is -689.3139852491629 on iteration 17.
# Iteration=18
# new_angles=[0.70109679]
# likelihood is -689.2823746199487 on iteration 18.
# Iteration=19
# new_angles=[0.70104242]
# likelihood is -689.2452476011639 on iteration 19.
# Iteration=20
# new_angles=[0.7010018]
# likelihood is -689.2007803112107 on iteration 20.
# 6-th start
# theta=[0.73079862],P=[[6.86735671e-08-2.97785021e-24j]]
# Inital likelihood = -689.5792625347437
# Iteration=1
# new_angles=[0.73079862]
# likelihood is -689.570552543065 on iteration 1.
# Iteration=2
# new_angles=[0.72556506]
# likelihood is -689.5602527591172 on iteration 2.
# Iteration=3
# new_angles=[0.72100555]
# likelihood is -689.5488608356081 on iteration 3.
# Iteration=4
# new_angles=[0.71735119]
# likelihood is -689.5368939003016 on iteration 4.
# Iteration=5
# new_angles=[0.714384]
# likelihood is -689.5245487182691 on iteration 5.
# Iteration=6
# new_angles=[0.71189446]
# likelihood is -689.5118606102411 on iteration 6.
# Iteration=7
# new_angles=[0.7099204]
# likelihood is -689.4988754559827 on iteration 7.
# Iteration=8
# new_angles=[0.70831196]
# likelihood is -689.4854888852753 on iteration 8.
# Iteration=9
# new_angles=[0.70697216]
# likelihood is -689.4715747714902 on iteration 9.
# Iteration=10
# new_angles=[0.70585089]
# likelihood is -689.4569906353066 on iteration 10.
# Iteration=11
# new_angles=[0.70498115]
# likelihood is -689.4415870338663 on iteration 11.
# Iteration=12
# new_angles=[0.70424803]
# likelihood is -689.4251205882903 on iteration 12.
# Iteration=13
# new_angles=[0.70369964]
# likelihood is -689.4073547263778 on iteration 13.
# Iteration=14
# new_angles=[0.7031515]
# likelihood is -689.3879192475837 on iteration 14.
# Iteration=15
# new_angles=[0.70277704]
# likelihood is -689.366461383134 on iteration 15.
# Iteration=16
# new_angles=[0.70241646]
# likelihood is -689.3424187234186 on iteration 16.
# Iteration=17
# new_angles=[0.70209985]
# likelihood is -689.3151140129353 on iteration 17.
# Iteration=18
# new_angles=[0.70188556]
# likelihood is -689.2836344113273 on iteration 18.
# Iteration=19
# new_angles=[0.70168799]
# likelihood is -689.2466879676576 on iteration 19.
# Iteration=20
# new_angles=[0.70153137]
# likelihood is -689.202475344211 on iteration 20.
# 7-th start
# theta=[0.83991537],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579268841746
# Iteration=1
# new_angles=[0.83991537]
# likelihood is -689.5799823206631 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 8-th start
# theta=[0.86805869],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688779773
# Iteration=1
# new_angles=[0.86805869]
# likelihood is -689.5800569434394 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 9-th start
# theta=[0.74591953],P=[[4.89913064e-08-9.92616735e-25j]]
# Inital likelihood = -689.5792655524413
# Iteration=1
# new_angles=[0.74591953]
# likelihood is -689.5732474781139 on iteration 1.
# Iteration=2
# new_angles=[0.73759899]
# likelihood is -689.5642170792968 on iteration 2.
# Iteration=3
# new_angles=[0.73065141]
# likelihood is -689.553094568491 on iteration 3.
# Iteration=4
# new_angles=[0.72505081]
# likelihood is -689.5408152819646 on iteration 4.
# Iteration=5
# new_angles=[0.72049661]
# likelihood is -689.5279010608914 on iteration 5.
# Iteration=6
# new_angles=[0.7168734]
# likelihood is -689.5146755536795 on iteration 6.
# Iteration=7
# new_angles=[0.71392134]
# likelihood is -689.5011599493685 on iteration 7.
# Iteration=8
# new_angles=[0.71160753]
# likelihood is -689.4873759148074 on iteration 8.
# Iteration=9
# new_angles=[0.70970672]
# likelihood is -689.4731421673132 on iteration 9.
# Iteration=10
# new_angles=[0.70810179]
# likelihood is -689.458291045939 on iteration 10.
# Iteration=11
# new_angles=[0.70682008]
# likelihood is -689.4426868308374 on iteration 11.
# Iteration=12
# new_angles=[0.70580272]
# likelihood is -689.4260984820908 on iteration 12.
# Iteration=13
# new_angles=[0.70488891]
# likelihood is -689.4082030743224 on iteration 13.
# Iteration=14
# new_angles=[0.70419351]
# likelihood is -689.3887359486088 on iteration 14.
# Iteration=15
# new_angles=[0.70364515]
# likelihood is -689.3672638057712 on iteration 15.
# Iteration=16
# new_angles=[0.70309704]
# likelihood is -689.3432171976953 on iteration 16.
# Iteration=17
# new_angles=[0.70272259]
# likelihood is -689.3159719729033 on iteration 17.
# Iteration=18
# new_angles=[0.70236203]
# likelihood is -689.2845583496976 on iteration 18.
# Iteration=19
# new_angles=[0.70213425]
# likelihood is -689.2477441208773 on iteration 19.
# Iteration=20
# new_angles=[0.70190651]
# likelihood is -689.2037031494963 on iteration 20.
# 10-th start
# theta=[0.45944132],P=[[5.55659323e-08+3.57342025e-23j]]
# Inital likelihood = -689.5792678138821
# Iteration=1
# new_angles=[0.46489919]
# likelihood is -689.5779288726142 on iteration 1.
# Iteration=2
# new_angles=[0.46599474]
# likelihood is -689.5765651688256 on iteration 2.
# Iteration=3
# new_angles=[0.46677998]
# likelihood is -689.5751871112067 on iteration 3.
# Iteration=4
# new_angles=[0.46756554]
# likelihood is -689.5737907642878 on iteration 4.
# Iteration=5
# new_angles=[0.4681126]
# likelihood is -689.5723873976783 on iteration 5.
# Iteration=6
# new_angles=[0.46853656]
# likelihood is -689.5709731090113 on iteration 6.
# Iteration=7
# new_angles=[0.46896061]
# likelihood is -689.5695395358478 on iteration 7.
# Iteration=8
# new_angles=[0.46930373]
# likelihood is -689.5680877068155 on iteration 8.
# Iteration=9
# new_angles=[0.46964692]
# likelihood is -689.56660845722 on iteration 9.
# Iteration=10
# new_angles=[0.46999016]
# likelihood is -689.5650961032349 on iteration 10.
# Iteration=11
# new_angles=[0.47033347]
# likelihood is -689.5635440490654 on iteration 11.
# Iteration=12
# new_angles=[0.47057254]
# likelihood is -689.5619517652349 on iteration 12.
# Iteration=13
# new_angles=[0.47081164]
# likelihood is -689.5603033073261 on iteration 13.
# Iteration=14
# new_angles=[0.47105077]
# likelihood is -689.558588045359 on iteration 14.
# Iteration=15
# new_angles=[0.47125316]
# likelihood is -689.5567962127886 on iteration 15.
# Iteration=16
# new_angles=[0.47149234]
# likelihood is -689.5549078529663 on iteration 16.
# Iteration=17
# new_angles=[0.47169478]
# likelihood is -689.5529109149454 on iteration 17.
# Iteration=18
# new_angles=[0.4718454]
# likelihood is -689.5507857378185 on iteration 18.
# Iteration=19
# new_angles=[0.47199603]
# likelihood is -689.5485034504669 on iteration 19.
# Iteration=20
# new_angles=[0.47219853]
# likelihood is -689.54602951945 on iteration 20.
# 11-th start
# theta=[0.49094045],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579267869759
# Iteration=1
# new_angles=[0.49094045]
# likelihood is -689.577984178447 on iteration 1.
# Iteration=2
# new_angles=[0.49008754]
# likelihood is -689.5766881841694 on iteration 2.
# Iteration=3
# new_angles=[0.48977567]
# likelihood is -689.5753908961057 on iteration 3.
# Iteration=4
# new_angles=[0.48898102]
# likelihood is -689.5740634470377 on iteration 4.
# Iteration=5
# new_angles=[0.488428]
# likelihood is -689.5727264529672 on iteration 5.
# Iteration=6
# new_angles=[0.48787515]
# likelihood is -689.5713688946497 on iteration 6.
# Iteration=7
# new_angles=[0.48732246]
# likelihood is -689.5699870127089 on iteration 7.
# Iteration=8
# new_angles=[0.48676993]
# likelihood is -689.5685764640608 on iteration 8.
# Iteration=9
# new_angles=[0.48621756]
# likelihood is -689.567132248149 on iteration 9.
# Iteration=10
# new_angles=[0.48566535]
# likelihood is -689.5656486125209 on iteration 10.
# Iteration=11
# new_angles=[0.48511607]
# likelihood is -689.5641192407223 on iteration 11.
# Iteration=12
# new_angles=[0.48456694]
# likelihood is -689.5625362215715 on iteration 12.
# Iteration=13
# new_angles=[0.48409459]
# likelihood is -689.5609004429634 on iteration 13.
# Iteration=14
# new_angles=[0.48362235]
# likelihood is -689.5591929470896 on iteration 14.
# Iteration=15
# new_angles=[0.48315023]
# likelihood is -689.557401498367 on iteration 15.
# Iteration=16
# new_angles=[0.48267823]
# likelihood is -689.5555116715109 on iteration 16.
# Iteration=17
# new_angles=[0.48235548]
# likelihood is -689.553529596855 on iteration 17.
# Iteration=18
# new_angles=[0.48204488]
# likelihood is -689.5514155856208 on iteration 18.
# Iteration=19
# new_angles=[0.48173433]
# likelihood is -689.549142930363 on iteration 19.
# Iteration=20
# new_angles=[0.48142383]
# likelihood is -689.5466812593291 on iteration 20.
# 12-th start
# theta=[0.61180126],P=[[8.06311518e-08-5.29395592e-24j]]
# Inital likelihood = -689.5792664814606
# Iteration=1
# new_angles=[0.61027297]
# likelihood is -689.5767463732176 on iteration 1.
# Iteration=2
# new_angles=[0.61027297]
# likelihood is -689.5742441349797 on iteration 2.
# Iteration=3
# new_angles=[0.61027297]
# likelihood is -689.5717382266652 on iteration 3.
# Iteration=4
# new_angles=[0.61027297]
# likelihood is -689.5692231409001 on iteration 4.
# Iteration=5
# new_angles=[0.60993722]
# likelihood is -689.5666795524412 on iteration 5.
# Iteration=6
# new_angles=[0.60971492]
# likelihood is -689.5641118358247 on iteration 6.
# Iteration=7
# new_angles=[0.60937929]
# likelihood is -689.5615000363518 on iteration 7.
# Iteration=8
# new_angles=[0.60904375]
# likelihood is -689.5588377976918 on iteration 8.
# Iteration=9
# new_angles=[0.60870828]
# likelihood is -689.5561127761413 on iteration 9.
# Iteration=10
# new_angles=[0.60819882]
# likelihood is -689.5532887222191 on iteration 10.
# Iteration=11
# new_angles=[0.60768954]
# likelihood is -689.5503627169787 on iteration 11.
# Iteration=12
# new_angles=[0.60717029]
# likelihood is -689.5473129698821 on iteration 12.
# Iteration=13
# new_angles=[0.60657587]
# likelihood is -689.5441008747738 on iteration 13.
# Iteration=14
# new_angles=[0.60597476]
# likelihood is -689.5407088614073 on iteration 14.
# Iteration=15
# new_angles=[0.6053739]
# likelihood is -689.5371059414765 on iteration 15.
# Iteration=16
# new_angles=[0.60470267]
# likelihood is -689.533228695357 on iteration 16.
# Iteration=17
# new_angles=[0.60397564]
# likelihood is -689.5290259290476 on iteration 17.
# Iteration=18
# new_angles=[0.60316124]
# likelihood is -689.5244160222398 on iteration 18.
# Iteration=19
# new_angles=[0.60235742]
# likelihood is -689.5193642631621 on iteration 19.
# Iteration=20
# new_angles=[0.60147179]
# likelihood is -689.5137276863821 on iteration 20.
# 13-th start
# theta=[0.74517223],P=[[4.99996792e-08+3.97046694e-24j]]
# Inital likelihood = -689.5792654235444
# Iteration=1
# new_angles=[0.74517223]
# likelihood is -689.5731098858369 on iteration 1.
# Iteration=2
# new_angles=[0.73685736]
# likelihood is -689.5639530133606 on iteration 2.
# Iteration=3
# new_angles=[0.73028372]
# likelihood is -689.5529139050464 on iteration 3.
# Iteration=4
# new_angles=[0.72468495]
# likelihood is -689.5406039683377 on iteration 4.
# Iteration=5
# new_angles=[0.72039851]
# likelihood is -689.5278361082067 on iteration 5.
# Iteration=6
# new_angles=[0.71678954]
# likelihood is -689.5146174594945 on iteration 6.
# Iteration=7
# new_angles=[0.7138377]
# likelihood is -689.5011019527713 on iteration 7.
# Iteration=8
# new_angles=[0.71134933]
# likelihood is -689.4872162004157 on iteration 8.
# Iteration=9
# new_angles=[0.7095097]
# likelihood is -689.4730211599492 on iteration 9.
# Iteration=10
# new_angles=[0.70809857]
# likelihood is -689.4582758468414 on iteration 10.
# Iteration=11
# new_angles=[0.70681687]
# likelihood is -689.4426708124043 on iteration 11.
# Iteration=12
# new_angles=[0.70581331]
# likelihood is -689.426087793422 on iteration 12.
# Iteration=13
# new_angles=[0.70488891]
# likelihood is -689.4081863640117 on iteration 13.
# Iteration=14
# new_angles=[0.70419351]
# likelihood is -689.3887176783899 on iteration 14.
# Iteration=15
# new_angles=[0.70364515]
# likelihood is -689.367243617489 on iteration 15.
# Iteration=16
# new_angles=[0.70309704]
# likelihood is -689.343194618359 on iteration 16.
# Iteration=17
# new_angles=[0.70272259]
# likelihood is -689.3159463802932 on iteration 17.
# Iteration=18
# new_angles=[0.70236203]
# likelihood is -689.2845288936451 on iteration 18.
# Iteration=19
# new_angles=[0.70213425]
# likelihood is -689.2477096237899 on iteration 19.
# Iteration=20
# new_angles=[0.70190651]
# likelihood is -689.2036619248879 on iteration 20.
# 14-th start
# theta=[0.81529611],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688264825
# Iteration=1
# new_angles=[0.81529611]
# likelihood is -689.5799507299589 on iteration 1.
# Likelihood is converged!
# 15-th start
# theta=[0.64780331],P=[[8.03558405e-08+0.j]]
# Inital likelihood = -689.5792644427597
# Iteration=1
# new_angles=[0.64780331]
# likelihood is -689.5742001854517 on iteration 1.
# Iteration=2
# new_angles=[0.6527111]
# likelihood is -689.5676677849586 on iteration 2.
# Iteration=3
# new_angles=[0.65772616]
# likelihood is -689.5594213314326 on iteration 3.
# Iteration=4
# new_angles=[0.66267469]
# likelihood is -689.54943568476 on iteration 4.
# Iteration=5
# new_angles=[0.6676393]
# likelihood is -689.537688418541 on iteration 5.
# Iteration=6
# new_angles=[0.67200245]
# likelihood is -689.5248545378781 on iteration 6.
# Iteration=7
# new_angles=[0.67601138]
# likelihood is -689.511003574737 on iteration 7.
# Iteration=8
# new_angles=[0.67977271]
# likelihood is -689.4962157956581 on iteration 8.
# Iteration=9
# new_angles=[0.68291906]
# likelihood is -689.4809964168628 on iteration 9.
# Iteration=10
# new_angles=[0.68570115]
# likelihood is -689.4651288423263 on iteration 10.
# Iteration=11
# new_angles=[0.68800215]
# likelihood is -689.4486776431177 on iteration 11.
# Iteration=12
# new_angles=[0.68999092]
# likelihood is -689.4313364519386 on iteration 12.
# Iteration=13
# new_angles=[0.69166593]
# likelihood is -689.4128949559754 on iteration 13.
# Iteration=14
# new_angles=[0.69308834]
# likelihood is -689.3930046907595 on iteration 14.
# Iteration=15
# new_angles=[0.69430441]
# likelihood is -689.371241499742 on iteration 15.
# Iteration=16
# new_angles=[0.69531195]
# likelihood is -689.3471016320491 on iteration 16.
# Iteration=17
# new_angles=[0.69621203]
# likelihood is -689.3198424607402 on iteration 17.
# Iteration=18
# new_angles=[0.6969402]
# likelihood is -689.2886133824693 on iteration 18.
# Iteration=19
# new_angles=[0.69757714]
# likelihood is -689.2521266596851 on iteration 19.
# Iteration=20
# new_angles=[0.69816018]
# likelihood is -689.2086228001223 on iteration 20.
# 16-th start
# theta=[0.22711654],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792687212914
# Iteration=1
# new_angles=[0.22711654]
# likelihood is -689.5797345820387 on iteration 1.
# Likelihood is converged!
# 17-th start
# theta=[0.45039062],P=[[4.93435618e-08-4.76456033e-23j]]
# Inital likelihood = -689.579268038814
# Iteration=1
# new_angles=[0.45039062]
# likelihood is -689.5783422772163 on iteration 1.
# Iteration=2
# new_angles=[0.45271134]
# likelihood is -689.5772384738892 on iteration 2.
# Iteration=3
# new_angles=[0.45488441]
# likelihood is -689.5759954425216 on iteration 3.
# Iteration=4
# new_angles=[0.45650938]
# likelihood is -689.5746962412002 on iteration 4.
# Iteration=5
# new_angles=[0.45825388]
# likelihood is -689.5732956884966 on iteration 5.
# Iteration=6
# new_angles=[0.45954429]
# likelihood is -689.5718861705581 on iteration 6.
# Iteration=7
# new_angles=[0.46078489]
# likelihood is -689.5704258405653 on iteration 7.
# Iteration=8
# new_angles=[0.46195394]
# likelihood is -689.5689231559493 on iteration 8.
# Iteration=9
# new_angles=[0.46292223]
# likelihood is -689.5674031058364 on iteration 9.
# Iteration=10
# new_angles=[0.46370627]
# likelihood is -689.5658647027689 on iteration 10.
# Iteration=11
# new_angles=[0.46449061]
# likelihood is -689.5642734713986 on iteration 11.
# Iteration=12
# new_angles=[0.46523861]
# likelihood is -689.5626307725119 on iteration 12.
# Iteration=13
# new_angles=[0.4658907]
# likelihood is -689.5609407851989 on iteration 13.
# Iteration=14
# new_angles=[0.46644004]
# likelihood is -689.5591962402287 on iteration 14.
# Iteration=15
# new_angles=[0.46698953]
# likelihood is -689.5573672038532 on iteration 15.
# Iteration=16
# new_angles=[0.46753006]
# likelihood is -689.5554417269041 on iteration 16.
# Iteration=17
# new_angles=[0.46807074]
# likelihood is -689.5534017034603 on iteration 17.
# Iteration=18
# new_angles=[0.46849469]
# likelihood is -689.551248503799 on iteration 18.
# Iteration=19
# new_angles=[0.46903563]
# likelihood is -689.5489150874982 on iteration 19.
# Iteration=20
# new_angles=[0.46937876]
# likelihood is -689.5464281284818 on iteration 20.
# 18-th start
# theta=[1.57079633],P=[[8.75235434e-08-2.70617725e-23j]]
# Inital likelihood = -689.5792674589636
# Iteration=1
# new_angles=[1.57079633]
# likelihood is -689.5780758869118 on iteration 1.
# Iteration=2
# new_angles=[1.48237918]
# likelihood is -689.576259703996 on iteration 2.
# Iteration=3
# new_angles=[1.4457148]
# likelihood is -689.5738898973976 on iteration 3.
# Iteration=4
# new_angles=[1.4309281]
# likelihood is -689.571563360935 on iteration 4.
# Iteration=5
# new_angles=[1.41755332]
# likelihood is -689.5690032209305 on iteration 5.
# Iteration=6
# new_angles=[1.40524789]
# likelihood is -689.5662307331277 on iteration 6.
# Iteration=7
# new_angles=[1.39378864]
# likelihood is -689.5632664810091 on iteration 7.
# Iteration=8
# new_angles=[1.3833973]
# likelihood is -689.560156032496 on iteration 8.
# Iteration=9
# new_angles=[1.37569116]
# likelihood is -689.5570499904009 on iteration 9.
# Iteration=10
# new_angles=[1.36862403]
# likelihood is -689.5538290214516 on iteration 10.
# Iteration=11
# new_angles=[1.36313435]
# likelihood is -689.550574597683 on iteration 11.
# Iteration=12
# new_angles=[1.35844978]
# likelihood is -689.547227746284 on iteration 12.
# Iteration=13
# new_angles=[1.35386487]
# likelihood is -689.543718461719 on iteration 13.
# Iteration=14
# new_angles=[1.34969353]
# likelihood is -689.5400558379782 on iteration 14.
# Iteration=15
# new_angles=[1.34606276]
# likelihood is -689.5362285214666 on iteration 15.
# Iteration=16
# new_angles=[1.34279939]
# likelihood is -689.5321911275688 on iteration 16.
# Iteration=17
# new_angles=[1.33988805]
# likelihood is -689.5279037353873 on iteration 17.
# Iteration=18
# new_angles=[1.33701233]
# likelihood is -689.5232881937841 on iteration 18.
# Iteration=19
# new_angles=[1.33431334]
# likelihood is -689.5182961759629 on iteration 19.
# Iteration=20
# new_angles=[1.33223814]
# likelihood is -689.5128928149973 on iteration 20.
# 19-th start
# theta=[0.75399535],P=[[7.64820505e-08-1.0753348e-24j]]
# Inital likelihood = -689.5792650119403
# Iteration=1
# new_angles=[0.75399535]
# likelihood is -689.5746837109166 on iteration 1.
# Iteration=2
# new_angles=[0.74428431]
# likelihood is -689.5666166828958 on iteration 2.
# Iteration=3
# new_angles=[0.73634751]
# likelihood is -689.5559747188474 on iteration 3.
# Iteration=4
# new_angles=[0.72978016]
# likelihood is -689.5436793261199 on iteration 4.
# Iteration=5
# new_angles=[0.72455133]
# likelihood is -689.5305929600477 on iteration 5.
# Iteration=6
# new_angles=[0.72027937]
# likelihood is -689.5170289620403 on iteration 6.
# Iteration=7
# new_angles=[0.71667077]
# likelihood is -689.5030704371002 on iteration 7.
# Iteration=8
# new_angles=[0.71371923]
# likelihood is -689.4888355324935 on iteration 8.
# Iteration=9
# new_angles=[0.71141969]
# likelihood is -689.474316597773 on iteration 9.
# Iteration=10
# new_angles=[0.70957995]
# likelihood is -689.4592926841148 on iteration 10.
# Iteration=11
# new_angles=[0.70809857]
# likelihood is -689.4435534728242 on iteration 11.
# Iteration=12
# new_angles=[0.70681687]
# likelihood is -689.4268126317473 on iteration 12.
# Iteration=13
# new_angles=[0.70577027]
# likelihood is -689.40884550008 on iteration 13.
# Iteration=14
# new_angles=[0.70488891]
# likelihood is -689.3893014155586 on iteration 14.
# Iteration=15
# new_angles=[0.70419351]
# likelihood is -689.3677884277355 on iteration 15.
# Iteration=16
# new_angles=[0.70364515]
# likelihood is -689.3437688420405 on iteration 16.
# Iteration=17
# new_angles=[0.70309704]
# likelihood is -689.3165045563187 on iteration 17.
# Iteration=18
# new_angles=[0.70272259]
# likelihood is -689.2851448235946 on iteration 18.
# Iteration=19
# new_angles=[0.70236203]
# likelihood is -689.2483721970049 on iteration 19.
# Iteration=20
# new_angles=[0.70213425]
# likelihood is -689.2044418105655 on iteration 20.
# best_start=5
# Время выполнения функции: 59.109419 секунд

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.7010018]), array([[0.0033627+0.j]]))

# %%
lf.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q2), lf.incomplete_lkhd(X2_with_mv, theta2_rad, P2, Q2)
# Out:
# (np.float64(-689.2007803112107), np.float64(-673.6467390084401))
