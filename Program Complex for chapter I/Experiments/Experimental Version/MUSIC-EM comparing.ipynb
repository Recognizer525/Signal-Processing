# %%
import numpy as np

# %%
from pathlib import Path
import sys

try:
    ROOT = Path().resolve().parents[1]
    assert (ROOT / "common").exists()
except AssertionError:
    ROOT = next(p for p in Path().resolve().parents if (p / "common").exists())

if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
#print(ROOT)

# %%
from common import sensors as sn 
from common import subspace_methods as sm
from common import em_tools as em
from common import log_funcs as lf

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12

failing_sensors1 = np.arange(5)
gap_ratio1 = 0.5 * np.ones_like(failing_sensors1, dtype=np.float32)

theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sn.gss(Num_emitters1, sample_size1, P1)
N1 = sn.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sn.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sn.initial_Cov(X1_with_mv)
MUSIC_theta1 = sm.MUSIC_DoA(R1, Num_emitters1)

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sn.SNR(A1, P1, Q1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1, lhd_list1, angles_list1 = em.multistart_EM(X1_with_mv, 
                                                                        Num_emitters1, 
                                                                        Q=Q1,
                                                                        theta_guess=MUSIC_theta1, 
                                                                        num_of_starts=10, 
                                                                        max_iter=20, 
                                                                        rtol_params=1e-6,
                                                                        rtol_lkhd=1e-6,
                                                                        reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.71558499],P=[[1.18642836e-07-1.98523347e-24j]]
# Inital likelihood = -870.4011155592349
# Iteration=1
# new_angles=[0.72207638]
# new_P:
# [[0.00010709+0.j]]
# likelihood is -870.3917920097845 on iteration 1.
# Iteration=2
# new_angles=[0.71688292]
# new_P:
# [[0.00020728+0.j]]
# likelihood is -870.3817423165093 on iteration 2.
# Iteration=3
# new_angles=[0.71263946]
# new_P:
# [[0.00030806+0.j]]
# likelihood is -870.3709881346135 on iteration 3.
# Iteration=4
# new_angles=[0.70942051]
# new_P:
# [[0.00040989+0.j]]
# likelihood is -870.3599315768512 on iteration 4.
# Iteration=5
# new_angles=[0.70684918]
# new_P:
# [[0.00051323+0.j]]
# likelihood is -870.3486576579278 on iteration 5.
# Iteration=6
# new_angles=[0.70486983]
# new_P:
# [[0.00061861+0.j]]
# likelihood is -870.3372214664555 on iteration 6.
# Iteration=7
# new_angles=[0.70322761]
# new_P:
# [[0.00072661+0.j]]
# likelihood is -870.3255491077532 on iteration 7.
# Iteration=8
# new_angles=[0.70189359]
# new_P:
# [[0.00083785+0.j]]
# likelihood is -870.3135995430688 on iteration 8.
# Iteration=9
# new_angles=[0.70088047]
# new_P:
# [[0.00095305+0.j]]
# likelihood is -870.3013153055845 on iteration 9.
# Iteration=10
# new_angles=[0.70009904]
# new_P:
# [[0.00107302+0.j]]
# likelihood is -870.2885911765383 on iteration 10.
# Iteration=11
# new_angles=[0.69939303]
# new_P:
# [[0.00119869+0.j]]
# likelihood is -870.2752944715131 on iteration 11.
# Iteration=12
# new_angles=[0.69884689]
# new_P:
# [[0.00133116+0.j]]
# likelihood is -870.2613316764638 on iteration 12.
# Iteration=13
# new_angles=[0.69830099]
# new_P:
# [[0.00147173+0.j]]
# likelihood is -870.2465373228381 on iteration 13.
# Iteration=14
# new_angles=[0.69792806]
# new_P:
# [[0.00162195+0.j]]
# likelihood is -870.2307812896312 on iteration 14.
# Iteration=15
# new_angles=[0.69762523]
# new_P:
# [[0.00178371+0.j]]
# likelihood is -870.2138496726755 on iteration 15.
# Iteration=16
# new_angles=[0.69741176]
# new_P:
# [[0.00195929+0.j]]
# likelihood is -870.195506704119 on iteration 16.
# Iteration=17
# new_angles=[0.69724508]
# new_P:
# [[0.00215157+0.j]]
# likelihood is -870.1754529828403 on iteration 17.
# Iteration=18
# new_angles=[0.69708586]
# new_P:
# [[0.00236412+0.j]]
# likelihood is -870.1533169559793 on iteration 18.
# Iteration=19
# new_angles=[0.69694351]
# new_P:
# [[0.00260153+0.j]]
# likelihood is -870.1286329093077 on iteration 19.
# Iteration=20
# new_angles=[0.69686031]
# new_P:
# [[0.00286974+0.j]]
# likelihood is -870.100800469138 on iteration 20.
# 1-th start
# theta=[0.75761751],P=[[7.62531873e-08-2.64697796e-24j]]
# Inital likelihood = -870.4011243940959
# Iteration=1
# new_angles=[0.76310548]
# new_P:
# [[0.000107+0.j]]
# likelihood is -870.3984926714636 on iteration 1.
# Iteration=2
# new_angles=[0.75063718]
# new_P:
# [[0.00020708+0.j]]
# likelihood is -870.3923632738711 on iteration 2.
# Iteration=3
# new_angles=[0.73963342]
# new_P:
# [[0.00030751+0.j]]
# likelihood is -870.3826353917026 on iteration 3.
# Iteration=4
# new_angles=[0.73070433]
# new_P:
# [[0.00040877+0.j]]
# likelihood is -870.3706577367938 on iteration 4.
# Iteration=5
# new_angles=[0.72375569]
# new_P:
# [[0.00051143+0.j]]
# likelihood is -870.3577694308144 on iteration 5.
# Iteration=6
# new_angles=[0.71822275]
# new_P:
# [[0.00061608+0.j]]
# likelihood is -870.3445401556255 on iteration 6.
# Iteration=7
# new_angles=[0.71386992]
# new_P:
# [[0.00072337+0.j]]
# likelihood is -870.3313042896768 on iteration 7.
# Iteration=8
# new_angles=[0.71040394]
# new_P:
# [[0.00083394+0.j]]
# likelihood is -870.318072726954 on iteration 8.
# Iteration=9
# new_angles=[0.7076857]
# new_P:
# [[0.00094851+0.j]]
# likelihood is -870.3048041784976 on iteration 9.
# Iteration=10
# new_angles=[0.70544201]
# new_P:
# [[0.0010679+0.j]]
# likelihood is -870.2912912691825 on iteration 10.
# Iteration=11
# new_angles=[0.70369547]
# new_P:
# [[0.00119302+0.j]]
# likelihood is -870.2774645548029 on iteration 11.
# Iteration=12
# new_angles=[0.70227236]
# new_P:
# [[0.00132494+0.j]]
# likelihood is -870.2631105235974 on iteration 12.
# Iteration=13
# new_angles=[0.70115353]
# new_P:
# [[0.00146496+0.j]]
# likelihood is -870.2480766111 on iteration 13.
# Iteration=14
# new_angles=[0.70028725]
# new_P:
# [[0.00161459+0.j]]
# likelihood is -870.2321668094567 on iteration 14.
# Iteration=15
# new_angles=[0.69957023]
# new_P:
# [[0.00177569+0.j]]
# likelihood is -870.2151394043128 on iteration 15.
# Iteration=16
# new_angles=[0.69894911]
# new_P:
# [[0.00195054+0.j]]
# likelihood is -870.1967378270417 on iteration 16.
# Iteration=17
# new_angles=[0.69847082]
# new_P:
# [[0.00214195+0.j]]
# likelihood is -870.1766818351772 on iteration 17.
# Iteration=18
# new_angles=[0.69808443]
# new_P:
# [[0.00235349+0.j]]
# likelihood is -870.1545879277127 on iteration 18.
# Iteration=19
# new_angles=[0.69776897]
# new_P:
# [[0.00258967+0.j]]
# likelihood is -870.1299856690076 on iteration 19.
# Iteration=20
# new_angles=[0.69752643]
# new_P:
# [[0.00285636+0.j]]
# likelihood is -870.1022760177409 on iteration 20.
# 2-th start
# theta=[0.75275765],P=[[9.44715207e-08-1.12496563e-23j]]
# Inital likelihood = -870.4011231381311
# Iteration=1
# new_angles=[0.75812361]
# new_P:
# [[0.00011017+0.j]]
# likelihood is -870.3976862149243 on iteration 1.
# Iteration=2
# new_angles=[0.74609121]
# new_P:
# [[0.00021027+0.j]]
# likelihood is -870.3907063123024 on iteration 2.
# Iteration=3
# new_angles=[0.73559887]
# new_P:
# [[0.00031077+0.j]]
# likelihood is -870.3803835396684 on iteration 3.
# Iteration=4
# new_angles=[0.72772404]
# new_P:
# [[0.00041215+0.j]]
# likelihood is -870.3685294952184 on iteration 4.
# Iteration=5
# new_angles=[0.72129721]
# new_P:
# [[0.00051497+0.j]]
# likelihood is -870.3557720434493 on iteration 5.
# Iteration=6
# new_angles=[0.71620042]
# new_P:
# [[0.00061983+0.j]]
# likelihood is -870.3427746935254 on iteration 6.
# Iteration=7
# new_angles=[0.71228198]
# new_P:
# [[0.00072734+0.j]]
# likelihood is -870.3298325687575 on iteration 7.
# Iteration=8
# new_angles=[0.70915337]
# new_P:
# [[0.00083815+0.j]]
# likelihood is -870.3168433078432 on iteration 8.
# Iteration=9
# new_angles=[0.706675]
# new_P:
# [[0.00095297+0.j]]
# likelihood is -870.3037437524526 on iteration 9.
# Iteration=10
# new_angles=[0.70469595]
# new_P:
# [[0.00107262+0.j]]
# likelihood is -870.2903967073756 on iteration 10.
# Iteration=11
# new_angles=[0.70305397]
# new_P:
# [[0.00119802+0.j]]
# likelihood is -870.2766288888888 on iteration 11.
# Iteration=12
# new_angles=[0.70177455]
# new_P:
# [[0.00133027+0.j]]
# likelihood is -870.2623362256711 on iteration 12.
# Iteration=13
# new_angles=[0.7007481]
# new_P:
# [[0.00147064+0.j]]
# likelihood is -870.2473237475358 on iteration 13.
# Iteration=14
# new_angles=[0.69988211]
# new_P:
# [[0.00162069+0.j]]
# likelihood is -870.2313878101072 on iteration 14.
# Iteration=15
# new_angles=[0.6992365]
# new_P:
# [[0.00178227+0.j]]
# likelihood is -870.2143474241817 on iteration 15.
# Iteration=16
# new_angles=[0.69869042]
# new_P:
# [[0.00195769+0.j]]
# likelihood is -870.1959199775737 on iteration 16.
# Iteration=17
# new_angles=[0.69828832]
# new_P:
# [[0.00214979+0.j]]
# likelihood is -870.1758205355168 on iteration 17.
# Iteration=18
# new_angles=[0.6979291]
# new_P:
# [[0.00236214+0.j]]
# likelihood is -870.1536535104962 on iteration 18.
# Iteration=19
# new_angles=[0.69762628]
# new_P:
# [[0.00259932+0.j]]
# likelihood is -870.1289550785722 on iteration 19.
# Iteration=20
# new_angles=[0.69738852]
# new_P:
# [[0.00286725+0.j]]
# likelihood is -870.101122611473 on iteration 20.
# 3-th start
# theta=[0.82383174],P=[[9.765625e-08+0.j]]
# Inital likelihood = -870.4011268013815
# Iteration=1
# new_angles=[0.82008405]
# new_P:
# [[0.00011024+0.j]]
# likelihood is -870.4011220963937 on iteration 1.
# Likelihood is converged!
# 4-th start
# theta=[0.72131738],P=[[1.09961713e-07-2.97785021e-24j]]
# Inital likelihood = -870.4011171320063
# Iteration=1
# new_angles=[0.7278417]
# new_P:
# [[0.00010719+0.j]]
# likelihood is -870.3926593902522 on iteration 1.
# Iteration=2
# new_angles=[0.7214142]
# new_P:
# [[0.00020737+0.j]]
# likelihood is -870.3828760811638 on iteration 2.
# Iteration=3
# new_angles=[0.71631688]
# new_P:
# [[0.00030811+0.j]]
# likelihood is -870.3721289667886 on iteration 3.
# Iteration=4
# new_angles=[0.71243907]
# new_P:
# [[0.00040988+0.j]]
# likelihood is -870.360965316077 on iteration 4.
# Iteration=5
# new_angles=[0.70922068]
# new_P:
# [[0.00051316+0.j]]
# likelihood is -870.3494927436282 on iteration 5.
# Iteration=6
# new_angles=[0.706653]
# new_P:
# [[0.00061849+0.j]]
# likelihood is -870.3378452189468 on iteration 6.
# Iteration=7
# new_angles=[0.70467398]
# new_P:
# [[0.00072643+0.j]]
# likelihood is -870.3260404588256 on iteration 7.
# Iteration=8
# new_angles=[0.70303203]
# new_P:
# [[0.00083762+0.j]]
# likelihood is -870.3139696966145 on iteration 8.
# Iteration=9
# new_angles=[0.70175264]
# new_P:
# [[0.00095277+0.j]]
# likelihood is -870.301589541663 on iteration 9.
# Iteration=10
# new_angles=[0.70073964]
# new_P:
# [[0.00107269+0.j]]
# likelihood is -870.2887906376233 on iteration 10.
# Iteration=11
# new_angles=[0.69987366]
# new_P:
# [[0.00119833+0.j]]
# likelihood is -870.2754438605668 on iteration 11.
# Iteration=12
# new_angles=[0.69922805]
# new_P:
# [[0.00133076+0.j]]
# likelihood is -870.2614531467002 on iteration 12.
# Iteration=13
# new_angles=[0.69868198]
# new_P:
# [[0.0014713+0.j]]
# likelihood is -870.2466523697668 on iteration 13.
# Iteration=14
# new_angles=[0.69827988]
# new_P:
# [[0.00162148+0.j]]
# likelihood is -870.2308881451988 on iteration 14.
# Iteration=15
# new_angles=[0.69792066]
# new_P:
# [[0.0017832+0.j]]
# likelihood is -870.2139458424128 on iteration 15.
# Iteration=16
# new_angles=[0.69761784]
# new_P:
# [[0.00195874+0.j]]
# likelihood is -870.1955912437761 on iteration 16.
# Iteration=17
# new_angles=[0.69740436]
# new_P:
# [[0.00215096+0.j]]
# likelihood is -870.1755349435211 on iteration 17.
# Iteration=18
# new_angles=[0.69723769]
# new_P:
# [[0.00236345+0.j]]
# likelihood is -870.1534026703087 on iteration 18.
# Iteration=19
# new_angles=[0.69708166]
# new_P:
# [[0.00260078+0.j]]
# likelihood is -870.1287230910386 on iteration 19.
# Iteration=20
# new_angles=[0.69693931]
# new_P:
# [[0.0028689+0.j]]
# likelihood is -870.1008936938554 on iteration 20.
# 5-th start
# theta=[0.69420695],P=[[2.63712642e-07-3.97046694e-24j]]
# Inital likelihood = -870.4010990043953
# Iteration=1
# new_angles=[0.68922612]
# new_P:
# [[0.00012188+0.j]]
# likelihood is -870.3884423465073 on iteration 1.
# Iteration=2
# new_angles=[0.69058332]
# new_P:
# [[0.00022216+0.j]]
# likelihood is -870.377895774694 on iteration 2.
# Iteration=3
# new_angles=[0.69149351]
# new_P:
# [[0.00032314+0.j]]
# likelihood is -870.3672541067064 on iteration 3.
# Iteration=4
# new_angles=[0.69239074]
# new_P:
# [[0.00042524+0.j]]
# likelihood is -870.3564647196074 on iteration 4.
# Iteration=5
# new_angles=[0.69302845]
# new_P:
# [[0.00052894+0.j]]
# likelihood is -870.345517871513 on iteration 5.
# Iteration=6
# new_angles=[0.69366331]
# new_P:
# [[0.00063475+0.j]]
# likelihood is -870.3343429427725 on iteration 6.
# Iteration=7
# new_angles=[0.6942155]
# new_P:
# [[0.00074324+0.j]]
# likelihood is -870.3228949370625 on iteration 7.
# Iteration=8
# new_angles=[0.6947089]
# new_P:
# [[0.00085507+0.j]]
# likelihood is -870.3111089519588 on iteration 8.
# Iteration=9
# new_angles=[0.69502992]
# new_P:
# [[0.00097094+0.j]]
# likelihood is -870.2989211135318 on iteration 9.
# Iteration=10
# new_angles=[0.69529373]
# new_P:
# [[0.00109168+0.j]]
# likelihood is -870.2862353967607 on iteration 10.
# Iteration=11
# new_angles=[0.69552861]
# new_P:
# [[0.00121826+0.j]]
# likelihood is -870.2729507119697 on iteration 11.
# Iteration=12
# new_angles=[0.69570446]
# new_P:
# [[0.0013518+0.j]]
# likelihood is -870.2589529401712 on iteration 12.
# Iteration=13
# new_angles=[0.69582306]
# new_P:
# [[0.00149362+0.j]]
# likelihood is -870.244104180107 on iteration 13.
# Iteration=14
# new_angles=[0.69592797]
# new_P:
# [[0.00164533+0.j]]
# likelihood is -870.2282377969495 on iteration 14.
# Iteration=15
# new_angles=[0.69601952]
# new_P:
# [[0.00180884+0.j]]
# likelihood is -870.2111553409135 on iteration 15.
# Iteration=16
# new_angles=[0.69611107]
# new_P:
# [[0.00198653+0.j]]
# likelihood is -870.1926133637137 on iteration 16.
# Iteration=17
# new_angles=[0.69620263]
# new_P:
# [[0.00218133+0.j]]
# likelihood is -870.1723108494637 on iteration 17.
# Iteration=18
# new_angles=[0.69621947]
# new_P:
# [[0.00239697+0.j]]
# likelihood is -870.1498712143087 on iteration 18.
# Iteration=19
# new_angles=[0.69623631]
# new_P:
# [[0.00263816+0.j]]
# likelihood is -870.1248100942704 on iteration 19.
# Iteration=20
# new_angles=[0.69625316]
# new_P:
# [[0.00291105+0.j]]
# likelihood is -870.096502715453 on iteration 20.
# 6-th start
# theta=[0.72207198],P=[[1.08695785e-07+1.65436123e-24j]]
# Inital likelihood = -870.4011173514194
# Iteration=1
# new_angles=[0.72860067]
# new_P:
# [[0.00010717+0.j]]
# likelihood is -870.3927830096814 on iteration 1.
# Iteration=2
# new_angles=[0.72206764]
# new_P:
# [[0.00020735+0.j]]
# likelihood is -870.3830555250058 on iteration 2.
# Iteration=3
# new_angles=[0.71687422]
# new_P:
# [[0.00030809+0.j]]
# likelihood is -870.3723213011959 on iteration 3.
# Iteration=4
# new_angles=[0.71263079]
# new_P:
# [[0.00040985+0.j]]
# likelihood is -870.3610403355616 on iteration 4.
# Iteration=5
# new_angles=[0.70941187]
# new_P:
# [[0.00051313+0.j]]
# likelihood is -870.3495698733919 on iteration 5.
# Iteration=6
# new_angles=[0.70684056]
# new_P:
# [[0.00061844+0.j]]
# likelihood is -870.337920095766 on iteration 6.
# Iteration=7
# new_angles=[0.70486122]
# new_P:
# [[0.00072638+0.j]]
# likelihood is -870.3261130050511 on iteration 7.
# Iteration=8
# new_angles=[0.70321901]
# new_P:
# [[0.00083756+0.j]]
# likelihood is -870.314038409016 on iteration 8.
# Iteration=9
# new_angles=[0.70188501]
# new_P:
# [[0.0009527+0.j]]
# likelihood is -870.3016372711327 on iteration 9.
# Iteration=10
# new_angles=[0.7008719]
# new_P:
# [[0.00107262+0.j]]
# likelihood is -870.2888357428234 on iteration 10.
# Iteration=11
# new_angles=[0.70008938]
# new_P:
# [[0.00119824+0.j]]
# likelihood is -870.2755078714924 on iteration 11.
# Iteration=12
# new_angles=[0.69938339]
# new_P:
# [[0.00133067+0.j]]
# likelihood is -870.2614989126896 on iteration 12.
# Iteration=13
# new_angles=[0.69883724]
# new_P:
# [[0.00147119+0.j]]
# likelihood is -870.2466955176583 on iteration 13.
# Iteration=14
# new_angles=[0.69837587]
# new_P:
# [[0.00162137+0.j]]
# likelihood is -870.230918149523 on iteration 14.
# Iteration=15
# new_angles=[0.69801663]
# new_P:
# [[0.00178307+0.j]]
# likelihood is -870.2139750530218 on iteration 15.
# Iteration=16
# new_angles=[0.69771486]
# new_P:
# [[0.0019586+0.j]]
# likelihood is -870.1956200206309 on iteration 16.
# Iteration=17
# new_angles=[0.69747234]
# new_P:
# [[0.00215081+0.j]]
# likelihood is -870.1755598264319 on iteration 17.
# Iteration=18
# new_angles=[0.69724549]
# new_P:
# [[0.00236328+0.j]]
# likelihood is -870.1534210853654 on iteration 18.
# Iteration=19
# new_angles=[0.69708627]
# new_P:
# [[0.0026006+0.j]]
# likelihood is -870.1287430523444 on iteration 19.
# Iteration=20
# new_angles=[0.69694392]
# new_P:
# [[0.00286869+0.j]]
# likelihood is -870.1009160407333 on iteration 20.
# 7-th start
# theta=[0.83118872],P=[[9.765625e-08+0.j]]
# Inital likelihood = -870.4011267594258
# Iteration=1
# new_angles=[0.82741109]
# new_P:
# [[0.00010992+0.j]]
# likelihood is -870.4010690302937 on iteration 1.
# Likelihood is converged!
# 8-th start
# theta=[0.85933204],P=[[9.765625e-08+0.j]]
# Inital likelihood = -870.4011269181249
# Iteration=1
# new_angles=[0.85933204]
# new_P:
# [[0.00011031+0.j]]
# likelihood is -870.4012260455469 on iteration 1.
# Likelihood is converged!
# 9-th start
# theta=[0.73719288],P=[[7.93250092e-08-4.63221143e-24j]]
# Inital likelihood = -870.4011217367256
# Iteration=1
# new_angles=[0.74381132]
# new_P:
# [[0.00010557+0.j]]
# likelihood is -870.3955004490456 on iteration 1.
# Iteration=2
# new_angles=[0.7341905]
# new_P:
# [[0.0002057+0.j]]
# likelihood is -870.3869222354713 on iteration 2.
# Iteration=3
# new_angles=[0.72641955]
# new_P:
# [[0.00030631+0.j]]
# likelihood is -870.3763014100127 on iteration 3.
# Iteration=4
# new_angles=[0.72040993]
# new_P:
# [[0.00040787+0.j]]
# likelihood is -870.3647283403457 on iteration 4.
# Iteration=5
# new_angles=[0.7155399]
# new_P:
# [[0.00051089+0.j]]
# likelihood is -870.3526496548036 on iteration 5.
# Iteration=6
# new_angles=[0.71175748]
# new_P:
# [[0.00061594+0.j]]
# likelihood is -870.3404410391695 on iteration 6.
# Iteration=7
# new_angles=[0.70863028]
# new_P:
# [[0.00072361+0.j]]
# likelihood is -870.3280577817357 on iteration 7.
# Iteration=8
# new_angles=[0.7062381]
# new_P:
# [[0.00083453+0.j]]
# likelihood is -870.3155965905067 on iteration 8.
# Iteration=9
# new_angles=[0.7043175]
# new_P:
# [[0.00094942+0.j]]
# likelihood is -870.3029009678221 on iteration 9.
# Iteration=10
# new_angles=[0.7028088]
# new_P:
# [[0.00106909+0.j]]
# likelihood is -870.2898774299576 on iteration 10.
# Iteration=11
# new_angles=[0.70153285]
# new_P:
# [[0.00119445+0.j]]
# likelihood is -870.2763589418969 on iteration 11.
# Iteration=12
# new_angles=[0.70053378]
# new_P:
# [[0.00132661+0.j]]
# likelihood is -870.2622483322493 on iteration 12.
# Iteration=13
# new_angles=[0.69975149]
# new_P:
# [[0.00146684+0.j]]
# likelihood is -870.2473827972829 on iteration 13.
# Iteration=14
# new_angles=[0.69911658]
# new_P:
# [[0.00161668+0.j]]
# likelihood is -870.231575371699 on iteration 14.
# Iteration=15
# new_angles=[0.69859769]
# new_P:
# [[0.00177801+0.j]]
# likelihood is -870.2146210489145 on iteration 15.
# Iteration=16
# new_angles=[0.69819561]
# new_P:
# [[0.00195309+0.j]]
# likelihood is -870.196280895938 on iteration 16.
# Iteration=17
# new_angles=[0.6978695]
# new_P:
# [[0.00214478+0.j]]
# likelihood is -870.1762519016927 on iteration 17.
# Iteration=18
# new_angles=[0.69756777]
# new_P:
# [[0.00235662+0.j]]
# likelihood is -870.1541587433875 on iteration 18.
# Iteration=19
# new_angles=[0.6973543]
# new_P:
# [[0.00259317+0.j]]
# likelihood is -870.1295476038147 on iteration 19.
# Iteration=20
# new_angles=[0.69719507]
# new_P:
# [[0.00286032+0.j]]
# likelihood is -870.1018120292729 on iteration 20.
# best_start=5
# Время выполнения функции: 44.500509 секунд

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.69625316]), array([[0.00291105+0.j]]))

# %%
lf.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q1), lf.incomplete_lkhd(X1_with_mv, theta1_rad, P1, Q1)
# Out:
# (np.float64(-870.096502715453), np.float64(-852.4011191641745))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11

failing_sensors2 = np.arange(8)
gap_ratio2 = 0.5 * np.ones_like(failing_sensors2, dtype=np.float32)

theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sn.gss(Num_emitters2, sample_size2, P2)
N2 = sn.gss(Num_sensors2, sample_size2, Q2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sn.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sn.initial_Cov(X2_with_mv)
MUSIC_theta2 = sm.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sn.SNR(A2, P2, Q2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2, lhd_list2, angles_list2 = em.multistart_EM(X2_with_mv, 
                                                                        Num_emitters2, 
                                                                        Q=Q2,
                                                                        theta_guess=MUSIC_theta2, 
                                                                        num_of_starts=20, 
                                                                        max_iter=20, 
                                                                        rtol_params=1e-6,
                                                                        rtol_lkhd=1e-6,
                                                                        reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.72431164],P=[[7.5917774e-08+4.13590306e-24j]]
# Inital likelihood = -689.5792611594288
# Iteration=1
# new_angles=[0.72431164]
# new_P:
# [[0.00010484+0.j]]
# likelihood is -689.5691426530494 on iteration 1.
# Iteration=2
# new_angles=[0.72004058]
# new_P:
# [[0.00020508+0.j]]
# likelihood is -689.5583380649606 on iteration 2.
# Iteration=3
# new_angles=[0.71643273]
# new_P:
# [[0.00030603+0.j]]
# likelihood is -689.5468378630277 on iteration 3.
# Iteration=4
# new_angles=[0.7134818]
# new_P:
# [[0.00040827+0.j]]
# likelihood is -689.534921465554 on iteration 4.
# Iteration=5
# new_angles=[0.71122371]
# new_P:
# [[0.00051244+0.j]]
# likelihood is -689.5227543532703 on iteration 5.
# Iteration=6
# new_angles=[0.70938428]
# new_P:
# [[0.00061923+0.j]]
# likelihood is -689.5102895341357 on iteration 6.
# Iteration=7
# new_angles=[0.7077798]
# new_P:
# [[0.00072945+0.j]]
# likelihood is -689.4974409215903 on iteration 7.
# Iteration=8
# new_angles=[0.70658759]
# new_P:
# [[0.00084402+0.j]]
# likelihood is -689.4842037655498 on iteration 8.
# Iteration=9
# new_angles=[0.70558423]
# new_P:
# [[0.000964+0.j]]
# likelihood is -689.4704015336896 on iteration 9.
# Iteration=10
# new_angles=[0.70471469]
# new_P:
# [[0.00109064+0.j]]
# likelihood is -689.4558870575754 on iteration 10.
# Iteration=11
# new_angles=[0.70403318]
# new_P:
# [[0.00122547+0.j]]
# likelihood is -689.4405117743823 on iteration 11.
# Iteration=12
# new_angles=[0.70339597]
# new_P:
# [[0.00137033+0.j]]
# likelihood is -689.4240330130519 on iteration 12.
# Iteration=13
# new_angles=[0.70296731]
# new_P:
# [[0.00152751+0.j]]
# likelihood is -689.4062374024287 on iteration 13.
# Iteration=14
# new_angles=[0.70260668]
# new_P:
# [[0.00169987+0.j]]
# likelihood is -689.3867712284027 on iteration 14.
# Iteration=15
# new_angles=[0.70229001]
# new_P:
# [[0.00189109+0.j]]
# likelihood is -689.3652241990378 on iteration 15.
# Iteration=16
# new_angles=[0.70206225]
# new_P:
# [[0.00210594+0.j]]
# likelihood is -689.341079033587 on iteration 16.
# Iteration=17
# new_angles=[0.70184797]
# new_P:
# [[0.00235075+0.j]]
# likelihood is -689.3136272776425 on iteration 17.
# Iteration=18
# new_angles=[0.70168799]
# new_P:
# [[0.00263409+0.j]]
# likelihood is -689.2819396625813 on iteration 18.
# Iteration=19
# new_angles=[0.70153137]
# new_P:
# [[0.00296784+0.j]]
# likelihood is -689.2447152306714 on iteration 19.
# Iteration=20
# new_angles=[0.70137477]
# new_P:
# [[0.00336895+0.j]]
# likelihood is -689.2001214597753 on iteration 20.
# 1-th start
# theta=[0.76634416],P=[[4.65993421e-08-2.64697796e-24j]]
# Inital likelihood = -689.5792672995802
# Iteration=1
# new_angles=[0.76634416]
# new_P:
# [[0.00010289+0.j]]
# likelihood is -689.576630918838 on iteration 1.
# Iteration=2
# new_angles=[0.75555606]
# new_P:
# [[0.00020298+0.j]]
# likelihood is -689.5705838365645 on iteration 2.
# Iteration=3
# new_angles=[0.74583096]
# new_P:
# [[0.00030347+0.j]]
# likelihood is -689.561019405907 on iteration 3.
# Iteration=4
# new_angles=[0.7375111]
# new_P:
# [[0.00040491+0.j]]
# likelihood is -689.5488289922573 on iteration 4.
# Iteration=5
# new_angles=[0.73092595]
# new_P:
# [[0.00050801+0.j]]
# likelihood is -689.5353835870984 on iteration 5.
# Iteration=6
# new_angles=[0.72544821]
# new_P:
# [[0.00061357+0.j]]
# likelihood is -689.5211272048788 on iteration 6.
# Iteration=7
# new_angles=[0.7209827]
# new_P:
# [[0.00072247+0.j]]
# likelihood is -689.5065229612909 on iteration 7.
# Iteration=8
# new_angles=[0.71737188]
# new_P:
# [[0.00083567+0.j]]
# likelihood is -689.491714984163 on iteration 8.
# Iteration=9
# new_angles=[0.71440464]
# new_P:
# [[0.00095426+0.j]]
# likelihood is -689.4766089786202 on iteration 9.
# Iteration=10
# new_angles=[0.71196186]
# new_P:
# [[0.00107949+0.j]]
# likelihood is -689.4610719359422 on iteration 10.
# Iteration=11
# new_angles=[0.7100211]
# new_P:
# [[0.00121285+0.j]]
# likelihood is -689.4449640015109 on iteration 11.
# Iteration=12
# new_angles=[0.70841575]
# new_P:
# [[0.00135612+0.j]]
# likelihood is -689.4279713957919 on iteration 12.
# Iteration=13
# new_angles=[0.70707583]
# new_P:
# [[0.00151155+0.j]]
# likelihood is -689.4098019256231 on iteration 13.
# Iteration=14
# new_angles=[0.70605824]
# new_P:
# [[0.00168194+0.j]]
# likelihood is -689.3901740533659 on iteration 14.
# Iteration=15
# new_angles=[0.70517262]
# new_P:
# [[0.00187083+0.j]]
# likelihood is -689.3685696745399 on iteration 15.
# Iteration=16
# new_angles=[0.70440822]
# new_P:
# [[0.00208289+0.j]]
# likelihood is -689.344470434262 on iteration 16.
# Iteration=17
# new_angles=[0.7037708]
# new_P:
# [[0.00232427+0.j]]
# likelihood is -689.3172006430822 on iteration 17.
# Iteration=18
# new_angles=[0.70328736]
# new_P:
# [[0.00260328+0.j]]
# likelihood is -689.2858571993283 on iteration 18.
# Iteration=19
# new_angles=[0.7028994]
# new_P:
# [[0.00293143+0.j]]
# likelihood is -689.2491561668539 on iteration 19.
# Iteration=20
# new_angles=[0.70253878]
# new_P:
# [[0.00332507+0.j]]
# likelihood is -689.2052962704763 on iteration 20.
# 2-th start
# theta=[0.7614843],P=[[5.77524969e-08+5.29395592e-24j]]
# Inital likelihood = -689.5792665882861
# Iteration=1
# new_angles=[0.7614843]
# new_P:
# [[0.0001043+0.j]]
# likelihood is -689.5758272549378 on iteration 1.
# Iteration=2
# new_angles=[0.75084161]
# new_P:
# [[0.0002044+0.j]]
# likelihood is -689.5688281155833 on iteration 2.
# Iteration=3
# new_angles=[0.74180666]
# new_P:
# [[0.00030496+0.j]]
# likelihood is -689.55868958081 on iteration 3.
# Iteration=4
# new_angles=[0.7341747]
# new_P:
# [[0.00040654+0.j]]
# likelihood is -689.5463406773912 on iteration 4.
# Iteration=5
# new_angles=[0.72790225]
# new_P:
# [[0.00050984+0.j]]
# likelihood is -689.5327905508022 on iteration 5.
# Iteration=6
# new_angles=[0.72300008]
# new_P:
# [[0.00061566+0.j]]
# likelihood is -689.5188430528472 on iteration 6.
# Iteration=7
# new_angles=[0.7190444]
# new_P:
# [[0.00072486+0.j]]
# likelihood is -689.5046147983185 on iteration 7.
# Iteration=8
# new_angles=[0.71576318]
# new_P:
# [[0.00083837+0.j]]
# likelihood is -689.4900792726963 on iteration 8.
# Iteration=9
# new_angles=[0.71313672]
# new_P:
# [[0.00095728+0.j]]
# likelihood is -689.4752624584138 on iteration 9.
# Iteration=10
# new_angles=[0.71097201]
# new_P:
# [[0.00108285+0.j]]
# likelihood is -689.4599530416014 on iteration 10.
# Iteration=11
# new_angles=[0.70920125]
# new_P:
# [[0.00121656+0.j]]
# likelihood is -689.443971078466 on iteration 11.
# Iteration=12
# new_angles=[0.70777721]
# new_P:
# [[0.00136023+0.j]]
# likelihood is -689.4270923477012 on iteration 12.
# Iteration=13
# new_angles=[0.70656926]
# new_P:
# [[0.0015161+0.j]]
# likelihood is -689.4089851650909 on iteration 13.
# Iteration=14
# new_angles=[0.70556591]
# new_P:
# [[0.00168699+0.j]]
# likelihood is -689.3893299490293 on iteration 14.
# Iteration=15
# new_angles=[0.70472866]
# new_P:
# [[0.0018765+0.j]]
# likelihood is -689.3677030670775 on iteration 15.
# Iteration=16
# new_angles=[0.70404714]
# new_P:
# [[0.00208932+0.j]]
# likelihood is -689.3435780573813 on iteration 16.
# Iteration=17
# new_angles=[0.70349884]
# new_P:
# [[0.00233163+0.j]]
# likelihood is -689.3162578703061 on iteration 17.
# Iteration=18
# new_angles=[0.70302192]
# new_P:
# [[0.00261181+0.j]]
# likelihood is -689.2847957212576 on iteration 18.
# Iteration=19
# new_angles=[0.70264735]
# new_P:
# [[0.00294149+0.j]]
# likelihood is -689.2479375437476 on iteration 19.
# Iteration=20
# new_angles=[0.70233068]
# new_P:
# [[0.00333719+0.j]]
# likelihood is -689.2038758155836 on iteration 20.
# 3-th start
# theta=[0.83255839],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688437123
# Iteration=1
# new_angles=[0.83255839]
# new_P:
# [[0.00010397+0.j]]
# likelihood is -689.5800117151923 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 4-th start
# theta=[0.73004403],P=[[6.95706666e-08-3.30872245e-25j]]
# Inital likelihood = -689.5792623721018
# Iteration=1
# new_angles=[0.73539341]
# new_P:
# [[0.00010445+0.j]]
# likelihood is -689.5710163669963 on iteration 1.
# Iteration=2
# new_angles=[0.72892259]
# new_P:
# [[0.00020465+0.j]]
# likelihood is -689.560910508075 on iteration 2.
# Iteration=3
# new_angles=[0.723701]
# new_P:
# [[0.0003055+0.j]]
# likelihood is -689.5495323646464 on iteration 3.
# Iteration=4
# new_angles=[0.71947675]
# new_P:
# [[0.00040759+0.j]]
# likelihood is -689.5374355129316 on iteration 4.
# Iteration=5
# new_angles=[0.7162279]
# new_P:
# [[0.00051156+0.j]]
# likelihood is -689.5250011138256 on iteration 5.
# Iteration=6
# new_angles=[0.71341145]
# new_P:
# [[0.00061813+0.j]]
# likelihood is -689.5121503208945 on iteration 6.
# Iteration=7
# new_angles=[0.71114598]
# new_P:
# [[0.00072813+0.j]]
# likelihood is -689.4990024022773 on iteration 7.
# Iteration=8
# new_angles=[0.70938491]
# new_P:
# [[0.00084246+0.j]]
# likelihood is -689.4855135245285 on iteration 8.
# Iteration=9
# new_angles=[0.70786968]
# new_P:
# [[0.00096219+0.j]]
# likelihood is -689.4714820973795 on iteration 9.
# Iteration=10
# new_angles=[0.70667738]
# new_P:
# [[0.00108858+0.j]]
# likelihood is -689.4568255072602 on iteration 10.
# Iteration=11
# new_angles=[0.70566015]
# new_P:
# [[0.00122314+0.j]]
# likelihood is -689.4413196506991 on iteration 11.
# Iteration=12
# new_angles=[0.70479055]
# new_P:
# [[0.00136771+0.j]]
# likelihood is -689.4247547455998 on iteration 12.
# Iteration=13
# new_angles=[0.70408786]
# new_P:
# [[0.00152456+0.j]]
# likelihood is -689.4068859560655 on iteration 13.
# Iteration=14
# new_angles=[0.70352383]
# new_P:
# [[0.00169656+0.j]]
# likelihood is -689.3873838314111 on iteration 14.
# Iteration=15
# new_angles=[0.70297578]
# new_P:
# [[0.00188735+0.j]]
# likelihood is -689.3658062036557 on iteration 15.
# Iteration=16
# new_angles=[0.70260137]
# new_P:
# [[0.0021017+0.j]]
# likelihood is -689.3416739128666 on iteration 16.
# Iteration=17
# new_angles=[0.70228471]
# new_P:
# [[0.00234588+0.j]]
# likelihood is -689.3142613378027 on iteration 17.
# Iteration=18
# new_angles=[0.70205694]
# new_P:
# [[0.00262843+0.j]]
# likelihood is -689.2826431929926 on iteration 18.
# Iteration=19
# new_angles=[0.70184783]
# new_P:
# [[0.00296115+0.j]]
# likelihood is -689.2455174271538 on iteration 19.
# Iteration=20
# new_angles=[0.70168799]
# new_P:
# [[0.00336089+0.j]]
# likelihood is -689.201069140591 on iteration 20.
# 5-th start
# theta=[0.7029336],P=[[1.77615171e-07-2.64697796e-24j]]
# Inital likelihood = -689.579248242526
# Iteration=1
# new_angles=[0.71321846]
# new_P:
# [[0.00011845+0.j]]
# likelihood is -689.5663603735208 on iteration 1.
# Iteration=2
# new_angles=[0.71090605]
# new_P:
# [[0.00021878+0.j]]
# likelihood is -689.5550627014438 on iteration 2.
# Iteration=3
# new_angles=[0.70897778]
# new_P:
# [[0.00031994+0.j]]
# likelihood is -689.5435106948846 on iteration 3.
# Iteration=4
# new_angles=[0.7076844]
# new_P:
# [[0.00042249+0.j]]
# likelihood is -689.5317934788368 on iteration 4.
# Iteration=5
# new_angles=[0.70649229]
# new_P:
# [[0.00052708+0.j]]
# likelihood is -689.5198023551814 on iteration 5.
# Iteration=6
# new_angles=[0.70547522]
# new_P:
# [[0.00063439+0.j]]
# likelihood is -689.5075016423232 on iteration 6.
# Iteration=7
# new_angles=[0.70460576]
# new_P:
# [[0.00074525+0.j]]
# likelihood is -689.4948148707805 on iteration 7.
# Iteration=8
# new_angles=[0.70392772]
# new_P:
# [[0.00086057+0.j]]
# likelihood is -689.4816570761459 on iteration 8.
# Iteration=9
# new_angles=[0.70337948]
# new_P:
# [[0.00098144+0.j]]
# likelihood is -689.4679000621121 on iteration 9.
# Iteration=10
# new_angles=[0.70296731]
# new_P:
# [[0.00110915+0.j]]
# likelihood is -689.4534030098148 on iteration 10.
# Iteration=11
# new_angles=[0.70260668]
# new_P:
# [[0.00124525+0.j]]
# likelihood is -689.4379800370328 on iteration 11.
# Iteration=12
# new_angles=[0.70229001]
# new_P:
# [[0.00139163+0.j]]
# likelihood is -689.4214204149155 on iteration 12.
# Iteration=13
# new_angles=[0.70204655]
# new_P:
# [[0.00155064+0.j]]
# likelihood is -689.4034679319601 on iteration 13.
# Iteration=14
# new_angles=[0.70184604]
# new_P:
# [[0.00172525+0.j]]
# likelihood is -689.3837908427428 on iteration 14.
# Iteration=15
# new_angles=[0.70164555]
# new_P:
# [[0.00191923+0.j]]
# likelihood is -689.3619661593145 on iteration 15.
# Iteration=16
# new_angles=[0.70148894]
# new_P:
# [[0.00213753+0.j]]
# likelihood is -689.3374561875111 on iteration 16.
# Iteration=17
# new_angles=[0.70136837]
# new_P:
# [[0.00238671+0.j]]
# likelihood is -689.3095406782699 on iteration 17.
# Iteration=18
# new_angles=[0.70130055]
# new_P:
# [[0.00267568+0.j]]
# likelihood is -689.277248565034 on iteration 18.
# Iteration=19
# new_angles=[0.70123273]
# new_P:
# [[0.00301681+0.j]]
# likelihood is -689.2392285729052 on iteration 19.
# Iteration=20
# new_angles=[0.70117835]
# new_P:
# [[0.00342784+0.j]]
# likelihood is -689.193567005708 on iteration 20.
# 6-th start
# theta=[0.73079862],P=[[6.86735671e-08-2.97785021e-24j]]
# Inital likelihood = -689.5792625347437
# Iteration=1
# new_angles=[0.73501302]
# new_P:
# [[0.00010439+0.j]]
# likelihood is -689.5709525722062 on iteration 1.
# Iteration=2
# new_angles=[0.72869196]
# new_P:
# [[0.00020459+0.j]]
# likelihood is -689.5608424827947 on iteration 2.
# Iteration=3
# new_angles=[0.72356191]
# new_P:
# [[0.00030544+0.j]]
# likelihood is -689.5494805235817 on iteration 3.
# Iteration=4
# new_angles=[0.71929366]
# new_P:
# [[0.00040753+0.j]]
# likelihood is -689.5373552143838 on iteration 4.
# Iteration=5
# new_angles=[0.71599781]
# new_P:
# [[0.00051151+0.j]]
# likelihood is -689.5248914590389 on iteration 5.
# Iteration=6
# new_angles=[0.71318192]
# new_P:
# [[0.00061809+0.j]]
# likelihood is -689.5120394405311 on iteration 6.
# Iteration=7
# new_angles=[0.71101713]
# new_P:
# [[0.00072809+0.j]]
# likelihood is -689.4989422762967 on iteration 7.
# Iteration=8
# new_angles=[0.70917803]
# new_P:
# [[0.00084243+0.j]]
# likelihood is -689.4854178866584 on iteration 8.
# Iteration=9
# new_angles=[0.70766307]
# new_P:
# [[0.00096217+0.j]]
# likelihood is -689.4713906023678 on iteration 9.
# Iteration=10
# new_angles=[0.70649264]
# new_P:
# [[0.00108858+0.j]]
# likelihood is -689.456746818044 on iteration 10.
# Iteration=11
# new_angles=[0.70548937]
# new_P:
# [[0.00122316+0.j]]
# likelihood is -689.4412501705989 on iteration 11.
# Iteration=12
# new_angles=[0.7046199]
# new_P:
# [[0.00136774+0.j]]
# likelihood is -689.424689077496 on iteration 12.
# Iteration=13
# new_angles=[0.70397916]
# new_P:
# [[0.00152461+0.j]]
# likelihood is -689.4068435804039 on iteration 13.
# Iteration=14
# new_angles=[0.7034309]
# new_P:
# [[0.00169663+0.j]]
# likelihood is -689.3873474216947 on iteration 14.
# Iteration=15
# new_angles=[0.70296731]
# new_P:
# [[0.00188744+0.j]]
# likelihood is -689.3657942906059 on iteration 15.
# Iteration=16
# new_angles=[0.70260668]
# new_P:
# [[0.00210179+0.j]]
# likelihood is -689.3416645061922 on iteration 16.
# Iteration=17
# new_angles=[0.70229001]
# new_P:
# [[0.00234599+0.j]]
# likelihood is -689.3142504375645 on iteration 17.
# Iteration=18
# new_angles=[0.70206225]
# new_P:
# [[0.00262855+0.j]]
# likelihood is -689.2826304454197 on iteration 18.
# Iteration=19
# new_angles=[0.70186173]
# new_P:
# [[0.0029613+0.j]]
# likelihood is -689.2455041213727 on iteration 19.
# Iteration=20
# new_angles=[0.70168799]
# new_P:
# [[0.00336106+0.j]]
# likelihood is -689.201049834398 on iteration 20.
# 7-th start
# theta=[0.83991537],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579268841746
# Iteration=1
# new_angles=[0.83991537]
# new_P:
# [[0.00010405+0.j]]
# likelihood is -689.5800081331448 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 8-th start
# theta=[0.86805869],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688779773
# Iteration=1
# new_angles=[0.86354155]
# new_P:
# [[0.00010422+0.j]]
# likelihood is -689.5800685448779 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 9-th start
# theta=[0.74591953],P=[[9.79826128e-08-1.98523347e-24j]]
# Inital likelihood = -689.5792626099957
# Iteration=1
# new_angles=[0.7472533]
# new_P:
# [[0.00011078+0.j]]
# likelihood is -689.57288826786 on iteration 1.
# Iteration=2
# new_angles=[0.73892262]
# new_P:
# [[0.00021095+0.j]]
# likelihood is -689.5639272378546 on iteration 2.
# Iteration=3
# new_angles=[0.73195262]
# new_P:
# [[0.00031172+0.j]]
# likelihood is -689.5528423282858 on iteration 3.
# Iteration=4
# new_angles=[0.72615448]
# new_P:
# [[0.00041367+0.j]]
# likelihood is -689.5404586105429 on iteration 4.
# Iteration=5
# new_angles=[0.72153726]
# new_P:
# [[0.00051749+0.j]]
# likelihood is -689.5274746556083 on iteration 5.
# Iteration=6
# new_angles=[0.71773505]
# new_P:
# [[0.00062392+0.j]]
# likelihood is -689.514080242787 on iteration 6.
# Iteration=7
# new_angles=[0.71476688]
# new_P:
# [[0.00073381+0.j]]
# likelihood is -689.5004868743767 on iteration 7.
# Iteration=8
# new_angles=[0.71227651]
# new_P:
# [[0.00084809+0.j]]
# likelihood is -689.4865149217917 on iteration 8.
# Iteration=9
# new_angles=[0.71028794]
# new_P:
# [[0.00096783+0.j]]
# likelihood is -689.4721434165242 on iteration 9.
# Iteration=10
# new_angles=[0.70862428]
# new_P:
# [[0.00109431+0.j]]
# likelihood is -689.4571621881188 on iteration 10.
# Iteration=11
# new_angles=[0.70728412]
# new_P:
# [[0.00122903+0.j]]
# likelihood is -689.4414195546815 on iteration 11.
# Iteration=12
# new_angles=[0.70617172]
# new_P:
# [[0.00137386+0.j]]
# likelihood is -689.4246625492419 on iteration 12.
# Iteration=13
# new_angles=[0.70521269]
# new_P:
# [[0.00153108+0.j]]
# likelihood is -689.4066021924979 on iteration 13.
# Iteration=14
# new_angles=[0.7044879]
# new_P:
# [[0.00170356+0.j]]
# likelihood is -689.3869537815385 on iteration 14.
# Iteration=15
# new_angles=[0.70385044]
# new_P:
# [[0.00189499+0.j]]
# likelihood is -689.3652426810305 on iteration 15.
# Iteration=16
# new_angles=[0.70332947]
# new_P:
# [[0.00211016+0.j]]
# likelihood is -689.3409519008395 on iteration 16.
# Iteration=17
# new_angles=[0.7029415]
# new_P:
# [[0.00235541+0.j]]
# likelihood is -689.3133864179355 on iteration 17.
# Iteration=18
# new_angles=[0.7025671]
# new_P:
# [[0.00263935+0.j]]
# likelihood is -689.2815632750036 on iteration 18.
# Iteration=19
# new_angles=[0.70225045]
# new_P:
# [[0.00297392+0.j]]
# likelihood is -689.2441980522364 on iteration 19.
# Iteration=20
# new_angles=[0.70200769]
# new_P:
# [[0.00337617+0.j]]
# likelihood is -689.1994516471874 on iteration 20.
# 10-th start
# theta=[0.45944132],P=[[5.55659323e-08+3.57342025e-23j]]
# Inital likelihood = -689.5792678138821
# Iteration=1
# new_angles=[0.46489919]
# new_P:
# [[0.00010389+0.j]]
# likelihood is -689.5778825634303 on iteration 1.
# Iteration=2
# new_angles=[0.465992]
# new_P:
# [[0.00020395+0.j]]
# likelihood is -689.5765184181334 on iteration 2.
# Iteration=3
# new_angles=[0.46668978]
# new_P:
# [[0.00030422+0.j]]
# likelihood is -689.5751431630533 on iteration 3.
# Iteration=4
# new_angles=[0.4673153]
# new_P:
# [[0.00040488+0.j]]
# likelihood is -689.5737539373051 on iteration 4.
# Iteration=5
# new_angles=[0.46786503]
# new_P:
# [[0.00050615+0.j]]
# likelihood is -689.5723515641869 on iteration 5.
# Iteration=6
# new_angles=[0.4684058]
# new_P:
# [[0.00060829+0.j]]
# likelihood is -689.5709317319624 on iteration 6.
# Iteration=7
# new_angles=[0.46882982]
# new_P:
# [[0.0007116+0.j]]
# likelihood is -689.5694981533521 on iteration 7.
# Iteration=8
# new_angles=[0.46925486]
# new_P:
# [[0.00081643+0.j]]
# likelihood is -689.5680410435104 on iteration 8.
# Iteration=9
# new_angles=[0.46959803]
# new_P:
# [[0.00092317+0.j]]
# likelihood is -689.5665611261451 on iteration 9.
# Iteration=10
# new_angles=[0.46994127]
# new_P:
# [[0.0010323+0.j]]
# likelihood is -689.5650478906414 on iteration 10.
# Iteration=11
# new_angles=[0.47026777]
# new_P:
# [[0.00114434+0.j]]
# likelihood is -689.563495869455 on iteration 11.
# Iteration=12
# new_angles=[0.47053527]
# new_P:
# [[0.00125989+0.j]]
# likelihood is -689.5619003589459 on iteration 12.
# Iteration=13
# new_angles=[0.47080919]
# new_P:
# [[0.00137967+0.j]]
# likelihood is -689.560247850076 on iteration 13.
# Iteration=14
# new_angles=[0.47104832]
# new_P:
# [[0.00150449+0.j]]
# likelihood is -689.558530671729 on iteration 14.
# Iteration=15
# new_angles=[0.47128748]
# new_P:
# [[0.00163531+0.j]]
# likelihood is -689.5567339175071 on iteration 15.
# Iteration=16
# new_angles=[0.47152667]
# new_P:
# [[0.00177327+0.j]]
# likelihood is -689.5548428983993 on iteration 16.
# Iteration=17
# new_angles=[0.47172911]
# new_P:
# [[0.0019197+0.j]]
# likelihood is -689.5528428197672 on iteration 17.
# Iteration=18
# new_angles=[0.47191167]
# new_P:
# [[0.00207622+0.j]]
# likelihood is -689.5507115856209 on iteration 18.
# Iteration=19
# new_angles=[0.47206231]
# new_P:
# [[0.00224478+0.j]]
# likelihood is -689.5484248526764 on iteration 19.
# Iteration=20
# new_angles=[0.47218579]
# new_P:
# [[0.00242777+0.j]]
# likelihood is -689.5459515686949 on iteration 20.
# 11-th start
# theta=[0.49094045],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579267869759
# Iteration=1
# new_angles=[0.49648824]
# new_P:
# [[0.00010384+0.j]]
# likelihood is -689.577995949398 on iteration 1.
# Iteration=2
# new_angles=[0.49648824]
# new_P:
# [[0.0002039+0.j]]
# likelihood is -689.5767718770156 on iteration 2.
# Iteration=3
# new_angles=[0.49601287]
# new_P:
# [[0.00030416+0.j]]
# likelihood is -689.5755353684921 on iteration 3.
# Iteration=4
# new_angles=[0.49553763]
# new_P:
# [[0.0004048+0.j]]
# likelihood is -689.5742878031242 on iteration 4.
# Iteration=5
# new_angles=[0.49507501]
# new_P:
# [[0.00050603+0.j]]
# likelihood is -689.5730267236578 on iteration 5.
# Iteration=6
# new_angles=[0.49452296]
# new_P:
# [[0.00060811+0.j]]
# likelihood is -689.5717432184705 on iteration 6.
# Iteration=7
# new_angles=[0.49397108]
# new_P:
# [[0.00071133+0.j]]
# likelihood is -689.5704363445693 on iteration 7.
# Iteration=8
# new_angles=[0.49341936]
# new_P:
# [[0.00081603+0.j]]
# likelihood is -689.5691014128516 on iteration 8.
# Iteration=9
# new_angles=[0.49294478]
# new_P:
# [[0.00092261+0.j]]
# likelihood is -689.5677402625774 on iteration 9.
# Iteration=10
# new_angles=[0.49247032]
# new_P:
# [[0.00103153+0.j]]
# likelihood is -689.5663416490391 on iteration 10.
# Iteration=11
# new_angles=[0.49199598]
# new_P:
# [[0.00114331+0.j]]
# likelihood is -689.5648987669827 on iteration 11.
# Iteration=12
# new_angles=[0.49152176]
# new_P:
# [[0.00125855+0.j]]
# likelihood is -689.563403808275 on iteration 12.
# Iteration=13
# new_angles=[0.49104766]
# new_P:
# [[0.00137795+0.j]]
# likelihood is -689.5618477712552 on iteration 13.
# Iteration=14
# new_angles=[0.49057368]
# new_P:
# [[0.00150232+0.j]]
# likelihood is -689.5602202186079 on iteration 14.
# Iteration=15
# new_angles=[0.49008754]
# new_P:
# [[0.00163261+0.j]]
# likelihood is -689.5585068345091 on iteration 15.
# Iteration=16
# new_angles=[0.4896138]
# new_P:
# [[0.00176993+0.j]]
# likelihood is -689.5566973751254 on iteration 16.
# Iteration=17
# new_angles=[0.48914019]
# new_P:
# [[0.00191561+0.j]]
# likelihood is -689.5547729152565 on iteration 17.
# Iteration=18
# new_angles=[0.48866669]
# new_P:
# [[0.00207125+0.j]]
# likelihood is -689.5527131624417 on iteration 18.
# Iteration=19
# new_angles=[0.48819331]
# new_P:
# [[0.00223877+0.j]]
# likelihood is -689.5504936292505 on iteration 19.
# Iteration=20
# new_angles=[0.48772005]
# new_P:
# [[0.00242052+0.j]]
# likelihood is -689.5480844660833 on iteration 20.
# 12-th start
# theta=[0.61180126],P=[[8.06311518e-08-5.29395592e-24j]]
# Inital likelihood = -689.5792664814606
# Iteration=1
# new_angles=[0.60712296]
# new_P:
# [[0.00010727+0.j]]
# likelihood is -689.5765454614212 on iteration 1.
# Iteration=2
# new_angles=[0.60639471]
# new_P:
# [[0.00020736+0.j]]
# likelihood is -689.5739836224362 on iteration 2.
# Iteration=3
# new_angles=[0.60569787]
# new_P:
# [[0.00030773+0.j]]
# likelihood is -689.5713927657537 on iteration 3.
# Iteration=4
# new_angles=[0.60497034]
# new_P:
# [[0.00040862+0.j]]
# likelihood is -689.5687612206045 on iteration 4.
# Iteration=5
# new_angles=[0.60415538]
# new_P:
# [[0.00051028+0.j]]
# likelihood is -689.5660708641462 on iteration 5.
# Iteration=6
# new_angles=[0.60335101]
# new_P:
# [[0.00061303+0.j]]
# likelihood is -689.5633164401697 on iteration 6.
# Iteration=7
# new_angles=[0.60245491]
# new_P:
# [[0.00071723+0.j]]
# likelihood is -689.5604690499616 on iteration 7.
# Iteration=8
# new_angles=[0.60156626]
# new_P:
# [[0.00082329+0.j]]
# likelihood is -689.5575254372923 on iteration 8.
# Iteration=9
# new_angles=[0.60060082]
# new_P:
# [[0.00093171+0.j]]
# likelihood is -689.5544501002007 on iteration 9.
# Iteration=10
# new_angles=[0.59963602]
# new_P:
# [[0.00104303+0.j]]
# likelihood is -689.5512378297356 on iteration 10.
# Iteration=11
# new_angles=[0.59861696]
# new_P:
# [[0.0011579+0.j]]
# likelihood is -689.5478505993086 on iteration 11.
# Iteration=12
# new_angles=[0.5975986]
# new_P:
# [[0.00127707+0.j]]
# likelihood is -689.5442780876075 on iteration 12.
# Iteration=13
# new_angles=[0.59658095]
# new_P:
# [[0.00140141+0.j]]
# likelihood is -689.5404933155744 on iteration 13.
# Iteration=14
# new_angles=[0.59556301]
# new_P:
# [[0.00153195+0.j]]
# likelihood is -689.5364644659785 on iteration 14.
# Iteration=15
# new_angles=[0.59454577]
# new_P:
# [[0.00166991+0.j]]
# likelihood is -689.5321549562399 on iteration 15.
# Iteration=16
# new_angles=[0.59350777]
# new_P:
# [[0.00181676+0.j]]
# likelihood is -689.5275095152598 on iteration 16.
# Iteration=17
# new_angles=[0.59249293]
# new_P:
# [[0.00197426+0.j]]
# likelihood is -689.5224971998668 on iteration 17.
# Iteration=18
# new_angles=[0.59147879]
# new_P:
# [[0.00214457+0.j]]
# likelihood is -689.517042475757 on iteration 18.
# Iteration=19
# new_angles=[0.59051993]
# new_P:
# [[0.00233035+0.j]]
# likelihood is -689.5111004524617 on iteration 19.
# Iteration=20
# new_angles=[0.58956169]
# new_P:
# [[0.00253493+0.j]]
# likelihood is -689.5045405329541 on iteration 20.
# 13-th start
# theta=[0.74517223],P=[[9.99993584e-08+7.94093388e-24j]]
# Inital likelihood = -689.5792623522027
# Iteration=1
# new_angles=[0.74650508]
# new_P:
# [[0.00011114+0.j]]
# likelihood is -689.5727160386141 on iteration 1.
# Iteration=2
# new_angles=[0.73813581]
# new_P:
# [[0.00021131+0.j]]
# likelihood is -689.5636035972835 on iteration 2.
# Iteration=3
# new_angles=[0.73118487]
# new_P:
# [[0.0003121+0.j]]
# likelihood is -689.5524160568517 on iteration 3.
# Iteration=4
# new_angles=[0.72539069]
# new_P:
# [[0.00041407+0.j]]
# likelihood is -689.5399625421173 on iteration 4.
# Iteration=5
# new_angles=[0.7209254]
# new_P:
# [[0.00051793+0.j]]
# likelihood is -689.527034634599 on iteration 5.
# Iteration=6
# new_angles=[0.71730082]
# new_P:
# [[0.00062442+0.j]]
# likelihood is -689.5137422654036 on iteration 6.
# Iteration=7
# new_angles=[0.71434767]
# new_P:
# [[0.00073435+0.j]]
# likelihood is -689.5001551480083 on iteration 7.
# Iteration=8
# new_angles=[0.71196186]
# new_P:
# [[0.00084868+0.j]]
# likelihood is -689.4862513206616 on iteration 8.
# Iteration=9
# new_angles=[0.70998768]
# new_P:
# [[0.00096849+0.j]]
# likelihood is -689.4718910059885 on iteration 9.
# Iteration=10
# new_angles=[0.70837915]
# new_P:
# [[0.00109503+0.j]]
# likelihood is -689.4569437847953 on iteration 10.
# Iteration=11
# new_angles=[0.70703927]
# new_P:
# [[0.00122983+0.j]]
# likelihood is -689.4412021457284 on iteration 11.
# Iteration=12
# new_angles=[0.70599248]
# new_P:
# [[0.00137474+0.j]]
# likelihood is -689.4244761429293 on iteration 12.
# Iteration=13
# new_angles=[0.7051069]
# new_P:
# [[0.00153206+0.j]]
# likelihood is -689.4064449346475 on iteration 13.
# Iteration=14
# new_angles=[0.70438218]
# new_P:
# [[0.00170465+0.j]]
# likelihood is -689.3867880856455 on iteration 14.
# Iteration=15
# new_angles=[0.70374478]
# new_P:
# [[0.00189621+0.j]]
# likelihood is -689.3650661680307 on iteration 15.
# Iteration=16
# new_angles=[0.70326455]
# new_P:
# [[0.00211153+0.j]]
# likelihood is -689.3407750440516 on iteration 16.
# Iteration=17
# new_angles=[0.7028766]
# new_P:
# [[0.00235698+0.j]]
# likelihood is -689.313189163128 on iteration 17.
# Iteration=18
# new_angles=[0.70251598]
# new_P:
# [[0.00264117+0.j]]
# likelihood is -689.2813441538678 on iteration 18.
# Iteration=19
# new_angles=[0.70219935]
# new_P:
# [[0.00297607+0.j]]
# likelihood is -689.2439441633337 on iteration 19.
# Iteration=20
# new_angles=[0.7019716]
# new_P:
# [[0.00337876+0.j]]
# likelihood is -689.1991546133903 on iteration 20.
# 14-th start
# theta=[0.81529611],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688264825
# Iteration=1
# new_angles=[0.81529611]
# new_P:
# [[0.00010376+0.j]]
# likelihood is -689.5799736255957 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 15-th start
# theta=[0.64780331],P=[[8.03558405e-08+0.j]]
# Inital likelihood = -689.5792644427597
# Iteration=1
# new_angles=[0.64300145]
# new_P:
# [[0.00010513+0.j]]
# likelihood is -689.5746601752537 on iteration 1.
# Iteration=2
# new_angles=[0.64727204]
# new_P:
# [[0.00020525+0.j]]
# likelihood is -689.5690853062741 on iteration 2.
# Iteration=3
# new_angles=[0.65217785]
# new_P:
# [[0.00030581+0.j]]
# likelihood is -689.5618554718658 on iteration 3.
# Iteration=4
# new_angles=[0.65719085]
# new_P:
# [[0.00040721+0.j]]
# likelihood is -689.55281413003 on iteration 4.
# Iteration=5
# new_angles=[0.66213733]
# new_P:
# [[0.00051004+0.j]]
# likelihood is -689.5419659830278 on iteration 5.
# Iteration=6
# new_angles=[0.66687853]
# new_P:
# [[0.00061502+0.j]]
# likelihood is -689.5294958676183 on iteration 6.
# Iteration=7
# new_angles=[0.67132565]
# new_P:
# [[0.00072301+0.j]]
# likelihood is -689.51567557864 on iteration 7.
# Iteration=8
# new_angles=[0.67538877]
# new_P:
# [[0.00083503+0.j]]
# likelihood is -689.5008238574306 on iteration 8.
# Iteration=9
# new_angles=[0.67909482]
# new_P:
# [[0.00095222+0.j]]
# likelihood is -689.4850941487717 on iteration 9.
# Iteration=10
# new_angles=[0.68232681]
# new_P:
# [[0.00107592+0.j]]
# likelihood is -689.4687339111574 on iteration 10.
# Iteration=11
# new_angles=[0.68512112]
# new_P:
# [[0.00120764+0.j]]
# likelihood is -689.4517095019744 on iteration 11.
# Iteration=12
# new_angles=[0.68759227]
# new_P:
# [[0.0013492+0.j]]
# likelihood is -689.4337969179448 on iteration 12.
# Iteration=13
# new_angles=[0.68960238]
# new_P:
# [[0.00150283+0.j]]
# likelihood is -689.4149681326667 on iteration 13.
# Iteration=14
# new_angles=[0.69134728]
# new_P:
# [[0.00167127+0.j]]
# likelihood is -689.3947269065426 on iteration 14.
# Iteration=15
# new_angles=[0.6928655]
# new_P:
# [[0.00185804+0.j]]
# likelihood is -689.3726611092173 on iteration 15.
# Iteration=16
# new_angles=[0.69413539]
# new_P:
# [[0.00206769+0.j]]
# likelihood is -689.3482920025672 on iteration 16.
# Iteration=17
# new_angles=[0.69520723]
# new_P:
# [[0.00230623+0.j]]
# likelihood is -689.3209055938772 on iteration 17.
# Iteration=18
# new_angles=[0.69610709]
# new_P:
# [[0.0025818+0.j]]
# likelihood is -689.28958313589 on iteration 18.
# Iteration=19
# new_angles=[0.69684858]
# new_P:
# [[0.00290561+0.j]]
# likelihood is -689.2530825021785 on iteration 19.
# Iteration=20
# new_angles=[0.69748547]
# new_P:
# [[0.00329361+0.j]]
# likelihood is -689.2096299037644 on iteration 20.
# 16-th start
# theta=[0.22711654],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792687212914
# Iteration=1
# new_angles=[0.22711654]
# new_P:
# [[0.00010389+0.j]]
# likelihood is -689.579750754444 on iteration 1.
# Likelihood is converged!
# 17-th start
# theta=[0.45039062],P=[[4.93435618e-08-4.76456033e-23j]]
# Inital likelihood = -689.579268038814
# Iteration=1
# new_angles=[0.45481234]
# new_P:
# [[0.00010298+0.j]]
# likelihood is -689.5781475537035 on iteration 1.
# Iteration=2
# new_angles=[0.45668102]
# new_P:
# [[0.00020304+0.j]]
# likelihood is -689.5769397001249 on iteration 2.
# Iteration=3
# new_angles=[0.45831377]
# new_P:
# [[0.00030329+0.j]]
# likelihood is -689.5756511263107 on iteration 3.
# Iteration=4
# new_angles=[0.45964077]
# new_P:
# [[0.00040392+0.j]]
# likelihood is -689.5743163206072 on iteration 4.
# Iteration=5
# new_angles=[0.46093207]
# new_P:
# [[0.00050515+0.j]]
# likelihood is -689.5729275321354 on iteration 5.
# Iteration=6
# new_angles=[0.4621012]
# new_P:
# [[0.00060722+0.j]]
# likelihood is -689.571502247477 on iteration 6.
# Iteration=7
# new_angles=[0.46318612]
# new_P:
# [[0.00071046+0.j]]
# likelihood is -689.5700423176411 on iteration 7.
# Iteration=8
# new_angles=[0.46408354]
# new_P:
# [[0.0008152+0.j]]
# likelihood is -689.5685646772159 on iteration 8.
# Iteration=9
# new_angles=[0.46490549]
# new_P:
# [[0.00092185+0.j]]
# likelihood is -689.567055616716 on iteration 9.
# Iteration=10
# new_angles=[0.46561745]
# new_P:
# [[0.00103087+0.j]]
# likelihood is -689.5655180446694 on iteration 10.
# Iteration=11
# new_angles=[0.46631418]
# new_P:
# [[0.00114279+0.j]]
# likelihood is -689.5639346657966 on iteration 11.
# Iteration=12
# new_angles=[0.46693024]
# new_P:
# [[0.00125822+0.j]]
# likelihood is -689.5623090198933 on iteration 12.
# Iteration=13
# new_angles=[0.46747075]
# new_P:
# [[0.00137786+0.j]]
# likelihood is -689.5606329074357 on iteration 13.
# Iteration=14
# new_angles=[0.46801141]
# new_P:
# [[0.00150252+0.j]]
# likelihood is -689.558885849166 on iteration 14.
# Iteration=15
# new_angles=[0.4684871]
# new_P:
# [[0.00163317+0.j]]
# likelihood is -689.5570657358933 on iteration 15.
# Iteration=16
# new_angles=[0.46889889]
# new_P:
# [[0.00177094+0.j]]
# likelihood is -689.5551583761995 on iteration 16.
# Iteration=17
# new_angles=[0.46925136]
# new_P:
# [[0.00191716+0.j]]
# likelihood is -689.5531462043023 on iteration 17.
# Iteration=18
# new_angles=[0.46960389]
# new_P:
# [[0.00207344+0.j]]
# likelihood is -689.5510001178177 on iteration 18.
# Iteration=19
# new_angles=[0.46994712]
# new_P:
# [[0.00224173+0.j]]
# likelihood is -689.5486966000237 on iteration 19.
# Iteration=20
# new_angles=[0.47022097]
# new_P:
# [[0.0024244+0.j]]
# likelihood is -689.546214011735 on iteration 20.
# 18-th start
# theta=[1.57079633],P=[[8.75235434e-08-2.70617725e-23j]]
# Inital likelihood = -689.5792674589636
# Iteration=1
# new_angles=[-1.4457148]
# new_P:
# [[0.00010832+0.j]]
# likelihood is -689.578724884963 on iteration 1.
# Likelihood is converged!
# 19-th start
# theta=[0.75399535],P=[[7.64820505e-08-1.0753348e-24j]]
# Inital likelihood = -689.5792650119403
# Iteration=1
# new_angles=[0.75399535]
# new_P:
# [[0.00010711+0.j]]
# likelihood is -689.5743936172373 on iteration 1.
# Iteration=2
# new_angles=[0.74428431]
# new_P:
# [[0.00020724+0.j]]
# likelihood is -689.5662143993746 on iteration 2.
# Iteration=3
# new_angles=[0.73634751]
# new_P:
# [[0.00030791+0.j]]
# likelihood is -689.5554783579265 on iteration 3.
# Iteration=4
# new_angles=[0.72978016]
# new_P:
# [[0.00040968+0.j]]
# likelihood is -689.5431060426182 on iteration 4.
# Iteration=5
# new_angles=[0.72450988]
# new_P:
# [[0.00051326+0.j]]
# likelihood is -689.5299287369957 on iteration 5.
# Iteration=6
# new_angles=[0.72022409]
# new_P:
# [[0.0006194+0.j]]
# likelihood is -689.5163010532128 on iteration 6.
# Iteration=7
# new_angles=[0.71675002]
# new_P:
# [[0.00072895+0.j]]
# likelihood is -689.5023934453759 on iteration 7.
# Iteration=8
# new_angles=[0.7139323]
# new_P:
# [[0.00084285+0.j]]
# likelihood is -689.4882059794157 on iteration 8.
# Iteration=9
# new_angles=[0.71161846]
# new_P:
# [[0.00096218+0.j]]
# likelihood is -689.4736244519981 on iteration 9.
# Iteration=10
# new_angles=[0.70968901]
# new_P:
# [[0.0010882+0.j]]
# likelihood is -689.4584849510654 on iteration 10.
# Iteration=11
# new_angles=[0.70817338]
# new_P:
# [[0.00122242+0.j]]
# likelihood is -689.4426620746135 on iteration 11.
# Iteration=12
# new_angles=[0.70689159]
# new_P:
# [[0.00136665+0.j]]
# likelihood is -689.4258478735214 on iteration 12.
# Iteration=13
# new_angles=[0.70584493]
# new_P:
# [[0.00152318+0.j]]
# likelihood is -689.4077938738467 on iteration 13.
# Iteration=14
# new_angles=[0.70498868]
# new_P:
# [[0.00169484+0.j]]
# likelihood is -689.3881570895676 on iteration 14.
# Iteration=15
# new_angles=[0.70426403]
# new_P:
# [[0.00188527+0.j]]
# likelihood is -689.3665034119381 on iteration 15.
# Iteration=16
# new_angles=[0.70371563]
# new_P:
# [[0.00209921+0.j]]
# likelihood is -689.3423267618373 on iteration 16.
# Iteration=17
# new_angles=[0.70323542]
# new_P:
# [[0.00234292+0.j]]
# likelihood is -689.3148897294469 on iteration 17.
# Iteration=18
# new_angles=[0.70280732]
# new_P:
# [[0.00262488+0.j]]
# likelihood is -689.2832579421095 on iteration 18.
# Iteration=19
# new_angles=[0.7024874]
# new_P:
# [[0.00295688+0.j]]
# likelihood is -689.2461693087287 on iteration 19.
# Iteration=20
# new_angles=[0.70217077]
# new_P:
# [[0.00335567+0.j]]
# likelihood is -689.2017732796954 on iteration 20.
# best_start=5
# Время выполнения функции: 76.516077 секунд

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.70117835]), array([[0.00342784+0.j]]))

# %%
lf.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q2), lf.incomplete_lkhd(X2_with_mv, theta2_rad, P2, Q2)
# Out:
# (np.float64(-689.193567005708), np.float64(-673.6467390084401))
