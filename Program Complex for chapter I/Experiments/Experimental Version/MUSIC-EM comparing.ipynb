# %%
import numpy as np

# %%
from pathlib import Path
import sys

try:
    ROOT = Path().resolve().parents[1]
    assert (ROOT / "common").exists()
except AssertionError:
    ROOT = next(p for p in Path().resolve().parents if (p / "common").exists())

if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
#print(ROOT)

# %%
from common import sensors as sn 
from common import subspace_methods as sm
import em_tools as em

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12

failing_sensors1 = np.arange(5)
gap_ratio1 = 0.5 * np.ones_like(failing_sensors1, dtype=np.float32)

theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sn.gss(Num_emitters1, sample_size1, P1)
N1 = sn.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sn.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sn.initial_Cov(X1_with_mv)
MUSIC_theta1 = sm.MUSIC_DoA(R1, Num_emitters1)

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sn.SNR(A1, P1, Q1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1, lhd_list1, angles_list1 = em.multistart_EM2(X1_with_mv, 
                                                                         Num_emitters1, 
                                                                         Q=Q1,
                                                                         theta_guess=MUSIC_theta1, 
                                                                         num_of_starts=10, 
                                                                         max_iter=20, 
                                                                         rtol=1e-6,
                                                                         reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.71558499],P=[[1.18642836e-07-1.98523347e-24j]]
# Inital likelihood = -870.4011155592349
# Iteration=1
# likelihood is -870.3990861263244 on iteration 1.
# Iteration=2
# likelihood is -870.3971595200366 on iteration 2.
# Iteration=3
# likelihood is -870.3952074420494 on iteration 3.
# Iteration=4
# likelihood is -870.3932458873422 on iteration 4.
# Iteration=5
# likelihood is -870.3912322774454 on iteration 5.
# Iteration=6
# likelihood is -870.3891745274426 on iteration 6.
# Iteration=7
# likelihood is -870.3870645820474 on iteration 7.
# Iteration=8
# likelihood is -870.3848935214203 on iteration 8.
# Iteration=9
# likelihood is -870.3826515300914 on iteration 9.
# Iteration=10
# likelihood is -870.3803278562572 on iteration 10.
# Iteration=11
# likelihood is -870.3779107558906 on iteration 11.
# Iteration=12
# likelihood is -870.3753874866486 on iteration 12.
# Iteration=13
# likelihood is -870.3727441122039 on iteration 13.
# Iteration=14
# likelihood is -870.3699656238991 on iteration 14.
# Iteration=15
# likelihood is -870.3670356868489 on iteration 15.
# Iteration=16
# likelihood is -870.3639364994691 on iteration 16.
# Iteration=17
# likelihood is -870.3606485446751 on iteration 17.
# Iteration=18
# likelihood is -870.357150219337 on iteration 18.
# Iteration=19
# likelihood is -870.3534173292853 on iteration 19.
# Iteration=20
# likelihood is -870.3494224057639 on iteration 20.
# 1-th start
# theta=[0.75761751],P=[[7.62531873e-08-2.64697796e-24j]]
# Inital likelihood = -870.4011243940959
# Iteration=1
# likelihood is -870.3983235052531 on iteration 1.
# Iteration=2
# likelihood is -870.3919209414651 on iteration 2.
# Iteration=3
# likelihood is -870.3821069365422 on iteration 3.
# Iteration=4
# likelihood is -870.370184907254 on iteration 4.
# Iteration=5
# likelihood is -870.3573151650385 on iteration 5.
# Iteration=6
# likelihood is -870.3441607590955 on iteration 6.
# Iteration=7
# likelihood is -870.3309853165083 on iteration 7.
# Iteration=8
# likelihood is -870.3178203183849 on iteration 8.
# Iteration=9
# likelihood is -870.3045832038943 on iteration 9.
# Iteration=10
# likelihood is -870.2911413261554 on iteration 10.
# Iteration=11
# likelihood is -870.2773409921493 on iteration 11.
# Iteration=12
# likelihood is -870.2630172909583 on iteration 12.
# Iteration=13
# likelihood is -870.247994049525 on iteration 13.
# Iteration=14
# likelihood is -870.2320786685971 on iteration 14.
# Iteration=15
# likelihood is -870.2150537267664 on iteration 15.
# Iteration=16
# likelihood is -870.1966658176874 on iteration 16.
# Iteration=17
# likelihood is -870.1766125188767 on iteration 17.
# Iteration=18
# likelihood is -870.1545168544319 on iteration 18.
# Iteration=19
# likelihood is -870.1299112313411 on iteration 19.
# Iteration=20
# likelihood is -870.1021932705387 on iteration 20.
# 2-th start
# theta=[0.75275765],P=[[9.44715207e-08-1.12496563e-23j]]
# Inital likelihood = -870.4011231381311
# Iteration=1
# likelihood is -870.3976272355848 on iteration 1.
# Iteration=2
# likelihood is -870.3905644879306 on iteration 2.
# Iteration=3
# likelihood is -870.3804096775266 on iteration 3.
# Iteration=4
# likelihood is -870.3684652178081 on iteration 4.
# Iteration=5
# likelihood is -870.3557483961424 on iteration 5.
# Iteration=6
# likelihood is -870.3428028803029 on iteration 6.
# Iteration=7
# likelihood is -870.32982762097 on iteration 7.
# Iteration=8
# likelihood is -870.3168283057352 on iteration 8.
# Iteration=9
# likelihood is -870.3037168863804 on iteration 9.
# Iteration=10
# likelihood is -870.2903638169638 on iteration 10.
# Iteration=11
# likelihood is -870.2766210836219 on iteration 11.
# Iteration=12
# likelihood is -870.2623293686198 on iteration 12.
# Iteration=13
# likelihood is -870.2473170549287 on iteration 13.
# Iteration=14
# likelihood is -870.2313948004796 on iteration 14.
# Iteration=15
# likelihood is -870.2143471622696 on iteration 15.
# Iteration=16
# likelihood is -870.1959215242922 on iteration 16.
# Iteration=17
# likelihood is -870.1758164295162 on iteration 17.
# Iteration=18
# likelihood is -870.1536503689885 on iteration 18.
# Iteration=19
# likelihood is -870.128954649683 on iteration 19.
# Iteration=20
# likelihood is -870.1011223131575 on iteration 20.
# 3-th start
# theta=[0.82383174],P=[[9.765625e-08+0.j]]
# Inital likelihood = -870.4011268013815
# Iteration=1
# likelihood is -870.401115176151 on iteration 1.
# Likelihood is converged!
# 4-th start
# theta=[0.72131738],P=[[1.09961713e-07-2.97785021e-24j]]
# Inital likelihood = -870.4011171320063
# Iteration=1
# likelihood is -870.3990304665008 on iteration 1.
# Iteration=2
# likelihood is -870.3970449646486 on iteration 2.
# Iteration=3
# likelihood is -870.3950246500183 on iteration 3.
# Iteration=4
# likelihood is -870.392962810476 on iteration 4.
# Iteration=5
# likelihood is -870.390852101285 on iteration 5.
# Iteration=6
# likelihood is -870.3886845325644 on iteration 6.
# Iteration=7
# likelihood is -870.3864515333555 on iteration 7.
# Iteration=8
# likelihood is -870.3841439498085 on iteration 8.
# Iteration=9
# likelihood is -870.3817521022921 on iteration 9.
# Iteration=10
# likelihood is -870.3792658144873 on iteration 10.
# Iteration=11
# likelihood is -870.3766744055412 on iteration 11.
# Iteration=12
# likelihood is -870.3739721729045 on iteration 12.
# Iteration=13
# likelihood is -870.3711370999714 on iteration 13.
# Iteration=14
# likelihood is -870.368161564788 on iteration 14.
# Iteration=15
# likelihood is -870.3650322223987 on iteration 15.
# Iteration=16
# likelihood is -870.3617345217663 on iteration 16.
# Iteration=17
# likelihood is -870.3582522723304 on iteration 17.
# Iteration=18
# likelihood is -870.3545670601208 on iteration 18.
# Iteration=19
# likelihood is -870.3506575290173 on iteration 19.
# Iteration=20
# likelihood is -870.3465128482419 on iteration 20.
# 5-th start
# theta=[0.69420695],P=[[2.63712642e-07-3.97046694e-24j]]
# Inital likelihood = -870.4010990043953
# Iteration=1
# likelihood is -870.3884896841228 on iteration 1.
# Iteration=2
# likelihood is -870.3779566921139 on iteration 2.
# Iteration=3
# likelihood is -870.3672979423859 on iteration 3.
# Iteration=4
# likelihood is -870.3565018391838 on iteration 4.
# Iteration=5
# likelihood is -870.3455372029734 on iteration 5.
# Iteration=6
# likelihood is -870.3343590699583 on iteration 6.
# Iteration=7
# likelihood is -870.3229117100561 on iteration 7.
# Iteration=8
# likelihood is -870.3111297236164 on iteration 8.
# Iteration=9
# likelihood is -870.2989377531244 on iteration 9.
# Iteration=10
# likelihood is -870.2862493818765 on iteration 10.
# Iteration=11
# likelihood is -870.2729638872589 on iteration 11.
# Iteration=12
# likelihood is -870.2589646319834 on iteration 12.
# Iteration=13
# likelihood is -870.2441136483266 on iteration 13.
# Iteration=14
# likelihood is -870.2282462677924 on iteration 14.
# Iteration=15
# likelihood is -870.2111635849868 on iteration 15.
# Iteration=16
# likelihood is -870.1926223351056 on iteration 16.
# Iteration=17
# likelihood is -870.1723211303934 on iteration 17.
# Iteration=18
# likelihood is -870.1498814259628 on iteration 18.
# Iteration=19
# likelihood is -870.1248207421141 on iteration 19.
# Iteration=20
# likelihood is -870.0965142413762 on iteration 20.
# 6-th start
# theta=[0.72207198],P=[[1.08695785e-07+1.65436123e-24j]]
# Inital likelihood = -870.4011173514194
# Iteration=1
# likelihood is -870.399023005645 on iteration 1.
# Iteration=2
# likelihood is -870.3970291091481 on iteration 2.
# Iteration=3
# likelihood is -870.3949991526761 on iteration 3.
# Iteration=4
# likelihood is -870.392926349366 on iteration 4.
# Iteration=5
# likelihood is -870.3908033106965 on iteration 5.
# Iteration=6
# likelihood is -870.3886220408501 on iteration 6.
# Iteration=7
# likelihood is -870.3863739866284 on iteration 7.
# Iteration=8
# likelihood is -870.3840500824376 on iteration 8.
# Iteration=9
# likelihood is -870.3816407933837 on iteration 9.
# Iteration=10
# likelihood is -870.3791361299609 on iteration 10.
# Iteration=11
# likelihood is -870.3765256847482 on iteration 11.
# Iteration=12
# likelihood is -870.3738084997755 on iteration 12.
# Iteration=13
# likelihood is -870.3709545169175 on iteration 13.
# Iteration=14
# likelihood is -870.367960425539 on iteration 14.
# Iteration=15
# likelihood is -870.3648132483934 on iteration 15.
# Iteration=16
# likelihood is -870.3614987752043 on iteration 16.
# Iteration=17
# likelihood is -870.3580011025816 on iteration 17.
# Iteration=18
# likelihood is -870.3543020631894 on iteration 18.
# Iteration=19
# likelihood is -870.3503804389605 on iteration 19.
# Iteration=20
# likelihood is -870.3462374627632 on iteration 20.
# 7-th start
# theta=[0.83118872],P=[[9.765625e-08+0.j]]
# Inital likelihood = -870.4011267594258
# Iteration=1
# likelihood is -870.4010631800656 on iteration 1.
# Likelihood is converged!
# 8-th start
# theta=[0.85933204],P=[[9.765625e-08+0.j]]
# Inital likelihood = -870.4011269181249
# Iteration=1
# likelihood is -870.4012067196353 on iteration 1.
# Likelihood is converged!
# 9-th start
# theta=[0.73719288],P=[[7.93250092e-08-4.63221143e-24j]]
# Inital likelihood = -870.4011217367256
# Iteration=1
# likelihood is -870.3955918848882 on iteration 1.
# Iteration=2
# likelihood is -870.3870440216756 on iteration 2.
# Iteration=3
# likelihood is -870.3764464160994 on iteration 3.
# Iteration=4
# likelihood is -870.364808248568 on iteration 4.
# Iteration=5
# likelihood is -870.3527302546364 on iteration 5.
# Iteration=6
# likelihood is -870.3404825224706 on iteration 6.
# Iteration=7
# likelihood is -870.3281349423717 on iteration 7.
# Iteration=8
# likelihood is -870.3156516667059 on iteration 8.
# Iteration=9
# likelihood is -870.3029450466588 on iteration 9.
# Iteration=10
# likelihood is -870.2899019698411 on iteration 10.
# Iteration=11
# likelihood is -870.276394515007 on iteration 11.
# Iteration=12
# likelihood is -870.262281972673 on iteration 12.
# Iteration=13
# likelihood is -870.2474082567942 on iteration 13.
# Iteration=14
# likelihood is -870.2315963965566 on iteration 14.
# Iteration=15
# likelihood is -870.2146406500887 on iteration 15.
# Iteration=16
# likelihood is -870.1962960633738 on iteration 16.
# Iteration=17
# likelihood is -870.1762659469169 on iteration 17.
# Iteration=18
# likelihood is -870.1541775938884 on iteration 18.
# Iteration=19
# likelihood is -870.1295654726757 on iteration 19.
# Iteration=20
# likelihood is -870.1018281027644 on iteration 20.
# best_start=5

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.69625362]), array([[0.00291094+0.j]]))

# %%
em.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q1), em.incomplete_lkhd(X1_with_mv, theta1_rad, P1, Q1)
# Out:
# (np.float64(-870.0965142413762), np.float64(-852.4011191641745))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11

failing_sensors2 = np.arange(8)
gap_ratio2 = 0.5 * np.ones_like(failing_sensors2, dtype=np.float32)

theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sn.gss(Num_emitters2, sample_size2, P2)
N2 = sn.gss(Num_sensors2, sample_size2, Q2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sn.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sn.initial_Cov(X2_with_mv)
MUSIC_theta2 = sm.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sn.SNR(A2, P2, Q2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2, lhd_list2, angles_list2 = em.multistart_EM2(X2_with_mv, 
                                                                         Num_emitters2, 
                                                                         Q=Q2,
                                                                         theta_guess=MUSIC_theta2, 
                                                                         num_of_starts=20, 
                                                                         max_iter=20, 
                                                                         rtol=1e-6,
                                                                         reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.72431164],P=[[7.5917774e-08+4.13590306e-24j]]
# Inital likelihood = -689.5792611594288
# Iteration=1
# likelihood is -689.569880880428 on iteration 1.
# Iteration=2
# likelihood is -689.5593298568175 on iteration 2.
# Iteration=3
# likelihood is -689.547884902096 on iteration 3.
# Iteration=4
# likelihood is -689.5359197732676 on iteration 4.
# Iteration=5
# likelihood is -689.5236084313234 on iteration 5.
# Iteration=6
# likelihood is -689.5109968718982 on iteration 6.
# Iteration=7
# likelihood is -689.4980525449125 on iteration 7.
# Iteration=8
# likelihood is -689.4846932949999 on iteration 8.
# Iteration=9
# likelihood is -689.4708301552024 on iteration 9.
# Iteration=10
# likelihood is -689.4562542910969 on iteration 10.
# Iteration=11
# likelihood is -689.440823427417 on iteration 11.
# Iteration=12
# likelihood is -689.4243229822999 on iteration 12.
# Iteration=13
# likelihood is -689.4064911500433 on iteration 13.
# Iteration=14
# likelihood is -689.387003193946 on iteration 14.
# Iteration=15
# likelihood is -689.3654486807897 on iteration 15.
# Iteration=16
# likelihood is -689.3412985084392 on iteration 16.
# Iteration=17
# likelihood is -689.3138562485956 on iteration 17.
# Iteration=18
# likelihood is -689.2821846723479 on iteration 18.
# Iteration=19
# likelihood is -689.2449916030382 on iteration 19.
# Iteration=20
# likelihood is -689.2004467999656 on iteration 20.
# 1-th start
# theta=[0.76634416],P=[[4.65993421e-08-2.64697796e-24j]]
# Inital likelihood = -689.5792672995802
# Iteration=1
# likelihood is -689.5766626777022 on iteration 1.
# Iteration=2
# likelihood is -689.5705363000969 on iteration 2.
# Iteration=3
# likelihood is -689.5609189425317 on iteration 3.
# Iteration=4
# likelihood is -689.5487907960637 on iteration 4.
# Iteration=5
# likelihood is -689.5352238607727 on iteration 5.
# Iteration=6
# likelihood is -689.5209859889626 on iteration 6.
# Iteration=7
# likelihood is -689.5063958836533 on iteration 7.
# Iteration=8
# likelihood is -689.4915915263944 on iteration 8.
# Iteration=9
# likelihood is -689.4765182918201 on iteration 9.
# Iteration=10
# likelihood is -689.4610278303176 on iteration 10.
# Iteration=11
# likelihood is -689.4449147540923 on iteration 11.
# Iteration=12
# likelihood is -689.427930325399 on iteration 12.
# Iteration=13
# likelihood is -689.4097812939475 on iteration 13.
# Iteration=14
# likelihood is -689.3901180463134 on iteration 14.
# Iteration=15
# likelihood is -689.368513337545 on iteration 15.
# Iteration=16
# likelihood is -689.3444299709636 on iteration 16.
# Iteration=17
# likelihood is -689.3171729796708 on iteration 17.
# Iteration=18
# likelihood is -689.2858179203628 on iteration 18.
# Iteration=19
# likelihood is -689.2491002904014 on iteration 19.
# Iteration=20
# likelihood is -689.2052392467056 on iteration 20.
# 2-th start
# theta=[0.7614843],P=[[5.77524969e-08+5.29395592e-24j]]
# Inital likelihood = -689.5792665882861
# Iteration=1
# likelihood is -689.5758842445574 on iteration 1.
# Iteration=2
# likelihood is -689.5689465233503 on iteration 2.
# Iteration=3
# likelihood is -689.5588141961143 on iteration 3.
# Iteration=4
# likelihood is -689.5465409869332 on iteration 4.
# Iteration=5
# likelihood is -689.5330881353163 on iteration 5.
# Iteration=6
# likelihood is -689.519062751376 on iteration 6.
# Iteration=7
# likelihood is -689.5047448654368 on iteration 7.
# Iteration=8
# likelihood is -689.4901919568201 on iteration 8.
# Iteration=9
# likelihood is -689.4753284477229 on iteration 9.
# Iteration=10
# likelihood is -689.4600013237734 on iteration 10.
# Iteration=11
# likelihood is -689.4440079020113 on iteration 11.
# Iteration=12
# likelihood is -689.4271045975873 on iteration 12.
# Iteration=13
# likelihood is -689.4090032818925 on iteration 13.
# Iteration=14
# likelihood is -689.3893583551802 on iteration 14.
# Iteration=15
# likelihood is -689.367744976423 on iteration 15.
# Iteration=16
# likelihood is -689.3436264508356 on iteration 16.
# Iteration=17
# likelihood is -689.316306110825 on iteration 17.
# Iteration=18
# likelihood is -689.2848550364366 on iteration 18.
# Iteration=19
# likelihood is -689.2480004520761 on iteration 19.
# Iteration=20
# likelihood is -689.2039475351589 on iteration 20.
# 3-th start
# theta=[0.83255839],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688437123
# Iteration=1
# likelihood is -689.580011383586 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 4-th start
# theta=[0.73004403],P=[[6.95706666e-08-3.30872245e-25j]]
# Inital likelihood = -689.5792623721018
# Iteration=1
# likelihood is -689.5707273410778 on iteration 1.
# Iteration=2
# likelihood is -689.560507796311 on iteration 2.
# Iteration=3
# likelihood is -689.5491158531814 on iteration 3.
# Iteration=4
# likelihood is -689.5370609086646 on iteration 4.
# Iteration=5
# likelihood is -689.5246039513293 on iteration 5.
# Iteration=6
# likelihood is -689.5118386009552 on iteration 6.
# Iteration=7
# likelihood is -689.4987547248631 on iteration 7.
# Iteration=8
# likelihood is -689.4852785370899 on iteration 8.
# Iteration=9
# likelihood is -689.4713058776624 on iteration 9.
# Iteration=10
# likelihood is -689.4566625181851 on iteration 10.
# Iteration=11
# likelihood is -689.4411825918594 on iteration 11.
# Iteration=12
# likelihood is -689.4246487730269 on iteration 12.
# Iteration=13
# likelihood is -689.4067969450332 on iteration 13.
# Iteration=14
# likelihood is -689.3873006738814 on iteration 14.
# Iteration=15
# likelihood is -689.3657485374838 on iteration 15.
# Iteration=16
# likelihood is -689.3416112063443 on iteration 16.
# Iteration=17
# likelihood is -689.3141928999358 on iteration 17.
# Iteration=18
# likelihood is -689.2825581245421 on iteration 18.
# Iteration=19
# likelihood is -689.2454179376786 on iteration 19.
# Iteration=20
# likelihood is -689.2009475830046 on iteration 20.
# 5-th start
# theta=[0.7029336],P=[[1.77615171e-07-2.64697796e-24j]]
# Inital likelihood = -689.579248242526
# Iteration=1
# likelihood is -689.5662327602989 on iteration 1.
# Iteration=2
# likelihood is -689.5549122958456 on iteration 2.
# Iteration=3
# likelihood is -689.5434902790769 on iteration 3.
# Iteration=4
# likelihood is -689.531743190781 on iteration 4.
# Iteration=5
# likelihood is -689.5197560186419 on iteration 5.
# Iteration=6
# likelihood is -689.5074660044137 on iteration 6.
# Iteration=7
# likelihood is -689.494795357322 on iteration 7.
# Iteration=8
# likelihood is -689.4816435847403 on iteration 8.
# Iteration=9
# likelihood is -689.4678895627119 on iteration 9.
# Iteration=10
# likelihood is -689.4533883318942 on iteration 10.
# Iteration=11
# likelihood is -689.4379654324896 on iteration 11.
# Iteration=12
# likelihood is -689.4214085163734 on iteration 12.
# Iteration=13
# likelihood is -689.4034554697939 on iteration 13.
# Iteration=14
# likelihood is -689.3837776615783 on iteration 14.
# Iteration=15
# likelihood is -689.3619561294698 on iteration 15.
# Iteration=16
# likelihood is -689.3374470858919 on iteration 16.
# Iteration=17
# likelihood is -689.3095309044029 on iteration 17.
# Iteration=18
# likelihood is -689.2772347360818 on iteration 18.
# Iteration=19
# likelihood is -689.2392117430193 on iteration 19.
# Iteration=20
# likelihood is -689.1935464462898 on iteration 20.
# 6-th start
# theta=[0.73079862],P=[[6.86735671e-08-2.97785021e-24j]]
# Inital likelihood = -689.5792625347437
# Iteration=1
# likelihood is -689.5708403925664 on iteration 1.
# Iteration=2
# likelihood is -689.560667625065 on iteration 2.
# Iteration=3
# likelihood is -689.5492845344974 on iteration 3.
# Iteration=4
# likelihood is -689.5372182656113 on iteration 4.
# Iteration=5
# likelihood is -689.5247418363796 on iteration 5.
# Iteration=6
# likelihood is -689.5119555736134 on iteration 6.
# Iteration=7
# likelihood is -689.4988526072802 on iteration 7.
# Iteration=8
# likelihood is -689.4853603911929 on iteration 8.
# Iteration=9
# likelihood is -689.4713655988396 on iteration 9.
# Iteration=10
# likelihood is -689.4567145008357 on iteration 10.
# Iteration=11
# likelihood is -689.4412290489911 on iteration 11.
# Iteration=12
# likelihood is -689.4246916030296 on iteration 12.
# Iteration=13
# likelihood is -689.4068377926951 on iteration 13.
# Iteration=14
# likelihood is -689.3873409946427 on iteration 14.
# Iteration=15
# likelihood is -689.3657896997145 on iteration 15.
# Iteration=16
# likelihood is -689.34165458021 on iteration 16.
# Iteration=17
# likelihood is -689.3142399751331 on iteration 17.
# Iteration=18
# likelihood is -689.2826106624545 on iteration 18.
# Iteration=19
# likelihood is -689.2454781765349 on iteration 19.
# Iteration=20
# likelihood is -689.2010185551652 on iteration 20.
# 7-th start
# theta=[0.83991537],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579268841746
# Iteration=1
# likelihood is -689.5800081513287 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 8-th start
# theta=[0.86805869],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688779773
# Iteration=1
# likelihood is -689.5800713937713 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 9-th start
# theta=[0.74591953],P=[[9.79826128e-08-1.98523347e-24j]]
# Inital likelihood = -689.5792626099957
# Iteration=1
# likelihood is -689.5729183501008 on iteration 1.
# Iteration=2
# likelihood is -689.5638921055545 on iteration 2.
# Iteration=3
# likelihood is -689.5527608958749 on iteration 3.
# Iteration=4
# likelihood is -689.540412783581 on iteration 4.
# Iteration=5
# likelihood is -689.5274179673524 on iteration 5.
# Iteration=6
# likelihood is -689.514058493848 on iteration 6.
# Iteration=7
# likelihood is -689.5004185263091 on iteration 7.
# Iteration=8
# likelihood is -689.4864610670375 on iteration 8.
# Iteration=9
# likelihood is -689.4720799553743 on iteration 9.
# Iteration=10
# likelihood is -689.457111753692 on iteration 10.
# Iteration=11
# likelihood is -689.4413672663795 on iteration 11.
# Iteration=12
# likelihood is -689.4246154055858 on iteration 12.
# Iteration=13
# likelihood is -689.4065790622096 on iteration 13.
# Iteration=14
# likelihood is -689.3869200346081 on iteration 14.
# Iteration=15
# likelihood is -689.3652161603961 on iteration 15.
# Iteration=16
# likelihood is -689.3409278156736 on iteration 16.
# Iteration=17
# likelihood is -689.3133485323133 on iteration 17.
# Iteration=18
# likelihood is -689.2815305296393 on iteration 18.
# Iteration=19
# likelihood is -689.244169201568 on iteration 19.
# Iteration=20
# likelihood is -689.1994178911956 on iteration 20.
# 10-th start
# theta=[0.45944132],P=[[5.55659323e-08+3.57342025e-23j]]
# Inital likelihood = -689.5792678138821
# Iteration=1
# likelihood is -689.577887962384 on iteration 1.
# Iteration=2
# likelihood is -689.5765351615171 on iteration 2.
# Iteration=3
# likelihood is -689.5751641089611 on iteration 3.
# Iteration=4
# likelihood is -689.5737773970168 on iteration 4.
# Iteration=5
# likelihood is -689.5723756890262 on iteration 5.
# Iteration=6
# likelihood is -689.5709580978746 on iteration 6.
# Iteration=7
# likelihood is -689.5695224211813 on iteration 7.
# Iteration=8
# likelihood is -689.5680653101889 on iteration 8.
# Iteration=9
# likelihood is -689.5665823365777 on iteration 9.
# Iteration=10
# likelihood is -689.5650680147688 on iteration 10.
# Iteration=11
# likelihood is -689.563515759107 on iteration 11.
# Iteration=12
# likelihood is -689.5619177809888 on iteration 12.
# Iteration=13
# likelihood is -689.5602649488378 on iteration 13.
# Iteration=14
# likelihood is -689.5585465646872 on iteration 14.
# Iteration=15
# likelihood is -689.5567500757617 on iteration 15.
# Iteration=16
# likelihood is -689.5548606807195 on iteration 16.
# Iteration=17
# likelihood is -689.552860824606 on iteration 17.
# Iteration=18
# likelihood is -689.5507295154952 on iteration 18.
# Iteration=19
# likelihood is -689.5484414387614 on iteration 19.
# Iteration=20
# likelihood is -689.5459657539427 on iteration 20.
# 11-th start
# theta=[0.49094045],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579267869759
# Iteration=1
# likelihood is -689.5780007076089 on iteration 1.
# Iteration=2
# likelihood is -689.5767743021187 on iteration 2.
# Iteration=3
# likelihood is -689.57554006741 on iteration 3.
# Iteration=4
# likelihood is -689.5742951597593 on iteration 4.
# Iteration=5
# likelihood is -689.5730362794113 on iteration 5.
# Iteration=6
# likelihood is -689.5717596571734 on iteration 6.
# Iteration=7
# likelihood is -689.5704610275387 on iteration 7.
# Iteration=8
# likelihood is -689.5691355792959 on iteration 8.
# Iteration=9
# likelihood is -689.5677778943982 on iteration 9.
# Iteration=10
# likelihood is -689.566381873882 on iteration 10.
# Iteration=11
# likelihood is -689.5649406123707 on iteration 11.
# Iteration=12
# likelihood is -689.5634462621697 on iteration 12.
# Iteration=13
# likelihood is -689.561889849908 on iteration 13.
# Iteration=14
# likelihood is -689.5602610322094 on iteration 14.
# Iteration=15
# likelihood is -689.5585477920939 on iteration 15.
# Iteration=16
# likelihood is -689.556736035534 on iteration 16.
# Iteration=17
# likelihood is -689.554809095439 on iteration 17.
# Iteration=18
# likelihood is -689.5527470440579 on iteration 18.
# Iteration=19
# likelihood is -689.550525840533 on iteration 19.
# Iteration=20
# likelihood is -689.548116148312 on iteration 20.
# 12-th start
# theta=[0.61180126],P=[[8.06311518e-08-5.29395592e-24j]]
# Inital likelihood = -689.5792664814606
# Iteration=1
# likelihood is -689.5765268522907 on iteration 1.
# Iteration=2
# likelihood is -689.5739452715718 on iteration 2.
# Iteration=3
# likelihood is -689.5713279657899 on iteration 3.
# Iteration=4
# likelihood is -689.5686625907256 on iteration 4.
# Iteration=5
# likelihood is -689.5659353358391 on iteration 5.
# Iteration=6
# likelihood is -689.5631310535675 on iteration 6.
# Iteration=7
# likelihood is -689.560233389331 on iteration 7.
# Iteration=8
# likelihood is -689.5572249843176 on iteration 8.
# Iteration=9
# likelihood is -689.5540871364307 on iteration 9.
# Iteration=10
# likelihood is -689.5508003131727 on iteration 10.
# Iteration=11
# likelihood is -689.5473435845448 on iteration 11.
# Iteration=12
# likelihood is -689.543694268028 on iteration 12.
# Iteration=13
# likelihood is -689.5398272880769 on iteration 13.
# Iteration=14
# likelihood is -689.5357431540535 on iteration 14.
# Iteration=15
# likelihood is -689.5313531106949 on iteration 15.
# Iteration=16
# likelihood is -689.5266439007216 on iteration 16.
# Iteration=17
# likelihood is -689.52156724025 on iteration 17.
# Iteration=18
# likelihood is -689.5160633259002 on iteration 18.
# Iteration=19
# likelihood is -689.5100570628238 on iteration 19.
# Iteration=20
# likelihood is -689.5034530465766 on iteration 20.
# 13-th start
# theta=[0.74517223],P=[[9.99993584e-08+7.94093388e-24j]]
# Inital likelihood = -689.5792623522027
# Iteration=1
# likelihood is -689.57276319111 on iteration 1.
# Iteration=2
# likelihood is -689.5636567912182 on iteration 2.
# Iteration=3
# likelihood is -689.5524966666444 on iteration 3.
# Iteration=4
# likelihood is -689.5401543145082 on iteration 4.
# Iteration=5
# likelihood is -689.5271823478605 on iteration 5.
# Iteration=6
# likelihood is -689.5138509671438 on iteration 6.
# Iteration=7
# likelihood is -689.5002378444347 on iteration 7.
# Iteration=8
# likelihood is -689.4863031207788 on iteration 8.
# Iteration=9
# likelihood is -689.4719408272325 on iteration 9.
# Iteration=10
# likelihood is -689.4569853109442 on iteration 10.
# Iteration=11
# likelihood is -689.4412491043955 on iteration 11.
# Iteration=12
# likelihood is -689.4245015934854 on iteration 12.
# Iteration=13
# likelihood is -689.4064660384151 on iteration 13.
# Iteration=14
# likelihood is -689.3868044422044 on iteration 14.
# Iteration=15
# likelihood is -689.3650946329296 on iteration 15.
# Iteration=16
# likelihood is -689.3407967317909 on iteration 16.
# Iteration=17
# likelihood is -689.3132036899062 on iteration 17.
# Iteration=18
# likelihood is -689.2813667107287 on iteration 18.
# Iteration=19
# likelihood is -689.2439795300049 on iteration 19.
# Iteration=20
# likelihood is -689.1991928378103 on iteration 20.
# 14-th start
# theta=[0.81529611],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688264825
# Iteration=1
# likelihood is -689.5799824800301 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 15-th start
# theta=[0.64780331],P=[[8.03558405e-08+0.j]]
# Inital likelihood = -689.5792644427597
# Iteration=1
# likelihood is -689.5748721735529 on iteration 1.
# Iteration=2
# likelihood is -689.5695078608928 on iteration 2.
# Iteration=3
# likelihood is -689.5626135455466 on iteration 3.
# Iteration=4
# likelihood is -689.55391634696 on iteration 4.
# Iteration=5
# likelihood is -689.5433358435569 on iteration 5.
# Iteration=6
# likelihood is -689.5329278953556 on iteration 6.
# Iteration=7
# likelihood is -689.51928068333 on iteration 7.
# Iteration=8
# likelihood is -689.5043686094722 on iteration 8.
# Iteration=9
# likelihood is -689.4884908404672 on iteration 9.
# Iteration=10
# likelihood is -689.4718379389051 on iteration 10.
# Iteration=11
# likelihood is -689.4544634982631 on iteration 11.
# Iteration=12
# likelihood is -689.4362875826907 on iteration 12.
# Iteration=13
# likelihood is -689.4171115365218 on iteration 13.
# Iteration=14
# likelihood is -689.396629473752 on iteration 14.
# Iteration=15
# likelihood is -689.3744281553641 on iteration 15.
# Iteration=16
# likelihood is -689.3499709220898 on iteration 16.
# Iteration=17
# likelihood is -689.3225616295857 on iteration 17.
# Iteration=18
# likelihood is -689.2912817705287 on iteration 18.
# Iteration=19
# likelihood is -689.2548880062208 on iteration 19.
# Iteration=20
# likelihood is -689.2116458445058 on iteration 20.
# 16-th start
# theta=[0.22711654],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792687212914
# Iteration=1
# likelihood is -689.5797592902953 on iteration 1.
# Likelihood is converged!
# 17-th start
# theta=[0.45039062],P=[[4.93435618e-08-4.76456033e-23j]]
# Inital likelihood = -689.579268038814
# Iteration=1
# likelihood is -689.5782162028979 on iteration 1.
# Iteration=2
# likelihood is -689.5770474695321 on iteration 2.
# Iteration=3
# likelihood is -689.5757790478132 on iteration 3.
# Iteration=4
# likelihood is -689.5744547080254 on iteration 4.
# Iteration=5
# likelihood is -689.5730666338009 on iteration 5.
# Iteration=6
# likelihood is -689.5716399514665 on iteration 6.
# Iteration=7
# likelihood is -689.5701813622867 on iteration 7.
# Iteration=8
# likelihood is -689.5686934987742 on iteration 8.
# Iteration=9
# likelihood is -689.5671759119423 on iteration 9.
# Iteration=10
# likelihood is -689.5656257242316 on iteration 10.
# Iteration=11
# likelihood is -689.5640380347226 on iteration 11.
# Iteration=12
# likelihood is -689.5624061065131 on iteration 12.
# Iteration=13
# likelihood is -689.5607214460279 on iteration 13.
# Iteration=14
# likelihood is -689.5589737184806 on iteration 14.
# Iteration=15
# likelihood is -689.5571505490835 on iteration 15.
# Iteration=16
# likelihood is -689.5552372146449 on iteration 16.
# Iteration=17
# likelihood is -689.5532161631021 on iteration 17.
# Iteration=18
# likelihood is -689.5510663920538 on iteration 18.
# Iteration=19
# likelihood is -689.5487625607473 on iteration 19.
# Iteration=20
# likelihood is -689.5462738294866 on iteration 20.
# 18-th start
# theta=[1.57079633],P=[[8.75235434e-08-2.70617725e-23j]]
# Inital likelihood = -689.5792674589636
# Iteration=1
# likelihood is -689.5779876603073 on iteration 1.
# Iteration=2
# likelihood is -689.5762533917922 on iteration 2.
# Iteration=3
# likelihood is -689.5741131876518 on iteration 3.
# Iteration=4
# likelihood is -689.5716709724502 on iteration 4.
# Iteration=5
# likelihood is -689.5690080346699 on iteration 5.
# Iteration=6
# likelihood is -689.5661831970502 on iteration 6.
# Iteration=7
# likelihood is -689.5632359277869 on iteration 7.
# Iteration=8
# likelihood is -689.5601900216769 on iteration 8.
# Iteration=9
# likelihood is -689.5570570045213 on iteration 9.
# Iteration=10
# likelihood is -689.5538387663026 on iteration 10.
# Iteration=11
# likelihood is -689.5505295417805 on iteration 11.
# Iteration=12
# likelihood is -689.5471171464063 on iteration 12.
# Iteration=13
# likelihood is -689.5435836446172 on iteration 13.
# Iteration=14
# likelihood is -689.539905556056 on iteration 14.
# Iteration=15
# likelihood is -689.5360535757453 on iteration 15.
# Iteration=16
# likelihood is -689.5319922337633 on iteration 16.
# Iteration=17
# likelihood is -689.527677205412 on iteration 17.
# Iteration=18
# likelihood is -689.5230558271463 on iteration 18.
# Iteration=19
# likelihood is -689.5180630324197 on iteration 19.
# Iteration=20
# likelihood is -689.5126182379131 on iteration 20.
# 19-th start
# theta=[0.75399535],P=[[7.64820505e-08-1.0753348e-24j]]
# Inital likelihood = -689.5792650119403
# Iteration=1
# likelihood is -689.5745343352627 on iteration 1.
# Iteration=2
# likelihood is -689.5664919636706 on iteration 2.
# Iteration=3
# likelihood is -689.555773946055 on iteration 3.
# Iteration=4
# likelihood is -689.5434091625797 on iteration 4.
# Iteration=5
# likelihood is -689.5301683127045 on iteration 5.
# Iteration=6
# likelihood is -689.516482697268 on iteration 6.
# Iteration=7
# likelihood is -689.5025215937136 on iteration 7.
# Iteration=8
# likelihood is -689.4882872386726 on iteration 8.
# Iteration=9
# likelihood is -689.4736834040718 on iteration 9.
# Iteration=10
# likelihood is -689.4585537786485 on iteration 10.
# Iteration=11
# likelihood is -689.4427003959036 on iteration 11.
# Iteration=12
# likelihood is -689.4258863503828 on iteration 12.
# Iteration=13
# likelihood is -689.4078296575449 on iteration 13.
# Iteration=14
# likelihood is -689.3881891243974 on iteration 14.
# Iteration=15
# likelihood is -689.366541957629 on iteration 15.
# Iteration=16
# likelihood is -689.3423507675976 on iteration 16.
# Iteration=17
# likelihood is -689.3149148590323 on iteration 17.
# Iteration=18
# likelihood is -689.283296974395 on iteration 18.
# Iteration=19
# likelihood is -689.2462099072164 on iteration 19.
# Iteration=20
# likelihood is -689.2018350962884 on iteration 20.
# best_start=5

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.7011151]), array([[0.00342798+0.j]]))

# %%
em.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q2), em.incomplete_lkhd(X2_with_mv, theta2_rad, P2, Q2)
# Out:
# (np.float64(-689.1935464462898), np.float64(-673.6467390084401))
