# %%
import numpy as np

# %%
from pathlib import Path
import sys

try:
    ROOT = Path().resolve().parents[1]
    assert (ROOT / "common").exists()
except AssertionError:
    ROOT = next(p for p in Path().resolve().parents if (p / "common").exists())

if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
#print(ROOT)

# %%
from common import sensors as sn 
from common import subspace_methods as sm
from common import em_tools as em
from common import log_funcs as lf

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12

failing_sensors1 = np.arange(5)
gap_ratio1 = 0.5 * np.ones_like(failing_sensors1, dtype=np.float32)

theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sn.gss(Num_emitters1, sample_size1, P1)
N1 = sn.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sn.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sn.initial_Cov(X1_with_mv)
MUSIC_theta1 = sm.MUSIC_DoA(R1, Num_emitters1)

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sn.SNR(A1, P1, Q1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1, lhd_list1, angles_list1 = em.multistart_EM(X1_with_mv, 
                                                                        Num_emitters1, 
                                                                        Q=Q1,
                                                                        theta_guess=MUSIC_theta1, 
                                                                        num_of_starts=10, 
                                                                        max_iter=20, 
                                                                        rtol_params=1e-6,
                                                                        rtol_lkhd=1e-6,
                                                                        reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.71558499],P=[[1.18642836e-07-1.98523347e-24j]]
# Inital likelihood = -870.4011155592349
# Iteration=1
# new_angles=[0.72207638]
# new_P:
# [[0.00010076+0.j]]
# likelihood is -870.3923435488267 on iteration 1.
# Iteration=2
# new_angles=[0.71688292]
# new_P:
# [[0.00020093+0.j]]
# likelihood is -870.3823358969338 on iteration 2.
# Iteration=3
# new_angles=[0.71263946]
# new_P:
# [[0.00030166+0.j]]
# likelihood is -870.3716135091055 on iteration 3.
# Iteration=4
# new_angles=[0.70942051]
# new_P:
# [[0.00040341+0.j]]
# likelihood is -870.3605813225518 on iteration 4.
# Iteration=5
# new_angles=[0.70684918]
# new_P:
# [[0.00050665+0.j]]
# likelihood is -870.3493290350375 on iteration 5.
# Iteration=6
# new_angles=[0.70486983]
# new_P:
# [[0.0006119+0.j]]
# likelihood is -870.337913757388 on iteration 6.
# Iteration=7
# new_angles=[0.70322761]
# new_P:
# [[0.00071972+0.j]]
# likelihood is -870.3262637920732 on iteration 7.
# Iteration=8
# new_angles=[0.70189359]
# new_P:
# [[0.00083075+0.j]]
# likelihood is -870.3143391204977 on iteration 8.
# Iteration=9
# new_angles=[0.70088047]
# new_P:
# [[0.0009457+0.j]]
# likelihood is -870.3020831656527 on iteration 9.
# Iteration=10
# new_angles=[0.70009904]
# new_P:
# [[0.00106536+0.j]]
# likelihood is -870.2893918171228 on iteration 10.
# Iteration=11
# new_angles=[0.69940645]
# new_P:
# [[0.00119066+0.j]]
# likelihood is -870.2761364608207 on iteration 11.
# Iteration=12
# new_angles=[0.6988603]
# new_P:
# [[0.0013227+0.j]]
# likelihood is -870.2622185565216 on iteration 12.
# Iteration=13
# new_angles=[0.69839784]
# new_P:
# [[0.00146276+0.j]]
# likelihood is -870.2474914123404 on iteration 13.
# Iteration=14
# new_angles=[0.69802488]
# new_P:
# [[0.00161237+0.j]]
# likelihood is -870.2317966251385 on iteration 14.
# Iteration=15
# new_angles=[0.69772311]
# new_P:
# [[0.0017734+0.j]]
# likelihood is -870.214938329267 on iteration 15.
# Iteration=16
# new_angles=[0.69748058]
# new_P:
# [[0.00194812+0.j]]
# likelihood is -870.1966797996531 on iteration 16.
# Iteration=17
# new_angles=[0.69728083]
# new_P:
# [[0.00213935+0.j]]
# likelihood is -870.1767289071788 on iteration 17.
# Iteration=18
# new_angles=[0.69711418]
# new_P:
# [[0.00235064+0.j]]
# likelihood is -870.1547216700129 on iteration 18.
# Iteration=19
# new_angles=[0.69697183]
# new_P:
# [[0.0025865+0.j]]
# likelihood is -870.1301962088341 on iteration 19.
# Iteration=20
# new_angles=[0.69688863]
# new_P:
# [[0.00285278+0.j]]
# likelihood is -870.1025601476994 on iteration 20.
# 1-th start
# theta=[0.75761751],P=[[7.62531873e-08-2.64697796e-24j]]
# Inital likelihood = -870.4011243940959
# Iteration=1
# new_angles=[0.76436369]
# new_P:
# [[0.00010072+0.j]]
# likelihood is -870.3988038603204 on iteration 1.
# Iteration=2
# new_angles=[0.75188063]
# new_P:
# [[0.00020078+0.j]]
# likelihood is -870.3930159998467 on iteration 2.
# Iteration=3
# new_angles=[0.74067072]
# new_P:
# [[0.00030118+0.j]]
# likelihood is -870.3835309140472 on iteration 3.
# Iteration=4
# new_angles=[0.7315413]
# new_P:
# [[0.00040236+0.j]]
# likelihood is -870.3716622465081 on iteration 4.
# Iteration=5
# new_angles=[0.72434994]
# new_P:
# [[0.0005049+0.j]]
# likelihood is -870.3587390846225 on iteration 5.
# Iteration=6
# new_angles=[0.7187369]
# new_P:
# [[0.0006094+0.j]]
# likelihood is -870.3455243951697 on iteration 6.
# Iteration=7
# new_angles=[0.71420779]
# new_P:
# [[0.0007165+0.j]]
# likelihood is -870.3322053055928 on iteration 7.
# Iteration=8
# new_angles=[0.71065159]
# new_P:
# [[0.00082684+0.j]]
# likelihood is -870.3189439043811 on iteration 8.
# Iteration=9
# new_angles=[0.7077594]
# new_P:
# [[0.00094115+0.j]]
# likelihood is -870.3055952757983 on iteration 9.
# Iteration=10
# new_angles=[0.70551237]
# new_P:
# [[0.00106023+0.j]]
# likelihood is -870.2921169373521 on iteration 10.
# Iteration=11
# new_angles=[0.70376572]
# new_P:
# [[0.00118499+0.j]]
# likelihood is -870.2783298841051 on iteration 11.
# Iteration=12
# new_angles=[0.70234253]
# new_P:
# [[0.00131648+0.j]]
# likelihood is -870.2640207326788 on iteration 12.
# Iteration=13
# new_angles=[0.70123946]
# new_P:
# [[0.00145598+0.j]]
# likelihood is -870.2490456502256 on iteration 13.
# Iteration=14
# new_angles=[0.70029706]
# new_P:
# [[0.00160501+0.j]]
# likelihood is -870.2331682220644 on iteration 14.
# Iteration=15
# new_angles=[0.69958003]
# new_P:
# [[0.00176539+0.j]]
# likelihood is -870.2162158443418 on iteration 15.
# Iteration=16
# new_angles=[0.6989589]
# new_P:
# [[0.00193937+0.j]]
# likelihood is -870.1979035054378 on iteration 16.
# Iteration=17
# new_angles=[0.69848061]
# new_P:
# [[0.00212975+0.j]]
# likelihood is -870.1779544913052 on iteration 17.
# Iteration=18
# new_angles=[0.69809422]
# new_P:
# [[0.00234002+0.j]]
# likelihood is -870.1559900190612 on iteration 18.
# Iteration=19
# new_angles=[0.69777557]
# new_P:
# [[0.00257466+0.j]]
# likelihood is -870.1315452622953 on iteration 19.
# Iteration=20
# new_angles=[0.69753303]
# new_P:
# [[0.00283944+0.j]]
# likelihood is -870.1040311772267 on iteration 20.
# 2-th start
# theta=[0.75275765],P=[[4.72357604e-08-5.62482817e-24j]]
# Inital likelihood = -870.4011249844442
# Iteration=1
# new_angles=[0.75947273]
# new_P:
# [[0.00010028+0.j]]
# likelihood is -870.398181432558 on iteration 1.
# Iteration=2
# new_angles=[0.74704674]
# new_P:
# [[0.00020036+0.j]]
# likelihood is -870.3915063761417 on iteration 2.
# Iteration=3
# new_angles=[0.7367381]
# new_P:
# [[0.0003008+0.j]]
# likelihood is -870.3816072386211 on iteration 3.
# Iteration=4
# new_angles=[0.72848638]
# new_P:
# [[0.00040207+0.j]]
# likelihood is -870.3697864231367 on iteration 4.
# Iteration=5
# new_angles=[0.72195402]
# new_P:
# [[0.00050473+0.j]]
# likelihood is -870.3571069422206 on iteration 5.
# Iteration=6
# new_angles=[0.71676436]
# new_P:
# [[0.00060936+0.j]]
# likelihood is -870.3441373485492 on iteration 6.
# Iteration=7
# new_angles=[0.7126552]
# new_P:
# [[0.00071658+0.j]]
# likelihood is -870.3311286710043 on iteration 7.
# Iteration=8
# new_angles=[0.70943621]
# new_P:
# [[0.00082705+0.j]]
# likelihood is -870.3181315205288 on iteration 8.
# Iteration=9
# new_angles=[0.70686806]
# new_P:
# [[0.00094146+0.j]]
# likelihood is -870.305027145207 on iteration 9.
# Iteration=10
# new_angles=[0.70479993]
# new_P:
# [[0.00106062+0.j]]
# likelihood is -870.2916852555771 on iteration 10.
# Iteration=11
# new_angles=[0.70315781]
# new_P:
# [[0.00118545+0.j]]
# likelihood is -870.2779788448363 on iteration 11.
# Iteration=12
# new_angles=[0.70187082]
# new_P:
# [[0.00131702+0.j]]
# likelihood is -870.2637531377226 on iteration 12.
# Iteration=13
# new_angles=[0.70085772]
# new_P:
# [[0.00145659+0.j]]
# likelihood is -870.2488279359342 on iteration 13.
# Iteration=14
# new_angles=[0.70001881]
# new_P:
# [[0.00160568+0.j]]
# likelihood is -870.2329974199095 on iteration 14.
# Iteration=15
# new_angles=[0.69931286]
# new_P:
# [[0.00176613+0.j]]
# likelihood is -870.216052293442 on iteration 15.
# Iteration=16
# new_angles=[0.69875109]
# new_P:
# [[0.00194019+0.j]]
# likelihood is -870.1977586798723 on iteration 16.
# Iteration=17
# new_angles=[0.69828976]
# new_P:
# [[0.00213066+0.j]]
# likelihood is -870.1778116753994 on iteration 17.
# Iteration=18
# new_angles=[0.69793054]
# new_P:
# [[0.00234103+0.j]]
# likelihood is -870.1558481376042 on iteration 18.
# Iteration=19
# new_angles=[0.69762772]
# new_P:
# [[0.00257579+0.j]]
# likelihood is -870.1313983679456 on iteration 19.
# Iteration=20
# new_angles=[0.69738996]
# new_P:
# [[0.00284071+0.j]]
# likelihood is -870.1038732224949 on iteration 20.
# 3-th start
# theta=[0.82383174],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -870.4011268160693
# Iteration=1
# new_angles=[0.82383174]
# new_P:
# [[0.00010028+0.j]]
# likelihood is -870.401097126884 on iteration 1.
# Likelihood is converged!
# 4-th start
# theta=[0.72131738],P=[[1.09961713e-07-2.97785021e-24j]]
# Inital likelihood = -870.4011171320063
# Iteration=1
# new_angles=[0.7278417]
# new_P:
# [[0.00010076+0.j]]
# likelihood is -870.3931668768738 on iteration 1.
# Iteration=2
# new_angles=[0.7214142]
# new_P:
# [[0.00020092+0.j]]
# likelihood is -870.3834431278541 on iteration 2.
# Iteration=3
# new_angles=[0.71631688]
# new_P:
# [[0.00030162+0.j]]
# likelihood is -870.3727394253249 on iteration 3.
# Iteration=4
# new_angles=[0.71243907]
# new_P:
# [[0.00040332+0.j]]
# likelihood is -870.3616078670675 on iteration 4.
# Iteration=5
# new_angles=[0.70922068]
# new_P:
# [[0.00050649+0.j]]
# likelihood is -870.350162817238 on iteration 5.
# Iteration=6
# new_angles=[0.706653]
# new_P:
# [[0.00061168+0.j]]
# likelihood is -870.338540378413 on iteration 6.
# Iteration=7
# new_angles=[0.70467398]
# new_P:
# [[0.00071944+0.j]]
# likelihood is -870.3267603756078 on iteration 7.
# Iteration=8
# new_angles=[0.70303203]
# new_P:
# [[0.00083042+0.j]]
# likelihood is -870.3147163146972 on iteration 8.
# Iteration=9
# new_angles=[0.70175264]
# new_P:
# [[0.00094531+0.j]]
# likelihood is -870.3023657999115 on iteration 9.
# Iteration=10
# new_angles=[0.70073964]
# new_P:
# [[0.00106493+0.j]]
# likelihood is -870.2896007721097 on iteration 10.
# Iteration=11
# new_angles=[0.69987366]
# new_P:
# [[0.00119019+0.j]]
# likelihood is -870.276293381833 on iteration 11.
# Iteration=12
# new_angles=[0.69922805]
# new_P:
# [[0.00132219+0.j]]
# likelihood is -870.2623485920899 on iteration 12.
# Iteration=13
# new_angles=[0.69868198]
# new_P:
# [[0.00146221+0.j]]
# likelihood is -870.2476018460935 on iteration 13.
# Iteration=14
# new_angles=[0.69827988]
# new_P:
# [[0.00161178+0.j]]
# likelihood is -870.2319013861461 on iteration 14.
# Iteration=15
# new_angles=[0.69792066]
# new_P:
# [[0.00177276+0.j]]
# likelihood is -870.215034819662 on iteration 15.
# Iteration=16
# new_angles=[0.69761784]
# new_P:
# [[0.00194742+0.j]]
# likelihood is -870.1967706323869 on iteration 16.
# Iteration=17
# new_angles=[0.69740436]
# new_P:
# [[0.00213859+0.j]]
# likelihood is -870.1768229555412 on iteration 17.
# Iteration=18
# new_angles=[0.69723769]
# new_P:
# [[0.0023498+0.j]]
# likelihood is -870.1548222809795 on iteration 18.
# Iteration=19
# new_angles=[0.69708166]
# new_P:
# [[0.00258556+0.j]]
# likelihood is -870.1303036734114 on iteration 19.
# Iteration=20
# new_angles=[0.69693931]
# new_P:
# [[0.00285173+0.j]]
# likelihood is -870.10267336991 on iteration 20.
# 5-th start
# theta=[0.69420695],P=[[2.63712642e-07-3.97046694e-24j]]
# Inital likelihood = -870.4010990043953
# Iteration=1
# new_angles=[0.69420695]
# new_P:
# [[0.00010224+0.j]]
# likelihood is -870.3903426116663 on iteration 1.
# Iteration=2
# new_angles=[0.69447058]
# new_P:
# [[0.00020244+0.j]]
# likelihood is -870.3797732735353 on iteration 2.
# Iteration=3
# new_angles=[0.69474794]
# new_P:
# [[0.00030326+0.j]]
# likelihood is -870.3691407863737 on iteration 3.
# Iteration=4
# new_angles=[0.69506579]
# new_P:
# [[0.00040512+0.j]]
# likelihood is -870.3583999076479 on iteration 4.
# Iteration=5
# new_angles=[0.69532961]
# new_P:
# [[0.00050849+0.j]]
# likelihood is -870.3475063014287 on iteration 5.
# Iteration=6
# new_angles=[0.69559348]
# new_P:
# [[0.00061388+0.j]]
# likelihood is -870.3364064784018 on iteration 6.
# Iteration=7
# new_angles=[0.695685]
# new_P:
# [[0.00072185+0.j]]
# likelihood is -870.3250479969862 on iteration 7.
# Iteration=8
# new_angles=[0.69586088]
# new_P:
# [[0.00083302+0.j]]
# likelihood is -870.3133581660138 on iteration 8.
# Iteration=9
# new_angles=[0.69595242]
# new_P:
# [[0.0009481+0.j]]
# likelihood is -870.3012686683717 on iteration 9.
# Iteration=10
# new_angles=[0.69604396]
# new_P:
# [[0.0010679+0.j]]
# likelihood is -870.2886933562526 on iteration 10.
# Iteration=11
# new_angles=[0.69613552]
# new_P:
# [[0.00119336+0.j]]
# likelihood is -870.2755356073703 on iteration 11.
# Iteration=12
# new_angles=[0.69622708]
# new_P:
# [[0.00132555+0.j]]
# likelihood is -870.2616826432571 on iteration 12.
# Iteration=13
# new_angles=[0.69623027]
# new_P:
# [[0.00146579+0.j]]
# likelihood is -870.2470024300691 on iteration 13.
# Iteration=14
# new_angles=[0.69624711]
# new_P:
# [[0.0016156+0.j]]
# likelihood is -870.2313344191499 on iteration 14.
# Iteration=15
# new_angles=[0.69626395]
# new_P:
# [[0.00177686+0.j]]
# likelihood is -870.2144868361859 on iteration 15.
# Iteration=16
# new_angles=[0.69628079]
# new_P:
# [[0.00195185+0.j]]
# likelihood is -870.1962251666226 on iteration 16.
# Iteration=17
# new_angles=[0.69629763]
# new_P:
# [[0.0021434+0.j]]
# likelihood is -870.176259294521 on iteration 17.
# Iteration=18
# new_angles=[0.69631447]
# new_P:
# [[0.00235508+0.j]]
# likelihood is -870.154225510949 on iteration 18.
# Iteration=19
# new_angles=[0.69633132]
# new_P:
# [[0.00259142+0.j]]
# likelihood is -870.1296612617186 on iteration 19.
# Iteration=20
# new_angles=[0.69634708]
# new_P:
# [[0.0028583+0.j]]
# likelihood is -870.1019690338246 on iteration 20.
# 6-th start
# theta=[0.72207198],P=[[1.08695785e-07+1.65436123e-24j]]
# Inital likelihood = -870.4011173514194
# Iteration=1
# new_angles=[0.72860067]
# new_P:
# [[0.00010076+0.j]]
# likelihood is -870.3932823076648 on iteration 1.
# Iteration=2
# new_angles=[0.72206764]
# new_P:
# [[0.00020091+0.j]]
# likelihood is -870.383616072994 on iteration 2.
# Iteration=3
# new_angles=[0.71687422]
# new_P:
# [[0.00030161+0.j]]
# likelihood is -870.3729266777282 on iteration 3.
# Iteration=4
# new_angles=[0.71263079]
# new_P:
# [[0.0004033+0.j]]
# likelihood is -870.3616805610839 on iteration 4.
# Iteration=5
# new_angles=[0.70941187]
# new_P:
# [[0.00050647+0.j]]
# likelihood is -870.350237754079 on iteration 5.
# Iteration=6
# new_angles=[0.70684056]
# new_P:
# [[0.00061165+0.j]]
# likelihood is -870.3386131793816 on iteration 6.
# Iteration=7
# new_angles=[0.70486122]
# new_P:
# [[0.00071941+0.j]]
# likelihood is -870.3268309131217 on iteration 7.
# Iteration=8
# new_angles=[0.70321901]
# new_P:
# [[0.00083038+0.j]]
# likelihood is -870.3147830624605 on iteration 8.
# Iteration=9
# new_angles=[0.70188501]
# new_P:
# [[0.00094526+0.j]]
# likelihood is -870.3024117131066 on iteration 9.
# Iteration=10
# new_angles=[0.7008719]
# new_P:
# [[0.00106487+0.j]]
# likelihood is -870.2896440344074 on iteration 10.
# Iteration=11
# new_angles=[0.70008938]
# new_P:
# [[0.00119013+0.j]]
# likelihood is -870.2763553590115 on iteration 11.
# Iteration=12
# new_angles=[0.69938339]
# new_P:
# [[0.00132212+0.j]]
# likelihood is -870.2623923654717 on iteration 12.
# Iteration=13
# new_angles=[0.69883724]
# new_P:
# [[0.00146212+0.j]]
# likelihood is -870.247642917514 on iteration 13.
# Iteration=14
# new_angles=[0.69837587]
# new_P:
# [[0.00161169+0.j]]
# likelihood is -870.2319292698263 on iteration 14.
# Iteration=15
# new_angles=[0.69801663]
# new_P:
# [[0.00177266+0.j]]
# likelihood is -870.2150617651788 on iteration 15.
# Iteration=16
# new_angles=[0.69771486]
# new_P:
# [[0.00194731+0.j]]
# likelihood is -870.1967969671934 on iteration 16.
# Iteration=17
# new_angles=[0.69747234]
# new_P:
# [[0.00213846+0.j]]
# likelihood is -870.1768452019254 on iteration 17.
# Iteration=18
# new_angles=[0.69724549]
# new_P:
# [[0.00234966+0.j]]
# likelihood is -870.1548378332184 on iteration 18.
# Iteration=19
# new_angles=[0.69708627]
# new_P:
# [[0.00258541+0.j]]
# likelihood is -870.1303204402076 on iteration 19.
# Iteration=20
# new_angles=[0.69694392]
# new_P:
# [[0.00285155+0.j]]
# likelihood is -870.102692107929 on iteration 20.
# 7-th start
# theta=[0.83118872],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -870.4011267950915
# Iteration=1
# new_angles=[0.83118872]
# new_P:
# [[0.00010028+0.j]]
# likelihood is -870.4010540618876 on iteration 1.
# Likelihood is converged!
# 8-th start
# theta=[0.85933204],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -870.4011268744408
# Iteration=1
# new_angles=[0.85933204]
# new_P:
# [[0.00010029+0.j]]
# likelihood is -870.4012169873824 on iteration 1.
# Likelihood is converged!
# 9-th start
# theta=[0.73719288],P=[[7.93250092e-08-4.63221143e-24j]]
# Inital likelihood = -870.4011217367256
# Iteration=1
# new_angles=[0.74381132]
# new_P:
# [[0.00010059+0.j]]
# likelihood is -870.3957658959068 on iteration 1.
# Iteration=2
# new_angles=[0.7341905]
# new_P:
# [[0.0002007+0.j]]
# likelihood is -870.3872668789235 on iteration 2.
# Iteration=3
# new_angles=[0.72641955]
# new_P:
# [[0.00030128+0.j]]
# likelihood is -870.3767081355625 on iteration 3.
# Iteration=4
# new_angles=[0.72040993]
# new_P:
# [[0.00040279+0.j]]
# likelihood is -870.3651805524319 on iteration 4.
# Iteration=5
# new_angles=[0.7155399]
# new_P:
# [[0.00050574+0.j]]
# likelihood is -870.3531373947189 on iteration 5.
# Iteration=6
# new_angles=[0.71175748]
# new_P:
# [[0.00061069+0.j]]
# likelihood is -870.3409572495541 on iteration 6.
# Iteration=7
# new_angles=[0.70863028]
# new_P:
# [[0.00071823+0.j]]
# likelihood is -870.3285997446301 on iteration 7.
# Iteration=8
# new_angles=[0.7062381]
# new_P:
# [[0.00082899+0.j]]
# likelihood is -870.3161629634747 on iteration 8.
# Iteration=9
# new_angles=[0.7043175]
# new_P:
# [[0.00094369+0.j]]
# likelihood is -870.3034927602691 on iteration 9.
# Iteration=10
# new_angles=[0.7028088]
# new_P:
# [[0.00106311+0.j]]
# likelihood is -870.290496932249 on iteration 10.
# Iteration=11
# new_angles=[0.70153285]
# new_P:
# [[0.0011882+0.j]]
# likelihood is -870.2770098647519 on iteration 11.
# Iteration=12
# new_angles=[0.70053378]
# new_P:
# [[0.00132002+0.j]]
# likelihood is -870.2629353021022 on iteration 12.
# Iteration=13
# new_angles=[0.69975149]
# new_P:
# [[0.00145985+0.j]]
# likelihood is -870.2481117082434 on iteration 13.
# Iteration=14
# new_angles=[0.69911658]
# new_P:
# [[0.00160922+0.j]]
# likelihood is -870.2323535712794 on iteration 14.
# Iteration=15
# new_angles=[0.69859769]
# new_P:
# [[0.00176998+0.j]]
# likelihood is -870.2154575810755 on iteration 15.
# Iteration=16
# new_angles=[0.69819561]
# new_P:
# [[0.0019444+0.j]]
# likelihood is -870.1971869157985 on iteration 16.
# Iteration=17
# new_angles=[0.6978695]
# new_P:
# [[0.00213527+0.j]]
# likelihood is -870.1772413466495 on iteration 17.
# Iteration=18
# new_angles=[0.69756777]
# new_P:
# [[0.00234614+0.j]]
# likelihood is -870.1552492149068 on iteration 18.
# Iteration=19
# new_angles=[0.6973543]
# new_P:
# [[0.00258148+0.j]]
# likelihood is -870.1307615371287 on iteration 19.
# Iteration=20
# new_angles=[0.69719507]
# new_P:
# [[0.00284713+0.j]]
# likelihood is -870.103178587541 on iteration 20.
# best_start=5
# Время выполнения функции: 31.486953 секунд

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.69634708]), array([[0.0028583+0.j]]))

# %%
lf.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q1), lf.incomplete_lkhd(X1_with_mv, theta1_rad, P1, Q1)
# Out:
# (np.float64(-870.1019690338246), np.float64(-852.4011191641745))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11

failing_sensors2 = np.arange(8)
gap_ratio2 = 0.5 * np.ones_like(failing_sensors2, dtype=np.float32)

theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sn.gss(Num_emitters2, sample_size2, P2)
N2 = sn.gss(Num_sensors2, sample_size2, Q2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sn.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sn.initial_Cov(X2_with_mv)
MUSIC_theta2 = sm.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sn.SNR(A2, P2, Q2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2, lhd_list2, angles_list2 = em.multistart_EM(X2_with_mv, 
                                                                        Num_emitters2, 
                                                                        Q=Q2,
                                                                        theta_guess=MUSIC_theta2, 
                                                                        num_of_starts=20, 
                                                                        max_iter=20, 
                                                                        rtol_params=1e-6,
                                                                        rtol_lkhd=1e-6,
                                                                        reg_coef=1e-4)
# Out:
# 0-th start
# theta=[0.72431164],P=[[7.5917774e-08+4.13590306e-24j]]
# Inital likelihood = -689.5792611594288
# Iteration=1
# new_angles=[0.72431164]
# new_P:
# [[0.00010052+0.j]]
# likelihood is -689.5695600608823 on iteration 1.
# Iteration=2
# new_angles=[0.72004058]
# new_P:
# [[0.00020073+0.j]]
# likelihood is -689.5587808820582 on iteration 2.
# Iteration=3
# new_angles=[0.71643273]
# new_P:
# [[0.00030165+0.j]]
# likelihood is -689.5473016687944 on iteration 3.
# Iteration=4
# new_angles=[0.7134818]
# new_P:
# [[0.00040382+0.j]]
# likelihood is -689.5354035618469 on iteration 4.
# Iteration=5
# new_angles=[0.71122371]
# new_P:
# [[0.0005079+0.j]]
# likelihood is -689.5232535314586 on iteration 5.
# Iteration=6
# new_angles=[0.70938428]
# new_P:
# [[0.00061458+0.j]]
# likelihood is -689.5108067863074 on iteration 6.
# Iteration=7
# new_angles=[0.7077798]
# new_P:
# [[0.00072465+0.j]]
# likelihood is -689.4979786479865 on iteration 7.
# Iteration=8
# new_angles=[0.70658759]
# new_P:
# [[0.00083902+0.j]]
# likelihood is -689.4847648457004 on iteration 8.
# Iteration=9
# new_angles=[0.70558423]
# new_P:
# [[0.00095877+0.j]]
# likelihood is -689.4709902761108 on iteration 9.
# Iteration=10
# new_angles=[0.70471469]
# new_P:
# [[0.00108512+0.j]]
# likelihood is -689.4565088777086 on iteration 10.
# Iteration=11
# new_angles=[0.70403318]
# new_P:
# [[0.0012196+0.j]]
# likelihood is -689.4411732558264 on iteration 11.
# Iteration=12
# new_angles=[0.70339597]
# new_P:
# [[0.00136403+0.j]]
# likelihood is -689.4247425026177 on iteration 12.
# Iteration=13
# new_angles=[0.70296731]
# new_P:
# [[0.00152069+0.j]]
# likelihood is -689.4070051072791 on iteration 13.
# Iteration=14
# new_angles=[0.70260668]
# new_P:
# [[0.00169241+0.j]]
# likelihood is -689.3876102272163 on iteration 14.
# Iteration=15
# new_angles=[0.70229001]
# new_P:
# [[0.00188284+0.j]]
# likelihood is -689.3661512600308 on iteration 15.
# Iteration=16
# new_angles=[0.70206225]
# new_P:
# [[0.00209669+0.j]]
# likelihood is -689.3421159611104 on iteration 16.
# Iteration=17
# new_angles=[0.70184797]
# new_P:
# [[0.00234024+0.j]]
# likelihood is -689.3148030984648 on iteration 17.
# Iteration=18
# new_angles=[0.70168799]
# new_P:
# [[0.00262196+0.j]]
# likelihood is -689.2832937276362 on iteration 18.
# Iteration=19
# new_angles=[0.70153137]
# new_P:
# [[0.00295358+0.j]]
# likelihood is -689.2463023029653 on iteration 19.
# Iteration=20
# new_angles=[0.70137477]
# new_P:
# [[0.00335184+0.j]]
# likelihood is -689.2020198440149 on iteration 20.
# 1-th start
# theta=[0.76634416],P=[[4.65993421e-08-2.64697796e-24j]]
# Inital likelihood = -689.5792672995802
# Iteration=1
# new_angles=[0.76634416]
# new_P:
# [[0.00010031+0.j]]
# likelihood is -689.5766970662252 on iteration 1.
# Iteration=2
# new_angles=[0.75555606]
# new_P:
# [[0.00020039+0.j]]
# likelihood is -689.5706943795022 on iteration 2.
# Iteration=3
# new_angles=[0.74583096]
# new_P:
# [[0.00030087+0.j]]
# likelihood is -689.5611754545597 on iteration 3.
# Iteration=4
# new_angles=[0.7375111]
# new_P:
# [[0.00040228+0.j]]
# likelihood is -689.5490258333062 on iteration 4.
# Iteration=5
# new_angles=[0.73092595]
# new_P:
# [[0.00050534+0.j]]
# likelihood is -689.5356131338399 on iteration 5.
# Iteration=6
# new_angles=[0.72544821]
# new_P:
# [[0.00061085+0.j]]
# likelihood is -689.5213843775167 on iteration 6.
# Iteration=7
# new_angles=[0.7209827]
# new_P:
# [[0.00071967+0.j]]
# likelihood is -689.5068039982544 on iteration 7.
# Iteration=8
# new_angles=[0.71737188]
# new_P:
# [[0.00083277+0.j]]
# likelihood is -689.4920179080442 on iteration 8.
# Iteration=9
# new_angles=[0.71440464]
# new_P:
# [[0.00095123+0.j]]
# likelihood is -689.4769336397283 on iteration 9.
# Iteration=10
# new_angles=[0.71196186]
# new_P:
# [[0.0010763+0.j]]
# likelihood is -689.4614195723287 on iteration 10.
# Iteration=11
# new_angles=[0.7100211]
# new_P:
# [[0.00120946+0.j]]
# likelihood is -689.4453369841949 on iteration 11.
# Iteration=12
# new_angles=[0.70841575]
# new_P:
# [[0.0013525+0.j]]
# likelihood is -689.4283735985492 on iteration 12.
# Iteration=13
# new_angles=[0.70707583]
# new_P:
# [[0.00150763+0.j]]
# likelihood is -689.4102386542095 on iteration 13.
# Iteration=14
# new_angles=[0.70605824]
# new_P:
# [[0.00167766+0.j]]
# likelihood is -689.3906521635691 on iteration 14.
# Iteration=15
# new_angles=[0.70517262]
# new_P:
# [[0.0018661+0.j]]
# likelihood is -689.3690984505596 on iteration 15.
# Iteration=16
# new_angles=[0.70440822]
# new_P:
# [[0.0020776+0.j]]
# likelihood is -689.3450620560782 on iteration 16.
# Iteration=17
# new_angles=[0.7037708]
# new_P:
# [[0.00231826+0.j]]
# likelihood is -689.3178713274838 on iteration 17.
# Iteration=18
# new_angles=[0.70328736]
# new_P:
# [[0.00259636+0.j]]
# likelihood is -689.2866289518289 on iteration 18.
# Iteration=19
# new_angles=[0.7028994]
# new_P:
# [[0.0029233+0.j]]
# likelihood is -689.250059660937 on iteration 19.
# Iteration=20
# new_angles=[0.70253878]
# new_P:
# [[0.00331534+0.j]]
# likelihood is -689.2063753760971 on iteration 20.
# 2-th start
# theta=[0.7614843],P=[[5.77524969e-08+5.29395592e-24j]]
# Inital likelihood = -689.5792665882861
# Iteration=1
# new_angles=[0.7614843]
# new_P:
# [[0.00010045+0.j]]
# likelihood is -689.5759541508345 on iteration 1.
# Iteration=2
# new_angles=[0.75084161]
# new_P:
# [[0.00020055+0.j]]
# likelihood is -689.5690248600367 on iteration 2.
# Iteration=3
# new_angles=[0.74180666]
# new_P:
# [[0.00030109+0.j]]
# likelihood is -689.5589508075494 on iteration 3.
# Iteration=4
# new_angles=[0.7341747]
# new_P:
# [[0.00040262+0.j]]
# likelihood is -689.546657310612 on iteration 4.
# Iteration=5
# new_angles=[0.72790225]
# new_P:
# [[0.00050586+0.j]]
# likelihood is -689.5331525268239 on iteration 5.
# Iteration=6
# new_angles=[0.72300008]
# new_P:
# [[0.00061159+0.j]]
# likelihood is -689.519241443416 on iteration 6.
# Iteration=7
# new_angles=[0.7190444]
# new_P:
# [[0.00072067+0.j]]
# likelihood is -689.5050450738587 on iteration 7.
# Iteration=8
# new_angles=[0.71576318]
# new_P:
# [[0.00083402+0.j]]
# likelihood is -689.4905399852585 on iteration 8.
# Iteration=9
# new_angles=[0.71313672]
# new_P:
# [[0.00095274+0.j]]
# likelihood is -689.4757538364056 on iteration 9.
# Iteration=10
# new_angles=[0.71097201]
# new_P:
# [[0.00107807+0.j]]
# likelihood is -689.4604775666742 on iteration 10.
# Iteration=11
# new_angles=[0.70920125]
# new_P:
# [[0.00121148+0.j]]
# likelihood is -689.4445329330883 on iteration 11.
# Iteration=12
# new_angles=[0.70777721]
# new_P:
# [[0.00135479+0.j]]
# likelihood is -689.4276974927418 on iteration 12.
# Iteration=13
# new_angles=[0.70656926]
# new_P:
# [[0.00151022+0.j]]
# likelihood is -689.4096418226192 on iteration 13.
# Iteration=14
# new_angles=[0.70556591]
# new_P:
# [[0.00168056+0.j]]
# likelihood is -689.3900487799039 on iteration 14.
# Iteration=15
# new_angles=[0.70472866]
# new_P:
# [[0.0018694+0.j]]
# likelihood is -689.3684980098003 on iteration 15.
# Iteration=16
# new_angles=[0.70404714]
# new_P:
# [[0.00208136+0.j]]
# likelihood is -689.3444674286045 on iteration 16.
# Iteration=17
# new_angles=[0.70349884]
# new_P:
# [[0.0023226+0.j]]
# likelihood is -689.3172661312005 on iteration 17.
# Iteration=18
# new_angles=[0.70302192]
# new_P:
# [[0.0026014+0.j]]
# likelihood is -689.2859562103438 on iteration 18.
# Iteration=19
# new_angles=[0.70264735]
# new_P:
# [[0.00292928+0.j]]
# likelihood is -689.2492965443075 on iteration 19.
# Iteration=20
# new_angles=[0.70233068]
# new_P:
# [[0.00332254+0.j]]
# likelihood is -689.2054995137876 on iteration 20.
# 3-th start
# theta=[0.83255839],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688437123
# Iteration=1
# new_angles=[0.83255839]
# new_P:
# [[0.00010042+0.j]]
# likelihood is -689.5799863001762 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 4-th start
# theta=[0.73004403],P=[[6.95706666e-08-3.30872245e-25j]]
# Inital likelihood = -689.5792623721018
# Iteration=1
# new_angles=[0.73004403]
# new_P:
# [[0.00010048+0.j]]
# likelihood is -689.5704295427246 on iteration 1.
# Iteration=2
# new_angles=[0.72444645]
# new_P:
# [[0.00020067+0.j]]
# likelihood is -689.5599332705547 on iteration 2.
# Iteration=3
# new_angles=[0.72016091]
# new_P:
# [[0.00030154+0.j]]
# likelihood is -689.5485485489918 on iteration 3.
# Iteration=4
# new_angles=[0.71655268]
# new_P:
# [[0.00040365+0.j]]
# likelihood is -689.5365588400466 on iteration 4.
# Iteration=5
# new_angles=[0.71364574]
# new_P:
# [[0.00050764+0.j]]
# likelihood is -689.5242201752494 on iteration 5.
# Iteration=6
# new_angles=[0.71134634]
# new_P:
# [[0.00061423+0.j]]
# likelihood is -689.5116102134241 on iteration 6.
# Iteration=7
# new_angles=[0.70950672]
# new_P:
# [[0.0007242+0.j]]
# likelihood is -689.4986840844683 on iteration 7.
# Iteration=8
# new_angles=[0.70790207]
# new_P:
# [[0.00083847+0.j]]
# likelihood is -689.4853037581923 on iteration 8.
# Iteration=9
# new_angles=[0.70662058]
# new_P:
# [[0.00095812+0.j]]
# likelihood is -689.471418198931 on iteration 9.
# Iteration=10
# new_angles=[0.70560339]
# new_P:
# [[0.00108438+0.j]]
# likelihood is -689.4568768547032 on iteration 10.
# Iteration=11
# new_angles=[0.70473384]
# new_P:
# [[0.00121875+0.j]]
# likelihood is -689.4414762039984 on iteration 11.
# Iteration=12
# new_angles=[0.70405231]
# new_P:
# [[0.00136308+0.j]]
# likelihood is -689.4250278079476 on iteration 12.
# Iteration=13
# new_angles=[0.70350401]
# new_P:
# [[0.00151961+0.j]]
# likelihood is -689.4072616486976 on iteration 13.
# Iteration=14
# new_angles=[0.70310027]
# new_P:
# [[0.00169119+0.j]]
# likelihood is -689.3878638690093 on iteration 14.
# Iteration=15
# new_angles=[0.70271237]
# new_P:
# [[0.00188145+0.j]]
# likelihood is -689.3663987516563 on iteration 15.
# Iteration=16
# new_angles=[0.70235181]
# new_P:
# [[0.00209511+0.j]]
# likelihood is -689.3423514407949 on iteration 16.
# Iteration=17
# new_angles=[0.70212403]
# new_P:
# [[0.00233843+0.j]]
# likelihood is -689.3150588165557 on iteration 17.
# Iteration=18
# new_angles=[0.7018963]
# new_P:
# [[0.00261984+0.j]]
# likelihood is -689.2835673688384 on iteration 18.
# Iteration=19
# new_angles=[0.70169581]
# new_P:
# [[0.00295108+0.j]]
# likelihood is -689.2466084856075 on iteration 19.
# Iteration=20
# new_angles=[0.70153918]
# new_P:
# [[0.00334882+0.j]]
# likelihood is -689.2023800446891 on iteration 20.
# 5-th start
# theta=[0.7029336],P=[[1.77615171e-07-2.64697796e-24j]]
# Inital likelihood = -689.579248242526
# Iteration=1
# new_angles=[0.7029336]
# new_P:
# [[0.00010189+0.j]]
# likelihood is -689.5676552044063 on iteration 1.
# Iteration=2
# new_angles=[0.7025592]
# new_P:
# [[0.00020215+0.j]]
# likelihood is -689.5562289370833 on iteration 2.
# Iteration=3
# new_angles=[0.70218493]
# new_P:
# [[0.00030316+0.j]]
# likelihood is -689.5447186077594 on iteration 3.
# Iteration=4
# new_angles=[0.70181077]
# new_P:
# [[0.00040549+0.j]]
# likelihood is -689.5330638137063 on iteration 4.
# Iteration=5
# new_angles=[0.7015831]
# new_P:
# [[0.00050976+0.j]]
# likelihood is -689.5212013521705 on iteration 5.
# Iteration=6
# new_angles=[0.70136837]
# new_P:
# [[0.00061666+0.j]]
# likelihood is -689.5090506287391 on iteration 6.
# Iteration=7
# new_angles=[0.70131399]
# new_P:
# [[0.00072696+0.j]]
# likelihood is -689.4965274300723 on iteration 7.
# Iteration=8
# new_angles=[0.70125961]
# new_P:
# [[0.00084159+0.j]]
# likelihood is -689.483526157929 on iteration 8.
# Iteration=9
# new_angles=[0.70120523]
# new_P:
# [[0.0009616+0.j]]
# likelihood is -689.4699282724284 on iteration 9.
# Iteration=10
# new_angles=[0.70115085]
# new_P:
# [[0.00108824+0.j]]
# likelihood is -689.4555935411108 on iteration 10.
# Iteration=11
# new_angles=[0.70108304]
# new_P:
# [[0.00122303+0.j]]
# likelihood is -689.4403533791511 on iteration 11.
# Iteration=12
# new_angles=[0.70102867]
# new_P:
# [[0.00136781+0.j]]
# likelihood is -689.4240037879758 on iteration 12.
# Iteration=13
# new_angles=[0.70098805]
# new_P:
# [[0.00152485+0.j]]
# likelihood is -689.4062919288734 on iteration 13.
# Iteration=14
# new_angles=[0.70093369]
# new_P:
# [[0.00169703+0.j]]
# likelihood is -689.3869002716827 on iteration 14.
# Iteration=15
# new_angles=[0.70089307]
# new_P:
# [[0.00188801+0.j]]
# likelihood is -689.3654255930815 on iteration 15.
# Iteration=16
# new_angles=[0.70089307]
# new_P:
# [[0.00210254+0.j]]
# likelihood is -689.3413447860951 on iteration 16.
# Iteration=17
# new_angles=[0.70089307]
# new_P:
# [[0.00234692+0.j]]
# likelihood is -689.3139658470445 on iteration 17.
# Iteration=18
# new_angles=[0.70088911]
# new_P:
# [[0.00262971+0.j]]
# likelihood is -689.2823563031297 on iteration 18.
# Iteration=19
# new_angles=[0.70088911]
# new_P:
# [[0.00296272+0.j]]
# likelihood is -689.2452292804061 on iteration 19.
# Iteration=20
# new_angles=[0.70088911]
# new_P:
# [[0.00336283+0.j]]
# likelihood is -689.2007606897392 on iteration 20.
# 6-th start
# theta=[0.73079862],P=[[6.86735671e-08-2.97785021e-24j]]
# Inital likelihood = -689.5792625347437
# Iteration=1
# new_angles=[0.73079862]
# new_P:
# [[0.00010047+0.j]]
# likelihood is -689.570552543065 on iteration 1.
# Iteration=2
# new_angles=[0.72556506]
# new_P:
# [[0.00020067+0.j]]
# likelihood is -689.5602527591172 on iteration 2.
# Iteration=3
# new_angles=[0.72100555]
# new_P:
# [[0.00030152+0.j]]
# likelihood is -689.5488608356081 on iteration 3.
# Iteration=4
# new_angles=[0.71735119]
# new_P:
# [[0.00040361+0.j]]
# likelihood is -689.5368939003016 on iteration 4.
# Iteration=5
# new_angles=[0.714384]
# new_P:
# [[0.00050758+0.j]]
# likelihood is -689.5245487182691 on iteration 5.
# Iteration=6
# new_angles=[0.71189446]
# new_P:
# [[0.00061413+0.j]]
# likelihood is -689.5118606102411 on iteration 6.
# Iteration=7
# new_angles=[0.7099204]
# new_P:
# [[0.00072407+0.j]]
# likelihood is -689.4988754559827 on iteration 7.
# Iteration=8
# new_angles=[0.70831196]
# new_P:
# [[0.00083832+0.j]]
# likelihood is -689.4854888852753 on iteration 8.
# Iteration=9
# new_angles=[0.70697216]
# new_P:
# [[0.00095793+0.j]]
# likelihood is -689.4715747714902 on iteration 9.
# Iteration=10
# new_angles=[0.70585089]
# new_P:
# [[0.00108416+0.j]]
# likelihood is -689.4569906353066 on iteration 10.
# Iteration=11
# new_angles=[0.70498115]
# new_P:
# [[0.0012185+0.j]]
# likelihood is -689.4415870338663 on iteration 11.
# Iteration=12
# new_angles=[0.70424803]
# new_P:
# [[0.00136279+0.j]]
# likelihood is -689.4251205882903 on iteration 12.
# Iteration=13
# new_angles=[0.70369964]
# new_P:
# [[0.00151929+0.j]]
# likelihood is -689.4073547263778 on iteration 13.
# Iteration=14
# new_angles=[0.70321943]
# new_P:
# [[0.00169082+0.j]]
# likelihood is -689.3879378755745 on iteration 14.
# Iteration=15
# new_angles=[0.70280732]
# new_P:
# [[0.00188103+0.j]]
# likelihood is -689.3664697513801 on iteration 15.
# Iteration=16
# new_angles=[0.70244673]
# new_P:
# [[0.00209464+0.j]]
# likelihood is -689.3424267957765 on iteration 16.
# Iteration=17
# new_angles=[0.70216757]
# new_P:
# [[0.00233787+0.j]]
# likelihood is -689.3151299133018 on iteration 17.
# Iteration=18
# new_angles=[0.70195328]
# new_P:
# [[0.0026192+0.j]]
# likelihood is -689.2836503826071 on iteration 18.
# Iteration=19
# new_angles=[0.70173902]
# new_P:
# [[0.00295032+0.j]]
# likelihood is -689.2467009067956 on iteration 19.
# Iteration=20
# new_angles=[0.70157919]
# new_P:
# [[0.0033479+0.j]]
# likelihood is -689.2024884105788 on iteration 20.
# 7-th start
# theta=[0.83991537],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579268841746
# Iteration=1
# new_angles=[0.83991537]
# new_P:
# [[0.00010043+0.j]]
# likelihood is -689.5799823206631 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 8-th start
# theta=[0.86805869],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688779773
# Iteration=1
# new_angles=[0.86214407]
# new_P:
# [[0.00010044+0.j]]
# likelihood is -689.5800339235634 on iteration 1.
# Accumulation of floating-point errors, likelihood started to decrease!
# 9-th start
# theta=[0.74591953],P=[[4.89913064e-08-9.92616735e-25j]]
# Inital likelihood = -689.5792655524413
# Iteration=1
# new_angles=[0.74591953]
# new_P:
# [[0.0001003+0.j]]
# likelihood is -689.5732474781139 on iteration 1.
# Iteration=2
# new_angles=[0.73759899]
# new_P:
# [[0.00020044+0.j]]
# likelihood is -689.5642170792968 on iteration 2.
# Iteration=3
# new_angles=[0.73065141]
# new_P:
# [[0.00030115+0.j]]
# likelihood is -689.553094568491 on iteration 3.
# Iteration=4
# new_angles=[0.72505081]
# new_P:
# [[0.00040301+0.j]]
# likelihood is -689.5408152819646 on iteration 4.
# Iteration=5
# new_angles=[0.72058686]
# new_P:
# [[0.00050668+0.j]]
# likelihood is -689.527956612107 on iteration 5.
# Iteration=6
# new_angles=[0.71701847]
# new_P:
# [[0.00061291+0.j]]
# likelihood is -689.5147673221338 on iteration 6.
# Iteration=7
# new_angles=[0.71406604]
# new_P:
# [[0.0007225+0.j]]
# likelihood is -689.5012511665467 on iteration 7.
# Iteration=8
# new_angles=[0.71175194]
# new_P:
# [[0.0008364+0.j]]
# likelihood is -689.4874654524001 on iteration 8.
# Iteration=9
# new_angles=[0.70977812]
# new_P:
# [[0.00095565+0.j]]
# likelihood is -689.473187373398 on iteration 9.
# Iteration=10
# new_angles=[0.70817309]
# new_P:
# [[0.00108152+0.j]]
# likelihood is -689.4583346163134 on iteration 10.
# Iteration=11
# new_angles=[0.7068913]
# new_P:
# [[0.00121549+0.j]]
# likelihood is -689.442728985229 on iteration 11.
# Iteration=12
# new_angles=[0.70584464]
# new_P:
# [[0.00135939+0.j]]
# likelihood is -689.4261260930359 on iteration 12.
# Iteration=13
# new_angles=[0.70498839]
# new_P:
# [[0.00151545+0.j]]
# likelihood is -689.4082547625211 on iteration 13.
# Iteration=14
# new_angles=[0.70429294]
# new_P:
# [[0.0016865+0.j]]
# likelihood is -689.3887867470587 on iteration 14.
# Iteration=15
# new_angles=[0.70372881]
# new_P:
# [[0.00187614+0.j]]
# likelihood is -689.3673088111839 on iteration 15.
# Iteration=16
# new_angles=[0.70324859]
# new_P:
# [[0.00208906+0.j]]
# likelihood is -689.343285353855 on iteration 16.
# Iteration=17
# new_angles=[0.70286064]
# new_P:
# [[0.00233145+0.j]]
# likelihood is -689.3160371505213 on iteration 17.
# Iteration=18
# new_angles=[0.70250003]
# new_P:
# [[0.00261171+0.j]]
# likelihood is -689.2846253022391 on iteration 18.
# Iteration=19
# new_angles=[0.7021834]
# new_P:
# [[0.00294146+0.j]]
# likelihood is -689.2477911266674 on iteration 19.
# Iteration=20
# new_angles=[0.7019691]
# new_P:
# [[0.00333723+0.j]]
# likelihood is -689.2037603448325 on iteration 20.
# 10-th start
# theta=[0.45944132],P=[[5.55659323e-08+3.57342025e-23j]]
# Inital likelihood = -689.5792678138821
# Iteration=1
# new_angles=[0.46489919]
# new_P:
# [[0.00010041+0.j]]
# likelihood is -689.5779288726142 on iteration 1.
# Iteration=2
# new_angles=[0.465992]
# new_P:
# [[0.00020047+0.j]]
# likelihood is -689.576565241105 on iteration 2.
# Iteration=3
# new_angles=[0.46668978]
# new_P:
# [[0.00030073+0.j]]
# likelihood is -689.5751903351342 on iteration 3.
# Iteration=4
# new_angles=[0.4673153]
# new_P:
# [[0.00040138+0.j]]
# likelihood is -689.5738014820536 on iteration 4.
# Iteration=5
# new_angles=[0.46786503]
# new_P:
# [[0.00050263+0.j]]
# likelihood is -689.5723995250046 on iteration 5.
# Iteration=6
# new_angles=[0.4684058]
# new_P:
# [[0.00060474+0.j]]
# likelihood is -689.5709801945934 on iteration 6.
# Iteration=7
# new_angles=[0.46882982]
# new_P:
# [[0.00070801+0.j]]
# likelihood is -689.5695471873447 on iteration 7.
# Iteration=8
# new_angles=[0.46925486]
# new_P:
# [[0.00081278+0.j]]
# likelihood is -689.5680907752017 on iteration 8.
# Iteration=9
# new_angles=[0.46959803]
# new_P:
# [[0.00091947+0.j]]
# likelihood is -689.5666116784029 on iteration 9.
# Iteration=10
# new_angles=[0.46994127]
# new_P:
# [[0.00102853+0.j]]
# likelihood is -689.565099430992 on iteration 10.
# Iteration=11
# new_angles=[0.47026777]
# new_P:
# [[0.00114047+0.j]]
# likelihood is -689.5635485852027 on iteration 11.
# Iteration=12
# new_angles=[0.47053527]
# new_P:
# [[0.00125592+0.j]]
# likelihood is -689.5619544565254 on iteration 12.
# Iteration=13
# new_angles=[0.47080919]
# new_P:
# [[0.00137558+0.j]]
# likelihood is -689.5603035844579 on iteration 13.
# Iteration=14
# new_angles=[0.47104832]
# new_P:
# [[0.00150025+0.j]]
# likelihood is -689.5585883288327 on iteration 14.
# Iteration=15
# new_angles=[0.47128748]
# new_P:
# [[0.0016309+0.j]]
# likelihood is -689.5567938387043 on iteration 15.
# Iteration=16
# new_angles=[0.47152667]
# new_P:
# [[0.00176866+0.j]]
# likelihood is -689.5549054836924 on iteration 16.
# Iteration=17
# new_angles=[0.47172911]
# new_P:
# [[0.00191485+0.j]]
# likelihood is -689.5529085350923 on iteration 17.
# Iteration=18
# new_angles=[0.47191167]
# new_P:
# [[0.00207109+0.j]]
# likelihood is -689.5507809912284 on iteration 18.
# Iteration=19
# new_angles=[0.47206231]
# new_P:
# [[0.00223931+0.j]]
# likelihood is -689.548498621641 on iteration 19.
# Iteration=20
# new_angles=[0.47218579]
# new_P:
# [[0.0024219+0.j]]
# likelihood is -689.5460305217726 on iteration 20.
# 11-th start
# theta=[0.49094045],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.579267869759
# Iteration=1
# new_angles=[0.49094045]
# new_P:
# [[0.0001004+0.j]]
# likelihood is -689.577984178447 on iteration 1.
# Iteration=2
# new_angles=[0.49008754]
# new_P:
# [[0.00020046+0.j]]
# likelihood is -689.5766881841694 on iteration 2.
# Iteration=3
# new_angles=[0.48953697]
# new_P:
# [[0.00030072+0.j]]
# likelihood is -689.575383193415 on iteration 3.
# Iteration=4
# new_angles=[0.48898102]
# new_P:
# [[0.00040135+0.j]]
# likelihood is -689.5740634416019 on iteration 4.
# Iteration=5
# new_angles=[0.488428]
# new_P:
# [[0.00050258+0.j]]
# likelihood is -689.5727264474824 on iteration 5.
# Iteration=6
# new_angles=[0.48787515]
# new_P:
# [[0.00060466+0.j]]
# likelihood is -689.5713688891043 on iteration 6.
# Iteration=7
# new_angles=[0.48732246]
# new_P:
# [[0.00070789+0.j]]
# likelihood is -689.5699870070889 on iteration 7.
# Iteration=8
# new_angles=[0.48676993]
# new_P:
# [[0.00081261+0.j]]
# likelihood is -689.568576458351 on iteration 8.
# Iteration=9
# new_angles=[0.48622032]
# new_P:
# [[0.00091922+0.j]]
# likelihood is -689.5671325014782 on iteration 9.
# Iteration=10
# new_angles=[0.48574756]
# new_P:
# [[0.00102819+0.j]]
# likelihood is -689.5656570764211 on iteration 10.
# Iteration=11
# new_angles=[0.48519825]
# new_P:
# [[0.00114002+0.j]]
# likelihood is -689.5641284355687 on iteration 11.
# Iteration=12
# new_angles=[0.4846491]
# new_P:
# [[0.00125534+0.j]]
# likelihood is -689.5625461079527 on iteration 12.
# Iteration=13
# new_angles=[0.48417673]
# new_P:
# [[0.00137485+0.j]]
# likelihood is -689.560911022976 on iteration 13.
# Iteration=14
# new_angles=[0.48373389]
# new_P:
# [[0.00149935+0.j]]
# likelihood is -689.5592081933255 on iteration 14.
# Iteration=15
# new_angles=[0.48326174]
# new_P:
# [[0.0016298+0.j]]
# likelihood is -689.5574176024675 on iteration 15.
# Iteration=16
# new_angles=[0.48290672]
# new_P:
# [[0.00176732+0.j]]
# likelihood is -689.5555462455723 on iteration 16.
# Iteration=17
# new_angles=[0.48243478]
# new_P:
# [[0.00191325+0.j]]
# likelihood is -689.5535424818438 on iteration 17.
# Iteration=18
# new_angles=[0.48207991]
# new_P:
# [[0.00206919+0.j]]
# likelihood is -689.5514218533242 on iteration 18.
# Iteration=19
# new_angles=[0.48176936]
# new_P:
# [[0.00223706+0.j]]
# likelihood is -689.5491495430756 on iteration 19.
# Iteration=20
# new_angles=[0.48145886]
# new_P:
# [[0.00241924+0.j]]
# likelihood is -689.5466882309684 on iteration 20.
# 12-th start
# theta=[0.61180126],P=[[8.06311518e-08-5.29395592e-24j]]
# Inital likelihood = -689.5792664814606
# Iteration=1
# new_angles=[0.61027297]
# new_P:
# [[0.00010076+0.j]]
# likelihood is -689.5767463732176 on iteration 1.
# Iteration=2
# new_angles=[0.61027297]
# new_P:
# [[0.00020084+0.j]]
# likelihood is -689.5742441349797 on iteration 2.
# Iteration=3
# new_angles=[0.60993722]
# new_P:
# [[0.00030119+0.j]]
# likelihood is -689.5717305169677 on iteration 3.
# Iteration=4
# new_angles=[0.60971492]
# new_P:
# [[0.00040202+0.j]]
# likelihood is -689.569205353551 on iteration 4.
# Iteration=5
# new_angles=[0.60937929]
# new_P:
# [[0.00050361+0.j]]
# likelihood is -689.5666547063884 on iteration 5.
# Iteration=6
# new_angles=[0.60904375]
# new_P:
# [[0.00060625+0.j]]
# likelihood is -689.5640728284787 on iteration 6.
# Iteration=7
# new_angles=[0.60870828]
# new_P:
# [[0.0007103+0.j]]
# likelihood is -689.5614501193945 on iteration 7.
# Iteration=8
# new_angles=[0.6082767]
# new_P:
# [[0.00081614+0.j]]
# likelihood is -689.5587660802032 on iteration 8.
# Iteration=9
# new_angles=[0.6077674]
# new_P:
# [[0.00092426+0.j]]
# likelihood is -689.5560040260201 on iteration 9.
# Iteration=10
# new_angles=[0.60724811]
# new_P:
# [[0.00103517+0.j]]
# likelihood is -689.553153245045 on iteration 10.
# Iteration=11
# new_angles=[0.60665663]
# new_P:
# [[0.0011495+0.j]]
# likelihood is -689.550183939933 on iteration 11.
# Iteration=12
# new_angles=[0.60605549]
# new_P:
# [[0.00126795+0.j]]
# likelihood is -689.5470822263494 on iteration 12.
# Iteration=13
# new_angles=[0.60542377]
# new_P:
# [[0.00139136+0.j]]
# likelihood is -689.5438177349373 on iteration 13.
# Iteration=14
# new_angles=[0.60469739]
# new_P:
# [[0.0015207+0.j]]
# likelihood is -689.5403393992193 on iteration 14.
# Iteration=15
# new_angles=[0.60397036]
# new_P:
# [[0.00165713+0.j]]
# likelihood is -689.5366335386435 on iteration 15.
# Iteration=16
# new_angles=[0.60319132]
# new_P:
# [[0.00180204+0.j]]
# likelihood is -689.5326391720953 on iteration 16.
# Iteration=17
# new_angles=[0.60237294]
# new_P:
# [[0.00195708+0.j]]
# likelihood is -689.5283050900857 on iteration 17.
# Iteration=18
# new_angles=[0.60149901]
# new_P:
# [[0.00212431+0.j]]
# likelihood is -689.523556487046 on iteration 18.
# Iteration=19
# new_angles=[0.60061095]
# new_P:
# [[0.00230622+0.j]]
# likelihood is -689.5183337403399 on iteration 19.
# Iteration=20
# new_angles=[0.59967309]
# new_P:
# [[0.00250595+0.j]]
# likelihood is -689.5125189266961 on iteration 20.
# 13-th start
# theta=[0.74517223],P=[[4.99996792e-08+3.97046694e-24j]]
# Inital likelihood = -689.5792654235444
# Iteration=1
# new_angles=[0.74517223]
# new_P:
# [[0.00010031+0.j]]
# likelihood is -689.5731098858369 on iteration 1.
# Iteration=2
# new_angles=[0.73685736]
# new_P:
# [[0.00020045+0.j]]
# likelihood is -689.5639530133606 on iteration 2.
# Iteration=3
# new_angles=[0.73027608]
# new_P:
# [[0.00030118+0.j]]
# likelihood is -689.552910201559 on iteration 3.
# Iteration=4
# new_angles=[0.72467735]
# new_P:
# [[0.00040304+0.j]]
# likelihood is -689.5405996427577 on iteration 4.
# Iteration=5
# new_angles=[0.72039094]
# new_P:
# [[0.00050673+0.j]]
# likelihood is -689.5278314192029 on iteration 5.
# Iteration=6
# new_angles=[0.71681561]
# new_P:
# [[0.00061297+0.j]]
# likelihood is -689.5146336277406 on iteration 6.
# Iteration=7
# new_angles=[0.713908]
# new_P:
# [[0.00072258+0.j]]
# likelihood is -689.5011451943363 on iteration 7.
# Iteration=8
# new_angles=[0.71159422]
# new_P:
# [[0.00083649+0.j]]
# likelihood is -689.4873609743662 on iteration 8.
# Iteration=9
# new_angles=[0.70970672]
# new_P:
# [[0.00095576+0.j]]
# likelihood is -689.4731346158429 on iteration 9.
# Iteration=10
# new_angles=[0.70819107]
# new_P:
# [[0.00108164+0.j]]
# likelihood is -689.4583304811438 on iteration 10.
# Iteration=11
# new_angles=[0.70690605]
# new_P:
# [[0.00121562+0.j]]
# likelihood is -689.4427218850933 on iteration 11.
# Iteration=12
# new_angles=[0.70585937]
# new_P:
# [[0.00135952+0.j]]
# likelihood is -689.4261175758618 on iteration 12.
# Iteration=13
# new_angles=[0.70500311]
# new_P:
# [[0.00151559+0.j]]
# likelihood is -689.4082446627536 on iteration 13.
# Iteration=14
# new_angles=[0.70430765]
# new_P:
# [[0.00168666+0.j]]
# likelihood is -689.388774863002 on iteration 14.
# Iteration=15
# new_angles=[0.70374351]
# new_P:
# [[0.00187631+0.j]]
# likelihood is -689.3672948756707 on iteration 15.
# Iteration=16
# new_angles=[0.70326328]
# new_P:
# [[0.00208925+0.j]]
# likelihood is -689.3432689569373 on iteration 16.
# Iteration=17
# new_angles=[0.70287533]
# new_P:
# [[0.00233167+0.j]]
# likelihood is -689.3160177945931 on iteration 17.
# Iteration=18
# new_angles=[0.70251472]
# new_P:
# [[0.00261196+0.j]]
# likelihood is -689.2846021686611 on iteration 18.
# Iteration=19
# new_angles=[0.70219808]
# new_P:
# [[0.00294175+0.j]]
# likelihood is -689.247763142575 on iteration 19.
# Iteration=20
# new_angles=[0.70197033]
# new_P:
# [[0.00333757+0.j]]
# likelihood is -689.2037225740253 on iteration 20.
# 14-th start
# theta=[0.81529611],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792688264825
# Iteration=1
# new_angles=[0.81529611]
# new_P:
# [[0.0001004+0.j]]
# likelihood is -689.5799507299589 on iteration 1.
# Likelihood is converged!
# 15-th start
# theta=[0.64780331],P=[[8.03558405e-08+0.j]]
# Inital likelihood = -689.5792644427597
# Iteration=1
# new_angles=[0.64780331]
# new_P:
# [[0.00010056+0.j]]
# likelihood is -689.5742001854517 on iteration 1.
# Iteration=2
# new_angles=[0.6527111]
# new_P:
# [[0.00020068+0.j]]
# likelihood is -689.5676677849586 on iteration 2.
# Iteration=3
# new_angles=[0.65772616]
# new_P:
# [[0.00030127+0.j]]
# likelihood is -689.5594213314326 on iteration 3.
# Iteration=4
# new_angles=[0.66267469]
# new_P:
# [[0.00040278+0.j]]
# likelihood is -689.54943568476 on iteration 4.
# Iteration=5
# new_angles=[0.66741789]
# new_P:
# [[0.00050582+0.j]]
# likelihood is -689.5378697878756 on iteration 5.
# Iteration=6
# new_angles=[0.67186691]
# new_P:
# [[0.00061112+0.j]]
# likelihood is -689.5249824955384 on iteration 6.
# Iteration=7
# new_angles=[0.67592866]
# new_P:
# [[0.00071955+0.j]]
# likelihood is -689.5110898772351 on iteration 7.
# Iteration=8
# new_angles=[0.67954942]
# new_P:
# [[0.00083209+0.j]]
# likelihood is -689.496452785868 on iteration 8.
# Iteration=9
# new_angles=[0.68269519]
# new_P:
# [[0.00094986+0.j]]
# likelihood is -689.4812394139717 on iteration 9.
# Iteration=10
# new_angles=[0.68547678]
# new_P:
# [[0.00107414+0.j]]
# likelihood is -689.4653728155936 on iteration 10.
# Iteration=11
# new_angles=[0.68786315]
# new_P:
# [[0.00120645+0.j]]
# likelihood is -689.4488350015209 on iteration 11.
# Iteration=12
# new_angles=[0.68991887]
# new_P:
# [[0.00134858+0.j]]
# likelihood is -689.43142878606 on iteration 12.
# Iteration=13
# new_angles=[0.69166105]
# new_P:
# [[0.00150276+0.j]]
# likelihood is -689.4129272302545 on iteration 13.
# Iteration=14
# new_angles=[0.69309152]
# new_P:
# [[0.00167175+0.j]]
# likelihood is -689.3930327350877 on iteration 14.
# Iteration=15
# new_angles=[0.69430758]
# new_P:
# [[0.00185906+0.j]]
# likelihood is -689.37127292226 on iteration 15.
# Iteration=16
# new_angles=[0.69536589]
# new_P:
# [[0.00206926+0.j]]
# likelihood is -689.3470991833793 on iteration 16.
# Iteration=17
# new_angles=[0.69625263]
# new_P:
# [[0.00230839+0.j]]
# likelihood is -689.3198554212297 on iteration 17.
# Iteration=18
# new_angles=[0.69700792]
# new_P:
# [[0.00258462+0.j]]
# likelihood is -689.28861526155 on iteration 18.
# Iteration=19
# new_angles=[0.69760439]
# new_P:
# [[0.00290922+0.j]]
# likelihood is -689.2521616658217 on iteration 19.
# Iteration=20
# new_angles=[0.69808552]
# new_P:
# [[0.00329821+0.j]]
# likelihood is -689.208727253109 on iteration 20.
# 16-th start
# theta=[0.22711654],P=[[4.8828125e-08+0.j]]
# Inital likelihood = -689.5792687212914
# Iteration=1
# new_angles=[0.22711654]
# new_P:
# [[0.00010041+0.j]]
# likelihood is -689.5797345820387 on iteration 1.
# Likelihood is converged!
# 17-th start
# theta=[0.45039062],P=[[4.93435618e-08-4.76456033e-23j]]
# Inital likelihood = -689.579268038814
# Iteration=1
# new_angles=[0.45039062]
# new_P:
# [[0.00010032+0.j]]
# likelihood is -689.5783422772163 on iteration 1.
# Iteration=2
# new_angles=[0.45271134]
# new_P:
# [[0.00020037+0.j]]
# likelihood is -689.5772384738892 on iteration 2.
# Iteration=3
# new_angles=[0.45488441]
# new_P:
# [[0.00030061+0.j]]
# likelihood is -689.5759954425216 on iteration 3.
# Iteration=4
# new_angles=[0.45671665]
# new_P:
# [[0.00040121+0.j]]
# likelihood is -689.5746710585184 on iteration 4.
# Iteration=5
# new_angles=[0.45834308]
# new_P:
# [[0.0005024+0.j]]
# likelihood is -689.573283479316 on iteration 5.
# Iteration=6
# new_angles=[0.4596701]
# new_P:
# [[0.00060442+0.j]]
# likelihood is -689.5718672934815 on iteration 6.
# Iteration=7
# new_angles=[0.46096142]
# new_P:
# [[0.00070759+0.j]]
# likelihood is -689.5703977537383 on iteration 7.
# Iteration=8
# new_angles=[0.46205481]
# new_P:
# [[0.00081226+0.j]]
# likelihood is -689.5689063720016 on iteration 8.
# Iteration=9
# new_angles=[0.46302315]
# new_P:
# [[0.00091882+0.j]]
# likelihood is -689.5673857367093 on iteration 9.
# Iteration=10
# new_angles=[0.46392049]
# new_P:
# [[0.00102773+0.j]]
# likelihood is -689.5658269888064 on iteration 10.
# Iteration=11
# new_angles=[0.46474238]
# new_P:
# [[0.00113953+0.j]]
# likelihood is -689.564228440958 on iteration 11.
# Iteration=12
# new_angles=[0.46552713]
# new_P:
# [[0.00125481+0.j]]
# likelihood is -689.5625788418046 on iteration 12.
# Iteration=13
# new_angles=[0.46622382]
# new_P:
# [[0.00137429+0.j]]
# likelihood is -689.5608805044275 on iteration 13.
# Iteration=14
# new_angles=[0.46683985]
# new_P:
# [[0.00149878+0.j]]
# likelihood is -689.5591233921201 on iteration 14.
# Iteration=15
# new_angles=[0.46738034]
# new_P:
# [[0.00162923+0.j]]
# likelihood is -689.5572955425697 on iteration 15.
# Iteration=16
# new_angles=[0.46785587]
# new_P:
# [[0.00176677+0.j]]
# likelihood is -689.5553814946985 on iteration 16.
# Iteration=17
# new_angles=[0.46833152]
# new_P:
# [[0.00191272+0.j]]
# likelihood is -689.553353265129 on iteration 17.
# Iteration=18
# new_angles=[0.46875553]
# new_P:
# [[0.00206869+0.j]]
# likelihood is -689.551199740958 on iteration 18.
# Iteration=19
# new_angles=[0.46910797]
# new_P:
# [[0.00223661+0.j]]
# likelihood is -689.5488998361737 on iteration 19.
# Iteration=20
# new_angles=[0.46945112]
# new_P:
# [[0.00241885+0.j]]
# likelihood is -689.5464125641763 on iteration 20.
# 18-th start
# theta=[1.57079633],P=[[8.75235434e-08-2.70617725e-23j]]
# Inital likelihood = -689.5792674589636
# Iteration=1
# new_angles=[1.57079633]
# new_P:
# [[0.00010086+0.j]]
# likelihood is -689.5780758869118 on iteration 1.
# Iteration=2
# new_angles=[1.48237918]
# new_P:
# [[0.00020091+0.j]]
# likelihood is -689.576259703996 on iteration 2.
# Iteration=3
# new_angles=[1.45380282]
# new_P:
# [[0.00030119+0.j]]
# likelihood is -689.5740992276841 on iteration 3.
# Iteration=4
# new_angles=[1.4309281]
# new_P:
# [[0.0004019+0.j]]
# likelihood is -689.5715635798231 on iteration 4.
# Iteration=5
# new_angles=[1.41438694]
# new_P:
# [[0.00050331+0.j]]
# likelihood is -689.5688550460029 on iteration 5.
# Iteration=6
# new_angles=[1.40231071]
# new_P:
# [[0.00060575+0.j]]
# likelihood is -689.5660668342027 on iteration 6.
# Iteration=7
# new_angles=[1.39143018]
# new_P:
# [[0.00070957+0.j]]
# likelihood is -689.5631167807026 on iteration 7.
# Iteration=8
# new_angles=[1.38302058]
# new_P:
# [[0.00081519+0.j]]
# likelihood is -689.5601289519317 on iteration 8.
# Iteration=9
# new_angles=[1.37532911]
# new_P:
# [[0.00092309+0.j]]
# likelihood is -689.5570219302772 on iteration 9.
# Iteration=10
# new_angles=[1.36827445]
# new_P:
# [[0.00103381+0.j]]
# likelihood is -689.5538003755343 on iteration 10.
# Iteration=11
# new_angles=[1.36229263]
# new_P:
# [[0.00114798+0.j]]
# likelihood is -689.5505043061249 on iteration 11.
# Iteration=12
# new_angles=[1.35762629]
# new_P:
# [[0.00126632+0.j]]
# likelihood is -689.5471559193189 on iteration 12.
# Iteration=13
# new_angles=[1.35305845]
# new_P:
# [[0.00138966+0.j]]
# likelihood is -689.5436458735353 on iteration 13.
# Iteration=14
# new_angles=[1.34890203]
# new_P:
# [[0.00151898+0.j]]
# likelihood is -689.5399827568805 on iteration 14.
# Iteration=15
# new_angles=[1.3455982]
# new_P:
# [[0.00165543+0.j]]
# likelihood is -689.5361830170116 on iteration 15.
# Iteration=16
# new_angles=[1.34234135]
# new_P:
# [[0.00180038+0.j]]
# likelihood is -689.5321451498012 on iteration 16.
# Iteration=17
# new_angles=[1.33943568]
# new_P:
# [[0.00195549+0.j]]
# likelihood is -689.5278571752377 on iteration 17.
# Iteration=18
# new_angles=[1.33656541]
# new_P:
# [[0.00212277+0.j]]
# likelihood is -689.5232412590796 on iteration 18.
# Iteration=19
# new_angles=[1.33431334]
# new_P:
# [[0.00230468+0.j]]
# likelihood is -689.5182899434421 on iteration 19.
# Iteration=20
# new_angles=[1.33223814]
# new_P:
# [[0.0025043+0.j]]
# likelihood is -689.5128860445923 on iteration 20.
# 19-th start
# theta=[0.75399535],P=[[7.64820505e-08-1.0753348e-24j]]
# Inital likelihood = -689.5792650119403
# Iteration=1
# new_angles=[0.75399535]
# new_P:
# [[0.00010073+0.j]]
# likelihood is -689.5746837109166 on iteration 1.
# Iteration=2
# new_angles=[0.74428431]
# new_P:
# [[0.00020085+0.j]]
# likelihood is -689.5666166828958 on iteration 2.
# Iteration=3
# new_angles=[0.73634751]
# new_P:
# [[0.00030148+0.j]]
# likelihood is -689.5559747188474 on iteration 3.
# Iteration=4
# new_angles=[0.72978016]
# new_P:
# [[0.00040318+0.j]]
# likelihood is -689.5436793261199 on iteration 4.
# Iteration=5
# new_angles=[0.72450988]
# new_P:
# [[0.00050664+0.j]]
# likelihood is -689.5305635972181 on iteration 5.
# Iteration=6
# new_angles=[0.72022409]
# new_P:
# [[0.00061262+0.j]]
# likelihood is -689.516988051402 on iteration 6.
# Iteration=7
# new_angles=[0.71675002]
# new_P:
# [[0.00072197+0.j]]
# likelihood is -689.5031276025671 on iteration 7.
# Iteration=8
# new_angles=[0.7139323]
# new_P:
# [[0.0008356+0.j]]
# likelihood is -689.4889862048127 on iteration 8.
# Iteration=9
# new_angles=[0.71161846]
# new_P:
# [[0.0009546+0.j]]
# likelihood is -689.4744530369394 on iteration 9.
# Iteration=10
# new_angles=[0.70968901]
# new_P:
# [[0.00108022+0.j]]
# likelihood is -689.4593670650759 on iteration 10.
# Iteration=11
# new_angles=[0.70817338]
# new_P:
# [[0.00121393+0.j]]
# likelihood is -689.44360509325 on iteration 11.
# Iteration=12
# new_angles=[0.70689159]
# new_P:
# [[0.00135756+0.j]]
# likelihood is -689.4268625813638 on iteration 12.
# Iteration=13
# new_angles=[0.70584493]
# new_P:
# [[0.00151334+0.j]]
# likelihood is -689.4088941821343 on iteration 13.
# Iteration=14
# new_angles=[0.70498868]
# new_P:
# [[0.00168409+0.j]]
# likelihood is -689.3893610971892 on iteration 14.
# Iteration=15
# new_angles=[0.70426403]
# new_P:
# [[0.00187338+0.j]]
# likelihood is -689.3678347381922 on iteration 15.
# Iteration=16
# new_angles=[0.70371563]
# new_P:
# [[0.0020859+0.j]]
# likelihood is -689.343816215321 on iteration 16.
# Iteration=17
# new_angles=[0.70323542]
# new_P:
# [[0.0023278+0.j]]
# likelihood is -689.3165786593755 on iteration 17.
# Iteration=18
# new_angles=[0.70280732]
# new_P:
# [[0.00260744+0.j]]
# likelihood is -689.2852025134453 on iteration 18.
# Iteration=19
# new_angles=[0.7024874]
# new_P:
# [[0.0029364+0.j]]
# likelihood is -689.2484474683052 on iteration 19.
# Iteration=20
# new_angles=[0.70217077]
# new_P:
# [[0.00333111+0.j]]
# likelihood is -689.2044967018061 on iteration 20.
# best_start=5
# Время выполнения функции: 62.340767 секунд

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.70088911]), array([[0.00336283+0.j]]))

# %%
lf.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q2), lf.incomplete_lkhd(X2_with_mv, theta2_rad, P2, Q2)
# Out:
# (np.float64(-689.2007606897392), np.float64(-673.6467390084401))
