# %%
import numpy as np

import diff_sensor_structures
import sensors
import em_stoch
import subspace_methods

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 25
Num_emitters1 = 1
sample_size1 = 12
failing_sensors1 = np.array([0, 1, 2, 3, 4], dtype=np.int16)
gap_ratio1 = np.array([0.5, 0.5, 0.5, 0.5, 0.5], dtype=np.float32)
theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P_1 = 0.5 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q_1 = 8.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
N1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + N1.T).T
X1_with_mv = sensors.MCAR(X1, failing_sensors1, gap_ratio1)
R1 = sensors.initial_Cov(X1_with_mv)
MUSIC_theta1 = subspace_methods.MUSIC_DoA(R1, Num_emitters1)

# %%
MUSIC_theta1
# Out:
# array([0.71558499])

# %%
sensors.SNR(A1, P_1, Q_1, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(1.54320987654321)

# %%
EM_theta1_rad, EM_P1, lhd_1, lhd_list1, angles_list1 = em_stoch.multistart_EM2(X1_with_mv, 
                                                                               Num_emitters1, 
                                                                               Q=Q_1,
                                                                               MUSIC_theta=MUSIC_theta1, 
                                                                               num_of_starts=10, 
                                                                               max_iter=20, 
                                                                               rtol=1e-5)
# Out:
# 0-th start
# theta=[0.80378761],P=[[4.8828125e-08+0.j]]
# new_angles=[0.80378761]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -870.4013699741913 on iteration 0
# new_angles=[0.80378761]
# new_P:
# [[0.002+0.j]]
# 1-th start
# theta=[0.62809672],P=[[6.82086539e-08+0.j]]
# new_angles=[0.62809672]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3703510235397 on iteration 0
# new_angles=[0.63652529]
# new_P:
# [[0.00200259+0.j]]
# likelihood is -870.3229202992447 on iteration 1
# new_angles=[0.64351668]
# new_P:
# [[0.00301676+0.j]]
# likelihood is -870.2574883963157 on iteration 2
# new_angles=[0.64915417]
# new_P:
# [[0.00405798+0.j]]
# likelihood is -870.1767514850162 on iteration 3
# new_angles=[0.65527209]
# new_P:
# [[0.00514762+0.j]]
# likelihood is -870.0713184156422 on iteration 4
# new_angles=[0.66020812]
# new_P:
# [[0.00631826+0.j]]
# likelihood is -869.9518196120267 on iteration 5
# new_angles=[0.66584631]
# new_P:
# [[0.00760901+0.j]]
# likelihood is -869.8012138725377 on iteration 6
# new_angles=[0.67042794]
# new_P:
# [[0.00908209+0.j]]
# likelihood is -869.6336769848124 on iteration 7
# new_angles=[0.67452948]
# new_P:
# [[0.01081419+0.j]]
# likelihood is -869.439905173139 on iteration 8
# new_angles=[0.67785858]
# new_P:
# [[0.01292041+0.j]]
# likelihood is -869.2156877865646 on iteration 9
# new_angles=[0.68091942]
# new_P:
# [[0.01557261+0.j]]
# likelihood is -868.9415995492491 on iteration 10
# new_angles=[0.68368617]
# new_P:
# [[0.01905432+0.j]]
# likelihood is -868.5951136655833 on iteration 11
# new_angles=[0.68582747]
# new_P:
# [[0.02384983+0.j]]
# likelihood is -868.1425648582203 on iteration 12
# new_angles=[0.68772176]
# new_P:
# [[0.03083451+0.j]]
# likelihood is -867.5139614403472 on iteration 13
# new_angles=[0.68930259]
# new_P:
# [[0.04173702+0.j]]
# likelihood is -866.5937452615385 on iteration 14
# new_angles=[0.69056874]
# new_P:
# [[0.06024589+0.j]]
# likelihood is -865.1723346711963 on iteration 15
# new_angles=[0.6916065]
# new_P:
# [[0.09494137+0.j]]
# likelihood is -862.8935576631707 on iteration 16
# new_angles=[0.69249951]
# new_P:
# [[0.16704572+0.j]]
# likelihood is -859.3378283046562 on iteration 17
# new_angles=[0.69321344]
# new_P:
# [[0.3264501+0.j]]
# likelihood is -854.7789294240926 on iteration 18
# new_angles=[0.69378937]
# new_P:
# [[0.64881776+0.j]]
# likelihood is -851.3095823518696 on iteration 19
# 2-th start
# theta=[0.64303758],P=[[1.11433171e-07-5.95570041e-24j]]
# new_angles=[0.64303758]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3537914015952 on iteration 0
# new_angles=[0.64587575]
# new_P:
# [[0.00200397+0.j]]
# likelihood is -870.2988610720574 on iteration 1
# new_angles=[0.6531849]
# new_P:
# [[0.00302215+0.j]]
# likelihood is -870.2154646730075 on iteration 2
# new_angles=[0.65811298]
# new_P:
# [[0.00407394+0.j]]
# likelihood is -870.121830051033 on iteration 3
# new_angles=[0.66408785]
# new_P:
# [[0.00518241+0.j]]
# likelihood is -870.0019721963126 on iteration 4
# new_angles=[0.66905798]
# new_P:
# [[0.00638388+0.j]]
# likelihood is -869.8680513529544 on iteration 5
# new_angles=[0.67333986]
# new_P:
# [[0.00772192+0.j]]
# likelihood is -869.7182342140886 on iteration 6
# new_angles=[0.67725608]
# new_P:
# [[0.00925553+0.j]]
# likelihood is -869.5472302225929 on iteration 7
# new_angles=[0.68052412]
# new_P:
# [[0.01106923+0.j]]
# likelihood is -869.3520932947715 on iteration 8
# new_angles=[0.68305552]
# new_P:
# [[0.01328525+0.j]]
# likelihood is -869.1243291171731 on iteration 9
# new_angles=[0.6853296]
# new_P:
# [[0.01609122+0.j]]
# likelihood is -868.8439908424227 on iteration 10
# new_angles=[0.68729561]
# new_P:
# [[0.01979825+0.j]]
# likelihood is -868.4861495263472 on iteration 11
# new_angles=[0.68895442]
# new_P:
# [[0.02494381+0.j]]
# likelihood is -868.0085418713879 on iteration 12
# new_angles=[0.69025625]
# new_P:
# [[0.03252082+0.j]]
# likelihood is -867.3388104190974 on iteration 13
# new_angles=[0.6914191]
# new_P:
# [[0.04450636+0.j]]
# likelihood is -866.3447475648496 on iteration 14
# new_angles=[0.69237025]
# new_P:
# [[0.06519337+0.j]]
# likelihood is -864.7936201437046 on iteration 15
# new_angles=[0.69311709]
# new_P:
# [[0.10470261+0.j]]
# likelihood is -862.3036321230762 on iteration 16
# new_angles=[0.69372324]
# new_P:
# [[0.18809672+0.j]]
# likelihood is -858.4990382900228 on iteration 17
# new_angles=[0.69421242]
# new_P:
# [[0.3719368+0.j]]
# likelihood is -853.9452894352055 on iteration 18
# new_angles=[0.69460267]
# new_P:
# [[0.72671541+0.j]]
# likelihood is -850.9527482660849 on iteration 19
# 3-th start
# theta=[0.64132648],P=[[1.05540317e-07-2.64697796e-24j]]
# new_angles=[0.64132648]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.3560430120068 on iteration 0
# new_angles=[0.64132648]
# new_P:
# [[0.00200379+0.j]]
# likelihood is -870.3111388895816 on iteration 1
# new_angles=[0.64132648]
# new_P:
# [[0.00301992+0.j]]
# likelihood is -870.2660306722588 on iteration 2
# new_angles=[0.64632502]
# new_P:
# [[0.00405906+0.j]]
# likelihood is -870.19302074438 on iteration 3
# new_angles=[0.6512273]
# new_P:
# [[0.00514329+0.j]]
# likelihood is -870.1023710530011 on iteration 4
# new_angles=[0.65614797]
# new_P:
# [[0.00630065+0.j]]
# likelihood is -869.9908880493226 on iteration 5
# new_angles=[0.66218933]
# new_P:
# [[0.00757031+0.j]]
# likelihood is -869.8433171877068 on iteration 6
# new_angles=[0.66719424]
# new_P:
# [[0.00901457+0.j]]
# likelihood is -869.6772372463543 on iteration 7
# new_angles=[0.6718132]
# new_P:
# [[0.01070833+0.j]]
# likelihood is -869.4828681367617 on iteration 8
# new_angles=[0.67597124]
# new_P:
# [[0.01276442+0.j]]
# likelihood is -869.2538989955572 on iteration 9
# new_angles=[0.67923309]
# new_P:
# [[0.01535348+0.j]]
# likelihood is -868.9837238667781 on iteration 10
# new_angles=[0.68174591]
# new_P:
# [[0.01874151+0.j]]
# likelihood is -868.6499415096935 on iteration 11
# new_angles=[0.68426387]
# new_P:
# [[0.02338073+0.j]]
# likelihood is -868.2062787787124 on iteration 12
# new_angles=[0.686442]
# new_P:
# [[0.03010782+0.j]]
# likelihood is -867.5950449984197 on iteration 13
# new_angles=[0.6881901]
# new_P:
# [[0.040546+0.j]]
# likelihood is -866.7073584208573 on iteration 14
# new_angles=[0.68967936]
# new_P:
# [[0.05813108+0.j]]
# likelihood is -865.3414378036892 on iteration 15
# new_angles=[0.69087674]
# new_P:
# [[0.09081149+0.j]]
# likelihood is -863.1561604289243 on iteration 16
# new_angles=[0.69189316]
# new_P:
# [[0.15819882+0.j]]
# likelihood is -859.7206405321822 on iteration 17
# new_angles=[0.69270686]
# new_P:
# [[0.3070815+0.j]]
# likelihood is -855.1892752844484 on iteration 18
# new_angles=[0.69337041]
# new_P:
# [[0.61378436+0.j]]
# likelihood is -851.516246937224 on iteration 19
# 4-th start
# theta=[0.65905647],P=[[1.72770544e-07-1.09187841e-23j]]
# new_angles=[0.65905647]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -870.3304044487845 on iteration 0
# new_angles=[0.66077756]
# new_P:
# [[0.00200592+0.j]]
# likelihood is -870.2546311700683 on iteration 1
# new_angles=[0.66401656]
# new_P:
# [[0.00303147+0.j]]
# likelihood is -870.1662170872171 on iteration 2
# new_angles=[0.66696406]
# new_P:
# [[0.00409576+0.j]]
# likelihood is -870.067989018604 on iteration 3
# new_angles=[0.67194551]
# new_P:
# [[0.00522304+0.j]]
# likelihood is -869.9441015555043 on iteration 4
# new_angles=[0.67524663]
# new_P:
# [[0.00645111+0.j]]
# likelihood is -869.8141781521991 on iteration 5
# new_angles=[0.67927663]
# new_P:
# [[0.00782168+0.j]]
# likelihood is -869.660691885569 on iteration 6
# new_angles=[0.68212655]
# new_P:
# [[0.00939999+0.j]]
# likelihood is -869.4929013642245 on iteration 7
# new_angles=[0.68452864]
# new_P:
# [[0.01127006+0.j]]
# likelihood is -869.2991911759572 on iteration 8
# new_angles=[0.68664646]
# new_P:
# [[0.0135604+0.j]]
# likelihood is -869.0676717684455 on iteration 9
# new_angles=[0.68845114]
# new_P:
# [[0.01647275+0.j]]
# likelihood is -868.7816261874684 on iteration 10
# new_angles=[0.68988149]
# new_P:
# [[0.02033873+0.j]]
# likelihood is -868.4142803013801 on iteration 11
# new_angles=[0.69114825]
# new_P:
# [[0.02573575+0.j]]
# likelihood is -867.9188364231718 on iteration 12
# new_angles=[0.6920887]
# new_P:
# [[0.03374271+0.j]]
# likelihood is -867.2180717452495 on iteration 13
# new_angles=[0.6928471]
# new_P:
# [[0.04652776+0.j]]
# likelihood is -866.1710593655982 on iteration 14
# new_angles=[0.69348187]
# new_P:
# [[0.06884254+0.j]]
# likelihood is -864.5275127535976 on iteration 15
# new_angles=[0.69403456]
# new_P:
# [[0.11198473+0.j]]
# likelihood is -861.8897960883174 on iteration 16
# new_angles=[0.69445723]
# new_P:
# [[0.20388543+0.j]]
# likelihood is -857.9296520574709 on iteration 17
# new_angles=[0.6948109]
# new_P:
# [[0.40538932+0.j]]
# likelihood is -853.430807050993 on iteration 18
# new_angles=[0.69508903]
# new_P:
# [[0.78025129+0.j]]
# likelihood is -850.7749291175156 on iteration 19
# 5-th start
# theta=[0.69671681],P=[[2.64175428e-07+1.32348898e-24j]]
# new_angles=[0.69671681]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -870.2958123617279 on iteration 0
# new_angles=[0.69671681]
# new_P:
# [[0.0020088+0.j]]
# likelihood is -870.1902915258543 on iteration 1
# new_angles=[0.69671681]
# new_P:
# [[0.00304508+0.j]]
# likelihood is -870.0826252298389 on iteration 2
# new_angles=[0.69671681]
# new_P:
# [[0.00413071+0.j]]
# likelihood is -869.9706249269598 on iteration 3
# new_angles=[0.69671681]
# new_P:
# [[0.00529229+0.j]]
# likelihood is -869.8516773816025 on iteration 4
# new_angles=[0.69666172]
# new_P:
# [[0.00656389+0.j]]
# likelihood is -869.7225000561892 on iteration 5
# new_angles=[0.69666172]
# new_P:
# [[0.00799104+0.j]]
# likelihood is -869.5788095090821 on iteration 6
# new_angles=[0.69666172]
# new_P:
# [[0.00963711+0.j]]
# likelihood is -869.4147410975862 on iteration 7
# new_angles=[0.69666172]
# new_P:
# [[0.01159393+0.j]]
# likelihood is -869.2219824983265 on iteration 8
# new_angles=[0.69666172]
# new_P:
# [[0.01400031+0.j]]
# likelihood is -868.9882826746141 on iteration 9
# new_angles=[0.69666172]
# new_P:
# [[0.01707572+0.j]]
# likelihood is -868.6948611504081 on iteration 10
# new_angles=[0.69662408]
# new_P:
# [[0.0211853+0.j]]
# likelihood is -868.3117059247011 on iteration 11
# new_angles=[0.69659766]
# new_P:
# [[0.02697319+0.j]]
# likelihood is -867.7888059979975 on iteration 12
# new_angles=[0.69658198]
# new_P:
# [[0.03565526+0.j]]
# likelihood is -867.0392535243507 on iteration 13
# new_angles=[0.69656934]
# new_P:
# [[0.0497128+0.j]]
# likelihood is -865.9075231074346 on iteration 14
# new_angles=[0.69656713]
# new_P:
# [[0.07465974+0.j]]
# likelihood is -864.1188415661502 on iteration 15
# new_angles=[0.69652783]
# new_P:
# [[0.12374249+0.j]]
# likelihood is -861.2589174343301 on iteration 16
# new_angles=[0.69651032]
# new_P:
# [[0.22947912+0.j]]
# likelihood is -857.0958697089975 on iteration 17
# new_angles=[0.69646848]
# new_P:
# [[0.45827295+0.j]]
# likelihood is -852.7518654668311 on iteration 18
# new_angles=[0.69644619]
# new_P:
# [[0.85889812+0.j]]
# likelihood is -850.5896372449038 on iteration 19
# 6-th start
# theta=[0.71784892],P=[[1.15423857e-07+2.31610572e-24j]]
# new_angles=[0.71605382]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -870.30694222975 on iteration 0
# new_angles=[0.71170404]
# new_P:
# [[0.00200787+0.j]]
# likelihood is -870.204132104939 on iteration 1
# new_angles=[0.70869914]
# new_P:
# [[0.00304184+0.j]]
# likelihood is -870.0964892001542 on iteration 2
# new_angles=[0.70470151]
# new_P:
# [[0.00412389+0.j]]
# likelihood is -869.9797191084551 on iteration 3
# new_angles=[0.70294099]
# new_P:
# [[0.00528209+0.j]]
# likelihood is -869.8593779432272 on iteration 4
# new_angles=[0.70205931]
# new_P:
# [[0.00654978+0.j]]
# likelihood is -869.7300931073825 on iteration 5
# new_angles=[0.70101715]
# new_P:
# [[0.00797183+0.j]]
# likelihood is -869.585705990004 on iteration 6
# new_angles=[0.70025586]
# new_P:
# [[0.00961164+0.j]]
# likelihood is -869.4214205356485 on iteration 7
# new_angles=[0.69965434]
# new_P:
# [[0.01156033+0.j]]
# likelihood is -869.2288041689421 on iteration 8
# new_angles=[0.69923507]
# new_P:
# [[0.01395557+0.j]]
# likelihood is -868.9958017944092 on iteration 9
# new_angles=[0.69889343]
# new_P:
# [[0.01701472+0.j]]
# likelihood is -868.7036152172872 on iteration 10
# new_angles=[0.69839478]
# new_P:
# [[0.02109926+0.j]]
# likelihood is -868.3219674900687 on iteration 11
# new_angles=[0.69795936]
# new_P:
# [[0.02684697+0.j]]
# likelihood is -867.8017929762505 on iteration 12
# new_angles=[0.6976875]
# new_P:
# [[0.03545943+0.j]]
# likelihood is -867.057285642662 on iteration 13
# new_angles=[0.69741175]
# new_P:
# [[0.04938477+0.j]]
# likelihood is -865.9341408575433 on iteration 14
# new_angles=[0.69722292]
# new_P:
# [[0.07405679+0.j]]
# likelihood is -864.1602809609112 on iteration 15
# new_angles=[0.69706537]
# new_P:
# [[0.12251601+0.j]]
# likelihood is -861.3226740870458 on iteration 16
# new_angles=[0.69694211]
# new_P:
# [[0.22680549+0.j]]
# likelihood is -857.1782305537274 on iteration 17
# new_angles=[0.69682726]
# new_P:
# [[0.45282804+0.j]]
# likelihood is -852.815155235879 on iteration 18
# new_angles=[0.69674291]
# new_P:
# [[0.85111361+0.j]]
# likelihood is -850.6046786338325 on iteration 19
# 7-th start
# theta=[0.70172546],P=[[2.62158203e-07+1.12496563e-23j]]
# new_angles=[0.70172546]
# new_P:
# [[0.00100003+0.j]]
# likelihood is -870.2966599178419 on iteration 0
# new_angles=[0.70172546]
# new_P:
# [[0.00200871+0.j]]
# likelihood is -870.1919945109717 on iteration 1
# new_angles=[0.70172546]
# new_P:
# [[0.00304471+0.j]]
# likelihood is -870.0852236998405 on iteration 2
# new_angles=[0.70172546]
# new_P:
# [[0.00412967+0.j]]
# likelihood is -869.9741929916665 on iteration 3
# new_angles=[0.70161774]
# new_P:
# [[0.00529+0.j]]
# likelihood is -869.8561535449546 on iteration 4
# new_angles=[0.70048721]
# new_P:
# [[0.00655952+0.j]]
# likelihood is -869.726156642292 on iteration 5
# new_angles=[0.69914742]
# new_P:
# [[0.00798439+0.j]]
# likelihood is -869.5812259560398 on iteration 6
# new_angles=[0.6983165]
# new_P:
# [[0.00962827+0.j]]
# likelihood is -869.4166273606886 on iteration 7
# new_angles=[0.69789158]
# new_P:
# [[0.0115826+0.j]]
# likelihood is -869.2238130346553 on iteration 8
# new_angles=[0.69778197]
# new_P:
# [[0.01398566+0.j]]
# likelihood is -868.9904335511266 on iteration 9
# new_angles=[0.6972737]
# new_P:
# [[0.01705609+0.j]]
# likelihood is -868.6970517986769 on iteration 10
# new_angles=[0.69716671]
# new_P:
# [[0.02115845+0.j]]
# likelihood is -868.3144959748165 on iteration 11
# new_angles=[0.69716671]
# new_P:
# [[0.02693447+0.j]]
# likelihood is -867.7926503916311 on iteration 12
# new_angles=[0.69705249]
# new_P:
# [[0.03559544+0.j]]
# likelihood is -867.044660090344 on iteration 13
# new_angles=[0.6969246]
# new_P:
# [[0.04961279+0.j]]
# likelihood is -865.9155600227223 on iteration 14
# new_angles=[0.69682022]
# new_P:
# [[0.07447605+0.j]]
# likelihood is -864.1313631134838 on iteration 15
# new_angles=[0.69672076]
# new_P:
# [[0.12336907+0.j]]
# likelihood is -861.2781720417333 on iteration 16
# new_angles=[0.69665078]
# new_P:
# [[0.22866584+0.j]]
# likelihood is -857.1206761095184 on iteration 17
# new_angles=[0.69659841]
# new_P:
# [[0.45662026+0.j]]
# likelihood is -852.7708297622711 on iteration 18
# new_angles=[0.69655338]
# new_P:
# [[0.85654405+0.j]]
# likelihood is -850.5940332906982 on iteration 19
# 8-th start
# theta=[0.7055677],P=[[2.57996973e-07-6.6174449e-24j]]
# new_angles=[0.7055677]
# new_P:
# [[0.00100001+0.j]]
# likelihood is -870.2983175085549 on iteration 0
# new_angles=[0.70295406]
# new_P:
# [[0.00200855+0.j]]
# likelihood is -870.1928832633805 on iteration 1
# new_angles=[0.70295406]
# new_P:
# [[0.00304441+0.j]]
# likelihood is -870.0865740165401 on iteration 2
# new_angles=[0.7007339]
# new_P:
# [[0.00412902+0.j]]
# likelihood is -869.9730868230484 on iteration 3
# new_angles=[0.69950306]
# new_P:
# [[0.00528969+0.j]]
# likelihood is -869.8534314304273 on iteration 4
# new_angles=[0.69884976]
# new_P:
# [[0.00656038+0.j]]
# likelihood is -869.7239991258316 on iteration 5
# new_angles=[0.6984419]
# new_P:
# [[0.00798647+0.j]]
# likelihood is -869.5802253719764 on iteration 6
# new_angles=[0.6984419]
# new_P:
# [[0.00963119+0.j]]
# likelihood is -869.4164775158852 on iteration 7
# new_angles=[0.69797494]
# new_P:
# [[0.01158598+0.j]]
# likelihood is -869.223568772966 on iteration 8
# new_angles=[0.69793553]
# new_P:
# [[0.01398975+0.j]]
# likelihood is -868.99022100372 on iteration 9
# new_angles=[0.69762147]
# new_P:
# [[0.01706112+0.j]]
# likelihood is -868.6969309307892 on iteration 10
# new_angles=[0.69739591]
# new_P:
# [[0.02116474+0.j]]
# likelihood is -868.3141586229389 on iteration 11
# new_angles=[0.69739591]
# new_P:
# [[0.026943+0.j]]
# likelihood is -867.7921957425137 on iteration 12
# new_angles=[0.69721109]
# new_P:
# [[0.0356078+0.j]]
# likelihood is -867.0438460838158 on iteration 13
# new_angles=[0.69706275]
# new_P:
# [[0.04963263+0.j]]
# likelihood is -865.914244195506 on iteration 14
# new_angles=[0.69698921]
# new_P:
# [[0.07451145+0.j]]
# likelihood is -864.1293212995208 on iteration 15
# new_angles=[0.69687504]
# new_P:
# [[0.12343904+0.j]]
# likelihood is -861.2749561614322 on iteration 16
# new_angles=[0.69677735]
# new_P:
# [[0.22881503+0.j]]
# likelihood is -857.1165221310005 on iteration 17
# new_angles=[0.69670536]
# new_P:
# [[0.45691834+0.j]]
# likelihood is -852.7678302582378 on iteration 18
# new_angles=[0.69663923]
# new_P:
# [[0.8569604+0.j]]
# likelihood is -850.5936317419531 on iteration 19
# 9-th start
# theta=[0.62610695],P=[[6.40458684e-08+0.j]]
# new_angles=[0.62610695]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -870.371955076054 on iteration 0
# new_angles=[0.62610695]
# new_P:
# [[0.00200246+0.j]]
# likelihood is -870.3429653719961 on iteration 1
# new_angles=[0.62988122]
# new_P:
# [[0.0030133+0.j]]
# likelihood is -870.3044839267238 on iteration 2
# new_angles=[0.63472367]
# new_P:
# [[0.00404277+0.j]]
# likelihood is -870.2525876505398 on iteration 3
# new_angles=[0.63958345]
# new_P:
# [[0.00510678+0.j]]
# likelihood is -870.1856432940496 on iteration 4
# new_angles=[0.64529829]
# new_P:
# [[0.00622792+0.j]]
# likelihood is -870.0931778296606 on iteration 5
# new_angles=[0.65093195]
# new_P:
# [[0.00744176+0.j]]
# likelihood is -869.9755991454119 on iteration 6
# new_angles=[0.65720047]
# new_P:
# [[0.00879677+0.j]]
# likelihood is -869.8196961011179 on iteration 7
# new_angles=[0.66269674]
# new_P:
# [[0.0103687+0.j]]
# likelihood is -869.636878356146 on iteration 8
# new_angles=[0.66766144]
# new_P:
# [[0.01225552+0.j]]
# likelihood is -869.4200195461622 on iteration 9
# new_angles=[0.67215448]
# new_P:
# [[0.01460474+0.j]]
# likelihood is -869.1588218998987 on iteration 10
# new_angles=[0.6760415]
# new_P:
# [[0.01764836+0.j]]
# likelihood is -868.8387097230327 on iteration 11
# new_angles=[0.6795157]
# new_P:
# [[0.02176844+0.j]]
# likelihood is -868.4270988978159 on iteration 12
# new_angles=[0.68237868]
# new_P:
# [[0.02764642+0.j]]
# likelihood is -867.876626348572 on iteration 13
# new_angles=[0.68486145]
# new_P:
# [[0.03657103+0.j]]
# likelihood is -867.0925731615653 on iteration 14
# new_angles=[0.68686325]
# new_P:
# [[0.0512105+0.j]]
# likelihood is -865.9129181908836 on iteration 15
# new_angles=[0.68856595]
# new_P:
# [[0.0775643+0.j]]
# likelihood is -864.0425257504032 on iteration 16
# new_angles=[0.68997159]
# new_P:
# [[0.13025384+0.j]]
# likelihood is -861.0494783140482 on iteration 17
# new_angles=[0.69111898]
# new_P:
# [[0.24540011+0.j]]
# likelihood is -856.7509551312158 on iteration 18
# new_angles=[0.69207442]
# new_P:
# [[0.49485348+0.j]]
# likelihood is -852.4796329742435 on iteration 19
# best_start=5

# %%
EM_theta1_rad, EM_P1
# Out:
# (array([0.69644619]), array([[0.85889812+0.j]]))

# %%
em_stoch.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q_1), em_stoch.incomplete_lkhd(X1_with_mv, theta1_rad, P_1, Q_1)
# Out:
# (np.float64(-850.5896372449038), np.float64(-852.4011191641745))

# %%
Num_sensors2 = 25
Num_emitters2 = 1
sample_size2 = 11
failing_sensors2 = np.array([0, 1, 2, 3, 4, 5, 6, 7], dtype=np.int16)
gap_ratio2 = np.array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5], dtype=np.float32)
theta2_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P_2 = 0.5 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q_2 = 6.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sensors.gss(Num_emitters2, sample_size2, P_2)
N2 = sensors.gss(Num_sensors2, sample_size2, Q_2)
X2 = (A2 @ S2.T + N2.T).T
X2_with_mv = sensors.MCAR(X2, failing_sensors2, gap_ratio2)
R2 = sensors.initial_Cov(X2_with_mv)
MUSIC_theta2 = subspace_methods.MUSIC_DoA(R2, Num_emitters2)

# %%
MUSIC_theta2
# Out:
# array([0.72431164])

# %%
sensors.SNR(A2, P_2, Q_2, metrics = 'avg', scale = 'linear')
# Out:
# np.float64(2.0491803278688523)

# %%
EM_theta2_rad, EM_P2, lhd_2, lhd_list2, angles_list2 = em_stoch.multistart_EM2(X2_with_mv, 
                                                                               Num_emitters2, 
                                                                               Q=Q_2,
                                                                               MUSIC_theta=MUSIC_theta2, 
                                                                               num_of_starts=20, 
                                                                               max_iter=20, 
                                                                               rtol=1e-5)
# Out:
# 0-th start
# theta=[0.81251426],P=[[4.8828125e-08+0.j]]
# new_angles=[0.81251426]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -689.5858366251647 on iteration 0
# new_angles=[0.81251426]
# new_P:
# [[0.00199942+0.j]]
# 1-th start
# theta=[0.63682337],P=[[1.17743922e-07+4.63221143e-24j]]
# new_angles=[0.63682337]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.542752465457 on iteration 0
# new_angles=[0.64317969]
# new_P:
# [[0.00200334+0.j]]
# likelihood is -689.4918290109238 on iteration 1
# new_angles=[0.64789975]
# new_P:
# [[0.00302146+0.j]]
# likelihood is -689.428710427439 on iteration 2
# new_angles=[0.65280791]
# new_P:
# [[0.00407284+0.j]]
# likelihood is -689.347488422542 on iteration 3
# new_angles=[0.65818051]
# new_P:
# [[0.00518576+0.j]]
# likelihood is -689.2414126395938 on iteration 4
# new_angles=[0.66312769]
# new_P:
# [[0.00640285+0.j]]
# likelihood is -689.1129430897106 on iteration 5
# new_angles=[0.66809407]
# new_P:
# [[0.00778282+0.j]]
# likelihood is -688.9541664931371 on iteration 6
# new_angles=[0.67215948]
# new_P:
# [[0.00941403+0.j]]
# likelihood is -688.7703952652829 on iteration 7
# new_angles=[0.67638316]
# new_P:
# [[0.01142212+0.j]]
# likelihood is -688.5387246979608 on iteration 8
# new_angles=[0.68014562]
# new_P:
# [[0.01402004+0.j]]
# likelihood is -688.2500961536248 on iteration 9
# new_angles=[0.68328978]
# new_P:
# [[0.01756182+0.j]]
# likelihood is -687.8784446994474 on iteration 10
# new_angles=[0.68582335]
# new_P:
# [[0.02268854+0.j]]
# likelihood is -687.3733853476887 on iteration 11
# new_angles=[0.68813999]
# new_P:
# [[0.03066279+0.j]]
# likelihood is -686.63473000098 on iteration 12
# new_angles=[0.69008912]
# new_P:
# [[0.04422385+0.j]]
# likelihood is -685.4915340182446 on iteration 13
# new_angles=[0.69175858]
# new_P:
# [[0.06986542+0.j]]
# likelihood is -683.6337735690779 on iteration 14
# new_angles=[0.69318598]
# new_P:
# [[0.12423953+0.j]]
# likelihood is -680.6567454302544 on iteration 15
# new_angles=[0.69437678]
# new_P:
# [[0.24906672+0.j]]
# likelihood is -676.7130222330425 on iteration 16
# new_angles=[0.69537012]
# new_P:
# [[0.51559629+0.j]]
# likelihood is -673.7359321305514 on iteration 17
# new_angles=[0.69620652]
# new_P:
# [[0.91107344+0.j]]
# likelihood is -673.2532531663738 on iteration 18
# new_angles=[0.69690764]
# new_P:
# [[1.2418214+0.j]]
# 2-th start
# theta=[0.65176423],P=[[8.96189647e-08-1.32348898e-24j]]
# new_angles=[0.65176423]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.5231536456283 on iteration 0
# new_angles=[0.65530629]
# new_P:
# [[0.00200513+0.j]]
# likelihood is -689.4560916606732 on iteration 1
# new_angles=[0.66048409]
# new_P:
# [[0.00302973+0.j]]
# likelihood is -689.368459445884 on iteration 2
# new_angles=[0.66544018]
# new_P:
# [[0.00409769+0.j]]
# likelihood is -689.2622718337896 on iteration 3
# new_angles=[0.67041562]
# new_P:
# [[0.0052427+0.j]]
# likelihood is -689.1344824415519 on iteration 4
# new_angles=[0.67449874]
# new_P:
# [[0.00651276+0.j]]
# likelihood is -688.9904761905511 on iteration 5
# new_angles=[0.67825549]
# new_P:
# [[0.00797177+0.j]]
# likelihood is -688.8227249726973 on iteration 6
# new_angles=[0.68155288]
# new_P:
# [[0.00971509+0.j]]
# likelihood is -688.6256176859266 on iteration 7
# new_angles=[0.6845123]
# new_P:
# [[0.01188819+0.j]]
# likelihood is -688.3859946339251 on iteration 8
# new_angles=[0.68703595]
# new_P:
# [[0.0147288+0.j]]
# likelihood is -688.0846887327194 on iteration 9
# new_angles=[0.68911924]
# new_P:
# [[0.01864777+0.j]]
# likelihood is -687.6873359060955 on iteration 10
# new_angles=[0.69101867]
# new_P:
# [[0.02440929+0.j]]
# likelihood is -687.129723699564 on iteration 11
# new_angles=[0.69259861]
# new_P:
# [[0.03356202+0.j]]
# likelihood is -686.3020460545395 on iteration 12
# new_angles=[0.69393415]
# new_P:
# [[0.04952788+0.j]]
# likelihood is -684.9978905580205 on iteration 13
# new_angles=[0.69502827]
# new_P:
# [[0.08061875+0.j]]
# likelihood is -682.8685951477585 on iteration 14
# new_angles=[0.69594802]
# new_P:
# [[0.14828792+0.j]]
# likelihood is -679.554071091586 on iteration 15
# new_angles=[0.69671283]
# new_P:
# [[0.30352805+0.j]]
# likelihood is -675.6105305247446 on iteration 16
# new_angles=[0.69734965]
# new_P:
# [[0.61275878+0.j]]
# likelihood is -673.2993368706398 on iteration 17
# new_angles=[0.69788357]
# new_P:
# [[1.00895008+0.j]]
# likelihood is -673.2918120428969 on iteration 18
# new_angles=[0.69832394]
# new_P:
# [[1.29542832+0.j]]
# 3-th start
# theta=[0.65005312],P=[[8.55417288e-08-3.97046694e-24j]]
# new_angles=[0.65005312]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.5257666281028 on iteration 0
# new_angles=[0.65005312]
# new_P:
# [[0.00200489+0.j]]
# likelihood is -689.4725246304941 on iteration 1
# new_angles=[0.65527209]
# new_P:
# [[0.00302652+0.j]]
# likelihood is -689.3943943495709 on iteration 2
# new_angles=[0.66119175]
# new_P:
# [[0.00408734+0.j]]
# likelihood is -689.2914823073421 on iteration 3
# new_angles=[0.66615058]
# new_P:
# [[0.00522124+0.j]]
# likelihood is -689.1713798738251 on iteration 4
# new_angles=[0.67074291]
# new_P:
# [[0.00647279+0.j]]
# likelihood is -689.0298250769293 on iteration 5
# new_angles=[0.67487339]
# new_P:
# [[0.00790575+0.j]]
# likelihood is -688.8646400721027 on iteration 6
# new_angles=[0.67862364]
# new_P:
# [[0.0096122+0.j]]
# likelihood is -688.6689023777606 on iteration 7
# new_angles=[0.68215706]
# new_P:
# [[0.01173324+0.j]]
# likelihood is -688.4293828420773 on iteration 8
# new_angles=[0.68503568]
# new_P:
# [[0.01449924+0.j]]
# likelihood is -688.1323399924518 on iteration 9
# new_angles=[0.68747728]
# new_P:
# [[0.01830099+0.j]]
# likelihood is -687.7425808741449 on iteration 10
# new_angles=[0.68957528]
# new_P:
# [[0.0238644+0.j]]
# likelihood is -687.2008964934629 on iteration 11
# new_angles=[0.69136377]
# new_P:
# [[0.03264712+0.j]]
# likelihood is -686.400948481788 on iteration 12
# new_angles=[0.69280362]
# new_P:
# [[0.04785129+0.j]]
# likelihood is -685.1480664969204 on iteration 13
# new_angles=[0.69405292]
# new_P:
# [[0.07719817+0.j]]
# likelihood is -683.1024624916773 on iteration 14
# new_angles=[0.69514892]
# new_P:
# [[0.14060532+0.j]]
# likelihood is -679.8844154252404 on iteration 15
# new_angles=[0.69603877]
# new_P:
# [[0.28630962+0.j]]
# likelihood is -675.9210260981803 on iteration 16
# new_angles=[0.69678338]
# new_P:
# [[0.58329659+0.j]]
# likelihood is -673.40320869496 on iteration 17
# new_angles=[0.69740033]
# new_P:
# [[0.98117202+0.j]]
# likelihood is -673.2727197976747 on iteration 18
# new_angles=[0.69791801]
# new_P:
# [[1.28096515+0.j]]
# 4-th start
# theta=[0.66778311],P=[[1.30082571e-07+5.29395592e-24j]]
# new_angles=[0.66778311]
# new_P:
# [[0.00100007+0.j]]
# likelihood is -689.4970085428247 on iteration 0
# new_angles=[0.67140081]
# new_P:
# [[0.00200752+0.j]]
# likelihood is -689.4034628102971 on iteration 1
# new_angles=[0.67639989]
# new_P:
# [[0.00304168+0.j]]
# likelihood is -689.2919860268836 on iteration 2
# new_angles=[0.6787287]
# new_P:
# [[0.00413084+0.j]]
# likelihood is -689.1782261611338 on iteration 3
# new_angles=[0.68198415]
# new_P:
# [[0.00530832+0.j]]
# likelihood is -689.0457710721463 on iteration 4
# new_angles=[0.68504336]
# new_P:
# [[0.00662441+0.j]]
# likelihood is -688.8960412133415 on iteration 5
# new_angles=[0.6875681]
# new_P:
# [[0.00814856+0.j]]
# likelihood is -688.7258450590903 on iteration 6
# new_angles=[0.68988748]
# new_P:
# [[0.00998205+0.j]]
# likelihood is -688.5243788221388 on iteration 7
# new_angles=[0.69153181]
# new_P:
# [[0.01228436+0.j]]
# likelihood is -688.2806554004585 on iteration 8
# new_angles=[0.693255]
# new_P:
# [[0.0153155+0.j]]
# likelihood is -687.9664082308806 on iteration 9
# new_angles=[0.6945253]
# new_P:
# [[0.01953904+0.j]]
# likelihood is -687.5459750664261 on iteration 10
# new_angles=[0.69565098]
# new_P:
# [[0.02582591+0.j]]
# likelihood is -686.9482013215608 on iteration 11
# new_angles=[0.69652279]
# new_P:
# [[0.03596797+0.j]]
# likelihood is -686.0479144740433 on iteration 12
# new_angles=[0.69716177]
# new_P:
# [[0.05399664+0.j]]
# likelihood is -684.614865311471 on iteration 13
# new_angles=[0.69774081]
# new_P:
# [[0.08984343+0.j]]
# likelihood is -682.2742940611454 on iteration 14
# new_angles=[0.69824109]
# new_P:
# [[0.1691133+0.j]]
# likelihood is -678.7399844127519 on iteration 15
# new_angles=[0.69863957]
# new_P:
# [[0.34926074+0.j]]
# likelihood is -674.9171275616198 on iteration 16
# new_angles=[0.69897368]
# new_P:
# [[0.68582968+0.j]]
# likelihood is -673.1193018841097 on iteration 17
# new_angles=[0.69925309]
# new_P:
# [[1.07180059+0.j]]
# 5-th start
# theta=[0.70544346],P=[[1.7674577e-07+6.6174449e-25j]]
# new_angles=[0.70544346]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.4663031180482 on iteration 0
# new_angles=[0.70544346]
# new_P:
# [[0.00201027+0.j]]
# likelihood is -689.3531652999187 on iteration 1
# new_angles=[0.70444976]
# new_P:
# [[0.00305361+0.j]]
# likelihood is -689.2364932347548 on iteration 2
# new_angles=[0.70444976]
# new_P:
# [[0.00415839+0.j]]
# likelihood is -689.1146598353386 on iteration 3
# new_angles=[0.70380872]
# new_P:
# [[0.00536087+0.j]]
# likelihood is -688.9825770978373 on iteration 4
# new_angles=[0.70344828]
# new_P:
# [[0.00671083+0.j]]
# likelihood is -688.8360908909958 on iteration 5
# new_angles=[0.70296731]
# new_P:
# [[0.00827887+0.j]]
# likelihood is -688.667798348532 on iteration 6
# new_angles=[0.70237319]
# new_P:
# [[0.01017105+0.j]]
# likelihood is -688.4675049874394 on iteration 7
# new_angles=[0.70210174]
# new_P:
# [[0.01255466+0.j]]
# likelihood is -688.2200787744928 on iteration 8
# new_angles=[0.70175122]
# new_P:
# [[0.015708+0.j]]
# likelihood is -687.9000884197046 on iteration 9
# new_angles=[0.70162635]
# new_P:
# [[0.0201255+0.j]]
# likelihood is -687.465796480337 on iteration 10
# new_angles=[0.70146794]
# new_P:
# [[0.02674958+0.j]]
# likelihood is -686.8429403713084 on iteration 11
# new_angles=[0.70136027]
# new_P:
# [[0.03753414+0.j]]
# likelihood is -685.8964985109692 on iteration 12
# new_angles=[0.70125244]
# new_P:
# [[0.05692096+0.j]]
# likelihood is -684.3808735867566 on iteration 13
# new_angles=[0.70113944]
# new_P:
# [[0.09593674+0.j]]
# likelihood is -681.9116353467476 on iteration 14
# new_angles=[0.70106949]
# new_P:
# [[0.18289122+0.j]]
# likelihood is -678.265209948485 on iteration 15
# new_angles=[0.70103806]
# new_P:
# [[0.37861506+0.j]]
# likelihood is -674.5623284023013 on iteration 16
# new_angles=[0.70099721]
# new_P:
# [[0.7289445+0.j]]
# likelihood is -673.0615832534434 on iteration 17
# new_angles=[0.70095425]
# new_P:
# [[1.10520111+0.j]]
# 6-th start
# theta=[0.72657557],P=[[7.35180779e-08+1.32348898e-24j]]
# new_angles=[0.72657557]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.4863069221292 on iteration 0
# new_angles=[0.72147688]
# new_P:
# [[0.00200845+0.j]]
# likelihood is -689.3793942807698 on iteration 1
# new_angles=[0.71901471]
# new_P:
# [[0.003047+0.j]]
# likelihood is -689.2684846755934 on iteration 2
# new_angles=[0.71391639]
# new_P:
# [[0.00414276+0.j]]
# likelihood is -689.1379026140271 on iteration 3
# new_angles=[0.71164951]
# new_P:
# [[0.00533577+0.j]]
# likelihood is -689.0043546233508 on iteration 4
# new_angles=[0.70999923]
# new_P:
# [[0.00667347+0.j]]
# likelihood is -688.8571268492143 on iteration 5
# new_angles=[0.70809857]
# new_P:
# [[0.00822531+0.j]]
# likelihood is -688.6866106754085 on iteration 6
# new_angles=[0.70681365]
# new_P:
# [[0.01009686+0.j]]
# likelihood is -688.4864099749423 on iteration 7
# new_angles=[0.70584941]
# new_P:
# [[0.01245132+0.j]]
# likelihood is -688.2403387603006 on iteration 8
# new_angles=[0.70498822]
# new_P:
# [[0.0155607+0.j]]
# likelihood is -687.9231961574088 on iteration 9
# new_angles=[0.70424803]
# new_P:
# [[0.01990716+0.j]]
# likelihood is -687.4940070549577 on iteration 10
# new_angles=[0.7036075]
# new_P:
# [[0.02640732+0.j]]
# likelihood is -686.8804590363159 on iteration 11
# new_angles=[0.70312979]
# new_P:
# [[0.03695479+0.j]]
# likelihood is -685.9510668235641 on iteration 12
# new_angles=[0.70273332]
# new_P:
# [[0.05583852+0.j]]
# likelihood is -684.4654570372836 on iteration 13
# new_angles=[0.70232748]
# new_P:
# [[0.09367879+0.j]]
# likelihood is -682.0422020974733 on iteration 14
# new_angles=[0.70206103]
# new_P:
# [[0.17779273+0.j]]
# likelihood is -678.4342475193212 on iteration 15
# new_angles=[0.70184783]
# new_P:
# [[0.3678485+0.j]]
# likelihood is -674.6840631604442 on iteration 16
# new_angles=[0.70167179]
# new_P:
# [[0.71346175+0.j]]
# likelihood is -673.0778207541154 on iteration 17
# new_angles=[0.70151884]
# new_P:
# [[1.09348941+0.j]]
# 7-th start
# theta=[0.7104521],P=[[1.73164662e-07-1.81979735e-24j]]
# new_angles=[0.7104521]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.4686980328167 on iteration 0
# new_angles=[0.70865372]
# new_P:
# [[0.00201005+0.j]]
# likelihood is -689.3558880057589 on iteration 1
# new_angles=[0.70865372]
# new_P:
# [[0.00305288+0.j]]
# likelihood is -689.2414993687321 on iteration 2
# new_angles=[0.70705595]
# new_P:
# [[0.00415626+0.j]]
# likelihood is -689.1184708588644 on iteration 3
# new_angles=[0.70553205]
# new_P:
# [[0.00535721+0.j]]
# likelihood is -688.985357191172 on iteration 4
# new_angles=[0.70456878]
# new_P:
# [[0.00670556+0.j]]
# likelihood is -688.8382609073627 on iteration 5
# new_angles=[0.7037414]
# new_P:
# [[0.00827178+0.j]]
# likelihood is -688.6696365033571 on iteration 6
# new_angles=[0.70319291]
# new_P:
# [[0.0101617+0.j]]
# likelihood is -688.4695764759616 on iteration 7
# new_angles=[0.70267832]
# new_P:
# [[0.01254189+0.j]]
# likelihood is -688.222146129906 on iteration 8
# new_angles=[0.70232748]
# new_P:
# [[0.01569026+0.j]]
# likelihood is -687.9025973576015 on iteration 9
# new_angles=[0.70195246]
# new_P:
# [[0.02009953+0.j]]
# likelihood is -687.4687241291533 on iteration 10
# new_angles=[0.70169612]
# new_P:
# [[0.02670953+0.j]]
# likelihood is -686.8469114718196 on iteration 11
# new_angles=[0.70152614]
# new_P:
# [[0.03746714+0.j]]
# likelihood is -685.9023833669557 on iteration 12
# new_angles=[0.70136837]
# new_P:
# [[0.05679677+0.j]]
# likelihood is -684.3900951509088 on iteration 13
# new_angles=[0.70127903]
# new_P:
# [[0.09567911+0.j]]
# likelihood is -681.9261150168068 on iteration 14
# new_angles=[0.7012086]
# new_P:
# [[0.18231127+0.j]]
# likelihood is -678.2839177012552 on iteration 15
# new_angles=[0.70113275]
# new_P:
# [[0.37739762+0.j]]
# likelihood is -674.5754248563311 on iteration 16
# new_angles=[0.70107049]
# new_P:
# [[0.72721591+0.j]]
# likelihood is -673.0629460266751 on iteration 17
# new_angles=[0.70101592]
# new_P:
# [[1.10391338+0.j]]
# 8-th start
# theta=[0.71429435],P=[[8.44135407e-08-3.72231276e-25j]]
# new_angles=[0.71429435]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.4716077369084 on iteration 0
# new_angles=[0.71398439]
# new_P:
# [[0.00200979+0.j]]
# likelihood is -689.3633032217589 on iteration 1
# new_angles=[0.71045181]
# new_P:
# [[0.00305128+0.j]]
# likelihood is -689.2448427161781 on iteration 2
# new_angles=[0.70874735]
# new_P:
# [[0.00415368+0.j]]
# likelihood is -689.1220533664197 on iteration 3
# new_angles=[0.70736424]
# new_P:
# [[0.00535316+0.j]]
# likelihood is -688.9894655698929 on iteration 4
# new_angles=[0.70671423]
# new_P:
# [[0.00669925+0.j]]
# likelihood is -688.8435384173399 on iteration 5
# new_angles=[0.70553014]
# new_P:
# [[0.0082617+0.j]]
# likelihood is -688.6744458106803 on iteration 6
# new_angles=[0.70459511]
# new_P:
# [[0.0101468+0.j]]
# likelihood is -688.4740275915798 on iteration 7
# new_angles=[0.70424803]
# new_P:
# [[0.01252054+0.j]]
# likelihood is -688.227753924088 on iteration 8
# new_angles=[0.70365681]
# new_P:
# [[0.01565825+0.j]]
# likelihood is -687.9087532484893 on iteration 9
# new_angles=[0.70317152]
# new_P:
# [[0.02005052+0.j]]
# likelihood is -687.4762112551979 on iteration 10
# new_angles=[0.70287614]
# new_P:
# [[0.02663067+0.j]]
# likelihood is -686.8570646231354 on iteration 11
# new_angles=[0.7025181]
# new_P:
# [[0.03733018+0.j]]
# likelihood is -685.9166680972073 on iteration 12
# new_angles=[0.70219826]
# new_P:
# [[0.05653639+0.j]]
# likelihood is -684.4116987930661 on iteration 13
# new_angles=[0.70194262]
# new_P:
# [[0.09512984+0.j]]
# likelihood is -681.9591050198266 on iteration 14
# new_angles=[0.7017485]
# new_P:
# [[0.18106199+0.j]]
# likelihood is -678.3264391499891 on iteration 15
# new_angles=[0.70158751]
# new_P:
# [[0.37475122+0.j]]
# likelihood is -674.6063991924977 on iteration 16
# new_angles=[0.70145407]
# new_P:
# [[0.72341082+0.j]]
# likelihood is -673.068109188038 on iteration 17
# new_angles=[0.70133814]
# new_P:
# [[1.10102803+0.j]]
# 9-th start
# theta=[0.6348336],P=[[1.11590995e-07-6.6174449e-25j]]
# new_angles=[0.6348336]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.5446987603111 on iteration 0
# new_angles=[0.6348336]
# new_P:
# [[0.00200316+0.j]]
# likelihood is -689.5103921147604 on iteration 1
# new_angles=[0.63787335]
# new_P:
# [[0.00301793+0.j]]
# likelihood is -689.4669441738699 on iteration 2
# new_angles=[0.64274453]
# new_P:
# [[0.00405887+0.j]]
# likelihood is -689.4061492440386 on iteration 3
# new_angles=[0.64763354]
# new_P:
# [[0.00514999+0.j]]
# likelihood is -689.3272141142693 on iteration 4
# new_angles=[0.65254071]
# new_P:
# [[0.00632583+0.j]]
# likelihood is -689.2256429158211 on iteration 5
# new_angles=[0.65746634]
# new_P:
# [[0.00763673+0.j]]
# likelihood is -689.0959835351758 on iteration 6
# new_angles=[0.66241078]
# new_P:
# [[0.00915721+0.j]]
# likelihood is -688.9310001468516 on iteration 7
# new_angles=[0.66727443]
# new_P:
# [[0.01100095+0.j]]
# likelihood is -688.721957847407 on iteration 8
# new_angles=[0.67156195]
# new_P:
# [[0.01334759+0.j]]
# likelihood is -688.463116988508 on iteration 9
# new_angles=[0.67551806]
# new_P:
# [[0.01648753+0.j]]
# likelihood is -688.1276618383747 on iteration 10
# new_angles=[0.67915289]
# new_P:
# [[0.02094149+0.j]]
# likelihood is -687.6738505197467 on iteration 11
# new_angles=[0.68226083]
# new_P:
# [[0.02770945+0.j]]
# likelihood is -687.0318192660656 on iteration 12
# new_angles=[0.68502795]
# new_P:
# [[0.03887268+0.j]]
# likelihood is -686.0582929687597 on iteration 13
# new_angles=[0.68743915]
# new_P:
# [[0.05922979+0.j]]
# likelihood is -684.4977385021174 on iteration 14
# new_angles=[0.68949415]
# new_P:
# [[0.10084688+0.j]]
# likelihood is -681.9536477671847 on iteration 15
# new_angles=[0.69123572]
# new_P:
# [[0.19492522+0.j]]
# likelihood is -678.2383868280862 on iteration 16
# new_angles=[0.69270201]
# new_P:
# [[0.4070933+0.j]]
# likelihood is -674.6342779293724 on iteration 17
# new_angles=[0.69394291]
# new_P:
# [[0.7769134+0.j]]
# likelihood is -673.3507635457653 on iteration 18
# new_angles=[0.69498202]
# new_P:
# [[1.15452894+0.j]]
# 10-th start
# theta=[0.68408872],P=[[1.6429738e-07+0.j]]
# new_angles=[0.68408872]
# new_P:
# [[0.00100008+0.j]]
# likelihood is -689.474582365374 on iteration 0
# new_angles=[0.68651207]
# new_P:
# [[0.00200956+0.j]]
# likelihood is -689.3651037600822 on iteration 1
# new_angles=[0.68779015]
# new_P:
# [[0.00305072+0.j]]
# likelihood is -689.2522225794244 on iteration 2
# new_angles=[0.69023544]
# new_P:
# [[0.00415107+0.j]]
# likelihood is -689.1287041292354 on iteration 3
# new_angles=[0.69267881]
# new_P:
# [[0.00534794+0.j]]
# likelihood is -688.993859569438 on iteration 4
# new_angles=[0.69427303]
# new_P:
# [[0.00669154+0.j]]
# likelihood is -688.8458583468649 on iteration 5
# new_angles=[0.69598494]
# new_P:
# [[0.00825185+0.j]]
# likelihood is -688.675552546073 on iteration 6
# new_angles=[0.6966451]
# new_P:
# [[0.01013487+0.j]]
# likelihood is -688.4760606244821 on iteration 7
# new_angles=[0.69734543]
# new_P:
# [[0.01250482+0.j]]
# likelihood is -688.2292190250456 on iteration 8
# new_angles=[0.69785827]
# new_P:
# [[0.0156376+0.j]]
# likelihood is -687.9108920658573 on iteration 9
# new_angles=[0.69831172]
# new_P:
# [[0.0200214+0.j]]
# likelihood is -687.4791960510754 on iteration 10
# new_angles=[0.6987058]
# new_P:
# [[0.02658636+0.j]]
# likelihood is -686.8609758228441 on iteration 11
# new_angles=[0.69905856]
# new_P:
# [[0.03725728+0.j]]
# likelihood is -685.9226542782567 on iteration 12
# new_angles=[0.69937125]
# new_P:
# [[0.05640286+0.j]]
# likelihood is -684.4212579793641 on iteration 13
# new_angles=[0.69957478]
# new_P:
# [[0.09485518+0.j]]
# likelihood is -681.974343645722 on iteration 14
# new_angles=[0.69977158]
# new_P:
# [[0.18044668+0.j]]
# likelihood is -678.3460034169549 on iteration 15
# new_angles=[0.69993117]
# new_P:
# [[0.37346395+0.j]]
# likelihood is -674.6198812825945 on iteration 16
# new_angles=[0.70005783]
# new_P:
# [[0.72158807+0.j]]
# likelihood is -673.0689063321906 on iteration 17
# new_angles=[0.70016425]
# new_P:
# [[1.09969163+0.j]]
# 11-th start
# theta=[0.72251562],P=[[7.77089257e-08+6.6174449e-25j]]
# new_angles=[0.72251562]
# new_P:
# [[0.00100004+0.j]]
# likelihood is -689.4806436166313 on iteration 0
# new_angles=[0.71701074]
# new_P:
# [[0.00200897+0.j]]
# likelihood is -689.3691010725081 on iteration 1
# new_angles=[0.7123591]
# new_P:
# [[0.00304939+0.j]]
# likelihood is -689.2490797296533 on iteration 2
# new_angles=[0.71073644]
# new_P:
# [[0.00415056+0.j]]
# likelihood is -689.1272379751153 on iteration 3
# new_angles=[0.70816265]
# new_P:
# [[0.00534794+0.j]]
# likelihood is -688.9919881765904 on iteration 4
# new_angles=[0.70740751]
# new_P:
# [[0.00669243+0.j]]
# likelihood is -688.8461767540391 on iteration 5
# new_angles=[0.70614519]
# new_P:
# [[0.00825264+0.j]]
# likelihood is -688.6770838291743 on iteration 6
# new_angles=[0.70520163]
# new_P:
# [[0.01013464+0.j]]
# likelihood is -688.4769453858737 on iteration 7
# new_angles=[0.70424803]
# new_P:
# [[0.01250376+0.j]]
# likelihood is -688.2294717683164 on iteration 8
# new_angles=[0.7036075]
# new_P:
# [[0.01563603+0.j]]
# likelihood is -687.9108314478653 on iteration 9
# new_angles=[0.70314825]
# new_P:
# [[0.02001947+0.j]]
# likelihood is -687.4791358293827 on iteration 10
# new_angles=[0.70274316]
# new_P:
# [[0.02658383+0.j]]
# likelihood is -686.860908264204 on iteration 11
# new_angles=[0.70241998]
# new_P:
# [[0.0372537+0.j]]
# likelihood is -685.922737508811 on iteration 12
# new_angles=[0.70216591]
# new_P:
# [[0.05639681+0.j]]
# likelihood is -684.4217174658636 on iteration 13
# new_angles=[0.70193355]
# new_P:
# [[0.09484232+0.j]]
# likelihood is -681.9749655732749 on iteration 14
# new_angles=[0.70175324]
# new_P:
# [[0.18041746+0.j]]
# likelihood is -678.3470526286039 on iteration 15
# new_angles=[0.70159304]
# new_P:
# [[0.37339802+0.j]]
# likelihood is -674.6209301452805 on iteration 16
# new_angles=[0.70145971]
# new_P:
# [[0.72147854+0.j]]
# likelihood is -673.0694913203298 on iteration 17
# new_angles=[0.70134634]
# new_P:
# [[1.09958078+0.j]]
# 12-th start
# theta=[0.75041272],P=[[8.5918593e-08-5.29395592e-24j]]
# new_angles=[0.75041272]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -689.527624394897 on iteration 0
# new_angles=[0.73965887]
# new_P:
# [[0.00200469+0.j]]
# likelihood is -689.4373088128998 on iteration 1
# new_angles=[0.73216198]
# new_P:
# [[0.00303268+0.j]]
# likelihood is -689.3263115421053 on iteration 2
# new_angles=[0.72692206]
# new_P:
# [[0.00411219+0.j]]
# likelihood is -689.204264557318 on iteration 3
# new_angles=[0.72170645]
# new_P:
# [[0.00527916+0.j]]
# likelihood is -689.062766521559 on iteration 4
# new_angles=[0.71805122]
# new_P:
# [[0.0065852+0.j]]
# likelihood is -688.9107843539338 on iteration 5
# new_angles=[0.71490194]
# new_P:
# [[0.008097+0.j]]
# likelihood is -688.7377705463342 on iteration 6
# new_angles=[0.71231846]
# new_P:
# [[0.00991553+0.j]]
# likelihood is -688.5359639857911 on iteration 7
# new_angles=[0.71067267]
# new_P:
# [[0.01219699+0.j]]
# likelihood is -688.2944484523515 on iteration 8
# new_angles=[0.70913872]
# new_P:
# [[0.0151954+0.j]]
# likelihood is -687.9848414134431 on iteration 9
# new_angles=[0.70785265]
# new_P:
# [[0.01936299+0.j]]
# likelihood is -687.5696712039031 on iteration 10
# new_angles=[0.70661037]
# new_P:
# [[0.02555097+0.j]]
# likelihood is -686.9796246819317 on iteration 11
# new_angles=[0.70564777]
# new_P:
# [[0.03550505+0.j]]
# likelihood is -686.0933093214245 on iteration 12
# new_angles=[0.7047724]
# new_P:
# [[0.05313805+0.j]]
# likelihood is -684.6831131532012 on iteration 13
# new_angles=[0.70412179]
# new_P:
# [[0.08807297+0.j]]
# likelihood is -682.3810037310017 on iteration 14
# new_angles=[0.70356677]
# new_P:
# [[0.165126+0.j]]
# likelihood is -678.883517406961 on iteration 15
# new_angles=[0.70308661]
# new_P:
# [[0.34064481+0.j]]
# likelihood is -675.030550187098 on iteration 16
# new_angles=[0.70270257]
# new_P:
# [[0.67264361+0.j]]
# likelihood is -673.1411078759223 on iteration 17
# new_angles=[0.70238972]
# new_P:
# [[1.06105191+0.j]]
# 13-th start
# theta=[0.76848612],P=[[8.39647801e-08+2.64697796e-24j]]
# new_angles=[0.76848612]
# new_P:
# [[0.00100001+0.j]]
# likelihood is -689.5567832264339 on iteration 0
# new_angles=[0.75844802]
# new_P:
# [[0.00200204+0.j]]
# likelihood is -689.5041291035327 on iteration 1
# new_angles=[0.7477397]
# new_P:
# [[0.00301792+0.j]]
# likelihood is -689.4105136635668 on iteration 2
# new_angles=[0.73713668]
# new_P:
# [[0.00407415+0.j]]
# likelihood is -689.2753826492105 on iteration 3
# new_angles=[0.73020989]
# new_P:
# [[0.00521339+0.j]]
# likelihood is -689.1322452674735 on iteration 4
# new_angles=[0.7244683]
# new_P:
# [[0.00648265+0.j]]
# likelihood is -688.9716514829231 on iteration 5
# new_angles=[0.72060084]
# new_P:
# [[0.00794986+0.j]]
# likelihood is -688.799644765197 on iteration 6
# new_angles=[0.71705889]
# new_P:
# [[0.00970681+0.j]]
# likelihood is -688.5969365170049 on iteration 7
# new_angles=[0.71438323]
# new_P:
# [[0.01190302+0.j]]
# likelihood is -688.3564468394801 on iteration 8
# new_angles=[0.71180091]
# new_P:
# [[0.01477706+0.j]]
# likelihood is -688.0500248150636 on iteration 9
# new_angles=[0.70963249]
# new_P:
# [[0.01875219+0.j]]
# likelihood is -687.6448491088914 on iteration 10
# new_angles=[0.70804433]
# new_P:
# [[0.02461509+0.j]]
# likelihood is -687.0797593990777 on iteration 11
# new_angles=[0.70681365]
# new_P:
# [[0.03395648+0.j]]
# likelihood is -686.2383552530205 on iteration 12
# new_angles=[0.70578133]
# new_P:
# [[0.05031279+0.j]]
# likelihood is -684.9082803169737 on iteration 13
# new_angles=[0.70490697]
# new_P:
# [[0.08230575+0.j]]
# likelihood is -682.7339784302452 on iteration 14
# new_angles=[0.70422256]
# new_P:
# [[0.15220869+0.j]]
# likelihood is -679.3680956346632 on iteration 15
# new_angles=[0.70366208]
# new_P:
# [[0.31244526+0.j]]
# likelihood is -675.4367301394246 on iteration 16
# new_angles=[0.70318189]
# new_P:
# [[0.62786615+0.j]]
# likelihood is -673.2315226785424 on iteration 17
# new_angles=[0.70278733]
# new_P:
# [[1.02291744+0.j]]
# 14-th start
# theta=[0.73864851],P=[[5.87367942e-08-3.30872245e-24j]]
# new_angles=[0.73620981]
# new_P:
# [[0.00100003+0.j]]
# likelihood is -689.502003994854 on iteration 0
# new_angles=[0.72631517]
# new_P:
# [[0.00200702+0.j]]
# likelihood is -689.3927554151247 on iteration 1
# new_angles=[0.72110235]
# new_P:
# [[0.00304312+0.j]]
# likelihood is -689.2763674054951 on iteration 2
# new_angles=[0.71801955]
# new_P:
# [[0.0041366+0.j]]
# likelihood is -689.1548044741188 on iteration 3
# new_angles=[0.71542906]
# new_P:
# [[0.00532302+0.j]]
# likelihood is -689.0220915956113 on iteration 4
# new_angles=[0.71310312]
# new_P:
# [[0.00665137+0.j]]
# likelihood is -688.8737537735565 on iteration 5
# new_angles=[0.71073258]
# new_P:
# [[0.00819122+0.j]]
# likelihood is -688.702224944333 on iteration 6
# new_angles=[0.70865402]
# new_P:
# [[0.0100471+0.j]]
# likelihood is -688.4998808785039 on iteration 7
# new_angles=[0.70730455]
# new_P:
# [[0.01238147+0.j]]
# likelihood is -688.254185667932 on iteration 8
# new_angles=[0.70622637]
# new_P:
# [[0.0154612+0.j]]
# likelihood is -687.9390142685162 on iteration 9
# new_angles=[0.70536007]
# new_P:
# [[0.01975979+0.j]]
# likelihood is -687.5137859312147 on iteration 10
# new_angles=[0.70466847]
# new_P:
# [[0.02617578+0.j]]
# likelihood is -686.9074344781462 on iteration 11
# new_angles=[0.70398835]
# new_P:
# [[0.03656084+0.j]]
# likelihood is -685.9895504826821 on iteration 12
# new_angles=[0.70338906]
# new_P:
# [[0.05510162+0.j]]
# likelihood is -684.5241256897808 on iteration 13
# new_angles=[0.70293639]
# new_P:
# [[0.09214417+0.j]]
# likelihood is -682.1335863888819 on iteration 14
# new_angles=[0.70257715]
# new_P:
# [[0.17432128+0.j]]
# likelihood is -678.5540003158296 on iteration 15
# new_angles=[0.70227896]
# new_P:
# [[0.3604486+0.j]]
# likelihood is -674.7735809556253 on iteration 16
# new_angles=[0.70203468]
# new_P:
# [[0.70259003+0.j]]
# likelihood is -673.0925973502549 on iteration 17
# new_angles=[0.70182331]
# new_P:
# [[1.08506056+0.j]]
# 15-th start
# theta=[0.68749862],P=[[1.6917191e-07+2.64697796e-24j]]
# new_angles=[0.68749862]
# new_P:
# [[0.00100008+0.j]]
# likelihood is -689.4713567101921 on iteration 0
# new_angles=[0.68957862]
# new_P:
# [[0.00200985+0.j]]
# likelihood is -689.3600484913666 on iteration 1
# new_angles=[0.69242356]
# new_P:
# [[0.00305193+0.j]]
# likelihood is -689.2423455955247 on iteration 2
# new_angles=[0.69366162]
# new_P:
# [[0.00415504+0.j]]
# likelihood is -689.120105976674 on iteration 3
# new_angles=[0.69505909]
# new_P:
# [[0.00535531+0.j]]
# likelihood is -688.987316383545 on iteration 4
# new_angles=[0.69585237]
# new_P:
# [[0.00670259+0.j]]
# likelihood is -688.8407308185914 on iteration 5
# new_angles=[0.69656255]
# new_P:
# [[0.00826704+0.j]]
# likelihood is -688.6725442906301 on iteration 6
# new_angles=[0.69723769]
# new_P:
# [[0.01015423+0.j]]
# likelihood is -688.4725457186295 on iteration 7
# new_angles=[0.69785827]
# new_P:
# [[0.01253053+0.j]]
# likelihood is -688.2252732286807 on iteration 8
# new_angles=[0.69837527]
# new_P:
# [[0.01567308+0.j]]
# likelihood is -687.9059764422354 on iteration 9
# new_angles=[0.69887736]
# new_P:
# [[0.02007314+0.j]]
# likelihood is -687.4726539489606 on iteration 10
# new_angles=[0.69913347]
# new_P:
# [[0.02666725+0.j]]
# likelihood is -686.8522758658642 on iteration 11
# new_angles=[0.69945248]
# new_P:
# [[0.03739391+0.j]]
# likelihood is -685.9098324082445 on iteration 12
# new_angles=[0.69972442]
# new_P:
# [[0.05665816+0.j]]
# likelihood is -684.401317345373 on iteration 13
# new_angles=[0.69993117]
# new_P:
# [[0.09538802+0.j]]
# likelihood is -681.9431755974455 on iteration 14
# new_angles=[0.70007502]
# new_P:
# [[0.18165247+0.j]]
# likelihood is -678.3057339455466 on iteration 15
# new_angles=[0.70018601]
# new_P:
# [[0.37601079+0.j]]
# likelihood is -674.5908867507239 on iteration 16
# new_angles=[0.70027017]
# new_P:
# [[0.72524212+0.j]]
# likelihood is -673.0648529008993 on iteration 17
# new_angles=[0.7003394]
# new_P:
# [[1.10244614+0.j]]
# 16-th start
# theta=[0.65346953],P=[[9.37792273e-08+6.6174449e-24j]]
# new_angles=[0.65346953]
# new_P:
# [[0.00100005+0.j]]
# likelihood is -689.5204833069567 on iteration 0
# new_angles=[0.6600824]
# new_P:
# [[0.00200537+0.j]]
# likelihood is -689.4404149037282 on iteration 1
# new_angles=[0.66503693]
# new_P:
# [[0.00303282+0.j]]
# likelihood is -689.3455306783603 on iteration 2
# new_angles=[0.67001079]
# new_P:
# [[0.0041071+0.j]]
# likelihood is -689.2316653018449 on iteration 3
# new_angles=[0.67406261]
# new_P:
# [[0.00526376+0.j]]
# likelihood is -689.1041118635242 on iteration 4
# new_angles=[0.6782366]
# new_P:
# [[0.00654937+0.j]]
# likelihood is -688.9540926141633 on iteration 5
# new_angles=[0.6814243]
# new_P:
# [[0.00803267+0.j]]
# likelihood is -688.7863255200291 on iteration 6
# new_angles=[0.68420042]
# new_P:
# [[0.00980886+0.j]]
# likelihood is -688.589154144567 on iteration 7
# new_angles=[0.68679291]
# new_P:
# [[0.01202755+0.j]]
# likelihood is -688.3475830115932 on iteration 8
# new_angles=[0.68896965]
# new_P:
# [[0.0149357+0.j]]
# likelihood is -688.0424538052168 on iteration 9
# new_angles=[0.69089644]
# new_P:
# [[0.01896122+0.j]]
# likelihood is -687.6358355465603 on iteration 10
# new_angles=[0.69240412]
# new_P:
# [[0.02490755+0.j]]
# likelihood is -687.0657886868778 on iteration 11
# new_angles=[0.69376391]
# new_P:
# [[0.0344028+0.j]]
# likelihood is -686.2129106564507 on iteration 12
# new_angles=[0.69486352]
# new_P:
# [[0.05107812+0.j]]
# likelihood is -684.8643864472897 on iteration 13
# new_angles=[0.69580987]
# new_P:
# [[0.08379366+0.j]]
# likelihood is -682.6606946171489 on iteration 14
# new_angles=[0.69661399]
# new_P:
# [[0.15542712+0.j]]
# likelihood is -679.2642464343688 on iteration 15
# new_angles=[0.69727905]
# new_P:
# [[0.31934996+0.j]]
# likelihood is -675.352385507003 on iteration 16
# new_angles=[0.69782845]
# new_P:
# [[0.63884521+0.j]]
# likelihood is -673.2249627623369 on iteration 17
# new_angles=[0.698286]
# new_P:
# [[1.03230294+0.j]]
# 17-th start
# theta=[0.69944808],P=[[1.77772732e-07+6.6174449e-24j]]
# new_angles=[0.69944808]
# new_P:
# [[0.00100006+0.j]]
# likelihood is -689.4656264602315 on iteration 0
# new_angles=[0.69944808]
# new_P:
# [[0.00201035+0.j]]
# likelihood is -689.3518048351036 on iteration 1
# new_angles=[0.69944808]
# new_P:
# [[0.00305394+0.j]]
# likelihood is -689.235256331019 on iteration 2
# new_angles=[0.69944808]
# new_P:
# [[0.00415906+0.j]]
# likelihood is -689.1129565562354 on iteration 3
# new_angles=[0.69944808]
# new_P:
# [[0.00536222+0.j]]
# likelihood is -688.9811035456968 on iteration 4
# new_angles=[0.69944808]
# new_P:
# [[0.00671298+0.j]]
# likelihood is -688.834661551721 on iteration 5
# new_angles=[0.69975194]
# new_P:
# [[0.00828209+0.j]]
# likelihood is -688.6664293243715 on iteration 6
# new_angles=[0.69984494]
# new_P:
# [[0.0101757+0.j]]
# likelihood is -688.4664536846983 on iteration 7
# new_angles=[0.69999396]
# new_P:
# [[0.01256102+0.j]]
# likelihood is -688.2189534257384 on iteration 8
# new_angles=[0.70021276]
# new_P:
# [[0.01571696+0.j]]
# likelihood is -687.8988675298015 on iteration 9
# new_angles=[0.70030004]
# new_P:
# [[0.02013855+0.j]]
# likelihood is -687.4642141679846 on iteration 10
# new_angles=[0.70041004]
# new_P:
# [[0.0267699+0.j]]
# likelihood is -686.8407865440585 on iteration 11
# new_angles=[0.70045761]
# new_P:
# [[0.03756846+0.j]]
# likelihood is -685.8933305973329 on iteration 12
# new_angles=[0.70051119]
# new_P:
# [[0.05698509+0.j]]
# likelihood is -684.375946636948 on iteration 13
# new_angles=[0.70055911]
# new_P:
# [[0.09607061+0.j]]
# likelihood is -681.9040345090465 on iteration 14
# new_angles=[0.70059996]
# new_P:
# [[0.18319335+0.j]]
# likelihood is -678.2554163864772 on iteration 15
# new_angles=[0.70063903]
# new_P:
# [[0.37925021+0.j]]
# likelihood is -674.5553029896508 on iteration 16
# new_angles=[0.70065544]
# new_P:
# [[0.72984998+0.j]]
# likelihood is -673.0606078496251 on iteration 17
# new_angles=[0.70066776]
# new_P:
# [[1.10588331+0.j]]
# 18-th start
# theta=[0.74249062],P=[[1.07227531e-07+3.30872245e-24j]]
# new_angles=[0.72690744]
# new_P:
# [[0.00100001+0.j]]
# likelihood is -689.4868019109922 on iteration 0
# new_angles=[0.72175422]
# new_P:
# [[0.00200838+0.j]]
# likelihood is -689.3801032270713 on iteration 1
# new_angles=[0.71801109]
# new_P:
# [[0.00304679+0.j]]
# likelihood is -689.265139568839 on iteration 2
# new_angles=[0.71352024]
# new_P:
# [[0.00414347+0.j]]
# likelihood is -689.1364668287513 on iteration 3
# new_angles=[0.71093983]
# new_P:
# [[0.00533705+0.j]]
# likelihood is -689.0016415637281 on iteration 4
# new_angles=[0.70948754]
# new_P:
# [[0.00667614+0.j]]
# likelihood is -688.8548592060777 on iteration 5
# new_angles=[0.70783407]
# new_P:
# [[0.00822958+0.j]]
# likelihood is -688.6851466335303 on iteration 6
# new_angles=[0.70654944]
# new_P:
# [[0.01010274+0.j]]
# likelihood is -688.484778928492 on iteration 7
# new_angles=[0.70553014]
# new_P:
# [[0.01245961+0.j]]
# likelihood is -688.2382332852877 on iteration 8
# new_angles=[0.70469973]
# new_P:
# [[0.01557302+0.j]]
# likelihood is -687.920800795989 on iteration 9
# new_angles=[0.70398839]
# new_P:
# [[0.01992602+0.j]]
# likelihood is -687.4911007308156 on iteration 10
# new_angles=[0.70341265]
# new_P:
# [[0.02643763+0.j]]
# likelihood is -686.8768158464189 on iteration 11
# new_angles=[0.70297381]
# new_P:
# [[0.03700669+0.j]]
# likelihood is -685.9459077020329 on iteration 12
# new_angles=[0.70262128]
# new_P:
# [[0.05593606+0.j]]
# likelihood is -684.457659039261 on iteration 13
# new_angles=[0.70232052]
# new_P:
# [[0.09388249+0.j]]
# likelihood is -682.0307891981413 on iteration 14
# new_angles=[0.7020463]
# new_P:
# [[0.1782496+0.j]]
# likelihood is -678.4192839995194 on iteration 15
# new_angles=[0.70182854]
# new_P:
# [[0.36881314+0.j]]
# likelihood is -674.6731898736105 on iteration 16
# new_angles=[0.70164803]
# new_P:
# [[0.71485857+0.j]]
# likelihood is -673.076426680941 on iteration 17
# new_angles=[0.70150157]
# new_P:
# [[1.09455427+0.j]]
# 19-th start
# theta=[0.78572482],P=[[4.92090995e-08+5.29395592e-24j]]
# new_angles=[0.78572482]
# new_P:
# [[0.00100002+0.j]]
# likelihood is -689.5752533619083 on iteration 0
# new_angles=[0.76686352]
# new_P:
# [[0.00200038+0.j]]
# likelihood is -689.5300742789266 on iteration 1
# new_angles=[0.75607011]
# new_P:
# [[0.00301156+0.j]]
# likelihood is -689.4549134999095 on iteration 2
# new_angles=[0.7456053]
# new_P:
# [[0.00405563+0.j]]
# likelihood is -689.3380478968487 on iteration 3
# new_angles=[0.73765893]
# new_P:
# [[0.00517136+0.j]]
# likelihood is -689.2001437929663 on iteration 4
# new_angles=[0.73069072]
# new_P:
# [[0.0064067+0.j]]
# likelihood is -689.0376438481577 on iteration 5
# new_angles=[0.72539913]
# new_P:
# [[0.00782972+0.j]]
# likelihood is -688.8596538176739 on iteration 6
# new_angles=[0.72102676]
# new_P:
# [[0.00953107+0.j]]
# likelihood is -688.6556373254742 on iteration 7
# new_angles=[0.71756394]
# new_P:
# [[0.01165119+0.j]]
# likelihood is -688.4156270703924 on iteration 8
# new_angles=[0.71454454]
# new_P:
# [[0.01441537+0.j]]
# likelihood is -688.1156108483254 on iteration 9
# new_angles=[0.71202679]
# new_P:
# [[0.01821712+0.j]]
# likelihood is -687.7231269940226 on iteration 10
# new_angles=[0.71009344]
# new_P:
# [[0.02378382+0.j]]
# likelihood is -687.1809292423826 on iteration 11
# new_angles=[0.70848476]
# new_P:
# [[0.0325726+0.j]]
# likelihood is -686.3796983400543 on iteration 12
# new_angles=[0.70719942]
# new_P:
# [[0.04779201+0.j]]
# likelihood is -685.1230015739204 on iteration 13
# new_angles=[0.70614569]
# new_P:
# [[0.07718811+0.j]]
# likelihood is -683.0710691383917 on iteration 14
# new_angles=[0.70524788]
# new_P:
# [[0.14075279+0.j]]
# likelihood is -679.8437168876955 on iteration 15
# new_angles=[0.70451592]
# new_P:
# [[0.28691351+0.j]]
# likelihood is -675.8738814326726 on iteration 16
# new_angles=[0.70390179]
# new_P:
# [[0.58475243+0.j]]
# likelihood is -673.3647533935912 on iteration 17
# new_angles=[0.70339081]
# new_P:
# [[0.98302753+0.j]]
# likelihood is -673.2474788358985 on iteration 18
# new_angles=[0.70296631]
# new_P:
# [[1.28231234+0.j]]
# best_start=17

# %%
EM_theta2_rad, EM_P2
# Out:
# (array([0.70065544]), array([[0.72984998+0.j]]))

# %%
em_stoch.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q_2), em_stoch.incomplete_lkhd(X2_with_mv, theta2_rad, P_2, Q_2)
# Out:
# (np.float64(-673.0606078496251), np.float64(-673.6467390084401))

# %%
lhd_list2
# Out:
# [np.float64(-689.4656264602315),
#  np.float64(-689.3518048351036),
#  np.float64(-689.235256331019),
#  np.float64(-689.1129565562354),
#  np.float64(-688.9811035456968),
#  np.float64(-688.834661551721),
#  np.float64(-688.6664293243715),
#  np.float64(-688.4664536846983),
#  np.float64(-688.2189534257384),
#  np.float64(-687.8988675298015),
#  np.float64(-687.4642141679846),
#  np.float64(-686.8407865440585),
#  np.float64(-685.8933305973329),
#  np.float64(-684.375946636948),
#  np.float64(-681.9040345090465),
#  np.float64(-678.2554163864772),
#  np.float64(-674.5553029896508),
#  np.float64(-673.0606078496251)]

# %%
np.array(angles_list2)
# Out:
# array([[0.69944808],
#        [0.69944808],
#        [0.69944808],
#        [0.69944808],
#        [0.69944808],
#        [0.69944808],
#        [0.69944808],
#        [0.69975194],
#        [0.69984494],
#        [0.69999396],
#        [0.70021276],
#        [0.70030004],
#        [0.70041004],
#        [0.70045761],
#        [0.70051119],
#        [0.70055911],
#        [0.70059996],
#        [0.70063903],
#        [0.70065544]])

# %%
np.array(angles_list1)
# Out:
# array([[0.69671681],
#        [0.69671681],
#        [0.69671681],
#        [0.69671681],
#        [0.69671681],
#        [0.69671681],
#        [0.69666172],
#        [0.69666172],
#        [0.69666172],
#        [0.69666172],
#        [0.69666172],
#        [0.69666172],
#        [0.69662408],
#        [0.69659766],
#        [0.69658198],
#        [0.69656934],
#        [0.69656713],
#        [0.69652783],
#        [0.69651032],
#        [0.69646848],
#        [0.69644619]])
