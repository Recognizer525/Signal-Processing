# %%
import numpy as np
import matplotlib.pyplot as plt
from sensors import *
from functools import partial

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
# Истинное DOA в градусах
theta1_deg = rad_to_deg(theta1_rad[0])
GS_1 = np.array([[0.7]]) # Ковариация сигнала
GN_1 = 4.1*np.eye(5, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s1 = CN(Num_emitters1, sample_size1, GS_1)
n1 = CN(Num_sensors1, sample_size1, GN_1)
X1 = (A1 @ s1.T + n1.T).T

# %%
EM_theta1_rad, neglhd_1, K1, mu1 = multi_start_EM(X1, GS_1, GN_1, 10, max_iter=50, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[0.59416963], -likelihood = -138.05327
# Iteration=2, theta_new=[0.5803018], -likelihood = -140.57719
# Iteration=3, theta_new=[0.5687411], -likelihood = -142.39288
# Iteration=4, theta_new=[0.55913249], -likelihood = -143.68200
# Iteration=5, theta_new=[0.55116048], -likelihood = -144.58821
# Iteration=6, theta_new=[0.54454009], -likelihood = -145.22110
# Iteration=7, theta_new=[0.53906279], -likelihood = -145.66208
# Iteration=8, theta_new=[0.5345355], -likelihood = -145.96753
# Iteration=9, theta_new=[0.53077705], -likelihood = -146.17874
# Iteration=10, theta_new=[0.52761519], -likelihood = -146.32535
# Iteration=11, theta_new=[0.52498742], -likelihood = -146.42832
# Iteration=12, theta_new=[0.52283415], -likelihood = -146.49964
# Iteration=13, theta_new=[0.52104712], -likelihood = -146.54838
# Iteration=14, theta_new=[0.51952062], -likelihood = -146.58216
# Iteration=15, theta_new=[0.51825226], -likelihood = -146.60622
# Iteration=16, theta_new=[0.51724005], -likelihood = -146.62283
# Iteration=17, theta_new=[0.51638135], -likelihood = -146.63389
# Iteration=18, theta_new=[0.51567536], -likelihood = -146.64174
# Iteration=19, theta_new=[0.51507105], -likelihood = -146.64714
# Iteration=20, theta_new=[0.51456805], -likelihood = -146.65100
# Iteration=21, theta_new=[0.51416604], -likelihood = -146.65368
# Iteration=22, theta_new=[0.51381456], -likelihood = -146.65548
# Iteration=23, theta_new=[0.5135135], -likelihood = -146.65679
# Iteration=24, theta_new=[0.51326276], -likelihood = -146.65773
# Iteration=25, theta_new=[0.51306227], -likelihood = -146.65837
# Iteration=26, theta_new=[0.51291196], -likelihood = -146.65880
# Iteration=27, theta_new=[0.51276169], -likelihood = -146.65908
# Iteration=28, theta_new=[0.51266154], -likelihood = -146.65931
# Iteration=29, theta_new=[0.51256141], -likelihood = -146.65944
# Iteration=30, theta_new=[0.5124613], -likelihood = -146.65955
# Iteration=31, theta_new=[0.51241126], -likelihood = -146.65963
# Iteration=32, theta_new=[0.51236122], -likelihood = -146.65967
# Iteration=33, theta_new=[0.51231118], -likelihood = -146.65971
# Iteration=34, theta_new=[0.51226115], -likelihood = -146.65974
# Iteration=35, theta_new=[0.51221113], -likelihood = -146.65976
# Iteration=36, theta_new=[0.5121611], -likelihood = -146.65978
# norm=0.0
# Iteration=37, theta_new=[0.5121611], -likelihood = -146.65979
# 1-th start
# Iteration=1, theta_new=[1.57077176], -likelihood = -77.15149
# norm=0.0
# Iteration=2, theta_new=[1.57077176], -likelihood = -77.23370
# 2-th start
# Iteration=1, theta_new=[1.28262038], -likelihood = -75.25680
# Iteration=2, theta_new=[1.30203505], -likelihood = -75.52133
# Iteration=3, theta_new=[1.3225065], -likelihood = -75.77958
# Iteration=4, theta_new=[1.34413929], -likelihood = -76.02722
# Iteration=5, theta_new=[1.36717606], -likelihood = -76.26088
# Iteration=6, theta_new=[1.39207628], -likelihood = -76.47843
# Iteration=7, theta_new=[1.41953716], -likelihood = -76.67877
# Iteration=8, theta_new=[1.45121336], -likelihood = -76.86049
# Iteration=9, theta_new=[1.49202873], -likelihood = -77.02360
# Iteration=10, theta_new=[1.57078279], -likelihood = -77.16731
# norm=0.0
# Iteration=11, theta_new=[1.57078279], -likelihood = -77.23370
# 3-th start
# Iteration=1, theta_new=[-0.71131787], -likelihood = -70.77191
# Iteration=2, theta_new=[-0.70173175], -likelihood = -71.18101
# Iteration=3, theta_new=[-0.69165806], -likelihood = -71.64972
# Iteration=4, theta_new=[-0.68118863], -likelihood = -72.17516
# Iteration=5, theta_new=[-0.67041201], -likelihood = -72.75192
# Iteration=6, theta_new=[-0.65941307], -likelihood = -73.37216
# Iteration=7, theta_new=[-0.64833699], -likelihood = -74.02593
# Iteration=8, theta_new=[-0.63738364], -likelihood = -74.69765
# Iteration=9, theta_new=[-0.62661534], -likelihood = -75.36706
# Iteration=10, theta_new=[-0.61615135], -likelihood = -76.02214
# Iteration=11, theta_new=[-0.60610279], -likelihood = -76.64828
# Iteration=12, theta_new=[-0.59657325], -likelihood = -77.23304
# Iteration=13, theta_new=[-0.58760134], -likelihood = -77.76672
# Iteration=14, theta_new=[-0.57922343], -likelihood = -78.24569
# Iteration=15, theta_new=[-0.57141749], -likelihood = -78.66843
# Iteration=16, theta_new=[-0.56421897], -likelihood = -79.03788
# Iteration=17, theta_new=[-0.55760703], -likelihood = -79.35533
# Iteration=18, theta_new=[-0.55156266], -likelihood = -79.62545
# Iteration=19, theta_new=[-0.54601471], -likelihood = -79.85310
# Iteration=20, theta_new=[-0.54100247], -likelihood = -80.04489
# Iteration=21, theta_new=[-0.53645889], -likelihood = -80.20334
# Iteration=22, theta_new=[-0.5323202], -likelihood = -80.33435
# Iteration=23, theta_new=[-0.52857732], -likelihood = -80.44288
# Iteration=24, theta_new=[-0.52522209], -likelihood = -80.53192
# Iteration=25, theta_new=[-0.52219591], -likelihood = -80.60422
# Iteration=26, theta_new=[-0.51949314], -likelihood = -80.66322
# Iteration=27, theta_new=[-0.51705801], -likelihood = -80.71085
# Iteration=28, theta_new=[-0.51483628], -likelihood = -80.74962
# Iteration=29, theta_new=[-0.51287548], -likelihood = -80.78152
# Iteration=30, theta_new=[-0.5110724], -likelihood = -80.80691
# Iteration=31, theta_new=[-0.5094753], -likelihood = -80.82794
# Iteration=32, theta_new=[-0.5080822], -likelihood = -80.84470
# Iteration=33, theta_new=[-0.50679215], -likelihood = -80.85789
# Iteration=34, theta_new=[-0.50560436], -likelihood = -80.86890
# Iteration=35, theta_new=[-0.5045181], -likelihood = -80.87801
# Iteration=36, theta_new=[-0.50363125], -likelihood = -80.88548
# Iteration=37, theta_new=[-0.50274596], -likelihood = -80.89096
# Iteration=38, theta_new=[-0.50196042], -likelihood = -80.89588
# Iteration=39, theta_new=[-0.50127415], -likelihood = -80.89979
# Iteration=40, theta_new=[-0.50068671], -likelihood = -80.90284
# Iteration=41, theta_new=[-0.50009997], -likelihood = -80.90518
# Iteration=42, theta_new=[-0.49961159], -likelihood = -80.90729
# Iteration=43, theta_new=[-0.49922127], -likelihood = -80.90884
# Iteration=44, theta_new=[-0.49883126], -likelihood = -80.90997
# Iteration=45, theta_new=[-0.49844154], -likelihood = -80.91099
# Iteration=46, theta_new=[-0.49814949], -likelihood = -80.91190
# Iteration=47, theta_new=[-0.4978576], -likelihood = -80.91251
# Iteration=48, theta_new=[-0.49756589], -likelihood = -80.91305
# Iteration=49, theta_new=[-0.49737153], -likelihood = -80.91354
# Iteration=50, theta_new=[-0.49717724], -likelihood = -80.91383
# 4-th start
# Iteration=1, theta_new=[2.0836176], -likelihood = -72.68265
# Iteration=2, theta_new=[2.08549978], -likelihood = -72.68910
# Iteration=3, theta_new=[2.08768914], -likelihood = -72.69781
# Iteration=4, theta_new=[2.09023759], -likelihood = -72.70966
# Iteration=5, theta_new=[2.0931974], -likelihood = -72.72584
# Iteration=6, theta_new=[2.09667244], -likelihood = -72.74794
# Iteration=7, theta_new=[2.10071631], -likelihood = -72.77858
# Iteration=8, theta_new=[2.10543472], -likelihood = -72.82084
# Iteration=9, theta_new=[2.11098616], -likelihood = -72.87954
# Iteration=10, theta_new=[2.11747991], -likelihood = -72.96216
# Iteration=11, theta_new=[2.12513096], -likelihood = -73.07842
# Iteration=12, theta_new=[2.13415862], -likelihood = -73.24422
# Iteration=13, theta_new=[2.14483983], -likelihood = -73.48272
# Iteration=14, theta_new=[2.15745962], -likelihood = -73.82942
# Iteration=15, theta_new=[2.17241857], -likelihood = -74.33664
# Iteration=16, theta_new=[2.19018615], -likelihood = -75.08690
# Iteration=17, theta_new=[2.21114692], -likelihood = -76.20696
# Iteration=18, theta_new=[2.23570922], -likelihood = -77.87532
# Iteration=19, theta_new=[2.26403766], -likelihood = -80.34245
# Iteration=20, theta_new=[2.29593097], -likelihood = -83.90326
# Iteration=21, theta_new=[2.33051567], -likelihood = -88.82404
# Iteration=22, theta_new=[2.3663041], -likelihood = -95.16730
# Iteration=23, theta_new=[2.40160224], -likelihood = -102.63700
# Iteration=24, theta_new=[2.43478845], -likelihood = -110.60586
# Iteration=25, theta_new=[2.4648072], -likelihood = -118.29825
# Iteration=26, theta_new=[2.49122445], -likelihood = -125.10640
# Iteration=27, theta_new=[2.51391065], -likelihood = -130.73283
# Iteration=28, theta_new=[2.53318232], -likelihood = -135.12419
# Iteration=29, theta_new=[2.54938579], -likelihood = -138.43126
# Iteration=30, theta_new=[2.56289205], -likelihood = -140.85120
# Iteration=31, theta_new=[2.57415476], -likelihood = -142.58396
# Iteration=32, theta_new=[2.58351875], -likelihood = -143.81388
# Iteration=33, theta_new=[2.59127688], -likelihood = -144.67855
# Iteration=34, theta_new=[2.59772976], -likelihood = -145.28169
# Iteration=35, theta_new=[2.60312056], -likelihood = -145.70277
# Iteration=36, theta_new=[2.60756925], -likelihood = -145.99722
# Iteration=37, theta_new=[2.61126161], -likelihood = -146.20026
# Iteration=38, theta_new=[2.61432168], -likelihood = -146.34101
# Iteration=39, theta_new=[2.61687473], -likelihood = -146.43841
# Iteration=40, theta_new=[2.61898306], -likelihood = -146.50622
# Iteration=41, theta_new=[2.62077338], -likelihood = -146.55295
# Iteration=42, theta_new=[2.622245], -likelihood = -146.58603
# Iteration=43, theta_new=[2.62346137], -likelihood = -146.60867
# Iteration=44, theta_new=[2.62448616], -likelihood = -146.62426
# Iteration=45, theta_new=[2.62531913], -likelihood = -146.63521
# Iteration=46, theta_new=[2.62602417], -likelihood = -146.64263
# Iteration=47, theta_new=[2.62660118], -likelihood = -146.64787
# Iteration=48, theta_new=[2.62711419], -likelihood = -146.65146
# Iteration=49, theta_new=[2.62749902], -likelihood = -146.65411
# Iteration=50, theta_new=[2.62781976], -likelihood = -146.65576
# 5-th start
# Iteration=1, theta_new=[2.44276151], -likelihood = -112.61348
# Iteration=2, theta_new=[2.47192436], -likelihood = -120.13348
# Iteration=3, theta_new=[2.49739194], -likelihood = -126.66554
# Iteration=4, theta_new=[2.51915876], -likelihood = -131.97325
# Iteration=5, theta_new=[2.53760963], -likelihood = -136.06707
# Iteration=6, theta_new=[2.55309797], -likelihood = -139.12729
# Iteration=7, theta_new=[2.56600059], -likelihood = -141.35435
# Iteration=8, theta_new=[2.57671314], -likelihood = -142.94356
# Iteration=9, theta_new=[2.58564608], -likelihood = -144.06467
# Iteration=10, theta_new=[2.59303184], -likelihood = -144.85430
# Iteration=11, theta_new=[2.59917256], -likelihood = -145.40353
# Iteration=12, theta_new=[2.60431253], -likelihood = -145.78674
# Iteration=13, theta_new=[2.60857251], -likelihood = -146.05519
# Iteration=14, theta_new=[2.61207524], -likelihood = -146.24100
# Iteration=15, theta_new=[2.61500872], -likelihood = -146.36862
# Iteration=16, theta_new=[2.61743475], -likelihood = -146.45786
# Iteration=17, theta_new=[2.61947962], -likelihood = -146.51945
# Iteration=18, theta_new=[2.62114238], -likelihood = -146.56274
# Iteration=19, theta_new=[2.62255022], -likelihood = -146.59210
# Iteration=20, theta_new=[2.62370271], -likelihood = -146.61284
# Iteration=21, theta_new=[2.62466353], -likelihood = -146.62702
# Iteration=22, theta_new=[2.62549656], -likelihood = -146.63690
# Iteration=23, theta_new=[2.62620165], -likelihood = -146.64403
# Iteration=24, theta_new=[2.62677869], -likelihood = -146.64904
# Iteration=25, theta_new=[2.62722761], -likelihood = -146.65243
# Iteration=26, theta_new=[2.62761245], -likelihood = -146.65463
# Iteration=27, theta_new=[2.62793321], -likelihood = -146.65620
# Iteration=28, theta_new=[2.62818984], -likelihood = -146.65729
# Iteration=29, theta_new=[2.6284465], -likelihood = -146.65802
# Iteration=30, theta_new=[2.62863901], -likelihood = -146.65863
# Iteration=31, theta_new=[2.62876737], -likelihood = -146.65901
# Iteration=32, theta_new=[2.62889572], -likelihood = -146.65922
# Iteration=33, theta_new=[2.62902409], -likelihood = -146.65939
# Iteration=34, theta_new=[2.62908827], -likelihood = -146.65954
# Iteration=35, theta_new=[2.62915246], -likelihood = -146.65960
# Iteration=36, theta_new=[2.62921665], -likelihood = -146.65965
# Iteration=37, theta_new=[2.62928084], -likelihood = -146.65970
# Iteration=38, theta_new=[2.62934503], -likelihood = -146.65973
# Iteration=39, theta_new=[2.62940922], -likelihood = -146.65976
# norm=0.0
# Iteration=40, theta_new=[2.62940922], -likelihood = -146.65978
# 6-th start
# Iteration=1, theta_new=[-0.13423606], -likelihood = -66.25910
# Iteration=2, theta_new=[-0.13009362], -likelihood = -66.39243
# Iteration=3, theta_new=[-0.12572329], -likelihood = -66.53989
# Iteration=4, theta_new=[-0.12120511], -likelihood = -66.70295
# Iteration=5, theta_new=[-0.11647053], -likelihood = -66.87894
# Iteration=6, theta_new=[-0.11155693], -likelihood = -67.07068
# Iteration=7, theta_new=[-0.10650201], -likelihood = -67.27675
# Iteration=8, theta_new=[-0.10134332], -likelihood = -67.49532
# Iteration=9, theta_new=[-0.09603863], -likelihood = -67.72428
# Iteration=10, theta_new=[-0.09063646], -likelihood = -67.96488
# Iteration=11, theta_new=[-0.08518411], -likelihood = -68.21423
# Iteration=12, theta_new=[-0.079727], -likelihood = -68.46923
# Iteration=13, theta_new=[-0.07424577], -likelihood = -68.72678
# Iteration=14, theta_new=[-0.06873534], -likelihood = -68.98682
# Iteration=15, theta_new=[-0.06325799], -likelihood = -69.24868
# Iteration=16, theta_new=[-0.05782176], -likelihood = -69.50853
# Iteration=17, theta_new=[-0.05240097], -likelihood = -69.76523
# Iteration=18, theta_new=[-0.047079], -likelihood = -70.01934
# Iteration=19, theta_new=[-0.04178261], -likelihood = -70.26644
# Iteration=20, theta_new=[-0.03655978], -likelihood = -70.50954
# Iteration=21, theta_new=[-0.03147569], -likelihood = -70.74613
# Iteration=22, theta_new=[-0.02645925], -likelihood = -70.97317
# Iteration=23, theta_new=[-0.02149814], -likelihood = -71.19384
# Iteration=24, theta_new=[-0.01666106], -likelihood = -71.40871
# Iteration=25, theta_new=[-0.01192307], -likelihood = -71.61493
# Iteration=26, theta_new=[-0.00722836], -likelihood = -71.81382
# Iteration=27, theta_new=[-0.00262028], -likelihood = -72.00797
# Iteration=28, theta_new=[0.0018997], -likelihood = -72.19583
# Iteration=29, theta_new=[0.00636401], -likelihood = -72.37770
# Iteration=30, theta_new=[0.01073926], -likelihood = -72.55522
# Iteration=31, theta_new=[0.01510209], -likelihood = -72.72743
# Iteration=32, theta_new=[0.01944394], -likelihood = -72.89771
# Iteration=33, theta_new=[0.0236973], -likelihood = -73.06610
# Iteration=34, theta_new=[0.02791838], -likelihood = -73.23039
# Iteration=35, theta_new=[0.03219338], -likelihood = -73.39318
# Iteration=36, theta_new=[0.03646907], -likelihood = -73.55822
# Iteration=37, theta_new=[0.04074279], -likelihood = -73.72397
# Iteration=38, theta_new=[0.04500805], -likelihood = -73.89083
# Iteration=39, theta_new=[0.0493682], -likelihood = -74.05910
# Iteration=40, theta_new=[0.05376506], -likelihood = -74.23355
# Iteration=41, theta_new=[0.05821748], -likelihood = -74.41262
# Iteration=42, theta_new=[0.06276572], -likelihood = -74.59793
# Iteration=43, theta_new=[0.06747314], -likelihood = -74.79218
# Iteration=44, theta_new=[0.07232278], -likelihood = -74.99943
# Iteration=45, theta_new=[0.07735147], -likelihood = -75.22059
# Iteration=46, theta_new=[0.08254852], -likelihood = -75.45936
# Iteration=47, theta_new=[0.08803026], -likelihood = -75.71761
# Iteration=48, theta_new=[0.09380725], -likelihood = -76.00430
# Iteration=49, theta_new=[0.09989006], -likelihood = -76.32429
# Iteration=50, theta_new=[0.1063673], -likelihood = -76.68335
# 7-th start
# Iteration=1, theta_new=[2.28334939], -likelihood = -82.39437
# Iteration=2, theta_new=[2.31701987], -likelihood = -86.77033
# Iteration=3, theta_new=[2.35254449], -likelihood = -92.57680
# Iteration=4, theta_new=[2.38821173], -likelihood = -99.67349
# Iteration=5, theta_new=[2.42237902], -likelihood = -107.53549
# Iteration=6, theta_new=[2.45372328], -likelihood = -115.42270
# Iteration=7, theta_new=[2.48151936], -likelihood = -122.62909
# Iteration=8, theta_new=[2.50563178], -likelihood = -128.71993
# Iteration=9, theta_new=[2.52618579], -likelihood = -133.57804
# Iteration=10, theta_new=[2.54351632], -likelihood = -137.28107
# Iteration=11, theta_new=[2.55798505], -likelihood = -140.01572
# Iteration=12, theta_new=[2.5701005], -likelihood = -141.98596
# Iteration=13, theta_new=[2.58013996], -likelihood = -143.39453
# Iteration=14, theta_new=[2.58851786], -likelihood = -144.38353
# Iteration=15, theta_new=[2.59546944], -likelihood = -145.07918
# Iteration=16, theta_new=[2.60123574], -likelihood = -145.56372
# Iteration=17, theta_new=[2.60599875], -likelihood = -145.90027
# Iteration=18, theta_new=[2.60994338], -likelihood = -146.13274
# Iteration=19, theta_new=[2.61325678], -likelihood = -146.29366
# Iteration=20, theta_new=[2.61600019], -likelihood = -146.40650
# Iteration=21, theta_new=[2.61829941], -likelihood = -146.48437
# Iteration=22, theta_new=[2.62015318], -likelihood = -146.53872
# Iteration=23, theta_new=[2.6217524], -likelihood = -146.57526
# Iteration=24, theta_new=[2.62303255], -likelihood = -146.60155
# Iteration=25, theta_new=[2.62412121], -likelihood = -146.61908
# Iteration=26, theta_new=[2.62501813], -likelihood = -146.63154
# Iteration=27, theta_new=[2.62578718], -likelihood = -146.64010
# Iteration=28, theta_new=[2.62642824], -likelihood = -146.64622
# Iteration=29, theta_new=[2.62694121], -likelihood = -146.65045
# Iteration=30, theta_new=[2.62739015], -likelihood = -146.65327
# Iteration=31, theta_new=[2.62777502], -likelihood = -146.65532
# Iteration=32, theta_new=[2.6280958], -likelihood = -146.65678
# Iteration=33, theta_new=[2.62835245], -likelihood = -146.65777
# Iteration=34, theta_new=[2.62854495], -likelihood = -146.65843
# Iteration=35, theta_new=[2.62873747], -likelihood = -146.65883
# Iteration=36, theta_new=[2.62886583], -likelihood = -146.65917
# Iteration=37, theta_new=[2.62899419], -likelihood = -146.65935
# Iteration=38, theta_new=[2.62905838], -likelihood = -146.65950
# Iteration=39, theta_new=[2.62912256], -likelihood = -146.65957
# Iteration=40, theta_new=[2.62918675], -likelihood = -146.65963
# Iteration=41, theta_new=[2.62925094], -likelihood = -146.65968
# Iteration=42, theta_new=[2.62931513], -likelihood = -146.65972
# Iteration=43, theta_new=[2.62937932], -likelihood = -146.65975
# norm=0.0
# Iteration=44, theta_new=[2.62937932], -likelihood = -146.65977
# 8-th start
# Iteration=1, theta_new=[-1.46092275], -likelihood = -77.35779
# Iteration=2, theta_new=[-1.43481446], -likelihood = -77.46204
# Iteration=3, theta_new=[-1.4144272], -likelihood = -77.55255
# Iteration=4, theta_new=[-1.39764469], -likelihood = -77.63047
# Iteration=5, theta_new=[-1.38344987], -likelihood = -77.69737
# Iteration=6, theta_new=[-1.37122309], -likelihood = -77.75454
# Iteration=7, theta_new=[-1.36057736], -likelihood = -77.80327
# Iteration=8, theta_new=[-1.3512101], -likelihood = -77.84466
# Iteration=9, theta_new=[-1.342897], -likelihood = -77.87979
# Iteration=10, theta_new=[-1.33555303], -likelihood = -77.90962
# Iteration=11, theta_new=[-1.32896656], -likelihood = -77.93465
# Iteration=12, theta_new=[-1.32306148], -likelihood = -77.95586
# Iteration=13, theta_new=[-1.31776407], -likelihood = -77.97375
# Iteration=14, theta_new=[-1.31300262], -likelihood = -77.98878
# Iteration=15, theta_new=[-1.30877126], -likelihood = -78.00140
# Iteration=16, theta_new=[-1.30493697], -likelihood = -78.01184
# Iteration=17, theta_new=[-1.3014325], -likelihood = -78.02064
# Iteration=18, theta_new=[-1.29831872], -likelihood = -78.02810
# Iteration=19, theta_new=[-1.29546597], -likelihood = -78.03424
# Iteration=20, theta_new=[-1.29287251], -likelihood = -78.03943
# Iteration=21, theta_new=[-1.29053675], -likelihood = -78.04379
# Iteration=22, theta_new=[-1.28839426], -likelihood = -78.04742
# Iteration=23, theta_new=[-1.28650696], -likelihood = -78.05047
# Iteration=24, theta_new=[-1.28474807], -likelihood = -78.05295
# Iteration=25, theta_new=[-1.28317977], -likelihood = -78.05508
# Iteration=26, theta_new=[-1.2817387], -likelihood = -78.05682
# Iteration=27, theta_new=[-1.28042442], -likelihood = -78.05830
# Iteration=28, theta_new=[-1.27923652], -likelihood = -78.05953
# Iteration=29, theta_new=[-1.27817466], -likelihood = -78.06055
# Iteration=30, theta_new=[-1.27717608], -likelihood = -78.06139
# Iteration=31, theta_new=[-1.27630301], -likelihood = -78.06211
# Iteration=32, theta_new=[-1.27549286], -likelihood = -78.06269
# Iteration=33, theta_new=[-1.2747455], -likelihood = -78.06319
# Iteration=34, theta_new=[-1.27406082], -likelihood = -78.06360
# Iteration=35, theta_new=[-1.27343872], -likelihood = -78.06395
# Iteration=36, theta_new=[-1.27287911], -likelihood = -78.06425
# Iteration=37, theta_new=[-1.27238189], -likelihood = -78.06449
# Iteration=38, theta_new=[-1.27188487], -likelihood = -78.06468
# Iteration=39, theta_new=[-1.27145014], -likelihood = -78.06486
# Iteration=40, theta_new=[-1.27107764], -likelihood = -78.06501
# Iteration=41, theta_new=[-1.27070526], -likelihood = -78.06512
# Iteration=42, theta_new=[-1.27039503], -likelihood = -78.06522
# Iteration=43, theta_new=[-1.27008487], -likelihood = -78.06530
# Iteration=44, theta_new=[-1.26983681], -likelihood = -78.06537
# Iteration=45, theta_new=[-1.26958879], -likelihood = -78.06542
# Iteration=46, theta_new=[-1.26934083], -likelihood = -78.06547
# Iteration=47, theta_new=[-1.26915489], -likelihood = -78.06552
# Iteration=48, theta_new=[-1.26896898], -likelihood = -78.06555
# Iteration=49, theta_new=[-1.26878309], -likelihood = -78.06558
# Iteration=50, theta_new=[-1.26859724], -likelihood = -78.06560
# 9-th start
# Iteration=1, theta_new=[1.87117527], -likelihood = -75.08222
# Iteration=2, theta_new=[1.85244525], -likelihood = -75.34790
# Iteration=3, theta_new=[1.83272683], -likelihood = -75.61063
# Iteration=4, theta_new=[1.81187599], -likelihood = -75.86507
# Iteration=5, theta_new=[1.78975836], -likelihood = -76.10830
# Iteration=6, theta_new=[1.76616291], -likelihood = -76.33709
# Iteration=7, theta_new=[1.7405501], -likelihood = -76.54875
# Iteration=8, theta_new=[1.71190921], -likelihood = -76.74247
# Iteration=9, theta_new=[1.67797195], -likelihood = -76.91792
# Iteration=10, theta_new=[1.51115794], -likelihood = -77.07506
# Iteration=11, theta_new=[1.57077785], -likelihood = -77.20272
# norm=0.0
# Iteration=12, theta_new=[1.57077785], -likelihood = -77.23370

# %%
theta_ML, ML_func_val = multi_start_ML(X1, GS_1, GN_1)
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:818: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[k] = func(sim[k])
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:854: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxe
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:857: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxr
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:884: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxcc
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:872: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxc
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML
# Out:
# array([0.51204284])

# %%
EM_theta1_rad
# Out:
# array([0.5121611])

# %%
theta1_rad
# Out:
# [0.5]
