# %%
import numpy as np
import matplotlib.pyplot as plt
from sensors import *
from functools import partial

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
# Истинное DOA в градусах
theta1_deg = rad_to_deg(theta1_rad[0])
GS_1 = np.array([[0.7]]) # Ковариация сигнала
GN_1 = 4.1*np.eye(5, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s1 = CN(Num_emitters1, sample_size1, GS_1)
n1 = CN(Num_sensors1, sample_size1, GN_1)
X1 = (A1 @ s1.T + n1.T).T

# %%
EM_theta1_rad, neglhd_1, K1, mu1 = multi_start_EM(X1, GS_1, GN_1, 10, max_iter=50, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[0.07286404], -likelihood = -75.02430
# Iteration=2, theta_new=[0.07787345], -likelihood = -75.24581
# Iteration=3, theta_new=[0.08310557], -likelihood = -75.48475
# Iteration=4, theta_new=[0.0886243], -likelihood = -75.74604
# Iteration=5, theta_new=[0.09444027], -likelihood = -76.03632
# Iteration=6, theta_new=[0.10056413], -likelihood = -76.36055
# Iteration=7, theta_new=[0.10708508], -likelihood = -76.72464
# Iteration=8, theta_new=[0.11411254], -likelihood = -77.14081
# Iteration=9, theta_new=[0.12169033], -likelihood = -77.62570
# Iteration=10, theta_new=[0.12996147], -likelihood = -78.19524
# Iteration=11, theta_new=[0.13899785], -likelihood = -78.87764
# Iteration=12, theta_new=[0.14893403], -likelihood = -79.70237
# Iteration=13, theta_new=[0.15998772], -likelihood = -80.71286
# Iteration=14, theta_new=[0.17229928], -likelihood = -81.97432
# Iteration=15, theta_new=[0.18609668], -likelihood = -83.56033
# Iteration=16, theta_new=[0.20150781], -likelihood = -85.57466
# Iteration=17, theta_new=[0.21874618], -likelihood = -88.12634
# Iteration=18, theta_new=[0.23780102], -likelihood = -91.35158
# Iteration=19, theta_new=[0.25851572], -likelihood = -95.34223
# Iteration=20, theta_new=[0.28063093], -likelihood = -100.11884
# Iteration=21, theta_new=[0.30354181], -likelihood = -105.60428
# Iteration=22, theta_new=[0.32654459], -likelihood = -111.54169
# Iteration=23, theta_new=[0.34893075], -likelihood = -117.56904
# Iteration=24, theta_new=[0.37012557], -likelihood = -123.30394
# Iteration=25, theta_new=[0.38964391], -likelihood = -128.44579
# Iteration=26, theta_new=[0.40722355], -likelihood = -132.80432
# Iteration=27, theta_new=[0.42281258], -likelihood = -136.33265
# Iteration=28, theta_new=[0.43643837], -likelihood = -139.09128
# Iteration=29, theta_new=[0.44820175], -likelihood = -141.18539
# Iteration=30, theta_new=[0.45826878], -likelihood = -142.73784
# Iteration=31, theta_new=[0.46686132], -likelihood = -143.86940
# Iteration=32, theta_new=[0.47415603], -likelihood = -144.68697
# Iteration=33, theta_new=[0.4802682], -likelihood = -145.27172
# Iteration=34, theta_new=[0.48542733], -likelihood = -145.68340
# Iteration=35, theta_new=[0.48978859], -likelihood = -145.97491
# Iteration=36, theta_new=[0.49342374], -likelihood = -146.18119
# Iteration=37, theta_new=[0.49650764], -likelihood = -146.32495
# Iteration=38, theta_new=[0.49902897], -likelihood = -146.42682
# Iteration=39, theta_new=[0.50117323], -likelihood = -146.49640
# Iteration=40, theta_new=[0.50293517], -likelihood = -146.54586
# Iteration=41, theta_new=[0.50440861], -likelihood = -146.57984
# Iteration=42, theta_new=[0.50568934], -likelihood = -146.60365
# Iteration=43, theta_new=[0.50677578], -likelihood = -146.62092
# Iteration=44, theta_new=[0.50766659], -likelihood = -146.63309
# Iteration=45, theta_new=[0.50836067], -likelihood = -146.64137
# Iteration=46, theta_new=[0.5089564], -likelihood = -146.64676
# Iteration=47, theta_new=[0.50945343], -likelihood = -146.65064
# Iteration=48, theta_new=[0.50985144], -likelihood = -146.65335
# Iteration=49, theta_new=[0.51024976], -likelihood = -146.65518
# Iteration=50, theta_new=[0.51054874], -likelihood = -146.65671
# 1-th start
# Iteration=1, theta_new=[-0.35460379], -likelihood = -73.48443
# Iteration=2, theta_new=[-0.36499257], -likelihood = -74.33970
# Iteration=3, theta_new=[-0.3751867], -likelihood = -75.16368
# Iteration=4, theta_new=[-0.38500604], -likelihood = -75.94527
# Iteration=5, theta_new=[-0.3944056], -likelihood = -76.66488
# Iteration=6, theta_new=[-0.40326432], -likelihood = -77.31662
# Iteration=7, theta_new=[-0.41153439], -likelihood = -77.89249
# Iteration=8, theta_new=[-0.41925066], -likelihood = -78.39268
# Iteration=9, theta_new=[-0.42637465], -likelihood = -78.82401
# Iteration=10, theta_new=[-0.43295348], -likelihood = -79.18998
# Iteration=11, theta_new=[-0.43895732], -likelihood = -79.49906
# Iteration=12, theta_new=[-0.44444429], -likelihood = -79.75602
# Iteration=13, theta_new=[-0.44947901], -likelihood = -79.96932
# Iteration=14, theta_new=[-0.45404403], -likelihood = -80.14655
# Iteration=15, theta_new=[-0.45821201], -likelihood = -80.29169
# Iteration=16, theta_new=[-0.46197078], -likelihood = -80.41115
# Iteration=17, theta_new=[-0.46530924], -likelihood = -80.50809
# Iteration=18, theta_new=[-0.46830831], -likelihood = -80.58556
# Iteration=19, theta_new=[-0.4710523], -likelihood = -80.64821
# Iteration=20, theta_new=[-0.47353637], -likelihood = -80.69975
# Iteration=21, theta_new=[-0.47575607], -likelihood = -80.74163
# Iteration=22, theta_new=[-0.47780033], -likelihood = -80.77522
# Iteration=23, theta_new=[-0.47957342], -likelihood = -80.80296
# Iteration=24, theta_new=[-0.48116575], -likelihood = -80.82453
# Iteration=25, theta_new=[-0.48257542], -likelihood = -80.84193
# Iteration=26, theta_new=[-0.48389496], -likelihood = -80.85579
# Iteration=27, theta_new=[-0.48502909], -likelihood = -80.86743
# Iteration=28, theta_new=[-0.48607114], -likelihood = -80.87643
# Iteration=29, theta_new=[-0.4870205], -likelihood = -80.88387
# Iteration=30, theta_new=[-0.48787659], -likelihood = -80.88995
# Iteration=31, theta_new=[-0.4886389], -likelihood = -80.89487
# Iteration=32, theta_new=[-0.48930696], -likelihood = -80.89881
# Iteration=33, theta_new=[-0.48997594], -likelihood = -80.90190
# Iteration=34, theta_new=[-0.49055013], -likelihood = -80.90468
# Iteration=35, theta_new=[-0.49102918], -likelihood = -80.90681
# Iteration=36, theta_new=[-0.4915087], -likelihood = -80.90840
# Iteration=37, theta_new=[-0.49189269], -likelihood = -80.90983
# Iteration=38, theta_new=[-0.49227698], -likelihood = -80.91085
# Iteration=39, theta_new=[-0.49256543], -likelihood = -80.91176
# Iteration=40, theta_new=[-0.49285404], -likelihood = -80.91238
# Iteration=41, theta_new=[-0.49314282], -likelihood = -80.91294
# Iteration=42, theta_new=[-0.49333545], -likelihood = -80.91343
# Iteration=43, theta_new=[-0.49352816], -likelihood = -80.91373
# Iteration=44, theta_new=[-0.49372095], -likelihood = -80.91400
# Iteration=45, theta_new=[-0.49391381], -likelihood = -80.91425
# Iteration=46, theta_new=[-0.49410674], -likelihood = -80.91446
# Iteration=47, theta_new=[-0.49420325], -likelihood = -80.91465
# Iteration=48, theta_new=[-0.49429977], -likelihood = -80.91474
# Iteration=49, theta_new=[-0.49439631], -likelihood = -80.91482
# Iteration=50, theta_new=[-0.49449288], -likelihood = -80.91489
# 2-th start
# Iteration=1, theta_new=[2.81871884], -likelihood = -110.57263
# Iteration=2, theta_new=[2.79614706], -likelihood = -116.61115
# Iteration=3, theta_new=[2.77478002], -likelihood = -122.42728
# Iteration=4, theta_new=[2.75499887], -likelihood = -127.66682
# Iteration=5, theta_new=[2.73710752], -likelihood = -132.15155
# Iteration=6, theta_new=[2.72120343], -likelihood = -135.81074
# Iteration=7, theta_new=[2.70731839], -likelihood = -138.68705
# Iteration=8, theta_new=[2.6952888], -likelihood = -140.87356
# Iteration=9, theta_new=[2.68495773], -likelihood = -142.50393
# Iteration=10, theta_new=[2.67610839], -likelihood = -143.69837
# Iteration=11, theta_new=[2.66866023], -likelihood = -144.56526
# Iteration=12, theta_new=[2.66234041], -likelihood = -145.18071
# Iteration=13, theta_new=[2.65701053], -likelihood = -145.61994
# Iteration=14, theta_new=[2.65253461], -likelihood = -145.93067
# Iteration=15, theta_new=[2.64877858], -likelihood = -146.14920
# Iteration=16, theta_new=[2.64560987], -likelihood = -146.30263
# Iteration=17, theta_new=[2.64296168], -likelihood = -146.41079
# Iteration=18, theta_new=[2.64076781], -likelihood = -146.48623
# Iteration=19, theta_new=[2.63889813], -likelihood = -146.53844
# Iteration=20, theta_new=[2.6373519], -likelihood = -146.57556
# Iteration=21, theta_new=[2.63606413], -likelihood = -146.60115
# Iteration=22, theta_new=[2.63497006], -likelihood = -146.61893
# Iteration=23, theta_new=[2.63406944], -likelihood = -146.63152
# Iteration=24, theta_new=[2.63329774], -likelihood = -146.64014
# Iteration=25, theta_new=[2.63265484], -likelihood = -146.64628
# Iteration=26, theta_new=[2.63214065], -likelihood = -146.65053
# Iteration=27, theta_new=[2.63169082], -likelihood = -146.65335
# Iteration=28, theta_new=[2.63130532], -likelihood = -146.65539
# Iteration=29, theta_new=[2.63098412], -likelihood = -146.65684
# Iteration=30, theta_new=[2.63072718], -likelihood = -146.65783
# Iteration=31, theta_new=[2.6305345], -likelihood = -146.65847
# Iteration=32, theta_new=[2.63034184], -likelihood = -146.65887
# Iteration=33, theta_new=[2.6302134], -likelihood = -146.65920
# Iteration=34, theta_new=[2.63008497], -likelihood = -146.65938
# Iteration=35, theta_new=[2.63002076], -likelihood = -146.65953
# Iteration=36, theta_new=[2.62995655], -likelihood = -146.65959
# Iteration=37, theta_new=[2.62989235], -likelihood = -146.65965
# Iteration=38, theta_new=[2.62982814], -likelihood = -146.65969
# Iteration=39, theta_new=[2.62976393], -likelihood = -146.65973
# Iteration=40, theta_new=[2.62969973], -likelihood = -146.65976
# norm=0.0
# Iteration=41, theta_new=[2.62969973], -likelihood = -146.65978
# 3-th start
# Iteration=1, theta_new=[2.07348191], -likelihood = -72.66427
# Iteration=2, theta_new=[2.07378564], -likelihood = -72.66443
# Iteration=3, theta_new=[2.07414005], -likelihood = -72.66465
# Iteration=4, theta_new=[2.07454515], -likelihood = -72.66494
# Iteration=5, theta_new=[2.07500099], -likelihood = -72.66533
# Iteration=6, theta_new=[2.07555824], -likelihood = -72.66583
# Iteration=7, theta_new=[2.07616631], -likelihood = -72.66654
# Iteration=8, theta_new=[2.07687594], -likelihood = -72.66744
# Iteration=9, theta_new=[2.07768722], -likelihood = -72.66865
# Iteration=10, theta_new=[2.07865099], -likelihood = -72.67025
# Iteration=11, theta_new=[2.07976745], -likelihood = -72.67245
# Iteration=12, theta_new=[2.08103684], -likelihood = -72.67541
# Iteration=13, theta_new=[2.08251023], -likelihood = -72.67932
# Iteration=14, theta_new=[2.08423888], -likelihood = -72.68460
# Iteration=15, theta_new=[2.08622338], -likelihood = -72.69183
# Iteration=16, theta_new=[2.08856631], -likelihood = -72.70152
# Iteration=17, theta_new=[2.0912688], -likelihood = -72.71494
# Iteration=18, theta_new=[2.09443429], -likelihood = -72.73313
# Iteration=19, theta_new=[2.09811592], -likelihood = -72.75826
# Iteration=20, theta_new=[2.10241869], -likelihood = -72.79283
# Iteration=21, theta_new=[2.10744889], -likelihood = -72.84083
# Iteration=22, theta_new=[2.11331435], -likelihood = -72.90778
# Iteration=23, theta_new=[2.12022803], -likelihood = -73.00135
# Iteration=24, theta_new=[2.12835488], -likelihood = -73.13428
# Iteration=25, theta_new=[2.13796781], -likelihood = -73.32390
# Iteration=26, theta_new=[2.14934664], -likelihood = -73.59807
# Iteration=27, theta_new=[2.16283253], -likelihood = -73.99799
# Iteration=28, theta_new=[2.178832], -likelihood = -74.58682
# Iteration=29, theta_new=[2.19776912], -likelihood = -75.46148
# Iteration=30, theta_new=[2.22009021], -likelihood = -76.76572
# Iteration=31, theta_new=[2.24610689], -likelihood = -78.70807
# Iteration=32, theta_new=[2.27588316], -likelihood = -81.55965
# Iteration=33, theta_new=[2.30894348], -likelihood = -85.62027
# Iteration=34, theta_new=[2.34417516], -likelihood = -91.09535
# Iteration=35, theta_new=[2.38000166], -likelihood = -97.92403
# Iteration=36, theta_new=[2.41463255], -likelihood = -105.67802
# Iteration=37, theta_new=[2.44670188], -likelihood = -113.62364
# Iteration=38, theta_new=[2.47537417], -likelihood = -121.03485
# Iteration=39, theta_new=[2.50033339], -likelihood = -127.41090
# Iteration=40, theta_new=[2.52169854], -likelihood = -132.55328
# Iteration=41, theta_new=[2.53973706], -likelihood = -136.51241
# Iteration=42, theta_new=[2.55486635], -likelihood = -139.45266
# Iteration=43, theta_new=[2.56746604], -likelihood = -141.58698
# Iteration=44, theta_new=[2.57793398], -likelihood = -143.10782
# Iteration=45, theta_new=[2.58668234], -likelihood = -144.18051
# Iteration=46, theta_new=[2.59394475], -likelihood = -144.93709
# Iteration=47, theta_new=[2.59996098], -likelihood = -145.46476
# Iteration=48, theta_new=[2.60491208], -likelihood = -145.83103
# Iteration=49, theta_new=[2.60904585], -likelihood = -146.08336
# Iteration=50, theta_new=[2.61248551], -likelihood = -146.25958
# 4-th start
# Iteration=1, theta_new=[0.64326857], -likelihood = -126.91130
# Iteration=2, theta_new=[0.62159595], -likelihood = -132.15790
# Iteration=3, theta_new=[0.60326373], -likelihood = -136.21480
# Iteration=4, theta_new=[0.58788757], -likelihood = -139.23797
# Iteration=5, theta_new=[0.57508494], -likelihood = -141.43473
# Iteration=6, theta_new=[0.56441442], -likelihood = -143.00079
# Iteration=7, theta_new=[0.55554033], -likelihood = -144.10909
# Iteration=8, theta_new=[0.54821631], -likelihood = -144.88698
# Iteration=9, theta_new=[0.54211312], -likelihood = -145.42681
# Iteration=10, theta_new=[0.53703081], -likelihood = -145.80412
# Iteration=11, theta_new=[0.53283525], -likelihood = -146.06698
# Iteration=12, theta_new=[0.52934893], -likelihood = -146.24831
# Iteration=13, theta_new=[0.52645405], -likelihood = -146.37418
# Iteration=14, theta_new=[0.52403771], -likelihood = -146.46144
# Iteration=15, theta_new=[0.52204186], -likelihood = -146.52222
# Iteration=16, theta_new=[0.5203595], -likelihood = -146.56410
# Iteration=17, theta_new=[0.51898746], -likelihood = -146.59355
# Iteration=18, theta_new=[0.51782177], -likelihood = -146.61358
# Iteration=19, theta_new=[0.51686097], -likelihood = -146.62778
# Iteration=20, theta_new=[0.51605337], -likelihood = -146.63753
# Iteration=21, theta_new=[0.51539822], -likelihood = -146.64437
# Iteration=22, theta_new=[0.51484457], -likelihood = -146.64900
# Iteration=23, theta_new=[0.51439207], -likelihood = -146.65227
# Iteration=24, theta_new=[0.5139902], -likelihood = -146.65450
# Iteration=25, theta_new=[0.51368904], -likelihood = -146.65616
# Iteration=26, theta_new=[0.51343821], -likelihood = -146.65720
# Iteration=27, theta_new=[0.51318751], -likelihood = -146.65793
# Iteration=28, theta_new=[0.51298705], -likelihood = -146.65855
# Iteration=29, theta_new=[0.51283676], -likelihood = -146.65895
# Iteration=30, theta_new=[0.51268651], -likelihood = -146.65920
# Iteration=31, theta_new=[0.51258638], -likelihood = -146.65941
# Iteration=32, theta_new=[0.51248626], -likelihood = -146.65952
# Iteration=33, theta_new=[0.51243622], -likelihood = -146.65961
# Iteration=34, theta_new=[0.51238617], -likelihood = -146.65966
# Iteration=35, theta_new=[0.51233614], -likelihood = -146.65969
# Iteration=36, theta_new=[0.5122861], -likelihood = -146.65972
# Iteration=37, theta_new=[0.51223608], -likelihood = -146.65975
# Iteration=38, theta_new=[0.51218605], -likelihood = -146.65977
# norm=0.0
# Iteration=39, theta_new=[0.51218605], -likelihood = -146.65978
# 5-th start
# Iteration=1, theta_new=[-0.26498352], -likelihood = -67.20638
# Iteration=2, theta_new=[-0.27233267], -likelihood = -67.58387
# Iteration=3, theta_new=[-0.28025798], -likelihood = -68.02734
# Iteration=4, theta_new=[-0.28874235], -likelihood = -68.54087
# Iteration=5, theta_new=[-0.29782195], -likelihood = -69.12684
# Iteration=6, theta_new=[-0.30736156], -likelihood = -69.78964
# Iteration=7, theta_new=[-0.31732679], -likelihood = -70.51857
# Iteration=8, theta_new=[-0.32761512], -likelihood = -71.30693
# Iteration=9, theta_new=[-0.33810905], -likelihood = -72.13977
# Iteration=10, theta_new=[-0.34867495], -likelihood = -72.99824
# Iteration=11, theta_new=[-0.35916244], -likelihood = -73.86070
# Iteration=12, theta_new=[-0.36947433], -likelihood = -74.70409
# Iteration=13, theta_new=[-0.37950498], -likelihood = -75.51111
# Iteration=14, theta_new=[-0.38914085], -likelihood = -76.26620
# Iteration=15, theta_new=[-0.39826134], -likelihood = -76.95641
# Iteration=16, theta_new=[-0.40689552], -likelihood = -77.57211
# Iteration=17, theta_new=[-0.41492217], -likelihood = -78.11676
# Iteration=18, theta_new=[-0.42237781], -likelihood = -78.58640
# Iteration=19, theta_new=[-0.42930744], -likelihood = -78.98857
# Iteration=20, theta_new=[-0.43567997], -likelihood = -79.33126
# Iteration=21, theta_new=[-0.44146635], -likelihood = -79.61877
# Iteration=22, theta_new=[-0.44672601], -likelihood = -79.85614
# Iteration=23, theta_new=[-0.45152482], -likelihood = -80.05185
# Iteration=24, theta_new=[-0.45593424], -likelihood = -80.21343
# Iteration=25, theta_new=[-0.45985243], -likelihood = -80.34742
# Iteration=26, theta_new=[-0.46344502], -likelihood = -80.45472
# Iteration=27, theta_new=[-0.46670362], -likelihood = -80.54330
# Iteration=28, theta_new=[-0.46962052], -likelihood = -80.61551
# Iteration=29, theta_new=[-0.47228048], -likelihood = -80.67354
# Iteration=30, theta_new=[-0.47458654], -likelihood = -80.72102
# Iteration=31, theta_new=[-0.47671847], -likelihood = -80.75798
# Iteration=32, theta_new=[-0.47858065], -likelihood = -80.78866
# Iteration=33, theta_new=[-0.48026316], -likelihood = -80.81274
# Iteration=34, theta_new=[-0.48176398], -likelihood = -80.83229
# Iteration=35, theta_new=[-0.4831754], -likelihood = -80.84799
# Iteration=36, theta_new=[-0.48440221], -likelihood = -80.86124
# Iteration=37, theta_new=[-0.48553753], -likelihood = -80.87158
# Iteration=38, theta_new=[-0.48658068], -likelihood = -80.88016
# Iteration=39, theta_new=[-0.487436], -likelihood = -80.88721
# Iteration=40, theta_new=[-0.48829282], -likelihood = -80.89240
# Iteration=41, theta_new=[-0.48905577], -likelihood = -80.89707
# Iteration=42, theta_new=[-0.4897244], -likelihood = -80.90078
# Iteration=43, theta_new=[-0.4902983], -likelihood = -80.90368
# Iteration=44, theta_new=[-0.49077711], -likelihood = -80.90590
# Iteration=45, theta_new=[-0.49125638], -likelihood = -80.90759
# Iteration=46, theta_new=[-0.49164018], -likelihood = -80.90909
# Iteration=47, theta_new=[-0.49202427], -likelihood = -80.91019
# Iteration=48, theta_new=[-0.49240866], -likelihood = -80.91117
# Iteration=49, theta_new=[-0.49269718], -likelihood = -80.91205
# Iteration=50, theta_new=[-0.49298587], -likelihood = -80.91264
# 6-th start
# Iteration=1, theta_new=[-2.04764684], -likelihood = -76.13887
# Iteration=2, theta_new=[-2.03594886], -likelihood = -76.41519
# Iteration=3, theta_new=[-2.02481477], -likelihood = -76.65969
# Iteration=4, theta_new=[-2.0142359], -likelihood = -76.87211
# Iteration=5, theta_new=[-2.00420406], -likelihood = -77.05573
# Iteration=6, theta_new=[-1.99471149], -likelihood = -77.21372
# Iteration=7, theta_new=[-1.98575087], -likelihood = -77.34904
# Iteration=8, theta_new=[-1.97741227], -likelihood = -77.46444
# Iteration=9, theta_new=[-1.96959145], -likelihood = -77.56136
# Iteration=10, theta_new=[-1.96228242], -likelihood = -77.64336
# Iteration=11, theta_new=[-1.95547959], -likelihood = -77.71244
# Iteration=12, theta_new=[-1.94908227], -likelihood = -77.77040
# Iteration=13, theta_new=[-1.94318172], -likelihood = -77.81950
# Iteration=14, theta_new=[-1.93767857], -likelihood = -77.86029
# Iteration=15, theta_new=[-1.93256946], -likelihood = -77.89457
# Iteration=16, theta_new=[-1.92785127], -likelihood = -77.92325
# Iteration=17, theta_new=[-1.92352114], -likelihood = -77.94712
# Iteration=18, theta_new=[-1.91948249], -likelihood = -77.96688
# Iteration=19, theta_new=[-1.91582723], -likelihood = -77.98352
# Iteration=20, theta_new=[-1.91245956], -likelihood = -77.99712
# Iteration=21, theta_new=[-1.90928458], -likelihood = -78.00847
# Iteration=22, theta_new=[-1.90639455], -likelihood = -78.01814
# Iteration=23, theta_new=[-1.90369507], -likelihood = -78.02610
# Iteration=24, theta_new=[-1.90127827], -likelihood = -78.03283
# Iteration=25, theta_new=[-1.89905021], -likelihood = -78.03828
# Iteration=26, theta_new=[-1.89701021], -likelihood = -78.04284
# Iteration=27, theta_new=[-1.89515766], -likelihood = -78.04663
# Iteration=28, theta_new=[-1.89339946], -likelihood = -78.04976
# Iteration=29, theta_new=[-1.89182779], -likelihood = -78.05245
# Iteration=30, theta_new=[-1.8903498], -likelihood = -78.05464
# Iteration=31, theta_new=[-1.88905757], -likelihood = -78.05651
# Iteration=32, theta_new=[-1.88785846], -likelihood = -78.05800
# Iteration=33, theta_new=[-1.88675229], -likelihood = -78.05926
# Iteration=34, theta_new=[-1.8857389], -likelihood = -78.06032
# Iteration=35, theta_new=[-1.88481813], -likelihood = -78.06120
# Iteration=36, theta_new=[-1.88398984], -likelihood = -78.06193
# Iteration=37, theta_new=[-1.88316192], -likelihood = -78.06253
# Iteration=38, theta_new=[-1.88242631], -likelihood = -78.06308
# Iteration=39, theta_new=[-1.8817829], -likelihood = -78.06352
# Iteration=40, theta_new=[-1.88113971], -likelihood = -78.06388
# Iteration=41, theta_new=[-1.8805886], -likelihood = -78.06420
# Iteration=42, theta_new=[-1.88003764], -likelihood = -78.06445
# Iteration=43, theta_new=[-1.87957865], -likelihood = -78.06468
# Iteration=44, theta_new=[-1.87911977], -likelihood = -78.06485
# Iteration=45, theta_new=[-1.87875275], -likelihood = -78.06501
# Iteration=46, theta_new=[-1.87838581], -likelihood = -78.06512
# Iteration=47, theta_new=[-1.87801893], -likelihood = -78.06522
# Iteration=48, theta_new=[-1.87774383], -likelihood = -78.06532
# Iteration=49, theta_new=[-1.87746877], -likelihood = -78.06538
# Iteration=50, theta_new=[-1.87719375], -likelihood = -78.06544
# 7-th start
# Iteration=1, theta_new=[-0.5339651], -likelihood = -80.28344
# Iteration=2, theta_new=[-0.53010636], -likelihood = -80.40099
# Iteration=3, theta_new=[-0.52658613], -likelihood = -80.49660
# Iteration=4, theta_new=[-0.52344924], -likelihood = -80.57569
# Iteration=5, theta_new=[-0.52058662], -likelihood = -80.63950
# Iteration=6, theta_new=[-0.5180447], -likelihood = -80.69216
# Iteration=7, theta_new=[-0.51571754], -likelihood = -80.73438
# Iteration=8, theta_new=[-0.51365266], -likelihood = -80.76927
# Iteration=9, theta_new=[-0.51179669], -likelihood = -80.79716
# Iteration=10, theta_new=[-0.51009736], -likelihood = -80.81976
# Iteration=11, theta_new=[-0.50860294], -likelihood = -80.83839
# Iteration=12, theta_new=[-0.50721222], -likelihood = -80.85312
# Iteration=13, theta_new=[-0.50602345], -likelihood = -80.86544
# Iteration=14, theta_new=[-0.50493629], -likelihood = -80.87491
# Iteration=15, theta_new=[-0.50395008], -likelihood = -80.88270
# Iteration=16, theta_new=[-0.50306423], -likelihood = -80.88906
# Iteration=17, theta_new=[-0.50227819], -likelihood = -80.89418
# Iteration=18, theta_new=[-0.50159149], -likelihood = -80.89826
# Iteration=19, theta_new=[-0.50100368], -likelihood = -80.90146
# Iteration=20, theta_new=[-0.50041657], -likelihood = -80.90395
# Iteration=21, theta_new=[-0.49992788], -likelihood = -80.90618
# Iteration=22, theta_new=[-0.49943967], -likelihood = -80.90786
# Iteration=23, theta_new=[-0.49904948], -likelihood = -80.90936
# Iteration=24, theta_new=[-0.4986596], -likelihood = -80.91044
# Iteration=25, theta_new=[-0.49836742], -likelihood = -80.91140
# Iteration=26, theta_new=[-0.49807541], -likelihood = -80.91206
# Iteration=27, theta_new=[-0.49778356], -likelihood = -80.91265
# Iteration=28, theta_new=[-0.49749189], -likelihood = -80.91318
# Iteration=29, theta_new=[-0.49729756], -likelihood = -80.91365
# Iteration=30, theta_new=[-0.4971033], -likelihood = -80.91394
# Iteration=31, theta_new=[-0.49690912], -likelihood = -80.91419
# Iteration=32, theta_new=[-0.49671502], -likelihood = -80.91441
# Iteration=33, theta_new=[-0.496618], -likelihood = -80.91461
# Iteration=34, theta_new=[-0.49652101], -likelihood = -80.91470
# Iteration=35, theta_new=[-0.49642403], -likelihood = -80.91478
# Iteration=36, theta_new=[-0.49632707], -likelihood = -80.91486
# Iteration=37, theta_new=[-0.49623014], -likelihood = -80.91493
# Iteration=38, theta_new=[-0.49613322], -likelihood = -80.91499
# Iteration=39, theta_new=[-0.49603631], -likelihood = -80.91505
# Iteration=40, theta_new=[-0.49593943], -likelihood = -80.91509
# Iteration=41, theta_new=[-0.49584257], -likelihood = -80.91513
# norm=0.0
# Iteration=42, theta_new=[-0.49584257], -likelihood = -80.91517
# 8-th start
# Iteration=1, theta_new=[-0.52827217], -likelihood = -80.45181
# Iteration=2, theta_new=[-0.52497047], -likelihood = -80.53879
# Iteration=3, theta_new=[-0.521997], -likelihood = -80.60935
# Iteration=4, theta_new=[-0.51929526], -likelihood = -80.66689
# Iteration=5, theta_new=[-0.51686107], -likelihood = -80.71415
# Iteration=6, theta_new=[-0.51469065], -likelihood = -80.75258
# Iteration=7, theta_new=[-0.51273041], -likelihood = -80.78350
# Iteration=8, theta_new=[-0.51097791], -likelihood = -80.80869
# Iteration=9, theta_new=[-0.5093811], -likelihood = -80.82898
# Iteration=10, theta_new=[-0.50798826], -likelihood = -80.84564
# Iteration=11, theta_new=[-0.50669845], -likelihood = -80.85874
# Iteration=12, theta_new=[-0.50551088], -likelihood = -80.86966
# Iteration=13, theta_new=[-0.50452355], -likelihood = -80.87868
# Iteration=14, theta_new=[-0.50363669], -likelihood = -80.88544
# Iteration=15, theta_new=[-0.50275139], -likelihood = -80.89093
# Iteration=16, theta_new=[-0.50196584], -likelihood = -80.89585
# Iteration=17, theta_new=[-0.50127956], -likelihood = -80.89976
# Iteration=18, theta_new=[-0.50069213], -likelihood = -80.90282
# Iteration=19, theta_new=[-0.50010538], -likelihood = -80.90516
# Iteration=20, theta_new=[-0.49961699], -likelihood = -80.90727
# Iteration=21, theta_new=[-0.49922667], -likelihood = -80.90883
# Iteration=22, theta_new=[-0.49883665], -likelihood = -80.90996
# Iteration=23, theta_new=[-0.49844693], -likelihood = -80.91097
# Iteration=24, theta_new=[-0.49815487], -likelihood = -80.91189
# Iteration=25, theta_new=[-0.49786298], -likelihood = -80.91250
# Iteration=26, theta_new=[-0.49757127], -likelihood = -80.91304
# Iteration=27, theta_new=[-0.4973769], -likelihood = -80.91353
# Iteration=28, theta_new=[-0.49718262], -likelihood = -80.91382
# Iteration=29, theta_new=[-0.4969884], -likelihood = -80.91409
# Iteration=30, theta_new=[-0.49679427], -likelihood = -80.91432
# Iteration=31, theta_new=[-0.49669724], -likelihood = -80.91453
# Iteration=32, theta_new=[-0.49660023], -likelihood = -80.91463
# Iteration=33, theta_new=[-0.49650323], -likelihood = -80.91472
# Iteration=34, theta_new=[-0.49640626], -likelihood = -80.91480
# Iteration=35, theta_new=[-0.49630931], -likelihood = -80.91487
# Iteration=36, theta_new=[-0.49621237], -likelihood = -80.91494
# Iteration=37, theta_new=[-0.49611545], -likelihood = -80.91500
# Iteration=38, theta_new=[-0.49601856], -likelihood = -80.91505
# Iteration=39, theta_new=[-0.49592168], -likelihood = -80.91510
# Iteration=40, theta_new=[-0.49582482], -likelihood = -80.91514
# norm=0.0
# Iteration=41, theta_new=[-0.49582482], -likelihood = -80.91517
# 9-th start
# Iteration=1, theta_new=[0.4717012], -likelihood = -144.42991
# Iteration=2, theta_new=[0.47824237], -likelihood = -145.08624
# Iteration=3, theta_new=[0.48375336], -likelihood = -145.55490
# Iteration=4, theta_new=[0.48838303], -likelihood = -145.88596
# Iteration=5, theta_new=[0.49229391], -likelihood = -146.11873
# Iteration=6, theta_new=[0.49556305], -likelihood = -146.28301
# Iteration=7, theta_new=[0.49827316], -likelihood = -146.39758
# Iteration=8, theta_new=[0.5005115], -likelihood = -146.47683
# Iteration=9, theta_new=[0.50246662], -likelihood = -146.53154
# Iteration=10, theta_new=[0.50403683], -likelihood = -146.57140
# Iteration=11, theta_new=[0.50531661], -likelihood = -146.59803
# Iteration=12, theta_new=[0.50640225], -likelihood = -146.61622
# Iteration=13, theta_new=[0.50729241], -likelihood = -146.62916
# Iteration=14, theta_new=[0.50808506], -likelihood = -146.63808
# Iteration=15, theta_new=[0.5087797], -likelihood = -146.64472
# Iteration=16, theta_new=[0.50927656], -likelihood = -146.64955
# Iteration=17, theta_new=[0.5097739], -likelihood = -146.65244
# Iteration=18, theta_new=[0.51017216], -likelihood = -146.65485
# Iteration=19, theta_new=[0.51047109], -likelihood = -146.65644
# Iteration=20, theta_new=[0.51077019], -likelihood = -146.65742
# Iteration=21, theta_new=[0.51096971], -likelihood = -146.65825
# Iteration=22, theta_new=[0.51116931], -likelihood = -146.65870
# Iteration=23, theta_new=[0.51126915], -likelihood = -146.65906
# Iteration=24, theta_new=[0.51136901], -likelihood = -146.65923
# Iteration=25, theta_new=[0.51146888], -likelihood = -146.65937
# Iteration=26, theta_new=[0.51156878], -likelihood = -146.65949
# Iteration=27, theta_new=[0.51166869], -likelihood = -146.65959
# Iteration=28, theta_new=[0.51176863], -likelihood = -146.65966
# norm=0.0
# Iteration=29, theta_new=[0.51176863], -likelihood = -146.65972

# %%
theta_ML, ML_func_val = multi_start_ML(X1, GS_1, GN_1)
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:818: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[k] = func(sim[k])
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:854: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxe
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:857: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxr
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:884: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxcc
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:872: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxc
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML
# Out:
# array([0.51204729])

# %%
EM_theta1_rad
# Out:
# array([0.51218605])

# %%
theta1_rad
# Out:
# [0.5]
