# %%
import numpy as np
import sensors
import ecm_stoch

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.7] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
P_1 = 1 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация шума
Q_1 = 1.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шума
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
n1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + n1.T).T

# %%
X1_with_mv = sensors.MCAR(X1, [2,4], [40, 40])

# %%
ECM_theta1_rad, ECM_P, lhd_1 = ecm_stoch.multi_start_ECM(X1, 1, Q_1, 10, 
                                                         max_iter=10, 
                                                         rtol=1e-3)
# Out:
# 0-th start
# Initial theta = [-2.83488836]
# likelihood is -1084.745830993925 on iteration 0
# likelihood is -1067.762290276114 on iteration 1
# likelihood is -1061.4103512765212 on iteration 2
# likelihood is -1058.3046495892079 on iteration 3
# likelihood is -1056.568849362241 on iteration 4
# likelihood is -1055.5211551945483 on iteration 5
# likelihood is -1054.8528242040957 on iteration 6
# likelihood is -1054.4047909452033 on iteration 7
# likelihood is -1054.0970899502643 on iteration 8
# likelihood is -1053.8773292575845 on iteration 9
# 1-th start
# Initial theta = [-2.86887136]
# likelihood is -1088.234153181677 on iteration 0
# likelihood is -1069.8765994096716 on iteration 1
# likelihood is -1062.6782923533633 on iteration 2
# likelihood is -1059.0345924432831 on iteration 3
# likelihood is -1056.9703749532075 on iteration 4
# likelihood is -1055.724755125471 on iteration 5
# likelihood is -1054.9411912123003 on iteration 6
# likelihood is -1054.4303875871385 on iteration 7
# likelihood is -1054.0861746856112 on iteration 8
# likelihood is -1053.8505554979206 on iteration 9
# 2-th start
# Initial theta = [-0.32903623]
# likelihood is -1084.819168793887 on iteration 0
# likelihood is -1067.3621340533132 on iteration 1
# likelihood is -1061.1370039367318 on iteration 2
# likelihood is -1058.1583300970015 on iteration 3
# likelihood is -1056.508605054046 on iteration 4
# likelihood is -1055.5094974676817 on iteration 5
# likelihood is -1054.8657221823623 on iteration 6
# likelihood is -1054.4311840906566 on iteration 7
# likelihood is -1054.1267641283343 on iteration 8
# likelihood is -1053.9070552280698 on iteration 9
# 3-th start
# Initial theta = [2.8344867]
# likelihood is -1059.788940247028 on iteration 0
# likelihood is -995.5683951763414 on iteration 1
# likelihood is -924.9261514403963 on iteration 2
# likelihood is -855.006863091051 on iteration 3
# likelihood is -799.7504877428956 on iteration 4
# likelihood is -766.0559144586446 on iteration 5
# likelihood is -748.5472440579443 on iteration 6
# likelihood is -739.8165784689005 on iteration 7
# likelihood is -735.4097262241568 on iteration 8
# likelihood is -733.1578324235385 on iteration 9
# 4-th start
# Initial theta = [-2.08143765]
# likelihood is -1089.6277158687703 on iteration 0
# likelihood is -1072.2307434695588 on iteration 1
# likelihood is -1065.716871831897 on iteration 2
# likelihood is -1062.456121705899 on iteration 3
# likelihood is -1060.5626200722759 on iteration 4
# likelihood is -1059.3620767185162 on iteration 5
# likelihood is -1058.5501242386351 on iteration 6
# likelihood is -1057.9775002683173 on iteration 7
# likelihood is -1057.5579616395878 on iteration 8
# likelihood is -1057.2423808485387 on iteration 9
# 5-th start
# Initial theta = [-1.9246683]
# likelihood is -1094.180513786797 on iteration 0
# likelihood is -1076.1706813233882 on iteration 1
# likelihood is -1069.2495912277461 on iteration 2
# likelihood is -1065.5858842379885 on iteration 3
# likelihood is -1063.2625588198493 on iteration 4
# likelihood is -1061.605130632797 on iteration 5
# likelihood is -1060.3259522484045 on iteration 6
# likelihood is -1059.310752615914 on iteration 7
# likelihood is -1058.5051974220237 on iteration 8
# likelihood is -1057.868306644542 on iteration 9
# 6-th start
# Initial theta = [0.20336959]
# likelihood is -1069.8656460031254 on iteration 0
# likelihood is -1062.2308389506097 on iteration 1
# likelihood is -1057.7836712143717 on iteration 2
# likelihood is -1055.0959727170696 on iteration 3
# likelihood is -881.4775974964253 on iteration 4
# likelihood is -807.5931372907606 on iteration 5
# likelihood is -753.7205632224805 on iteration 6
# likelihood is -734.7210639991446 on iteration 7
# likelihood is -731.2588320789573 on iteration 8
# likelihood is -730.8299395474378 on iteration 9
# 7-th start
# Initial theta = [0.98360982]
# likelihood is -873.4647672592735 on iteration 0
# likelihood is -817.2661062561446 on iteration 1
# likelihood is -779.4554199440182 on iteration 2
# likelihood is -756.8805080682862 on iteration 3
# likelihood is -744.4905423716914 on iteration 4
# likelihood is -737.9216231509341 on iteration 5
# likelihood is -734.4982047864987 on iteration 6
# likelihood is -732.7026010836289 on iteration 7
# likelihood is -731.7715234636967 on iteration 8
# likelihood is -731.2868730317938 on iteration 9
# 8-th start
# Initial theta = [0.51131793]
# likelihood is -821.6738822673007 on iteration 0
# likelihood is -780.7165256151308 on iteration 1
# likelihood is -756.9620659700961 on iteration 2
# likelihood is -744.2886850948091 on iteration 3
# likelihood is -737.732446457681 on iteration 4
# likelihood is -734.3426277489632 on iteration 5
# likelihood is -732.6101664451821 on iteration 6
# likelihood is -731.7217412580395 on iteration 7
# likelihood is -731.259272498119 on iteration 8
# likelihood is -731.0191470900269 on iteration 9
# 9-th start
# Initial theta = [2.72188548]
# likelihood is -918.9773495987057 on iteration 0
# likelihood is -846.5152473159235 on iteration 1
# likelihood is -796.5854333530681 on iteration 2
# likelihood is -765.8534004541112 on iteration 3
# likelihood is -748.9733824087949 on iteration 4
# likelihood is -740.1522940747699 on iteration 5
# likelihood is -735.600562792859 on iteration 6
# likelihood is -733.2590236990973 on iteration 7
# likelihood is -732.0528992726732 on iteration 8
# likelihood is -731.4294621378151 on iteration 9
# best_start=6

# %%
ECM_theta1_rad
# Out:
# array([0.6905615])

# %%
ECM_P
# Out:
# array([[1.07530294]])

# %%
ECM_theta1_deg = np.rad2deg(ECM_theta1_rad)

# %%
print(f"Погрешность в смысле разности углов в градусах: \
      {np.abs(ECM_theta1_deg-theta1_deg)},")
print(f"Погрешность в смысле разности синусов углов: \
      {np.abs(np.sin(ECM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах:       [0.5407861],
# Погрешность в смысле разности синусов углов:       [0.00724755].
