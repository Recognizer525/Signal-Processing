# %%
import numpy as np

import sensors
import em_stoch

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 20
Num_emitters1 = 1
sample_size1 = 80
failing_sensors1 = np.array([2, 4], dtype=np.int16)
gap_ratio1 = np.array([0.5, 0.5], dtype=np.float32)
theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P_1 = 1 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q_1 = 2.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
N1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + N1.T).T

Num_sensors2 = 20
Num_emitters2 = 2
sample_size2 = 80
failing_sensors2 = np.array([2, 4], dtype=np.int16)
gap_ratio2 = np.array([0.5, 0.5], dtype=np.float32)
theta2_rad = np.array([-0.5, 0.7], dtype=np.float64) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P_2 = 1 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q_2 = 1.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sensors.gss(Num_emitters2, sample_size2, P_2)
N2 = sensors.gss(Num_sensors2, sample_size2, Q_2)
X2 = (A2 @ S2.T + N2.T).T

# %%
X1_with_mv = sensors.MCAR(X1, failing_sensors1, gap_ratio1)
X2_with_mv = sensors.MCAR(X2, failing_sensors2, gap_ratio2)
# Out:
# share_mv=[0.5 0.5]
# mis_cols=[2 4]
# share_mv=[0.5 0.5]
# mis_cols=[2 4]

# %%
X1_with_mv
# Out:
# array([[ 1.47375889-1.19127215j,  0.03175204-1.88842948j,
#                 nan+0.j        , ..., -0.76397286-2.94873339j,
#          0.72662444+0.27358696j,  1.62576741-0.61924096j],
#        [-0.75093165-1.09293498j, -0.99980865-0.34039036j,
#          2.94445197-1.56076135j, ...,  0.33293359+0.82505105j,
#          0.07846728+0.13232699j, -1.07843768+0.39630101j],
#        [ 0.76613778+1.51307616j,  0.98300291+0.8604167j ,
#         -2.77695094-1.28910182j, ..., -0.60766186+0.05449384j,
#         -1.0589133 -1.09211055j, -0.1291021 +1.6502334j ],
#        ...,
#        [ 1.16245983+2.06921586j,  2.97479457-1.66960229j,
#         -2.74510029-0.87284081j, ...,  1.19492776-0.80840476j,
#         -2.23063739-0.51135893j,  0.20866592+3.56230975j],
#        [ 1.57700122+0.90672591j, -2.1236758 -2.06001117j,
#         -1.06651492+2.87218098j, ..., -1.12889979-0.66445606j,
#         -0.37962652-0.26983634j,  1.95978744-1.35519038j],
#        [-0.56114001+1.07715026j, -0.59027711+0.12132465j,
#                 nan+0.j        , ...,  1.47473186+0.5409653j ,
#         -1.79549689-0.86866438j, -0.2348961 -0.34663937j]], shape=(80, 20))

# %%
print(np.trace(sensors.initial_Cov(X1_with_mv)))
print(np.trace(sensors.complex_cov(X1)))
# Out:
# Way First
# (73.88343486532314+0j)
# (63.702954966635296+0j)

# %%
EM_theta1_rad, EM_P1, lhd_1 = em_stoch.multi_start_EM(X1_with_mv, 
                                                      Num_emitters1, 
                                                      Q=Q_1, 
                                                      num_of_starts=10, 
                                                      max_iter=30, 
                                                      rtol=1e-6)
# Out:
# Way First
# 0-th start
# theta=[0.15335215],P=[[0.00022361+0.j]]
# Way First
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379+0.00000000e+00j
#  1.98180846-1.35525272e-20j 1.24264901-3.38813179e-21j
#  3.65111824+0.00000000e+00j 1.6804558 +0.00000000e+00j
#  0.96155409-6.77626358e-21j 1.27025671+0.00000000e+00j
#  1.65889204+0.00000000e+00j 1.36190987+0.00000000e+00j
#  1.09550401+0.00000000e+00j 0.89691465+0.00000000e+00j
#  1.6196736 +1.35525272e-20j 0.79194526-1.69406589e-21j
#  1.14151686+0.00000000e+00j 2.29130715+1.35525272e-20j
#  1.17223031+0.00000000e+00j 1.31477482+0.00000000e+00j
#  1.22932654+0.00000000e+00j 1.67873947+0.00000000e+00j]
# new_angles=[0.15335215]
# likelihood is -3420.8363426126166 on iteration 0
# new_angles=[0.15335215]
# 1-th start
# theta=[0.13636065],P=[[0.0023446-2.48253415e-17j]]
# Way First
# Initial diagonal of diff is [1.83120106+2.48253415e-17j 3.0029428 +2.48282297e-17j
#  1.97968746+2.47198095e-17j 1.24052801+2.47198095e-17j
#  3.64899724+2.48824399e-17j 1.67833481+2.51534904e-17j
#  0.95943309+2.47198095e-17j 1.26813572+2.48824399e-17j
#  1.65677104+2.49366500e-17j 1.35978887+2.47198095e-17j
#  1.09338301+2.47198095e-17j 0.89479365+2.48214535e-17j
#  1.61755261+2.48282297e-17j 0.78982427+2.47198095e-17j
#  1.13939587+2.47198095e-17j 2.28918616+2.48282297e-17j
#  1.17010932+2.47198095e-17j 1.31265383+2.49366500e-17j
#  1.22720554+2.48282297e-17j 1.67661847+2.47198095e-17j]
# new_angles=[0.13252574]
# likelihood is -3420.679837409119 on iteration 0
# new_angles=[0.13170919]
# likelihood is -3420.813275785244 on iteration 1
# new_angles=[0.1309383]
# likelihood is -3421.019142497723 on iteration 2
# new_angles=[0.13021115]
# likelihood is -3421.3294315828302 on iteration 3
# new_angles=[0.12952602]
# likelihood is -3421.787924804277 on iteration 4
# new_angles=[0.12887942]
# likelihood is -3422.450637101291 on iteration 5
# new_angles=[0.12827241]
# likelihood is -3423.381938477321 on iteration 6
# new_angles=[0.1277017]
# likelihood is -3424.6416219239704 on iteration 7
# new_angles=[0.12716515]
# likelihood is -3426.2626418373748 on iteration 8
# new_angles=[0.126661]
# likelihood is -3428.2247064029407 on iteration 9
# new_angles=[0.1261875]
# likelihood is -3430.4400004617405 on iteration 10
# new_angles=[0.12574299]
# likelihood is -3432.7673801913775 on iteration 11
# new_angles=[0.12532614]
# likelihood is -3435.0536989190296 on iteration 12
# new_angles=[0.12493559]
# likelihood is -3437.1789148506987 on iteration 13
# new_angles=[0.12456977]
# likelihood is -3439.0799462717314 on iteration 14
# new_angles=[0.12422777]
# likelihood is -3440.747377785723 on iteration 15
# new_angles=[0.12390798]
# likelihood is -3442.2065364261293 on iteration 16
# new_angles=[0.12360929]
# likelihood is -3443.4975020830393 on iteration 17
# new_angles=[0.12333034]
# likelihood is -3444.6612014849934 on iteration 18
# new_angles=[0.1230698]
# likelihood is -3445.7325510936703 on iteration 19
# new_angles=[0.12282676]
# likelihood is -3446.7384553290544 on iteration 20
# new_angles=[0.12259984]
# likelihood is -3447.698287667622 on iteration 21
# new_angles=[0.12238827]
# likelihood is -3448.62540973307 on iteration 22
# new_angles=[0.12219089]
# likelihood is -3449.528707401171 on iteration 23
# new_angles=[0.12200662]
# likelihood is -3450.413965574152 on iteration 24
# new_angles=[0.12183483]
# likelihood is -3451.2849025922983 on iteration 25
# new_angles=[0.12167453]
# likelihood is -3452.143871046703 on iteration 26
# new_angles=[0.12152507]
# likelihood is -3452.992377763709 on iteration 27
# new_angles=[0.12138561]
# likelihood is -3453.8313909912795 on iteration 28
# new_angles=[0.1212554]
# likelihood is -3454.6615554538553 on iteration 29
# 2-th start
# theta=[1.40627821],P=[[0.00072472+1.11520089e-18j]]
# Way First
# Initial diagonal of diff is [1.83282094-1.11520089e-18j 3.00456268-1.11130723e-18j
#  1.98130735-1.12485975e-18j 1.2421479 -1.11130723e-18j
#  3.65061713-1.13841228e-18j 1.67995469-1.11130723e-18j
#  0.96105298-1.11130723e-18j 1.2697556 -1.08420217e-18j
#  1.65839093-1.11130723e-18j 1.36140876-1.08420217e-18j
#  1.0950029 -1.08420217e-18j 0.89641354-1.13841228e-18j
#  1.6191725 -1.08420217e-18j 0.79144415-1.08420217e-18j
#  1.14101576-1.13841228e-18j 2.29080604-1.13841228e-18j
#  1.1717292 -1.08420217e-18j 1.31427371-1.13841228e-18j
#  1.22882543-1.02999206e-18j 1.67823836-1.08420217e-18j]
# new_angles=[1.45456866]
# likelihood is -3420.8109572973913 on iteration 0
# new_angles=[1.45456866]
# 3-th start
# theta=[-0.15355298],P=[[0.00022361+0.j]]
# Way First
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379-1.35525272e-20j
#  1.98180846+0.00000000e+00j 1.24264901-3.38813179e-21j
#  3.65111824+0.00000000e+00j 1.6804558 +0.00000000e+00j
#  0.96155409+6.77626358e-21j 1.27025671-6.77626358e-21j
#  1.65889204+0.00000000e+00j 1.36190987+1.35525272e-20j
#  1.09550401+0.00000000e+00j 0.89691465+0.00000000e+00j
#  1.6196736 +0.00000000e+00j 0.79194526+0.00000000e+00j
#  1.14151686+0.00000000e+00j 2.29130715-1.35525272e-20j
#  1.17223031+0.00000000e+00j 1.31477482-1.35525272e-20j
#  1.22932654+1.35525272e-20j 1.67873947+0.00000000e+00j]
# new_angles=[-0.15355298]
# likelihood is -3420.896866232598 on iteration 0
# new_angles=[-0.15355298]
# 4-th start
# theta=[0.5300775],P=[[0.00056861+3.10619813e-20j]]
# Way First
# Initial diagonal of diff is [1.83297705-3.10619813e-20j 3.00471879-3.04931861e-20j
#  1.98146346-3.04931861e-20j 1.24230401-2.71050543e-20j
#  3.65077323-3.38813179e-20j 1.6801108 -3.38813179e-20j
#  0.96120909-3.38813179e-20j 1.26991171-2.71050543e-20j
#  1.65854703-2.71050543e-20j 1.36156486-4.06575815e-20j
#  1.09515901-2.71050543e-20j 0.89656965-1.35525272e-20j
#  1.6193286 -2.71050543e-20j 0.79160026-2.71050543e-20j
#  1.14117186-2.71050543e-20j 2.29096215-2.71050543e-20j
#  1.17188531-2.71050543e-20j 1.31442982+0.00000000e+00j
#  1.22898154-2.71050543e-20j 1.67839446+0.00000000e+00j]
# new_angles=[0.72055058]
# likelihood is -3405.8897211562166 on iteration 0
# new_angles=[0.71608768]
# likelihood is -3400.782233258399 on iteration 1
# new_angles=[0.71256328]
# likelihood is -3392.26614216273 on iteration 2
# new_angles=[0.70981141]
# likelihood is -3376.059687987712 on iteration 3
# new_angles=[0.70765356]
# likelihood is -3339.665477141472 on iteration 4
# new_angles=[0.7059611]
# likelihood is -3243.360890390442 on iteration 5
# new_angles=[0.70463464]
# likelihood is -3016.632896506589 on iteration 6
# new_angles=[0.70359653]
# likelihood is -2836.8935585669096 on iteration 7
# new_angles=[0.70278372]
# likelihood is -2829.9631072011503 on iteration 8
# new_angles=[0.70214513]
# likelihood is -2834.091721823635 on iteration 9
# new_angles=[0.70164272]
# likelihood is -2834.5294316111735 on iteration 10
# new_angles=[0.70124739]
# likelihood is -2834.503635584332 on iteration 11
# new_angles=[0.70093609]
# likelihood is -2834.4820255010954 on iteration 12
# new_angles=[0.70069099]
# likelihood is -2834.4966405276728 on iteration 13
# new_angles=[0.70049798]
# likelihood is -2834.537980809114 on iteration 14
# new_angles=[0.70034598]
# likelihood is -2834.596855574476 on iteration 15
# new_angles=[0.70022625]
# likelihood is -2834.6671096876216 on iteration 16
# new_angles=[0.70013193]
# likelihood is -2834.7447974050374 on iteration 17
# new_angles=[0.70005763]
# likelihood is -2834.8273956436237 on iteration 18
# new_angles=[0.69999909]
# likelihood is -2834.913281346696 on iteration 19
# new_angles=[0.69995296]
# likelihood is -2835.0014027365346 on iteration 20
# new_angles=[0.69991661]
# likelihood is -2835.0910714803035 on iteration 21
# new_angles=[0.69988796]
# likelihood is -2835.1818323265657 on iteration 22
# new_angles=[0.69986539]
# likelihood is -2835.2733804130557 on iteration 23
# new_angles=[0.69984759]
# likelihood is -2835.3655087792267 on iteration 24
# new_angles=[0.69983357]
# likelihood is -2835.4580748276676 on iteration 25
# new_angles=[0.69982252]
# likelihood is -2835.5509787446485 on iteration 26
# new_angles=[0.6998138]
# likelihood is -2835.644149508839 on iteration 27
# new_angles=[0.69980693]
# likelihood is -2835.737535734636 on iteration 28
# new_angles=[0.69980152]
# likelihood is -2835.83109961645 on iteration 29
# 5-th start
# theta=[0.60846218],P=[[0.00408934+9.69739904e-20j]]
# Way First
# Initial diagonal of diff is [1.82945632-9.69739904e-20j 3.00119806-1.08420217e-19j
#  1.97794272+0.00000000e+00j 1.23878327+0.00000000e+00j
#  3.6472525 +0.00000000e+00j 1.67659007+0.00000000e+00j
#  0.95768836+0.00000000e+00j 1.26639098-9.48676901e-20j
#  1.6550263 -1.08420217e-19j 1.35804413+0.00000000e+00j
#  1.09163827-4.33680869e-19j 0.89304892-4.33680869e-19j
#  1.61580787+0.00000000e+00j 0.78807953-1.08420217e-19j
#  1.13765113-8.80914265e-20j 2.28744142-1.08420217e-19j
#  1.16836458+0.00000000e+00j 1.31090909-4.33680869e-19j
#  1.2254608 +0.00000000e+00j 1.67487373+2.16840434e-19j]
# new_angles=[0.60486771]
# likelihood is -3397.3852749243374 on iteration 0
# new_angles=[0.61865626]
# likelihood is -3360.4449085066058 on iteration 1
# new_angles=[0.63255683]
# likelihood is -3277.6117295771633 on iteration 2
# new_angles=[0.64511496]
# likelihood is -3149.1842225012097 on iteration 3
# new_angles=[0.65580898]
# likelihood is -3041.927999893504 on iteration 4
# new_angles=[0.66464375]
# likelihood is -2973.630462850602 on iteration 5
# new_angles=[0.67182228]
# likelihood is -2925.812501906425 on iteration 6
# new_angles=[0.67759684]
# likelihood is -2892.9082335110256 on iteration 7
# new_angles=[0.68221276]
# likelihood is -2871.235697797227 on iteration 8
# new_angles=[0.68588646]
# likelihood is -2857.342099340744 on iteration 9
# new_angles=[0.6888022]
# likelihood is -2848.581260085365 on iteration 10
# new_angles=[0.69111178]
# likelihood is -2843.123355038956 on iteration 11
# new_angles=[0.69293869]
# likelihood is -2839.7595433718216 on iteration 12
# new_angles=[0.69438236]
# likelihood is -2837.710991521924 on iteration 13
# new_angles=[0.69552238]
# likelihood is -2836.4832529002315 on iteration 14
# new_angles=[0.69642214]
# likelihood is -2835.765414653889 on iteration 15
# new_angles=[0.69713205]
# likelihood is -2835.363078607179 on iteration 16
# new_angles=[0.69769199]
# likelihood is -2835.1553360732873 on iteration 17
# new_angles=[0.69813358]
# likelihood is -2835.067165092226 on iteration 18
# new_angles=[0.69848177]
# likelihood is -2835.052176823553 on iteration 19
# new_angles=[0.6987563]
# likelihood is -2835.081763990213 on iteration 20
# new_angles=[0.69897274]
# likelihood is -2835.138336081606 on iteration 21
# new_angles=[0.69914338]
# likelihood is -2835.2111167818834 on iteration 22
# new_angles=[0.69927791]
# likelihood is -2835.293532993548 on iteration 23
# new_angles=[0.69938397]
# likelihood is -2835.3815977938048 on iteration 24
# new_angles=[0.69946758]
# likelihood is -2835.4729106768064 on iteration 25
# new_angles=[0.69953351]
# likelihood is -2835.5660403116503 on iteration 26
# new_angles=[0.69958548]
# likelihood is -2835.660144970451 on iteration 27
# new_angles=[0.69962647]
# likelihood is -2835.75473880166 on iteration 28
# new_angles=[0.69965878]
# likelihood is -2835.8495491760336 on iteration 29
# 6-th start
# theta=[-1.46911153],P=[[0.00075317-3.39408966e-19j]]
# Way First
# Initial diagonal of diff is [1.83279249+3.39408966e-19j 3.00453423+3.40507245e-19j
#  1.98127889+3.38813179e-19j 1.24211944+3.38813179e-19j
#  3.65058867+3.32036915e-19j 1.67992624+3.45589442e-19j
#  0.96102453+3.38813179e-19j 1.26972715+3.38813179e-19j
#  1.65836247+3.38813179e-19j 1.3613803 +3.38813179e-19j
#  1.09497444+3.65918233e-19j 0.89638509+3.52365706e-19j
#  1.61914404+3.25260652e-19j 0.7914157 +3.52365706e-19j
#  1.1409873 +3.52365706e-19j 2.29077759+3.79470760e-19j
#  1.17170075+3.52365706e-19j 1.31424526+3.25260652e-19j
#  1.22879697+3.52365706e-19j 1.6782099 +3.52365706e-19j]
# new_angles=[-1.42107231]
# likelihood is -3420.8363762250574 on iteration 0
# new_angles=[-1.42107231]
# 7-th start
# theta=[-1.07899142],P=[[0.00022361+0.j]]
# Way First
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379+0.00000000e+00j
#  1.98180846+0.00000000e+00j 1.24264901+0.00000000e+00j
#  3.65111824-3.38813179e-21j 1.6804558 -1.35525272e-20j
#  0.96155409+0.00000000e+00j 1.27025671+1.35525272e-20j
#  1.65889204-6.77626358e-21j 1.36190987-6.77626358e-21j
#  1.09550401+0.00000000e+00j 0.89691465+0.00000000e+00j
#  1.6196736 +0.00000000e+00j 0.79194526-3.38813179e-21j
#  1.14151686+0.00000000e+00j 2.29130715+0.00000000e+00j
#  1.17223031+0.00000000e+00j 1.31477482+0.00000000e+00j
#  1.22932654+1.35525272e-20j 1.67873947+0.00000000e+00j]
# new_angles=[-1.07899142]
# likelihood is -3420.8261577653902 on iteration 0
# new_angles=[-1.07899142]
# 8-th start
# theta=[-1.31513736],P=[[0.00092031-6.30330937e-19j]]
# Way First
# Initial diagonal of diff is [1.83262534+6.30330937e-19j 3.00436708+6.23416249e-19j
#  1.98111175+6.23416249e-19j 1.2419523 +6.50521303e-19j
#  3.65042153+6.50521303e-19j 1.6797591 +5.96311195e-19j
#  0.96085738+7.04731412e-19j 1.26956   +6.50521303e-19j
#  1.65819533+6.50521303e-19j 1.36121316+7.04731412e-19j
#  1.0948073 +5.96311195e-19j 0.89621794+5.96311195e-19j
#  1.6189769 +6.50521303e-19j 0.79124855+6.50521303e-19j
#  1.14082016+6.23416249e-19j 2.29061044+6.30192513e-19j
#  1.1715336 +6.23416249e-19j 1.31407812+6.23416249e-19j
#  1.22862983+6.50521303e-19j 1.67804276+5.96311195e-19j]
# new_angles=[-1.33383537]
# likelihood is -3420.8469409122727 on iteration 0
# new_angles=[-1.33383537]
# 9-th start
# theta=[-0.20985359],P=[[0.00022361+0.j]]
# Way First
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379+0.00000000e+00j
#  1.98180846+0.00000000e+00j 1.24264901-1.35525272e-20j
#  3.65111824+0.00000000e+00j 1.6804558 +0.00000000e+00j
#  0.96155409+1.35525272e-20j 1.27025671+0.00000000e+00j
#  1.65889204-1.35525272e-20j 1.36190987+1.35525272e-20j
#  1.09550401+0.00000000e+00j 0.89691465+1.35525272e-20j
#  1.6196736 +2.64697796e-23j 0.79194526+0.00000000e+00j
#  1.14151686+0.00000000e+00j 2.29130715+0.00000000e+00j
#  1.17223031+0.00000000e+00j 1.31477482+0.00000000e+00j
#  1.22932654+0.00000000e+00j 1.67873947+3.38813179e-21j]
# new_angles=[-0.20985359]
# likelihood is -3420.909393623268 on iteration 0
# new_angles=[-0.20985359]
# best_start=4

# %%
print(f"EM_theta1_rad={EM_theta1_rad},\nEM_P1={EM_P1}")
# Out:
# EM_theta1_rad=[0.69980152],
# EM_P1=[[2.02017922+1.85434971e-16j]]

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)
print(f"Погрешность в смысле разности углов в градусах: \
      {np.abs(EM_theta1_deg-theta1_deg)},")
print(f"Погрешность в смысле разности синусов углов: \
      {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах:       [0.01137227],
# Погрешность в смысле разности синусов углов:       [0.00015182].

# %%
print(np.trace(sensors.initial_Cov(X2_with_mv)))
print(np.trace(sensors.complex_cov(X2)))
# Out:
# Way First
# (49.65503774285381+0j)
# (61.03171543408073+0j)

# %%
EM_theta2_rad, EM_P2, lhd_2 = em_stoch.multi_start_EM(X2_with_mv, 
                                                      Num_emitters2, 
                                                      Q=Q_2, 
                                                      num_of_starts=10, 
                                                      max_iter=30,
                                                      rtol=1e-3)
# Out:
# Way First
# 0-th start
# theta=[-1.41744418  0.15335215],P=[[0.00276336-1.33017438e-17j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00299515+1.51605636e-17j]]
# Way First
# Initial diagonal of diff is [1.15026919-1.85881981e-18j 1.99389114-1.73472348e-18j
#  1.06671809-1.73472348e-18j 1.72938522-1.84314369e-18j
#  1.14907423-1.84314369e-18j 2.05874687-1.95156391e-18j
#  0.64406552-1.78893358e-18j 1.342387  -1.95156391e-18j
#  1.1722289 -1.73472348e-18j 0.99058821-1.95156391e-18j
#  1.30708874-2.05998413e-18j 1.34610167-2.16840434e-18j
#  1.15990072-2.08708918e-18j 0.72086538-1.95156391e-18j
#  1.63418616-1.73472348e-18j 1.56259193-1.73472348e-18j
#  2.11217389-2.16840434e-18j 0.92115863-1.78893358e-18j
#  1.31483313-2.19550940e-18j 2.16361287-1.84314369e-18j]
# new_angles=[-1.30628286  0.71136362]
# likelihood is -3976.6769266742576 on iteration 0
# new_angles=[-1.25884776  0.70922639]
# likelihood is -3562.2471281128555 on iteration 1
# new_angles=[-1.26177706  0.7082357 ]
# likelihood is -3426.2373024372973 on iteration 2
# new_angles=[-1.27456432  0.7075119 ]
# likelihood is -3408.1621586385227 on iteration 3
# new_angles=[-1.28153836  0.70674895]
# likelihood is -3391.2580559374273 on iteration 4
# new_angles=[-1.28487913  0.70600082]
# likelihood is -3379.0174454492644 on iteration 5
# new_angles=[-1.28649694  0.70529957]
# likelihood is -3371.587230908934 on iteration 6
# new_angles=[-1.28704748  0.70465801]
# likelihood is -3367.9505803645857 on iteration 7
# new_angles=[-1.28672171  0.7040839 ]
# likelihood is -3366.991053035422 on iteration 8
# new_angles=[-1.28569253  0.70358186]
# likelihood is -3367.741427632551 on iteration 9
# new_angles=[-1.2841424   0.70315364]
# likelihood is -3369.45616184246 on iteration 10
# new_angles=[-1.28227319  0.70279618]
# likelihood is -3371.6018357205126 on iteration 11
# new_angles=[-1.28028265  0.7025034 ]
# likelihood is -3373.823971377325 on iteration 12
# new_angles=[-1.27832093  0.70226704]
# likelihood is -3375.9143974440112 on iteration 13
# new_angles=[-1.27648545  0.70207817]
# likelihood is -3377.781257580756 on iteration 14
# new_angles=[-1.27483452  0.7019281 ]
# likelihood is -3379.413084338465 on iteration 15
# new_angles=[-1.27339596  0.70180946]
# likelihood is -3380.841271535218 on iteration 16
# new_angles=[-1.27218677  0.70171596]
# likelihood is -3382.1123891893008 on iteration 17
# new_angles=[-1.27121193  0.70164234]
# likelihood is -3383.2709200467325 on iteration 18
# new_angles=[-1.27047384  0.70158448]
# likelihood is -3384.3531282312556 on iteration 19
# new_angles=[-1.26997268  0.70153909]
# likelihood is -3385.385752879175 on iteration 20
# new_angles=[-1.26970799  0.70150359]
# likelihood is -3386.387422226697 on iteration 21
# new_angles=[-1.26967949  0.70147596]
# likelihood is -3387.3707025605445 on iteration 22
# new_angles=[-1.26988771  0.7014546 ]
# likelihood is -3388.3439770522323 on iteration 23
# new_angles=[-1.27040016  0.70143818]
# likelihood is -3389.319635855326 on iteration 24
# new_angles=[-1.27107771  0.70142614]
# likelihood is -3390.285603172185 on iteration 25
# new_angles=[-1.27201131  0.70141732]
# likelihood is -3391.2560844150526 on iteration 26
# new_angles=[-1.27319718  0.70141132]
# likelihood is -3392.2318990890203 on iteration 27
# new_angles=[-1.27464275  0.70140775]
# likelihood is -3393.214942774443 on iteration 28
# new_angles=[-1.27635597  0.70140616]
# likelihood is -3394.2069380596217 on iteration 29
# 1-th start
# theta=[-1.43443568  0.13636065],P=[[0.00209247+2.33229794e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00447612-8.48930966e-18j]]
# Way First
# Initial diagonal of diff is [1.14945911+8.25607987e-18j 1.99308107+8.23993651e-18j
#  1.06590801+8.23993651e-18j 1.72857515+8.23993651e-18j
#  1.14826415+8.13151629e-18j 2.05793679+7.80625564e-18j
#  0.64325545+8.02309608e-18j 1.34157692+8.23993651e-18j
#  1.17141882+8.23993651e-18j 0.98977813+8.67361738e-18j
#  1.30627866+8.23993651e-18j 1.34529159+8.23993651e-18j
#  1.15909064+8.34835673e-18j 0.7200553 +8.23993651e-18j
#  1.63337608+8.13151629e-18j 1.56178186+8.45677695e-18j
#  2.11136381+8.23993651e-18j 0.92034856+8.23993651e-18j
#  1.31402306+8.23993651e-18j 2.1628028 +8.61940727e-18j]
# new_angles=[-0.65907927  0.13015543]
# likelihood is -4321.851952691746 on iteration 0
# new_angles=[-0.96227111 -0.51544939]
# likelihood is -3537.3417655001062 on iteration 1
# new_angles=[-0.52520365 -0.51190232]
# likelihood is -3135.9398175044803 on iteration 2
# new_angles=[-0.52147042 -0.50904381]
# likelihood is -3121.1598015236264 on iteration 3
# new_angles=[-0.51790245 -0.50695459]
# likelihood is -3109.1256214335826 on iteration 4
# new_angles=[-0.51580549 -0.50522171]
# likelihood is -3100.8715491267662 on iteration 5
# new_angles=[-0.51434341 -0.50383283]
# likelihood is -3095.790362488987 on iteration 6
# new_angles=[-0.51339259 -0.50274755]
# likelihood is -3092.8072945418135 on iteration 7
# new_angles=[-0.51271969 -0.50189694]
# likelihood is -3091.026073213153 on iteration 8
# new_angles=[-0.51228082 -0.50122455]
# likelihood is -3089.9734031429753 on iteration 9
# new_angles=[-0.51206387 -0.50068292]
# likelihood is -3089.360301628818 on iteration 10
# new_angles=[-0.51209226 -0.5002297 ]
# likelihood is -3089.0131260550734 on iteration 11
# new_angles=[-0.51239292 -0.49983062]
# likelihood is -3088.827097685844 on iteration 12
# new_angles=[-0.51306052 -0.49944671]
# likelihood is -3088.7422093254027 on iteration 13
# new_angles=[-0.51394289 -0.49908572]
# likelihood is -3088.71789606355 on iteration 14
# new_angles=[-0.51492478 -0.49875385]
# likelihood is -3088.73815875568 on iteration 15
# new_angles=[-0.51585662 -0.49846621]
# likelihood is -3088.79221807147 on iteration 16
# new_angles=[-0.51673381 -0.49821453]
# likelihood is -3088.871825263578 on iteration 17
# new_angles=[-0.51755647 -0.4979936 ]
# likelihood is -3088.970605879848 on iteration 18
# new_angles=[-0.51832724 -0.49779845]
# likelihood is -3089.083846538749 on iteration 19
# new_angles=[-0.51906682 -0.49762192]
# likelihood is -3089.208886623789 on iteration 20
# new_angles=[-0.51976615 -0.49746242]
# likelihood is -3089.3442401835428 on iteration 21
# new_angles=[-0.5204469  -0.49731417]
# likelihood is -3089.488818742218 on iteration 22
# new_angles=[-0.52112175 -0.49717289]
# likelihood is -3089.644002653093 on iteration 23
# new_angles=[-0.52175977 -0.49704188]
# likelihood is -3089.80893009664 on iteration 24
# new_angles=[-0.52237571 -0.49691734]
# likelihood is -3089.981360780122 on iteration 25
# new_angles=[-0.52295233 -0.4967995 ]
# likelihood is -3090.1607881850578 on iteration 26
# new_angles=[-0.52353087 -0.49668212]
# likelihood is -3090.3483997142207 on iteration 27
# new_angles=[-0.52409986 -0.49656695]
# likelihood is -3090.5475508406557 on iteration 28
# new_angles=[-0.52464031 -0.4964525 ]
# likelihood is -3090.756051842694 on iteration 29
# 2-th start
# theta=[-0.16451812  1.40627821],P=[[0.0001118+0.00000000e+00j 0.       +0.00000000e+00j]
#  [0.       +0.00000000e+00j 0.0047305+9.15648187e-18j]]
# Way First
# Initial diagonal of diff is [1.15118539-9.15648187e-18j 1.99480735-9.16150836e-18j
#  1.06763429-9.10729825e-18j 1.73030143-9.10729825e-18j
#  1.14999044-9.10729825e-18j 2.05966308-9.10729825e-18j
#  0.64498173-9.10729825e-18j 1.3433032 -9.32413868e-18j
#  1.17314511-9.32413868e-18j 0.99150442-8.89045781e-18j
#  1.30800494-9.10729825e-18j 1.34701788-8.89045781e-18j
#  1.16081692-9.10729825e-18j 0.72178159-9.10729825e-18j
#  1.63510236-9.54097912e-18j 1.56350814-9.54097912e-18j
#  2.1130901 -9.10729825e-18j 0.92207484-9.10729825e-18j
#  1.31574934-9.10729825e-18j 2.16452908-9.54097912e-18j]
# new_angles=[-0.1817427   0.65892495]
# likelihood is -3961.258732893149 on iteration 0
# new_angles=[-1.57079633  0.6678142 ]
# likelihood is -3602.7352823538745 on iteration 1
# new_angles=[-1.10835575  0.67488089]
# likelihood is -3480.7611159014696 on iteration 2
# new_angles=[-1.09778184  0.68043036]
# likelihood is -3438.851415808008 on iteration 3
# new_angles=[-1.09156704  0.68480641]
# likelihood is -3409.212040221391 on iteration 4
# new_angles=[0.75647048 0.68831645]
# likelihood is -3384.8170691025343 on iteration 5
# new_angles=[0.69063078 0.75863175]
# likelihood is -3374.9047053607014 on iteration 6
# new_angles=[0.69246777 0.75979433]
# likelihood is -3369.2781050645513 on iteration 7
# new_angles=[0.69392203 0.76042564]
# likelihood is -3365.8191642486922 on iteration 8
# new_angles=[0.69507321 0.76070153]
# likelihood is -3363.676763111424 on iteration 9
# new_angles=[0.69598915 0.7606331 ]
# likelihood is -3362.3498412181943 on iteration 10
# new_angles=[0.69672138 0.76022603]
# likelihood is -3361.531705923155 on iteration 11
# new_angles=[0.69731048 0.75955259]
# likelihood is -3361.0301045703823 on iteration 12
# new_angles=[0.69779298 0.75852655]
# likelihood is -3360.72416618837 on iteration 13
# new_angles=[0.69820373 0.75690405]
# likelihood is -3360.536494976167 on iteration 14
# new_angles=[0.69858262 0.7541776 ]
# likelihood is -3360.414173236418 on iteration 15
# new_angles=[0.69896119 0.74992394]
# likelihood is -3360.330599986252 on iteration 16
# new_angles=[0.69934179 0.74434756]
# likelihood is -3360.2938800732186 on iteration 17
# new_angles=[0.69968332 0.73866304]
# likelihood is -3360.349219597986 on iteration 18
# new_angles=[0.69997502 0.73324094]
# likelihood is -3360.484269937492 on iteration 19
# new_angles=[0.69909953 0.33318188]
# likelihood is -3361.1793497161566 on iteration 20
# new_angles=[-0.18749657  0.69946494]
# likelihood is -3361.72690979338 on iteration 21
# new_angles=[-0.18704684  0.69984494]
# likelihood is -3361.6645625029196 on iteration 22
# new_angles=[-0.18683671  0.70014276]
# likelihood is -3361.5735521810234 on iteration 23
# new_angles=[-0.18666445  0.70037581]
# likelihood is -3361.5361822989016 on iteration 24
# new_angles=[-0.18651805  0.70055818]
# 3-th start
# theta=[-0.15355298  1.41724335],P=[[0.0001118 +0.00000000e+00j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00572669-4.89593623e-18j]]
# Way First
# Initial diagonal of diff is [1.1501892 +4.89593623e-18j 1.99381116+4.87890978e-18j
#  1.0666381 +4.87890978e-18j 1.72930524+4.87890978e-18j
#  1.14899425+4.98732999e-18j 2.05866688+4.77048956e-18j
#  0.64398554+4.77048956e-18j 1.34230701+4.98732999e-18j
#  1.17214892+4.98732999e-18j 0.99050822+4.77048956e-18j
#  1.30700875+5.20417043e-18j 1.34602168+5.20417043e-18j
#  1.15982073+4.77048956e-18j 0.72078539+4.77048956e-18j
#  1.63410617+5.20417043e-18j 1.56251195+4.77048956e-18j
#  2.1120939 +4.77048956e-18j 0.92107865+5.20417043e-18j
#  1.31475315+5.20417043e-18j 2.16353289+5.20417043e-18j]
# new_angles=[-0.17267301  0.65953597]
# likelihood is -3887.5414433810424 on iteration 0
# new_angles=[0.74533922 0.66835012]
# likelihood is -3552.705032386553 on iteration 1
# new_angles=[0.67486673 0.75253092]
# likelihood is -3472.369153456969 on iteration 2
# new_angles=[0.68004873 0.75824845]
# likelihood is -3433.7501714367036 on iteration 3
# new_angles=[0.68416445 0.76231715]
# likelihood is -3406.624158892988 on iteration 4
# new_angles=[0.68742005 0.76528268]
# likelihood is -3389.193650632694 on iteration 5
# new_angles=[0.68999066 0.76740002]
# likelihood is -3378.2502071091794 on iteration 6
# new_angles=[0.69202223 0.7688271 ]
# likelihood is -3371.420251535965 on iteration 7
# new_angles=[0.69362301 0.76971257]
# likelihood is -3367.1857342824214 on iteration 8
# new_angles=[0.69488839 0.77013266]
# likelihood is -3364.5604231275283 on iteration 9
# new_angles=[0.69589104 0.77019754]
# likelihood is -3362.934634156537 on iteration 10
# new_angles=[0.69668621 0.76994443]
# likelihood is -3361.9336889727833 on iteration 11
# new_angles=[0.69732073 0.7694117 ]
# likelihood is -3361.3195197123173 on iteration 12
# new_angles=[0.69783223 0.76856618]
# likelihood is -3360.9455267716658 on iteration 13
# new_angles=[ 0.69809993 -0.18156758]
# likelihood is -3361.027970044721 on iteration 14
# new_angles=[-0.18123227  0.69877686]
# likelihood is -3361.460527006107 on iteration 15
# new_angles=[-0.1809159   0.69930613]
# likelihood is -3361.1110340982004 on iteration 16
# new_angles=[-0.18062774  0.69971914]
# likelihood is -3360.8711299313422 on iteration 17
# new_angles=[-0.18034011  0.70004177]
# likelihood is -3360.7415190975858 on iteration 18
# new_angles=[-0.18016061  0.70029436]
# likelihood is -3360.6824525147595 on iteration 19
# new_angles=[-0.17997289  0.70049175]
# likelihood is -3360.6688276198315 on iteration 20
# new_angles=[-0.1798054   0.70064608]
# likelihood is -3360.6834620955997 on iteration 21
# new_angles=[-0.17965544  0.70076676]
# likelihood is -3360.7160923138827 on iteration 22
# new_angles=[-0.17951975  0.70086115]
# likelihood is -3360.7602841641556 on iteration 23
# new_angles=[-0.17939571  0.70093499]
# likelihood is -3360.8119977383817 on iteration 24
# new_angles=[-0.17928124  0.70099277]
# likelihood is -3360.868682844614 on iteration 25
# new_angles=[-0.17917397  0.70103801]
# likelihood is -3360.9287269382517 on iteration 26
# new_angles=[-0.17907489  0.70107326]
# likelihood is -3360.9910865136458 on iteration 27
# new_angles=[-0.17899432  0.70110082]
# likelihood is -3361.0549293674603 on iteration 28
# new_angles=[-0.17889221  0.70112266]
# likelihood is -3361.120293619834 on iteration 29
# 4-th start
# theta=[-1.04071883  0.5300775 ],P=[[3.49385621e-06+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 3.58409028e-03-8.27175728e-19j]]
# Way First
# Initial diagonal of diff is [1.15244011+8.27175728e-19j 1.99606207+8.26704157e-19j
#  1.06888902+8.40256684e-19j 1.73155615+8.40256684e-19j
#  1.15124516+8.13151629e-19j 2.0609178 +8.13151629e-19j
#  0.64623645+8.13151629e-19j 1.34455792+8.13151629e-19j
#  1.17439983+8.67361738e-19j 0.99275914+8.67361738e-19j
#  1.30925967+8.67361738e-19j 1.3482726 +8.67361738e-19j
#  1.16207164+6.50521303e-19j 0.72303631+7.58941521e-19j
#  1.63635709+7.58941521e-19j 1.56476286+7.58941521e-19j
#  2.11434482+8.67361738e-19j 0.92332956+8.67361738e-19j
#  1.31700406+8.67361738e-19j 2.1657838 +8.67361738e-19j]
# new_angles=[-0.53056526  0.68179018]
# likelihood is -3701.9224068719936 on iteration 0
# new_angles=[-0.23645458  0.6859641 ]
# likelihood is -3403.260541908611 on iteration 1
# new_angles=[0.2526712 0.6892323]
# likelihood is -3385.583163684556 on iteration 2
# new_angles=[0.25378736 0.691792  ]
# likelihood is -3378.45401016234 on iteration 3
# new_angles=[0.53547236 0.69378879]
# likelihood is -3372.157276968532 on iteration 4
# new_angles=[0.53380732 0.69535316]
# likelihood is -3368.146043184955 on iteration 5
# new_angles=[-0.46593952  0.69657905]
# likelihood is -3365.6471572495598 on iteration 6
# new_angles=[-0.10605087  0.69753302]
# likelihood is -3364.137248614773 on iteration 7
# new_angles=[-0.10549112  0.69827813]
# likelihood is -3363.227396411773 on iteration 8
# new_angles=[-0.10509898  0.69885913]
# likelihood is -3362.6908010928782 on iteration 9
# new_angles=[-0.10472845  0.69931294]
# likelihood is -3362.3796779435525 on iteration 10
# new_angles=[-0.10448856  0.6996659 ]
# likelihood is -3362.2088263578057 on iteration 11
# new_angles=[-0.10425992  0.69994145]
# likelihood is -3362.1240660579683 on iteration 12
# new_angles=[-0.10412146  0.70015663]
# likelihood is -3362.0930416130973 on iteration 13
# new_angles=[-0.10389418  0.70032448]
# 5-th start
# theta=[-0.96233415  0.60846218],P=[[0.00189661+1.15722072e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00636671+3.83942552e-19j]]
# Way First
# Initial diagonal of diff is [1.14776437-4.99664625e-19j 1.99138633-4.33680869e-19j
#  1.06421328-4.33680869e-19j 1.72688041-4.33680869e-19j
#  1.14656942-8.67361738e-19j 2.05624206-4.33680869e-19j
#  0.64156071-4.33680869e-19j 1.33988218-5.42101086e-19j
#  1.16972409-4.33680869e-19j 0.9880834 -6.50521303e-19j
#  1.30458393-8.67361738e-19j 1.34359686-8.67361738e-19j
#  1.1573959 -8.67361738e-19j 0.71836057-4.33680869e-19j
#  1.63168135-4.91279109e-19j 1.56008712-4.33680869e-19j
#  2.10966908-6.50521303e-19j 0.91865382+0.00000000e+00j
#  1.31232832+0.00000000e+00j 2.16110806-4.33680869e-19j]
# new_angles=[-0.9697569   0.61123572]
# likelihood is -4250.812624756932 on iteration 0
# new_angles=[-0.5157751   0.62668653]
# likelihood is -3856.9591319724173 on iteration 1
# new_angles=[-0.51170356  0.64080076]
# likelihood is -3114.830489011597 on iteration 2
# new_angles=[-0.50882232  0.65250327]
# likelihood is -2551.742715697403 on iteration 3
# new_angles=[-0.50694052  0.66240314]
# likelihood is -2407.8444815099356 on iteration 4
# new_angles=[-0.50556695  0.67058603]
# likelihood is -2311.800737658054 on iteration 5
# new_angles=[-0.50449276  0.67711581]
# likelihood is -2244.7375203605575 on iteration 6
# new_angles=[-0.50363883  0.68227742]
# likelihood is -2201.17522743601 on iteration 7
# new_angles=[-0.50295545  0.68633872]
# likelihood is -2173.686300865488 on iteration 8
# new_angles=[-0.50240623  0.68952492]
# likelihood is -2156.6151470886525 on iteration 9
# new_angles=[-0.50196369  0.69201932]
# likelihood is -2146.1277629578462 on iteration 10
# new_angles=[-0.50160666  0.69396927]
# likelihood is -2139.7401433727537 on iteration 11
# new_angles=[-0.5013178   0.69549187]
# likelihood is -2135.8826775391635 on iteration 12
# new_angles=[-0.50108396  0.69667962]
# likelihood is -2133.578576788647 on iteration 13
# new_angles=[-0.50089456  0.69760549]
# likelihood is -2132.224475336155 on iteration 14
# new_angles=[-0.50074078  0.69832652]
# likelihood is -2131.4501375427403 on iteration 15
# new_angles=[-0.500616    0.69888834]
# likelihood is -2131.028306669403 on iteration 16
# new_angles=[-0.50051426  0.69932467]
# likelihood is -2130.821828553297 on iteration 17
# new_angles=[-0.50043118  0.69966363]
# likelihood is -2130.745706599281 on iteration 18
# new_angles=[-0.50036312  0.69992663]
# likelihood is -2130.7486635825085 on iteration 19
# new_angles=[-0.50030713  0.70013037]
# likelihood is -2130.799522060476 on iteration 20
# new_angles=[-0.50026083  0.70028792]
# likelihood is -2130.879339191611 on iteration 21
# new_angles=[-0.50022232  0.70040944]
# likelihood is -2130.976631102706 on iteration 22
# new_angles=[-0.50019006  0.70050287]
# likelihood is -2131.0844420433186 on iteration 23
# new_angles=[-0.50016282  0.70057442]
# likelihood is -2131.19856636787 on iteration 24
# new_angles=[-0.50013961  0.70062889]
# likelihood is -2131.316466710191 on iteration 25
# new_angles=[-0.50011963  0.70067007]
# likelihood is -2131.436616399967 on iteration 26
# new_angles=[-0.50010223  0.70070087]
# likelihood is -2131.558099731204 on iteration 27
# new_angles=[-0.50008692  0.7007236 ]
# likelihood is -2131.6803699680772 on iteration 28
# new_angles=[-0.50007323  0.70074002]
# likelihood is -2131.8031070266493 on iteration 29
# 6-th start
# theta=[-1.46911153  0.10168479],P=[[0.00443737+1.62172784e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.0001118 +0.00000000e+00j]]
# Way First
# Initial diagonal of diff is [1.15147852-1.62172784e-19j 1.99510048-1.62630326e-19j
#  1.06792743-1.89735380e-19j 1.73059456-1.62630326e-19j
#  1.15028357-1.62630326e-19j 2.05995621-1.62630326e-19j
#  0.64527486-1.62630326e-19j 1.34359633-1.08420217e-19j
#  1.17343824-1.08420217e-19j 0.99179755-1.08420217e-19j
#  1.30829808-2.16840434e-19j 1.34731101-1.08420217e-19j
#  1.16111005-2.16840434e-19j 0.72207472-2.16840434e-19j
#  1.6353955 +0.00000000e+00j 1.56380127-2.16840434e-19j
#  2.11338323-2.16840434e-19j 0.92236797-4.33680869e-19j
#  1.31604247-2.16840434e-19j 2.16482221-2.16840434e-19j]
# new_angles=[0.66646134 1.26905452]
# likelihood is -3930.8394381277394 on iteration 0
# new_angles=[0.67390675 0.64884781]
# likelihood is -3545.9451813100163 on iteration 1
# new_angles=[0.52869268 0.67975724]
# likelihood is -3439.298854452935 on iteration 2
# new_angles=[0.53780117 0.68424122]
# likelihood is -3413.542304589348 on iteration 3
# new_angles=[0.53963515 0.68779199]
# likelihood is -3394.3168018163515 on iteration 4
# new_angles=[0.53915003 0.69058716]
# likelihood is -3381.8659051192226 on iteration 5
# new_angles=[0.53777304 0.69278797]
# likelihood is -3374.123200663685 on iteration 6
# new_angles=[0.53609658 0.6945219 ]
# likelihood is -3369.3389726764744 on iteration 7
# new_angles=[0.53446941 0.69588804]
# likelihood is -3366.387739881813 on iteration 8
# new_angles=[0.53307596 0.69696325]
# likelihood is -3364.573395951277 on iteration 9
# new_angles=[-0.46356175  0.69789886]
# likelihood is -3360.146114268424 on iteration 10
# new_angles=[-0.4666379   0.69861504]
# likelihood is -3359.2897515409354 on iteration 11
# new_angles=[-0.4671688   0.69916973]
# likelihood is -3358.501511407637 on iteration 12
# new_angles=[-0.46705299  0.6996016 ]
# likelihood is -3357.8673976429973 on iteration 13
# new_angles=[-0.46680694  0.69993901]
# likelihood is -3357.295771721717 on iteration 14
# new_angles=[-0.4665768   0.70020292]
# likelihood is -3356.7123316348307 on iteration 15
# new_angles=[-0.46639475  0.70040955]
# likelihood is -3356.0545414183002 on iteration 16
# new_angles=[-0.4662616   0.70057147]
# likelihood is -3355.2569800068254 on iteration 17
# new_angles=[-0.46617158  0.70069852]
# likelihood is -3354.2355565684857 on iteration 18
# new_angles=[-0.46611906  0.70079843]
# likelihood is -3352.864602926019 on iteration 19
# new_angles=[-0.46610054  0.70087724]
# likelihood is -3350.934432088281 on iteration 20
# new_angles=[-0.46611565  0.70093973]
# likelihood is -3348.059993542718 on iteration 21
# new_angles=[-0.46616889  0.70098972]
# likelihood is -3343.4579291986456 on iteration 22
# new_angles=[-0.46627463  0.70103031]
# likelihood is -3335.3220303836797 on iteration 23
# new_angles=[-0.46647383  0.70106422]
# likelihood is -3318.751570583196 on iteration 24
# new_angles=[-0.46690728  0.70109412]
# likelihood is -3277.314960287297 on iteration 25
# new_angles=[-0.46824212  0.70112331]
# likelihood is -3142.211128932162 on iteration 26
# new_angles=[-0.47283718  0.70115514]
# likelihood is -2694.2169994283436 on iteration 27
# new_angles=[-0.47877032  0.70122161]
# likelihood is -2280.186101325447 on iteration 28
# new_angles=[-0.48359222  0.70135948]
# likelihood is -2219.9178667846863 on iteration 29
# 7-th start
# theta=[-1.07899142  0.49180491],P=[[3.49385621e-06+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 1.27299140e-03+2.29972578e-19j]]
# Way First
# Initial diagonal of diff is [1.15475121-2.29972578e-19j 1.99837317-2.30392962e-19j
#  1.07120012-2.16840434e-19j 1.73386725-2.16840434e-19j
#  1.15355626-2.71050543e-19j 2.0632289 -1.62630326e-19j
#  0.64854755-3.25260652e-19j 1.34686902-3.25260652e-19j
#  1.17671093-3.25260652e-19j 0.99507024-2.16840434e-19j
#  1.31157077-2.16840434e-19j 1.3505837 -2.16840434e-19j
#  1.16438274-3.25260652e-19j 0.72534741-2.16840434e-19j
#  1.63866819-2.16840434e-19j 1.56707396-2.16840434e-19j
#  2.11665592-1.89735380e-19j 0.92564066-2.43945489e-19j
#  1.31931516-2.29757687e-19j 2.1680949 -2.30392962e-19j]
# new_angles=[-1.07665164  0.65514357]
# likelihood is -4148.4285040037 on iteration 0
# new_angles=[-0.99250665  0.6648264 ]
# likelihood is -3856.673322379418 on iteration 1
# new_angles=[-0.31839224  0.67255156]
# likelihood is -3526.990927189924 on iteration 2
# new_angles=[-0.11383596  0.67866834]
# likelihood is -3454.025948776914 on iteration 3
# new_angles=[-0.10912029  0.68349498]
# likelihood is -3421.9336312405417 on iteration 4
# new_angles=[-0.10631507  0.68728966]
# likelihood is -3399.279410321239 on iteration 5
# new_angles=[-0.10405454  0.69026574]
# likelihood is -3384.899093607084 on iteration 6
# new_angles=[-0.10276447  0.69259669]
# likelihood is -3375.992287404101 on iteration 7
# new_angles=[-0.10159712  0.6944198 ]
# likelihood is -3370.5166569892103 on iteration 8
# new_angles=[-0.45995135  0.69585048]
# likelihood is -3367.2678951846397 on iteration 9
# new_angles=[-0.45931805  0.69696652]
# likelihood is -3365.227475606375 on iteration 10
# new_angles=[-0.45834907  0.6978399 ]
# likelihood is -3363.978858526355 on iteration 11
# new_angles=[-0.45793304  0.69852064]
# likelihood is -3363.2296840447866 on iteration 12
# new_angles=[-0.45720125  0.6990529 ]
# likelihood is -3362.7868930590553 on iteration 13
# new_angles=[-0.45693078  0.69946772]
# likelihood is -3362.534150380436 on iteration 14
# new_angles=[-0.4566424   0.69979146]
# likelihood is -3362.3988749177815 on iteration 15
# new_angles=[-0.45641888  0.70004464]
# likelihood is -3362.3363058331133 on iteration 16
# new_angles=[-0.45617786  0.70024153]
# likelihood is -3362.3198174078834 on iteration 17
# new_angles=[-0.45596035  0.70039515]
# likelihood is -3362.331961341088 on iteration 18
# new_angles=[-0.45596001  0.70051502]
# likelihood is -3362.3620935338613 on iteration 19
# new_angles=[-0.4558132  0.7006085]
# likelihood is -3362.4040365451333 on iteration 20
# new_angles=[-0.45569163  0.70068151]
# likelihood is -3362.4534433660247 on iteration 21
# new_angles=[-0.45560992  0.70073846]
# likelihood is -3362.5077563288987 on iteration 22
# new_angles=[-0.4555371  0.7007829]
# likelihood is -3362.5653422134665 on iteration 23
# new_angles=[-0.45547321  0.70081764]
# likelihood is -3362.625121447879 on iteration 24
# new_angles=[-0.45544362  0.70084448]
# likelihood is -3362.6864237049704 on iteration 25
# new_angles=[-0.45539302  0.70086564]
# likelihood is -3362.7487669383636 on iteration 26
# new_angles=[-0.455393    0.70088217]
# likelihood is -3362.8118040043128 on iteration 27
# new_angles=[-0.4553125   0.70089517]
# likelihood is -3362.8754526726916 on iteration 28
# new_angles=[-0.45529464  0.70090514]
# likelihood is -3362.939443719482 on iteration 29
# 8-th start
# theta=[-1.31513736  0.25565896],P=[[3.79460496e-03-1.42636553e-18j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 5.59016994e-05+0.00000000e+00j]]
# Way First
# Initial diagonal of diff is [1.15217719+1.42636553e-18j 1.99579915+1.40946282e-18j
#  1.06862609+1.40946282e-18j 1.73129323+1.30104261e-18j
#  1.15098224+1.51788304e-18j 2.06065488+1.51788304e-18j
#  0.64597353+1.51788304e-18j 1.344295  +1.30104261e-18j
#  1.17413691+1.08420217e-18j 0.99249622+1.51788304e-18j
#  1.30899674+1.73472348e-18j 1.34800968+1.30104261e-18j
#  1.16180872+1.30104261e-18j 0.72277339+1.40946282e-18j
#  1.63609416+1.40946282e-18j 1.56449994+1.43656788e-18j
#  2.1140819 +1.40946282e-18j 0.92306664+1.51788304e-18j
#  1.31674114+1.30104261e-18j 2.16552088+1.51788304e-18j]
# new_angles=[-1.28413806  0.24500144]
# likelihood is -4308.600956891366 on iteration 0
# new_angles=[-1.2727568   0.67747627]
# likelihood is -4306.81420675961 on iteration 1
# new_angles=[-1.26009172  0.68090315]
# likelihood is -4306.305150443755 on iteration 2
# new_angles=[-1.24771041  0.68339102]
# likelihood is -4305.884967199964 on iteration 3
# new_angles=[-1.23607222  0.6863071 ]
# likelihood is -4305.732129754242 on iteration 4
# new_angles=[-1.22549818  0.68943999]
# likelihood is -4306.019418643482 on iteration 5
# new_angles=[-1.21615332  0.69244501]
# likelihood is -4306.790360577946 on iteration 6
# new_angles=[-1.20804307  0.69521347]
# likelihood is -4307.910308092902 on iteration 7
# new_angles=[-1.20113298  0.6977194 ]
# likelihood is -4309.156382282837 on iteration 8
# new_angles=[-1.19529848  0.69982221]
# likelihood is -4310.325951839388 on iteration 9
# new_angles=[-1.19039281  0.701634  ]
# likelihood is -4311.309723057536 on iteration 10
# new_angles=[-1.18629303  0.70315736]
# likelihood is -4312.089683658755 on iteration 11
# new_angles=[0.70981824 1.2741117 ]
# likelihood is -3534.379471426253 on iteration 12
# new_angles=[0.70784621 0.70093932]
# likelihood is -3358.360149932257 on iteration 13
# new_angles=[0.70009095 0.70633985]
# likelihood is -3365.126306820344 on iteration 14
# new_angles=[0.69982439 0.7051572 ]
# likelihood is -3364.8756317796697 on iteration 15
# new_angles=[0.69916621 0.70424593]
# likelihood is -3363.8478898624735 on iteration 16
# new_angles=[-0.44152403  0.70362612]
# likelihood is -3359.71169994215 on iteration 17
# new_angles=[-0.44476356  0.70308491]
# likelihood is -3360.808922335944 on iteration 18
# new_angles=[-0.44566776  0.70265585]
# likelihood is -3360.675589869144 on iteration 19
# new_angles=[-0.44603577  0.70232201]
# likelihood is -3360.5543826605954 on iteration 20
# new_angles=[-0.4462452   0.70206168]
# likelihood is -3360.4903986350773 on iteration 21
# new_angles=[-0.44638317  0.70185855]
# likelihood is -3360.462057203138 on iteration 22
# new_angles=[-0.44647787  0.70170012]
# likelihood is -3360.4533595508415 on iteration 23
# new_angles=[-0.44654131  0.70157657]
# 9-th start
# theta=[-0.20985359  1.36094274],P=[[0.0001118+0.00000000e+00j 0.       +0.00000000e+00j]
#  [0.       +0.00000000e+00j 0.0041411+1.10075139e-17j]]
# Way First
# Initial diagonal of diff is [1.1517748 -1.10075139e-17j 1.99539676-1.10046521e-17j
#  1.0682237 -1.11672824e-17j 1.73089083-1.10588622e-17j
#  1.15057984-1.12757026e-17j 2.06025248-1.10588622e-17j
#  0.64557113-1.08420217e-17j 1.34389261-1.08420217e-17j
#  1.17373451-1.10588622e-17j 0.99209382-1.10588622e-17j
#  1.30859435-1.12757026e-17j 1.34760728-1.08420217e-17j
#  1.16140633-1.12757026e-17j 0.72237099-1.12757026e-17j
#  1.63569177-1.08420217e-17j 1.56409754-1.08420217e-17j
#  2.1136795 -1.10588622e-17j 0.92266424-1.08420217e-17j
#  1.31633874-1.10588622e-17j 2.16511849-1.10588622e-17j]
# new_angles=[-0.95925349  0.65625723]
# likelihood is -4020.693648044734 on iteration 0
# new_angles=[-1.18732275  0.66568831]
# likelihood is -3660.1945561413286 on iteration 1
# new_angles=[0.31269959 0.67326561]
# likelihood is -3498.417407233843 on iteration 2
# new_angles=[-0.07776094  0.67910205]
# likelihood is -3450.132024617757 on iteration 3
# new_angles=[-0.07366134  0.68369888]
# likelihood is -3418.0230466860958 on iteration 4
# new_angles=[0.70771899 0.68776002]
# likelihood is -3394.763202441227 on iteration 5
# new_angles=[0.69024066 0.71476055]
# likelihood is -3380.6343880632594 on iteration 6
# new_angles=[0.69235448 0.71655964]
# likelihood is -3373.1290946191984 on iteration 7
# new_angles=[0.69402171 0.71771362]
# likelihood is -3368.620715668911 on iteration 8
# new_angles=[0.69533509 0.71847113]
# likelihood is -3365.859098902427 on iteration 9
# new_angles=[0.69636684 0.71895779]
# likelihood is -3364.1741176765295 on iteration 10
# new_angles=[0.69717763 0.7192324 ]
# likelihood is -3363.1528109013775 on iteration 11
# new_angles=[0.69781636 0.71933808]
# likelihood is -3362.5401015277885 on iteration 12
# new_angles=[0.69832083 0.71931364]
# likelihood is -3362.1799970234174 on iteration 13
# new_angles=[0.6987216  0.71915863]
# likelihood is -3361.976429352985 on iteration 14
# new_angles=[0.6990437  0.71886172]
# likelihood is -3361.870030521995 on iteration 15
# new_angles=[ 0.69892478 -0.41350511]
# likelihood is -3358.2889464529353 on iteration 16
# new_angles=[-0.41651385  0.69943865]
# likelihood is -3360.253886071986 on iteration 17
# new_angles=[-0.41693803  0.69982631]
# likelihood is -3360.1991834807627 on iteration 18
# new_angles=[-0.41668869  0.70012507]
# likelihood is -3360.104059082594 on iteration 19
# new_angles=[-0.41628958  0.70035709]
# likelihood is -3360.0684833532373 on iteration 20
# new_angles=[-0.41588441  0.70053774]
# likelihood is -3360.073677521178 on iteration 21
# new_angles=[-0.41550573  0.70067849]
# likelihood is -3360.1042450972373 on iteration 22
# new_angles=[-0.41515631  0.70078812]
# likelihood is -3360.1508673089184 on iteration 23
# new_angles=[-0.41483336  0.70087345]
# likelihood is -3360.2078217332482 on iteration 24
# new_angles=[-0.41452877  0.70093982]
# likelihood is -3360.2717975950113 on iteration 25
# new_angles=[-0.41424263  0.7009914 ]
# likelihood is -3360.340362581953 on iteration 26
# new_angles=[-0.41396864  0.70103136]
# likelihood is -3360.412322495509 on iteration 27
# new_angles=[-0.41370528  0.70106225]
# likelihood is -3360.4867264012805 on iteration 28
# new_angles=[-0.41345087  0.70108615]
# likelihood is -3360.5629705344877 on iteration 29
# best_start=5

# %%
print(f"EM_theta2_rad={EM_theta2_rad},\nEM_P2={EM_P2}")
# Out:
# EM_theta2_rad=[-0.50007323  0.70074002],
# EM_P2=[[ 2.14550864e+00+1.79756881e-15j -1.80933186e-03-2.96731544e-01j]
#  [-1.80933186e-03+2.96731544e-01j  1.71442520e+00-2.17625307e-15j]]

# %%
EM_theta2_deg = np.rad2deg(EM_theta2_rad)
print(f"Погрешность в смысле разности углов в градусах: \
      {np.abs(np.sort(EM_theta2_deg)-np.sort(theta2_deg))},")
print(f"Погрешность в смысле разности синусов углов: \
      {np.abs(np.sin(EM_theta2_rad)-np.sin(theta2_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах:       [0.00419579 0.04239988],
# Погрешность в смысле разности синусов углов:       [6.42644351e-05 5.65820122e-04].

# %%
em_stoch.incomplete_lkhd(X1_with_mv, theta1_rad, P_1, Q_1)
# Out:
# np.float64(-2824.8936593288777)

# %%
em_stoch.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q_1)
# Out:
# np.float64(-2835.83109961645)

# %%
em_stoch.incomplete_lkhd(X2_with_mv, theta2_rad, P_2, Q_2)
# Out:
# np.float64(-2106.4163518053156)

# %%
em_stoch.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q_2)
# Out:
# np.float64(-2131.8031070266493)
