# %%
import numpy as np

import sensors
import em_stoch

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 20
Num_emitters1 = 1
sample_size1 = 80
failing_sensors1 = np.array([2, 4], dtype=np.int16)
gap_ratio1 = np.array([0.5, 0.5], dtype=np.float32)
theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P_1 = 1 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q_1 = 2.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
N1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + N1.T).T

Num_sensors2 = 20
Num_emitters2 = 2
sample_size2 = 80
failing_sensors2 = np.array([2, 4], dtype=np.int16)
gap_ratio2 = np.array([0.5, 0.5], dtype=np.float32)
theta2_rad = np.array([-0.5, 0.7], dtype=np.float64) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P_2 = 1 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q_2 = 1.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sensors.gss(Num_emitters2, sample_size2, P_2)
N2 = sensors.gss(Num_sensors2, sample_size2, Q_2)
X2 = (A2 @ S2.T + N2.T).T

# %%
X1_with_mv = sensors.MCAR(X1, failing_sensors1, gap_ratio1)
X2_with_mv = sensors.MCAR(X2, failing_sensors2, gap_ratio2)
# Out:
# share_mv=[0.5 0.5]
# mis_cols=[2 4]
# share_mv=[0.5 0.5]
# mis_cols=[2 4]

# %%
X1_with_mv
# Out:
# array([[ 1.47375889-1.19127215j,  0.03175204-1.88842948j,
#                 nan+0.j        , ..., -0.76397286-2.94873339j,
#          0.72662444+0.27358696j,  1.62576741-0.61924096j],
#        [-0.75093165-1.09293498j, -0.99980865-0.34039036j,
#          2.94445197-1.56076135j, ...,  0.33293359+0.82505105j,
#          0.07846728+0.13232699j, -1.07843768+0.39630101j],
#        [ 0.76613778+1.51307616j,  0.98300291+0.8604167j ,
#         -2.77695094-1.28910182j, ..., -0.60766186+0.05449384j,
#         -1.0589133 -1.09211055j, -0.1291021 +1.6502334j ],
#        ...,
#        [ 1.16245983+2.06921586j,  2.97479457-1.66960229j,
#         -2.74510029-0.87284081j, ...,  1.19492776-0.80840476j,
#         -2.23063739-0.51135893j,  0.20866592+3.56230975j],
#        [ 1.57700122+0.90672591j, -2.1236758 -2.06001117j,
#         -1.06651492+2.87218098j, ..., -1.12889979-0.66445606j,
#         -0.37962652-0.26983634j,  1.95978744-1.35519038j],
#        [-0.56114001+1.07715026j, -0.59027711+0.12132465j,
#                 nan+0.j        , ...,  1.47473186+0.5409653j ,
#         -1.79549689-0.86866438j, -0.2348961 -0.34663937j]], shape=(80, 20))

# %%
print(np.trace(sensors.initial_Cov(X1_with_mv)))
print(np.trace(sensors.complex_cov(X1)))
# Out:
# Way First
# (73.88343486532314+0j)
# (63.702954966635296+0j)

# %%
EM_theta1_rad, EM_P1, lhd_1 = em_stoch.multi_start_EM(X1_with_mv, 
                                                      Num_emitters1, 
                                                      Q=Q_1, 
                                                      num_of_starts=10, 
                                                      max_iter=30, 
                                                      rtol=1e-6)
# Out:
# Way First
# 0-th start
# theta=[0.15335215],P=[0.00022361+0.j]
# Way First
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379+0.00000000e+00j
#  1.98180846-1.35525272e-20j 1.24264901-3.38813179e-21j
#  3.65111824+0.00000000e+00j 1.6804558 +0.00000000e+00j
#  0.96155409-6.77626358e-21j 1.27025671+0.00000000e+00j
#  1.65889204+0.00000000e+00j 1.36190987+0.00000000e+00j
#  1.09550401+0.00000000e+00j 0.89691465+0.00000000e+00j
#  1.6196736 +1.35525272e-20j 0.79194526-1.69406589e-21j
#  1.14151686+0.00000000e+00j 2.29130715+1.35525272e-20j
#  1.17223031+0.00000000e+00j 1.31477482+0.00000000e+00j
#  1.22932654+0.00000000e+00j 1.67873947+0.00000000e+00j]
# new_angles=[0.15335215]
# likelihood is -3420.8363426126166 on iteration 0
# new_angles=[0.15335215]
# 1-th start
# theta=[0.13636065],P=[0.0023446-2.48253415e-17j]
# Way First
# Initial diagonal of diff is [1.83120106+2.48253415e-17j 3.0029428 +2.48282297e-17j
#  1.97968746+2.47198095e-17j 1.24052801+2.47198095e-17j
#  3.64899724+2.48824399e-17j 1.67833481+2.51534904e-17j
#  0.95943309+2.47198095e-17j 1.26813572+2.48824399e-17j
#  1.65677104+2.49366500e-17j 1.35978887+2.47198095e-17j
#  1.09338301+2.47198095e-17j 0.89479365+2.48214535e-17j
#  1.61755261+2.48282297e-17j 0.78982427+2.47198095e-17j
#  1.13939587+2.47198095e-17j 2.28918616+2.48282297e-17j
#  1.17010932+2.47198095e-17j 1.31265383+2.49366500e-17j
#  1.22720554+2.48282297e-17j 1.67661847+2.47198095e-17j]
# new_angles=[0.13252582]
# likelihood is -3420.679840162819 on iteration 0
# new_angles=[0.13170934]
# likelihood is -3420.8132809195654 on iteration 1
# new_angles=[0.13093837]
# likelihood is -3421.0191447515062 on iteration 2
# new_angles=[0.13021149]
# likelihood is -3421.329444275318 on iteration 3
# new_angles=[0.12952634]
# likelihood is -3421.787936558403 on iteration 4
# new_angles=[0.12888232]
# likelihood is -3422.4507578766406 on iteration 5
# new_angles=[0.12827525]
# likelihood is -3423.382050612769 on iteration 6
# new_angles=[0.12770436]
# likelihood is -3424.6417139951573 on iteration 7
# new_angles=[0.12716766]
# likelihood is -3426.2627085087975 on iteration 8
# new_angles=[0.12666332]
# likelihood is -3428.224743318241 on iteration 9
# new_angles=[0.12618962]
# likelihood is -3430.4400074408345 on iteration 10
# new_angles=[0.12574498]
# likelihood is -3432.7673669633223 on iteration 11
# new_angles=[0.12532793]
# likelihood is -3435.053670065288 on iteration 12
# new_angles=[0.12493729]
# likelihood is -3437.1788847660455 on iteration 13
# new_angles=[0.12457158]
# likelihood is -3439.079929275353 on iteration 14
# new_angles=[0.12422923]
# likelihood is -3440.7473510010313 on iteration 15
# new_angles=[0.12390924]
# likelihood is -3442.206512174354 on iteration 16
# new_angles=[0.12361037]
# likelihood is -3443.497481911487 on iteration 17
# new_angles=[0.12333152]
# likelihood is -3444.661195886737 on iteration 18
# new_angles=[0.1230712]
# likelihood is -3445.7325603503673 on iteration 19
# new_angles=[0.12282807]
# likelihood is -3446.738462125471 on iteration 20
# new_angles=[0.12260121]
# likelihood is -3447.698298836384 on iteration 21
# new_angles=[0.12238955]
# likelihood is -3448.6254181123386 on iteration 22
# new_angles=[0.12219208]
# likelihood is -3449.5287139764996 on iteration 23
# new_angles=[0.12200785]
# likelihood is -3450.4139752149135 on iteration 24
# new_angles=[0.12183595]
# likelihood is -3451.284909605865 on iteration 25
# new_angles=[0.12167564]
# likelihood is -3452.1438785263626 on iteration 26
# new_angles=[0.121526]
# likelihood is -3452.9923812682396 on iteration 27
# new_angles=[0.12138652]
# likelihood is -3453.831396008877 on iteration 28
# new_angles=[0.12125645]
# likelihood is -3454.6615646806927 on iteration 29
# 2-th start
# theta=[1.40627821],P=[0.02319093+3.56864285e-17j]
# Way First
# Initial diagonal of diff is [1.81035473-3.56864285e-17j 2.98209647-3.55618313e-17j
#  1.95884114-3.59955121e-17j 1.21968169-3.55618313e-17j
#  3.62815091-3.64291930e-17j 1.65748848-3.55618313e-17j
#  0.93858677-3.55618313e-17j 1.24728939-3.46944695e-17j
#  1.63592472-3.55618313e-17j 1.33894255-3.46944695e-17j
#  1.07253669-3.46944695e-17j 0.87394733-3.64291930e-17j
#  1.59670628-3.46944695e-17j 0.76897794-3.46944695e-17j
#  1.11854954-3.64291930e-17j 2.26833983-3.64291930e-17j
#  1.14926299-3.46944695e-17j 1.2918075 -3.64291930e-17j
#  1.20635922-3.29597460e-17j 1.65577214-3.46944695e-17j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[-0.47492012+3.08248358e-14j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[-0.47492012+3.08248358e-14j]]
# new_angles=[1.4714373]
# likelihood is -3468.429081851265 on iteration 0
# new_angles=[1.46381354]
# likelihood is -3448.8357317182563 on iteration 1
# new_angles=[1.45696929]
# likelihood is -3442.1279256149933 on iteration 2
# new_angles=[1.45082434]
# likelihood is -3439.052691864471 on iteration 3
# new_angles=[1.44524774]
# likelihood is -3437.527632478509 on iteration 4
# new_angles=[1.44016079]
# likelihood is -3436.8261974267352 on iteration 5
# new_angles=[1.43550258]
# likelihood is -3436.628870570112 on iteration 6
# new_angles=[1.4312243]
# likelihood is -3436.7714290162694 on iteration 7
# new_angles=[1.42728528]
# likelihood is -3437.1582690763244 on iteration 8
# new_angles=[1.42365161]
# likelihood is -3437.7272797346277 on iteration 9
# new_angles=[1.42029413]
# likelihood is -3438.4340633305856 on iteration 10
# new_angles=[1.41718842]
# likelihood is -3439.244477945994 on iteration 11
# new_angles=[1.41431052]
# likelihood is -3440.131051880164 on iteration 12
# new_angles=[1.41164279]
# likelihood is -3441.071351457547 on iteration 13
# new_angles=[1.40916563]
# likelihood is -3442.0471296541427 on iteration 14
# new_angles=[1.4068645]
# likelihood is -3443.04391106648 on iteration 15
# new_angles=[1.40472535]
# likelihood is -3444.050565965867 on iteration 16
# new_angles=[1.40273543]
# likelihood is -3445.05888771556 on iteration 17
# new_angles=[1.4008832]
# likelihood is -3446.06311250535 on iteration 18
# new_angles=[1.39915896]
# likelihood is -3447.059424791624 on iteration 19
# new_angles=[1.3975523]
# likelihood is -3448.045476496656 on iteration 20
# new_angles=[1.39605355]
# likelihood is -3449.0199828856134 on iteration 21
# new_angles=[1.39465645]
# likelihood is -3449.9823895338473 on iteration 22
# new_angles=[1.39335236]
# likelihood is -3450.9325947885977 on iteration 23
# new_angles=[1.3921352]
# likelihood is -3451.870780191396 on iteration 24
# new_angles=[1.39099827]
# likelihood is -3452.7972720344105 on iteration 25
# new_angles=[1.38993603]
# likelihood is -3453.712464257264 on iteration 26
# new_angles=[1.38894311]
# likelihood is -3454.6167657474366 on iteration 27
# new_angles=[1.38801406]
# likelihood is -3455.5105737895265 on iteration 28
# new_angles=[1.38714511]
# likelihood is -3456.394261398658 on iteration 29
# 3-th start
# theta=[-0.15355298],P=[0.00022361+0.j]
# Way First
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379-1.35525272e-20j
#  1.98180846+0.00000000e+00j 1.24264901-3.38813179e-21j
#  3.65111824+0.00000000e+00j 1.6804558 +0.00000000e+00j
#  0.96155409+6.77626358e-21j 1.27025671-6.77626358e-21j
#  1.65889204+0.00000000e+00j 1.36190987+1.35525272e-20j
#  1.09550401+0.00000000e+00j 0.89691465+0.00000000e+00j
#  1.6196736 +0.00000000e+00j 0.79194526+0.00000000e+00j
#  1.14151686+0.00000000e+00j 2.29130715-1.35525272e-20j
#  1.17223031+0.00000000e+00j 1.31477482-1.35525272e-20j
#  1.22932654+1.35525272e-20j 1.67873947+0.00000000e+00j]
# new_angles=[-0.15355298]
# likelihood is -3420.896866232598 on iteration 0
# new_angles=[-0.15355298]
# 4-th start
# theta=[0.5300775],P=[0.58225455+3.18074688e-17j]
# Way First
# Initial diagonal of diff is [1.25129111-3.18074688e-17j 2.42303285-3.12250226e-17j
#  1.39977752-3.12250226e-17j 0.66061807-2.77555756e-17j
#  3.06908729-3.46944695e-17j 1.09842486-3.46944695e-17j
#  0.37952315-3.46944695e-17j 0.68822577-2.77555756e-17j
#  1.0768611 -2.77555756e-17j 0.77987893-4.16333634e-17j
#  0.51347307-2.77555756e-17j 0.31488371-1.38777878e-17j
#  1.03764266-2.77555756e-17j 0.20991432-2.77555756e-17j
#  0.55948592-2.77555756e-17j 1.70927621-2.77555756e-17j
#  0.59019937-2.77555756e-17j 0.73274388+0.00000000e+00j
#  0.6472956 -2.77555756e-17j 1.09670852+0.00000000e+00j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[8] is not psd
# K_S_cond[8]=[[-0.33942494+8.15009752e-10j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[28] is not psd
# K_S_cond[28]=[[-8.320551+9.04879197e-10j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[72] is not psd
# K_S_cond[72]=[[-30.29383531+6.11623999e-10j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[-420.36903435+1.98271652e-11j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[-420.36903435+1.98271652e-11j]]
# new_angles=[0.74282148]
# likelihood is -3557.881151521919 on iteration 0
# new_angles=[0.73363763]
# likelihood is -2968.009588996014 on iteration 1
# new_angles=[0.72638473]
# likelihood is -2917.772737370715 on iteration 2
# new_angles=[0.72068088]
# likelihood is -2886.903547145205 on iteration 3
# new_angles=[0.71620332]
# likelihood is -2867.300884935142 on iteration 4
# new_angles=[0.71268901]
# likelihood is -2854.897042700377 on iteration 5
# new_angles=[0.70993029]
# likelihood is -2847.1060910039223 on iteration 6
# new_angles=[0.70776393]
# likelihood is -2842.2443035111055 on iteration 7
# new_angles=[0.70606198]
# likelihood is -2839.22852885604 on iteration 8
# new_angles=[0.70472431]
# likelihood is -2837.3709242943532 on iteration 9
# new_angles=[0.70367252]
# likelihood is -2836.2383940175146 on iteration 10
# new_angles=[0.70284523]
# likelihood is -2835.559584590251 on iteration 11
# new_angles=[0.70219427]
# likelihood is -2835.1648741863755 on iteration 12
# new_angles=[0.70168198]
# likelihood is -2834.9484087432465 on iteration 13
# new_angles=[0.70127871]
# likelihood is -2834.84400021263 on iteration 14
# new_angles=[0.70096119]
# likelihood is -2834.810290584422 on iteration 15
# new_angles=[0.70071114]
# likelihood is -2834.8213737856386 on iteration 16
# new_angles=[0.7005142]
# likelihood is -2834.86098904991 on iteration 17
# new_angles=[0.70035906]
# likelihood is -2834.91889595369 on iteration 18
# new_angles=[0.70023684]
# likelihood is -2834.9886230398643 on iteration 19
# new_angles=[0.70014055]
# likelihood is -2835.06606109756 on iteration 20
# new_angles=[0.70006467]
# likelihood is -2835.1485860644298 on iteration 21
# new_angles=[0.70000488]
# likelihood is -2835.234511443094 on iteration 22
# new_angles=[0.69995775]
# likelihood is -2835.322744271306 on iteration 23
# new_angles=[0.69992061]
# likelihood is -2835.412569923709 on iteration 24
# new_angles=[0.69989134]
# likelihood is -2835.503515846603 on iteration 25
# new_angles=[0.69986826]
# likelihood is -2835.595266017291 on iteration 26
# new_angles=[0.69985007]
# likelihood is -2835.687605964132 on iteration 27
# new_angles=[0.69983573]
# likelihood is -2835.7803881311215 on iteration 28
# new_angles=[0.69982442]
# likelihood is -2835.8735093773585 on iteration 29
# 5-th start
# theta=[0.60846218],P=[1.04687128+2.48253415e-17j]
# Way First
# Initial diagonal of diff is [ 0.78667438-2.48253415e-17j  1.95841612-2.77555756e-17j
#   0.93516078+0.00000000e+00j  0.19600133+0.00000000e+00j
#   2.60447056+0.00000000e+00j  0.63380813+0.00000000e+00j
#  -0.08509359+0.00000000e+00j  0.22360904-2.42861287e-17j
#   0.61224436-2.77555756e-17j  0.31526219+0.00000000e+00j
#   0.04885633-1.11022302e-16j -0.14973303-1.11022302e-16j
#   0.57302593+0.00000000e+00j -0.25470241-2.77555756e-17j
#   0.09486919-2.25514052e-17j  1.24465948-2.77555756e-17j
#   0.12558264+0.00000000e+00j  0.26812715-1.11022302e-16j
#   0.18267886+0.00000000e+00j  0.63209179+5.55111512e-17j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[8] is not psd
# K_S_cond[8]=[[-4.1055098+3.07784232e-10j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[18] is not psd
# K_S_cond[18]=[[-9.11488862-3.96505728e-10j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[33] is not psd
# K_S_cond[33]=[[-37.29481305-6.57417021e-10j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[69] is not psd
# K_S_cond[69]=[[-40.65683131+3.45755635e-10j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[-213.78885657+1.35626956e-11j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[-213.78885657+1.35626956e-11j]]
# new_angles=[0.60487213]
# likelihood is -4038.572771591343 on iteration 0
# new_angles=[0.61857339]
# likelihood is -3338.1933213450156 on iteration 1
# new_angles=[0.6324306]
# likelihood is -3237.9760122262333 on iteration 2
# new_angles=[0.64497882]
# likelihood is -3135.33034195626 on iteration 3
# new_angles=[0.65568532]
# likelihood is -3045.1568664064334 on iteration 4
# new_angles=[0.66454025]
# likelihood is -2975.910039797527 on iteration 5
# new_angles=[0.67173805]
# likelihood is -2926.6636166152207 on iteration 6
# new_angles=[0.677529]
# likelihood is -2893.3208122364554 on iteration 7
# new_angles=[0.68215808]
# likelihood is -2871.4856824047674 on iteration 8
# new_angles=[0.68584273]
# likelihood is -2857.5033411293134 on iteration 9
# new_angles=[0.68876728]
# likelihood is -2848.6874073364365 on iteration 10
# new_angles=[0.69108388]
# likelihood is -2843.1946173057972 on iteration 11
# new_angles=[0.69291642]
# likelihood is -2839.808619605831 on iteration 12
# new_angles=[0.69436457]
# likelihood is -2837.7461011534806 on iteration 13
# new_angles=[0.69550815]
# likelihood is -2836.509612420968 on iteration 14
# new_angles=[0.69641071]
# likelihood is -2835.7863160921206 on iteration 15
# new_angles=[0.69712285]
# likelihood is -2835.3805634558153 on iteration 16
# new_angles=[0.69768456]
# likelihood is -2835.1706892685856 on iteration 17
# new_angles=[0.69812754]
# likelihood is -2835.0811932771862 on iteration 18
# new_angles=[0.69847683]
# likelihood is -2835.065383342768 on iteration 19
# new_angles=[0.69875223]
# likelihood is -2835.094461010282 on iteration 20
# new_angles=[0.69896936]
# likelihood is -2835.1507189474314 on iteration 21
# new_angles=[0.69914055]
# likelihood is -2835.2233072162894 on iteration 22
# new_angles=[0.6992755]
# likelihood is -2835.3056068209976 on iteration 23
# new_angles=[0.6993819]
# likelihood is -2835.393602226789 on iteration 24
# new_angles=[0.69946578]
# likelihood is -2835.484875088865 on iteration 25
# new_angles=[0.69953192]
# likelihood is -2835.5779829612975 on iteration 26
# new_angles=[0.69958407]
# likelihood is -2835.672077147153 on iteration 27
# new_angles=[0.69962518]
# likelihood is -2835.766667501033 on iteration 28
# new_angles=[0.6996576]
# likelihood is -2835.8614786712046 on iteration 29
# 6-th start
# theta=[-1.46911153],P=[0.02410148-1.08610869e-17j]
# Way First
# Initial diagonal of diff is [1.80944417+1.08610869e-17j 2.98118591+1.08962318e-17j
#  1.95793058+1.08420217e-17j 1.21877113+1.08420217e-17j
#  3.62724036+1.06251813e-17j 1.65657793+1.10588622e-17j
#  0.93767621+1.08420217e-17j 1.24637883+1.08420217e-17j
#  1.63501416+1.08420217e-17j 1.33803199+1.08420217e-17j
#  1.07162613+1.17093835e-17j 0.87303677+1.12757026e-17j
#  1.59579573+1.04083409e-17j 0.76806738+1.12757026e-17j
#  1.11763899+1.12757026e-17j 2.26742928+1.21430643e-17j
#  1.14835244+1.12757026e-17j 1.29089695+1.04083409e-17j
#  1.20544866+1.12757026e-17j 1.65486159+1.12757026e-17j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[-0.49748162+3.21197476e-14j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[-0.49748162+3.21197476e-14j]]
# new_angles=[-1.4269565]
# likelihood is -3481.134578590215 on iteration 0
# new_angles=[-1.43325302]
# likelihood is -3452.5573582933466 on iteration 1
# new_angles=[-1.43999323]
# likelihood is -3444.0200443592125 on iteration 2
# new_angles=[-1.44721125]
# likelihood is -3440.2279604115884 on iteration 3
# new_angles=[-1.45499202]
# likelihood is -3438.320712802884 on iteration 4
# new_angles=[-1.46345836]
# likelihood is -3437.3735804662088 on iteration 5
# new_angles=[-1.47272244]
# likelihood is -3436.9991003383802 on iteration 6
# new_angles=[-1.48294122]
# likelihood is -3437.0056791368033 on iteration 7
# new_angles=[-1.49449943]
# likelihood is -3437.284878563849 on iteration 8
# new_angles=[-1.50804406]
# likelihood is -3437.768918827881 on iteration 9
# new_angles=[-1.52524114]
# likelihood is -3438.4102317505813 on iteration 10
# new_angles=[-1.55529251]
# likelihood is -3439.172485750489 on iteration 11
# new_angles=[1.53128068]
# likelihood is -3440.026123120926 on iteration 12
# new_angles=[1.51314717]
# likelihood is -3440.9465038125727 on iteration 13
# new_angles=[1.49979712]
# likelihood is -3441.9128486258664 on iteration 14
# new_angles=[1.48887941]
# likelihood is -3442.9080599079457 on iteration 15
# new_angles=[1.4795466]
# likelihood is -3443.9186673836184 on iteration 16
# new_angles=[1.47134646]
# likelihood is -3444.9341699564243 on iteration 17
# new_angles=[1.46404023]
# likelihood is -3445.947271418525 on iteration 18
# new_angles=[1.45746159]
# likelihood is -3446.952907967241 on iteration 19
# new_angles=[1.45149388]
# likelihood is -3447.9479066161066 on iteration 20
# new_angles=[1.44605071]
# likelihood is -3448.9305002280826 on iteration 21
# new_angles=[1.44106543]
# likelihood is -3449.899904844116 on iteration 22
# new_angles=[1.4364933]
# likelihood is -3450.8560533221257 on iteration 23
# new_angles=[1.43228098]
# likelihood is -3451.799079611931 on iteration 24
# new_angles=[1.42839303]
# likelihood is -3452.729460879363 on iteration 25
# new_angles=[1.42479744]
# likelihood is -3453.6477394129424 on iteration 26
# new_angles=[1.42146732]
# likelihood is -3454.5544827965255 on iteration 27
# new_angles=[1.41837691]
# likelihood is -3455.4502165397503 on iteration 28
# new_angles=[1.41551023]
# likelihood is -3456.3354781311905 on iteration 29
# 7-th start
# theta=[-1.07899142],P=[0.00022361+0.j]
# Way First
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379+0.00000000e+00j
#  1.98180846+0.00000000e+00j 1.24264901+0.00000000e+00j
#  3.65111824-3.38813179e-21j 1.6804558 -1.35525272e-20j
#  0.96155409+0.00000000e+00j 1.27025671+1.35525272e-20j
#  1.65889204-6.77626358e-21j 1.36190987-6.77626358e-21j
#  1.09550401+0.00000000e+00j 0.89691465+0.00000000e+00j
#  1.6196736 +0.00000000e+00j 0.79194526-3.38813179e-21j
#  1.14151686+0.00000000e+00j 2.29130715+0.00000000e+00j
#  1.17223031+0.00000000e+00j 1.31477482+0.00000000e+00j
#  1.22932654+1.35525272e-20j 1.67873947+0.00000000e+00j]
# new_angles=[-1.07899142]
# likelihood is -3420.8261577653902 on iteration 0
# new_angles=[-1.07899142]
# 8-th start
# theta=[-1.31513736],P=[0.02945007-2.017059e-17j]
# Way First
# Initial diagonal of diff is [1.80409559+2.01705900e-17j 2.97583733+1.99493200e-17j
#  1.952582  +1.99493200e-17j 1.21342255+2.08166817e-17j
#  3.62189178+2.08166817e-17j 1.65122934+1.90819582e-17j
#  0.93232763+2.25514052e-17j 1.24103025+2.08166817e-17j
#  1.62966558+2.08166817e-17j 1.33268341+2.25514052e-17j
#  1.06627755+1.90819582e-17j 0.86768819+1.90819582e-17j
#  1.59044714+2.08166817e-17j 0.7627188 +2.08166817e-17j
#  1.1122904 +1.99493200e-17j 2.26208069+2.01661604e-17j
#  1.14300385+1.99493200e-17j 1.28554836+1.99493200e-17j
#  1.20010008+2.08166817e-17j 1.64951301+1.90819582e-17j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[-0.47769795+3.01983749e-14j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[-0.47769795+3.01983749e-14j]]
# new_angles=[-1.33270966]
# likelihood is -3503.8054879929914 on iteration 0
# new_angles=[-1.33141339]
# likelihood is -3457.125539053484 on iteration 1
# new_angles=[-1.33002355]
# likelihood is -3446.085231403046 on iteration 2
# new_angles=[-1.32852656]
# likelihood is -3441.4804914828646 on iteration 3
# new_angles=[-1.32691226]
# likelihood is -3439.2067832089724 on iteration 4
# new_angles=[-1.32517067]
# likelihood is -3438.0593388516095 on iteration 5
# new_angles=[-1.32329242]
# likelihood is -3437.558662969092 on iteration 6
# new_angles=[-1.32126743]
# likelihood is -3437.4756293293835 on iteration 7
# new_angles=[-1.31908553]
# likelihood is -3437.68512468683 on iteration 8
# new_angles=[-1.31673635]
# likelihood is -3438.110587617506 on iteration 9
# new_angles=[-1.31420961]
# likelihood is -3438.6999557323693 on iteration 10
# new_angles=[-1.31149506]
# likelihood is -3439.414314509754 on iteration 11
# new_angles=[-1.30858381]
# likelihood is -3440.2223834528168 on iteration 12
# new_angles=[-1.30546485]
# likelihood is -3441.097758365151 on iteration 13
# new_angles=[-1.30213077]
# likelihood is -3442.0178672213765 on iteration 14
# new_angles=[-1.29857661]
# likelihood is -3442.9634593675005 on iteration 15
# new_angles=[-1.29479483]
# likelihood is -3443.91821419596 on iteration 16
# new_angles=[-1.29078411]
# likelihood is -3444.868895443055 on iteration 17
# new_angles=[-1.2865456]
# likelihood is -3445.804993314097 on iteration 18
# new_angles=[-1.28208493]
# likelihood is -3446.7185296133352 on iteration 19
# new_angles=[-1.2774112]
# likelihood is -3447.6036933596624 on iteration 20
# new_angles=[-1.2725394]
# likelihood is -3448.4566706979626 on iteration 21
# new_angles=[-1.26749082]
# likelihood is -3449.275432571779 on iteration 22
# new_angles=[-1.26229225]
# likelihood is -3450.059503129608 on iteration 23
# new_angles=[-1.25697325]
# likelihood is -3450.809639174949 on iteration 24
# new_angles=[-1.2515744]
# likelihood is -3451.5284031797482 on iteration 25
# new_angles=[-1.24612582]
# likelihood is -3452.2182725144 on iteration 26
# new_angles=[-1.24067691]
# likelihood is -3452.8842099338644 on iteration 27
# new_angles=[-1.23526959]
# likelihood is -3453.530952064663 on iteration 28
# new_angles=[-1.22994573]
# likelihood is -3454.163633173349 on iteration 29
# 9-th start
# theta=[-0.20985359],P=[0.00022361+0.j]
# Way First
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379+0.00000000e+00j
#  1.98180846+0.00000000e+00j 1.24264901-1.35525272e-20j
#  3.65111824+0.00000000e+00j 1.6804558 +0.00000000e+00j
#  0.96155409+1.35525272e-20j 1.27025671+0.00000000e+00j
#  1.65889204-1.35525272e-20j 1.36190987+1.35525272e-20j
#  1.09550401+0.00000000e+00j 0.89691465+1.35525272e-20j
#  1.6196736 +2.64697796e-23j 0.79194526+0.00000000e+00j
#  1.14151686+0.00000000e+00j 2.29130715+0.00000000e+00j
#  1.17223031+0.00000000e+00j 1.31477482+0.00000000e+00j
#  1.22932654+0.00000000e+00j 1.67873947+3.38813179e-21j]
# new_angles=[-0.20985359]
# likelihood is -3420.909393623268 on iteration 0
# new_angles=[-0.20985359]
# best_start=5

# %%
print(f"EM_theta1_rad={EM_theta1_rad},\nEM_P1={EM_P1}")
# Out:
# EM_theta1_rad=[0.6996576],
# EM_P1=[[2.02243233-1.34738233e-11j]]

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)
print(f"Погрешность в смысле разности углов в градусах: \
      {np.abs(EM_theta1_deg-theta1_deg)},")
print(f"Погрешность в смысле разности синусов углов: \
      {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах:       [0.01961807],
# Погрешность в смысле разности синусов углов:       [0.00026192].

# %%
print(np.trace(sensors.initial_Cov(X2_with_mv)))
print(np.trace(sensors.complex_cov(X2)))
# Out:
# Way First
# (49.65503774285381+0j)
# (61.03171543408073+0j)

# %%
EM_theta2_rad, EM_P2, lhd_2 = em_stoch.multi_start_EM(X2_with_mv, 
                                                      Num_emitters2, 
                                                      Q=Q_2, 
                                                      num_of_starts=10, 
                                                      max_iter=30,
                                                      rtol=1e-3)
# Out:
# Way First
# 0-th start
# theta=[-1.41744418  0.15335215],P=[0.00276336-1.33017438e-17j 0.00299515+1.51605636e-17j]
# Way First
# Initial diagonal of diff is [1.15026919-1.85881981e-18j 1.99389114-1.73472348e-18j
#  1.06671809-1.73472348e-18j 1.72938522-1.84314369e-18j
#  1.14907423-1.84314369e-18j 2.05874687-1.95156391e-18j
#  0.64406552-1.78893358e-18j 1.342387  -1.95156391e-18j
#  1.1722289 -1.73472348e-18j 0.99058821-1.95156391e-18j
#  1.30708874-2.05998413e-18j 1.34610167-2.16840434e-18j
#  1.15990072-2.08708918e-18j 0.72086538-1.95156391e-18j
#  1.63418616-1.73472348e-18j 1.56259193-1.73472348e-18j
#  2.11217389-2.16840434e-18j 0.92115863-1.78893358e-18j
#  1.31483313-2.19550940e-18j 2.16361287-1.84314369e-18j]
# new_angles=[-0.51926116  0.14911809]
# likelihood is -4020.4032750670167 on iteration 0
# new_angles=[-0.51646482 -0.47820429]
# likelihood is -3194.819489522057 on iteration 1
# new_angles=[-0.51614629 -0.47861158]
# likelihood is -3080.3862260088913 on iteration 2
# new_angles=[-0.51623319 -0.47844319]
# likelihood is -3089.393796765344 on iteration 3
# new_angles=[-0.51635067 -0.47824293]
# likelihood is -3090.1730530356244 on iteration 4
# new_angles=[-0.51639266 -0.47816218]
# 1-th start
# theta=[-1.43443568  0.13636065],P=[0.00418494+4.66459589e-19j 0.00895224-1.69786193e-17j]
# Way First
# Initial diagonal of diff is [1.14289052+1.65121597e-17j 1.98651248+1.64798730e-17j
#  1.05933942+1.64798730e-17j 1.72200656+1.64798730e-17j
#  1.14169557+1.62630326e-17j 2.0513682 +1.56125113e-17j
#  0.63668686+1.60461922e-17j 1.33500833+1.64798730e-17j
#  1.16485024+1.64798730e-17j 0.98320954+1.73472348e-17j
#  1.29971007+1.64798730e-17j 1.33872301+1.64798730e-17j
#  1.15252205+1.66967135e-17j 0.71348671+1.64798730e-17j
#  1.62680749+1.62630326e-17j 1.55521327+1.69135539e-17j
#  2.10479523+1.64798730e-17j 0.91377997+1.64798730e-17j
#  1.30745447+1.64798730e-17j 2.15623421+1.72388145e-17j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[ 0.00095436-2.34634130e-17j  0.00061376+7.60614821e-04j]
#  [ 0.00061376-7.60614821e-04j -0.00244144-3.71792769e-17j]]
# new_angles=[-0.51155379  0.12939746]
# likelihood is -3930.361195975587 on iteration 0
# new_angles=[-0.50943539  0.14093883]
# likelihood is -3307.2219441973316 on iteration 1
# new_angles=[-0.50744762 -0.49850676]
# likelihood is -3092.056849032798 on iteration 2
# new_angles=[-0.50652183 -0.49671144]
# likelihood is -3092.9682526869224 on iteration 3
# new_angles=[-0.50585174 -0.4953407 ]
# likelihood is -3091.178495991021 on iteration 4
# new_angles=[-0.50541588 -0.49411055]
# likelihood is -3089.966374122169 on iteration 5
# new_angles=[-0.50517859 -0.49292592]
# likelihood is -3089.244613692278 on iteration 6
# new_angles=[-0.50511614 -0.49170828]
# likelihood is -3088.8220606703403 on iteration 7
# new_angles=[-0.5052094  -0.49040628]
# likelihood is -3088.586149011027 on iteration 8
# new_angles=[-0.50544115 -0.4889976 ]
# likelihood is -3088.4888151850937 on iteration 9
# new_angles=[-0.50579392 -0.48747343]
# likelihood is -3088.540082233308 on iteration 10
# new_angles=[-0.50624602 -0.48584928]
# likelihood is -3088.83442502851 on iteration 11
# new_angles=[-0.50676836 -0.48415552]
# likelihood is -3089.6190334857783 on iteration 12
# new_angles=[-0.50732825 -0.48242837]
# likelihood is -3091.4192154157554 on iteration 13
# new_angles=[-0.50785448 -0.48081422]
# likelihood is -3094.968974769594 on iteration 14
# new_angles=[-0.50826743 -0.47951291]
# likelihood is -3100.493420451407 on iteration 15
# new_angles=[-0.50853068 -0.47862087]
# likelihood is -3106.9165024251806 on iteration 16
# new_angles=[-0.5086651  -0.47807532]
# likelihood is -3112.6301008661985 on iteration 17
# new_angles=[-0.50871391 -0.47775062]
# likelihood is -3116.8881478278618 on iteration 18
# new_angles=[-0.50871357 -0.47754391]
# likelihood is -3119.87196735659 on iteration 19
# new_angles=[-0.50868669 -0.47739286]
# likelihood is -3122.0413797631945 on iteration 20
# new_angles=[-0.50864517 -0.47726513]
# likelihood is -3123.7625275145156 on iteration 21
# new_angles=[-0.50859472 -0.47714507]
# likelihood is -3125.2524040042945 on iteration 22
# new_angles=[-0.50853798 -0.47702545]
# likelihood is -3126.623493712309 on iteration 23
# new_angles=[-0.5084761  -0.47690297]
# likelihood is -3127.9301600252857 on iteration 24
# new_angles=[-0.50840959 -0.47677612]
# likelihood is -3129.197660052066 on iteration 25
# new_angles=[-0.50833864 -0.47664414]
# likelihood is -3130.437555724268 on iteration 26
# new_angles=[-0.50826336 -0.47650666]
# likelihood is -3131.655134353837 on iteration 27
# new_angles=[-0.50818376 -0.4763634 ]
# likelihood is -3132.8529736730115 on iteration 28
# new_angles=[-0.50809985 -0.47621414]
# likelihood is -3134.0324431602103 on iteration 29
# 2-th start
# theta=[-0.16451812  1.40627821],P=[0.00022361+0.00000000e+00j 0.00946101+1.83129637e-17j]
# Way First
# Initial diagonal of diff is [1.14634309-1.83129637e-17j 1.98996504-1.83230167e-17j
#  1.06279199-1.82145965e-17j 1.72545912-1.82145965e-17j
#  1.14514813-1.82145965e-17j 2.05482077-1.82145965e-17j
#  0.64013942-1.82145965e-17j 1.33846089-1.86482774e-17j
#  1.1683028 -1.86482774e-17j 0.98666211-1.77809156e-17j
#  1.30316264-1.82145965e-17j 1.34217557-1.77809156e-17j
#  1.15597461-1.82145965e-17j 0.71693928-1.82145965e-17j
#  1.63026006-1.90819582e-17j 1.55866583-1.90819582e-17j
#  2.10824779-1.82145965e-17j 0.91723253-1.82145965e-17j
#  1.31090703-1.82145965e-17j 2.15968677-1.90819582e-17j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[ 0.00020706-1.34344976e-19j  0.00023065-1.82614843e-04j]
#  [ 0.00023065+1.82614843e-04j -0.00476852-8.73352415e-17j]]
# new_angles=[-0.4771101   0.65894609]
# likelihood is -3728.703597336334 on iteration 0
# new_angles=[0.73548478 0.66785637]
# likelihood is -3533.902560945143 on iteration 1
# new_angles=[0.67432908 0.74193082]
# likelihood is -3474.1952669464076 on iteration 2
# new_angles=[0.67947668 0.74683844]
# likelihood is -3432.8463397945497 on iteration 3
# new_angles=[0.68355473 0.75051432]
# likelihood is -3405.6203891148753 on iteration 4
# new_angles=[0.68677625 0.75324472]
# likelihood is -3388.38523433741 on iteration 5
# new_angles=[0.68932389 0.7551622 ]
# likelihood is -3377.5942840170624 on iteration 6
# new_angles=[0.69133645 0.75646712]
# likelihood is -3370.8779440995067 on iteration 7
# new_angles=[0.69292348 0.7572933 ]
# likelihood is -3366.7184881396106 on iteration 8
# new_angles=[0.69418427 0.75766317]
# likelihood is -3364.136485449177 on iteration 9
# new_angles=[0.69518379 0.75771394]
# likelihood is -3362.541895348024 on iteration 10
# new_angles=[0.69597993 0.75753098]
# likelihood is -3361.5572664585775 on iteration 11
# new_angles=[0.69661931 0.75708511]
# likelihood is -3360.9521788775187 on iteration 12
# new_angles=[0.69714158 0.75632623]
# likelihood is -3360.5813522589647 on iteration 13
# new_angles=[0.69758063 0.75515554]
# likelihood is -3360.3541870121203 on iteration 14
# new_angles=[0.69798262 0.75308727]
# likelihood is -3360.204948917151 on iteration 15
# new_angles=[0.69841094 0.74917965]
# likelihood is -3360.081926845263 on iteration 16
# new_angles=[0.69886383 0.74368911]
# likelihood is -3359.9988993552574 on iteration 17
# new_angles=[0.69929007 0.7378613 ]
# likelihood is -3360.011057354759 on iteration 18
# new_angles=[0.69965844 0.73233914]
# likelihood is -3360.12913863902 on iteration 19
# new_angles=[0.69995739 0.72738261]
# likelihood is -3360.3357231370996 on iteration 20
# new_angles=[0.70019692 0.72288961]
# likelihood is -3360.593303277374 on iteration 21
# new_angles=[0.70038387 0.71879531]
# likelihood is -3360.886740695502 on iteration 22
# new_angles=[ 0.6988609  -0.19033422]
# likelihood is -3363.170992044086 on iteration 23
# new_angles=[-0.18993574  0.69938537]
# likelihood is -3362.9642437941316 on iteration 24
# new_angles=[-0.18965948  0.69979569]
# likelihood is -3362.7494128498397 on iteration 25
# new_angles=[-0.18942655  0.70011721]
# likelihood is -3362.635813180281 on iteration 26
# new_angles=[-0.18922666  0.70036921]
# likelihood is -3362.5928637131105 on iteration 27
# new_angles=[-0.18905461  0.70056682]
# 3-th start
# theta=[-0.15355298  1.41724335],P=[0.00022361+0.00000000e+00j 0.01145339-9.79187246e-18j]
# Way First
# Initial diagonal of diff is [1.1443507 +9.79187246e-18j 1.98797266+9.75781955e-18j
#  1.0607996 +9.75781955e-18j 1.72346674+9.75781955e-18j
#  1.14315575+9.97465999e-18j 2.05282839+9.54097912e-18j
#  0.63814704+9.54097912e-18j 1.33646851+9.97465999e-18j
#  1.16631042+9.97465999e-18j 0.98466973+9.54097912e-18j
#  1.30117025+1.04083409e-17j 1.34018319+1.04083409e-17j
#  1.15398223+9.54097912e-18j 0.7149469 +9.54097912e-18j
#  1.62826767+1.04083409e-17j 1.55667345+9.54097912e-18j
#  2.10625541+9.54097912e-18j 0.91524015+1.04083409e-17j
#  1.30891465+1.04083409e-17j 2.15769439+1.04083409e-17j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[ 0.00020893-1.15908001e-19j  0.00030309-1.35952479e-04j]
#  [ 0.00030309+1.35952479e-04j -0.00973108-1.68914895e-16j]]
# new_angles=[-0.16945169  0.65947283]
# likelihood is -3698.845103723724 on iteration 0
# new_angles=[0.74595597 0.6682773 ]
# likelihood is -3535.9824078599495 on iteration 1
# new_angles=[0.67478306 0.75238875]
# likelihood is -3475.399091528091 on iteration 2
# new_angles=[0.67995377 0.75725189]
# likelihood is -3433.281303779496 on iteration 3
# new_angles=[0.68404594 0.76089592]
# likelihood is -3405.8763740847985 on iteration 4
# new_angles=[0.68727631 0.76358423]
# likelihood is -3388.567901352013 on iteration 5
# new_angles=[0.68982404 0.76548353]
# likelihood is -3377.752705674995 on iteration 6
# new_angles=[0.69183318 0.76675637]
# likelihood is -3371.0281214484535 on iteration 7
# new_angles=[0.69341636 0.76756042]
# likelihood is -3366.86167898077 on iteration 8
# new_angles=[0.69466863 0.76789279]
# likelihood is -3364.282922579538 on iteration 9
# new_angles=[0.69565993 0.76789928]
# likelihood is -3362.6897302642246 on iteration 10
# new_angles=[0.69644748 0.7676279 ]
# likelihood is -3361.7080129034703 on iteration 11
# new_angles=[0.69707654 0.76710562]
# likelihood is -3361.106166415551 on iteration 12
# new_angles=[0.69758816 0.76621027]
# likelihood is -3360.7379452169384 on iteration 13
# new_angles=[ 0.6978274  -0.18334998]
# likelihood is -3361.381090037876 on iteration 14
# new_angles=[-0.1830504   0.69857128]
# likelihood is -3361.9043252001816 on iteration 15
# new_angles=[-0.18270283  0.69915386]
# likelihood is -3361.4755301554164 on iteration 16
# new_angles=[-0.18237781  0.69960882]
# likelihood is -3361.176693670628 on iteration 17
# new_angles=[-0.18209458  0.69996485]
# likelihood is -3361.0099000074633 on iteration 18
# new_angles=[-0.18184703  0.7002435 ]
# likelihood is -3360.929095655657 on iteration 19
# new_angles=[-0.18163206  0.70046164]
# likelihood is -3360.9024263872784 on iteration 20
# new_angles=[-0.18144119  0.70063248]
# likelihood is -3360.910024874991 on iteration 21
# new_angles=[-0.18127097  0.70076634]
# likelihood is -3360.9395095094806 on iteration 22
# new_angles=[-0.18111797  0.70087131]
# likelihood is -3360.983191612223 on iteration 23
# new_angles=[-0.18097943  0.70095369]
# likelihood is -3361.0362696521815 on iteration 24
# new_angles=[-0.18085317  0.70101844]
# likelihood is -3361.0957335212693 on iteration 25
# new_angles=[-0.1807375  0.7010694]
# likelihood is -3361.159688816957 on iteration 26
# new_angles=[-0.18063107  0.70110959]
# likelihood is -3361.226943065952 on iteration 27
# new_angles=[-0.18053402  0.70114149]
# likelihood is -3361.2967050977127 on iteration 28
# new_angles=[-0.18044226  0.70116672]
# likelihood is -3361.36858283772 on iteration 29
# 4-th start
# theta=[-1.04071883  0.5300775 ],P=[2.23606798e-04+0.00000000e+00j 2.29381778e-01-5.29392466e-17j]
# Way First
# Initial diagonal of diff is [0.92642231+5.29392466e-17j 1.77004427+5.29090660e-17j
#  0.84287122+5.37764278e-17j 1.50553835+5.37764278e-17j
#  0.92522736+5.20417043e-17j 1.8349    +5.20417043e-17j
#  0.42021865+5.20417043e-17j 1.11854012+5.20417043e-17j
#  0.94838203+5.55111512e-17j 0.76674134+5.55111512e-17j
#  1.08324187+5.55111512e-17j 1.1222548 +5.55111512e-17j
#  0.93605384+4.16333634e-17j 0.49701851+4.85722573e-17j
#  1.41033929+4.85722573e-17j 1.33874506+4.85722573e-17j
#  1.88832702+5.55111512e-17j 0.69731176+5.55111512e-17j
#  1.09098626+5.55111512e-17j 1.939766  +5.55111512e-17j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[23] is not psd
# K_S_cond[23]=[[ 3.48009759e-04-2.95512954e-19j  6.53071567e-03-2.30785243e-02j]
#  [ 6.53071567e-03+2.30785243e-02j -1.13972341e+00-2.45080632e-13j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[28] is not psd
# K_S_cond[28]=[[ 3.33443234e-04-3.90855818e-19j -1.37724053e-02+1.40854672e-02j]
#  [-1.37724053e-02-1.40854672e-02j -3.50838624e+00-3.67835229e-13j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[33] is not psd
# K_S_cond[33]=[[3.66882232e-04-8.35827260e-20j 2.34363274e-02-2.00551261e-03j]
#  [2.34363274e-02+2.00551261e-03j 9.38515866e-01+8.05601900e-14j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[70] is not psd
# K_S_cond[70]=[[ 3.61919711e-04+5.20779537e-19j -1.02808697e-02+1.35026150e-02j]
#  [-1.02808697e-02-1.35026150e-02j -1.58953215e+00+2.97896188e-13j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[ 2.05660875e-04-8.69810856e-20j -2.24949535e-03+8.00102933e-03j]
#  [-2.24949535e-03-8.00102933e-03j -1.12836948e+01-6.28427850e-14j]]
# new_angles=[-1.57079633  0.68179556]
# likelihood is -3814.697917368431 on iteration 0
# new_angles=[-0.95804703  0.68595627]
# likelihood is -3409.43307156287 on iteration 1
# new_angles=[-0.95892308  0.68922427]
# likelihood is -3389.565013326297 on iteration 2
# new_angles=[-1.28321515  0.69178773]
# likelihood is -3378.724338569402 on iteration 3
# new_angles=[-0.47837545  0.69379156]
# likelihood is -3364.2719769558544 on iteration 4
# new_angles=[-0.47646933  0.69535722]
# likelihood is -3358.9716881540826 on iteration 5
# new_angles=[-0.47496985  0.6965824 ]
# likelihood is -3354.7341055160277 on iteration 6
# new_angles=[-0.47346298  0.69753909]
# likelihood is -3350.7094820314624 on iteration 7
# new_angles=[-0.47220104  0.69828552]
# likelihood is -3345.9041649721535 on iteration 8
# new_angles=[-0.4710736   0.69886893]
# likelihood is -3338.823577118036 on iteration 9
# new_angles=[-0.47019801  0.69932526]
# likelihood is -3326.0630128082566 on iteration 10
# new_angles=[-0.46992309  0.69968332]
# likelihood is -3297.3400384784254 on iteration 11
# new_angles=[-0.47123985  0.69996572]
# likelihood is -3211.5706313495075 on iteration 12
# new_angles=[-0.47554048  0.70019046]
# likelihood is -2893.548862733665 on iteration 13
# new_angles=[-0.48082848  0.70037953]
# likelihood is -2320.527280786769 on iteration 14
# new_angles=[-0.48519625  0.70061781]
# likelihood is -2197.1217830381565 on iteration 15
# new_angles=[-0.48859475  0.70083453]
# likelihood is -2174.992567291804 on iteration 16
# new_angles=[-0.49122027  0.70097815]
# likelihood is -2157.671762321452 on iteration 17
# new_angles=[-0.49324608  0.70106326]
# likelihood is -2146.9083200505943 on iteration 18
# new_angles=[-0.49480786  0.70110624]
# likelihood is -2140.472681757948 on iteration 19
# new_angles=[-0.49601209  0.70112075]
# likelihood is -2136.6558991708384 on iteration 20
# new_angles=[-0.49693992  0.70111623]
# likelihood is -2134.4111113269955 on iteration 21
# new_angles=[-0.49765445  0.70109983]
# likelihood is -2133.107623860832 on iteration 22
# new_angles=[-0.49820437  0.70107663]
# likelihood is -2132.3680893797646 on iteration 23
# new_angles=[-0.49862721  0.70104995]
# likelihood is -2131.967029764875 on iteration 24
# new_angles=[-0.49895198  0.70102266]
# likelihood is -2131.769625948732 on iteration 25
# new_angles=[-0.49920121  0.70099525]
# likelihood is -2131.695001496266 on iteration 26
# new_angles=[-0.49939207  0.70096915]
# 5-th start
# theta=[-0.96233415  0.60846218],P=[0.12138312+7.40621264e-18j 0.40746961+2.45723233e-17j]
# Way First
# Initial diagonal of diff is [0.62717497-3.19785360e-17j 1.47079693-2.77555756e-17j
#  0.54362387-2.77555756e-17j 1.20629101-2.77555756e-17j
#  0.62598001-5.55111512e-17j 1.53565265-2.77555756e-17j
#  0.12097131-2.77555756e-17j 0.81929278-3.46944695e-17j
#  0.64913468-2.77555756e-17j 0.46749399-4.16333634e-17j
#  0.78399452-5.55111512e-17j 0.82300745-5.55111512e-17j
#  0.6368065 -5.55111512e-17j 0.19777116-2.77555756e-17j
#  1.11109194-3.14418630e-17j 1.03949772-2.77555756e-17j
#  1.58907967-4.16333634e-17j 0.39806442+0.00000000e+00j
#  0.79173892+0.00000000e+00j 1.64051866-2.77555756e-17j]
# K_S_cond[0] is not psd
# K_S_cond[0]=[[ 2.33588323+4.29125353e-14j -6.24446516+6.92289894e+00j]
#  [-6.24446516-6.92289894e+00j 24.69998185-8.11417157e-14j]]
# K_S_cond[1] is not psd
# K_S_cond[1]=[[11.20099359+1.35929981e-13j  6.65281859-9.71715808e+00j]
#  [ 6.65281859+9.71715808e+00j  3.88605394-7.42713763e-14j]]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[4] is not psd
# K_S_cond[4]=[[ 3.3075536 -3.44206429e-14j -2.53060658+2.89537972e+00j]
#  [-2.53060658-2.89537972e+00j -0.99698835-5.25655154e-13j]]
# K_S_cond[5] is not psd
# K_S_cond[5]=[[ 22.70778181+2.45203782e-13j -68.78062575+2.66299021e+01j]
#  [-68.78062575-2.66299021e+01j 228.02823286-1.26468505e-13j]]
# K_S_cond[6] is not psd
# K_S_cond[6]=[[ 6.23187356-3.87229867e-14j  0.63358559+1.64034986e+00j]
#  [ 0.63358559-1.64034986e+00j -5.88609758-8.31342845e-14j]]
# K_S_cond[7] is not psd
# K_S_cond[7]=[[ 9.92103902-1.66532400e-13j -5.2011387 +3.17690312e+01j]
#  [-5.2011387 -3.17690312e+01j 92.00710046-2.86099206e-13j]]
# K_S_cond[8] is not psd
# K_S_cond[8]=[[13.52994398-1.12015970e-13j -7.92243258+9.53340174e+00j]
#  [-7.92243258-9.53340174e+00j  3.70773682+2.32685551e-13j]]
# K_S_cond[9] is not psd
# K_S_cond[9]=[[12.6242113 -1.10541522e-13j  9.24394112-3.58408662e+01j]
#  [ 9.24394112+3.58408662e+01j 92.25551908-2.46496533e-13j]]
# K_S_cond[10] is not psd
# K_S_cond[10]=[[ 23.87382726-8.02354819e-14j -19.72757856+1.08169551e+01j]
#  [-19.72757856-1.08169551e+01j  15.84240794-2.98575754e-13j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[12] is not psd
# K_S_cond[12]=[[ 9.63231472-1.28418624e-13j  9.48148727-1.20852442e+01j]
#  [ 9.48148727+1.20852442e+01j 14.98450421-3.70247313e-13j]]
# K_S_cond[13] is not psd
# K_S_cond[13]=[[30.00046431+7.71189786e-15j -3.66738364+3.11353118e+01j]
#  [-3.66738364-3.11353118e+01j 27.35873452+1.69557651e-13j]]
# K_S_cond[14] is not psd
# K_S_cond[14]=[[ 91.41482447-3.34932165e-14j -10.40360668+6.13577442e+01j]
#  [-10.40360668-6.13577442e+01j  35.58354502-6.12685530e-14j]]
# K_S_cond[15] is not psd
# K_S_cond[15]=[[20.0742049 -2.08008333e-14j -5.05642029-1.04209120e+00j]
#  [-5.05642029+1.04209120e+00j -5.65073008+1.97342899e-14j]]
# K_S_cond[16] is not psd
# K_S_cond[16]=[[ 0.85703714-1.22544303e-14j -3.02337833+8.22712730e+00j]
#  [-3.02337833-8.22712730e+00j 40.63005275-2.80519168e-13j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[18] is not psd
# K_S_cond[18]=[[ 8.60714595+7.54861760e-15j  7.03558108-1.12909567e+01j]
#  [ 7.03558108+1.12909567e+01j 11.34640737-8.74692788e-14j]]
# K_S_cond[19] is not psd
# K_S_cond[19]=[[ 52.96589828+1.00329746e-14j -79.25480827+1.60303729e+01j]
#  [-79.25480827-1.60303729e+01j 117.36384564-1.01139931e-13j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[22] is not psd
# K_S_cond[22]=[[18.89651446-9.68161100e-14j -9.78863402+1.46126932e+01j]
#  [-9.78863402-1.46126932e+01j 11.26992182+3.22033143e-13j]]
# K_S_cond[23] is not psd
# K_S_cond[23]=[[ 30.13678606-1.12291499e-13j -33.99512343+4.43914951e+00j]
#  [-33.99512343-4.43914951e+00j  29.53154511+3.13606159e-13j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[25] is not psd
# K_S_cond[25]=[[  5.32761775-6.44659303e-14j -10.26866838+5.19882282e+00j]
#  [-10.26866838-5.19882282e+00j  17.89033001+7.95474951e-14j]]
# K_S_cond[26] is not psd
# K_S_cond[26]=[[  4.61877976-1.62620994e-14j -15.33135305+6.12086462e-01j]
#  [-15.33135305-6.12086462e-01j  28.91674767-1.57829207e-13j]]
# K_S_cond[27] is not psd
# K_S_cond[27]=[[112.28874856-6.82360388e-15j  41.14084552+9.65132036e-01j]
#  [ 41.14084552-9.65132036e-01j   8.57611427+2.09115864e-13j]]
# K_S_cond[28] is not psd
# K_S_cond[28]=[[26.82290711-1.41384569e-13j -3.30447031+3.55025687e+01j]
#  [-3.30447031-3.55025687e+01j 41.27179148-2.57383671e-13j]]
# K_S_cond[29] is not psd
# K_S_cond[29]=[[111.01258053+8.25832964e-16j  52.60243998-5.52713412e+01j]
#  [ 52.60243998+5.52713412e+01j  44.96476532-8.00091107e-14j]]
# K_S_cond[30] is not psd
# K_S_cond[30]=[[18.89779116-1.45030257e-13j 37.84734692+8.02614568e+00j]
#  [37.84734692-8.02614568e+00j 68.35058197-3.06996695e-13j]]
# K_S_cond[31] is not psd
# K_S_cond[31]=[[  7.60373482+1.25425034e-13j -10.57160146-1.70811465e+01j]
#  [-10.57160146+1.70811465e+01j  40.92917365+1.57067840e-14j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[33] is not psd
# K_S_cond[33]=[[ 23.08721629-2.74997922e-14j -10.66714924+1.03761641e+01j]
#  [-10.66714924-1.03761641e+01j   4.56515862+1.26248366e-13j]]
# K_S_cond[34] is not psd
# K_S_cond[34]=[[-0.79261634+4.42918887e-14j  3.2862377 -4.16041614e+00j]
#  [ 3.2862377 +4.16041614e+00j 95.39188548-2.09935096e-13j]]
# K_S_cond[35] is not psd
# K_S_cond[35]=[[0.56390311-1.03030951e-13j 1.07609379+2.72413661e+00j]
#  [1.07609379-2.72413661e+00j 0.92051982-2.86853576e-13j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[37] is not psd
# K_S_cond[37]=[[143.29030167-1.44661613e-14j  99.32363532+3.14282827e+01j]
#  [ 99.32363532-3.14282827e+01j  69.11435739+1.31912948e-13j]]
# K_S_cond[38] is not psd
# K_S_cond[38]=[[61.44833699-6.74671040e-14j 50.00466668-6.23756715e+01j]
#  [50.00466668+6.23756715e+01j 94.37226421-5.97372240e-14j]]
# K_S_cond[39] is not psd
# K_S_cond[39]=[[  4.53698197-1.58445378e-14j -15.1742687 +6.29064975e+00j]
#  [-15.1742687 -6.29064975e+00j  47.21796192+2.53862655e-13j]]
# K_S_cond[40] is not psd
# K_S_cond[40]=[[ 15.09729981-9.26802967e-14j -12.97656808+2.85487052e+01j]
#  [-12.97656808-2.85487052e+01j  57.63597612-2.92341394e-13j]]
# K_S_cond[41] is not psd
# K_S_cond[41]=[[ 18.25504363+6.25667320e-14j -13.05316445-3.93510604e+01j]
#  [-13.05316445+3.93510604e+01j  77.10963255+1.90963080e-13j]]
# K_S_cond[42] is not psd
# K_S_cond[42]=[[13.0555999 -5.29594771e-14j -6.58266079-2.55123681e+01j]
#  [-6.58266079+2.55123681e+01j 42.8145956 +9.42678746e-14j]]
# K_S_cond[43] is not psd
# K_S_cond[43]=[[131.7870081 +1.03292755e-14j  16.92164555+1.35116286e+01j]
#  [ 16.92164555-1.35116286e+01j  -2.89353404-1.09761892e-13j]]
# K_S_cond[44] is not psd
# K_S_cond[44]=[[10.13754299+5.84900414e-14j  1.72495383+3.34606055e+01j]
#  [ 1.72495383-3.34606055e+01j 98.47993079-5.48429586e-14j]]
# K_S_cond[45] is not psd
# K_S_cond[45]=[[ 0.7118998 +2.05015892e-13j  7.08294642+2.62514524e+00j]
#  [ 7.08294642-2.62514524e+00j 26.7983913 -1.43888604e-13j]]
# K_S_cond[46] is not psd
# K_S_cond[46]=[[ 57.46786657+6.38101034e-14j 100.56021074+9.27483485e+01j]
#  [100.56021074-9.27483485e+01j 313.23066722+1.64378848e-13j]]
# K_S_cond[47] is not psd
# K_S_cond[47]=[[54.99856058-1.31681227e-13j -8.5463983 +5.07788997e+01j]
#  [-8.5463983 -5.07788997e+01j 42.66505295-3.45181581e-13j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[49] is not psd
# K_S_cond[49]=[[ 2.19965146-6.68676401e-14j  4.25953743-7.40010194e+00j]
#  [ 4.25953743+7.40010194e+00j 14.27515553-3.21899399e-13j]]
# K_S_cond[50] is not psd
# K_S_cond[50]=[[16.55088057-4.91382089e-14j 24.19257034+3.43836588e+01j]
#  [24.19257034-3.43836588e+01j 95.50369533-4.82286380e-13j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[53] is not psd
# K_S_cond[53]=[[ 1.00538348-1.83969051e-14j -3.98500195-5.58051192e+00j]
#  [-3.98500195+5.58051192e+00j 17.39498873-3.82643197e-13j]]
# K_S_cond[54] is not psd
# K_S_cond[54]=[[17.06941564+1.52162953e-14j  0.42312511-1.11477613e+01j]
#  [ 0.42312511+1.11477613e+01j  0.87077835+1.26500000e-13j]]
# K_S_cond[55] is not psd
# K_S_cond[55]=[[-0.13793523+7.76810053e-14j -4.57130536-1.37969683e+00j]
#  [-4.57130536+1.37969683e+00j 26.17664629+1.21556790e-14j]]
# K_S_cond[56] is not psd
# K_S_cond[56]=[[ 9.16601700e-02-1.10584550e-15j -1.21241906e+01-1.41904786e+00j]
#  [-1.21241906e+01+1.41904786e+00j  1.45925388e+02+2.33137296e-14j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[61] is not psd
# K_S_cond[61]=[[-0.66903067+1.61917680e-14j  1.43173963+2.87004401e+00j]
#  [ 1.43173963-2.87004401e+00j 36.89812135-5.07194078e-14j]]
# K_S_cond[62] is not psd
# K_S_cond[62]=[[ 0.64627371+7.47244140e-14j  3.81329588+1.10785074e+01j]
#  [ 3.81329588-1.10785074e+01j 84.91720307+6.68798919e-14j]]
# K_S_cond[63] is not psd
# K_S_cond[63]=[[185.79047908-7.64032753e-14j  49.08930853+1.34217861e+02j]
#  [ 49.08930853-1.34217861e+02j 103.33474063+9.17900536e-14j]]
# K_S_cond[64] is not psd
# K_S_cond[64]=[[ 11.86061111+4.61294486e-14j -22.87735605+3.60723262e+01j]
#  [-22.87735605-3.60723262e+01j 139.98344004-1.55386197e-13j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[66] is not psd
# K_S_cond[66]=[[21.76336269-1.10634005e-13j -8.06441787+3.95339073e+00j]
#  [-8.06441787-3.95339073e+00j -1.53885788-4.78782559e-13j]]
# K_S_cond[67] is not psd
# K_S_cond[67]=[[ 17.26746789-1.13554901e-13j -11.17842626-2.98100639e+01j]
#  [-11.17842626+2.98100639e+01j  49.14116193-5.04136333e-13j]]
# K_S_cond[68] is not psd
# K_S_cond[68]=[[ 32.24479712-8.45673646e-14j -23.42638842+2.23458203e+01j]
#  [-23.42638842-2.23458203e+01j  27.12957277-3.00791020e-13j]]
# K_S_cond[69] is not psd
# K_S_cond[69]=[[47.26593594+3.10848697e-14j  0.30152239-1.96335323e+01j]
#  [ 0.30152239+1.96335323e+01j  0.84156659-1.49124477e-13j]]
# K_S_cond[70] is not psd
# K_S_cond[70]=[[ 35.22719237+4.64470574e-14j -10.09175308+5.86813942e+01j]
#  [-10.09175308-5.86813942e+01j  94.30944006-2.12798655e-13j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[72] is not psd
# K_S_cond[72]=[[ 42.52175663+3.72877496e-14j  26.04129106+6.55666540e+01j]
#  [ 26.04129106-6.55666540e+01j 108.19456366+1.36208014e-13j]]
# K_S_cond[73] is not psd
# K_S_cond[73]=[[ 9.73850344+1.75401620e-14j 29.91141687+7.80534772e+00j]
#  [29.91141687-7.80534772e+00j 82.20041741-2.78933216e-13j]]
# K_S_cond[74] is not psd
# K_S_cond[74]=[[ 57.0737378 +1.34871136e-13j 103.72629218+8.97470954e+00j]
#  [103.72629218-8.97470954e+00j 179.79337448-2.60920939e-13j]]
# K_S_cond[75] is not psd
# K_S_cond[75]=[[117.80064266-1.69070157e-13j  98.74019639+2.06633494e+01j]
#  [ 98.74019639-2.06633494e+01j  79.51837444+5.23135909e-13j]]
# K_S_cond[76] is not psd
# K_S_cond[76]=[[64.54668036-1.90132389e-14j 15.21699494+3.77027664e+01j]
#  [15.21699494-3.77027664e+01j 19.16130853-3.20549859e-13j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[ -2.36778294-1.16804127e-14j  -2.06233714-7.12176390e-01j]
#  [ -2.06233714+7.12176390e-01j -10.1893176 -4.18817849e-14j]]
# K_S_cond[79] is not psd
# K_S_cond[79]=[[ 3.98812552-1.08110939e-13j -0.68678692+1.26313790e+01j]
#  [-0.68678692-1.26313790e+01j 28.66905392-1.64094104e-13j]]
# new_angles=[0.09555586 0.14485712]
# likelihood is -5178.899506212337 on iteration 0
# new_angles=[ 0.19605943 -0.5094253 ]
# likelihood is -3311.350927127052 on iteration 1
# new_angles=[-0.5078435   0.19521245]
# likelihood is -3144.422065355682 on iteration 2
# new_angles=[-0.50649166  0.19787403]
# likelihood is -3124.8063574138673 on iteration 3
# new_angles=[-0.5053641  0.2001876]
# likelihood is -3116.555660740644 on iteration 4
# new_angles=[-0.50445509  0.20208099]
# likelihood is -3112.142991025152 on iteration 5
# new_angles=[-0.50373427  0.20375431]
# likelihood is -3109.7625001764736 on iteration 6
# new_angles=[-0.50316763  0.20528327]
# likelihood is -3108.565552529211 on iteration 7
# new_angles=[-0.50272417  0.20671054]
# likelihood is -3108.1142457335504 on iteration 8
# new_angles=[-0.50237884  0.20804903]
# likelihood is -3108.159943457951 on iteration 9
# new_angles=[-0.50211057  0.20934684]
# likelihood is -3108.5540408497295 on iteration 10
# new_angles=[-0.50190279  0.21059131]
# likelihood is -3109.196788479996 on iteration 11
# new_angles=[-0.50174246  0.21181621]
# likelihood is -3110.0245048314455 on iteration 12
# new_angles=[-0.50161929  0.21302814]
# likelihood is -3110.9895742712797 on iteration 13
# new_angles=[-0.50152528  0.21423127]
# likelihood is -3112.055998386174 on iteration 14
# new_angles=[-0.50145397  0.21544054]
# likelihood is -3113.1967292182167 on iteration 15
# new_angles=[-0.50140011  0.21662112]
# likelihood is -3114.3856502727576 on iteration 16
# new_angles=[-0.50136032  0.21781616]
# likelihood is -3115.6095828634648 on iteration 17
# new_angles=[-0.50133099  0.21898101]
# likelihood is -3116.8499414264475 on iteration 18
# new_angles=[-0.50131008  0.22014157]
# likelihood is -3118.09913739698 on iteration 19
# new_angles=[-0.50129589  0.22130572]
# likelihood is -3119.3501456736794 on iteration 20
# new_angles=[-0.50128645  0.22244031]
# likelihood is -3120.5942543333235 on iteration 21
# new_angles=[-0.50128088  0.22356497]
# likelihood is -3121.830086540357 on iteration 22
# new_angles=[-0.50127827  0.2246762 ]
# likelihood is -3123.0552116896997 on iteration 23
# new_angles=[-0.50127792  0.2257735 ]
# likelihood is -3124.2684073764126 on iteration 24
# new_angles=[-0.50127924  0.22685506]
# likelihood is -3125.469028475596 on iteration 25
# new_angles=[-0.50128183  0.22792124]
# likelihood is -3126.6570364406184 on iteration 26
# new_angles=[-0.50128526  0.22896912]
# likelihood is -3127.832384216656 on iteration 27
# new_angles=[-0.50128897  0.23000816]
# likelihood is -3128.995866395398 on iteration 28
# new_angles=[-0.5012937   0.23102624]
# likelihood is -3130.1471823171087 on iteration 29
# 6-th start
# theta=[-1.46911153  0.10168479],P=[0.00887474+3.24345568e-19j 0.00022361+0.00000000e+00j]
# Way First
# Initial diagonal of diff is [1.14692935-3.24345568e-19j 1.99055131-3.25260652e-19j
#  1.06337825-3.79470760e-19j 1.72604539-3.25260652e-19j
#  1.1457344 -3.25260652e-19j 2.05540703-3.25260652e-19j
#  0.64072569-3.25260652e-19j 1.33904716-2.16840434e-19j
#  1.16888907-2.16840434e-19j 0.98724837-2.16840434e-19j
#  1.3037489 -4.33680869e-19j 1.34276184-2.16840434e-19j
#  1.15656088-4.33680869e-19j 0.71752554-4.33680869e-19j
#  1.63084632+0.00000000e+00j 1.5592521 -4.33680869e-19j
#  2.10883406-4.33680869e-19j 0.9178188 -8.67361738e-19j
#  1.3114933 -4.33680869e-19j 2.16027304-4.33680869e-19j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[-0.00541438-1.06407457e-16j  0.00014057-1.90999441e-04j]
#  [ 0.00014057+1.90999441e-04j  0.00020881-5.28862360e-20j]]
# new_angles=[0.66620575 0.72905933]
# likelihood is -3689.4000865455273 on iteration 0
# new_angles=[0.67420073 0.65367388]
# likelihood is -3496.4111992272205 on iteration 1
# new_angles=[0.53748815 0.67995085]
# likelihood is -3441.9855460813064 on iteration 2
# new_angles=[0.54251745 0.6844071 ]
# likelihood is -3412.9819774232533 on iteration 3
# new_angles=[0.54369425 0.6879133 ]
# likelihood is -3393.4848308448213 on iteration 4
# new_angles=[0.54328266 0.69066846]
# likelihood is -3381.269781052739 on iteration 5
# new_angles=[0.54207133 0.69283379]
# likelihood is -3373.725670909864 on iteration 6
# new_angles=[0.5404822 0.6945394]
# likelihood is -3369.0723167341453 on iteration 7
# new_angles=[0.5389029  0.69588271]
# likelihood is -3366.204305579762 on iteration 8
# new_angles=[0.5375436  0.69693985]
# likelihood is -3364.4410579356686 on iteration 9
# new_angles=[0.53641754 0.69777124]
# likelihood is -3363.3644971923795 on iteration 10
# new_angles=[0.53553726 0.6984252 ]
# ...
# K_S_cond[77] is not psd
# K_S_cond[77]=[[ 2.06132413e-04-7.87828634e-20j -8.46834680e-04+4.07240872e-03j]
#  [-8.46834680e-04-4.07240872e-03j -2.86616358e+00-2.14410728e-14j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[ 2.06132413e-04-7.87828634e-20j -8.46834680e-04+4.07240872e-03j]
#  [-8.46834680e-04-4.07240872e-03j -2.86616358e+00-2.14410728e-14j]]
# new_angles=[-1.57079633  0.655254  ]
# likelihood is -4005.441486215951 on iteration 0
# new_angles=[-0.97755356  0.66485151]
# likelihood is -3606.2100967496544 on iteration 1
# new_angles=[-0.97079665  0.67255323]
# likelihood is -3516.834772699698 on iteration 2
# new_angles=[-0.48861488  0.67867629]
# likelihood is -3451.228639318519 on iteration 3
# new_angles=[-0.48162323  0.68350275]
# likelihood is -3413.358183441242 on iteration 4
# new_angles=[-0.47664256  0.68729843]
# likelihood is -3388.730598493609 on iteration 5
# new_angles=[-0.47322689  0.69027675]
# likelihood is -3372.1712667416464 on iteration 6
# new_angles=[-0.47078184  0.6926096 ]
# likelihood is -3359.9769534029524 on iteration 7
# new_angles=[-0.46893436  0.69443526]
# likelihood is -3349.1040117853263 on iteration 8
# new_angles=[-0.46757376  0.69586428]
# likelihood is -3335.8985370495657 on iteration 9
# new_angles=[-0.46701677  0.69698124]
# likelihood is -3312.5821130609897 on iteration 10
# new_angles=[-0.46791288  0.6978563 ]
# likelihood is -3252.871421611321 on iteration 11
# new_angles=[-0.47183301  0.69854355]
# likelihood is -3040.5513318834287 on iteration 12
# new_angles=[-0.47766528  0.69908835]
# likelihood is -2478.9162710650007 on iteration 13
# new_angles=[-0.48272873  0.69957871]
# likelihood is -2221.105326313304 on iteration 14
# new_angles=[-0.48669216  0.70003342]
# likelihood is -2190.027230979709 on iteration 15
# new_angles=[-0.48975652  0.70037017]
# likelihood is -2167.1646290095687 on iteration 16
# new_angles=[-0.49212106  0.70060519]
# likelihood is -2152.5630697250663 on iteration 17
# new_angles=[-0.49394416  0.70076303]
# likelihood is -2143.794265024249 on iteration 18
# new_angles=[-0.49534935  0.70086456]
# likelihood is -2138.5859489425998 on iteration 19
# new_angles=[-0.49643125  0.70092567]
# likelihood is -2135.515588553032 on iteration 20
# new_angles=[-0.49726439  0.70095876]
# likelihood is -2133.7212853041706 on iteration 21
# new_angles=[-0.49790596  0.70097302]
# likelihood is -2132.68933429099 on iteration 22
# new_angles=[-0.49839934  0.70097449]
# likelihood is -2132.1142795357805 on iteration 23
# new_angles=[-0.49877835  0.70096776]
# likelihood is -2131.8131240957255 on iteration 24
# new_angles=[-0.49906929  0.70095609]
# likelihood is -2131.676463030225 on iteration 25
# new_angles=[-0.49929221  0.70094169]
# likelihood is -2131.6391493330707 on iteration 26
# new_angles=[-0.49946264  0.70092603]
# likelihood is -2131.662115468507 on iteration 27
# new_angles=[-0.49959259  0.7009101 ]
# likelihood is -2131.721892441541 on iteration 28
# new_angles=[-0.49969128  0.70089446]
# likelihood is -2131.804346062193 on iteration 29
# 8-th start
# theta=[-1.31513736  0.25565896],P=[0.01517842-5.70546213e-18j 0.00022361+0.00000000e+00j]
# Way First
# Initial diagonal of diff is [1.14062567+5.70546213e-18j 1.98424763+5.63785130e-18j
#  1.05707457+5.63785130e-18j 1.71974171+5.20417043e-18j
#  1.13943072+6.07153217e-18j 2.04910336+6.07153217e-18j
#  0.63442201+6.07153217e-18j 1.33274348+5.20417043e-18j
#  1.16258539+4.33680869e-18j 0.9809447 +6.07153217e-18j
#  1.29744522+6.93889390e-18j 1.33645816+5.20417043e-18j
#  1.1502572 +5.20417043e-18j 0.71122187+5.63785130e-18j
#  1.62454264+5.63785130e-18j 1.55294842+5.74627151e-18j
#  2.10253038+5.63785130e-18j 0.91151512+6.07153217e-18j
#  1.30518962+5.20417043e-18j 2.15396936+6.07153217e-18j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[-0.02791426-2.90226054e-16j  0.00024323-2.88535688e-04j]
#  [ 0.00024323+2.88535688e-04j  0.00021124-1.71442955e-20j]]
# new_angles=[-0.21261489 -0.51450834]
# likelihood is -4385.604468549978 on iteration 0
# new_angles=[-0.36860278 -0.46818408]
# likelihood is -3552.3987578445685 on iteration 1
# new_angles=[-0.47535986 -0.38033057]
# likelihood is -3271.809460545794 on iteration 2
# new_angles=[-0.48092648 -0.40350797]
# likelihood is -3200.7810610342226 on iteration 3
# new_angles=[-0.48523976 -0.41133178]
# likelihood is -3156.5149006813645 on iteration 4
# new_angles=[-0.4885491  -0.41575604]
# likelihood is -3128.893711446471 on iteration 5
# new_angles=[-0.4910896  -0.41890606]
# likelihood is -3112.384505242059 on iteration 6
# new_angles=[-0.49303938 -0.42124748]
# likelihood is -3102.6456222371867 on iteration 7
# new_angles=[-0.49453539 -0.42302024]
# likelihood is -3096.942862975245 on iteration 8
# new_angles=[-0.49568333 -0.42439355]
# likelihood is -3093.6263339778443 on iteration 9
# new_angles=[-0.49656473 -0.42551312]
# likelihood is -3091.7147931985705 on iteration 10
# new_angles=[-0.49724211 -0.42647117]
# likelihood is -3090.628536390325 on iteration 11
# new_angles=[-0.4977643  -0.42736598]
# likelihood is -3090.0260679781886 on iteration 12
# new_angles=[-0.49816727 -0.42819428]
# likelihood is -3089.707690982472 on iteration 13
# new_angles=[-0.49848043 -0.42907213]
# likelihood is -3089.5564653044544 on iteration 14
# new_angles=[-0.49872352 -0.42990908]
# likelihood is -3089.503840541194 on iteration 15
# new_angles=[-0.49891365 -0.4307538 ]
# likelihood is -3089.508594771707 on iteration 16
# new_angles=[-0.49906255 -0.43155802]
# likelihood is -3089.5467391491234 on iteration 17
# new_angles=[-0.4991799  -0.43232944]
# likelihood is -3089.6038610570167 on iteration 18
# new_angles=[-0.49927382 -0.43309072]
# likelihood is -3089.672297126035 on iteration 19
# new_angles=[-0.49934859 -0.43379183]
# likelihood is -3089.746582561496 on iteration 20
# new_angles=[-0.49940864 -0.43444473]
# likelihood is -3089.823705004079 on iteration 21
# new_angles=[-0.49945687 -0.43504372]
# likelihood is -3089.902017969945 on iteration 22
# new_angles=[-0.49949635 -0.43558328]
# likelihood is -3089.9804080618683 on iteration 23
# new_angles=[-0.49952866 -0.43607194]
# likelihood is -3090.0585850670263 on iteration 24
# new_angles=[-0.49955517 -0.43650751]
# likelihood is -3090.136280490981 on iteration 25
# new_angles=[-0.49957696 -0.43689185]
# likelihood is -3090.2134219763752 on iteration 26
# new_angles=[-0.4995949  -0.43722736]
# likelihood is -3090.2900566905896 on iteration 27
# new_angles=[-0.49960963 -0.43751662]
# likelihood is -3090.3662912912155 on iteration 28
# new_angles=[-0.49962167 -0.43776222]
# likelihood is -3090.4422645856616 on iteration 29
# 9-th start
# theta=[-0.20985359  1.36094274],P=[0.00022361+0.00000000e+00j 0.00828219+2.20150278e-17j]
# Way First
# Initial diagonal of diff is [1.1475219 -2.20150278e-17j 1.99114386-2.20093041e-17j
#  1.0639708 -2.23345648e-17j 1.72663793-2.21177243e-17j
#  1.14632694-2.25514052e-17j 2.05599958-2.21177243e-17j
#  0.64131823-2.16840434e-17j 1.33963971-2.16840434e-17j
#  1.16948161-2.21177243e-17j 0.98784092-2.21177243e-17j
#  1.30434145-2.25514052e-17j 1.34335438-2.16840434e-17j
#  1.15715343-2.25514052e-17j 0.71811809-2.25514052e-17j
#  1.63143887-2.16840434e-17j 1.55984464-2.16840434e-17j
#  2.1094266 -2.21177243e-17j 0.91841134-2.16840434e-17j
#  1.31208584-2.21177243e-17j 2.16086558-2.21177243e-17j]
# K_S_cond[2] is not psd
# K_S_cond[2]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[3] is not psd
# K_S_cond[3]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[11] is not psd
# K_S_cond[11]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[17] is not psd
# K_S_cond[17]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[20] is not psd
# K_S_cond[20]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[21] is not psd
# K_S_cond[21]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[24] is not psd
# K_S_cond[24]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[32] is not psd
# K_S_cond[32]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[36] is not psd
# K_S_cond[36]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[48] is not psd
# K_S_cond[48]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[51] is not psd
# K_S_cond[51]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[52] is not psd
# K_S_cond[52]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[57] is not psd
# K_S_cond[57]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[58] is not psd
# K_S_cond[58]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[59] is not psd
# K_S_cond[59]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[60] is not psd
# K_S_cond[60]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[65] is not psd
# K_S_cond[65]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[71] is not psd
# K_S_cond[71]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[77] is not psd
# K_S_cond[77]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# K_S_cond[78] is not psd
# K_S_cond[78]=[[ 2.07919251e-04-9.40662545e-20j  6.43840951e-06-1.90678769e-04j]
#  [ 6.43840951e-06+1.90678769e-04j -1.74948380e-03-5.08985479e-17j]]
# new_angles=[0.24416862 0.65630635]
# likelihood is -3797.8590756379986 on iteration 0
# new_angles=[0.55823706 0.665248  ]
# likelihood is -3571.5213769662923 on iteration 1
# new_angles=[0.69852126 0.67305215]
# likelihood is -3499.44393098549 on iteration 2
# new_angles=[0.67876844 0.7043409 ]
# likelihood is -3448.030584431476 on iteration 3
# new_angles=[0.68329806 0.70860038]
# likelihood is -3415.344227262028 on iteration 4
# new_angles=[0.68686965 0.71179578]
# likelihood is -3394.7900335236236 on iteration 5
# new_angles=[0.68968232 0.71414944]
# likelihood is -3381.9868105589003 on iteration 6
# new_angles=[0.69189626 0.71585578]
# likelihood is -3374.0597855571855 on iteration 7
# new_angles=[0.69363425 0.7170663 ]
# likelihood is -3369.184063702171 on iteration 8
# new_angles=[0.69500138 0.71786819]
# likelihood is -3366.1913280568588 on iteration 9
# new_angles=[0.69607526 0.71842585]
# likelihood is -3364.360131415815 on iteration 10
# new_angles=[0.69692208 0.71873599]
# likelihood is -3363.2456031359843 on iteration 11
# new_angles=[0.69759056 0.71886958]
# likelihood is -3362.574346914806 on iteration 12
# new_angles=[0.69811927 0.71886177]
# likelihood is -3362.1778462288253 on iteration 13
# new_angles=[0.69853912 0.71872125]
# likelihood is -3361.9521106928783 on iteration 14
# new_angles=[0.69887652 0.71844244]
# likelihood is -3361.8320500482423 on iteration 15
# new_angles=[0.69915078 0.71803063]
# likelihood is -3361.778754796559 on iteration 16
# new_angles=[0.69938261 0.71739304]
# likelihood is -3361.7663595174913 on iteration 17
# new_angles=[0.69958634 0.71647092]
# likelihood is -3361.7819653818638 on iteration 18
# new_angles=[0.69976771 0.71533766]
# likelihood is -3361.8205937259963 on iteration 19
# new_angles=[0.69993877 0.71388423]
# likelihood is -3361.8752736239067 on iteration 20
# new_angles=[0.70010857 0.71204562]
# likelihood is -3361.947624102372 on iteration 21
# new_angles=[0.7002746  0.70992248]
# likelihood is -3362.0450195272856 on iteration 22
# new_angles=[0.70043397 0.70759635]
# likelihood is -3362.1700580338916 on iteration 23
# new_angles=[0.7005842  0.70515849]
# likelihood is -3362.324549607238 on iteration 24
# new_angles=[0.7007232  0.70265574]
# likelihood is -3362.5078295265653 on iteration 25
# new_angles=[0.7008485 0.7001426]
# likelihood is -3362.7194372975196 on iteration 26
# new_angles=[0.69767845 0.70095751]
# likelihood is -3362.956557572919 on iteration 27
# new_angles=[0.69523578 0.70105152]
# likelihood is -3363.2139504141223 on iteration 28
# new_angles=[-0.40955996  0.69957261]
# likelihood is -3359.3060094927378 on iteration 29
# best_start=4

# %%
print(f"EM_theta2_rad={EM_theta2_rad},\nEM_P2={EM_P2}")
# Out:
# EM_theta2_rad=[-0.50075146  0.70181351],
# EM_P2=[[ 2.10165534+1.77163355e-15j -0.02734127-2.58058318e-01j]
#  [-0.02734127+2.58058318e-01j  1.6702062 +7.11319458e-16j]]

# %%
EM_theta2_deg = np.rad2deg(EM_theta2_rad)
print(f"Погрешность в смысле разности углов в градусах: \
      {np.abs(np.sort(EM_theta2_deg)-np.sort(theta2_deg))},")
print(f"Погрешность в смысле разности синусов углов: \
      {np.abs(np.sin(EM_theta2_rad)-np.sin(theta2_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах:       [0.04305568 0.10390658],
# Погрешность в смысле разности синусов углов:       [0.00065934 0.00138599].

# %%
em_stoch.incomplete_lkhd(X1_with_mv, theta1_rad, P_1, Q_1)
# Out:
# np.float64(-2824.8936593288777)

# %%
em_stoch.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q_1)
# Out:
# np.float64(-2835.8614786712046)

# %%
em_stoch.incomplete_lkhd(X2_with_mv, theta2_rad, P_2, Q_2)
# Out:
# np.float64(-2106.4163518053156)

# %%
em_stoch.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q_2)
# Out:
# np.float64(-2130.4960978858803)
