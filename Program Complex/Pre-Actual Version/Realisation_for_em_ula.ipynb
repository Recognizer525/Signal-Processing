# %%
import numpy as np

import sensors
import em_stoch

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 20
Num_emitters1 = 1
sample_size1 = 80
failing_sensors1 = np.array([2, 4], dtype=np.int16)
gap_ratio1 = np.array([0.5, 0.5], dtype=np.float32)
theta1_rad = np.array([0.7]) # Угловые координаты источников (DoA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Угловые координаты источников (DoA) в градусах
P_1 = 1 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация сигналов
Q_1 = 2.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шумов
A1 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * 
             np.sin(theta1_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
N1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + N1.T).T

Num_sensors2 = 20
Num_emitters2 = 2
sample_size2 = 80
failing_sensors2 = np.array([2, 4], dtype=np.int16)
gap_ratio2 = np.array([0.5, 0.5], dtype=np.float32)
theta2_rad = np.array([-0.5, 0.7], dtype=np.float64) # Угловые координаты источников (DoA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Угловые координаты источников (DoA) в градусах
P_2 = 1 * np.eye(Num_emitters2, dtype=np.float64) # Ковариация сигналов
Q_2 = 1.1 * np.eye(Num_sensors2, dtype=np.float64) # Ковариация шумов
A2 = (np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors2).reshape(-1,1) * 
             np.sin(theta2_rad))) # Матрица векторов направленности
# Генерация сигналов, шумов и наблюдений
S2 = sensors.gss(Num_emitters2, sample_size2, P_2)
N2 = sensors.gss(Num_sensors2, sample_size2, Q_2)
X2 = (A2 @ S2.T + N2.T).T

# %%
X1_with_mv = sensors.MCAR(X1, failing_sensors1, gap_ratio1)
X2_with_mv = sensors.MCAR(X2, failing_sensors2, gap_ratio2)
# Out:
# share_mv=[0.5 0.5]
# mis_cols=[2 4]
# share_mv=[0.5 0.5]
# mis_cols=[2 4]

# %%
X1_with_mv
# Out:
# array([[ 1.47375889-1.19127215j,  0.03175204-1.88842948j,
#                 nan+0.j        , ..., -0.76397286-2.94873339j,
#          0.72662444+0.27358696j,  1.62576741-0.61924096j],
#        [-0.75093165-1.09293498j, -0.99980865-0.34039036j,
#          2.94445197-1.56076135j, ...,  0.33293359+0.82505105j,
#          0.07846728+0.13232699j, -1.07843768+0.39630101j],
#        [ 0.76613778+1.51307616j,  0.98300291+0.8604167j ,
#         -2.77695094-1.28910182j, ..., -0.60766186+0.05449384j,
#         -1.0589133 -1.09211055j, -0.1291021 +1.6502334j ],
#        ...,
#        [ 1.16245983+2.06921586j,  2.97479457-1.66960229j,
#         -2.74510029-0.87284081j, ...,  1.19492776-0.80840476j,
#         -2.23063739-0.51135893j,  0.20866592+3.56230975j],
#        [ 1.57700122+0.90672591j, -2.1236758 -2.06001117j,
#         -1.06651492+2.87218098j, ..., -1.12889979-0.66445606j,
#         -0.37962652-0.26983634j,  1.95978744-1.35519038j],
#        [-0.56114001+1.07715026j, -0.59027711+0.12132465j,
#                 nan+0.j        , ...,  1.47473186+0.5409653j ,
#         -1.79549689-0.86866438j, -0.2348961 -0.34663937j]], shape=(80, 20))

# %%
print(np.trace(sensors.initial_Cov(X1_with_mv)))
print(np.trace(sensors.complex_cov(X1)))
# Out:
# (73.88343486532314+0j)
# (63.702954966635296+0j)

# %%
EM_theta1_rad, EM_P1, lhd_1 = em_stoch.multi_start_EM(X1_with_mv, 
                                                      Num_emitters1, 
                                                      Q=Q_1, 
                                                      num_of_starts=10, 
                                                      max_iter=30, 
                                                      rtol=1e-6)
# Out:
# 0-th start
# theta=[0.15335215],P=[[0.00022361+0.j]]
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379+0.00000000e+00j
#  1.98180846-1.35525272e-20j 1.24264901-3.38813179e-21j
#  3.65111824+0.00000000e+00j 1.6804558 +0.00000000e+00j
#  0.96155409-6.77626358e-21j 1.27025671+0.00000000e+00j
#  1.65889204+0.00000000e+00j 1.36190987+0.00000000e+00j
#  1.09550401+0.00000000e+00j 0.89691465+0.00000000e+00j
#  1.6196736 +1.35525272e-20j 0.79194526-1.69406589e-21j
#  1.14151686+0.00000000e+00j 2.29130715+1.35525272e-20j
#  1.17223031+0.00000000e+00j 1.31477482+0.00000000e+00j
#  1.22932654+0.00000000e+00j 1.67873947+0.00000000e+00j]
# new_angles=[0.15335215]
# likelihood is -3420.8363426126166 on iteration 0
# new_angles=[0.15335215]
# 1-th start
# theta=[0.13636065],P=[[0.0023446-2.48253415e-17j]]
# Initial diagonal of diff is [1.83120106+2.48253415e-17j 3.0029428 +2.48282297e-17j
#  1.97968746+2.47198095e-17j 1.24052801+2.47198095e-17j
#  3.64899724+2.48824399e-17j 1.67833481+2.51534904e-17j
#  0.95943309+2.47198095e-17j 1.26813572+2.48824399e-17j
#  1.65677104+2.49366500e-17j 1.35978887+2.47198095e-17j
#  1.09338301+2.47198095e-17j 0.89479365+2.48214535e-17j
#  1.61755261+2.48282297e-17j 0.78982427+2.47198095e-17j
#  1.13939587+2.47198095e-17j 2.28918616+2.48282297e-17j
#  1.17010932+2.47198095e-17j 1.31265383+2.49366500e-17j
#  1.22720554+2.48282297e-17j 1.67661847+2.47198095e-17j]
# new_angles=[0.13252571]
# likelihood is -3420.6798364814144 on iteration 0
# new_angles=[0.13170927]
# likelihood is -3420.813278343723 on iteration 1
# new_angles=[0.13093831]
# likelihood is -3421.0191430427512 on iteration 2
# new_angles=[0.1302107]
# likelihood is -3421.3294140903754 on iteration 3
# new_angles=[0.12952557]
# likelihood is -3421.7879074463485 on iteration 4
# new_angles=[0.12888052]
# likelihood is -3422.450686667547 on iteration 5
# new_angles=[0.12827357]
# likelihood is -3423.381989337976 on iteration 6
# new_angles=[0.12770278]
# likelihood is -3424.641665808324 on iteration 7
# new_angles=[0.12716617]
# likelihood is -3426.2626763280327 on iteration 8
# new_angles=[0.12666193]
# likelihood is -3428.2247287377054 on iteration 9
# new_angles=[0.12618832]
# likelihood is -3430.44000898768 on iteration 10
# new_angles=[0.12574376]
# likelihood is -3432.7673804791207 on iteration 11
# new_angles=[0.12532683]
# likelihood is -3435.0536921479056 on iteration 12
# new_angles=[0.1249362]
# likelihood is -3437.1789045812952 on iteration 13
# new_angles=[0.12457055]
# likelihood is -3439.079947136572 on iteration 14
# new_angles=[0.12422834]
# likelihood is -3440.747368734014 on iteration 15
# new_angles=[0.12390857]
# likelihood is -3442.20653298659 on iteration 16
# new_angles=[0.12360961]
# likelihood is -3443.4974893617446 on iteration 17
# new_angles=[0.12333064]
# likelihood is -3444.6611937141965 on iteration 18
# new_angles=[0.12307015]
# likelihood is -3445.732549135519 on iteration 19
# new_angles=[0.12282708]
# likelihood is -3446.738453976576 on iteration 20
# new_angles=[0.1226001]
# likelihood is -3447.6982861373212 on iteration 21
# new_angles=[0.12238843]
# likelihood is -3448.6254063913893 on iteration 22
# new_angles=[0.12219113]
# likelihood is -3449.5287085332448 on iteration 23
# new_angles=[0.12200699]
# likelihood is -3450.4139710979143 on iteration 24
# new_angles=[0.1218352]
# likelihood is -3451.2849072518784 on iteration 25
# new_angles=[0.12167494]
# likelihood is -3452.143875961923 on iteration 26
# new_angles=[0.12152554]
# likelihood is -3452.992383455701 on iteration 27
# new_angles=[0.12138607]
# likelihood is -3453.8313956192114 on iteration 28
# new_angles=[0.12125594]
# likelihood is -3454.661561698765 on iteration 29
# 2-th start
# theta=[1.40627821],P=[[0.00072472+1.11520089e-18j]]
# Initial diagonal of diff is [1.83282094-1.11520089e-18j 3.00456268-1.11130723e-18j
#  1.98130735-1.12485975e-18j 1.2421479 -1.11130723e-18j
#  3.65061713-1.13841228e-18j 1.67995469-1.11130723e-18j
#  0.96105298-1.11130723e-18j 1.2697556 -1.08420217e-18j
#  1.65839093-1.11130723e-18j 1.36140876-1.08420217e-18j
#  1.0950029 -1.08420217e-18j 0.89641354-1.13841228e-18j
#  1.6191725 -1.08420217e-18j 0.79144415-1.08420217e-18j
#  1.14101576-1.13841228e-18j 2.29080604-1.13841228e-18j
#  1.1717292 -1.08420217e-18j 1.31427371-1.13841228e-18j
#  1.22882543-1.02999206e-18j 1.67823836-1.08420217e-18j]
# new_angles=[1.45728966]
# likelihood is -3420.8112987055747 on iteration 0
# new_angles=[1.45728966]
# 3-th start
# theta=[-0.15355298],P=[[0.00022361+0.j]]
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379-1.35525272e-20j
#  1.98180846+0.00000000e+00j 1.24264901-3.38813179e-21j
#  3.65111824+0.00000000e+00j 1.6804558 +0.00000000e+00j
#  0.96155409+6.77626358e-21j 1.27025671-6.77626358e-21j
#  1.65889204+0.00000000e+00j 1.36190987+1.35525272e-20j
#  1.09550401+0.00000000e+00j 0.89691465+0.00000000e+00j
#  1.6196736 +0.00000000e+00j 0.79194526+0.00000000e+00j
#  1.14151686+0.00000000e+00j 2.29130715-1.35525272e-20j
#  1.17223031+0.00000000e+00j 1.31477482-1.35525272e-20j
#  1.22932654+1.35525272e-20j 1.67873947+0.00000000e+00j]
# new_angles=[-0.15355298]
# likelihood is -3420.896866232598 on iteration 0
# new_angles=[-0.15355298]
# 4-th start
# theta=[0.5300775],P=[[0.00056861+3.10619813e-20j]]
# Initial diagonal of diff is [1.83297705-3.10619813e-20j 3.00471879-3.04931861e-20j
#  1.98146346-3.04931861e-20j 1.24230401-2.71050543e-20j
#  3.65077323-3.38813179e-20j 1.6801108 -3.38813179e-20j
#  0.96120909-3.38813179e-20j 1.26991171-2.71050543e-20j
#  1.65854703-2.71050543e-20j 1.36156486-4.06575815e-20j
#  1.09515901-2.71050543e-20j 0.89656965-1.35525272e-20j
#  1.6193286 -2.71050543e-20j 0.79160026-2.71050543e-20j
#  1.14117186-2.71050543e-20j 2.29096215-2.71050543e-20j
#  1.17188531-2.71050543e-20j 1.31442982+0.00000000e+00j
#  1.22898154-2.71050543e-20j 1.67839446+0.00000000e+00j]
# new_angles=[0.72133982]
# likelihood is -3405.9805614275874 on iteration 0
# new_angles=[0.7167084]
# likelihood is -3400.8841372207344 on iteration 1
# new_angles=[0.71304877]
# likelihood is -3392.408179191341 on iteration 2
# new_angles=[0.7101194]
# likelihood is -3376.3004831574212 on iteration 3
# new_angles=[0.70789449]
# likelihood is -3340.219577900811 on iteration 4
# new_angles=[0.70614996]
# likelihood is -3244.856242441423 on iteration 5
# new_angles=[0.70478283]
# likelihood is -3019.3243966064488 on iteration 6
# new_angles=[0.7037129]
# likelihood is -2837.560966761317 on iteration 7
# new_angles=[0.70287524]
# likelihood is -2829.9577574808513 on iteration 8
# new_angles=[0.70221714]
# likelihood is -2834.124334726725 on iteration 9
# new_angles=[0.7016994]
# likelihood is -2834.558042665464 on iteration 10
# new_angles=[0.70129192]
# likelihood is -2834.522800037859 on iteration 11
# new_angles=[0.70097116]
# likelihood is -2834.494454094656 on iteration 12
# new_angles=[0.70071861]
# likelihood is -2834.5047036576393 on iteration 13
# new_angles=[0.70051974]
# likelihood is -2834.5432494210754 on iteration 14
# new_angles=[0.70036312]
# likelihood is -2834.6003282535125 on iteration 15
# new_angles=[0.70023976]
# likelihood is -2834.6694196261387 on iteration 16
# new_angles=[0.70014258]
# likelihood is -2834.746348265322 on iteration 17
# new_angles=[0.70006602]
# likelihood is -2834.828445572983 on iteration 18
# new_angles=[0.7000057]
# likelihood is -2834.9139969850758 on iteration 19
# new_angles=[0.69995817]
# likelihood is -2835.0018923415682 on iteration 20
# new_angles=[0.69992072]
# likelihood is -2835.0914062613388 on iteration 21
# new_angles=[0.6998912]
# likelihood is -2835.1820595364206 on iteration 22
# new_angles=[0.69986794]
# likelihood is -2835.273531809891 on iteration 23
# new_angles=[0.69984961]
# likelihood is -2835.3656059878667 on iteration 24
# new_angles=[0.69983516]
# likelihood is -2835.4581327778837 on iteration 25
# new_angles=[0.69982377]
# likelihood is -2835.551007890961 on iteration 26
# new_angles=[0.69981479]
# likelihood is -2835.644157276223 on iteration 27
# new_angles=[0.69980771]
# likelihood is -2835.737527469336 on iteration 28
# new_angles=[0.69980213]
# likelihood is -2835.8310792182633 on iteration 29
# 5-th start
# theta=[0.60846218],P=[[0.00408934+9.69739904e-20j]]
# Initial diagonal of diff is [1.82945632-9.69739904e-20j 3.00119806-1.08420217e-19j
#  1.97794272+0.00000000e+00j 1.23878327+0.00000000e+00j
#  3.6472525 +0.00000000e+00j 1.67659007+0.00000000e+00j
#  0.95768836+0.00000000e+00j 1.26639098-9.48676901e-20j
#  1.6550263 -1.08420217e-19j 1.35804413+0.00000000e+00j
#  1.09163827-4.33680869e-19j 0.89304892-4.33680869e-19j
#  1.61580787+0.00000000e+00j 0.78807953-1.08420217e-19j
#  1.13765113-8.80914265e-20j 2.28744142-1.08420217e-19j
#  1.16836458+0.00000000e+00j 1.31090909-4.33680869e-19j
#  1.2254608 +0.00000000e+00j 1.67487373+2.16840434e-19j]
# new_angles=[0.60487129]
# likelihood is -3397.3802115502262 on iteration 0
# new_angles=[0.61865935]
# likelihood is -3360.43481511502 on iteration 1
# new_angles=[0.63255984]
# likelihood is -3277.5906167372664 on iteration 2
# new_angles=[0.645118]
# likelihood is -3149.154898988185 on iteration 3
# new_angles=[0.65581173]
# likelihood is -3041.9046070742497 on iteration 4
# new_angles=[0.66464593]
# likelihood is -2973.6147581082664 on iteration 5
# new_angles=[0.67182404]
# likelihood is -2925.8015537577394 on iteration 6
# new_angles=[0.6775982]
# likelihood is -2892.901207552382 on iteration 7
# new_angles=[0.68221354]
# likelihood is -2871.232474125624 on iteration 8
# new_angles=[0.68588713]
# likelihood is -2857.3398471758455 on iteration 9
# new_angles=[0.68880272]
# likelihood is -2848.579840774683 on iteration 10
# new_angles=[0.6911122]
# likelihood is -2843.122465979526 on iteration 11
# new_angles=[0.69293902]
# likelihood is -2839.7589938204237 on iteration 12
# new_angles=[0.69438263]
# likelihood is -2837.7106396367108 on iteration 13
# new_angles=[0.69552298]
# likelihood is -2836.4826220082814 on iteration 14
# new_angles=[0.69642263]
# likelihood is -2835.765025318847 on iteration 15
# new_angles=[0.69713243]
# likelihood is -2835.362846186159 on iteration 16
# new_angles=[0.6976923]
# likelihood is -2835.15519243738 on iteration 17
# new_angles=[0.69813382]
# likelihood is -2835.0670787746826 on iteration 18
# new_angles=[0.69848196]
# likelihood is -2835.05212581093 on iteration 19
# new_angles=[0.69875645]
# likelihood is -2835.081734849086 on iteration 20
# new_angles=[0.69897286]
# likelihood is -2835.1383197737955 on iteration 21
# new_angles=[0.69914347]
# likelihood is -2835.2111082341303 on iteration 22
# new_angles=[0.69927798]
# likelihood is -2835.293528902717 on iteration 23
# new_angles=[0.69938402]
# likelihood is -2835.381596359214 on iteration 24
# new_angles=[0.69946763]
# likelihood is -2835.472910585864 on iteration 25
# new_angles=[0.69953354]
# likelihood is -2835.5660410097917 on iteration 26
# new_angles=[0.69958551]
# likelihood is -2835.6601460400093 on iteration 27
# new_angles=[0.69962649]
# likelihood is -2835.7547400164453 on iteration 28
# new_angles=[0.6996588]
# likelihood is -2835.8495504268194 on iteration 29
# 6-th start
# theta=[-1.46911153],P=[[0.00075317-3.39408966e-19j]]
# Initial diagonal of diff is [1.83279249+3.39408966e-19j 3.00453423+3.40507245e-19j
#  1.98127889+3.38813179e-19j 1.24211944+3.38813179e-19j
#  3.65058867+3.32036915e-19j 1.67992624+3.45589442e-19j
#  0.96102453+3.38813179e-19j 1.26972715+3.38813179e-19j
#  1.65836247+3.38813179e-19j 1.3613803 +3.38813179e-19j
#  1.09497444+3.65918233e-19j 0.89638509+3.52365706e-19j
#  1.61914404+3.25260652e-19j 0.7914157 +3.52365706e-19j
#  1.1409873 +3.52365706e-19j 2.29077759+3.79470760e-19j
#  1.17170075+3.52365706e-19j 1.31424526+3.25260652e-19j
#  1.22879697+3.52365706e-19j 1.6782099 +3.52365706e-19j]
# new_angles=[-1.44525251]
# likelihood is -3420.8309729019315 on iteration 0
# new_angles=[-1.44525251]
# 7-th start
# theta=[-1.07899142],P=[[0.00022361+0.j]]
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379+0.00000000e+00j
#  1.98180846+0.00000000e+00j 1.24264901+0.00000000e+00j
#  3.65111824-3.38813179e-21j 1.6804558 -1.35525272e-20j
#  0.96155409+0.00000000e+00j 1.27025671+1.35525272e-20j
#  1.65889204-6.77626358e-21j 1.36190987-6.77626358e-21j
#  1.09550401+0.00000000e+00j 0.89691465+0.00000000e+00j
#  1.6196736 +0.00000000e+00j 0.79194526-3.38813179e-21j
#  1.14151686+0.00000000e+00j 2.29130715+0.00000000e+00j
#  1.17223031+0.00000000e+00j 1.31477482+0.00000000e+00j
#  1.22932654+1.35525272e-20j 1.67873947+0.00000000e+00j]
# new_angles=[-1.05288993]
# likelihood is -3420.8448029464985 on iteration 0
# new_angles=[-1.05288993]
# 8-th start
# theta=[-1.31513736],P=[[0.00092031-6.30330937e-19j]]
# Initial diagonal of diff is [1.83262534+6.30330937e-19j 3.00436708+6.23416249e-19j
#  1.98111175+6.23416249e-19j 1.2419523 +6.50521303e-19j
#  3.65042153+6.50521303e-19j 1.6797591 +5.96311195e-19j
#  0.96085738+7.04731412e-19j 1.26956   +6.50521303e-19j
#  1.65819533+6.50521303e-19j 1.36121316+7.04731412e-19j
#  1.0948073 +5.96311195e-19j 0.89621794+5.96311195e-19j
#  1.6189769 +6.50521303e-19j 0.79124855+6.50521303e-19j
#  1.14082016+6.23416249e-19j 2.29061044+6.30192513e-19j
#  1.1715336 +6.23416249e-19j 1.31407812+6.23416249e-19j
#  1.22862983+6.50521303e-19j 1.67804276+5.96311195e-19j]
# new_angles=[-1.33293986]
# likelihood is -3420.846747527709 on iteration 0
# new_angles=[-1.33164342]
# 9-th start
# theta=[-0.20985359],P=[[0.00022361+0.j]]
# Initial diagonal of diff is [1.83332205+0.00000000e+00j 3.00506379+0.00000000e+00j
#  1.98180846+0.00000000e+00j 1.24264901-1.35525272e-20j
#  3.65111824+0.00000000e+00j 1.6804558 +0.00000000e+00j
#  0.96155409+1.35525272e-20j 1.27025671+0.00000000e+00j
#  1.65889204-1.35525272e-20j 1.36190987+1.35525272e-20j
#  1.09550401+0.00000000e+00j 0.89691465+1.35525272e-20j
#  1.6196736 +2.64697796e-23j 0.79194526+0.00000000e+00j
#  1.14151686+0.00000000e+00j 2.29130715+0.00000000e+00j
#  1.17223031+0.00000000e+00j 1.31477482+0.00000000e+00j
#  1.22932654+0.00000000e+00j 1.67873947+3.38813179e-21j]
# new_angles=[-0.2048612]
# likelihood is -3420.9161679132944 on iteration 0
# new_angles=[-0.2048612]
# best_start=4

# %%
print(f"EM_theta1_rad={EM_theta1_rad},\nEM_P1={EM_P1}")
# Out:
# EM_theta1_rad=[0.69980213],
# EM_P1=[[2.02017548+4.53522301e-16j]]

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)
print(f"Погрешность в смысле разности углов в градусах: \
      {np.abs(EM_theta1_deg-theta1_deg)},")
print(f"Погрешность в смысле разности синусов углов: \
      {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах:       [0.01133691],
# Погрешность в смысле разности синусов углов:       [0.00015135].

# %%
print(np.trace(sensors.initial_Cov(X2_with_mv)))
print(np.trace(sensors.complex_cov(X2)))
# Out:
# (49.65503774285381+0j)
# (61.03171543408073+0j)

# %%
EM_theta2_rad, EM_P2, lhd_2 = em_stoch.multi_start_EM(X2_with_mv, 
                                                      Num_emitters2, 
                                                      Q=Q_2, 
                                                      num_of_starts=10, 
                                                      max_iter=30,
                                                      rtol=1e-3)
# Out:
# 0-th start
# theta=[-1.41744418  0.15335215],P=[[0.00276336-1.33017438e-17j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00299515+1.51605636e-17j]]
# Initial diagonal of diff is [1.15026919-1.85881981e-18j 1.99389114-1.73472348e-18j
#  1.06671809-1.73472348e-18j 1.72938522-1.84314369e-18j
#  1.14907423-1.84314369e-18j 2.05874687-1.95156391e-18j
#  0.64406552-1.78893358e-18j 1.342387  -1.95156391e-18j
#  1.1722289 -1.73472348e-18j 0.99058821-1.95156391e-18j
#  1.30708874-2.05998413e-18j 1.34610167-2.16840434e-18j
#  1.15990072-2.08708918e-18j 0.72086538-1.95156391e-18j
#  1.63418616-1.73472348e-18j 1.56259193-1.73472348e-18j
#  2.11217389-2.16840434e-18j 0.92115863-1.78893358e-18j
#  1.31483313-2.19550940e-18j 2.16361287-1.84314369e-18j]
# new_angles=[-0.51944372 -0.18254039]
# likelihood is -4030.5071271988627 on iteration 0
# new_angles=[-0.51567262 -0.22379118]
# likelihood is -3529.234064260616 on iteration 1
# new_angles=[-0.51189168 -0.47105202]
# likelihood is -3081.716093605585 on iteration 2
# new_angles=[-0.51267969 -0.47052573]
# likelihood is -3091.1087929673786 on iteration 3
# new_angles=[-0.51311431 -0.47047047]
# likelihood is -3091.751256907771 on iteration 4
# new_angles=[-0.51334435 -0.47063695]
# likelihood is -3091.5168261123254 on iteration 5
# new_angles=[-0.51347597 -0.47084965]
# likelihood is -3091.284399848261 on iteration 6
# new_angles=[-0.51354677 -0.47106928]
# likelihood is -3091.0841389528196 on iteration 7
# new_angles=[-0.51357281 -0.47129413]
# likelihood is -3090.9064251259506 on iteration 8
# new_angles=[-0.51356345 -0.47152999]
# likelihood is -3090.745524829124 on iteration 9
# new_angles=[-0.51352666 -0.47177988]
# likelihood is -3090.6015180583327 on iteration 10
# new_angles=[-0.51346561 -0.47205411]
# likelihood is -3090.4795238692204 on iteration 11
# new_angles=[-0.51338555 -0.47235536]
# likelihood is -3090.3917147384354 on iteration 12
# new_angles=[-0.51329248 -0.47268289]
# likelihood is -3090.362217988634 on iteration 13
# new_angles=[-0.51319359 -0.47303156]
# likelihood is -3090.435042965705 on iteration 14
# new_angles=[-0.51310219 -0.47338126]
# likelihood is -3090.6925799883156 on iteration 15
# new_angles=[-0.5130371  -0.47369604]
# likelihood is -3091.2889749044834 on iteration 16
# new_angles=[-0.51302126 -0.47392311]
# likelihood is -3092.5051838219238 on iteration 17
# new_angles=[-0.51307044 -0.47401193]
# likelihood is -3094.8008839780086 on iteration 18
# new_angles=[-0.51317352 -0.47395428]
# likelihood is -3098.724887507684 on iteration 19
# new_angles=[-0.51328254 -0.47382185]
# likelihood is -3104.4339185267313 on iteration 20
# new_angles=[-0.51334048 -0.473722  ]
# likelihood is -3111.0891699353133 on iteration 21
# new_angles=[-0.51332359 -0.47371606]
# likelihood is -3117.223641006353 on iteration 22
# new_angles=[-0.51324499 -0.4737956 ]
# likelihood is -3121.9315310635743 on iteration 23
# new_angles=[-0.51312995 -0.47392099]
# likelihood is -3125.2422233830403 on iteration 24
# new_angles=[-0.51299825 -0.47405856]
# likelihood is -3127.5960021391375 on iteration 25
# new_angles=[-0.51286109 -0.47418872]
# likelihood is -3129.400868682901 on iteration 26
# new_angles=[-0.51272368 -0.47430257]
# likelihood is -3130.915373076276 on iteration 27
# new_angles=[-0.5125879  -0.47439714]
# likelihood is -3132.27849247947 on iteration 28
# new_angles=[-0.5124541  -0.47447227]
# likelihood is -3133.5590109536956 on iteration 29
# 1-th start
# theta=[-1.43443568  0.13636065],P=[[0.00209247+2.33229794e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00447612-8.48930966e-18j]]
# Initial diagonal of diff is [1.14945911+8.25607987e-18j 1.99308107+8.23993651e-18j
#  1.06590801+8.23993651e-18j 1.72857515+8.23993651e-18j
#  1.14826415+8.13151629e-18j 2.05793679+7.80625564e-18j
#  0.64325545+8.02309608e-18j 1.34157692+8.23993651e-18j
#  1.17141882+8.23993651e-18j 0.98977813+8.67361738e-18j
#  1.30627866+8.23993651e-18j 1.34529159+8.23993651e-18j
#  1.15909064+8.34835673e-18j 0.7200553 +8.23993651e-18j
#  1.63337608+8.13151629e-18j 1.56178186+8.45677695e-18j
#  2.11136381+8.23993651e-18j 0.92034856+8.23993651e-18j
#  1.31402306+8.23993651e-18j 2.1628028 +8.61940727e-18j]
# new_angles=[-0.9807972  0.6750664]
# likelihood is -3725.237235171802 on iteration 0
# new_angles=[-0.96891356  0.68055201]
# likelihood is -3459.539840872777 on iteration 1
# new_angles=[-0.10911909  0.68497252]
# likelihood is -3412.6016197540316 on iteration 2
# new_angles=[-0.10659385  0.68836373]
# likelihood is -3395.708960198091 on iteration 3
# new_angles=[-0.10492138  0.6910238 ]
# likelihood is -3383.0713262339436 on iteration 4
# new_angles=[-0.1039043   0.69311172]
# likelihood is -3374.7774300049964 on iteration 5
# new_angles=[-0.1034022   0.69475327]
# likelihood is -3369.4610872041426 on iteration 6
# new_angles=[-0.10337682  0.69604792]
# likelihood is -3366.153020669227 on iteration 7
# new_angles=[-0.10383767  0.69707318]
# likelihood is -3364.2629494840467 on iteration 8
# new_angles=[-0.10486259  0.69788942]
# likelihood is -3363.445009648521 on iteration 9
# new_angles=[-0.10652162  0.69854343]
# likelihood is -3363.5119960911816 on iteration 10
# new_angles=[-0.10896274  0.69907198]
# likelihood is -3364.3647134891626 on iteration 11
# new_angles=[-0.11219928  0.69950304]
# likelihood is -3365.971673526586 on iteration 12
# new_angles=[-0.11610036  0.69985834]
# likelihood is -3368.325241323963 on iteration 13
# new_angles=[-0.12034779  0.70015465]
# likelihood is -3371.3650187787857 on iteration 14
# new_angles=[-0.12457854  0.70040397]
# likelihood is -3374.8678127595167 on iteration 15
# new_angles=[-0.12852086  0.70061503]
# likelihood is -3378.4572813461646 on iteration 16
# new_angles=[-0.13206014  0.70079364]
# likelihood is -3381.7772169779128 on iteration 17
# new_angles=[-0.13518742  0.70094415]
# likelihood is -3384.6424581150404 on iteration 18
# new_angles=[-0.13794785  0.70107026]
# likelihood is -3387.0431034885496 on iteration 19
# new_angles=[-0.14040151  0.70117535]
# likelihood is -3389.063155308778 on iteration 20
# new_angles=[-0.14260529  0.70126278]
# likelihood is -3390.8069930624497 on iteration 21
# new_angles=[-0.14460852  0.70133528]
# likelihood is -3392.3643679205047 on iteration 22
# new_angles=[-0.14645082  0.70139545]
# likelihood is -3393.8004877411636 on iteration 23
# new_angles=[-0.14816218  0.70144567]
# likelihood is -3395.1582231337225 on iteration 24
# new_angles=[-0.14977184  0.70148768]
# likelihood is -3396.4680424206995 on iteration 25
# new_angles=[-0.15129585  0.70152195]
# likelihood is -3397.7447305648466 on iteration 26
# new_angles=[-0.15276872  0.70155209]
# likelihood is -3399.0093441018157 on iteration 27
# new_angles=[-0.15416542  0.70157805]
# likelihood is -3400.2433676989967 on iteration 28
# new_angles=[-0.15552257  0.70160085]
# likelihood is -3401.470232011504 on iteration 29
# 2-th start
# theta=[-0.16451812  1.40627821],P=[[0.0001118+0.00000000e+00j 0.       +0.00000000e+00j]
#  [0.       +0.00000000e+00j 0.0047305+9.15648187e-18j]]
# Initial diagonal of diff is [1.15118539-9.15648187e-18j 1.99480735-9.16150836e-18j
#  1.06763429-9.10729825e-18j 1.73030143-9.10729825e-18j
#  1.14999044-9.10729825e-18j 2.05966308-9.10729825e-18j
#  0.64498173-9.10729825e-18j 1.3433032 -9.32413868e-18j
#  1.17314511-9.32413868e-18j 0.99150442-8.89045781e-18j
#  1.30800494-9.10729825e-18j 1.34701788-8.89045781e-18j
#  1.16081692-9.10729825e-18j 0.72178159-9.10729825e-18j
#  1.63510236-9.54097912e-18j 1.56350814-9.54097912e-18j
#  2.1130901 -9.10729825e-18j 0.92207484-9.10729825e-18j
#  1.31574934-9.10729825e-18j 2.16452908-9.54097912e-18j]
# new_angles=[-0.33243865  0.65902846]
# likelihood is -3962.1122094380707 on iteration 0
# new_angles=[0.73548577 0.66795501]
# likelihood is -3579.377904005413 on iteration 1
# new_angles=[0.67446659 0.74227577]
# likelihood is -3470.148531134997 on iteration 2
# new_angles=[0.67963862 0.74787149]
# likelihood is -3433.347335374807 on iteration 3
# new_angles=[0.68375014 0.75193927]
# likelihood is -3406.596828625408 on iteration 4
# new_angles=[0.68700659 0.75491475]
# likelihood is -3389.192927084737 on iteration 5
# new_angles=[0.68958249 0.75702725]
# likelihood is -3378.2334692242775 on iteration 6
# new_angles=[0.69161845 0.75848792]
# likelihood is -3371.389118833954 on iteration 7
# new_angles=[0.69323003 0.75937001]
# likelihood is -3367.130087313699 on iteration 8
# new_angles=[0.69450524 0.75982134]
# likelihood is -3364.4876483999506 on iteration 9
# new_angles=[0.69551721 0.75993485]
# likelihood is -3362.849367263971 on iteration 10
# new_angles=[0.69632535 0.75971308]
# likelihood is -3361.835233558466 on iteration 11
# new_angles=[0.69697203 0.75924358]
# likelihood is -3361.2120247179887 on iteration 12
# new_angles=[0.69749826 0.75843032]
# likelihood is -3360.829958334842 on iteration 13
# new_angles=[0.69793748 0.75716674]
# likelihood is -3360.5964416030624 on iteration 14
# new_angles=[0.69832995 0.75501017]
# likelihood is -3360.447199496331 on iteration 15
# new_angles=[0.69872609 0.75113485]
# likelihood is -3360.3359412263067 on iteration 16
# new_angles=[0.69913488 0.74563153]
# likelihood is -3360.2660150282077 on iteration 17
# new_angles=[0.69951326 0.73975456]
# likelihood is -3360.2855897974546 on iteration 18
# new_angles=[0.69882163 0.33314096]
# likelihood is -3360.9305594512543 on iteration 19
# new_angles=[-0.18834684  0.69924661]
# likelihood is -3361.904436512624 on iteration 20
# new_angles=[-0.18788078  0.69967589]
# likelihood is -3361.812275370763 on iteration 21
# new_angles=[-0.18765438  0.70001275]
# likelihood is -3361.681005096511 on iteration 22
# new_angles=[-0.18747333  0.70027631]
# likelihood is -3361.617185716404 on iteration 23
# new_angles=[-0.1873155   0.70048255]
# likelihood is -3361.601384267533 on iteration 24
# new_angles=[-0.18718228  0.70064397]
# likelihood is -3361.6161594798177 on iteration 25
# new_angles=[-0.18706718  0.70077031]
# likelihood is -3361.650429577244 on iteration 26
# new_angles=[-0.18696659  0.70086923]
# likelihood is -3361.697225695554 on iteration 27
# new_angles=[-0.18687768  0.70094671]
# likelihood is -3361.75218093299 on iteration 28
# new_angles=[-0.18679826  0.70100743]
# likelihood is -3361.8125425521566 on iteration 29
# 3-th start
# theta=[-0.15355298  1.41724335],P=[[0.0001118 +0.00000000e+00j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00572669-4.89593623e-18j]]
# Initial diagonal of diff is [1.1501892 +4.89593623e-18j 1.99381116+4.87890978e-18j
#  1.0666381 +4.87890978e-18j 1.72930524+4.87890978e-18j
#  1.14899425+4.98732999e-18j 2.05866688+4.77048956e-18j
#  0.64398554+4.77048956e-18j 1.34230701+4.98732999e-18j
#  1.17214892+4.98732999e-18j 0.99050822+4.77048956e-18j
#  1.30700875+5.20417043e-18j 1.34602168+5.20417043e-18j
#  1.15982073+4.77048956e-18j 0.72078539+4.77048956e-18j
#  1.63410617+5.20417043e-18j 1.56251195+4.77048956e-18j
#  2.1120939 +4.77048956e-18j 0.92107865+5.20417043e-18j
#  1.31475315+5.20417043e-18j 2.16353289+5.20417043e-18j]
# new_angles=[-0.17259054  0.65955595]
# likelihood is -3887.394462933021 on iteration 0
# new_angles=[0.74539111 0.66836799]
# likelihood is -3552.49496070195 on iteration 1
# new_angles=[0.67488173 0.75254865]
# likelihood is -3472.2333407419214 on iteration 2
# new_angles=[0.68006068 0.75826283]
# likelihood is -3433.6624223748263 on iteration 3
# new_angles=[0.68417389 0.76233017]
# likelihood is -3406.5681831240986 on iteration 4
# new_angles=[0.68742754 0.76529032]
# likelihood is -3389.1587049479936 on iteration 5
# new_angles=[0.68999705 0.76740155]
# likelihood is -3378.227011838428 on iteration 6
# new_angles=[0.69202409 0.76883023]
# likelihood is -3371.4155038090503 on iteration 7
# new_angles=[0.69362521 0.76968566]
# likelihood is -3367.1824556276692 on iteration 8
# new_angles=[0.69488969 0.77013291]
# likelihood is -3364.558295115445 on iteration 9
# new_angles=[0.69589128 0.77020178]
# likelihood is -3362.934461863084 on iteration 10
# new_angles=[0.69668645 0.76994698]
# likelihood is -3361.9335501401433 on iteration 11
# new_angles=[0.69732094 0.76941412]
# likelihood is -3361.3194435558976 on iteration 12
# new_angles=[0.69783525 0.76848452]
# likelihood is -3360.9438825934485 on iteration 13
# new_angles=[0.6982557  0.76721886]
# likelihood is -3360.7188003522674 on iteration 14
# new_angles=[0.69862607 0.76491081]
# likelihood is -3360.5766860861336 on iteration 15
# new_angles=[0.69900275 0.76033976]
# likelihood is -3360.4685202143173 on iteration 16
# new_angles=[0.6988827  0.34019066]
# likelihood is -3360.903223138411 on iteration 17
# new_angles=[-0.18100947  0.69931516]
# likelihood is -3361.101147513414 on iteration 18
# new_angles=[-0.18056702  0.69972515]
# likelihood is -3361.0009487168836 on iteration 19
# new_angles=[-0.18031742  0.7000461 ]
# likelihood is -3360.881953617403 on iteration 20
# new_angles=[-0.18010975  0.70029705]
# likelihood is -3360.8253670921995 on iteration 21
# new_angles=[-0.17992571  0.70049327]
# likelihood is -3360.8127215026343 on iteration 22
# new_angles=[-0.17976311  0.70064671]
# likelihood is -3360.8280677977423 on iteration 23
# new_angles=[-0.17961797  0.70076672]
# likelihood is -3360.8612388300844 on iteration 24
# new_angles=[-0.17948702  0.7008606 ]
# likelihood is -3360.9058668532166 on iteration 25
# new_angles=[-0.17936765  0.70093406]
# likelihood is -3360.9579550143135 on iteration 26
# new_angles=[-0.17925783  0.70099156]
# likelihood is -3361.0149796266683 on iteration 27
# new_angles=[-0.17915608  0.70103658]
# likelihood is -3361.0753345305657 on iteration 28
# new_angles=[-0.17906078  0.70107166]
# likelihood is -3361.138021921909 on iteration 29
# 4-th start
# theta=[-1.04071883  0.5300775 ],P=[[3.49385621e-06+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 3.58409028e-03-8.27175728e-19j]]
# Initial diagonal of diff is [1.15244011+8.27175728e-19j 1.99606207+8.26704157e-19j
#  1.06888902+8.40256684e-19j 1.73155615+8.40256684e-19j
#  1.15124516+8.13151629e-19j 2.0609178 +8.13151629e-19j
#  0.64623645+8.13151629e-19j 1.34455792+8.13151629e-19j
#  1.17439983+8.67361738e-19j 0.99275914+8.67361738e-19j
#  1.30925967+8.67361738e-19j 1.3482726 +8.67361738e-19j
#  1.16207164+6.50521303e-19j 0.72303631+7.58941521e-19j
#  1.63635709+7.58941521e-19j 1.56476286+7.58941521e-19j
#  2.11434482+8.67361738e-19j 0.92332956+8.67361738e-19j
#  1.31700406+8.67361738e-19j 2.1657838 +8.67361738e-19j]
# new_angles=[-0.53177124  0.68179731]
# likelihood is -3701.8897698937058 on iteration 0
# new_angles=[-0.8076121   0.68596845]
# likelihood is -3403.24615472524 on iteration 1
# new_angles=[-0.47165146  0.68923708]
# likelihood is -3385.522835399391 on iteration 2
# new_angles=[-0.47095516  0.69179692]
# likelihood is -3378.3999828888973 on iteration 3
# new_angles=[-0.4690389   0.69380052]
# likelihood is -3372.1177595374174 on iteration 4
# new_angles=[-0.46741172  0.69536492]
# likelihood is -3368.1068816177212 on iteration 5
# new_angles=[-0.46627568  0.69658699]
# likelihood is -3365.6457869205683 on iteration 6
# new_angles=[-0.46527061  0.6975412 ]
# likelihood is -3364.149876403669 on iteration 7
# new_angles=[-0.46466122  0.69828675]
# likelihood is -3363.2471523316667 on iteration 8
# new_angles=[-0.46412505  0.69886863]
# likelihood is -3362.710741968118 on iteration 9
# new_angles=[-0.4637124   0.69932209]
# likelihood is -3362.4005312662216 on iteration 10
# new_angles=[-0.4633995   0.69967414]
# likelihood is -3362.230683391619 on iteration 11
# new_angles=[-0.46316438  0.69994986]
# likelihood is -3362.146090976849 on iteration 12
# new_angles=[-0.46295983  0.70016565]
# likelihood is -3362.1151109970774 on iteration 13
# new_angles=[-0.46270899  0.70033319]
# 5-th start
# theta=[-0.96233415  0.60846218],P=[[0.00189661+1.15722072e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.00636671+3.83942552e-19j]]
# Initial diagonal of diff is [1.14776437-4.99664625e-19j 1.99138633-4.33680869e-19j
#  1.06421328-4.33680869e-19j 1.72688041-4.33680869e-19j
#  1.14656942-8.67361738e-19j 2.05624206-4.33680869e-19j
#  0.64156071-4.33680869e-19j 1.33988218-5.42101086e-19j
#  1.16972409-4.33680869e-19j 0.9880834 -6.50521303e-19j
#  1.30458393-8.67361738e-19j 1.34359686-8.67361738e-19j
#  1.1573959 -8.67361738e-19j 0.71836057-4.33680869e-19j
#  1.63168135-4.91279109e-19j 1.56008712-4.33680869e-19j
#  2.10966908-6.50521303e-19j 0.91865382+0.00000000e+00j
#  1.31232832+0.00000000e+00j 2.16110806-4.33680869e-19j]
# new_angles=[-0.969747    0.61114193]
# likelihood is -4251.092395873549 on iteration 0
# new_angles=[-0.51578231  0.62659467]
# likelihood is -3857.6952358560306 on iteration 1
# new_angles=[-0.51171339  0.64071516]
# likelihood is -3116.1188205714184 on iteration 2
# new_angles=[-0.50883078  0.65242985]
# likelihood is -2552.8790830196904 on iteration 3
# new_angles=[-0.50694686  0.66234084]
# likelihood is -2408.6403193659617 on iteration 4
# new_angles=[-0.50557199  0.67053604]
# likelihood is -2312.3531840003507 on iteration 5
# new_angles=[-0.50449682  0.67707622]
# likelihood is -2245.101191817677 on iteration 6
# new_angles=[-0.50364227  0.68224605]
# likelihood is -2201.4087669979804 on iteration 7
# new_angles=[-0.50295827  0.68631411]
# likelihood is -2173.8323545470494 on iteration 8
# new_angles=[-0.50240858  0.68950561]
# likelihood is -2156.705765120216 on iteration 9
# new_angles=[-0.50196562  0.69200425]
# likelihood is -2146.1833275981217 on iteration 10
# new_angles=[-0.50160795  0.69395752]
# likelihood is -2139.7738222760436 on iteration 11
# new_angles=[-0.50131887  0.69548271]
# likelihood is -2135.9032038986074 on iteration 12
# new_angles=[-0.5010849   0.69667252]
# likelihood is -2133.5910142532384 on iteration 13
# new_angles=[-0.50089549  0.69760023]
# likelihood is -2132.2317144591802 on iteration 14
# new_angles=[-0.50074161  0.69832253]
# likelihood is -2131.4544417595007 on iteration 15
# new_angles=[-0.50061666  0.69888523]
# likelihood is -2131.0309100048257 on iteration 16
# new_angles=[-0.50051479  0.69932224]
# likelihood is -2130.8233972306166 on iteration 17
# new_angles=[-0.50043161  0.69966174]
# likelihood is -2130.746644655312 on iteration 18
# new_angles=[-0.50036346  0.69992515]
# likelihood is -2130.7492180186373 on iteration 19
# new_angles=[-0.5003074   0.70012923]
# likelihood is -2130.799842333611 on iteration 20
# new_angles=[-0.50026104  0.70028702]
# likelihood is -2130.879520063235 on iteration 21
# new_angles=[-0.50022249  0.70040874]
# likelihood is -2130.9767283041874 on iteration 22
# new_angles=[-0.5001902   0.70050233]
# likelihood is -2131.084488848206 on iteration 23
# new_angles=[-0.50016293  0.700574  ]
# likelihood is -2131.1985829279442 on iteration 24
# new_angles=[-0.5001397   0.70062857]
# likelihood is -2131.316465198594 on iteration 25
# new_angles=[-0.5001197   0.70066981]
# likelihood is -2131.4366041520893 on iteration 26
# new_angles=[-0.50010229  0.70070067]
# likelihood is -2131.55808115313 on iteration 27
# new_angles=[-0.50008697  0.70072344]
# likelihood is -2131.680347695985 on iteration 28
# new_angles=[-0.50007331  0.70073991]
# likelihood is -2131.8030778988214 on iteration 29
# 6-th start
# theta=[-1.46911153  0.10168479],P=[[0.00443737+1.62172784e-19j 0.        +0.00000000e+00j]
#  [0.        +0.00000000e+00j 0.0001118 +0.00000000e+00j]]
# Initial diagonal of diff is [1.15147852-1.62172784e-19j 1.99510048-1.62630326e-19j
#  1.06792743-1.89735380e-19j 1.73059456-1.62630326e-19j
#  1.15028357-1.62630326e-19j 2.05995621-1.62630326e-19j
#  0.64527486-1.62630326e-19j 1.34359633-1.08420217e-19j
#  1.17343824-1.08420217e-19j 0.99179755-1.08420217e-19j
#  1.30829808-2.16840434e-19j 1.34731101-1.08420217e-19j
#  1.16111005-2.16840434e-19j 0.72207472-2.16840434e-19j
#  1.6353955 +0.00000000e+00j 1.56380127-2.16840434e-19j
#  2.11338323-2.16840434e-19j 0.92236797-4.33680869e-19j
#  1.31604247-2.16840434e-19j 2.16482221-2.16840434e-19j]
# new_angles=[-0.52550056 -1.57079633]
# likelihood is -3795.667607485585 on iteration 0
# new_angles=[-0.54341745 -0.51991677]
# likelihood is -3252.121166521669 on iteration 1
# new_angles=[-0.53766298 -0.51550494]
# likelihood is -3158.4778417708862 on iteration 2
# new_angles=[-0.64913786 -0.51218613]
# likelihood is -3128.9264509751206 on iteration 3
# new_angles=[-0.64437179 -0.50968976]
# likelihood is -3115.0343570754017 on iteration 4
# new_angles=[-0.6445397  -0.50775779]
# likelihood is -3105.553640575843 on iteration 5
# new_angles=[-0.99065102 -0.5060463 ]
# likelihood is -3097.741508438 on iteration 6
# new_angles=[-0.99267514 -0.50479948]
# likelihood is -3093.5979489800657 on iteration 7
# new_angles=[-0.99344753 -0.50383629]
# likelihood is -3091.187979425935 on iteration 8
# new_angles=[-0.99391198 -0.50309142]
# likelihood is -3089.75648731313 on iteration 9
# new_angles=[-0.99422362 -0.50251536]
# likelihood is -3088.9116327325055 on iteration 10
# new_angles=[-0.9944539  -0.50206986]
# likelihood is -3088.4202475608404 on iteration 11
# new_angles=[-0.99477879 -0.50172473]
# likelihood is -3088.1417946275974 on iteration 12
# new_angles=[-0.99484365 -0.50145849]
# likelihood is -3087.9927496617647 on iteration 13
# new_angles=[-0.99505474 -0.50124817]
# likelihood is -3087.918889156579 on iteration 14
# new_angles=[-0.99513041 -0.50108978]
# likelihood is -3087.895761024033 on iteration 15
# new_angles=[-0.99528337 -0.50096713]
# likelihood is -3087.90082251448 on iteration 16
# new_angles=[-0.99544531 -0.50087227]
# likelihood is -3087.923516022803 on iteration 17
# new_angles=[-0.99570458 -0.50079856]
# likelihood is -3087.957067311608 on iteration 18
# new_angles=[-1.26468033 -0.50073569]
# likelihood is -3089.4263615421673 on iteration 19
# new_angles=[-1.26599144 -0.50069678]
# likelihood is -3089.599579302205 on iteration 20
# new_angles=[-1.26655555 -0.50066679]
# likelihood is -3089.6565280103246 on iteration 21
# new_angles=[-1.26708771 -0.50064354]
# likelihood is -3089.707208251368 on iteration 22
# new_angles=[ 0.41456919 -0.50068389]
# likelihood is -3090.169449298089 on iteration 23
# new_angles=[-0.50066582  0.41437594]
# likelihood is -3090.4744542084063 on iteration 24
# new_angles=[-0.50065152  0.4144753 ]
# likelihood is -3090.5443728296564 on iteration 25
# new_angles=[-0.50063436  0.41463361]
# likelihood is -3090.6020194294433 on iteration 26
# new_angles=[-0.50062706  0.4146879 ]
# likelihood is -3090.6598815282123 on iteration 27
# new_angles=[-0.50062135  0.41477808]
# likelihood is -3090.7184848057386 on iteration 28
# new_angles=[-0.50061691  0.41487303]
# likelihood is -3090.7776764417786 on iteration 29
# 7-th start
# theta=[-1.07899142  0.49180491],P=[[3.49385621e-06+0.00000000e+00j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 1.27299140e-03+2.29972578e-19j]]
# Initial diagonal of diff is [1.15475121-2.29972578e-19j 1.99837317-2.30392962e-19j
#  1.07120012-2.16840434e-19j 1.73386725-2.16840434e-19j
#  1.15355626-2.71050543e-19j 2.0632289 -1.62630326e-19j
#  0.64854755-3.25260652e-19j 1.34686902-3.25260652e-19j
#  1.17671093-3.25260652e-19j 0.99507024-2.16840434e-19j
#  1.31157077-2.16840434e-19j 1.3505837 -2.16840434e-19j
#  1.16438274-3.25260652e-19j 0.72534741-2.16840434e-19j
#  1.63866819-2.16840434e-19j 1.56707396-2.16840434e-19j
#  2.11665592-1.89735380e-19j 0.92564066-2.43945489e-19j
#  1.31931516-2.29757687e-19j 2.1680949 -2.30392962e-19j]
# new_angles=[-0.54790963  0.65514548]
# likelihood is -4148.320135127416 on iteration 0
# new_angles=[-0.54836265  0.66480952]
# likelihood is -3856.7450478940054 on iteration 1
# new_angles=[0.85258475 0.67253612]
# likelihood is -3527.084440614911 on iteration 2
# new_angles=[0.67864971 0.86829119]
# likelihood is -3454.2539909381553 on iteration 3
# new_angles=[0.68347308 0.54562503]
# likelihood is -3421.9681810158995 on iteration 4
# new_angles=[0.54698515 0.68726552]
# likelihood is -3399.358737955221 on iteration 5
# new_angles=[0.54663568 0.6902409 ]
# likelihood is -3385.002576841495 on iteration 6
# new_angles=[0.54527654 0.69257175]
# likelihood is -3376.1107857237926 on iteration 7
# new_angles=[0.54351777 0.69439594]
# likelihood is -3370.6415013718415 on iteration 8
# new_angles=[0.5417898 0.6958224]
# likelihood is -3367.290868638833 on iteration 9
# new_angles=[0.54026894 0.6969376 ]
# likelihood is -3365.2455940706636 on iteration 10
# new_angles=[0.5389132 0.6978098]
# likelihood is -3364.0035463813997 on iteration 11
# new_angles=[-0.45726282  0.69849756]
# likelihood is -3363.225164079353 on iteration 12
# new_angles=[-0.45712988  0.69903434]
# likelihood is -3362.8001994245938 on iteration 13
# new_angles=[-0.45674508  0.69945322]
# likelihood is -3362.5435737191965 on iteration 14
# new_angles=[-0.45641802  0.69978027]
# likelihood is -3362.404689958578 on iteration 15
# new_angles=[-0.45606021  0.70003528]
# likelihood is -3362.3402641222783 on iteration 16
# new_angles=[-0.4559031   0.70023427]
# likelihood is -3362.322125838498 on iteration 17
# new_angles=[-0.45578075  0.70038955]
# likelihood is -3362.3332220236775 on iteration 18
# new_angles=[-0.45564736  0.70051063]
# likelihood is -3362.3628876445337 on iteration 19
# new_angles=[-0.45548797  0.70060516]
# likelihood is -3362.4044099895245 on iteration 20
# new_angles=[-0.45542355  0.70067836]
# likelihood is -3362.453627054537 on iteration 21
# new_angles=[-0.45538672  0.70073599]
# likelihood is -3362.507710062899 on iteration 22
# new_angles=[-0.45529192  0.70078103]
# likelihood is -3362.565181622715 on iteration 23
# new_angles=[-0.45525824  0.70081653]
# likelihood is -3362.624791100715 on iteration 24
# new_angles=[-0.45518813  0.70084386]
# likelihood is -3362.686058052892 on iteration 25
# new_angles=[-0.45514018  0.70086521]
# likelihood is -3362.7483627247143 on iteration 26
# new_angles=[-0.45514016  0.70088188]
# likelihood is -3362.811381923787 on iteration 27
# new_angles=[-0.45502642  0.70089489]
# likelihood is -3362.8750622502284 on iteration 28
# new_angles=[-0.45502642  0.70090506]
# likelihood is -3362.939007717652 on iteration 29
# 8-th start
# theta=[-1.31513736  0.25565896],P=[[3.79460496e-03-1.42636553e-18j 0.00000000e+00+0.00000000e+00j]
#  [0.00000000e+00+0.00000000e+00j 5.59016994e-05+0.00000000e+00j]]
# Initial diagonal of diff is [1.15217719+1.42636553e-18j 1.99579915+1.40946282e-18j
#  1.06862609+1.40946282e-18j 1.73129323+1.30104261e-18j
#  1.15098224+1.51788304e-18j 2.06065488+1.51788304e-18j
#  0.64597353+1.51788304e-18j 1.344295  +1.30104261e-18j
#  1.17413691+1.08420217e-18j 0.99249622+1.51788304e-18j
#  1.30899674+1.73472348e-18j 1.34800968+1.30104261e-18j
#  1.16180872+1.30104261e-18j 0.72277339+1.40946282e-18j
#  1.63609416+1.40946282e-18j 1.56449994+1.43656788e-18j
#  2.1140819 +1.40946282e-18j 0.92306664+1.51788304e-18j
#  1.31674114+1.30104261e-18j 2.16552088+1.51788304e-18j]
# new_angles=[-0.50637708  0.57022508]
# likelihood is -3849.7491563921667 on iteration 0
# new_angles=[-0.50510449  0.15627008]
# likelihood is -3208.6431422484875 on iteration 1
# new_angles=[-0.50409611 -0.51084627]
# likelihood is -3082.590952874263 on iteration 2
# new_angles=[-0.50931619 -0.50331454]
# likelihood is -3090.0656806960205 on iteration 3
# new_angles=[-0.97009472 -0.50268653]
# likelihood is -3088.643109359086 on iteration 4
# new_angles=[ 0.15880993 -0.50224851]
# likelihood is -3088.8406069650773 on iteration 5
# new_angles=[-0.50188633  0.15891479]
# likelihood is -3088.583373564444 on iteration 6
# new_angles=[-0.50160616  0.15894974]
# likelihood is -3088.4132079716214 on iteration 7
# new_angles=[-0.50138942  0.15892571]
# likelihood is -3088.3266622015417 on iteration 8
# new_angles=[-0.50122185  0.15893553]
# likelihood is -3088.2927569172557 on iteration 9
# new_angles=[-0.501092    0.15892691]
# 9-th start
# theta=[-0.20985359  1.36094274],P=[[0.0001118+0.00000000e+00j 0.       +0.00000000e+00j]
#  [0.       +0.00000000e+00j 0.0041411+1.10075139e-17j]]
# Initial diagonal of diff is [1.1517748 -1.10075139e-17j 1.99539676-1.10046521e-17j
#  1.0682237 -1.11672824e-17j 1.73089083-1.10588622e-17j
#  1.15057984-1.12757026e-17j 2.06025248-1.10588622e-17j
#  0.64557113-1.08420217e-17j 1.34389261-1.08420217e-17j
#  1.17373451-1.10588622e-17j 0.99209382-1.10588622e-17j
#  1.30859435-1.12757026e-17j 1.34760728-1.08420217e-17j
#  1.16140633-1.12757026e-17j 0.72237099-1.12757026e-17j
#  1.63569177-1.08420217e-17j 1.56409754-1.08420217e-17j
#  2.1136795 -1.10588622e-17j 0.92266424-1.08420217e-17j
#  1.31633874-1.10588622e-17j 2.16511849-1.10588622e-17j]
# new_angles=[0.12231271 0.65623508]
# likelihood is -4020.4457639169195 on iteration 0
# new_angles=[0.69277257 0.66572979]
# likelihood is -3639.138251072743 on iteration 1
# new_angles=[0.67299146 0.69972272]
# likelihood is -3491.8101546930197 on iteration 2
# new_angles=[0.67876701 0.70482635]
# likelihood is -3447.251999605688 on iteration 3
# new_angles=[0.68332382 0.7089    ]
# likelihood is -3415.6504662883563 on iteration 4
# new_angles=[0.68691103 0.71208438]
# likelihood is -3395.075852399542 on iteration 5
# new_angles=[0.68973336 0.71446852]
# likelihood is -3382.1953645999465 on iteration 6
# new_angles=[0.69195471 0.71617705]
# likelihood is -3374.2144048504465 on iteration 7
# new_angles=[0.69370048 0.71738667]
# likelihood is -3369.2967316514546 on iteration 8
# new_angles=[0.69507152 0.71821852]
# likelihood is -3366.278668891022 on iteration 9
# new_angles=[0.69615182 0.71873298]
# likelihood is -3364.4299223859475 on iteration 10
# new_angles=[0.69700215 0.71904288]
# likelihood is -3363.305007916595 on iteration 11
# new_angles=[0.69767219 0.71917746]
# likelihood is -3362.628155851465 on iteration 12
# new_angles=[0.69820098 0.71916771]
# likelihood is -3362.2289305130835 on iteration 13
# new_angles=[0.69862101 0.71902529]
# likelihood is -3362.0010538652828 on iteration 14
# new_angles=[0.69895754 0.71874832]
# likelihood is -3361.879873162142 on iteration 15
# new_angles=[0.69922951 0.71834891]
# likelihood is -3361.8260578995946 on iteration 16
# new_angles=[0.69945979 0.71768116]
# likelihood is -3361.8125229432944 on iteration 17
# new_angles=[0.69965259 0.71689263]
# likelihood is -3361.830427945665 on iteration 18
# new_angles=[ 0.69928912 -0.41252795]
# likelihood is -3358.1304701980507 on iteration 19
# new_angles=[-0.41560851  0.6997253 ]
# likelihood is -3360.2965102897324 on iteration 20
# new_angles=[-0.41612501  0.7000518 ]
# likelihood is -3360.3193629866732 on iteration 21
# new_angles=[-0.41594232  0.70030254]
# likelihood is -3360.271245728708 on iteration 22
# new_angles=[-0.41558942  0.70049694]
# likelihood is -3360.2661833270668 on iteration 23
# new_angles=[-0.4152163   0.70064815]
# likelihood is -3360.2916155078815 on iteration 24
# new_angles=[-0.4148604   0.70076587]
# likelihood is -3360.335964660624 on iteration 25
# new_angles=[-0.41452736  0.70085749]
# likelihood is -3360.3923330066596 on iteration 26
# new_angles=[-0.41421486  0.70092873]
# likelihood is -3360.45658863737 on iteration 27
# new_angles=[-0.4139193   0.70098407]
# likelihood is -3360.526189947265 on iteration 28
# new_angles=[-0.4136254   0.70102614]
# likelihood is -3360.6004595471486 on iteration 29
# best_start=5

# %%
print(f"EM_theta2_rad={EM_theta2_rad},\nEM_P2={EM_P2}")
# Out:
# EM_theta2_rad=[-0.50007331  0.70073991],
# EM_P2=[[ 2.14550803e+00+3.84788568e-15j -1.80899785e-03-2.96730738e-01j]
#  [-1.80899785e-03+2.96730738e-01j  1.71442439e+00+1.09401785e-15j]]

# %%
EM_theta2_deg = np.rad2deg(EM_theta2_rad)
print(f"Погрешность в смысле разности углов в градусах: \
      {np.abs(np.sort(EM_theta2_deg)-np.sort(theta2_deg))},")
print(f"Погрешность в смысле разности синусов углов: \
      {np.abs(np.sin(EM_theta2_rad)-np.sin(theta2_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах:       [0.0042002  0.04239364],
# Погрешность в смысле разности синусов углов:       [6.43318723e-05 5.65736886e-04].

# %%
em_stoch.incomplete_lkhd(X1_with_mv, theta1_rad, P_1, Q_1)
# Out:
# np.float64(-2824.8936593288777)

# %%
em_stoch.incomplete_lkhd(X1_with_mv, EM_theta1_rad, EM_P1, Q_1)
# Out:
# np.float64(-2835.8310792182633)

# %%
em_stoch.incomplete_lkhd(X2_with_mv, theta2_rad, P_2, Q_2)
# Out:
# np.float64(-2106.4163518053156)

# %%
em_stoch.incomplete_lkhd(X2_with_mv, EM_theta2_rad, EM_P2, Q_2)
# Out:
# np.float64(-2131.8030778988214)
