# %%
import numpy as np
import sensors
import ecm_determ

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Направление прибытия (DOA) в градусах
#Q1 = 1.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шума
Q1 = sensors.random_complex_cov(n=Num_sensors1, max_real=1.2, seed=50)
A1 = np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1 = sensors.gds(Num_emitters1, sample_size1)
n1 = sensors.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + n1.T).T

# %%
X1_with_mv = sensors.MCAR(X1, [2,4], [40, 40])

# %%
EM_theta1_rad, EM_S1, EM_Q1, lhd_1 = ecm_determ.multi_start_ECM_un(X1_with_mv, Num_emitters1, num_of_starts=10, max_iter=10, rtol=1e-6)
# Out:
# 0-th start
# Initial theta = [-2.83488836]
# incomplete likelihood is -200.224454753177 on iteration 0
# incomplete likelihood is -108.148787381567 on iteration 1
# incomplete likelihood is -129.99410955188955 on iteration 2
# incomplete likelihood is -141.70048569926422 on iteration 3
# incomplete likelihood is -148.6617344444916 on iteration 4
# incomplete likelihood is -149.9525157344547 on iteration 5
# incomplete likelihood is -143.33186755794534 on iteration 6
# incomplete likelihood is -125.38236326889782 on iteration 7
# incomplete likelihood is -89.33878467463796 on iteration 8
# incomplete likelihood is -20.63198921593018 on iteration 9
# 1-th start
# Initial theta = [-2.86887136]
# incomplete likelihood is -444.91305139778416 on iteration 0
# incomplete likelihood is -390.90259052257187 on iteration 1
# incomplete likelihood is -405.5949933877607 on iteration 2
# incomplete likelihood is -420.6642838072166 on iteration 3
# incomplete likelihood is -435.7321295452035 on iteration 4
# incomplete likelihood is -449.17157437770186 on iteration 5
# incomplete likelihood is -458.9226275872072 on iteration 6
# incomplete likelihood is -462.18668397673895 on iteration 7
# incomplete likelihood is -454.9807578475392 on iteration 8
# incomplete likelihood is -431.68023887916945 on iteration 9
# 2-th start
# Initial theta = [-0.32903623]
# incomplete likelihood is -130.5210863078514 on iteration 0
# incomplete likelihood is -98.05444810700536 on iteration 1
# incomplete likelihood is -120.72928343602595 on iteration 2
# incomplete likelihood is -124.6257481032466 on iteration 3
# incomplete likelihood is -130.93133233299295 on iteration 4
# incomplete likelihood is -132.18743267398295 on iteration 5
# incomplete likelihood is -126.48380309123372 on iteration 6
# incomplete likelihood is -110.89644010709118 on iteration 7
# incomplete likelihood is -79.67643735324536 on iteration 8
# incomplete likelihood is -22.656213206663296 on iteration 9
# 3-th start
# Initial theta = [2.8344867]
# incomplete likelihood is -166.78517150979215 on iteration 0
# incomplete likelihood is -84.82730792472007 on iteration 1
# incomplete likelihood is -84.85528008026488 on iteration 2
# incomplete likelihood is -80.72026569420433 on iteration 3
# incomplete likelihood is -71.05057690805167 on iteration 4
# incomplete likelihood is -53.968204684636326 on iteration 5
# incomplete likelihood is -25.484986918287735 on iteration 6
# incomplete likelihood is 26.229021368880808 on iteration 7
# incomplete likelihood is 118.03193309113426 on iteration 8
# incomplete likelihood is 261.13607115047085 on iteration 9
# 4-th start
# Initial theta = [-2.08143765]
# incomplete likelihood is -491.3706807193472 on iteration 0
# incomplete likelihood is -341.42061037722993 on iteration 1
# incomplete likelihood is -354.4632593742357 on iteration 2
# incomplete likelihood is -372.1505870683874 on iteration 3
# incomplete likelihood is -388.68469981539863 on iteration 4
# incomplete likelihood is -403.53558366008303 on iteration 5
# incomplete likelihood is -415.25799258782905 on iteration 6
# incomplete likelihood is -421.7169565039975 on iteration 7
# incomplete likelihood is -420.05477799072105 on iteration 8
# incomplete likelihood is -406.53596885476315 on iteration 9
# 5-th start
# Initial theta = [-1.9246683]
# incomplete likelihood is -535.8446452712318 on iteration 0
# incomplete likelihood is -472.55599067652275 on iteration 1
# incomplete likelihood is -480.57926767213024 on iteration 2
# incomplete likelihood is -491.1423901463039 on iteration 3
# incomplete likelihood is -503.5403567680253 on iteration 4
# incomplete likelihood is -516.4853289487614 on iteration 5
# incomplete likelihood is -528.4356682769863 on iteration 6
# incomplete likelihood is -537.3688593634822 on iteration 7
# incomplete likelihood is -540.4879536517637 on iteration 8
# incomplete likelihood is -416.096227251638 on iteration 9
# 6-th start
# Initial theta = [0.20336959]
# incomplete likelihood is -119.39486365123017 on iteration 0
# incomplete likelihood is -15.177033890549502 on iteration 1
# incomplete likelihood is -20.071517177723777 on iteration 2
# incomplete likelihood is -16.324122215793864 on iteration 3
# incomplete likelihood is -5.7076062888109345 on iteration 4
# incomplete likelihood is 22.346657675736363 on iteration 5
# incomplete likelihood is 90.08421342751016 on iteration 6
# incomplete likelihood is 215.732489011016 on iteration 7
# incomplete likelihood is 399.4179126112077 on iteration 8
# incomplete likelihood is 638.8396891670667 on iteration 9
# 7-th start
# Initial theta = [0.98360982]
# incomplete likelihood is -260.03935978723905 on iteration 0
# incomplete likelihood is -220.8480185173707 on iteration 1
# incomplete likelihood is -237.58189824233304 on iteration 2
# incomplete likelihood is -252.69877580377147 on iteration 3
# incomplete likelihood is -266.2868348823812 on iteration 4
# incomplete likelihood is -276.95180425520556 on iteration 5
# incomplete likelihood is -282.4142551885953 on iteration 6
# incomplete likelihood is -279.2714400119593 on iteration 7
# incomplete likelihood is -262.5286102230716 on iteration 8
# incomplete likelihood is -225.21068536595658 on iteration 9
# 8-th start
# Initial theta = [0.51131793]
# incomplete likelihood is 345.0978070636029 on iteration 0
# incomplete likelihood is 384.1342086378201 on iteration 1
# incomplete likelihood is 415.50547714405576 on iteration 2
# incomplete likelihood is 448.3467729351671 on iteration 3
# incomplete likelihood is 490.8707281725055 on iteration 4
# incomplete likelihood is 547.7697728253963 on iteration 5
# incomplete likelihood is 623.8263000687176 on iteration 6
# incomplete likelihood is 723.9344732095119 on iteration 7
# incomplete likelihood is 853.1004105526316 on iteration 8
# incomplete likelihood is 1016.3737893841084 on iteration 9
# 9-th start
# Initial theta = [2.72188548]
# incomplete likelihood is -94.18149476885841 on iteration 0
# incomplete likelihood is -47.6900069315887 on iteration 1
# incomplete likelihood is -44.13989102837606 on iteration 2
# incomplete likelihood is -35.77447539195078 on iteration 3
# incomplete likelihood is -22.32662535415374 on iteration 4
# incomplete likelihood is -1.5118908000579552 on iteration 5
# incomplete likelihood is 34.4766094712856 on iteration 6
# incomplete likelihood is 103.11235963295643 on iteration 7
# incomplete likelihood is 214.9454449343809 on iteration 8
# incomplete likelihood is 370.7796669763134 on iteration 9
# best_start=8

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)
print(f"Погрешность в смысле разности углов в градусах: {np.abs(EM_theta1_deg-theta1_deg)},")
print(f"Погрешность в смысле разности синусов углов: {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах: [0.01175359],
# Погрешность в смысле разности синусов углов: [0.00018004].

# %%
EM_Q1-Q1
# Out:
# array([[ 0.04495054+0.00000000e+00j, -0.03992931-1.06666705e-01j,
#         -0.11062603-1.45199213e-02j, -0.03914684-4.76145836e-02j,
#          0.1048952 -5.52034130e-02j],
#        [-0.03992931+1.06666705e-01j, -0.19688184+0.00000000e+00j,
#         -0.01307358-5.20634956e-02j,  0.06834897+9.67301187e-03j,
#         -0.04548263+3.58096838e-02j],
#        [-0.11062603+1.45199213e-02j, -0.01307358+5.20634956e-02j,
#          0.54770267+0.00000000e+00j,  0.09709726+1.09144010e-01j,
#         -0.25519261+1.62557005e-01j],
#        [-0.03914684+4.76145836e-02j,  0.06834897-9.67301187e-03j,
#          0.09709726-1.09144010e-01j,  0.17999484+0.00000000e+00j,
#          0.01797322+1.38056074e-01j],
#        [ 0.1048952 +5.52034130e-02j, -0.04548263-3.58096838e-02j,
#         -0.25519261-1.62557005e-01j,  0.01797322-1.38056074e-01j,
#          1.03746828+1.74652275e-19j]])

# %%
print(np.round(Q1-EM_Q1, 3))
# Out:
# [[-0.045+0.j     0.04 +0.107j  0.111+0.015j  0.039+0.048j -0.105+0.055j]
#  [ 0.04 -0.107j  0.197+0.j     0.013+0.052j -0.068-0.01j   0.045-0.036j]
#  [ 0.111-0.015j  0.013-0.052j -0.548+0.j    -0.097-0.109j  0.255-0.163j]
#  [ 0.039-0.048j -0.068+0.01j  -0.097+0.109j -0.18 +0.j    -0.018-0.138j]
#  [-0.105-0.055j  0.045+0.036j  0.255+0.163j -0.018+0.138j -1.037-0.j   ]]

# %%
for row in EM_Q1 - Q1:
    print(" ".join(f"{x:.3f}" for x in row))
# Out:
# 0.045+0.000j -0.040-0.107j -0.111-0.015j -0.039-0.048j 0.105-0.055j
# -0.040+0.107j -0.197+0.000j -0.013-0.052j 0.068+0.010j -0.045+0.036j
# -0.111+0.015j -0.013+0.052j 0.548+0.000j 0.097+0.109j -0.255+0.163j
# -0.039+0.048j 0.068-0.010j 0.097-0.109j 0.180+0.000j 0.018+0.138j
# 0.105+0.055j -0.045-0.036j -0.255-0.163j 0.018-0.138j 1.037+0.000j

# %%
for row in Q1:
    print(" ".join(f"{x:.3f}" for x in row))
# Out:
# 0.225+0.000j -0.012-0.041j -0.089+0.034j -0.060-0.015j 0.060+0.009j
# -0.012+0.041j 0.290+0.000j 0.036-0.057j -0.041-0.029j 0.042+0.069j
# -0.089-0.034j 0.036+0.057j 0.117+0.000j 0.097-0.062j -0.087+0.007j
# -0.060+0.015j -0.041+0.029j 0.097+0.062j 0.386+0.000j -0.083-0.152j
# 0.060-0.009j 0.042-0.069j -0.087-0.007j -0.083+0.152j 0.182-0.000j

# %%
for row in EM_Q1:
    print(" ".join(f"{x:.3f}" for x in row))
# Out:
# 0.270+0.000j -0.052-0.148j -0.200+0.019j -0.099-0.062j 0.165-0.047j
# -0.052+0.148j 0.093+0.000j 0.023-0.109j 0.028-0.019j -0.003+0.104j
# -0.200-0.019j 0.023+0.109j 0.664+0.000j 0.194+0.047j -0.342+0.170j
# -0.099+0.062j 0.028+0.019j 0.194-0.047j 0.566+0.000j -0.065-0.014j
# 0.165+0.047j -0.003-0.104j -0.342-0.170j -0.065+0.014j 1.219+0.000j

# %%
EM_theta1_deg
# Out:
# array([28.63613617])

# %%
theta1_deg
# Out:
# array([28.64788976])
