# %%
import numpy as np
import matplotlib.pyplot as plt
from sensors import *
from functools import partial

# %% [markdown]
# # Case 1

# %% [markdown]
# Имеется 5 датчиков, 1 источник (дисперсия сигнала 0.7), и шум на каждом датчике имеет дисперсию 4.1.

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
theta1_deg = rad_to_deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
GS_1 = np.array([[0.7]]) # Ковариация сигнала
GN_1 = 4.1*np.eye(5, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s1 = CN(Num_emitters1, sample_size1, GS_1)
n1 = CN(Num_sensors1, sample_size1, GN_1)
X1 = (A1 @ s1.T + n1.T).T

# %% [markdown]
# ## ML1

# %%
theta_ML1_Case1, ML1_func_val_Case1 = multi_start_ML1(X1, L=Num_sensors1, M=Num_emitters1, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML1_Case1
# Out:
# array([0.5120428])

# %% [markdown]
# ## ML2

# %%
theta_ML2_Case1, ML2_func_val_Case1 = multi_start_ML2(X1, GS_1, GN_1, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML2_Case1
# Out:
# array([0.5120428])

# %% [markdown]
# ## EM

# %%
EM_theta1_rad, neglhd_1, K1, mu1 = multi_start_EM(X1, GS_1, GN_1, 10, max_iter=50, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[-2.04739902], -likelihood = -76.14479
# Iteration=2, theta_new=[-2.03580242], -likelihood = -76.42059
# Iteration=3, theta_new=[-2.02466913], -likelihood = -76.66261
# Iteration=4, theta_new=[-2.01409102], -likelihood = -76.87475
# Iteration=5, theta_new=[-2.0040599], -likelihood = -77.05813
# Iteration=6, theta_new=[-1.99456802], -likelihood = -77.21588
# Iteration=7, theta_new=[-1.98570544], -likelihood = -77.35098
# Iteration=8, theta_new=[-1.97736703], -likelihood = -77.46500
# Iteration=9, theta_new=[-1.96954638], -likelihood = -77.56186
# Iteration=10, theta_new=[-1.96223752], -likelihood = -77.64381
# Iteration=11, theta_new=[-1.95543484], -likelihood = -77.71285
# Iteration=12, theta_new=[-1.94903767], -likelihood = -77.77076
# Iteration=13, theta_new=[-1.94313726], -likelihood = -77.81982
# Iteration=14, theta_new=[-1.93763423], -likelihood = -77.86058
# Iteration=15, theta_new=[-1.93252524], -likelihood = -77.89483
# Iteration=16, theta_new=[-1.92780716], -likelihood = -77.92348
# Iteration=17, theta_new=[-1.92347712], -likelihood = -77.94733
# Iteration=18, theta_new=[-1.91943857], -likelihood = -77.96707
# Iteration=19, theta_new=[-1.91578339], -likelihood = -77.98369
# Iteration=20, theta_new=[-1.9124158], -likelihood = -77.99728
# Iteration=21, theta_new=[-1.90924089], -likelihood = -78.00861
# Iteration=22, theta_new=[-1.90635093], -likelihood = -78.01827
# Iteration=23, theta_new=[-1.90374459], -likelihood = -78.02621
# Iteration=24, theta_new=[-1.90132773], -likelihood = -78.03271
# Iteration=25, theta_new=[-1.89909961], -likelihood = -78.03818
# Iteration=26, theta_new=[-1.89705956], -likelihood = -78.04275
# Iteration=27, theta_new=[-1.89520696], -likelihood = -78.04654
# Iteration=28, theta_new=[-1.89344872], -likelihood = -78.04968
# Iteration=29, theta_new=[-1.89187701], -likelihood = -78.05238
# Iteration=30, theta_new=[-1.89039898], -likelihood = -78.05458
# Iteration=31, theta_new=[-1.88901441], -likelihood = -78.05645
# Iteration=32, theta_new=[-1.88781533], -likelihood = -78.05805
# Iteration=33, theta_new=[-1.88670918], -likelihood = -78.05930
# Iteration=34, theta_new=[-1.88569581], -likelihood = -78.06035
# Iteration=35, theta_new=[-1.88477506], -likelihood = -78.06123
# Iteration=36, theta_new=[-1.88394679], -likelihood = -78.06196
# Iteration=37, theta_new=[-1.88311889], -likelihood = -78.06256
# Iteration=38, theta_new=[-1.88238329], -likelihood = -78.06311
# Iteration=39, theta_new=[-1.8817399], -likelihood = -78.06355
# Iteration=40, theta_new=[-1.88109673], -likelihood = -78.06390
# Iteration=41, theta_new=[-1.88054563], -likelihood = -78.06422
# Iteration=42, theta_new=[-1.87999469], -likelihood = -78.06447
# Iteration=43, theta_new=[-1.8795357], -likelihood = -78.06469
# Iteration=44, theta_new=[-1.87907683], -likelihood = -78.06487
# Iteration=45, theta_new=[-1.87870982], -likelihood = -78.06502
# Iteration=46, theta_new=[-1.87834289], -likelihood = -78.06513
# Iteration=47, theta_new=[-1.87806774], -likelihood = -78.06524
# Iteration=48, theta_new=[-1.87779263], -likelihood = -78.06531
# Iteration=49, theta_new=[-1.87751757], -likelihood = -78.06537
# Iteration=50, theta_new=[-1.87724254], -likelihood = -78.06543
# 1-th start
# Iteration=1, theta_new=[0.68690225], -likelihood = -115.67916
# Iteration=2, theta_new=[0.65919809], -likelihood = -122.84731
# Iteration=3, theta_new=[0.63518628], -likelihood = -128.90429
# Iteration=4, theta_new=[0.61477844], -likelihood = -133.72561
# Iteration=5, theta_new=[0.59754783], -likelihood = -137.38682
# Iteration=6, theta_new=[0.58313433], -likelihood = -140.09291
# Iteration=7, theta_new=[0.57111857], -likelihood = -142.04524
# Iteration=8, theta_new=[0.56113515], -likelihood = -143.43428
# Iteration=9, theta_new=[0.5528606], -likelihood = -144.41208
# Iteration=10, theta_new=[0.54594984], -likelihood = -145.09538
# Iteration=11, theta_new=[0.54024509], -likelihood = -145.57471
# Iteration=12, theta_new=[0.53549684], -likelihood = -145.90620
# Iteration=13, theta_new=[0.53157475], -likelihood = -146.13704
# Iteration=14, theta_new=[0.52830432], -likelihood = -146.29643
# Iteration=15, theta_new=[0.52556993], -likelihood = -146.40748
# Iteration=16, theta_new=[0.52331162], -likelihood = -146.48495
# Iteration=17, theta_new=[0.52142075], -likelihood = -146.53833
# Iteration=18, theta_new=[0.51984223], -likelihood = -146.57560
# Iteration=19, theta_new=[0.51852232], -likelihood = -146.60152
# Iteration=20, theta_new=[0.51745894], -likelihood = -146.61955
# Iteration=21, theta_new=[0.51654935], -likelihood = -146.63167
# Iteration=22, theta_new=[0.51579268], -likelihood = -146.64032
# Iteration=23, theta_new=[0.51518824], -likelihood = -146.64631
# Iteration=24, theta_new=[0.51468512], -likelihood = -146.65030
# Iteration=25, theta_new=[0.51423276], -likelihood = -146.65310
# Iteration=26, theta_new=[0.51388124], -likelihood = -146.65520
# Iteration=27, theta_new=[0.51358014], -likelihood = -146.65656
# Iteration=28, theta_new=[0.51332936], -likelihood = -146.65753
# Iteration=29, theta_new=[0.51312884], -likelihood = -146.65821
# Iteration=30, theta_new=[0.5129284], -likelihood = -146.65867
# Iteration=31, theta_new=[0.51277813], -likelihood = -146.65905
# Iteration=32, theta_new=[0.51267798], -likelihood = -146.65928
# Iteration=33, theta_new=[0.51257785], -likelihood = -146.65942
# Iteration=34, theta_new=[0.51247773], -likelihood = -146.65953
# Iteration=35, theta_new=[0.51242769], -likelihood = -146.65962
# Iteration=36, theta_new=[0.51237765], -likelihood = -146.65966
# Iteration=37, theta_new=[0.51232761], -likelihood = -146.65970
# Iteration=38, theta_new=[0.51227758], -likelihood = -146.65973
# Iteration=39, theta_new=[0.51222755], -likelihood = -146.65975
# Iteration=40, theta_new=[0.51217753], -likelihood = -146.65977
# norm=0.0
# Iteration=41, theta_new=[0.51217753], -likelihood = -146.65979
# 2-th start
# Iteration=1, theta_new=[0.25932856], -likelihood = -95.50722
# Iteration=2, theta_new=[0.28146266], -likelihood = -100.31424
# Iteration=3, theta_new=[0.30438647], -likelihood = -105.81639
# Iteration=4, theta_new=[0.32739381], -likelihood = -111.76308
# Iteration=5, theta_new=[0.34977425], -likelihood = -117.79017
# Iteration=6, theta_new=[0.37088367], -likelihood = -123.51499
# Iteration=7, theta_new=[0.39029711], -likelihood = -128.62258
# Iteration=8, theta_new=[0.40775376], -likelihood = -132.94263
# Iteration=9, theta_new=[0.42328344], -likelihood = -136.43246
# Iteration=10, theta_new=[0.43684174], -likelihood = -139.16873
# Iteration=11, theta_new=[0.44853067], -likelihood = -141.24263
# Iteration=12, theta_new=[0.45851748], -likelihood = -142.77772
# Iteration=13, theta_new=[0.46702513], -likelihood = -143.89500
# Iteration=14, theta_new=[0.47423119], -likelihood = -144.70120
# Iteration=15, theta_new=[0.48034432], -likelihood = -145.27722
# Iteration=16, theta_new=[0.48550427], -likelihood = -145.68807
# Iteration=17, theta_new=[0.48986622], -likelihood = -145.97886
# Iteration=18, theta_new=[0.49350195], -likelihood = -146.18453
# Iteration=19, theta_new=[0.49658634], -likelihood = -146.32776
# Iteration=20, theta_new=[0.49910806], -likelihood = -146.42918
# Iteration=21, theta_new=[0.50125267], -likelihood = -146.49838
# Iteration=22, theta_new=[0.50301488], -likelihood = -146.54753
# Iteration=23, theta_new=[0.50448856], -likelihood = -146.58124
# Iteration=24, theta_new=[0.50576949], -likelihood = -146.60482
# Iteration=25, theta_new=[0.5068561], -likelihood = -146.62189
# Iteration=26, theta_new=[0.50774706], -likelihood = -146.63390
# Iteration=27, theta_new=[0.50844125], -likelihood = -146.64204
# Iteration=28, theta_new=[0.50903708], -likelihood = -146.64732
# Iteration=29, theta_new=[0.50953418], -likelihood = -146.65111
# Iteration=30, theta_new=[0.50993226], -likelihood = -146.65375
# Iteration=31, theta_new=[0.51033064], -likelihood = -146.65551
# Iteration=32, theta_new=[0.51062966], -likelihood = -146.65698
# Iteration=33, theta_new=[0.51082913], -likelihood = -146.65788
# Iteration=34, theta_new=[0.51102867], -likelihood = -146.65839
# Iteration=35, theta_new=[0.51122829], -likelihood = -146.65881
# Iteration=36, theta_new=[0.51132814], -likelihood = -146.65916
# Iteration=37, theta_new=[0.51142801], -likelihood = -146.65931
# Iteration=38, theta_new=[0.5115279], -likelihood = -146.65944
# Iteration=39, theta_new=[0.5116278], -likelihood = -146.65955
# Iteration=40, theta_new=[0.51172773], -likelihood = -146.65964
# Iteration=41, theta_new=[0.51182768], -likelihood = -146.65970
# norm=0.0
# Iteration=42, theta_new=[0.51182768], -likelihood = -146.65975
# 3-th start
# Iteration=1, theta_new=[-2.77967859], -likelihood = -74.08339
# Iteration=2, theta_new=[-2.76943124], -likelihood = -74.92198
# Iteration=3, theta_new=[-2.75949212], -likelihood = -75.71663
# Iteration=4, theta_new=[-2.74999289], -likelihood = -76.45579
# Iteration=5, theta_new=[-2.74099633], -likelihood = -77.12623
# Iteration=6, theta_new=[-2.73249764], -likelihood = -77.72324
# Iteration=7, theta_new=[-2.72455898], -likelihood = -78.24909
# Iteration=8, theta_new=[-2.71724205], -likelihood = -78.70372
# Iteration=9, theta_new=[-2.71047548], -likelihood = -79.08925
# Iteration=10, theta_new=[-2.70425515], -likelihood = -79.41564
# Iteration=11, theta_new=[-2.69857727], -likelihood = -79.68910
# Iteration=12, theta_new=[-2.69343838], -likelihood = -79.91579
# Iteration=13, theta_new=[-2.68876958], -likelihood = -80.10165
# Iteration=14, theta_new=[-2.68450273], -likelihood = -80.25433
# Iteration=15, theta_new=[-2.6806359], -likelihood = -80.38022
# Iteration=16, theta_new=[-2.6771673], -likelihood = -80.48295
# Iteration=17, theta_new=[-2.67402999], -likelihood = -80.56584
# Iteration=18, theta_new=[-2.67122278], -likelihood = -80.63325
# Iteration=19, theta_new=[-2.66867938], -likelihood = -80.68745
# Iteration=20, theta_new=[-2.66639902], -likelihood = -80.73155
# Iteration=21, theta_new=[-2.66431589], -likelihood = -80.76706
# Iteration=22, theta_new=[-2.66249458], -likelihood = -80.79615
# Iteration=23, theta_new=[-2.66080452], -likelihood = -80.81897
# Iteration=24, theta_new=[-2.65931042], -likelihood = -80.83797
# Iteration=25, theta_new=[-2.657947], -likelihood = -80.85302
# Iteration=26, theta_new=[-2.65671407], -likelihood = -80.86533
# Iteration=27, theta_new=[-2.65561143], -likelihood = -80.87529
# Iteration=28, theta_new=[-2.65463892], -likelihood = -80.88326
# Iteration=29, theta_new=[-2.65379638], -likelihood = -80.88954
# Iteration=30, theta_new=[-2.6530189], -likelihood = -80.89443
# Iteration=31, theta_new=[-2.65230642], -likelihood = -80.89849
# Iteration=32, theta_new=[-2.65165888], -likelihood = -80.90181
# Iteration=33, theta_new=[-2.65107624], -likelihood = -80.90452
# Iteration=34, theta_new=[-2.65055845], -likelihood = -80.90669
# Iteration=35, theta_new=[-2.65010548], -likelihood = -80.90842
# Iteration=36, theta_new=[-2.64971728], -likelihood = -80.90977
# Iteration=37, theta_new=[-2.64932914], -likelihood = -80.91080
# Iteration=38, theta_new=[-2.64900573], -likelihood = -80.91173
# Iteration=39, theta_new=[-2.64874704], -likelihood = -80.91242
# Iteration=40, theta_new=[-2.64848837], -likelihood = -80.91292
# Iteration=41, theta_new=[-2.64822973], -likelihood = -80.91337
# Iteration=42, theta_new=[-2.64803577], -likelihood = -80.91377
# Iteration=43, theta_new=[-2.64784182], -likelihood = -80.91404
# Iteration=44, theta_new=[-2.64764789], -likelihood = -80.91428
# Iteration=45, theta_new=[-2.64751861], -likelihood = -80.91450
# Iteration=46, theta_new=[-2.64738934], -likelihood = -80.91463
# Iteration=47, theta_new=[-2.64726007], -likelihood = -80.91474
# Iteration=48, theta_new=[-2.64713081], -likelihood = -80.91485
# Iteration=49, theta_new=[-2.64706618], -likelihood = -80.91494
# Iteration=50, theta_new=[-2.64700156], -likelihood = -80.91498
# 4-th start
# Iteration=1, theta_new=[2.00693588], -likelihood = -73.07864
# Iteration=2, theta_new=[1.99850832], -likelihood = -73.17889
# Iteration=3, theta_new=[1.98923789], -likelihood = -73.29816
# Iteration=4, theta_new=[1.97894203], -likelihood = -73.43709
# Iteration=5, theta_new=[1.96773318], -likelihood = -73.59884
# Iteration=6, theta_new=[1.95553093], -likelihood = -73.78139
# Iteration=7, theta_new=[1.94225853], -likelihood = -73.98495
# Iteration=8, theta_new=[1.928033], -likelihood = -74.20890
# Iteration=9, theta_new=[1.91278196], -likelihood = -74.44850
# Iteration=10, theta_new=[1.89653078], -likelihood = -74.70136
# Iteration=11, theta_new=[1.87930643], -likelihood = -74.96285
# Iteration=12, theta_new=[1.86104559], -likelihood = -75.22787
# Iteration=13, theta_new=[1.84178086], -likelihood = -75.49245
# Iteration=14, theta_new=[1.82145652], -likelihood = -75.75114
# Iteration=15, theta_new=[1.79993345], -likelihood = -75.99987
# Iteration=16, theta_new=[1.77708274], -likelihood = -76.23555
# Iteration=17, theta_new=[1.7524396], -likelihood = -76.45487
# Iteration=18, theta_new=[1.72531443], -likelihood = -76.65705
# Iteration=19, theta_new=[1.69422844], -likelihood = -76.84097
# Iteration=20, theta_new=[1.48658619], -likelihood = -77.00626
# Iteration=21, theta_new=[1.57078736], -likelihood = -77.15309
# norm=0.0
# Iteration=22, theta_new=[1.57078736], -likelihood = -77.23370
# 5-th start
# Iteration=1, theta_new=[0.41035905], -likelihood = -133.54225
# Iteration=2, theta_new=[0.42550707], -likelihood = -136.91696
# Iteration=3, theta_new=[0.43872105], -likelihood = -139.52969
# Iteration=4, theta_new=[0.45011752], -likelihood = -141.50559
# Iteration=5, theta_new=[0.45987593], -likelihood = -142.96740
# Iteration=6, theta_new=[0.46822914], -likelihood = -144.03280
# Iteration=7, theta_new=[0.47527087], -likelihood = -144.80431
# Iteration=8, theta_new=[0.48121175], -likelihood = -145.35215
# Iteration=9, theta_new=[0.48619305], -likelihood = -145.74054
# Iteration=10, theta_new=[0.49046623], -likelihood = -146.01378
# Iteration=11, theta_new=[0.49401061], -likelihood = -146.20993
# Iteration=12, theta_new=[0.49700169], -likelihood = -146.34576
# Iteration=13, theta_new=[0.49952553], -likelihood = -146.44142
# Iteration=14, theta_new=[0.50157437], -likelihood = -146.50865
# Iteration=15, theta_new=[0.50333771], -likelihood = -146.55413
# Iteration=16, theta_new=[0.50481234], -likelihood = -146.58676
# Iteration=17, theta_new=[0.50599549], -likelihood = -146.60944
# Iteration=18, theta_new=[0.50698376], -likelihood = -146.62458
# Iteration=19, theta_new=[0.50777592], -likelihood = -146.63515
# Iteration=20, theta_new=[0.50847015], -likelihood = -146.64228
# Iteration=21, theta_new=[0.50906601], -likelihood = -146.64752
# Iteration=22, theta_new=[0.50956315], -likelihood = -146.65128
# Iteration=23, theta_new=[0.50996124], -likelihood = -146.65389
# Iteration=24, theta_new=[0.51026005], -likelihood = -146.65563
# Iteration=25, theta_new=[0.51055903], -likelihood = -146.65675
# Iteration=26, theta_new=[0.51075847], -likelihood = -146.65768
# Iteration=27, theta_new=[0.51095798], -likelihood = -146.65822
# Iteration=28, theta_new=[0.51115757], -likelihood = -146.65867
# Iteration=29, theta_new=[0.51125741], -likelihood = -146.65904
# Iteration=30, theta_new=[0.51135727], -likelihood = -146.65921
# Iteration=31, theta_new=[0.51145714], -likelihood = -146.65935
# Iteration=32, theta_new=[0.51155703], -likelihood = -146.65948
# Iteration=33, theta_new=[0.51165695], -likelihood = -146.65958
# Iteration=34, theta_new=[0.51175688], -likelihood = -146.65966
# norm=0.0
# Iteration=35, theta_new=[0.51175688], -likelihood = -146.65972
# 6-th start
# Iteration=1, theta_new=[2.30625375], -likelihood = -85.25685
# Iteration=2, theta_new=[2.34138809], -likelihood = -90.61396
# Iteration=3, theta_new=[2.37722916], -likelihood = -97.35126
# Iteration=4, theta_new=[2.41205185], -likelihood = -105.05617
# Iteration=5, theta_new=[2.44438135], -likelihood = -113.02465
# Iteration=6, theta_new=[2.47332483], -likelihood = -120.50454
# Iteration=7, theta_new=[2.49856531], -likelihood = -126.96899
# Iteration=8, theta_new=[2.52015935], -likelihood = -132.20555
# Iteration=9, theta_new=[2.53843297], -likelihood = -136.24339
# Iteration=10, theta_new=[2.55374042], -likelihood = -139.25392
# Iteration=11, theta_new=[2.56652159], -likelihood = -141.43939
# Iteration=12, theta_new=[2.57717365], -likelihood = -143.00235
# Iteration=13, theta_new=[2.58604527], -likelihood = -144.10866
# Iteration=14, theta_new=[2.59336903], -likelihood = -144.88642
# Iteration=15, theta_new=[2.59944724], -likelihood = -145.42632
# Iteration=16, theta_new=[2.60452429], -likelihood = -145.80230
# Iteration=17, theta_new=[2.60872103], -likelihood = -146.06521
# Iteration=18, theta_new=[2.61222395], -likelihood = -146.24688
# Iteration=19, theta_new=[2.6151576], -likelihood = -146.37352
# Iteration=20, theta_new=[2.61758377], -likelihood = -146.46196
# Iteration=21, theta_new=[2.61956485], -likelihood = -146.52287
# Iteration=22, theta_new=[2.62122766], -likelihood = -146.56437
# Iteration=23, theta_new=[2.62263555], -likelihood = -146.59346
# Iteration=24, theta_new=[2.62378808], -likelihood = -146.61398
# Iteration=25, theta_new=[2.62474894], -likelihood = -146.62797
# Iteration=26, theta_new=[2.62551791], -likelihood = -146.63769
# Iteration=27, theta_new=[2.6261589], -likelihood = -146.64420
# Iteration=28, theta_new=[2.62673594], -likelihood = -146.64877
# Iteration=29, theta_new=[2.62718484], -likelihood = -146.65220
# Iteration=30, theta_new=[2.62756968], -likelihood = -146.65443
# Iteration=31, theta_new=[2.62789043], -likelihood = -146.65604
# Iteration=32, theta_new=[2.62814706], -likelihood = -146.65716
# Iteration=33, theta_new=[2.62840372], -likelihood = -146.65791
# Iteration=34, theta_new=[2.62859623], -likelihood = -146.65854
# Iteration=35, theta_new=[2.62872458], -likelihood = -146.65893
# Iteration=36, theta_new=[2.62885293], -likelihood = -146.65915
# Iteration=37, theta_new=[2.62898129], -likelihood = -146.65934
# Iteration=38, theta_new=[2.62904548], -likelihood = -146.65949
# Iteration=39, theta_new=[2.62910966], -likelihood = -146.65956
# Iteration=40, theta_new=[2.62917385], -likelihood = -146.65962
# Iteration=41, theta_new=[2.62923804], -likelihood = -146.65967
# Iteration=42, theta_new=[2.62930223], -likelihood = -146.65971
# Iteration=43, theta_new=[2.62936642], -likelihood = -146.65974
# norm=0.0
# Iteration=44, theta_new=[2.62936642], -likelihood = -146.65977
# 7-th start
# Iteration=1, theta_new=[-1.19405622], -likelihood = -77.78379
# Iteration=2, theta_new=[-1.19982827], -likelihood = -77.83059
# Iteration=3, theta_new=[-1.20521812], -likelihood = -77.86946
# Iteration=4, theta_new=[-1.21022025], -likelihood = -77.90217
# Iteration=5, theta_new=[-1.21482948], -likelihood = -77.92954
# Iteration=6, theta_new=[-1.21910037], -likelihood = -77.95227
# Iteration=7, theta_new=[-1.22302911], -likelihood = -77.97128
# Iteration=8, theta_new=[-1.22667192], -likelihood = -77.98707
# Iteration=9, theta_new=[-1.2300261], -likelihood = -78.00029
# Iteration=10, theta_new=[-1.23308915], -likelihood = -78.01129
# Iteration=11, theta_new=[-1.235919], -likelihood = -78.02037
# Iteration=12, theta_new=[-1.23851394], -likelihood = -78.02796
# Iteration=13, theta_new=[-1.24087244], -likelihood = -78.03427
# Iteration=14, theta_new=[-1.24305366], -likelihood = -78.03947
# Iteration=15, theta_new=[-1.24505663], -likelihood = -78.04383
# Iteration=16, theta_new=[-1.24688044], -likelihood = -78.04746
# Iteration=17, theta_new=[-1.24858516], -likelihood = -78.05047
# Iteration=18, theta_new=[-1.25017028], -likelihood = -78.05302
# Iteration=19, theta_new=[-1.25157428], -likelihood = -78.05517
# Iteration=20, theta_new=[-1.25285763], -likelihood = -78.05691
# Iteration=21, theta_new=[-1.25408113], -likelihood = -78.05835
# Iteration=22, theta_new=[-1.25518335], -likelihood = -78.05960
# Iteration=23, theta_new=[-1.25616396], -likelihood = -78.06062
# Iteration=24, theta_new=[-1.257084], -likelihood = -78.06145
# Iteration=25, theta_new=[-1.25794334], -likelihood = -78.06216
# Iteration=26, theta_new=[-1.25874184], -likelihood = -78.06277
# Iteration=27, theta_new=[-1.25941792], -likelihood = -78.06327
# Iteration=28, theta_new=[-1.26009436], -likelihood = -78.06367
# Iteration=29, theta_new=[-1.26070964], -likelihood = -78.06402
# Iteration=30, theta_new=[-1.26126367], -likelihood = -78.06432
# Iteration=31, theta_new=[-1.26175635], -likelihood = -78.06456
# Iteration=32, theta_new=[-1.26218761], -likelihood = -78.06476
# Iteration=33, theta_new=[-1.26261902], -likelihood = -78.06491
# Iteration=34, theta_new=[-1.26298893], -likelihood = -78.06505
# Iteration=35, theta_new=[-1.26335895], -likelihood = -78.06516
# Iteration=36, theta_new=[-1.26366738], -likelihood = -78.06526
# Iteration=37, theta_new=[-1.2639759], -likelihood = -78.06534
# Iteration=38, theta_new=[-1.26422277], -likelihood = -78.06541
# Iteration=39, theta_new=[-1.26446969], -likelihood = -78.06546
# Iteration=40, theta_new=[-1.26465491], -likelihood = -78.06551
# Iteration=41, theta_new=[-1.26484016], -likelihood = -78.06554
# Iteration=42, theta_new=[-1.26502544], -likelihood = -78.06557
# Iteration=43, theta_new=[-1.26521075], -likelihood = -78.06559
# Iteration=44, theta_new=[-1.26533431], -likelihood = -78.06562
# Iteration=45, theta_new=[-1.26545787], -likelihood = -78.06563
# Iteration=46, theta_new=[-1.26558145], -likelihood = -78.06565
# Iteration=47, theta_new=[-1.26570504], -likelihood = -78.06566
# Iteration=48, theta_new=[-1.26582865], -likelihood = -78.06567
# Iteration=49, theta_new=[-1.26595226], -likelihood = -78.06568
# Iteration=50, theta_new=[-1.26601408], -likelihood = -78.06569
# 8-th start
# Iteration=1, theta_new=[1.33606763], -likelihood = -75.93798
# Iteration=2, theta_new=[1.35857463], -likelihood = -76.17706
# Iteration=3, theta_new=[1.38272117], -likelihood = -76.40091
# Iteration=4, theta_new=[1.4091198], -likelihood = -76.60761
# Iteration=5, theta_new=[1.43898103], -likelihood = -76.79618
# Iteration=6, theta_new=[1.47537713], -likelihood = -76.96619
# Iteration=7, theta_new=[1.53437781], -likelihood = -77.11780
# Iteration=8, theta_new=[1.57078932], -likelihood = -77.22438
# norm=0.0
# Iteration=9, theta_new=[1.57078932], -likelihood = -77.23370
# 9-th start
# Iteration=1, theta_new=[-2.26382315], -likelihood = -69.48564
# Iteration=2, theta_new=[-2.2565829], -likelihood = -69.64493
# Iteration=3, theta_new=[-2.24870469], -likelihood = -69.83332
# Iteration=4, theta_new=[-2.24014029], -likelihood = -70.05290
# Iteration=5, theta_new=[-2.23084283], -likelihood = -70.30688
# Iteration=6, theta_new=[-2.22087593], -likelihood = -70.59813
# Iteration=7, theta_new=[-2.21019447], -likelihood = -70.92523
# Iteration=8, theta_new=[-2.19886291], -likelihood = -71.28920
# Iteration=9, theta_new=[-2.18694524], -likelihood = -71.68625
# Iteration=10, theta_new=[-2.17450486], -likelihood = -72.11126
# Iteration=11, theta_new=[-2.16165744], -likelihood = -72.55797
# Iteration=12, theta_new=[-2.14846373], -likelihood = -73.01741
# Iteration=13, theta_new=[-2.13503583], -likelihood = -73.48216
# Iteration=14, theta_new=[-2.12153548], -likelihood = -73.94307
# Iteration=15, theta_new=[-2.10801691], -likelihood = -74.38993
# Iteration=16, theta_new=[-2.09463594], -likelihood = -74.81718
# Iteration=17, theta_new=[-2.08149333], -likelihood = -75.21729
# Iteration=18, theta_new=[-2.06863645], -likelihood = -75.58602
# Iteration=19, theta_new=[-2.05621251], -likelihood = -75.92195
# Iteration=20, theta_new=[-2.04421459], -likelihood = -76.22231
# Iteration=21, theta_new=[-2.03273585], -likelihood = -76.48919
# Iteration=22, theta_new=[-2.02171858], -likelihood = -76.72301
# Iteration=23, theta_new=[-2.0112546], -likelihood = -76.92768
# Iteration=24, theta_new=[-2.00133582], -likelihood = -77.10431
# Iteration=25, theta_new=[-1.99205228], -likelihood = -77.25605
# Iteration=26, theta_new=[-1.98329814], -likelihood = -77.38453
# Iteration=27, theta_new=[-1.97506668], -likelihood = -77.49398
# Iteration=28, theta_new=[-1.96735158], -likelihood = -77.58685
# Iteration=29, theta_new=[-1.96014692], -likelihood = -77.66530
# Iteration=30, theta_new=[-1.9534472], -likelihood = -77.73129
# Iteration=31, theta_new=[-1.94724729], -likelihood = -77.78656
# Iteration=32, theta_new=[-1.94144739], -likelihood = -77.83264
# Iteration=33, theta_new=[-1.93613874], -likelihood = -77.87148
# Iteration=34, theta_new=[-1.93122276], -likelihood = -77.90353
# Iteration=35, theta_new=[-1.92660216], -likelihood = -77.93031
# Iteration=36, theta_new=[-1.92236891], -likelihood = -77.95303
# Iteration=37, theta_new=[-1.91842655], -likelihood = -77.97180
# Iteration=38, theta_new=[-1.91486697], -likelihood = -77.98759
# Iteration=39, theta_new=[-1.91150099], -likelihood = -78.00047
# Iteration=40, theta_new=[-1.90842093], -likelihood = -78.01149
# Iteration=41, theta_new=[-1.9056254], -likelihood = -78.02060
# Iteration=42, theta_new=[-1.90302005], -likelihood = -78.02809
# Iteration=43, theta_new=[-1.90060411], -likelihood = -78.03440
# Iteration=44, theta_new=[-1.89837683], -likelihood = -78.03971
# Iteration=45, theta_new=[-1.89633756], -likelihood = -78.04413
# Iteration=46, theta_new=[-1.89448567], -likelihood = -78.04780
# Iteration=47, theta_new=[-1.8928206], -likelihood = -78.05082
# Iteration=48, theta_new=[-1.89124941], -likelihood = -78.05328
# Iteration=49, theta_new=[-1.88986421], -likelihood = -78.05540
# Iteration=50, theta_new=[-1.88857231], -likelihood = -78.05709

# %%
EM_theta1_rad
# Out:
# array([0.51217753])

# %% [markdown]
# ## True result

# %%
theta1_rad
# Out:
# [0.5]

# %% [markdown]
# # Case 2

# %% [markdown]
# Имеется 5 датчиков, 2 источника (дисперсии сигналов - 2 и 3), и шум на каждом датчике имеет дисперсию 7.1.

# %%
Num_sensors2 = 5
Num_emitters2 = 2
sample_size2 = 100
theta2_rad = np.array([0.34906585, 1.22173048]) # Направление прибытия (DOA) в радианах
theta2_deg = rad_to_deg(theta2_rad) # Направление прибытия (DOA) в градусах
GS_2 = np.array([[2,0],[0,3]]) # Ковариация сигнала
GN_2 = 7.1*np.eye(5, dtype=np.float64) # Ковариация шума
A2 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors2).reshape(-1,1) * np.sin(theta2_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s2 = CN(Num_emitters2, sample_size2, GS_2)
n2 = CN(Num_sensors2, sample_size2, GN_2)
X2 = (A2 @ s2.T + n2.T).T

# %% [markdown]
# ## ML1

# %%
theta_ML1_Case2, ML1_func_val_Case2 = multi_start_ML1(X2, L=Num_sensors2, M=Num_emitters2, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML1_Case2
# Out:
# array([0.32881681, 1.23455554])

# %% [markdown]
# ## ML2

# %%
theta_ML2_Case2, ML2_func_val_Case2 = multi_start_ML2(X2, GS_2, GN_2, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML2_Case2
# Out:
# array([0.32583368, 1.24079361])

# %% [markdown]
# ## EM

# %%
EM_theta2_rad, neglhd_2, K2, mu2 = multi_start_EM(X2, GS_2, GN_2, 30, max_iter=20, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[ 1.27155015 -1.90030329], -likelihood = -304.25906
# Iteration=2, theta_new=[ 1.17114855 -1.93488894], -likelihood = -332.39634
# Iteration=3, theta_new=[ 1.11405981 -1.95796297], -likelihood = -352.22894
# Iteration=4, theta_new=[ 1.07808204 -1.96993502], -likelihood = -362.24368
# Iteration=5, theta_new=[ 1.05360696 -1.97450179], -likelihood = -367.19982
# Iteration=6, theta_new=[ 1.03600897 -1.97436414], -likelihood = -369.82559
# Iteration=7, theta_new=[ 1.02263785 -1.97119983], -likelihood = -371.33267
# Iteration=8, theta_new=[ 1.01202594 -1.96620075], -likelihood = -372.27781
# Iteration=9, theta_new=[ 1.00319541 -1.96004483], -likelihood = -372.92092
# Iteration=10, theta_new=[ 0.99560349 -1.9531671 ], -likelihood = -373.39519
# Iteration=11, theta_new=[ 0.98886782 -1.94597964], -likelihood = -373.76619
# Iteration=12, theta_new=[ 0.98276056 -1.93857289], -likelihood = -374.07421
# Iteration=13, theta_new=[ 0.97714068 -1.93120617], -likelihood = -374.33884
# Iteration=14, theta_new=[ 0.97181766 -1.92390442], -likelihood = -374.57412
# Iteration=15, theta_new=[ 0.9668349  -1.91676791], -likelihood = -374.79258
# Iteration=16, theta_new=[ 0.96203345 -1.90974823], -likelihood = -374.99348
# Iteration=17, theta_new=[ 0.95744667 -1.9028945 ], -likelihood = -375.18582
# Iteration=18, theta_new=[ 0.95305228 -1.89629316], -likelihood = -375.36851
# Iteration=19, theta_new=[ 0.9487999  -1.88985029], -likelihood = -375.54406
# Iteration=20, theta_new=[ 0.94462068 -1.88363507], -likelihood = -375.71441
# 1-th start
# Iteration=1, theta_new=[-0.03271819  0.335077  ], -likelihood = -314.55491
# Iteration=2, theta_new=[-0.02569564  0.33584223], -likelihood = -315.17148
# Iteration=3, theta_new=[-0.01932375  0.33683443], -likelihood = -315.68437
# Iteration=4, theta_new=[-0.01353887  0.33802253], -likelihood = -316.11589
# Iteration=5, theta_new=[-0.00829885  0.33938655], -likelihood = -316.48112
# Iteration=6, theta_new=[-0.00351479  0.34083962], -likelihood = -316.79159
# Iteration=7, theta_new=[0.00084689 0.34228947], -likelihood = -317.05739
# Iteration=8, theta_new=[0.00487483 0.34375751], -likelihood = -317.28361
# Iteration=9, theta_new=[0.00858267 0.34525872], -likelihood = -317.47915
# Iteration=10, theta_new=[0.01206216 0.34667174], -likelihood = -317.64844
# Iteration=11, theta_new=[0.01526878 0.34809776], -likelihood = -317.79482
# Iteration=12, theta_new=[0.01834517 0.34946229], -likelihood = -317.92152
# Iteration=13, theta_new=[0.02116947 0.35078166], -likelihood = -318.03304
# Iteration=14, theta_new=[0.0238262 0.3520959], -likelihood = -318.12813
# Iteration=15, theta_new=[0.02632193 0.35330751], -likelihood = -318.21133
# Iteration=16, theta_new=[0.02869188 0.3545092 ], -likelihood = -318.28225
# Iteration=17, theta_new=[0.0308717  0.35559155], -likelihood = -318.34438
# Iteration=18, theta_new=[0.03294752 0.35664889], -likelihood = -318.39590
# Iteration=19, theta_new=[0.03490597 0.35765427], -likelihood = -318.44070
# Iteration=20, theta_new=[0.0367969  0.35864392], -likelihood = -318.47890
# 2-th start
# Iteration=1, theta_new=[-1.52040087 -0.46500672], -likelihood = -355.56277
# Iteration=2, theta_new=[-1.57077916 -0.46467805], -likelihood = -359.77852
# Iteration=3, theta_new=[-1.57077822 -0.46430663], -likelihood = -359.93717
# Iteration=4, theta_new=[-1.57077728 -0.46393551], -likelihood = -359.94068
# Iteration=5, theta_new=[-1.57080123 -0.46358147], -likelihood = -359.94422
# Iteration=6, theta_new=[-1.57076733 -0.46320804], -likelihood = -359.94763
# Iteration=7, theta_new=[-1.57082347 -0.46284752], -likelihood = -359.95126
# Iteration=8, theta_new=[-1.57081091 -0.46248266], -likelihood = -359.95481
# Iteration=9, theta_new=[-1.57080561 -0.46211904], -likelihood = -359.95843
# Iteration=10, theta_new=[-1.57084096 -0.46175326], -likelihood = -359.96207
# Iteration=11, theta_new=[-1.57083758 -0.46138056], -likelihood = -359.96577
# Iteration=12, theta_new=[-1.57082959 -0.46100077], -likelihood = -359.96957
# Iteration=13, theta_new=[-1.57076681 -0.46061106], -likelihood = -359.97349
# Iteration=14, theta_new=[-1.57078957 -0.46023666], -likelihood = -359.97754
# Iteration=15, theta_new=[-1.5708327  -0.45984698], -likelihood = -359.98147
# Iteration=16, theta_new=[-1.57080588 -0.45947478], -likelihood = -359.98560
# Iteration=17, theta_new=[-1.57081156 -0.45909125], -likelihood = -359.98959
# Iteration=18, theta_new=[-1.57081723 -0.45870805], -likelihood = -359.99373
# Iteration=19, theta_new=[-1.57081609 -0.45830849], -likelihood = -359.99790
# Iteration=20, theta_new=[-1.57080281 -0.45790384], -likelihood = -360.00229
# 3-th start
# Iteration=1, theta_new=[-1.98722523  0.66697439], -likelihood = -340.24026
# Iteration=2, theta_new=[-1.9245209   0.66462126], -likelihood = -356.81774
# Iteration=3, theta_new=[-1.86291086  0.65837863], -likelihood = -368.78558
# Iteration=4, theta_new=[-1.79979798  0.64754   ], -likelihood = -377.78955
# Iteration=5, theta_new=[-1.72829866  0.63179789], -likelihood = -385.46984
# Iteration=6, theta_new=[-1.60388554  0.611222  ], -likelihood = -393.17347
# Iteration=7, theta_new=[-1.57077517  0.58720058], -likelihood = -400.78003
# Iteration=8, theta_new=[-1.57077254  0.56090199], -likelihood = -408.01570
# Iteration=9, theta_new=[-1.57082072  0.53329915], -likelihood = -416.91817
# Iteration=10, theta_new=[-1.57081477  0.5056636 ], -likelihood = -427.15150
# Iteration=11, theta_new=[-1.5707737   0.47924842], -likelihood = -437.90937
# Iteration=12, theta_new=[-1.57077913  0.45505145], -likelihood = -448.20751
# Iteration=13, theta_new=[-1.57079203  0.43357823], -likelihood = -457.22766
# Iteration=14, theta_new=[-1.57080261  0.41497747], -likelihood = -464.57792
# Iteration=15, theta_new=[-1.57072725  0.39915746], -likelihood = -470.23638
# Iteration=16, theta_new=[-1.57082212  0.38583309], -likelihood = -474.40862
# Iteration=17, theta_new=[-1.57079177  0.37470915], -likelihood = -477.39999
# Iteration=18, theta_new=[-1.57077174  0.36547459], -likelihood = -479.49760
# Iteration=19, theta_new=[-1.57078606  0.3578239 ], -likelihood = -480.94591
# Iteration=20, theta_new=[-1.57079336  0.35149397], -likelihood = -481.93637
# 4-th start
# Iteration=1, theta_new=[0.76956173 2.0587528 ], -likelihood = -314.94400
# Iteration=2, theta_new=[0.71973485 2.01051703], -likelihood = -365.34117
# Iteration=3, theta_new=[0.67959877 1.97774544], -likelihood = -387.51641
# Iteration=4, theta_new=[0.64403015 1.95552982], -likelihood = -400.81215
# Iteration=5, theta_new=[0.61062799 1.94113666], -likelihood = -411.31338
# Iteration=6, theta_new=[0.57850685 1.93224426], -likelihood = -421.20383
# Iteration=7, theta_new=[0.54759973 1.92704656], -likelihood = -431.26534
# Iteration=8, theta_new=[0.51826993 1.92407528], -likelihood = -441.56892
# Iteration=9, theta_new=[0.4910523  1.92214882], -likelihood = -451.77568
# Iteration=10, theta_new=[0.4663644  1.92052796], -likelihood = -461.36188
# Iteration=11, theta_new=[0.44445575 1.9187563 ], -likelihood = -469.86322
# Iteration=12, theta_new=[0.42527956 1.91681565], -likelihood = -476.99845
# Iteration=13, theta_new=[0.40874734 1.91466497], -likelihood = -482.73088
# Iteration=14, theta_new=[0.39461302 1.91246982], -likelihood = -487.15582
# Iteration=15, theta_new=[0.38264321 1.91029629], -likelihood = -490.47429
# Iteration=16, theta_new=[0.37256041 1.90821896], -likelihood = -492.90079
# Iteration=17, theta_new=[0.36412435 1.90627727], -likelihood = -494.64428
# Iteration=18, theta_new=[0.35706427 1.90454283], -likelihood = -495.87737
# Iteration=19, theta_new=[0.35111476 1.90297086], -likelihood = -496.74328
# Iteration=20, theta_new=[0.34614623 1.90156581], -likelihood = -497.35167
# 5-th start
# Iteration=1, theta_new=[ 1.91628773 -1.36486318], -likelihood = -311.33887
# Iteration=2, theta_new=[ 2.00613084 -1.30612265], -likelihood = -331.71412
# Iteration=3, theta_new=[ 2.06158709 -1.26700865], -likelihood = -351.13455
# Iteration=4, theta_new=[ 2.09695281 -1.24493267], -likelihood = -362.14064
# Iteration=5, theta_new=[ 2.12080717 -1.23347052], -likelihood = -367.71567
# Iteration=6, theta_new=[ 2.13776265 -1.2285331 ], -likelihood = -370.65142
# Iteration=7, theta_new=[ 2.15041083 -1.22771198], -likelihood = -372.31230
# Iteration=8, theta_new=[ 2.16029375 -1.22950407], -likelihood = -373.32781
# Iteration=9, theta_new=[ 2.1683662  -1.23285196], -likelihood = -373.99978
# Iteration=10, theta_new=[ 2.17517486 -1.23723663], -likelihood = -374.48152
# Iteration=11, theta_new=[ 2.18111374 -1.24232078], -likelihood = -374.84726
# Iteration=12, theta_new=[ 2.18648007 -1.24771767], -likelihood = -375.14089
# Iteration=13, theta_new=[ 2.19133591 -1.25331156], -likelihood = -375.39247
# Iteration=14, theta_new=[ 2.19587429 -1.25896643], -likelihood = -375.61015
# Iteration=15, theta_new=[ 2.20019202 -1.26457939], -likelihood = -375.80864
# Iteration=16, theta_new=[ 2.20430604 -1.2702176 ], -likelihood = -375.99555
# Iteration=17, theta_new=[ 2.20828661 -1.27576142], -likelihood = -376.17148
# Iteration=18, theta_new=[ 2.21210993 -1.28116047], -likelihood = -376.34216
# Iteration=19, theta_new=[ 2.21583128 -1.28647468], -likelihood = -376.50687
# Iteration=20, theta_new=[ 2.21942402 -1.2917797 ], -likelihood = -376.66825
# 6-th start
# Iteration=1, theta_new=[ 2.89831057 -1.57078488], -likelihood = -473.36072
# Iteration=2, theta_new=[ 2.88511529 -1.57082673], -likelihood = -477.87667
# Iteration=3, theta_new=[ 2.87410297 -1.570825  ], -likelihood = -481.00924
# Iteration=4, theta_new=[ 2.86495499 -1.57075509], -likelihood = -483.21899
# Iteration=5, theta_new=[ 2.85735749 -1.57079725], -likelihood = -484.76623
# Iteration=6, theta_new=[ 2.85106441 -1.57078726], -likelihood = -485.84830
# Iteration=7, theta_new=[ 2.84585369 -1.57077695], -likelihood = -486.60332
# Iteration=8, theta_new=[ 2.84154004 -1.57080218], -likelihood = -487.13079
# Iteration=9, theta_new=[ 2.8379761  -1.57075718], -likelihood = -487.50015
# Iteration=10, theta_new=[ 2.83502643 -1.57084158], -likelihood = -487.75917
# Iteration=11, theta_new=[ 2.83259152 -1.57076039], -likelihood = -487.94190
# Iteration=12, theta_new=[ 2.83058677 -1.57082989], -likelihood = -488.07114
# Iteration=13, theta_new=[ 2.82893315 -1.57076264], -likelihood = -488.16286
# Iteration=14, theta_new=[ 2.82756772 -1.57076737], -likelihood = -488.22854
# Iteration=15, theta_new=[ 2.82642643 -1.57075429], -likelihood = -488.27598
# Iteration=16, theta_new=[ 2.82549873 -1.57083432], -likelihood = -488.31091
# Iteration=17, theta_new=[ 2.82473338 -1.57077999], -likelihood = -488.33614
# Iteration=18, theta_new=[ 2.8240935  -1.57078908], -likelihood = -488.35482
# Iteration=19, theta_new=[ 2.82356078 -1.57078282], -likelihood = -488.36896
# Iteration=20, theta_new=[ 2.82313575 -1.57080557], -likelihood = -488.37970
# 7-th start
# Iteration=1, theta_new=[-2.19353792 -0.34954956], -likelihood = -226.17810
# Iteration=2, theta_new=[-2.13183268 -0.36075879], -likelihood = -245.23526
# Iteration=3, theta_new=[-2.06236701 -0.37002454], -likelihood = -268.77451
# Iteration=4, theta_new=[-1.98771019 -0.37683998], -likelihood = -293.84889
# Iteration=5, theta_new=[-1.90930069 -0.38131829], -likelihood = -316.87057
# Iteration=6, theta_new=[-1.82572396 -0.3838999 ], -likelihood = -335.46260
# Iteration=7, theta_new=[-1.72752806 -0.38509509], -likelihood = -349.07923
# Iteration=8, theta_new=[-1.5708079  -0.38547508], -likelihood = -358.23561
# Iteration=9, theta_new=[-1.5708161  -0.38561925], -likelihood = -361.12135
# Iteration=10, theta_new=[-1.57082429 -0.38576347], -likelihood = -361.11937
# Iteration=11, theta_new=[-1.57079287 -0.38588934], -likelihood = -361.11739
# Iteration=12, theta_new=[-1.57076145 -0.38601525], -likelihood = -361.11566
# Iteration=13, theta_new=[-1.57077845 -0.38613691], -likelihood = -361.11393
# Iteration=14, theta_new=[-1.57078752 -0.38625371], -likelihood = -361.11225
# Iteration=15, theta_new=[-1.57086087 -0.38636062], -likelihood = -361.11063
# Iteration=16, theta_new=[-1.57083833 -0.38647667], -likelihood = -361.10915
# Iteration=17, theta_new=[-1.57083537 -0.38660564], -likelihood = -361.10754
# Iteration=18, theta_new=[-1.57083242 -0.38673464], -likelihood = -361.10574
# Iteration=19, theta_new=[-1.57083655 -0.38684939], -likelihood = -361.10394
# Iteration=20, theta_new=[-1.57084069 -0.38696416], -likelihood = -361.10234
# 8-th start
# Iteration=1, theta_new=[ 2.65442058 -2.25658352], -likelihood = -275.98209
# Iteration=2, theta_new=[ 2.68101796 -2.20070844], -likelihood = -303.70649
# Iteration=3, theta_new=[ 2.70447935 -2.13597786], -likelihood = -336.91010
# Iteration=4, theta_new=[ 2.72468832 -2.06581834], -likelihood = -372.46510
# Iteration=5, theta_new=[ 2.74169354 -1.99330441], -likelihood = -405.97686
# Iteration=6, theta_new=[ 2.75585361 -1.91998353], -likelihood = -433.95188
# Iteration=7, theta_new=[ 2.76754005 -1.84510941], -likelihood = -455.17166
# Iteration=8, theta_new=[ 2.77713552 -1.76450161], -likelihood = -470.21733
# Iteration=9, theta_new=[ 2.78498036 -1.65700016], -likelihood = -480.38914
# Iteration=10, theta_new=[ 2.79128845 -1.57083059], -likelihood = -486.19938
# Iteration=11, theta_new=[ 2.79645417 -1.57083538], -likelihood = -487.30428
# Iteration=12, theta_new=[ 2.80073471 -1.57075975], -likelihood = -487.70182
# Iteration=13, theta_new=[ 2.80426622 -1.57075293], -likelihood = -487.96703
# Iteration=14, theta_new=[ 2.80718072 -1.57079321], -likelihood = -488.14162
# Iteration=15, theta_new=[ 2.80960275 -1.57083356], -likelihood = -488.25540
# Iteration=16, theta_new=[ 2.81160229 -1.57075847], -likelihood = -488.32901
# Iteration=17, theta_new=[ 2.81324943 -1.57082153], -likelihood = -488.37539
# Iteration=18, theta_new=[ 2.81460441 -1.57079821], -likelihood = -488.40381
# Iteration=19, theta_new=[ 2.81573835 -1.57082418], -likelihood = -488.42054
# Iteration=20, theta_new=[ 2.81666939 -1.57076491], -likelihood = -488.42992
# 9-th start
# Iteration=1, theta_new=[-1.14949256  2.5906086 ], -likelihood = -348.79795
# Iteration=2, theta_new=[-1.22428626  2.618642  ], -likelihood = -379.55683
# Iteration=3, theta_new=[-1.30163131  2.64675878], -likelihood = -407.03096
# Iteration=4, theta_new=[-1.38662875  2.67315144], -likelihood = -430.05122
# Iteration=5, theta_new=[-1.51352663  2.69675092], -likelihood = -448.21825
# Iteration=6, theta_new=[-1.57076762  2.7169487 ], -likelihood = -460.65208
# Iteration=7, theta_new=[-1.57082368  2.73423414], -likelihood = -467.38886
# Iteration=8, theta_new=[-1.57080618  2.74886261], -likelihood = -472.32532
# Iteration=9, theta_new=[-1.57081553  2.76112416], -likelihood = -475.91446
# Iteration=10, theta_new=[-1.57076264  2.77132873], -likelihood = -478.45859
# Iteration=11, theta_new=[-1.57076972  2.7797971 ], -likelihood = -480.22873
# Iteration=12, theta_new=[-1.57072904  2.78681764], -likelihood = -481.44627
# Iteration=13, theta_new=[-1.57084342  2.79261053], -likelihood = -482.27693
# Iteration=14, theta_new=[-1.57079505  2.79739017], -likelihood = -482.83756
# Iteration=15, theta_new=[-1.57075668  2.80133063], -likelihood = -483.21383
# Iteration=16, theta_new=[-1.57081631  2.80456533], -likelihood = -483.46471
# Iteration=17, theta_new=[-1.5708302   2.80724001], -likelihood = -483.63026
# Iteration=18, theta_new=[-1.5707843   2.80943611], -likelihood = -483.73949
# Iteration=19, theta_new=[-1.57085422  2.81125527], -likelihood = -483.81038
# Iteration=20, theta_new=[-1.57079015  2.81275102], -likelihood = -483.85623
# 10-th start
# Iteration=1, theta_new=[ 2.82214698 -1.00180018], -likelihood = -360.96782
# Iteration=2, theta_new=[ 2.82049352 -1.0740936 ], -likelihood = -390.71018
# Iteration=3, theta_new=[ 2.81977074 -1.14772747], -likelihood = -419.33457
# Iteration=4, theta_new=[ 2.8196323  -1.22145362], -likelihood = -443.25236
# Iteration=5, theta_new=[ 2.81979858 -1.29612926], -likelihood = -461.38030
# Iteration=6, theta_new=[ 2.82006197 -1.37617632], -likelihood = -474.22644
# Iteration=7, theta_new=[ 2.82033771 -1.48166335], -likelihood = -482.93589
# Iteration=8, theta_new=[ 2.8205087  -1.57083612], -likelihood = -487.86452
# Iteration=9, theta_new=[ 2.82061624 -1.57076997], -likelihood = -488.42322
# Iteration=10, theta_new=[ 2.82069787 -1.57085945], -likelihood = -488.42221
# Iteration=11, theta_new=[ 2.82076116 -1.5708127 ], -likelihood = -488.42141
# Iteration=12, theta_new=[ 2.82082171 -1.57079778], -likelihood = -488.42078
# Iteration=13, theta_new=[ 2.82086965 -1.57083636], -likelihood = -488.42017
# Iteration=14, theta_new=[ 2.82090469 -1.57074081], -likelihood = -488.41967
# Iteration=15, theta_new=[ 2.82093177 -1.57080705], -likelihood = -488.41930
# Iteration=16, theta_new=[ 2.82094844 -1.57083753], -likelihood = -488.41902
# Iteration=17, theta_new=[ 2.82096637 -1.57084898], -likelihood = -488.41884
# Iteration=18, theta_new=[ 2.82097771 -1.57080099], -likelihood = -488.41865
# Iteration=19, theta_new=[ 2.82100054 -1.57076351], -likelihood = -488.41852
# Iteration=20, theta_new=[ 2.82102076 -1.57083515], -likelihood = -488.41828
# 11-th start
# Iteration=1, theta_new=[-0.45807519  1.88330635], -likelihood = -385.63955
# Iteration=2, theta_new=[-0.4536318   1.89118186], -likelihood = -386.05324
# Iteration=3, theta_new=[-0.44915002  1.89743444], -likelihood = -386.39829
# Iteration=4, theta_new=[-0.44458065  1.9024787 ], -likelihood = -386.69544
# Iteration=5, theta_new=[-0.44000032  1.90655113], -likelihood = -386.96433
# Iteration=6, theta_new=[-0.4355135   1.90983851], -likelihood = -387.21136
# Iteration=7, theta_new=[-0.43110914  1.91265261], -likelihood = -387.43809
# Iteration=8, theta_new=[-0.42684292  1.91490411], -likelihood = -387.65005
# Iteration=9, theta_new=[-0.42268193  1.9167626 ], -likelihood = -387.84553
# Iteration=10, theta_new=[-0.4186564   1.91834223], -likelihood = -388.02813
# Iteration=11, theta_new=[-0.41480065  1.91974007], -likelihood = -388.19774
# Iteration=12, theta_new=[-0.41116028  1.92089475], -likelihood = -388.35382
# Iteration=13, theta_new=[-0.40765705  1.92179708], -likelihood = -388.49499
# Iteration=14, theta_new=[-0.4043325  1.9226342], -likelihood = -388.62485
# Iteration=15, theta_new=[-0.40122082  1.92331764], -likelihood = -388.74283
# Iteration=16, theta_new=[-0.39828011  1.92390986], -likelihood = -388.84823
# Iteration=17, theta_new=[-0.395517    1.92435815], -likelihood = -388.94325
# Iteration=18, theta_new=[-0.39289012  1.9246878 ], -likelihood = -389.02825
# Iteration=19, theta_new=[-0.39045279  1.92498068], -likelihood = -389.10514
# Iteration=20, theta_new=[-0.38818495  1.92525042], -likelihood = -389.17298
# 12-th start
# Iteration=1, theta_new=[2.74204162 1.11350094], -likelihood = -474.34590
# Iteration=2, theta_new=[2.75377822 1.13683741], -likelihood = -481.52530
# Iteration=3, theta_new=[2.76400852 1.15661747], -likelihood = -486.75714
# Iteration=4, theta_new=[2.77276168 1.17328466], -likelihood = -490.49353
# Iteration=5, theta_new=[2.78023862 1.1871282 ], -likelihood = -493.10439
# Iteration=6, theta_new=[2.78662814 1.19855417], -likelihood = -494.90445
# Iteration=7, theta_new=[2.79200387 1.20796484], -likelihood = -496.13847
# Iteration=8, theta_new=[2.79656865 1.21567272], -likelihood = -496.97397
# Iteration=9, theta_new=[2.80041538 1.22186938], -likelihood = -497.54058
# Iteration=10, theta_new=[2.80363033 1.22689821], -likelihood = -497.91993
# Iteration=11, theta_new=[2.80634249 1.23103314], -likelihood = -498.17293
# Iteration=12, theta_new=[2.80862572 1.23435761], -likelihood = -498.34275
# Iteration=13, theta_new=[2.81051118 1.23693475], -likelihood = -498.45516
# Iteration=14, theta_new=[2.81209053 1.23910668], -likelihood = -498.52759
# Iteration=15, theta_new=[2.81344954 1.24078647], -likelihood = -498.57531
# Iteration=16, theta_new=[2.81456294 1.24215545], -likelihood = -498.60640
# Iteration=17, theta_new=[2.81552829 1.24326606], -likelihood = -498.62569
# Iteration=18, theta_new=[2.81632628 1.24410603], -likelihood = -498.63790
# Iteration=19, theta_new=[2.81695759 1.24476972], -likelihood = -498.64493
# Iteration=20, theta_new=[2.81751133 1.24529611], -likelihood = -498.64862
# 13-th start
# Iteration=1, theta_new=[-0.59336037 -2.10149439], -likelihood = -284.34506
# Iteration=2, theta_new=[-0.58599265 -2.03444604], -likelihood = -308.70051
# Iteration=3, theta_new=[-0.58256802 -1.96830127], -likelihood = -327.84006
# Iteration=4, theta_new=[-0.58113128 -1.90220494], -likelihood = -343.16822
# Iteration=5, theta_new=[-0.58060724 -1.83447392], -likelihood = -355.03592
# Iteration=6, theta_new=[-0.58051834 -1.7612701 ], -likelihood = -363.85558
# Iteration=7, theta_new=[-0.58051724 -1.66620348], -likelihood = -370.14869
# Iteration=8, theta_new=[-0.58126106 -1.57082701], -likelihood = -373.99401
# Iteration=9, theta_new=[-0.5823794  -1.57078361], -likelihood = -374.53899
# Iteration=10, theta_new=[-0.58345844 -1.57086945], -likelihood = -374.55993
# Iteration=11, theta_new=[-0.58454221 -1.57079314], -likelihood = -374.58015
# Iteration=12, theta_new=[-0.58558425 -1.57082569], -likelihood = -374.60048
# Iteration=13, theta_new=[-0.5865949 -1.5708156], -likelihood = -374.62002
# Iteration=14, theta_new=[-0.58761855 -1.57079505], -likelihood = -374.63897
# Iteration=15, theta_new=[-0.58860386 -1.57080133], -likelihood = -374.65816
# Iteration=16, theta_new=[-0.58958051 -1.57082239], -likelihood = -374.67662
# Iteration=17, theta_new=[-0.59053599 -1.57076482], -likelihood = -374.69489
# Iteration=18, theta_new=[-0.59146676 -1.57081198], -likelihood = -374.71274
# Iteration=19, theta_new=[-0.59237741 -1.57084273], -likelihood = -374.73010
# Iteration=20, theta_new=[-0.59325806 -1.57079707], -likelihood = -374.74706
# 14-th start
# Iteration=1, theta_new=[-0.36404833 -0.45555346], -likelihood = -123.97557
# Iteration=2, theta_new=[-0.3177022  -0.49164622], -likelihood = -149.93075
# Iteration=3, theta_new=[-0.2890482  -0.51368248], -likelihood = -175.98470
# Iteration=4, theta_new=[-0.27044398 -0.52679677], -likelihood = -185.26257
# Iteration=5, theta_new=[-0.25740902 -0.53466716], -likelihood = -188.69577
# Iteration=6, theta_new=[-0.24773566 -0.53923219], -likelihood = -190.13880
# Iteration=7, theta_new=[-0.24012163 -0.54169723], -likelihood = -190.81965
# Iteration=8, theta_new=[-0.23392144 -0.54269265], -likelihood = -191.19018
# Iteration=9, theta_new=[-0.22864022 -0.54278535], -likelihood = -191.42548
# Iteration=10, theta_new=[-0.22403189 -0.54211503], -likelihood = -191.60200
# Iteration=11, theta_new=[-0.21981327 -0.54095676], -likelihood = -191.75584
# Iteration=12, theta_new=[-0.21595942 -0.53943439], -likelihood = -191.90331
# Iteration=13, theta_new=[-0.21231892 -0.53760821], -likelihood = -192.04888
# Iteration=14, theta_new=[-0.20884635 -0.53564375], -likelihood = -192.19847
# Iteration=15, theta_new=[-0.20538043 -0.53357076], -likelihood = -192.34901
# Iteration=16, theta_new=[-0.20206111 -0.53137628], -likelihood = -192.50365
# Iteration=17, theta_new=[-0.19876638 -0.52915229], -likelihood = -192.66058
# Iteration=18, theta_new=[-0.19552995 -0.52688399], -likelihood = -192.81880
# Iteration=19, theta_new=[-0.19235637 -0.52456019], -likelihood = -192.97838
# Iteration=20, theta_new=[-0.18915442 -0.52224936], -likelihood = -193.13984
# 15-th start
# Iteration=1, theta_new=[-2.22593316 -1.57080259], -likelihood = -344.55472
# Iteration=2, theta_new=[-2.26091996 -1.57081859], -likelihood = -356.72105
# Iteration=3, theta_new=[-2.29067078 -1.57077556], -likelihood = -362.03379
# Iteration=4, theta_new=[-2.3159134  -1.57078857], -likelihood = -365.86311
# Iteration=5, theta_new=[-2.33742734 -1.57075526], -likelihood = -368.59506
# Iteration=6, theta_new=[-2.35585522 -1.57082107], -likelihood = -370.54714
# Iteration=7, theta_new=[-2.3717083  -1.57065303], -likelihood = -371.94795
# Iteration=8, theta_new=[-2.38549231 -1.57076796], -likelihood = -372.95786
# Iteration=9, theta_new=[-2.39752143 -1.57076565], -likelihood = -373.69378
# Iteration=10, theta_new=[-2.40806992 -1.57079147], -likelihood = -374.23165
# Iteration=11, theta_new=[-2.41738791 -1.57074555], -likelihood = -374.62617
# Iteration=12, theta_new=[-2.42566201 -1.57082935], -likelihood = -374.91691
# Iteration=13, theta_new=[-2.43305455 -1.57075479], -likelihood = -375.13135
# Iteration=14, theta_new=[-2.43965579 -1.57078507], -likelihood = -375.28945
# Iteration=15, theta_new=[-2.4456099  -1.57074061], -likelihood = -375.40488
# Iteration=16, theta_new=[-2.45099263 -1.57076001], -likelihood = -375.48893
# Iteration=17, theta_new=[-2.45589508 -1.57071494], -likelihood = -375.54910
# Iteration=18, theta_new=[-2.46031199 -1.57079829], -likelihood = -375.59131
# Iteration=19, theta_new=[-2.46433407 -1.57078969], -likelihood = -375.61939
# Iteration=20, theta_new=[-2.46802348 -1.57077794], -likelihood = -375.63705
# 16-th start
# Iteration=1, theta_new=[ 2.90112297 -2.34770574], -likelihood = -282.61295
# Iteration=2, theta_new=[ 2.884981   -2.31987005], -likelihood = -292.10513
# Iteration=3, theta_new=[ 2.87095856 -2.27944527], -likelihood = -304.40123
# Iteration=4, theta_new=[ 2.85912828 -2.22493027], -likelihood = -322.66968
# Iteration=5, theta_new=[ 2.84963069 -2.1590427 ], -likelihood = -348.81634
# Iteration=6, theta_new=[ 2.84251031 -2.0868841 ], -likelihood = -380.15032
# Iteration=7, theta_new=[ 2.83744571 -2.01277267], -likelihood = -411.00429
# Iteration=8, theta_new=[ 2.83387893 -1.93868597], -likelihood = -437.09145
# Iteration=9, theta_new=[ 2.83137892 -1.8642091 ], -likelihood = -457.00145
# Iteration=10, theta_new=[ 2.82951541 -1.78618783], -likelihood = -471.21257
# Iteration=11, theta_new=[ 2.82808972 -1.69206505], -likelihood = -480.89619
# Iteration=12, theta_new=[ 2.82691521 -1.57075752], -likelihood = -486.95510
# Iteration=13, theta_new=[ 2.82590518 -1.57077446], -likelihood = -488.29647
# Iteration=14, theta_new=[ 2.82505744 -1.57083296], -likelihood = -488.32543
# Iteration=15, theta_new=[ 2.82436703 -1.57078573], -likelihood = -488.34715
# Iteration=16, theta_new=[ 2.82379972 -1.57083178], -likelihood = -488.36308
# Iteration=17, theta_new=[ 2.82333416 -1.57079706], -likelihood = -488.37499
# Iteration=18, theta_new=[ 2.82294006 -1.57083009], -likelihood = -488.38398
# Iteration=19, theta_new=[ 2.82261665 -1.57075635], -likelihood = -488.39103
# Iteration=20, theta_new=[ 2.8223513  -1.57075629], -likelihood = -488.39643
# 17-th start
# Iteration=1, theta_new=[-0.01823556 -0.5514008 ], -likelihood = -194.12770
# Iteration=2, theta_new=[-0.00227714 -0.5411611 ], -likelihood = -197.64594
# Iteration=3, theta_new=[ 0.01664678 -0.53226271], -likelihood = -202.06713
# Iteration=4, theta_new=[ 0.03907508 -0.5248611 ], -likelihood = -207.90655
# Iteration=5, theta_new=[ 0.0650112  -0.51914844], -likelihood = -215.90600
# Iteration=6, theta_new=[ 0.09390599 -0.51520154], -likelihood = -226.68551
# Iteration=7, theta_new=[ 0.12434734 -0.51278308], -likelihood = -240.31969
# Iteration=8, theta_new=[ 0.15447554 -0.51125769], -likelihood = -255.77975
# Iteration=9, theta_new=[ 0.18265556 -0.51003045], -likelihood = -271.19965
# Iteration=10, theta_new=[ 0.20779831 -0.50859579], -likelihood = -284.86240
# Iteration=11, theta_new=[ 0.2296074  -0.50677634], -likelihood = -295.86469
# Iteration=12, theta_new=[ 0.24809033 -0.50450511], -likelihood = -304.19206
# Iteration=13, theta_new=[ 0.2635616  -0.50194872], -likelihood = -310.21736
# Iteration=14, theta_new=[ 0.27636714 -0.49917162], -likelihood = -314.46323
# Iteration=15, theta_new=[ 0.28693282 -0.4963768 ], -likelihood = -317.39957
# Iteration=16, theta_new=[ 0.29551516 -0.49363362], -likelihood = -319.41271
# Iteration=17, theta_new=[ 0.30256271 -0.49104468], -likelihood = -320.77090
# Iteration=18, theta_new=[ 0.3083216  -0.48856979], -likelihood = -321.69599
# Iteration=19, theta_new=[ 0.3129493  -0.48632272], -likelihood = -322.32509
# Iteration=20, theta_new=[ 0.31672153 -0.48419337], -likelihood = -322.74616
# 18-th start
# Iteration=1, theta_new=[ 1.7723117  -0.83110754], -likelihood = -354.09494
# Iteration=2, theta_new=[ 1.82957527 -0.81961995], -likelihood = -361.44039
# Iteration=3, theta_new=[ 1.86438005 -0.81272075], -likelihood = -365.02165
# Iteration=4, theta_new=[ 1.88764595 -0.80885426], -likelihood = -366.84955
# Iteration=5, theta_new=[ 1.9039764 -0.8071783], -likelihood = -367.80830
# Iteration=6, theta_new=[ 1.91599649 -0.80702319], -likelihood = -368.31976
# Iteration=7, theta_new=[ 1.9250297 -0.8080268], -likelihood = -368.60240
# Iteration=8, theta_new=[ 1.93205256 -0.80984174], -likelihood = -368.76101
# Iteration=9, theta_new=[ 1.93766178 -0.81233099], -likelihood = -368.85440
# Iteration=10, theta_new=[ 1.94234711 -0.81541452], -likelihood = -368.91191
# Iteration=11, theta_new=[ 1.9463857 -0.8189333], -likelihood = -368.95025
# Iteration=12, theta_new=[ 1.95005893 -0.82283113], -likelihood = -368.97815
# Iteration=13, theta_new=[ 1.95341134 -0.82705115], -likelihood = -369.00096
# Iteration=14, theta_new=[ 1.9566766 -0.8316244], -likelihood = -369.02036
# Iteration=15, theta_new=[ 1.95985129 -0.83653653], -likelihood = -369.03897
# Iteration=16, theta_new=[ 1.96302987 -0.84175629], -likelihood = -369.05710
# Iteration=17, theta_new=[ 1.96619854 -0.84722476], -likelihood = -369.07591
# Iteration=18, theta_new=[ 1.96944274 -0.85299077], -likelihood = -369.09557
# Iteration=19, theta_new=[ 1.97282858 -0.8591123 ], -likelihood = -369.11705
# Iteration=20, theta_new=[ 1.9763793 -0.8655309], -likelihood = -369.14133
# 19-th start
# Iteration=1, theta_new=[-1.95488209 -0.77034983], -likelihood = -281.75404
# Iteration=2, theta_new=[-1.86618365 -0.74093981], -likelihood = -327.17849
# Iteration=3, theta_new=[-1.77966029 -0.72195501], -likelihood = -345.68684
# Iteration=4, theta_new=[-1.6751181  -0.70923872], -likelihood = -355.13721
# Iteration=5, theta_new=[-1.57082187 -0.70101549], -likelihood = -359.92781
# Iteration=6, theta_new=[-1.57081778 -0.69459116], -likelihood = -360.66800
# Iteration=7, theta_new=[-1.57081809 -0.68861946], -likelihood = -360.81423
# Iteration=8, theta_new=[-1.57081369 -0.68307103], -likelihood = -360.92955
# Iteration=9, theta_new=[-1.57078222 -0.67789877], -likelihood = -361.01953
# Iteration=10, theta_new=[-1.57077114 -0.67309463], -likelihood = -361.08908
# Iteration=11, theta_new=[-1.57083248 -0.66858799], -likelihood = -361.14174
# Iteration=12, theta_new=[-1.57081972 -0.66438363], -likelihood = -361.18107
# Iteration=13, theta_new=[-1.57081505 -0.66041256], -likelihood = -361.20931
# Iteration=14, theta_new=[-1.57077896 -0.65668602], -likelihood = -361.22877
# Iteration=15, theta_new=[-1.57081602 -0.65317694], -likelihood = -361.24089
# Iteration=16, theta_new=[-1.57083013 -0.64987925], -likelihood = -361.24707
# Iteration=17, theta_new=[-1.57076217 -0.6467646 ], -likelihood = -361.24843
# Iteration=18, theta_new=[-1.57081079 -0.64382005], -likelihood = -361.24591
# Iteration=19, theta_new=[-1.57081719 -0.6410124 ], -likelihood = -361.24025
# Iteration=20, theta_new=[-1.57075556 -0.63836645], -likelihood = -361.23199
# 20-th start
# Iteration=1, theta_new=[1.85389336 0.7669712 ], -likelihood = -369.45500
# Iteration=2, theta_new=[1.82535949 0.75344354], -likelihood = -373.90096
# Iteration=3, theta_new=[1.80502095 0.74109267], -likelihood = -376.67904
# Iteration=4, theta_new=[1.79200817 0.72890003], -likelihood = -378.74171
# Iteration=5, theta_new=[1.78534966 0.71614894], -likelihood = -380.59839
# Iteration=6, theta_new=[1.78416697 0.70211048], -likelihood = -382.56704
# Iteration=7, theta_new=[1.78769007 0.6862125 ], -likelihood = -384.92361
# Iteration=8, theta_new=[1.79516645 0.66785252], -likelihood = -387.93671
# Iteration=9, theta_new=[1.80583766 0.64670277], -likelihood = -391.93420
# Iteration=10, theta_new=[1.81882681 0.62253019], -likelihood = -397.25031
# Iteration=11, theta_new=[1.8331119  0.59560851], -likelihood = -404.22483
# Iteration=12, theta_new=[1.84760531 0.56680808], -likelihood = -413.00550
# Iteration=13, theta_new=[1.86120035 0.537354  ], -likelihood = -423.36269
# Iteration=14, theta_new=[1.8730801  0.50862973], -likelihood = -434.66226
# Iteration=15, theta_new=[1.8825299  0.48178236], -likelihood = -445.98419
# Iteration=16, theta_new=[1.88962242 0.45750277], -likelihood = -456.44008
# Iteration=17, theta_new=[1.89445076 0.43613509], -likelihood = -465.44916
# Iteration=18, theta_new=[1.89753123 0.41770274], -likelihood = -472.76284
# Iteration=19, theta_new=[1.89921219 0.40199591], -likelihood = -478.42893
# Iteration=20, theta_new=[1.89993939 0.38876065], -likelihood = -482.67397
# 21-th start
# Iteration=1, theta_new=[-1.79306462  0.79020985], -likelihood = -373.75465
# Iteration=2, theta_new=[-1.77305625  0.79846293], -likelihood = -374.10397
# Iteration=3, theta_new=[-1.75876323  0.80594419], -likelihood = -374.11683
# Iteration=4, theta_new=[-1.74977137  0.81294543], -likelihood = -373.97533
# Iteration=5, theta_new=[-1.74527934  0.81961902], -likelihood = -373.77342
# Iteration=6, theta_new=[-1.74454774  0.8261846 ], -likelihood = -373.56144
# Iteration=7, theta_new=[-1.74677094  0.83275432], -likelihood = -373.36136
# Iteration=8, theta_new=[-1.75131024  0.83945465], -likelihood = -373.18432
# Iteration=9, theta_new=[-1.7576596   0.84629637], -likelihood = -373.03455
# Iteration=10, theta_new=[-1.76515434  0.85329956], -likelihood = -372.91655
# Iteration=11, theta_new=[-1.77357073  0.86050849], -likelihood = -372.82919
# Iteration=12, theta_new=[-1.78266381  0.86782004], -likelihood = -372.77299
# Iteration=13, theta_new=[-1.79224894  0.8752436 ], -likelihood = -372.75014
# Iteration=14, theta_new=[-1.80208346  0.88279861], -likelihood = -372.75922
# Iteration=15, theta_new=[-1.81205767  0.89034974], -likelihood = -372.79606
# Iteration=16, theta_new=[-1.82211406  0.89787965], -likelihood = -372.86055
# Iteration=17, theta_new=[-1.83215477  0.90536513], -likelihood = -372.95036
# Iteration=18, theta_new=[-1.84207189  0.91273136], -likelihood = -373.06176
# Iteration=19, theta_new=[-1.85192992  0.91992374], -likelihood = -373.19105
# Iteration=20, theta_new=[-1.86161963  0.92693468], -likelihood = -373.33844
# 22-th start
# Iteration=1, theta_new=[-0.50929262 -1.80748094], -likelihood = -355.01052
# Iteration=2, theta_new=[-0.51071183 -1.72194978], -likelihood = -364.55996
# Iteration=3, theta_new=[-0.51128385 -1.57079312], -likelihood = -371.19118
# Iteration=4, theta_new=[-0.51193347 -1.57081408], -likelihood = -373.57856
# Iteration=5, theta_new=[-0.51261075 -1.57081344], -likelihood = -373.58191
# Iteration=6, theta_new=[-0.51329373 -1.57078064], -likelihood = -373.58554
# Iteration=7, theta_new=[-0.51399253 -1.57077859], -likelihood = -373.58936
# Iteration=8, theta_new=[-0.51470706 -1.57077817], -likelihood = -373.59342
# Iteration=9, theta_new=[-0.5154605  -1.57078169], -likelihood = -373.59774
# Iteration=10, theta_new=[-0.51618179 -1.57069907], -likelihood = -373.60247
# Iteration=11, theta_new=[-0.51693291 -1.57084154], -likelihood = -373.60717
# Iteration=12, theta_new=[-0.51772137 -1.57081843], -likelihood = -373.61224
# Iteration=13, theta_new=[-0.51851792 -1.57082335], -likelihood = -373.61775
# Iteration=14, theta_new=[-0.51931283 -1.57074396], -likelihood = -373.62352
# Iteration=15, theta_new=[-0.52013107 -1.57077416], -likelihood = -373.62947
# Iteration=16, theta_new=[-0.52098083 -1.5708014 ], -likelihood = -373.63580
# Iteration=17, theta_new=[-0.52183842 -1.5708134 ], -likelihood = -373.64260
# Iteration=18, theta_new=[-0.5227125  -1.57085244], -likelihood = -373.64968
# Iteration=19, theta_new=[-0.52359196 -1.57076667], -likelihood = -373.65712
# Iteration=20, theta_new=[-0.52449123 -1.57077307], -likelihood = -373.66484
# 23-th start
# Iteration=1, theta_new=[ 0.84630509 -0.86721826], -likelihood = -283.06744
# Iteration=2, theta_new=[ 0.89342357 -0.91202091], -likelihood = -317.33248
# Iteration=3, theta_new=[ 0.93326187 -0.95557639], -likelihood = -344.38646
# Iteration=4, theta_new=[ 0.96366241 -0.99424072], -likelihood = -360.26564
# Iteration=5, theta_new=[ 0.9850153  -1.02694848], -likelihood = -368.07472
# Iteration=6, theta_new=[ 0.99882473 -1.05416925], -likelihood = -371.51149
# Iteration=7, theta_new=[ 1.00679757 -1.07690561], -likelihood = -372.87863
# Iteration=8, theta_new=[ 1.01048066 -1.09609429], -likelihood = -373.35580
# Iteration=9, theta_new=[ 1.01107588 -1.11265553], -likelihood = -373.49555
# Iteration=10, theta_new=[ 1.00961557 -1.12728581], -likelihood = -373.54190
# Iteration=11, theta_new=[ 1.00677891 -1.14033075], -likelihood = -373.58591
# Iteration=12, theta_new=[ 1.00306201 -1.15222877], -likelihood = -373.65760
# Iteration=13, theta_new=[ 0.99881143 -1.16324417], -likelihood = -373.76006
# Iteration=14, theta_new=[ 0.9941581  -1.17350643], -likelihood = -373.88735
# Iteration=15, theta_new=[ 0.98941457 -1.18315735], -likelihood = -374.03816
# Iteration=16, theta_new=[ 0.98456977 -1.19229365], -likelihood = -374.19761
# Iteration=17, theta_new=[ 0.97973746 -1.20095546], -likelihood = -374.36689
# Iteration=18, theta_new=[ 0.97495494 -1.209248  ], -likelihood = -374.54022
# Iteration=19, theta_new=[ 0.9702428  -1.21716639], -likelihood = -374.71486
# Iteration=20, theta_new=[ 0.96556057 -1.22472104], -likelihood = -374.89006
# 24-th start
# Iteration=1, theta_new=[ 0.71406418 -1.57077016], -likelihood = -391.64616
# Iteration=2, theta_new=[ 0.70130901 -1.57074609], -likelihood = -393.10869
# Iteration=3, theta_new=[ 0.68716073 -1.5707997 ], -likelihood = -394.78799
# Iteration=4, theta_new=[ 0.67133829 -1.57081779], -likelihood = -396.84100
# Iteration=5, theta_new=[ 0.65357819 -1.57075754], -likelihood = -399.40658
# Iteration=6, theta_new=[ 0.63364371 -1.57080896], -likelihood = -402.66629
# Iteration=7, theta_new=[ 0.61140608 -1.57076752], -likelihood = -406.84905
# Iteration=8, theta_new=[ 0.5869651  -1.57077951], -likelihood = -412.20562
# Iteration=9, theta_new=[ 0.56075053 -1.57077047], -likelihood = -418.93191
# Iteration=10, theta_new=[ 0.53357226 -1.57082793], -likelihood = -427.04042
# Iteration=11, theta_new=[ 0.50650317 -1.57080294], -likelihood = -436.22154
# Iteration=12, theta_new=[ 0.4805943  -1.57074469], -likelihood = -445.82776
# Iteration=13, theta_new=[ 0.45671076 -1.57078171], -likelihood = -455.06836
# Iteration=14, theta_new=[ 0.43537221 -1.57080906], -likelihood = -463.25902
# Iteration=15, theta_new=[ 0.4167659  -1.57082762], -likelihood = -470.02180
# Iteration=16, theta_new=[ 0.40079562 -1.57082543], -likelihood = -475.29588
# Iteration=17, theta_new=[ 0.38726155 -1.57081328], -likelihood = -479.24241
# Iteration=18, theta_new=[ 0.37589366 -1.57074665], -likelihood = -482.10197
# Iteration=19, theta_new=[ 0.36639477 -1.57077111], -likelihood = -484.12583
# Iteration=20, theta_new=[ 0.35848371 -1.5707704 ], -likelihood = -485.53495
# 25-th start
# Iteration=1, theta_new=[-3.1537144   1.73829861], -likelihood = -374.58465
# Iteration=2, theta_new=[-3.18029688  1.79051242], -likelihood = -386.16595
# Iteration=3, theta_new=[-3.20987854  1.82362773], -likelihood = -399.38813
# Iteration=4, theta_new=[-3.24045631  1.84600028], -likelihood = -414.19085
# Iteration=5, theta_new=[-3.270164    1.86126071], -likelihood = -429.50978
# Iteration=6, theta_new=[-3.29767178  1.87156911], -likelihood = -444.00878
# Iteration=7, theta_new=[-3.32239859  1.87835387], -likelihood = -456.70136
# Iteration=8, theta_new=[-3.34411491  1.88286077], -likelihood = -467.20139
# Iteration=9, theta_new=[-3.36289271  1.88581411], -likelihood = -475.50031
# Iteration=10, theta_new=[-3.37897791  1.88774191], -likelihood = -481.84015
# Iteration=11, theta_new=[-3.3925963   1.88898198], -likelihood = -486.56893
# Iteration=12, theta_new=[-3.40414567  1.88984518], -likelihood = -490.01737
# Iteration=13, theta_new=[-3.41385345  1.89046237], -likelihood = -492.51667
# Iteration=14, theta_new=[-3.42200899  1.89085584], -likelihood = -494.30158
# Iteration=15, theta_new=[-3.42877881  1.8911746 ], -likelihood = -495.57062
# Iteration=16, theta_new=[-3.43449162  1.89145008], -likelihood = -496.46118
# Iteration=17, theta_new=[-3.43924477  1.89169084], -likelihood = -497.09608
# Iteration=18, theta_new=[-3.44319835  1.89185466], -likelihood = -497.54218
# Iteration=19, theta_new=[-3.4464853   1.89207833], -likelihood = -497.85587
# Iteration=20, theta_new=[-3.44922806  1.89230464], -likelihood = -498.07728
# 26-th start
# Iteration=1, theta_new=[0.36148767 1.22090708], -likelihood = -494.83434
# Iteration=2, theta_new=[0.35489167 1.22571354], -likelihood = -496.02128
# Iteration=3, theta_new=[0.34935184 1.22971696], -likelihood = -496.85461
# Iteration=4, theta_new=[0.34474679 1.23300154], -likelihood = -497.43373
# Iteration=5, theta_new=[0.34089218 1.2357054 ], -likelihood = -497.83001
# Iteration=6, theta_new=[0.33764863 1.23792534], -likelihood = -498.10184
# Iteration=7, theta_new=[0.3349615  1.23974246], -likelihood = -498.28813
# Iteration=8, theta_new=[0.33269631 1.24125618], -likelihood = -498.41320
# Iteration=9, theta_new=[0.33081519 1.24240997], -likelihood = -498.49804
# Iteration=10, theta_new=[0.32923531 1.24341137], -likelihood = -498.55403
# Iteration=11, theta_new=[0.32794433 1.24415219], -likelihood = -498.59119
# Iteration=12, theta_new=[0.32682318 1.24485599], -likelihood = -498.61477
# Iteration=13, theta_new=[0.32593708 1.24532102], -likelihood = -498.63040
# Iteration=14, theta_new=[0.32516486 1.24578713], -likelihood = -498.63957
# Iteration=15, theta_new=[0.32452073 1.24613417], -likelihood = -498.64523
# Iteration=16, theta_new=[0.32400736 1.24640332], -likelihood = -498.64834
# Iteration=17, theta_new=[0.32357403 1.24666003], -likelihood = -498.64977
# Iteration=18, theta_new=[0.32319207 1.2468813 ], -likelihood = -498.65021
# Iteration=19, theta_new=[0.32290848 1.24704244], -likelihood = -498.65004
# Iteration=20, theta_new=[0.32266979 1.247151  ], -likelihood = -498.64958
# 27-th start
# Iteration=1, theta_new=[-1.57074223  2.44076808], -likelihood = -381.28784
# Iteration=2, theta_new=[-1.57075582  2.45080553], -likelihood = -382.69961
# Iteration=3, theta_new=[-1.57079385  2.4625516 ], -likelihood = -384.09780
# Iteration=4, theta_new=[-1.57087485  2.47628841], -likelihood = -385.91289
# Iteration=5, theta_new=[-1.57073547  2.49239728], -likelihood = -388.30144
# Iteration=6, theta_new=[-1.57080318  2.51116415], -likelihood = -391.49584
# Iteration=7, theta_new=[-1.57083833  2.53275331], -likelihood = -395.78415
# Iteration=8, theta_new=[-1.57077915  2.55705516], -likelihood = -401.49015
# Iteration=9, theta_new=[-1.57079662  2.58353414], -likelihood = -408.87142
# Iteration=10, theta_new=[-1.5708226   2.61121193], -likelihood = -417.93596
# Iteration=11, theta_new=[-1.57075117  2.63877516], -likelihood = -428.27144
# Iteration=12, theta_new=[-1.57085036  2.66498879], -likelihood = -439.02702
# Iteration=13, theta_new=[-1.57084121  2.68894141], -likelihood = -449.22018
# Iteration=14, theta_new=[-1.5708243   2.71011592], -likelihood = -458.08532
# Iteration=15, theta_new=[-1.57080907  2.72840961], -likelihood = -465.25362
# Iteration=16, theta_new=[-1.57080951  2.74396645], -likelihood = -470.74116
# Iteration=17, theta_new=[-1.57077271  2.75703127], -likelihood = -474.77772
# Iteration=18, theta_new=[-1.57075714  2.76794123], -likelihood = -477.65873
# Iteration=19, theta_new=[-1.57082202  2.77700386], -likelihood = -479.67722
# Iteration=20, theta_new=[-1.57074566  2.78449576], -likelihood = -481.07042
# 28-th start
# Iteration=1, theta_new=[ 2.64304912 -1.5707828 ], -likelihood = -437.38923
# Iteration=2, theta_new=[ 2.66841151 -1.57078962], -likelihood = -448.68120
# Iteration=3, theta_new=[ 2.69156987 -1.57078855], -likelihood = -457.66135
# Iteration=4, theta_new=[ 2.7120869  -1.57074303], -likelihood = -465.44758
# Iteration=5, theta_new=[ 2.72989572 -1.57079581], -likelihood = -471.75535
# Iteration=6, theta_new=[ 2.74511028 -1.57081134], -likelihood = -476.61124
# Iteration=7, theta_new=[ 2.75795711 -1.57081642], -likelihood = -480.20456
# Iteration=8, theta_new=[ 2.76873605 -1.57077091], -likelihood = -482.78630
# Iteration=9, theta_new=[ 2.77773004 -1.57075144], -likelihood = -484.60493
# Iteration=10, theta_new=[ 2.78521181 -1.57084063], -likelihood = -485.86566
# Iteration=11, theta_new=[ 2.79142917 -1.57075806], -likelihood = -486.72951
# Iteration=12, theta_new=[ 2.79656999 -1.57082243], -likelihood = -487.31622
# Iteration=13, theta_new=[ 2.80081879 -1.57077791], -likelihood = -487.70977
# Iteration=14, theta_new=[ 2.80435108 -1.57079689], -likelihood = -487.97165
# Iteration=15, theta_new=[ 2.8072658  -1.57071248], -likelihood = -488.14532
# Iteration=16, theta_new=[ 2.80967085 -1.57084272], -likelihood = -488.25831
# Iteration=17, theta_new=[ 2.81165937 -1.57077321], -likelihood = -488.33080
# Iteration=18, theta_new=[ 2.81330965 -1.57073905], -likelihood = -488.37653
# Iteration=19, theta_new=[ 2.81466278 -1.57085587], -likelihood = -488.40468
# Iteration=20, theta_new=[ 2.81577305 -1.57078287], -likelihood = -488.42113
# 29-th start
# Iteration=1, theta_new=[ 1.16986375 -0.7884153 ], -likelihood = -368.29195
# Iteration=2, theta_new=[ 1.17599384 -0.79492006], -likelihood = -368.65648
# Iteration=3, theta_new=[ 1.17992635 -0.80087373], -likelihood = -368.84940
# Iteration=4, theta_new=[ 1.1822448  -0.80644182], -likelihood = -368.94996
# Iteration=5, theta_new=[ 1.18332202 -0.8117701 ], -likelihood = -369.00281
# Iteration=6, theta_new=[ 1.18341875 -0.8169957 ], -likelihood = -369.03116
# Iteration=7, theta_new=[ 1.182714   -0.82214511], -likelihood = -369.04761
# Iteration=8, theta_new=[ 1.1814594  -0.82741064], -likelihood = -369.05898
# Iteration=9, theta_new=[ 1.17974001 -0.83270112], -likelihood = -369.06882
# Iteration=10, theta_new=[ 1.17760927 -0.83817322], -likelihood = -369.07897
# Iteration=11, theta_new=[ 1.17510029 -0.84382701], -likelihood = -369.09079
# Iteration=12, theta_new=[ 1.17239459 -0.84965119], -likelihood = -369.10534
# Iteration=13, theta_new=[ 1.16942028 -0.85572348], -likelihood = -369.12196
# Iteration=14, theta_new=[ 1.16624401 -0.86207965], -likelihood = -369.14195
# Iteration=15, theta_new=[ 1.16285004 -0.86871845], -likelihood = -369.16524
# Iteration=16, theta_new=[ 1.15931572 -0.87568734], -likelihood = -369.19274
# Iteration=17, theta_new=[ 1.15554037 -0.8829865 ], -likelihood = -369.22396
# Iteration=18, theta_new=[ 1.15151572 -0.89058055], -likelihood = -369.26108
# Iteration=19, theta_new=[ 1.14735331 -0.89854908], -likelihood = -369.30545
# Iteration=20, theta_new=[ 1.14299894 -0.90691475], -likelihood = -369.35576

# %%
EM_theta2_rad
# Out:
# array([0.32266979, 1.247151  ])

# %% [markdown]
# ## True result

# %%
theta2_rad
# Out:
# array([0.34906585, 1.22173048])

# %% [markdown]
# # Case 3

# %% [markdown]
# Имеется 7 датчиков, 3 источника (дисперсии сигналов - 0.1, 0.5 и 0.9), и шум на каждом датчике имеет дисперсию 1.1.

# %%
Num_sensors3 = 7
Num_emitters3 = 3
sample_size3 = 100
theta3_rad = [0.5, 1.2, 1.6] # Направление прибытия (DOA) в радианах
theta3_deg = rad_to_deg(theta3_rad[0]) # Направление прибытия (DOA) в градусах
GS_3 = np.diag([0.1, 0.5, 0.9]) # Ковариация сигнала
GN_3 = 1.1*np.eye(7, dtype=np.float64) # Ковариация шума
A3 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors3).reshape(-1,1) * np.sin(theta3_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s3 = CN(Num_emitters3, sample_size3, GS_3)
n3 = CN(Num_sensors3, sample_size3, GN_3)
X3 = (A3 @ s3.T + n3.T).T

# %% [markdown]
# ## ML1

# %%
theta_ML1_Case3, ML1_func_val_Case3 = multi_start_ML1(X3, L=Num_sensors3, M=Num_emitters3, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML1_Case3
# Out:
# array([0.50012876, 1.14007338, 1.38774257])

# %% [markdown]
# ## ML2

# %%
theta_ML2_Case3, ML2_func_val_Case3 = multi_start_ML2(X3, GS_3, GN_3, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML2_Case3
# Out:
# array([ 0.50595641,  1.19839997, -1.46391099])

# %% [markdown]
# ## EM

# %%
EM_theta3_rad, neglhd_3, K3, mu3 = multi_start_EM(X3, GS_3, GN_3, 30, max_iter=20, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[-2.97277556  1.6741446  -0.07932455], -likelihood = -1004.82191
# Iteration=2, theta_new=[-2.93996512  1.7020123  -0.06988788], -likelihood = -1030.28902
# Iteration=3, theta_new=[-2.9204847   1.71973761 -0.0622255 ], -likelihood = -1043.07383
# Iteration=4, theta_new=[-2.90780345  1.73181907 -0.05619312], -likelihood = -1048.89747
# Iteration=5, theta_new=[-2.89907329  1.74028054 -0.05127877], -likelihood = -1051.80409
# Iteration=6, theta_new=[-2.89296472  1.74630179 -0.04719994], -likelihood = -1053.38066
# Iteration=7, theta_new=[-2.88870759  1.75064908 -0.04373884], -likelihood = -1054.28423
# Iteration=8, theta_new=[-2.88573841  1.75388064 -0.04073418], -likelihood = -1054.83238
# Iteration=9, theta_new=[-2.88371406  1.75622988 -0.03798564], -likelihood = -1055.18938
# Iteration=10, theta_new=[-2.88252227  1.75802132 -0.03553064], -likelihood = -1055.44465
# Iteration=11, theta_new=[-2.88191307  1.75937913 -0.03317272], -likelihood = -1055.63775
# Iteration=12, theta_new=[-2.88178852  1.76045178 -0.03094801], -likelihood = -1055.80516
# Iteration=13, theta_new=[-2.88209066  1.76124377 -0.02880078], -likelihood = -1055.95736
# Iteration=14, theta_new=[-2.88273141  1.76193629 -0.02671864], -likelihood = -1056.10568
# Iteration=15, theta_new=[-2.88358086  1.76245668 -0.02467698], -likelihood = -1056.25585
# Iteration=16, theta_new=[-2.88466761  1.76293266 -0.02260702], -likelihood = -1056.40915
# Iteration=17, theta_new=[-2.88598185  1.76329651 -0.02056068], -likelihood = -1056.57338
# Iteration=18, theta_new=[-2.8874473   1.76362778 -0.01847968], -likelihood = -1056.74658
# Iteration=19, theta_new=[-2.88908856  1.76391034 -0.01636943], -likelihood = -1056.93148
# Iteration=20, theta_new=[-2.8908915   1.76423947 -0.0141861 ], -likelihood = -1057.12941
# 1-th start
# Iteration=1, theta_new=[-1.96618685  2.88304626  0.68771068], -likelihood = -618.17891
# Iteration=2, theta_new=[-1.89717771  2.87660786  0.67852901], -likelihood = -703.56973
# Iteration=3, theta_new=[-1.83384232  2.8702708   0.66978184], -likelihood = -759.95753
# Iteration=4, theta_new=[-1.7739525   2.86378709  0.66138161], -likelihood = -794.87064
# Iteration=5, theta_new=[-1.71348886  2.85717003  0.65344373], -likelihood = -815.97967
# Iteration=6, theta_new=[-1.63909241  2.85050532  0.64609753], -likelihood = -828.72472
# Iteration=7, theta_new=[-1.57081797  2.84423248  0.63916209], -likelihood = -835.95963
# Iteration=8, theta_new=[-1.57070215  2.83849847  0.63262319], -likelihood = -838.06866
# Iteration=9, theta_new=[-1.57087634  2.83329114  0.62658322], -likelihood = -839.10012
# Iteration=10, theta_new=[-1.5708197   2.82865518  0.62107761], -likelihood = -839.93554
# Iteration=11, theta_new=[-1.57076334  2.82458656  0.61612671], -likelihood = -840.59813
# Iteration=12, theta_new=[-1.57078486  2.82107049  0.61172226], -likelihood = -841.11588
# Iteration=13, theta_new=[-1.57076346  2.81808511  0.60784335], -likelihood = -841.51585
# Iteration=14, theta_new=[-1.57081503  2.81557783  0.60443769], -likelihood = -841.82180
# Iteration=15, theta_new=[-1.57081369  2.81350365  0.6014632 ], -likelihood = -842.05561
# Iteration=16, theta_new=[-1.57082453  2.81180849  0.59885663], -likelihood = -842.23387
# Iteration=17, theta_new=[-1.57066209  2.81043621  0.59660582], -likelihood = -842.37054
# Iteration=18, theta_new=[-1.57074185  2.80936048  0.5946154 ], -likelihood = -842.47507
# Iteration=19, theta_new=[-1.57081961  2.80854288  0.59288862], -likelihood = -842.55632
# Iteration=20, theta_new=[-1.57091637  2.80792791  0.59136236], -likelihood = -842.61904
# 2-th start
# Iteration=1, theta_new=[-0.55809703 -0.24731061 -1.85012336], -likelihood = -956.29778
# Iteration=2, theta_new=[-0.55707416 -0.24061773 -1.78820951], -likelihood = -1020.01842
# Iteration=3, theta_new=[-0.55505836 -0.23450341 -1.72801163], -likelihood = -1056.54464
# Iteration=4, theta_new=[-0.55271049 -0.22889829 -1.66088293], -likelihood = -1077.07925
# Iteration=5, theta_new=[-0.55031554 -0.22360954 -1.57081632], -likelihood = -1088.20038
# Iteration=6, theta_new=[-0.54815422 -0.21847787 -1.57077715], -likelihood = -1090.72845
# Iteration=7, theta_new=[-0.54609169 -0.21372168 -1.57081975], -likelihood = -1091.22708
# Iteration=8, theta_new=[-0.54414271 -0.20934578 -1.57076623], -likelihood = -1091.64688
# Iteration=9, theta_new=[-0.54230685 -0.20532061 -1.57075933], -likelihood = -1091.99581
# Iteration=10, theta_new=[-0.5406015  -0.20161412 -1.57086335], -likelihood = -1092.28425
# Iteration=11, theta_new=[-0.53902143 -0.19823374 -1.5707548 ], -likelihood = -1092.52098
# Iteration=12, theta_new=[-0.53753537 -0.19510883 -1.57073338], -likelihood = -1092.71279
# Iteration=13, theta_new=[-0.53620929 -0.19228775 -1.57080014], -likelihood = -1092.86957
# Iteration=14, theta_new=[-0.53497191 -0.18969865 -1.57086958], -likelihood = -1092.99300
# Iteration=15, theta_new=[-0.53384067 -0.18732538 -1.57081627], -likelihood = -1093.09206
# Iteration=16, theta_new=[-0.53284046 -0.18516446 -1.57085144], -likelihood = -1093.17035
# Iteration=17, theta_new=[-0.53190604 -0.18319391 -1.57080244], -likelihood = -1093.23069
# Iteration=18, theta_new=[-0.53108231 -0.18138429 -1.57083389], -likelihood = -1093.27768
# Iteration=19, theta_new=[-0.53032264 -0.17972085 -1.5708018 ], -likelihood = -1093.31306
# Iteration=20, theta_new=[-0.52965342 -0.17819693 -1.57079901], -likelihood = -1093.33969
# 3-th start
# Iteration=1, theta_new=[-2.37590854  0.23990808  2.67686617], -likelihood = -328.40212
# Iteration=2, theta_new=[-2.40382791  0.24485155  2.66781047], -likelihood = -339.53708
# Iteration=3, theta_new=[-2.43168525  0.24981411  2.65900676], -likelihood = -354.20718
# Iteration=4, theta_new=[-2.45536803  0.25494718  2.65045871], -likelihood = -368.72942
# Iteration=5, theta_new=[-2.47384761  0.26023897  2.64235585], -likelihood = -380.32226
# Iteration=6, theta_new=[-2.48779311  0.26545465  2.6346998 ], -likelihood = -388.64635
# Iteration=7, theta_new=[-2.49839735  0.2706985   2.62760278], -likelihood = -394.48552
# Iteration=8, theta_new=[-2.50634486  0.27580818  2.62105784], -likelihood = -398.70257
# Iteration=9, theta_new=[-2.51232165  0.28067686  2.61514566], -likelihood = -401.79530
# Iteration=10, theta_new=[-2.51694362  0.2852296   2.6097894 ], -likelihood = -404.10072
# Iteration=11, theta_new=[-2.52049056  0.28951133  2.60496866], -likelihood = -405.85520
# Iteration=12, theta_new=[-2.52326483  0.2934398   2.60069395], -likelihood = -407.20371
# Iteration=13, theta_new=[-2.52541302  0.29705303  2.59690787], -likelihood = -408.23466
# Iteration=14, theta_new=[-2.52714028  0.30029106  2.59353802], -likelihood = -409.02578
# Iteration=15, theta_new=[-2.52850628  0.30328741  2.59058097], -likelihood = -409.62744
# Iteration=16, theta_new=[-2.52957516  0.30597282  2.5879407 ], -likelihood = -410.09321
# Iteration=17, theta_new=[-2.53043682  0.3083544   2.58568183], -likelihood = -410.44481
# Iteration=18, theta_new=[-2.53112721  0.31055177  2.58370353], -likelihood = -410.70805
# Iteration=19, theta_new=[-2.53175128  0.31245402  2.58191763], -likelihood = -410.91290
# Iteration=20, theta_new=[-2.53227898  0.31422544  2.58037963], -likelihood = -411.06198
# 4-th start
# Iteration=1, theta_new=[ 1.19972358  2.02546274 -2.64739727], -likelihood = -840.28195
# Iteration=2, theta_new=[ 1.28147656  1.98998863 -2.63417581], -likelihood = -926.56652
# Iteration=3, theta_new=[ 1.37549794  1.96349539 -2.62386963], -likelihood = -977.97121
# Iteration=4, theta_new=[ 1.57085194  1.94372664 -2.61564117], -likelihood = -1009.75374
# Iteration=5, theta_new=[ 1.57082426  1.92151872 -2.60947758], -likelihood = -1027.90538
# Iteration=6, theta_new=[ 1.57081332  1.90272772 -2.60446958], -likelihood = -1032.38377
# Iteration=7, theta_new=[ 1.570781    1.88696655 -2.6003703 ], -likelihood = -1035.17927
# Iteration=8, theta_new=[ 1.5707785   1.87383012 -2.59700164], -likelihood = -1036.86772
# Iteration=9, theta_new=[ 1.57072265  1.86296725 -2.59420365], -likelihood = -1037.84847
# Iteration=10, theta_new=[ 1.57075744  1.85404427 -2.59185251], -likelihood = -1038.38647
# Iteration=11, theta_new=[ 1.57077708  1.84674289 -2.58986775], -likelihood = -1038.65487
# Iteration=12, theta_new=[ 1.57069177  1.84083172 -2.58819001], -likelihood = -1038.76406
# Iteration=13, theta_new=[ 1.57082918  1.83604033 -2.58676811], -likelihood = -1038.78262
# Iteration=14, theta_new=[ 1.57077524  1.83218256 -2.58554523], -likelihood = -1038.75314
# Iteration=15, theta_new=[ 1.57076904  1.82908378 -2.58450263], -likelihood = -1038.70069
# Iteration=16, theta_new=[ 1.57056537  1.82658501 -2.58361356], -likelihood = -1038.63997
# Iteration=17, theta_new=[ 1.5707831   1.82459666 -2.58285448], -likelihood = -1038.57880
# Iteration=18, theta_new=[ 1.57077375  1.82300373 -2.58219087], -likelihood = -1038.52194
# Iteration=19, theta_new=[ 1.57075708  1.82174347 -2.58161937], -likelihood = -1038.47058
# Iteration=20, theta_new=[ 1.57083453  1.82074367 -2.58113   ], -likelihood = -1038.42592
# 5-th start
# Iteration=1, theta_new=[-0.07496382 -1.14947587 -2.6479383 ], -likelihood = -692.27334
# Iteration=2, theta_new=[-0.07875339 -1.22112817 -2.64291551], -likelihood = -838.28958
# Iteration=3, theta_new=[-0.08276666 -1.28617451 -2.63813286], -likelihood = -934.91300
# Iteration=4, theta_new=[-0.08649536 -1.34683775 -2.63313561], -likelihood = -993.95130
# Iteration=5, theta_new=[-0.08981856 -1.40643746 -2.62798745], -likelihood = -1028.92522
# Iteration=6, theta_new=[-0.09282785 -1.47270108 -2.62289806], -likelihood = -1049.39875
# Iteration=7, theta_new=[-0.09550175 -1.57080018 -2.61791328], -likelihood = -1061.05708
# Iteration=8, theta_new=[-0.09787974 -1.5707501  -2.61306339], -likelihood = -1064.12698
# Iteration=9, theta_new=[-0.10009174 -1.57076051 -2.60864222], -likelihood = -1064.50032
# Iteration=10, theta_new=[-0.10216273 -1.57081629 -2.60459102], -likelihood = -1064.79918
# Iteration=11, theta_new=[-0.10413137 -1.57083937 -2.60087958], -likelihood = -1065.03827
# Iteration=12, theta_new=[-0.10596822 -1.570829   -2.59750465], -likelihood = -1065.22909
# Iteration=13, theta_new=[-0.10769922 -1.57078729 -2.5944447 ], -likelihood = -1065.37867
# Iteration=14, theta_new=[-0.1093053  -1.5708257  -2.59165616], -likelihood = -1065.49533
# Iteration=15, theta_new=[-0.1108272  -1.57080997 -2.58912638], -likelihood = -1065.58515
# Iteration=16, theta_new=[-0.11225323 -1.57078089 -2.58681407], -likelihood = -1065.65417
# Iteration=17, theta_new=[-0.11360725 -1.57074607 -2.58472027], -likelihood = -1065.70632
# Iteration=18, theta_new=[-0.11489828 -1.57075645 -2.58283047], -likelihood = -1065.74539
# Iteration=19, theta_new=[-0.11612019 -1.5708215  -2.58110516], -likelihood = -1065.77437
# Iteration=20, theta_new=[-0.11727388 -1.57079075 -2.57953258], -likelihood = -1065.79520
# 6-th start
# Iteration=1, theta_new=[ 2.7203899  -1.57078296  0.375135  ], -likelihood = -1028.93562
# Iteration=2, theta_new=[ 2.66591308 -1.57077113  0.37702256], -likelihood = -1045.86501
# Iteration=3, theta_new=[ 2.62905513 -1.57079016  0.37638189], -likelihood = -1066.26394
# Iteration=4, theta_new=[ 2.60230819 -1.57081997  0.37662544], -likelihood = -1078.22365
# Iteration=5, theta_new=[ 2.58112064 -1.57076511  0.3782014 ], -likelihood = -1085.26369
# Iteration=6, theta_new=[ 2.5631875  -1.57074169  0.38092132], -likelihood = -1090.03764
# Iteration=7, theta_new=[ 2.54712741 -1.57081407  0.38457511], -likelihood = -1093.77518
# Iteration=8, theta_new=[ 2.53207384 -1.57081937  0.38892107], -likelihood = -1097.08057
# Iteration=9, theta_new=[ 2.51746201 -1.57073142  0.39378612], -likelihood = -1100.26438
# Iteration=10, theta_new=[ 2.50284934 -1.57082879  0.39904904], -likelihood = -1103.49513
# Iteration=11, theta_new=[ 2.48805741 -1.57079584  0.40460547], -likelihood = -1106.87908
# Iteration=12, theta_new=[ 2.47284476 -1.57083243  0.4103347 ], -likelihood = -1110.44789
# Iteration=13, theta_new=[ 2.45716163 -1.57088954  0.41616838], -likelihood = -1114.22162
# Iteration=14, theta_new=[ 2.44107527 -1.57076371  0.42203337], -likelihood = -1118.17080
# Iteration=15, theta_new=[ 2.42463685 -1.57083215  0.42786485], -likelihood = -1122.22407
# Iteration=16, theta_new=[ 2.40797442 -1.57081788  0.43359252], -likelihood = -1126.29996
# Iteration=17, theta_new=[ 2.39131986 -1.5708352   0.43915252], -likelihood = -1130.29361
# Iteration=18, theta_new=[ 2.37488188 -1.57079314  0.44450574], -likelihood = -1134.08465
# Iteration=19, theta_new=[ 2.35890538 -1.57076658  0.44959985], -likelihood = -1137.57536
# Iteration=20, theta_new=[ 2.34358214 -1.57079466  0.45441983], -likelihood = -1140.68351
# 7-th start
# Iteration=1, theta_new=[-0.81008305 -1.0546464  -1.35384064], -likelihood = -987.04616
# Iteration=2, theta_new=[-0.7743399  -1.04347835 -1.41966543], -likelihood = -1027.65841
# Iteration=3, theta_new=[-0.73835834 -1.03764828 -1.51757887], -likelihood = -1055.62416
# Iteration=4, theta_new=[-0.71100278 -1.03430906 -1.57079104], -likelihood = -1072.50681
# Iteration=5, theta_new=[-0.68860907 -1.0303839  -1.57080114], -likelihood = -1078.74721
# Iteration=6, theta_new=[-0.66988125 -1.02553652 -1.57076239], -likelihood = -1083.65252
# Iteration=7, theta_new=[-0.65412481 -1.02023686 -1.57080387], -likelihood = -1087.49044
# Iteration=8, theta_new=[-0.64084997 -1.01473424 -1.57076714], -likelihood = -1090.47089
# Iteration=9, theta_new=[-0.62958559 -1.00918594 -1.57073627], -likelihood = -1092.77197
# Iteration=10, theta_new=[-0.62002458 -1.00374902 -1.5708089 ], -likelihood = -1094.55208
# Iteration=11, theta_new=[-0.61185848 -0.99856017 -1.57075231], -likelihood = -1095.92333
# Iteration=12, theta_new=[-0.60481252 -0.99360944 -1.5707678 ], -likelihood = -1096.97953
# Iteration=13, theta_new=[-0.59876254 -0.98892335 -1.57080292], -likelihood = -1097.79911
# Iteration=14, theta_new=[-0.59357704 -0.9845611  -1.57080607], -likelihood = -1098.43099
# Iteration=15, theta_new=[-0.58904035 -0.9804917  -1.57083459], -likelihood = -1098.91496
# Iteration=16, theta_new=[-0.58508782 -0.97669307 -1.57075526], -likelihood = -1099.29049
# Iteration=17, theta_new=[-0.58163208 -0.97317978 -1.57081159], -likelihood = -1099.57983
# Iteration=18, theta_new=[-0.57862478 -0.96998335 -1.57076654], -likelihood = -1099.80152
# Iteration=19, theta_new=[-0.57597246 -0.96702681 -1.57078475], -likelihood = -1099.96901
# Iteration=20, theta_new=[-0.57364064 -0.96428529 -1.57083132], -likelihood = -1100.09628
# 8-th start
# Iteration=1, theta_new=[-1.70660109 -2.42321058  3.01110097], -likelihood = -784.43815
# Iteration=2, theta_new=[-1.65954533 -2.43738859  3.01187721], -likelihood = -790.65975
# Iteration=3, theta_new=[-1.57082109 -2.45026554  3.0127253 ], -likelihood = -795.21964
# Iteration=4, theta_new=[-1.57079997 -2.46120609  3.0136206 ], -likelihood = -798.12043
# Iteration=5, theta_new=[-1.570816   -2.47074172  3.01442363], -likelihood = -799.60077
# Iteration=6, theta_new=[-1.5707833  -2.47896292  3.01516159], -likelihood = -800.80984
# Iteration=7, theta_new=[-1.57076641 -2.48598897  3.01586182], -likelihood = -801.78195
# Iteration=8, theta_new=[-1.57074557 -2.49196973  3.01654721], -likelihood = -802.55516
# Iteration=9, theta_new=[-1.57082559 -2.49705032  3.0172247 ], -likelihood = -803.16806
# Iteration=10, theta_new=[-1.57080409 -2.5013555   3.01790219], -likelihood = -803.65389
# Iteration=11, theta_new=[-1.57076532 -2.50500933  3.01861566], -likelihood = -804.03965
# Iteration=12, theta_new=[-1.57076312 -2.50811228  3.01934364], -likelihood = -804.34903
# Iteration=13, theta_new=[-1.5708613  -2.51072454  3.02010829], -likelihood = -804.59854
# Iteration=14, theta_new=[-1.57077661 -2.51294433  3.02089874], -likelihood = -804.80046
# Iteration=15, theta_new=[-1.57081793 -2.51483866  3.02172808], -likelihood = -804.96663
# Iteration=16, theta_new=[-1.5708422  -2.51643505  3.02257788], -likelihood = -805.10564
# Iteration=17, theta_new=[-1.57079795 -2.5177867   3.02347359], -likelihood = -805.22160
# Iteration=18, theta_new=[-1.57083682 -2.51893825  3.02440744], -likelihood = -805.32053
# Iteration=19, theta_new=[-1.57079569 -2.5199265   3.02538689], -likelihood = -805.40626
# Iteration=20, theta_new=[-1.57081558 -2.5207582   3.02641149], -likelihood = -805.48205
# 9-th start
# Iteration=1, theta_new=[-2.92821881  1.12506812  0.61817715], -likelihood = -905.62605
# Iteration=2, theta_new=[-2.93242932  1.17081327  0.61698908], -likelihood = -978.60115
# Iteration=3, theta_new=[-2.93679601  1.21060234  0.61328791], -likelihood = -1029.88225
# Iteration=4, theta_new=[-2.94124718  1.24441378  0.60793757], -likelihood = -1063.86560
# Iteration=5, theta_new=[-2.94573943  1.27255849  0.60152504], -likelihood = -1085.54401
# Iteration=6, theta_new=[-2.95020648  1.29566634  0.59452719], -likelihood = -1099.20002
# Iteration=7, theta_new=[-2.95468077  1.31434268  0.58725757], -likelihood = -1107.93499
# Iteration=8, theta_new=[-2.95911577  1.32933338  0.57990224], -likelihood = -1113.72318
# Iteration=9, theta_new=[-2.96339448  1.34119211  0.57263877], -likelihood = -1117.78197
# Iteration=10, theta_new=[-2.96767169  1.35051012  0.56556533], -likelihood = -1120.77863
# Iteration=11, theta_new=[-2.97179439  1.35782069  0.55879265], -likelihood = -1123.12052
# Iteration=12, theta_new=[-2.97573583  1.36353207  0.55240054], -likelihood = -1125.01018
# Iteration=13, theta_new=[-2.97955775  1.36795521  0.54644268], -likelihood = -1126.56333
# Iteration=14, theta_new=[-2.98315012  1.37131152  0.54089999], -likelihood = -1127.85347
# Iteration=15, theta_new=[-2.98647772  1.37388779  0.53585653], -likelihood = -1128.92859
# Iteration=16, theta_new=[-2.98966947  1.3758252   0.53124808], -likelihood = -1129.81171
# Iteration=17, theta_new=[-2.99268991  1.37730666  0.52704902], -likelihood = -1130.54568
# Iteration=18, theta_new=[-2.99543155  1.37838367  0.52325091], -likelihood = -1131.15254
# Iteration=19, theta_new=[-2.99787772  1.37924419  0.51980547], -likelihood = -1131.64660
# Iteration=20, theta_new=[-3.00020886  1.37992336  0.51675416], -likelihood = -1132.04699
# 10-th start
# Iteration=1, theta_new=[-1.57075313  2.44767273 -1.87848637], -likelihood = -940.24048
# Iteration=2, theta_new=[-1.57083807  2.45035022 -1.8207686 ], -likelihood = -1001.62103
# Iteration=3, theta_new=[-1.57074719  2.45341626 -1.76502747], -likelihood = -1027.69577
# Iteration=4, theta_new=[-1.57083118  2.45713767 -1.70763796], -likelihood = -1045.10377
# Iteration=5, theta_new=[-1.57082282  2.46158907 -1.63491638], -likelihood = -1056.29508
# Iteration=6, theta_new=[-1.57086296  2.46619267 -1.57078135], -likelihood = -1062.38842
# Iteration=7, theta_new=[-1.57077365  2.47115106 -1.57080403], -likelihood = -1063.30408
# Iteration=8, theta_new=[-1.57076167  2.47666535 -1.570784  ], -likelihood = -1063.88012
# Iteration=9, theta_new=[-1.57073877  2.48276415 -1.57081523], -likelihood = -1064.59229
# Iteration=10, theta_new=[-1.57076616  2.48946927 -1.57079543], -likelihood = -1065.46390
# Iteration=11, theta_new=[-1.57083822  2.49676967 -1.57079413], -likelihood = -1066.51750
# Iteration=12, theta_new=[-1.57072663  2.50462107 -1.57078803], -likelihood = -1067.76806
# Iteration=13, theta_new=[-1.57076656  2.51296677 -1.57080996], -likelihood = -1069.21840
# Iteration=14, theta_new=[-1.57083347  2.52169749 -1.57080633], -likelihood = -1070.85919
# Iteration=15, theta_new=[-1.57075078  2.5306844  -1.57080026], -likelihood = -1072.65858
# Iteration=16, theta_new=[-1.57080931  2.53977349 -1.57081876], -likelihood = -1074.56790
# Iteration=17, theta_new=[-1.57078199  2.54880332 -1.57077237], -likelihood = -1076.52335
# Iteration=18, theta_new=[-1.57080225  2.55763142 -1.57076793], -likelihood = -1078.45531
# Iteration=19, theta_new=[-1.57075409  2.56611763 -1.57080485], -likelihood = -1080.30059
# Iteration=20, theta_new=[-1.5707563   2.57415926 -1.57080724], -likelihood = -1082.00460
# 11-th start
# Iteration=1, theta_new=[-0.64784045  0.68258828 -1.05377793], -likelihood = -583.34653
# Iteration=2, theta_new=[-0.66319001  0.66789965 -1.12839619], -likelihood = -744.19425
# Iteration=3, theta_new=[-0.67480784  0.65547485 -1.1976673 ], -likelihood = -881.99567
# Iteration=4, theta_new=[-0.68157695  0.64453067 -1.26141003], -likelihood = -981.38511
# Iteration=5, theta_new=[-0.68412509  0.63436146 -1.32054074], -likelihood = -1046.32360
# Iteration=6, theta_new=[-0.68349817  0.62461535 -1.37677552], -likelihood = -1086.64066
# Iteration=7, theta_new=[-0.6806186   0.61507591 -1.43333213], -likelihood = -1111.18618
# Iteration=8, theta_new=[-0.67616317  0.6057635  -1.50120257], -likelihood = -1126.22279
# Iteration=9, theta_new=[-0.6715222   0.5968681  -1.57078885], -likelihood = -1134.94014
# Iteration=10, theta_new=[-0.6669596   0.5882843  -1.57084951], -likelihood = -1137.65863
# Iteration=11, theta_new=[-0.66231691  0.57996664 -1.57067786], -likelihood = -1139.52973
# Iteration=12, theta_new=[-0.65766147  0.57201839 -1.57077425], -likelihood = -1141.31462
# Iteration=13, theta_new=[-0.65296318  0.56451463 -1.57082139], -likelihood = -1142.97452
# Iteration=14, theta_new=[-0.64828661  0.55752496 -1.5707602 ], -likelihood = -1144.48933
# Iteration=15, theta_new=[-0.64364285  0.5510682  -1.57082526], -likelihood = -1145.84370
# Iteration=16, theta_new=[-0.63906133  0.54515558 -1.57076097], -likelihood = -1147.04000
# Iteration=17, theta_new=[-0.63453825  0.53979439 -1.57083265], -likelihood = -1148.08506
# Iteration=18, theta_new=[-0.63009045  0.53494735 -1.57079499], -likelihood = -1148.99090
# Iteration=19, theta_new=[-0.62571437  0.53060925 -1.57078264], -likelihood = -1149.77470
# Iteration=20, theta_new=[-0.62147494  0.52672927 -1.57084228], -likelihood = -1150.45063
# 12-th start
# Iteration=1, theta_new=[-1.57077707  2.92527939 -0.96329244], -likelihood = -781.02694
# Iteration=2, theta_new=[-1.57083407  2.91996871 -1.01527431], -likelihood = -802.88860
# Iteration=3, theta_new=[-1.57083166  2.91534299 -1.07451741], -likelihood = -825.37189
# Iteration=4, theta_new=[-1.57085616  2.91184342 -1.13598423], -likelihood = -855.67073
# Iteration=5, theta_new=[-1.57081002  2.909269   -1.19640919], -likelihood = -891.26066
# Iteration=6, theta_new=[-1.57079524  2.90707528 -1.25435209], -likelihood = -927.38517
# Iteration=7, theta_new=[-1.57074227  2.90476022 -1.30967097], -likelihood = -959.05156
# Iteration=8, theta_new=[-1.57080843  2.90198867 -1.36334266], -likelihood = -983.62708
# Iteration=9, theta_new=[-1.57082624  2.89855524 -1.41785383], -likelihood = -1001.17045
# Iteration=10, theta_new=[-1.57083873  2.8943308  -1.48082688], -likelihood = -1013.13136
# Iteration=11, theta_new=[-1.57075473  2.88927221 -1.5707786 ], -likelihood = -1020.89938
# Iteration=12, theta_new=[-1.57078263  2.88336566 -1.5708122 ], -likelihood = -1023.14804
# Iteration=13, theta_new=[-1.57080176  2.87649703 -1.57078643], -likelihood = -1024.06744
# Iteration=14, theta_new=[-1.57077225  2.86852042 -1.57078201], -likelihood = -1025.32247
# Iteration=15, theta_new=[-1.57082689  2.85928729 -1.57080956], -likelihood = -1027.03128
# Iteration=16, theta_new=[-1.57081228  2.84866776 -1.5707976 ], -likelihood = -1029.33901
# Iteration=17, theta_new=[-1.57081433  2.83663338 -1.57078012], -likelihood = -1032.40500
# Iteration=18, theta_new=[-1.57086709  2.82326966 -1.57079977], -likelihood = -1036.35230
# Iteration=19, theta_new=[-1.57077068  2.80883362 -1.57081638], -likelihood = -1041.21399
# Iteration=20, theta_new=[-1.57077911  2.79375286 -1.5707747 ], -likelihood = -1046.86292
# 13-th start
# Iteration=1, theta_new=[-1.43467241  2.50538514 -2.34575334], -likelihood = -816.35746
# Iteration=2, theta_new=[-1.48543285  2.51459657 -2.35734639], -likelihood = -825.46090
# Iteration=3, theta_new=[-1.57076468  2.52332736 -2.36946645], -likelihood = -831.56019
# Iteration=4, theta_new=[-1.57083874  2.53179146 -2.38221998], -likelihood = -835.77119
# Iteration=5, theta_new=[-1.57085407  2.53994153 -2.39608133], -likelihood = -839.22304
# Iteration=6, theta_new=[-1.57080532  2.54778179 -2.41050896], -likelihood = -842.78986
# Iteration=7, theta_new=[-1.57077291  2.5552988  -2.42483296], -likelihood = -846.33549
# Iteration=8, theta_new=[-1.57077629  2.5624216  -2.43849422], -likelihood = -849.71450
# Iteration=9, theta_new=[-1.57083396  2.569083   -2.45110216], -likelihood = -852.81188
# Iteration=10, theta_new=[-1.5707932   2.57521418 -2.46241375], -likelihood = -855.56284
# Iteration=11, theta_new=[-1.57082653  2.5807796  -2.47234853], -likelihood = -857.93979
# Iteration=12, theta_new=[-1.57080617  2.5857657  -2.48094351], -likelihood = -859.95077
# Iteration=13, theta_new=[-1.57083611  2.59019397 -2.48831355], -likelihood = -861.62455
# Iteration=14, theta_new=[-1.57080783  2.59408791 -2.49458019], -likelihood = -863.00361
# Iteration=15, theta_new=[-1.57077802  2.59749807 -2.49987291], -likelihood = -864.12898
# Iteration=16, theta_new=[-1.57079463  2.60047344 -2.50433105], -likelihood = -865.04298
# Iteration=17, theta_new=[-1.57080321  2.60307013 -2.50808517], -likelihood = -865.78408
# Iteration=18, theta_new=[-1.57075231  2.60533647 -2.51124508], -likelihood = -866.38637
# Iteration=19, theta_new=[-1.57080541  2.60729384 -2.51388799], -likelihood = -866.87713
# Iteration=20, theta_new=[-1.57081823  2.60900743 -2.51612422], -likelihood = -867.27496
# 14-th start
# Iteration=1, theta_new=[ 1.15021458  2.26595326 -1.00135682], -likelihood = -773.93886
# Iteration=2, theta_new=[ 1.20241503  2.2430087  -1.06947724], -likelihood = -904.80583
# Iteration=3, theta_new=[ 1.24233917  2.21516314 -1.12569236], -likelihood = -978.90462
# Iteration=4, theta_new=[ 1.26875896  2.18837472 -1.1704867 ], -likelihood = -1021.69766
# Iteration=5, theta_new=[ 1.28354111  2.16555576 -1.20603774], -likelihood = -1045.95732
# Iteration=6, theta_new=[ 1.2907455   2.14736876 -1.23436628], -likelihood = -1059.15766
# Iteration=7, theta_new=[ 1.29377187  2.13345788 -1.25696369], -likelihood = -1066.14150
# Iteration=8, theta_new=[ 1.2951327   2.12316826 -1.27498057], -likelihood = -1069.76682
# Iteration=9, theta_new=[ 1.29555391  2.11574221 -1.28933363], -likelihood = -1071.60988
# Iteration=10, theta_new=[ 1.29551022  2.11054913 -1.30074859], -likelihood = -1072.52634
# Iteration=11, theta_new=[ 1.29529629  2.10704119 -1.30985438], -likelihood = -1072.96870
# Iteration=12, theta_new=[ 1.29507581  2.10480662 -1.31714412], -likelihood = -1073.17708
# Iteration=13, theta_new=[ 1.29485464  2.10350424 -1.32302121], -likelihood = -1073.27606
# Iteration=14, theta_new=[ 1.29465651  2.10288619 -1.32780624], -likelihood = -1073.32880
# Iteration=15, theta_new=[ 1.2944999   2.1027838  -1.33173172], -likelihood = -1073.36600
# Iteration=16, theta_new=[ 1.29430871  2.10302842 -1.33498634], -likelihood = -1073.40225
# Iteration=17, theta_new=[ 1.29411171  2.10351575 -1.33772526], -likelihood = -1073.44196
# Iteration=18, theta_new=[ 1.29388366  2.10418629 -1.34005384], -likelihood = -1073.48627
# Iteration=19, theta_new=[ 1.29381339  2.10495131 -1.34210338], -likelihood = -1073.53581
# Iteration=20, theta_new=[ 1.29368364  2.10578418 -1.34391876], -likelihood = -1073.58659
# 15-th start
# Iteration=1, theta_new=[-2.52801508 -2.1741924   0.14184487], -likelihood = -375.97160
# Iteration=2, theta_new=[-2.51177638 -2.09481189  0.147098  ], -likelihood = -514.92297
# Iteration=3, theta_new=[-2.4970827  -2.01941177  0.15252669], -likelihood = -680.49142
# Iteration=4, theta_new=[-2.48695582 -1.95090204  0.15629511], -likelihood = -817.23494
# Iteration=5, theta_new=[-2.48177967 -1.88866186  0.15826756], -likelihood = -911.35466
# Iteration=6, theta_new=[-2.48055844 -1.83150681  0.15883744], -likelihood = -971.47048
# Iteration=7, theta_new=[-2.48213936 -1.77777253  0.15849155], -likelihood = -1008.49360
# Iteration=8, theta_new=[-2.48566165 -1.72481642  0.15743337], -likelihood = -1030.90431
# Iteration=9, theta_new=[-2.49049475 -1.66681867  0.15603987], -likelihood = -1044.43810
# Iteration=10, theta_new=[-2.49593587 -1.57082852  0.15431615], -likelihood = -1052.58795
# Iteration=11, theta_new=[-2.50087963 -1.57078417  0.15237883], -likelihood = -1055.35605
# Iteration=12, theta_new=[-2.50564284 -1.57077018  0.15043888], -likelihood = -1055.80300
# Iteration=13, theta_new=[-2.51020097 -1.57076614  0.14847368], -likelihood = -1056.23762
# Iteration=14, theta_new=[-2.51455916 -1.57081535  0.14650636], -likelihood = -1056.65823
# Iteration=15, theta_new=[-2.51873284 -1.57077345  0.14452939], -likelihood = -1057.06237
# Iteration=16, theta_new=[-2.52271028 -1.57077342  0.14255016], -likelihood = -1057.45050
# Iteration=17, theta_new=[-2.52646101 -1.57075727  0.14056188], -likelihood = -1057.82065
# Iteration=18, theta_new=[-2.53000541 -1.57084449  0.13854532], -likelihood = -1058.17098
# Iteration=19, theta_new=[-2.53335518 -1.570813    0.1365668 ], -likelihood = -1058.50377
# Iteration=20, theta_new=[-2.53651571 -1.57081449  0.13455992], -likelihood = -1058.81548
# 16-th start
# Iteration=1, theta_new=[-2.6071685   0.36079101 -1.84567698], -likelihood = -993.80565
# Iteration=2, theta_new=[-2.60588541  0.37554203 -1.78374988], -likelihood = -1060.25121
# Iteration=3, theta_new=[-2.60482858  0.38966315 -1.72306026], -likelihood = -1100.22892
# Iteration=4, theta_new=[-2.60395982  0.40258425 -1.65338346], -likelihood = -1124.21277
# Iteration=5, theta_new=[-2.60310505  0.41410572 -1.5707934 ], -likelihood = -1138.17408
# Iteration=6, theta_new=[-2.60228989  0.42433158 -1.57082252], -likelihood = -1143.01448
# Iteration=7, theta_new=[-2.60154041  0.43340926 -1.57080223], -likelihood = -1145.72279
# Iteration=8, theta_new=[-2.60082186  0.44142187 -1.5707907 ], -likelihood = -1147.85713
# Iteration=9, theta_new=[-2.60016051  0.44844803 -1.57075062], -likelihood = -1149.51995
# Iteration=10, theta_new=[-2.59954088  0.45461301 -1.57080625], -likelihood = -1150.80190
# Iteration=11, theta_new=[-2.59893879  0.45997882 -1.5707993 ], -likelihood = -1151.78838
# Iteration=12, theta_new=[-2.59837755  0.46465576 -1.57082479], -likelihood = -1152.54041
# Iteration=13, theta_new=[-2.59783612  0.46873257 -1.57077953], -likelihood = -1153.11434
# Iteration=14, theta_new=[-2.59731806  0.47227849 -1.5708019 ], -likelihood = -1153.55242
# Iteration=15, theta_new=[-2.5968539   0.47537178 -1.5708367 ], -likelihood = -1153.88624
# Iteration=16, theta_new=[-2.59642325  0.47806163 -1.57079365], -likelihood = -1154.14159
# Iteration=17, theta_new=[-2.59599655  0.48040761 -1.57076371], -likelihood = -1154.33649
# Iteration=18, theta_new=[-2.59561547  0.48245294 -1.57078861], -likelihood = -1154.48583
# Iteration=19, theta_new=[-2.59524385  0.48423647 -1.57085231], -likelihood = -1154.60041
# Iteration=20, theta_new=[-2.59490054  0.4857933  -1.57077951], -likelihood = -1154.68838
# 17-th start
# Iteration=1, theta_new=[-2.54290299  2.00965116  1.35676636], -likelihood = -1030.00965
# Iteration=2, theta_new=[-2.54590183  2.04723561  1.4205517 ], -likelihood = -1092.05418
# Iteration=3, theta_new=[-2.54757308  2.07033737  1.48466194], -likelihood = -1116.71412
# Iteration=4, theta_new=[-2.54883326  2.08503588  1.57082365], -likelihood = -1126.83259
# Iteration=5, theta_new=[-2.55020241  2.09459896  1.57076339], -likelihood = -1129.87421
# Iteration=6, theta_new=[-2.55137339  2.10292374  1.57077301], -likelihood = -1131.38614
# Iteration=7, theta_new=[-2.55237737  2.11019331  1.57081971], -likelihood = -1132.58752
# Iteration=8, theta_new=[-2.55326081  2.11656919  1.57079828], -likelihood = -1133.55104
# Iteration=9, theta_new=[-2.55405407  2.12217791  1.57082254], -likelihood = -1134.33191
# Iteration=10, theta_new=[-2.55472822  2.12709885  1.57077722], -likelihood = -1134.97023
# Iteration=11, theta_new=[-2.55533102  2.13147504  1.57075852], -likelihood = -1135.49300
# Iteration=12, theta_new=[-2.55586499  2.13535149  1.57076069], -likelihood = -1135.92926
# Iteration=13, theta_new=[-2.55635207  2.13880275  1.57080534], -likelihood = -1136.29344
# Iteration=14, theta_new=[-2.55679007  2.14185436  1.57078976], -likelihood = -1136.60038
# Iteration=15, theta_new=[-2.5571828   2.14460054  1.57082225], -likelihood = -1136.85832
# Iteration=16, theta_new=[-2.55752939  2.14703758  1.57082352], -likelihood = -1137.07966
# Iteration=17, theta_new=[-2.5578451   2.14920656  1.5707538 ], -likelihood = -1137.26759
# Iteration=18, theta_new=[-2.55813355  2.15116187  1.57081196], -likelihood = -1137.42826
# Iteration=19, theta_new=[-2.55840964  2.15291131  1.5708208 ], -likelihood = -1137.56780
# Iteration=20, theta_new=[-2.55864187  2.154473    1.57075769], -likelihood = -1137.68851
# 18-th start
# Iteration=1, theta_new=[ 2.63639546  0.03185019 -1.81001457], -likelihood = -1042.69388
# Iteration=2, theta_new=[ 2.63645314  0.02976939 -1.75260769], -likelihood = -1081.45094
# Iteration=3, theta_new=[ 2.63681991  0.02793636 -1.69373596], -likelihood = -1103.68266
# Iteration=4, theta_new=[ 2.63732989  0.02619816 -1.61313653], -likelihood = -1116.29160
# Iteration=5, theta_new=[ 2.63792286  0.02452348 -1.57082166], -likelihood = -1121.72680
# Iteration=6, theta_new=[ 2.63846456  0.02277984 -1.57079534], -likelihood = -1121.99752
# Iteration=7, theta_new=[ 2.63889326  0.02095762 -1.57082185], -likelihood = -1122.07631
# Iteration=8, theta_new=[ 2.63928716  0.01905193 -1.57078681], -likelihood = -1122.16050
# Iteration=9, theta_new=[ 2.63961362  0.01708507 -1.57079541], -likelihood = -1122.25158
# Iteration=10, theta_new=[ 2.63986154  0.01502215 -1.57080342], -likelihood = -1122.34891
# Iteration=11, theta_new=[ 2.64007315  0.0128663  -1.5708091 ], -likelihood = -1122.45482
# Iteration=12, theta_new=[ 2.6402623   0.01060136 -1.5707629 ], -likelihood = -1122.57001
# Iteration=13, theta_new=[ 2.64042736  0.0082416  -1.57077177], -likelihood = -1122.69607
# Iteration=14, theta_new=[ 2.64056528  0.0057564  -1.57082577], -likelihood = -1122.83284
# Iteration=15, theta_new=[ 2.64067897  0.0031643  -1.57079304], -likelihood = -1122.98280
# Iteration=16, theta_new=[ 2.64077082e+00  4.66707044e-04 -1.57080001e+00], -likelihood = -1123.14552
# Iteration=17, theta_new=[ 2.64084387e+00 -2.31736442e-03 -1.57073883e+00], -likelihood = -1123.32150
# Iteration=18, theta_new=[ 2.64089008 -0.00523395 -1.57076181], -likelihood = -1123.50992
# Iteration=19, theta_new=[ 2.64099251 -0.00823753 -1.57082566], -likelihood = -1123.71434
# Iteration=20, theta_new=[ 2.64107621 -0.01135166 -1.57083944], -likelihood = -1123.93205
# 19-th start
# Iteration=1, theta_new=[2.70826726 1.71878889 2.74061102], -likelihood = -1047.11643
# Iteration=2, theta_new=[2.65108162 1.7332469  2.7381514 ], -likelihood = -1058.77917
# Iteration=3, theta_new=[2.60898607 1.74350918 2.73902533], -likelihood = -1078.67125
# Iteration=4, theta_new=[2.57773656 1.75127674 2.73927912], -likelihood = -1092.96099
# Iteration=5, theta_new=[2.55252224 1.7573215  2.73819929], -likelihood = -1102.14474
# Iteration=6, theta_new=[2.53076281 1.76203016 2.73596372], -likelihood = -1108.68740
# Iteration=7, theta_new=[2.51124854 1.76572331 2.73285196], -likelihood = -1113.91051
# Iteration=8, theta_new=[2.49321744 1.76861896 2.72908676], -likelihood = -1118.40439
# Iteration=9, theta_new=[2.47624156 1.77072297 2.72489354], -likelihood = -1122.46544
# Iteration=10, theta_new=[2.46014154 1.77222086 2.72048874], -likelihood = -1126.21818
# Iteration=11, theta_new=[2.44478611 1.77305864 2.71593718], -likelihood = -1129.69293
# Iteration=12, theta_new=[2.4301414  1.77333383 2.71139211], -likelihood = -1132.90643
# Iteration=13, theta_new=[2.41625872 1.77308786 2.7069053 ], -likelihood = -1135.84286
# Iteration=14, theta_new=[2.40315809 1.77240413 2.70253793], -likelihood = -1138.48792
# Iteration=15, theta_new=[2.39074884 1.77126043 2.69835141], -likelihood = -1140.83791
# Iteration=16, theta_new=[2.3791402  1.76981836 2.6943493 ], -likelihood = -1142.91033
# Iteration=17, theta_new=[2.36828351 1.76794643 2.69054692], -likelihood = -1144.70665
# Iteration=18, theta_new=[2.35810728 1.76583853 2.6870143 ], -likelihood = -1146.25454
# Iteration=19, theta_new=[2.34864158 1.7634102  2.68368892], -likelihood = -1147.57397
# Iteration=20, theta_new=[2.33986622 1.76084174 2.68059234], -likelihood = -1148.69284
# 20-th start
# Iteration=1, theta_new=[ 2.37150768  0.42660708 -2.78100479], -likelihood = -319.04387
# Iteration=2, theta_new=[ 2.35455613  0.4327558  -2.78370608], -likelihood = -322.28954
# Iteration=3, theta_new=[ 2.32611226  0.4394658  -2.78700066], -likelihood = -329.35713
# Iteration=4, theta_new=[ 2.27968448  0.44689836 -2.79118503], -likelihood = -347.22507
# Iteration=5, theta_new=[ 2.21560769  0.45447022 -2.79649588], -likelihood = -391.89728
# Iteration=6, theta_new=[ 2.14539882  0.46085941 -2.80255267], -likelihood = -475.91784
# Iteration=7, theta_new=[ 2.07912517  0.4654393  -2.80850928], -likelihood = -579.99165
# Iteration=8, theta_new=[ 2.02059325  0.46877192 -2.81385876], -likelihood = -671.72511
# Iteration=9, theta_new=[ 1.97049251  0.47165642 -2.81856907], -likelihood = -737.31112
# Iteration=10, theta_new=[ 1.92829693  0.47442372 -2.82278252], -likelihood = -779.04091
# Iteration=11, theta_new=[ 1.89311293  0.47727611 -2.82678834], -likelihood = -804.06329
# Iteration=12, theta_new=[ 1.86407151  0.48015676 -2.83062237], -likelihood = -818.68203
# Iteration=13, theta_new=[ 1.84041813  0.48303526 -2.83449945], -likelihood = -827.13770
# Iteration=14, theta_new=[ 1.82140858  0.48588185 -2.83835544], -likelihood = -832.04725
# Iteration=15, theta_new=[ 1.80627106  0.48866329 -2.84230109], -likelihood = -834.94836
# Iteration=16, theta_new=[ 1.79437218  0.49134391 -2.8463579 ], -likelihood = -836.74239
# Iteration=17, theta_new=[ 1.78510702  0.49388429 -2.85052745], -likelihood = -837.92857
# Iteration=18, theta_new=[ 1.7779729   0.49624263 -2.85481194], -likelihood = -838.78981
# Iteration=19, theta_new=[ 1.7726049   0.49846008 -2.85924466], -likelihood = -839.48484
# Iteration=20, theta_new=[ 1.76864919  0.50051248 -2.86377103], -likelihood = -840.10671
# 21-th start
# Iteration=1, theta_new=[-0.17689422 -0.40828844  0.33215476], -likelihood = -287.29235
# Iteration=2, theta_new=[-0.17555625 -0.41735245  0.33866525], -likelihood = -290.62798
# Iteration=3, theta_new=[-0.17545863 -0.42723291  0.34466797], -likelihood = -293.90114
# Iteration=4, theta_new=[-0.17634729 -0.43803968  0.35015291], -likelihood = -297.29119
# Iteration=5, theta_new=[-0.17815    -0.44992629  0.35508439], -likelihood = -300.94615
# Iteration=6, theta_new=[-0.18062034 -0.46295125  0.35947949], -likelihood = -305.03823
# Iteration=7, theta_new=[-0.1837002  -0.47711763  0.3634153 ], -likelihood = -309.70745
# Iteration=8, theta_new=[-0.18711311 -0.49218974  0.36697761], -likelihood = -315.05861
# Iteration=9, theta_new=[-0.19065411 -0.50783835  0.37030003], -likelihood = -321.02032
# Iteration=10, theta_new=[-0.19412839 -0.52346316  0.37355663], -likelihood = -327.38623
# Iteration=11, theta_new=[-0.19725925 -0.53856572  0.37695177], -likelihood = -333.76395
# Iteration=12, theta_new=[-0.19984971 -0.55269032  0.38072774], -likelihood = -339.78502
# Iteration=13, theta_new=[-0.2019042 -0.5654333  0.3849698], -likelihood = -345.18415
# Iteration=14, theta_new=[-0.20324829 -0.57660757  0.38980752], -likelihood = -349.82752
# Iteration=15, theta_new=[-0.20387808 -0.58627258  0.395306  ], -likelihood = -353.76780
# Iteration=16, theta_new=[-0.20374728 -0.59441091  0.40142273], -likelihood = -357.18686
# Iteration=17, theta_new=[-0.20300878 -0.60122041  0.40817986], -likelihood = -360.24035
# Iteration=18, theta_new=[-0.20158567 -0.60687184  0.41553657], -likelihood = -363.12468
# Iteration=19, theta_new=[-0.19945427 -0.61150636  0.4234788 ], -likelihood = -365.98092
# Iteration=20, theta_new=[-0.19669297 -0.61524506  0.43189018], -likelihood = -368.91548
# 22-th start
# Iteration=1, theta_new=[ 0.08694521 -2.10016803  2.18288743], -likelihood = -722.10505
# Iteration=2, theta_new=[ 0.0796366  -2.04334493  2.1332235 ], -likelihood = -961.50365
# Iteration=3, theta_new=[ 0.07357387 -2.00172737  2.09613896], -likelihood = -1057.20224
# Iteration=4, theta_new=[ 0.06836636 -1.97163441  2.06823284], -likelihood = -1092.89026
# Iteration=5, theta_new=[ 0.06364315 -1.95040615  2.04701909], -likelihood = -1107.26580
# Iteration=6, theta_new=[ 0.05922348 -1.93592932  2.03070017], -likelihood = -1113.38343
# Iteration=7, theta_new=[ 0.05506967 -1.92647391  2.01793123], -likelihood = -1116.05214
# Iteration=8, theta_new=[ 0.05113028 -1.92083241  2.00787153], -likelihood = -1117.22343
# Iteration=9, theta_new=[ 0.04737598 -1.91789831  1.99977729], -likelihood = -1117.73854
# Iteration=10, theta_new=[ 0.04387228 -1.91681112  1.99316557], -likelihood = -1117.98194
# Iteration=11, theta_new=[ 0.04047728 -1.91706795  1.98769744], -likelihood = -1118.11517
# Iteration=12, theta_new=[ 0.03727215 -1.91815245  1.98306154], -likelihood = -1118.21780
# Iteration=13, theta_new=[ 0.03422835 -1.91976069  1.97914084], -likelihood = -1118.30986
# Iteration=14, theta_new=[ 0.03127563 -1.92170631  1.97569245], -likelihood = -1118.40224
# Iteration=15, theta_new=[ 0.02845202 -1.92379074  1.97266771], -likelihood = -1118.49693
# Iteration=16, theta_new=[ 0.02581434 -1.92589023  1.96999594], -likelihood = -1118.58988
# Iteration=17, theta_new=[ 0.02324755 -1.92804332  1.96761857], -likelihood = -1118.67612
# Iteration=18, theta_new=[ 0.02080608 -1.93011329  1.96554919], -likelihood = -1118.76214
# Iteration=19, theta_new=[ 0.01846985 -1.93210745  1.96364523], -likelihood = -1118.84368
# Iteration=20, theta_new=[ 0.01626508 -1.93397825  1.96188819], -likelihood = -1118.91786
# 23-th start
# Iteration=1, theta_new=[-2.92431477  2.76486379 -0.06453177], -likelihood = -290.19111
# Iteration=2, theta_new=[-2.90839175  2.75762271 -0.05725817], -likelihood = -301.18764
# Iteration=3, theta_new=[-2.8975731   2.74996673 -0.05189707], -likelihood = -306.83472
# Iteration=4, theta_new=[-2.88981968  2.74183819 -0.0479352 ], -likelihood = -310.58806
# Iteration=5, theta_new=[-2.88408413  2.73328555 -0.04497266], -likelihood = -313.69080
# Iteration=6, theta_new=[-2.87967245  2.72427637 -0.0427366 ], -likelihood = -316.63095
# Iteration=7, theta_new=[-2.87625357  2.71496098 -0.04099936], -likelihood = -319.63563
# Iteration=8, theta_new=[-2.87362985  2.7053527  -0.03952824], -likelihood = -322.73946
# Iteration=9, theta_new=[-2.87161925  2.69553352 -0.03825728], -likelihood = -325.95360
# Iteration=10, theta_new=[-2.87016345  2.68568421 -0.03710631], -likelihood = -329.23050
# Iteration=11, theta_new=[-2.86917872  2.67597133 -0.03598414], -likelihood = -332.47115
# Iteration=12, theta_new=[-2.86858825  2.66653835 -0.03484981], -likelihood = -335.57809
# Iteration=13, theta_new=[-2.86836568  2.65747123 -0.03367857], -likelihood = -338.46889
# Iteration=14, theta_new=[-2.86845899  2.64893608 -0.03246529], -likelihood = -341.09379
# Iteration=15, theta_new=[-2.86880826  2.64091052 -0.03126359], -likelihood = -343.39742
# Iteration=16, theta_new=[-2.86937463  2.63356299 -0.03007937], -likelihood = -345.39085
# Iteration=17, theta_new=[-2.87014181  2.62687746 -0.02886171], -likelihood = -347.05248
# Iteration=18, theta_new=[-2.87098156  2.62090691 -0.02764759], -likelihood = -348.41887
# Iteration=19, theta_new=[-2.87189326  2.6155216  -0.02650636], -likelihood = -349.51105
# Iteration=20, theta_new=[-2.87282309  2.6107428  -0.02541121], -likelihood = -350.38619
# 24-th start
# Iteration=1, theta_new=[-0.31514423  0.27796009 -2.58913994], -likelihood = -339.74959
# Iteration=2, theta_new=[-0.31107861  0.28243392 -2.57732693], -likelihood = -345.02307
# Iteration=3, theta_new=[-0.30875586  0.28651218 -2.56787366], -likelihood = -348.03976
# Iteration=4, theta_new=[-0.30745133  0.29034347 -2.56042594], -likelihood = -349.83067
# Iteration=5, theta_new=[-0.30673418  0.29399518 -2.55454612], -likelihood = -350.91197
# Iteration=6, theta_new=[-0.30643604  0.29752994 -2.54988152], -likelihood = -351.59182
# Iteration=7, theta_new=[-0.30631657  0.30095572 -2.54619619], -likelihood = -352.04853
# Iteration=8, theta_new=[-0.30626126  0.3043598  -2.54326778], -likelihood = -352.37833
# Iteration=9, theta_new=[-0.3063727   0.30773643 -2.54091486], -likelihood = -352.64515
# Iteration=10, theta_new=[-0.30651424  0.31109334 -2.53904178], -likelihood = -352.88470
# Iteration=11, theta_new=[-0.30673345  0.31445693 -2.53753824], -likelihood = -353.11465
# Iteration=12, theta_new=[-0.30692848  0.31779465 -2.5362711 ], -likelihood = -353.34949
# Iteration=13, theta_new=[-0.30716342  0.32114745 -2.53526791], -likelihood = -353.58994
# Iteration=14, theta_new=[-0.30747552  0.32459713 -2.53438758], -likelihood = -353.84686
# Iteration=15, theta_new=[-0.30780642  0.32809218 -2.53362337], -likelihood = -354.12862
# Iteration=16, theta_new=[-0.30816771  0.33166736 -2.53295726], -likelihood = -354.43355
# Iteration=17, theta_new=[-0.30852083  0.3353432  -2.53230295], -likelihood = -354.76855
# Iteration=18, theta_new=[-0.30899739  0.33915888 -2.53174508], -likelihood = -355.13664
# Iteration=19, theta_new=[-0.30946094  0.34317843 -2.53118862], -likelihood = -355.55286
# Iteration=20, theta_new=[-0.3100056   0.34736131 -2.53062587], -likelihood = -356.02572
# 25-th start
# Iteration=1, theta_new=[-1.18699961  1.72529307  0.65607895], -likelihood = -1061.16778
# Iteration=2, theta_new=[-1.15194503  1.76445753  0.64725671], -likelihood = -1079.71062
# Iteration=3, theta_new=[-1.12745638  1.78835599  0.63816074], -likelihood = -1092.81352
# Iteration=4, theta_new=[-1.11121241  1.80386982  0.62908861], -likelihood = -1101.39197
# Iteration=5, theta_new=[-1.1006546   1.81416961  0.62017856], -likelihood = -1107.11404
# Iteration=6, theta_new=[-1.0940291   1.82111595  0.61150235], -likelihood = -1111.17796
# Iteration=7, theta_new=[-1.09005977  1.82579399  0.60311441], -likelihood = -1114.26912
# Iteration=8, theta_new=[-1.0878376   1.82902398  0.59508027], -likelihood = -1116.75439
# Iteration=9, theta_new=[-1.08678373  1.83122814  0.58738087], -likelihood = -1118.83284
# Iteration=10, theta_new=[-1.08653281  1.83270603  0.58004149], -likelihood = -1120.61185
# Iteration=11, theta_new=[-1.08677836  1.83366007  0.57311437], -likelihood = -1122.14319
# Iteration=12, theta_new=[-1.0872963   1.83433064  0.56660342], -likelihood = -1123.45594
# Iteration=13, theta_new=[-1.08800987  1.83477972  0.56057761], -likelihood = -1124.58421
# Iteration=14, theta_new=[-1.0887484   1.83512646  0.55494948], -likelihood = -1125.53158
# Iteration=15, theta_new=[-1.08953644  1.8353632   0.54977558], -likelihood = -1126.34040
# Iteration=16, theta_new=[-1.09031568  1.83555716  0.54499106], -likelihood = -1127.00917
# Iteration=17, theta_new=[-1.09111564  1.83566592  0.54060369], -likelihood = -1127.56611
# Iteration=18, theta_new=[-1.09179379  1.83577135  0.53659137], -likelihood = -1128.01552
# Iteration=19, theta_new=[-1.09245474  1.83588867  0.53291585], -likelihood = -1128.38709
# Iteration=20, theta_new=[-1.09302944  1.83601956  0.52963223], -likelihood = -1128.68744
# 26-th start
# Iteration=1, theta_new=[-2.35714326  0.70576692 -1.4275906 ], -likelihood = -1107.76194
# Iteration=2, theta_new=[-2.35897046  0.70467177 -1.47800961], -likelihood = -1115.55696
# Iteration=3, theta_new=[-2.3603424   0.7030099  -1.57081598], -likelihood = -1120.12555
# Iteration=4, theta_new=[-2.36044567  0.70149083 -1.57086572], -likelihood = -1121.32527
# Iteration=5, theta_new=[-2.36049577  0.69978091 -1.57078485], -likelihood = -1121.39398
# Iteration=6, theta_new=[-2.36050734  0.69785908 -1.57076416], -likelihood = -1121.47820
# Iteration=7, theta_new=[-2.36048069  0.69571915 -1.57086496], -likelihood = -1121.58111
# Iteration=8, theta_new=[-2.36041365  0.69330124 -1.57085672], -likelihood = -1121.70589
# Iteration=9, theta_new=[-2.36030796  0.69058898 -1.57075746], -likelihood = -1121.85972
# Iteration=10, theta_new=[-2.36017152  0.687561   -1.57076818], -likelihood = -1122.04839
# Iteration=11, theta_new=[-2.35996607  0.68421006 -1.57080314], -likelihood = -1122.27895
# Iteration=12, theta_new=[-2.35967909  0.68046283 -1.57075545], -likelihood = -1122.55928
# Iteration=13, theta_new=[-2.35934824  0.67628943 -1.57081612], -likelihood = -1122.90394
# Iteration=14, theta_new=[-2.35891055  0.67164774 -1.57084471], -likelihood = -1123.32526
# Iteration=15, theta_new=[-2.35842004  0.66653719 -1.57077037], -likelihood = -1123.84069
# Iteration=16, theta_new=[-2.35789958  0.66089504 -1.5708268 ], -likelihood = -1124.46245
# Iteration=17, theta_new=[-2.35728971  0.65472792 -1.57080873], -likelihood = -1125.21185
# Iteration=18, theta_new=[-2.35663602  0.64804638 -1.57076511], -likelihood = -1126.10386
# Iteration=19, theta_new=[-2.35595965  0.64085519 -1.57086093], -likelihood = -1127.14854
# Iteration=20, theta_new=[-2.35526007  0.6332067  -1.57080547], -likelihood = -1128.35376
# 27-th start
# Iteration=1, theta_new=[-1.57085249 -0.52559734 -1.2264197 ], -likelihood = -916.73509
# Iteration=2, theta_new=[-1.5707738  -0.52931801 -1.28659442], -likelihood = -956.89609
# Iteration=3, theta_new=[-1.57077122 -0.53247072 -1.34473318], -likelihood = -988.76221
# Iteration=4, theta_new=[-1.57086046 -0.53529312 -1.40342384], -likelihood = -1011.95247
# Iteration=5, theta_new=[-1.57076182 -0.53785647 -1.47038582], -likelihood = -1027.68858
# Iteration=6, theta_new=[-1.57083045 -0.54020541 -1.57080839], -likelihood = -1037.67068
# Iteration=7, theta_new=[-1.57082004 -0.54242942 -1.57078133], -likelihood = -1040.02737
# Iteration=8, theta_new=[-1.57081643 -0.54441311 -1.57079961], -likelihood = -1040.10032
# Iteration=9, theta_new=[-1.57081979 -0.54619106 -1.57078882], -likelihood = -1040.15577
# Iteration=10, theta_new=[-1.57072736 -0.54778461 -1.57081422], -likelihood = -1040.19776
# Iteration=11, theta_new=[-1.57083038 -0.54920442 -1.57080264], -likelihood = -1040.22923
# Iteration=12, theta_new=[-1.57078924 -0.55046994 -1.5707999 ], -likelihood = -1040.25238
# Iteration=13, theta_new=[-1.57074698 -0.55160909 -1.57080435], -likelihood = -1040.26912
# Iteration=14, theta_new=[-1.57086997 -0.55262873 -1.57084374], -likelihood = -1040.28108
# Iteration=15, theta_new=[-1.57082793 -0.55353821 -1.57078647], -likelihood = -1040.28928
# Iteration=16, theta_new=[-1.5707826  -0.55435962 -1.57081204], -likelihood = -1040.29461
# Iteration=17, theta_new=[-1.57080629 -0.55508474 -1.57079864], -likelihood = -1040.29782
# Iteration=18, theta_new=[-1.57078631 -0.55574215 -1.57081133], -likelihood = -1040.29940
# Iteration=19, theta_new=[-1.57079484 -0.55632131 -1.57079822], -likelihood = -1040.29980
# Iteration=20, theta_new=[-1.57085083 -0.55684335 -1.5708119 ], -likelihood = -1040.29935
# 28-th start
# Iteration=1, theta_new=[-0.99435346 -0.57220735  0.25450739], -likelihood = -401.81869
# Iteration=2, theta_new=[-1.06936896 -0.58638845  0.25957895], -likelihood = -491.64833
# Iteration=3, theta_new=[-1.14128858 -0.59685387  0.26375117], -likelihood = -585.06107
# Iteration=4, theta_new=[-1.20868391 -0.60364382  0.26801859], -likelihood = -663.39827
# Iteration=5, theta_new=[-1.27178692 -0.60751252  0.27296272], -likelihood = -720.92893
# Iteration=6, theta_new=[-1.33193765 -0.60916104  0.2788991 ], -likelihood = -759.90393
# Iteration=7, theta_new=[-1.39189009 -0.60934311  0.28587253], -likelihood = -785.31926
# Iteration=8, theta_new=[-1.4584501  -0.60862014  0.29381564], -likelihood = -801.91153
# Iteration=9, theta_new=[-1.57080306 -0.60750883  0.3025295 ], -likelihood = -813.08023
# Iteration=10, theta_new=[-1.57075678 -0.6068909   0.3115604 ], -likelihood = -818.85493
# Iteration=11, theta_new=[-1.57078488 -0.6063995   0.3210031 ], -likelihood = -821.54318
# Iteration=12, theta_new=[-1.57082409 -0.60605864  0.33081848], -likelihood = -824.55688
# Iteration=13, theta_new=[-1.57077501 -0.60587215  0.3409825 ], -likelihood = -827.88163
# Iteration=14, theta_new=[-1.57076338 -0.6058455   0.35142443], -likelihood = -831.49464
# Iteration=15, theta_new=[-1.57081376 -0.60597087  0.36208439], -likelihood = -835.34043
# Iteration=16, theta_new=[-1.5708022  -0.60626095  0.37284257], -likelihood = -839.35111
# Iteration=17, theta_new=[-1.5708065  -0.60670179  0.38361967], -likelihood = -843.42142
# Iteration=18, theta_new=[-1.57081026 -0.60725551  0.39429541], -likelihood = -847.45412
# Iteration=19, theta_new=[-1.57078829 -0.60791662  0.40473777], -likelihood = -851.33705
# Iteration=20, theta_new=[-1.57080551 -0.60862828  0.41485254], -likelihood = -854.96242
# 29-th start
# Iteration=1, theta_new=[-2.77860616 -1.57082839 -0.92766709], -likelihood = -1048.64438
# Iteration=2, theta_new=[-2.77569406 -1.57076696 -0.93056338], -likelihood = -1049.64738
# Iteration=3, theta_new=[-2.77234676 -1.57080499 -0.93347818], -likelihood = -1049.71742
# Iteration=4, theta_new=[-2.76857642 -1.57082794 -0.93637255], -likelihood = -1049.81388
# Iteration=5, theta_new=[-2.76427228 -1.57077972 -0.93925595], -likelihood = -1049.94443
# Iteration=6, theta_new=[-2.7593217  -1.57079354 -0.94211965], -likelihood = -1050.12436
# Iteration=7, theta_new=[-2.75376841 -1.57079227 -0.94494848], -likelihood = -1050.37382
# Iteration=8, theta_new=[-2.747493   -1.57084884 -0.94774011], -likelihood = -1050.70452
# Iteration=9, theta_new=[-2.74049573 -1.57083525 -0.95042511], -likelihood = -1051.14177
# Iteration=10, theta_new=[-2.73270426 -1.57081519 -0.95303749], -likelihood = -1051.70552
# Iteration=11, theta_new=[-2.72417906 -1.57081023 -0.955544  ], -likelihood = -1052.41664
# Iteration=12, theta_new=[-2.71493397 -1.57073223 -0.95788702], -likelihood = -1053.28105
# Iteration=13, theta_new=[-2.70506415 -1.57082088 -0.96009469], -likelihood = -1054.30366
# Iteration=14, theta_new=[-2.69474587 -1.57076744 -0.96216414], -likelihood = -1055.46325
# Iteration=15, theta_new=[-2.68418974 -1.57077415 -0.9640148 ], -likelihood = -1056.71729
# Iteration=16, theta_new=[-2.67355443 -1.57082845 -0.96571213], -likelihood = -1058.01497
# Iteration=17, theta_new=[-2.66303797 -1.57080041 -0.9672749 ], -likelihood = -1059.29809
# Iteration=18, theta_new=[-2.65284895 -1.57074964 -0.96873444], -likelihood = -1060.50949
# Iteration=19, theta_new=[-2.64316818 -1.57079709 -0.97015364], -likelihood = -1061.59916
# Iteration=20, theta_new=[-2.63410686 -1.57074557 -0.97155454], -likelihood = -1062.53145

# %%
EM_theta3_rad
# Out:
# array([-0.54669212,  0.4857933 , -1.57077951])

# %% [markdown]
# ## True result

# %%
theta3_rad
# Out:
# [0.5, 1.2, 1.6]

# %% [markdown]
# # Case 4

# %% [markdown]
# Имеется 7 датчиков, 3 источника (дисперсии сигналов - 0.5, 0.5 и 0.5), и шум на каждом датчике имеет дисперсию 1.1.

# %%
Num_sensors4 = 7
Num_emitters4 = 3
sample_size4 = 100
theta4_rad = [0.5, 1.1, -0.3] # Направление прибытия (DOA) в радианах
theta4_deg = rad_to_deg(theta4_rad[0]) # Направление прибытия (DOA) в градусах
GS_4 = np.diag([0.5, 0.5, 0.5]) # Ковариация сигнала
GN_4 = 1.1*np.eye(7, dtype=np.float64) # Ковариация шума
A4 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors4).reshape(-1,1) * np.sin(theta4_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s4 = CN(Num_emitters4, sample_size4, GS_4)
n4 = CN(Num_sensors4, sample_size4, GN_4)
X4 = (A4 @ s4.T + n4.T).T

# %% [markdown]
# ## ML1

# %%
theta_ML1_Case4, ML1_func_val_Case4 = multi_start_ML1(X4, L=Num_sensors4, M=Num_emitters4, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML1_Case4
# Out:
# array([ 1.11180646,  0.51075174, -0.29378152])

# %% [markdown]
# ## ML2

# %%
theta_ML2_Case4, ML2_func_val_Case4 = multi_start_ML2(X4, GS_4, GN_4, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML2_Case4
# Out:
# array([ 0.51031112, -0.29329847,  1.11202126])

# %% [markdown]
# ## EM

# %%
EM_theta4_rad, neglhd_4, K4, mu4 = multi_start_EM(X4, GS_4, GN_4, 30, max_iter=20, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[ 0.94545693  0.31682385 -2.99287378], -likelihood = -682.10150
# Iteration=2, theta_new=[ 0.98291068  0.35127351 -2.96455125], -likelihood = -851.11554
# Iteration=3, theta_new=[ 1.01476584  0.38223122 -2.941683  ], -likelihood = -991.82409
# Iteration=4, theta_new=[ 1.04044425  0.40904797 -2.92298546], -likelihood = -1095.63456
# Iteration=5, theta_new=[ 1.06029811  0.43145591 -2.90765359], -likelihood = -1170.71380
# Iteration=6, theta_new=[ 1.07507457  0.4496278  -2.89521531], -likelihood = -1222.84288
# Iteration=7, theta_new=[ 1.0858495   0.46399166 -2.8851966 ], -likelihood = -1257.10565
# Iteration=8, theta_new=[ 1.09355284  0.47517074 -2.87721324], -likelihood = -1278.59536
# Iteration=9, theta_new=[ 1.09896925  0.48379911 -2.87095227], -likelihood = -1291.64003
# Iteration=10, theta_new=[ 1.10281938  0.4903892  -2.86602146], -likelihood = -1299.39436
# Iteration=11, theta_new=[ 1.10543101  0.49540997 -2.86213459], -likelihood = -1303.96870
# Iteration=12, theta_new=[ 1.10717419  0.49927339 -2.85913564], -likelihood = -1306.66026
# Iteration=13, theta_new=[ 1.10831883  0.50221059 -2.85674906], -likelihood = -1308.24300
# Iteration=14, theta_new=[ 1.10911771  0.5044452  -2.85486898], -likelihood = -1309.18172
# Iteration=15, theta_new=[ 1.10962764  0.50611236 -2.85339542], -likelihood = -1309.73842
# Iteration=16, theta_new=[ 1.10996319  0.50740764 -2.85226176], -likelihood = -1310.06572
# Iteration=17, theta_new=[ 1.11008852  0.50838565 -2.85135241], -likelihood = -1310.26161
# Iteration=18, theta_new=[ 1.11016889  0.50912061 -2.85063307], -likelihood = -1310.38002
# Iteration=19, theta_new=[ 1.11013686  0.50971728 -2.85008235], -likelihood = -1310.45138
# Iteration=20, theta_new=[ 1.11014402  0.51014441 -2.84965621], -likelihood = -1310.49550
# 1-th start
# Iteration=1, theta_new=[2.05588985 2.35191549 2.63369746], -likelihood = -992.61068
# Iteration=2, theta_new=[2.03836773 2.35622969 2.6383173 ], -likelihood = -1001.04336
# Iteration=3, theta_new=[2.02390025 2.3590577  2.64211954], -likelihood = -1006.13330
# Iteration=4, theta_new=[2.01200713 2.3606506  2.64521652], -likelihood = -1009.26311
# Iteration=5, theta_new=[2.00213495 2.36146045 2.64769927], -likelihood = -1011.20225
# Iteration=6, theta_new=[1.9940073  2.36165382 2.64969123], -likelihood = -1012.42081
# Iteration=7, theta_new=[1.98728195 2.36134911 2.65122136], -likelihood = -1013.18800
# Iteration=8, theta_new=[1.98172659 2.3607284  2.65239362], -likelihood = -1013.67584
# Iteration=9, theta_new=[1.97710205 2.35977964 2.65330148], -likelihood = -1013.99103
# Iteration=10, theta_new=[1.97317523 2.35860016 2.65392383], -likelihood = -1014.20352
# Iteration=11, theta_new=[1.96991533 2.35725316 2.65436635], -likelihood = -1014.35451
# Iteration=12, theta_new=[1.96699214 2.3557436  2.65465612], -likelihood = -1014.46592
# Iteration=13, theta_new=[1.96445508 2.35418302 2.65483467], -likelihood = -1014.55860
# Iteration=14, theta_new=[1.96224157 2.35241875 2.65486047], -likelihood = -1014.63572
# Iteration=15, theta_new=[1.96023404 2.35061594 2.65480959], -likelihood = -1014.70824
# Iteration=16, theta_new=[1.95844101 2.34873301 2.65468754], -likelihood = -1014.77558
# Iteration=17, theta_new=[1.95678478 2.34685523 2.65451822], -likelihood = -1014.84011
# Iteration=18, theta_new=[1.95511037 2.34490667 2.65429633], -likelihood = -1014.90133
# Iteration=19, theta_new=[1.9535988  2.34295621 2.65403452], -likelihood = -1014.96313
# Iteration=20, theta_new=[1.95216634 2.34089034 2.65375318], -likelihood = -1015.02209
# 2-th start
# Iteration=1, theta_new=[ 2.89202568 -1.3487804   1.92593733], -likelihood = -535.45947
# Iteration=2, theta_new=[ 2.8677764  -1.28780427  1.97097092], -likelihood = -621.62634
# Iteration=3, theta_new=[ 2.83425249 -1.25449192  1.99629074], -likelihood = -674.00869
# Iteration=4, theta_new=[ 2.79705448 -1.2356891   2.01287883], -likelihood = -731.67287
# Iteration=5, theta_new=[ 2.76250127 -1.22604882  2.02550789], -likelihood = -798.90018
# Iteration=6, theta_new=[ 2.73347649 -1.22320992  2.03612202], -likelihood = -862.20999
# Iteration=7, theta_new=[ 2.71036927 -1.22526783  2.04552134], -likelihood = -911.47296
# Iteration=8, theta_new=[ 2.69241545 -1.23099102  2.05396977], -likelihood = -945.04645
# Iteration=9, theta_new=[ 2.67865177 -1.23941519  2.06163827], -likelihood = -966.26078
# Iteration=10, theta_new=[ 2.66813088 -1.24968464  2.06867975], -likelihood = -979.18765
# Iteration=11, theta_new=[ 2.66008487 -1.26134746  2.07529568], -likelihood = -987.04729
# Iteration=12, theta_new=[ 2.65393278 -1.27409655  2.08151345], -likelihood = -991.93552
# Iteration=13, theta_new=[ 2.64922944 -1.28771478  2.08744094], -likelihood = -995.09397
# Iteration=14, theta_new=[ 2.64560107 -1.30207916  2.0931044 ], -likelihood = -997.25454
# Iteration=15, theta_new=[ 2.64281271 -1.3168983   2.09854996], -likelihood = -998.83883
# Iteration=16, theta_new=[ 2.64066426 -1.33227956  2.10375678], -likelihood = -1000.07418
# Iteration=17, theta_new=[ 2.63901592 -1.34812576  2.10880805], -likelihood = -1001.09369
# Iteration=18, theta_new=[ 2.637754   -1.36448593  2.11368349], -likelihood = -1001.97804
# Iteration=19, theta_new=[ 2.6367701  -1.3813949   2.11840254], -likelihood = -1002.76818
# Iteration=20, theta_new=[ 2.63602714 -1.39896114  2.1229327 ], -likelihood = -1003.49057
# 3-th start
# Iteration=1, theta_new=[-0.85688149 -2.95527699 -2.56932796], -likelihood = -542.21144
# Iteration=2, theta_new=[-0.84243344 -2.93750187 -2.58725157], -likelihood = -588.31503
# Iteration=3, theta_new=[-0.82971805 -2.92417642 -2.60370568], -likelihood = -617.16833
# Iteration=4, theta_new=[-0.81898189 -2.91433204 -2.61803651], -likelihood = -634.44785
# Iteration=5, theta_new=[-0.81002059 -2.90711182 -2.63026023], -likelihood = -644.72654
# Iteration=6, theta_new=[-0.80251901 -2.90194293 -2.6405384 ], -likelihood = -650.94966
# Iteration=7, theta_new=[-0.79613638 -2.89830038 -2.64911147], -likelihood = -654.77667
# Iteration=8, theta_new=[-0.79077728 -2.89589954 -2.65631719], -likelihood = -657.19189
# Iteration=9, theta_new=[-0.78619703 -2.89439394 -2.66238977], -likelihood = -658.73433
# Iteration=10, theta_new=[-0.78217891 -2.89355655 -2.66758662], -likelihood = -659.75481
# Iteration=11, theta_new=[-0.77872947 -2.89323935 -2.67208985], -likelihood = -660.46092
# Iteration=12, theta_new=[-0.77569541 -2.89327818 -2.67608359], -likelihood = -660.95707
# Iteration=13, theta_new=[-0.77306051 -2.89359149 -2.67963571], -likelihood = -661.32292
# Iteration=14, theta_new=[-0.77079009 -2.89409309 -2.68281903], -likelihood = -661.59515
# Iteration=15, theta_new=[-0.76879034 -2.89473205 -2.68569111], -likelihood = -661.79952
# Iteration=16, theta_new=[-0.76697513 -2.89545653 -2.68832396], -likelihood = -661.95763
# Iteration=17, theta_new=[-0.76536144 -2.89623904 -2.69076093], -likelihood = -662.08391
# Iteration=18, theta_new=[-0.76387518 -2.89708229 -2.69304667], -likelihood = -662.18209
# Iteration=19, theta_new=[-0.76247794 -2.89791056 -2.69515433], -likelihood = -662.26080
# Iteration=20, theta_new=[-0.76126226 -2.89875109 -2.6971854 ], -likelihood = -662.32436
# 4-th start
# Iteration=1, theta_new=[2.02886574 1.83512564 0.02403871], -likelihood = -589.24638
# Iteration=2, theta_new=[2.06214999 1.79110912 0.03254127], -likelihood = -623.44178
# Iteration=3, theta_new=[2.08278833 1.75947945 0.04065445], -likelihood = -641.26464
# Iteration=4, theta_new=[2.0965238  1.73962914 0.04831159], -likelihood = -649.40308
# Iteration=5, theta_new=[2.1061782  1.72947838 0.05538986], -likelihood = -653.68508
# Iteration=6, theta_new=[2.11330101 1.72657632 0.06174625], -likelihood = -656.26928
# Iteration=7, theta_new=[2.11882795 1.72842566 0.06734092], -likelihood = -657.98063
# Iteration=8, theta_new=[2.12326323 1.73292327 0.07217427], -likelihood = -659.18460
# Iteration=9, theta_new=[2.12700524 1.73942645 0.07629773], -likelihood = -660.05870
# Iteration=10, theta_new=[2.13032162 1.74655056 0.07979135], -likelihood = -660.71105
# Iteration=11, theta_new=[2.13331479 1.75371393 0.08270653], -likelihood = -661.21842
# Iteration=12, theta_new=[2.13607851 1.76084616 0.08513811], -likelihood = -661.62234
# Iteration=13, theta_new=[2.13866933 1.76760909 0.0871706 ], -likelihood = -661.95610
# Iteration=14, theta_new=[2.14113748 1.77404342 0.08882954], -likelihood = -662.24249
# Iteration=15, theta_new=[2.14347955 1.78007031 0.09020639], -likelihood = -662.49629
# Iteration=16, theta_new=[2.14574181 1.78576628 0.09134579], -likelihood = -662.72674
# Iteration=17, theta_new=[2.14796966 1.79104349 0.09228476], -likelihood = -662.94312
# Iteration=18, theta_new=[2.1501293  1.79600981 0.09305604], -likelihood = -663.15295
# Iteration=19, theta_new=[2.15220369 1.80063561 0.09366984], -likelihood = -663.35580
# Iteration=20, theta_new=[2.15421636 1.80506749 0.09419557], -likelihood = -663.55155
# 5-th start
# Iteration=1, theta_new=[ 2.84751906  0.83852534 -0.80515816], -likelihood = -464.21419
# Iteration=2, theta_new=[ 2.81154494  0.87233368 -0.79417847], -likelihood = -530.70506
# Iteration=3, theta_new=[ 2.77531299  0.90945605 -0.78413465], -likelihood = -631.20898
# Iteration=4, theta_new=[ 2.7436519   0.94533291 -0.77514963], -likelihood = -739.83321
# Iteration=5, theta_new=[ 2.71792702  0.97733134 -0.76744397], -likelihood = -830.65974
# Iteration=6, theta_new=[ 2.6977412   1.004657   -0.76104423], -likelihood = -895.51234
# Iteration=7, theta_new=[ 2.68221974  1.02723267 -0.75588599], -likelihood = -937.87509
# Iteration=8, theta_new=[ 2.6704071   1.04559441 -0.75178416], -likelihood = -964.07470
# Iteration=9, theta_new=[ 2.66146174  1.06033414 -0.74846563], -likelihood = -979.82825
# Iteration=10, theta_new=[ 2.65473814  1.07202324 -0.74577233], -likelihood = -989.15060
# Iteration=11, theta_new=[ 2.64968779  1.08121314 -0.74360934], -likelihood = -994.59904
# Iteration=12, theta_new=[ 2.64591757  1.08845698 -0.74183856], -likelihood = -997.76922
# Iteration=13, theta_new=[ 2.6430934   1.09412529 -0.74038395], -likelihood = -999.61381
# Iteration=14, theta_new=[ 2.64099111  1.09847031 -0.7391841 ], -likelihood = -1000.68751
# Iteration=15, theta_new=[ 2.63942025  1.10192082 -0.73816981], -likelihood = -1001.30661
# Iteration=16, theta_new=[ 2.63827911  1.1045471  -0.73727035], -likelihood = -1001.67250
# Iteration=17, theta_new=[ 2.63744043  1.10658389 -0.7365651 ], -likelihood = -1001.88293
# Iteration=18, theta_new=[ 2.63679267  1.10818403 -0.73591559], -likelihood = -1002.00633
# Iteration=19, theta_new=[ 2.63632316  1.10935127 -0.73535802], -likelihood = -1002.08170
# Iteration=20, theta_new=[ 2.63597399  1.11032703 -0.73486189], -likelihood = -1002.12510
# 6-th start
# Iteration=1, theta_new=[-1.57042419 -2.99481632  3.00131839], -likelihood = -647.78015
# Iteration=2, theta_new=[-1.57076197 -2.969552    3.0192376 ], -likelihood = -704.91430
# Iteration=3, theta_new=[-1.57079965 -2.94879612  3.03417152], -likelihood = -750.58992
# Iteration=4, theta_new=[-1.5707575  -2.93201425  3.0459284 ], -likelihood = -783.83192
# Iteration=5, theta_new=[-1.57077354 -2.91847626  3.05481934], -likelihood = -806.55805
# Iteration=6, theta_new=[-1.57085964 -2.90755269  3.06140935], -likelihood = -821.63948
# Iteration=7, theta_new=[-1.57081561 -2.8987238   3.06623036], -likelihood = -831.52412
# Iteration=8, theta_new=[-1.57075792 -2.89155839  3.06970775], -likelihood = -837.97953
# Iteration=9, theta_new=[-1.5707398  -2.88576201  3.07216982], -likelihood = -842.20396
# Iteration=10, theta_new=[-1.57076683 -2.88103715  3.07390023], -likelihood = -844.96117
# Iteration=11, theta_new=[-1.57067298 -2.87720248  3.07509437], -likelihood = -846.77768
# Iteration=12, theta_new=[-1.57077366 -2.87408099  3.07585226], -likelihood = -847.97171
# Iteration=13, theta_new=[-1.57073685 -2.87152298  3.07637025], -likelihood = -848.75866
# Iteration=14, theta_new=[-1.57081452 -2.86943585  3.07667831], -likelihood = -849.28401
# Iteration=15, theta_new=[-1.5707637  -2.86773808  3.07683559], -likelihood = -849.63239
# Iteration=16, theta_new=[-1.57076805 -2.8663491   3.07686765], -likelihood = -849.86296
# Iteration=17, theta_new=[-1.57077107 -2.865214    3.07681419], -likelihood = -850.01604
# Iteration=18, theta_new=[-1.57077542 -2.864288    3.07669558], -likelihood = -850.11742
# Iteration=19, theta_new=[-1.5707655  -2.86354208  3.07656521], -likelihood = -850.18406
# Iteration=20, theta_new=[-1.57077847 -2.86291482  3.0764288 ], -likelihood = -850.22767
# 7-th start
# Iteration=1, theta_new=[-2.63616404 -2.48824363  0.42214815], -likelihood = -621.48454
# Iteration=2, theta_new=[-2.66551871 -2.47777187  0.44311256], -likelihood = -766.78204
# Iteration=3, theta_new=[-2.69081899 -2.47276156  0.45907133], -likelihood = -834.96807
# Iteration=4, theta_new=[-2.71314037 -2.47018629  0.47116601], -likelihood = -881.17302
# Iteration=5, theta_new=[-2.732895   -2.46888105  0.48030524], -likelihood = -915.10685
# Iteration=6, theta_new=[-2.75022918 -2.4678345   0.48715541], -likelihood = -940.93410
# Iteration=7, theta_new=[-2.76536232 -2.46684353  0.49235178], -likelihood = -960.69786
# Iteration=8, theta_new=[-2.77836808 -2.46578054  0.49625018], -likelihood = -975.84731
# Iteration=9, theta_new=[-2.78949832 -2.4646756   0.49920679], -likelihood = -987.24082
# Iteration=10, theta_new=[-2.79888039 -2.46354951  0.50142983], -likelihood = -995.72387
# Iteration=11, theta_new=[-2.80674851 -2.46244115  0.50312767], -likelihood = -1001.89094
# Iteration=12, theta_new=[-2.81327627 -2.46137049  0.50436299], -likelihood = -1006.31669
# Iteration=13, theta_new=[-2.81868309 -2.46040459  0.50528349], -likelihood = -1009.43080
# Iteration=14, theta_new=[-2.82317579 -2.45943485  0.50599524], -likelihood = -1011.60797
# Iteration=15, theta_new=[-2.82681883 -2.45848077  0.50655156], -likelihood = -1013.12733
# Iteration=16, theta_new=[-2.82982669 -2.45758396  0.50695767], -likelihood = -1014.15900
# Iteration=17, theta_new=[-2.83228202 -2.45679235  0.50725807], -likelihood = -1014.87057
# Iteration=18, theta_new=[-2.8342137  -2.4560502   0.50748772], -likelihood = -1015.35524
# Iteration=19, theta_new=[-2.835839   -2.45536496  0.50764182], -likelihood = -1015.67480
# Iteration=20, theta_new=[-2.83713793 -2.45472608  0.50776793], -likelihood = -1015.90083
# 8-th start
# Iteration=1, theta_new=[ 0.90591949  1.24219511 -0.87578317], -likelihood = -663.84505
# Iteration=2, theta_new=[ 0.90009801  1.24490881 -0.87180255], -likelihood = -665.02620
# Iteration=3, theta_new=[ 0.89485701  1.24624476 -0.86834254], -likelihood = -665.95018
# Iteration=4, theta_new=[ 0.88983673  1.2464567  -0.86535685], -likelihood = -666.72813
# Iteration=5, theta_new=[ 0.88492562  1.24570583 -0.8627865 ], -likelihood = -667.47033
# Iteration=6, theta_new=[ 0.87992365  1.24427368 -0.8606317 ], -likelihood = -668.22919
# Iteration=7, theta_new=[ 0.87463938  1.24222354 -0.85884403], -likelihood = -669.06068
# Iteration=8, theta_new=[ 0.86888153  1.2395842  -0.85742436], -likelihood = -670.02410
# Iteration=9, theta_new=[ 0.86247128  1.23641468 -0.85634987], -likelihood = -671.19059
# Iteration=10, theta_new=[ 0.85507068  1.2326638  -0.85558177], -likelihood = -672.64203
# Iteration=11, theta_new=[ 0.84641909  1.22828217 -0.85514357], -likelihood = -674.52922
# Iteration=12, theta_new=[ 0.83607585  1.22317701 -0.85508271], -likelihood = -677.04716
# Iteration=13, theta_new=[ 0.823434    1.21721968 -0.85543014], -likelihood = -680.53915
# Iteration=14, theta_new=[ 0.80754699  1.21021354 -0.8561601 ], -likelihood = -685.59176
# Iteration=15, theta_new=[ 0.78737111  1.20180912 -0.85732225], -likelihood = -693.29527
# Iteration=16, theta_new=[ 0.7617846   1.19178915 -0.85884532], -likelihood = -705.53440
# Iteration=17, theta_new=[ 0.73059237  1.18010518 -0.8603121 ], -likelihood = -725.30582
# Iteration=18, theta_new=[ 0.69536972  1.16727272 -0.86102343], -likelihood = -755.85876
# Iteration=19, theta_new=[ 0.6597455   1.15476449 -0.8599443 ], -likelihood = -797.97495
# Iteration=20, theta_new=[ 0.62722947  1.14390279 -0.85655943], -likelihood = -846.52829
# 9-th start
# Iteration=1, theta_new=[-0.90928759 -2.44232649 -2.70186741], -likelihood = -477.72606
# Iteration=2, theta_new=[-0.93250588 -2.44794744 -2.72230897], -likelihood = -524.56458
# Iteration=3, theta_new=[-0.95246536 -2.45121537 -2.7396087 ], -likelihood = -554.92791
# Iteration=4, theta_new=[-0.97091801 -2.45271819 -2.75442264], -likelihood = -575.66781
# Iteration=5, theta_new=[-0.98945031 -2.45272237 -2.76724072], -likelihood = -590.93622
# Iteration=6, theta_new=[-1.00965025 -2.45133754 -2.77836014], -likelihood = -603.20573
# Iteration=7, theta_new=[-1.03356872 -2.44853453 -2.78808472], -likelihood = -614.20012
# Iteration=8, theta_new=[-1.06377879 -2.44414863 -2.7966092 ], -likelihood = -625.74766
# Iteration=9, theta_new=[-1.10415948 -2.43814784 -2.80423425], -likelihood = -640.31593
# Iteration=10, theta_new=[-1.15924201 -2.43054136 -2.81122904], -likelihood = -661.90316
# Iteration=11, theta_new=[-1.23397716 -2.42174578 -2.81789566], -likelihood = -695.56142
# Iteration=12, theta_new=[-1.33574437 -2.41281691 -2.82428509], -likelihood = -744.02362
# Iteration=13, theta_new=[-1.53785612 -2.40517111 -2.83021604], -likelihood = -801.81920
# Iteration=14, theta_new=[-1.57080246 -2.39464359 -2.83546756], -likelihood = -839.05306
# Iteration=15, theta_new=[-1.5709125  -2.38215479 -2.83974461], -likelihood = -844.15758
# Iteration=16, theta_new=[-1.57080105 -2.36804484 -2.84322569], -likelihood = -849.19082
# Iteration=17, theta_new=[-1.57087394 -2.35274873 -2.846058  ], -likelihood = -854.55146
# Iteration=18, theta_new=[-1.57076527 -2.33700416 -2.84837677], -likelihood = -860.20139
# Iteration=19, theta_new=[-1.57083654 -2.3215307  -2.85026193], -likelihood = -865.87014
# Iteration=20, theta_new=[-1.57073327 -2.3069693  -2.85180396], -likelihood = -871.23275
# 10-th start
# Iteration=1, theta_new=[0.35928982 2.54285915 0.19240902], -likelihood = -662.10674
# Iteration=2, theta_new=[0.37228042 2.54964545 0.18197264], -likelihood = -674.76445
# Iteration=3, theta_new=[0.38249086 2.55395293 0.1739504 ], -likelihood = -679.98060
# Iteration=4, theta_new=[0.39063007 2.55656586 0.16769582], -likelihood = -682.27486
# Iteration=5, theta_new=[0.39716142 2.55792842 0.16279454], -likelihood = -683.28668
# Iteration=6, theta_new=[0.40240413 2.55840929 0.15900398], -likelihood = -683.72553
# Iteration=7, theta_new=[0.40674468 2.55822955 0.15602031], -likelihood = -683.91868
# Iteration=8, theta_new=[0.41040148 2.5576186  0.15368741], -likelihood = -684.03277
# Iteration=9, theta_new=[0.41341169 2.55665843 0.15195901], -likelihood = -684.12991
# Iteration=10, theta_new=[0.41603874 2.55548524 0.15060839], -likelihood = -684.25187
# Iteration=11, theta_new=[0.41827436 2.55415986 0.14959732], -likelihood = -684.39919
# Iteration=12, theta_new=[0.42023607 2.55279292 0.14882823], -likelihood = -684.57612
# Iteration=13, theta_new=[0.42198098 2.55137072 0.14824421], -likelihood = -684.76706
# Iteration=14, theta_new=[0.42354384 2.54991455 0.14788866], -likelihood = -684.97645
# Iteration=15, theta_new=[0.42500673 2.54838365 0.1477208 ], -likelihood = -685.20801
# Iteration=16, theta_new=[0.42635388 2.54689124 0.14763   ], -likelihood = -685.46881
# Iteration=17, theta_new=[0.42754267 2.54535029 0.14764712], -likelihood = -685.73007
# Iteration=18, theta_new=[0.42870812 2.54386743 0.1477308 ], -likelihood = -686.01198
# Iteration=19, theta_new=[0.42980019 2.54234726 0.14791981], -likelihood = -686.29111
# Iteration=20, theta_new=[0.43077487 2.54085079 0.14814576], -likelihood = -686.58981
# 11-th start
# Iteration=1, theta_new=[-0.41699091 -1.86374921  1.17634615], -likelihood = -769.11770
# Iteration=2, theta_new=[-0.39392064 -1.90197239  1.14633316], -likelihood = -844.78155
# Iteration=3, theta_new=[-0.37437263 -1.92650768  1.12703868], -likelihood = -889.89013
# Iteration=4, theta_new=[-0.35819072 -1.943191    1.11405257], -likelihood = -919.03301
# Iteration=5, theta_new=[-0.34497166 -1.95491037  1.10518054], -likelihood = -938.07590
# Iteration=6, theta_new=[-0.33424465 -1.96339194  1.09905212], -likelihood = -950.47339
# Iteration=7, theta_new=[-0.32560273 -1.9696875   1.09485951], -likelihood = -958.50708
# Iteration=8, theta_new=[-0.31867454 -1.97447342  1.092049  ], -likelihood = -963.67430
# Iteration=9, theta_new=[-0.31314169 -1.97815339  1.09023184], -likelihood = -966.98367
# Iteration=10, theta_new=[-0.30870999 -1.9811913   1.08909543], -likelihood = -969.09947
# Iteration=11, theta_new=[-0.30518325 -1.98372252  1.08842733], -likelihood = -970.46725
# Iteration=12, theta_new=[-0.30240634 -1.98593551  1.0880816 ], -likelihood = -971.35223
# Iteration=13, theta_new=[-0.30018568 -1.98806769  1.08796192], -likelihood = -971.93031
# Iteration=14, theta_new=[-0.29842594 -1.99003815  1.0879941 ], -likelihood = -972.32908
# Iteration=15, theta_new=[-0.29704363 -1.99192194  1.08820234], -likelihood = -972.60908
# Iteration=16, theta_new=[-0.29592251 -1.99386044  1.08851221], -likelihood = -972.82151
# Iteration=17, theta_new=[-0.2950489  -1.99576092  1.0888427 ], -likelihood = -972.99815
# Iteration=18, theta_new=[-0.29434587 -1.99774248  1.08923091], -likelihood = -973.14353
# Iteration=19, theta_new=[-0.29381251 -1.99972066  1.0896847 ], -likelihood = -973.27855
# Iteration=20, theta_new=[-0.29337821 -2.00174225  1.09014241], -likelihood = -973.40668
# 12-th start
# Iteration=1, theta_new=[ 2.66232034 -1.18258124 -3.12835955], -likelihood = -722.25301
# Iteration=2, theta_new=[ 2.65704895 -1.27581216 -3.11328833], -likelihood = -779.58376
# Iteration=3, theta_new=[ 2.65368358 -1.39577207 -3.09186299], -likelihood = -843.32356
# Iteration=4, theta_new=[ 2.65182175 -1.57080273 -3.06329128], -likelihood = -906.38213
# Iteration=5, theta_new=[ 2.65102078 -1.57072068 -3.03042823], -likelihood = -949.38455
# Iteration=6, theta_new=[ 2.65037629 -1.57081692 -2.99822666], -likelihood = -993.91956
# Iteration=7, theta_new=[ 2.64958236 -1.57084193 -2.96955617], -likelihood = -1042.89520
# Iteration=8, theta_new=[ 2.64857557 -1.57082735 -2.94536804], -likelihood = -1087.47172
# Iteration=9, theta_new=[ 2.64744137 -1.57081401 -2.92556224], -likelihood = -1122.92874
# Iteration=10, theta_new=[ 2.64632648 -1.57083778 -2.90960612], -likelihood = -1148.62434
# Iteration=11, theta_new=[ 2.64530748 -1.57084467 -2.89688253], -likelihood = -1166.13683
# Iteration=12, theta_new=[ 2.64441774 -1.57081976 -2.88679325], -likelihood = -1177.60323
# Iteration=13, theta_new=[ 2.64369185 -1.57084591 -2.87879739], -likelihood = -1184.93172
# Iteration=14, theta_new=[ 2.64308721 -1.57070117 -2.87247424], -likelihood = -1189.55937
# Iteration=15, theta_new=[ 2.64260659 -1.57084015 -2.86747663], -likelihood = -1192.45564
# Iteration=16, theta_new=[ 2.64222416 -1.57077138 -2.86351655], -likelihood = -1194.25940
# Iteration=17, theta_new=[ 2.64191625 -1.57079706 -2.8603904 ], -likelihood = -1195.38218
# Iteration=18, theta_new=[ 2.6416659  -1.57076809 -2.85790817], -likelihood = -1196.07668
# Iteration=19, theta_new=[ 2.64149964 -1.57083426 -2.85594354], -likelihood = -1196.50759
# Iteration=20, theta_new=[ 2.64137866 -1.57078932 -2.85438567], -likelihood = -1196.77331
# 13-th start
# Iteration=1, theta_new=[-3.09951874  0.26738144  2.72830329], -likelihood = -579.65774
# Iteration=2, theta_new=[-3.07878683  0.24917505  2.71278063], -likelihood = -655.90099
# Iteration=3, theta_new=[-3.05514253  0.23431924  2.70088154], -likelihood = -694.25685
# Iteration=4, theta_new=[-3.02897509  0.22195897  2.69101904], -likelihood = -727.43129
# Iteration=5, theta_new=[-3.00142032  0.21197766  2.68225779], -likelihood = -764.41014
# Iteration=6, theta_new=[-2.97440301  0.2045487   2.67419267], -likelihood = -807.42553
# Iteration=7, theta_new=[-2.94967777  0.19975584  2.66668129], -likelihood = -853.05281
# Iteration=8, theta_new=[-2.92833874  0.19728479  2.66004609], -likelihood = -895.13462
# Iteration=9, theta_new=[-2.9106324   0.19643752  2.65438106], -likelihood = -928.77450
# Iteration=10, theta_new=[-2.89634795  0.19659788  2.64969711], -likelihood = -952.88869
# Iteration=11, theta_new=[-2.8849617   0.19736289  2.64595277], -likelihood = -968.90054
# Iteration=12, theta_new=[-2.87595451  0.19838926  2.64300722], -likelihood = -979.09140
# Iteration=13, theta_new=[-2.86883927  0.19948598  2.64069524], -likelihood = -985.42080
# Iteration=14, theta_new=[-2.86323597  0.20063089  2.63889582], -likelihood = -989.31171
# Iteration=15, theta_new=[-2.85884381  0.2017482   2.63751149], -likelihood = -991.68613
# Iteration=16, theta_new=[-2.8553476   0.20279577  2.63645935], -likelihood = -993.12466
# Iteration=17, theta_new=[-2.8526044   0.20382086  2.63564903], -likelihood = -994.00572
# Iteration=18, theta_new=[-2.85044938  0.20477638  2.63498926], -likelihood = -994.53902
# Iteration=19, theta_new=[-2.84879621  0.2056483   2.63446956], -likelihood = -994.86222
# Iteration=20, theta_new=[-2.84745849  0.20641502  2.63407287], -likelihood = -995.05379
# 14-th start
# Iteration=1, theta_new=[-0.12418364 -1.5708333   1.2941168 ], -likelihood = -527.20854
# Iteration=2, theta_new=[-0.15771925 -1.40273805  1.20197368], -likelihood = -662.34541
# Iteration=3, theta_new=[-0.18612433 -1.32925337  1.15738141], -likelihood = -785.08098
# Iteration=4, theta_new=[-0.20897252 -1.28818721  1.1318118 ], -likelihood = -858.82109
# Iteration=5, theta_new=[-0.22692357 -1.26215931  1.11536159], -likelihood = -902.98238
# Iteration=6, theta_new=[-0.24091895 -1.24465497  1.10424145], -likelihood = -929.67094
# Iteration=7, theta_new=[-0.25183404 -1.23253023  1.09649319], -likelihood = -945.69946
# Iteration=8, theta_new=[-0.26034404 -1.22397657  1.0910371 ], -likelihood = -955.31940
# Iteration=9, theta_new=[-0.26701534 -1.21782818  1.08712855], -likelihood = -961.09864
# Iteration=10, theta_new=[-0.27225761 -1.2134384   1.08428429], -likelihood = -964.60016
# Iteration=11, theta_new=[-0.27635154 -1.2102272   1.08223523], -likelihood = -966.72874
# Iteration=12, theta_new=[-0.27960513 -1.20789172  1.08075129], -likelihood = -968.02311
# Iteration=13, theta_new=[-0.28216159 -1.20618287  1.07963757], -likelihood = -968.82555
# Iteration=14, theta_new=[-0.28417051 -1.2049014   1.07880861], -likelihood = -969.31692
# Iteration=15, theta_new=[-0.28577098 -1.20400663  1.07822015], -likelihood = -969.61990
# Iteration=16, theta_new=[-0.28703103 -1.20330358  1.07779195], -likelihood = -969.80907
# Iteration=17, theta_new=[-0.28801233 -1.20277273  1.07745456], -likelihood = -969.92835
# Iteration=18, theta_new=[-0.28878062 -1.20234327  1.0771903 ], -likelihood = -970.00098
# Iteration=19, theta_new=[-0.28939716 -1.2021065   1.07702693], -likelihood = -970.04659
# Iteration=20, theta_new=[-0.28991251 -1.20208579  1.0769493 ], -likelihood = -970.07507
# 15-th start
# Iteration=1, theta_new=[ 2.53713493 -0.84770674  1.21383902], -likelihood = -862.35546
# Iteration=2, theta_new=[ 2.56139641 -0.84381331  1.19249725], -likelihood = -911.17955
# Iteration=3, theta_new=[ 2.58022431 -0.83877726  1.17646331], -likelihood = -945.69952
# Iteration=4, theta_new=[ 2.59442965 -0.83327703  1.16445733], -likelihood = -967.84384
# Iteration=5, theta_new=[ 2.60512874 -0.82767789  1.15534961], -likelihood = -981.17863
# Iteration=6, theta_new=[ 2.61311262 -0.82218607  1.1484351 ], -likelihood = -989.05978
# Iteration=7, theta_new=[ 2.61909312 -0.8168047   1.14313383], -likelihood = -993.65824
# Iteration=8, theta_new=[ 2.62350111 -0.81164865  1.13897198], -likelihood = -996.37551
# Iteration=9, theta_new=[ 2.62675131 -0.80661844  1.13569848], -likelihood = -997.99758
# Iteration=10, theta_new=[ 2.62920894 -0.80187173  1.13308802], -likelihood = -999.00646
# Iteration=11, theta_new=[ 2.63099984 -0.79738976  1.13093683], -likelihood = -999.66790
# Iteration=12, theta_new=[ 2.63234112 -0.79315743  1.12916318], -likelihood = -1000.11895
# Iteration=13, theta_new=[ 2.63332263 -0.78913425  1.12764386], -likelihood = -1000.44774
# Iteration=14, theta_new=[ 2.6340242  -0.78534653  1.1263928 ], -likelihood = -1000.70119
# Iteration=15, theta_new=[ 2.63455967 -0.78180346  1.1252324 ], -likelihood = -1000.90273
# Iteration=16, theta_new=[ 2.63490784 -0.77842307  1.12427183], -likelihood = -1001.07127
# Iteration=17, theta_new=[ 2.63518823 -0.7752636   1.12338229], -likelihood = -1001.21454
# Iteration=18, theta_new=[ 2.63535171 -0.77228888  1.12256705], -likelihood = -1001.33826
# Iteration=19, theta_new=[ 2.63546872 -0.76954832  1.12182587], -likelihood = -1001.44652
# Iteration=20, theta_new=[ 2.63555126 -0.76695373  1.12119011], -likelihood = -1001.53966
# 16-th start
# Iteration=1, theta_new=[-2.88716202 -1.57076652  3.08336239], -likelihood = -810.01474
# Iteration=2, theta_new=[-2.88245086 -1.57082404  3.08352317], -likelihood = -845.09657
# Iteration=3, theta_new=[-2.87853528 -1.5709294   3.08337421], -likelihood = -846.76780
# Iteration=4, theta_new=[-2.87532641 -1.57081387  3.0830574 ], -likelihood = -847.91504
# Iteration=5, theta_new=[-2.87268187 -1.57080025  3.0826178 ], -likelihood = -848.69214
# Iteration=6, theta_new=[-2.87050803 -1.57074881  3.08211228], -likelihood = -849.22148
# Iteration=7, theta_new=[-2.86870089 -1.57077981  3.08155623], -likelihood = -849.58119
# Iteration=8, theta_new=[-2.86720616 -1.57080566  3.08097604], -likelihood = -849.82794
# Iteration=9, theta_new=[-2.86597243 -1.57079901  3.08042993], -likelihood = -849.99579
# Iteration=10, theta_new=[-2.86495536 -1.57077466  3.07988103], -likelihood = -850.10960
# Iteration=11, theta_new=[-2.86411468 -1.57077422  3.07935337], -likelihood = -850.18590
# Iteration=12, theta_new=[-2.86342092 -1.57079288  3.07885615], -likelihood = -850.23678
# Iteration=13, theta_new=[-2.86286013 -1.57080163  3.07838476], -likelihood = -850.27017
# Iteration=14, theta_new=[-2.86237893 -1.57076708  3.07794388], -likelihood = -850.29101
# Iteration=15, theta_new=[-2.86199117 -1.5708195   3.07754086], -likelihood = -850.30451
# Iteration=16, theta_new=[-2.86166626 -1.57082575  3.07715494], -likelihood = -850.31203
# Iteration=17, theta_new=[-2.86139544 -1.57079047  3.07683986], -likelihood = -850.31571
# Iteration=18, theta_new=[-2.86116462 -1.57085864  3.0765351 ], -likelihood = -850.31747
# Iteration=19, theta_new=[-2.86097419 -1.57077328  3.07627631], -likelihood = -850.31737
# Iteration=20, theta_new=[-2.86081256 -1.57074444  3.07603426], -likelihood = -850.31642
# 17-th start
# Iteration=1, theta_new=[ 1.79519812 -1.00919094 -0.95867103], -likelihood = -517.35640
# Iteration=2, theta_new=[ 1.84700563 -1.0425486  -0.91505587], -likelihood = -536.72281
# Iteration=3, theta_new=[ 1.89001982 -1.06675185 -0.87719165], -likelihood = -569.03902
# Iteration=4, theta_new=[ 1.92600459 -1.0798644  -0.84707577], -likelihood = -599.69486
# Iteration=5, theta_new=[ 1.95477329 -1.08816426 -0.82308434], -likelihood = -622.46255
# Iteration=6, theta_new=[ 1.97727913 -1.09433733 -0.8040272 ], -likelihood = -637.66346
# Iteration=7, theta_new=[ 1.99486244 -1.09974237 -0.78892375], -likelihood = -647.11969
# Iteration=8, theta_new=[ 2.00866814 -1.10479702 -0.7770413 ], -likelihood = -652.79177
# Iteration=9, theta_new=[ 2.01961307 -1.10996084 -0.76761685], -likelihood = -656.11513
# Iteration=10, theta_new=[ 2.02835238 -1.11516144 -0.76012938], -likelihood = -658.03843
# Iteration=11, theta_new=[ 2.03538875 -1.12044288 -0.75422489], -likelihood = -659.12530
# Iteration=12, theta_new=[ 2.04112325 -1.12596293 -0.74951809], -likelihood = -659.71384
# Iteration=13, theta_new=[ 2.04589824 -1.13157954 -0.74581276], -likelihood = -660.01004
# Iteration=14, theta_new=[ 2.04992812 -1.13728783 -0.74290835], -likelihood = -660.13468
# Iteration=15, theta_new=[ 2.05339354 -1.14307679 -0.74071041], -likelihood = -660.15889
# Iteration=16, theta_new=[ 2.05638895 -1.14890534 -0.73906699], -likelihood = -660.12563
# Iteration=17, theta_new=[ 2.05902222 -1.15489284 -0.73789206], -likelihood = -660.06100
# Iteration=18, theta_new=[ 2.061392   -1.1608832  -0.73710431], -likelihood = -659.97957
# Iteration=19, theta_new=[ 2.06358822 -1.16691582 -0.73660703], -likelihood = -659.89150
# Iteration=20, theta_new=[ 2.06563561 -1.17303884 -0.73633875], -likelihood = -659.80038
# 18-th start
# Iteration=1, theta_new=[ 1.24503346  1.77720939 -1.74717833], -likelihood = -390.05648
# Iteration=2, theta_new=[ 1.18492516  1.8434981  -1.87475911], -likelihood = -501.24470
# Iteration=3, theta_new=[ 1.15409569  1.87406751 -1.92888504], -likelihood = -554.84437
# Iteration=4, theta_new=[ 1.12915415  1.88822981 -1.9643345 ], -likelihood = -570.51198
# Iteration=5, theta_new=[ 1.10685299  1.89232718 -1.99130166], -likelihood = -578.66733
# Iteration=6, theta_new=[ 1.08654812  1.89019498 -2.01410933], -likelihood = -584.96907
# Iteration=7, theta_new=[ 1.06811587  1.88471678 -2.03535936], -likelihood = -591.21714
# Iteration=8, theta_new=[ 1.0513655   1.87781497 -2.05646432], -likelihood = -597.96786
# Iteration=9, theta_new=[ 1.03614261  1.87049168 -2.0780915 ], -likelihood = -605.32087
# Iteration=10, theta_new=[ 1.02218041  1.86317067 -2.1001704 ], -likelihood = -613.17795
# Iteration=11, theta_new=[ 1.00946491  1.85640556 -2.12227302], -likelihood = -621.29787
# Iteration=12, theta_new=[ 0.99796027  1.85024318 -2.14362398], -likelihood = -629.21374
# Iteration=13, theta_new=[ 0.98767811  1.8449532  -2.16368856], -likelihood = -636.43976
# Iteration=14, theta_new=[ 0.97869652  1.84060979 -2.1819969 ], -likelihood = -642.61921
# Iteration=15, theta_new=[ 0.97094239  1.83708618 -2.19847311], -likelihood = -647.58089
# Iteration=16, theta_new=[ 0.9643536   1.83456858 -2.21307984], -likelihood = -651.40837
# Iteration=17, theta_new=[ 0.95884409  1.83293863 -2.22594339], -likelihood = -654.25068
# Iteration=18, theta_new=[ 0.95421136  1.83201489 -2.23728635], -likelihood = -656.31085
# Iteration=19, theta_new=[ 0.95036887  1.83162057 -2.24722485], -likelihood = -657.79600
# Iteration=20, theta_new=[ 0.94722045  1.8316403  -2.25589923], -likelihood = -658.84974
# 19-th start
# Iteration=1, theta_new=[-1.62812317 -2.99126065 -2.36853358], -likelihood = -627.43952
# Iteration=2, theta_new=[-1.57085805 -2.96338471 -2.35050501], -likelihood = -712.96965
# Iteration=3, theta_new=[-1.57076608 -2.94071908 -2.33324538], -likelihood = -765.81856
# Iteration=4, theta_new=[-1.57074529 -2.92272707 -2.31733084], -likelihood = -805.21398
# Iteration=5, theta_new=[-1.57076938 -2.90858295 -2.30306154], -likelihood = -833.06686
# Iteration=6, theta_new=[-1.57080171 -2.89750177 -2.29044849], -likelihood = -852.18992
# Iteration=7, theta_new=[-1.57075887 -2.88882545 -2.27952721], -likelihood = -865.21697
# Iteration=8, theta_new=[-1.57083976 -2.8820416  -2.2701579 ], -likelihood = -874.09679
# Iteration=9, theta_new=[-1.57095054 -2.87670429 -2.26223542], -likelihood = -880.19829
# Iteration=10, theta_new=[-1.57076357 -2.87252932 -2.2555204 ], -likelihood = -884.44457
# Iteration=11, theta_new=[-1.5708236  -2.86924877 -2.24990876], -likelihood = -887.44198
# Iteration=12, theta_new=[-1.57073741 -2.86667014 -2.24521538], -likelihood = -889.58495
# Iteration=13, theta_new=[-1.57079112 -2.86462557 -2.24136902], -likelihood = -891.14444
# Iteration=14, theta_new=[-1.57082975 -2.86302591 -2.23818442], -likelihood = -892.28686
# Iteration=15, theta_new=[-1.57076323 -2.86175249 -2.23556431], -likelihood = -893.13834
# Iteration=16, theta_new=[-1.57078452 -2.86075125 -2.23343609], -likelihood = -893.78263
# Iteration=17, theta_new=[-1.57078081 -2.85995202 -2.23166295], -likelihood = -894.26991
# Iteration=18, theta_new=[-1.57079052 -2.85932807 -2.23026355], -likelihood = -894.65131
# Iteration=19, theta_new=[-1.57075941 -2.85882749 -2.22911767], -likelihood = -894.93870
# Iteration=20, theta_new=[-1.57083049 -2.85842269 -2.22813307], -likelihood = -895.16480
# 20-th start
# Iteration=1, theta_new=[-2.33970254  3.02780632 -1.57075624], -likelihood = -571.65347
# Iteration=2, theta_new=[-2.327991    3.03205213 -1.57082738], -likelihood = -577.39764
# Iteration=3, theta_new=[-2.31742127  3.03541877 -1.57078983], -likelihood = -581.03650
# Iteration=4, theta_new=[-2.30797697  3.03809998 -1.57079585], -likelihood = -584.06473
# Iteration=5, theta_new=[-2.29968206  3.0402357  -1.5707295 ], -likelihood = -586.57661
# Iteration=6, theta_new=[-2.29245539  3.04195798 -1.57085196], -likelihood = -588.63739
# Iteration=7, theta_new=[-2.28622588  3.04332804 -1.57077099], -likelihood = -590.32453
# Iteration=8, theta_new=[-2.28087139  3.04444273 -1.57076199], -likelihood = -591.69657
# Iteration=9, theta_new=[-2.27629354  3.045334   -1.57077867], -likelihood = -592.81623
# Iteration=10, theta_new=[-2.2723994   3.04607031 -1.57079554], -likelihood = -593.72831
# Iteration=11, theta_new=[-2.26912543  3.04667173 -1.57078385], -likelihood = -594.47259
# Iteration=12, theta_new=[-2.26635011  3.04714547 -1.57076648], -likelihood = -595.07546
# Iteration=13, theta_new=[-2.26397705  3.04755396 -1.57082335], -likelihood = -595.56874
# Iteration=14, theta_new=[-2.26200314  3.04788682 -1.5707354 ], -likelihood = -595.97915
# Iteration=15, theta_new=[-2.26036569  3.04814374 -1.57084929], -likelihood = -596.31195
# Iteration=16, theta_new=[-2.25898313  3.04836485 -1.57078135], -likelihood = -596.58140
# Iteration=17, theta_new=[-2.25785698  3.04853664 -1.5707969 ], -likelihood = -596.80506
# Iteration=18, theta_new=[-2.25690354  3.04867866 -1.57076562], -likelihood = -596.98413
# Iteration=19, theta_new=[-2.25611347  3.04879643 -1.57077098], -likelihood = -597.13364
# Iteration=20, theta_new=[-2.25544499  3.04890309 -1.57083075], -likelihood = -597.25620
# 21-th start
# Iteration=1, theta_new=[ 1.04428708 -2.21386266 -2.9164798 ], -likelihood = -885.35373
# Iteration=2, theta_new=[ 1.06467882 -2.20749031 -2.90228514], -likelihood = -921.71018
# Iteration=3, theta_new=[ 1.08036664 -2.20157703 -2.89123484], -likelihood = -943.59551
# Iteration=4, theta_new=[ 1.09237423 -2.19619295 -2.88265519], -likelihood = -956.76482
# Iteration=5, theta_new=[ 1.1015135  -2.19146338 -2.87600733], -likelihood = -964.75553
# Iteration=6, theta_new=[ 1.10846332 -2.18728858 -2.87079334], -likelihood = -969.65085
# Iteration=7, theta_new=[ 1.11367952 -2.1837198  -2.8667678 ], -likelihood = -972.71699
# Iteration=8, theta_new=[ 1.1176396  -2.18059464 -2.86360099], -likelihood = -974.63629
# Iteration=9, theta_new=[ 1.12065112 -2.17778317 -2.86111637], -likelihood = -975.87898
# Iteration=10, theta_new=[ 1.12284566 -2.17535705 -2.85919008], -likelihood = -976.69840
# Iteration=11, theta_new=[ 1.12448019 -2.17316233 -2.8576809 ], -likelihood = -977.23730
# Iteration=12, theta_new=[ 1.12571995 -2.17116409 -2.85647358], -likelihood = -977.60667
# Iteration=13, theta_new=[ 1.12655909 -2.16939857 -2.85555131], -likelihood = -977.87005
# Iteration=14, theta_new=[ 1.12715638 -2.16782082 -2.85480026], -likelihood = -978.05185
# Iteration=15, theta_new=[ 1.12757914 -2.16636695 -2.85420218], -likelihood = -978.18657
# Iteration=16, theta_new=[ 1.12786944 -2.16496851 -2.85372983], -likelihood = -978.28829
# Iteration=17, theta_new=[ 1.12800402 -2.16373555 -2.85335906], -likelihood = -978.36777
# Iteration=18, theta_new=[ 1.12813502 -2.16256308 -2.85307386], -likelihood = -978.42636
# Iteration=19, theta_new=[ 1.12813295 -2.16146359 -2.85284569], -likelihood = -978.47557
# Iteration=20, theta_new=[ 1.12812761 -2.16049932 -2.8526796 ], -likelihood = -978.51310
# 22-th start
# Iteration=1, theta_new=[-0.94183217 -0.34680073 -1.5708251 ], -likelihood = -836.92264
# Iteration=2, theta_new=[-0.93801631 -0.3341139  -1.57079613], -likelihood = -866.44059
# Iteration=3, theta_new=[-0.93483591 -0.32389928 -1.57082822], -likelihood = -878.03648
# Iteration=4, theta_new=[-0.93216778 -0.3157248  -1.57082063], -likelihood = -885.50141
# Iteration=5, theta_new=[-0.92993464 -0.30922254 -1.57076629], -likelihood = -890.17177
# Iteration=6, theta_new=[-0.92797806 -0.30405447 -1.57076986], -likelihood = -893.01746
# Iteration=7, theta_new=[-0.92630018 -0.2999755  -1.57079393], -likelihood = -894.70029
# Iteration=8, theta_new=[-0.92489993 -0.29674873 -1.5707282 ], -likelihood = -895.65760
# Iteration=9, theta_new=[-0.92369355 -0.29420001 -1.57085925], -likelihood = -896.18203
# Iteration=10, theta_new=[-0.92269035 -0.29219655 -1.57081245], -likelihood = -896.44213
# Iteration=11, theta_new=[-0.92181444 -0.29061452 -1.57078677], -likelihood = -896.55151
# Iteration=12, theta_new=[-0.92108563 -0.28936819 -1.57081127], -likelihood = -896.57134
# Iteration=13, theta_new=[-0.92048191 -0.28838566 -1.57074953], -likelihood = -896.54726
# Iteration=14, theta_new=[-0.91998566 -0.2876108  -1.57081305], -likelihood = -896.50277
# Iteration=15, theta_new=[-0.91954448 -0.28698911 -1.57079133], -likelihood = -896.45145
# Iteration=16, theta_new=[-0.91918958 -0.28650544 -1.57083578], -likelihood = -896.39542
# Iteration=17, theta_new=[-0.9189009  -0.28611733 -1.57080801], -likelihood = -896.34481
# Iteration=18, theta_new=[-0.91867389 -0.28582924 -1.57077189], -likelihood = -896.30027
# Iteration=19, theta_new=[-0.91849229 -0.28558886 -1.57076968], -likelihood = -896.26337
# Iteration=20, theta_new=[-0.91831896 -0.28540337 -1.57083544], -likelihood = -896.23249
# 23-th start
# Iteration=1, theta_new=[-1.51354662  0.90702417 -1.24108728], -likelihood = -517.20091
# Iteration=2, theta_new=[-1.57074424  0.92125806 -1.19876327], -likelihood = -560.47560
# Iteration=3, theta_new=[-1.57079707  0.9327615  -1.14602142], -likelihood = -576.03734
# Iteration=4, theta_new=[-1.57079911  0.94159152 -1.09368837], -likelihood = -595.84205
# Iteration=5, theta_new=[-1.57080785  0.94772768 -1.0486456 ], -likelihood = -614.90869
# Iteration=6, theta_new=[-1.57079521  0.95191315 -1.01159544], -likelihood = -629.38157
# Iteration=7, theta_new=[-1.57078023  0.95493784 -0.98123997], -likelihood = -639.29084
# Iteration=8, theta_new=[-1.57077687  0.95735323 -0.95619301], -likelihood = -645.86222
# Iteration=9, theta_new=[-1.57078793  0.95948628 -0.93533457], -likelihood = -650.19710
# Iteration=10, theta_new=[-1.57082836  0.96150828 -0.91777543], -likelihood = -653.06985
# Iteration=11, theta_new=[-1.57080126  0.96350089 -0.90287998], -likelihood = -654.99264
# Iteration=12, theta_new=[-1.5707858   0.96546924 -0.89012926], -likelihood = -656.29015
# Iteration=13, theta_new=[-1.57084857  0.96742173 -0.87913814], -likelihood = -657.17499
# Iteration=14, theta_new=[-1.57081117  0.96935563 -0.86962204], -likelihood = -657.78230
# Iteration=15, theta_new=[-1.57078717  0.97123756 -0.86129302], -likelihood = -658.19987
# Iteration=16, theta_new=[-1.57082401  0.97306115 -0.85399035], -likelihood = -658.48871
# Iteration=17, theta_new=[-1.57080471  0.97480933 -0.84755899], -likelihood = -658.68644
# Iteration=18, theta_new=[-1.57079537  0.97647184 -0.84186502], -likelihood = -658.81989
# Iteration=19, theta_new=[-1.57080901  0.97804033 -0.83679959], -likelihood = -658.90762
# Iteration=20, theta_new=[-1.57075756  0.97950122 -0.83226541], -likelihood = -658.96249
# 24-th start
# Iteration=1, theta_new=[-2.1294062   1.37343839 -2.56492508], -likelihood = -614.07212
# Iteration=2, theta_new=[-2.1486154   1.31661886 -2.57931301], -likelihood = -640.21736
# Iteration=3, theta_new=[-2.16335141  1.27806253 -2.59624331], -likelihood = -657.73262
# Iteration=4, theta_new=[-2.17482136  1.24933906 -2.61661726], -likelihood = -673.78168
# Iteration=5, theta_new=[-2.18336703  1.22672072 -2.64095548], -likelihood = -693.12009
# Iteration=6, theta_new=[-2.18912294  1.2081146  -2.66890025], -likelihood = -720.35699
# Iteration=7, theta_new=[-2.19200535  1.19228948 -2.69844118], -likelihood = -758.95806
# Iteration=8, theta_new=[-2.19201376  1.17881232 -2.72675647], -likelihood = -806.98449
# Iteration=9, theta_new=[-2.18992805  1.16753739 -2.75164777], -likelihood = -855.93644
# Iteration=10, theta_new=[-2.18682856  1.15845675 -2.77242019], -likelihood = -896.88644
# Iteration=11, theta_new=[-2.18336146  1.15137757 -2.78919314], -likelihood = -926.63237
# Iteration=12, theta_new=[-2.18000746  1.14594372 -2.80254895], -likelihood = -946.39847
# Iteration=13, theta_new=[-2.17702018  1.14174345 -2.81310948], -likelihood = -958.94858
# Iteration=14, theta_new=[-2.17430771  1.13858312 -2.82143079], -likelihood = -966.72730
# Iteration=15, theta_new=[-2.17196518  1.13613501 -2.82797749], -likelihood = -971.48998
# Iteration=16, theta_new=[-2.16980453  1.13428854 -2.8331175 ], -likelihood = -974.38057
# Iteration=17, theta_new=[-2.16792419  1.13283742 -2.83714504], -likelihood = -976.12681
# Iteration=18, theta_new=[-2.16623891  1.13173055 -2.84032769], -likelihood = -977.17171
# Iteration=19, theta_new=[-2.16465345  1.13082618 -2.84283894], -likelihood = -977.79949
# Iteration=20, theta_new=[-2.1632033   1.1301618  -2.84478101], -likelihood = -978.17352
# 25-th start
# Iteration=1, theta_new=[-2.67029969 -1.57081554  2.41254454], -likelihood = -714.10257
# Iteration=2, theta_new=[-2.6964188  -1.5707851   2.43667849], -likelihood = -759.87272
# Iteration=3, theta_new=[-2.72171448 -1.57077646  2.46913603], -likelihood = -819.08510
# Iteration=4, theta_new=[-2.74490022 -1.57075327  2.50472811], -likelihood = -901.36245
# Iteration=5, theta_new=[-2.76497078 -1.57076525  2.53669763], -likelihood = -991.31461
# Iteration=6, theta_new=[-2.78162202 -1.57082109  2.5623327 ], -likelihood = -1065.00504
# Iteration=7, theta_new=[-2.79512064 -1.57079868  2.58197728], -likelihood = -1115.28888
# Iteration=8, theta_new=[-2.80596881 -1.57085263  2.59676676], -likelihood = -1147.07051
# Iteration=9, theta_new=[-2.8146504  -1.57083963  2.60785707], -likelihood = -1166.62096
# Iteration=10, theta_new=[-2.82157797 -1.57084136  2.61616613], -likelihood = -1178.54987
# Iteration=11, theta_new=[-2.82708324 -1.57079264  2.62236543], -likelihood = -1185.80504
# Iteration=12, theta_new=[-2.83147592 -1.57077308  2.62702297], -likelihood = -1190.20137
# Iteration=13, theta_new=[-2.8349623  -1.57075629  2.63050996], -likelihood = -1192.88462
# Iteration=14, theta_new=[-2.8377309  -1.57081714  2.63312109], -likelihood = -1194.51910
# Iteration=15, theta_new=[-2.83993196 -1.57083296  2.63507981], -likelihood = -1195.51925
# Iteration=16, theta_new=[-2.84167562 -1.5707317   2.63653831], -likelihood = -1196.13523
# Iteration=17, theta_new=[-2.843064   -1.57076897  2.63764261], -likelihood = -1196.51515
# Iteration=18, theta_new=[-2.84416737 -1.57081748  2.63846911], -likelihood = -1196.75339
# Iteration=19, theta_new=[-2.84501582 -1.57078744  2.6390808 ], -likelihood = -1196.90305
# Iteration=20, theta_new=[-2.84570943 -1.57086101  2.63953754], -likelihood = -1196.99579
# 26-th start
# Iteration=1, theta_new=[ 0.40591327 -2.04879424 -0.79273086], -likelihood = -610.84717
# Iteration=2, theta_new=[ 0.42937538 -1.98353555 -0.79845159], -likelihood = -714.89312
# Iteration=3, theta_new=[ 0.44649237 -1.91421666 -0.80567215], -likelihood = -790.29185
# Iteration=4, theta_new=[ 0.45902464 -1.83815473 -0.81229349], -likelihood = -843.18275
# Iteration=5, theta_new=[ 0.46835449 -1.74581526 -0.8176137 ], -likelihood = -881.58674
# Iteration=6, theta_new=[ 0.47536661 -1.57077482 -0.82189094], -likelihood = -910.49633
# Iteration=7, theta_new=[ 0.48038107 -1.57081396 -0.82708187], -likelihood = -922.12653
# Iteration=8, theta_new=[ 0.4841737  -1.57081491 -0.83148031], -likelihood = -924.41400
# Iteration=9, theta_new=[ 0.48702432 -1.57072803 -0.83522781], -likelihood = -925.90767
# Iteration=10, theta_new=[ 0.48917414 -1.57075703 -0.83842649], -likelihood = -926.91603
# Iteration=11, theta_new=[ 0.49079448 -1.57080997 -0.84111586], -likelihood = -927.62428
# Iteration=12, theta_new=[ 0.49202839 -1.570809   -0.84340958], -likelihood = -928.13444
# Iteration=13, theta_new=[ 0.49295258 -1.57076306 -0.8453687 ], -likelihood = -928.51827
# Iteration=14, theta_new=[ 0.49365372 -1.57081833 -0.84703504], -likelihood = -928.81436
# Iteration=15, theta_new=[ 0.49418345 -1.57066391 -0.84849659], -likelihood = -929.04788
# Iteration=16, theta_new=[ 0.49458678 -1.57087893 -0.84973163], -likelihood = -929.24050
# Iteration=17, theta_new=[ 0.49488362 -1.5707988  -0.85073928], -likelihood = -929.39641
# Iteration=18, theta_new=[ 0.49511097 -1.57081365 -0.85163295], -likelihood = -929.51950
# Iteration=19, theta_new=[ 0.49527918 -1.57083498 -0.85237669], -likelihood = -929.62576
# Iteration=20, theta_new=[ 0.4954073  -1.57076608 -0.8530071 ], -likelihood = -929.71247
# 27-th start
# Iteration=1, theta_new=[-2.73143607  2.53857375  0.17653058], -likelihood = -731.59575
# Iteration=2, theta_new=[-2.75450596  2.56414927  0.17841593], -likelihood = -829.00115
# Iteration=3, theta_new=[-2.77315674  2.58276308  0.18111749], -likelihood = -894.78057
# Iteration=4, theta_new=[-2.7879561   2.59622846  0.18399632], -likelihood = -934.82362
# Iteration=5, theta_new=[-2.79961703  2.60600147  0.18686663], -likelihood = -958.64952
# Iteration=6, theta_new=[-2.80880615  2.61311855  0.18928914], -likelihood = -972.87228
# Iteration=7, theta_new=[-2.81605176  2.61832275  0.19140339], -likelihood = -981.42405
# Iteration=8, theta_new=[-2.82168845  2.62218534  0.19331679], -likelihood = -986.62002
# Iteration=9, theta_new=[-2.8261113   2.6250166   0.19508808], -likelihood = -989.78729
# Iteration=10, theta_new=[-2.82963014  2.62712528  0.19664204], -likelihood = -991.74249
# Iteration=11, theta_new=[-2.83234681  2.62869931  0.1980214 ], -likelihood = -992.97450
# Iteration=12, theta_new=[-2.83453874  2.62990371  0.19939023], -likelihood = -993.74232
# Iteration=13, theta_new=[-2.83622027  2.63073689  0.20055001], -likelihood = -994.24965
# Iteration=14, theta_new=[-2.83759766  2.63135758  0.20163823], -likelihood = -994.56774
# Iteration=15, theta_new=[-2.83867569  2.63183626  0.20268616], -likelihood = -994.78615
# Iteration=16, theta_new=[-2.83952585  2.63213656  0.20365474], -likelihood = -994.93545
# Iteration=17, theta_new=[-2.84016032  2.63239981  0.20454564], -likelihood = -995.03787
# Iteration=18, theta_new=[-2.84066833  2.63256348  0.20538898], -likelihood = -995.11009
# Iteration=19, theta_new=[-2.84109257  2.63268112  0.2061928 ], -likelihood = -995.16368
# Iteration=20, theta_new=[-2.84143132  2.63276207  0.20693842], -likelihood = -995.20599
# 28-th start
# Iteration=1, theta_new=[-0.41215398  0.62974018  0.05904192], -likelihood = -660.82774
# Iteration=2, theta_new=[-0.38786703  0.59801674  0.06003056], -likelihood = -768.55270
# Iteration=3, theta_new=[-0.36803567  0.57383942  0.05934125], -likelihood = -854.16695
# Iteration=4, theta_new=[-0.35235001  0.55611986  0.05756358], -likelihood = -910.30400
# Iteration=5, theta_new=[-0.34007816  0.54324388  0.05501027], -likelihood = -944.09578
# Iteration=6, theta_new=[-0.33054263  0.53398353  0.05198499], -likelihood = -963.93785
# Iteration=7, theta_new=[-0.32312954  0.52730545  0.04849327], -likelihood = -975.49855
# Iteration=8, theta_new=[-0.31734118  0.52250102  0.04459202], -likelihood = -982.34237
# Iteration=9, theta_new=[-0.31278884  0.51907436  0.04038298], -likelihood = -986.51338
# Iteration=10, theta_new=[-0.30926292  0.51659654  0.0358008 ], -likelihood = -989.17167
# Iteration=11, theta_new=[-0.3065091   0.51483352  0.03090191], -likelihood = -990.98759
# Iteration=12, theta_new=[-0.30435087  0.51350786  0.02572713], -likelihood = -992.34263
# Iteration=13, theta_new=[-0.30270851  0.51255563  0.02034992], -likelihood = -993.45959
# Iteration=14, theta_new=[-0.30149608  0.51187087  0.01468131], -likelihood = -994.43814
# Iteration=15, theta_new=[-0.30060609  0.51132543  0.00888644], -likelihood = -995.36418
# Iteration=16, theta_new=[-0.30001697  0.51087907  0.00293735], -likelihood = -996.25973
# Iteration=17, theta_new=[-0.2996581   0.51054384 -0.00308615], -likelihood = -997.14649
# Iteration=18, theta_new=[-0.29956369  0.51023594 -0.00917669], -likelihood = -998.02023
# Iteration=19, theta_new=[-0.29962175  0.50999376 -0.01526597], -likelihood = -998.88743
# Iteration=20, theta_new=[-0.29984669  0.50974178 -0.02128896], -likelihood = -999.73440
# 29-th start
# Iteration=1, theta_new=[1.91225122 0.70411972 0.5192608 ], -likelihood = -977.98121
# Iteration=2, theta_new=[1.92638177 0.72042986 0.51045741], -likelihood = -995.19905
# Iteration=3, theta_new=[1.93638214 0.73342005 0.50403567], -likelihood = -1003.60192
# Iteration=4, theta_new=[1.94350009 0.74380642 0.49927298], -likelihood = -1008.11888
# Iteration=5, theta_new=[1.94860234 0.75221529 0.49570271], -likelihood = -1010.67146
# Iteration=6, theta_new=[1.95202103 0.75910322 0.49303934], -likelihood = -1012.17002
# Iteration=7, theta_new=[1.95443099 0.76479727 0.49107   ], -likelihood = -1013.06826
# Iteration=8, theta_new=[1.95596971 0.76959596 0.48961474], -likelihood = -1013.62344
# Iteration=9, theta_new=[1.95680436 0.77369875 0.488592  ], -likelihood = -1013.97789
# Iteration=10, theta_new=[1.95722558 0.77731675 0.48789013], -likelihood = -1014.21274
# Iteration=11, theta_new=[1.95721366 0.78056914 0.48742091], -likelihood = -1014.37998
# Iteration=12, theta_new=[1.95693575 0.78353435 0.4871545 ], -likelihood = -1014.50644
# Iteration=13, theta_new=[1.95650316 0.78630258 0.48701948], -likelihood = -1014.60830
# Iteration=14, theta_new=[1.95580547 0.78886266 0.48697555], -likelihood = -1014.69505
# Iteration=15, theta_new=[1.9549485  0.79132479 0.48705717], -likelihood = -1014.77047
# Iteration=16, theta_new=[1.95399845 0.79370259 0.48721381], -likelihood = -1014.84174
# Iteration=17, theta_new=[1.95294637 0.79601898 0.48742252], -likelihood = -1014.90916
# Iteration=18, theta_new=[1.95182918 0.79829952 0.48765344], -likelihood = -1014.97363
# Iteration=19, theta_new=[1.95070276 0.80059078 0.48790091], -likelihood = -1015.03487
# Iteration=20, theta_new=[1.94950531 0.80284007 0.48821028], -likelihood = -1015.09354

# %%
EM_theta4_rad
# Out:
# array([ 1.11014402,  0.51014441, -0.29193645])

# %% [markdown]
# ## True Result

# %%
theta4_rad
# Out:
# [0.5, 1.1, -0.3]
