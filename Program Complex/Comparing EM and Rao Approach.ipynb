# %%
import numpy as np
import matplotlib.pyplot as plt
from sensors import *
from functools import partial

# %% [markdown]
# # Case 1

# %% [markdown]
# Имеется 5 датчиков, 1 источник (дисперсия сигнала 0.7), и шум на каждом датчике имеет дисперсию 4.1.

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
GS_1 = np.array([[0.7]]) # Ковариация сигнала
GN_1 = 4.1*np.eye(5, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s1 = CN(Num_emitters1, sample_size1, GS_1)
n1 = CN(Num_sensors1, sample_size1, GN_1)
X1 = (A1 @ s1.T + n1.T).T

# %% [markdown]
# ## ML1

# %%
theta_ML1_Case1, ML1_func_val_Case1 = multi_start_ML1(X1, L=Num_sensors1, M=Num_emitters1, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
np.rad2deg(theta_ML1_Case1)
# Out:
# array([29.33789075])

# %% [markdown]
# ## ML2

# %%
theta_ML2_Case1, ML2_func_val_Case1 = multi_start_ML2(X1, GS_1, GN_1, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
np.rad2deg(theta_ML2_Case1)
# Out:
# array([29.33789135])

# %% [markdown]
# ## EM

# %%
EM_theta1_rad, neglhd_1, K1, mu1 = multi_start_EM(X1, GS_1, GN_1, 10, max_iter=50, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[2.52948019], -likelihood = -134.32180
# Iteration=2, theta_new=[2.54627752], -likelihood = -137.83015
# Iteration=3, theta_new=[2.5603268], -likelihood = -140.41476
# Iteration=4, theta_new=[2.57201579], -likelihood = -142.27593
# Iteration=5, theta_new=[2.58174876], -likelihood = -143.59597
# Iteration=6, theta_new=[2.58981673], -likelihood = -144.52642
# Iteration=7, theta_new=[2.59651889], -likelihood = -145.17617
# Iteration=8, theta_new=[2.60209735], -likelihood = -145.62942
# Iteration=9, theta_new=[2.60673488], -likelihood = -145.94539
# Iteration=10, theta_new=[2.61055334], -likelihood = -146.16495
# Iteration=11, theta_new=[2.61374005], -likelihood = -146.31598
# Iteration=12, theta_new=[2.61642015], -likelihood = -146.42124
# Iteration=13, theta_new=[2.61859199], -likelihood = -146.49504
# Iteration=14, theta_new=[2.62044597], -likelihood = -146.54492
# Iteration=15, theta_new=[2.62198139], -likelihood = -146.58044
# Iteration=16, theta_new=[2.62326165], -likelihood = -146.60491
# Iteration=17, theta_new=[2.62428636], -likelihood = -146.62189
# Iteration=18, theta_new=[2.62518334], -likelihood = -146.63323
# Iteration=19, theta_new=[2.62588834], -likelihood = -146.64151
# Iteration=20, theta_new=[2.62652943], -likelihood = -146.64693
# Iteration=21, theta_new=[2.62704242], -likelihood = -146.65105
# Iteration=22, theta_new=[2.62749138], -likelihood = -146.65376
# Iteration=23, theta_new=[2.62781212], -likelihood = -146.65573
# Iteration=24, theta_new=[2.62813289], -likelihood = -146.65690
# Iteration=25, theta_new=[2.62838955], -likelihood = -146.65787
# Iteration=26, theta_new=[2.62858206], -likelihood = -146.65851
# Iteration=27, theta_new=[2.62877458], -likelihood = -146.65890
# Iteration=28, theta_new=[2.62890294], -likelihood = -146.65923
# Iteration=29, theta_new=[2.6290313], -likelihood = -146.65940
# Iteration=30, theta_new=[2.62909549], -likelihood = -146.65954
# Iteration=31, theta_new=[2.62915968], -likelihood = -146.65961
# Iteration=32, theta_new=[2.62922386], -likelihood = -146.65966
# Iteration=33, theta_new=[2.62928805], -likelihood = -146.65970
# Iteration=34, theta_new=[2.62935225], -likelihood = -146.65974
# Iteration=35, theta_new=[2.62941644], -likelihood = -146.65976
# norm=0.0
# Iteration=36, theta_new=[2.62941644], -likelihood = -146.65979
# 1-th start
# Iteration=1, theta_new=[-1.6573206], -likelihood = -77.27894
# Iteration=2, theta_new=[-1.69001384], -likelihood = -77.39330
# Iteration=3, theta_new=[-1.71386218], -likelihood = -77.49297
# Iteration=4, theta_new=[-1.73294229], -likelihood = -77.57906
# Iteration=5, theta_new=[-1.74885015], -likelihood = -77.65331
# Iteration=6, theta_new=[-1.76234226], -likelihood = -77.71711
# Iteration=7, theta_new=[-1.77404531], -likelihood = -77.77137
# Iteration=8, theta_new=[-1.78426686], -likelihood = -77.81770
# Iteration=9, theta_new=[-1.79324047], -likelihood = -77.85701
# Iteration=10, theta_new=[-1.80120848], -likelihood = -77.89021
# Iteration=11, theta_new=[-1.8083324], -likelihood = -77.91833
# Iteration=12, theta_new=[-1.81468982], -likelihood = -77.94218
# Iteration=13, theta_new=[-1.82036073], -likelihood = -77.96224
# Iteration=14, theta_new=[-1.82542716], -likelihood = -77.97906
# Iteration=15, theta_new=[-1.8299729], -likelihood = -77.99312
# Iteration=16, theta_new=[-1.83408319], -likelihood = -78.00489
# Iteration=17, theta_new=[-1.8378445], -likelihood = -78.01481
# Iteration=18, theta_new=[-1.84116482], -likelihood = -78.02324
# Iteration=19, theta_new=[-1.84422144], -likelihood = -78.03013
# Iteration=20, theta_new=[-1.84701299], -likelihood = -78.03601
# Iteration=21, theta_new=[-1.8495382], -likelihood = -78.04096
# Iteration=22, theta_new=[-1.85179594], -likelihood = -78.04510
# Iteration=23, theta_new=[-1.85387559], -likelihood = -78.04850
# Iteration=24, theta_new=[-1.85577654], -likelihood = -78.05139
# Iteration=25, theta_new=[-1.85749821], -likelihood = -78.05381
# Iteration=26, theta_new=[-1.85904008], -likelihood = -78.05582
# Iteration=27, theta_new=[-1.86040168], -likelihood = -78.05748
# Iteration=28, theta_new=[-1.86167344], -likelihood = -78.05882
# Iteration=29, theta_new=[-1.86285516], -likelihood = -78.05997
# Iteration=30, theta_new=[-1.86385572], -likelihood = -78.06095
# Iteration=31, theta_new=[-1.86476581], -likelihood = -78.06171
# Iteration=32, theta_new=[-1.86567634], -likelihood = -78.06235
# Iteration=33, theta_new=[-1.86649621], -likelihood = -78.06293
# Iteration=34, theta_new=[-1.86722531], -likelihood = -78.06341
# Iteration=35, theta_new=[-1.86786353], -likelihood = -78.06380
# Iteration=36, theta_new=[-1.86850196], -likelihood = -78.06411
# Iteration=37, theta_new=[-1.86904937], -likelihood = -78.06440
# Iteration=38, theta_new=[-1.86950568], -likelihood = -78.06462
# Iteration=39, theta_new=[-1.8699621], -likelihood = -78.06479
# Iteration=40, theta_new=[-1.87041863], -likelihood = -78.06495
# Iteration=41, theta_new=[-1.87078395], -likelihood = -78.06509
# Iteration=42, theta_new=[-1.87114934], -likelihood = -78.06519
# Iteration=43, theta_new=[-1.87142343], -likelihood = -78.06529
# Iteration=44, theta_new=[-1.87169757], -likelihood = -78.06535
# Iteration=45, theta_new=[-1.87197174], -likelihood = -78.06541
# Iteration=46, theta_new=[-1.87224596], -likelihood = -78.06547
# Iteration=47, theta_new=[-1.87242879], -likelihood = -78.06552
# Iteration=48, theta_new=[-1.87261165], -likelihood = -78.06555
# Iteration=49, theta_new=[-1.87279452], -likelihood = -78.06557
# Iteration=50, theta_new=[-1.87297741], -likelihood = -78.06560
# 2-th start
# Iteration=1, theta_new=[0.2217958], -likelihood = -88.61244
# Iteration=2, theta_new=[0.24111629], -likelihood = -91.96138
# Iteration=3, theta_new=[0.26211978], -likelihood = -96.07829
# Iteration=4, theta_new=[0.28438973], -likelihood = -100.98929
# Iteration=5, theta_new=[0.3073853], -likelihood = -106.56548
# Iteration=6, theta_new=[0.33031913], -likelihood = -112.54967
# Iteration=7, theta_new=[0.35257696], -likelihood = -118.55031
# Iteration=8, theta_new=[0.37351122], -likelihood = -124.21289
# Iteration=9, theta_new=[0.39269744], -likelihood = -129.23098
# Iteration=10, theta_new=[0.40995465], -likelihood = -133.44636
# Iteration=11, theta_new=[0.42516781], -likelihood = -136.84241
# Iteration=12, theta_new=[0.4384543], -likelihood = -139.47513
# Iteration=13, theta_new=[0.44992947], -likelihood = -141.46864
# Iteration=14, theta_new=[0.45977168], -likelihood = -142.94516
# Iteration=15, theta_new=[0.468123], -likelihood = -144.02235
# Iteration=16, theta_new=[0.47516313], -likelihood = -144.79533
# Iteration=17, theta_new=[0.48110267], -likelihood = -145.34448
# Iteration=18, theta_new=[0.4861768], -likelihood = -145.73403
# Iteration=19, theta_new=[0.49044984], -likelihood = -146.01297
# Iteration=20, theta_new=[0.49399411], -likelihood = -146.20925
# Iteration=21, theta_new=[0.49698509], -likelihood = -146.34518
# Iteration=22, theta_new=[0.49950884], -likelihood = -146.44094
# Iteration=23, theta_new=[0.50155761], -likelihood = -146.50824
# Iteration=24, theta_new=[0.50332089], -likelihood = -146.55379
# Iteration=25, theta_new=[0.50479547], -likelihood = -146.58648
# Iteration=26, theta_new=[0.50597858], -likelihood = -146.60920
# Iteration=27, theta_new=[0.50696682], -likelihood = -146.62439
# Iteration=28, theta_new=[0.50785797], -likelihood = -146.63499
# Iteration=29, theta_new=[0.50855231], -likelihood = -146.64295
# Iteration=30, theta_new=[0.50914827], -likelihood = -146.64808
# Iteration=31, theta_new=[0.50964549], -likelihood = -146.65174
# Iteration=32, theta_new=[0.51004365], -likelihood = -146.65428
# Iteration=33, theta_new=[0.5103425], -likelihood = -146.65596
# Iteration=34, theta_new=[0.51064153], -likelihood = -146.65702
# Iteration=35, theta_new=[0.510841], -likelihood = -146.65791
# Iteration=36, theta_new=[0.51104055], -likelihood = -146.65842
# Iteration=37, theta_new=[0.51124017], -likelihood = -146.65883
# Iteration=38, theta_new=[0.51134002], -likelihood = -146.65918
# Iteration=39, theta_new=[0.51143989], -likelihood = -146.65933
# Iteration=40, theta_new=[0.51153978], -likelihood = -146.65946
# Iteration=41, theta_new=[0.51163969], -likelihood = -146.65956
# Iteration=42, theta_new=[0.51173962], -likelihood = -146.65964
# Iteration=43, theta_new=[0.51183957], -likelihood = -146.65971
# norm=0.0
# Iteration=44, theta_new=[0.51183957], -likelihood = -146.65976
# 3-th start
# Iteration=1, theta_new=[2.8338097], -likelihood = -106.68025
# Iteration=2, theta_new=[2.81084035], -likelihood = -112.65403
# Iteration=3, theta_new=[2.78860616], -likelihood = -118.66265
# Iteration=4, theta_new=[2.76770523], -likelihood = -124.31443
# Iteration=5, theta_new=[2.74858266], -likelihood = -129.31753
# Iteration=6, theta_new=[2.73140402], -likelihood = -133.51142
# Iteration=7, theta_new=[2.71619991], -likelihood = -136.88558
# Iteration=8, theta_new=[2.70293722], -likelihood = -139.51132
# Iteration=9, theta_new=[2.691521], -likelihood = -141.49651
# Iteration=10, theta_new=[2.68173007], -likelihood = -142.96198
# Iteration=11, theta_new=[2.67341513], -likelihood = -144.03147
# Iteration=12, theta_new=[2.66636609], -likelihood = -144.79995
# Iteration=13, theta_new=[2.66037718], -likelihood = -145.34900
# Iteration=14, theta_new=[2.65537599], -likelihood = -145.74077
# Iteration=15, theta_new=[2.65116213], -likelihood = -146.01497
# Iteration=16, theta_new=[2.64760222], -likelihood = -146.20844
# Iteration=17, theta_new=[2.64462884], -likelihood = -146.34506
# Iteration=18, theta_new=[2.64211076], -likelihood = -146.44032
# Iteration=19, theta_new=[2.64004661], -likelihood = -146.50759
# Iteration=20, theta_new=[2.63830635], -likelihood = -146.55356
# Iteration=21, theta_new=[2.63682488], -likelihood = -146.58590
# Iteration=22, theta_new=[2.63560174], -likelihood = -146.60881
# Iteration=23, theta_new=[2.63457221], -likelihood = -146.62453
# Iteration=24, theta_new=[2.63373604], -likelihood = -146.63552
# Iteration=25, theta_new=[2.63302874], -likelihood = -146.64294
# Iteration=26, theta_new=[2.63245019], -likelihood = -146.64816
# Iteration=27, theta_new=[2.63200031], -likelihood = -146.65171
# Iteration=28, theta_new=[2.63161476], -likelihood = -146.65403
# Iteration=29, theta_new=[2.63129352], -likelihood = -146.65570
# Iteration=30, theta_new=[2.63097232], -likelihood = -146.65688
# Iteration=31, theta_new=[2.63071539], -likelihood = -146.65786
# Iteration=32, theta_new=[2.63052271], -likelihood = -146.65850
# Iteration=33, theta_new=[2.63033004], -likelihood = -146.65889
# Iteration=34, theta_new=[2.63020161], -likelihood = -146.65922
# Iteration=35, theta_new=[2.63007318], -likelihood = -146.65939
# Iteration=36, theta_new=[2.63000897], -likelihood = -146.65954
# Iteration=37, theta_new=[2.62994476], -likelihood = -146.65960
# Iteration=38, theta_new=[2.62988055], -likelihood = -146.65965
# Iteration=39, theta_new=[2.62981635], -likelihood = -146.65970
# Iteration=40, theta_new=[2.62975214], -likelihood = -146.65973
# Iteration=41, theta_new=[2.62968794], -likelihood = -146.65976
# norm=0.0
# Iteration=42, theta_new=[2.62968794], -likelihood = -146.65978
# 4-th start
# Iteration=1, theta_new=[-0.93287564], -likelihood = -70.97365
# Iteration=2, theta_new=[-0.94426328], -likelihood = -71.34042
# Iteration=3, theta_new=[-0.956251], -likelihood = -71.74062
# Iteration=4, theta_new=[-0.96876444], -likelihood = -72.16877
# Iteration=5, theta_new=[-0.98163084], -likelihood = -72.61814
# Iteration=6, theta_new=[-0.99485985], -likelihood = -73.07764
# Iteration=7, theta_new=[-1.00826714], -likelihood = -73.54236
# Iteration=8, theta_new=[-1.02175666], -likelihood = -74.00068
# Iteration=9, theta_new=[-1.03522708], -likelihood = -74.44482
# Iteration=10, theta_new=[-1.0485718], -likelihood = -74.86784
# Iteration=11, theta_new=[-1.06167895], -likelihood = -75.26394
# Iteration=12, theta_new=[-1.07448338], -likelihood = -75.62864
# Iteration=13, theta_new=[-1.08686512], -likelihood = -75.96017
# Iteration=14, theta_new=[-1.09880578], -likelihood = -76.25658
# Iteration=15, theta_new=[-1.11023379], -likelihood = -76.51942
# Iteration=16, theta_new=[-1.12113013], -likelihood = -76.74965
# Iteration=17, theta_new=[-1.13147649], -likelihood = -76.94979
# Iteration=18, theta_new=[-1.14131062], -likelihood = -77.12250
# Iteration=19, theta_new=[-1.15056147], -likelihood = -77.27129
# Iteration=20, theta_new=[-1.15926934], -likelihood = -77.39787
# Iteration=21, theta_new=[-1.16742045], -likelihood = -77.50549
# Iteration=22, theta_new=[-1.17505884], -likelihood = -77.59636
# Iteration=23, theta_new=[-1.18217346], -likelihood = -77.67313
# Iteration=24, theta_new=[-1.18881164], -likelihood = -77.73757
# Iteration=25, theta_new=[-1.19496467], -likelihood = -77.79174
# Iteration=26, theta_new=[-1.20068276], -likelihood = -77.83698
# Iteration=27, theta_new=[-1.20601783], -likelihood = -77.87487
# Iteration=28, theta_new=[-1.2109055], -likelihood = -77.90674
# Iteration=29, theta_new=[-1.21545822], -likelihood = -77.93307
# Iteration=30, theta_new=[-1.21967196], -likelihood = -77.95520
# Iteration=31, theta_new=[-1.22354299], -likelihood = -77.97368
# Iteration=32, theta_new=[-1.22712759], -likelihood = -77.98902
# Iteration=33, theta_new=[-1.2304231], -likelihood = -78.00185
# Iteration=34, theta_new=[-1.23348714], -likelihood = -78.01251
# Iteration=35, theta_new=[-1.23625767], -likelihood = -78.02148
# Iteration=36, theta_new=[-1.23885333], -likelihood = -78.02882
# Iteration=37, theta_new=[-1.24121247], -likelihood = -78.03505
# Iteration=38, theta_new=[-1.24339429], -likelihood = -78.04017
# Iteration=39, theta_new=[-1.24539781], -likelihood = -78.04447
# Iteration=40, theta_new=[-1.24722212], -likelihood = -78.04805
# Iteration=41, theta_new=[-1.24886641], -likelihood = -78.05100
# Iteration=42, theta_new=[-1.2503909], -likelihood = -78.05342
# Iteration=43, theta_new=[-1.25179515], -likelihood = -78.05546
# Iteration=44, theta_new=[-1.25307873], -likelihood = -78.05716
# Iteration=45, theta_new=[-1.25424125], -likelihood = -78.05858
# Iteration=46, theta_new=[-1.25534361], -likelihood = -78.05975
# Iteration=47, theta_new=[-1.25632435], -likelihood = -78.06076
# Iteration=48, theta_new=[-1.25724451], -likelihood = -78.06158
# Iteration=49, theta_new=[-1.25810395], -likelihood = -78.06228
# Iteration=50, theta_new=[-1.25884113], -likelihood = -78.06287
# 5-th start
# Iteration=1, theta_new=[1.04346342], -likelihood = -72.75837
# Iteration=2, theta_new=[1.03918359], -likelihood = -72.79297
# Iteration=3, theta_new=[1.03416019], -likelihood = -72.84072
# Iteration=4, theta_new=[1.02830264], -likelihood = -72.90755
# Iteration=5, theta_new=[1.02142386], -likelihood = -73.00092
# Iteration=6, theta_new=[1.01334424], -likelihood = -73.13304
# Iteration=7, theta_new=[1.00374518], -likelihood = -73.32118
# Iteration=8, theta_new=[0.99237463], -likelihood = -73.59429
# Iteration=9, theta_new=[0.97890392], -likelihood = -73.99299
# Iteration=10, theta_new=[0.96293937], -likelihood = -74.57985
# Iteration=11, theta_new=[0.94403792], -likelihood = -75.45059
# Iteration=12, theta_new=[0.92172765], -likelihood = -76.74923
# Iteration=13, theta_new=[0.89571405], -likelihood = -78.68618
# Iteration=14, theta_new=[0.86597354], -likelihood = -81.53181
# Iteration=15, theta_new=[0.83299213], -likelihood = -85.58054
# Iteration=16, theta_new=[0.79776893], -likelihood = -91.03363
# Iteration=17, theta_new=[0.76193165], -likelihood = -97.85153
# Iteration=18, theta_new=[0.72725781], -likelihood = -105.60146
# Iteration=19, theta_new=[0.69515619], -likelihood = -113.55452
# Iteration=20, theta_new=[0.66644027], -likelihood = -120.97427
# Iteration=21, theta_new=[0.64144876], -likelihood = -127.36320
# Iteration=22, theta_new=[0.62008802], -likelihood = -132.51615
# Iteration=23, theta_new=[0.60204249], -likelihood = -136.47867
# Iteration=24, theta_new=[0.58687384], -likelihood = -139.42432
# Iteration=25, theta_new=[0.57426522], -likelihood = -141.56775
# Iteration=26, theta_new=[0.56372207], -likelihood = -143.09243
# Iteration=27, theta_new=[0.55496896], -likelihood = -144.17456
# Iteration=28, theta_new=[0.54770667], -likelihood = -144.93246
# Iteration=29, theta_new=[0.54171613], -likelihood = -145.46086
# Iteration=30, theta_new=[0.53674335], -likelihood = -145.82634
# Iteration=31, theta_new=[0.53260246], -likelihood = -146.08044
# Iteration=32, theta_new=[0.52916967], -likelihood = -146.25742
# Iteration=33, theta_new=[0.52627577], -likelihood = -146.38004
# Iteration=34, theta_new=[0.52391164], -likelihood = -146.46630
# Iteration=35, theta_new=[0.52191627], -likelihood = -146.52509
# Iteration=36, theta_new=[0.52028529], -likelihood = -146.56649
# Iteration=37, theta_new=[0.51891344], -likelihood = -146.59472
# Iteration=38, theta_new=[0.51774791], -likelihood = -146.61455
# Iteration=39, theta_new=[0.51678725], -likelihood = -146.62859
# Iteration=40, theta_new=[0.51597977], -likelihood = -146.63821
# Iteration=41, theta_new=[0.51532471], -likelihood = -146.64493
# Iteration=42, theta_new=[0.51477114], -likelihood = -146.64946
# Iteration=43, theta_new=[0.51431871], -likelihood = -146.65266
# Iteration=44, theta_new=[0.51391689], -likelihood = -146.65483
# Iteration=45, theta_new=[0.51361577], -likelihood = -146.65643
# Iteration=46, theta_new=[0.51336498], -likelihood = -146.65743
# Iteration=47, theta_new=[0.51316445], -likelihood = -146.65812
# Iteration=48, theta_new=[0.51296399], -likelihood = -146.65860
# Iteration=49, theta_new=[0.51281371], -likelihood = -146.65899
# Iteration=50, theta_new=[0.51266347], -likelihood = -146.65923
# 6-th start
# Iteration=1, theta_new=[-0.31986873], -likelihood = -70.71115
# Iteration=2, theta_new=[-0.33023948], -likelihood = -71.51131
# Iteration=3, theta_new=[-0.34075296], -likelihood = -72.35403
# Iteration=4, theta_new=[-0.35133494], -likelihood = -73.21467
# Iteration=5, theta_new=[-0.36183381], -likelihood = -74.07622
# Iteration=6, theta_new=[-0.37208106], -likelihood = -74.91565
# Iteration=7, theta_new=[-0.38203713], -likelihood = -75.71051
# Iteration=8, theta_new=[-0.39151345], -likelihood = -76.45119
# Iteration=9, theta_new=[-0.40053661], -likelihood = -77.12031
# Iteration=10, theta_new=[-0.40898543], -likelihood = -77.71941
# Iteration=11, theta_new=[-0.41689354], -likelihood = -78.24257
# Iteration=12, theta_new=[-0.42422175], -likelihood = -78.69602
# Iteration=13, theta_new=[-0.43101593], -likelihood = -79.08275
# Iteration=14, theta_new=[-0.43724545], -likelihood = -79.41098
# Iteration=15, theta_new=[-0.44288182], -likelihood = -79.68524
# Iteration=16, theta_new=[-0.44807184], -likelihood = -79.91071
# Iteration=17, theta_new=[-0.4527976], -likelihood = -80.09881
# Iteration=18, theta_new=[-0.45704258], -likelihood = -80.25354
# Iteration=19, theta_new=[-0.46088102], -likelihood = -80.37890
# Iteration=20, theta_new=[-0.46439164], -likelihood = -80.48104
# Iteration=21, theta_new=[-0.46756619], -likelihood = -80.56508
# Iteration=22, theta_new=[-0.47039716], -likelihood = -80.63332
# Iteration=23, theta_new=[-0.47296964], -likelihood = -80.68794
# Iteration=24, theta_new=[-0.47527906], -likelihood = -80.73247
# Iteration=25, theta_new=[-0.47732128], -likelihood = -80.76831
# Iteration=26, theta_new=[-0.47918582], -likelihood = -80.79674
# Iteration=27, theta_new=[-0.48087045], -likelihood = -80.82001
# Iteration=28, theta_new=[-0.48237317], -likelihood = -80.83884
# Iteration=29, theta_new=[-0.48369216], -likelihood = -80.85389
# Iteration=30, theta_new=[-0.48492029], -likelihood = -80.86573
# Iteration=31, theta_new=[-0.48596211], -likelihood = -80.87561
# Iteration=32, theta_new=[-0.48691125], -likelihood = -80.88313
# Iteration=33, theta_new=[-0.48776715], -likelihood = -80.88928
# Iteration=34, theta_new=[-0.48852929], -likelihood = -80.89427
# Iteration=35, theta_new=[-0.4891972], -likelihood = -80.89826
# Iteration=36, theta_new=[-0.48986602], -likelihood = -80.90142
# Iteration=37, theta_new=[-0.49044008], -likelihood = -80.90425
# Iteration=38, theta_new=[-0.49091903], -likelihood = -80.90642
# Iteration=39, theta_new=[-0.49139844], -likelihood = -80.90805
# Iteration=40, theta_new=[-0.49178235], -likelihood = -80.90951
# Iteration=41, theta_new=[-0.49216655], -likelihood = -80.91057
# Iteration=42, theta_new=[-0.49245493], -likelihood = -80.91151
# Iteration=43, theta_new=[-0.49274348], -likelihood = -80.91215
# Iteration=44, theta_new=[-0.4930322], -likelihood = -80.91273
# Iteration=45, theta_new=[-0.49332108], -likelihood = -80.91325
# Iteration=46, theta_new=[-0.49351379], -likelihood = -80.91371
# Iteration=47, theta_new=[-0.49370657], -likelihood = -80.91398
# Iteration=48, theta_new=[-0.49389942], -likelihood = -80.91423
# Iteration=49, theta_new=[-0.49409235], -likelihood = -80.91445
# Iteration=50, theta_new=[-0.49418885], -likelihood = -80.91464
# 7-th start
# Iteration=1, theta_new=[1.8402376], -likelihood = -75.51292
# Iteration=2, theta_new=[1.81984044], -likelihood = -75.77091
# Iteration=3, theta_new=[1.79824761], -likelihood = -76.01855
# Iteration=4, theta_new=[1.77524268], -likelihood = -76.25281
# Iteration=5, theta_new=[1.75045169], -likelihood = -76.47118
# Iteration=6, theta_new=[1.72310089], -likelihood = -76.67187
# Iteration=7, theta_new=[1.6916341], -likelihood = -76.85429
# Iteration=8, theta_new=[1.49025696], -likelihood = -77.01802
# Iteration=9, theta_new=[1.57080942], -likelihood = -77.16291
# norm=0.0
# Iteration=10, theta_new=[1.57080942], -likelihood = -77.23370
# 8-th start
# Iteration=1, theta_new=[0.70662251], -likelihood = -110.65379
# Iteration=2, theta_new=[0.67660485], -likelihood = -118.34021
# Iteration=3, theta_new=[0.65024105], -likelihood = -125.14630
# Iteration=4, theta_new=[0.62757151], -likelihood = -130.75872
# Iteration=5, theta_new=[0.60832762], -likelihood = -135.14435
# Iteration=6, theta_new=[0.59216892], -likelihood = -138.44450
# Iteration=7, theta_new=[0.57863693], -likelihood = -140.85644
# Iteration=8, theta_new=[0.56739194], -likelihood = -142.59148
# Iteration=9, theta_new=[0.55802776], -likelihood = -143.81848
# Iteration=10, theta_new=[0.55023499], -likelihood = -144.68244
# Iteration=11, theta_new=[0.54378692], -likelihood = -145.28741
# Iteration=12, theta_new=[0.5384234], -likelihood = -145.70729
# Iteration=13, theta_new=[0.53400664], -likelihood = -145.99964
# Iteration=14, theta_new=[0.53030406], -likelihood = -146.20095
# Iteration=15, theta_new=[0.52724859], -likelihood = -146.34195
# Iteration=16, theta_new=[0.52472563], -likelihood = -146.43905
# Iteration=17, theta_new=[0.52262467], -likelihood = -146.50603
# Iteration=18, theta_new=[0.52083836], -likelihood = -146.55265
# Iteration=19, theta_new=[0.51936333], -likelihood = -146.58571
# Iteration=20, theta_new=[0.51814607], -likelihood = -146.60845
# Iteration=21, theta_new=[0.51713407], -likelihood = -146.62409
# Iteration=22, theta_new=[0.51627554], -likelihood = -146.63494
# Iteration=23, theta_new=[0.5155697], -likelihood = -146.64261
# Iteration=24, theta_new=[0.51496552], -likelihood = -146.64786
# Iteration=25, theta_new=[0.51446262], -likelihood = -146.65160
# Iteration=26, theta_new=[0.5140607], -likelihood = -146.65418
# Iteration=27, theta_new=[0.51370929], -likelihood = -146.65589
# Iteration=28, theta_new=[0.51340829], -likelihood = -146.65713
# Iteration=29, theta_new=[0.5131576], -likelihood = -146.65801
# Iteration=30, theta_new=[0.51295715], -likelihood = -146.65861
# Iteration=31, theta_new=[0.51280687], -likelihood = -146.65900
# Iteration=32, theta_new=[0.51265663], -likelihood = -146.65924
# Iteration=33, theta_new=[0.5125565], -likelihood = -146.65944
# Iteration=34, theta_new=[0.51245639], -likelihood = -146.65955
# Iteration=35, theta_new=[0.51240635], -likelihood = -146.65964
# Iteration=36, theta_new=[0.51235631], -likelihood = -146.65968
# Iteration=37, theta_new=[0.51230627], -likelihood = -146.65971
# Iteration=38, theta_new=[0.51225624], -likelihood = -146.65974
# Iteration=39, theta_new=[0.51220622], -likelihood = -146.65976
# Iteration=40, theta_new=[0.5121562], -likelihood = -146.65978
# norm=0.0
# Iteration=41, theta_new=[0.5121562], -likelihood = -146.65979
# 9-th start
# Iteration=1, theta_new=[-0.19403658], -likelihood = -65.34338
# Iteration=2, theta_new=[-0.19441556], -likelihood = -65.34455
# Iteration=3, theta_new=[-0.19487122], -likelihood = -65.34584
# Iteration=4, theta_new=[-0.19532795], -likelihood = -65.34754
# Iteration=5, theta_new=[-0.19586205], -likelihood = -65.34942
# Iteration=6, theta_new=[-0.19647412], -likelihood = -65.35181
# Iteration=7, theta_new=[-0.1970881], -likelihood = -65.35484
# Iteration=8, theta_new=[-0.19778099], -likelihood = -65.35818
# Iteration=9, theta_new=[-0.19855357], -likelihood = -65.36230
# Iteration=10, theta_new=[-0.19940673], -likelihood = -65.36735
# Iteration=11, theta_new=[-0.20034145], -likelihood = -65.37348
# Iteration=12, theta_new=[-0.20135881], -likelihood = -65.38087
# Iteration=13, theta_new=[-0.20245999], -likelihood = -65.38971
# Iteration=14, theta_new=[-0.20372536], -likelihood = -65.40022
# Iteration=15, theta_new=[-0.20507823], -likelihood = -65.41350
# Iteration=16, theta_new=[-0.20660029], -likelihood = -65.42914
# Iteration=17, theta_new=[-0.20829506], -likelihood = -65.44851
# Iteration=18, theta_new=[-0.21008509], -likelihood = -65.47230
# Iteration=19, theta_new=[-0.21213671], -likelihood = -65.49997
# Iteration=20, theta_new=[-0.21437409], -likelihood = -65.53491
# Iteration=21, theta_new=[-0.21680254], -likelihood = -65.57694
# Iteration=22, theta_new=[-0.21951257], -likelihood = -65.62720
# Iteration=23, theta_new=[-0.22251372], -likelihood = -65.68898
# Iteration=24, theta_new=[-0.22581666], -likelihood = -65.76441
# Iteration=25, theta_new=[-0.22943326], -likelihood = -65.85591
# Iteration=26, theta_new=[-0.23346626], -likelihood = -65.96622
# Iteration=27, theta_new=[-0.23784375], -likelihood = -66.10161
# Iteration=28, theta_new=[-0.24267496], -likelihood = -66.26317
# Iteration=29, theta_new=[-0.24798347], -likelihood = -66.45878
# Iteration=30, theta_new=[-0.25379558], -likelihood = -66.69418
# Iteration=31, theta_new=[-0.26014047], -likelihood = -66.97571
# Iteration=32, theta_new=[-0.26710126], -likelihood = -67.31028
# Iteration=33, theta_new=[-0.27461349], -likelihood = -67.70825
# Iteration=34, theta_new=[-0.28271244], -likelihood = -68.17153
# Iteration=35, theta_new=[-0.29138155], -likelihood = -68.70675
# Iteration=36, theta_new=[-0.30060104], -likelihood = -69.31597
# Iteration=37, theta_new=[-0.31028838], -likelihood = -69.99890
# Iteration=38, theta_new=[-0.32034851], -likelihood = -70.74767
# Iteration=39, theta_new=[-0.33073481], -likelihood = -71.55001
# Iteration=40, theta_new=[-0.34126407], -likelihood = -72.39453
# Iteration=41, theta_new=[-0.35179526], -likelihood = -73.25647
# Iteration=42, theta_new=[-0.36223918], -likelihood = -74.11342
# Iteration=43, theta_new=[-0.37249791], -likelihood = -74.94762
# Iteration=44, theta_new=[-0.38239239], -likelihood = -75.74220
# Iteration=45, theta_new=[-0.39187751], -likelihood = -76.47694
# Iteration=46, theta_new=[-0.40090906], -likelihood = -77.14523
# Iteration=47, theta_new=[-0.40936574], -likelihood = -77.74327
# Iteration=48, theta_new=[-0.41728121], -likelihood = -78.26520
# Iteration=49, theta_new=[-0.42461623], -likelihood = -78.71730
# Iteration=50, theta_new=[-0.43133379], -likelihood = -79.10262

# %%
np.rad2deg(EM_theta1_rad)
# Out:
# array([29.34438859])

# %% [markdown]
# ## True result

# %%
np.rad2deg(theta1_rad)
# Out:
# array([28.64788976])

# %% [markdown]
# # Case 2

# %% [markdown]
# Имеется 5 датчиков, 2 источника (дисперсии сигналов - 2 и 3), и шум на каждом датчике имеет дисперсию 7.1.

# %%
Num_sensors2 = 5
Num_emitters2 = 2
sample_size2 = 100
theta2_rad = np.array([0.34906585, 1.22173048]) # Направление прибытия (DOA) в радианах
GS_2 = np.array([[2,0],[0,3]]) # Ковариация сигнала
GN_2 = 7.1*np.eye(5, dtype=np.float64) # Ковариация шума
A2 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors2).reshape(-1,1) * np.sin(theta2_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s2 = CN(Num_emitters2, sample_size2, GS_2)
n2 = CN(Num_sensors2, sample_size2, GN_2)
X2 = (A2 @ s2.T + n2.T).T

# %% [markdown]
# ## ML1

# %%
theta_ML1_Case2, ML1_func_val_Case2 = multi_start_ML1(X2, L=Num_sensors2, M=Num_emitters2, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
np.rad2deg(theta_ML1_Case2)
# Out:
# array([18.83981904, 70.73481887])

# %% [markdown]
# ## ML2

# %%
theta_ML2_Case2, ML2_func_val_Case2 = multi_start_ML2(X2, GS_2, GN_2, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
np.rad2deg(theta_ML2_Case2)
# Out:
# array([18.66889475, 71.09223552])

# %% [markdown]
# ## EM

# %%
EM_theta2_rad, neglhd_2, K2, mu2 = multi_start_EM(X2, GS_2, GN_2, 30, max_iter=20, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[-3.1303273  -2.53652867], -likelihood = -190.05015
# Iteration=2, theta_new=[-3.15046069 -2.54671298], -likelihood = -194.93169
# Iteration=3, theta_new=[-3.17400368 -2.55609664], -likelihood = -201.55472
# Iteration=4, theta_new=[-3.20085267 -2.56451057], -likelihood = -210.48532
# Iteration=5, theta_new=[-3.23019587 -2.57197978], -likelihood = -222.12290
# Iteration=6, theta_new=[-3.26062685 -2.57867621], -likelihood = -236.21526
# Iteration=7, theta_new=[-3.29048825 -2.58505382], -likelihood = -251.66343
# Iteration=8, theta_new=[-3.31832824 -2.59139691], -likelihood = -266.88168
# Iteration=9, theta_new=[-3.34341398 -2.59786021], -likelihood = -280.46663
# Iteration=10, theta_new=[-3.36528948 -2.60445822], -likelihood = -291.74641
# Iteration=11, theta_new=[-3.38403642 -2.61101036], -likelihood = -300.55828
# Iteration=12, theta_new=[-3.39991061 -2.61742205], -likelihood = -307.18318
# Iteration=13, theta_new=[-3.41318362 -2.62344297], -likelihood = -312.03676
# Iteration=14, theta_new=[-3.42418496 -2.62905314], -likelihood = -315.50897
# Iteration=15, theta_new=[-3.4332883  -2.63420584], -likelihood = -317.96072
# Iteration=16, theta_new=[-3.44073473 -2.63890794], -likelihood = -319.68336
# Iteration=17, theta_new=[-3.44685506 -2.6431678 ], -likelihood = -320.88189
# Iteration=18, theta_new=[-3.45190808 -2.64692615], -likelihood = -321.71991
# Iteration=19, theta_new=[-3.4560868  -2.65025442], -likelihood = -322.30537
# Iteration=20, theta_new=[-3.45945304 -2.65318019], -likelihood = -322.71558
# 1-th start
# Iteration=1, theta_new=[-2.12803121 -0.06612665], -likelihood = -238.54304
# Iteration=2, theta_new=[-2.05863816 -0.05918583], -likelihood = -262.06142
# Iteration=3, theta_new=[-1.98600325 -0.05162195], -likelihood = -285.53153
# Iteration=4, theta_new=[-1.91065548 -0.04230794], -likelihood = -306.75122
# Iteration=5, theta_new=[-1.83071107 -0.03015098], -likelihood = -324.68218
# Iteration=6, theta_new=[-1.73825412 -0.01415392], -likelihood = -339.61589
# Iteration=7, theta_new=[-1.57081511  0.0063474 ], -likelihood = -352.74307
# Iteration=8, theta_new=[-1.57077037  0.03141671], -likelihood = -363.22583
# Iteration=9, theta_new=[-1.57082807  0.06011621], -likelihood = -373.53284
# Iteration=10, theta_new=[-1.57076369  0.09089434], -likelihood = -387.31333
# Iteration=11, theta_new=[-1.57080198  0.12174429], -likelihood = -403.47413
# Iteration=12, theta_new=[-1.57084939  0.15093163], -likelihood = -420.04977
# Iteration=13, theta_new=[-1.57078828  0.1773941 ], -likelihood = -435.19886
# Iteration=14, theta_new=[-1.57083828  0.20066195], -likelihood = -447.88453
# Iteration=15, theta_new=[-1.57083828  0.22072815], -likelihood = -457.85485
# Iteration=16, theta_new=[-1.57079737  0.23778346], -likelihood = -465.36460
# Iteration=17, theta_new=[-1.57074509  0.25215558], -likelihood = -470.85008
# Iteration=18, theta_new=[-1.5708218   0.26418659], -likelihood = -474.77887
# Iteration=19, theta_new=[-1.57078625  0.27420091], -likelihood = -477.55333
# Iteration=20, theta_new=[-1.57075225  0.28252564], -likelihood = -479.49248
# 2-th start
# Iteration=1, theta_new=[-0.85109648  2.74002974], -likelihood = -310.02460
# Iteration=2, theta_new=[-0.9021063   2.75301364], -likelihood = -326.04111
# Iteration=3, theta_new=[-0.96356595  2.76390376], -likelihood = -347.47583
# Iteration=4, theta_new=[-1.03201409  2.77319149], -likelihood = -373.79746
# Iteration=5, theta_new=[-1.10362982  2.7811374 ], -likelihood = -401.63067
# Iteration=6, theta_new=[-1.17598378  2.78789273], -likelihood = -426.96092
# Iteration=7, theta_new=[-1.2486339   2.79361413], -likelihood = -447.41707
# Iteration=8, theta_new=[-1.32324528  2.79833885], -likelihood = -462.59566
# Iteration=9, theta_new=[-1.40604831  2.802241  ], -likelihood = -473.19850
# Iteration=10, theta_new=[-1.57073898  2.80543627], -likelihood = -480.30454
# Iteration=11, theta_new=[-1.57085925  2.80794572], -likelihood = -483.66859
# Iteration=12, theta_new=[-1.57074665  2.81002638], -likelihood = -483.76412
# Iteration=13, theta_new=[-1.5707733  2.8117316], -likelihood = -483.82654
# Iteration=14, theta_new=[-1.57079978  2.8131361 ], -likelihood = -483.86630
# Iteration=15, theta_new=[-1.5708244   2.81430039], -likelihood = -483.89134
# Iteration=16, theta_new=[-1.57073718  2.81525274], -likelihood = -483.90680
# Iteration=17, theta_new=[-1.57080795  2.81603114], -likelihood = -483.91587
# Iteration=18, theta_new=[-1.57083959  2.81668086], -likelihood = -483.92090
# Iteration=19, theta_new=[-1.57077542  2.81720764], -likelihood = -483.92344
# Iteration=20, theta_new=[-1.57077714  2.81765203], -likelihood = -483.92441
# 3-th start
# Iteration=1, theta_new=[2.36735178 2.85533748], -likelihood = -353.22475
# Iteration=2, theta_new=[2.31859347 2.84727063], -likelihood = -370.63774
# Iteration=3, theta_new=[2.26616979 2.83997249], -likelihood = -392.33381
# Iteration=4, theta_new=[2.21386636 2.83389077], -likelihood = -415.69255
# Iteration=5, theta_new=[2.16447799 2.82918023], -likelihood = -437.31451
# Iteration=6, theta_new=[2.11978954 2.82571957], -likelihood = -454.97593
# Iteration=7, theta_new=[2.08051664 2.82326614], -likelihood = -468.05175
# Iteration=8, theta_new=[2.04671841 2.82156133], -likelihood = -477.09179
# Iteration=9, theta_new=[2.01812489 2.82040159], -likelihood = -483.06092
# Iteration=10, theta_new=[1.99418029 2.81962637], -likelihood = -486.88117
# Iteration=11, theta_new=[1.97433832 2.81912825], -likelihood = -489.28470
# Iteration=12, theta_new=[1.9580181  2.81880299], -likelihood = -490.77695
# Iteration=13, theta_new=[1.94463819 2.81859993], -likelihood = -491.69600
# Iteration=14, theta_new=[1.93379471 2.81848521], -likelihood = -492.25978
# Iteration=15, theta_new=[1.92502455 2.81844373], -likelihood = -492.60119
# Iteration=16, theta_new=[1.91799861 2.81843685], -likelihood = -492.80699
# Iteration=17, theta_new=[1.91240725 2.81843016], -likelihood = -492.92922
# Iteration=18, theta_new=[1.90797621 2.81845222], -likelihood = -493.00081
# Iteration=19, theta_new=[1.90442612 2.81847985], -likelihood = -493.04204
# Iteration=20, theta_new=[1.90157358 2.81850909], -likelihood = -493.06554
# 4-th start
# Iteration=1, theta_new=[ 2.34238108 -2.66003147], -likelihood = -256.09180
# Iteration=2, theta_new=[ 2.294672   -2.66789129], -likelihood = -272.47727
# Iteration=3, theta_new=[ 2.2445806  -2.67555137], -likelihood = -292.75922
# Iteration=4, theta_new=[ 2.19620547 -2.68283642], -likelihood = -313.34930
# Iteration=5, theta_new=[ 2.1520134  -2.68967372], -likelihood = -331.12119
# Iteration=6, theta_new=[ 2.1130177  -2.69593838], -likelihood = -344.81474
# Iteration=7, theta_new=[ 2.07950689 -2.70166629], -likelihood = -354.61235
# Iteration=8, theta_new=[ 2.05127921 -2.70687012], -likelihood = -361.28679
# Iteration=9, theta_new=[ 2.02778633 -2.71160589], -likelihood = -365.69908
# Iteration=10, theta_new=[ 2.00849229 -2.71594937], -likelihood = -368.58004
# Iteration=11, theta_new=[ 1.99274539 -2.71988949], -likelihood = -370.45146
# Iteration=12, theta_new=[ 1.97992889 -2.72352579], -likelihood = -371.67328
# Iteration=13, theta_new=[ 1.96965678 -2.72681784], -likelihood = -372.48434
# Iteration=14, theta_new=[ 1.96148    -2.72986024], -likelihood = -373.02545
# Iteration=15, theta_new=[ 1.95498138 -2.73267535], -likelihood = -373.39669
# Iteration=16, theta_new=[ 1.94981802 -2.73534282], -likelihood = -373.65960
# Iteration=17, theta_new=[ 1.94579932 -2.73781564], -likelihood = -373.85448
# Iteration=18, theta_new=[ 1.94264833 -2.74010725], -likelihood = -374.00137
# Iteration=19, theta_new=[ 1.94020482 -2.7422143 ], -likelihood = -374.11638
# Iteration=20, theta_new=[ 1.93830573 -2.74421446], -likelihood = -374.20839
# 5-th start
# Iteration=1, theta_new=[ 2.66249034 -0.08790593], -likelihood = -247.64897
# Iteration=2, theta_new=[ 2.69028415 -0.07358151], -likelihood = -262.98853
# Iteration=3, theta_new=[ 2.71384244 -0.05708084], -likelihood = -277.09309
# Iteration=4, theta_new=[ 2.73268192 -0.0400284 ], -likelihood = -288.45602
# Iteration=5, theta_new=[ 2.74706653 -0.02402379], -likelihood = -296.61155
# Iteration=6, theta_new=[ 2.75748586 -0.00978493], -likelihood = -301.94791
# Iteration=7, theta_new=[2.76471192e+00 2.45875406e-03], -likelihood = -305.22888
# Iteration=8, theta_new=[2.76944993 0.01282534], -likelihood = -307.18288
# Iteration=9, theta_new=[2.77226636 0.02166827], -likelihood = -308.33543
# Iteration=10, theta_new=[2.77363887 0.02922891], -likelihood = -309.02958
# Iteration=11, theta_new=[2.77393613 0.03580933], -likelihood = -309.46368
# Iteration=12, theta_new=[2.77350747 0.04170108], -likelihood = -309.75550
# Iteration=13, theta_new=[2.77254325 0.04694075], -likelihood = -309.96986
# Iteration=14, theta_new=[2.77124524 0.05179126], -likelihood = -310.13546
# Iteration=15, theta_new=[2.76969434 0.05630444], -likelihood = -310.27297
# Iteration=16, theta_new=[2.76798254 0.06062125], -likelihood = -310.39066
# Iteration=17, theta_new=[2.76615444 0.06470831], -likelihood = -310.49408
# Iteration=18, theta_new=[2.76421557 0.0685841 ], -likelihood = -310.58490
# Iteration=19, theta_new=[2.76230609 0.07232883], -likelihood = -310.66587
# Iteration=20, theta_new=[2.76035248 0.07599814], -likelihood = -310.73554
# 6-th start
# Iteration=1, theta_new=[ 3.11676501 -1.64429235], -likelihood = -368.75538
# Iteration=2, theta_new=[ 3.08839956 -1.57075542], -likelihood = -383.59439
# Iteration=3, theta_new=[ 3.05745751 -1.57084836], -likelihood = -396.18503
# Iteration=4, theta_new=[ 3.02614618 -1.57079933], -likelihood = -410.95893
# Iteration=5, theta_new=[ 2.99634028 -1.57081956], -likelihood = -426.47448
# Iteration=6, theta_new=[ 2.96926874 -1.5707594 ], -likelihood = -440.89737
# Iteration=7, theta_new=[ 2.94545173 -1.57078735], -likelihood = -453.09375
# Iteration=8, theta_new=[ 2.92493447 -1.57081751], -likelihood = -462.74354
# Iteration=9, theta_new=[ 2.90748758 -1.57077026], -likelihood = -470.04058
# Iteration=10, theta_new=[ 2.89279552 -1.570806  ], -likelihood = -475.39765
# Iteration=11, theta_new=[ 2.88050406 -1.5707477 ], -likelihood = -479.24900
# Iteration=12, theta_new=[ 2.87026268 -1.5708405 ], -likelihood = -481.98011
# Iteration=13, theta_new=[ 2.86175565 -1.57083283], -likelihood = -483.90076
# Iteration=14, theta_new=[ 2.85470327 -1.57085454], -likelihood = -485.24451
# Iteration=15, theta_new=[ 2.84886113 -1.57074507], -likelihood = -486.18242
# Iteration=16, theta_new=[ 2.84402026 -1.57077646], -likelihood = -486.83718
# Iteration=17, theta_new=[ 2.84003541 -1.57079942], -likelihood = -487.29525
# Iteration=18, theta_new=[ 2.83673171 -1.57084725], -likelihood = -487.61460
# Iteration=19, theta_new=[ 2.83401303 -1.57081465], -likelihood = -487.83976
# Iteration=20, theta_new=[ 2.83175051 -1.57079594], -likelihood = -487.99806
# 7-th start
# Iteration=1, theta_new=[-0.36703335  1.02910521], -likelihood = -360.31640
# Iteration=2, theta_new=[-0.36803697  1.06360771], -likelihood = -370.88116
# Iteration=3, theta_new=[-0.36848657  1.09256821], -likelihood = -377.82315
# Iteration=4, theta_new=[-0.3685528   1.11657755], -likelihood = -382.26688
# Iteration=5, theta_new=[-0.36843986  1.13625515], -likelihood = -385.06595
# Iteration=6, theta_new=[-0.3682008   1.15229256], -likelihood = -386.80886
# Iteration=7, theta_new=[-0.36781834  1.16529017], -likelihood = -387.89110
# Iteration=8, theta_new=[-0.36742567  1.17570168], -likelihood = -388.56267
# Iteration=9, theta_new=[-0.36699836  1.184015  ], -likelihood = -388.97612
# Iteration=10, theta_new=[-0.36656041  1.19064458], -likelihood = -389.23196
# Iteration=11, theta_new=[-0.36616109  1.19591861], -likelihood = -389.39128
# Iteration=12, theta_new=[-0.36574131  1.20013009], -likelihood = -389.49072
# Iteration=13, theta_new=[-0.365333    1.20338142], -likelihood = -389.55406
# Iteration=14, theta_new=[-0.36494822  1.20593703], -likelihood = -389.59368
# Iteration=15, theta_new=[-0.36460727  1.20796013], -likelihood = -389.61936
# Iteration=16, theta_new=[-0.36424156  1.20957083], -likelihood = -389.63629
# Iteration=17, theta_new=[-0.36392678  1.21078963], -likelihood = -389.64830
# Iteration=18, theta_new=[-0.36361626  1.21184909], -likelihood = -389.65635
# Iteration=19, theta_new=[-0.36332439  1.21266779], -likelihood = -389.66270
# Iteration=20, theta_new=[-0.36304402  1.21328604], -likelihood = -389.66742
# 8-th start
# Iteration=1, theta_new=[0.31078063 1.93589245], -likelihood = -497.38549
# Iteration=2, theta_new=[0.31265511 1.92710183], -likelihood = -497.86424
# Iteration=3, theta_new=[0.3142288  1.92007681], -likelihood = -498.15777
# Iteration=4, theta_new=[0.31548728 1.91450973], -likelihood = -498.34082
# Iteration=5, theta_new=[0.31651533 1.91014932], -likelihood = -498.45319
# Iteration=6, theta_new=[0.31737792 1.90667396], -likelihood = -498.52245
# Iteration=7, theta_new=[0.31805571 1.90394129], -likelihood = -498.56625
# Iteration=8, theta_new=[0.31864763 1.90177154], -likelihood = -498.59309
# Iteration=9, theta_new=[0.31911409 1.90004264], -likelihood = -498.61053
# Iteration=10, theta_new=[0.31949788 1.89872254], -likelihood = -498.62129
# Iteration=11, theta_new=[0.31982552 1.89764117], -likelihood = -498.62805
# Iteration=12, theta_new=[0.32009114 1.89679866], -likelihood = -498.63254
# Iteration=13, theta_new=[0.32032123 1.89615356], -likelihood = -498.63539
# Iteration=14, theta_new=[0.32049898 1.89568639], -likelihood = -498.63737
# Iteration=15, theta_new=[0.32067566 1.89528095], -likelihood = -498.63863
# Iteration=16, theta_new=[0.32078955 1.89499437], -likelihood = -498.63974
# Iteration=17, theta_new=[0.3208965 1.894736 ], -likelihood = -498.64030
# Iteration=18, theta_new=[0.32100816 1.89455297], -likelihood = -498.64075
# Iteration=19, theta_new=[0.32107534 1.89439581], -likelihood = -498.64131
# Iteration=20, theta_new=[0.32111341 1.89426542], -likelihood = -498.64153
# 9-th start
# Iteration=1, theta_new=[-2.21792365 -2.51017349], -likelihood = -185.59026
# Iteration=2, theta_new=[-2.14132424 -2.53528608], -likelihood = -257.83164
# Iteration=3, theta_new=[-2.07197468 -2.54866006], -likelihood = -288.51717
# Iteration=4, theta_new=[-2.00570993 -2.55609971], -likelihood = -308.97767
# Iteration=5, theta_new=[-1.94083906 -2.56035754], -likelihood = -324.69228
# Iteration=6, theta_new=[-1.8760014  -2.56295833], -likelihood = -336.93107
# Iteration=7, theta_new=[-1.80908626 -2.56470869], -likelihood = -346.21806
# Iteration=8, theta_new=[-1.73470242 -2.5661047 ], -likelihood = -353.02095
# Iteration=9, theta_new=[-1.6200569  -2.56738795], -likelihood = -357.84345
# Iteration=10, theta_new=[-1.57083731 -2.56780455], -likelihood = -360.38724
# Iteration=11, theta_new=[-1.57080176 -2.568117  ], -likelihood = -360.49205
# Iteration=12, theta_new=[-1.57079723 -2.56842321], -likelihood = -360.48750
# Iteration=13, theta_new=[-1.5707927  -2.56872945], -likelihood = -360.48304
# Iteration=14, theta_new=[-1.57079182 -2.56905439], -likelihood = -360.47859
# Iteration=15, theta_new=[-1.57085296 -2.56936681], -likelihood = -360.47387
# Iteration=16, theta_new=[-1.57079962 -2.56967093], -likelihood = -360.46933
# Iteration=17, theta_new=[-1.57081121 -2.56996959], -likelihood = -360.46491
# Iteration=18, theta_new=[-1.57077395 -2.57024393], -likelihood = -360.46057
# Iteration=19, theta_new=[-1.5708337  -2.57053185], -likelihood = -360.45659
# Iteration=20, theta_new=[-1.5707652  -2.57080015], -likelihood = -360.45242
# 10-th start
# Iteration=1, theta_new=[-1.30288772 -2.50902141], -likelihood = -343.62076
# Iteration=2, theta_new=[-1.37415592 -2.51464626], -likelihood = -351.53294
# Iteration=3, theta_new=[-1.46112007 -2.51869828], -likelihood = -356.95546
# Iteration=4, theta_new=[-1.57077208 -2.52125819], -likelihood = -360.39455
# Iteration=5, theta_new=[-1.57076712 -2.52295083], -likelihood = -361.09569
# Iteration=6, theta_new=[-1.57081141 -2.52456915], -likelihood = -361.07944
# Iteration=7, theta_new=[-1.57084136 -2.52611696], -likelihood = -361.06329
# Iteration=8, theta_new=[-1.57076915 -2.52762166], -likelihood = -361.04731
# Iteration=9, theta_new=[-1.57082849 -2.52905481], -likelihood = -361.03129
# Iteration=10, theta_new=[-1.57081496 -2.53043524], -likelihood = -361.01560
# Iteration=11, theta_new=[-1.57076092 -2.5317727 ], -likelihood = -361.00011
# Iteration=12, theta_new=[-1.57083601 -2.53306965], -likelihood = -360.98476
# Iteration=13, theta_new=[-1.57080696 -2.53431893], -likelihood = -360.96957
# Iteration=14, theta_new=[-1.57078286 -2.53551958], -likelihood = -360.95466
# Iteration=15, theta_new=[-1.57078426 -2.53666212], -likelihood = -360.94008
# Iteration=16, theta_new=[-1.57080208 -2.53777668], -likelihood = -360.92599
# Iteration=17, theta_new=[-1.57081553 -2.53885131], -likelihood = -360.91206
# Iteration=18, theta_new=[-1.57084361 -2.53990281], -likelihood = -360.89845
# Iteration=19, theta_new=[-1.57082686 -2.54092483], -likelihood = -360.88497
# Iteration=20, theta_new=[-1.57079951 -2.54192316], -likelihood = -360.87173
# 11-th start
# Iteration=1, theta_new=[ 1.31889555 -1.57083455], -likelihood = -304.86348
# Iteration=2, theta_new=[ 1.20933984 -1.69793908], -likelihood = -313.49112
# Iteration=3, theta_new=[ 1.12341336 -1.78494674], -likelihood = -330.78581
# Iteration=4, theta_new=[ 1.06796419 -1.83667047], -likelihood = -350.09108
# Iteration=5, theta_new=[ 1.03244415 -1.86538507], -likelihood = -361.77689
# Iteration=6, theta_new=[ 1.00858193 -1.88085288], -likelihood = -367.75606
# Iteration=7, theta_new=[ 0.99171436 -1.88849433], -likelihood = -370.89045
# Iteration=8, theta_new=[ 0.97919173 -1.89129133], -likelihood = -372.65026
# Iteration=9, theta_new=[ 0.96948389 -1.89107731], -likelihood = -373.71762
# Iteration=10, theta_new=[ 0.96168309 -1.88895093], -likelihood = -374.41655
# Iteration=11, theta_new=[ 0.95514115 -1.88558298], -likelihood = -374.90612
# Iteration=12, theta_new=[ 0.94942463 -1.88140736], -likelihood = -375.27425
# Iteration=13, theta_new=[ 0.94437347 -1.87676982], -likelihood = -375.57032
# Iteration=14, theta_new=[ 0.93977016 -1.87186539], -likelihood = -375.81617
# Iteration=15, theta_new=[ 0.93546404 -1.86682658], -likelihood = -376.03094
# Iteration=16, theta_new=[ 0.93139733 -1.86171751], -likelihood = -376.22684
# Iteration=17, theta_new=[ 0.92751916 -1.85653605], -likelihood = -376.40884
# Iteration=18, theta_new=[ 0.92375068 -1.85139213], -likelihood = -376.58041
# Iteration=19, theta_new=[ 0.92010885 -1.84636476], -likelihood = -376.74762
# Iteration=20, theta_new=[ 0.91655641 -1.84137531], -likelihood = -376.91040
# 12-th start
# Iteration=1, theta_new=[ 0.83185408 -3.00221818], -likelihood = -237.79809
# Iteration=2, theta_new=[ 0.88590963 -3.00143437], -likelihood = -259.59123
# Iteration=3, theta_new=[ 0.93981031 -2.99956472], -likelihood = -284.18042
# Iteration=4, theta_new=[ 0.98985702 -2.99617014], -likelihood = -306.74729
# Iteration=5, theta_new=[ 1.03421396 -2.99105036], -likelihood = -324.56121
# Iteration=6, theta_new=[ 1.07235021 -2.98429903], -likelihood = -337.35973
# Iteration=7, theta_new=[ 1.10458611 -2.97614449], -likelihood = -346.14778
# Iteration=8, theta_new=[ 1.13140151 -2.96673793], -likelihood = -352.17390
# Iteration=9, theta_new=[ 1.15333099 -2.95642462], -likelihood = -356.43439
# Iteration=10, theta_new=[ 1.17109239 -2.94554054], -likelihood = -359.59346
# Iteration=11, theta_new=[ 1.18524415 -2.93438385], -likelihood = -362.07223
# Iteration=12, theta_new=[ 1.19624955 -2.92321885], -likelihood = -364.10477
# Iteration=13, theta_new=[ 1.20467318 -2.9122366 ], -likelihood = -365.81857
# Iteration=14, theta_new=[ 1.21090097 -2.90166841], -likelihood = -367.28993
# Iteration=15, theta_new=[ 1.21536139 -2.89156476], -likelihood = -368.55049
# Iteration=16, theta_new=[ 1.21838373 -2.88208664], -likelihood = -369.63503
# Iteration=17, theta_new=[ 1.22032363 -2.87321808], -likelihood = -370.55548
# Iteration=18, theta_new=[ 1.22136078 -2.8649491 ], -likelihood = -371.33626
# Iteration=19, theta_new=[ 1.22182828 -2.85728586], -likelihood = -371.99597
# Iteration=20, theta_new=[ 1.22177614 -2.85022037], -likelihood = -372.54909
# 13-th start
# Iteration=1, theta_new=[2.16993134 2.66507442], -likelihood = -406.16938
# Iteration=2, theta_new=[2.12996858 2.68730846], -likelihood = -426.83346
# Iteration=3, theta_new=[2.09439701 2.70651428], -likelihood = -443.00710
# Iteration=4, theta_new=[2.06292538 2.72325185], -likelihood = -455.95468
# Iteration=5, theta_new=[2.03527444 2.73778667], -likelihood = -466.13755
# Iteration=6, theta_new=[2.01130598 2.75032399], -likelihood = -473.91165
# Iteration=7, theta_new=[1.99070053 2.76112258], -likelihood = -479.65623
# Iteration=8, theta_new=[1.97318251 2.77030501], -likelihood = -483.80729
# Iteration=9, theta_new=[1.9584134  2.77813489], -likelihood = -486.73366
# Iteration=10, theta_new=[1.9460598  2.78478523], -likelihood = -488.77493
# Iteration=11, theta_new=[1.93586312 2.79038149], -likelihood = -490.18272
# Iteration=12, theta_new=[1.92743688 2.79505602], -likelihood = -491.13983
# Iteration=13, theta_new=[1.92050004 2.79902002], -likelihood = -491.78649
# Iteration=14, theta_new=[1.91486542 2.80233299], -likelihood = -492.22611
# Iteration=15, theta_new=[1.91023261 2.80508255], -likelihood = -492.52006
# Iteration=16, theta_new=[1.90653024 2.80739649], -likelihood = -492.71588
# Iteration=17, theta_new=[1.90347972 2.80931955], -likelihood = -492.84627
# Iteration=18, theta_new=[1.9010038  2.81091838], -likelihood = -492.93253
# Iteration=19, theta_new=[1.89906998 2.81225403], -likelihood = -492.98904
# Iteration=20, theta_new=[1.89745583 2.81337679], -likelihood = -493.02571
# 14-th start
# Iteration=1, theta_new=[-0.102604    2.00525231], -likelihood = -365.10304
# Iteration=2, theta_new=[-0.10148217  1.98512619], -likelihood = -367.92517
# Iteration=3, theta_new=[-0.10041039  1.96880692], -likelihood = -369.63410
# Iteration=4, theta_new=[-0.09926715  1.95562872], -likelihood = -370.66676
# Iteration=5, theta_new=[-0.09798151  1.94514342], -likelihood = -371.29223
# Iteration=6, theta_new=[-0.09652112  1.93680367], -likelihood = -371.67097
# Iteration=7, theta_new=[-0.09477284  1.93021576], -likelihood = -371.90746
# Iteration=8, theta_new=[-0.09265811  1.92502281], -likelihood = -372.06567
# Iteration=9, theta_new=[-0.09005157  1.92106912], -likelihood = -372.18827
# Iteration=10, theta_new=[-0.08678676  1.91795537], -likelihood = -372.30681
# Iteration=11, theta_new=[-0.08274803  1.91559766], -likelihood = -372.45499
# Iteration=12, theta_new=[-0.07761484  1.91394105], -likelihood = -372.66630
# Iteration=13, theta_new=[-0.07111713  1.91273918], -likelihood = -372.99891
# Iteration=14, theta_new=[-0.06285879  1.91200525], -likelihood = -373.53808
# Iteration=15, theta_new=[-0.05233965  1.91176986], -likelihood = -374.42622
# Iteration=16, theta_new=[-0.03891347  1.91182824], -likelihood = -375.89954
# Iteration=17, theta_new=[-0.02204607  1.91221999], -likelihood = -378.34559
# Iteration=18, theta_new=[-1.15115199e-03  1.91284934e+00], -likelihood = -382.30335
# Iteration=19, theta_new=[0.02374453 1.91346592], -likelihood = -388.47966
# Iteration=20, theta_new=[0.05186458 1.91388152], -likelihood = -397.41635
# 15-th start
# Iteration=1, theta_new=[ 0.96405346 -0.38059359], -likelihood = -324.93554
# Iteration=2, theta_new=[ 1.00665192 -0.38199955], -likelihood = -341.17050
# Iteration=3, theta_new=[ 1.04340243 -0.38267757], -likelihood = -352.79355
# Iteration=4, theta_new=[ 1.07457364 -0.38282453], -likelihood = -360.66254
# Iteration=5, theta_new=[ 1.10051791 -0.38264241], -likelihood = -365.82320
# Iteration=6, theta_new=[ 1.12203681 -0.38223832], -likelihood = -369.12232
# Iteration=7, theta_new=[ 1.13965428 -0.38175807], -likelihood = -371.22172
# Iteration=8, theta_new=[ 1.15400014 -0.38120434], -likelihood = -372.54177
# Iteration=9, theta_new=[ 1.16549757 -0.38067118], -likelihood = -373.37178
# Iteration=10, theta_new=[ 1.17473025 -0.38014675], -likelihood = -373.88841
# Iteration=11, theta_new=[ 1.18209324 -0.37959921], -likelihood = -374.21395
# Iteration=12, theta_new=[ 1.18795925 -0.37906939], -likelihood = -374.42070
# Iteration=13, theta_new=[ 1.19267634 -0.37857777], -likelihood = -374.55347
# Iteration=14, theta_new=[ 1.19638981 -0.37808593], -likelihood = -374.64050
# Iteration=15, theta_new=[ 1.19924969 -0.37763107], -likelihood = -374.69810
# Iteration=16, theta_new=[ 1.20157288 -0.37718117], -likelihood = -374.73627
# Iteration=17, theta_new=[ 1.20339924 -0.37678197], -likelihood = -374.76389
# Iteration=18, theta_new=[ 1.20487896 -0.37641202], -likelihood = -374.78337
# Iteration=19, theta_new=[ 1.20600698 -0.37604649], -likelihood = -374.79800
# Iteration=20, theta_new=[ 1.20686657 -0.3757476 ], -likelihood = -374.80936
# 16-th start
# Iteration=1, theta_new=[-0.37639524  2.55862976], -likelihood = -243.45575
# Iteration=2, theta_new=[-0.38429865  2.58606984], -likelihood = -251.05779
# Iteration=3, theta_new=[-0.39158602  2.61616911], -likelihood = -261.91069
# Iteration=4, theta_new=[-0.39837428  2.64626058], -likelihood = -274.98444
# Iteration=5, theta_new=[-0.40481541  2.67392686], -likelihood = -288.32207
# Iteration=6, theta_new=[-0.41098837  2.69804009], -likelihood = -300.06877
# Iteration=7, theta_new=[-0.41696127  2.71833008], -likelihood = -309.41681
# Iteration=8, theta_new=[-0.42264543  2.73508134], -likelihood = -316.37066
# Iteration=9, theta_new=[-0.4279902  2.7487555], -likelihood = -321.33811
# Iteration=10, theta_new=[-0.4328909   2.75988806], -likelihood = -324.80289
# Iteration=11, theta_new=[-0.43740107  2.76889801], -likelihood = -327.19227
# Iteration=12, theta_new=[-0.4415529  2.7761975], -likelihood = -328.82801
# Iteration=13, theta_new=[-0.44521278  2.78213656], -likelihood = -329.94969
# Iteration=14, theta_new=[-0.44849407  2.78695383], -likelihood = -330.71743
# Iteration=15, theta_new=[-0.45140024  2.79082282], -likelihood = -331.24424
# Iteration=16, theta_new=[-0.453931   2.7939868], -likelihood = -331.60355
# Iteration=17, theta_new=[-0.45625398  2.79659073], -likelihood = -331.85205
# Iteration=18, theta_new=[-0.45820179  2.79869932], -likelihood = -332.02751
# Iteration=19, theta_new=[-0.45988698  2.80038868], -likelihood = -332.14711
# Iteration=20, theta_new=[-0.46139787  2.80182389], -likelihood = -332.22926
# 17-th start
# Iteration=1, theta_new=[-2.6449398  -1.72595428], -likelihood = -363.79002
# Iteration=2, theta_new=[-2.6445716  -1.57081813], -likelihood = -370.90270
# Iteration=3, theta_new=[-2.64425    -1.57075699], -likelihood = -373.54107
# Iteration=4, theta_new=[-2.64391551 -1.57075787], -likelihood = -373.54114
# Iteration=5, theta_new=[-2.64360129 -1.57072974], -likelihood = -373.54126
# Iteration=6, theta_new=[-2.64326084 -1.57078712], -likelihood = -373.54140
# Iteration=7, theta_new=[-2.64290891 -1.57080218], -likelihood = -373.54159
# Iteration=8, theta_new=[-2.64257454 -1.57085712], -likelihood = -373.54183
# Iteration=9, theta_new=[-2.64222686 -1.57079562], -likelihood = -373.54210
# Iteration=10, theta_new=[-2.64185913 -1.57084032], -likelihood = -373.54243
# Iteration=11, theta_new=[-2.64148419 -1.5707342 ], -likelihood = -373.54281
# Iteration=12, theta_new=[-2.64110839 -1.57075724], -likelihood = -373.54325
# Iteration=13, theta_new=[-2.64070575 -1.57079907], -likelihood = -373.54375
# Iteration=14, theta_new=[-2.64029728 -1.57073455], -likelihood = -373.54433
# Iteration=15, theta_new=[-2.63986831 -1.5707807 ], -likelihood = -373.54498
# Iteration=16, theta_new=[-2.63943518 -1.57082273], -likelihood = -373.54572
# Iteration=17, theta_new=[-2.63901113 -1.57078816], -likelihood = -373.54653
# Iteration=18, theta_new=[-2.63856392 -1.57075596], -likelihood = -373.54739
# Iteration=19, theta_new=[-2.63812008 -1.57078433], -likelihood = -373.54837
# Iteration=20, theta_new=[-2.63766036 -1.57081548], -likelihood = -373.54940
# 18-th start
# Iteration=1, theta_new=[-2.80494804 -1.57082184], -likelihood = -374.34316
# Iteration=2, theta_new=[-2.80394257 -1.57076588], -likelihood = -375.51723
# Iteration=3, theta_new=[-2.80297888 -1.57073645], -likelihood = -375.52069
# Iteration=4, theta_new=[-2.80207669 -1.57081876], -likelihood = -375.52343
# Iteration=5, theta_new=[-2.80122607 -1.5708398 ], -likelihood = -375.52549
# Iteration=6, theta_new=[-2.80039603 -1.57071365], -likelihood = -375.52700
# Iteration=7, theta_new=[-2.7996294 -1.5707557], -likelihood = -375.52806
# Iteration=8, theta_new=[-2.79888818 -1.570829  ], -likelihood = -375.52869
# Iteration=9, theta_new=[-2.79817937 -1.57078241], -likelihood = -375.52897
# Iteration=10, theta_new=[-2.79751174 -1.57076863], -likelihood = -375.52895
# Iteration=11, theta_new=[-2.7968904  -1.57078648], -likelihood = -375.52867
# Iteration=12, theta_new=[-2.79625958 -1.57080591], -likelihood = -375.52818
# Iteration=13, theta_new=[-2.795679  -1.5707807], -likelihood = -375.52747
# Iteration=14, theta_new=[-2.79514075 -1.57081754], -likelihood = -375.52662
# Iteration=15, theta_new=[-2.79462055 -1.5707675 ], -likelihood = -375.52566
# Iteration=16, theta_new=[-2.79412093 -1.57080444], -likelihood = -375.52459
# Iteration=17, theta_new=[-2.79365328 -1.5707417 ], -likelihood = -375.52343
# Iteration=18, theta_new=[-2.79319382 -1.57074707], -likelihood = -375.52221
# Iteration=19, theta_new=[-2.79275872 -1.57080997], -likelihood = -375.52091
# Iteration=20, theta_new=[-2.79236386 -1.57075129], -likelihood = -375.51957
# 19-th start
# Iteration=1, theta_new=[0.43880002 0.81018852], -likelihood = -345.29776
# Iteration=2, theta_new=[0.4217017 0.8652196], -likelihood = -379.68218
# Iteration=3, theta_new=[0.40866982 0.91683169], -likelihood = -406.02728
# Iteration=4, theta_new=[0.39777279 0.9647784 ], -likelihood = -428.37234
# Iteration=5, theta_new=[0.38811472 1.00843553], -likelihood = -447.13695
# Iteration=6, theta_new=[0.37936962 1.0474372 ], -likelihood = -462.14758
# Iteration=7, theta_new=[0.3714578 1.0815307], -likelihood = -473.53541
# Iteration=8, theta_new=[0.36439447 1.11080676], -likelihood = -481.74965
# Iteration=9, theta_new=[0.35811205 1.13563789], -likelihood = -487.44960
# Iteration=10, theta_new=[0.35263272 1.15647621], -likelihood = -491.31251
# Iteration=11, theta_new=[0.34789492 1.17378082], -likelihood = -493.88108
# Iteration=12, theta_new=[0.34382525 1.18801011], -likelihood = -495.56796
# Iteration=13, theta_new=[0.34034089 1.19968538], -likelihood = -496.66657
# Iteration=14, theta_new=[0.33734325 1.20923327], -likelihood = -497.38136
# Iteration=15, theta_new=[0.33478234 1.21692572], -likelihood = -497.84639
# Iteration=16, theta_new=[0.33264513 1.22309994], -likelihood = -498.14540
# Iteration=17, theta_new=[0.33083319 1.22800456], -likelihood = -498.33561
# Iteration=18, theta_new=[0.32930455 1.23198298], -likelihood = -498.45660
# Iteration=19, theta_new=[0.32800012 1.23521851], -likelihood = -498.53395
# Iteration=20, theta_new=[0.32690662 1.23778593], -likelihood = -498.58317
# 20-th start
# Iteration=1, theta_new=[ 3.00916155 -2.83390422], -likelihood = -238.64336
# Iteration=2, theta_new=[ 2.98616997 -2.82890817], -likelihood = -246.63530
# Iteration=3, theta_new=[ 2.96317435 -2.82236679], -likelihood = -255.56062
# Iteration=4, theta_new=[ 2.94072793 -2.81374643], -likelihood = -265.22851
# Iteration=5, theta_new=[ 2.91948881 -2.80280405], -likelihood = -275.28586
# Iteration=6, theta_new=[ 2.89992338 -2.78986836], -likelihood = -285.22387
# Iteration=7, theta_new=[ 2.88252487 -2.77575198], -likelihood = -294.48464
# Iteration=8, theta_new=[ 2.86757741 -2.76142607], -likelihood = -302.47905
# Iteration=9, theta_new=[ 2.85500888 -2.74776117], -likelihood = -308.86604
# Iteration=10, theta_new=[ 2.84474498 -2.73549526], -likelihood = -313.65421
# Iteration=11, theta_new=[ 2.83645789 -2.72478979], -likelihood = -317.02530
# Iteration=12, theta_new=[ 2.82990552 -2.71564652], -likelihood = -319.32420
# Iteration=13, theta_new=[ 2.82470694 -2.70803861], -likelihood = -320.84829
# Iteration=14, theta_new=[ 2.82068651 -2.7016409 ], -likelihood = -321.84272
# Iteration=15, theta_new=[ 2.8175029  -2.69639298], -likelihood = -322.48806
# Iteration=16, theta_new=[ 2.81511225 -2.69212909], -likelihood = -322.90439
# Iteration=17, theta_new=[ 2.81322306 -2.68861459], -likelihood = -323.16710
# Iteration=18, theta_new=[ 2.81180971 -2.68577061], -likelihood = -323.33801
# Iteration=19, theta_new=[ 2.81071342 -2.68336741], -likelihood = -323.44645
# Iteration=20, theta_new=[ 2.809925   -2.68144303], -likelihood = -323.51855
# 21-th start
# Iteration=1, theta_new=[-2.91253958  1.9204034 ], -likelihood = -381.89123
# Iteration=2, theta_new=[-2.90208571  1.91785097], -likelihood = -383.06577
# Iteration=3, theta_new=[-2.89217609  1.91618176], -likelihood = -384.11729
# Iteration=4, theta_new=[-2.88294465  1.91525889], -likelihood = -385.04096
# Iteration=5, theta_new=[-2.87432307  1.91479761], -likelihood = -385.83412
# Iteration=6, theta_new=[-2.86638143  1.91485435], -likelihood = -386.51341
# Iteration=7, theta_new=[-2.85902388  1.91509671], -likelihood = -387.08509
# Iteration=8, theta_new=[-2.85233505  1.9155773 ], -likelihood = -387.56648
# Iteration=9, theta_new=[-2.84615807  1.91621887], -likelihood = -387.96333
# Iteration=10, theta_new=[-2.84051106  1.91688274], -likelihood = -388.29469
# Iteration=11, theta_new=[-2.83538182  1.91763995], -likelihood = -388.56743
# Iteration=12, theta_new=[-2.83072128  1.91835599], -likelihood = -388.79034
# Iteration=13, theta_new=[-2.8264825   1.91903337], -likelihood = -388.97191
# Iteration=14, theta_new=[-2.82262704  1.91971645], -likelihood = -389.11971
# Iteration=15, theta_new=[-2.81908881  1.92036018], -likelihood = -389.23996
# Iteration=16, theta_new=[-2.81583504  1.92088467], -likelihood = -389.33832
# Iteration=17, theta_new=[-2.81292282  1.92143999], -likelihood = -389.41847
# Iteration=18, theta_new=[-2.81024547  1.92194704], -likelihood = -389.48224
# Iteration=19, theta_new=[-2.80777987  1.92237822], -likelihood = -389.53407
# Iteration=20, theta_new=[-2.80551286  1.92273986], -likelihood = -389.57601
# 22-th start
# Iteration=1, theta_new=[ 2.99994994 -0.37877526], -likelihood = -243.52706
# Iteration=2, theta_new=[ 2.9734689  -0.38671439], -likelihood = -255.37134
# Iteration=3, theta_new=[ 2.9475677  -0.39645121], -likelihood = -268.72786
# Iteration=4, theta_new=[ 2.92355746 -0.40717407], -likelihood = -282.18624
# Iteration=5, theta_new=[ 2.90225393 -0.4179537 ], -likelihood = -294.14266
# Iteration=6, theta_new=[ 2.88409084 -0.4278761 ], -likelihood = -303.65484
# Iteration=7, theta_new=[ 2.86894527 -0.43652748], -likelihood = -310.55247
# Iteration=8, theta_new=[ 2.85655154 -0.44362943], -likelihood = -315.27545
# Iteration=9, theta_new=[ 2.84656392 -0.44935503], -likelihood = -318.37171
# Iteration=10, theta_new=[ 2.83854943 -0.45396555], -likelihood = -320.35065
# Iteration=11, theta_new=[ 2.83218791 -0.45751185], -likelihood = -321.60381
# Iteration=12, theta_new=[ 2.82707955 -0.46036022], -likelihood = -322.38264
# Iteration=13, theta_new=[ 2.82303806 -0.46250667], -likelihood = -322.87359
# Iteration=14, theta_new=[ 2.81987743 -0.4641795 ], -likelihood = -323.17568
# Iteration=15, theta_new=[ 2.81737683 -0.46544253], -likelihood = -323.36073
# Iteration=16, theta_new=[ 2.81536674 -0.46646383], -likelihood = -323.47488
# Iteration=17, theta_new=[ 2.81375318 -0.46723192], -likelihood = -323.54673
# Iteration=18, theta_new=[ 2.81251031 -0.46781664], -likelihood = -323.59124
# Iteration=19, theta_new=[ 2.81148996 -0.46828778], -likelihood = -323.61780
# Iteration=20, theta_new=[ 2.8106824  -0.46858609], -likelihood = -323.63464
# 23-th start
# Iteration=1, theta_new=[-0.70837038  0.09881496], -likelihood = -223.41327
# Iteration=2, theta_new=[-0.70597372  0.12566983], -likelihood = -235.35342
# Iteration=3, theta_new=[-0.7014204   0.15173184], -likelihood = -247.83150
# Iteration=4, theta_new=[-0.69458672  0.17630205], -likelihood = -260.12913
# Iteration=5, theta_new=[-0.68552778  0.19880388], -likelihood = -271.61578
# Iteration=6, theta_new=[-0.67431385  0.21893673], -likelihood = -281.83113
# Iteration=7, theta_new=[-0.66111511  0.23651313], -likelihood = -290.62415
# Iteration=8, theta_new=[-0.64618339  0.25167295], -likelihood = -298.05132
# Iteration=9, theta_new=[-0.62989938  0.26454035], -likelihood = -304.35895
# Iteration=10, theta_new=[-0.61301313  0.27538945], -likelihood = -309.76088
# Iteration=11, theta_new=[-0.59612814  0.28447344], -likelihood = -314.39608
# Iteration=12, theta_new=[-0.5799091   0.29210593], -likelihood = -318.34312
# Iteration=13, theta_new=[-0.5649226   0.29848712], -likelihood = -321.63651
# Iteration=14, theta_new=[-0.55142568  0.3038471 ], -likelihood = -324.29324
# Iteration=15, theta_new=[-0.53940057  0.30838625], -likelihood = -326.38038
# Iteration=16, theta_new=[-0.5289397   0.31216607], -likelihood = -327.99323
# Iteration=17, theta_new=[-0.51992935  0.31542717], -likelihood = -329.20085
# Iteration=18, theta_new=[-0.51216806  0.31818159], -likelihood = -330.09875
# Iteration=19, theta_new=[-0.50560629  0.32051372], -likelihood = -330.75850
# Iteration=20, theta_new=[-0.50005686  0.32243481], -likelihood = -331.23422
# 24-th start
# Iteration=1, theta_new=[-0.75942165 -0.50710802], -likelihood = -173.27328
# Iteration=2, theta_new=[-0.81412062 -0.49118828], -likelihood = -205.96009
# Iteration=3, theta_new=[-0.86656069 -0.48477959], -likelihood = -223.57794
# Iteration=4, theta_new=[-0.9207415  -0.48394138], -likelihood = -238.97282
# Iteration=5, theta_new=[-0.97824545 -0.48643552], -likelihood = -255.50396
# Iteration=6, theta_new=[-1.03916764 -0.49050993], -likelihood = -273.66902
# Iteration=7, theta_new=[-1.10271377 -0.49502655], -likelihood = -292.51783
# Iteration=8, theta_new=[-1.16812305 -0.49912186], -likelihood = -310.47442
# Iteration=9, theta_new=[-1.23534665 -0.50235122], -likelihood = -326.14641
# Iteration=10, theta_new=[-1.30548619 -0.50448622], -likelihood = -338.81714
# Iteration=11, theta_new=[-1.38284923 -0.50553781], -likelihood = -348.41143
# Iteration=12, theta_new=[-1.49022994 -0.50560941], -likelihood = -355.31630
# Iteration=13, theta_new=[-1.5707676  -0.50553826], -likelihood = -359.37398
# Iteration=14, theta_new=[-1.57078616 -0.50549216], -likelihood = -359.79647
# Iteration=15, theta_new=[-1.57080472 -0.50544607], -likelihood = -359.79635
# Iteration=16, theta_new=[-1.57080058 -0.50539898], -likelihood = -359.79623
# Iteration=17, theta_new=[-1.57079644 -0.50535189], -likelihood = -359.79611
# Iteration=18, theta_new=[-1.5707923  -0.50530481], -likelihood = -359.79599
# Iteration=19, theta_new=[-1.57078815 -0.50525773], -likelihood = -359.79586
# Iteration=20, theta_new=[-1.57078401 -0.50521065], -likelihood = -359.79574
# 25-th start
# Iteration=1, theta_new=[0.50274167 1.26475966], -likelihood = -447.10232
# Iteration=2, theta_new=[0.47680839 1.25657946], -likelihood = -457.23330
# Iteration=3, theta_new=[0.45349792 1.2505387 ], -likelihood = -466.44521
# Iteration=4, theta_new=[0.43299287 1.2463899 ], -likelihood = -474.31182
# Iteration=5, theta_new=[0.41524427 1.24367028], -likelihood = -480.68859
# Iteration=6, theta_new=[0.40003505 1.24213945], -likelihood = -485.64613
# Iteration=7, theta_new=[0.38716136 1.24143709], -likelihood = -489.38340
# Iteration=8, theta_new=[0.37630272 1.24126199], -likelihood = -492.12130
# Iteration=9, theta_new=[0.3671844  1.24142364], -likelihood = -494.09511
# Iteration=10, theta_new=[0.35955205 1.24182771], -likelihood = -495.49787
# Iteration=11, theta_new=[0.35318771 1.24236104], -likelihood = -496.48410
# Iteration=12, theta_new=[0.34789258 1.24287486], -likelihood = -497.17060
# Iteration=13, theta_new=[0.34345297 1.24338151], -likelihood = -497.64486
# Iteration=14, theta_new=[0.33974749 1.24392538], -likelihood = -497.97344
# Iteration=15, theta_new=[0.33669156 1.24437429], -likelihood = -498.19884
# Iteration=16, theta_new=[0.33409785 1.24485473], -likelihood = -498.35081
# Iteration=17, theta_new=[0.33197831 1.24527347], -likelihood = -498.45562
# Iteration=18, theta_new=[0.33020854 1.24563254], -likelihood = -498.52463
# Iteration=19, theta_new=[0.32875694 1.24591789], -likelihood = -498.57071
# Iteration=20, theta_new=[0.32751056 1.24619385], -likelihood = -498.60068
# 26-th start
# Iteration=1, theta_new=[ 2.55497518 -1.57083058], -likelihood = -410.51230
# Iteration=2, theta_new=[ 2.58119733 -1.57080959], -likelihood = -419.03367
# Iteration=3, theta_new=[ 2.60837644 -1.57076889], -likelihood = -427.15590
# Iteration=4, theta_new=[ 2.63545191 -1.57076747], -likelihood = -436.34573
# Iteration=5, theta_new=[ 2.66133652 -1.57075856], -likelihood = -445.95769
# Iteration=6, theta_new=[ 2.68518073 -1.57084368], -likelihood = -455.18739
# Iteration=7, theta_new=[ 2.70648703 -1.57078715], -likelihood = -463.35799
# Iteration=8, theta_new=[ 2.72505529 -1.57075693], -likelihood = -470.10188
# Iteration=9, theta_new=[ 2.74099211 -1.57082238], -likelihood = -475.35638
# Iteration=10, theta_new=[ 2.75449014 -1.57083588], -likelihood = -479.28692
# Iteration=11, theta_new=[ 2.76583352 -1.57082397], -likelihood = -482.13273
# Iteration=12, theta_new=[ 2.77531332 -1.57077456], -likelihood = -484.14761
# Iteration=13, theta_new=[ 2.78321041 -1.57080725], -likelihood = -485.55044
# Iteration=14, theta_new=[ 2.78975813 -1.57078001], -likelihood = -486.51517
# Iteration=15, theta_new=[ 2.79519308 -1.57080986], -likelihood = -487.17037
# Iteration=16, theta_new=[ 2.79968474 -1.5708336 ], -likelihood = -487.61256
# Iteration=17, theta_new=[ 2.80340217 -1.57076551], -likelihood = -487.90740
# Iteration=18, theta_new=[ 2.80647983 -1.57074763], -likelihood = -488.10262
# Iteration=19, theta_new=[ 2.80902215 -1.57083561], -likelihood = -488.23055
# Iteration=20, theta_new=[ 2.81111157 -1.57079555], -likelihood = -488.31310
# 27-th start
# Iteration=1, theta_new=[2.12929672 1.57078876], -likelihood = -348.28881
# Iteration=2, theta_new=[2.15818512 1.57078595], -likelihood = -360.49702
# Iteration=3, theta_new=[2.18212272 1.57070846], -likelihood = -364.80914
# Iteration=4, theta_new=[2.202312   1.57080893], -likelihood = -368.10277
# Iteration=5, theta_new=[2.21964513 1.57076129], -likelihood = -370.67650
# Iteration=6, theta_new=[2.23478103 1.57082246], -likelihood = -372.73920
# Iteration=7, theta_new=[2.24819366 1.57073545], -likelihood = -374.43431
# Iteration=8, theta_new=[2.26026758 1.57073689], -likelihood = -375.85914
# Iteration=9, theta_new=[2.27126343 1.57076495], -likelihood = -377.08476
# Iteration=10, theta_new=[2.28139842 1.57076541], -likelihood = -378.15858
# Iteration=11, theta_new=[2.29082766 1.57078648], -likelihood = -379.11669
# Iteration=12, theta_new=[2.29972333 1.5707987 ], -likelihood = -379.98456
# Iteration=13, theta_new=[2.3082011  1.57078212], -likelihood = -380.78592
# Iteration=14, theta_new=[2.31636007 1.5708302 ], -likelihood = -381.53707
# Iteration=15, theta_new=[2.32428816 1.57083329], -likelihood = -382.25143
# Iteration=16, theta_new=[2.33206111 1.58358805], -likelihood = -382.94056
# Iteration=17, theta_new=[2.33975352 1.60574205], -likelihood = -383.61776
# Iteration=18, theta_new=[2.34762667 1.62533808], -likelihood = -384.30187
# Iteration=19, theta_new=[2.35587497 1.64360676], -likelihood = -385.03150
# Iteration=20, theta_new=[2.3646881  1.66097911], -likelihood = -385.83851
# 28-th start
# Iteration=1, theta_new=[2.35992526 3.05524315], -likelihood = -269.38781
# Iteration=2, theta_new=[2.31135634 3.02739883], -likelihood = -297.09789
# Iteration=3, theta_new=[2.25739778 3.00029762], -likelihood = -331.88263
# Iteration=4, theta_new=[2.2034332  2.97497027], -likelihood = -368.98282
# Iteration=5, theta_new=[2.15304042 2.95191495], -likelihood = -402.61271
# Iteration=6, theta_new=[2.10807992 2.93142609], -likelihood = -429.69121
# Iteration=7, theta_new=[2.06908817 2.91357708], -likelihood = -449.79280
# Iteration=8, theta_new=[2.035979   2.89819823], -likelihood = -463.97644
# Iteration=9, theta_new=[2.00817056 2.88511741], -likelihood = -473.68925
# Iteration=10, theta_new=[1.98509711 2.87401825], -likelihood = -480.22599
# Iteration=11, theta_new=[1.96608921 2.86471162], -likelihood = -484.58809
# Iteration=12, theta_new=[1.95058773 2.85691326], -likelihood = -487.47417
# Iteration=13, theta_new=[1.93811982 2.85041193], -likelihood = -489.37967
# Iteration=14, theta_new=[1.92806658 2.84498579], -likelihood = -490.63206
# Iteration=15, theta_new=[1.92009465 2.84049994], -likelihood = -491.45975
# Iteration=16, theta_new=[1.91367573 2.83677357], -likelihood = -492.00257
# Iteration=17, theta_new=[1.90868092 2.83371204], -likelihood = -492.36257
# Iteration=18, theta_new=[1.90477367 2.83115289], -likelihood = -492.59839
# Iteration=19, theta_new=[1.90163774 2.8290275 ], -likelihood = -492.75609
# Iteration=20, theta_new=[1.8991862  2.82729354], -likelihood = -492.86167
# 29-th start
# Iteration=1, theta_new=[-1.57077782  2.54475448], -likelihood = -397.46380
# Iteration=2, theta_new=[-1.57076391  2.57025603], -likelihood = -405.01325
# Iteration=3, theta_new=[-1.57080912  2.59748874], -likelihood = -413.27024
# Iteration=4, theta_new=[-1.5708021   2.62528455], -likelihood = -423.06000
# Iteration=5, theta_new=[-1.57085958  2.65231853], -likelihood = -433.73536
# Iteration=6, theta_new=[-1.57081699  2.67746967], -likelihood = -444.32866
# Iteration=7, theta_new=[-1.57083417  2.70004736], -likelihood = -453.91846
# Iteration=8, theta_new=[-1.57084248  2.71975381], -likelihood = -461.94088
# Iteration=9, theta_new=[-1.5707732   2.73663907], -likelihood = -468.23683
# Iteration=10, theta_new=[-1.57077298  2.75088802], -likelihood = -472.95448
# Iteration=11, theta_new=[-1.5707812   2.76281069], -likelihood = -476.36495
# Iteration=12, theta_new=[-1.57082415  2.77273885], -likelihood = -478.77343
# Iteration=13, theta_new=[-1.57081365  2.78096278], -likelihood = -480.44755
# Iteration=14, theta_new=[-1.57083507  2.78777809], -likelihood = -481.59553
# Iteration=15, theta_new=[-1.57079033  2.79340179], -likelihood = -482.37775
# Iteration=16, theta_new=[-1.57078005  2.79804285], -likelihood = -482.90527
# Iteration=17, theta_new=[-1.57077909  2.80186741], -likelihood = -483.25911
# Iteration=18, theta_new=[-1.57078638  2.80501417], -likelihood = -483.49471
# Iteration=19, theta_new=[-1.57078196  2.80761242], -likelihood = -483.65035
# Iteration=20, theta_new=[-1.57080724  2.80974312], -likelihood = -483.75271

# %%
np.rad2deg(EM_theta2_rad)
# Out:
# array([18.39844309, 71.46658629])

# %% [markdown]
# ## True result

# %%
np.rad2deg(theta2_rad)
# Out:
# array([19.99999998, 70.00000021])

# %% [markdown]
# # Case 3

# %% [markdown]
# Имеется 7 датчиков, 3 источника (дисперсии сигналов - 0.1, 0.5 и 0.9), и шум на каждом датчике имеет дисперсию 1.1.

# %%
Num_sensors3 = 7
Num_emitters3 = 3
sample_size3 = 100
theta3_rad = [0.5, 1.2, 1.6] # Направление прибытия (DOA) в радианах
GS_3 = np.diag([0.1, 0.5, 0.9]) # Ковариация сигнала
GN_3 = 1.1*np.eye(7, dtype=np.float64) # Ковариация шума
A3 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors3).reshape(-1,1) * np.sin(theta3_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s3 = CN(Num_emitters3, sample_size3, GS_3)
n3 = CN(Num_sensors3, sample_size3, GN_3)
X3 = (A3 @ s3.T + n3.T).T

# %% [markdown]
# ## ML1

# %%
theta_ML1_Case3, ML1_func_val_Case3 = multi_start_ML1(X3, L=Num_sensors3, M=Num_emitters3, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
np.rad2deg(theta_ML1_Case3)
# Out:
# array([ 59.89284651, -63.39567897, -63.63814575])

# %% [markdown]
# ## ML2

# %%
theta_ML2_Case3, ML2_func_val_Case3 = multi_start_ML2(X3, GS_3, GN_3, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
np.rad2deg(theta_ML2_Case3)
# Out:
# array([ 28.98916692,  68.66326015, -83.8759217 ])

# %% [markdown]
# ## EM

# %%
EM_theta3_rad, neglhd_3, K3, mu3 = multi_start_EM(X3, GS_3, GN_3, 30, max_iter=20, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[-1.42711028  1.1634118  -1.70846055], -likelihood = -1026.35249
# Iteration=2, theta_new=[-1.39143101  1.13372256 -1.74405921], -likelihood = -1049.43714
# Iteration=3, theta_new=[-1.37151671  1.11364441 -1.76331327], -likelihood = -1059.11174
# Iteration=4, theta_new=[-1.35917434  1.09922836 -1.77454046], -likelihood = -1063.83613
# Iteration=5, theta_new=[-1.35124816  1.08845049 -1.78112251], -likelihood = -1066.39239
# Iteration=6, theta_new=[-1.34578959  1.08015411 -1.78472754], -likelihood = -1067.89448
# Iteration=7, theta_new=[-1.34176561  1.07359617 -1.78634738], -likelihood = -1068.84250
# Iteration=8, theta_new=[-1.33849961  1.06828452 -1.786624  ], -likelihood = -1069.48384
# Iteration=9, theta_new=[-1.33540468  1.06388211 -1.7859547 ], -likelihood = -1069.94724
# Iteration=10, theta_new=[-1.3319661   1.06015281 -1.78459397], -likelihood = -1070.30307
# Iteration=11, theta_new=[-1.32782885  1.05693329 -1.78270579], -likelihood = -1070.59199
# Iteration=12, theta_new=[-1.32263094  1.05411569 -1.7803913 ], -likelihood = -1070.83886
# Iteration=13, theta_new=[-1.31594505  1.05161299 -1.77768669], -likelihood = -1071.06038
# Iteration=14, theta_new=[-1.30727483  1.04935956 -1.77457846], -likelihood = -1071.27167
# Iteration=15, theta_new=[-1.29608148  1.04732375 -1.77099907], -likelihood = -1071.48964
# Iteration=16, theta_new=[-1.2818549   1.04549893 -1.76685732], -likelihood = -1071.73672
# Iteration=17, theta_new=[-1.26393219  1.04385793 -1.76199496], -likelihood = -1072.04693
# Iteration=18, theta_new=[-1.24182966  1.04239742 -1.75625487], -likelihood = -1072.48133
# Iteration=19, theta_new=[-1.21539269  1.04113352 -1.74947347], -likelihood = -1073.13576
# Iteration=20, theta_new=[-1.18516618  1.0400306  -1.74169736], -likelihood = -1074.14845
# 1-th start
# Iteration=1, theta_new=[-2.00899294  1.78427127  2.3680456 ], -likelihood = -1076.12192
# Iteration=2, theta_new=[-2.02131975  1.79365196  2.36878688], -likelihood = -1079.27378
# Iteration=3, theta_new=[-2.03099543  1.80062543  2.37025899], -likelihood = -1081.60858
# Iteration=4, theta_new=[-2.0385667   1.80586269  2.37231966], -likelihood = -1083.40127
# Iteration=5, theta_new=[-2.04465439  1.80995586  2.37488501], -likelihood = -1084.82075
# Iteration=6, theta_new=[-2.04951777  1.81315771  2.37787193], -likelihood = -1086.01369
# Iteration=7, theta_new=[-2.0535677   1.81580493  2.3812199 ], -likelihood = -1087.04440
# Iteration=8, theta_new=[-2.05689038  1.81802184  2.38490976], -likelihood = -1087.98758
# Iteration=9, theta_new=[-2.05957134  1.81993115  2.38892431], -likelihood = -1088.86944
# Iteration=10, theta_new=[-2.0618377   1.82161718  2.39326806], -likelihood = -1089.71301
# Iteration=11, theta_new=[-2.06376297  1.82320703  2.39790071], -likelihood = -1090.55219
# Iteration=12, theta_new=[-2.06527858  1.82464843  2.40287302], -likelihood = -1091.40104
# Iteration=13, theta_new=[-2.06656898  1.82603082  2.40815624], -likelihood = -1092.26394
# Iteration=14, theta_new=[-2.06760452  1.82730307  2.41368109], -likelihood = -1093.16332
# Iteration=15, theta_new=[-2.06837413  1.82854511  2.41951274], -likelihood = -1094.09041
# Iteration=16, theta_new=[-2.06901993  1.82972881  2.42570466], -likelihood = -1095.06320
# Iteration=17, theta_new=[-2.06940895  1.83091518  2.43216732], -likelihood = -1096.10643
# Iteration=18, theta_new=[-2.06967301  1.83203924  2.43891819], -likelihood = -1097.20574
# Iteration=19, theta_new=[-2.06971037  1.83308047  2.44599499], -likelihood = -1098.37767
# Iteration=20, theta_new=[-2.06954466  1.8340659   2.45334431], -likelihood = -1099.62728
# 2-th start
# Iteration=1, theta_new=[-1.78188687 -0.61057781  1.98424247], -likelihood = -1020.99332
# Iteration=2, theta_new=[-1.85425826 -0.60433695  1.96305097], -likelihood = -1050.14650
# Iteration=3, theta_new=[-1.90385073 -0.59951471  1.94487856], -likelihood = -1069.49771
# Iteration=4, theta_new=[-1.94125964 -0.5957775   1.92919021], -likelihood = -1082.63272
# Iteration=5, theta_new=[-1.97100721 -0.5927906   1.9156365 ], -likelihood = -1091.72724
# Iteration=6, theta_new=[-1.99531231 -0.59033412  1.90387752], -likelihood = -1098.16351
# Iteration=7, theta_new=[-2.01562287 -0.58830542  1.89368989], -likelihood = -1102.79239
# Iteration=8, theta_new=[-2.03283675 -0.58658558  1.88477822], -likelihood = -1106.17493
# Iteration=9, theta_new=[-2.0475655  -0.58514105  1.87697862], -likelihood = -1108.68382
# Iteration=10, theta_new=[-2.06021152 -0.58385378  1.870167  ], -likelihood = -1110.56235
# Iteration=11, theta_new=[-2.07125833 -0.58272305  1.8642658 ], -likelihood = -1111.97796
# Iteration=12, theta_new=[-2.08086958 -0.58171369  1.85903884], -likelihood = -1113.06265
# Iteration=13, theta_new=[-2.08923996 -0.58079072  1.85442602], -likelihood = -1113.89536
# Iteration=14, theta_new=[-2.09658975 -0.57995839  1.85043059], -likelihood = -1114.53660
# Iteration=15, theta_new=[-2.10300179 -0.57916927  1.84692532], -likelihood = -1115.03532
# Iteration=16, theta_new=[-2.10868377 -0.5784664   1.84381402], -likelihood = -1115.42265
# Iteration=17, theta_new=[-2.11370896 -0.57782656  1.84112442], -likelihood = -1115.72828
# Iteration=18, theta_new=[-2.11805404 -0.57719732  1.83873162], -likelihood = -1115.97046
# Iteration=19, theta_new=[-2.12200287 -0.57662455  1.83660014], -likelihood = -1116.15799
# Iteration=20, theta_new=[-2.12541299 -0.57610089  1.8346831 ], -likelihood = -1116.31155
# 3-th start
# Iteration=1, theta_new=[-1.93053205  0.57255401 -2.55379093], -likelihood = -716.78548
# Iteration=2, theta_new=[-1.86895743  0.56652898 -2.54686025], -likelihood = -775.57117
# Iteration=3, theta_new=[-1.81151919  0.56127824 -2.54225794], -likelihood = -814.05411
# Iteration=4, theta_new=[-1.75625148  0.55666068 -2.53933224], -likelihood = -838.02604
# Iteration=5, theta_new=[-1.69927574  0.5526452  -2.5375502 ], -likelihood = -852.58493
# Iteration=6, theta_new=[-1.62481702  0.54912252 -2.53655899], -likelihood = -861.32863
# Iteration=7, theta_new=[-1.57085673  0.54584468 -2.53552853], -likelihood = -866.02870
# Iteration=8, theta_new=[-1.57080785  0.54290714 -2.53454041], -likelihood = -866.93616
# Iteration=9, theta_new=[-1.57077858  0.54030496 -2.53368399], -likelihood = -867.30429
# Iteration=10, theta_new=[-1.57077004  0.53801672 -2.53293033], -likelihood = -867.61073
# Iteration=11, theta_new=[-1.57082521  0.53600208 -2.53228244], -likelihood = -867.86395
# Iteration=12, theta_new=[-1.57082578  0.53422288 -2.53170961], -likelihood = -868.07467
# Iteration=13, theta_new=[-1.57080395  0.5326584  -2.53121623], -likelihood = -868.25055
# Iteration=14, theta_new=[-1.57081514  0.53126795 -2.53078356], -likelihood = -868.39760
# Iteration=15, theta_new=[-1.57076762  0.53004843 -2.53040936], -likelihood = -868.52216
# Iteration=16, theta_new=[-1.57089598  0.5289668  -2.53007215], -likelihood = -868.62664
# Iteration=17, theta_new=[-1.57073154  0.5280164  -2.52977696], -likelihood = -868.71512
# Iteration=18, theta_new=[-1.57079525  0.52717855 -2.52953246], -likelihood = -868.78982
# Iteration=19, theta_new=[-1.57081289  0.52643946 -2.52930373], -likelihood = -868.85397
# Iteration=20, theta_new=[-1.57080398  0.5257981  -2.52911189], -likelihood = -868.90807
# 4-th start
# Iteration=1, theta_new=[-3.06427119 -0.38056693 -0.50254654], -likelihood = -233.69775
# Iteration=2, theta_new=[-3.06917827 -0.36828101 -0.52243826], -likelihood = -318.04834
# Iteration=3, theta_new=[-3.07238434 -0.36012291 -0.53808053], -likelihood = -332.80994
# Iteration=4, theta_new=[-3.07453259 -0.35416191 -0.55075823], -likelihood = -339.20991
# Iteration=5, theta_new=[-3.07595213 -0.34970237 -0.56111399], -likelihood = -342.29885
# Iteration=6, theta_new=[-3.07700524 -0.34629458 -0.5695036 ], -likelihood = -343.80422
# Iteration=7, theta_new=[-3.07779493 -0.34365209 -0.57628723], -likelihood = -344.47754
# Iteration=8, theta_new=[-3.07844178 -0.34151624 -0.58172326], -likelihood = -344.70867
# Iteration=9, theta_new=[-3.07887869 -0.33988907 -0.58606097], -likelihood = -344.70429
# Iteration=10, theta_new=[-3.07927333 -0.33857569 -0.58957071], -likelihood = -344.59162
# Iteration=11, theta_new=[-3.07959127 -0.33752882 -0.59234639], -likelihood = -344.42834
# Iteration=12, theta_new=[-3.07989568 -0.3366964  -0.59458567], -likelihood = -344.25490
# Iteration=13, theta_new=[-3.08010855 -0.33597479 -0.59629726], -likelihood = -344.08631
# Iteration=14, theta_new=[-3.08034049 -0.3354001  -0.59764953], -likelihood = -343.93866
# Iteration=15, theta_new=[-3.08057448 -0.33491643 -0.59876238], -likelihood = -343.80989
# Iteration=16, theta_new=[-3.08072372 -0.33452272 -0.59958977], -likelihood = -343.69564
# Iteration=17, theta_new=[-3.08084625 -0.33418406 -0.60027743], -likelihood = -343.60646
# Iteration=18, theta_new=[-3.08101805 -0.3339197  -0.60079121], -likelihood = -343.52952
# Iteration=19, theta_new=[-3.0811004  -0.33378065 -0.60126308], -likelihood = -343.46752
# Iteration=20, theta_new=[-3.08117181 -0.33355631 -0.60157985], -likelihood = -343.41570
# 5-th start
# Iteration=1, theta_new=[ 1.95537573  0.94787831 -2.51056557], -likelihood = -723.02796
# Iteration=2, theta_new=[ 1.88276932  0.98127281 -2.51941935], -likelihood = -809.07435
# Iteration=3, theta_new=[ 1.80969354  1.01695122 -2.52674597], -likelihood = -872.87558
# Iteration=4, theta_new=[ 1.72486443  1.05201169 -2.5329028 ], -likelihood = -923.06341
# Iteration=5, theta_new=[ 1.57080573  1.08560109 -2.53829197], -likelihood = -962.90700
# Iteration=6, theta_new=[ 1.57079452  1.12044798 -2.54380331], -likelihood = -989.35745
# Iteration=7, theta_new=[ 1.57083399  1.15180575 -2.54871804], -likelihood = -1003.42579
# Iteration=8, theta_new=[ 1.57083835  1.17957368 -2.55300515], -likelihood = -1014.42888
# Iteration=9, theta_new=[ 1.57077855  1.20381347 -2.55669632], -likelihood = -1022.56696
# Iteration=10, theta_new=[ 1.57076081  1.22472674 -2.55984599], -likelihood = -1028.29739
# Iteration=11, theta_new=[ 1.5708217   1.24253859 -2.56251341], -likelihood = -1032.16867
# Iteration=12, theta_new=[ 1.5708352   1.25757202 -2.56478693], -likelihood = -1034.68533
# Iteration=13, theta_new=[ 1.5708061   1.27014821 -2.56670352], -likelihood = -1036.27013
# Iteration=14, theta_new=[ 1.5708445   1.28057207 -2.56833947], -likelihood = -1037.23361
# Iteration=15, theta_new=[ 1.57082214  1.2891487  -2.56972254], -likelihood = -1037.79742
# Iteration=16, theta_new=[ 1.57083597  1.29615264 -2.57089705], -likelihood = -1038.11030
# Iteration=17, theta_new=[ 1.57075959  1.30184652 -2.57190435], -likelihood = -1038.27077
# Iteration=18, theta_new=[ 1.57079694  1.30644704 -2.57275519], -likelihood = -1038.34216
# Iteration=19, theta_new=[ 1.57082869  1.31015216 -2.5734862 ], -likelihood = -1038.36265
# Iteration=20, theta_new=[ 1.57082654  1.31313445 -2.57410834], -likelihood = -1038.35670
# 6-th start
# Iteration=1, theta_new=[-3.07054052 -1.57078387 -2.10719846], -likelihood = -1049.32845
# Iteration=2, theta_new=[-3.06995132 -1.57081542 -2.10332355], -likelihood = -1049.41713
# Iteration=3, theta_new=[-3.06936614 -1.5708497  -2.09937248], -likelihood = -1048.79232
# Iteration=4, theta_new=[-3.06878846 -1.5708384  -2.09538581], -likelihood = -1048.13380
# Iteration=5, theta_new=[-3.06820607 -1.57080939 -2.09132776], -likelihood = -1047.44771
# Iteration=6, theta_new=[-3.06759819 -1.57080264 -2.08715133], -likelihood = -1046.72738
# Iteration=7, theta_new=[-3.06700526 -1.57082466 -2.08285407], -likelihood = -1045.96340
# Iteration=8, theta_new=[-3.06636369 -1.5708022  -2.07844776], -likelihood = -1045.15361
# Iteration=9, theta_new=[-3.06575976 -1.57078635 -2.07390681], -likelihood = -1044.29926
# Iteration=10, theta_new=[-3.06514634 -1.57078557 -2.06923226], -likelihood = -1043.39361
# Iteration=11, theta_new=[-3.06450997 -1.57082221 -2.06440853], -likelihood = -1042.43571
# Iteration=12, theta_new=[-3.06387355 -1.57097616 -2.05941614], -likelihood = -1041.42109
# Iteration=13, theta_new=[-3.06324476 -1.57072345 -2.05424019], -likelihood = -1040.34421
# Iteration=14, theta_new=[-3.0625502  -1.57082299 -2.04884394], -likelihood = -1039.20037
# Iteration=15, theta_new=[-3.06187886 -1.57079737 -2.04321565], -likelihood = -1037.98040
# Iteration=16, theta_new=[-3.06115884 -1.57077699 -2.03732526], -likelihood = -1036.67986
# Iteration=17, theta_new=[-3.0604048  -1.57075402 -2.0311257 ], -likelihood = -1035.29118
# Iteration=18, theta_new=[-3.05962595 -1.57080172 -2.02460228], -likelihood = -1033.80245
# Iteration=19, theta_new=[-3.05882208 -1.57085872 -2.01766607], -likelihood = -1032.21006
# Iteration=20, theta_new=[-3.05792244 -1.57077664 -2.01030103], -likelihood = -1030.49311
# 7-th start
# Iteration=1, theta_new=[-2.2772774   0.03106749 -1.23581235], -likelihood = -931.73336
# Iteration=2, theta_new=[-2.29174118  0.03032791 -1.29001141], -likelihood = -997.37087
# Iteration=3, theta_new=[-2.30126799  0.02998164 -1.34102371], -likelihood = -1035.24520
# Iteration=4, theta_new=[-2.30768164  0.0298115  -1.39040225], -likelihood = -1058.17506
# Iteration=5, theta_new=[-2.31168629  0.0297388  -1.44100124], -likelihood = -1072.09062
# Iteration=6, theta_new=[-2.31388109  0.02970887 -1.50205626], -likelihood = -1080.47522
# Iteration=7, theta_new=[-2.31412464  0.02968672 -1.5707594 ], -likelihood = -1084.93678
# Iteration=8, theta_new=[-2.31345425  0.02968599 -1.57083139], -likelihood = -1085.34425
# Iteration=9, theta_new=[-2.31278205  0.02969108 -1.57075092], -likelihood = -1085.35950
# Iteration=10, theta_new=[-2.31215637  0.02971592 -1.57082546], -likelihood = -1085.37471
# Iteration=11, theta_new=[-2.31153657  0.02972316 -1.57076928], -likelihood = -1085.38882
# Iteration=12, theta_new=[-2.31093484  0.02971861 -1.57076618], -likelihood = -1085.40270
# Iteration=13, theta_new=[-2.31033326  0.02971406 -1.57076309], -likelihood = -1085.41608
# Iteration=14, theta_new=[-2.30974033  0.0297123  -1.57075161], -likelihood = -1085.42937
# Iteration=15, theta_new=[-2.30918857  0.02971133 -1.57081351], -likelihood = -1085.44241
# Iteration=16, theta_new=[-2.30864098  0.0297194  -1.57081982], -likelihood = -1085.45447
# Iteration=17, theta_new=[-2.30812376  0.02971697 -1.57083946], -likelihood = -1085.46638
# Iteration=18, theta_new=[-2.30760471  0.02972292 -1.57075477], -likelihood = -1085.47755
# Iteration=19, theta_new=[-2.30713767  0.0297229  -1.57078426], -likelihood = -1085.48870
# Iteration=20, theta_new=[-2.30668262  0.02973712 -1.57080464], -likelihood = -1085.49867
# 8-th start
# Iteration=1, theta_new=[0.1923228  1.770144   0.60346002], -likelihood = -1110.70521
# Iteration=2, theta_new=[0.19321368 1.76734553 0.59524174], -likelihood = -1112.61902
# Iteration=3, theta_new=[0.19403679 1.76511694 0.58718914], -likelihood = -1114.46914
# Iteration=4, theta_new=[0.19483026 1.76337276 0.57938421], -likelihood = -1116.20954
# Iteration=5, theta_new=[0.19552777 1.76194162 0.57196026], -likelihood = -1117.81343
# Iteration=6, theta_new=[0.19604532 1.76069696 0.56497896], -likelihood = -1119.24914
# Iteration=7, theta_new=[0.19646276 1.75972826 0.55841617], -likelihood = -1120.50739
# Iteration=8, theta_new=[0.19665835 1.7590145  0.55232356], -likelihood = -1121.59970
# Iteration=9, theta_new=[0.19668825 1.75842454 0.5467666 ], -likelihood = -1122.53078
# Iteration=10, theta_new=[0.19648413 1.7579867  0.54161668], -likelihood = -1123.30634
# Iteration=11, theta_new=[0.1961222  1.75766241 0.53695008], -likelihood = -1123.96236
# Iteration=12, theta_new=[0.19555241 1.75743372 0.53271783], -likelihood = -1124.50337
# Iteration=13, theta_new=[0.19484492 1.75721513 0.52889082], -likelihood = -1124.95185
# Iteration=14, theta_new=[0.19393075 1.75712293 0.52542544], -likelihood = -1125.32198
# Iteration=15, theta_new=[0.19296523 1.75707141 0.5223208 ], -likelihood = -1125.63250
# Iteration=16, theta_new=[0.19189153 1.75709343 0.51947856], -likelihood = -1125.88826
# Iteration=17, theta_new=[0.19068001 1.75717362 0.51695925], -likelihood = -1126.10625
# Iteration=18, theta_new=[0.18946741 1.75720627 0.51468674], -likelihood = -1126.28978
# Iteration=19, theta_new=[0.18821355 1.75735465 0.51264894], -likelihood = -1126.44363
# Iteration=20, theta_new=[0.18690035 1.75743899 0.51084158], -likelihood = -1126.57598
# 9-th start
# Iteration=1, theta_new=[ 0.07054237 -0.94477356  1.83174396], -likelihood = -1098.99367
# Iteration=2, theta_new=[ 0.06794245 -0.9604761   1.82855384], -likelihood = -1101.45938
# Iteration=3, theta_new=[ 0.06533597 -0.97483003  1.82749724], -likelihood = -1103.32665
# Iteration=4, theta_new=[ 0.06280944 -0.98809848  1.82812457], -likelihood = -1104.81316
# Iteration=5, theta_new=[ 0.06030655 -1.0003878   1.83003923], -likelihood = -1106.05507
# Iteration=6, theta_new=[ 0.05784713 -1.01179839  1.83286267], -likelihood = -1107.13019
# Iteration=7, theta_new=[ 0.05541007 -1.02245012  1.8363516 ], -likelihood = -1108.08365
# Iteration=8, theta_new=[ 0.05299146 -1.03243548  1.84030097], -likelihood = -1108.94797
# Iteration=9, theta_new=[ 0.05063606 -1.04182585  1.84455243], -likelihood = -1109.74257
# Iteration=10, theta_new=[ 0.048247   -1.05067099  1.84895284], -likelihood = -1110.47775
# Iteration=11, theta_new=[ 0.04592562 -1.05899412  1.85350989], -likelihood = -1111.16306
# Iteration=12, theta_new=[ 0.04367386 -1.06685701  1.85803937], -likelihood = -1111.80363
# Iteration=13, theta_new=[ 0.04137929 -1.074272    1.86247833], -likelihood = -1112.39874
# Iteration=14, theta_new=[ 0.03916926 -1.08130731  1.86682387], -likelihood = -1112.95370
# Iteration=15, theta_new=[ 0.0370298  -1.08793004  1.8710184 ], -likelihood = -1113.46909
# Iteration=16, theta_new=[ 0.03492984 -1.09409804  1.87508925], -likelihood = -1113.94419
# Iteration=17, theta_new=[ 0.03288768 -1.09998249  1.87902082], -likelihood = -1114.38345
# Iteration=18, theta_new=[ 0.03084954 -1.10550408  1.88278792], -likelihood = -1114.79160
# Iteration=19, theta_new=[ 0.0288395  -1.11065862  1.88639815], -likelihood = -1115.16922
# Iteration=20, theta_new=[ 0.0269381  -1.11549825  1.88985333], -likelihood = -1115.51796
# 10-th start
# Iteration=1, theta_new=[ 2.4129879  -3.1080128   0.58349384], -likelihood = -304.21351
# Iteration=2, theta_new=[ 2.35364497 -3.11094322  0.57571334], -likelihood = -347.54651
# Iteration=3, theta_new=[ 2.29374834 -3.11466262  0.57316437], -likelihood = -388.09366
# Iteration=4, theta_new=[ 2.23008004 -3.1191421   0.57393998], -likelihood = -439.66577
# Iteration=5, theta_new=[ 2.16527681 -3.12373149  0.57599532], -likelihood = -509.23797
# Iteration=6, theta_new=[ 2.10293858 -3.12779963  0.57761009], -likelihood = -589.89807
# Iteration=7, theta_new=[ 2.0455922  -3.13095263  0.57795944], -likelihood = -667.19211
# Iteration=8, theta_new=[ 1.99454866 -3.13301144  0.57682105], -likelihood = -729.96841
# Iteration=9, theta_new=[ 1.95015167 -3.13413418  0.57453308], -likelihood = -774.94373
# Iteration=10, theta_new=[ 1.91224171 -3.13453375  0.57142018], -likelihood = -804.56406
# Iteration=11, theta_new=[ 1.880171   -3.13436773  0.56784296], -likelihood = -823.08833
# Iteration=12, theta_new=[ 1.8533542  -3.13379314  0.56409041], -likelihood = -834.43370
# Iteration=13, theta_new=[ 1.83112792 -3.13294913  0.56032726], -likelihood = -841.33821
# Iteration=14, theta_new=[ 1.81290284 -3.13187211  0.55666387], -likelihood = -845.58993
# Iteration=15, theta_new=[ 1.79805251 -3.13067267  0.55317349], -likelihood = -848.27256
# Iteration=16, theta_new=[ 1.78598492 -3.12935702  0.5498689 ], -likelihood = -850.03201
# Iteration=17, theta_new=[ 1.77631221 -3.12795353  0.54682583], -likelihood = -851.24861
# Iteration=18, theta_new=[ 1.76859878 -3.12648362  0.54399767], -likelihood = -852.12459
# Iteration=19, theta_new=[ 1.76249745 -3.12499673  0.54144028], -likelihood = -852.79527
# Iteration=20, theta_new=[ 1.7576708  -3.12349146  0.53906622], -likelihood = -853.32466
# 11-th start
# Iteration=1, theta_new=[1.72226123 0.72664836 2.72280196], -likelihood = -866.84502
# Iteration=2, theta_new=[1.7402316  0.73247756 2.71911387], -likelihood = -869.92929
# Iteration=3, theta_new=[1.75152657 0.73874883 2.71559236], -likelihood = -872.18801
# Iteration=4, theta_new=[1.75833764 0.74562739 2.71215199], -likelihood = -874.04314
# Iteration=5, theta_new=[1.76203272 0.75331426 2.70877239], -likelihood = -875.76728
# Iteration=6, theta_new=[1.76313825 0.76212256 2.70544273], -likelihood = -877.54583
# Iteration=7, theta_new=[1.76197808 0.77245599 2.70206625], -likelihood = -879.54446
# Iteration=8, theta_new=[1.75860036 0.78483652 2.69865731], -likelihood = -881.96403
# Iteration=9, theta_new=[1.7526603  0.79991356 2.69511386], -likelihood = -885.06863
# Iteration=10, theta_new=[1.74356253 0.81871765 2.69137786], -likelihood = -889.28378
# Iteration=11, theta_new=[1.73030913 0.84244183 2.68747988], -likelihood = -895.34732
# Iteration=12, theta_new=[1.71078498 0.87218287 2.68343286], -likelihood = -904.40275
# Iteration=13, theta_new=[1.68130837 0.9082635  2.67936254], -likelihood = -917.99886
# Iteration=14, theta_new=[1.6287495  0.94939313 2.67552521], -likelihood = -937.42029
# Iteration=15, theta_new=[1.57078866 0.99403374 2.67214668], -likelihood = -962.09483
# Iteration=16, theta_new=[1.5708549  1.03916389 2.66945374], -likelihood = -987.02852
# Iteration=17, theta_new=[1.5707577  1.08201125 2.66737834], -likelihood = -1010.54231
# Iteration=18, theta_new=[1.57076648 1.121335   2.66567569], -likelihood = -1031.56556
# Iteration=19, theta_new=[1.57075397 1.15655207 2.66418001], -likelihood = -1048.86366
# Iteration=20, theta_new=[1.57080417 1.1875432  2.66277795], -likelihood = -1062.03312
# 12-th start
# Iteration=1, theta_new=[-1.21184954 -0.90272714  1.17633958], -likelihood = -1027.51525
# Iteration=2, theta_new=[-1.22911602 -0.92367554  1.19892972], -likelihood = -1037.87709
# Iteration=3, theta_new=[-1.23950674 -0.94543619  1.21633047], -likelihood = -1044.42694
# Iteration=4, theta_new=[-1.24652321 -0.96644479  1.22946953], -likelihood = -1048.85371
# Iteration=5, theta_new=[-1.25215765 -0.98585455  1.23910678], -likelihood = -1051.88234
# Iteration=6, theta_new=[-1.25729307 -1.00334099  1.24581301], -likelihood = -1053.95909
# Iteration=7, theta_new=[-1.26223566 -1.01896785  1.25012976], -likelihood = -1055.39376
# Iteration=8, theta_new=[-1.2669815  -1.03285323  1.25250688], -likelihood = -1056.41198
# Iteration=9, theta_new=[-1.27143192 -1.04521925  1.25338293], -likelihood = -1057.16191
# Iteration=10, theta_new=[-1.27545044 -1.05628207  1.25307717], -likelihood = -1057.74304
# Iteration=11, theta_new=[-1.27897553 -1.06623754  1.2518836 ], -likelihood = -1058.21892
# Iteration=12, theta_new=[-1.28201187 -1.07523326  1.25004881], -likelihood = -1058.62826
# Iteration=13, theta_new=[-1.28441312 -1.08344564  1.24775944], -likelihood = -1058.99293
# Iteration=14, theta_new=[-1.28628951 -1.09097624  1.24514209], -likelihood = -1059.32703
# Iteration=15, theta_new=[-1.28771234 -1.0979177   1.24234694], -likelihood = -1059.63839
# Iteration=16, theta_new=[-1.28871229 -1.10433874  1.23943877], -likelihood = -1059.92897
# Iteration=17, theta_new=[-1.28925407 -1.11032417  1.23649327], -likelihood = -1060.20175
# Iteration=18, theta_new=[-1.28950781 -1.11591137  1.23355219], -likelihood = -1060.45748
# Iteration=19, theta_new=[-1.28936158 -1.12114447  1.23065777], -likelihood = -1060.69710
# Iteration=20, theta_new=[-1.28892739 -1.12606385  1.22784162], -likelihood = -1060.92052
# 13-th start
# Iteration=1, theta_new=[-2.12018708  2.41928137  1.29758465], -likelihood = -1122.82706
# Iteration=2, theta_new=[-2.12130737  2.42528452  1.30416776], -likelihood = -1124.08968
# Iteration=3, theta_new=[-2.12313465  2.43143277  1.30960925], -likelihood = -1125.27386
# Iteration=4, theta_new=[-2.1253802   2.43768716  1.31412769], -likelihood = -1126.43520
# Iteration=5, theta_new=[-2.12765302  2.4441124   1.31784143], -likelihood = -1127.59396
# Iteration=6, theta_new=[-2.13003298  2.45068343  1.32088901], -likelihood = -1128.76808
# Iteration=7, theta_new=[-2.13217707  2.45744685  1.32341243], -likelihood = -1129.97440
# Iteration=8, theta_new=[-2.13413695  2.46442558  1.32555602], -likelihood = -1131.22206
# Iteration=9, theta_new=[-2.13585703  2.47167524  1.32732316], -likelihood = -1132.52809
# Iteration=10, theta_new=[-2.13731499  2.47912268  1.32885348], -likelihood = -1133.90853
# Iteration=11, theta_new=[-2.1385617   2.48683411  1.33012504], -likelihood = -1135.35644
# Iteration=12, theta_new=[-2.13952123  2.49468287  1.33120027], -likelihood = -1136.88874
# Iteration=13, theta_new=[-2.1403665   2.5027322   1.33209036], -likelihood = -1138.47908
# Iteration=14, theta_new=[-2.14098552  2.51087821  1.33292008], -likelihood = -1140.14072
# Iteration=15, theta_new=[-2.14145223  2.51910557  1.33357316], -likelihood = -1141.84198
# Iteration=16, theta_new=[-2.14184049  2.52732342  1.33412067], -likelihood = -1143.57052
# Iteration=17, theta_new=[-2.14211737  2.53544623  1.33466513], -likelihood = -1145.29489
# Iteration=18, theta_new=[-2.14239165  2.5434554   1.33513826], -likelihood = -1146.97982
# Iteration=19, theta_new=[-2.14263048  2.55127943  1.33558651], -likelihood = -1148.60871
# Iteration=20, theta_new=[-2.14292028  2.55881002  1.33597084], -likelihood = -1150.15133
# 14-th start
# Iteration=1, theta_new=[-0.10217709 -1.6748925  -2.65994884], -likelihood = -1045.04913
# Iteration=2, theta_new=[-0.10714761 -1.57080136 -2.65317281], -likelihood = -1057.29875
# Iteration=3, theta_new=[-0.11169982 -1.57072535 -2.646412  ], -likelihood = -1061.66419
# Iteration=4, theta_new=[-0.11597896 -1.57080611 -2.6400936 ], -likelihood = -1062.64345
# Iteration=5, theta_new=[-0.12000512 -1.57074485 -2.63423079], -likelihood = -1063.47483
# Iteration=6, theta_new=[-0.12380796 -1.57079766 -2.62882127], -likelihood = -1064.17161
# Iteration=7, theta_new=[-0.12734119 -1.57081752 -2.62382389], -likelihood = -1064.74975
# Iteration=8, theta_new=[-0.13062322 -1.57082115 -2.61923953], -likelihood = -1065.22334
# Iteration=9, theta_new=[-0.13366265 -1.57085868 -2.61504497], -likelihood = -1065.60645
# Iteration=10, theta_new=[-0.13649847 -1.5706476  -2.61120827], -likelihood = -1065.91298
# Iteration=11, theta_new=[-0.13915756 -1.57075172 -2.60773506], -likelihood = -1066.15684
# Iteration=12, theta_new=[-0.14160162 -1.57077209 -2.6045596 ], -likelihood = -1066.34860
# Iteration=13, theta_new=[-0.14386092 -1.57074912 -2.60167707], -likelihood = -1066.49675
# Iteration=14, theta_new=[-0.1459067  -1.5707824  -2.59907099], -likelihood = -1066.60961
# Iteration=15, theta_new=[-0.14782762 -1.57081294 -2.59669235], -likelihood = -1066.69272
# Iteration=16, theta_new=[-0.14962353 -1.57080059 -2.5945489 ], -likelihood = -1066.75433
# Iteration=17, theta_new=[-0.15126151 -1.57083377 -2.59259412], -likelihood = -1066.79851
# Iteration=18, theta_new=[-0.1527707  -1.57081486 -2.59084528], -likelihood = -1066.82777
# Iteration=19, theta_new=[-0.15412384 -1.57087313 -2.58922942], -likelihood = -1066.84607
# Iteration=20, theta_new=[-0.15538577 -1.57076582 -2.58776722], -likelihood = -1066.85446
# 15-th start
# Iteration=1, theta_new=[-0.79834615  2.91689347 -1.82273149], -likelihood = -1017.19603
# Iteration=2, theta_new=[-0.79327896  2.91605788 -1.77500089], -likelihood = -1042.51652
# Iteration=3, theta_new=[-0.78918685  2.91472015 -1.72786771], -likelihood = -1058.68211
# Iteration=4, theta_new=[-0.78585816  2.91294085 -1.67780946], -likelihood = -1068.81402
# Iteration=5, theta_new=[-0.78315744  2.91070042 -1.60622894], -likelihood = -1075.06611
# Iteration=6, theta_new=[-0.78189924  2.90808574 -1.57085418], -likelihood = -1077.81236
# Iteration=7, theta_new=[-0.78083176  2.90506652 -1.57075075], -likelihood = -1078.02768
# Iteration=8, theta_new=[-0.77977225  2.90159112 -1.57083939], -likelihood = -1078.25306
# Iteration=9, theta_new=[-0.77872896  2.89757402 -1.57080492], -likelihood = -1078.55805
# Iteration=10, theta_new=[-0.77771465  2.89292023 -1.57082751], -likelihood = -1078.97280
# Iteration=11, theta_new=[-0.77673966  2.8875156  -1.5708251 ], -likelihood = -1079.53886
# Iteration=12, theta_new=[-0.77582526  2.88121196 -1.57082389], -likelihood = -1080.31419
# Iteration=13, theta_new=[-0.77501404  2.8738421  -1.57076715], -likelihood = -1081.38160
# Iteration=14, theta_new=[-0.77430146  2.86525808 -1.5707533 ], -likelihood = -1082.85410
# Iteration=15, theta_new=[-0.77374925  2.8553356  -1.57080467], -likelihood = -1084.87009
# Iteration=16, theta_new=[-0.77336926  2.84399144 -1.5708164 ], -likelihood = -1087.58713
# Iteration=17, theta_new=[-0.77321841  2.83117614 -1.57075873], -likelihood = -1091.15608
# Iteration=18, theta_new=[-0.77328326  2.81713125 -1.57076121], -likelihood = -1095.68971
# Iteration=19, theta_new=[-0.77359264  2.80218587 -1.57080795], -likelihood = -1101.11454
# Iteration=20, theta_new=[-0.77407991  2.78688721 -1.57081423], -likelihood = -1107.19876
# 16-th start
# Iteration=1, theta_new=[-1.33274414  2.22021108  1.13208376], -likelihood = -977.69061
# Iteration=2, theta_new=[-1.31100551  2.24488046  1.16163676], -likelihood = -1027.80387
# Iteration=3, theta_new=[-1.28150291  2.2629548   1.18585688], -likelihood = -1049.03403
# Iteration=4, theta_new=[-1.25044582  2.27754155  1.20659192], -likelihood = -1062.94836
# Iteration=5, theta_new=[-1.2203702   2.28988263  1.22455265], -likelihood = -1073.44681
# Iteration=6, theta_new=[-1.19238251  2.30063487  1.24013597], -likelihood = -1081.85062
# Iteration=7, theta_new=[-1.16678885  2.3101492   1.25366876], -likelihood = -1088.74673
# Iteration=8, theta_new=[-1.14368225  2.31872798  1.26545763], -likelihood = -1094.47473
# Iteration=9, theta_new=[-1.12296931  2.32656389  1.27573736], -likelihood = -1099.25776
# Iteration=10, theta_new=[-1.10445888  2.33373872  1.28472809], -likelihood = -1103.26035
# Iteration=11, theta_new=[-1.087991    2.34038913  1.29260512], -likelihood = -1106.61264
# Iteration=12, theta_new=[-1.07329066  2.34662612  1.29953255], -likelihood = -1109.42497
# Iteration=13, theta_new=[-1.0602909   2.35243312  1.3056219 ], -likelihood = -1111.80231
# Iteration=14, theta_new=[-1.04873085  2.35794491  1.31104297], -likelihood = -1113.80145
# Iteration=15, theta_new=[-1.03848754  2.36315302  1.31577655], -likelihood = -1115.50679
# Iteration=16, theta_new=[-1.0294265   2.3681669   1.32001252], -likelihood = -1116.96174
# Iteration=17, theta_new=[-1.02137769  2.37299184  1.32369795], -likelihood = -1118.22087
# Iteration=18, theta_new=[-1.01422093  2.37762877  1.32694   ], -likelihood = -1119.31975
# Iteration=19, theta_new=[-1.00800299  2.38217268  1.329809  ], -likelihood = -1120.28716
# Iteration=20, theta_new=[-1.00248374  2.38664549  1.33235919], -likelihood = -1121.14766
# 17-th start
# Iteration=1, theta_new=[ 0.52983315 -1.20398222  2.48742566], -likelihood = -803.29442
# Iteration=2, theta_new=[ 0.50091821 -1.27089467  2.4788026 ], -likelihood = -935.44111
# Iteration=3, theta_new=[ 0.48187233 -1.33194421  2.46925696], -likelihood = -1017.18721
# Iteration=4, theta_new=[ 0.4684081  -1.3894935   2.45997263], -likelihood = -1064.70953
# Iteration=5, theta_new=[ 0.45876955 -1.44806154  2.45128935], -likelihood = -1091.73691
# Iteration=6, theta_new=[ 0.45178559 -1.52706287  2.44323728], -likelihood = -1107.08525
# Iteration=7, theta_new=[ 0.44683332 -1.57077109  2.43522128], -likelihood = -1114.51297
# Iteration=8, theta_new=[ 0.44372863 -1.57082623  2.42719561], -likelihood = -1116.70380
# Iteration=9, theta_new=[ 0.44208746 -1.57076807  2.41894999], -likelihood = -1118.50929
# Iteration=10, theta_new=[ 0.4415553  -1.57080304  2.41040294], -likelihood = -1120.27946
# Iteration=11, theta_new=[ 0.44194622 -1.57075524  2.40141988], -likelihood = -1122.08459
# Iteration=12, theta_new=[ 0.44302957 -1.57085735  2.3919376 ], -likelihood = -1123.97710
# Iteration=13, theta_new=[ 0.44470236 -1.57079365  2.38192473], -likelihood = -1125.97134
# Iteration=14, theta_new=[ 0.44681614 -1.57081911  2.37137368], -likelihood = -1128.06461
# Iteration=15, theta_new=[ 0.44931882 -1.57076426  2.3602995 ], -likelihood = -1130.23573
# Iteration=16, theta_new=[ 0.45206779 -1.57079604  2.34872473], -likelihood = -1132.45565
# Iteration=17, theta_new=[ 0.45503419 -1.57072581  2.33672084], -likelihood = -1134.68268
# Iteration=18, theta_new=[ 0.4581218  -1.57078615  2.32439412], -likelihood = -1136.87066
# Iteration=19, theta_new=[ 0.46126607 -1.5707805   2.31182247], -likelihood = -1138.96547
# Iteration=20, theta_new=[ 0.46440388 -1.57075726  2.29910138], -likelihood = -1140.92467
# 18-th start
# Iteration=1, theta_new=[-2.6193389  -1.91687076 -1.95567187], -likelihood = -734.56171
# Iteration=2, theta_new=[-2.61688219 -1.79059751 -1.92623401], -likelihood = -863.45532
# Iteration=3, theta_new=[-2.61352683 -1.57082464 -1.92637273], -likelihood = -969.43823
# Iteration=4, theta_new=[-2.60926581 -1.57074019 -1.91027428], -likelihood = -1012.54385
# Iteration=5, theta_new=[-2.60565543 -1.57083435 -1.89197569], -likelihood = -1009.68429
# Iteration=6, theta_new=[-2.60260833 -1.57075724 -1.8710129 ], -likelihood = -1006.91808
# Iteration=7, theta_new=[-2.60018879 -1.57077756 -1.84679095], -likelihood = -1004.49861
# Iteration=8, theta_new=[-2.5983464  -1.57084395 -1.81856399], -likelihood = -1002.75609
# Iteration=9, theta_new=[-2.59700203 -1.57077847 -1.78515811], -likelihood = -1002.08428
# Iteration=10, theta_new=[-2.59604275 -1.57081887 -1.7444208 ], -likelihood = -1002.85152
# Iteration=11, theta_new=[-2.59540624 -1.57073224 -1.69036808], -likelihood = -1005.28367
# Iteration=12, theta_new=[-2.59494609 -1.57081489 -1.57079301], -likelihood = -1009.34275
# Iteration=13, theta_new=[-2.59441151 -1.57084059 -1.57080287], -likelihood = -1011.66940
# Iteration=14, theta_new=[-2.59393305 -1.57078857 -1.57082108], -likelihood = -1011.67188
# Iteration=15, theta_new=[-2.59350113 -1.57078653 -1.57082419], -likelihood = -1011.67373
# Iteration=16, theta_new=[-2.59312193 -1.57077476 -1.5708213 ], -likelihood = -1011.67510
# Iteration=17, theta_new=[-2.59277842 -1.57075017 -1.57076841], -likelihood = -1011.67607
# Iteration=18, theta_new=[-2.59246667 -1.57077839 -1.57078662], -likelihood = -1011.67676
# Iteration=19, theta_new=[-2.59219259 -1.57079945 -1.57081268], -likelihood = -1011.67723
# Iteration=20, theta_new=[-2.59194361 -1.57079449 -1.57078874], -likelihood = -1011.67753
# 19-th start
# Iteration=1, theta_new=[1.1784902  2.10727028 0.52495054], -likelihood = -748.16887
# Iteration=2, theta_new=[1.2695245  2.06463272 0.52290196], -likelihood = -877.59714
# Iteration=3, theta_new=[1.3647154  2.02771062 0.51994518], -likelihood = -965.03651
# Iteration=4, theta_new=[1.50357111 1.99634918 0.51695363], -likelihood = -1021.22735
# Iteration=5, theta_new=[1.5708184  1.9638824  0.51444392], -likelihood = -1054.60255
# Iteration=6, theta_new=[1.57084888 1.93490254 0.5120892 ], -likelihood = -1067.56644
# Iteration=7, theta_new=[1.57081908 1.91003998 0.50992987], -likelihood = -1075.53088
# Iteration=8, theta_new=[1.57081486 1.88894854 0.5080005 ], -likelihood = -1080.64275
# Iteration=9, theta_new=[1.5708223  1.87123043 0.50630339], -likelihood = -1083.76308
# Iteration=10, theta_new=[1.57076467 1.85645149 0.50481913], -likelihood = -1085.57523
# Iteration=11, theta_new=[1.57075388 1.84427887 0.50352955], -likelihood = -1086.56765
# Iteration=12, theta_new=[1.57080824 1.83428774 0.50241958], -likelihood = -1087.06172
# Iteration=13, theta_new=[1.5708206  1.82615733 0.50146934], -likelihood = -1087.26780
# Iteration=14, theta_new=[1.57079059 1.81956918 0.50064281], -likelihood = -1087.31365
# Iteration=15, theta_new=[1.57081134 1.81426069 0.49993588], -likelihood = -1087.27662
# Iteration=16, theta_new=[1.57082141 1.81000041 0.49933542], -likelihood = -1087.20140
# Iteration=17, theta_new=[1.57084404 1.80658881 0.49882024], -likelihood = -1087.11325
# Iteration=18, theta_new=[1.57075615 1.80388556 0.49837219], -likelihood = -1087.02559
# Iteration=19, theta_new=[1.57082209 1.8017351  0.49798455], -likelihood = -1086.94565
# Iteration=20, theta_new=[1.57083022 1.80004001 0.49764961], -likelihood = -1086.87552
# 20-th start
# Iteration=1, theta_new=[-1.57072819  2.63987581 -2.02765298], -likelihood = -907.15620
# Iteration=2, theta_new=[-1.57077886  2.63774074 -1.96589479], -likelihood = -944.91672
# Iteration=3, theta_new=[-1.57081666  2.63674299 -1.90684079], -likelihood = -982.58844
# Iteration=4, theta_new=[-1.57073719  2.63660509 -1.85081426], -likelihood = -1016.70836
# Iteration=5, theta_new=[-1.57075633  2.63696461 -1.79703751], -likelihood = -1043.94690
# Iteration=6, theta_new=[-1.57075016  2.63756523 -1.74350319], -likelihood = -1063.81158
# Iteration=7, theta_new=[-1.57082774  2.63826205 -1.685352  ], -likelihood = -1077.50442
# Iteration=8, theta_new=[-1.57080449  2.63898395 -1.5622858 ], -likelihood = -1086.64097
# Iteration=9, theta_new=[-1.5707627   2.63968627 -1.57076688], -likelihood = -1090.44911
# Iteration=10, theta_new=[-1.57081169  2.64030051 -1.57080486], -likelihood = -1090.46147
# Iteration=11, theta_new=[-1.57079683  2.64082671 -1.57078392], -likelihood = -1090.46606
# Iteration=12, theta_new=[-1.57077248  2.64129425 -1.57080137], -likelihood = -1090.46897
# Iteration=13, theta_new=[-1.57079603  2.64169498 -1.57080185], -likelihood = -1090.47076
# Iteration=14, theta_new=[-1.57080129  2.64205144 -1.57080463], -likelihood = -1090.47170
# Iteration=15, theta_new=[-1.57081412  2.64235548 -1.5707878 ], -likelihood = -1090.47207
# Iteration=16, theta_new=[-1.57081275  2.64262752 -1.57079932], -likelihood = -1090.47204
# Iteration=17, theta_new=[-1.57079689  2.64285699 -1.57077371], -likelihood = -1090.47174
# Iteration=18, theta_new=[-1.57084047  2.64306009 -1.5707889 ], -likelihood = -1090.47129
# Iteration=19, theta_new=[-1.57082871  2.64323206 -1.5707849 ], -likelihood = -1090.47074
# Iteration=20, theta_new=[-1.57075128  2.64338485 -1.57079478], -likelihood = -1090.47016
# 21-th start
# Iteration=1, theta_new=[-0.0120382  -2.89145147 -1.40039999], -likelihood = -1038.02357
# Iteration=2, theta_new=[-0.0070313  -2.89552689 -1.46273255], -likelihood = -1060.15189
# Iteration=3, theta_new=[-1.70603898e-03 -2.89987676e+00 -1.57075125e+00], -likelihood = -1072.70678
# Iteration=4, theta_new=[ 0.00371597 -2.90470758 -1.57081622], -likelihood = -1077.10241
# Iteration=5, theta_new=[ 0.00920019 -2.909576   -1.57082661], -likelihood = -1077.96633
# Iteration=6, theta_new=[ 0.0146929  -2.91441807 -1.57083379], -likelihood = -1078.84542
# Iteration=7, theta_new=[ 0.02015361 -2.9192158  -1.57085193], -likelihood = -1079.72137
# Iteration=8, theta_new=[ 0.02554415 -2.92391226 -1.57084044], -likelihood = -1080.58156
# Iteration=9, theta_new=[ 0.03081388 -2.92848434 -1.57076229], -likelihood = -1081.41077
# Iteration=10, theta_new=[ 0.03594414 -2.93292635 -1.57078849], -likelihood = -1082.19766
# Iteration=11, theta_new=[ 0.04091958 -2.93716612 -1.57081335], -likelihood = -1082.93644
# Iteration=12, theta_new=[ 0.0457089  -2.94122404 -1.57077285], -likelihood = -1083.61737
# Iteration=13, theta_new=[ 0.05027844 -2.94507585 -1.57080965], -likelihood = -1084.23970
# Iteration=14, theta_new=[ 0.05459628 -2.94873359 -1.57077103], -likelihood = -1084.80031
# Iteration=15, theta_new=[ 0.05869564 -2.95215054 -1.57083501], -likelihood = -1085.30061
# Iteration=16, theta_new=[ 0.06257502 -2.95540363 -1.57079553], -likelihood = -1085.74211
# Iteration=17, theta_new=[ 0.06622277 -2.95844872 -1.57081287], -likelihood = -1086.13348
# Iteration=18, theta_new=[ 0.06964495 -2.9612961  -1.57074052], -likelihood = -1086.47487
# Iteration=19, theta_new=[ 0.07280783 -2.9639751  -1.57088478], -likelihood = -1086.77119
# Iteration=20, theta_new=[ 0.07577131 -2.96643505 -1.57076442], -likelihood = -1087.02686
# 22-th start
# Iteration=1, theta_new=[-2.20952788 -1.82476871  2.32904559], -likelihood = -1022.17367
# Iteration=2, theta_new=[-2.24217856 -1.78574969  2.31112894], -likelihood = -1062.22206
# Iteration=3, theta_new=[-2.26626299 -1.75451401  2.29461052], -likelihood = -1079.64568
# Iteration=4, theta_new=[-2.28554462 -1.73003278  2.27922451], -likelihood = -1088.37188
# Iteration=5, theta_new=[-2.30216728 -1.71198999  2.26469608], -likelihood = -1093.26770
# Iteration=6, theta_new=[-2.31733445 -1.70035723  2.25086979], -likelihood = -1096.37791
# Iteration=7, theta_new=[-2.33191267 -1.69482637  2.23751551], -likelihood = -1098.65385
# Iteration=8, theta_new=[-2.34613224 -1.69472674  2.22451028], -likelihood = -1100.59661
# Iteration=9, theta_new=[-2.36027153 -1.69893343  2.21178026], -likelihood = -1102.43726
# Iteration=10, theta_new=[-2.37428061 -1.70619685  2.19920353], -likelihood = -1104.30498
# Iteration=11, theta_new=[-2.38813419 -1.71551937  2.18676576], -likelihood = -1106.23685
# Iteration=12, theta_new=[-2.40170833 -1.72603762  2.17446567], -likelihood = -1108.23682
# Iteration=13, theta_new=[-2.41470124 -1.73720631  2.16232621], -likelihood = -1110.27462
# Iteration=14, theta_new=[-2.42707998 -1.74864853  2.15036147], -likelihood = -1112.29330
# Iteration=15, theta_new=[-2.43872785 -1.76004612  2.13865112], -likelihood = -1114.26100
# Iteration=16, theta_new=[-2.44947253 -1.77123499  2.12720432], -likelihood = -1116.13505
# Iteration=17, theta_new=[-2.45930848 -1.78220065  2.11607561], -likelihood = -1117.87791
# Iteration=18, theta_new=[-2.46823137 -1.79274471  2.10529765], -likelihood = -1119.48065
# Iteration=19, theta_new=[-2.47633798 -1.80290954  2.0949265 ], -likelihood = -1120.92774
# Iteration=20, theta_new=[-2.48361489 -1.81274017  2.08500826], -likelihood = -1122.22948
# 23-th start
# Iteration=1, theta_new=[-1.57079658  2.87205023 -2.20941807], -likelihood = -789.09884
# Iteration=2, theta_new=[-1.57073395  2.86404003 -2.16689024], -likelihood = -800.25064
# Iteration=3, theta_new=[-1.57080388  2.85675404 -2.11423261], -likelihood = -815.88164
# Iteration=4, theta_new=[-1.57076238  2.849979   -2.0549183 ], -likelihood = -838.84520
# Iteration=5, theta_new=[-1.5707874   2.84289699 -1.99293323], -likelihood = -869.86539
# Iteration=6, theta_new=[-1.5707932   2.8343614  -1.93127014], -likelihood = -907.51827
# Iteration=7, theta_new=[-1.57075129  2.82363309 -1.87148925], -likelihood = -947.18544
# Iteration=8, theta_new=[-1.5708206   2.81071775 -1.81377497], -likelihood = -983.43258
# Iteration=9, theta_new=[-1.57081175  2.79622782 -1.75680947], -likelihood = -1013.16770
# Iteration=10, theta_new=[-1.57078257  2.78105614 -1.69623365], -likelihood = -1036.08698
# Iteration=11, theta_new=[-1.57081868  2.7660577  -1.60580529], -likelihood = -1053.30532
# Iteration=12, theta_new=[-1.57083117  2.75189086 -1.57078462], -likelihood = -1064.03330
# Iteration=13, theta_new=[-1.57078355  2.73879138 -1.57079123], -likelihood = -1069.43577
# Iteration=14, theta_new=[-1.57077446  2.72690149 -1.57077745], -likelihood = -1073.96501
# Iteration=15, theta_new=[-1.57078284  2.71627763 -1.57079454], -likelihood = -1077.68559
# Iteration=16, theta_new=[-1.57084907  2.70688059 -1.57080393], -likelihood = -1080.65372
# Iteration=17, theta_new=[-1.57084552  2.6986353  -1.57080339], -likelihood = -1082.97561
# Iteration=18, theta_new=[-1.570824    2.69144569 -1.57080015], -likelihood = -1084.76597
# Iteration=19, theta_new=[-1.57080515  2.68519056 -1.57079548], -likelihood = -1086.13254
# Iteration=20, theta_new=[-1.57081789  2.67975514 -1.57078424], -likelihood = -1087.17109
# 24-th start
# Iteration=1, theta_new=[ 1.25377497 -1.05167917  2.94970885], -likelihood = -867.24933
# Iteration=2, theta_new=[ 1.24814267 -1.10821069  2.94562055], -likelihood = -906.36482
# Iteration=3, theta_new=[ 1.23439095 -1.15909533  2.94193852], -likelihood = -940.77974
# Iteration=4, theta_new=[ 1.21573999 -1.2041297   2.93877166], -likelihood = -970.12179
# Iteration=5, theta_new=[ 1.19471258 -1.24355671  2.93594272], -likelihood = -993.88265
# Iteration=6, theta_new=[ 1.17297751 -1.27785867  2.93327913], -likelihood = -1012.26365
# Iteration=7, theta_new=[ 1.15183007 -1.30752839  2.93061528], -likelihood = -1026.14560
# Iteration=8, theta_new=[ 1.13171972 -1.33318237  2.92784051], -likelihood = -1036.53013
# Iteration=9, theta_new=[ 1.11308191 -1.3553577   2.92486122], -likelihood = -1044.42707
# Iteration=10, theta_new=[ 1.09591057 -1.37469724  2.9216267 ], -likelihood = -1050.54153
# Iteration=11, theta_new=[ 1.08028846 -1.39165314  2.91806178], -likelihood = -1055.42997
# Iteration=12, theta_new=[ 1.06616345 -1.40670221  2.91415591], -likelihood = -1059.43206
# Iteration=13, theta_new=[ 1.05342703 -1.42022376  2.90981812], -likelihood = -1062.79322
# Iteration=14, theta_new=[ 1.04194009 -1.43254643  2.90501811], -likelihood = -1065.69859
# Iteration=15, theta_new=[ 1.03166394 -1.44395798  2.89968289], -likelihood = -1068.28773
# Iteration=16, theta_new=[ 1.02248486 -1.45469781  2.89376985], -likelihood = -1070.66286
# Iteration=17, theta_new=[ 1.01427467 -1.46507594  2.88716237], -likelihood = -1072.92385
# Iteration=18, theta_new=[ 1.00693429 -1.47533625  2.87980064], -likelihood = -1075.17982
# Iteration=19, theta_new=[ 1.00038528 -1.48573326  2.87161268], -likelihood = -1077.53070
# Iteration=20, theta_new=[ 0.99460315 -1.4966869   2.86247924], -likelihood = -1080.08262
# 25-th start
# Iteration=1, theta_new=[-1.57081926 -2.01429773 -0.0840684 ], -likelihood = -853.33657
# Iteration=2, theta_new=[-1.57076204 -1.95431676 -0.0860397 ], -likelihood = -887.44769
# Iteration=3, theta_new=[-1.57078447 -1.89651023 -0.08848222], -likelihood = -920.71144
# Iteration=4, theta_new=[-1.57078833 -1.84118387 -0.09105689], -likelihood = -950.03911
# Iteration=5, theta_new=[-1.57081855 -1.7875592  -0.09360429], -likelihood = -972.98175
# Iteration=6, theta_new=[-1.57080793 -1.73344074 -0.09604968], -likelihood = -989.47809
# Iteration=7, theta_new=[-1.57069522 -1.67272735 -0.09836076], -likelihood = -1000.74169
# Iteration=8, theta_new=[-1.57074341 -1.57079355 -0.10053013], -likelihood = -1008.13508
# Iteration=9, theta_new=[-1.57077783 -1.57080764 -0.10245922], -likelihood = -1010.52528
# Iteration=10, theta_new=[-1.5707668  -1.57077284 -0.10430571], -likelihood = -1010.62366
# Iteration=11, theta_new=[-1.57073927 -1.57078078 -0.10606667], -likelihood = -1010.71446
# Iteration=12, theta_new=[-1.57083111 -1.57078228 -0.10773639], -likelihood = -1010.79781
# Iteration=13, theta_new=[-1.57080457 -1.57080594 -0.10932594], -likelihood = -1010.87378
# Iteration=14, theta_new=[-1.5708056  -1.57079754 -0.11083971], -likelihood = -1010.94322
# Iteration=15, theta_new=[-1.57079269 -1.57077552 -0.11226423], -likelihood = -1011.00664
# Iteration=16, theta_new=[-1.57081598 -1.57080169 -0.11361225], -likelihood = -1011.06382
# Iteration=17, theta_new=[-1.57076152 -1.57079613 -0.11488984], -likelihood = -1011.11562
# Iteration=18, theta_new=[-1.5707744  -1.57080112 -0.11609164], -likelihood = -1011.16260
# Iteration=19, theta_new=[-1.57078895 -1.57079103 -0.11723285], -likelihood = -1011.20486
# Iteration=20, theta_new=[-1.57077734 -1.57079595 -0.11830049], -likelihood = -1011.24321
# 26-th start
# Iteration=1, theta_new=[ 1.76511669  1.255695   -1.28389154], -likelihood = -1012.35682
# Iteration=2, theta_new=[ 1.81812732  1.21911383 -1.26847484], -likelihood = -1038.47322
# Iteration=3, theta_new=[ 1.85147267  1.19449492 -1.26048701], -likelihood = -1050.05579
# Iteration=4, theta_new=[ 1.87369688  1.17644897 -1.25699045], -likelihood = -1056.02454
# Iteration=5, theta_new=[ 1.88869855  1.16243768 -1.25633676], -likelihood = -1059.48795
# Iteration=6, theta_new=[ 1.89880563  1.15111115 -1.2575375 ], -likelihood = -1061.71016
# Iteration=7, theta_new=[ 1.90526001  1.14160717 -1.25990061], -likelihood = -1063.26343
# Iteration=8, theta_new=[ 1.90892694  1.13337847 -1.26298846], -likelihood = -1064.43492
# Iteration=9, theta_new=[ 1.91039872  1.12607455 -1.26652713], -likelihood = -1065.37497
# Iteration=10, theta_new=[ 1.91018895  1.11951476 -1.27033897], -likelihood = -1066.16558
# Iteration=11, theta_new=[ 1.9086198   1.11349326 -1.27427106], -likelihood = -1066.84910
# Iteration=12, theta_new=[ 1.90606446  1.10792437 -1.27823564], -likelihood = -1067.45794
# Iteration=13, theta_new=[ 1.9026742   1.102733   -1.28219652], -likelihood = -1068.00721
# Iteration=14, theta_new=[ 1.89877086  1.09786296 -1.2860769 ], -likelihood = -1068.50751
# Iteration=15, theta_new=[ 1.89450145  1.0932973  -1.28988071], -likelihood = -1068.96601
# Iteration=16, theta_new=[ 1.89007196  1.08900831 -1.29357282], -likelihood = -1069.38580
# Iteration=17, theta_new=[ 1.88568851  1.08498892 -1.29715335], -likelihood = -1069.77038
# Iteration=18, theta_new=[ 1.88134394  1.08119652 -1.30059715], -likelihood = -1070.12181
# Iteration=19, theta_new=[ 1.8772594   1.07763163 -1.30389543], -likelihood = -1070.44432
# Iteration=20, theta_new=[ 1.87344067  1.07428827 -1.30706336], -likelihood = -1070.73950
# 27-th start
# Iteration=1, theta_new=[ 2.76728018  2.41953781 -3.09027782], -likelihood = -325.48964
# Iteration=2, theta_new=[ 2.76306956  2.42846174 -3.09126121], -likelihood = -327.05656
# Iteration=3, theta_new=[ 2.75961739  2.43888844 -3.09214369], -likelihood = -329.12407
# Iteration=4, theta_new=[ 2.75715359  2.45031792 -3.09299887], -likelihood = -331.67443
# Iteration=5, theta_new=[ 2.75597774  2.46207643 -3.09391879], -likelihood = -334.54660
# Iteration=6, theta_new=[ 2.75617455  2.47359088 -3.09502466], -likelihood = -337.49811
# Iteration=7, theta_new=[ 2.7577074   2.48445036 -3.09636292], -likelihood = -340.33861
# Iteration=8, theta_new=[ 2.76047539  2.49431291 -3.09799075], -likelihood = -342.96373
# Iteration=9, theta_new=[ 2.7642941   2.50322141 -3.09992837], -likelihood = -345.32651
# Iteration=10, theta_new=[ 2.76893791  2.5111207  -3.10220861], -likelihood = -347.47625
# Iteration=11, theta_new=[ 2.77411246  2.51816509 -3.10478967], -likelihood = -349.43462
# Iteration=12, theta_new=[ 2.77958721  2.524433   -3.10763911], -likelihood = -351.24058
# Iteration=13, theta_new=[ 2.78528869  2.52998542 -3.11070137], -likelihood = -352.91056
# Iteration=14, theta_new=[ 2.79097313  2.53501158 -3.11391309], -likelihood = -354.46209
# Iteration=15, theta_new=[ 2.79658114  2.5394901  -3.11725527], -likelihood = -355.90490
# Iteration=16, theta_new=[ 2.80193356  2.54351009 -3.12066932], -likelihood = -357.23593
# Iteration=17, theta_new=[ 2.80697466  2.54709466 -3.12402495], -likelihood = -358.45093
# Iteration=18, theta_new=[ 2.81171783  2.55029184 -3.12727445], -likelihood = -359.53976
# Iteration=19, theta_new=[ 2.8160301   2.55317668 -3.13034731], -likelihood = -360.50776
# Iteration=20, theta_new=[ 2.82004107  2.55576017 -3.13320246], -likelihood = -361.35140
# 28-th start
# Iteration=1, theta_new=[-3.00756477  2.93969235 -2.50216145], -likelihood = -329.19897
# Iteration=2, theta_new=[-3.01878834  2.93376812 -2.50645792], -likelihood = -332.43134
# Iteration=3, theta_new=[-3.03032394  2.92781294 -2.50987517], -likelihood = -335.54793
# Iteration=4, theta_new=[-3.04168352  2.92191671 -2.51262285], -likelihood = -338.57765
# Iteration=5, theta_new=[-3.05253191  2.91617    -2.51490845], -likelihood = -341.42976
# Iteration=6, theta_new=[-3.06269346  2.9105742  -2.51675176], -likelihood = -344.02692
# Iteration=7, theta_new=[-3.07196804  2.90518676 -2.51837579], -likelihood = -346.32553
# Iteration=8, theta_new=[-3.08033011  2.89997949 -2.51972508], -likelihood = -348.30661
# Iteration=9, theta_new=[-3.08778216  2.89498938 -2.52088476], -likelihood = -349.98305
# Iteration=10, theta_new=[-3.09437596  2.8901948  -2.52192672], -likelihood = -351.38341
# Iteration=11, theta_new=[-3.10015085  2.88557676 -2.52280565], -likelihood = -352.54955
# Iteration=12, theta_new=[-3.10521582  2.88120442 -2.52356849], -likelihood = -353.51369
# Iteration=13, theta_new=[-3.10961477  2.8769998  -2.52419643], -likelihood = -354.30946
# Iteration=14, theta_new=[-3.11358488  2.8729372  -2.52473634], -likelihood = -354.96880
# Iteration=15, theta_new=[-3.1170014   2.86909455 -2.52514363], -likelihood = -355.53044
# Iteration=16, theta_new=[-3.11997237  2.86538828 -2.52548205], -likelihood = -355.99391
# Iteration=17, theta_new=[-3.12258754  2.86181753 -2.52577959], -likelihood = -356.38730
# Iteration=18, theta_new=[-3.12493391  2.85841124 -2.52602535], -likelihood = -356.72625
# Iteration=19, theta_new=[-3.12698221  2.85513855 -2.52619462], -likelihood = -357.02031
# Iteration=20, theta_new=[-3.12876024  2.85194234 -2.52626907], -likelihood = -357.27571
# 29-th start
# Iteration=1, theta_new=[-0.32246536  2.84293113 -0.1329059 ], -likelihood = -278.20458
# Iteration=2, theta_new=[-0.32732488  2.83452223 -0.12720204], -likelihood = -281.74001
# Iteration=3, theta_new=[-0.33059419  2.82632761 -0.12217846], -likelihood = -284.62788
# Iteration=4, theta_new=[-0.33276891  2.81829233 -0.11769466], -likelihood = -287.16432
# Iteration=5, theta_new=[-0.3341229   2.81039294 -0.11359559], -likelihood = -289.49391
# Iteration=6, theta_new=[-0.33480134  2.80262863 -0.10977642], -likelihood = -291.69735
# Iteration=7, theta_new=[-0.33493896  2.79488816 -0.10618321], -likelihood = -293.81966
# Iteration=8, theta_new=[-0.33463199  2.78721263 -0.10273058], -likelihood = -295.91572
# Iteration=9, theta_new=[-0.33392808  2.7795397  -0.09933154], -likelihood = -297.99927
# Iteration=10, theta_new=[-0.3328342   2.77185039 -0.09600828], -likelihood = -300.10596
# Iteration=11, theta_new=[-0.33150242  2.76412957 -0.09279557], -likelihood = -302.25353
# Iteration=12, theta_new=[-0.32993931  2.75630903 -0.08956069], -likelihood = -304.45045
# Iteration=13, theta_new=[-0.32808775  2.74832661 -0.08637517], -likelihood = -306.73234
# Iteration=14, theta_new=[-0.32601467  2.74019094 -0.08316337], -likelihood = -309.12344
# Iteration=15, theta_new=[-0.32370854  2.73187582 -0.07990365], -likelihood = -311.63105
# Iteration=16, theta_new=[-0.32115936  2.72334453 -0.07665751], -likelihood = -314.26911
# Iteration=17, theta_new=[-0.3185499   2.71468805 -0.07337906], -likelihood = -317.04543
# Iteration=18, theta_new=[-0.31568621  2.70591404 -0.07012182], -likelihood = -319.92025
# Iteration=19, theta_new=[-0.31272542  2.69703259 -0.06688313], -likelihood = -322.88755
# Iteration=20, theta_new=[-0.30960861  2.68811123 -0.06359127], -likelihood = -325.91448

# %%
np.rad2deg(EM_theta3_rad)
# Out:
# array([-57.21971209,  33.39098506,  76.54549077])

# %% [markdown]
# ## True result

# %%
np.rad2deg(theta3_rad)
# Out:
# array([28.64788976, 68.75493542, 91.67324722])

# %% [markdown]
# # Case 4

# %% [markdown]
# Имеется 7 датчиков, 3 источника (дисперсии сигналов - 0.5, 0.5 и 0.5), и шум на каждом датчике имеет дисперсию 1.1.

# %%
Num_sensors4 = 7
Num_emitters4 = 3
sample_size4 = 100
theta4_rad = [0.5, 1.1, -0.3] # Направление прибытия (DOA) в радианах
GS_4 = np.diag([0.5, 0.5, 0.5]) # Ковариация сигнала
GN_4 = 1.1*np.eye(7, dtype=np.float64) # Ковариация шума
A4 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors4).reshape(-1,1) * np.sin(theta4_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s4 = CN(Num_emitters4, sample_size4, GS_4)
n4 = CN(Num_sensors4, sample_size4, GN_4)
X4 = (A4 @ s4.T + n4.T).T

# %% [markdown]
# ## ML1

# %%
theta_ML1_Case4, ML1_func_val_Case4 = multi_start_ML1(X4, L=Num_sensors4, M=Num_emitters4, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
np.rad2deg(theta_ML1_Case4)
# Out:
# array([ 63.70182371,  29.26391723, -16.83244179])

# %% [markdown]
# ## ML2

# %%
theta_ML2_Case4, ML2_func_val_Case4 = multi_start_ML2(X4, GS_4, GN_4, method='CG')
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
np.rad2deg(theta_ML2_Case4)
# Out:
# array([-16.80476507,  29.23867373,  63.71412425])

# %% [markdown]
# ## EM

# %%
EM_theta4_rad, neglhd_4, K4, mu4 = multi_start_EM(X4, GS_4, GN_4, 30, max_iter=20, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[-0.84722277  1.93215421  1.38309335], -likelihood = -537.82591
# Iteration=2, theta_new=[-0.8459026   1.99451153  1.48109374], -likelihood = -579.83935
# Iteration=3, theta_new=[-0.83944142  2.03047896  1.57077196], -likelihood = -618.81225
# Iteration=4, theta_new=[-0.83206531  2.05531716  1.57083689], -likelihood = -635.49397
# Iteration=5, theta_new=[-0.82531497  2.07421447  1.57080311], -likelihood = -644.28424
# Iteration=6, theta_new=[-0.81944663  2.08883128  1.57083205], -likelihood = -649.65809
# Iteration=7, theta_new=[-0.81445639  2.10026823  1.57076955], -likelihood = -652.96765
# Iteration=8, theta_new=[-0.81025832  2.10930487  1.57066991], -likelihood = -655.02444
# Iteration=9, theta_new=[-0.80675212  2.11649028  1.57081021], -likelihood = -656.31484
# Iteration=10, theta_new=[-0.80382809  2.12223697  1.5708123 ], -likelihood = -657.12952
# Iteration=11, theta_new=[-0.80138711  2.126848    1.57075147], -likelihood = -657.64654
# Iteration=12, theta_new=[-0.79932447  2.13050621  1.5477326 ], -likelihood = -657.97649
# Iteration=13, theta_new=[-0.79757236  2.13345532  1.61032302], -likelihood = -658.16608
# Iteration=14, theta_new=[-0.79607744  2.13588983  1.62479644], -likelihood = -658.26812
# Iteration=15, theta_new=[-0.79480198  2.13794514  1.63764478], -likelihood = -658.31931
# Iteration=16, theta_new=[-0.79371753  2.13972763  1.64903397], -likelihood = -658.34059
# Iteration=17, theta_new=[-0.79278126  2.14131103  1.65933493], -likelihood = -658.34504
# Iteration=18, theta_new=[-0.79197897  2.142757    1.66863264], -likelihood = -658.33914
# Iteration=19, theta_new=[-0.79130677  2.14408608  1.67706411], -likelihood = -658.32822
# Iteration=20, theta_new=[-0.79073286  2.1453192   1.6847609 ], -likelihood = -658.31479
# 1-th start
# Iteration=1, theta_new=[-2.58074139 -1.04719766 -2.76880008], -likelihood = -578.75572
# Iteration=2, theta_new=[-2.56949053 -1.07774391 -2.78168696], -likelihood = -601.78361
# Iteration=3, theta_new=[-2.56134766 -1.12369551 -2.79257608], -likelihood = -622.70036
# Iteration=4, theta_new=[-2.55618954 -1.19285364 -2.80219209], -likelihood = -652.96642
# Iteration=5, theta_new=[-2.55429456 -1.29190851 -2.81116782], -likelihood = -704.32702
# Iteration=6, theta_new=[-2.55559869 -1.44527046 -2.81959491], -likelihood = -777.28236
# Iteration=7, theta_new=[-2.56031761 -1.5708388  -2.82712969], -likelihood = -839.69517
# Iteration=8, theta_new=[-2.56625797 -1.57085755 -2.8336147 ], -likelihood = -850.80287
# Iteration=9, theta_new=[-2.57257583 -1.57084129 -2.83915069], -likelihood = -855.06997
# Iteration=10, theta_new=[-2.57908693 -1.57079832 -2.84391148], -likelihood = -858.56946
# Iteration=11, theta_new=[-2.58565399 -1.57075436 -2.84802628], -likelihood = -861.48053
# Iteration=12, theta_new=[-2.59214506 -1.57086094 -2.8516204 ], -likelihood = -863.92479
# Iteration=13, theta_new=[-2.59845782 -1.57076931 -2.85479773], -likelihood = -865.98865
# Iteration=14, theta_new=[-2.60453771 -1.57080214 -2.85764115], -likelihood = -867.73399
# Iteration=15, theta_new=[-2.61033025 -1.57077912 -2.86019434], -likelihood = -869.21044
# Iteration=16, theta_new=[-2.61579935 -1.57081514 -2.86254397], -likelihood = -870.45103
# Iteration=17, theta_new=[-2.62093426 -1.57083111 -2.864687  ], -likelihood = -871.49259
# Iteration=18, theta_new=[-2.62576382 -1.57076715 -2.86667692], -likelihood = -872.35736
# Iteration=19, theta_new=[-2.63028954 -1.57072291 -2.86852351], -likelihood = -873.07638
# Iteration=20, theta_new=[-2.63448082 -1.57081754 -2.87025968], -likelihood = -873.66865
# 2-th start
# Iteration=1, theta_new=[-0.61627096 -0.41091845 -0.3136384 ], -likelihood = -553.57621
# Iteration=2, theta_new=[-0.63045779 -0.41868475 -0.29621085], -likelihood = -587.37296
# Iteration=3, theta_new=[-0.64667063 -0.42379567 -0.28266813], -likelihood = -612.84933
# Iteration=4, theta_new=[-0.66250624 -0.42713379 -0.27204439], -likelihood = -631.01357
# Iteration=5, theta_new=[-0.67680572 -0.42920289 -0.26366929], -likelihood = -643.23654
# Iteration=6, theta_new=[-0.68925041 -0.4304411  -0.25706128], -likelihood = -651.06726
# Iteration=7, theta_new=[-0.69983998 -0.43098219 -0.25186899], -likelihood = -655.93526
# Iteration=8, theta_new=[-0.70868537 -0.43104605 -0.24779511], -likelihood = -658.87662
# Iteration=9, theta_new=[-0.71605629 -0.43078093 -0.24456263], -likelihood = -660.61375
# Iteration=10, theta_new=[-0.72209627 -0.43022294 -0.24194398], -likelihood = -661.62309
# Iteration=11, theta_new=[-0.72703877 -0.4295165  -0.23984031], -likelihood = -662.18443
# Iteration=12, theta_new=[-0.73108155 -0.4286791  -0.2381356 ], -likelihood = -662.47636
# Iteration=13, theta_new=[-0.73437446 -0.42779393 -0.23671792], -likelihood = -662.60605
# Iteration=14, theta_new=[-0.73697312 -0.42689546 -0.23555928], -likelihood = -662.64321
# Iteration=15, theta_new=[-0.73910141 -0.42591866 -0.23457498], -likelihood = -662.62678
# Iteration=16, theta_new=[-0.74084038 -0.4250385  -0.23368637], -likelihood = -662.57735
# Iteration=17, theta_new=[-0.74222856 -0.42416148 -0.23295193], -likelihood = -662.51851
# Iteration=18, theta_new=[-0.74329957 -0.42325917 -0.2322756 ], -likelihood = -662.45142
# Iteration=19, theta_new=[-0.7441045  -0.42242529 -0.2316841 ], -likelihood = -662.38096
# Iteration=20, theta_new=[-0.74472922 -0.42163185 -0.2311388 ], -likelihood = -662.31490
# 3-th start
# Iteration=1, theta_new=[-1.57081648 -2.68945218 -2.18214449], -likelihood = -675.28355
# Iteration=2, theta_new=[-1.57073813 -2.71559458 -2.19254848], -likelihood = -719.84615
# Iteration=3, theta_new=[-1.57079627 -2.74001904 -2.19964953], -likelihood = -757.00175
# Iteration=4, theta_new=[-1.5709325  -2.76169465 -2.20438688], -likelihood = -793.28086
# Iteration=5, theta_new=[-1.57082822 -2.78024383 -2.20758951], -likelihood = -824.49422
# Iteration=6, theta_new=[-1.57080053 -2.79564006 -2.20992545], -likelihood = -848.68885
# Iteration=7, theta_new=[-1.57076905 -2.80818486 -2.21176828], -likelihood = -865.92263
# Iteration=8, theta_new=[-1.57077595 -2.81829577 -2.21332405], -likelihood = -877.51446
# Iteration=9, theta_new=[-1.57080635 -2.82636652 -2.21473073], -likelihood = -885.01484
# Iteration=10, theta_new=[-1.57077682 -2.83278196 -2.21593518], -likelihood = -889.71421
# Iteration=11, theta_new=[-1.57082639 -2.83786745 -2.21703502], -likelihood = -892.60254
# Iteration=12, theta_new=[-1.57082559 -2.8418995  -2.21801903], -likelihood = -894.33315
# Iteration=13, theta_new=[-1.57082626 -2.84507014 -2.2188892 ], -likelihood = -895.34623
# Iteration=14, theta_new=[-1.5707874  -2.84759227 -2.2196547 ], -likelihood = -895.91421
# Iteration=15, theta_new=[-1.57076314 -2.84956691 -2.22030485], -likelihood = -896.21969
# Iteration=16, theta_new=[-1.57078859 -2.85112637 -2.2208633 ], -likelihood = -896.36726
# Iteration=17, theta_new=[-1.57083032 -2.85235399 -2.22137878], -likelihood = -896.42483
# Iteration=18, theta_new=[-1.57095091 -2.85331762 -2.22180849], -likelihood = -896.42638
# Iteration=19, theta_new=[-1.57076736 -2.85408106 -2.22217232], -likelihood = -896.40373
# Iteration=20, theta_new=[-1.57069378 -2.85467124 -2.22248491], -likelihood = -896.36965
# 4-th start
# Iteration=1, theta_new=[-2.18936171 -1.20100146  0.81644524], -likelihood = -410.26360
# Iteration=2, theta_new=[-2.21225822 -1.2655204   0.83081952], -likelihood = -589.31766
# Iteration=3, theta_new=[-2.22673586 -1.32776123  0.84473274], -likelihood = -623.15004
# Iteration=4, theta_new=[-2.23742843 -1.39461626  0.85781475], -likelihood = -639.87134
# Iteration=5, theta_new=[-2.24599909 -1.4821242   0.86954031], -likelihood = -649.55996
# Iteration=6, theta_new=[-2.2529779  -1.57077426  0.87893282], -likelihood = -654.33780
# Iteration=7, theta_new=[-2.2591198  -1.57075031  0.88745866], -likelihood = -654.55620
# Iteration=8, theta_new=[-2.26486578 -1.57081796  0.89612267], -likelihood = -654.96964
# Iteration=9, theta_new=[-2.27029901 -1.5707458   0.90472159], -likelihood = -655.44786
# Iteration=10, theta_new=[-2.27546074 -1.57074545  0.91309708], -likelihood = -655.95415
# Iteration=11, theta_new=[-2.28039957 -1.57076174  0.92111457], -likelihood = -656.45661
# Iteration=12, theta_new=[-2.28513383 -1.57080475  0.9286771 ], -likelihood = -656.92935
# Iteration=13, theta_new=[-2.28967075 -1.57077686  0.93570081], -likelihood = -657.35524
# Iteration=14, theta_new=[-2.29399418 -1.5708206   0.94215532], -likelihood = -657.72387
# Iteration=15, theta_new=[-2.29810289 -1.57074374  0.94804901], -likelihood = -658.03301
# Iteration=16, theta_new=[-2.30201043 -1.57076793  0.95338211], -likelihood = -658.28548
# Iteration=17, theta_new=[-2.30570738 -1.57083207  0.95816864], -likelihood = -658.48546
# Iteration=18, theta_new=[-2.3091941  -1.5707777   0.96244639], -likelihood = -658.63905
# Iteration=19, theta_new=[-2.31247039 -1.57077209  0.96625224], -likelihood = -658.75346
# Iteration=20, theta_new=[-2.31555053 -1.57081763  0.96962413], -likelihood = -658.83542
# 5-th start
# Iteration=1, theta_new=[-1.13640759  1.30592066 -1.57074926], -likelihood = -466.80855
# Iteration=2, theta_new=[-1.1003314   1.23899966 -1.57085076], -likelihood = -535.02575
# Iteration=3, theta_new=[-1.07175594  1.19399496 -1.57085348], -likelihood = -559.82235
# Iteration=4, theta_new=[-1.04559706  1.15942487 -1.57077147], -likelihood = -576.18123
# Iteration=5, theta_new=[-1.02007778  1.13108644 -1.57079363], -likelihood = -589.73191
# Iteration=6, theta_new=[-0.99483053  1.10689482 -1.59597099], -likelihood = -602.24486
# Iteration=7, theta_new=[-0.97030362  1.08612373 -1.53086888], -likelihood = -614.20395
# Iteration=8, theta_new=[-0.9473196   1.06848968 -1.61985751], -likelihood = -625.18077
# Iteration=9, theta_new=[-0.92654041  1.05374995 -1.62386811], -likelihood = -634.50516
# Iteration=10, theta_new=[-0.90825883  1.04158658 -1.62303155], -likelihood = -641.82371
# Iteration=11, theta_new=[-0.89245622  1.03165185 -1.61703629], -likelihood = -647.21687
# Iteration=12, theta_new=[-0.87891372  1.02358294 -1.60410504], -likelihood = -651.01735
# Iteration=13, theta_new=[-0.86736915  1.01700149 -1.57080292], -likelihood = -653.62247
# Iteration=14, theta_new=[-0.85756395  1.01151472 -1.57081256], -likelihood = -655.37997
# Iteration=15, theta_new=[-0.84917668  1.0071423  -1.57082693], -likelihood = -656.62418
# Iteration=16, theta_new=[-0.84198672  1.00368228 -1.57078931], -likelihood = -657.44983
# Iteration=17, theta_new=[-0.83579464  1.00095959 -1.57082833], -likelihood = -657.99196
# Iteration=18, theta_new=[-0.83045034  0.99882514 -1.57081116], -likelihood = -658.34398
# Iteration=19, theta_new=[-0.82582005  0.99717401 -1.57080288], -likelihood = -658.56867
# Iteration=20, theta_new=[-0.82178325  0.99590633 -1.5708101 ], -likelihood = -658.70786
# 6-th start
# Iteration=1, theta_new=[-0.70426199 -1.33018978  0.67270291], -likelihood = -586.81219
# Iteration=2, theta_new=[-0.71581483 -1.49123796  0.63764705], -likelihood = -681.30741
# Iteration=3, theta_new=[-0.72731159 -1.57079629  0.60665542], -likelihood = -766.51535
# Iteration=4, theta_new=[-0.73916014 -1.57074651  0.58092907], -likelihood = -815.93648
# Iteration=5, theta_new=[-0.75099761 -1.57083004  0.56060666], -likelihood = -852.70453
# Iteration=6, theta_new=[-0.76249636 -1.57078065  0.54493584], -likelihood = -877.93014
# Iteration=7, theta_new=[-0.77334951 -1.57076931  0.53299816], -likelihood = -894.44173
# Iteration=8, theta_new=[-0.78339145 -1.57080273  0.5239481 ], -likelihood = -905.10374
# Iteration=9, theta_new=[-0.79254713 -1.57076662  0.51710167], -likelihood = -912.05079
# Iteration=10, theta_new=[-0.80081509 -1.57081857  0.51193618], -likelihood = -916.67739
# Iteration=11, theta_new=[-0.80821284 -1.57080785  0.50801509], -likelihood = -919.85011
# Iteration=12, theta_new=[-0.81475122 -1.57086214  0.50506058], -likelihood = -922.10408
# Iteration=13, theta_new=[-0.82049175 -1.57076773  0.50282251], -likelihood = -923.74681
# Iteration=14, theta_new=[-0.82553301 -1.57076731  0.50112141], -likelihood = -924.98083
# Iteration=15, theta_new=[-0.82989435 -1.57083043  0.49982963], -likelihood = -925.93525
# Iteration=16, theta_new=[-0.83367913 -1.5707787   0.49885863], -likelihood = -926.68156
# Iteration=17, theta_new=[-0.83696198 -1.57089431  0.49812892], -likelihood = -927.27748
# Iteration=18, theta_new=[-0.83980111 -1.57084935  0.49756647], -likelihood = -927.76097
# Iteration=19, theta_new=[-0.84225016 -1.57076558  0.49713862], -likelihood = -928.15761
# Iteration=20, theta_new=[-0.84435391 -1.57074635  0.49681395], -likelihood = -928.48504
# 7-th start
# Iteration=1, theta_new=[-1.5707648  -1.06741641  1.33050763], -likelihood = -510.87418
# Iteration=2, theta_new=[-1.57076098 -1.04718607  1.25621785], -likelihood = -540.31579
# Iteration=3, theta_new=[-1.59957063 -1.02841585  1.20495926], -likelihood = -560.82092
# Iteration=4, theta_new=[-1.63988851 -1.00842836  1.16477497], -likelihood = -577.87726
# Iteration=5, theta_new=[-1.6644148  -0.98657647  1.13278623], -likelihood = -593.69490
# Iteration=6, theta_new=[-1.679757   -0.96371931  1.10682675], -likelihood = -608.21151
# Iteration=7, theta_new=[-1.68898716 -0.9413861   1.08559729], -likelihood = -621.12963
# Iteration=8, theta_new=[-1.69370235 -0.92075381  1.06832411], -likelihood = -631.91941
# Iteration=9, theta_new=[-1.69473384 -0.90243842  1.05431854], -likelihood = -640.27408
# Iteration=10, theta_new=[-1.69281067 -0.88660345  1.04304837], -likelihood = -646.34698
# Iteration=11, theta_new=[-1.68827906 -0.87305691  1.03400047], -likelihood = -650.55526
# Iteration=12, theta_new=[-1.68135747 -0.86154657  1.02671166], -likelihood = -653.39126
# Iteration=13, theta_new=[-1.67234571 -0.85177619  1.02082347], -likelihood = -655.27048
# Iteration=14, theta_new=[-1.66117053 -0.84347543  1.01601432], -likelihood = -656.50339
# Iteration=15, theta_new=[-1.64748552 -0.8364289   1.01205867], -likelihood = -657.30749
# Iteration=16, theta_new=[-1.6301557  -0.8304074   1.00875607], -likelihood = -657.82609
# Iteration=17, theta_new=[-1.6045813  -0.82525477  1.00597524], -likelihood = -658.15792
# Iteration=18, theta_new=[-1.57076483 -0.820885    1.00345747], -likelihood = -658.35668
# Iteration=19, theta_new=[-1.57082517 -0.81716971  1.00124679], -likelihood = -658.49912
# Iteration=20, theta_new=[-1.57082444 -0.81394889  0.99951177], -likelihood = -658.63016
# 8-th start
# Iteration=1, theta_new=[ 2.11507448 -0.36781073  1.61528568], -likelihood = -897.37955
# Iteration=2, theta_new=[ 2.1170396  -0.35265542  1.62458968], -likelihood = -917.83574
# Iteration=3, theta_new=[ 2.11843958 -0.34020494  1.638867  ], -likelihood = -932.54015
# Iteration=4, theta_new=[ 2.11955624 -0.33007576  1.6538593 ], -likelihood = -942.73788
# Iteration=5, theta_new=[ 2.12052771 -0.32189905  1.66802643], -likelihood = -949.60680
# Iteration=6, theta_new=[ 2.12145904 -0.31533755  1.6811519 ], -likelihood = -954.12392
# Iteration=7, theta_new=[ 2.12239806 -0.31009012  1.69310945], -likelihood = -957.03499
# Iteration=8, theta_new=[ 2.12338726 -0.30591289  1.70392125], -likelihood = -958.88118
# Iteration=9, theta_new=[ 2.12441355 -0.30259796  1.71372647], -likelihood = -960.03283
# Iteration=10, theta_new=[ 2.12547555 -0.29996273  1.72261658], -likelihood = -960.73956
# Iteration=11, theta_new=[ 2.12658244 -0.29787501  1.73078526], -likelihood = -961.16781
# Iteration=12, theta_new=[ 2.12773224 -0.29622022  1.73822121], -likelihood = -961.42112
# Iteration=13, theta_new=[ 2.12888544 -0.29489785  1.74514478], -likelihood = -961.56859
# Iteration=14, theta_new=[ 2.13006544 -0.29385823  1.7514758 ], -likelihood = -961.65081
# Iteration=15, theta_new=[ 2.13125892 -0.29302536  1.75740468], -likelihood = -961.69514
# Iteration=16, theta_new=[ 2.1324514  -0.29236546  1.76293174], -likelihood = -961.71772
# Iteration=17, theta_new=[ 2.13365588 -0.29185912  1.76803905], -likelihood = -961.72815
# Iteration=18, theta_new=[ 2.13482323 -0.29144529  1.77288356], -likelihood = -961.73375
# Iteration=19, theta_new=[ 2.135992   -0.29111016  1.77739889], -likelihood = -961.73572
# Iteration=20, theta_new=[ 2.13712759 -0.29084933  1.78162271], -likelihood = -961.73887
# 9-th start
# Iteration=1, theta_new=[-2.85908364  2.10050867 -0.08500991], -likelihood = -943.66559
# Iteration=2, theta_new=[-2.8547382   2.08214992 -0.08023101], -likelihood = -957.72601
# Iteration=3, theta_new=[-2.85149517  2.06811635 -0.07630037], -likelihood = -965.86392
# Iteration=4, theta_new=[-2.8490654   2.05746566 -0.07291415], -likelihood = -970.53032
# Iteration=5, theta_new=[-2.84730678  2.04944305 -0.06993181], -likelihood = -973.22800
# Iteration=6, theta_new=[-2.84604823  2.043524   -0.06725128], -likelihood = -974.81006
# Iteration=7, theta_new=[-2.84515962  2.03904418 -0.064768  ], -likelihood = -975.75937
# Iteration=8, theta_new=[-2.84460059  2.03568138 -0.06246344], -likelihood = -976.37518
# Iteration=9, theta_new=[-2.84426354  2.03321934 -0.06020033], -likelihood = -976.80131
# Iteration=10, theta_new=[-2.84414263  2.03139812 -0.05791028], -likelihood = -977.12750
# Iteration=11, theta_new=[-2.84415404  2.03002531 -0.05558905], -likelihood = -977.41092
# Iteration=12, theta_new=[-2.84426841  2.0290496  -0.05319779], -likelihood = -977.67466
# Iteration=13, theta_new=[-2.84451593  2.02825632 -0.05075465], -likelihood = -977.93280
# Iteration=14, theta_new=[-2.84485582  2.02765664 -0.04819159], -likelihood = -978.19823
# Iteration=15, theta_new=[-2.84523139  2.02721238 -0.04552521], -likelihood = -978.47663
# Iteration=16, theta_new=[-2.84566964  2.0268202  -0.04279412], -likelihood = -978.76390
# Iteration=17, theta_new=[-2.84617     2.02661132 -0.03992072], -likelihood = -979.06134
# Iteration=18, theta_new=[-2.84672703  2.02634746 -0.03686787], -likelihood = -979.37308
# Iteration=19, theta_new=[-2.84730632  2.02610884 -0.03379582], -likelihood = -979.70561
# Iteration=20, theta_new=[-2.8479281   2.0258904  -0.03056967], -likelihood = -980.03831
# 10-th start
# Iteration=1, theta_new=[-2.92079417 -0.69992064 -1.24901702], -likelihood = -648.37491
# Iteration=2, theta_new=[-2.90647037 -0.7104727  -1.36474309], -likelihood = -726.07554
# Iteration=3, theta_new=[-2.89527158 -0.71951292 -1.57081643], -likelihood = -798.06577
# Iteration=4, theta_new=[-2.88653417 -0.73006931 -1.57078191], -likelihood = -829.65572
# Iteration=5, theta_new=[-2.8797849  -0.74243541 -1.5708298 ], -likelihood = -837.24516
# Iteration=6, theta_new=[-2.87458099 -0.75655873 -1.57078726], -likelihood = -843.38862
# Iteration=7, theta_new=[-2.87060061 -0.77205911 -1.57075778], -likelihood = -849.09017
# Iteration=8, theta_new=[-2.86756622 -0.78835392 -1.57078869], -likelihood = -854.80328
# Iteration=9, theta_new=[-2.86527144 -0.80472693 -1.57074971], -likelihood = -860.58954
# Iteration=10, theta_new=[-2.86351715 -0.8205523  -1.57076408], -likelihood = -866.25198
# Iteration=11, theta_new=[-2.86220068 -0.83522344 -1.57081744], -likelihood = -871.54551
# Iteration=12, theta_new=[-2.86117692 -0.84843762 -1.57084423], -likelihood = -876.23198
# Iteration=13, theta_new=[-2.86040066 -0.86004506 -1.57079785], -likelihood = -880.22470
# Iteration=14, theta_new=[-2.85976959 -0.87001787 -1.57091146], -likelihood = -883.51698
# Iteration=15, theta_new=[-2.85927478 -0.8785138  -1.57077366], -likelihood = -886.16755
# Iteration=16, theta_new=[-2.85886552 -0.88566081 -1.57083799], -likelihood = -888.28157
# Iteration=17, theta_new=[-2.85853786 -0.8915997  -1.57082183], -likelihood = -889.95166
# Iteration=18, theta_new=[-2.85826795 -0.89648688 -1.57083547], -likelihood = -891.25964
# Iteration=19, theta_new=[-2.85804058 -0.90047447 -1.57082609], -likelihood = -892.27995
# Iteration=20, theta_new=[-2.8578526  -0.90376512 -1.57081712], -likelihood = -893.07411
# 11-th start
# Iteration=1, theta_new=[-1.5707645   1.85849462 -1.96892214], -likelihood = -418.85192
# Iteration=2, theta_new=[-1.57078377  1.91918373 -2.01486383], -likelihood = -533.16152
# Iteration=3, theta_new=[-1.5707844   1.95978596 -2.04926618], -likelihood = -560.51478
# Iteration=4, theta_new=[-1.57083583  1.99109812 -2.07942372], -likelihood = -576.77993
# Iteration=5, theta_new=[-1.57079493  2.01697025 -2.10780343], -likelihood = -589.79271
# Iteration=6, theta_new=[-1.57077333  2.03917178 -2.13512532], -likelihood = -601.78006
# Iteration=7, theta_new=[-1.57082186  2.05850331 -2.16115093], -likelihood = -613.26327
# Iteration=8, theta_new=[-1.56835082  2.07525801 -2.18531235], -likelihood = -623.93397
# Iteration=9, theta_new=[-1.57080127  2.08957705 -2.20706716], -likelihood = -633.20729
# Iteration=10, theta_new=[-1.57083535  2.10160305 -2.22621227], -likelihood = -640.67898
# Iteration=11, theta_new=[-1.57074707  2.11154935 -2.24279997], -likelihood = -646.32596
# Iteration=12, theta_new=[-1.57081776  2.11967433 -2.2570412 ], -likelihood = -650.39608
# Iteration=13, theta_new=[-1.57082955  2.12624944 -2.26922371], -likelihood = -653.23687
# Iteration=14, theta_new=[-1.57077572  2.13152564 -2.27963109], -likelihood = -655.17942
# Iteration=15, theta_new=[-1.57076761  2.13572478 -2.28852874], -likelihood = -656.48863
# Iteration=16, theta_new=[-1.57077358  2.13905305 -2.29616266], -likelihood = -657.36111
# Iteration=17, theta_new=[-1.57075061  2.14165919 -2.30272984], -likelihood = -657.93783
# Iteration=18, theta_new=[-1.57082701  2.14368812 -2.30840061], -likelihood = -658.31366
# Iteration=19, theta_new=[-1.57078057  2.14525148 -2.31331528], -likelihood = -658.55484
# Iteration=20, theta_new=[-1.57079557  2.14644507 -2.31759755], -likelihood = -658.70564
# 12-th start
# Iteration=1, theta_new=[0.26748454 1.88668214 1.07570825], -likelihood = -607.84023
# Iteration=2, theta_new=[0.29982939 1.84810173 1.04864263], -likelihood = -658.00334
# Iteration=3, theta_new=[0.33733314 1.82059136 1.03044112], -likelihood = -718.55963
# Iteration=4, theta_new=[0.3728056  1.80306378 1.0162904 ], -likelihood = -792.95233
# Iteration=5, theta_new=[0.40250028 1.79357767 1.00436069], -likelihood = -865.25783
# Iteration=6, theta_new=[0.42595216 1.78926567 0.99422677], -likelihood = -920.55156
# Iteration=7, theta_new=[0.44405897 1.78784281 0.98566372], -likelihood = -956.80802
# Iteration=8, theta_new=[0.45793343 1.78793792 0.97848725], -likelihood = -978.86577
# Iteration=9, theta_new=[0.46858555 1.78881442 0.97246455], -likelihood = -991.92170
# Iteration=10, theta_new=[0.47679707 1.79021736 0.96740302], -likelihood = -999.65597
# Iteration=11, theta_new=[0.48314205 1.7918231  0.96309698], -likelihood = -1004.29209
# Iteration=12, theta_new=[0.48805968 1.79372374 0.95941107], -likelihood = -1007.11854
# Iteration=13, theta_new=[0.49186252 1.79557792 0.95625708], -likelihood = -1008.87728
# Iteration=14, theta_new=[0.49485793 1.79766064 0.95354064], -likelihood = -1009.99261
# Iteration=15, theta_new=[0.49719723 1.79972678 0.95115047], -likelihood = -1010.72661
# Iteration=16, theta_new=[0.49902215 1.80180083 0.94900005], -likelihood = -1011.22267
# Iteration=17, theta_new=[0.50043952 1.8038576  0.9470796 ], -likelihood = -1011.57211
# Iteration=18, theta_new=[0.50155043 1.80589317 0.94537787], -likelihood = -1011.82604
# Iteration=19, theta_new=[0.50239743 1.80780395 0.94386526], -likelihood = -1012.01691
# Iteration=20, theta_new=[0.50307859 1.80966647 0.94244851], -likelihood = -1012.16449
# 13-th start
# Iteration=1, theta_new=[-0.39752512 -0.20739254 -1.39454684], -likelihood = -798.54454
# Iteration=2, theta_new=[-0.39716091 -0.21075018 -1.57075996], -likelihood = -851.02986
# Iteration=3, theta_new=[-0.39758667 -0.21342066 -1.57076658], -likelihood = -864.21409
# Iteration=4, theta_new=[-0.39837429 -0.21559549 -1.5707974 ], -likelihood = -864.73559
# Iteration=5, theta_new=[-0.399378   -0.21740384 -1.57077963], -likelihood = -865.19316
# Iteration=6, theta_new=[-0.4005484  -0.21892386 -1.57080362], -likelihood = -865.60819
# Iteration=7, theta_new=[-0.40180252 -0.22022234 -1.57077381], -likelihood = -865.99621
# Iteration=8, theta_new=[-0.40310496 -0.22137557 -1.57080963], -likelihood = -866.35970
# Iteration=9, theta_new=[-0.40441088 -0.2224167  -1.57076976], -likelihood = -866.70606
# Iteration=10, theta_new=[-0.40572782 -0.2233555  -1.57081496], -likelihood = -867.03395
# Iteration=11, theta_new=[-0.40702031 -0.22421451 -1.57084736], -likelihood = -867.34667
# Iteration=12, theta_new=[-0.40828822 -0.22501339 -1.57082457], -likelihood = -867.64212
# Iteration=13, theta_new=[-0.40950845 -0.22575508 -1.57079774], -likelihood = -867.92305
# Iteration=14, theta_new=[-0.41069775 -0.22644914 -1.57081995], -likelihood = -868.18680
# Iteration=15, theta_new=[-0.41186754 -0.22710694 -1.57080562], -likelihood = -868.43731
# Iteration=16, theta_new=[-0.4129992  -0.22773559 -1.57078344], -likelihood = -868.67780
# Iteration=17, theta_new=[-0.41407571 -0.22832636 -1.57081183], -likelihood = -868.90661
# Iteration=18, theta_new=[-0.41510805 -0.22887908 -1.57081744], -likelihood = -869.12072
# Iteration=19, theta_new=[-0.41609831 -0.2294093  -1.57074457], -likelihood = -869.32203
# Iteration=20, theta_new=[-0.41705556 -0.22992347 -1.57081407], -likelihood = -869.51280
# 14-th start
# Iteration=1, theta_new=[ 2.23832358 -1.0514789   1.94485326], -likelihood = -646.03378
# Iteration=2, theta_new=[ 2.25353007 -1.03582673  1.94278452], -likelihood = -654.92992
# Iteration=3, theta_new=[ 2.26947265 -1.02194685  1.942345  ], -likelihood = -663.43743
# Iteration=4, theta_new=[ 2.28670631 -1.0102337   1.9435923 ], -likelihood = -671.72425
# Iteration=5, theta_new=[ 2.30577157 -1.00103788  1.94661265], -likelihood = -680.33848
# Iteration=6, theta_new=[ 2.32756572 -0.99460726  1.95139335], -likelihood = -690.11579
# Iteration=7, theta_new=[ 2.35296503 -0.99102125  1.95803226], -likelihood = -702.45748
# Iteration=8, theta_new=[ 2.38236665 -0.99051026  1.96658096], -likelihood = -719.32627
# Iteration=9, theta_new=[ 2.41525822 -0.99282418  1.97661338], -likelihood = -742.94189
# Iteration=10, theta_new=[ 2.44960706 -0.99733494  1.98739974], -likelihood = -774.68841
# Iteration=11, theta_new=[ 2.48288186 -1.00289806  1.99787258], -likelihood = -813.19927
# Iteration=12, theta_new=[ 2.51290139 -1.00841805  2.00708831], -likelihood = -854.19746
# Iteration=13, theta_new=[ 2.5387036  -1.0133569   2.01462269], -likelihood = -892.22705
# Iteration=14, theta_new=[ 2.55998589 -1.01738042  2.02043054], -likelihood = -923.62705
# Iteration=15, theta_new=[ 2.57709885 -1.02087138  2.02468099], -likelihood = -947.02111
# Iteration=16, theta_new=[ 2.59057209 -1.02408784  2.02770956], -likelihood = -963.18990
# Iteration=17, theta_new=[ 2.60103142 -1.0272005   2.02986677], -likelihood = -973.73341
# Iteration=18, theta_new=[ 2.60909752 -1.03033271  2.03140611], -likelihood = -980.34285
# Iteration=19, theta_new=[ 2.61529093 -1.03360495  2.03256091], -likelihood = -984.39398
# Iteration=20, theta_new=[ 2.62002083 -1.03702335  2.03352375], -likelihood = -986.84572
# 15-th start
# Iteration=1, theta_new=[-0.44379308 -0.50001296 -0.11181583], -likelihood = -380.28237
# Iteration=2, theta_new=[-0.41021731 -0.53493711 -0.13692943], -likelihood = -518.96349
# Iteration=3, theta_new=[-0.39447795 -0.55861014 -0.15180847], -likelihood = -599.08256
# Iteration=4, theta_new=[-0.38440825 -0.57801199 -0.16209198], -likelihood = -621.46140
# Iteration=5, theta_new=[-0.37771066 -0.59483666 -0.16948752], -likelihood = -631.88363
# Iteration=6, theta_new=[-0.37327184 -0.60971467 -0.17500165], -likelihood = -637.90604
# Iteration=7, theta_new=[-0.37047279 -0.62314731 -0.17919259], -likelihood = -641.90066
# Iteration=8, theta_new=[-0.36887081 -0.63536662 -0.18240733], -likelihood = -644.84331
# Iteration=9, theta_new=[-0.36816643 -0.64647583 -0.18504073], -likelihood = -647.15781
# Iteration=10, theta_new=[-0.36807546 -0.65663734 -0.18722809], -likelihood = -649.05028
# Iteration=11, theta_new=[-0.36840018 -0.66584236 -0.18907724], -likelihood = -650.63132
# Iteration=12, theta_new=[-0.36903212 -0.67417427 -0.19078232], -likelihood = -651.94735
# Iteration=13, theta_new=[-0.36989764 -0.68165835 -0.19227298], -likelihood = -653.05235
# Iteration=14, theta_new=[-0.37083569 -0.68835844 -0.19370073], -likelihood = -653.97534
# Iteration=15, theta_new=[-0.37193248 -0.69435431 -0.1950552 ], -likelihood = -654.73941
# Iteration=16, theta_new=[-0.37308979 -0.6997134  -0.19633014], -likelihood = -655.38914
# Iteration=17, theta_new=[-0.37426905 -0.70450218 -0.19753711], -likelihood = -655.93731
# Iteration=18, theta_new=[-0.37547019 -0.70873521 -0.19869057], -likelihood = -656.40096
# Iteration=19, theta_new=[-0.37659949 -0.71248402 -0.19980229], -likelihood = -656.79654
# Iteration=20, theta_new=[-0.37775675 -0.71581805 -0.2008745 ], -likelihood = -657.12823
# 16-th start
# Iteration=1, theta_new=[-2.34225849  0.64444844 -2.16851138], -likelihood = -441.71580
# Iteration=2, theta_new=[-2.35290008  0.61171233 -2.11816105], -likelihood = -573.01070
# Iteration=3, theta_new=[-2.35493745  0.58493177 -2.0659308 ], -likelihood = -654.30038
# Iteration=4, theta_new=[-2.35243061  0.56386858 -2.00848064], -likelihood = -719.70320
# Iteration=5, theta_new=[-2.34745068  0.54758133 -1.94479665], -likelihood = -774.81702
# Iteration=6, theta_new=[-2.34146023  0.53515201 -1.87353459], -likelihood = -822.15328
# Iteration=7, theta_new=[-2.33566198  0.52572469 -1.78949014], -likelihood = -862.51415
# Iteration=8, theta_new=[-2.33089     0.51870344 -1.66528526], -likelihood = -896.16956
# Iteration=9, theta_new=[-2.32505878  0.51318376 -1.57080675], -likelihood = -918.10929
# Iteration=10, theta_new=[-2.31956051  0.50894989 -1.57084749], -likelihood = -922.22028
# Iteration=11, theta_new=[-2.31473984  0.50574893 -1.5708413 ], -likelihood = -924.18239
# Iteration=12, theta_new=[-2.31052451  0.50331726 -1.57072645], -likelihood = -925.53966
# Iteration=13, theta_new=[-2.3068992   0.50148357 -1.57079863], -likelihood = -926.51383
# Iteration=14, theta_new=[-2.30375719  0.50010868 -1.57081869], -likelihood = -927.22783
# Iteration=15, theta_new=[-2.30103701  0.49905639 -1.57079789], -likelihood = -927.77047
# Iteration=16, theta_new=[-2.29869285  0.49825476 -1.57073865], -likelihood = -928.19564
# Iteration=17, theta_new=[-2.29668943  0.49766563 -1.57077173], -likelihood = -928.53424
# Iteration=18, theta_new=[-2.29495106  0.49721478 -1.57076521], -likelihood = -928.80585
# Iteration=19, theta_new=[-2.29350328  0.49687967 -1.57079235], -likelihood = -929.03070
# Iteration=20, theta_new=[-2.29222315  0.49662643 -1.57085794], -likelihood = -929.21130
# 17-th start
# Iteration=1, theta_new=[-2.74913896  2.87666135  0.63677713], -likelihood = -729.53321
# Iteration=2, theta_new=[-2.76979911  2.86041782  0.60914872], -likelihood = -829.53670
# Iteration=3, theta_new=[-2.78638718  2.84591921  0.58871805], -likelihood = -896.68307
# Iteration=4, theta_new=[-2.7994158   2.83409562  0.57405964], -likelihood = -935.20630
# Iteration=5, theta_new=[-2.80965322  2.82488547  0.56366413], -likelihood = -956.44936
# Iteration=6, theta_new=[-2.81765141  2.81786845  0.55631509], -likelihood = -968.22509
# Iteration=7, theta_new=[-2.82394493  2.81251229  0.55119539], -likelihood = -974.79620
# Iteration=8, theta_new=[-2.82886209  2.80829763  0.54762452], -likelihood = -978.48304
# Iteration=9, theta_new=[-2.83275403  2.80502707  0.54522503], -likelihood = -980.53464
# Iteration=10, theta_new=[-2.83577161  2.80229909  0.54359208], -likelihood = -981.66416
# Iteration=11, theta_new=[-2.83819942  2.80003964  0.54259837], -likelihood = -982.25055
# Iteration=12, theta_new=[-2.84016525  2.79805249  0.54200012], -likelihood = -982.53435
# Iteration=13, theta_new=[-2.84166714  2.79621214  0.54167576], -likelihood = -982.64137
# Iteration=14, theta_new=[-2.84285148  2.79452486  0.54161095], -likelihood = -982.62977
# Iteration=15, theta_new=[-2.84380899  2.79281994  0.54166966], -likelihood = -982.55362
# Iteration=16, theta_new=[-2.84458752  2.79114181  0.54189223], -likelihood = -982.43267
# Iteration=17, theta_new=[-2.8452263   2.78946257  0.54218157], -likelihood = -982.28385
# Iteration=18, theta_new=[-2.84568623  2.78781881  0.5425778 ], -likelihood = -982.11932
# Iteration=19, theta_new=[-2.84610215  2.7860947   0.54300278], -likelihood = -981.94544
# Iteration=20, theta_new=[-2.84639958  2.78434314  0.54350211], -likelihood = -981.76067
# 18-th start
# Iteration=1, theta_new=[ 0.85261075 -2.34358417  0.67209734], -likelihood = -573.57907
# Iteration=2, theta_new=[ 0.88107711 -2.35865997  0.64659568], -likelihood = -765.67769
# Iteration=3, theta_new=[ 0.90559826 -2.37152247  0.62602011], -likelihood = -826.42003
# Iteration=4, theta_new=[ 0.92837944 -2.38222051  0.6081687 ], -likelihood = -864.34648
# Iteration=5, theta_new=[ 0.95006789 -2.39101964  0.59232367], -likelihood = -893.10050
# Iteration=6, theta_new=[ 0.97070706 -2.39804322  0.57829583], -likelihood = -916.86008
# Iteration=7, theta_new=[ 0.99003668 -2.40363113  0.5659692 ], -likelihood = -936.90955
# Iteration=8, theta_new=[ 1.00777617 -2.40797263  0.55534062], -likelihood = -953.59876
# Iteration=9, theta_new=[ 1.0238191  -2.41133411  0.54633103], -likelihood = -966.99079
# Iteration=10, theta_new=[ 1.03793749 -2.41391262  0.53880227], -likelihood = -977.33777
# Iteration=11, theta_new=[ 1.05021584 -2.4158059   0.53261343], -likelihood = -984.99370
# Iteration=12, theta_new=[ 1.06074526 -2.41720296  0.52753901], -likelihood = -990.47743
# Iteration=13, theta_new=[ 1.06968137 -2.41820687  0.52340877], -likelihood = -994.31503
# Iteration=14, theta_new=[ 1.07720249 -2.41890453  0.52006286], -likelihood = -996.94747
# Iteration=15, theta_new=[ 1.08351908 -2.41938906  0.51738406], -likelihood = -998.72691
# Iteration=16, theta_new=[ 1.0887329  -2.41967942  0.51523072], -likelihood = -999.91643
# Iteration=17, theta_new=[ 1.0929934  -2.41988677  0.51350166], -likelihood = -1000.70144
# Iteration=18, theta_new=[ 1.09653834 -2.41996688  0.51211161], -likelihood = -1001.21528
# Iteration=19, theta_new=[ 1.09940531 -2.41997365  0.51100483], -likelihood = -1001.55512
# Iteration=20, theta_new=[ 1.10179013 -2.41983335  0.51012786], -likelihood = -1001.77483
# 19-th start
# Iteration=1, theta_new=[ 2.42261368  0.44361392 -2.33675516], -likelihood = -707.86847
# Iteration=2, theta_new=[ 2.41206722  0.45293065 -2.34964586], -likelihood = -722.27386
# Iteration=3, theta_new=[ 2.39534114  0.46137875 -2.36087883], -likelihood = -737.32589
# Iteration=4, theta_new=[ 2.37196506  0.46943421 -2.37085494], -likelihood = -755.68654
# Iteration=5, theta_new=[ 2.3424291   0.47731546 -2.37991884], -likelihood = -779.56754
# Iteration=6, theta_new=[ 2.30863465  0.48488105 -2.38816757], -likelihood = -809.62511
# Iteration=7, theta_new=[ 2.27330773  0.49179175 -2.39551797], -likelihood = -843.86620
# Iteration=8, theta_new=[ 2.23892973  0.49764662 -2.40190054], -likelihood = -878.45427
# Iteration=9, theta_new=[ 2.20694258  0.50223369 -2.40717252], -likelihood = -909.69102
# Iteration=10, theta_new=[ 2.17823063  0.50552493 -2.41135294], -likelihood = -935.59336
# Iteration=11, theta_new=[ 2.15304847  0.50780093 -2.41467635], -likelihood = -955.62459
# Iteration=12, theta_new=[ 2.13138338  0.50918584 -2.41721156], -likelihood = -970.38969
# Iteration=13, theta_new=[ 2.11307754  0.50992143 -2.41908122], -likelihood = -980.84442
# Iteration=14, theta_new=[ 2.09778521  0.51023936 -2.42043887], -likelihood = -988.02048
# Iteration=15, theta_new=[ 2.08504186  0.51025122 -2.42141675], -likelihood = -992.85198
# Iteration=16, theta_new=[ 2.07457271  0.5101023  -2.42210112], -likelihood = -996.08009
# Iteration=17, theta_new=[ 2.06598803  0.50986335 -2.42252916], -likelihood = -998.20026
# Iteration=18, theta_new=[ 2.05905238  0.50955312 -2.42273782], -likelihood = -999.58885
# Iteration=19, theta_new=[ 2.05342252  0.50922095 -2.42284219], -likelihood = -1000.48665
# Iteration=20, theta_new=[ 2.04885375  0.50891527 -2.42275947], -likelihood = -1001.07157
# 20-th start
# Iteration=1, theta_new=[ 0.87278279  1.94333559 -1.31996057], -likelihood = -603.07957
# Iteration=2, theta_new=[ 0.86143673  1.96544662 -1.27863268], -likelihood = -621.67907
# Iteration=3, theta_new=[ 0.84218429  1.98066511 -1.24601097], -likelihood = -639.84417
# Iteration=4, theta_new=[ 0.81553331  1.99328483 -1.22016441], -likelihood = -662.32003
# Iteration=5, theta_new=[ 0.78258329  2.00560871 -1.20142843], -likelihood = -691.83086
# Iteration=6, theta_new=[ 0.74604922  2.01828635 -1.19044859], -likelihood = -728.88155
# Iteration=7, theta_new=[ 0.7092514   2.03100197 -1.18674282], -likelihood = -771.17120
# Iteration=8, theta_new=[ 0.67487262  2.04304874 -1.18882513], -likelihood = -815.04113
# Iteration=9, theta_new=[ 0.6443751   2.05384985 -1.19485616], -likelihood = -856.78111
# Iteration=10, theta_new=[ 0.61816588  2.06321705 -1.20328756], -likelihood = -893.51146
# Iteration=11, theta_new=[ 0.5962491   2.07114432 -1.21345879], -likelihood = -923.72334
# Iteration=12, theta_new=[ 0.57823339  2.07791726 -1.22490303], -likelihood = -947.03507
# Iteration=13, theta_new=[ 0.56364329  2.08375262 -1.23746065], -likelihood = -964.17305
# Iteration=14, theta_new=[ 0.55195075  2.08888435 -1.25101255], -likelihood = -976.29894
# Iteration=15, theta_new=[ 0.54264818  2.0936167  -1.26530737], -likelihood = -984.67716
# Iteration=16, theta_new=[ 0.5353366   2.09801009 -1.28015029], -likelihood = -990.41524
# Iteration=17, theta_new=[ 0.52952444  2.10223792 -1.29571947], -likelihood = -994.33349
# Iteration=18, theta_new=[ 0.52497711  2.10636264 -1.31173019], -likelihood = -997.09824
# Iteration=19, theta_new=[ 0.52141036  2.11040956 -1.32818045], -likelihood = -999.08438
# Iteration=20, theta_new=[ 0.51859634  2.11442761 -1.3449754 ], -likelihood = -1000.57333
# 21-th start
# Iteration=1, theta_new=[-1.5707631  -1.5708216   2.75370499], -likelihood = -640.39048
# Iteration=2, theta_new=[-1.57075862 -1.57079916  2.72689939], -likelihood = -708.71510
# Iteration=3, theta_new=[-1.57078282 -1.57082662  2.70651172], -likelihood = -752.17851
# Iteration=4, theta_new=[-1.57076306 -1.57076688  2.69117302], -likelihood = -778.04404
# Iteration=5, theta_new=[-1.57080873 -1.57080649  2.67968328], -likelihood = -792.86857
# Iteration=6, theta_new=[-1.57082633 -1.57079909  2.67109505], -likelihood = -801.22063
# Iteration=7, theta_new=[-1.57081013 -1.57083546  2.66467679], -likelihood = -805.88849
# Iteration=8, theta_new=[-1.57081181 -1.57078645  2.65988056], -likelihood = -808.49016
# Iteration=9, theta_new=[-1.57075326 -1.57074787  2.65630024], -likelihood = -809.93855
# Iteration=10, theta_new=[-1.57083882 -1.5708062   2.65362452], -likelihood = -810.74381
# Iteration=11, theta_new=[-1.57084527 -1.57079499  2.65163112], -likelihood = -811.19202
# Iteration=12, theta_new=[-1.57073104 -1.57085497  2.6501352 ], -likelihood = -811.44077
# Iteration=13, theta_new=[-1.57082092 -1.57088694  2.64901393], -likelihood = -811.57981
# Iteration=14, theta_new=[-1.57078179 -1.57083893  2.64818348], -likelihood = -811.65731
# Iteration=15, theta_new=[-1.57085648 -1.57076786  2.64756158], -likelihood = -811.69998
# Iteration=16, theta_new=[-1.57081732 -1.57080734  2.64709723], -likelihood = -811.72373
# Iteration=17, theta_new=[-1.57080759 -1.57081511  2.64674871], -likelihood = -811.73689
# Iteration=18, theta_new=[-1.57081317 -1.57076959  2.64649114], -likelihood = -811.74421
# Iteration=19, theta_new=[-1.57076764 -1.57076528  2.64629875], -likelihood = -811.74820
# Iteration=20, theta_new=[-1.57084573 -1.57084887  2.64614698], -likelihood = -811.75039
# 22-th start
# Iteration=1, theta_new=[ 1.10338185  1.40538135 -0.17067994], -likelihood = -757.24906
# Iteration=2, theta_new=[ 1.08063311  1.45636605 -0.19670941], -likelihood = -831.39050
# Iteration=3, theta_new=[ 1.06601177  1.50149969 -0.21735074], -likelihood = -880.51966
# Iteration=4, theta_new=[ 1.05603451  1.55086101 -0.23348914], -likelihood = -912.08962
# Iteration=5, theta_new=[ 1.04906207  1.57079819 -0.24604107], -likelihood = -931.75360
# Iteration=6, theta_new=[ 1.04358151  1.57078399 -0.25579043], -likelihood = -943.66884
# Iteration=7, theta_new=[ 1.03925016  1.54596234 -0.26336912], -likelihood = -950.96153
# Iteration=8, theta_new=[ 1.03577944  1.61534602 -0.26926514], -likelihood = -955.38629
# Iteration=9, theta_new=[ 1.03289959  1.63281331 -0.27386168], -likelihood = -958.04755
# Iteration=10, theta_new=[ 1.03042959  1.64834321 -0.27743935], -likelihood = -959.64483
# Iteration=11, theta_new=[ 1.02824208  1.66227228 -0.28023975], -likelihood = -960.59620
# Iteration=12, theta_new=[ 1.02626571  1.6748722  -0.28242133], -likelihood = -961.15997
# Iteration=13, theta_new=[ 1.02444012  1.68631965 -0.28412438], -likelihood = -961.48571
# Iteration=14, theta_new=[ 1.02273467  1.69683332 -0.28545431], -likelihood = -961.66838
# Iteration=15, theta_new=[ 1.02110257  1.70648602 -0.28648624], -likelihood = -961.76416
# Iteration=16, theta_new=[ 1.01954675  1.7153796  -0.28727892], -likelihood = -961.80858
# Iteration=17, theta_new=[ 1.01804903  1.72357637 -0.28790151], -likelihood = -961.82233
# Iteration=18, theta_new=[ 1.01658893  1.7312209  -0.28839509], -likelihood = -961.82020
# Iteration=19, theta_new=[ 1.01514796  1.73829894 -0.28876346], -likelihood = -961.80964
# Iteration=20, theta_new=[ 1.01376803  1.74490211 -0.2890519 ], -likelihood = -961.79595
# 23-th start
# Iteration=1, theta_new=[2.07678841 0.85802108 0.57101157], -likelihood = -907.78373
# Iteration=2, theta_new=[2.04718414 0.8484304  0.55701201], -likelihood = -950.54246
# Iteration=3, theta_new=[2.02320005 0.84270767 0.54527311], -likelihood = -975.82433
# Iteration=4, theta_new=[2.0035849  0.83948613 0.53562531], -likelihood = -991.05521
# Iteration=5, theta_new=[1.98743926 0.83787677 0.52774989], -likelihood = -1000.36575
# Iteration=6, theta_new=[1.97420258 0.83744207 0.52136539], -likelihood = -1006.14705
# Iteration=7, theta_new=[1.96332402 0.83783956 0.51620536], -likelihood = -1009.75332
# Iteration=8, theta_new=[1.95431332 0.8387907  0.51207843], -likelihood = -1012.01596
# Iteration=9, theta_new=[1.94686936 0.84007084 0.50882447], -likelihood = -1013.43588
# Iteration=10, theta_new=[1.94065529 0.84158624 0.50626862], -likelihood = -1014.31962
# Iteration=11, theta_new=[1.93548051 0.84329047 0.50423562], -likelihood = -1014.86983
# Iteration=12, theta_new=[1.93099034 0.84506008 0.50267962], -likelihood = -1015.21132
# Iteration=13, theta_new=[1.92719172 0.8469208  0.5014815 ], -likelihood = -1015.42160
# Iteration=14, theta_new=[1.92392982 0.84884008 0.50055292], -likelihood = -1015.54609
# Iteration=15, theta_new=[1.92102446 0.85076924 0.49991142], -likelihood = -1015.61716
# Iteration=16, theta_new=[1.91839932 0.85271908 0.49944357], -likelihood = -1015.65399
# Iteration=17, theta_new=[1.91603319 0.85469608 0.49912296], -likelihood = -1015.67003
# Iteration=18, theta_new=[1.91388056 0.85658594 0.49891495], -likelihood = -1015.67128
# Iteration=19, theta_new=[1.91178389 0.85847864 0.49879951], -likelihood = -1015.66444
# Iteration=20, theta_new=[1.90982228 0.8603367  0.49875607], -likelihood = -1015.65205
# 24-th start
# Iteration=1, theta_new=[-1.27860967 -1.5708042  -3.07327123], -likelihood = -416.51060
# Iteration=2, theta_new=[-1.21599929 -1.57081282 -3.04103585], -likelihood = -484.91822
# Iteration=3, theta_new=[-1.13479417 -1.57080378 -3.00578133], -likelihood = -569.47026
# Iteration=4, theta_new=[-1.07374228 -1.57078842 -2.97426287], -likelihood = -682.95166
# Iteration=5, theta_new=[-1.03211647 -1.57082653 -2.94859317], -likelihood = -768.30819
# Iteration=6, theta_new=[-1.00268188 -1.57080395 -2.92835614], -likelihood = -820.98801
# Iteration=7, theta_new=[-0.98134833 -1.57079961 -2.91255776], -likelihood = -852.28221
# Iteration=8, theta_new=[-0.96569911 -1.57094154 -2.90025362], -likelihood = -870.79330
# Iteration=9, theta_new=[-0.95405963 -1.5707853  -2.89069114], -likelihood = -881.73697
# Iteration=10, theta_new=[-0.9453496  -1.57078214 -2.88322995], -likelihood = -888.16032
# Iteration=11, theta_new=[-0.93878314 -1.57076913 -2.87742293], -likelihood = -891.90243
# Iteration=12, theta_new=[-0.93380415 -1.5707965  -2.8729156 ], -likelihood = -894.03603
# Iteration=13, theta_new=[-0.93001979 -1.57078068 -2.86940161], -likelihood = -895.21570
# Iteration=14, theta_new=[-0.92714397 -1.57078161 -2.86665854], -likelihood = -895.84666
# Iteration=15, theta_new=[-0.92493528 -1.57082688 -2.86452215], -likelihood = -896.16484
# Iteration=16, theta_new=[-0.92322338 -1.57079826 -2.86285755], -likelihood = -896.30442
# Iteration=17, theta_new=[-0.92192434 -1.5707735  -2.86155699], -likelihood = -896.34590
# Iteration=18, theta_new=[-0.9209057  -1.57079097 -2.86053848], -likelihood = -896.34175
# Iteration=19, theta_new=[-0.92012914 -1.57081006 -2.85976469], -likelihood = -896.31266
# Iteration=20, theta_new=[-0.91952906 -1.57078821 -2.85913632], -likelihood = -896.27509
# 25-th start
# Iteration=1, theta_new=[-0.40253743 -2.53333675  0.93897766], -likelihood = -766.34580
# Iteration=2, theta_new=[-0.38475085 -2.52950854  0.97399696], -likelihood = -832.72138
# Iteration=3, theta_new=[-0.36912441 -2.52767569  1.00316176], -likelihood = -881.87756
# Iteration=4, theta_new=[-0.35560892 -2.52725935  1.02674355], -likelihood = -916.80768
# Iteration=5, theta_new=[-0.3439479  -2.52790424  1.04563102], -likelihood = -940.94551
# Iteration=6, theta_new=[-0.33406712 -2.52944695  1.06055694], -likelihood = -957.56162
# Iteration=7, theta_new=[-0.3256724  -2.53170898  1.07225644], -likelihood = -968.89448
# Iteration=8, theta_new=[-0.31862695 -2.5345202   1.08146289], -likelihood = -976.68138
# Iteration=9, theta_new=[-0.31275947 -2.53774812  1.08868374], -likelihood = -982.06001
# Iteration=10, theta_new=[-0.30787142 -2.54133245  1.09431404], -likelihood = -985.80627
# Iteration=11, theta_new=[-0.30379107 -2.54517151  1.09877647], -likelihood = -988.46619
# Iteration=12, theta_new=[-0.30032828 -2.54914312  1.10227348], -likelihood = -990.40788
# Iteration=13, theta_new=[-0.29741913 -2.55317156  1.10499437], -likelihood = -991.86539
# Iteration=14, theta_new=[-0.2949582  -2.55717349  1.10717051], -likelihood = -992.97764
# Iteration=15, theta_new=[-0.29284838 -2.56115282  1.10891413], -likelihood = -993.85016
# Iteration=16, theta_new=[-0.29103942 -2.56499478  1.11036666], -likelihood = -994.55516
# Iteration=17, theta_new=[-0.28945978 -2.5688021   1.11161432], -likelihood = -995.12929
# Iteration=18, theta_new=[-0.28806375 -2.5725347   1.1126165 ], -likelihood = -995.61447
# Iteration=19, theta_new=[-0.28683304 -2.57607411  1.11343356], -likelihood = -996.02560
# Iteration=20, theta_new=[-0.28567556 -2.57947875  1.11406824], -likelihood = -996.36929
# 26-th start
# Iteration=1, theta_new=[-2.62946498  0.61423666  2.29144788], -likelihood = -818.62346
# Iteration=2, theta_new=[-2.65933856  0.59963217  2.26123712], -likelihood = -895.44866
# Iteration=3, theta_new=[-2.69114779  0.5868169   2.23292594], -likelihood = -969.95262
# Iteration=4, theta_new=[-2.72087132  0.57526646  2.20606861], -likelihood = -1046.45999
# Iteration=5, theta_new=[-2.74638307  0.56483813  2.18076491], -likelihood = -1116.58876
# Iteration=6, theta_new=[-2.76730862  0.55560712  2.15749856], -likelihood = -1173.86390
# Iteration=7, theta_new=[-2.78418883  0.54761467  2.13655294], -likelihood = -1217.03846
# Iteration=8, theta_new=[-2.79761639  0.54088342  2.11824028], -likelihood = -1248.09150
# Iteration=9, theta_new=[-2.80824485  0.535271    2.10254969], -likelihood = -1269.53870
# Iteration=10, theta_new=[-2.81663605  0.53059867  2.08938508], -likelihood = -1283.97731
# Iteration=11, theta_new=[-2.82326829  0.52684583  2.07841571], -likelihood = -1293.50373
# Iteration=12, theta_new=[-2.82851919  0.52379956  2.06939422], -likelihood = -1299.69699
# Iteration=13, theta_new=[-2.83266783  0.5213497   2.06203907], -likelihood = -1303.68747
# Iteration=14, theta_new=[-2.83590889  0.5194193   2.05611899], -likelihood = -1306.23275
# Iteration=15, theta_new=[-2.83850097  0.51785927  2.05133538], -likelihood = -1307.83211
# Iteration=16, theta_new=[-2.84053366  0.51656662  2.04745964], -likelihood = -1308.85164
# Iteration=17, theta_new=[-2.84211772  0.51554898  2.04433454], -likelihood = -1309.49704
# Iteration=18, theta_new=[-2.84337252  0.51476626  2.04182045], -likelihood = -1309.90001
# Iteration=19, theta_new=[-2.8443883   0.51411858  2.03980433], -likelihood = -1310.15216
# Iteration=20, theta_new=[-2.84517704  0.51359812  2.03818496], -likelihood = -1310.31237
# 27-th start
# Iteration=1, theta_new=[-2.67324705 -0.75960461  2.07841972], -likelihood = -747.44542
# Iteration=2, theta_new=[-2.70021945 -0.74700671  2.06752696], -likelihood = -787.87883
# Iteration=3, theta_new=[-2.72495708 -0.73440968  2.05943952], -likelihood = -828.02746
# Iteration=4, theta_new=[-2.74683669 -0.7224449   2.0535063 ], -likelihood = -864.87274
# Iteration=5, theta_new=[-2.76563319 -0.71135798  2.04907652], -likelihood = -896.06367
# Iteration=6, theta_new=[-2.78151201 -0.70108804  2.04569372], -likelihood = -920.75880
# Iteration=7, theta_new=[-2.79466195 -0.69154699  2.04301015], -likelihood = -939.45913
# Iteration=8, theta_new=[-2.80549597 -0.68249923  2.04089328], -likelihood = -953.12142
# Iteration=9, theta_new=[-2.81431401 -0.67379866  2.03906111], -likelihood = -963.00356
# Iteration=10, theta_new=[-2.82147502 -0.66528491  2.03753707], -likelihood = -970.12598
# Iteration=11, theta_new=[-2.82729143 -0.65702773  2.03618874], -likelihood = -975.34091
# Iteration=12, theta_new=[-2.83202986 -0.64898765  2.03504659], -likelihood = -979.24050
# Iteration=13, theta_new=[-2.8359219  -0.64113529  2.0340517 ], -likelihood = -982.24418
# Iteration=14, theta_new=[-2.83911509 -0.63356248  2.03314867], -likelihood = -984.63933
# Iteration=15, theta_new=[-2.84174677 -0.62625815  2.03241099], -likelihood = -986.58759
# Iteration=16, theta_new=[-2.84402798 -0.61925029  2.03168244], -likelihood = -988.20881
# Iteration=17, theta_new=[-2.84591664 -0.61253224  2.03104844], -likelihood = -989.59972
# Iteration=18, theta_new=[-2.84759166 -0.6061551   2.03043939], -likelihood = -990.78689
# Iteration=19, theta_new=[-2.84905801 -0.60006523  2.02990688], -likelihood = -991.81803
# Iteration=20, theta_new=[-2.85031778 -0.59429698  2.02939884], -likelihood = -992.71613
# 28-th start
# Iteration=1, theta_new=[ 1.23699287  0.49059739 -2.32457879], -likelihood = -976.13489
# Iteration=2, theta_new=[ 1.21427884  0.49324227 -2.32635829], -likelihood = -983.17714
# Iteration=3, theta_new=[ 1.19644735  0.495379   -2.32872599], -likelihood = -988.24191
# Iteration=4, theta_new=[ 1.18220445  0.49711194 -2.3314814 ], -likelihood = -991.83585
# Iteration=5, theta_new=[ 1.17086128  0.4985321  -2.33452795], -likelihood = -994.39507
# Iteration=6, theta_new=[ 1.16173364  0.49969744 -2.33784045], -likelihood = -996.20710
# Iteration=7, theta_new=[ 1.15436079  0.50068555 -2.34125196], -likelihood = -997.50869
# Iteration=8, theta_new=[ 1.14831671  0.50153745 -2.3446896 ], -likelihood = -998.45673
# Iteration=9, theta_new=[ 1.14331776  0.50224426 -2.34812478], -likelihood = -999.16474
# Iteration=10, theta_new=[ 1.13923285  0.50283346 -2.35158518], -likelihood = -999.70307
# Iteration=11, theta_new=[ 1.13588114  0.50331976 -2.3549418 ], -likelihood = -1000.11856
# Iteration=12, theta_new=[ 1.13307837  0.50373972 -2.35818056], -likelihood = -1000.44365
# Iteration=13, theta_new=[ 1.1306462   0.50407557 -2.36133093], -likelihood = -1000.70591
# Iteration=14, theta_new=[ 1.12864902  0.50434746 -2.36434723], -likelihood = -1000.92397
# Iteration=15, theta_new=[ 1.12694036  0.5045968  -2.36727047], -likelihood = -1001.10214
# Iteration=16, theta_new=[ 1.12548173  0.50481902 -2.37001437], -likelihood = -1001.25419
# Iteration=17, theta_new=[ 1.12421763  0.50498683 -2.37256399], -likelihood = -1001.38212
# Iteration=18, theta_new=[ 1.12311208  0.50516214 -2.3750226 ], -likelihood = -1001.48937
# Iteration=19, theta_new=[ 1.12215049  0.50530125 -2.37735751], -likelihood = -1001.58358
# Iteration=20, theta_new=[ 1.121288    0.50543947 -2.37956066], -likelihood = -1001.66460
# 29-th start
# Iteration=1, theta_new=[ 1.15503997  2.77636203 -1.74017673], -likelihood = -726.37808
# Iteration=2, theta_new=[ 1.1238799   2.7446     -1.78560607], -likelihood = -822.35401
# Iteration=3, theta_new=[ 1.10209633  2.71915622 -1.80555766], -likelihood = -888.03352
# Iteration=4, theta_new=[ 1.08562465  2.69933571 -1.81245202], -likelihood = -931.84919
# Iteration=5, theta_new=[ 1.07252468  2.6841027  -1.8117272 ], -likelihood = -959.53792
# Iteration=6, theta_new=[ 1.06175267  2.67246287 -1.80625148], -likelihood = -976.44054
# Iteration=7, theta_new=[ 1.05258026  2.66355772 -1.7976427 ], -likelihood = -986.66393
# Iteration=8, theta_new=[ 1.04460675  2.65672889 -1.7867866 ], -likelihood = -992.94587
# Iteration=9, theta_new=[ 1.03752937  2.65148765 -1.77420833], -likelihood = -996.92112
# Iteration=10, theta_new=[ 1.0311559   2.64744031 -1.76022711], -likelihood = -999.54336
# Iteration=11, theta_new=[ 1.02530781  2.64433358 -1.74504262], -likelihood = -1001.36639
# Iteration=12, theta_new=[ 1.01993987  2.64194337 -1.72859214], -likelihood = -1002.70377
# Iteration=13, theta_new=[ 1.01491594  2.64008789 -1.71075069], -likelihood = -1003.73635
# Iteration=14, theta_new=[ 1.01023481  2.63866234 -1.6910952 ], -likelihood = -1004.57977
# Iteration=15, theta_new=[ 1.00583341  2.63756973 -1.66861376], -likelihood = -1005.28958
# Iteration=16, theta_new=[ 1.00166536  2.63673447 -1.64081737], -likelihood = -1005.90724
# Iteration=17, theta_new=[ 0.99771985  2.63609724 -1.59263558], -likelihood = -1006.45776
# Iteration=18, theta_new=[ 0.9935601   2.63563473 -1.57078082], -likelihood = -1006.88105
# Iteration=19, theta_new=[ 0.98994677  2.63527345 -1.57080817], -likelihood = -1007.24352
# Iteration=20, theta_new=[ 0.98688247  2.63498639 -1.57077821], -likelihood = -1007.53289

# %%
np.rad2deg(EM_theta4_rad)
# Out:
# array([-16.98336345,  29.42700468,  63.22060413])

# %% [markdown]
# ## True Result

# %%
np.rad2deg(theta4_rad)
# Out:
# array([ 28.64788976,  63.02535746, -17.18873385])
