# %%
import numpy as np
import matplotlib.pyplot as plt
import em_dtools_un
from functools import partial

# %%
dist_ratio = 0.5

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
P_1 = 4.1 * np.ones(Num_sensors1, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1 = em_dtools_un.gds(Num_emitters1, sample_size1)
n1 = em_dtools_un.gss(Num_sensors1, sample_size1, P_1)
X1 = (A1 @ S1.T + n1.T).T

# %%
X1_with_mv = em_dtools_un.MCAR(X1, [2,4], [80, 80])

# %%
X1_with_mv
# Out:
# array([[-0.79648763+0.64615246j, -0.29241011-0.61740544j,
#         -1.52077025-1.20204555j, -2.18353123-0.01401332j,
#         -1.04078864+0.72410055j],
#        [ 2.44100428-0.15928782j,  3.39289402-1.13118218j,
#                 nan+0.j        ,  1.41527602-1.30278698j,
#                 nan+0.j        ],
#        [ 1.49659839+2.73918643j,  2.74940089+2.20894232j,
#                 nan+0.j        ,  0.99048014+1.28882335j,
#                 nan+0.j        ],
#        [ 1.35227287+0.83733241j,  2.71265039+0.83056802j,
#                 nan+0.j        ,  1.44387074-0.69606858j,
#                 nan+0.j        ],
#        [-0.69874893+1.78376259j,  0.55926467+2.30152184j,
#                 nan+0.j        , -0.0235706 +0.40396441j,
#                 nan+0.j        ],
#        [-2.38435865+1.17200435j, -1.42285085+2.13438448j,
#                 nan+0.j        , -1.22979622+0.15874508j,
#                 nan+0.j        ],
#        [ 0.15895296+1.07171622j,  0.67557112+2.33019876j,
#                 nan+0.j        ,  1.61472268+0.58136615j,
#                 nan+0.j        ],
#        [-0.75268276-0.30755819j, -0.76068077+1.05281264j,
#          0.59633268+1.14866247j,  0.77963399-0.19932616j,
#         -0.55370002-0.46931341j],
#        [-1.67332374-1.21773229j, -2.20470376+0.03458876j,
#                 nan+0.j        , -0.30093348-0.52762103j,
#                 nan+0.j        ],
#        [ 2.5741131 -2.38020264j,  1.60135596-1.42919463j,
#                 nan+0.j        ,  3.57478412-1.2147129j ,
#                 nan+0.j        ],
#        [-0.66311139-2.42362568j, -1.9271259 -1.92069423j,
#                 nan+0.j        , -0.18858737-0.96262069j,
#                 nan+0.j        ],
#        [ 3.30980918-0.34008204j,  1.94960524-0.36284152j,
#                 nan+0.j        ,  3.18495574+1.19097002j,
#                 nan+0.j        ],
#        [ 0.72168608-3.5699691j , -0.52479504-4.1149072j ,
#                 nan+0.j        ,  0.01672308-2.20514825j,
#                 nan+0.j        ],
#        [ 1.27261467-0.09912529j,  0.33221848-1.08214496j,
#                 nan+0.j        ,  0.09633492+0.88883959j,
#                 nan+0.j        ],
#        [ 1.34119591+3.58040638j,  0.85201036+2.3110088j ,
#         -0.44633371+2.71718041j, -0.12487236+4.03904853j,
#          1.2149991 +3.80364001j],
#        [ 0.39070509+1.68148316j,  0.42822335+0.32160629j,
#                 nan+0.j        , -1.13890199+1.54002301j,
#                 nan+0.j        ],
#        [ 0.61043002+0.36956424j,  1.16886211-0.87093015j,
#                 nan+0.j        , -0.74666063-0.35016749j,
#                 nan+0.j        ],
#        [ 0.66617004+1.26014683j,  1.65933642+0.3304731j ,
#                 nan+0.j        , -0.30897241+0.07321547j,
#                 nan+0.j        ],
#        [-2.30259517+3.6458602j , -1.02796391+3.17047824j,
#                 nan+0.j        , -2.74530135+2.17490138j,
#                 nan+0.j        ],
#        [-1.03816819+0.71850302j,  0.32122148+0.77077565j,
#                 nan+0.j        , -0.880118  -0.80947895j,
#                 nan+0.j        ],
#        [ 0.50394652-1.63861835j,  1.7383081 -1.06675801j,
#                 nan+0.j        ,  1.23836221-2.98781898j,
#                 nan+0.j        ],
#        [-0.8419971 +1.49156436j,  0.07684459+2.49476052j,
#          1.13729532+1.64263557j,  0.35544598+0.52935919j,
#         -0.80600652+1.23766758j],
#        [-2.41492432+1.79340428j, -1.95340185+3.07311897j,
#                 nan+0.j        , -0.93924809+1.36668606j,
#                 nan+0.j        ],
#        [-0.82943108+0.20944111j, -0.89645191+1.56818349j,
#                 nan+0.j        ,  0.69674586+0.38406272j,
#                 nan+0.j        ],
#        [-0.66321179-0.16760277j, -1.248433  +1.06048061j,
#                 nan+0.j        ,  0.67793997+0.58141036j,
#                 nan+0.j        ],
#        [ 1.22586485-1.32471706j,  0.21275699-0.41681554j,
#                 nan+0.j        ,  2.17501939-0.1169032j ,
#                 nan+0.j        ],
#        [-1.13394885-2.86486011j, -2.41859639-2.41725154j,
#                 nan+0.j        , -0.72326894-1.38464029j,
#                 nan+0.j        ],
#        [ 0.01892478-1.53509599j, -1.33901035-1.61685714j,
#         -1.50831195-0.26703876j, -0.17224774-0.0109038j ,
#          0.16965085-1.32763386j],
#        [ 0.14767934-2.7716204j , -1.07398128-3.37013362j,
#                 nan+0.j        , -0.61584309-1.43867548j,
#                 nan+0.j        ],
#        [ 0.10044927-0.60216757j, -0.79640519-1.62506777j,
#                 nan+0.j        , -1.11759318+0.33382462j,
#                 nan+0.j        ],
#        [ 2.4446729 -0.85376259j,  2.01103092-2.1431916j ,
#                 nan+0.j        ,  0.96008379-0.45916926j,
#                 nan+0.j        ],
#        [ 1.6921135 +1.32876818j,  1.78860531-0.0281998j ,
#                 nan+0.j        ,  0.17008551+1.12106727j,
#                 nan+0.j        ],
#        [ 0.03778952-0.07236982j,  0.64952418-1.28746383j,
#         -0.52351951-1.97640591j, -1.28679167-0.85031164j,
#         -0.21234989-0.01589715j],
#        [ 3.81333876+1.34681345j,  4.84591086+0.46111164j,
#                 nan+0.j        ,  2.89061914+0.11868583j,
#                 nan+0.j        ],
#        [-1.21155448-0.05645686j,  0.08250432-0.47608117j,
#         -0.25265847-1.79454186j, -1.59001463-1.54524042j,
#         -1.42761573-0.19457418j],
#        [-2.46084597+1.31782519j, -1.10500503+1.42903634j,
#                 nan+0.j        , -2.23664123-0.20185932j,
#                 nan+0.j        ],
#        [-1.53353852-1.88115321j, -0.32515424-1.25626907j,
#                 nan+0.j        , -0.74126894-3.19721464j,
#                 nan+0.j        ],
#        [-1.43700023-1.37010145j, -0.56255548-0.32797909j,
#                 nan+0.j        , -0.19893217-2.27943989j,
#                 nan+0.j        ],
#        [-2.03742771+4.27961237j, -1.63187039+5.57814847j,
#                 nan+0.j        , -0.5446249 +3.91732988j,
#                 nan+0.j        ],
#        [ 0.96486028-2.08611972j,  0.83894285-0.73156533j,
#                 nan+0.j        ,  2.48202233-1.84543739j,
#                 nan+0.j        ],
#        [-1.09125011+1.28832844j, -1.72921011+2.48986072j,
#                 nan+0.j        ,  0.2161366 +2.0948325j ,
#                 nan+0.j        ],
#        [-0.10966923-1.61637061j, -1.16121922-0.75328584j,
#                 nan+0.j        ,  0.78618086-0.36850786j,
#                 nan+0.j        ],
#        [-1.82339813-1.1270136j , -3.12625859-0.73557115j,
#                 nan+0.j        , -1.47733593+0.36963253j,
#                 nan+0.j        ],
#        [ 0.61654408-1.36931655j, -0.73656409-1.50992538j,
#         -0.96427867-0.16872489j,  0.35941266+0.14514443j,
#          0.75812587-1.15550943j],
#        [-0.23360504+1.38897355j, -1.42814375+0.73801283j,
#                 nan+0.j        , -1.05424853+2.68753162j,
#                 nan+0.j        ],
#        [ 0.28826036+1.46299881j, -0.56336273+0.40214503j,
#                 nan+0.j        , -0.96925009+2.34525507j,
#                 nan+0.j        ],
#        [ 1.01551707+1.67798899j,  0.63823546+0.37095748j,
#         -0.69043588+0.66302797j, -0.48479627+2.00779005j,
#          0.87044024+1.88944017j],
#        [ 1.37926882+1.87558932j,  1.53455244+0.5240866j ,
#                 nan+0.j        , -0.13231281+1.602039j  ,
#                 nan+0.j        ],
#        [ 0.55181359+2.21115496j,  1.21569845+1.02375042j,
#                 nan+0.j        , -0.73776284+1.37646861j,
#                 nan+0.j        ],
#        [-0.20861046+2.22217204j,  0.86142214+1.38211083j,
#                 nan+0.j        , -1.07716903+0.9551619j ,
#                 nan+0.j        ],
#        [ 1.1139435 +2.34877401j,  2.42499206+1.98569782j,
#                 nan+0.j        ,  0.80044233+0.84497027j,
#                 nan+0.j        ],
#        [-0.42861666+0.43281365j,  0.92112146+0.60275383j,
#                 nan+0.j        , -0.13867964-1.07571058j,
#                 nan+0.j        ],
#        [ 2.1916523 -0.16531827j,  3.37178287+0.51141252j,
#                 nan+0.j        ,  3.04028324-1.44576124j,
#                 nan+0.j        ],
#        [-1.49746886-0.57121963j, -0.66906844+0.50786582j,
#                 nan+0.j        , -0.22110821-1.42597822j,
#                 nan+0.j        ],
#        [ 1.01562545-1.46245784j,  1.36445359-0.14754655j,
#                 nan+0.j        ,  2.52274262-1.75962213j,
#                 nan+0.j        ],
#        [-0.86882629-3.41382616j, -1.05340302-2.06601157j,
#                 nan+0.j        ,  0.63646289-3.10753657j,
#                 nan+0.j        ],
#        [-1.37755594-0.77931093j, -2.06705294+0.39340672j,
#                 nan+0.j        , -0.10639718+0.08316469j,
#                 nan+0.j        ],
#        [-3.17114077-1.40683472j, -4.25915199-0.59019266j,
#                 nan+0.j        , -2.33028281-0.12127389j,
#                 nan+0.j        ],
#        [-2.72622614+0.66880132j, -4.04484526+1.00334027j,
#                 nan+0.j        , -2.44543366+2.17905438j,
#                 nan+0.j        ],
#        [-0.34940037+0.06052365j, -1.69513268-0.1386679j ,
#         -1.98083127+1.19138812j, -0.67200641+1.56240053j,
#         -0.2172297 +0.28027306j],
#        [-0.74711583-2.0940399j , -1.91228239-2.79622192j,
#                 nan+0.j        , -1.6233345 -0.83231503j,
#                 nan+0.j        ],
#        [ 1.39079116-1.08556687j,  0.58600368-2.18237579j,
#         -0.56049733-1.45011345j,  0.09618158-0.25870861j,
#          1.32751444-0.83706151j],
#        [ 0.43472765+1.84339628j,  0.11451727+0.52122458j,
#                 nan+0.j        , -1.07848347+2.10778386j,
#                 nan+0.j        ],
#        [-1.09792767+3.26216304j, -0.8841447 +1.91867144j,
#                 nan+0.j        , -2.59621532+2.92327849j,
#                 nan+0.j        ],
#        [ 1.87673753-0.76114551j,  2.59152191-1.91862383j,
#                 nan+0.j        ,  0.62459516-1.65100409j,
#                 nan+0.j        ],
#        [-0.32984616-0.19906368j,  0.77563123-0.99190191j,
#                 nan+0.j        , -1.14260744-1.50256966j,
#                 nan+0.j        ],
#        [-1.25144361+0.82712312j,  0.07412495+0.52127904j,
#                 nan+0.j        , -1.49939518-0.68886786j,
#                 nan+0.j        ],
#        [ 0.0976869 -1.35064522j,  1.43877952-1.12229613j,
#                 nan+0.j        ,  0.45280999-2.84516734j,
#                 nan+0.j        ],
#        [-5.06539125-1.10167408j, -3.9157375 -0.37437151j,
#                 nan+0.j        , -4.16199757-2.3440865j ,
#                 nan+0.j        ],
#        [-0.61775798+1.46867107j,  0.16303755+2.58268682j,
#          1.32515976+1.87547776j,  0.69449081+0.67010255j,
#         -0.54910321+1.22159744j],
#        [-1.06287941+0.69469818j, -0.77143755+2.02350753j,
#                 nan+0.j        ,  0.455713  +0.46321183j,
#                 nan+0.j        ],
#        [ 0.05905609-0.9308432j , -0.1838323 +0.40769253j,
#                 nan+0.j        ,  1.54963663-0.55952337j,
#                 nan+0.j        ],
#        [ 2.34342154+1.09423418j,  1.60368643+2.23592798j,
#                 nan+0.j        ,  3.57595771+2.01105659j,
#                 nan+0.j        ],
#        [-0.7629166 -0.90690423j, -1.88533944-0.13824323j,
#                 nan+0.j        ,  0.0213652 +0.41393296j,
#                 nan+0.j        ],
#        [ 0.45647092-0.30378217j, -0.87542271-0.02677692j,
#         -0.68502505+1.3202277j ,  0.67146481+1.21723278j,
#          0.65630279-0.14307705j],
#        [-0.59589653-1.43844651j, -1.93171775-1.69584559j,
#                 nan+0.j        , -0.98336936+0.04801692j,
#                 nan+0.j        ],
#        [ 4.17263428-3.04605653j,  3.03903492-3.79813707j,
#                 nan+0.j        ,  3.24249116-1.82354174j,
#                 nan+0.j        ],
#        [ 1.73293764+0.78140817j,  0.9765018 -0.3492896j ,
#                 nan+0.j        ,  0.4036677 +1.55131089j,
#                 nan+0.j        ],
#        [-1.56335387+1.73853069j, -1.82588984+0.40370954j,
#         -3.17488122+0.57947911j, -3.08661219+1.93700674j,
#         -1.72621793+1.93660688j],
#        [-1.33900578+0.71584209j, -1.06712629-0.61710737j,
#                 nan+0.j        , -2.82117704+0.31226183j,
#                 nan+0.j        ],
#        [ 0.08868026-1.22301404j,  0.85301761-2.34838559j,
#                 nan+0.j        , -1.12366924-2.16636846j,
#                 nan+0.j        ],
#        [-0.30605788+2.91589986j,  0.83278173+2.1717782j ,
#          0.16377342+0.98725273j, -1.06149081+1.57835363j,
#         -0.550766  +2.83923938j],
#        [-2.36146335+2.38636287j, -1.02387191+2.13832701j,
#                 nan+0.j        , -2.54339822+0.86104046j,
#                 nan+0.j        ],
#        [ 1.35734425-1.05523092j,  2.68726498-0.76890308j,
#                 nan+0.j        ,  1.77698441-2.53293551j,
#                 nan+0.j        ],
#        [-1.0994771 +0.53034645j,  0.01753406+1.30685069j,
#                 nan+0.j        , -0.14302253-0.67169492j,
#                 nan+0.j        ],
#        [-0.26875444+1.12007923j,  0.46296537+2.26692653j,
#                 nan+0.j        ,  1.07691051+0.37920502j,
#                 nan+0.j        ],
#        [-1.69900007-3.34949879j, -1.46549354-2.00929453j,
#                 nan+0.j        , -0.17179321-3.51487103j,
#                 nan+0.j        ],
#        [ 0.40092693-0.21205295j,  0.10018446+1.11468236j,
#                 nan+0.j        ,  1.87399086+0.22359762j,
#                 nan+0.j        ],
#        [-1.29805533+1.17680508j, -2.086635  +2.28532425j,
#                 nan+0.j        , -0.10646362+2.14624712j,
#                 nan+0.j        ],
#        [ 1.85762338-0.58950793j,  0.70290338+0.12972392j,
#          1.34604812+1.32848892j,  2.58385158+0.76411733j,
#          2.1006102 -0.50755498j],
#        [-1.48890461-1.91483216j, -2.83156385-1.69588247j,
#         -2.69979587-0.34188472j, -1.34011446-0.38592069j,
#         -1.2962345 -1.74560714j],
#        [ 0.46197438-3.45439968j, -0.86141936-3.76952144j,
#                 nan+0.j        ,  0.01036462-1.98614997j,
#                 nan+0.j        ],
#        [ 1.92760627-0.6546047j ,  0.82770951-1.4551669j ,
#         -0.04222503-0.40927656j,  0.94529082+0.52639707j,
#          1.94279577-0.39862j   ],
#        [ 2.52813225+4.2764974j ,  1.82147308+3.11404072j,
#          0.61579963+3.74413931j,  1.16670609+4.98799411j,
#          2.44354737+4.51858062j],
#        [-0.2316515 -0.40134811j, -0.43601859-1.74630416j,
#                 nan+0.j        , -1.76208756-0.26915751j,
#                 nan+0.j        ],
#        [ 0.68402922+0.27851329j,  1.01349304-1.04138302j,
#                 nan+0.j        , -0.77923351-0.18900244j,
#                 nan+0.j        ],
#        [-3.48656612-0.5457904j , -2.67411561-1.63693516j,
#                 nan+0.j        , -4.65683883-1.54086353j,
#                 nan+0.j        ],
#        [ 1.18556436+1.78299891j,  2.35562086+1.08899563j,
#                 nan+0.j        ,  0.48888294+0.41393217j,
#                 nan+0.j        ],
#        [-0.27870591+2.61799633j,  1.06838861+2.42823596j,
#          0.96603549+1.07169752j, -0.39428135+1.08621595j,
#         -0.46765826+2.44462993j],
#        [-1.2495626 -2.60810849j,  0.06668083-2.26434132j,
#                 nan+0.j        , -0.76619596-4.06621184j,
#                 nan+0.j        ]])

# %%
EM_theta1_rad, neglhd_1, K1, mu1 = em_dtools_un.multi_start_EM(X1, P_1, 10, max_iter=50, eps=1e-6)
# Out:
# 0-th start
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 EM_theta1_rad, neglhd_1, K1, mu1 = em_dtools_un.multi_start_EM(X1, P_1, 10, max_iter=50, eps=1e-6)
#
# File ~\Desktop\Аспирантура\Диссертация\Компоненты диссертации\Program Complex\EM, deterministic model with missing values and unknown noise\em_dtools_un.py:234, in multi_start_EM(X, M, num_of_starts, max_iter, eps)
#     232 for i in range(num_of_starts):
#     233     print(f'{i}-th start')
# --> 234     theta, S, Q = initializer(X, M)
#     235     est_theta, neg_lhd = EM(theta, S, Q, X, max_iter, eps)
#     236     if neg_lhd < best_neg_lhd:
#
# File ~\Desktop\Аспирантура\Диссертация\Компоненты диссертации\Program Complex\EM, deterministic model with missing values and unknown noise\em_dtools_un.py:115, in initializer(X, M, seed)
#     113 if seed is None:
#     114     seed = 100
# --> 115 theta = np.random.RandomState(seed).uniform(-np.pi, np.pi, M)
#     116 signals = gds(len(X), M, seed=seed+20)
#     117 noise_cov = initial_noise_covariance(X, theta, signals)
#
# File numpy\\random\\mtrand.pyx:1158, in numpy.random.mtrand.RandomState.uniform()
#
# File _common.pyx:636, in numpy.random._common.cont()
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)

# %%
print(f"Погрешность в смысле разности углов в градусах: {np.abs(EM_theta1_deg-theta1_deg)}.\nПогрешность в смысле разности синусов углов {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
