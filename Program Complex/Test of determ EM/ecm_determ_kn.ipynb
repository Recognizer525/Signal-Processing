# %%
import numpy as np
import sensors
import ecm_determ

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
#Q1 = 1.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шума
Q1 = sensors.random_complex_cov(n=Num_sensors1, max_real=1.2, seed=50)
A1 = np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1 = sensors.gds(Num_emitters1, sample_size1)
n1 = sensors.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + n1.T).T
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 7
#       5 theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
#       6 #Q1 = 1.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шума
# ----> 7 Q1 = sensors.random_complex_cov(n=Num_sensors1, max_real=1.2, seed=50)
#       8 A1 = np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad)) # Матрица управляющих векторов
#       9 # Генерация векторов сигнала, шума и принятого сигнала
#
# AttributeError: module 'sensors' has no attribute 'random_complex_cov'

# %%
X1_with_mv = sensors.MCAR(X1, [2,4], [40, 40])

# %%
EM_theta1_rad, EM_S, lhd_1 = ecm_determ.multi_start_ECM_kn(X1_with_mv, 1, Q1, 10, max_iter=30, rtol=1e-3)

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)
print(f"Погрешность в смысле разности углов в градусах: {np.abs(EM_theta1_deg-theta1_deg)},")
print(f"Погрешность в смысле разности синусов углов: {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")

# %%
import numpy as np

# %%
A = np.random.RandomState(42).randn(5,5)

# %%
A
# Out:
# array([[ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986, -0.23415337],
#        [-0.23413696,  1.57921282,  0.76743473, -0.46947439,  0.54256004],
#        [-0.46341769, -0.46572975,  0.24196227, -1.91328024, -1.72491783],
#        [-0.56228753, -1.01283112,  0.31424733, -0.90802408, -1.4123037 ],
#        [ 1.46564877, -0.2257763 ,  0.0675282 , -1.42474819, -0.54438272]])

# %%
# Out:
# Случайная ковариационная матрица:
#  [[ 0.16279714+0.j          0.05418938-0.17775398j -0.02656988-0.05066513j
#   -0.05100209+0.12546186j]
#  [ 0.05418938+0.17775398j  0.31568061+0.j          0.03392068-0.05281619j
#   -0.14467252-0.08532815j]
#  [-0.02656988+0.05066513j  0.03392068+0.05281619j  0.11521243+0.j
#   -0.07701324+0.05051537j]
#  [-0.05100209-0.12546186j -0.14467252+0.08532815j -0.07701324-0.05051537j
#    0.40630982+0.j        ]]
#
# Эрмитовость: True
# Собственные значения: [0.0271687  0.04905638 0.27714761 0.64662731]
# Неотрицательная определённость: True

# %%
# Out:
# np.complex128(-0.06965964841977415j)
