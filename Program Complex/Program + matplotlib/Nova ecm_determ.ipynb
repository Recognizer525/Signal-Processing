# %%
import numpy as np
import matplotlib.pyplot as plt

import sensors
import ecm_determ

# %%
DIST_RATIO = 0.5

Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 70
theta1_rad = np.array([0.5]) # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad) # Направление прибытия (DOA) в градусах
Q1 = sensors.random_complex_cov(n=Num_sensors1, max_real=1.2, seed=50)
A1 = np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) 
            * np.sin(theta1_rad)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1, Amps = sensors.gds(Num_emitters1, sample_size1)
n1 = sensors.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + n1.T).T

# %%
X1_with_mv = sensors.MCAR(X1, [0, 2, 4], [10, 10, 10])
X_full = X1_with_mv[~np.isnan(X1_with_mv).any(axis=1)]
print(X_full.shape)
# Out:
# (42, 5)

# %%
EM_theta1_rad, EM_S, lhd_1, thetas1 = ecm_determ.multi_start_ECM_kn(X=X1_with_mv, K=1, Q=Q1, num_of_starts=12, max_iter=20, rtol=1e-3)
# Out:
# 0-th start
# Initial theta = [-2.83488836]
# new_theta=[0.54029049]
# incomplete likelihood is -151.01884683042 on iteration 0
# new_theta=[-0.56437681]
# incomplete likelihood is -1813.2690513341815 on iteration 1
# new_theta=[0.5549139]
# incomplete likelihood is 113.83168922076209 on iteration 2
# new_theta=[0.53466444]
# incomplete likelihood is 265.7590079070826 on iteration 3
# new_theta=[-0.54518166]
# incomplete likelihood is -1733.7143462035515 on iteration 4
# new_theta=[0.56942754]
# incomplete likelihood is 26.890238869954416 on iteration 5
# new_theta=[0.54550033]
# incomplete likelihood is 211.6912507198996 on iteration 6
# new_theta=[0.53084426]
# incomplete likelihood is 284.52023490086395 on iteration 7
# new_theta=[0.52139441]
# incomplete likelihood is 318.8912822123305 on iteration 8
# new_theta=[0.51526481]
# incomplete likelihood is 335.2163755185357 on iteration 9
# new_theta=[0.51131199]
# incomplete likelihood is 342.92736612732824 on iteration 10
# new_theta=[0.50876563]
# incomplete likelihood is 346.65141560307 on iteration 11
# new_theta=[0.50714552]
# incomplete likelihood is 348.50275743260585 on iteration 12
# new_theta=[0.50610378]
# incomplete likelihood is 349.47599130599616 on iteration 13
# new_theta=[0.50543579]
# incomplete likelihood is 350.0099412850546 on iteration 14
# new_theta=[0.50500641]
# incomplete likelihood is 350.3153837263226 on iteration 15
# new_theta=[0.50473428]
# incomplete likelihood is 350.4935483989579 on iteration 16
# new_theta=[0.5045637]
# incomplete likelihood is 350.59900555150523 on iteration 17
# new_theta=[0.50445418]
# incomplete likelihood is 350.6639701990067 on iteration 18
# new_theta=[0.50439517]
# incomplete likelihood is 350.698419527593 on iteration 19
# 1-th start
# Initial theta = [-2.86887136]
# new_theta=[-0.7171082]
# incomplete likelihood is -2722.543232532173 on iteration 0
# new_theta=[-0.79992182]
# incomplete likelihood is -2196.6905425030172 on iteration 1
# new_theta=[-0.8376214]
# incomplete likelihood is -2129.8235361467614 on iteration 2
# new_theta=[-0.86624512]
# incomplete likelihood is -2104.3221763714855 on iteration 3
# new_theta=[-0.89148178]
# incomplete likelihood is -2087.3773602524197 on iteration 4
# new_theta=[-0.91466501]
# incomplete likelihood is -2073.255423684683 on iteration 5
# new_theta=[-0.93652831]
# incomplete likelihood is -2060.319703766996 on iteration 6
# new_theta=[-0.95746632]
# incomplete likelihood is -2047.959721254126 on iteration 7
# new_theta=[-0.97776405]
# incomplete likelihood is -2035.8973067284785 on iteration 8
# new_theta=[-0.99769103]
# incomplete likelihood is -2023.9735280146635 on iteration 9
# new_theta=[-1.01752747]
# incomplete likelihood is -2012.0739783578588 on iteration 10
# new_theta=[-1.03757294]
# incomplete likelihood is -2000.1015736589188 on iteration 11
# new_theta=[-1.05808814]
# incomplete likelihood is -1987.9954661138872 on iteration 12
# new_theta=[-1.079359]
# incomplete likelihood is -1975.7071714550657 on iteration 13
# new_theta=[-1.10181474]
# incomplete likelihood is -1963.1597767832427 on iteration 14
# new_theta=[-1.12594279]
# incomplete likelihood is -1950.297152294003 on iteration 15
# new_theta=[-1.15240935]
# incomplete likelihood is -1937.0639853887908 on iteration 16
# new_theta=[-1.18201284]
# incomplete likelihood is -1923.4588030434234 on iteration 17
# new_theta=[-1.21624858]
# incomplete likelihood is -1909.422775473125 on iteration 18
# new_theta=[-1.25727906]
# incomplete likelihood is -1894.9924473866217 on iteration 19
# 2-th start
# Initial theta = [-0.32903623]
# new_theta=[-0.8208214]
# incomplete likelihood is -2321.3168146354883 on iteration 0
# new_theta=[-0.81836488]
# incomplete likelihood is -2152.9834807899683 on iteration 1
# new_theta=[-0.84086991]
# incomplete likelihood is -2116.8105555137354 on iteration 2
# new_theta=[-0.86688484]
# incomplete likelihood is -2098.4214422641357 on iteration 3
# new_theta=[-0.89207405]
# incomplete likelihood is -2083.935692302975 on iteration 4
# new_theta=[-0.91577502]
# incomplete likelihood is -2070.810024713536 on iteration 5
# new_theta=[-0.93807417]
# incomplete likelihood is -2058.336469999301 on iteration 6
# new_theta=[-0.95937122]
# incomplete likelihood is -2046.183977066458 on iteration 7
# new_theta=[-0.97995033]
# incomplete likelihood is -2034.2059598088097 on iteration 8
# new_theta=[-1.00006869]
# incomplete likelihood is -2022.3192521135609 on iteration 9
# new_theta=[-1.02004717]
# incomplete likelihood is -2010.433324592752 on iteration 10
# new_theta=[-1.0401871]
# incomplete likelihood is -1998.4733679546475 on iteration 11
# new_theta=[-1.06080607]
# incomplete likelihood is -1986.368789128511 on iteration 12
# new_theta=[-1.08224274]
# incomplete likelihood is -1974.0581572555182 on iteration 13
# new_theta=[-1.10474185]
# incomplete likelihood is -1961.5440294194577 on iteration 14
# new_theta=[-1.12908]
# incomplete likelihood is -1948.6677846156297 on iteration 15
# new_theta=[-1.1558591]
# incomplete likelihood is -1935.4085190548287 on iteration 16
# new_theta=[-1.18601207]
# incomplete likelihood is -1921.739538505995 on iteration 17
# new_theta=[-1.22088702]
# incomplete likelihood is -1907.6738995914086 on iteration 18
# new_theta=[-1.26301991]
# incomplete likelihood is -1893.1952286035266 on iteration 19
# 3-th start
# Initial theta = [2.8344867]
# new_theta=[-0.79690001]
# incomplete likelihood is -2212.210123713372 on iteration 0
# new_theta=[0.35746798]
# incomplete likelihood is -640.5061036041664 on iteration 1
# new_theta=[0.39711186]
# incomplete likelihood is -259.9684316467628 on iteration 2
# new_theta=[0.42874315]
# incomplete likelihood is 13.033428107885587 on iteration 3
# new_theta=[0.45278713]
# incomplete likelihood is 186.70171172533418 on iteration 4
# new_theta=[-0.63259221]
# incomplete likelihood is -2062.098293953523 on iteration 5
# new_theta=[0.51595303]
# incomplete likelihood is 291.94251470069145 on iteration 6
# new_theta=[0.51038843]
# incomplete likelihood is 339.6178384678735 on iteration 7
# new_theta=[0.50785388]
# incomplete likelihood is 345.7351712475461 on iteration 8
# new_theta=[0.50645728]
# incomplete likelihood is 348.0447564221163 on iteration 9
# new_theta=[0.50561435]
# incomplete likelihood is 349.23884672760875 on iteration 10
# new_theta=[0.50509515]
# incomplete likelihood is 349.8945116418681 on iteration 11
# new_theta=[0.50477263]
# incomplete likelihood is 350.26478903477164 on iteration 12
# new_theta=[0.50457326]
# incomplete likelihood is 350.4770028016212 on iteration 13
# new_theta=[0.50444949]
# incomplete likelihood is 350.60049782959317 on iteration 14
# new_theta=[0.50437342]
# incomplete likelihood is 350.672655797207 on iteration 15
# new_theta=[0.50430369]
# incomplete likelihood is 350.7272156714083 on iteration 16
# new_theta=[0.50427539]
# incomplete likelihood is 350.75200721494775 on iteration 17
# new_theta=[0.50427538]
# incomplete likelihood is 350.7576637458876 on iteration 18
# new_theta=[0.50427538]
# incomplete likelihood is 350.7608780130734 on iteration 19
# 4-th start
# Initial theta = [-2.08143765]
# new_theta=[-0.51337213]
# incomplete likelihood is -2519.059185344682 on iteration 0
# new_theta=[-0.43018374]
# incomplete likelihood is -1724.39271473097 on iteration 1
# new_theta=[0.63801326]
# incomplete likelihood is -664.0894995208866 on iteration 2
# new_theta=[0.59475458]
# incomplete likelihood is -199.166644228792 on iteration 3
# new_theta=[0.5655134]
# incomplete likelihood is 66.70070500308886 on iteration 4
# new_theta=[0.5452617]
# incomplete likelihood is 206.78950309021639 on iteration 5
# new_theta=[0.53125972]
# incomplete likelihood is 279.2903503223428 on iteration 6
# new_theta=[0.52179784]
# incomplete likelihood is 315.7139332949963 on iteration 7
# new_theta=[0.51552565]
# incomplete likelihood is 333.4588956754977 on iteration 8
# new_theta=[0.51146072]
# incomplete likelihood is 341.96461548782696 on iteration 9
# new_theta=[0.50887102]
# incomplete likelihood is 346.0893497504395 on iteration 10
# new_theta=[0.50719023]
# incomplete likelihood is 348.2002047253805 on iteration 11
# new_theta=[0.50615372]
# incomplete likelihood is 349.284246898498 on iteration 12
# new_theta=[0.50546187]
# incomplete likelihood is 349.9026531545146 on iteration 13
# new_theta=[0.50503419]
# incomplete likelihood is 350.2461541692176 on iteration 14
# new_theta=[0.50475065]
# incomplete likelihood is 350.4538824887361 on iteration 15
# new_theta=[0.50456905]
# incomplete likelihood is 350.57864176449857 on iteration 16
# new_theta=[0.50445685]
# incomplete likelihood is 350.65252692396996 on iteration 17
# new_theta=[0.50439283]
# incomplete likelihood is 350.69394183477306 on iteration 18
# new_theta=[0.50434684]
# incomplete likelihood is 350.72235302492055 on iteration 19
# 5-th start
# Initial theta = [-1.9246683]
# new_theta=[-0.54950933]
# incomplete likelihood is -2890.783290284887 on iteration 0
# new_theta=[0.55644875]
# incomplete likelihood is -57.01762843629816 on iteration 1
# new_theta=[0.53513663]
# incomplete likelihood is 243.1510111768543 on iteration 2
# new_theta=[0.52332579]
# incomplete likelihood is 312.0025621636571 on iteration 3
# new_theta=[0.51629947]
# incomplete likelihood is 333.36476990113505 on iteration 4
# new_theta=[0.51194064]
# incomplete likelihood is 342.18991037794154 on iteration 5
# new_theta=[0.50919067]
# incomplete likelihood is 346.27784902206076 on iteration 6
# new_theta=[0.50743013]
# incomplete likelihood is 348.30130330234726 on iteration 7
# new_theta=[0.50630225]
# incomplete likelihood is 349.35397596866966 on iteration 8
# new_theta=[0.5055778]
# incomplete likelihood is 349.92962744124833 on iteration 9
# new_theta=[0.50511156]
# incomplete likelihood is 350.25847106355104 on iteration 10
# new_theta=[0.50477408]
# incomplete likelihood is 350.4748305458481 on iteration 11
# new_theta=[0.50459381]
# incomplete likelihood is 350.5845764466126 on iteration 12
# new_theta=[0.50448186]
# incomplete likelihood is 350.65014826545803 on iteration 13
# new_theta=[0.50443327]
# incomplete likelihood is 350.67856014627637 on iteration 14
# new_theta=[0.504351]
# incomplete likelihood is 350.7237597183391 on iteration 15
# new_theta=[0.50431779]
# incomplete likelihood is 350.7419960578963 on iteration 16
# new_theta=[0.50430344]
# incomplete likelihood is 350.7499245788253 on iteration 17
# new_theta=[0.50430337]
# incomplete likelihood is 350.75018768390976 on iteration 18
# new_theta=[0.50430331]
# incomplete likelihood is 350.7503404948894 on iteration 19
# 6-th start
# Initial theta = [0.20336959]
# new_theta=[-0.74721514]
# incomplete likelihood is -2203.0263362859064 on iteration 0
# new_theta=[0.39435198]
# incomplete likelihood is -340.9046457126595 on iteration 1
# new_theta=[-0.68606219]
# incomplete likelihood is -2148.5153710356017 on iteration 2
# new_theta=[0.45710745]
# incomplete likelihood is 173.49159432568413 on iteration 3
# new_theta=[0.47203444]
# incomplete likelihood is 285.21418433712984 on iteration 4
# new_theta=[0.48297498]
# incomplete likelihood is 325.4943039805496 on iteration 5
# new_theta=[0.4904167]
# incomplete likelihood is 342.10433986953063 on iteration 6
# new_theta=[0.49531339]
# incomplete likelihood is 348.5404440110065 on iteration 7
# new_theta=[0.49848392]
# incomplete likelihood is 350.76361666557057 on iteration 8
# new_theta=[0.50053562]
# incomplete likelihood is 351.37213204537153 on iteration 9
# new_theta=[0.50185065]
# incomplete likelihood is 351.4168278608404 on iteration 10
# new_theta=[0.50270434]
# incomplete likelihood is 351.2984313291796 on iteration 11
# new_theta=[0.50325091]
# incomplete likelihood is 351.16150252544577 on iteration 12
# new_theta=[0.50360825]
# incomplete likelihood is 351.04491429004366 on iteration 13
# new_theta=[0.50383815]
# incomplete likelihood is 350.9584659445925 on iteration 14
# new_theta=[0.50398894]
# incomplete likelihood is 350.89645799803765 on iteration 15
# new_theta=[0.50408702]
# incomplete likelihood is 350.8537562963189 on iteration 16
# new_theta=[0.50415093]
# incomplete likelihood is 350.82482808498963 on iteration 17
# new_theta=[0.50419678]
# incomplete likelihood is 350.8033008822544 on iteration 18
# new_theta=[0.50419685]
# incomplete likelihood is 350.80427385751983 on iteration 19
# 7-th start
# Initial theta = [0.98360982]
# new_theta=[-0.65314883]
# incomplete likelihood is -2407.9216897275664 on iteration 0
# new_theta=[0.50015288]
# incomplete likelihood is 280.3216551753964 on iteration 1
# new_theta=[0.50015295]
# incomplete likelihood is 344.83535536359426 on iteration 2
# new_theta=[0.5012784]
# incomplete likelihood is 349.1635252538946 on iteration 3
# new_theta=[0.50223473]
# incomplete likelihood is 350.1496062805472 on iteration 4
# new_theta=[0.50291152]
# incomplete likelihood is 350.5544002404176 on iteration 5
# new_theta=[0.50336608]
# incomplete likelihood is 350.728210537574 on iteration 6
# new_theta=[0.50366662]
# incomplete likelihood is 350.79709774368126 on iteration 7
# new_theta=[0.50386258]
# incomplete likelihood is 350.81983873037393 on iteration 8
# new_theta=[0.504002]
# incomplete likelihood is 350.8173118851454 on iteration 9
# new_theta=[0.50408852]
# incomplete likelihood is 350.8113896998791 on iteration 10
# new_theta=[0.50414401]
# incomplete likelihood is 350.8045369508726 on iteration 11
# new_theta=[0.50420588]
# incomplete likelihood is 350.78502727656445 on iteration 12
# new_theta=[0.5042371]
# incomplete likelihood is 350.77583053198157 on iteration 13
# new_theta=[0.50423735]
# incomplete likelihood is 350.77964055144935 on iteration 14
# new_theta=[0.50423743]
# incomplete likelihood is 350.78183728007804 on iteration 15
# new_theta=[0.50423744]
# incomplete likelihood is 350.7831058581804 on iteration 16
# new_theta=[0.50423763]
# incomplete likelihood is 350.78373083695976 on iteration 17
# new_theta=[0.50424879]
# incomplete likelihood is 350.7783732136433 on iteration 18
# new_theta=[0.50425985]
# incomplete likelihood is 350.77287792358516 on iteration 19
# 8-th start
# Initial theta = [0.51131793]
# new_theta=[0.48342665]
# incomplete likelihood is 277.6077881680051 on iteration 0
# new_theta=[0.49004254]
# incomplete likelihood is 333.0690800182519 on iteration 1
# new_theta=[0.49484998]
# incomplete likelihood is 344.37059091207675 on iteration 2
# new_theta=[0.49810453]
# incomplete likelihood is 348.6240361764339 on iteration 3
# new_theta=[0.50025204]
# incomplete likelihood is 350.2753324235881 on iteration 4
# new_theta=[0.50165166]
# incomplete likelihood is 350.85702756537853 on iteration 5
# new_theta=[0.50255636]
# incomplete likelihood is 351.0168376764214 on iteration 6
# new_theta=[0.50314529]
# incomplete likelihood is 351.0218829318174 on iteration 7
# new_theta=[0.50352072]
# incomplete likelihood is 350.98294863903004 on iteration 8
# new_theta=[0.50377533]
# incomplete likelihood is 350.9321566347244 on iteration 9
# new_theta=[0.50394126]
# incomplete likelihood is 350.88863782662787 on iteration 10
# new_theta=[0.50405076]
# incomplete likelihood is 350.85450768136195 on iteration 11
# new_theta=[0.5041233]
# incomplete likelihood is 350.82911385860797 on iteration 12
# new_theta=[0.50416538]
# incomplete likelihood is 350.8138731913089 on iteration 13
# new_theta=[0.50419423]
# incomplete likelihood is 350.8025669217519 on iteration 14
# new_theta=[0.50421539]
# incomplete likelihood is 350.7936458340706 on iteration 15
# new_theta=[0.50421546]
# incomplete likelihood is 350.794677822507 on iteration 16
# new_theta=[0.50421546]
# incomplete likelihood is 350.795280130825 on iteration 17
# new_theta=[0.50423317]
# incomplete likelihood is 350.78653141463826 on iteration 18
# new_theta=[0.50423545]
# incomplete likelihood is 350.78555525649 on iteration 19
# 9-th start
# Initial theta = [2.72188548]
# new_theta=[-0.56001765]
# incomplete likelihood is -1832.8954230803272 on iteration 0
# new_theta=[0.56367772]
# incomplete likelihood is 14.73782669924336 on iteration 1
# new_theta=[0.54127919]
# incomplete likelihood is 226.88190998421712 on iteration 2
# new_theta=[0.52795628]
# incomplete likelihood is 293.7111813714091 on iteration 3
# new_theta=[-0.55044345]
# incomplete likelihood is -1752.7736686223166 on iteration 4
# new_theta=[0.56716919]
# incomplete likelihood is 41.08707945441646 on iteration 5
# new_theta=[0.5439497]
# incomplete likelihood is 219.8170312414444 on iteration 6
# new_theta=[0.52981573]
# incomplete likelihood is 288.53697262714127 on iteration 7
# new_theta=[0.520703]
# incomplete likelihood is 320.8440212308214 on iteration 8
# new_theta=[0.51481011]
# incomplete likelihood is 336.1424096385303 on iteration 9
# new_theta=[0.51101137]
# incomplete likelihood is 343.3787946464947 on iteration 10
# new_theta=[0.508573]
# incomplete likelihood is 346.87393192778427 on iteration 11
# new_theta=[0.50702001]
# incomplete likelihood is 348.6199459970208 on iteration 12
# new_theta=[0.50602056]
# incomplete likelihood is 349.5419322314986 on iteration 13
# new_theta=[0.50537786]
# incomplete likelihood is 350.05055087678204 on iteration 14
# new_theta=[0.50499416]
# incomplete likelihood is 350.3239650454309 on iteration 15
# new_theta=[0.50473015]
# incomplete likelihood is 350.49650381080465 on iteration 16
# new_theta=[0.50456151]
# incomplete likelihood is 350.60057206993804 on iteration 17
# new_theta=[0.50445383]
# incomplete likelihood is 350.66437645437924 on iteration 18
# new_theta=[0.50438777]
# incomplete likelihood is 350.70251928401757 on iteration 19
# 10-th start
# Initial theta = [-2.17656083]
# new_theta=[-0.48927186]
# incomplete likelihood is -1905.3680370693965 on iteration 0
# new_theta=[-0.44151214]
# incomplete likelihood is -1611.6661129085412 on iteration 1
# new_theta=[0.63213354]
# incomplete likelihood is -560.7286193560802 on iteration 2
# new_theta=[0.59121875]
# incomplete likelihood is -141.967452275337 on iteration 3
# new_theta=[0.56356507]
# incomplete likelihood is 92.22108786187971 on iteration 4
# new_theta=[0.54422031]
# incomplete likelihood is 218.84404702285278 on iteration 5
# new_theta=[0.53074336]
# incomplete likelihood is 285.5242724341086 on iteration 6
# new_theta=[-0.54632445]
# incomplete likelihood is -1744.2047962270365 on iteration 7
# new_theta=[0.56909384]
# incomplete likelihood is 31.466646407596407 on iteration 8
# new_theta=[0.54538939]
# incomplete likelihood is 213.21196605283254 on iteration 9
# new_theta=[0.53082629]
# incomplete likelihood is 285.120861582139 on iteration 10
# new_theta=[0.521408]
# incomplete likelihood is 319.18131555253217 on iteration 11
# new_theta=[0.51529302]
# incomplete likelihood is 335.3562559452564 on iteration 12
# new_theta=[0.51133696]
# incomplete likelihood is 343.00512266002283 on iteration 13
# new_theta=[0.50879074]
# incomplete likelihood is 346.6894094045397 on iteration 14
# new_theta=[0.50716209]
# incomplete likelihood is 348.5258365852986 on iteration 15
# new_theta=[0.50611515]
# incomplete likelihood is 349.4892067362924 on iteration 16
# new_theta=[0.50544582]
# incomplete likelihood is 350.01571790021507 on iteration 17
# new_theta=[0.50501881]
# incomplete likelihood is 350.3148747860508 on iteration 18
# new_theta=[0.50474603]
# incomplete likelihood is 350.49077449012566 on iteration 19
# 11-th start
# Initial theta = [1.08349288]
# new_theta=[-0.61761317]
# incomplete likelihood is -2245.7850901791917 on iteration 0
# new_theta=[0.52321914]
# incomplete likelihood is 246.46110225028087 on iteration 1
# new_theta=[0.51495983]
# incomplete likelihood is 331.03025358188034 on iteration 2
# new_theta=[0.51080732]
# incomplete likelihood is 342.50521444069614 on iteration 3
# new_theta=[0.50835948]
# incomplete likelihood is 346.48627891245724 on iteration 4
# new_theta=[0.50684115]
# incomplete likelihood is 348.4185411687918 on iteration 5
# new_theta=[0.50586925]
# incomplete likelihood is 349.44843716532927 on iteration 6
# new_theta=[0.50527168]
# incomplete likelihood is 350.00273294018825 on iteration 7
# new_theta=[0.50489133]
# incomplete likelihood is 350.3192478075487 on iteration 8
# new_theta=[0.50465668]
# incomplete likelihood is 350.5004461337445 on iteration 9
# new_theta=[0.50451362]
# incomplete likelihood is 350.60527909097453 on iteration 10
# new_theta=[0.50442054]
# incomplete likelihood is 350.6699391547068 on iteration 11
# new_theta=[0.50436027]
# incomplete likelihood is 350.7100857351851 on iteration 12
# new_theta=[0.5043259]
# incomplete likelihood is 350.73275336751914 on iteration 13
# new_theta=[0.50430361]
# incomplete likelihood is 350.74701389518316 on iteration 14
# new_theta=[0.50429967]
# incomplete likelihood is 350.7505208990427 on iteration 15
# new_theta=[0.50429401]
# incomplete likelihood is 350.7543057156044 on iteration 16
# new_theta=[0.50429129]
# incomplete likelihood is 350.7561927544718 on iteration 17
# new_theta=[0.50429002]
# incomplete likelihood is 350.7571224579477 on iteration 18
# new_theta=[0.50428493]
# incomplete likelihood is 350.7599380613693 on iteration 19
# best_start=6

# %%
thetas1[5]
# Out:
# {0: array([-31.48456527]),
#  1: array([31.88216499]),
#  2: array([30.66107012]),
#  3: array([29.98435892]),
#  4: array([29.58178072]),
#  5: array([29.33203829]),
#  6: array([29.17447657]),
#  7: array([29.07360482]),
#  8: array([29.00898203]),
#  9: array([28.9674742]),
#  10: array([28.94076079]),
#  11: array([28.92142431]),
#  12: array([28.91109562]),
#  13: array([28.90468117]),
#  14: array([28.90189733]),
#  15: array([28.8971839]),
#  16: array([28.89528086]),
#  17: array([28.89445884]),
#  18: array([28.89445446]),
#  19: array([28.89445146])}

# %%
theta1_deg
# Out:
# array([28.64788976])

# %%
Q2 = sensors.random_complex_cov(n=Num_sensors1, max_real=8.2, seed=50) # Ковариация шума
# Генерация векторов сигнала, шума и принятого сигнала
n2 = sensors.gss(Num_sensors1, sample_size1, Q2)
X2 = (A1 @ S1.T + n2.T).T

# %%
X2_with_mv = sensors.MCAR(X2, [0, 2, 4], [30, 30, 30])
X2_full = X2_with_mv[~np.isnan(X2_with_mv).any(axis=1)]
print(X2_full.shape)
# Out:
# (8, 5)

# %%
EM_theta2_rad, EM_P2, lhd_2, thetas2 = ecm_determ.multi_start_ECM_kn(X=X2_with_mv, K=1, Q=Q2, num_of_starts=12, max_iter=20, rtol=1e-3)
# Out:
# 0-th start
# Initial theta = [-2.83488836]
# new_theta=[-0.26726649]
# incomplete likelihood is -722.1873656607459 on iteration 0
# new_theta=[-0.24197672]
# incomplete likelihood is -640.9626586104952 on iteration 1
# new_theta=[-0.23087198]
# incomplete likelihood is -596.4678459285886 on iteration 2
# new_theta=[-0.22655106]
# incomplete likelihood is -569.7597556153645 on iteration 3
# new_theta=[-0.22496263]
# incomplete likelihood is -552.7859215340117 on iteration 4
# new_theta=[-0.22444904]
# incomplete likelihood is -541.5039699350272 on iteration 5
# new_theta=[-0.22434755]
# incomplete likelihood is -533.6970337749349 on iteration 6
# new_theta=[-0.22453861]
# incomplete likelihood is -528.0808704848562 on iteration 7
# new_theta=[-0.22476516]
# incomplete likelihood is -523.907696359865 on iteration 8
# new_theta=[-0.22511253]
# incomplete likelihood is -520.7060663250663 on iteration 9
# new_theta=[-0.22548573]
# incomplete likelihood is -518.1879248840596 on iteration 10
# new_theta=[-0.22591894]
# incomplete likelihood is -516.1620660804672 on iteration 11
# new_theta=[-0.22639763]
# incomplete likelihood is -514.5028635767287 on iteration 12
# new_theta=[-0.22689705]
# incomplete likelihood is -513.124346402535 on iteration 13
# new_theta=[-0.22740437]
# incomplete likelihood is -511.96550923027553 on iteration 14
# new_theta=[-0.227933]
# incomplete likelihood is -510.98164808392136 on iteration 15
# new_theta=[-0.22849854]
# incomplete likelihood is -510.1396012881117 on iteration 16
# new_theta=[-0.22905336]
# incomplete likelihood is -509.41508985165007 on iteration 17
# new_theta=[-0.22962082]
# incomplete likelihood is -508.7881873849481 on iteration 18
# new_theta=[-0.23019937]
# incomplete likelihood is -508.243469204422 on iteration 19
# 1-th start
# Initial theta = [-2.86887136]
# new_theta=[-0.28546975]
# incomplete likelihood is -783.1383670070671 on iteration 0
# new_theta=[-0.28319763]
# incomplete likelihood is -676.4661492631249 on iteration 1
# new_theta=[-0.28351903]
# incomplete likelihood is -617.927137953113 on iteration 2
# new_theta=[-0.28450608]
# incomplete likelihood is -583.6927579766982 on iteration 3
# new_theta=[-0.28540493]
# incomplete likelihood is -562.4821089523813 on iteration 4
# new_theta=[-0.2859811]
# incomplete likelihood is -548.5990389518929 on iteration 5
# new_theta=[-0.28625055]
# incomplete likelihood is -539.0362706738882 on iteration 6
# new_theta=[-0.28630094]
# incomplete likelihood is -532.1431497653053 on iteration 7
# new_theta=[-0.28612536]
# incomplete likelihood is -526.9808531752516 on iteration 8
# new_theta=[-0.28584752]
# incomplete likelihood is -522.9929437805956 on iteration 9
# new_theta=[-0.28538243]
# incomplete likelihood is -519.8391868545499 on iteration 10
# new_theta=[-0.28495463]
# incomplete likelihood is -517.2953024681557 on iteration 11
# new_theta=[-0.28443966]
# incomplete likelihood is -515.2168124322462 on iteration 12
# new_theta=[-0.28386926]
# incomplete likelihood is -513.5006388181596 on iteration 13
# new_theta=[-0.28324639]
# incomplete likelihood is -512.0726839915661 on iteration 14
# new_theta=[-0.28261827]
# incomplete likelihood is -510.87644854618526 on iteration 15
# new_theta=[-0.28195425]
# incomplete likelihood is -509.87043405564077 on iteration 16
# new_theta=[-0.2812662]
# incomplete likelihood is -509.021145361754 on iteration 17
# new_theta=[-0.28057075]
# incomplete likelihood is -508.30171565779085 on iteration 18
# new_theta=[-0.27987485]
# incomplete likelihood is -507.6906487611396 on iteration 19
# 2-th start
# Initial theta = [-0.32903623]
# new_theta=[-0.33118624]
# incomplete likelihood is -590.6635695499524 on iteration 0
# new_theta=[-0.32903861]
# incomplete likelihood is -561.4724240597754 on iteration 1
# new_theta=[-0.32767129]
# incomplete likelihood is -544.2820304862097 on iteration 2
# new_theta=[-0.32592195]
# incomplete likelihood is -533.5792940182894 on iteration 3
# new_theta=[-0.32365092]
# incomplete likelihood is -526.5695691258966 on iteration 4
# new_theta=[-0.32117261]
# incomplete likelihood is -521.7459616310666 on iteration 5
# new_theta=[-0.31859086]
# incomplete likelihood is -518.2812857860233 on iteration 6
# new_theta=[-0.31601745]
# incomplete likelihood is -515.6989057821711 on iteration 7
# new_theta=[-0.31347591]
# incomplete likelihood is -513.7166318878056 on iteration 8
# new_theta=[-0.31103667]
# incomplete likelihood is -512.1560252043448 on iteration 9
# new_theta=[-0.30866292]
# incomplete likelihood is -510.90554048759697 on iteration 10
# new_theta=[-0.30639349]
# incomplete likelihood is -509.88674916745896 on iteration 11
# new_theta=[-0.30422392]
# incomplete likelihood is -509.0466124573768 on iteration 12
# new_theta=[-0.30216815]
# incomplete likelihood is -508.3462062120973 on iteration 13
# new_theta=[-0.30020386]
# incomplete likelihood is -507.7581819532279 on iteration 14
# new_theta=[-0.29836212]
# incomplete likelihood is -507.25980620252164 on iteration 15
# new_theta=[-0.29656687]
# incomplete likelihood is -506.8375440973355 on iteration 16
# new_theta=[-0.29487121]
# incomplete likelihood is -506.475996444162 on iteration 17
# new_theta=[-0.29325591]
# incomplete likelihood is -506.1656072993825 on iteration 18
# new_theta=[-0.29169965]
# incomplete likelihood is -505.89869808026214 on iteration 19
# 3-th start
# Initial theta = [2.8344867]
# new_theta=[-0.77285917]
# incomplete likelihood is -597.8867137970723 on iteration 0
# new_theta=[-0.80909458]
# incomplete likelihood is -566.8676271385236 on iteration 1
# new_theta=[-0.84877722]
# incomplete likelihood is -554.6531978690468 on iteration 2
# new_theta=[-0.89055399]
# incomplete likelihood is -545.957280890791 on iteration 3
# new_theta=[-0.93250314]
# incomplete likelihood is -538.8985982757526 on iteration 4
# new_theta=[-0.97405218]
# incomplete likelihood is -532.973736921974 on iteration 5
# new_theta=[-1.01507943]
# incomplete likelihood is -527.955642386639 on iteration 6
# new_theta=[-1.05586926]
# incomplete likelihood is -523.7204858446555 on iteration 7
# new_theta=[-1.09668152]
# incomplete likelihood is -520.1919075227948 on iteration 8
# new_theta=[-1.13866238]
# incomplete likelihood is -517.3481875679723 on iteration 9
# new_theta=[-1.18252622]
# incomplete likelihood is -515.1615197389217 on iteration 10
# new_theta=[-1.22954219]
# incomplete likelihood is -513.6196878744342 on iteration 11
# new_theta=[-1.28185032]
# incomplete likelihood is -512.7154412161202 on iteration 12
# new_theta=[-1.34362125]
# incomplete likelihood is -512.43418586963 on iteration 13
# new_theta=[-1.42748346]
# incomplete likelihood is -512.7610492930778 on iteration 14
# new_theta=[1.4714646]
# incomplete likelihood is -513.6571793562443 on iteration 15
# new_theta=[1.37067259]
# incomplete likelihood is -515.085881257147 on iteration 16
# new_theta=[1.30638158]
# incomplete likelihood is -516.9370031294151 on iteration 17
# new_theta=[1.25525983]
# incomplete likelihood is -519.1224038422927 on iteration 18
# new_theta=[1.21166997]
# incomplete likelihood is -521.5181256303691 on iteration 19
# 4-th start
# Initial theta = [-2.08143765]
# new_theta=[-1.08857314]
# incomplete likelihood is -754.4458380972336 on iteration 0
# new_theta=[-1.15150964]
# incomplete likelihood is -627.8549128256019 on iteration 1
# new_theta=[-1.22654768]
# incomplete likelihood is -582.2242814991788 on iteration 2
# new_theta=[-1.31945564]
# incomplete likelihood is -561.316895271865 on iteration 3
# new_theta=[-1.47091019]
# incomplete likelihood is -550.9736164476642 on iteration 4
# new_theta=[1.36651774]
# incomplete likelihood is -546.263840142603 on iteration 5
# new_theta=[1.26657365]
# incomplete likelihood is -544.8976223178117 on iteration 6
# new_theta=[1.19355582]
# incomplete likelihood is -545.4829048054108 on iteration 7
# new_theta=[1.13413735]
# incomplete likelihood is -546.9821492123198 on iteration 8
# new_theta=[1.08360935]
# incomplete likelihood is -548.5641859606922 on iteration 9
# new_theta=[1.03984955]
# incomplete likelihood is -549.5212064626077 on iteration 10
# new_theta=[1.00158018]
# incomplete likelihood is -549.3214777258579 on iteration 11
# new_theta=[0.96791863]
# incomplete likelihood is -547.6204586710683 on iteration 12
# new_theta=[0.9381635]
# incomplete likelihood is -544.2604503580028 on iteration 13
# new_theta=[0.91166969]
# incomplete likelihood is -539.2485751551459 on iteration 14
# new_theta=[0.88783737]
# incomplete likelihood is -532.7020537736264 on iteration 15
# new_theta=[0.86611939]
# incomplete likelihood is -524.7897060438454 on iteration 16
# new_theta=[0.84600381]
# incomplete likelihood is -515.683241851425 on iteration 17
# new_theta=[0.82708512]
# incomplete likelihood is -505.5211645693967 on iteration 18
# new_theta=[0.80892541]
# incomplete likelihood is -494.38959270965023 on iteration 19
# 5-th start
# Initial theta = [-1.9246683]
# new_theta=[-1.22868127]
# incomplete likelihood is -929.7013071424468 on iteration 0
# new_theta=[-1.30550628]
# incomplete likelihood is -742.099296161823 on iteration 1
# new_theta=[-1.45979232]
# incomplete likelihood is -663.0748219810649 on iteration 2
# new_theta=[1.34407219]
# incomplete likelihood is -622.6853971668601 on iteration 3
# new_theta=[1.22631987]
# incomplete likelihood is -599.1123510110515 on iteration 4
# new_theta=[1.13772357]
# incomplete likelihood is -583.8706681622049 on iteration 5
# new_theta=[1.06496836]
# incomplete likelihood is -572.7072037684188 on iteration 6
# new_theta=[1.00370745]
# incomplete likelihood is -563.0041769513392 on iteration 7
# new_theta=[0.95160624]
# incomplete likelihood is -553.0515697204444 on iteration 8
# new_theta=[0.90698872]
# incomplete likelihood is -541.8060119015112 on iteration 9
# new_theta=[0.86861326]
# incomplete likelihood is -528.7612448065471 on iteration 10
# new_theta=[0.83531834]
# incomplete likelihood is -513.8284743763082 on iteration 11
# new_theta=[0.8060452]
# incomplete likelihood is -497.1889768137652 on iteration 12
# new_theta=[0.77995965]
# incomplete likelihood is -479.1832978251193 on iteration 13
# new_theta=[0.75618619]
# incomplete likelihood is -460.1591331650688 on iteration 14
# new_theta=[0.7342631]
# incomplete likelihood is -440.52872934891974 on iteration 15
# new_theta=[0.71391823]
# incomplete likelihood is -420.77214695981843 on iteration 16
# new_theta=[0.69489293]
# incomplete likelihood is -401.36337037079903 on iteration 17
# new_theta=[0.6770817]
# incomplete likelihood is -382.79893052224094 on iteration 18
# new_theta=[0.66054572]
# incomplete likelihood is -365.58605052685425 on iteration 19
# 6-th start
# Initial theta = [0.20336959]
# new_theta=[-0.83004856]
# incomplete likelihood is -599.8499967816193 on iteration 0
# new_theta=[-0.86950921]
# incomplete likelihood is -566.1142278636081 on iteration 1
# new_theta=[-0.90874901]
# incomplete likelihood is -551.2358474842171 on iteration 2
# new_theta=[-0.94878257]
# incomplete likelihood is -541.536840976712 on iteration 3
# new_theta=[-0.98907166]
# incomplete likelihood is -534.2797202364894 on iteration 4
# new_theta=[-1.02938605]
# incomplete likelihood is -528.538189252331 on iteration 5
# new_theta=[-1.06990968]
# incomplete likelihood is -523.9055821753037 on iteration 6
# new_theta=[-1.11103598]
# incomplete likelihood is -520.177273654758 on iteration 7
# new_theta=[-1.15349486]
# incomplete likelihood is -517.2464868231875 on iteration 8
# new_theta=[-1.19823678]
# incomplete likelihood is -515.0511780444473 on iteration 9
# new_theta=[-1.24682862]
# incomplete likelihood is -513.5587566624924 on iteration 10
# new_theta=[-1.30185151]
# incomplete likelihood is -512.7412351475028 on iteration 11
# new_theta=[-1.36930914]
# incomplete likelihood is -512.5827766524881 on iteration 12
# new_theta=[-1.47237753]
# incomplete likelihood is -513.0366190116503 on iteration 13
# new_theta=[1.42706857]
# incomplete likelihood is -514.0606641815947 on iteration 14
# new_theta=[1.34553512]
# incomplete likelihood is -515.5890194748009 on iteration 15
# new_theta=[1.28667674]
# incomplete likelihood is -517.5499819673171 on iteration 16
# new_theta=[1.23857755]
# incomplete likelihood is -519.7927191930062 on iteration 17
# new_theta=[1.19692122]
# incomplete likelihood is -522.2070434763834 on iteration 18
# new_theta=[1.15990416]
# incomplete likelihood is -524.6302836288196 on iteration 19
# 7-th start
# Initial theta = [0.98360982]
# new_theta=[0.95130984]
# incomplete likelihood is -696.6267508867679 on iteration 0
# new_theta=[0.92825177]
# incomplete likelihood is -630.0024132212369 on iteration 1
# new_theta=[0.8999147]
# incomplete likelihood is -587.3950704292545 on iteration 2
# new_theta=[0.86857302]
# incomplete likelihood is -555.5662133930427 on iteration 3
# new_theta=[0.83663564]
# incomplete likelihood is -528.3645974454555 on iteration 4
# new_theta=[0.80593368]
# incomplete likelihood is -503.0567865602632 on iteration 5
# new_theta=[0.77729566]
# incomplete likelihood is -478.54846912215703 on iteration 6
# new_theta=[0.75108396]
# incomplete likelihood is -454.6470641657376 on iteration 7
# new_theta=[0.72720499]
# incomplete likelihood is -431.54771110761135 on iteration 8
# new_theta=[0.70549151]
# incomplete likelihood is -409.6504338116537 on iteration 9
# new_theta=[0.68574913]
# incomplete likelihood is -389.3765116577479 on iteration 10
# new_theta=[0.66780822]
# incomplete likelihood is -371.05115145057283 on iteration 11
# new_theta=[0.65154603]
# incomplete likelihood is -354.8368015857616 on iteration 12
# new_theta=[0.63686889]
# incomplete likelihood is -340.7123668761317 on iteration 13
# new_theta=[0.62370626]
# incomplete likelihood is -328.526295776071 on iteration 14
# new_theta=[0.61203519]
# incomplete likelihood is -318.1002301952027 on iteration 15
# new_theta=[-0.42691325]
# incomplete likelihood is -606.035716992145 on iteration 16
# new_theta=[-0.41254412]
# incomplete likelihood is -565.9668332344163 on iteration 17
# new_theta=[0.64710548]
# incomplete likelihood is -368.6353104798589 on iteration 18
# new_theta=[0.62750359]
# incomplete likelihood is -337.4618911976857 on iteration 19
# 8-th start
# Initial theta = [0.51131793]
# new_theta=[0.47354414]
# incomplete likelihood is -307.64493086573947 on iteration 0
# new_theta=[0.48299067]
# incomplete likelihood is -279.6933127825726 on iteration 1
# new_theta=[0.49394873]
# incomplete likelihood is -272.0207076259885 on iteration 2
# new_theta=[0.50355763]
# incomplete likelihood is -268.5393776421324 on iteration 3
# new_theta=[-0.56479957]
# incomplete likelihood is -583.8651602641481 on iteration 4
# new_theta=[0.55413151]
# incomplete likelihood is -303.7792072245143 on iteration 5
# new_theta=[0.54535581]
# incomplete likelihood is -280.306919881958 on iteration 6
# new_theta=[0.54206173]
# incomplete likelihood is -274.99428987284745 on iteration 7
# new_theta=[0.54082199]
# incomplete likelihood is -272.7243848234661 on iteration 8
# new_theta=[0.54053303]
# incomplete likelihood is -271.48196594431965 on iteration 9
# new_theta=[0.54073859]
# incomplete likelihood is -270.7763843306622 on iteration 10
# new_theta=[0.54113017]
# incomplete likelihood is -270.3649124096726 on iteration 11
# new_theta=[0.5416161]
# incomplete likelihood is -270.13929726432264 on iteration 12
# new_theta=[0.54212726]
# incomplete likelihood is -270.0274866065661 on iteration 13
# new_theta=[0.54261713]
# incomplete likelihood is -269.9818378944125 on iteration 14
# new_theta=[0.54308541]
# incomplete likelihood is -269.9816749921885 on iteration 15
# new_theta=[0.54351426]
# incomplete likelihood is -270.00626946935654 on iteration 16
# new_theta=[0.54389806]
# incomplete likelihood is -270.0436264451625 on iteration 17
# new_theta=[0.54423989]
# incomplete likelihood is -270.08778439801034 on iteration 18
# new_theta=[0.5445401]
# incomplete likelihood is -270.1336775332787 on iteration 19
# 9-th start
# Initial theta = [2.72188548]
# new_theta=[-0.60286938]
# incomplete likelihood is -590.2601425300707 on iteration 0
# new_theta=[-0.60771008]
# incomplete likelihood is -572.0347108547425 on iteration 1
# new_theta=[-0.60556144]
# incomplete likelihood is -569.2933524208045 on iteration 2
# new_theta=[-0.60243351]
# incomplete likelihood is -567.8888396854838 on iteration 3
# new_theta=[0.51618046]
# incomplete likelihood is -301.8737749369903 on iteration 4
# new_theta=[0.51439885]
# incomplete likelihood is -277.3006777159983 on iteration 5
# new_theta=[0.5180029]
# incomplete likelihood is -272.4981791375211 on iteration 6
# new_theta=[0.52234319]
# incomplete likelihood is -270.5195920630357 on iteration 7
# new_theta=[0.52631487]
# incomplete likelihood is -269.5724250467607 on iteration 8
# new_theta=[0.52969258]
# incomplete likelihood is -269.1462267246703 on iteration 9
# new_theta=[0.53252515]
# incomplete likelihood is -269.0080676264199 on iteration 10
# new_theta=[0.53484612]
# incomplete likelihood is -269.0134353206894 on iteration 11
# new_theta=[0.53675601]
# incomplete likelihood is -269.09436804880494 on iteration 12
# new_theta=[0.53833489]
# incomplete likelihood is -269.2118211168225 on iteration 13
# new_theta=[0.53964109]
# incomplete likelihood is -269.34188252993465 on iteration 14
# new_theta=[0.540726]
# incomplete likelihood is -269.4726184296403 on iteration 15
# new_theta=[0.54162944]
# incomplete likelihood is -269.5973063377083 on iteration 16
# new_theta=[0.54238408]
# incomplete likelihood is -269.7128458309868 on iteration 17
# new_theta=[0.54301102]
# incomplete likelihood is -269.81607575033513 on iteration 18
# new_theta=[0.5435412]
# incomplete likelihood is -269.91042287310245 on iteration 19
# 10-th start
# Initial theta = [-2.17656083]
# new_theta=[-0.99008457]
# incomplete likelihood is -680.7378979497996 on iteration 0
# new_theta=[-1.04152441]
# incomplete likelihood is -599.3546752451625 on iteration 1
# new_theta=[-1.09323974]
# incomplete likelihood is -565.9795919783742 on iteration 2
# new_theta=[-1.14500649]
# incomplete likelihood is -547.9573114787938 on iteration 3
# new_theta=[-1.1984547]
# incomplete likelihood is -536.871221966289 on iteration 4
# new_theta=[-1.25624187]
# incomplete likelihood is -529.6645744565129 on iteration 5
# new_theta=[-1.32275921]
# incomplete likelihood is -524.9698433290172 on iteration 6
# new_theta=[-1.40994739]
# incomplete likelihood is -522.0747456596015 on iteration 7
# new_theta=[-1.57070771]
# incomplete likelihood is -519.6938343662214 on iteration 8
# new_theta=[1.38724344]
# incomplete likelihood is -519.2349080969619 on iteration 9
# new_theta=[1.31220933]
# incomplete likelihood is -519.6614842684222 on iteration 10
# new_theta=[1.25511163]
# incomplete likelihood is -520.7770293715055 on iteration 11
# new_theta=[1.20771933]
# incomplete likelihood is -522.3410447364096 on iteration 12
# new_theta=[1.16652606]
# incomplete likelihood is -524.155314742269 on iteration 13
# new_theta=[1.12982052]
# incomplete likelihood is -526.0127950686357 on iteration 14
# new_theta=[1.09679429]
# incomplete likelihood is -527.6841469282034 on iteration 15
# new_theta=[1.066568]
# incomplete likelihood is -529.0173640418064 on iteration 16
# new_theta=[1.03889983]
# incomplete likelihood is -529.8181850668198 on iteration 17
# new_theta=[1.01346809]
# incomplete likelihood is -529.9557362953976 on iteration 18
# new_theta=[0.9900013]
# incomplete likelihood is -529.34094032783 on iteration 19
# 11-th start
# Initial theta = [1.08349288]
# new_theta=[-0.08477579]
# incomplete likelihood is -697.1970893467554 on iteration 0
# new_theta=[-0.06588786]
# incomplete likelihood is -623.9866813352515 on iteration 1
# new_theta=[-0.05424885]
# incomplete likelihood is -583.0746029381253 on iteration 2
# new_theta=[-0.04755041]
# incomplete likelihood is -559.5259122341 on iteration 3
# new_theta=[-0.043559]
# incomplete likelihood is -545.2512429656676 on iteration 4
# new_theta=[-0.04095184]
# incomplete likelihood is -536.1684985555772 on iteration 5
# new_theta=[-0.03898133]
# incomplete likelihood is -530.1908334424228 on iteration 6
# new_theta=[-0.03723359]
# incomplete likelihood is -526.1835831599798 on iteration 7
# new_theta=[-0.03549342]
# incomplete likelihood is -523.485211372914 on iteration 8
# new_theta=[-0.03363579]
# incomplete likelihood is -521.69043392237 on iteration 9
# new_theta=[-0.03160488]
# incomplete likelihood is -520.538599153988 on iteration 10
# new_theta=[-0.02931114]
# incomplete likelihood is -519.8697856273503 on iteration 11
# new_theta=[-0.02671529]
# incomplete likelihood is -519.5761135656228 on iteration 12
# new_theta=[-0.02380812]
# incomplete likelihood is -519.5813281599786 on iteration 13
# new_theta=[-0.02054654]
# incomplete likelihood is -519.8412532101231 on iteration 14
# new_theta=[-0.0168377]
# incomplete likelihood is -520.34198101601 on iteration 15
# new_theta=[-0.01265267]
# incomplete likelihood is -521.0638319779624 on iteration 16
# new_theta=[-0.00797595]
# incomplete likelihood is -521.9862575470075 on iteration 17
# new_theta=[-0.00270937]
# incomplete likelihood is -523.1132869319497 on iteration 18
# new_theta=[1.35402856]
# incomplete likelihood is -562.9894452158444 on iteration 19
# best_start=9

# %%
thetas2[9]
# Out:
# {0: array([-34.54187091]),
#  1: array([-34.81922255]),
#  2: array([-34.69611448]),
#  3: array([-34.51689731]),
#  4: array([29.57496195]),
#  5: array([29.47288336]),
#  6: array([29.67937968]),
#  7: array([29.92806041]),
#  8: array([30.15562054]),
#  9: array([30.34914941]),
#  10: array([30.51144335]),
#  11: array([30.64442514]),
#  12: array([30.75385394]),
#  13: array([30.84431731]),
#  14: array([30.91915692]),
#  15: array([30.98131768]),
#  16: array([31.03308094]),
#  17: array([31.07631878]),
#  18: array([31.11223957]),
#  19: array([31.14261702])}

# %%
SNR1 = np.round(Amps/np.trace(Q1),3).real
SNR2 = np.round(Amps/np.trace(Q2),3).real
print(SNR1)
print(SNR2)
# Out:
# 0.824
# 0.121
