# %%
import numpy as np
import sensors
import ecm_determ

# %%
DIST_RATIO = 0.5

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
Q1 = sensors.random_complex_cov(n=Num_sensors1, max_real=1.2, seed=50)
A1 = np.exp(-2j * np.pi * DIST_RATIO * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1 = sensors.gds(Num_emitters1, sample_size1)
n1 = sensors.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + n1.T).T

# %%
Q1
# Out:
# array([[ 0.22495513+0.00000000e+00j, -0.01167394-4.13836956e-02j,
#         -0.08922484+3.37231581e-02j, -0.05955291-1.45246229e-02j,
#          0.05977694+8.68516572e-03j],
#        [-0.01167394+4.13836956e-02j,  0.29023804+0.00000000e+00j,
#          0.03597857-5.69580969e-02j, -0.04056085-2.90146847e-02j,
#          0.04223802+6.85719848e-02j],
#        [-0.08922484-3.37231581e-02j,  0.03597857+5.69580969e-02j,
#          0.11671479+0.00000000e+00j,  0.09723314-6.22457230e-02j,
#         -0.08722819+7.45769082e-03j],
#        [-0.05955291+1.45246229e-02j, -0.04056085+2.90146847e-02j,
#          0.09723314+6.22457230e-02j,  0.38634278+0.00000000e+00j,
#         -0.08341107-1.52086306e-01j],
#        [ 0.05977694-8.68516572e-03j,  0.04223802-6.85719848e-02j,
#         -0.08722819-7.45769082e-03j, -0.08341107+1.52086306e-01j,
#          0.18174926-1.74652275e-19j]])

# %%
X1_with_mv = sensors.MCAR(X1, [2,4], [40, 40])

# %%
EM_theta1_rad, EM_S, lhd_1 = ecm_determ.multi_start_ECM_kn(X1_with_mv, 1, Q1, 10, max_iter=30, rtol=1e-3)
# Out:
# 0-th start
# Initial theta = [-2.83488836]
# new_theta=[22.32853972]
# incomplete likelihood is -2839.43346702071 on iteration 0
# new_theta=[-103.34489928]
# incomplete likelihood is -2376.8033700526576 on iteration 1
# new_theta=[-103.34552227]
# incomplete likelihood is -2144.1594187107667 on iteration 2
# new_theta=[-38.02901671]
# incomplete likelihood is -2020.0162530275816 on iteration 3
# new_theta=[-38.03239956]
# incomplete likelihood is -1952.0746507152112 on iteration 4
# new_theta=[62.49555043]
# incomplete likelihood is -1913.7889777430646 on iteration 5
# new_theta=[62.49308606]
# incomplete likelihood is -1891.243762397529 on iteration 6
# new_theta=[72.59743197]
# incomplete likelihood is -1877.1595629166432 on iteration 7
# new_theta=[72.5992065]
# incomplete likelihood is -1867.7623887529667 on iteration 8
# new_theta=[72.60071689]
# incomplete likelihood is -1861.1289864516937 on iteration 9
# new_theta=[72.6020276]
# incomplete likelihood is -1856.2149031935428 on iteration 10
# new_theta=[78.88639581]
# incomplete likelihood is -1852.436109001657 on iteration 11
# new_theta=[78.88750476]
# incomplete likelihood is -1849.451694761261 on iteration 12
# new_theta=[78.88849765]
# incomplete likelihood is -1847.0683167066059 on iteration 13
# new_theta=[-78.1902324]
# incomplete likelihood is -1845.1446435179025 on iteration 14
# new_theta=[81.33101803]
# incomplete likelihood is -1843.586163454374 on iteration 15
# new_theta=[659.38329016]
# incomplete likelihood is -1842.3088913519134 on iteration 16
# new_theta=[78.89169226]
# incomplete likelihood is -1841.2657411144503 on iteration 17
# new_theta=[78.89230704]
# incomplete likelihood is -1840.4185810577496 on iteration 18
# new_theta=[78.89287335]
# incomplete likelihood is -1839.7244958901263 on iteration 19
# new_theta=[22.34471059]
# incomplete likelihood is -1839.1579467513152 on iteration 20
# new_theta=[22.34518033]
# incomplete likelihood is -1838.6919250688122 on iteration 21
# new_theta=[22.34560468]
# incomplete likelihood is -1838.309903332747 on iteration 22
# new_theta=[37.34430183]
# incomplete likelihood is -1838.0011049571306 on iteration 23
# new_theta=[-71.90146072]
# incomplete likelihood is -1837.7411318312284 on iteration 24
# new_theta=[-71.90113701]
# incomplete likelihood is -1837.527135610598 on iteration 25
# new_theta=[-71.90084176]
# incomplete likelihood is -1837.349992512769 on iteration 26
# new_theta=[-71.90057939]
# incomplete likelihood is -1837.2040171925319 on iteration 27
# new_theta=[-71.90033884]
# incomplete likelihood is -1837.0823959054612 on iteration 28
# new_theta=[81.32489942]
# incomplete likelihood is -1836.981184739943 on iteration 29
# 1-th start
# Initial theta = [-2.86887136]
# new_theta=[43.66642215]
# incomplete likelihood is -3937.031782343715 on iteration 0
# new_theta=[43.66675075]
# incomplete likelihood is -3073.484528640597 on iteration 1
# new_theta=[163.0446427]
# incomplete likelihood is -2601.906150612324 on iteration 2
# new_theta=[-185.03144791]
# incomplete likelihood is -2334.081811691705 on iteration 3
# new_theta=[-151.12402212]
# incomplete likelihood is -2176.036043446751 on iteration 4
# new_theta=[-210.15406422]
# incomplete likelihood is -2078.7660626205484 on iteration 5
# new_theta=[93.910443]
# incomplete likelihood is -2015.9894063051752 on iteration 6
# new_theta=[-99.82987856]
# incomplete likelihood is -1499.1510973038658 on iteration 7
# new_theta=[21.34067754]
# incomplete likelihood is -1021.2000559745107 on iteration 8
# new_theta=[0.61101317]
# incomplete likelihood is -535.9744970135466 on iteration 9
# new_theta=[-40.38404463]
# incomplete likelihood is -2024.1228291267075 on iteration 10
# new_theta=[43.55127762]
# incomplete likelihood is -1932.5670076873378 on iteration 11
# new_theta=[690.73156847]
# incomplete likelihood is -1895.9037656104322 on iteration 12
# new_theta=[-71.84598903]
# incomplete likelihood is -1876.1034854693999 on iteration 13
# new_theta=[580.54941994]
# incomplete likelihood is -876.3838321130107 on iteration 14
# new_theta=[605.7226934]
# incomplete likelihood is -399.0281796150156 on iteration 15
# new_theta=[-140.90474328]
# incomplete likelihood is -1986.8098396061414 on iteration 16
# new_theta=[-126.10507945]
# incomplete likelihood is -1908.8045306468237 on iteration 17
# new_theta=[-88.39277217]
# incomplete likelihood is -1879.4708855088236 on iteration 18
# new_theta=[91.52478667]
# incomplete likelihood is -1864.4656711995328 on iteration 19
# new_theta=[-78.12911886]
# incomplete likelihood is -1855.896126827695 on iteration 20
# new_theta=[-49.61935558]
# incomplete likelihood is -897.0696087686727 on iteration 21
# new_theta=[27.6685808]
# incomplete likelihood is -418.845293196349 on iteration 22
# new_theta=[57.12429213]
# incomplete likelihood is -70.57562642646994 on iteration 23
# new_theta=[57.10210655]
# incomplete likelihood is 141.2673487355708 on iteration 24
# new_theta=[31.95349861]
# incomplete likelihood is 260.70218470030096 on iteration 25
# new_theta=[50.79201754]
# incomplete likelihood is 326.8614080749674 on iteration 26
# new_theta=[38.2181312]
# incomplete likelihood is 362.8884820992771 on iteration 27
# new_theta=[-238.24709368]
# incomplete likelihood is 382.4953755261298 on iteration 28
# new_theta=[74.83906392]
# incomplete likelihood is -2326.3646503408813 on iteration 29
# 2-th start
# Initial theta = [-0.32903623]
# new_theta=[575.70796551]
# incomplete likelihood is -2801.2903948460325 on iteration 0
# new_theta=[-39.94897078]
# incomplete likelihood is -2394.656365998813 on iteration 1
# new_theta=[-27.32035424]
# incomplete likelihood is -2272.1537535574407 on iteration 2
# new_theta=[-20.98857926]
# incomplete likelihood is -2200.068831594036 on iteration 3
# new_theta=[60.73541663]
# incomplete likelihood is -2146.0592453142153 on iteration 4
# new_theta=[67.05888325]
# incomplete likelihood is -2101.761543439607 on iteration 5
# new_theta=[-38.82495832]
# incomplete likelihood is -2064.184378076226 on iteration 6
# new_theta=[-39.67208913]
# incomplete likelihood is -2032.1921025543033 on iteration 7
# new_theta=[161.43754428]
# incomplete likelihood is -2005.602400756553 on iteration 8
# new_theta=[-1.86815156]
# incomplete likelihood is -1984.9085307339883 on iteration 9
# new_theta=[-1.34850286]
# incomplete likelihood is -1971.1262435978003 on iteration 10
# new_theta=[-1.4840121]
# incomplete likelihood is -1965.7981525962161 on iteration 11
# new_theta=[-36.32445473]
# incomplete likelihood is -1970.7954936713413 on iteration 12
# new_theta=[-143.2421928]
# incomplete likelihood is -1987.647346627486 on iteration 13
# new_theta=[-149.60958209]
# incomplete likelihood is -2016.7204349217125 on iteration 14
# new_theta=[-17.73900254]
# incomplete likelihood is -2055.875193688489 on iteration 15
# new_theta=[-23.03021727]
# incomplete likelihood is -2098.1293787303575 on iteration 16
# new_theta=[121.55044875]
# incomplete likelihood is -2130.68587146042 on iteration 17
# new_theta=[-15.53219364]
# incomplete likelihood is -2078.8878274065924 on iteration 18
# new_theta=[-0.19233124]
# incomplete likelihood is -2033.9049223923375 on iteration 19
# new_theta=[-21.78134495]
# incomplete likelihood is -2000.7627422659286 on iteration 20
# new_theta=[-132.1740419]
# incomplete likelihood is -1974.8799663120346 on iteration 21
# new_theta=[53.6507141]
# incomplete likelihood is -1953.4748391712908 on iteration 22
# new_theta=[-141.1128485]
# incomplete likelihood is -1935.0371458881448 on iteration 23
# new_theta=[68.84254739]
# incomplete likelihood is -1918.8847216575232 on iteration 24
# new_theta=[288.74190083]
# incomplete likelihood is -1904.7714595783136 on iteration 25
# new_theta=[22.28637879]
# incomplete likelihood is -1892.580757733139 on iteration 26
# new_theta=[-128.50086158]
# incomplete likelihood is -1882.2396480939308 on iteration 27
# new_theta=[5.97080195]
# incomplete likelihood is -1873.616570185996 on iteration 28
# new_theta=[-112.36995513]
# incomplete likelihood is -1677.4765299187636 on iteration 29
# 3-th start
# Initial theta = [2.8344867]
# new_theta=[142.11752033]
# incomplete likelihood is -2631.3606676841905 on iteration 0
# new_theta=[-27.46937364]
# incomplete likelihood is -2433.401367761276 on iteration 1
# new_theta=[-38.55662178]
# incomplete likelihood is -2352.051277876237 on iteration 2
# new_theta=[24.22842623]
# incomplete likelihood is -2290.1690637102197 on iteration 3
# new_theta=[17.90362346]
# incomplete likelihood is -2237.6178871248176 on iteration 4
# new_theta=[10.40855955]
# incomplete likelihood is -2191.2941228278173 on iteration 5
# new_theta=[80.66211946]
# incomplete likelihood is -2149.720800211321 on iteration 6
# new_theta=[-46.07029664]
# incomplete likelihood is -2112.127095230984 on iteration 7
# new_theta=[-177.0171102]
# incomplete likelihood is -2078.0271004303777 on iteration 8
# new_theta=[909.93855683]
# incomplete likelihood is -2047.2767975703905 on iteration 9
# new_theta=[98.55071496]
# incomplete likelihood is -2019.9183542004114 on iteration 10
# new_theta=[4.34533275]
# incomplete likelihood is -1996.3496149406405 on iteration 11
# new_theta=[-38.95258685]
# incomplete likelihood is -1977.2790313594276 on iteration 12
# new_theta=[-1.31643682]
# incomplete likelihood is -1963.8247210192567 on iteration 13
# new_theta=[-1.73242506]
# incomplete likelihood is -1957.4658229753145 on iteration 14
# new_theta=[-1.57080374]
# incomplete likelihood is -1951.5395872936847 on iteration 15
# new_theta=[-1.57080249]
# incomplete likelihood is -1936.1852680977668 on iteration 16
# new_theta=[70.46970739]
# incomplete likelihood is -1949.4240910140752 on iteration 17
# new_theta=[51.52164299]
# incomplete likelihood is -1975.5349427645288 on iteration 18
# new_theta=[-17.67565582]
# incomplete likelihood is -2014.553710087729 on iteration 19
# new_theta=[-5.18416561]
# incomplete likelihood is -2063.3538182882485 on iteration 20
# new_theta=[33.52862884]
# incomplete likelihood is -2113.747240213713 on iteration 21
# new_theta=[-24.1697676]
# incomplete likelihood is -2151.5330302035914 on iteration 22
# new_theta=[-12.74548884]
# incomplete likelihood is -2087.3064026452757 on iteration 23
# new_theta=[-28.07975921]
# incomplete likelihood is -2039.597320910113 on iteration 24
# new_theta=[34.76863341]
# incomplete likelihood is -2004.5584203906747 on iteration 25
# new_theta=[47.35163155]
# incomplete likelihood is -1977.3520319593806 on iteration 26
# new_theta=[51.08682543]
# incomplete likelihood is -2027.3972087530599 on iteration 27
# new_theta=[15.98890828]
# incomplete likelihood is -1934.5451862286877 on iteration 28
# new_theta=[-128.5143778]
# incomplete likelihood is -1913.0111719468161 on iteration 29
# 4-th start
# Initial theta = [-2.08143765]
# new_theta=[35.55723399]
# incomplete likelihood is -3931.582761179605 on iteration 0
# new_theta=[79.56524613]
# incomplete likelihood is -2939.62010106322 on iteration 1
# new_theta=[-7.33679487]
# incomplete likelihood is -2557.4663060660573 on iteration 2
# new_theta=[-19.93355408]
# incomplete likelihood is -2364.0991394746875 on iteration 3
# new_theta=[-27.15717621]
# incomplete likelihood is -2246.104299875254 on iteration 4
# new_theta=[167.65852376]
# incomplete likelihood is -2165.6279289284325 on iteration 5
# new_theta=[-38.8957287]
# incomplete likelihood is -2107.489894998818 on iteration 6
# new_theta=[-51.51322649]
# incomplete likelihood is -2065.078606460361 on iteration 7
# new_theta=[-57.86257832]
# incomplete likelihood is -2035.789684884626 on iteration 8
# new_theta=[-39.42508287]
# incomplete likelihood is -2019.2635818844797 on iteration 9
# new_theta=[-36.27804357]
# incomplete likelihood is -2016.5179821286545 on iteration 10
# new_theta=[-30.11911875]
# incomplete likelihood is -2029.060577936636 on iteration 11
# new_theta=[-16.91130914]
# incomplete likelihood is -2057.619524954595 on iteration 12
# new_theta=[165.38402618]
# incomplete likelihood is -2100.0877004747704 on iteration 13
# new_theta=[33.51430999]
# incomplete likelihood is -2148.946366616597 on iteration 14
# new_theta=[50.13052296]
# incomplete likelihood is -2131.870387728477 on iteration 15
# new_theta=[40.99019936]
# incomplete likelihood is -2076.6927818917593 on iteration 16
# new_theta=[56.38216677]
# incomplete likelihood is -2037.6790086180918 on iteration 17
# new_theta=[28.45916464]
# incomplete likelihood is -2009.2606673012087 on iteration 18
# new_theta=[-141.16824214]
# incomplete likelihood is -1987.3858442309695 on iteration 19
# new_theta=[392.92048788]
# incomplete likelihood is -1969.1635779165392 on iteration 20
# new_theta=[176.7538179]
# incomplete likelihood is -2086.2958432871533 on iteration 21
# new_theta=[15.9856951]
# incomplete likelihood is -1933.4919936921222 on iteration 22
# new_theta=[-141.08434408]
# incomplete likelihood is -1914.210733499646 on iteration 23
# new_theta=[307.57966357]
# incomplete likelihood is -1899.611974944863 on iteration 24
# new_theta=[-132.25156658]
# incomplete likelihood is -1888.1310887616862 on iteration 25
# new_theta=[5.97117531]
# incomplete likelihood is -1878.90449003013 on iteration 26
# new_theta=[91.42462539]
# incomplete likelihood is -1871.4025029621243 on iteration 27
# new_theta=[0.72148624]
# incomplete likelihood is -1647.012429775236 on iteration 28
# new_theta=[-46.75954447]
# incomplete likelihood is -1859.4729587692887 on iteration 29
# 5-th start
# Initial theta = [-1.9246683]
# new_theta=[-40.28877052]
# incomplete likelihood is -5408.563529955967 on iteration 0
# new_theta=[464.52274219]
# incomplete likelihood is -2524.1582698757684 on iteration 1
# new_theta=[483.40275582]
# incomplete likelihood is -2141.400495410743 on iteration 2
# new_theta=[24.74004548]
# incomplete likelihood is -1992.6127963487863 on iteration 3
# new_theta=[-12.9541194]
# incomplete likelihood is -1924.2726923948965 on iteration 4
# new_theta=[53.79102309]
# incomplete likelihood is -1890.4415432311866 on iteration 5
# new_theta=[53.78773865]
# incomplete likelihood is -1872.2933113248328 on iteration 6
# new_theta=[-316.92301394]
# incomplete likelihood is -1861.6699365896689 on iteration 7
# new_theta=[-316.92541419]
# incomplete likelihood is -1854.9282815916283 on iteration 8
# new_theta=[-316.92745656]
# incomplete likelihood is -1850.3562554302612 on iteration 9
# new_theta=[-316.92913589]
# incomplete likelihood is -1847.077264376913 on iteration 10
# new_theta=[-316.93053188]
# incomplete likelihood is -1844.6427559732724 on iteration 11
# new_theta=[244.67511843]
# incomplete likelihood is -1842.8039890073298 on iteration 12
# new_theta=[244.67614856]
# incomplete likelihood is -1841.3818474144323 on iteration 13
# new_theta=[244.67704907]
# incomplete likelihood is -1840.2757298219312 on iteration 14
# new_theta=[244.67782608]
# incomplete likelihood is -1839.4054315966046 on iteration 15
# new_theta=[244.67849942]
# incomplete likelihood is -1838.7171762911275 on iteration 16
# new_theta=[244.6790877]
# incomplete likelihood is -1838.1715966875163 on iteration 17
# new_theta=[-27.9097263]
# incomplete likelihood is -1837.7416635213015 on iteration 18
# new_theta=[-25.49688023]
# incomplete likelihood is -1837.3997825380927 on iteration 19
# new_theta=[-31.77966837]
# incomplete likelihood is -1837.1243266764925 on iteration 20
# new_theta=[-31.77928279]
# incomplete likelihood is -1836.9121309616535 on iteration 21
# new_theta=[-31.77893631]
# incomplete likelihood is -1836.7443337628529 on iteration 22
# new_theta=[-31.77862455]
# incomplete likelihood is -1836.6119298236667 on iteration 23
# new_theta=[-31.77834072]
# incomplete likelihood is -1836.508321372068 on iteration 24
# new_theta=[-31.77808206]
# incomplete likelihood is -1836.4276438305783 on iteration 25
# new_theta=[-31.7778072]
# incomplete likelihood is -1836.372287362676 on iteration 26
# new_theta=[-31.77760737]
# incomplete likelihood is -1836.3212265792072 on iteration 27
# new_theta=[-31.77741411]
# incomplete likelihood is -1836.2841180536748 on iteration 28
# new_theta=[-31.77723325]
# incomplete likelihood is -1836.2570189050964 on iteration 29
# 6-th start
# Initial theta = [0.20336959]
# new_theta=[74.59011449]
# incomplete likelihood is -2669.036986813104 on iteration 0
# new_theta=[249.04380695]
# incomplete likelihood is -2421.632372259294 on iteration 1
# new_theta=[4.04531558]
# incomplete likelihood is -2322.926535569495 on iteration 2
# new_theta=[17.90445866]
# incomplete likelihood is -2256.2141494316124 on iteration 3
# new_theta=[10.40788647]
# incomplete likelihood is -2202.59054411358 on iteration 4
# new_theta=[16.72678057]
# incomplete likelihood is -2156.702280402858 on iteration 5
# new_theta=[1135.16834373]
# incomplete likelihood is -2116.29392159322 on iteration 6
# new_theta=[85.91090579]
# incomplete likelihood is -2080.287602884301 on iteration 7
# new_theta=[-46.00031985]
# incomplete likelihood is -2048.151224689835 on iteration 8
# new_theta=[-45.96233267]
# incomplete likelihood is -2019.814673053147 on iteration 9
# new_theta=[-38.90333217]
# incomplete likelihood is -1995.4719831436717 on iteration 10
# new_theta=[99.27677231]
# incomplete likelihood is -1975.8030112265792 on iteration 11
# new_theta=[-32.73315176]
# incomplete likelihood is -1961.843925348279 on iteration 12
# new_theta=[-1.41045435]
# incomplete likelihood is -1955.0690091671222 on iteration 13
# new_theta=[77.09697202]
# incomplete likelihood is -1957.2929426209794 on iteration 14
# new_theta=[-10.74420769]
# incomplete likelihood is -1970.3386925213185 on iteration 15
# new_theta=[20.76077662]
# incomplete likelihood is -1995.5740486322425 on iteration 16
# new_theta=[-17.69711499]
# incomplete likelihood is -2032.3727393917586 on iteration 17
# new_theta=[26.21285416]
# incomplete likelihood is -2076.7519014629174 on iteration 18
# new_theta=[33.54580597]
# incomplete likelihood is -2119.63980314684 on iteration 19
# new_theta=[-60.63745253]
# incomplete likelihood is -2146.0299423811853 on iteration 20
# new_theta=[-44.17162445]
# incomplete likelihood is -2079.7532021482507 on iteration 21
# new_theta=[-310.81280058]
# incomplete likelihood is -2031.2390285473941 on iteration 22
# new_theta=[-12.78768951]
# incomplete likelihood is -1995.6562541685928 on iteration 23
# new_theta=[355.23754564]
# incomplete likelihood is -1968.1677150644803 on iteration 24
# new_theta=[58.88030723]
# incomplete likelihood is -1989.8971276634186 on iteration 25
# new_theta=[122.81260705]
# incomplete likelihood is -1924.8682977657645 on iteration 26
# new_theta=[214.38140151]
# incomplete likelihood is -1768.5530400677312 on iteration 27
# new_theta=[-9.08683605]
# incomplete likelihood is -1886.5919103755411 on iteration 28
# new_theta=[-9.08497841]
# incomplete likelihood is -1872.640663395826 on iteration 29
# 7-th start
# Initial theta = [0.98360982]
# new_theta=[-144.74049533]
# incomplete likelihood is -2975.593051217953 on iteration 0
# new_theta=[46.32886883]
# incomplete likelihood is -2358.618651264682 on iteration 1
# new_theta=[602.87323265]
# incomplete likelihood is -2280.3975606758218 on iteration 2
# new_theta=[-122.19558329]
# incomplete likelihood is -2114.6734019068836 on iteration 3
# new_theta=[87.6288142]
# incomplete likelihood is -2019.5104421897238 on iteration 4
# new_theta=[-94.58968997]
# incomplete likelihood is -1963.4780238872015 on iteration 5
# new_theta=[-87.26745351]
# incomplete likelihood is -1455.0728963215793 on iteration 6
# new_theta=[-22.63834899]
# incomplete likelihood is -987.707067756419 on iteration 7
# new_theta=[13.17447832]
# incomplete likelihood is -512.6168360108696 on iteration 8
# new_theta=[-141.94941736]
# incomplete likelihood is -135.27985312712383 on iteration 9
# new_theta=[-112.54249962]
# incomplete likelihood is 106.58675164061377 on iteration 10
# new_theta=[-204.74173921]
# incomplete likelihood is 245.34590095485765 on iteration 11
# new_theta=[69.64165098]
# incomplete likelihood is 321.37530892351987 on iteration 12
# new_theta=[-85.34174256]
# incomplete likelihood is 361.70860945088714 on iteration 13
# new_theta=[-238.24755605]
# incomplete likelihood is 382.8837919784226 on iteration 14
# new_theta=[-399.49228909]
# incomplete likelihood is 394.1575814328383 on iteration 15
# new_theta=[43.4178893]
# incomplete likelihood is -2349.12133562548 on iteration 16
# new_theta=[338.78187065]
# incomplete likelihood is -2034.7931183148662 on iteration 17
# new_theta=[310.4347021]
# incomplete likelihood is -223.54826565396377 on iteration 18
# new_theta=[511.52449223]
# incomplete likelihood is 123.9038124689481 on iteration 19
# new_theta=[59.15296851]
# incomplete likelihood is 266.97608999614687 on iteration 20
# new_theta=[-66.4990579]
# incomplete likelihood is 335.16680144312494 on iteration 21
# new_theta=[-231.95988311]
# incomplete likelihood is 369.7760801784592 on iteration 22
# new_theta=[-93.73481058]
# incomplete likelihood is 387.5417646139301 on iteration 23
# new_theta=[43.42148317]
# incomplete likelihood is -2329.371846024356 on iteration 24
# new_theta=[-143.95634114]
# incomplete likelihood is 53.015634125860885 on iteration 25
# new_theta=[-159.69920396]
# incomplete likelihood is -2116.955610181525 on iteration 26
# new_theta=[21.41513321]
# incomplete likelihood is -108.0971354775913 on iteration 27
# new_theta=[697.98421869]
# incomplete likelihood is 168.66778358426592 on iteration 28
# new_theta=[672.83513887]
# incomplete likelihood is 287.4657526523574 on iteration 29
# 8-th start
# Initial theta = [0.51131793]
# new_theta=[-1250.84012697]
# incomplete likelihood is -2203.377408534356 on iteration 0
# new_theta=[28.72223478]
# incomplete likelihood is -1986.8894284950295 on iteration 1
# new_theta=[37.26739193]
# incomplete likelihood is -1915.4944562632134 on iteration 2
# new_theta=[116.65941911]
# incomplete likelihood is -1883.1559736911183 on iteration 3
# new_theta=[24.72117511]
# incomplete likelihood is -1866.497105899039 on iteration 4
# new_theta=[24.72845435]
# incomplete likelihood is -1857.0051771920205 on iteration 5
# new_theta=[43.58398986]
# incomplete likelihood is -1851.130346849349 on iteration 6
# new_theta=[-43.32672079]
# incomplete likelihood is -1027.56881751956 on iteration 7
# new_theta=[-74.78505816]
# incomplete likelihood is -532.8519875045423 on iteration 8
# new_theta=[200.60145651]
# incomplete likelihood is -1950.2978391943577 on iteration 9
# new_theta=[217.20653902]
# incomplete likelihood is -1891.106077439544 on iteration 10
# new_theta=[30.99199843]
# incomplete likelihood is -1868.8162006867274 on iteration 11
# new_theta=[32.05248107]
# incomplete likelihood is -776.737238585732 on iteration 12
# new_theta=[-87.36665274]
# incomplete likelihood is -319.04166520656975 on iteration 13
# new_theta=[-110.52527529]
# incomplete likelihood is -6.105327178720045 on iteration 14
# new_theta=[57.09757929]
# incomplete likelihood is 178.31359377353422 on iteration 15
# new_theta=[34.02320439]
# incomplete likelihood is 281.7068264873962 on iteration 16
# new_theta=[50.78975399]
# incomplete likelihood is 338.5497334495318 on iteration 17
# new_theta=[-81.16393373]
# incomplete likelihood is 369.32273337215713 on iteration 18
# new_theta=[-100.01806576]
# incomplete likelihood is 386.08614803572806 on iteration 19
# new_theta=[74.83771427]
# incomplete likelihood is -2331.8762616353806 on iteration 20
# new_theta=[-143.95606957]
# incomplete likelihood is 52.67185481448817 on iteration 21
# new_theta=[37.17745242]
# incomplete likelihood is -2116.605944911508 on iteration 22
# new_theta=[-143.9370839]
# incomplete likelihood is -108.44411393240658 on iteration 23
# new_theta=[-143.96244813]
# incomplete likelihood is 168.01686455599636 on iteration 24
# new_theta=[-169.11153681]
# incomplete likelihood is 286.8590980129542 on iteration 25
# new_theta=[-185.8777335]
# incomplete likelihood is 345.3315468838555 on iteration 26
# new_theta=[-231.96106629]
# incomplete likelihood is 375.03342246694916 on iteration 27
# new_theta=[-233.03375074]
# incomplete likelihood is -2308.3583440683096 on iteration 28
# new_theta=[352.41778537]
# incomplete likelihood is 38.06768846020122 on iteration 29
# 9-th start
# Initial theta = [2.72188548]
# new_theta=[-264.56919163]
# incomplete likelihood is -2645.0076384635036 on iteration 0
# new_theta=[-62.37516702]
# incomplete likelihood is 51.27788322644612 on iteration 1
# new_theta=[-132.58150975]
# incomplete likelihood is -2506.5628729086084 on iteration 2
# new_theta=[-119.97469822]
# incomplete likelihood is -2340.8966917729517 on iteration 3
# new_theta=[8.89242898]
# incomplete likelihood is 114.30733372216415 on iteration 4
# new_theta=[25.65216885]
# incomplete likelihood is 306.2496471016042 on iteration 5
# new_theta=[-160.73390746]
# incomplete likelihood is 357.078541580381 on iteration 6
# new_theta=[-207.90845198]
# incomplete likelihood is -2299.567307814989 on iteration 7
# new_theta=[-112.54138194]
# incomplete likelihood is 40.86443644393126 on iteration 8
# new_theta=[-131.41080306]
# incomplete likelihood is 256.93121643663636 on iteration 9
# new_theta=[-150.27232587]
# incomplete likelihood is 333.6061521577493 on iteration 10
# new_theta=[40.32411856]
# incomplete likelihood is 369.9213743393326 on iteration 11
# new_theta=[46.61210543]
# incomplete likelihood is 388.19436816273225 on iteration 12
# new_theta=[-235.0567106]
# incomplete likelihood is -2329.1097189698085 on iteration 13
# new_theta=[-257.05466323]
# incomplete likelihood is 55.61852676193322 on iteration 14
# new_theta=[52.87083741]
# incomplete likelihood is 265.053024345026 on iteration 15
# new_theta=[-213.1039797]
# incomplete likelihood is 338.0791468479989 on iteration 16
# new_theta=[-225.67787144]
# incomplete likelihood is 372.2954077326312 on iteration 17
# new_theta=[71.74464173]
# incomplete likelihood is 389.425512380818 on iteration 18
# new_theta=[44.49116982]
# incomplete likelihood is 398.23382633172815 on iteration 19
# new_theta=[-321.00880735]
# incomplete likelihood is -2350.721501502305 on iteration 20
# new_theta=[-116.79290324]
# incomplete likelihood is 69.22390331119936 on iteration 21
# new_theta=[-159.6957958]
# incomplete likelihood is -2125.873650089617 on iteration 22
# new_theta=[-181.63810237]
# incomplete likelihood is -96.3445159882811 on iteration 23
# new_theta=[-217.31921104]
# incomplete likelihood is 176.78769863882349 on iteration 24
# new_theta=[25.66609597]
# incomplete likelihood is 291.977646514561 on iteration 25
# new_theta=[8.90181751]
# incomplete likelihood is 348.255833445513 on iteration 26
# new_theta=[-104.18874031]
# incomplete likelihood is 376.7641583648425 on iteration 27
# new_theta=[-236.1312032]
# incomplete likelihood is 391.3322732556485 on iteration 28
# new_theta=[232.98671998]
# incomplete likelihood is 398.9714168020406 on iteration 29

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)
print(f"Погрешность в смысле разности углов в градусах: {np.abs(EM_theta1_deg-theta1_deg)},")
print(f"Погрешность в смысле разности синусов углов: {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах: [0.50784757],
# Погрешность в смысле разности синусов углов: [0.00775962].
