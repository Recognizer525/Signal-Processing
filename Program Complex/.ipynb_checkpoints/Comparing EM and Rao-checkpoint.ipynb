# %%
import numpy as np
import matplotlib.pyplot as plt
from sensors import *
from functools import partial

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
# Истинное DOA в градусах
theta1_deg = rad_to_deg(theta1_rad[0])
GS_1 = np.array([[0.7]]) # Ковариация сигнала
GN_1 = 4.1*np.eye(5, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s1 = CN(Num_emitters1, sample_size1, GS_1)
n1 = CN(Num_sensors1, sample_size1, GN_1)
X1 = (A1 @ s1.T + n1.T).T

# %%
EM_theta1_rad, neglhd_1, K1, mu1 = multi_start_EM(X1, GS_1, GN_1, 10, max_iter=50, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[3.09286854], -likelihood = -74.03554
# Iteration=2, theta_new=[3.08848899], -likelihood = -74.20760
# Iteration=3, theta_new=[3.08404024], -likelihood = -74.38545
# Iteration=4, theta_new=[3.07944731], -likelihood = -74.56996
# Iteration=5, theta_new=[3.07478603], -likelihood = -74.76536
# Iteration=6, theta_new=[3.06998168], -likelihood = -74.96966
# Iteration=7, theta_new=[3.06495998], -likelihood = -75.18760
# Iteration=8, theta_new=[3.05979684], -likelihood = -75.42459
# Iteration=9, theta_new=[3.05434359], -likelihood = -75.67942
# Iteration=10, theta_new=[3.04860178], -likelihood = -75.96248
# Iteration=11, theta_new=[3.04257305], -likelihood = -76.27788
# Iteration=12, theta_new=[3.03611056], -likelihood = -76.63048
# Iteration=13, theta_new=[3.02921704], -likelihood = -77.03562
# Iteration=14, theta_new=[3.0218215], -likelihood = -77.50213
# Iteration=15, theta_new=[3.01378003], -likelihood = -78.04616
# Iteration=16, theta_new=[3.00495059], -likelihood = -78.69394
# Iteration=17, theta_new=[2.99526667], -likelihood = -79.47900
# Iteration=18, theta_new=[2.98451706], -likelihood = -80.43666
# Iteration=19, theta_new=[2.97256733], -likelihood = -81.62742
# Iteration=20, theta_new=[2.95914143], -likelihood = -83.11941
# Iteration=21, theta_new=[2.94411454], -likelihood = -85.01771
# Iteration=22, theta_new=[2.92736701], -likelihood = -87.42843
# Iteration=23, theta_new=[2.90878509], -likelihood = -90.46893
# Iteration=24, theta_new=[2.88847473], -likelihood = -94.25601
# Iteration=25, theta_new=[2.86668423], -likelihood = -98.83542
# Iteration=26, theta_new=[2.84393832], -likelihood = -104.15476
# Iteration=27, theta_new=[2.82088687], -likelihood = -110.00160
# Iteration=28, theta_new=[2.79829774], -likelihood = -116.04408
# Iteration=29, theta_new=[2.77677763], -likelihood = -121.88277
# Iteration=30, theta_new=[2.75684665], -likelihood = -127.19227
# Iteration=31, theta_new=[2.73874139], -likelihood = -131.75069
# Iteration=32, theta_new=[2.72269407], -likelihood = -135.49428
# Iteration=33, theta_new=[2.708602], -likelihood = -138.43380
# Iteration=34, theta_new=[2.69636833], -likelihood = -140.68484
# Iteration=35, theta_new=[2.68590147], -likelihood = -142.36800
# Iteration=36, theta_new=[2.67691786], -likelihood = -143.59735
# Iteration=37, theta_new=[2.66933675], -likelihood = -144.49205
# Iteration=38, theta_new=[2.66288498], -likelihood = -145.12916
# Iteration=39, theta_new=[2.657489], -likelihood = -145.58511
# Iteration=40, theta_new=[2.65294739], -likelihood = -145.90502
# Iteration=41, theta_new=[2.64912601], -likelihood = -146.13067
# Iteration=42, theta_new=[2.64589221], -likelihood = -146.28959
# Iteration=43, theta_new=[2.64317914], -likelihood = -146.40194
# Iteration=44, theta_new=[2.64092056], -likelihood = -146.48055
# Iteration=45, theta_new=[2.63905077], -likelihood = -146.53510
# Iteration=46, theta_new=[2.63750445], -likelihood = -146.57278
# Iteration=47, theta_new=[2.63621661], -likelihood = -146.59883
# Iteration=48, theta_new=[2.63512247], -likelihood = -146.61699
# Iteration=49, theta_new=[2.6342218], -likelihood = -146.62990
# Iteration=50, theta_new=[2.63345005], -likelihood = -146.63879
# 1-th start
# Iteration=1, theta_new=[-0.75709657], -likelihood = -69.32672
# Iteration=2, theta_new=[-0.75110782], -likelihood = -69.46549
# Iteration=3, theta_new=[-0.74457964], -likelihood = -69.63519
# Iteration=4, theta_new=[-0.73745378], -likelihood = -69.83993
# Iteration=5, theta_new=[-0.72967594], -likelihood = -70.08638
# Iteration=6, theta_new=[-0.72133883], -likelihood = -70.38181
# Iteration=7, theta_new=[-0.71239253], -likelihood = -70.72773
# Iteration=8, theta_new=[-0.7028615], -likelihood = -71.13054
# Iteration=9, theta_new=[-0.69284023], -likelihood = -71.59282
# Iteration=10, theta_new=[-0.68242057], -likelihood = -72.11190
# Iteration=11, theta_new=[-0.67162446], -likelihood = -72.68261
# Iteration=12, theta_new=[-0.66067121], -likelihood = -73.30125
# Iteration=13, theta_new=[-0.64963852], -likelihood = -73.95033
# Iteration=14, theta_new=[-0.63866318], -likelihood = -74.61829
# Iteration=15, theta_new=[-0.62787326], -likelihood = -75.28886
# Iteration=16, theta_new=[-0.61738827], -likelihood = -75.94603
# Iteration=17, theta_new=[-0.60731954], -likelihood = -76.57504
# Iteration=18, theta_new=[-0.59771155], -likelihood = -77.16331
# Iteration=19, theta_new=[-0.58866416], -likelihood = -77.70422
# Iteration=20, theta_new=[-0.58021361], -likelihood = -78.19029
# Iteration=21, theta_new=[-0.57233766], -likelihood = -78.61982
# Iteration=22, theta_new=[-0.56507166], -likelihood = -78.99565
# Iteration=23, theta_new=[-0.55839454], -likelihood = -79.31896
# Iteration=24, theta_new=[-0.5522871], -likelihood = -79.59440
# Iteration=25, theta_new=[-0.54667793], -likelihood = -79.82682
# Iteration=26, theta_new=[-0.54160622], -likelihood = -80.02285
# Iteration=27, theta_new=[-0.53700468], -likelihood = -80.18502
# Iteration=28, theta_new=[-0.53280933], -likelihood = -80.31926
# Iteration=29, theta_new=[-0.52906301], -likelihood = -80.43060
# Iteration=30, theta_new=[-0.52565304], -likelihood = -80.52086
# Iteration=31, theta_new=[-0.52257304], -likelihood = -80.59534
# Iteration=32, theta_new=[-0.51981728], -likelihood = -80.65619
# Iteration=33, theta_new=[-0.51732988], -likelihood = -80.70539
# Iteration=34, theta_new=[-0.51510697], -likelihood = -80.74549
# Iteration=35, theta_new=[-0.51309484], -likelihood = -80.77782
# Iteration=36, theta_new=[-0.51129099], -likelihood = -80.80420
# Iteration=37, theta_new=[-0.5096932], -likelihood = -80.82551
# Iteration=38, theta_new=[-0.50819996], -likelihood = -80.84252
# Iteration=39, theta_new=[-0.50690961], -likelihood = -80.85683
# Iteration=40, theta_new=[-0.50572154], -likelihood = -80.86795
# Iteration=41, theta_new=[-0.50463503], -likelihood = -80.87716
# Iteration=42, theta_new=[-0.50364941], -likelihood = -80.88471
# Iteration=43, theta_new=[-0.50276409], -likelihood = -80.89085
# Iteration=44, theta_new=[-0.50197852], -likelihood = -80.89579
# Iteration=45, theta_new=[-0.50129223], -likelihood = -80.89970
# Iteration=46, theta_new=[-0.50070477], -likelihood = -80.90276
# Iteration=47, theta_new=[-0.50011801], -likelihood = -80.90511
# Iteration=48, theta_new=[-0.49962961], -likelihood = -80.90723
# Iteration=49, theta_new=[-0.49923928], -likelihood = -80.90879
# Iteration=50, theta_new=[-0.49884925], -likelihood = -80.90993
# 2-th start
# Iteration=1, theta_new=[0.00623634], -likelihood = -72.37298
# Iteration=2, theta_new=[0.01060178], -likelihood = -72.55016
# Iteration=3, theta_new=[0.01497501], -likelihood = -72.72204
# Iteration=4, theta_new=[0.01928032], -likelihood = -72.89277
# Iteration=5, theta_new=[0.02355814], -likelihood = -73.05977
# Iteration=6, theta_new=[0.02782806], -likelihood = -73.22502
# Iteration=7, theta_new=[0.03208923], -likelihood = -73.38970
# Iteration=8, theta_new=[0.03635108], -likelihood = -73.55420
# Iteration=9, theta_new=[0.04061097], -likelihood = -73.71938
# Iteration=10, theta_new=[0.04492589], -likelihood = -73.88566
# Iteration=11, theta_new=[0.04927808], -likelihood = -74.05584
# Iteration=12, theta_new=[0.05366691], -likelihood = -74.22991
# Iteration=13, theta_new=[0.05811121], -likelihood = -74.40858
# Iteration=14, theta_new=[0.06265114], -likelihood = -74.59345
# Iteration=15, theta_new=[0.06734998], -likelihood = -74.78722
# Iteration=16, theta_new=[0.07219076], -likelihood = -74.99392
# Iteration=17, theta_new=[0.07721027], -likelihood = -75.21446
# Iteration=18, theta_new=[0.08239784], -likelihood = -75.45251
# Iteration=19, theta_new=[0.08786957], -likelihood = -75.70994
# Iteration=20, theta_new=[0.09363601], -likelihood = -75.99567
# Iteration=21, theta_new=[0.09970772], -likelihood = -76.31452
# Iteration=22, theta_new=[0.10617314], -likelihood = -76.67223
# Iteration=23, theta_new=[0.11314075], -likelihood = -77.08073
# Iteration=24, theta_new=[0.12065401], -likelihood = -77.55626
# Iteration=25, theta_new=[0.12876045], -likelihood = -78.11432
# Iteration=26, theta_new=[0.13766303], -likelihood = -78.77440
# Iteration=27, theta_new=[0.14745001], -likelihood = -79.57506
# Iteration=28, theta_new=[0.15833597], -likelihood = -80.55472
# Iteration=29, theta_new=[0.17045856], -likelihood = -81.77626
# Iteration=30, theta_new=[0.18404198], -likelihood = -83.31070
# Iteration=31, theta_new=[0.19921106], -likelihood = -85.25855
# Iteration=32, theta_new=[0.21617513], -likelihood = -87.72592
# Iteration=33, theta_new=[0.23500601], -likelihood = -90.84642
# Iteration=34, theta_new=[0.25556904], -likelihood = -94.73085
# Iteration=35, theta_new=[0.277532], -likelihood = -99.41510
# Iteration=36, theta_new=[0.3003525], -likelihood = -104.81709
# Iteration=37, theta_new=[0.32340691], -likelihood = -110.70664
# Iteration=38, theta_new=[0.34595696], -likelihood = -116.75045
# Iteration=39, theta_new=[0.36730899], -likelihood = -122.55636
# Iteration=40, theta_new=[0.3870375], -likelihood = -127.78418
# Iteration=41, theta_new=[0.40487751], -likelihood = -132.24721
# Iteration=42, theta_new=[0.42069304], -likelihood = -135.88618
# Iteration=43, theta_new=[0.43457919], -likelihood = -138.73824
# Iteration=44, theta_new=[0.4465471], -likelihood = -140.91798
# Iteration=45, theta_new=[0.45683861], -likelihood = -142.53427
# Iteration=46, theta_new=[0.46567201], -likelihood = -143.71996
# Iteration=47, theta_new=[0.47313004], -likelihood = -144.58207
# Iteration=48, theta_new=[0.4794138], -likelihood = -145.19560
# Iteration=49, theta_new=[0.48475103], -likelihood = -145.63017
# Iteration=50, theta_new=[0.48920089], -likelihood = -145.93962
# 3-th start
# Iteration=1, theta_new=[-1.92644874], -likelihood = -77.93159
# Iteration=2, theta_new=[-1.92221582], -likelihood = -77.95374
# Iteration=3, theta_new=[-1.91827377], -likelihood = -77.97245
# Iteration=4, theta_new=[-1.91471448], -likelihood = -77.98817
# Iteration=5, theta_new=[-1.91144226], -likelihood = -78.00100
# Iteration=6, theta_new=[-1.9083623], -likelihood = -78.01167
# Iteration=7, theta_new=[-1.90556685], -likelihood = -78.02077
# Iteration=8, theta_new=[-1.90296158], -likelihood = -78.02824
# Iteration=9, theta_new=[-1.90054571], -likelihood = -78.03454
# Iteration=10, theta_new=[-1.89841131], -likelihood = -78.03983
# Iteration=11, theta_new=[-1.896372], -likelihood = -78.04407
# Iteration=12, theta_new=[-1.89452007], -likelihood = -78.04774
# Iteration=13, theta_new=[-1.89285497], -likelihood = -78.05077
# Iteration=14, theta_new=[-1.89128375], -likelihood = -78.05324
# Iteration=15, theta_new=[-1.88989853], -likelihood = -78.05535
# Iteration=16, theta_new=[-1.88860661], -likelihood = -78.05705
# Iteration=17, theta_new=[-1.88740779], -likelihood = -78.05849
# Iteration=18, theta_new=[-1.88630188], -likelihood = -78.05970
# Iteration=19, theta_new=[-1.88528873], -likelihood = -78.06072
# Iteration=20, theta_new=[-1.88436818], -likelihood = -78.06157
# Iteration=21, theta_new=[-1.88354009], -likelihood = -78.06227
# Iteration=22, theta_new=[-1.88280433], -likelihood = -78.06284
# Iteration=23, theta_new=[-1.88206886], -likelihood = -78.06330
# Iteration=24, theta_new=[-1.88142558], -likelihood = -78.06372
# Iteration=25, theta_new=[-1.88087438], -likelihood = -78.06406
# Iteration=26, theta_new=[-1.88032334], -likelihood = -78.06432
# Iteration=27, theta_new=[-1.87986428], -likelihood = -78.06456
# Iteration=28, theta_new=[-1.87940533], -likelihood = -78.06474
# Iteration=29, theta_new=[-1.87903826], -likelihood = -78.06491
# Iteration=30, theta_new=[-1.87867126], -likelihood = -78.06503
# Iteration=31, theta_new=[-1.87830433], -likelihood = -78.06514
# Iteration=32, theta_new=[-1.87802919], -likelihood = -78.06525
# Iteration=33, theta_new=[-1.87775408], -likelihood = -78.06532
# Iteration=34, theta_new=[-1.87747902], -likelihood = -78.06538
# Iteration=35, theta_new=[-1.877204], -likelihood = -78.06544
# Iteration=36, theta_new=[-1.87702068], -likelihood = -78.06549
# Iteration=37, theta_new=[-1.87683738], -likelihood = -78.06552
# Iteration=38, theta_new=[-1.87665409], -likelihood = -78.06555
# Iteration=39, theta_new=[-1.87647083], -likelihood = -78.06558
# Iteration=40, theta_new=[-1.87628758], -likelihood = -78.06561
# Iteration=41, theta_new=[-1.87610435], -likelihood = -78.06563
# Iteration=42, theta_new=[-1.87601274], -likelihood = -78.06565
# Iteration=43, theta_new=[-1.87592114], -likelihood = -78.06566
# Iteration=44, theta_new=[-1.87582954], -likelihood = -78.06567
# Iteration=45, theta_new=[-1.87573795], -likelihood = -78.06567
# Iteration=46, theta_new=[-1.87564636], -likelihood = -78.06568
# Iteration=47, theta_new=[-1.87555477], -likelihood = -78.06569
# Iteration=48, theta_new=[-1.87546319], -likelihood = -78.06569
# Iteration=49, theta_new=[-1.87537162], -likelihood = -78.06570
# Iteration=50, theta_new=[-1.87528005], -likelihood = -78.06571
# 4-th start
# Iteration=1, theta_new=[-2.22357267], -likelihood = -70.51697
# Iteration=2, theta_new=[-2.21309538], -likelihood = -70.83539
# Iteration=3, theta_new=[-2.20196507], -likelihood = -71.18919
# Iteration=4, theta_new=[-2.19019187], -likelihood = -71.57668
# Iteration=5, theta_new=[-2.17789343], -likelihood = -71.99500
# Iteration=6, theta_new=[-2.16513233], -likelihood = -72.43627
# Iteration=7, theta_new=[-2.15202313], -likelihood = -72.89361
# Iteration=8, theta_new=[-2.13867807], -likelihood = -73.35776
# Iteration=9, theta_new=[-2.12515469], -likelihood = -73.81951
# Iteration=10, theta_new=[-2.11166494], -likelihood = -74.27197
# Iteration=11, theta_new=[-2.09826081], -likelihood = -74.70406
# Iteration=12, theta_new=[-2.08504423], -likelihood = -75.11128
# Iteration=13, theta_new=[-2.07211451], -likelihood = -75.48887
# Iteration=14, theta_new=[-2.05956851], -likelihood = -75.83356
# Iteration=15, theta_new=[-2.04745044], -likelihood = -76.14356
# Iteration=16, theta_new=[-2.03585355], -likelihood = -76.41947
# Iteration=17, theta_new=[-2.02471998], -likelihood = -76.66159
# Iteration=18, theta_new=[-2.01414161], -likelihood = -76.87383
# Iteration=19, theta_new=[-2.00411024], -likelihood = -77.05729
# Iteration=20, theta_new=[-1.99461811], -likelihood = -77.21513
# Iteration=21, theta_new=[-1.98565792], -likelihood = -77.35031
# Iteration=22, theta_new=[-1.9773197], -likelihood = -77.46558
# Iteration=23, theta_new=[-1.96949925], -likelihood = -77.56238
# Iteration=24, theta_new=[-1.96219056], -likelihood = -77.64428
# Iteration=25, theta_new=[-1.95538805], -likelihood = -77.71327
# Iteration=26, theta_new=[-1.9490865], -likelihood = -77.77114
# Iteration=27, theta_new=[-1.94318595], -likelihood = -77.81947
# Iteration=28, theta_new=[-1.93768278], -likelihood = -77.86026
# Iteration=29, theta_new=[-1.93257366], -likelihood = -77.89454
# Iteration=30, theta_new=[-1.92785546], -likelihood = -77.92322
# Iteration=31, theta_new=[-1.92352532], -likelihood = -77.94710
# Iteration=32, theta_new=[-1.91948667], -likelihood = -77.96686
# Iteration=33, theta_new=[-1.91583139], -likelihood = -77.98350
# Iteration=34, theta_new=[-1.91246372], -likelihood = -77.99711
# Iteration=35, theta_new=[-1.90928873], -likelihood = -78.00845
# Iteration=36, theta_new=[-1.9063987], -likelihood = -78.01813
# Iteration=37, theta_new=[-1.90369921], -likelihood = -78.02609
# Iteration=38, theta_new=[-1.9012824], -likelihood = -78.03282
# Iteration=39, theta_new=[-1.89905433], -likelihood = -78.03827
# Iteration=40, theta_new=[-1.89701433], -likelihood = -78.04283
# Iteration=41, theta_new=[-1.89516178], -likelihood = -78.04662
# Iteration=42, theta_new=[-1.89340357], -likelihood = -78.04975
# Iteration=43, theta_new=[-1.8918319], -likelihood = -78.05245
# Iteration=44, theta_new=[-1.89035391], -likelihood = -78.05464
# Iteration=45, theta_new=[-1.88906167], -likelihood = -78.05651
# Iteration=46, theta_new=[-1.88786256], -likelihood = -78.05799
# Iteration=47, theta_new=[-1.88675639], -likelihood = -78.05925
# Iteration=48, theta_new=[-1.885743], -likelihood = -78.06031
# Iteration=49, theta_new=[-1.88482223], -likelihood = -78.06120
# Iteration=50, theta_new=[-1.88399393], -likelihood = -78.06193
# 5-th start
# Iteration=1, theta_new=[-2.92495371], -likelihood = -65.57370
# Iteration=2, theta_new=[-2.92224013], -likelihood = -65.62366
# Iteration=3, theta_new=[-2.91924369], -likelihood = -65.68517
# Iteration=4, theta_new=[-2.91596525], -likelihood = -65.76008
# Iteration=5, theta_new=[-2.91233453], -likelihood = -65.85042
# Iteration=6, theta_new=[-2.90835282], -likelihood = -65.96064
# Iteration=7, theta_new=[-2.90395053], -likelihood = -66.09367
# Iteration=8, theta_new=[-2.89912952], -likelihood = -66.25539
# Iteration=9, theta_new=[-2.89382105], -likelihood = -66.44983
# Iteration=10, theta_new=[-2.88802776], -likelihood = -66.68438
# Iteration=11, theta_new=[-2.881682], -likelihood = -66.96407
# Iteration=12, theta_new=[-2.87478735], -likelihood = -67.29768
# Iteration=13, theta_new=[-2.86727753], -likelihood = -67.69070
# Iteration=14, theta_new=[-2.85915731], -likelihood = -68.15250
# Iteration=15, theta_new=[-2.85050165], -likelihood = -68.68787
# Iteration=16, theta_new=[-2.84131547], -likelihood = -69.29500
# Iteration=17, theta_new=[-2.83167331], -likelihood = -69.97437
# Iteration=18, theta_new=[-2.82157994], -likelihood = -70.71866
# Iteration=19, theta_new=[-2.81124701], -likelihood = -71.52292
# Iteration=20, theta_new=[-2.80074601], -likelihood = -72.36271
# Iteration=21, theta_new=[-2.79014748], -likelihood = -73.22233
# Iteration=22, theta_new=[-2.77965718], -likelihood = -74.08513
# Iteration=23, theta_new=[-2.76940991], -likelihood = -74.92367
# Iteration=24, theta_new=[-2.75947087], -likelihood = -75.71825
# Iteration=25, theta_new=[-2.74997171], -likelihood = -76.45733
# Iteration=26, theta_new=[-2.74097522], -likelihood = -77.12768
# Iteration=27, theta_new=[-2.73247659], -likelihood = -77.72459
# Iteration=28, theta_new=[-2.724538], -likelihood = -78.25035
# Iteration=29, theta_new=[-2.71722113], -likelihood = -78.70488
# Iteration=30, theta_new=[-2.71045461], -likelihood = -79.09030
# Iteration=31, theta_new=[-2.70423433], -likelihood = -79.41660
# Iteration=32, theta_new=[-2.69855649], -likelihood = -79.68997
# Iteration=33, theta_new=[-2.69341764], -likelihood = -79.91657
# Iteration=34, theta_new=[-2.68874887], -likelihood = -80.10236
# Iteration=35, theta_new=[-2.68448206], -likelihood = -80.25497
# Iteration=36, theta_new=[-2.68061525], -likelihood = -80.38080
# Iteration=37, theta_new=[-2.67714668], -likelihood = -80.48347
# Iteration=38, theta_new=[-2.6740094], -likelihood = -80.56631
# Iteration=39, theta_new=[-2.67120222], -likelihood = -80.63367
# Iteration=40, theta_new=[-2.66865883], -likelihood = -80.68782
# Iteration=41, theta_new=[-2.66637849], -likelihood = -80.73189
# Iteration=42, theta_new=[-2.66429538], -likelihood = -80.76736
# Iteration=43, theta_new=[-2.66247408], -likelihood = -80.79642
# Iteration=44, theta_new=[-2.66078404], -likelihood = -80.81921
# Iteration=45, theta_new=[-2.65928994], -likelihood = -80.83819
# Iteration=46, theta_new=[-2.65792654], -likelihood = -80.85322
# Iteration=47, theta_new=[-2.6567585], -likelihood = -80.86551
# Iteration=48, theta_new=[-2.65565584], -likelihood = -80.87495
# Iteration=49, theta_new=[-2.65468331], -likelihood = -80.88295
# Iteration=50, theta_new=[-2.65384076], -likelihood = -80.88927
# 6-th start
# Iteration=1, theta_new=[-2.71188744], -likelihood = -79.01043
# Iteration=2, theta_new=[-2.70559766], -likelihood = -79.34999
# Iteration=3, theta_new=[-2.69985091], -likelihood = -79.63228
# Iteration=4, theta_new=[-2.69457776], -likelihood = -79.86687
# Iteration=5, theta_new=[-2.68977541], -likelihood = -80.06204
# Iteration=6, theta_new=[-2.6854413], -likelihood = -80.22275
# Iteration=7, theta_new=[-2.68150755], -likelihood = -80.35366
# Iteration=8, theta_new=[-2.67797236], -likelihood = -80.46074
# Iteration=9, theta_new=[-2.67476873], -likelihood = -80.54739
# Iteration=10, theta_new=[-2.67189544], -likelihood = -80.61803
# Iteration=11, theta_new=[-2.66928617], -likelihood = -80.67499
# Iteration=12, theta_new=[-2.66694012], -likelihood = -80.72146
# Iteration=13, theta_new=[-2.66485657], -likelihood = -80.75898
# Iteration=14, theta_new=[-2.66296983], -likelihood = -80.78890
# Iteration=15, theta_new=[-2.66127947], -likelihood = -80.81325
# Iteration=16, theta_new=[-2.65972013], -likelihood = -80.83285
# Iteration=17, theta_new=[-2.6583565], -likelihood = -80.84906
# Iteration=18, theta_new=[-2.65712337], -likelihood = -80.86178
# Iteration=19, theta_new=[-2.65602056], -likelihood = -80.87211
# Iteration=20, theta_new=[-2.6550479], -likelihood = -80.88040
# Iteration=21, theta_new=[-2.65414041], -likelihood = -80.88698
# Iteration=22, theta_new=[-2.65329804], -likelihood = -80.89250
# Iteration=23, theta_new=[-2.65258548], -likelihood = -80.89708
# Iteration=24, theta_new=[-2.65193788], -likelihood = -80.90056
# Iteration=25, theta_new=[-2.65135517], -likelihood = -80.90339
# Iteration=26, theta_new=[-2.65083733], -likelihood = -80.90568
# Iteration=27, theta_new=[-2.65038431], -likelihood = -80.90751
# Iteration=28, theta_new=[-2.64993136], -likelihood = -80.90895
# Iteration=29, theta_new=[-2.64954319], -likelihood = -80.91025
# Iteration=30, theta_new=[-2.64921976], -likelihood = -80.91123
# Iteration=31, theta_new=[-2.64889637], -likelihood = -80.91197
# Iteration=32, theta_new=[-2.64863768], -likelihood = -80.91264
# Iteration=33, theta_new=[-2.64837903], -likelihood = -80.91312
# Iteration=34, theta_new=[-2.64818506], -likelihood = -80.91355
# Iteration=35, theta_new=[-2.6479911], -likelihood = -80.91384
# Iteration=36, theta_new=[-2.64779715], -likelihood = -80.91410
# Iteration=37, theta_new=[-2.64760322], -likelihood = -80.91433
# Iteration=38, theta_new=[-2.64747394], -likelihood = -80.91454
# Iteration=39, theta_new=[-2.64734467], -likelihood = -80.91467
# Iteration=40, theta_new=[-2.64721541], -likelihood = -80.91478
# Iteration=41, theta_new=[-2.64708615], -likelihood = -80.91488
# Iteration=42, theta_new=[-2.64702152], -likelihood = -80.91497
# Iteration=43, theta_new=[-2.6469569], -likelihood = -80.91501
# Iteration=44, theta_new=[-2.64689228], -likelihood = -80.91504
# Iteration=45, theta_new=[-2.64682765], -likelihood = -80.91508
# Iteration=46, theta_new=[-2.64676303], -likelihood = -80.91511
# Iteration=47, theta_new=[-2.64669842], -likelihood = -80.91514
# Iteration=48, theta_new=[-2.6466338], -likelihood = -80.91516
# Iteration=49, theta_new=[-2.64656918], -likelihood = -80.91518
# Iteration=50, theta_new=[-2.64650457], -likelihood = -80.91520
# 7-th start
# Iteration=1, theta_new=[-0.97293351], -likelihood = -72.31320
# Iteration=2, theta_new=[-0.9859503], -likelihood = -72.76756
# Iteration=3, theta_new=[-0.99923752], -likelihood = -73.23047
# Iteration=4, theta_new=[-1.0127038], -likelihood = -73.69362
# Iteration=5, theta_new=[-1.02625267], -likelihood = -74.14882
# Iteration=6, theta_new=[-1.03973226], -likelihood = -74.58844
# Iteration=7, theta_new=[-1.05303352], -likelihood = -75.00424
# Iteration=8, theta_new=[-1.06604219], -likelihood = -75.39088
# Iteration=9, theta_new=[-1.07869103], -likelihood = -75.74442
# Iteration=10, theta_new=[-1.09096325], -likelihood = -76.06360
# Iteration=11, theta_new=[-1.10273585], -likelihood = -76.34935
# Iteration=12, theta_new=[-1.11398935], -likelihood = -76.60095
# Iteration=13, theta_new=[-1.12470497], -likelihood = -76.82076
# Iteration=14, theta_new=[-1.13486466], -likelihood = -77.01136
# Iteration=15, theta_new=[-1.14450658], -likelihood = -77.17544
# Iteration=16, theta_new=[-1.15355981], -likelihood = -77.31647
# Iteration=17, theta_new=[-1.16206506], -likelihood = -77.43617
# Iteration=18, theta_new=[-1.17000886], -likelihood = -77.53771
# Iteration=19, theta_new=[-1.17743567], -likelihood = -77.62327
# Iteration=20, theta_new=[-1.1843922], -likelihood = -77.69541
# Iteration=21, theta_new=[-1.19086935], -likelihood = -77.75631
# Iteration=22, theta_new=[-1.19685858], -likelihood = -77.80739
# Iteration=23, theta_new=[-1.20246886], -likelihood = -77.84997
# Iteration=24, theta_new=[-1.20763572], -likelihood = -77.88591
# Iteration=25, theta_new=[-1.21241201], -likelihood = -77.91575
# Iteration=26, theta_new=[-1.216852], -likelihood = -77.94064
# Iteration=27, theta_new=[-1.22095174], -likelihood = -77.96152
# Iteration=28, theta_new=[-1.2247076], -likelihood = -77.97892
# Iteration=29, theta_new=[-1.22817601], -likelihood = -77.99333
# Iteration=30, theta_new=[-1.23141436], -likelihood = -78.00536
# Iteration=31, theta_new=[-1.23436062], -likelihood = -78.01552
# Iteration=32, theta_new=[-1.23707284], -likelihood = -78.02387
# Iteration=33, theta_new=[-1.2395494], -likelihood = -78.03084
# Iteration=34, theta_new=[-1.24184934], -likelihood = -78.03661
# Iteration=35, theta_new=[-1.24397165], -likelihood = -78.04147
# Iteration=36, theta_new=[-1.24591535], -likelihood = -78.04554
# Iteration=37, theta_new=[-1.24767959], -likelihood = -78.04891
# Iteration=38, theta_new=[-1.24932448], -likelihood = -78.05169
# Iteration=39, theta_new=[-1.25084953], -likelihood = -78.05405
# Iteration=40, theta_new=[-1.25219322], -likelihood = -78.05603
# Iteration=41, theta_new=[-1.2534772], -likelihood = -78.05762
# Iteration=42, theta_new=[-1.2546401], -likelihood = -78.05900
# Iteration=43, theta_new=[-1.25568155], -likelihood = -78.06013
# Iteration=44, theta_new=[-1.25666255], -likelihood = -78.06105
# Iteration=45, theta_new=[-1.2575216], -likelihood = -78.06185
# Iteration=46, theta_new=[-1.25831983], -likelihood = -78.06248
# Iteration=47, theta_new=[-1.25905712], -likelihood = -78.06301
# Iteration=48, theta_new=[-1.25973337], -likelihood = -78.06346
# Iteration=49, theta_new=[-1.26034848], -likelihood = -78.06384
# Iteration=50, theta_new=[-1.26090234], -likelihood = -78.06415
# 8-th start
# Iteration=1, theta_new=[0.5879033], -likelihood = -139.24476
# Iteration=2, theta_new=[0.57510032], -likelihood = -141.43266
# Iteration=3, theta_new=[0.56442952], -likelihood = -142.99906
# Iteration=4, theta_new=[0.55555519], -likelihood = -144.10766
# Iteration=5, theta_new=[0.54823097], -likelihood = -144.88579
# Iteration=6, theta_new=[0.54212762], -likelihood = -145.42583
# Iteration=7, theta_new=[0.53704517], -likelihood = -145.80330
# Iteration=8, theta_new=[0.53284951], -likelihood = -146.06630
# Iteration=9, theta_new=[0.52936309], -likelihood = -146.24775
# Iteration=10, theta_new=[0.52646814], -likelihood = -146.37371
# Iteration=11, theta_new=[0.52405173], -likelihood = -146.46105
# Iteration=12, theta_new=[0.52205583], -likelihood = -146.52190
# Iteration=13, theta_new=[0.52037342], -likelihood = -146.56384
# Iteration=14, theta_new=[0.51900134], -likelihood = -146.59332
# Iteration=15, theta_new=[0.51783562], -likelihood = -146.61339
# Iteration=16, theta_new=[0.51687479], -likelihood = -146.62762
# Iteration=17, theta_new=[0.51606717], -likelihood = -146.63741
# Iteration=18, theta_new=[0.51541201], -likelihood = -146.64426
# Iteration=19, theta_new=[0.51485834], -likelihood = -146.64891
# Iteration=20, theta_new=[0.51440583], -likelihood = -146.65219
# Iteration=21, theta_new=[0.51400395], -likelihood = -146.65444
# Iteration=22, theta_new=[0.51365258], -likelihood = -146.65611
# Iteration=23, theta_new=[0.51340178], -likelihood = -146.65731
# Iteration=24, theta_new=[0.51315109], -likelihood = -146.65803
# Iteration=25, theta_new=[0.51295064], -likelihood = -146.65862
# Iteration=26, theta_new=[0.51280036], -likelihood = -146.65901
# Iteration=27, theta_new=[0.51265013], -likelihood = -146.65925
# Iteration=28, theta_new=[0.51255], -likelihood = -146.65945
# Iteration=29, theta_new=[0.51244989], -likelihood = -146.65956
# Iteration=30, theta_new=[0.51239985], -likelihood = -146.65964
# Iteration=31, theta_new=[0.51234981], -likelihood = -146.65968
# Iteration=32, theta_new=[0.51229978], -likelihood = -146.65971
# Iteration=33, theta_new=[0.51224975], -likelihood = -146.65974
# Iteration=34, theta_new=[0.51219972], -likelihood = -146.65976
# Iteration=35, theta_new=[0.5121497], -likelihood = -146.65978
# norm=0.0
# Iteration=36, theta_new=[0.5121497], -likelihood = -146.65979
# 9-th start
# Iteration=1, theta_new=[1.57076438], -likelihood = -77.23073
# norm=0.0
# Iteration=2, theta_new=[1.57076438], -likelihood = -77.23370

# %%
theta_ML = multi_start_ML(X1, GS_1, GN_1)
# Out:
# 0-th start
# 1-th start
# 2-th start
# 3-th start
# 4-th start
# 5-th start
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:818: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[k] = func(sim[k])
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:884: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxcc
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:854: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxe
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:872: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxc
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\scipy\optimize\_optimize.py:857: ComplexWarning: Casting complex values to real discards the imaginary part
#   fsim[-1] = fxr
# 6-th start
# 7-th start
# 8-th start
# 9-th start
# 10-th start
# 11-th start
# 12-th start
# 13-th start
# 14-th start
# 15-th start
# 16-th start
# 17-th start
# 18-th start
# 19-th start

# %%
theta_ML
# Out:
# (array([0.5120401]), 1285.7441691327863)

# %%
EM_theta1_rad
# Out:
# array([0.5121497])

# %%
theta1_rad
# Out:
# [0.5]
