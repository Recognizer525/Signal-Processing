# %%
import numpy as np
import matplotlib.pyplot as plt
from sensors import *
from functools import partial

# %% [markdown]
# # Case 1

# %% [markdown]
# Имеется 5 датчиков, 1 источник (дисперсия сигнала 0.7), и шум на каждом датчике имеет дисперсию 4.1.

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
GS_1 = np.array([[0.7]]) # Ковариация сигнала
GN_1 = 4.1*np.eye(5, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s1 = CN(Num_emitters1, sample_size1, GS_1)
n1 = CN(Num_sensors1, sample_size1, GN_1)
X1 = (A1 @ s1.T + n1.T).T

# %%
EM_theta1_rad, neglhd_1, K1, mu1 = multi_start_EM(X1, GS_1, GN_1, 10, max_iter=50, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[0.67235134], -likelihood = -119.44656
# Iteration=2, theta_new=[0.64654723], -likelihood = -126.08103
# Iteration=3, theta_new=[0.62438531], -likelihood = -131.50510
# Iteration=4, theta_new=[0.60566594], -likelihood = -135.71999
# Iteration=5, theta_new=[0.58993282], -likelihood = -138.86570
# Iteration=6, theta_new=[0.5767976], -likelihood = -141.16179
# Iteration=7, theta_new=[0.56586999], -likelihood = -142.80590
# Iteration=8, theta_new=[0.55675197], -likelihood = -143.96886
# Iteration=9, theta_new=[0.54919449], -likelihood = -144.78868
# Iteration=10, theta_new=[0.54291952], -likelihood = -145.36016
# Iteration=11, theta_new=[0.53772361], -likelihood = -145.75810
# Iteration=12, theta_new=[0.53341762], -likelihood = -146.03392
# Iteration=13, theta_new=[0.5298233], -likelihood = -146.22508
# Iteration=14, theta_new=[0.52682235], -likelihood = -146.35838
# Iteration=15, theta_new=[0.52435287], -likelihood = -146.45121
# Iteration=16, theta_new=[0.52230461], -likelihood = -146.51491
# Iteration=17, theta_new=[0.5205704], -likelihood = -146.55902
# Iteration=18, theta_new=[0.51914697], -likelihood = -146.59015
# Iteration=19, theta_new=[0.51798091], -likelihood = -146.61143
# Iteration=20, theta_new=[0.51696923], -likelihood = -146.62599
# Iteration=21, theta_new=[0.51616147], -likelihood = -146.63652
# Iteration=22, theta_new=[0.51545578], -likelihood = -146.64352
# Iteration=23, theta_new=[0.51490207], -likelihood = -146.64862
# Iteration=24, theta_new=[0.51444951], -likelihood = -146.65195
# Iteration=25, theta_new=[0.5140476], -likelihood = -146.65424
# Iteration=26, theta_new=[0.5136962], -likelihood = -146.65594
# Iteration=27, theta_new=[0.51344537], -likelihood = -146.65718
# Iteration=28, theta_new=[0.51319467], -likelihood = -146.65791
# Iteration=29, theta_new=[0.5129942], -likelihood = -146.65853
# Iteration=30, theta_new=[0.51284391], -likelihood = -146.65893
# Iteration=31, theta_new=[0.51269366], -likelihood = -146.65919
# Iteration=32, theta_new=[0.51259353], -likelihood = -146.65940
# Iteration=33, theta_new=[0.51249341], -likelihood = -146.65951
# Iteration=34, theta_new=[0.51244336], -likelihood = -146.65961
# Iteration=35, theta_new=[0.51239332], -likelihood = -146.65965
# Iteration=36, theta_new=[0.51234328], -likelihood = -146.65969
# Iteration=37, theta_new=[0.51229325], -likelihood = -146.65972
# Iteration=38, theta_new=[0.51224322], -likelihood = -146.65974
# Iteration=39, theta_new=[0.51219319], -likelihood = -146.65977
# Iteration=40, theta_new=[0.51214318], -likelihood = -146.65978
# norm=0.0
# Iteration=41, theta_new=[0.51214318], -likelihood = -146.65979
# 1-th start
# Iteration=1, theta_new=[0.49562673], -likelihood = -146.28905
# Iteration=2, theta_new=[0.49833719], -likelihood = -146.39961
# Iteration=3, theta_new=[0.50057581], -likelihood = -146.47853
# Iteration=4, theta_new=[0.50243342], -likelihood = -146.53297
# Iteration=5, theta_new=[0.50400352], -likelihood = -146.57078
# Iteration=6, theta_new=[0.50538166], -likelihood = -146.59752
# Iteration=7, theta_new=[0.50646744], -likelihood = -146.61706
# Iteration=8, theta_new=[0.50735771], -likelihood = -146.62987
# Iteration=9, theta_new=[0.50815046], -likelihood = -146.63867
# Iteration=10, theta_new=[0.5088452], -likelihood = -146.64521
# Iteration=11, theta_new=[0.50934211], -likelihood = -146.64996
# Iteration=12, theta_new=[0.50983952], -likelihood = -146.65278
# Iteration=13, theta_new=[0.51023783], -likelihood = -146.65513
# Iteration=14, theta_new=[0.5105368], -likelihood = -146.65667
# Iteration=15, theta_new=[0.51083594], -likelihood = -146.65761
# Iteration=16, theta_new=[0.51103549], -likelihood = -146.65840
# Iteration=17, theta_new=[0.51123511], -likelihood = -146.65882
# Iteration=18, theta_new=[0.51133496], -likelihood = -146.65917
# Iteration=19, theta_new=[0.51143483], -likelihood = -146.65932
# Iteration=20, theta_new=[0.51153472], -likelihood = -146.65945
# Iteration=21, theta_new=[0.51163463], -likelihood = -146.65956
# Iteration=22, theta_new=[0.51173456], -likelihood = -146.65964
# Iteration=23, theta_new=[0.51183451], -likelihood = -146.65970
# norm=0.0
# Iteration=24, theta_new=[0.51183451], -likelihood = -146.65976
# 2-th start
# Iteration=1, theta_new=[1.24118262], -likelihood = -74.64122
# Iteration=2, theta_new=[1.25821252], -likelihood = -74.90134
# Iteration=3, theta_new=[1.27621331], -likelihood = -75.16646
# Iteration=4, theta_new=[1.29521942], -likelihood = -75.43130
# Iteration=5, theta_new=[1.31533074], -likelihood = -75.69147
# Iteration=6, theta_new=[1.33652503], -likelihood = -75.94335
# Iteration=7, theta_new=[1.35903973], -likelihood = -76.18192
# Iteration=8, theta_new=[1.3832609], -likelihood = -76.40522
# Iteration=9, theta_new=[1.40973738], -likelihood = -76.61185
# Iteration=10, theta_new=[1.43968053], -likelihood = -76.80015
# Iteration=11, theta_new=[1.47630522], -likelihood = -76.96965
# Iteration=12, theta_new=[1.53671263], -likelihood = -77.12093
# Iteration=13, theta_new=[1.57077843], -likelihood = -77.22568
# norm=0.0
# Iteration=14, theta_new=[1.57077843], -likelihood = -77.23370
# 3-th start
# Iteration=1, theta_new=[-3.03719367], -likelihood = -67.36465
# Iteration=2, theta_new=[-3.04238418], -likelihood = -67.58800
# Iteration=3, theta_new=[-3.04773213], -likelihood = -67.82054
# Iteration=4, theta_new=[-3.05316388], -likelihood = -68.06495
# Iteration=5, theta_new=[-3.0586053], -likelihood = -68.31713
# Iteration=6, theta_new=[-3.06413111], -likelihood = -68.57268
# Iteration=7, theta_new=[-3.06966689], -likelihood = -68.83415
# Iteration=8, theta_new=[-3.07513773], -likelihood = -69.09707
# Iteration=9, theta_new=[-3.08061832], -likelihood = -69.35696
# Iteration=10, theta_new=[-3.08603347], -likelihood = -69.61655
# Iteration=11, theta_new=[-3.0913828], -likelihood = -69.87156
# Iteration=12, theta_new=[-3.09666592], -likelihood = -70.12139
# Iteration=13, theta_new=[-3.10188247], -likelihood = -70.36559
# Iteration=14, theta_new=[-3.10703208], -likelihood = -70.60381
# Iteration=15, theta_new=[-3.11211439], -likelihood = -70.83580
# Iteration=16, theta_new=[-3.11712902], -likelihood = -71.06144
# Iteration=17, theta_new=[-3.12199954], -likelihood = -71.28068
# Iteration=18, theta_new=[-3.12680144], -likelihood = -71.49031
# Iteration=19, theta_new=[-3.13153439], -likelihood = -71.69378
# Iteration=20, theta_new=[-3.13619806], -likelihood = -71.89128
# Iteration=21, theta_new=[-3.1407921], -likelihood = -72.08304
# Iteration=22, theta_new=[-3.14531619], -likelihood = -72.26932
# Iteration=23, theta_new=[-3.14977], -likelihood = -72.45046
# Iteration=24, theta_new=[-3.15415323], -likelihood = -72.62679
# Iteration=25, theta_new=[-3.15846555], -likelihood = -72.79867
# Iteration=26, theta_new=[-3.16278376], -likelihood = -72.96650
# Iteration=27, theta_new=[-3.16703066], -likelihood = -73.13365
# Iteration=28, theta_new=[-3.17128327], -likelihood = -73.29753
# Iteration=29, theta_new=[-3.17554158], -likelihood = -73.46155
# Iteration=30, theta_new=[-3.17980562], -likelihood = -73.62617
# Iteration=31, theta_new=[-3.18407537], -likelihood = -73.79188
# Iteration=32, theta_new=[-3.18835087], -likelihood = -73.95923
# Iteration=33, theta_new=[-3.19270994], -likelihood = -74.12880
# Iteration=34, theta_new=[-3.19715292], -likelihood = -74.30436
# Iteration=35, theta_new=[-3.20168014], -likelihood = -74.48681
# Iteration=36, theta_new=[-3.20629193], -likelihood = -74.67714
# Iteration=37, theta_new=[-3.21106693], -likelihood = -74.87649
# Iteration=38, theta_new=[-3.21600583], -likelihood = -75.08968
# Iteration=39, theta_new=[-3.22110935], -likelihood = -75.31861
# Iteration=40, theta_new=[-3.2264569], -likelihood = -75.56545
# Iteration=41, theta_new=[-3.23204963], -likelihood = -75.83683
# Iteration=42, theta_new=[-3.23796769], -likelihood = -76.13636
# Iteration=43, theta_new=[-3.24421279], -likelihood = -76.47295
# Iteration=44, theta_new=[-3.25086597], -likelihood = -76.85254
# Iteration=45, theta_new=[-3.25800898], -likelihood = -77.28757
# Iteration=46, theta_new=[-3.26580402], -likelihood = -77.79352
# Iteration=47, theta_new=[-3.27425557], -likelihood = -78.39626
# Iteration=48, theta_new=[-3.28352836], -likelihood = -79.11521
# Iteration=49, theta_new=[-3.29378939], -likelihood = -79.98947
# Iteration=50, theta_new=[-3.30520828], -likelihood = -81.06974
# 4-th start
# Iteration=1, theta_new=[2.80921856], -likelihood = -113.10149
# Iteration=2, theta_new=[2.78706578], -likelihood = -119.08266
# Iteration=3, theta_new=[2.76631249], -likelihood = -124.69527
# Iteration=4, theta_new=[2.74726707], -likelihood = -129.63667
# Iteration=5, theta_new=[2.7302308], -likelihood = -133.78388
# Iteration=6, theta_new=[2.71516654], -likelihood = -137.10079
# Iteration=7, theta_new=[2.70204146], -likelihood = -139.67653
# Iteration=8, theta_new=[2.69076097], -likelihood = -141.61980
# Iteration=9, theta_new=[2.68110418], -likelihood = -143.05127
# Iteration=10, theta_new=[2.67285665], -likelihood = -144.09382
# Iteration=11, theta_new=[2.66587433], -likelihood = -144.84690
# Iteration=12, theta_new=[2.65995161], -likelihood = -145.38376
# Iteration=13, theta_new=[2.65501616], -likelihood = -145.76598
# Iteration=14, theta_new=[2.65086769], -likelihood = -146.03283
# Iteration=15, theta_new=[2.6473729], -likelihood = -146.22067
# Iteration=16, theta_new=[2.64446441], -likelihood = -146.35301
# Iteration=17, theta_new=[2.64201105], -likelihood = -146.44509
# Iteration=18, theta_new=[2.63994697], -likelihood = -146.51000
# Iteration=19, theta_new=[2.63820677], -likelihood = -146.55557
# Iteration=20, theta_new=[2.63678977], -likelihood = -146.58757
# Iteration=21, theta_new=[2.63556665], -likelihood = -146.60930
# Iteration=22, theta_new=[2.63453713], -likelihood = -146.62494
# Iteration=23, theta_new=[2.63370097], -likelihood = -146.63586
# Iteration=24, theta_new=[2.63299368], -likelihood = -146.64322
# Iteration=25, theta_new=[2.63241514], -likelihood = -146.64839
# Iteration=26, theta_new=[2.63196527], -likelihood = -146.65190
# Iteration=27, theta_new=[2.63157973], -likelihood = -146.65419
# Iteration=28, theta_new=[2.63125849], -likelihood = -146.65584
# Iteration=29, theta_new=[2.63100153], -likelihood = -146.65699
# Iteration=30, theta_new=[2.63074459], -likelihood = -146.65778
# Iteration=31, theta_new=[2.63055191], -likelihood = -146.65843
# Iteration=32, theta_new=[2.63035925], -likelihood = -146.65884
# Iteration=33, theta_new=[2.63023081], -likelihood = -146.65917
# Iteration=34, theta_new=[2.63010238], -likelihood = -146.65936
# Iteration=35, theta_new=[2.63003817], -likelihood = -146.65951
# Iteration=36, theta_new=[2.62997396], -likelihood = -146.65957
# Iteration=37, theta_new=[2.62990975], -likelihood = -146.65963
# Iteration=38, theta_new=[2.62984554], -likelihood = -146.65968
# Iteration=39, theta_new=[2.62978134], -likelihood = -146.65972
# Iteration=40, theta_new=[2.62971714], -likelihood = -146.65975
# norm=0.0
# Iteration=41, theta_new=[2.62971714], -likelihood = -146.65977
# 5-th start
# Iteration=1, theta_new=[1.57080735], -likelihood = -77.21243
# norm=0.0
# Iteration=2, theta_new=[1.57080735], -likelihood = -77.23370
# 6-th start
# Iteration=1, theta_new=[-1.97034364], -likelihood = -77.55191
# Iteration=2, theta_new=[-1.9629356], -likelihood = -77.63584
# Iteration=3, theta_new=[-1.95603466], -likelihood = -77.70656
# Iteration=4, theta_new=[-1.94963552], -likelihood = -77.76589
# Iteration=5, theta_new=[-1.94373331], -likelihood = -77.81545
# Iteration=6, theta_new=[-1.93822859], -likelihood = -77.85665
# Iteration=7, theta_new=[-1.93311803], -likelihood = -77.89130
# Iteration=8, theta_new=[-1.9283985], -likelihood = -77.92031
# Iteration=9, theta_new=[-1.92406714], -likelihood = -77.94447
# Iteration=10, theta_new=[-1.92002735], -likelihood = -77.96450
# Iteration=11, theta_new=[-1.9162773], -likelihood = -77.98137
# Iteration=12, theta_new=[-1.91281527], -likelihood = -77.99552
# Iteration=13, theta_new=[-1.9096397], -likelihood = -78.00732
# Iteration=14, theta_new=[-1.90674913], -likelihood = -78.01711
# Iteration=15, theta_new=[-1.90404914], -likelihood = -78.02517
# Iteration=16, theta_new=[-1.90153892], -likelihood = -78.03198
# Iteration=17, theta_new=[-1.89931056], -likelihood = -78.03772
# Iteration=18, theta_new=[-1.89727028], -likelihood = -78.04233
# Iteration=19, theta_new=[-1.89532484], -likelihood = -78.04617
# Iteration=20, theta_new=[-1.89356648], -likelihood = -78.04949
# Iteration=21, theta_new=[-1.89199467], -likelihood = -78.05221
# Iteration=22, theta_new=[-1.89051655], -likelihood = -78.05442
# Iteration=23, theta_new=[-1.8891319], -likelihood = -78.05631
# Iteration=24, theta_new=[-1.88793274], -likelihood = -78.05792
# Iteration=25, theta_new=[-1.88682653], -likelihood = -78.05918
# Iteration=26, theta_new=[-1.8858131], -likelihood = -78.06025
# Iteration=27, theta_new=[-1.88489229], -likelihood = -78.06114
# Iteration=28, theta_new=[-1.88397193], -likelihood = -78.06187
# Iteration=29, theta_new=[-1.88314402], -likelihood = -78.06255
# Iteration=30, theta_new=[-1.88240841], -likelihood = -78.06309
# Iteration=31, theta_new=[-1.88176501], -likelihood = -78.06353
# Iteration=32, theta_new=[-1.88112183], -likelihood = -78.06389
# Iteration=33, theta_new=[-1.88057072], -likelihood = -78.06421
# Iteration=34, theta_new=[-1.88001977], -likelihood = -78.06446
# Iteration=35, theta_new=[-1.87956078], -likelihood = -78.06468
# Iteration=36, theta_new=[-1.87910191], -likelihood = -78.06486
# Iteration=37, theta_new=[-1.87873489], -likelihood = -78.06501
# Iteration=38, theta_new=[-1.87836795], -likelihood = -78.06513
# Iteration=39, theta_new=[-1.8780928], -likelihood = -78.06523
# Iteration=40, theta_new=[-1.87781769], -likelihood = -78.06530
# Iteration=41, theta_new=[-1.87754262], -likelihood = -78.06537
# Iteration=42, theta_new=[-1.87726759], -likelihood = -78.06543
# Iteration=43, theta_new=[-1.87708426], -likelihood = -78.06548
# Iteration=44, theta_new=[-1.87690095], -likelihood = -78.06551
# Iteration=45, theta_new=[-1.87671766], -likelihood = -78.06554
# Iteration=46, theta_new=[-1.87653439], -likelihood = -78.06557
# Iteration=47, theta_new=[-1.87635113], -likelihood = -78.06560
# Iteration=48, theta_new=[-1.8761679], -likelihood = -78.06562
# Iteration=49, theta_new=[-1.87607629], -likelihood = -78.06564
# Iteration=50, theta_new=[-1.87598468], -likelihood = -78.06565
# 7-th start
# Iteration=1, theta_new=[-0.08741872], -likelihood = -68.11115
# Iteration=2, theta_new=[-0.08195505], -likelihood = -68.36438
# Iteration=3, theta_new=[-0.0764487], -likelihood = -68.62141
# Iteration=4, theta_new=[-0.07095395], -likelihood = -68.88221
# Iteration=5, theta_new=[-0.0654661], -likelihood = -69.14325
# Iteration=6, theta_new=[-0.05999354], -likelihood = -69.40388
# Iteration=7, theta_new=[-0.05455663], -likelihood = -69.66287
# Iteration=8, theta_new=[-0.04918621], -likelihood = -69.91856
# Iteration=9, theta_new=[-0.04388332], -likelihood = -70.16892
# Iteration=10, theta_new=[-0.03867218], -likelihood = -70.41348
# Iteration=11, theta_new=[-0.03353603], -likelihood = -70.65083
# Iteration=12, theta_new=[-0.02850563], -likelihood = -70.88156
# Iteration=13, theta_new=[-0.02351714], -likelihood = -71.10423
# Iteration=14, theta_new=[-0.01866673], -likelihood = -71.32167
# Iteration=15, theta_new=[-0.01388338], -likelihood = -71.52981
# Iteration=16, theta_new=[-0.00919774], -likelihood = -71.73190
# Iteration=17, theta_new=[-0.00459887], -likelihood = -71.92687
# Iteration=18, theta_new=[-5.74858733e-05], -likelihood = -72.11549
# norm=0.0
# Iteration=19, theta_new=[-5.74858733e-05], -likelihood = -72.24013
# 8-th start
# Iteration=1, theta_new=[0.25384143], -likelihood = -94.38719
# Iteration=2, theta_new=[0.27565593], -likelihood = -99.00597
# Iteration=3, theta_new=[0.29842985], -likelihood = -104.34307
# Iteration=4, theta_new=[0.32145324], -likelihood = -110.20409
# Iteration=5, theta_new=[0.34405542], -likelihood = -116.23969
# Iteration=6, theta_new=[0.36555889], -likelihood = -122.07561
# Iteration=7, theta_new=[0.38547899], -likelihood = -127.36939
# Iteration=8, theta_new=[0.40347303], -likelihood = -131.91019
# Iteration=9, theta_new=[0.4194701], -likelihood = -135.61515
# Iteration=10, theta_new=[0.43347975], -likelihood = -138.53131
# Iteration=11, theta_new=[0.44567137], -likelihood = -140.75707
# Iteration=12, theta_new=[0.45611679], -likelihood = -142.42454
# Iteration=13, theta_new=[0.46502532], -likelihood = -143.64311
# Iteration=14, theta_new=[0.47256382], -likelihood = -144.52391
# Iteration=15, theta_new=[0.47893235], -likelihood = -145.15273
# Iteration=16, theta_new=[0.48435776], -likelihood = -145.59955
# Iteration=17, theta_new=[0.48889861], -likelihood = -145.91870
# Iteration=18, theta_new=[0.49271813], -likelihood = -146.14208
# Iteration=19, theta_new=[0.49589386], -likelihood = -146.29905
# Iteration=20, theta_new=[0.49850892], -likelihood = -146.40801
# Iteration=21, theta_new=[0.50074832], -likelihood = -146.48306
# Iteration=22, theta_new=[0.50260656], -likelihood = -146.53677
# Iteration=23, theta_new=[0.50417721], -likelihood = -146.57397
# Iteration=24, theta_new=[0.50545735], -likelihood = -146.60019
# Iteration=25, theta_new=[0.50654329], -likelihood = -146.61803
# Iteration=26, theta_new=[0.5074337], -likelihood = -146.63068
# Iteration=27, theta_new=[0.50822656], -likelihood = -146.63935
# Iteration=28, theta_new=[0.50882214], -likelihood = -146.64578
# Iteration=29, theta_new=[0.50931904], -likelihood = -146.64982
# Iteration=30, theta_new=[0.50981642], -likelihood = -146.65266
# Iteration=31, theta_new=[0.51021471], -likelihood = -146.65503
# Iteration=32, theta_new=[0.51051367], -likelihood = -146.65659
# Iteration=33, theta_new=[0.5108128], -likelihood = -146.65755
# Iteration=34, theta_new=[0.51101233], -likelihood = -146.65835
# Iteration=35, theta_new=[0.51121195], -likelihood = -146.65878
# Iteration=36, theta_new=[0.51131179], -likelihood = -146.65913
# Iteration=37, theta_new=[0.51141166], -likelihood = -146.65929
# Iteration=38, theta_new=[0.51151154], -likelihood = -146.65942
# Iteration=39, theta_new=[0.51161145], -likelihood = -146.65953
# Iteration=40, theta_new=[0.51171137], -likelihood = -146.65962
# Iteration=41, theta_new=[0.51181132], -likelihood = -146.65969
# norm=0.0
# Iteration=42, theta_new=[0.51181132], -likelihood = -146.65975
# 9-th start
# Iteration=1, theta_new=[1.27787093], -likelihood = -75.19028
# Iteration=2, theta_new=[1.29696412], -likelihood = -75.45482
# Iteration=3, theta_new=[1.31716586], -likelihood = -75.71429
# Iteration=4, theta_new=[1.33851835], -likelihood = -75.96510
# Iteration=5, theta_new=[1.36119735], -likelihood = -76.20293
# Iteration=6, theta_new=[1.3855899], -likelihood = -76.42501
# Iteration=7, theta_new=[1.41231392], -likelihood = -76.62995
# Iteration=8, theta_new=[1.44272557], -likelihood = -76.81649
# Iteration=9, theta_new=[1.48034351], -likelihood = -76.98448
# Iteration=10, theta_new=[1.59223666], -likelihood = -77.13416
# Iteration=11, theta_new=[1.57077878], -likelihood = -77.23077
# norm=0.0
# Iteration=12, theta_new=[1.57077878], -likelihood = -77.23370

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)

# %%
print(f"Погрешность в смысле разности углов в градусах: {np.abs(EM_theta1_deg-theta1_deg)}.\nПогрешность в смысле разности синусов углов {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах: [0.69575273].
# Погрешность в смысле разности синусов углов [0.01062103].

# %% [markdown]
# # Case 2

# %% [markdown]
# Имеется 5 датчиков, 2 источника (дисперсии сигналов - 2 и 3), и шум на каждом датчике имеет дисперсию 7.1.

# %%
Num_sensors2 = 5
Num_emitters2 = 2
sample_size2 = 100
theta2_rad = np.array([0.34906585, 1.22173048]) # Направление прибытия (DOA) в радианах
theta2_deg = np.rad2deg(theta2_rad) # Направление прибытия (DOA) в градусах
GS_2 = np.array([[2,0],[0,3]]) # Ковариация сигнала
GN_2 = 7.1*np.eye(5, dtype=np.float64) # Ковариация шума
A2 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors2).reshape(-1,1) * np.sin(theta2_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s2 = CN(Num_emitters2, sample_size2, GS_2)
n2 = CN(Num_sensors2, sample_size2, GN_2)
X2 = (A2 @ s2.T + n2.T).T

# %%
EM_theta2_rad, neglhd_2, K2, mu2 = multi_start_EM(X2, GS_2, GN_2, 10, max_iter=20, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[1.40139134 2.21799987], -likelihood = -354.30241
# Iteration=2, theta_new=[1.5707938  2.22450719], -likelihood = -362.92190
# Iteration=3, theta_new=[1.57079175 2.22448109], -likelihood = -366.14600
# Iteration=4, theta_new=[1.57077509 2.22445928], -likelihood = -366.14389
# Iteration=5, theta_new=[1.57075842 2.22443748], -likelihood = -366.14213
# Iteration=6, theta_new=[1.57083573 2.22440585], -likelihood = -366.14036
# Iteration=7, theta_new=[1.57082454 2.22438989], -likelihood = -366.13780
# Iteration=8, theta_new=[1.57078906 2.22436253], -likelihood = -366.13651
# norm=0.0
# Iteration=9, theta_new=[1.57078906 2.22436253], -likelihood = -366.13430
# 1-th start
# Iteration=1, theta_new=[0.91723119 2.70834774], -likelihood = -400.19282
# Iteration=2, theta_new=[0.96373888 2.72378777], -likelihood = -422.00549
# Iteration=3, theta_new=[1.00598215 2.73708414], -likelihood = -439.91214
# Iteration=4, theta_new=[1.0439806  2.74872244], -likelihood = -454.41189
# Iteration=5, theta_new=[1.07748899 2.75891096], -likelihood = -465.73349
# Iteration=6, theta_new=[1.10670664 2.76782121], -likelihood = -474.16507
# Iteration=7, theta_new=[1.13183778 2.77557251], -likelihood = -480.23379
# Iteration=8, theta_new=[1.15307112 2.78228423], -likelihood = -484.47539
# Iteration=9, theta_new=[1.17096977 2.78802348], -likelihood = -487.36800
# Iteration=10, theta_new=[1.18584827 2.7929263 ], -likelihood = -489.31859
# Iteration=11, theta_new=[1.19812278 2.79709669], -likelihood = -490.61787
# Iteration=12, theta_new=[1.20819113 2.80058525], -likelihood = -491.47750
# Iteration=13, theta_new=[1.21645535 2.80357652], -likelihood = -492.04077
# Iteration=14, theta_new=[1.2231327  2.80609375], -likelihood = -492.41390
# Iteration=15, theta_new=[1.22859451 2.80818807], -likelihood = -492.65670
# Iteration=16, theta_new=[1.23298145 2.80993578], -likelihood = -492.81448
# Iteration=17, theta_new=[1.23647402 2.81141268], -likelihood = -492.91598
# Iteration=18, theta_new=[1.23932299 2.81265257], -likelihood = -492.98128
# Iteration=19, theta_new=[1.24158508 2.81366799], -likelihood = -493.02321
# Iteration=20, theta_new=[1.24344404 2.81452836], -likelihood = -493.04916
# 2-th start
# Iteration=1, theta_new=[1.57081929 2.10949494], -likelihood = -345.02144
# Iteration=2, theta_new=[1.57079738 2.12186023], -likelihood = -353.98558
# Iteration=3, theta_new=[1.5707959  2.13253297], -likelihood = -355.57127
# Iteration=4, theta_new=[1.57082351 2.1418321 ], -likelihood = -356.88865
# Iteration=5, theta_new=[1.5707719  2.14995429], -likelihood = -357.99624
# Iteration=6, theta_new=[1.57082529 2.1570885 ], -likelihood = -358.93226
# Iteration=7, theta_new=[1.57078797 2.16337757], -likelihood = -359.72994
# Iteration=8, theta_new=[1.57080077 2.16895658], -likelihood = -360.41398
# Iteration=9, theta_new=[1.57075415 2.17395251], -likelihood = -361.00574
# Iteration=10, theta_new=[1.57076037 2.17839854], -likelihood = -361.52366
# Iteration=11, theta_new=[1.57078707 2.18239415], -likelihood = -361.97505
# Iteration=12, theta_new=[1.57079519 2.18596472], -likelihood = -362.37310
# Iteration=13, theta_new=[1.57077349 2.18917489], -likelihood = -362.72275
# Iteration=14, theta_new=[1.57081413 2.19208273], -likelihood = -363.03224
# Iteration=15, theta_new=[1.57082969 2.19472781], -likelihood = -363.30864
# Iteration=16, theta_new=[1.57079566 2.19713971], -likelihood = -363.55683
# Iteration=17, theta_new=[1.57085159 2.19931874], -likelihood = -363.78047
# Iteration=18, theta_new=[1.57076598 2.20130228], -likelihood = -363.98034
# Iteration=19, theta_new=[1.57079863 2.20312339], -likelihood = -364.16050
# Iteration=20, theta_new=[1.57076832 2.20475997], -likelihood = -364.32442
# 3-th start
# Iteration=1, theta_new=[2.10388067 0.5185564 ], -likelihood = -409.06544
# Iteration=2, theta_new=[2.07259752 0.49059501], -likelihood = -427.38730
# Iteration=3, theta_new=[2.04568759 0.46609026], -likelihood = -441.97474
# Iteration=4, theta_new=[2.02229762 0.44456342], -likelihood = -453.98681
# Iteration=5, theta_new=[2.00193318 0.42584374], -likelihood = -463.80442
# Iteration=6, theta_new=[1.98422408 0.40963479], -likelihood = -471.59354
# Iteration=7, theta_new=[1.96895767 0.39574063], -likelihood = -477.60458
# Iteration=8, theta_new=[1.95584532 0.38392493], -likelihood = -482.10155
# Iteration=9, theta_new=[1.94464811 0.37390129], -likelihood = -485.38601
# Iteration=10, theta_new=[1.93521851 0.36544654], -likelihood = -487.74594
# Iteration=11, theta_new=[1.9273289  0.35837131], -likelihood = -489.41255
# Iteration=12, theta_new=[1.92071801 0.35242688], -likelihood = -490.57261
# Iteration=13, theta_new=[1.9153252  0.34746715], -likelihood = -491.37857
# Iteration=14, theta_new=[1.91079039 0.34331691], -likelihood = -491.93054
# Iteration=15, theta_new=[1.90714845 0.33985325], -likelihood = -492.30989
# Iteration=16, theta_new=[1.90411579 0.33694792], -likelihood = -492.56735
# Iteration=17, theta_new=[1.90167509 0.33453469], -likelihood = -492.74301
# Iteration=18, theta_new=[1.89966102 0.33255973], -likelihood = -492.86078
# Iteration=19, theta_new=[1.8980187  0.33088412], -likelihood = -492.93864
# Iteration=20, theta_new=[1.89673838 0.32951095], -likelihood = -492.99143
# 4-th start
# Iteration=1, theta_new=[1.21615564 1.570768  ], -likelihood = -312.94020
# Iteration=2, theta_new=[1.14368248 1.57078284], -likelihood = -326.01312
# Iteration=3, theta_new=[1.0875712  1.57081978], -likelihood = -337.98775
# Iteration=4, theta_new=[1.04374529 1.57077012], -likelihood = -347.90168
# Iteration=5, theta_new=[1.00891226 1.57084824], -likelihood = -355.43112
# Iteration=6, theta_new=[0.98061051 1.57083634], -likelihood = -361.02016
# Iteration=7, theta_new=[0.95715249 1.57077687], -likelihood = -365.20741
# Iteration=8, theta_new=[0.93732923 1.57075475], -likelihood = -368.40770
# Iteration=9, theta_new=[0.92025176 1.57074572], -likelihood = -370.91542
# Iteration=10, theta_new=[0.90531324 1.57078832], -likelihood = -372.93392
# Iteration=11, theta_new=[0.89205421 1.5707874 ], -likelihood = -374.59698
# Iteration=12, theta_new=[0.88011761 1.57083156], -likelihood = -375.99822
# Iteration=13, theta_new=[0.86923237 1.57077198], -likelihood = -377.20457
# Iteration=14, theta_new=[0.85919046 1.57080669], -likelihood = -378.26366
# Iteration=15, theta_new=[0.84981863 1.57078936], -likelihood = -379.21009
# Iteration=16, theta_new=[0.84095901 1.57080026], -likelihood = -380.07055
# Iteration=17, theta_new=[0.83251297 1.57077879], -likelihood = -380.86710
# Iteration=18, theta_new=[0.82438413 1.57079909], -likelihood = -381.61435
# Iteration=19, theta_new=[0.81647484 1.5707467 ], -likelihood = -382.32536
# Iteration=20, theta_new=[0.80871829 1.58703982], -likelihood = -383.01262
# 5-th start
# Iteration=1, theta_new=[1.21859034 0.18460718], -likelihood = -449.72012
# Iteration=2, theta_new=[1.22449934 0.20586201], -likelihood = -460.58146
# Iteration=3, theta_new=[1.22971186 0.22435409], -likelihood = -469.22716
# Iteration=4, theta_new=[1.23423037 0.24022122], -likelihood = -475.85863
# Iteration=5, theta_new=[1.23804108 0.25374219], -likelihood = -480.79300
# Iteration=6, theta_new=[1.24116768 0.26516837], -likelihood = -484.39400
# Iteration=7, theta_new=[1.24360235 0.27478066], -likelihood = -486.97643
# Iteration=8, theta_new=[1.24557587 0.2828323 ], -likelihood = -488.80840
# Iteration=9, theta_new=[1.24704708 0.2895742 ], -likelihood = -490.09704
# Iteration=10, theta_new=[1.24821882 0.29519686], -likelihood = -491.00070
# Iteration=11, theta_new=[1.24906515 0.29986551], -likelihood = -491.63069
# Iteration=12, theta_new=[1.24973679 0.30376176], -likelihood = -492.06794
# Iteration=13, theta_new=[1.25016743 0.30697761], -likelihood = -492.37286
# Iteration=14, theta_new=[1.25051125 0.30963322], -likelihood = -492.58361
# Iteration=15, theta_new=[1.25077578 0.3118481 ], -likelihood = -492.72953
# Iteration=16, theta_new=[1.25087543 0.31369423], -likelihood = -492.83180
# Iteration=17, theta_new=[1.25095716 0.3152136 ], -likelihood = -492.90389
# Iteration=18, theta_new=[1.25096675 0.3164721 ], -likelihood = -492.95398
# Iteration=19, theta_new=[1.25098784 0.31752237], -likelihood = -492.98935
# Iteration=20, theta_new=[1.25098083 0.31840713], -likelihood = -493.01444
# 6-th start
# Iteration=1, theta_new=[-2.84382496 -2.08565665], -likelihood = -260.94749
# Iteration=2, theta_new=[-2.83908539 -2.00881436], -likelihood = -291.76114
# Iteration=3, theta_new=[-2.83586566 -1.92911076], -likelihood = -320.38979
# Iteration=4, theta_new=[-2.83340683 -1.8462714 ], -likelihood = -343.18907
# Iteration=5, theta_new=[-2.83110562 -1.7539448 ], -likelihood = -359.50073
# Iteration=6, theta_new=[-2.82875092 -1.57072305], -likelihood = -370.44742
# Iteration=7, theta_new=[-2.82631521 -1.57079795], -likelihood = -375.24213
# Iteration=8, theta_new=[-2.82404108 -1.57081235], -likelihood = -375.28834
# Iteration=9, theta_new=[-2.82192842 -1.57083749], -likelihood = -375.32760
# Iteration=10, theta_new=[-2.81995088 -1.57078243], -likelihood = -375.36076
# Iteration=11, theta_new=[-2.81809524 -1.57079343], -likelihood = -375.38896
# Iteration=12, theta_new=[-2.81634917 -1.5708186 ], -likelihood = -375.41294
# Iteration=13, theta_new=[-2.81469334 -1.57081165], -likelihood = -375.43335
# Iteration=14, theta_new=[-2.81313023 -1.57080506], -likelihood = -375.45079
# Iteration=15, theta_new=[-2.81165551 -1.57079066], -likelihood = -375.46558
# Iteration=16, theta_new=[-2.81027453 -1.57077291], -likelihood = -375.47806
# Iteration=17, theta_new=[-2.80898366 -1.57075377], -likelihood = -375.48846
# Iteration=18, theta_new=[-2.80776545 -1.5707836 ], -likelihood = -375.49707
# Iteration=19, theta_new=[-2.80659339 -1.57081751], -likelihood = -375.50422
# Iteration=20, theta_new=[-2.80550739 -1.57081596], -likelihood = -375.51023
# 7-th start
# Iteration=1, theta_new=[-1.57076925 -1.3941728 ], -likelihood = -296.92353
# Iteration=2, theta_new=[-1.5707967  -1.57075239], -likelihood = -299.59507
# Iteration=3, theta_new=[-1.57082984 -1.5707694 ], -likelihood = -301.47636
# norm=0.0
# Iteration=4, theta_new=[-1.57082984 -1.5707694 ], -likelihood = -301.47636
# 8-th start
# Iteration=1, theta_new=[ 0.2210561  -0.43136845], -likelihood = -286.86264
# Iteration=2, theta_new=[ 0.24193294 -0.43979983], -likelihood = -298.19854
# Iteration=3, theta_new=[ 0.25953969 -0.44706051], -likelihood = -306.70475
# Iteration=4, theta_new=[ 0.27406162 -0.4529826 ], -likelihood = -312.64970
# Iteration=5, theta_new=[ 0.28588577 -0.45762713], -likelihood = -316.61517
# Iteration=6, theta_new=[ 0.29547152 -0.46124027], -likelihood = -319.19070
# Iteration=7, theta_new=[ 0.30319325 -0.4639441 ], -likelihood = -320.84490
# Iteration=8, theta_new=[ 0.30931196 -0.46593353], -likelihood = -321.89432
# Iteration=9, theta_new=[ 0.31422978 -0.46740864], -likelihood = -322.54891
# Iteration=10, theta_new=[ 0.31812925 -0.46843006], -likelihood = -322.96308
# Iteration=11, theta_new=[ 0.32129658 -0.46916638], -likelihood = -323.22121
# Iteration=12, theta_new=[ 0.32379899 -0.46960748], -likelihood = -323.38610
# Iteration=13, theta_new=[ 0.3258183  -0.46992143], -likelihood = -323.48817
# Iteration=14, theta_new=[ 0.32741282 -0.47016785], -likelihood = -323.55292
# Iteration=15, theta_new=[ 0.32868667 -0.47028373], -likelihood = -323.59309
# Iteration=16, theta_new=[ 0.32969356 -0.47023442], -likelihood = -323.61815
# Iteration=17, theta_new=[ 0.33051969 -0.47023614], -likelihood = -323.63364
# Iteration=18, theta_new=[ 0.33120457 -0.47017353], -likelihood = -323.64357
# Iteration=19, theta_new=[ 0.33171804 -0.47019343], -likelihood = -323.64989
# Iteration=20, theta_new=[ 0.33208951 -0.4701519 ], -likelihood = -323.65353
# 9-th start
# Iteration=1, theta_new=[ 1.01642433 -1.74128728], -likelihood = -354.27168
# Iteration=2, theta_new=[ 0.9870413  -1.78772276], -likelihood = -364.57889
# Iteration=3, theta_new=[ 0.96698679 -1.81206301], -likelihood = -369.86698
# Iteration=4, theta_new=[ 0.95272732 -1.82528736], -likelihood = -372.67637
# Iteration=5, theta_new=[ 0.9421271  -1.83211512], -likelihood = -374.26878
# Iteration=6, theta_new=[ 0.93387539 -1.83498789], -likelihood = -375.24184
# Iteration=7, theta_new=[ 0.92722914 -1.83532195], -likelihood = -375.88427
# Iteration=8, theta_new=[ 0.92170858 -1.83403143], -likelihood = -376.33717
# Iteration=9, theta_new=[ 0.9168469  -1.83164255], -likelihood = -376.67648
# Iteration=10, theta_new=[ 0.91251772 -1.828465  ], -likelihood = -376.95311
# Iteration=11, theta_new=[ 0.90852712 -1.82489131], -likelihood = -377.18540
# Iteration=12, theta_new=[ 0.90479629 -1.82098775], -likelihood = -377.39273
# Iteration=13, theta_new=[ 0.90119262 -1.81684731], -likelihood = -377.58216
# Iteration=14, theta_new=[ 0.89774885 -1.81252141], -likelihood = -377.76345
# Iteration=15, theta_new=[ 0.89439952 -1.80811897], -likelihood = -377.93564
# Iteration=16, theta_new=[ 0.89109082 -1.80361397], -likelihood = -378.10383
# Iteration=17, theta_new=[ 0.88784576 -1.7989977 ], -likelihood = -378.27129
# Iteration=18, theta_new=[ 0.88461739 -1.79433503], -likelihood = -378.43681
# Iteration=19, theta_new=[ 0.88133753 -1.78963579], -likelihood = -378.60383
# Iteration=20, theta_new=[ 0.87810531 -1.78486895], -likelihood = -378.77671

# %%
EM_theta2_deg = np.rad2deg(EM_theta2_rad)

# %%
print(f"Погрешность в смысле разности углов в градусах: {np.abs(EM_theta2_deg-theta2_deg)}.\nПогрешность в смысле разности синусов углов {np.abs(np.sin(EM_theta2_rad)-np.sin(theta2_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах: [51.24409574 51.26059678].
# Погрешность в смысле разности синусов углов [0.60487686 0.61842829].

# %% [markdown]
# ## Примерный вид функции, оптимизируемой на М-шаге (первая итерация):

# %%
W1, W2 = goal_function_EM(X1, GS_1, GN_2, 50)

# %%
plt.title("График функции, подлежащей максимизации, на первом шаге ЕМ-алгоритма")
plt.plot(np.rad2deg(W1), W2.real, color='green')

# %% [markdown]
# Теперь проведем сравнение с **CAPON** и **MUSIC**:

# %%
R = space_covariance_matrix(X1)
angles = np.linspace(-1*np.pi, np.pi, 1000)
Powers_CAPON = []
Powers_MUSIC = []
for angle in angles:
    a = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1) * np.sin(angle))
    Powers_CAPON.append(capon_func(a,R).real)
    Powers_MUSIC.append(MUSIC(a,R,M=1))

# %%
np.rad2deg(angles[np.argmax(Powers_CAPON)])
# Out:
# 29.369369369369345

# %%
np.rad2deg(angles[np.argmax(Powers_MUSIC)])
# Out:
# 150.8108108108108

# %%
plt.title("График мощности для CAPON")
plt.plot(np.rad2deg(angles), Powers_CAPON) 
plt.xlabel("Angle")
plt.ylabel("Power(CAPON)")
plt.grid()
plt.show()

# %%
plt.title("График мощности для MUSIC")
plt.plot(np.rad2deg(angles), Powers_MUSIC) 
plt.xlabel("Angle")
plt.ylabel("Power(MUSIC)")
plt.grid()
plt.show()
# Out:
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# C:\Users\asus\anaconda3\envs\diploma\lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# # Оценка **CAPON** в градусах для первого случая

# %%
CAPON_theta1_deg = np.rad2deg(angles[np.argmax(Powers_CAPON)])

# %%
print(f"Оценка CAPON: {CAPON_theta1_deg}, \nОценка ЕМ-алгоритма: {EM_theta1_deg}, \nИстинное значение: {theta1_deg}")
# Out:
# Оценка CAPON: 29.369369369369345,
# Оценка ЕМ-алгоритма: [29.34364249],
# Истинное значение: 28.64788975654116

# %% [markdown]
# # Оценка **MUSIC** в градусах для первого случая

# %%
MUSIC_theta1_deg = np.rad2deg(angles[np.argmax(Powers_MUSIC)])
if MUSIC_theta1_deg > 90:
    MUSIC_theta1_deg = 180 - MUSIC_theta1_deg
elif MUSIC_theta1_deg < -90:
    MUSIC_theta1_deg = -(180 - np.abs(MUSIC_theta1_deg))

# %%
print(f"Оценка MUSIC: {MUSIC_theta1_deg}, \nОценка ЕМ-алгоритма: {EM_theta1_deg}, \nИстинное значение: {theta1_deg}")
# Out:
# Оценка MUSIC: 29.189189189189193,
# Оценка ЕМ-алгоритма: [29.34364249],
# Истинное значение: 28.64788975654116

# %% [markdown]
# # Case 3

# %% [markdown]
# Имеется 7 датчиков, 3 источника (дисперсии сигналов - 0.1, 0.5 и 0.9), и шум на каждом датчике имеет дисперсию 1.1.

# %%
Num_sensors3 = 7
Num_emitters3 = 3
sample_size3 = 100
theta3_rad = [0.5, 1.2, 1.6] # Направление прибытия (DOA) в радианах
theta3_deg = np.rad2deg(theta3_rad[0]) # Направление прибытия (DOA) в градусах
GS_3 = np.diag([0.1, 0.5, 0.9]) # Ковариация сигнала
GN_3 = 1.1*np.eye(7, dtype=np.float64) # Ковариация шума
A3 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors3).reshape(-1,1) * np.sin(theta3_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s3 = CN(Num_emitters3, sample_size3, GS_3)
n3 = CN(Num_sensors3, sample_size3, GN_3)
X3 = (A3 @ s3.T + n3.T).T

# %%
EM_theta3_rad, neglhd_3, K3, mu3 = multi_start_EM(X3, GS_3, GN_3, 25, max_iter=20, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[-2.60565214  1.84247058  1.3852545 ], -likelihood = -1024.33435
# Iteration=2, theta_new=[-2.60262966  1.91833345  1.48896118], -likelihood = -1039.35461
# Iteration=3, theta_new=[-2.59954721  1.9613659   1.57076873], -likelihood = -1080.29501
# Iteration=4, theta_new=[-2.59660446  1.99068526  1.57083734], -likelihood = -1097.11461
# Iteration=5, theta_new=[-2.59377155  2.01460057  1.57075108], -likelihood = -1106.92614
# Iteration=6, theta_new=[-2.59106377  2.03445677  1.57080915], -likelihood = -1114.05749
# Iteration=7, theta_new=[-2.58854002  2.05114572  1.57080181], -likelihood = -1119.31090
# Iteration=8, theta_new=[-2.58618327  2.06531053  1.57076031], -likelihood = -1123.23714
# Iteration=9, theta_new=[-2.58400324  2.07744535  1.57079512], -likelihood = -1126.21652
# Iteration=10, theta_new=[-2.58200127  2.08793626  1.57081857], -likelihood = -1128.51250
# Iteration=11, theta_new=[-2.5801572   2.09705911  1.57082048], -likelihood = -1130.30889
# Iteration=12, theta_new=[-2.57849591  2.10501496  1.57080373], -likelihood = -1131.73114
# Iteration=13, theta_new=[-2.57696466  2.11195864  1.57085148], -likelihood = -1132.86637
# Iteration=14, theta_new=[-2.57554734  2.11807936  1.57076039], -likelihood = -1133.77886
# Iteration=15, theta_new=[-2.57429231  2.12347054  1.57083067], -likelihood = -1134.52339
# Iteration=16, theta_new=[-2.57312228  2.12824612  1.57084162], -likelihood = -1135.13277
# Iteration=17, theta_new=[-2.57208163  2.13246213  1.57080297], -likelihood = -1135.63716
# Iteration=18, theta_new=[-2.57110245  2.13622012  1.57076108], -likelihood = -1136.05471
# Iteration=19, theta_new=[-2.57024334  2.13955411  1.57086827], -likelihood = -1136.40544
# Iteration=20, theta_new=[-2.56945084  2.14254852  1.57085   ], -likelihood = -1136.69946
# 1-th start
# Iteration=1, theta_new=[2.2342948  2.94161752 1.16642637], -likelihood = -909.26556
# Iteration=2, theta_new=[2.26766442 2.94200503 1.20697114], -likelihood = -1014.74018
# Iteration=3, theta_new=[2.28780795 2.94251938 1.2409877 ], -likelihood = -1056.71875
# Iteration=4, theta_new=[2.30116052 2.94310614 1.26987705], -likelihood = -1078.92819
# Iteration=5, theta_new=[2.31042294 2.94362186 1.29425577], -likelihood = -1091.78247
# Iteration=6, theta_new=[2.3168564  2.94411709 1.31478705], -likelihood = -1099.44379
# Iteration=7, theta_new=[2.32131369 2.94463266 1.33185171], -likelihood = -1104.08086
# Iteration=8, theta_new=[2.32427032 2.94513071 1.34595985], -likelihood = -1106.88624
# Iteration=9, theta_new=[2.32610809 2.94561506 1.35743374], -likelihood = -1108.59175
# Iteration=10, theta_new=[2.32717262 2.94611974 1.36676842], -likelihood = -1109.62451
# Iteration=11, theta_new=[2.32762971 2.94662192 1.37422593], -likelihood = -1110.25965
# Iteration=12, theta_new=[2.32770533 2.94716542 1.38024101], -likelihood = -1110.64941
# Iteration=13, theta_new=[2.32746958 2.94772996 1.38501321], -likelihood = -1110.89605
# Iteration=14, theta_new=[2.32698046 2.94827709 1.38881202], -likelihood = -1111.05274
# Iteration=15, theta_new=[2.32633366 2.94888449 1.39185927], -likelihood = -1111.15497
# Iteration=16, theta_new=[2.32558715 2.94953045 1.39430381], -likelihood = -1111.22437
# Iteration=17, theta_new=[2.32467872 2.95021221 1.39625076], -likelihood = -1111.27301
# Iteration=18, theta_new=[2.32378737 2.95093457 1.39784256], -likelihood = -1111.30787
# Iteration=19, theta_new=[2.32284236 2.95167011 1.39909269], -likelihood = -1111.33481
# Iteration=20, theta_new=[2.32194129 2.95242261 1.40014064], -likelihood = -1111.35541
# 2-th start
# Iteration=1, theta_new=[ 2.9316623   2.16469936 -3.09006909], -likelihood = -492.19650
# Iteration=2, theta_new=[ 2.9218484   2.09684056 -3.09650948], -likelihood = -643.31181
# Iteration=3, theta_new=[ 2.91263092  2.03579649 -3.10060948], -likelihood = -785.68252
# Iteration=4, theta_new=[ 2.9040171   1.98301008 -3.10280563], -likelihood = -892.71897
# Iteration=5, theta_new=[ 2.89575708  1.93841156 -3.10378229], -likelihood = -963.10797
# Iteration=6, theta_new=[ 2.88754618  1.90134569 -3.10413182], -likelihood = -1006.00793
# Iteration=7, theta_new=[ 2.87905099  1.87093935 -3.10410391], -likelihood = -1031.19374
# Iteration=8, theta_new=[ 2.87003098  1.84635488 -3.10385761], -likelihood = -1045.88885
# Iteration=9, theta_new=[ 2.86032388  1.82683253 -3.10348637], -likelihood = -1054.67966
# Iteration=10, theta_new=[ 2.84960706  1.81141677 -3.1029777 ], -likelihood = -1060.31398
# Iteration=11, theta_new=[ 2.83779821  1.79958758 -3.10226422], -likelihood = -1064.47788
# Iteration=12, theta_new=[ 2.82487449  1.7906128  -3.10137657], -likelihood = -1068.09514
# Iteration=13, theta_new=[ 2.81092468  1.78394131 -3.10013378], -likelihood = -1071.72467
# Iteration=14, theta_new=[ 2.79624402  1.77899278 -3.09855533], -likelihood = -1075.64198
# Iteration=15, theta_new=[ 2.78122066  1.77529901 -3.09648928], -likelihood = -1079.87913
# Iteration=16, theta_new=[ 2.76644598  1.77243223 -3.09405141], -likelihood = -1084.30834
# Iteration=17, theta_new=[ 2.7523936   1.77029365 -3.09121153], -likelihood = -1088.64526
# Iteration=18, theta_new=[ 2.73933188  1.76853325 -3.08806192], -likelihood = -1092.64242
# Iteration=19, theta_new=[ 2.72756119  1.76709482 -3.08472517], -likelihood = -1096.15086
# Iteration=20, theta_new=[ 2.71713462  1.76574321 -3.08126823], -likelihood = -1099.07583
# 3-th start
# Iteration=1, theta_new=[ 0.44943875 -0.44656272  0.2039392 ], -likelihood = -290.80952
# Iteration=2, theta_new=[ 0.45994675 -0.45968564  0.20970726], -likelihood = -297.10447
# Iteration=3, theta_new=[ 0.47051075 -0.47591302  0.21641528], -likelihood = -305.85517
# Iteration=4, theta_new=[ 0.48121369 -0.49478107  0.22390727], -likelihood = -318.04515
# Iteration=5, theta_new=[ 0.4920126  -0.51499299  0.23178759], -likelihood = -333.58215
# Iteration=6, theta_new=[ 0.50263605 -0.53460973  0.23968505], -likelihood = -350.60081
# Iteration=7, theta_new=[ 0.51247522 -0.55203218  0.24724318], -likelihood = -366.16506
# Iteration=8, theta_new=[ 0.52129932 -0.56651929  0.25428023], -likelihood = -378.23699
# Iteration=9, theta_new=[ 0.5290142  -0.57792443  0.26073842], -likelihood = -386.59939
# Iteration=10, theta_new=[ 0.5356446  -0.58668687  0.26660401], -likelihood = -391.99704
# Iteration=11, theta_new=[ 0.54127939 -0.5933164   0.27189225], -likelihood = -395.39936
# Iteration=12, theta_new=[ 0.54616454 -0.59826208  0.27671463], -likelihood = -397.54214
# Iteration=13, theta_new=[ 0.55030352 -0.60196429  0.28113445], -likelihood = -398.92575
# Iteration=14, theta_new=[ 0.55394322 -0.60469797  0.28516973], -likelihood = -399.84226
# Iteration=15, theta_new=[ 0.55709657 -0.60670695  0.28880683], -likelihood = -400.46973
# Iteration=16, theta_new=[ 0.55988359 -0.60820281  0.29220091], -likelihood = -400.90546
# Iteration=17, theta_new=[ 0.56229967 -0.60923657  0.29528017], -likelihood = -401.22347
# Iteration=18, theta_new=[ 0.56442678 -0.61005227  0.29814591], -likelihood = -401.45340
# Iteration=19, theta_new=[ 0.56638337 -0.61066716  0.30074817], -likelihood = -401.62442
# Iteration=20, theta_new=[ 0.56811615 -0.61108508  0.3031434 ], -likelihood = -401.74932
# 4-th start
# Iteration=1, theta_new=[-0.9071697  -1.86270376  2.67952725], -likelihood = -990.31563
# Iteration=2, theta_new=[-0.87772295 -1.80904457  2.67366253], -likelihood = -1055.67002
# Iteration=3, theta_new=[-0.85919567 -1.7587665   2.66900219], -likelihood = -1086.38514
# Iteration=4, theta_new=[-0.84714034 -1.70843872  2.6652553 ], -likelihood = -1103.23819
# Iteration=5, theta_new=[-0.83922975 -1.65067685  2.66216793], -likelihood = -1113.07812
# Iteration=6, theta_new=[-0.8343299  -1.57082412  2.65963447], -likelihood = -1118.70863
# Iteration=7, theta_new=[-0.83109003 -1.57075824  2.6574996 ], -likelihood = -1119.92876
# Iteration=8, theta_new=[-0.82788492 -1.57080494  2.65562572], -likelihood = -1120.07183
# Iteration=9, theta_new=[-0.82474293 -1.5708256   2.65397728], -likelihood = -1120.18249
# Iteration=10, theta_new=[-0.82165409 -1.57079784  2.65252822], -likelihood = -1120.26772
# Iteration=11, theta_new=[-0.81860254 -1.57076023  2.65126577], -likelihood = -1120.33286
# Iteration=12, theta_new=[-0.81558184 -1.57082736  2.65015318], -likelihood = -1120.38177
# Iteration=13, theta_new=[-0.8125812  -1.57076658  2.64918087], -likelihood = -1120.41837
# Iteration=14, theta_new=[-0.80959234 -1.57079185  2.64832237], -likelihood = -1120.44495
# Iteration=15, theta_new=[-0.80659899 -1.57077703  2.64758513], -likelihood = -1120.46386
# Iteration=16, theta_new=[-0.80363166 -1.5707609   2.64692796], -likelihood = -1120.47620
# Iteration=17, theta_new=[-0.80066722 -1.57072936  2.64634953], -likelihood = -1120.48400
# Iteration=18, theta_new=[-0.79764287 -1.57083287  2.64585769], -likelihood = -1120.48807
# Iteration=19, theta_new=[-0.79462164 -1.57076974  2.64542259], -likelihood = -1120.48886
# Iteration=20, theta_new=[-0.79161598 -1.57084407  2.64502169], -likelihood = -1120.48764
# 5-th start
# Iteration=1, theta_new=[-0.92947353  1.3869029  -2.66825433], -likelihood = -1070.51613
# Iteration=2, theta_new=[-0.93181413  1.37545711 -2.6575566 ], -likelihood = -1074.02640
# Iteration=3, theta_new=[-0.93543329  1.366351   -2.64738773], -likelihood = -1077.02183
# Iteration=4, theta_new=[-0.94004529  1.35873752 -2.63781143], -likelihood = -1079.55475
# Iteration=5, theta_new=[-0.94544668  1.3522801  -2.62898928], -likelihood = -1081.70035
# Iteration=6, theta_new=[-0.95141701  1.34663229 -2.6209463 ], -likelihood = -1083.48157
# Iteration=7, theta_new=[-0.95781702  1.34152562 -2.6136367 ], -likelihood = -1084.94684
# Iteration=8, theta_new=[-0.96427948  1.33693982 -2.60706786], -likelihood = -1086.14718
# Iteration=9, theta_new=[-0.97094401  1.33275467 -2.60119465], -likelihood = -1087.10979
# Iteration=10, theta_new=[-0.97759436  1.32892322 -2.59596557], -likelihood = -1087.87228
# Iteration=11, theta_new=[-0.98401385  1.32541365 -2.59136918], -likelihood = -1088.46521
# Iteration=12, theta_new=[-0.99030619  1.32220132 -2.58726188], -likelihood = -1088.91453
# Iteration=13, theta_new=[-0.99626335  1.31923258 -2.58363341], -likelihood = -1089.24835
# Iteration=14, theta_new=[-1.00201107  1.31649043 -2.58046001], -likelihood = -1089.48867
# Iteration=15, theta_new=[-1.00733364  1.31396087 -2.57769205], -likelihood = -1089.64928
# Iteration=16, theta_new=[-1.01235144  1.31160242 -2.57524425], -likelihood = -1089.75053
# Iteration=17, theta_new=[-1.01703268  1.30951267 -2.57306346], -likelihood = -1089.80522
# Iteration=18, theta_new=[-1.02138221  1.30754205 -2.57118268], -likelihood = -1089.81836
# Iteration=19, theta_new=[-1.02538789  1.30574154 -2.56956313], -likelihood = -1089.80521
# Iteration=20, theta_new=[-1.02911951  1.30410049 -2.56811641], -likelihood = -1089.77084
# 6-th start
# Iteration=1, theta_new=[-3.13298712 -0.5557353   2.02945029], -likelihood = -901.29820
# Iteration=2, theta_new=[-3.13766516 -0.55740595  1.98385448], -likelihood = -980.40824
# Iteration=3, theta_new=[-3.14179871 -0.55806791  1.94518406], -likelihood = -1031.29925
# Iteration=4, theta_new=[-3.14554667 -0.55835211  1.91274782], -likelihood = -1062.99412
# Iteration=5, theta_new=[-3.14895884 -0.55847049  1.88579066], -likelihood = -1082.25086
# Iteration=6, theta_new=[-3.15217433 -0.55864245  1.86366741], -likelihood = -1093.77469
# Iteration=7, theta_new=[-3.15520234 -0.55871878  1.84571044], -likelihood = -1100.58902
# Iteration=8, theta_new=[-3.15802555 -0.55886915  1.83127318], -likelihood = -1104.60173
# Iteration=9, theta_new=[-3.16076392 -0.5590309   1.81974073], -likelihood = -1106.96416
# Iteration=10, theta_new=[-3.16337378 -0.55915443  1.81071618], -likelihood = -1108.36978
# Iteration=11, theta_new=[-3.16582525 -0.55934242  1.80367704], -likelihood = -1109.20752
# Iteration=12, theta_new=[-3.16819325 -0.55947004  1.79822611], -likelihood = -1109.71815
# Iteration=13, theta_new=[-3.17046171 -0.55959381  1.79398546], -likelihood = -1110.04159
# Iteration=14, theta_new=[-3.17255658 -0.55966866  1.79072992], -likelihood = -1110.25599
# Iteration=15, theta_new=[-3.17459357 -0.5597537   1.7882892 ], -likelihood = -1110.40229
# Iteration=16, theta_new=[-3.17654518 -0.55981466  1.78643644], -likelihood = -1110.50896
# Iteration=17, theta_new=[-3.17833639 -0.5598565   1.78502276], -likelihood = -1110.59155
# Iteration=18, theta_new=[-3.18010819 -0.55990817  1.78392936], -likelihood = -1110.65647
# Iteration=19, theta_new=[-3.18177558 -0.55994972  1.78311914], -likelihood = -1110.71239
# Iteration=20, theta_new=[-3.18329123 -0.5599718   1.78246658], -likelihood = -1110.75972
# 7-th start
# Iteration=1, theta_new=[1.10998186 2.88961533 1.57076475], -likelihood = -1063.38817
# Iteration=2, theta_new=[1.0633461  2.88262826 1.57079589], -likelihood = -1080.78280
# Iteration=3, theta_new=[1.02986011 2.87482028 1.58022083], -likelihood = -1092.49910
# Iteration=4, theta_new=[1.00505107 2.86614972 1.60146094], -likelihood = -1100.59221
# Iteration=5, theta_new=[0.98589227 2.85651787 1.61849384], -likelihood = -1106.67607
# Iteration=6, theta_new=[0.97055207 2.84581135 1.63330623], -likelihood = -1111.87858
# Iteration=7, theta_new=[0.95787853 2.83396476 1.64627876], -likelihood = -1116.88902
# Iteration=8, theta_new=[0.94710032 2.82103013 1.65772301], -likelihood = -1122.13892
# Iteration=9, theta_new=[0.93756716 2.80717272 1.66800215], -likelihood = -1127.86337
# Iteration=10, theta_new=[0.9289881  2.79270842 1.67710917], -likelihood = -1134.12556
# Iteration=11, theta_new=[0.9209636  2.77804819 1.68523607], -likelihood = -1140.76407
# Iteration=12, theta_new=[0.91337817 2.76362377 1.69243063], -likelihood = -1147.48535
# Iteration=13, theta_new=[0.90622456 2.74989226 1.69872498], -likelihood = -1153.91459
# Iteration=14, theta_new=[0.89946478 2.73714797 1.7042771 ], -likelihood = -1159.69637
# Iteration=15, theta_new=[0.8932134  2.72559494 1.70907596], -likelihood = -1164.63678
# Iteration=16, theta_new=[0.88753688 2.71527074 1.7131832 ], -likelihood = -1168.66386
# Iteration=17, theta_new=[0.88255969 2.70617417 1.71660363], -likelihood = -1171.83895
# Iteration=18, theta_new=[0.87824161 2.69823419 1.71956871], -likelihood = -1174.26764
# Iteration=19, theta_new=[0.87465129 2.69135082 1.72208896], -likelihood = -1176.09025
# Iteration=20, theta_new=[0.87168118 2.68543063 1.72413114], -likelihood = -1177.43476
# 8-th start
# Iteration=1, theta_new=[-3.13074908 -2.46719667  0.33470577], -likelihood = -342.20508
# Iteration=2, theta_new=[-3.13065086 -2.48043332  0.34024044], -likelihood = -349.45652
# Iteration=3, theta_new=[-3.13012672 -2.49046784  0.34566576], -likelihood = -354.22021
# Iteration=4, theta_new=[-3.12931701 -2.49799751  0.35119111], -likelihood = -357.40215
# Iteration=5, theta_new=[-3.12811961 -2.50357943  0.35685763], -likelihood = -359.69241
# Iteration=6, theta_new=[-3.12658408 -2.50759977  0.36283882], -likelihood = -361.52853
# Iteration=7, theta_new=[-3.12479281 -2.51050098  0.36920793], -likelihood = -363.21431
# Iteration=8, theta_new=[-3.12264638 -2.51252712  0.37603933], -likelihood = -364.95300
# Iteration=9, theta_new=[-3.12030563 -2.5139094   0.38345689], -likelihood = -366.88652
# Iteration=10, theta_new=[-3.11772825 -2.51476842  0.39140504], -likelihood = -369.12868
# Iteration=11, theta_new=[-3.11498181 -2.51520883  0.40000042], -likelihood = -371.72560
# Iteration=12, theta_new=[-3.1122201  -2.51543188  0.40918643], -likelihood = -374.74430
# Iteration=13, theta_new=[-3.1095824  -2.51550705  0.41896884], -likelihood = -378.16472
# Iteration=14, theta_new=[-3.10725599 -2.51549901  0.42921561], -likelihood = -381.95519
# Iteration=15, theta_new=[-3.10533131 -2.51545967  0.43970828], -likelihood = -386.00195
# Iteration=16, theta_new=[-3.10381102 -2.51553151  0.45026666], -likelihood = -390.13941
# Iteration=17, theta_new=[-3.10280405 -2.51566884  0.4607005 ], -likelihood = -394.21374
# Iteration=18, theta_new=[-3.10226212 -2.51596307  0.47082135], -likelihood = -398.07331
# Iteration=19, theta_new=[-3.10213202 -2.51631919  0.48052723], -likelihood = -401.59866
# Iteration=20, theta_new=[-3.10231195 -2.51676511  0.48955559], -likelihood = -404.72466
# 9-th start
# Iteration=1, theta_new=[ 2.29575973 -1.9123262  -2.93797059], -likelihood = -902.76696
# Iteration=2, theta_new=[ 2.26098274 -1.85663721 -2.94458006], -likelihood = -999.78592
# Iteration=3, theta_new=[ 2.2336912  -1.80991421 -2.95056411], -likelihood = -1046.75340
# Iteration=4, theta_new=[ 2.21385076 -1.77029517 -2.95599515], -likelihood = -1067.80841
# Iteration=5, theta_new=[ 2.20030163 -1.73630484 -2.96089656], -likelihood = -1077.03983
# Iteration=6, theta_new=[ 2.19159012 -1.70660597 -2.96543345], -likelihood = -1081.05043
# Iteration=7, theta_new=[ 2.1863834  -1.68001083 -2.96956371], -likelihood = -1082.82258
# Iteration=8, theta_new=[ 2.18375924 -1.65526808 -2.97339481], -likelihood = -1083.65311
# Iteration=9, theta_new=[ 2.1828734  -1.63059709 -2.97693227], -likelihood = -1084.12682
# Iteration=10, theta_new=[ 2.1831901  -1.60064107 -2.98020408], -likelihood = -1084.47569
# Iteration=11, theta_new=[ 2.18451775 -1.57076007 -2.98328394], -likelihood = -1084.76579
# Iteration=12, theta_new=[ 2.18610514 -1.57082007 -2.98617239], -likelihood = -1085.07079
# Iteration=13, theta_new=[ 2.18751409 -1.57082348 -2.98887225], -likelihood = -1085.41554
# Iteration=14, theta_new=[ 2.18876956 -1.57082457 -2.99138681], -likelihood = -1085.71659
# Iteration=15, theta_new=[ 2.18988273 -1.57084736 -2.99374074], -likelihood = -1085.97949
# Iteration=16, theta_new=[ 2.19086067 -1.57082268 -2.99592225], -likelihood = -1086.20941
# Iteration=17, theta_new=[ 2.19175377 -1.57078513 -2.99796293], -likelihood = -1086.40867
# Iteration=18, theta_new=[ 2.192525   -1.57078344 -2.99987347], -likelihood = -1086.58528
# Iteration=19, theta_new=[ 2.19320655 -1.57076706 -3.00164671], -likelihood = -1086.73832
# Iteration=20, theta_new=[ 2.1938304  -1.57085834 -3.00330535], -likelihood = -1086.87166
# 10-th start
# Iteration=1, theta_new=[0.6864351  2.02159935 0.08375447], -likelihood = -893.43214
# Iteration=2, theta_new=[0.6850803  1.97721965 0.08111384], -likelihood = -961.40183
# Iteration=3, theta_new=[0.68299666 1.93876241 0.0790318 ], -likelihood = -1007.43534
# Iteration=4, theta_new=[0.6802855  1.90590131 0.07728104], -likelihood = -1037.50127
# Iteration=5, theta_new=[0.67718021 1.87830317 0.0756858 ], -likelihood = -1056.53126
# Iteration=6, theta_new=[0.67374735 1.85538448 0.07422457], -likelihood = -1068.27028
# Iteration=7, theta_new=[0.67002619 1.836592   0.07289829], -likelihood = -1075.43818
# Iteration=8, theta_new=[0.66604469 1.82146965 0.0716458 ], -likelihood = -1079.80843
# Iteration=9, theta_new=[0.66176789 1.80943016 0.07046135], -likelihood = -1082.49326
# Iteration=10, theta_new=[0.65716301 1.79996786 0.06932042], -likelihood = -1084.20541
# Iteration=11, theta_new=[0.652243   1.79255684 0.06823599], -likelihood = -1085.36922
# Iteration=12, theta_new=[0.64699017 1.78681951 0.06717307], -likelihood = -1086.23900
# Iteration=13, theta_new=[0.64143593 1.78233523 0.06611374], -likelihood = -1086.96201
# Iteration=14, theta_new=[0.63560536 1.77889656 0.06504197], -likelihood = -1087.62624
# Iteration=15, theta_new=[0.62950573 1.77620196 0.06394966], -likelihood = -1088.27770
# Iteration=16, theta_new=[0.62316888 1.77407856 0.06288717], -likelihood = -1088.94799
# Iteration=17, theta_new=[0.61667313 1.77235367 0.06177611], -likelihood = -1089.64948
# Iteration=18, theta_new=[0.60994008 1.77094724 0.06062208], -likelihood = -1090.38413
# Iteration=19, theta_new=[0.60318451 1.76982367 0.05948612], -likelihood = -1091.16255
# Iteration=20, theta_new=[0.596363   1.76888997 0.05829633], -likelihood = -1091.95821
# 11-th start
# Iteration=1, theta_new=[-0.05853584 -1.11487    -2.35349147], -likelihood = -818.45040
# Iteration=2, theta_new=[-0.0655607  -1.16090458 -2.3553872 ], -likelihood = -878.41068
# Iteration=3, theta_new=[-0.07155287 -1.2054338  -2.35788976], -likelihood = -926.25157
# Iteration=4, theta_new=[-0.07663288 -1.24859965 -2.36131181], -likelihood = -963.76533
# Iteration=5, theta_new=[-0.08086318 -1.29040204 -2.36545784], -likelihood = -992.47125
# Iteration=6, theta_new=[-0.08443819 -1.33090971 -2.37008441], -likelihood = -1013.79222
# Iteration=7, theta_new=[-0.08746071 -1.37044257 -2.37488526], -likelihood = -1029.14503
# Iteration=8, theta_new=[-0.09003418 -1.40957867 -2.37980763], -likelihood = -1039.89220
# Iteration=9, theta_new=[-0.09227371 -1.45002163 -2.38477409], -likelihood = -1047.19995
# Iteration=10, theta_new=[-0.09424844 -1.49660688 -2.38988764], -likelihood = -1052.08671
# Iteration=11, theta_new=[-0.09595185 -1.57081344 -2.39488575], -likelihood = -1055.24896
# Iteration=12, theta_new=[-0.09738785 -1.57077134 -2.39942904], -likelihood = -1056.19620
# Iteration=13, theta_new=[-0.09870278 -1.57077362 -2.40413869], -likelihood = -1056.27556
# Iteration=14, theta_new=[-0.09987633 -1.57077531 -2.40900152], -likelihood = -1056.37069
# Iteration=15, theta_new=[-0.10092466 -1.57075215 -2.41398725], -likelihood = -1056.48373
# Iteration=16, theta_new=[-0.10183259 -1.57078785 -2.41909132], -likelihood = -1056.61688
# Iteration=17, theta_new=[-0.10259562 -1.57092595 -2.42431937], -likelihood = -1056.77205
# Iteration=18, theta_new=[-0.10325005 -1.57077396 -2.42964369], -likelihood = -1056.95153
# Iteration=19, theta_new=[-0.1037784  -1.57082724 -2.43502619], -likelihood = -1057.15671
# Iteration=20, theta_new=[-0.10415349 -1.57076238 -2.4404678 ], -likelihood = -1057.38705
# 12-th start
# Iteration=1, theta_new=[-1.73508399  0.14675024 -0.54218249], -likelihood = -774.88005
# Iteration=2, theta_new=[-1.66281831  0.14742452 -0.5512528 ], -likelihood = -792.16151
# Iteration=3, theta_new=[-1.57083225  0.14775237 -0.55955253], -likelihood = -801.77179
# Iteration=4, theta_new=[-1.57078933  0.147971   -0.56716563], -likelihood = -804.51040
# Iteration=5, theta_new=[-1.57077216  0.1482711  -0.57390332], -likelihood = -804.99956
# Iteration=6, theta_new=[-1.57079987  0.14863131 -0.57978944], -likelihood = -805.31294
# Iteration=7, theta_new=[-1.57081241  0.14906453 -0.58491266], -likelihood = -805.49571
# Iteration=8, theta_new=[-1.57080843  0.1495409  -0.58931934], -likelihood = -805.58595
# Iteration=9, theta_new=[-1.57081131  0.15007729 -0.59312217], -likelihood = -805.61287
# Iteration=10, theta_new=[-1.57076945  0.15063533 -0.59637906], -likelihood = -805.59807
# Iteration=11, theta_new=[-1.57082675  0.15122839 -0.59917207], -likelihood = -805.55762
# Iteration=12, theta_new=[-1.57092894  0.15185578 -0.6015341 ], -likelihood = -805.50190
# Iteration=13, theta_new=[-1.57082278  0.15251851 -0.60356214], -likelihood = -805.43885
# Iteration=14, theta_new=[-1.57080329  0.15322414 -0.60528544], -likelihood = -805.37243
# Iteration=15, theta_new=[-1.57081075  0.15394743 -0.60674471], -likelihood = -805.30597
# Iteration=16, theta_new=[-1.57076593  0.15471097 -0.60796861], -likelihood = -805.24200
# Iteration=17, theta_new=[-1.57084093  0.15552956 -0.60901013], -likelihood = -805.18143
# Iteration=18, theta_new=[-1.5708133   0.15637384 -0.60988537], -likelihood = -805.12373
# Iteration=19, theta_new=[-1.57082651  0.15725429 -0.61060952], -likelihood = -805.07011
# Iteration=20, theta_new=[-1.57075402  0.15817361 -0.61121985], -likelihood = -805.02065
# 13-th start
# Iteration=1, theta_new=[1.20247036 1.81857466 1.5708179 ], -likelihood = -968.21233
# Iteration=2, theta_new=[1.11862651 1.84853577 1.57078121], -likelihood = -993.19067
# Iteration=3, theta_new=[1.05964457 1.87139599 1.57082289], -likelihood = -1014.05113
# Iteration=4, theta_new=[1.01643353 1.89096428 1.57077828], -likelihood = -1028.65799
# Iteration=5, theta_new=[0.98276839 1.90867271 1.57077537], -likelihood = -1038.93204
# Iteration=6, theta_new=[0.95494951 1.92497822 1.57078247], -likelihood = -1046.73308
# Iteration=7, theta_new=[0.93066894 1.94003723 1.57080731], -likelihood = -1053.14016
# Iteration=8, theta_new=[0.90848415 1.95396808 1.57083442], -likelihood = -1058.75874
# Iteration=9, theta_new=[0.88731457 1.96689811 1.57082585], -likelihood = -1063.95172
# Iteration=10, theta_new=[0.86651573 1.97893107 1.57081819], -likelihood = -1068.98810
# Iteration=11, theta_new=[0.84552954 1.99025477 1.57080572], -likelihood = -1074.06282
# Iteration=12, theta_new=[0.82404701 2.00103166 1.570817  ], -likelihood = -1079.37763
# Iteration=13, theta_new=[0.80187233 2.01139745 1.57079521], -likelihood = -1085.09901
# Iteration=14, theta_new=[0.77894964 2.02154705 1.57076463], -likelihood = -1091.36522
# Iteration=15, theta_new=[0.75544539 2.0315636  1.57079265], -likelihood = -1098.27165
# Iteration=16, theta_new=[0.73176869 2.04147173 1.5707675 ], -likelihood = -1105.78938
# Iteration=17, theta_new=[0.70833814 2.0512223  1.57078827], -likelihood = -1113.73439
# Iteration=18, theta_new=[0.68574766 2.0607591  1.57078397], -likelihood = -1121.82480
# Iteration=19, theta_new=[0.66443414 2.06999515 1.57082253], -likelihood = -1129.68737
# Iteration=20, theta_new=[0.64475722 2.07880428 1.57083809], -likelihood = -1137.00169
# 14-th start
# Iteration=1, theta_new=[ 0.9729374  -0.19508224  1.50833385], -likelihood = -1104.43092
# Iteration=2, theta_new=[ 0.95908386 -0.18966483  1.49521575], -likelihood = -1107.36821
# Iteration=3, theta_new=[ 0.94713319 -0.184592    1.48432599], -likelihood = -1109.73114
# Iteration=4, theta_new=[ 0.93668377 -0.17981668  1.47504564], -likelihood = -1111.65071
# Iteration=5, theta_new=[ 0.92744216 -0.17537407  1.46699959], -likelihood = -1113.23104
# Iteration=6, theta_new=[ 0.91925402 -0.17128565  1.46010444], -likelihood = -1114.53860
# Iteration=7, theta_new=[ 0.91189463 -0.16752008  1.45406604], -likelihood = -1115.61764
# Iteration=8, theta_new=[ 0.90535516 -0.16405151  1.44874436], -likelihood = -1116.51666
# Iteration=9, theta_new=[ 0.89944086 -0.16090785  1.44411547], -likelihood = -1117.26015
# Iteration=10, theta_new=[ 0.89408335 -0.15804822  1.44006317], -likelihood = -1117.87832
# Iteration=11, theta_new=[ 0.88928254 -0.1554074   1.43644226], -likelihood = -1118.39359
# Iteration=12, theta_new=[ 0.8848746  -0.15300031  1.43328467], -likelihood = -1118.82268
# Iteration=13, theta_new=[ 0.88089913 -0.1508192   1.43050691], -likelihood = -1119.18396
# Iteration=14, theta_new=[ 0.87728809 -0.14884457  1.42797525], -likelihood = -1119.48429
# Iteration=15, theta_new=[ 0.87401275 -0.14707778  1.42575392], -likelihood = -1119.73521
# Iteration=16, theta_new=[ 0.87103473 -0.14546772  1.42383   ], -likelihood = -1119.94421
# Iteration=17, theta_new=[ 0.86828235 -0.14397333  1.42206802], -likelihood = -1120.12015
# Iteration=18, theta_new=[ 0.86578575 -0.14261984  1.42051828], -likelihood = -1120.27081
# Iteration=19, theta_new=[ 0.86345904 -0.14142164  1.41914464], -likelihood = -1120.39739
# Iteration=20, theta_new=[ 0.86143276 -0.1403184   1.41790109], -likelihood = -1120.50513
# 15-th start
# Iteration=1, theta_new=[ 0.28621845 -2.01036872  2.59453869], -likelihood = -746.28054
# Iteration=2, theta_new=[ 0.28312728 -1.94186817  2.59746422], -likelihood = -876.41279
# Iteration=3, theta_new=[ 0.27876608 -1.87964065  2.60040287], -likelihood = -968.46133
# Iteration=4, theta_new=[ 0.2738947  -1.82225704  2.60304613], -likelihood = -1028.71715
# Iteration=5, theta_new=[ 0.26887336 -1.76815033  2.60543081], -likelihood = -1066.44052
# Iteration=6, theta_new=[ 0.26396999 -1.71454197  2.60764085], -likelihood = -1089.33305
# Iteration=7, theta_new=[ 0.25923102 -1.65395972  2.60971465], -likelihood = -1103.01182
# Iteration=8, theta_new=[ 0.25452811 -1.57078522  2.61173012], -likelihood = -1110.89770
# Iteration=9, theta_new=[ 0.24980335 -1.57085376  2.61368358], -likelihood = -1113.03976
# Iteration=10, theta_new=[ 0.2453261  -1.57082465  2.61559116], -likelihood = -1113.45766
# Iteration=11, theta_new=[ 0.24104405 -1.57074978  2.61742785], -likelihood = -1113.84531
# Iteration=12, theta_new=[ 0.23695164 -1.57074722  2.61919955], -likelihood = -1114.20551
# Iteration=13, theta_new=[ 0.23307838 -1.57081811  2.620888  ], -likelihood = -1114.53921
# Iteration=14, theta_new=[ 0.22944027 -1.57082272  2.62249576], -likelihood = -1114.84441
# Iteration=15, theta_new=[ 0.2259858  -1.57075168  2.62400878], -likelihood = -1115.12128
# Iteration=16, theta_new=[ 0.22271289 -1.57081827  2.62544317], -likelihood = -1115.37348
# Iteration=17, theta_new=[ 0.21956645 -1.57077073  2.62677989], -likelihood = -1115.60277
# Iteration=18, theta_new=[ 0.21665173 -1.57077193  2.62804538], -likelihood = -1115.81257
# Iteration=19, theta_new=[ 0.21390344 -1.57077445  2.62922817], -likelihood = -1115.99930
# Iteration=20, theta_new=[ 0.21131161 -1.5708278   2.63033834], -likelihood = -1116.16731
# 16-th start
# Iteration=1, theta_new=[ 1.89896491 -1.2610742   3.08213375], -likelihood = -982.34963
# Iteration=2, theta_new=[ 1.93418713 -1.29585042  3.08340362], -likelihood = -1007.09891
# Iteration=3, theta_new=[ 1.96393738 -1.32584715  3.08471522], -likelihood = -1024.28259
# Iteration=4, theta_new=[ 1.98955282 -1.35158171  3.08608983], -likelihood = -1036.33267
# Iteration=5, theta_new=[ 2.01180901 -1.373827    3.08750736], -likelihood = -1044.98768
# Iteration=6, theta_new=[ 2.03132366 -1.39315044  3.08901739], -likelihood = -1051.40487
# Iteration=7, theta_new=[ 2.04837431 -1.41015932  3.09055138], -likelihood = -1056.32410
# Iteration=8, theta_new=[ 2.06343213 -1.4252812   3.09213364], -likelihood = -1060.17369
# Iteration=9, theta_new=[ 2.07684217 -1.43882074  3.09374436], -likelihood = -1063.27405
# Iteration=10, theta_new=[ 2.088629   -1.45142745  3.09540501], -likelihood = -1065.82837
# Iteration=11, theta_new=[ 2.09914023 -1.46308566  3.0970657 ], -likelihood = -1067.93126
# Iteration=12, theta_new=[ 2.10846397 -1.47422219  3.09875801], -likelihood = -1069.70059
# Iteration=13, theta_new=[ 2.11683395 -1.48499903  3.10045047], -likelihood = -1071.19236
# Iteration=14, theta_new=[ 2.12435445 -1.49573095  3.10215096], -likelihood = -1072.47151
# Iteration=15, theta_new=[ 2.13113106 -1.50653409  3.10385443], -likelihood = -1073.57437
# Iteration=16, theta_new=[ 2.13722916 -1.51801425  3.10555803], -likelihood = -1074.53295
# Iteration=17, theta_new=[ 2.14276731 -1.61071958  3.1072772 ], -likelihood = -1075.36734
# Iteration=18, theta_new=[ 2.14779823 -1.54787842  3.10898443], -likelihood = -1076.10449
# Iteration=19, theta_new=[ 2.15248925 -1.5708301   3.1107036 ], -likelihood = -1076.75301
# Iteration=20, theta_new=[ 2.15676882 -1.57081223  3.11244909], -likelihood = -1077.35739
# 17-th start
# Iteration=1, theta_new=[ 2.92996582 -2.49583733 -3.02775854], -likelihood = -329.66087
# Iteration=2, theta_new=[ 2.9255527  -2.50147246 -3.03614532], -likelihood = -333.13249
# Iteration=3, theta_new=[ 2.92122177 -2.50587612 -3.04433281], -likelihood = -336.04694
# Iteration=4, theta_new=[ 2.91708589 -2.50935884 -3.0521313 ], -likelihood = -338.54562
# Iteration=5, theta_new=[ 2.9130552  -2.51209139 -3.05951179], -likelihood = -340.68387
# Iteration=6, theta_new=[ 2.90914183 -2.51436055 -3.06633904], -likelihood = -342.51792
# Iteration=7, theta_new=[ 2.90552562 -2.51617594 -3.07259647], -likelihood = -344.07751
# Iteration=8, theta_new=[ 2.90202842 -2.51770369 -3.07828433], -likelihood = -345.37689
# Iteration=9, theta_new=[ 2.89874174 -2.51896653 -3.08338036], -likelihood = -346.46357
# Iteration=10, theta_new=[ 2.89552586 -2.52001407 -3.0879468 ], -likelihood = -347.35567
# Iteration=11, theta_new=[ 2.89248024 -2.52087575 -3.09202005], -likelihood = -348.09308
# Iteration=12, theta_new=[ 2.88962091 -2.52165738 -3.09566379], -likelihood = -348.69692
# Iteration=13, theta_new=[ 2.88698124 -2.52230615 -3.09885487], -likelihood = -349.19546
# Iteration=14, theta_new=[ 2.88440435 -2.52281519 -3.10165653], -likelihood = -349.59727
# Iteration=15, theta_new=[ 2.88196105 -2.52328331 -3.10416777], -likelihood = -349.92543
# Iteration=16, theta_new=[ 2.87965349 -2.52369673 -3.10637155], -likelihood = -350.19915
# Iteration=17, theta_new=[ 2.87751668 -2.52396111 -3.10835371], -likelihood = -350.42396
# Iteration=18, theta_new=[ 2.87543163 -2.52418552 -3.11011075], -likelihood = -350.60742
# Iteration=19, theta_new=[ 2.87349091 -2.52435094 -3.11162935], -likelihood = -350.76092
# Iteration=20, theta_new=[ 2.87162236 -2.52456364 -3.11296376], -likelihood = -350.88523
# 18-th start
# Iteration=1, theta_new=[-1.44218998  2.40708041 -2.88971816], -likelihood = -792.09828
# Iteration=2, theta_new=[-1.53518682  2.40658268 -2.89430345], -likelihood = -803.68993
# Iteration=3, theta_new=[-1.5708217   2.40672024 -2.89892176], -likelihood = -809.15193
# Iteration=4, theta_new=[-1.57085517  2.40701596 -2.90351401], -likelihood = -809.95617
# Iteration=5, theta_new=[-1.57081977  2.40741726 -2.90808172], -likelihood = -810.56931
# Iteration=6, theta_new=[-1.57076386  2.40798239 -2.91261897], -likelihood = -811.17687
# Iteration=7, theta_new=[-1.57083042  2.40870412 -2.91709099], -likelihood = -811.77316
# Iteration=8, theta_new=[-1.57085107  2.40964322 -2.92151222], -likelihood = -812.35223
# Iteration=9, theta_new=[-1.57075054  2.41082221 -2.92587025], -likelihood = -812.91269
# Iteration=10, theta_new=[-1.57083661  2.41229103 -2.9301374 ], -likelihood = -813.45232
# Iteration=11, theta_new=[-1.57077071  2.41411401 -2.93432502], -likelihood = -813.96735
# Iteration=12, theta_new=[-1.57077052  2.41636058 -2.93842533], -likelihood = -814.46104
# Iteration=13, theta_new=[-1.57075491  2.41910616 -2.94243286], -likelihood = -814.93701
# Iteration=14, theta_new=[-1.57078375  2.42241974 -2.94634212], -likelihood = -815.40315
# Iteration=15, theta_new=[-1.57080952  2.42639139 -2.9501339 ], -likelihood = -815.87241
# Iteration=16, theta_new=[-1.57076576  2.43106981 -2.95381218], -likelihood = -816.36241
# Iteration=17, theta_new=[-1.57082864  2.43650829 -2.95737156], -likelihood = -816.89999
# Iteration=18, theta_new=[-1.57081312  2.44276914 -2.96078901], -likelihood = -817.51745
# Iteration=19, theta_new=[-1.57077328  2.44983173 -2.96405153], -likelihood = -818.25267
# Iteration=20, theta_new=[-1.57084811  2.45767625 -2.96717467], -likelihood = -819.14461
# 19-th start
# Iteration=1, theta_new=[-2.99845196 -2.80202331  1.45879524], -likelihood = -1070.83105
# Iteration=2, theta_new=[-3.00637635 -2.79323111  1.43466838], -likelihood = -1076.83713
# Iteration=3, theta_new=[-3.01142794 -2.784936    1.41912259], -likelihood = -1080.44632
# Iteration=4, theta_new=[-3.01438707 -2.77680763  1.4084556 ], -likelihood = -1082.88516
# Iteration=5, theta_new=[-3.01576252 -2.76869394  1.40087337], -likelihood = -1084.76509
# Iteration=6, theta_new=[-3.01589467 -2.76032638  1.3952228 ], -likelihood = -1086.40232
# Iteration=7, theta_new=[-3.01497882 -2.75162095  1.39100223], -likelihood = -1088.00017
# Iteration=8, theta_new=[-3.01333151 -2.74263448  1.38775359], -likelihood = -1089.65072
# Iteration=9, theta_new=[-3.01097892 -2.73335308  1.38509983], -likelihood = -1091.37628
# Iteration=10, theta_new=[-3.00822404 -2.7239011   1.38289665], -likelihood = -1093.19453
# Iteration=11, theta_new=[-3.00508213 -2.7143616   1.3808488 ], -likelihood = -1095.05997
# Iteration=12, theta_new=[-3.00170483 -2.70490624  1.3790823 ], -likelihood = -1096.94265
# Iteration=13, theta_new=[-2.99820239 -2.69557359  1.37739954], -likelihood = -1098.77615
# Iteration=14, theta_new=[-2.99462998 -2.68660617  1.37586145], -likelihood = -1100.52713
# Iteration=15, theta_new=[-2.99105371 -2.67802973  1.37435186], -likelihood = -1102.13416
# Iteration=16, theta_new=[-2.98757643 -2.66992742  1.3729625 ], -likelihood = -1103.58209
# Iteration=17, theta_new=[-2.98421727 -2.66242653  1.37161984], -likelihood = -1104.84977
# Iteration=18, theta_new=[-2.98099762 -2.65545006  1.37041468], -likelihood = -1105.92865
# Iteration=19, theta_new=[-2.97798627 -2.64908809  1.36931515], -likelihood = -1106.83788
# Iteration=20, theta_new=[-2.97510396 -2.64327965  1.3683457 ], -likelihood = -1107.58140
# 20-th start
# Iteration=1, theta_new=[-0.90775436  0.22445531  2.12614771], -likelihood = -603.19896
# Iteration=2, theta_new=[-0.97248744  0.23639376  2.0662723 ], -likelihood = -823.99645
# Iteration=3, theta_new=[-1.02473229  0.2478471   2.01827574], -likelihood = -971.08481
# Iteration=4, theta_new=[-1.06114603  0.25924391  1.98042297], -likelihood = -1037.17428
# Iteration=5, theta_new=[-1.08365391  0.27107019  1.95053416], -likelihood = -1065.90465
# Iteration=6, theta_new=[-1.0952729   0.28365615  1.92687699], -likelihood = -1080.39068
# Iteration=7, theta_new=[-1.0990417   0.29703323  1.90806069], -likelihood = -1089.61873
# Iteration=8, theta_new=[-1.0975944   0.3111079   1.89308524], -likelihood = -1097.01871
# Iteration=9, theta_new=[-1.09301104  0.32571059  1.88103193], -likelihood = -1103.86908
# Iteration=10, theta_new=[-1.0866776   0.34043012  1.87128764], -likelihood = -1110.58965
# Iteration=11, theta_new=[-1.07964684  0.35494675  1.86328336], -likelihood = -1117.14529
# Iteration=12, theta_new=[-1.07248067  0.36886749  1.85661248], -likelihood = -1123.38901
# Iteration=13, theta_new=[-1.06547641  0.38202068  1.850903  ], -likelihood = -1129.12418
# Iteration=14, theta_new=[-1.05871259  0.39422517  1.84601828], -likelihood = -1134.25796
# Iteration=15, theta_new=[-1.05248326  0.40538095  1.84173517], -likelihood = -1138.72979
# Iteration=16, theta_new=[-1.04676116  0.41550885  1.83793788], -likelihood = -1142.52281
# Iteration=17, theta_new=[-1.04146184  0.4246317   1.83450148], -likelihood = -1145.69694
# Iteration=18, theta_new=[-1.03660385  0.43279525  1.83144461], -likelihood = -1148.32210
# Iteration=19, theta_new=[-1.03211402  0.44006229  1.82868204], -likelihood = -1150.46968
# Iteration=20, theta_new=[-1.02805252  0.44653776  1.82610582], -likelihood = -1152.21583
# 21-th start
# Iteration=1, theta_new=[-2.94380944 -1.73561807  3.0171238 ], -likelihood = -1019.91165
# Iteration=2, theta_new=[-2.95159308 -1.67567598  3.01909135], -likelihood = -1039.11146
# Iteration=3, theta_new=[-2.95832557 -1.57081194  3.02131781], -likelihood = -1050.10429
# Iteration=4, theta_new=[-2.96430378 -1.57074713  3.02354331], -likelihood = -1054.12309
# Iteration=5, theta_new=[-2.96939076 -1.57084026  3.02553944], -likelihood = -1054.73487
# Iteration=6, theta_new=[-2.9736357  -1.57083926  3.02729399], -likelihood = -1055.18924
# Iteration=7, theta_new=[-2.97714605 -1.57082745  3.02884453], -likelihood = -1055.51786
# Iteration=8, theta_new=[-2.98001829 -1.57076928  3.03019773], -likelihood = -1055.75341
# Iteration=9, theta_new=[-2.98236448 -1.57085492  3.03137407], -likelihood = -1055.92020
# Iteration=10, theta_new=[-2.98424442 -1.57079979  3.03238763], -likelihood = -1056.03815
# Iteration=11, theta_new=[-2.9857138  -1.57079256  3.03326091], -likelihood = -1056.12051
# Iteration=12, theta_new=[-2.98689043 -1.57079898  3.03403122], -likelihood = -1056.17758
# Iteration=13, theta_new=[-2.98780436 -1.57083199  3.03469344], -likelihood = -1056.21846
# Iteration=14, theta_new=[-2.9885173  -1.57081168  3.03528629], -likelihood = -1056.24723
# Iteration=15, theta_new=[-2.98904962 -1.57081725  3.03578819], -likelihood = -1056.26817
# Iteration=16, theta_new=[-2.98944076 -1.57082139  3.03623337], -likelihood = -1056.28292
# Iteration=17, theta_new=[-2.98972544 -1.57082191  3.03664771], -likelihood = -1056.29369
# Iteration=18, theta_new=[-2.98990839 -1.57071468  3.03702753], -likelihood = -1056.30192
# Iteration=19, theta_new=[-2.99005567 -1.57079428  3.03736511], -likelihood = -1056.30807
# Iteration=20, theta_new=[-2.99012689 -1.57076792  3.0376741 ], -likelihood = -1056.31296
# 22-th start
# Iteration=1, theta_new=[ 1.95185591 -1.92497532  2.35817898], -likelihood = -1011.52139
# Iteration=2, theta_new=[ 1.94100285 -1.88145335  2.35192727], -likelihood = -1030.64333
# Iteration=3, theta_new=[ 1.93543203 -1.8443931   2.34426699], -likelihood = -1042.37525
# Iteration=4, theta_new=[ 1.93235102 -1.81279196  2.33593541], -likelihood = -1049.56927
# Iteration=5, theta_new=[ 1.92999253 -1.78567696  2.32735976], -likelihood = -1053.82977
# Iteration=6, theta_new=[ 1.92719548 -1.76244903  2.31874141], -likelihood = -1056.25818
# Iteration=7, theta_new=[ 1.92338253 -1.74263275  2.3101469 ], -likelihood = -1057.55684
# Iteration=8, theta_new=[ 1.91833577 -1.72582146  2.30158374], -likelihood = -1058.18975
# Iteration=9, theta_new=[ 1.91181694 -1.71177984  2.29299483], -likelihood = -1058.45177
# Iteration=10, theta_new=[ 1.9038488  -1.7004235   2.28436045], -likelihood = -1058.51531
# Iteration=11, theta_new=[ 1.89452961 -1.69152487  2.27561195], -likelihood = -1058.49202
# Iteration=12, theta_new=[ 1.88386548 -1.6851318   2.26673019], -likelihood = -1058.45141
# Iteration=13, theta_new=[ 1.87180761 -1.68114589  2.25771521], -likelihood = -1058.43028
# Iteration=14, theta_new=[ 1.85852868 -1.67944796  2.24855758], -likelihood = -1058.44750
# Iteration=15, theta_new=[ 1.84392631 -1.67978595  2.23921042], -likelihood = -1058.51620
# Iteration=16, theta_new=[ 1.82805267 -1.68192078  2.22972749], -likelihood = -1058.63787
# Iteration=17, theta_new=[ 1.8109506  -1.68569077  2.22012779], -likelihood = -1058.80971
# Iteration=18, theta_new=[ 1.79246231 -1.69069297  2.21040985], -likelihood = -1059.02803
# Iteration=19, theta_new=[ 1.7724999  -1.69675451  2.20063964], -likelihood = -1059.28433
# Iteration=20, theta_new=[ 1.75083615 -1.70366805  2.19082068], -likelihood = -1059.57096
# 23-th start
# Iteration=1, theta_new=[-2.30334952  0.23550035  1.44882887], -likelihood = -1082.81718
# Iteration=2, theta_new=[-2.3018204   0.23961694  1.431434  ], -likelihood = -1084.37048
# Iteration=3, theta_new=[-2.29935983  0.24450462  1.41921785], -likelihood = -1085.61686
# Iteration=4, theta_new=[-2.29597698  0.25030869  1.41015476], -likelihood = -1086.80980
# Iteration=5, theta_new=[-2.29185292  0.25721761  1.40318291], -likelihood = -1088.15372
# Iteration=6, theta_new=[-2.28698381  0.26539186  1.3975823 ], -likelihood = -1089.82785
# Iteration=7, theta_new=[-2.28146078  0.27499599  1.39286492], -likelihood = -1092.01734
# Iteration=8, theta_new=[-2.27534225  0.28613181  1.38868493], -likelihood = -1094.91081
# Iteration=9, theta_new=[-2.26880098  0.29879131  1.38482901], -likelihood = -1098.67580
# Iteration=10, theta_new=[-2.26198898  0.31276009  1.38121232], -likelihood = -1103.39539
# Iteration=11, theta_new=[-2.2550633   0.3276434   1.37764858], -likelihood = -1108.98733
# Iteration=12, theta_new=[-2.2482596   0.34293095  1.37430024], -likelihood = -1115.18548
# Iteration=13, theta_new=[-2.2418237   0.35806065  1.37115759], -likelihood = -1121.58499
# Iteration=14, theta_new=[-2.23586708  0.37256835  1.36825598], -likelihood = -1127.76087
# Iteration=15, theta_new=[-2.23035327  0.38610937  1.36566092], -likelihood = -1133.39670
# Iteration=16, theta_new=[-2.22544396  0.39850316  1.36334445], -likelihood = -1138.31406
# Iteration=17, theta_new=[-2.22093342  0.40975155  1.36134693], -likelihood = -1142.46499
# Iteration=18, theta_new=[-2.21688366  0.41980006  1.35966642], -likelihood = -1145.91006
# Iteration=19, theta_new=[-2.21323609  0.42874906  1.3582243 ], -likelihood = -1148.70592
# Iteration=20, theta_new=[-2.20977392  0.43668738  1.35698176], -likelihood = -1150.95993
# 24-th start
# Iteration=1, theta_new=[-1.44259316 -2.96721746  2.72078945], -likelihood = -823.87663
# Iteration=2, theta_new=[-1.52648873 -2.97225337  2.71283762], -likelihood = -837.48367
# Iteration=3, theta_new=[-1.57076831 -2.97701733  2.70570846], -likelihood = -844.68232
# Iteration=4, theta_new=[-1.57078642 -2.98157308  2.69909266], -likelihood = -847.05964
# Iteration=5, theta_new=[-1.57084787 -2.98594101  2.69294874], -likelihood = -848.81879
# Iteration=6, theta_new=[-1.57083516 -2.99012058  2.68725694], -likelihood = -850.30124
# Iteration=7, theta_new=[-1.57080253 -2.99410297  2.68200546], -likelihood = -851.53931
# Iteration=8, theta_new=[-1.57078943 -2.99792126  2.67717923], -likelihood = -852.56220
# Iteration=9, theta_new=[-1.57082462 -3.00156549  2.67274231], -likelihood = -853.40107
# Iteration=10, theta_new=[-1.57079237 -3.00503304  2.66867379], -likelihood = -854.08323
# Iteration=11, theta_new=[-1.57079892 -3.00836105  2.66495474], -likelihood = -854.63197
# Iteration=12, theta_new=[-1.57080728 -3.01153742  2.66155991], -likelihood = -855.06999
# Iteration=13, theta_new=[-1.57085196 -3.01455994  2.65847088], -likelihood = -855.41484
# Iteration=14, theta_new=[-1.57082405 -3.01743845  2.65566005], -likelihood = -855.68197
# Iteration=15, theta_new=[-1.57073693 -3.02018771  2.65310498], -likelihood = -855.88556
# Iteration=16, theta_new=[-1.57077559 -3.02282934  2.65078882], -likelihood = -856.03744
# Iteration=17, theta_new=[-1.57081587 -3.02532986  2.64866932], -likelihood = -856.14754
# Iteration=18, theta_new=[-1.57084753 -3.02773081  2.64675852], -likelihood = -856.22298
# Iteration=19, theta_new=[-1.57071512 -3.03000601  2.6450265 ], -likelihood = -856.27098
# Iteration=20, theta_new=[-1.57079672 -3.03217409  2.64346853], -likelihood = -856.29657

# %%
EM_theta3_rad
# Out:
# array([0.87168118, 0.45616202, 1.41746151])

# %% [markdown]
# # Case 4

# %% [markdown]
# Имеется 7 датчиков, 3 источника (дисперсии сигналов - 0.5, 0.5 и 0.5), и шум на каждом датчике имеет дисперсию 1.1.

# %%
Num_sensors4 = 7
Num_emitters4 = 3
sample_size4 = 100
theta4_rad = [0.5, 1.1, -0.3] # Направление прибытия (DOA) в радианах
theta4_deg = np.rad2deg(theta4_rad[0]) # Направление прибытия (DOA) в градусах
GS_4 = np.diag([0.5, 0.5, 0.5]) # Ковариация сигнала
GN_4 = 1.1*np.eye(7, dtype=np.float64) # Ковариация шума
A4 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors4).reshape(-1,1) * np.sin(theta4_rad).reshape(1,-1)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
s4 = CN(Num_emitters4, sample_size4, GS_4)
n4 = CN(Num_sensors4, sample_size4, GN_4)
X4 = (A4 @ s4.T + n4.T).T

# %%
EM_theta4_rad, neglhd_4, K4, mu4 = multi_start_EM(X4, GS_4, GN_4, 30, max_iter=20, eps=1e-6)
# Out:
# 0-th start
# Iteration=1, theta_new=[ 1.81971286  2.65482905 -2.91124449], -likelihood = -1178.50608
# Iteration=2, theta_new=[ 1.87613616  2.65067115 -2.8983055 ], -likelihood = -1223.88950
# Iteration=3, theta_new=[ 1.91462335  2.64712572 -2.88796205], -likelihood = -1254.66402
# Iteration=4, theta_new=[ 1.94238673  2.64416489 -2.87973686], -likelihood = -1274.89414
# Iteration=5, theta_new=[ 1.96300704  2.64164067 -2.87317305], -likelihood = -1287.94281
# Iteration=6, theta_new=[ 1.97853335  2.6395492  -2.86798532], -likelihood = -1296.29217
# Iteration=7, theta_new=[ 1.99040569  2.63782537 -2.86386838], -likelihood = -1301.56385
# Iteration=8, theta_new=[ 1.99954512  2.63638859 -2.86058145], -likelihood = -1304.89333
# Iteration=9, theta_new=[ 2.0065931   2.63517326 -2.85795802], -likelihood = -1306.99634
# Iteration=10, theta_new=[ 2.01202669  2.63420454 -2.85590229], -likelihood = -1308.32154
# Iteration=11, theta_new=[ 2.01632067  2.63342925 -2.85430771], -likelihood = -1309.14594
# Iteration=12, theta_new=[ 2.01969765  2.63278767 -2.85301797], -likelihood = -1309.66418
# Iteration=13, theta_new=[ 2.02237192  2.63226354 -2.85196713], -likelihood = -1309.99482
# Iteration=14, theta_new=[ 2.02443464  2.63183579 -2.85119166], -likelihood = -1310.20654
# Iteration=15, theta_new=[ 2.02603543  2.63146635 -2.85057754], -likelihood = -1310.33533
# Iteration=16, theta_new=[ 2.02731271  2.63117888 -2.85005652], -likelihood = -1310.41716
# Iteration=17, theta_new=[ 2.02829503  2.63094749 -2.84964718], -likelihood = -1310.47080
# Iteration=18, theta_new=[ 2.0290311   2.63078885 -2.84934647], -likelihood = -1310.50441
# Iteration=19, theta_new=[ 2.02961692  2.63062195 -2.84910357], -likelihood = -1310.52458
# Iteration=20, theta_new=[ 2.03013598  2.63052996 -2.84892402], -likelihood = -1310.53828
# 1-th start
# Iteration=1, theta_new=[-1.98316859  2.354135   -1.57076193], -likelihood = -527.51447
# Iteration=2, theta_new=[-2.04388358  2.358469   -1.57085573], -likelihood = -601.14027
# Iteration=3, theta_new=[-2.08850692  2.36724285 -1.57082959], -likelihood = -633.87183
# Iteration=4, theta_new=[-2.12073687  2.37999127 -1.57078109], -likelihood = -653.60235
# Iteration=5, theta_new=[-2.14436265  2.39701995 -1.5707816 ], -likelihood = -667.17153
# Iteration=6, theta_new=[-2.16181042  2.41915937 -1.57075452], -likelihood = -680.57438
# Iteration=7, theta_new=[-2.17478677  2.44673471 -1.57078559], -likelihood = -699.03159
# Iteration=8, theta_new=[-2.18495526  2.4783032  -1.57078467], -likelihood = -727.30229
# Iteration=9, theta_new=[-2.19406462  2.51041155 -1.57083697], -likelihood = -766.70827
# Iteration=10, theta_new=[-2.20327461  2.53953666 -1.57081926], -likelihood = -811.48550
# Iteration=11, theta_new=[-2.2127505   2.56386025 -1.57081363], -likelihood = -852.12726
# Iteration=12, theta_new=[-2.22205149  2.58322141 -1.57077339], -likelihood = -882.80206
# Iteration=13, theta_new=[-2.23074026  2.59822346 -1.57076151], -likelihood = -903.22625
# Iteration=14, theta_new=[-2.23857362  2.60970698 -1.57080089], -likelihood = -915.78157
# Iteration=15, theta_new=[-2.24545638  2.61845272 -1.57080181], -likelihood = -923.12932
# Iteration=16, theta_new=[-2.25138652  2.62507657 -1.57081552], -likelihood = -927.27698
# Iteration=17, theta_new=[-2.25649095  2.63011469 -1.57083278], -likelihood = -929.52695
# Iteration=18, theta_new=[-2.26084549  2.63392142 -1.57076587], -likelihood = -930.69152
# Iteration=19, theta_new=[-2.26454558  2.63680643 -1.57079712], -likelihood = -931.23621
# Iteration=20, theta_new=[-2.26765401  2.63898781 -1.57078299], -likelihood = -931.44161
# 2-th start
# Iteration=1, theta_new=[-1.57082466  1.11449134 -1.85196116], -likelihood = -545.42124
# Iteration=2, theta_new=[-1.57081335  1.0947912  -1.90991464], -likelihood = -560.74683
# Iteration=3, theta_new=[-1.57075482  1.08082823 -1.9612943 ], -likelihood = -571.69483
# Iteration=4, theta_new=[-1.57081194  1.06994285 -2.00849008], -likelihood = -582.09530
# Iteration=5, theta_new=[-1.57079472  1.06038605 -2.05172726], -likelihood = -593.07553
# Iteration=6, theta_new=[-1.57076711  1.0512195  -2.09083881], -likelihood = -604.48847
# Iteration=7, theta_new=[-1.57077835  1.04216601 -2.12562966], -likelihood = -615.70415
# Iteration=8, theta_new=[-1.57071059  1.03342063 -2.15614186], -likelihood = -625.97885
# Iteration=9, theta_new=[-1.57086046  1.02530666 -2.18254057], -likelihood = -634.73690
# Iteration=10, theta_new=[-1.57079614  1.01809326 -2.20517751], -likelihood = -641.71236
# Iteration=11, theta_new=[-1.57081795  1.01189768 -2.22448722], -likelihood = -646.97022
# Iteration=12, theta_new=[-1.57075354  1.00673365 -2.2409085 ], -likelihood = -650.77629
# Iteration=13, theta_new=[-1.57076006  1.0025197  -2.25489564], -likelihood = -653.45222
# Iteration=14, theta_new=[-1.57083469  0.99915727 -2.26683005], -likelihood = -655.30115
# Iteration=15, theta_new=[-1.57076993  0.99652314 -2.27703695], -likelihood = -656.56114
# Iteration=16, theta_new=[-1.57078403  0.99449594 -2.28580879], -likelihood = -657.41092
# Iteration=17, theta_new=[-1.57072471  0.99296958 -2.29335426], -likelihood = -657.97937
# Iteration=18, theta_new=[-1.57077013  0.99185473 -2.29990921], -likelihood = -658.35450
# Iteration=19, theta_new=[-1.57084958  0.9910732  -2.30561101], -likelihood = -658.59919
# Iteration=20, theta_new=[-1.57081261  0.99054719 -2.3105872 ], -likelihood = -658.75446
# 3-th start
# Iteration=1, theta_new=[ 1.24343376 -0.30046083  0.04360358], -likelihood = -933.68211
# Iteration=2, theta_new=[ 1.20771449 -0.29676045  0.04460247], -likelihood = -955.90930
# Iteration=3, theta_new=[ 1.18306257 -0.29384726  0.04506345], -likelihood = -968.49396
# Iteration=4, theta_new=[ 1.16574965 -0.29163724  0.04515145], -likelihood = -975.48406
# Iteration=5, theta_new=[ 1.15342335 -0.28993748  0.04503081], -likelihood = -979.28653
# Iteration=6, theta_new=[ 1.14447762 -0.28858504  0.04474645], -likelihood = -981.34353
# Iteration=7, theta_new=[ 1.13794322 -0.28755488  0.04435134], -likelihood = -982.46548
# Iteration=8, theta_new=[ 1.13325293 -0.28677678  0.04397969], -likelihood = -983.07335
# Iteration=9, theta_new=[ 1.12979103 -0.28615321  0.04351466], -likelihood = -983.39373
# Iteration=10, theta_new=[ 1.12718447 -0.28566777  0.04309865], -likelihood = -983.57108
# Iteration=11, theta_new=[ 1.12532725 -0.28530404  0.04270189], -likelihood = -983.66809
# Iteration=12, theta_new=[ 1.12393119 -0.284984    0.04225285], -likelihood = -983.71991
# Iteration=13, theta_new=[ 1.12292031 -0.28477165  0.04191491], -likelihood = -983.75211
# Iteration=14, theta_new=[ 1.122175   -0.28457554  0.04160848], -likelihood = -983.76929
# Iteration=15, theta_new=[ 1.1215984  -0.2844192   0.04123223], -likelihood = -983.77987
# Iteration=16, theta_new=[ 1.12114353 -0.28428035  0.0409415 ], -likelihood = -983.79026
# Iteration=17, theta_new=[ 1.12082268 -0.28418713  0.04066654], -likelihood = -983.79649
# Iteration=18, theta_new=[ 1.12064328 -0.28411746  0.04043196], -likelihood = -983.80228
# Iteration=19, theta_new=[ 1.12047145 -0.28404736  0.04018504], -likelihood = -983.80739
# Iteration=20, theta_new=[ 1.12035015 -0.28397107  0.0399569 ], -likelihood = -983.81253
# 4-th start
# Iteration=1, theta_new=[ 0.26285205 -2.20348085  1.3015583 ], -likelihood = -629.70062
# Iteration=2, theta_new=[ 0.29422556 -2.20934394  1.26759495], -likelihood = -663.62886
# Iteration=3, theta_new=[ 0.33095284 -2.21479404  1.24379821], -likelihood = -717.45191
# Iteration=4, theta_new=[ 0.36589916 -2.22065322  1.22609329], -likelihood = -784.89239
# Iteration=5, theta_new=[ 0.39571056 -2.22727632  1.21193611], -likelihood = -848.01748
# Iteration=6, theta_new=[ 0.4199677  -2.23456949  1.20009974], -likelihood = -897.44097
# Iteration=7, theta_new=[ 0.43918507 -2.24205033  1.18993667], -likelihood = -932.55297
# Iteration=8, theta_new=[ 0.45420641 -2.24946847  1.18121823], -likelihood = -955.98968
# Iteration=9, theta_new=[ 0.46582084 -2.25674463  1.17370025], -likelihood = -971.07299
# Iteration=10, theta_new=[ 0.47479855 -2.26377779  1.16719374], -likelihood = -980.58176
# Iteration=11, theta_new=[ 0.48167717 -2.27066429  1.16162027], -likelihood = -986.57963
# Iteration=12, theta_new=[ 0.48693817 -2.27740575  1.1567791 ], -likelihood = -990.38100
# Iteration=13, theta_new=[ 0.490969   -2.28402025  1.15265493], -likelihood = -992.85326
# Iteration=14, theta_new=[ 0.49402847 -2.29039517  1.14903477], -likelihood = -994.52139
# Iteration=15, theta_new=[ 0.49641047 -2.29664475  1.14585988], -likelihood = -995.69488
# Iteration=16, theta_new=[ 0.49823546 -2.30277734  1.14305433], -likelihood = -996.57963
# Iteration=17, theta_new=[ 0.49966747 -2.30876197  1.14067538], -likelihood = -997.27697
# Iteration=18, theta_new=[ 0.50079269 -2.31448138  1.13847328], -likelihood = -997.85094
# Iteration=19, theta_new=[ 0.50167671 -2.32009777  1.13651716], -likelihood = -998.34009
# Iteration=20, theta_new=[ 0.50238352 -2.32549704  1.13478056], -likelihood = -998.77119
# 5-th start
# Iteration=1, theta_new=[-2.16969628 -1.25368656 -0.31923219], -likelihood = -659.38526
# Iteration=2, theta_new=[-2.18520997 -1.352335   -0.31274528], -likelihood = -818.43102
# Iteration=3, theta_new=[-2.19284864 -1.50445298 -0.30727214], -likelihood = -871.82659
# Iteration=4, theta_new=[-2.19873308 -1.57074231 -0.30262714], -likelihood = -895.49796
# Iteration=5, theta_new=[-2.20354072 -1.57081305 -0.29891598], -likelihood = -896.84011
# Iteration=6, theta_new=[-2.2074123  -1.57077793 -0.29596454], -likelihood = -897.33220
# Iteration=7, theta_new=[-2.21053929 -1.57081472 -0.29361522], -likelihood = -897.49941
# Iteration=8, theta_new=[-2.21307523 -1.57074129 -0.29174932], -likelihood = -897.48768
# Iteration=9, theta_new=[-2.21513569 -1.57076271 -0.2902813 ], -likelihood = -897.38319
# Iteration=10, theta_new=[-2.21680724 -1.57077969 -0.28911315], -likelihood = -897.23685
# Iteration=11, theta_new=[-2.21815821 -1.57079525 -0.28819606], -likelihood = -897.08071
# Iteration=12, theta_new=[-2.21925438 -1.57084489 -0.28746347], -likelihood = -896.93065
# Iteration=13, theta_new=[-2.22016956 -1.57075813 -0.2868882 ], -likelihood = -896.79426
# Iteration=14, theta_new=[-2.22088669 -1.57076842 -0.28642718], -likelihood = -896.67049
# Iteration=15, theta_new=[-2.22147597 -1.57074869 -0.28607355], -likelihood = -896.56790
# Iteration=16, theta_new=[-2.22195237 -1.57076052 -0.28578981], -likelihood = -896.48002
# Iteration=17, theta_new=[-2.22233456 -1.5708816  -0.28556237], -likelihood = -896.40675
# Iteration=18, theta_new=[-2.22265174 -1.57078379 -0.28537477], -likelihood = -896.34653
# Iteration=19, theta_new=[-2.22289593 -1.57081202 -0.28522474], -likelihood = -896.29560
# Iteration=20, theta_new=[-2.22313285 -1.57079121 -0.2851133 ], -likelihood = -896.25566
# 6-th start
# Iteration=1, theta_new=[ 2.16912533  1.87485014 -2.42130027], -likelihood = -652.41234
# Iteration=2, theta_new=[ 2.17443754  1.86546422 -2.41978246], -likelihood = -654.19174
# Iteration=3, theta_new=[ 2.17807646  1.85899094 -2.41808189], -likelihood = -655.12545
# Iteration=4, theta_new=[ 2.18075858  1.85443175 -2.41625058], -likelihood = -655.65169
# Iteration=5, theta_new=[ 2.18263761  1.85130579 -2.4143451 ], -likelihood = -655.98988
# Iteration=6, theta_new=[ 2.18401641  1.84908975 -2.41234211], -likelihood = -656.21602
# Iteration=7, theta_new=[ 2.18501304  1.84758051 -2.41028894], -likelihood = -656.38658
# Iteration=8, theta_new=[ 2.18585298  1.84634874 -2.40821935], -likelihood = -656.52244
# Iteration=9, theta_new=[ 2.18649413  1.84551909 -2.40617777], -likelihood = -656.64541
# Iteration=10, theta_new=[ 2.18703324  1.84484587 -2.40409721], -likelihood = -656.75293
# Iteration=11, theta_new=[ 2.18742748  1.84437903 -2.40199431], -likelihood = -656.85551
# Iteration=12, theta_new=[ 2.18784481  1.84385482 -2.39992472], -likelihood = -656.95049
# Iteration=13, theta_new=[ 2.18814818  1.84345989 -2.39783693], -likelihood = -657.04697
# Iteration=14, theta_new=[ 2.18842308  1.84300139 -2.39580197], -likelihood = -657.13806
# Iteration=15, theta_new=[ 2.18872297  1.84263355 -2.39376756], -likelihood = -657.22689
# Iteration=16, theta_new=[ 2.18896903  1.84217396 -2.39178518], -likelihood = -657.31750
# Iteration=17, theta_new=[ 2.18920267  1.84180783 -2.38983381], -likelihood = -657.40431
# Iteration=18, theta_new=[ 2.18940655  1.84142653 -2.3878682 ], -likelihood = -657.48946
# Iteration=19, theta_new=[ 2.18956805  1.84111606 -2.38600018], -likelihood = -657.57403
# Iteration=20, theta_new=[ 2.1897694   1.84068935 -2.38412879], -likelihood = -657.65277
# 7-th start
# Iteration=1, theta_new=[-0.08253261  0.04101016 -0.49002145], -likelihood = -423.26632
# Iteration=2, theta_new=[-0.10668067  0.0466586  -0.46615691], -likelihood = -542.39314
# Iteration=3, theta_new=[-0.12577631  0.04974448 -0.4463656 ], -likelihood = -594.13415
# Iteration=4, theta_new=[-0.14125339  0.05240543 -0.43061246], -likelihood = -621.62311
# Iteration=5, theta_new=[-0.15374106  0.05513097 -0.41841721], -likelihood = -636.39977
# Iteration=6, theta_new=[-0.16371046  0.05786896 -0.40918477], -likelihood = -644.31131
# Iteration=7, theta_new=[-0.17164334  0.06045739 -0.40226354], -likelihood = -648.49174
# Iteration=8, theta_new=[-0.17792208  0.06283624 -0.3971602 ], -likelihood = -650.65334
# Iteration=9, theta_new=[-0.1828348   0.0649679  -0.39344757], -likelihood = -651.70812
# Iteration=10, theta_new=[-0.18668244  0.06681158 -0.39074753], -likelihood = -652.16322
# Iteration=11, theta_new=[-0.18970891  0.06842249 -0.38887185], -likelihood = -652.30875
# Iteration=12, theta_new=[-0.19209868  0.06974041 -0.38762236], -likelihood = -652.29977
# Iteration=13, theta_new=[-0.19405985  0.07086471 -0.38679416], -likelihood = -652.22733
# Iteration=14, theta_new=[-0.19564396  0.07183642 -0.38631651], -likelihood = -652.13100
# Iteration=15, theta_new=[-0.19691542  0.07258596 -0.3860343 ], -likelihood = -652.03265
# Iteration=16, theta_new=[-0.19797474  0.07328468 -0.38593618], -likelihood = -651.94581
# Iteration=17, theta_new=[-0.19883981  0.07380496 -0.38600014], -likelihood = -651.86657
# Iteration=18, theta_new=[-0.19960801  0.07425355 -0.3860856 ], -likelihood = -651.80676
# Iteration=19, theta_new=[-0.20020993  0.07460601 -0.38624947], -likelihood = -651.75263
# Iteration=20, theta_new=[-0.20076038  0.0749305  -0.3864395 ], -likelihood = -651.71294
# 8-th start
# Iteration=1, theta_new=[ 0.72759734 -2.48653526 -2.80081857], -likelihood = -711.70663
# Iteration=2, theta_new=[ 0.69694718 -2.48434482 -2.8088547 ], -likelihood = -734.95949
# Iteration=3, theta_new=[ 0.65869345 -2.48205223 -2.81555743], -likelihood = -781.14621
# Iteration=4, theta_new=[ 0.62245401 -2.48024638 -2.82114932], -likelihood = -846.51546
# Iteration=5, theta_new=[ 0.59308436 -2.47862259 -2.8256967 ], -likelihood = -907.54672
# Iteration=6, theta_new=[ 0.57074645 -2.47688364 -2.82933127], -likelihood = -951.28160
# Iteration=7, theta_new=[ 0.55415289 -2.47520033 -2.83217592], -likelihood = -978.77846
# Iteration=8, theta_new=[ 0.54189058 -2.4735071  -2.83437169], -likelihood = -994.99730
# Iteration=9, theta_new=[ 0.53291464 -2.47183985 -2.83612111], -likelihood = -1004.29522
# Iteration=10, theta_new=[ 0.5263156  -2.47021961 -2.83745658], -likelihood = -1009.52126
# Iteration=11, theta_new=[ 0.52144756 -2.46865953 -2.83849203], -likelihood = -1012.45425
# Iteration=12, theta_new=[ 0.51790962 -2.4671831  -2.83931297], -likelihood = -1014.10797
# Iteration=13, theta_new=[ 0.51531671 -2.46571154 -2.83998075], -likelihood = -1015.03511
# Iteration=14, theta_new=[ 0.51343456 -2.46437176 -2.8404808 ], -likelihood = -1015.56859
# Iteration=15, theta_new=[ 0.5120383  -2.46307842 -2.84086998], -likelihood = -1015.87553
# Iteration=16, theta_new=[ 0.51100853 -2.46182028 -2.84121375], -likelihood = -1016.06097
# Iteration=17, theta_new=[ 0.51026106 -2.46062378 -2.84150093], -likelihood = -1016.17738
# Iteration=18, theta_new=[ 0.50969192 -2.45963005 -2.84172444], -likelihood = -1016.25148
# Iteration=19, theta_new=[ 0.50930412 -2.45860995 -2.84186925], -likelihood = -1016.29958
# Iteration=20, theta_new=[ 0.5089975  -2.45767422 -2.8419939 ], -likelihood = -1016.33027
# 9-th start
# Iteration=1, theta_new=[2.73957897 3.15583973 3.00348804], -likelihood = -604.30538
# Iteration=2, theta_new=[2.72350165 3.17791292 3.00209243], -likelihood = -656.92608
# Iteration=3, theta_new=[2.71024851 3.19909691 3.00331249], -likelihood = -689.73868
# Iteration=4, theta_new=[2.69900479 3.22059981 3.00642268], -likelihood = -715.68220
# Iteration=5, theta_new=[2.68906864 3.24292709 3.01100388], -likelihood = -740.73211
# Iteration=6, theta_new=[2.68006512 3.26584756 3.0167364 ], -likelihood = -768.22068
# Iteration=7, theta_new=[2.67177882 3.28886273 3.02308363], -likelihood = -799.35226
# Iteration=8, theta_new=[2.66421276 3.31111911 3.02952807], -likelihood = -833.46371
# Iteration=9, theta_new=[2.65745358 3.33169378 3.03549468], -likelihood = -867.94599
# Iteration=10, theta_new=[2.65169975 3.34998674 3.04068272], -likelihood = -899.40039
# Iteration=11, theta_new=[2.64697155 3.36580873 3.04498612], -likelihood = -925.41196
# Iteration=12, theta_new=[2.64320057 3.37914557 3.04846945], -likelihood = -945.34880
# Iteration=13, theta_new=[2.64029943 3.39018829 3.05130063], -likelihood = -959.72825
# Iteration=14, theta_new=[2.63807258 3.39925912 3.05361747], -likelihood = -969.67282
# Iteration=15, theta_new=[2.63641891 3.40660577 3.05542996], -likelihood = -976.39949
# Iteration=16, theta_new=[2.63518931 3.41253497 3.05698165], -likelihood = -980.84094
# Iteration=17, theta_new=[2.63429276 3.41729759 3.05839975], -likelihood = -983.75838
# Iteration=18, theta_new=[2.63360316 3.4211618  3.05966479], -likelihood = -985.66737
# Iteration=19, theta_new=[2.63309659 3.42421087 3.06088635], -likelihood = -986.93174
# Iteration=20, theta_new=[2.63275761 3.42667368 3.06212849], -likelihood = -987.75367
# 10-th start
# Iteration=1, theta_new=[-2.706454    2.45427075 -0.68145643], -likelihood = -619.74583
# Iteration=2, theta_new=[-2.72751265  2.49285628 -0.68070561], -likelihood = -694.68555
# Iteration=3, theta_new=[-2.74628325  2.52810117 -0.67920248], -likelihood = -787.37059
# Iteration=4, theta_new=[-2.76265411  2.55593372 -0.67789128], -likelihood = -867.46376
# Iteration=5, theta_new=[-2.77666293  2.57680842 -0.6773095 ], -likelihood = -922.80180
# Iteration=6, theta_new=[-2.78845378  2.59213646 -0.67739363], -likelihood = -957.93119
# Iteration=7, theta_new=[-2.79830638  2.60335726 -0.67786628], -likelihood = -979.67274
# Iteration=8, theta_new=[-2.80649615  2.61156013 -0.67857118], -likelihood = -993.16499
# Iteration=9, theta_new=[-2.81326433  2.61752079 -0.67940675], -likelihood = -1001.59696
# Iteration=10, theta_new=[-2.81874318  2.62186197 -0.68031801], -likelihood = -1006.89393
# Iteration=11, theta_new=[-2.82327938  2.62503655 -0.68125174], -likelihood = -1010.22072
# Iteration=12, theta_new=[-2.82697079  2.62732369 -0.68214562], -likelihood = -1012.36551
# Iteration=13, theta_new=[-2.82995472  2.62900991 -0.6829721 ], -likelihood = -1013.73957
# Iteration=14, theta_new=[-2.83239137  2.63024544 -0.68382819], -likelihood = -1014.62925
# Iteration=15, theta_new=[-2.83433708  2.63110832 -0.68464101], -likelihood = -1015.21435
# Iteration=16, theta_new=[-2.83590087  2.63174983 -0.6854195 ], -likelihood = -1015.59302
# Iteration=17, theta_new=[-2.83716436  2.63223055 -0.68610412], -likelihood = -1015.84496
# Iteration=18, theta_new=[-2.83818938  2.63254946 -0.68673736], -likelihood = -1016.01477
# Iteration=19, theta_new=[-2.83903155  2.63277508 -0.68737279], -likelihood = -1016.12929
# Iteration=20, theta_new=[-2.83972653  2.632969   -0.6879757 ], -likelihood = -1016.20891
# 11-th start
# Iteration=1, theta_new=[-2.78385204  1.29744184  0.06222488], -likelihood = -839.35370
# Iteration=2, theta_new=[-2.79850034  1.24403867  0.06380349], -likelihood = -892.14847
# Iteration=3, theta_new=[-2.81054121  1.20816819  0.06412775], -likelihood = -928.01222
# Iteration=4, theta_new=[-2.82022468  1.18326997  0.06358772], -likelihood = -950.51618
# Iteration=5, theta_new=[-2.82792043  1.16563711  0.06244019], -likelihood = -964.01560
# Iteration=6, theta_new=[-2.83400281  1.15306525  0.06101809], -likelihood = -971.96441
# Iteration=7, theta_new=[-2.83882024  1.14404065  0.05944692], -likelihood = -976.60516
# Iteration=8, theta_new=[-2.84263106  1.13749652  0.05782965], -likelihood = -979.33084
# Iteration=9, theta_new=[-2.84564799  1.1327931   0.05619567], -likelihood = -980.94825
# Iteration=10, theta_new=[-2.84802491  1.12935668  0.05463633], -likelihood = -981.92027
# Iteration=11, theta_new=[-2.8499468   1.12689461  0.05319431], -likelihood = -982.51458
# Iteration=12, theta_new=[-2.85149073  1.12505347  0.0518138 ], -likelihood = -982.88851
# Iteration=13, theta_new=[-2.85269941  1.12376837  0.05054182], -likelihood = -983.13321
# Iteration=14, theta_new=[-2.85365485  1.12281019  0.04931596], -likelihood = -983.29365
# Iteration=15, theta_new=[-2.85441742  1.12208878  0.04823904], -likelihood = -983.40752
# Iteration=16, theta_new=[-2.85508401  1.12158541  0.04725493], -likelihood = -983.48768
# Iteration=17, theta_new=[-2.85559318  1.12121334  0.04637637], -likelihood = -983.54866
# Iteration=18, theta_new=[-2.85601668  1.12094684  0.04553904], -likelihood = -983.59422
# Iteration=19, theta_new=[-2.856367    1.12071811  0.04476701], -likelihood = -983.63214
# Iteration=20, theta_new=[-2.85662     1.12058169  0.04408435], -likelihood = -983.66331
# 12-th start
# Iteration=1, theta_new=[-1.57081687 -0.93696153 -2.90645133], -likelihood = -850.12360
# Iteration=2, theta_new=[-1.57082034 -0.9316799  -2.89563929], -likelihood = -874.66523
# Iteration=3, theta_new=[-1.57066063 -0.9277861  -2.88718991], -likelihood = -882.86200
# Iteration=4, theta_new=[-1.57079782 -0.92492004 -2.88059984], -likelihood = -887.94018
# Iteration=5, theta_new=[-1.570884   -0.92281723 -2.87545031], -likelihood = -891.05734
# Iteration=6, theta_new=[-1.57081359 -0.92126922 -2.87143543], -likelihood = -892.96613
# Iteration=7, theta_new=[-1.57077779 -0.92019193 -2.86827787], -likelihood = -894.12781
# Iteration=8, theta_new=[-1.57076301 -0.91940629 -2.86581795], -likelihood = -894.84952
# Iteration=9, theta_new=[-1.57080317 -0.91883822 -2.86389196], -likelihood = -895.28930
# Iteration=10, theta_new=[-1.570798   -0.91842452 -2.86238906], -likelihood = -895.56042
# Iteration=11, theta_new=[-1.57075454 -0.91812311 -2.86120421], -likelihood = -895.72732
# Iteration=12, theta_new=[-1.57080911 -0.91790957 -2.8602805 ], -likelihood = -895.83223
# Iteration=13, theta_new=[-1.57082102 -0.91773436 -2.85956123], -likelihood = -895.89862
# Iteration=14, theta_new=[-1.57076697 -0.91763583 -2.85898976], -likelihood = -895.93769
# Iteration=15, theta_new=[-1.57077502 -0.91757508 -2.85853315], -likelihood = -895.96783
# Iteration=16, theta_new=[-1.57077437 -0.91752409 -2.85818108], -likelihood = -895.99017
# Iteration=17, theta_new=[-1.57083205 -0.91752531 -2.85790298], -likelihood = -896.00404
# Iteration=18, theta_new=[-1.57075568 -0.91749027 -2.85768691], -likelihood = -896.01966
# Iteration=19, theta_new=[-1.57075491 -0.91747152 -2.8575297 ], -likelihood = -896.02529
# Iteration=20, theta_new=[-1.57081277 -0.91747822 -2.85738573], -likelihood = -896.02987
# 13-th start
# Iteration=1, theta_new=[-0.75876815  0.85568374 -2.15586784], -likelihood = -463.35363
# Iteration=2, theta_new=[-0.75662692  0.89031925 -2.11633845], -likelihood = -519.12723
# Iteration=3, theta_new=[-0.75800554  0.92328034 -2.07658843], -likelihood = -570.05440
# Iteration=4, theta_new=[-0.76030638  0.95153258 -2.03780002], -likelihood = -607.36017
# Iteration=5, theta_new=[-0.76215254  0.97435533 -2.00140388], -likelihood = -630.55638
# Iteration=6, theta_new=[-0.76341196  0.99205925 -1.96849408], -likelihood = -643.87199
# Iteration=7, theta_new=[-0.7642043   1.005369   -1.93968787], -likelihood = -651.22837
# Iteration=8, theta_new=[-0.76466621  1.01497599 -1.91474519], -likelihood = -655.17625
# Iteration=9, theta_new=[-0.76496823  1.02167274 -1.89331871], -likelihood = -657.21386
# Iteration=10, theta_new=[-0.76520251  1.02613995 -1.87486765], -likelihood = -658.21116
# Iteration=11, theta_new=[-0.76542354  1.02893298 -1.8587918 ], -likelihood = -658.65513
# Iteration=12, theta_new=[-0.76567416  1.03050439 -1.84467177], -likelihood = -658.81389
# Iteration=13, theta_new=[-0.76595355  1.03114213 -1.83199115], -likelihood = -658.83277
# Iteration=14, theta_new=[-0.76627852  1.03110617 -1.8204122 ], -likelihood = -658.78624
# Iteration=15, theta_new=[-0.76663114  1.03058202 -1.80967888], -likelihood = -658.71423
# Iteration=16, theta_new=[-0.76702492  1.02975457 -1.79956003], -likelihood = -658.63566
# Iteration=17, theta_new=[-0.76745083  1.02866135 -1.78975575], -likelihood = -658.55954
# Iteration=18, theta_new=[-0.76793653  1.02740853 -1.78030599], -likelihood = -658.48829
# Iteration=19, theta_new=[-0.76842715  1.02607153 -1.77112622], -likelihood = -658.42543
# Iteration=20, theta_new=[-0.76891729  1.02464592 -1.76196851], -likelihood = -658.36929
# 14-th start
# Iteration=1, theta_new=[-2.6318933  -1.42682463  2.69328333], -likelihood = -864.44451
# Iteration=2, theta_new=[-2.66152246 -1.57077658  2.68087946], -likelihood = -952.46712
# Iteration=3, theta_new=[-2.69007148 -1.57073276  2.67174838], -likelihood = -1002.78591
# Iteration=4, theta_new=[-2.71620722 -1.57082822  2.66471442], -likelihood = -1044.61429
# Iteration=5, theta_new=[-2.73928714 -1.57081071  2.65926711], -likelihood = -1081.92936
# Iteration=6, theta_new=[-2.7591364  -1.57075142  2.65504609], -likelihood = -1113.18306
# Iteration=7, theta_new=[-2.77587562 -1.57082623  2.6517602 ], -likelihood = -1137.84668
# Iteration=8, theta_new=[-2.78979119 -1.57082383  2.649225  ], -likelihood = -1156.33921
# Iteration=9, theta_new=[-2.80124104 -1.57074131  2.64726131], -likelihood = -1169.63665
# Iteration=10, theta_new=[-2.81056491 -1.57078178  2.64575121], -likelihood = -1178.89854
# Iteration=11, theta_new=[-2.81811926 -1.57075241  2.64459476], -likelihood = -1185.17809
# Iteration=12, theta_new=[-2.82422184 -1.57080869  2.64370322], -likelihood = -1189.36367
# Iteration=13, theta_new=[-2.82911704 -1.57082939  2.64303331], -likelihood = -1192.12143
# Iteration=14, theta_new=[-2.83303663 -1.57077161  2.64252276], -likelihood = -1193.91455
# Iteration=15, theta_new=[-2.83616843 -1.57075234  2.64212453], -likelihood = -1195.07449
# Iteration=16, theta_new=[-2.83868205 -1.57073913  2.64184687], -likelihood = -1195.82183
# Iteration=17, theta_new=[-2.84068088 -1.57080362  2.64161427], -likelihood = -1196.30470
# Iteration=18, theta_new=[-2.84226362 -1.5708215   2.64143751], -likelihood = -1196.61386
# Iteration=19, theta_new=[-2.84352179 -1.57084106  2.64131732], -likelihood = -1196.81127
# Iteration=20, theta_new=[-2.84452209 -1.57078866  2.64122376], -likelihood = -1196.93831
# 15-th start
# Iteration=1, theta_new=[ 2.7914892  -2.90729565 -0.87370341], -likelihood = -693.17725
# Iteration=2, theta_new=[ 2.75799297 -2.89701634 -0.85679494], -likelihood = -770.92350
# Iteration=3, theta_new=[ 2.72939278 -2.88823164 -0.8408974 ], -likelihood = -842.49274
# Iteration=4, theta_new=[ 2.70618641 -2.88055372 -0.82645452], -likelihood = -900.02591
# Iteration=5, theta_new=[ 2.68806713 -2.87396628 -0.81348192], -likelihood = -941.24633
# Iteration=6, theta_new=[ 2.67420244 -2.86840149 -0.80181037], -likelihood = -968.37832
# Iteration=7, theta_new=[ 2.66378228 -2.8636993  -0.79127644], -likelihood = -985.48480
# Iteration=8, theta_new=[ 2.6559661  -2.85991798 -0.78174272], -likelihood = -996.08492
# Iteration=9, theta_new=[ 2.65016795 -2.85682681 -0.77321153], -likelihood = -1002.65938
# Iteration=10, theta_new=[ 2.64589327 -2.85429759 -0.7655322 ], -likelihood = -1006.79186
# Iteration=11, theta_new=[ 2.64272075 -2.85225408 -0.75856059], -likelihood = -1009.45874
# Iteration=12, theta_new=[ 2.64040241 -2.85059579 -0.75238569], -likelihood = -1011.24253
# Iteration=13, theta_new=[ 2.63866968 -2.84924657 -0.74677875], -likelihood = -1012.45596
# Iteration=14, theta_new=[ 2.63738876 -2.84812325 -0.74178853], -likelihood = -1013.32536
# Iteration=15, theta_new=[ 2.63644035 -2.84720997 -0.73723652], -likelihood = -1013.95793
# Iteration=16, theta_new=[ 2.63571056 -2.84644567 -0.73319441], -likelihood = -1014.43665
# Iteration=17, theta_new=[ 2.63519695 -2.8458463  -0.72953135], -likelihood = -1014.80091
# Iteration=18, theta_new=[ 2.63481379 -2.84534959 -0.72625813], -likelihood = -1015.08457
# Iteration=19, theta_new=[ 2.63452925 -2.84493815 -0.72329949], -likelihood = -1015.30797
# Iteration=20, theta_new=[ 2.63433367 -2.8445577  -0.7206062 ], -likelihood = -1015.48771
# 16-th start
# Iteration=1, theta_new=[-1.87639126 -0.24284949  2.79608096], -likelihood = -769.38388
# Iteration=2, theta_new=[-1.74344707 -0.25129198  2.76147845], -likelihood = -926.26779
# Iteration=3, theta_new=[-1.57084396 -0.25839962  2.73330979], -likelihood = -1058.92526
# Iteration=4, theta_new=[-1.57080403 -0.26459303  2.71134879], -likelihood = -1119.04867
# Iteration=5, theta_new=[-1.57084899 -0.26991844  2.69433038], -likelihood = -1150.20117
# Iteration=6, theta_new=[-1.57077316 -0.27439237  2.68130059], -likelihood = -1169.58341
# Iteration=7, theta_new=[-1.57088833 -0.27810656  2.67138712], -likelihood = -1181.20130
# Iteration=8, theta_new=[-1.57081112 -0.28111549  2.66388128], -likelihood = -1188.02433
# Iteration=9, theta_new=[-1.57077702 -0.28353938  2.65820498], -likelihood = -1191.97068
# Iteration=10, theta_new=[-1.57079883 -0.28549886  2.65394182], -likelihood = -1194.23856
# Iteration=11, theta_new=[-1.57083212 -0.28706257  2.65071807], -likelihood = -1195.53153
# Iteration=12, theta_new=[-1.57081516 -0.28831121  2.64830271], -likelihood = -1196.26830
# Iteration=13, theta_new=[-1.57079708 -0.2893114   2.64647248], -likelihood = -1196.68328
# Iteration=14, theta_new=[-1.57077864 -0.29010132  2.64510848], -likelihood = -1196.91754
# Iteration=15, theta_new=[-1.57079691 -0.29073192  2.64408416], -likelihood = -1197.04637
# Iteration=16, theta_new=[-1.57081369 -0.29123272  2.64330584], -likelihood = -1197.11688
# Iteration=17, theta_new=[-1.57079938 -0.29162718  2.64272715], -likelihood = -1197.15473
# Iteration=18, theta_new=[-1.57077329 -0.29194431  2.64229228], -likelihood = -1197.17397
# Iteration=19, theta_new=[-1.5707861  -0.29221019  2.64196246], -likelihood = -1197.18326
# Iteration=20, theta_new=[-1.57079023 -0.29242219  2.641709  ], -likelihood = -1197.18727
# 17-th start
# Iteration=1, theta_new=[-2.92802609  0.04650775  1.30319462], -likelihood = -859.40434
# Iteration=2, theta_new=[-2.91663632  0.04478964  1.24950141], -likelihood = -903.49261
# Iteration=3, theta_new=[-2.90688058  0.04343847  1.2138164 ], -likelihood = -932.35501
# Iteration=4, theta_new=[-2.89855356  0.04243228  1.188912  ], -likelihood = -950.86504
# Iteration=5, theta_new=[-2.89151519  0.04169236  1.17114536], -likelihood = -962.66544
# Iteration=6, theta_new=[-2.8856096   0.04113408  1.15820585], -likelihood = -970.16644
# Iteration=7, theta_new=[-2.88070677  0.04067351  1.14869883], -likelihood = -974.96159
# Iteration=8, theta_new=[-2.8765863   0.04028965  1.14162499], -likelihood = -978.03161
# Iteration=9, theta_new=[-2.87321816  0.03999974  1.13636038], -likelihood = -980.03082
# Iteration=10, theta_new=[-2.87042828  0.03973771  1.13239735], -likelihood = -981.31521
# Iteration=11, theta_new=[-2.86812864  0.03956287  1.12945612], -likelihood = -982.15782
# Iteration=12, theta_new=[-2.86624439  0.0394099   1.12722667], -likelihood = -982.70866
# Iteration=13, theta_new=[-2.86468499  0.03924463  1.12556528], -likelihood = -983.07271
# Iteration=14, theta_new=[-2.86341702  0.0390901   1.1243011 ], -likelihood = -983.31765
# Iteration=15, theta_new=[-2.86239282  0.03891835  1.12328532], -likelihood = -983.48164
# Iteration=16, theta_new=[-2.86155111  0.03889738  1.12261808], -likelihood = -983.59306
# Iteration=17, theta_new=[-2.86085375  0.03877507  1.12196674], -likelihood = -983.66594
# Iteration=18, theta_new=[-2.86030913  0.03871356  1.12152548], -likelihood = -983.71988
# Iteration=19, theta_new=[-2.85984634  0.03863548  1.12120919], -likelihood = -983.75487
# Iteration=20, theta_new=[-2.8594456   0.03853126  1.12091809], -likelihood = -983.78138
# 18-th start
# Iteration=1, theta_new=[0.64863591 0.12283846 1.86319545], -likelihood = -764.64678
# Iteration=2, theta_new=[0.61727046 0.11925083 1.90860852], -likelihood = -834.19437
# Iteration=3, theta_new=[0.59114925 0.11712162 1.94033774], -likelihood = -892.66508
# Iteration=4, theta_new=[0.57042642 0.11609381 1.96278473], -likelihood = -935.06862
# Iteration=5, theta_new=[0.55450106 0.11570739 1.97882326], -likelihood = -962.87167
# Iteration=6, theta_new=[0.54232555 0.11571622 1.99031011], -likelihood = -979.87323
# Iteration=7, theta_new=[0.53314265 0.11597786 1.99859097], -likelihood = -989.92698
# Iteration=8, theta_new=[0.52617061 0.11637618 2.00451638], -likelihood = -995.70600
# Iteration=9, theta_new=[0.52089757 0.11686325 2.00878435], -likelihood = -999.00708
# Iteration=10, theta_new=[0.51689078 0.11734176 2.01178402], -likelihood = -1000.87598
# Iteration=11, theta_new=[0.51386039 0.11784412 2.01403211], -likelihood = -1001.92919
# Iteration=12, theta_new=[0.5115222  0.11832141 2.01557796], -likelihood = -1002.52414
# Iteration=13, theta_new=[0.50971168 0.11886028 2.0167119 ], -likelihood = -1002.85982
# Iteration=14, theta_new=[0.50835705 0.11928435 2.01749718], -likelihood = -1003.05125
# Iteration=15, theta_new=[0.50726252 0.11974449 2.01805598], -likelihood = -1003.15392
# Iteration=16, theta_new=[0.50646194 0.12013964 2.01840936], -likelihood = -1003.21328
# Iteration=17, theta_new=[0.50583923 0.12048121 2.01864183], -likelihood = -1003.24325
# Iteration=18, theta_new=[0.50538437 0.12081018 2.01880773], -likelihood = -1003.25873
# Iteration=19, theta_new=[0.50497698 0.12115545 2.01891867], -likelihood = -1003.26681
# Iteration=20, theta_new=[0.50468859 0.12141671 2.01894102], -likelihood = -1003.27121
# 19-th start
# Iteration=1, theta_new=[ 0.019717   -1.5708354  -1.57084572], -likelihood = -438.07028
# Iteration=2, theta_new=[ 0.03066947 -1.57082291 -1.57077868], -likelihood = -446.05777
# Iteration=3, theta_new=[ 0.04209375 -1.57079228 -1.57082331], -likelihood = -449.84840
# Iteration=4, theta_new=[ 0.0529129  -1.57080255 -1.57081776], -likelihood = -453.70772
# Iteration=5, theta_new=[ 0.06244419 -1.57080129 -1.5707853 ], -likelihood = -456.99471
# Iteration=6, theta_new=[ 0.07039007 -1.57083825 -1.57076656], -likelihood = -459.43877
# Iteration=7, theta_new=[ 0.07678717 -1.57076519 -1.57081452], -likelihood = -461.08113
# Iteration=8, theta_new=[ 0.08183309 -1.57080044 -1.57082588], -likelihood = -462.11291
# Iteration=9, theta_new=[ 0.08575942 -1.5707887  -1.57081207], -likelihood = -462.73289
# Iteration=10, theta_new=[ 0.08877794 -1.5707727  -1.57083188], -likelihood = -463.09303
# Iteration=11, theta_new=[ 0.09108955 -1.5707641  -1.57077681], -likelihood = -463.29576
# Iteration=12, theta_new=[ 0.09286399 -1.57087371 -1.57084671], -likelihood = -463.40697
# Iteration=13, theta_new=[ 0.09421526 -1.57080276 -1.57077143], -likelihood = -463.46626
# Iteration=14, theta_new=[ 0.0952399  -1.57076782 -1.57079886], -likelihood = -463.49617
# Iteration=15, theta_new=[ 0.0960295  -1.57082605 -1.57074369], -likelihood = -463.51005
# Iteration=16, theta_new=[ 0.0966396  -1.57080793 -1.57078626], -likelihood = -463.51556
# Iteration=17, theta_new=[ 0.09708908 -1.57077972 -1.57082334], -likelihood = -463.51673
# Iteration=18, theta_new=[ 0.0974308  -1.57079941 -1.57082619], -likelihood = -463.51587
# Iteration=19, theta_new=[ 0.09770725 -1.57078982 -1.57081407], -likelihood = -463.51422
# Iteration=20, theta_new=[ 0.0979025  -1.57083049 -1.57075284], -likelihood = -463.51228
# 20-th start
# Iteration=1, theta_new=[ 1.03475204 -0.42577555 -0.50374897], -likelihood = -650.04474
# Iteration=2, theta_new=[ 1.05231961 -0.39390683 -0.53327847], -likelihood = -825.68220
# Iteration=3, theta_new=[ 1.0659465  -0.37348223 -0.54852922], -likelihood = -910.10910
# Iteration=4, theta_new=[ 1.07656382 -0.35725326 -0.55839683], -likelihood = -941.82952
# Iteration=5, theta_new=[ 1.08479169 -0.34391678 -0.56504262], -likelihood = -959.92068
# Iteration=6, theta_new=[ 1.0912525  -0.33286903 -0.56925366], -likelihood = -971.53103
# Iteration=7, theta_new=[ 1.09629169 -0.32369055 -0.57173115], -likelihood = -979.33751
# Iteration=8, theta_new=[ 1.10029524 -0.31611838 -0.57281028], -likelihood = -984.67718
# Iteration=9, theta_new=[ 1.10345999 -0.30988387 -0.57276791], -likelihood = -988.34222
# Iteration=10, theta_new=[ 1.10600024 -0.30472649 -0.57198305], -likelihood = -990.87251
# Iteration=11, theta_new=[ 1.10802712 -0.30046398 -0.57058458], -likelihood = -992.64009
# Iteration=12, theta_new=[ 1.10967356 -0.29691995 -0.56873251], -likelihood = -993.89135
# Iteration=13, theta_new=[ 1.11099813 -0.29400605 -0.56651098], -likelihood = -994.79839
# Iteration=14, theta_new=[ 1.11206251 -0.29155793 -0.56411628], -likelihood = -995.46673
# Iteration=15, theta_new=[ 1.11299309 -0.28948762 -0.56160675], -likelihood = -995.97479
# Iteration=16, theta_new=[ 1.11374215 -0.2877266  -0.55900922], -likelihood = -996.37289
# Iteration=17, theta_new=[ 1.11442533 -0.28617154 -0.55636283], -likelihood = -996.69139
# Iteration=18, theta_new=[ 1.11495921 -0.28482866 -0.55376126], -likelihood = -996.95621
# Iteration=19, theta_new=[ 1.11545189 -0.28365281 -0.55120297], -likelihood = -997.17166
# Iteration=20, theta_new=[ 1.11586651 -0.28259988 -0.54866083], -likelihood = -997.35137
# 21-th start
# Iteration=1, theta_new=[-2.74141875 -0.23217274 -1.5707737 ], -likelihood = -860.93298
# Iteration=2, theta_new=[-2.73795317 -0.23067222 -1.57074359], -likelihood = -866.92446
# Iteration=3, theta_new=[-2.7351711  -0.22980744 -1.57084095], -likelihood = -867.57835
# Iteration=4, theta_new=[-2.73290077 -0.22937915 -1.57083277], -likelihood = -868.04207
# Iteration=5, theta_new=[-2.73100794 -0.22925443 -1.57083455], -likelihood = -868.39876
# Iteration=6, theta_new=[-2.72937314 -0.22930877 -1.57082819], -likelihood = -868.69287
# Iteration=7, theta_new=[-2.72794465 -0.22951649 -1.57081838], -likelihood = -868.94854
# Iteration=8, theta_new=[-2.72665503 -0.22979545 -1.57082478], -likelihood = -869.17903
# Iteration=9, theta_new=[-2.72550247 -0.23013414 -1.57082865], -likelihood = -869.39072
# Iteration=10, theta_new=[-2.72443131 -0.23049545 -1.57083521], -likelihood = -869.58494
# Iteration=11, theta_new=[-2.72344069 -0.23088373 -1.5707955 ], -likelihood = -869.76715
# Iteration=12, theta_new=[-2.72251886 -0.23124885 -1.57086696], -likelihood = -869.93860
# Iteration=13, theta_new=[-2.72164705 -0.23163515 -1.57077348], -likelihood = -870.09651
# Iteration=14, theta_new=[-2.72081353 -0.23202126 -1.57082194], -likelihood = -870.24808
# Iteration=15, theta_new=[-2.72003905 -0.23239042 -1.57075542], -likelihood = -870.39297
# Iteration=16, theta_new=[-2.71928893 -0.23274061 -1.57077837], -likelihood = -870.52714
# Iteration=17, theta_new=[-2.71859259 -0.23309111 -1.57076797], -likelihood = -870.65499
# Iteration=18, theta_new=[-2.71790831 -0.23342322 -1.57079717], -likelihood = -870.77492
# Iteration=19, theta_new=[-2.71725859 -0.23374561 -1.57082673], -likelihood = -870.89041
# Iteration=20, theta_new=[-2.7166382  -0.23405999 -1.57084885], -likelihood = -870.99967
# 22-th start
# Iteration=1, theta_new=[2.10897656 1.57073981 1.90994356], -likelihood = -565.79412
# Iteration=2, theta_new=[2.12180302 1.57075969 1.9232041 ], -likelihood = -569.86566
# Iteration=3, theta_new=[2.13300406 1.57082049 1.93523338], -likelihood = -572.75017
# Iteration=4, theta_new=[2.14316375 1.57080093 1.9458119 ], -likelihood = -575.21236
# Iteration=5, theta_new=[2.15264375 1.57079951 1.95495419], -likelihood = -577.40808
# Iteration=6, theta_new=[2.16172885 1.57078417 1.96284219], -likelihood = -579.44048
# Iteration=7, theta_new=[2.17062226 1.57074513 1.96968708], -likelihood = -581.39906
# Iteration=8, theta_new=[2.17947382 1.57084261 1.97569117], -likelihood = -583.35927
# Iteration=9, theta_new=[2.1884768  1.57076019 1.98106886], -likelihood = -585.38925
# Iteration=10, theta_new=[2.19779824 1.57078374 1.98600738], -likelihood = -587.57432
# Iteration=11, theta_new=[2.20764504 1.57080562 1.9907115 ], -likelihood = -590.00973
# Iteration=12, theta_new=[2.21832408 1.5708356  1.99532678], -likelihood = -592.82869
# Iteration=13, theta_new=[2.2302175  1.57080706 2.0000782 ], -likelihood = -596.23524
# Iteration=14, theta_new=[2.2438789  1.57075696 2.00518257], -likelihood = -600.55373
# Iteration=15, theta_new=[2.26014289 1.57080284 2.01098336], -likelihood = -606.33596
# Iteration=16, theta_new=[2.28022459 1.57091188 2.01793722], -likelihood = -614.60312
# Iteration=17, theta_new=[2.30576563 1.57078758 2.02673712], -likelihood = -627.28298
# Iteration=18, theta_new=[2.33834261 1.57074491 2.03822172], -likelihood = -647.94083
# Iteration=19, theta_new=[2.377359   1.57053497 2.0527555 ], -likelihood = -681.84967
# Iteration=20, theta_new=[2.41853232 1.57075583 2.06921119], -likelihood = -731.73500
# 23-th start
# Iteration=1, theta_new=[ 2.02171938 -0.94437227  1.37799217], -likelihood = -591.17618
# Iteration=2, theta_new=[ 2.05240804 -0.92994446  1.41545778], -likelihood = -612.45293
# Iteration=3, theta_new=[ 2.07495277 -0.91408329  1.44570615], -likelihood = -628.01270
# Iteration=4, theta_new=[ 2.09193141 -0.89876767  1.46883233], -likelihood = -638.60942
# Iteration=5, theta_new=[ 2.10490909 -0.88489013  1.4849198 ], -likelihood = -645.67039
# Iteration=6, theta_new=[ 2.11492317 -0.87271626  1.49390137], -likelihood = -650.30178
# Iteration=7, theta_new=[ 2.12273398 -0.86219492  1.49617819], -likelihood = -653.30742
# Iteration=8, theta_new=[ 2.12888593 -0.85314001  1.49336595], -likelihood = -655.25041
# Iteration=9, theta_new=[ 2.1337684  -0.84537887  1.48744756], -likelihood = -656.50674
# Iteration=10, theta_new=[ 2.13772554 -0.83870875  1.47984748], -likelihood = -657.31697
# Iteration=11, theta_new=[ 2.1409441  -0.83295292  1.47169861], -likelihood = -657.84100
# Iteration=12, theta_new=[ 2.1436206  -0.82798939  1.46355812], -likelihood = -658.17653
# Iteration=13, theta_new=[ 2.14586976 -0.82368447  1.45563604], -likelihood = -658.38953
# Iteration=14, theta_new=[ 2.14778274 -0.81993941  1.44818897], -likelihood = -658.52062
# Iteration=15, theta_new=[ 2.14944959 -0.81667605  1.44124734], -likelihood = -658.59780
# Iteration=16, theta_new=[ 2.15091692 -0.81383653  1.43472051], -likelihood = -658.63997
# Iteration=17, theta_new=[ 2.15225183 -0.81132049  1.42874133], -likelihood = -658.65806
# Iteration=18, theta_new=[ 2.15345246 -0.80912172  1.42314646], -likelihood = -658.66247
# Iteration=19, theta_new=[ 2.15453841 -0.80719329  1.41790649], -likelihood = -658.65616
# Iteration=20, theta_new=[ 2.1555613  -0.80546931  1.41311066], -likelihood = -658.64282
# 24-th start
# Iteration=1, theta_new=[-2.93182209  1.84636114 -1.43875634], -likelihood = -698.48326
# Iteration=2, theta_new=[-2.91484374  1.93449488 -1.34235374], -likelihood = -811.83802
# Iteration=3, theta_new=[-2.90122239  1.97625858 -1.27964948], -likelihood = -895.49935
# Iteration=4, theta_new=[-2.89043273  2.00083322 -1.24107797], -likelihood = -932.77366
# Iteration=5, theta_new=[-2.88190518  2.0168337  -1.21528948], -likelihood = -950.73854
# Iteration=6, theta_new=[-2.87520563  2.02766619 -1.19723825], -likelihood = -960.25675
# Iteration=7, theta_new=[-2.86991464  2.03510258 -1.18413345], -likelihood = -965.53508
# Iteration=8, theta_new=[-2.86573364  2.04022793 -1.17428251], -likelihood = -968.56849
# Iteration=9, theta_new=[-2.8624264   2.04378507 -1.16673881], -likelihood = -970.36278
# Iteration=10, theta_new=[-2.8598053   2.04618998 -1.16078533], -likelihood = -971.45050
# Iteration=11, theta_new=[-2.85773508  2.04778148 -1.1559295 ], -likelihood = -972.13495
# Iteration=12, theta_new=[-2.85611031  2.04878743 -1.15185692], -likelihood = -972.58504
# Iteration=13, theta_new=[-2.85479709  2.04940258 -1.14828523], -likelihood = -972.89747
# Iteration=14, theta_new=[-2.85378823  2.04969612 -1.14509363], -likelihood = -973.13360
# Iteration=15, theta_new=[-2.85298409  2.04974379 -1.14211743], -likelihood = -973.32152
# Iteration=16, theta_new=[-2.8523318   2.04965124 -1.13933902], -likelihood = -973.48758
# Iteration=17, theta_new=[-2.8518309   2.04944228 -1.13663188], -likelihood = -973.63700
# Iteration=18, theta_new=[-2.85144585  2.04912032 -1.13405311], -likelihood = -973.77866
# Iteration=19, theta_new=[-2.85112816  2.0487395  -1.13149413], -likelihood = -973.91577
# Iteration=20, theta_new=[-2.85087281  2.04831895 -1.12900044], -likelihood = -974.05183
# 25-th start
# Iteration=1, theta_new=[-2.60452313  2.38560289 -0.12867319], -likelihood = -517.53091
# Iteration=2, theta_new=[-2.62599453  2.3944685  -0.15570154], -likelihood = -586.22763
# Iteration=3, theta_new=[-2.64697294  2.41168389 -0.17742429], -likelihood = -647.67896
# Iteration=4, theta_new=[-2.66533496  2.44065187 -0.1942042 ], -likelihood = -698.34131
# Iteration=5, theta_new=[-2.68046392  2.47842277 -0.20686706], -likelihood = -754.10256
# Iteration=6, theta_new=[-2.69245041  2.5157238  -0.21603061], -likelihood = -822.88350
# Iteration=7, theta_new=[-2.70192641  2.54654523 -0.22236179], -likelihood = -889.18866
# Iteration=8, theta_new=[-2.70936385  2.5701527  -0.22652569], -likelihood = -938.10834
# Iteration=9, theta_new=[-2.71524866  2.58755284 -0.22915339], -likelihood = -968.73503
# Iteration=10, theta_new=[-2.71989007  2.60029615 -0.23057642], -likelihood = -986.16891
# Iteration=11, theta_new=[-2.72367499  2.6096323  -0.23123876], -likelihood = -995.72694
# Iteration=12, theta_new=[-2.72681549  2.61642872 -0.2313256 ], -likelihood = -1000.89569
# Iteration=13, theta_new=[-2.72944796  2.62142473 -0.23102362], -likelihood = -1003.66554
# Iteration=14, theta_new=[-2.73168944  2.62503928 -0.23040639], -likelihood = -1005.17517
# Iteration=15, theta_new=[-2.73365939  2.62775078 -0.22967773], -likelihood = -1006.00792
# Iteration=16, theta_new=[-2.73547589  2.62974656 -0.22890079], -likelihood = -1006.49595
# Iteration=17, theta_new=[-2.73714341  2.63120822 -0.22799625], -likelihood = -1006.78979
# Iteration=18, theta_new=[-2.73871553  2.63227815 -0.22708385], -likelihood = -1006.98852
# Iteration=19, theta_new=[-2.7401525   2.63308887 -0.22611787], -likelihood = -1007.13182
# Iteration=20, theta_new=[-2.7414863   2.63368552 -0.22521034], -likelihood = -1007.25131
# 26-th start
# Iteration=1, theta_new=[-1.26330014  1.92799484 -2.90687659], -likelihood = -846.07652
# Iteration=2, theta_new=[-1.21269861  1.96435947 -2.89500928], -likelihood = -915.51256
# Iteration=3, theta_new=[-1.17911208  1.98688293 -2.88561027], -likelihood = -944.37520
# Iteration=4, theta_new=[-1.15535616  2.00197955 -2.87820872], -likelihood = -958.57185
# Iteration=5, theta_new=[-1.13793111  2.01235065 -2.87236519], -likelihood = -966.16617
# Iteration=6, theta_new=[-1.12478173  2.01956544 -2.86774607], -likelihood = -970.41472
# Iteration=7, theta_new=[-1.11452132  2.02457327 -2.86408251], -likelihood = -972.86548
# Iteration=8, theta_new=[-1.10631853  2.02804441 -2.86120428], -likelihood = -974.32351
# Iteration=9, theta_new=[-1.09968235  2.03038682 -2.8589353 ], -likelihood = -975.21044
# Iteration=10, theta_new=[-1.09411317  2.0319375  -2.85713068], -likelihood = -975.77013
# Iteration=11, theta_new=[-1.08927468  2.03285651 -2.8556939 ], -likelihood = -976.14467
# Iteration=12, theta_new=[-1.0850258   2.03339777 -2.8545958 ], -likelihood = -976.41576
# Iteration=13, theta_new=[-1.08126589  2.03362929 -2.85370958], -likelihood = -976.61534
# Iteration=14, theta_new=[-1.07774483  2.0336426  -2.85300862], -likelihood = -976.77738
# Iteration=15, theta_new=[-1.07449543  2.03345308 -2.85245972], -likelihood = -976.91790
# Iteration=16, theta_new=[-1.07149974  2.03318377 -2.85203821], -likelihood = -977.04540
# Iteration=17, theta_new=[-1.06867616  2.03277589 -2.85170488], -likelihood = -977.15807
# Iteration=18, theta_new=[-1.06595413  2.03233559 -2.85144369], -likelihood = -977.26739
# Iteration=19, theta_new=[-1.06333231  2.0318968  -2.85126405], -likelihood = -977.36951
# Iteration=20, theta_new=[-1.06083451  2.03142396 -2.85112612], -likelihood = -977.46286
# 27-th start
# Iteration=1, theta_new=[-2.88853224 -1.57081687 -1.5708026 ], -likelihood = -731.94986
# Iteration=2, theta_new=[-2.88153139 -1.57075695 -1.57081303], -likelihood = -748.85287
# Iteration=3, theta_new=[-2.87609445 -1.57081372 -1.5707789 ], -likelihood = -752.53597
# Iteration=4, theta_new=[-2.87188296 -1.5707724  -1.57082813], -likelihood = -754.75969
# Iteration=5, theta_new=[-2.86860106 -1.57079648 -1.57081788], -likelihood = -756.09613
# Iteration=6, theta_new=[-2.86604064 -1.57080431 -1.57081621], -likelihood = -756.90310
# Iteration=7, theta_new=[-2.86404862 -1.57082943 -1.57081121], -likelihood = -757.38993
# Iteration=8, theta_new=[-2.86248719 -1.57081134 -1.57078042], -likelihood = -757.68223
# Iteration=9, theta_new=[-2.8612749  -1.57082437 -1.5707542 ], -likelihood = -757.85852
# Iteration=10, theta_new=[-2.86031855 -1.57077757 -1.57079525], -likelihood = -757.96342
# Iteration=11, theta_new=[-2.85957866 -1.57079245 -1.57077541], -likelihood = -758.02649
# Iteration=12, theta_new=[-2.85899699 -1.57075285 -1.5707974 ], -likelihood = -758.06339
# Iteration=13, theta_new=[-2.85853706 -1.5707703  -1.57075305], -likelihood = -758.08512
# Iteration=14, theta_new=[-2.85818639 -1.57076852 -1.57080577], -likelihood = -758.09777
# Iteration=15, theta_new=[-2.85790903 -1.57078681 -1.57077851], -likelihood = -758.10473
# Iteration=16, theta_new=[-2.85769241 -1.57072596 -1.57074561], -likelihood = -758.10859
# Iteration=17, theta_new=[-2.85751362 -1.57077998 -1.57080667], -likelihood = -758.11059
# Iteration=18, theta_new=[-2.85737731 -1.5708187  -1.57080777], -likelihood = -758.11158
# Iteration=19, theta_new=[-2.85727753 -1.57080379 -1.57080661], -likelihood = -758.11193
# Iteration=20, theta_new=[-2.85719156 -1.57078724 -1.5708322 ], -likelihood = -758.11196
# 28-th start
# Iteration=1, theta_new=[0.65412011 2.91206938 1.29086497], -likelihood = -753.09482
# Iteration=2, theta_new=[0.62532862 2.90036181 1.23994535], -likelihood = -831.87290
# Iteration=3, theta_new=[0.60261976 2.88687596 1.20525309], -likelihood = -893.44596
# Iteration=4, theta_new=[0.58561627 2.87324898 1.1809666 ], -likelihood = -933.13285
# Iteration=5, theta_new=[0.57319222 2.86041662 1.16361256], -likelihood = -956.10927
# Iteration=6, theta_new=[0.56424861 2.84866706 1.15091259], -likelihood = -968.84196
# Iteration=7, theta_new=[0.5579943  2.83802582 1.1415133 ], -likelihood = -975.86180
# Iteration=8, theta_new=[0.55371951 2.82838431 1.13439011], -likelihood = -979.75270
# Iteration=9, theta_new=[0.55103048 2.81954774 1.12906316], -likelihood = -981.97797
# Iteration=10, theta_new=[0.5496135  2.81148596 1.12495717], -likelihood = -983.30210
# Iteration=11, theta_new=[0.54909768 2.80402836 1.12183058], -likelihood = -984.16393
# Iteration=12, theta_new=[0.54933898 2.79707702 1.11939941], -likelihood = -984.80279
# Iteration=13, theta_new=[0.55016275 2.79057935 1.11748169], -likelihood = -985.35114
# Iteration=14, theta_new=[0.55144513 2.784417   1.11599332], -likelihood = -985.87534
# Iteration=15, theta_new=[0.55309454 2.77868681 1.11484335], -likelihood = -986.41130
# Iteration=16, theta_new=[0.55498915 2.77326014 1.11399176], -likelihood = -986.96586
# Iteration=17, theta_new=[0.55714628 2.76819055 1.11335686], -likelihood = -987.54056
# Iteration=18, theta_new=[0.55941762 2.7634331  1.11288087], -likelihood = -988.14081
# Iteration=19, theta_new=[0.561806   2.75901826 1.11252085], -likelihood = -988.74686
# Iteration=20, theta_new=[0.56426203 2.75492806 1.11226593], -likelihood = -989.35680
# 29-th start
# Iteration=1, theta_new=[-0.75398145  1.10930026 -0.28207151], -likelihood = -968.70943
# Iteration=2, theta_new=[-0.74918436  1.1114336  -0.28392727], -likelihood = -969.65654
# Iteration=3, theta_new=[-0.74385158  1.11280963 -0.28534561], -likelihood = -970.41854
# Iteration=4, theta_new=[-0.73797935  1.11367379 -0.28647683], -likelihood = -971.11998
# Iteration=5, theta_new=[-0.73145287  1.11410301 -0.28737268], -likelihood = -971.84752
# Iteration=6, theta_new=[-0.72433759  1.11421297 -0.28808538], -likelihood = -972.66156
# Iteration=7, theta_new=[-0.71658505  1.11418935 -0.28866884], -likelihood = -973.59191
# Iteration=8, theta_new=[-0.70828972  1.11393806 -0.28915108], -likelihood = -974.67108
# Iteration=9, theta_new=[-0.69948431  1.1136962  -0.28952967], -likelihood = -975.89953
# Iteration=10, theta_new=[-0.69032794  1.11340231 -0.28984955], -likelihood = -977.27766
# Iteration=11, theta_new=[-0.68086226  1.11304607 -0.2900772 ], -likelihood = -978.77498
# Iteration=12, theta_new=[-0.67127198  1.11273695 -0.29023718], -likelihood = -980.36978
# Iteration=13, theta_new=[-0.66167735  1.11247274 -0.29034099], -likelihood = -982.01188
# Iteration=14, theta_new=[-0.65223157  1.11235179 -0.29034575], -likelihood = -983.65761
# Iteration=15, theta_new=[-0.64302493  1.11233179 -0.2902977 ], -likelihood = -985.26135
# Iteration=16, theta_new=[-0.63415277  1.11230992 -0.29016345], -likelihood = -986.78921
# Iteration=17, theta_new=[-0.62576494  1.11241239 -0.28995146], -likelihood = -988.21301
# Iteration=18, theta_new=[-0.61786472  1.11254293 -0.28963303], -likelihood = -989.50557
# Iteration=19, theta_new=[-0.61039742  1.11273008 -0.28924722], -likelihood = -990.66718
# Iteration=20, theta_new=[-0.6034145   1.11297542 -0.28879609], -likelihood = -991.70809

# %%
EM_theta4_rad
# Out:
# array([ 1.11145667,  0.51106269, -0.29266864])
