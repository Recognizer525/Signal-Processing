# %% [markdown]
# # ECM-алгоритм для случая, когда шум известен, а сигналы предполагаются детерминированными

# %%
import numpy as np
import matplotlib.pyplot as plt
import em_dtools_kn
from functools import partial

# %%
dist_ratio = 0.5

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
Q1 = 1.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1 = em_dtools_kn.gds(Num_emitters1, sample_size1)
n1 = em_dtools_kn.gss(Num_sensors1, sample_size1, Q1)
X1 = (A1 @ S1.T + n1.T).T

# %%
X1_with_mv = em_dtools_kn.MCAR(X1, [2,4], [40, 40])

# %%
EM_theta1_rad, EM_S, lhd_1 = em_dtools_kn.multi_start_EM(X1_with_mv, 1, Q1, 10, max_iter=30, rtol=1e-9)
# Out:
# 0-th start
# Initial theta = [-2.83488836]
# new_theta=[0.62564523]
# incomplete likelihood is -1193.236233730436 on iteration 0
# new_theta=[-0.95608898]
# incomplete likelihood is -2398.168869453076 on iteration 1
# new_theta=[-0.96046607]
# incomplete likelihood is -4212.386236589922 on iteration 2
# new_theta=[-0.93595552]
# incomplete likelihood is -15511.910234939778 on iteration 3
# new_theta=[-0.9059549]
# incomplete likelihood is -150020.44499863262 on iteration 4
# new_theta=[-0.13463979]
# incomplete likelihood is -7770754.442286601 on iteration 5
# new_theta=[0.20480865]
# incomplete likelihood is -40527072560.98641 on iteration 6
# new_theta=[0.23545795]
# incomplete likelihood is -7.660914673977115e+18 on iteration 7
# new_theta=[0.23830022]
# incomplete likelihood is -1.549154629466935e+38 on iteration 8
# new_theta=None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'NoneType' object has no attribute 'sin'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 EM_theta1_rad, EM_S, lhd_1 = em_dtools_kn.multi_start_EM(X1_with_mv, 1, Q1, 10, max_iter=30, rtol=1e-9)
#
# File c:\Users\asus\Desktop\Аспирантура\Диссертация\Компоненты диссертации\Enhanced Program Complex (opt with Torch)\EM, deterministic model with missing values and known noise\em_dtools_kn.py:273, in multi_start_EM(X, M, Q, num_of_starts, max_iter, rtol)
#     271 print(f'{i}-th start')
#     272 theta, S = initializer(X, M, seed=i * 100)
# --> 273 est_theta, est_S, est_lhd = EM(theta, S, X, Q, max_iter, rtol)
#     274 if est_lhd > best_lhd:
#     275     best_lhd, best_theta, best_S = est_lhd, est_theta, est_S
#
# File c:\Users\asus\Desktop\Аспирантура\Диссертация\Компоненты диссертации\Enhanced Program Complex (opt with Torch)\EM, deterministic model with missing values and known noise\em_dtools_kn.py:246, in EM(theta, S, X, Q, max_iter, rtol)
#     244 #print(f'diff of theta is {new_theta-theta} on iteration {EM_Iteration}')
#     245 print(f"new_theta={new_theta}")
# --> 246 A = A_ULA(L, new_theta)
#     247 new_S = CM_step_S(X_modified.T, A, Q)
#     248 #print(f'diff of S is {np.sum((new_S-S)**2)} on iteration {EM_Iteration}')
#
# File c:\Users\asus\Desktop\Аспирантура\Диссертация\Компоненты диссертации\Enhanced Program Complex (opt with Torch)\EM, deterministic model with missing values and known noise\em_dtools_kn.py:98, in A_ULA(L, theta)
#      94 def A_ULA(L, theta):
#      95     """
#      96     Создает матрицу управляющих векторов для массива сенсоров типа ULA
#      97     """
# ---> 98     return np.exp(-2j * np.pi * dist_ratio * np.arange(L).reshape(-1,1) * np.sin(theta))
#
# TypeError: loop of ufunc does not support argument 0 of type NoneType which has no callable sin method

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)

# %%
print(f"Погрешность в смысле разности углов в градусах: {np.abs(EM_theta1_deg-theta1_deg)}.\nПогрешность в смысле разности синусов углов {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах: [0.18504861].
# Погрешность в смысле разности синусов углов [0.00283183].
