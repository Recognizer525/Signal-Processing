# %% [markdown]
# # ECM-алгоритм для случая, когда шум известен, а сигналы предполагаются детерминированными

# %%
import numpy as np
import matplotlib.pyplot as plt
import em_dtools_kn
from functools import partial

# %%
dist_ratio = 0.5

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
Q_1 = 1.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1 = em_dtools_kn.gds(Num_emitters1, sample_size1)
n1 = em_dtools_kn.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + n1.T).T
# Out:
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after

# %%
S1.shape
# Out:
# (100, 1)

# %%
X1_with_mv = em_dtools_kn.MCAR(X1, [2,4], [80, 80])

# %%
EM_theta1_rad, lhd_1 = em_dtools_kn.multi_start_EM(X1, 1, Q_1, 10, max_iter=10, eps=1e-6)
# Out:
# 0-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [0.30670429]
# diff of theta is [1.26409204] on iteration 0
# diff of S is (2.4290898895105304+2.360578119577876j) on iteration 0
# incomplete likelihood is -1227.540936342971 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (10.487221363851162+0.0030693266038159805j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9
# 1-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [0.27272129]
# diff of theta is [-1.84351762] on iteration 0
# diff of S is (-17.055532708941115+3.375740864192088j) on iteration 0
# incomplete likelihood is -1205.666420533598 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (9.455070173682648-4.532955515815697j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9
# 2-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [2.81255642]
# diff of theta is [-1.24176009] on iteration 0
# diff of S is (-2.0520444645550358+8.694704610761661j) on iteration 0
# incomplete likelihood is -1239.4702692723627 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (9.621097737676028+3.111641708588481j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9
# 3-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [-0.30710596]
# diff of theta is [1.87790228] on iteration 0
# diff of S is (2.500874120398212-9.413080869994946j) on iteration 0
# incomplete likelihood is -1053.4999361594446 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (6.51343868964054-6.799883223918226j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9
# 4-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [1.060155]
# diff of theta is [-2.63095133] on iteration 0
# diff of S is (-10.1870148686028-4.631980802526295j) on iteration 0
# incomplete likelihood is -952.1525985017129 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (0.9404304334026514-0.009648018417850013j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9
# 5-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [1.21692436]
# diff of theta is [0.35387197] on iteration 0
# diff of S is (-10.055510074555245+4.139586354056757j) on iteration 0
# incomplete likelihood is -868.702942047847 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (0.3108952649800285+0.1787207148017147j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9
# 6-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [-2.93822307]
# diff of theta is [1.36742674] on iteration 0
# diff of S is (-11.835770864496059+12.19671585879176j) on iteration 0
# incomplete likelihood is -1056.878533186061 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (6.080348450719715+2.088215899191654j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9
# 7-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [-2.15798284]
# diff of theta is [0.58718651] on iteration 0
# diff of S is (0.37928772018154255+6.1236224914745225j) on iteration 0
# incomplete likelihood is -980.0358253677302 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (-3.4136189101510195+1.7775487924960816j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9
# 8-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [-2.63027473]
# diff of theta is [1.0594784] on iteration 0
# diff of S is (2.1028848156092153-2.7596921818721514j) on iteration 0
# incomplete likelihood is -1002.0998194454356 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (2.7985095692886164-5.109731150511337j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9
# 9-th start
# Shape of signals is (1, 100) before
# Shape of signals is (100, 1) after
# Initial theta = [-0.41970718]
# diff of theta is [-1.15108915] on iteration 0
# diff of S is (7.863491760326699-3.2641416805268264j) on iteration 0
# incomplete likelihood is -1013.5334829314784 on iteration 0
# diff of theta is [0.] on iteration 1
# diff of S is (0.8302397237505648-5.729686289599677j) on iteration 1
# incomplete likelihood is -840.8313897427962 on iteration 1
# diff of theta is [0.] on iteration 2
# diff of S is 0j on iteration 2
# incomplete likelihood is -840.8313897427962 on iteration 2
# diff of theta is [0.] on iteration 3
# diff of S is 0j on iteration 3
# incomplete likelihood is -840.8313897427962 on iteration 3
# diff of theta is [0.] on iteration 4
# diff of S is 0j on iteration 4
# incomplete likelihood is -840.8313897427962 on iteration 4
# diff of theta is [0.] on iteration 5
# diff of S is 0j on iteration 5
# incomplete likelihood is -840.8313897427962 on iteration 5
# diff of theta is [0.] on iteration 6
# diff of S is 0j on iteration 6
# incomplete likelihood is -840.8313897427962 on iteration 6
# diff of theta is [0.] on iteration 7
# diff of S is 0j on iteration 7
# incomplete likelihood is -840.8313897427962 on iteration 7
# diff of theta is [0.] on iteration 8
# diff of S is 0j on iteration 8
# incomplete likelihood is -840.8313897427962 on iteration 8
# diff of theta is [0.] on iteration 9
# diff of S is 0j on iteration 9
# incomplete likelihood is -840.8313897427962 on iteration 9

# %%
EM_theta1_deg = np.rad2deg(EM_theta1_rad)

# %%
print(f"Погрешность в смысле разности углов в градусах: {np.abs(EM_theta1_deg-theta1_deg)}.\nПогрешность в смысле разности синусов углов {np.abs(np.sin(EM_theta1_rad)-np.sin(theta1_rad))}.")
# Out:
# Погрешность в смысле разности углов в градусах: [61.35211024].
# Погрешность в смысле разности синусов углов [0.52057446].
