# %%
import numpy as np
import sensors
import ecm_stoch

# %%
dist_ratio = 0.5

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.5] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
P_1 = 1 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация шума
Q_1 = 1.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
n1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + n1.T).T

# %%
X1_with_mv = sensors.MCAR(X1, [2,4], [40, 40])

# %%
ECM_theta1_rad, ECM_P, lhd_1 = ecm_stoch.multi_start_ECM(X1, 1, Q_1, 10, max_iter=10, rtol=1e-6)
# Out:
# 0-th start
# Initial theta = [-2.83488836]
# likelihood is -1703.5384882917551 on iteration 0
# likelihood is -1753.4856066014247 on iteration 1
# likelihood is -1754.6140191045922 on iteration 5
# 1-th start
# Initial theta = [-2.86887136]
# likelihood is -1703.5719923691952 on iteration 0
# likelihood is -1753.8358934977914 on iteration 1
# likelihood is -1754.858919997482 on iteration 5
# 2-th start
# Initial theta = [-0.32903623]
# likelihood is -1722.9725708357244 on iteration 0
# likelihood is -1753.9481340714074 on iteration 1
# likelihood is -1754.611421446911 on iteration 5
# 3-th start
# Initial theta = [2.8344867]
# likelihood is -1663.820841299027 on iteration 0
# likelihood is -1719.7139696166528 on iteration 1
# likelihood is -1709.8611970755017 on iteration 5
# 4-th start
# Initial theta = [-2.08143765]
# likelihood is -1711.4612214853462 on iteration 0
# likelihood is -1754.1192797280041 on iteration 1
# likelihood is -1755.243088871 on iteration 5
# 5-th start
# Initial theta = [-1.9246683]
# likelihood is -1712.97889480661 on iteration 0
# likelihood is -1754.4158798886904 on iteration 1
# likelihood is -1755.3710309175917 on iteration 5
# 6-th start
# Initial theta = [0.20336959]
# likelihood is -1515.103432016664 on iteration 0
# likelihood is -1724.8271871491777 on iteration 1
# likelihood is -1720.9446882071331 on iteration 5
# 7-th start
# Initial theta = [0.98360982]
# likelihood is -1629.221760493845 on iteration 0
# likelihood is -1748.519699878341 on iteration 1
# likelihood is -1740.1022402068843 on iteration 5
# 8-th start
# Initial theta = [0.51131793]
# likelihood is -1529.8990507972057 on iteration 0
# likelihood is -1701.8494189754128 on iteration 1
# likelihood is -1706.205918049596 on iteration 5
# 9-th start
# Initial theta = [2.72188548]
# likelihood is -1645.8983008936086 on iteration 0
# likelihood is -1707.963318037739 on iteration 1
# likelihood is -1706.7298377239092 on iteration 5
# best_start=8

# %%
ECM_theta1_rad
# Out:
# array([0.50885696])
