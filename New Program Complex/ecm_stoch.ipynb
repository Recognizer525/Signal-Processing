# %%
import numpy as np
import sensors
import ecm_stoch

# %%
dist_ratio = 0.5

# %%
Num_sensors1 = 5
Num_emitters1 = 1
sample_size1 = 100
theta1_rad = [0.7] # Направление прибытия (DOA) в радианах
theta1_deg = np.rad2deg(theta1_rad[0]) # Направление прибытия (DOA) в градусах
P_1 = 1 * np.eye(Num_emitters1, dtype=np.float64) # Ковариация шума
Q_1 = 1.1 * np.eye(Num_sensors1, dtype=np.float64) # Ковариация шума
A1 = np.exp(-2j * np.pi * dist_ratio * np.arange(Num_sensors1).reshape(-1,1) * np.sin(theta1_rad)) # Матрица управляющих векторов
# Генерация векторов сигнала, шума и принятого сигнала
S1 = sensors.gss(Num_emitters1, sample_size1, P_1)
n1 = sensors.gss(Num_sensors1, sample_size1, Q_1)
X1 = (A1 @ S1.T + n1.T).T

# %%
X1_with_mv = sensors.MCAR(X1, [2,4], [40, 40])

# %%
ECM_theta1_rad, ECM_P, lhd_1 = ecm_stoch.multi_start_ECM(X1, 1, Q_1, 10, max_iter=10, rtol=1e-3)
# Out:
# 0-th start
# Initial theta = [-2.83488836]
# likelihood is -1084.7627432454683 on iteration 0
# likelihood is -1067.7704913743212 on iteration 1
# likelihood is -1055.525450199443 on iteration 5
# 1-th start
# Initial theta = [-2.86887136]
# likelihood is -1088.2340673549386 on iteration 0
# likelihood is -1069.8791271546988 on iteration 1
# likelihood is -1055.7109069882258 on iteration 5
# 2-th start
# Initial theta = [-0.32903623]
# likelihood is -1084.821620625491 on iteration 0
# likelihood is -1067.3634511686946 on iteration 1
# likelihood is -1055.512847432075 on iteration 5
# 3-th start
# Initial theta = [2.8344867]
# likelihood is -1059.6713661671254 on iteration 0
# likelihood is -995.3503968791667 on iteration 1
# likelihood is -765.9517796247751 on iteration 5
# 4-th start
# Initial theta = [-2.08143765]
# likelihood is -1089.6278118886653 on iteration 0
# likelihood is -1072.2414739590029 on iteration 1
# likelihood is -1059.3640066065784 on iteration 5
# 5-th start
# Initial theta = [-1.9246683]
# likelihood is -1094.180515709165 on iteration 0
# likelihood is -1076.1680624882504 on iteration 1
# likelihood is -1061.6022602643268 on iteration 5
# 6-th start
# Initial theta = [0.20336959]
# likelihood is -1069.858687439626 on iteration 0
# likelihood is -1062.2252060406038 on iteration 1
# likelihood is -807.5926851371756 on iteration 5
# 7-th start
# Initial theta = [0.98360982]
# likelihood is -873.4859618262013 on iteration 0
# likelihood is -817.2956061410057 on iteration 1
# likelihood is -737.9101367610759 on iteration 5
# 8-th start
# Initial theta = [0.51131793]
# likelihood is -821.6164375529468 on iteration 0
# likelihood is -780.6899081660619 on iteration 1
# likelihood is -734.358850017175 on iteration 5
# 9-th start
# Initial theta = [2.72188548]
# likelihood is -918.9347344406928 on iteration 0
# likelihood is -846.4624535660519 on iteration 1
# likelihood is -740.1597353402052 on iteration 5
# best_start=6

# %%
ECM_theta1_rad
# Out:
# array([0.69046999])

# %%
ECM_P
# Out:
# array([[1.0752951]])
